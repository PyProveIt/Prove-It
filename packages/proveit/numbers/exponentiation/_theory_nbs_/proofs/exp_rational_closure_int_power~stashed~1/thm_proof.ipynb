# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">exponentiation</a>.<a class="ProveItLink" href="../../theorems.ipynb#exp_rational_closure_int_power">exp_rational_closure_int_power</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving exp_rational_closure_int_power
# Out:
# exp_rational_closure_int_power: forall_{a in Rational, b in Integer | a != 0} (a^{b} in Rational)
