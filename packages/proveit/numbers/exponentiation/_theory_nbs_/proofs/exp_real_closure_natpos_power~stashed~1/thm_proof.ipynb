# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">exponentiation</a>.<a class="ProveItLink" href="../../theorems.ipynb#exp_real_closure_natpos_power">exp_real_closure_natpos_power</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving exp_real_closure_natpos_power
# Out:
# exp_real_closure_natpos_power: forall_{a in Real, b in NaturalPos} (a^{b} in Real)
