# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet
from proveit.numbers import Exp, Natural, Rational

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Exp(a, b), Rational), And(InSet(a, Rational), InSet(b, Natural)))
# Out:
# expr: {a^{b} in Rational if a in Rational ,  b in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a^{b} \in \mathbb{Q} \textrm{ if } a \in \mathbb{Q} ,  b \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a^{b} in Rational if a in Rational ,  b in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a^{b} in Rational
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (a in Rational) and (b in Natural)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a^{b}, Rational)
#    core type: ExprTuple
#    sub-expressions: 6, 15
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Rational, b in Natural)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a^{b}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. a in Rational
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. b in Natural
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 16
# 11. (a, Rational)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (b, Natural)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. Rational
#     core type: Literal
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. Natural
#     core type: Literal
#     sub-expressions:
