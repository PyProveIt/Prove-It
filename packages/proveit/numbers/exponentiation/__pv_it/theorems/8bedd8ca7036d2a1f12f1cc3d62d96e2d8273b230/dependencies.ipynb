# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#exp_real_closure_nat_power">exp_real_closure_nat_power</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/exp_real_closure_nat_power/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.exponentiation import exp_real_closure_nat_power

# %%
# %dependencies exp_real_closure_nat_power
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on exp_real_closure_nat_power</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../physics/quantum/QPE/_theory_nbs_/proofs/all_abs_alpha_l_sqrd_are_real/thm_proof.ipynb">proveit.physics.quantum.QPE.all_abs_alpha_l_sqrd_are_real</a></dt><dd><a class="ProveItLink" href="../../../../../physics/quantum/QPE/__pv_it/theorems/5b8a7360996bf4708b971d54bd270430105bc8e90/expr.ipynb"><img src="../../../../../physics/quantum/QPE/__pv_it/theorems/5b8a7360996bf4708b971d54bd270430105bc8e90/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
