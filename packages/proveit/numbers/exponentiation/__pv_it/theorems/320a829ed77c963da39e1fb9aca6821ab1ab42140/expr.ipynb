# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, Lambda, k, n, x
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Exp, Mult, NaturalPos, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([x], Equals(Exp(x, n), Mult(ExprRange(k, x, one, n))), domain = Complex), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x)) if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{x \in \mathbb{C}}~\left(x^{n} = \left(x \cdot ..n \textrm{ repeats}.. \cdot x\right)\right) \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x)) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x)) if n in NaturalPos.
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. {forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x)) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. n in NaturalPos
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {x^{n} = (x * ..n repeats.. * x) if x in Complex.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 8. x -> {x^{n} = (x * ..n repeats.. * x) if x in Complex.
#    core type: Lambda
#    parameter: 29
#    body: 10
# ...
