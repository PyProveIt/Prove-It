# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.exponentiation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Exp, RationalNonZero, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(NotEquals(Exp(a, b), zero), And(InSet(a, RationalNonZero), InSet(b, RationalNonZero)))
# Out:
# expr: {a^{b} != 0 if a in RationalNonZero ,  b in RationalNonZero.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a^{b} \neq 0 \textrm{ if } a \in \mathbb{Q}^{\neq 0} ,  b \in \mathbb{Q}^{\neq 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a^{b} != 0 if a in RationalNonZero ,  b in RationalNonZero.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a^{b} != 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in RationalNonZero) and (b in RationalNonZero)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. !=
#    core type: Literal
#    sub-expressions:
# 4. (a^{b}, 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in RationalNonZero, b in RationalNonZero)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. a^{b}
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a in RationalNonZero
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. b in RationalNonZero
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (a, RationalNonZero)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (b, RationalNonZero)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. RationalNonZero
#     core type: Literal
#     sub-expressions:
