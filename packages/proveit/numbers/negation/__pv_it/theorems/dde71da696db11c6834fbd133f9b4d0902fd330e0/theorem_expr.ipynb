# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#negated_strong_bound">negated_strong_bound</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.negation import negated_strong_bound

# %%
# check that the built expression is the same as the stored expression
assert negated_strong_bound.expr == stored_expr
assert negated_strong_bound.expr._style_id == stored_expr._style_id
print("Passed sanity check: negated_strong_bound matches stored_expr")
# Out:
# Passed sanity check: negated_strong_bound matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(negated_strong_bound.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{R}~|~x < y}~\left(\left(-x\right) > \left(-y\right)\right)

# %%
negated_strong_bound.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
negated_strong_bound.expr_info()
# Out:
# 0. forall_{x, y in Real | x < y} ((-x) > (-y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {(-x) > (-y) if x in Real ,  y in Real ,  x < y.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {(-x) > (-y) if x in Real ,  y in Real ,  x < y.
#    core type: Lambda
#    parameters: 22\n   body: 4
# 4. {(-x) > (-y) if x in Real ,  y in Real ,  x < y.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (-x) > (-y)
#    core type: Operation
#    operator: 21
#    operands: 7
# 6. (x in Real) and (y in Real) and (x < y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (-y, -x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Real, y in Real, x < y)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. -y
#     core type: Operation
#     operator: 16
#     operand: 25
# 11. -x
# ...
