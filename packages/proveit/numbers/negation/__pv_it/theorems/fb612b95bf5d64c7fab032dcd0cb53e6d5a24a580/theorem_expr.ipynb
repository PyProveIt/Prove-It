# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#rational_nonpos_closure">rational_nonpos_closure</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.negation import rational_nonpos_closure

# %%
# check that the built expression is the same as the stored expression
assert rational_nonpos_closure.expr == stored_expr
assert rational_nonpos_closure.expr._style_id == stored_expr._style_id
print("Passed sanity check: rational_nonpos_closure matches stored_expr")
# Out:
# Passed sanity check: rational_nonpos_closure matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(rational_nonpos_closure.latex())
# Out:
# \vdash \forall_{a \in \mathbb{Q}^{\geq 0}}~\left(\left(-a\right) \in \mathbb{Q}^{\leq 0}\right)

# %%
rational_nonpos_closure.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
rational_nonpos_closure.expr_info()
# Out:
# 0. forall_{a in RationalNonNeg} ((-a) in RationalNonPos)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {(-a) in RationalNonPos if a in RationalNonNeg.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {(-a) in RationalNonPos if a in RationalNonNeg.
#    core type: Lambda
#    parameter: 15
#    body: 4
# 4. {(-a) in RationalNonPos if a in RationalNonNeg.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (-a) in RationalNonPos
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. a in RationalNonNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (-a, RationalNonPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a, RationalNonNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. -a
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. RationalNonPos
# ...
