# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import InSet
from proveit.numbers import Neg, RationalNonZero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(InSet(Neg(a), RationalNonZero), InSet(a, RationalNonZero))))
# Out:
# expr: (a -> {(-a) in RationalNonZero if a in RationalNonZero.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{\left(-a\right) \in \mathbb{Q}^{\neq 0} \textrm{ if } a \in \mathbb{Q}^{\neq 0}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {(-a) in RationalNonZero if a in RationalNonZero.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {(-a) in RationalNonZero if a in RationalNonZero.
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. {(-a) in RationalNonZero if a in RationalNonZero.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (-a) in RationalNonZero
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. a in RationalNonZero
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (-a, RationalNonZero)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (a, RationalNonZero)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 8. -a
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. RationalNonZero
#    core type: Literal
#    sub-expressions:
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (a)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. a
#     core type: Variable
#     sub-expressions:
