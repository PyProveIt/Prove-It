# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.logic import Forall, InSet
from proveit.numbers import Neg, RealNonNeg, RealNonPos

# %%
# build up the expression from sub-expressions
expr = Forall([a], InSet(Neg(a), RealNonPos), domain = RealNonNeg)
# Out:
# expr: forall_{a in RealNonNeg} ((-a) in RealNonPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}^{\ge 0}}~\left(\left(-a\right) \in \mathbb{R}^{\le 0}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in RealNonNeg} ((-a) in RealNonPos)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {(-a) in RealNonPos if a in RealNonNeg.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {(-a) in RealNonPos if a in RealNonNeg.
#    core type: Lambda
#    parameter: 15
#    body: 4
# 4. {(-a) in RealNonPos if a in RealNonNeg.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (-a) in RealNonPos
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. a in RealNonNeg
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (-a, RealNonPos)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. -a
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. RealNonPos
#     core type: Literal
#     sub-expressions:
# 12. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (a)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. a
#     core type: Variable
#     sub-expressions:
