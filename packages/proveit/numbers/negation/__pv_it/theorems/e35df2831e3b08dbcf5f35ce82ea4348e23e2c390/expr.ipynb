# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a
from proveit.logic import InSet
from proveit.numbers import Neg, RationalNeg, RationalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Neg(a), RationalNeg), InSet(a, RationalPos))
# Out:
# expr: {(-a) in RationalNeg if a in RationalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(-a\right) \in \mathbb{Q}^- \textrm{ if } a \in \mathbb{Q}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(-a) in RationalNeg if a in RationalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (-a) in RationalNeg
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a in RationalPos
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (-a, RationalNeg)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (a, RationalPos)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 6. -a
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. RationalNeg
#    core type: Literal
#    sub-expressions:
# 8. RationalPos
#    core type: Literal
#    sub-expressions:
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (a)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. a
#     core type: Variable
#     sub-expressions:
