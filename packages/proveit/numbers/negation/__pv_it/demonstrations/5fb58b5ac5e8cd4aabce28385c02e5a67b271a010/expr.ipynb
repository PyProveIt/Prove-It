# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.negation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, d
from proveit.numbers import Mult, Neg

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Neg(Mult(a, b, c, d)), Neg(Mult(b, Mult(a, c, d))))
# Out:
# expr: (-(a * b * c * d), -(b * (a * c * d)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(-\left(a \cdot b \cdot c \cdot d\right), -\left(b \cdot \left(a \cdot c \cdot d\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (-(a * b * c * d), -(b * (a * c * d)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. -(a * b * c * d)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. -(b * (a * c * d))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (a * b * c * d)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. -
#    core type: Literal
#    sub-expressions:
# 5. (b * (a * c * d))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. a * b * c * d
#    core type: Operation
#    operator: 12
#    operands: 8
# 7. b * (a * c * d)
#    core type: Operation
#    operator: 12
#    operands: 9
# 8. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 14, 10, 15, 16
# 9. (b, a * c * d)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. a * c * d
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a, c, d)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. d
#     core type: Variable
#     sub-expressions:
