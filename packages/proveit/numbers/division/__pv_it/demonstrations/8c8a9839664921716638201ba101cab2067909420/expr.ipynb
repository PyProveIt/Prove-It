# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d
from proveit.logic import Equals
from proveit.numbers import Add, Mult, frac, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(Add(a, b, c), b)
expr = Equals(frac(sub_expr1, Mult(d, a)), Mult(frac(sub_expr1, d), frac(one, a)))
# Out:
# expr: (((a + b + c) * b) / (d * a)) = ((((a + b + c) * b) / d) * (1 / a))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{\left(a + b + c\right) \cdot b}{d \cdot a} = \left(\frac{\left(a + b + c\right) \cdot b}{d} \cdot \frac{1}{a}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (((a + b + c) * b) / (d * a)) = ((((a + b + c) * b) / d) * (1 / a))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (((a + b + c) * b) / (d * a), (((a + b + c) * b) / d) * (1 / a))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. ((a + b + c) * b) / (d * a)
#    core type: Operation
#    operator: 12
#    operands: 5
# 4. (((a + b + c) * b) / d) * (1 / a)
#    core type: Operation
#    operator: 17
#    operands: 6
# 5. ((a + b + c) * b, d * a)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 6. (((a + b + c) * b) / d, 1 / a)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. d * a
#    core type: Operation
#    operator: 17
#    operands: 10
# 8. ((a + b + c) * b) / d
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. 1 / a
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (d, a)
#     core type: ExprTuple
#     sub-expressions: 15, 22
# 11. ((a + b + c) * b, d)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (1, a)
#     core type: ExprTuple
#     sub-expressions: 16, 22
# 14. (a + b + c) * b
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. d
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (a + b + c, b)
#     core type: ExprTuple
#     sub-expressions: 19, 23
# 19. a + b + c
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
