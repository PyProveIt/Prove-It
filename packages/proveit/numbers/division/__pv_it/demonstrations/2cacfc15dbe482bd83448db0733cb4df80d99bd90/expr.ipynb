# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, d
from proveit.numbers import Add, Mult, frac, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(Add(a, b, c), b)
expr = ExprTuple(frac(sub_expr1, Mult(a, d)), Mult(frac(one, a), frac(sub_expr1, d)))
# Out:
# expr: (((a + b + c) * b) / (a * d), (1 / a) * (((a + b + c) * b) / d))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{\left(a + b + c\right) \cdot b}{a \cdot d}, \frac{1}{a} \cdot \frac{\left(a + b + c\right) \cdot b}{d}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (((a + b + c) * b) / (a * d), (1 / a) * (((a + b + c) * b) / d))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ((a + b + c) * b) / (a * d)
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (1 / a) * (((a + b + c) * b) / d)
#    core type: Operation
#    operator: 15
#    operands: 4
# 3. ((a + b + c) * b, a * d)
#    core type: ExprTuple
#    sub-expressions: 13, 5
# 4. (1 / a, ((a + b + c) * b) / d)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. a * d
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. 1 / a
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. ((a + b + c) * b) / d
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (a, d)
#    core type: ExprTuple
#    sub-expressions: 20, 14
# 9. (1, a)
#    core type: ExprTuple
#    sub-expressions: 12, 20
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. ((a + b + c) * b, d)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. (a + b + c) * b
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. d
#     core type: Variable
#     sub-expressions:
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a + b + c, b)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 17. a + b + c
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. c
#     core type: Variable
#     sub-expressions:
