# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, d
from proveit.numbers import Add, Mult, frac

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(a, b, c)
expr = ExprTuple(Mult(frac(sub_expr1, a), frac(b, d)), frac(Mult(sub_expr1, b), Mult(a, d)))
# Out:
# expr: (((a + b + c) / a) * (b / d), ((a + b + c) * b) / (a * d))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{a + b + c}{a} \cdot \frac{b}{d}, \frac{\left(a + b + c\right) \cdot b}{a \cdot d}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (((a + b + c) / a) * (b / d), ((a + b + c) * b) / (a * d))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ((a + b + c) / a) * (b / d)
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. ((a + b + c) * b) / (a * d)
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. ((a + b + c) / a, b / d)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. ((a + b + c) * b, a * d)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. (a + b + c) / a
#    core type: Operation
#    operator: 10
#    operands: 9
# 6. b / d
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. (a + b + c) * b
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. a * d
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (a + b + c, a)
#    core type: ExprTuple
#    sub-expressions: 15, 19
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. (b, d)
#     core type: ExprTuple
#     sub-expressions: 20, 16
# 12. (a + b + c, b)
#     core type: ExprTuple
#     sub-expressions: 15, 20
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (a, d)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 15. a + b + c
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. d
#     core type: Variable
#     sub-expressions:
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
