# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#reverse_fraction_of_subtractions">reverse_fraction_of_subtractions</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import reverse_fraction_of_subtractions

# %%
# check that the built expression is the same as the stored expression
assert reverse_fraction_of_subtractions.expr == stored_expr
assert reverse_fraction_of_subtractions.expr._style_id == stored_expr._style_id
print("Passed sanity check: reverse_fraction_of_subtractions matches stored_expr")
# Out:
# Passed sanity check: reverse_fraction_of_subtractions matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(reverse_fraction_of_subtractions.latex())
# Out:
# \vdash \forall_{w, x, y, z \in \mathbb{C}~|~y \neq z}~\left(\frac{w - x}{y - z} = \frac{x - w}{z - y}\right)

# %%
reverse_fraction_of_subtractions.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
reverse_fraction_of_subtractions.expr_info()
# Out:
# 0. forall_{w, x, y, z in Complex | y != z} (((w - x) / (y - z)) = ((x - w) / (z - y)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((w, x, y, z) -> {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex ,  y != z.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (w, x, y, z) -> {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex ,  y != z.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (w, x, y, z)
#    core type: ExprTuple
#    sub-expressions: 50, 48, 51, 49
# 5. {((w - x) / (y - z)) = ((x - w) / (z - y)) if w in Complex ,  x in Complex ,  y in Complex ,  z in Complex ,  y != z.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. ((w - x) / (y - z)) = ((x - w) / (z - y))
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
