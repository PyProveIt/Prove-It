# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, x, y
from proveit.logic import Forall, InSet
from proveit.numbers import LessEq, RealNeg, RealNonNeg, frac, greater_eq

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(Forall([x, y], greater_eq(frac(a, x), frac(a, y)), domain = RealNeg, condition = LessEq(x, y)), InSet(a, RealNonNeg)))
# Out:
# expr: a -> {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{\forall_{x, y \in \mathbb{R}^-~|~x \leq y}~\left(\frac{a}{x} \geq \frac{a}{y}\right) \textrm{ if } a \in \mathbb{R}^{\ge 0}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a -> {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. a in RealNonNeg
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((x, y) -> {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 28, 8
# 7. (x, y) -> {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.
#    core type: Lambda
#    parameters: 27\n   body: 9
# 8. RealNonNeg
#    core type: Literal
#    sub-expressions:
# ...
