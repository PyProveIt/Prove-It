# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import ComplexNonZero, frac, zero

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(NotEquals(frac(a, b), zero), And(InSet(a, ComplexNonZero), InSet(b, ComplexNonZero))))
# Out:
# expr: (a, b) -> {(a / b) != 0 if a in ComplexNonZero ,  b in ComplexNonZero.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\frac{a}{b} \neq 0 \textrm{ if } a \in \mathbb{C}^{\neq 0} ,  b \in \mathbb{C}^{\neq 0}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(a / b) != 0 if a in ComplexNonZero ,  b in ComplexNonZero.
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. {(a / b) != 0 if a in ComplexNonZero ,  b in ComplexNonZero.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a / b) != 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in ComplexNonZero) and (b in ComplexNonZero)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. !=
#    core type: Literal
#    sub-expressions:
# 5. (a / b, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in ComplexNonZero, b in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. a / b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. a in ComplexNonZero
#     core type: Operation
#     operator: 15
#     operands: 14
# 11. b in ComplexNonZero
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. /
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. (a, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. ComplexNonZero
#     core type: Literal
#     sub-expressions:
