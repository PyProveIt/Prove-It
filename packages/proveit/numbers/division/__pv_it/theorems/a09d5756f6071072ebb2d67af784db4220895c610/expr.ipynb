# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x, y, z
from proveit.logic import And, Equals, InSet, NotEquals
from proveit.numbers import Complex, Mult, frac, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(frac(x, z), y), frac(Mult(x, y), z)), And(InSet(x, Complex), InSet(y, Complex), InSet(z, Complex), NotEquals(z, zero)))
# Out:
# expr: {((x / z) * y) = ((x * y) / z) if x in Complex ,  y in Complex ,  z in Complex ,  z != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\frac{x}{z} \cdot y\right) = \frac{x \cdot y}{z} \textrm{ if } x \in \mathbb{C} ,  y \in \mathbb{C} ,  z \in \mathbb{C} ,  z \neq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {((x / z) * y) = ((x * y) / z) if x in Complex ,  y in Complex ,  z in Complex ,  z != 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((x / z) * y) = ((x * y) / z)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complex) and (y in Complex) and (z in Complex) and (z != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x / z) * y, (x * y) / z)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex, y in Complex, z in Complex, z != 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. (x / z) * y
#    core type: Operation
#    operator: 27
#    operands: 13
# 8. (x * y) / z
#    core type: Operation
#    operator: 25
#    operands: 14
# 9. x in Complex
#    core type: Operation
#    operator: 17
#    operands: 15
# 10. y in Complex
#     core type: Operation
#     operator: 17
# ...
