# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x, y, z
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Lambda([x, z], Conditional(Forall([y], Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), domain = Complex), And(InSet(x, ComplexNonZero), InSet(z, ComplexNonZero))))
# Out:
# expr: (x, z) -> {forall_{y in Complex} (((x * y) / (x * z)) = (y / z)) if x in ComplexNonZero ,  z in ComplexNonZero.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, z\right) \mapsto \left\{\forall_{y \in \mathbb{C}}~\left(\frac{x \cdot y}{x \cdot z} = \frac{y}{z}\right) \textrm{ if } x \in \mathbb{C}^{\neq 0} ,  z \in \mathbb{C}^{\neq 0}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, z) -> {forall_{y in Complex} (((x * y) / (x * z)) = (y / z)) if x in ComplexNonZero ,  z in ComplexNonZero.
#    core type: Lambda
#    parameters: 31\n   body: 1
# 1. {forall_{y in Complex} (((x * y) / (x * z)) = (y / z)) if x in ComplexNonZero ,  z in ComplexNonZero.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{y in Complex} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (x in ComplexNonZero) and (z in ComplexNonZero)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (y -> {((x * y) / (x * z)) = (y / z) if y in Complex.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in ComplexNonZero, z in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. y -> {((x * y) / (x * z)) = (y / z) if y in Complex.
#    core type: Lambda
#    parameter: 32
# ...
