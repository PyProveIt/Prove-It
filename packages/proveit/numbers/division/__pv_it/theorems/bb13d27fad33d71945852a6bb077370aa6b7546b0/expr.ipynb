# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import Forall
from proveit.numbers import LessEq, RealPos, frac

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], LessEq(frac(a, x), frac(a, y)), domain = RealPos, condition = LessEq(x, y))
# Out:
# expr: forall_{x, y in RealPos | x <= y} ((a / x) <= (a / y))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, y \in \mathbb{R}^+~|~x \leq y}~\left(\frac{a}{x} \leq \frac{a}{y}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, y in RealPos | x <= y} ((a / x) <= (a / y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {(a / x) <= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {(a / x) <= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.
#    core type: Lambda
#    parameters: 22\n   body: 4
# 4. {(a / x) <= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a / x) <= (a / y)
#    core type: Operation
#    operator: 21
#    operands: 7
# 6. (x in RealPos) and (y in RealPos) and (x <= y)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a / x, a / y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in RealPos, y in RealPos, x <= y)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 10. a / x
#     core type: Operation
#     operator: 16
#     operands: 15
# 11. a / y
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. x in RealPos
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. y in RealPos
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. x <= y
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. (a, x)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (a, y)
#     core type: ExprTuple
#     sub-expressions: 23, 26
# 18. (x, RealPos)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (y, RealPos)
#     core type: ExprTuple
#     sub-expressions: 26, 24
# 21. <=
#     core type: Literal
#     sub-expressions:
# 22. (x, y)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. RealPos
#     core type: Literal
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. y
#     core type: Variable
#     sub-expressions:
