# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, e
from proveit.logic import Equals, Forall
from proveit.numbers import ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Forall([b, c, e], Equals(Mult(frac(Mult(a, b), c), frac(d, Mult(b, e))), Mult(frac(a, c), frac(d, e))), domain = ComplexNonZero)
# Out:
# expr: forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{b, c, e \in \mathbb{C}^{\neq 0}}~\left(\left(\frac{a \cdot b}{c} \cdot \frac{d}{b \cdot e}\right) = \left(\frac{a}{c} \cdot \frac{d}{e}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((b, c, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (b, c, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (b, c, e)
#    core type: ExprTuple
#    sub-expressions: 41, 35, 42
# 5. {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (b in ComplexNonZero) and (c in ComplexNonZero) and (e in ComplexNonZero)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (((a * b) / c) * (d / (b * e)), (a / c) * (d / e))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (b in ComplexNonZero, c in ComplexNonZero, e in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 12. ((a * b) / c) * (d / (b * e))
#     core type: Operation
#     operator: 38
#     operands: 17
# 13. (a / c) * (d / e)
#     core type: Operation
#     operator: 38
#     operands: 18
# 14. b in ComplexNonZero
#     core type: Operation
#     operator: 21
#     operands: 19
# 15. c in ComplexNonZero
#     core type: Operation
#     operator: 21
#     operands: 20
# 16. e in ComplexNonZero
#     core type: Operation
#     operator: 21
#     operands: 22
# 17. ((a * b) / c, d / (b * e))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. (a / c, d / e)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 19. (b, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 41, 27
# 20. (c, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 35, 27
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (e, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 42, 27
# 23. (a * b) / c
#     core type: Operation
#     operator: 31
#     operands: 28
# 24. d / (b * e)
#     core type: Operation
#     operator: 31
#     operands: 29
# 25. a / c
#     core type: Operation
#     operator: 31
#     operands: 30
# 26. d / e
#     core type: Operation
#     operator: 31
#     operands: 32
# 27. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 28. (a * b, c)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 29. (d, b * e)
#     core type: ExprTuple
#     sub-expressions: 36, 34
# 30. (a, c)
#     core type: ExprTuple
#     sub-expressions: 40, 35
# 31. /
#     core type: Literal
#     sub-expressions:
# 32. (d, e)
#     core type: ExprTuple
#     sub-expressions: 36, 42
# 33. a * b
#     core type: Operation
#     operator: 38
#     operands: 37
# 34. b * e
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. c
#     core type: Variable
#     sub-expressions:
# 36. d
#     core type: Variable
#     sub-expressions:
# 37. (a, b)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (b, e)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. e
#     core type: Variable
#     sub-expressions:
