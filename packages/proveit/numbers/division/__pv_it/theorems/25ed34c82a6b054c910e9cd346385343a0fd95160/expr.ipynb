# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, x, y
from proveit.logic import And, Equals, InSet
from proveit.numbers import ComplexNonZero, Mult, frac, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y], Conditional(Equals(frac(x, Mult(x, y)), frac(one, y)), And(InSet(x, ComplexNonZero), InSet(y, ComplexNonZero)))))
# Out:
# expr: ((x, y) -> {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y\right) \mapsto \left\{\frac{x}{x \cdot y} = \frac{1}{y} \textrm{ if } x \in \mathbb{C}^{\neq 0} ,  y \in \mathbb{C}^{\neq 0}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y) -> {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y) -> {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.
#    core type: Lambda
#    parameters: 23\n   body: 2
# 2. {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (x / (x * y)) = (1 / y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in ComplexNonZero) and (y in ComplexNonZero)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x / (x * y), 1 / y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in ComplexNonZero, y in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. x / (x * y)
#    core type: Operation
#    operator: 14
#    operands: 13
# ...
