# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, w, x, y, z
from proveit.logic import And, Equals, InSet
from proveit.numbers import ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Mult(frac(x, z), frac(y, w)), frac(Mult(x, y), Mult(z, w))), And(InSet(z, ComplexNonZero), InSet(w, ComplexNonZero)))
# Out:
# expr: {((x / z) * (y / w)) = ((x * y) / (z * w)) if z in ComplexNonZero ,  w in ComplexNonZero.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\frac{x}{z} \cdot \frac{y}{w}\right) = \frac{x \cdot y}{z \cdot w} \textrm{ if } z \in \mathbb{C}^{\neq 0} ,  w \in \mathbb{C}^{\neq 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {((x / z) * (y / w)) = ((x * y) / (z * w)) if z in ComplexNonZero ,  w in ComplexNonZero.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. ((x / z) * (y / w)) = ((x * y) / (z * w))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (z in ComplexNonZero) and (w in ComplexNonZero)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ((x / z) * (y / w), (x * y) / (z * w))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (z in ComplexNonZero, w in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (x / z) * (y / w)
#    core type: Operation
#    operator: 25
#    operands: 11
# 8. (x * y) / (z * w)
#    core type: Operation
#    operator: 22
#    operands: 12
# 9. z in ComplexNonZero
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. w in ComplexNonZero
#     core type: Operation
# ...
