# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, x, y, z
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([y], Equals(frac(Mult(x, y), Mult(x, z)), frac(y, z)), domain = Complex), And(InSet(x, ComplexNonZero), InSet(z, ComplexNonZero)))
# Out:
# expr: {forall_{y in Complex} (((x * y) / (x * z)) = (y / z)) if x in ComplexNonZero ,  z in ComplexNonZero.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{y \in \mathbb{C}}~\left(\frac{x \cdot y}{x \cdot z} = \frac{y}{z}\right) \textrm{ if } x \in \mathbb{C}^{\neq 0} ,  z \in \mathbb{C}^{\neq 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{y in Complex} (((x * y) / (x * z)) = (y / z)) if x in ComplexNonZero ,  z in ComplexNonZero.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{y in Complex} (((x * y) / (x * z)) = (y / z))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (x in ComplexNonZero) and (z in ComplexNonZero)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (y -> {((x * y) / (x * z)) = (y / z) if y in Complex.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in ComplexNonZero, z in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. y -> {((x * y) / (x * z)) = (y / z) if y in Complex.
#    core type: Lambda
#    parameter: 31
#    body: 10
# 8. x in ComplexNonZero
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. z in ComplexNonZero
#    core type: Operation
#    operator: 18
# ...
