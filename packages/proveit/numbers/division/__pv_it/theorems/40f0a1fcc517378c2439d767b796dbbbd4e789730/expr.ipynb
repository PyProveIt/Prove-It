# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, d, e
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Complex, ComplexNonZero, Mult, frac

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([b, c, e], Equals(Mult(frac(Mult(a, b), c), frac(d, Mult(b, e))), Mult(frac(a, c), frac(d, e))), domain = ComplexNonZero), And(InSet(a, Complex), InSet(d, Complex)))
# Out:
# expr: {forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))) if a in Complex ,  d in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{b, c, e \in \mathbb{C}^{\neq 0}}~\left(\left(\frac{a \cdot b}{c} \cdot \frac{d}{b \cdot e}\right) = \left(\frac{a}{c} \cdot \frac{d}{e}\right)\right) \textrm{ if } a \in \mathbb{C} ,  d \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e))) if a in Complex ,  d in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Complex) and (d in Complex)
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((b, c, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Complex, d in Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (b, c, e) -> {(((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)) if b in ComplexNonZero ,  c in ComplexNonZero ,  e in ComplexNonZero.
#    core type: Lambda
#    parameters: 9\n   body: 10
# ...
