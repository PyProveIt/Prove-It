# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import Forall, InSet
from proveit.numbers import LessEq, RealNeg, RealNonNeg, frac, greater_eq

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, y], greater_eq(frac(a, x), frac(a, y)), domain = RealNeg, condition = LessEq(x, y)), InSet(a, RealNonNeg))
# Out:
# expr: {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y \in \mathbb{R}^-~|~x \leq y}~\left(\frac{a}{x} \geq \frac{a}{y}\right) \textrm{ if } a \in \mathbb{R}^{\ge 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. a in RealNonNeg
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y) -> {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 27, 7
# 6. (x, y) -> {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.
#    core type: Lambda
#    parameters: 26\n   body: 8
# 7. RealNonNeg
#    core type: Literal
#    sub-expressions:
# 8. {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (a / x) >= (a / y)
#    core type: Operation
#    operator: 25
# ...
