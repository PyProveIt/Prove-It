# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#prod_of_fracs">prod_of_fracs</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import prod_of_fracs

# %%
# check that the built expression is the same as the stored expression
assert prod_of_fracs.expr == stored_expr
assert prod_of_fracs.expr._style_id == stored_expr._style_id
print("Passed sanity check: prod_of_fracs matches stored_expr")
# Out:
# Passed sanity check: prod_of_fracs matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(prod_of_fracs.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{C}}~\left[\forall_{z, w \in \mathbb{C}^{\neq 0}}~\left(\left(\frac{x}{z} \cdot \frac{y}{w}\right) = \frac{x \cdot y}{z \cdot w}\right)\right]

# %%
prod_of_fracs.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
prod_of_fracs.expr_info()
# Out:
# 0. forall_{x, y in Complex} [forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((x, y) -> {forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w))) if x in Complex ,  y in Complex.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (x, y) -> {forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w))) if x in Complex ,  y in Complex.
#    core type: Lambda
#    parameters: 39\n   body: 3
# 3. {forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w))) if x in Complex ,  y in Complex.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (x in Complex) and (y in Complex)
#    core type: Operation
#    operator: 20
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((z, w) -> {((x / z) * (y / w)) = ((x * y) / (z * w)) if z in ComplexNonZero ,  w in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x in Complex, y in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (z, w) -> {((x / z) * (y / w)) = ((x * y) / (z * w)) if z in ComplexNonZero ,  w in ComplexNonZero.
#    core type: Lambda
#    parameters: 41\n   body: 12
# 10. x in Complex
#     core type: Operation
#     operator: 29
#     operands: 13
# 11. y in Complex
#     core type: Operation
#     operator: 29
#     operands: 14
# 12. {((x / z) * (y / w)) = ((x * y) / (z * w)) if z in ComplexNonZero ,  w in ComplexNonZero.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 17
# 14. (y, Complex)
#     core type: ExprTuple
#     sub-expressions: 43, 17
# 15. ((x / z) * (y / w)) = ((x * y) / (z * w))
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. (z in ComplexNonZero) and (w in ComplexNonZero)
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. Complex
#     core type: Literal
#     sub-expressions:
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. ((x / z) * (y / w), (x * y) / (z * w))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. and
#     core type: Literal
#     sub-expressions:
# 21. (z in ComplexNonZero, w in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. (x / z) * (y / w)
#     core type: Operation
#     operator: 40
#     operands: 26
# 23. (x * y) / (z * w)
#     core type: Operation
#     operator: 37
#     operands: 27
# 24. z in ComplexNonZero
#     core type: Operation
#     operator: 29
#     operands: 28
# 25. w in ComplexNonZero
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (x / z, y / w)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. (x * y, z * w)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. (z, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 44, 35
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (w, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 45, 35
# 31. x / z
#     core type: Operation
#     operator: 37
#     operands: 36
# 32. y / w
#     core type: Operation
#     operator: 37
#     operands: 38
# 33. x * y
#     core type: Operation
#     operator: 40
#     operands: 39
# 34. z * w
#     core type: Operation
#     operator: 40
#     operands: 41
# 35. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 36. (x, z)
#     core type: ExprTuple
#     sub-expressions: 42, 44
# 37. /
#     core type: Literal
#     sub-expressions:
# 38. (y, w)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 39. (x, y)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. *
#     core type: Literal
#     sub-expressions:
# 41. (z, w)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. y
#     core type: Variable
#     sub-expressions:
# 44. z
#     core type: Variable
#     sub-expressions:
# 45. w
#     core type: Variable
#     sub-expressions:
