# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#frac_cancel_numer_left">frac_cancel_numer_left</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import frac_cancel_numer_left

# %%
# check that the built expression is the same as the stored expression
assert frac_cancel_numer_left.expr == stored_expr
assert frac_cancel_numer_left.expr._style_id == stored_expr._style_id
print("Passed sanity check: frac_cancel_numer_left matches stored_expr")
# Out:
# Passed sanity check: frac_cancel_numer_left matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(frac_cancel_numer_left.latex())
# Out:
# \vdash \forall_{x, y \in \mathbb{C}^{\neq 0}}~\left(\frac{x}{x \cdot y} = \frac{1}{y}\right)

# %%
frac_cancel_numer_left.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
frac_cancel_numer_left.expr_info()
# Out:
# 0. forall_{x, y in ComplexNonZero} ((x / (x * y)) = (1 / y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.
#    core type: Lambda
#    parameters: 25\n   body: 4
# 4. {(x / (x * y)) = (1 / y) if x in ComplexNonZero ,  y in ComplexNonZero.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x / (x * y)) = (1 / y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x in ComplexNonZero) and (y in ComplexNonZero)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (x / (x * y), 1 / y)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x in ComplexNonZero, y in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. x / (x * y)
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. 1 / y
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. x in ComplexNonZero
#     core type: Operation
#     operator: 19
#     operands: 18
# 14. y in ComplexNonZero
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. (x, x * y)
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 16. /
#     core type: Literal
#     sub-expressions:
# 17. (1, y)
#     core type: ExprTuple
#     sub-expressions: 22, 27
# 18. (x, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 26, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (y, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 27, 23
# 21. x * y
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (x, y)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. y
#     core type: Variable
#     sub-expressions:
