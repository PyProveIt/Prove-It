# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#weak_div_from_denom_bound__pos_over_neg">weak_div_from_denom_bound__pos_over_neg</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.division import weak_div_from_denom_bound__pos_over_neg

# %%
# check that the built expression is the same as the stored expression
assert weak_div_from_denom_bound__pos_over_neg.expr == stored_expr
assert weak_div_from_denom_bound__pos_over_neg.expr._style_id == stored_expr._style_id
print("Passed sanity check: weak_div_from_denom_bound__pos_over_neg matches stored_expr")
# Out:
# Passed sanity check: weak_div_from_denom_bound__pos_over_neg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(weak_div_from_denom_bound__pos_over_neg.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^{\ge 0}}~\left[\forall_{x, y \in \mathbb{R}^-~|~x \leq y}~\left(\frac{a}{x} \geq \frac{a}{y}\right)\right]

# %%
weak_div_from_denom_bound__pos_over_neg.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
weak_div_from_denom_bound__pos_over_neg.expr_info()
# Out:
# 0. forall_{a in RealNonNeg} [forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (a -> {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. a -> {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.
#    core type: Lambda
#    parameter: 30
#    body: 3
# 3. {forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y)) if a in RealNonNeg.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y in RealNeg | x <= y} ((a / x) >= (a / y))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. a in RealNonNeg
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y) -> {(a / x) >= (a / y) if x in RealNeg ,  y in RealNeg ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a, RealNonNeg)
# ...
