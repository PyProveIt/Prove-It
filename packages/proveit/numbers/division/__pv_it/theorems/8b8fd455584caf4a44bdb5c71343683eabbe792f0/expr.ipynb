# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, x, y
from proveit.logic import Forall, InSet
from proveit.numbers import Less, RealNeg, RealPos, frac, greater

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, y], greater(frac(a, x), frac(a, y)), domain = RealNeg, condition = Less(x, y)), InSet(a, RealPos))
# Out:
# expr: {forall_{x, y in RealNeg | x < y} ((a / x) > (a / y)) if a in RealPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y \in \mathbb{R}^-~|~x < y}~\left(\frac{a}{x} > \frac{a}{y}\right) \textrm{ if } a \in \mathbb{R}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y in RealNeg | x < y} ((a / x) > (a / y)) if a in RealPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y in RealNeg | x < y} ((a / x) > (a / y))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. a in RealPos
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y) -> {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a, RealPos)
#    core type: ExprTuple
#    sub-expressions: 27, 7
# 6. (x, y) -> {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.
#    core type: Lambda
#    parameters: 26\n   body: 8
# 7. RealPos
#    core type: Literal
#    sub-expressions:
# 8. {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. (a / x) > (a / y)
#    core type: Operation
#    operator: 25
#    operands: 11
# 10. (x in RealNeg) and (y in RealNeg) and (x < y)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a / y, a / x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. and
#     core type: Literal
#     sub-expressions:
# 13. (x in RealNeg, y in RealNeg, x < y)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 14. a / y
#     core type: Operation
#     operator: 20
#     operands: 19
# 15. a / x
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. x in RealNeg
#     core type: Operation
#     operator: 23
#     operands: 22
# 17. y in RealNeg
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. x < y
#     core type: Operation
#     operator: 25
#     operands: 26
# 19. (a, y)
#     core type: ExprTuple
#     sub-expressions: 27, 30
# 20. /
#     core type: Literal
#     sub-expressions:
# 21. (a, x)
#     core type: ExprTuple
#     sub-expressions: 27, 29
# 22. (x, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (y, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 30, 28
# 25. <
#     core type: Literal
#     sub-expressions:
# 26. (x, y)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. RealNeg
#     core type: Literal
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. y
#     core type: Variable
#     sub-expressions:
