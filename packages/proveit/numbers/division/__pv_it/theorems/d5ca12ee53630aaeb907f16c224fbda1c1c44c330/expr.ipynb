# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, x, y
from proveit.logic import Forall
from proveit.numbers import Less, RealNeg, RealPos, frac, greater

# %%
# build up the expression from sub-expressions
expr = Forall([a], Forall([x, y], greater(frac(a, x), frac(a, y)), domain = RealNeg, condition = Less(x, y)), domain = RealPos)
# Out:
# expr: forall_{a in RealPos} [forall_{x, y in RealNeg | x < y} ((a / x) > (a / y))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{R}^+}~\left[\forall_{x, y \in \mathbb{R}^-~|~x < y}~\left(\frac{a}{x} > \frac{a}{y}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in RealPos} [forall_{x, y in RealNeg | x < y} ((a / x) > (a / y))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (a -> {forall_{x, y in RealNeg | x < y} ((a / x) > (a / y)) if a in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. a -> {forall_{x, y in RealNeg | x < y} ((a / x) > (a / y)) if a in RealPos.
#    core type: Lambda
#    parameter: 30
#    body: 3
# 3. {forall_{x, y in RealNeg | x < y} ((a / x) > (a / y)) if a in RealPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y in RealNeg | x < y} ((a / x) > (a / y))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. a in RealPos
#    core type: Operation
#    operator: 26
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y) -> {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a, RealPos)
#    core type: ExprTuple
#    sub-expressions: 30, 10
# 9. (x, y) -> {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.
#    core type: Lambda
#    parameters: 29\n   body: 11
# 10. RealPos
#     core type: Literal
#     sub-expressions:
# 11. {(a / x) > (a / y) if x in RealNeg ,  y in RealNeg ,  x < y.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (a / x) > (a / y)
#     core type: Operation
#     operator: 28
#     operands: 14
# 13. (x in RealNeg) and (y in RealNeg) and (x < y)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (a / y, a / x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x in RealNeg, y in RealNeg, x < y)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 17. a / y
#     core type: Operation
#     operator: 23
#     operands: 22
# 18. a / x
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. x in RealNeg
#     core type: Operation
#     operator: 26
#     operands: 25
# 20. y in RealNeg
#     core type: Operation
#     operator: 26
#     operands: 27
# 21. x < y
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. (a, y)
#     core type: ExprTuple
#     sub-expressions: 30, 33
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (a, x)
#     core type: ExprTuple
#     sub-expressions: 30, 32
# 25. (x, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (y, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 28. <
#     core type: Literal
#     sub-expressions:
# 29. (x, y)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. RealNeg
#     core type: Literal
#     sub-expressions:
# 32. x
#     core type: Variable
#     sub-expressions:
# 33. y
#     core type: Variable
#     sub-expressions:
