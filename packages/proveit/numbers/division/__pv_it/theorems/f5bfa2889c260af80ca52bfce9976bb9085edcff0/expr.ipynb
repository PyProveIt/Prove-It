# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.division</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, x, y
from proveit.logic import And, InSet
from proveit.numbers import LessEq, RealPos, frac, greater_eq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, y], Conditional(greater_eq(frac(a, x), frac(a, y)), And(InSet(x, RealPos), InSet(y, RealPos), LessEq(x, y)))))
# Out:
# expr: ((x, y) -> {(a / x) >= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, y\right) \mapsto \left\{\frac{a}{x} \geq \frac{a}{y} \textrm{ if } x \in \mathbb{R}^+ ,  y \in \mathbb{R}^+ ,  x \leq y\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, y) -> {(a / x) >= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, y) -> {(a / x) >= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.
#    core type: Lambda
#    parameters: 20\n   body: 2
# 2. {(a / x) >= (a / y) if x in RealPos ,  y in RealPos ,  x <= y.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a / x) >= (a / y)
#    core type: Operation
#    operator: 19
#    operands: 5
# 4. (x in RealPos) and (y in RealPos) and (x <= y)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a / y, a / x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (x in RealPos, y in RealPos, x <= y)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. a / y
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. a / x
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. x in RealPos
# ...
