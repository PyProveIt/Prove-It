# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, j
from proveit.logic import InSet
from proveit.numbers import Add, Natural, greater, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(i, Natural), InSet(j, Natural), greater(Add(i, j), zero))
# Out:
# expr: (i in Natural, j in Natural, (i + j) > 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \in \mathbb{N}, j \in \mathbb{N}, \left(i + j\right) > 0\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i in Natural, j in Natural, (i + j) > 0)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. i in Natural
#    core type: Operation
#    operator: 5
#    operands: 4
# 2. j in Natural
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. (i + j) > 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j, Natural)
#    core type: ExprTuple
#    sub-expressions: 15, 9
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. (0, i + j)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Natural
#    core type: Literal
#    sub-expressions:
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. i + j
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (i, j)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. j
#     core type: Variable
#     sub-expressions:
