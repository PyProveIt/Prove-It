# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonzero_difference_if_different">nonzero_difference_if_different</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.addition.subtraction</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.addition.subtraction import nonzero_difference_if_different

# %%
# check that the built expression is the same as the stored expression
assert nonzero_difference_if_different.expr == stored_expr
assert nonzero_difference_if_different.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonzero_difference_if_different matches stored_expr")
# Out:
# Passed sanity check: nonzero_difference_if_different matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonzero_difference_if_different.latex())
# Out:
# \vdash \forall_{a, b~|~a \neq b}~\left(\left(a - b\right) \neq 0\right)

# %%
nonzero_difference_if_different.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonzero_difference_if_different.expr_info()
# Out:
# 0. forall_{a, b | a != b} ((a - b) != 0)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(a - b) != 0 if a != b.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(a - b) != 0 if a != b.
#    core type: Lambda
#    parameters: 9\n   body: 4
# 4. {(a - b) != 0 if a != b.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a - b) != 0
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. a != b
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a - b, 0)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. !=
#    core type: Literal
#    sub-expressions:
# 9. (a, b)
#    core type: ExprTuple
#    sub-expressions: 14, 18
# 10. a - b
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (a, -b)
# ...
