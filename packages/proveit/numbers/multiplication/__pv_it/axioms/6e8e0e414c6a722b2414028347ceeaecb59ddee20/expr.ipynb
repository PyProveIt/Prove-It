# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a_1_to_n, b], Equals(Mult(a_1_to_n, b), Mult(Mult(a_1_to_n), b)), domain = Complex), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n}, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n} \cdot b\right) = \left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \cdot b\right)\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.
#    core type: Lambda
#    parameter: 35
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in Natural
#    core type: Operation
#    operator: 29
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, Natural)
# ...
