# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Mult

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_n, b], Equals(Mult(a_1_to_n, b), Mult(Mult(a_1_to_n), b)), domain = Complex)
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{n}, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n} \cdot b\right) = \left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \cdot b\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex) and (b in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} * ..a_{_a}.. * a_{n} * b, (a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex, b in Complex)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. a_{1} * ..a_{_a}.. * a_{n} * b
#     core type: Operation
#     operator: 22
#     operands: 15
# 12. (a_{1} * ..a_{_a}.. * a_{n}) * b
#     core type: Operation
#     operator: 22
#     operands: 16
# 13. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 29
#     end_index: 30
# 14. b in Complex
#     core type: Operation
#     operator: 24
#     operands: 18
# 15. (a_{1}, ..a_{_a}.., a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 16. (a_{1} * ..a_{_a}.. * a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 17. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 34
#     body: 20
# 18. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 19. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. a_{_a} in Complex
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 26
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 31, 27
# 26. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 29
#     end_index: 30
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. _a -> a_{_a}
#     core type: Lambda
#     parameter: 34
#     body: 31
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. n
#     core type: Variable
#     sub-expressions:
# 31. a_{_a}
#     core type: IndexedVar
# variable: 32
# index: 34
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. (_a)
#     core type: ExprTuple
#     sub-expressions: 34
# 34. _a
#     core type: Variable
#     sub-expressions:
