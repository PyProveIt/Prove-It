# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, b, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_n, b], Conditional(Equals(Mult(a_1_to_n, b), Mult(Mult(a_1_to_n), b)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n), InSet(b, Complex))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}, b\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n} \cdot b\right) = \left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \cdot b\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{n} \in \mathbb{C} ,  b \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex) and (b in Complex)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} * ..a_{_a}.. * a_{n} * b, (a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. a_{1} * ..a_{_a}.. * a_{n} * b
#    core type: Operation
#    operator: 19
#    operands: 12
# 9. (a_{1} * ..a_{_a}.. * a_{n}) * b
#    core type: Operation
#    operator: 19
#    operands: 13
# 10. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 26
#     end_index: 27
# 11. b in Complex
#     core type: Operation
#     operator: 21
#     operands: 15
# 12. (a_{1}, ..a_{_a}.., a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 13. (a_{1} * ..a_{_a}.. * a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 31
#     body: 17
# 15. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 24
# 16. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. a_{_a} in Complex
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 24
# 23. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 26
#     end_index: 27
# 24. Complex
#     core type: Literal
#     sub-expressions:
# 25. _a -> a_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 28
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. a_{_a}
#     core type: IndexedVar
# variable: 29
# index: 31
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. (_a)
#     core type: ExprTuple
#     sub-expressions: 31
# 31. _a
#     core type: Variable
#     sub-expressions:
