# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, Equals, InSet
from proveit.numbers import Complex, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_n, b], Conditional(Equals(Mult(a_1_to_n, b), Mult(Mult(a_1_to_n), b)), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, n), InSet(b, Complex)))))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{n}, b\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n} \cdot b\right) = \left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \cdot b\right) \textrm{ if } a_{1} \in \mathbb{C} ,  \ldots ,  a_{n} \in \mathbb{C} ,  b \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 13\n   body: 2
# 2. {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex) and (b in Complex)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} * ..a_{_a}.. * a_{n} * b, (a_{1} * ..a_{_a}.. * a_{n}) * b)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex, b in Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. a_{1} * ..a_{_a}.. * a_{n} * b
#    core type: Operation
#    operator: 20
#    operands: 13
# 10. (a_{1} * ..a_{_a}.. * a_{n}) * b
#     core type: Operation
#     operator: 20
#     operands: 14
# 11. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 27
#     end_index: 28
# 12. b in Complex
#     core type: Operation
#     operator: 22
#     operands: 16
# 13. (a_{1}, ..a_{_a}.., a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 24, 19
# 14. (a_{1} * ..a_{_a}.. * a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 15. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 32
#     body: 18
# 16. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 19, 25
# 17. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. a_{_a} in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 29, 25
# 24. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 26
#     start_index: 27
#     end_index: 28
# 25. Complex
#     core type: Literal
#     sub-expressions:
# 26. _a -> a_{_a}
#     core type: Lambda
#     parameter: 32
#     body: 29
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. a_{_a}
#     core type: IndexedVar
# variable: 30
# index: 32
# 30. a
#     core type: Variable
#     sub-expressions:
# 31. (_a)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. _a
#     core type: Variable
#     sub-expressions:
