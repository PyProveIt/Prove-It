# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Equals, Forall
from proveit.numbers import Complex, Mult, Natural

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([a_1_to_n, b], Equals(Mult(a_1_to_n, b), Mult(Mult(a_1_to_n), b)), domain = Complex), domain = Natural)
# Out:
# expr: forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}}~\left[\forall_{a_{1}, \ldots, a_{n}, b \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n} \cdot b\right) = \left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \cdot b\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.
#    core type: Lambda
#    parameter: 37
#    body: 3
# 3. {forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)) if n in Natural.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{a_{1}, ..a_{_a}.., a_{n}, b in Complex} ((a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. n in Natural
#    core type: Operation
#    operator: 31
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 37, 10
# 9. (a_{1}, ..a_{_a}.., a_{n}, b) -> {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#    core type: Lambda
#    parameters: 22\n   body: 11
# 10. Natural
#     core type: Literal
#     sub-expressions:
# 11. {(a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b) if a_{1} in Complex ,  ..a_{_a} in Complex.. ,  a_{n} in Complex ,  b in Complex.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. (a_{1} * ..a_{_a}.. * a_{n} * b) = ((a_{1} * ..a_{_a}.. * a_{n}) * b)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{n} in Complex) and (b in Complex)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (a_{1} * ..a_{_a}.. * a_{n} * b, (a_{1} * ..a_{_a}.. * a_{n}) * b)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (a_{1} in Complex, ..a_{_a} in Complex.., a_{n} in Complex, b in Complex)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. a_{1} * ..a_{_a}.. * a_{n} * b
#     core type: Operation
#     operator: 29
#     operands: 22
# 19. (a_{1} * ..a_{_a}.. * a_{n}) * b
#     core type: Operation
#     operator: 29
#     operands: 23
# 20. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 36
#     end_index: 37
# 21. b in Complex
#     core type: Operation
#     operator: 31
#     operands: 25
# 22. (a_{1}, ..a_{_a}.., a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 33, 28
# 23. (a_{1} * ..a_{_a}.. * a_{n}, b)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 24. _a -> (a_{_a} in Complex)
#     core type: Lambda
#     parameter: 41
#     body: 27
# 25. (b, Complex)
#     core type: ExprTuple
#     sub-expressions: 28, 34
# 26. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. a_{_a} in Complex
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. b
#     core type: Variable
#     sub-expressions:
# 29. *
#     core type: Literal
#     sub-expressions:
# 30. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 33
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 38, 34
# 33. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 35
#     start_index: 36
#     end_index: 37
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. _a -> a_{_a}
#     core type: Lambda
#     parameter: 41
#     body: 38
# 36. 1
#     core type: Literal
#     sub-expressions:
# 37. n
#     core type: Variable
#     sub-expressions:
# 38. a_{_a}
#     core type: IndexedVar
# variable: 39
# index: 41
# 39. a
#     core type: Variable
#     sub-expressions:
# 40. (_a)
#     core type: ExprTuple
#     sub-expressions: 41
# 41. _a
#     core type: Variable
#     sub-expressions:
