# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import ComplexNonZero, Mult, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda([a_1_to_n], Conditional(NotEquals(Mult(a_1_to_n), zero), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), ComplexNonZero), one, n))))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{n}\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \neq 0 \textrm{ if } \left(a_{1} \in \mathbb{C}^{\neq 0}\right) \land \ldots \land \left(a_{n} \in \mathbb{C}^{\neq 0}\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Lambda
#    parameters: 12\n   body: 1
# 1. {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * ..a_{_a}.. * a_{n}) != 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. !=
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} * ..a_{_a}.. * a_{n}, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a_{1} in ComplexNonZero, ..a_{_a} in ComplexNonZero.., a_{n} in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in ComplexNonZero), ..(a_{_a} in ComplexNonZero).., (a_{n} in ComplexNonZero)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 17
#     end_index: 18
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 13. _a -> (a_{_a} in ComplexNonZero)
#     core type: Lambda
#     parameter: 25
#     body: 15
# 14. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 15. a_{_a} in ComplexNonZero
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. _a -> a_{_a}
#     core type: Lambda
#     parameter: 25
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (a_{_a}, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. a_{_a}
#     core type: IndexedVar
# variable: 23
# index: 25
# 22. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. (_a)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. _a
#     core type: Variable
#     sub-expressions:
