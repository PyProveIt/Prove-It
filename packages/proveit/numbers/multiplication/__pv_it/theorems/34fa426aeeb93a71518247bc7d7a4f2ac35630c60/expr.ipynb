# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, b, i, j, x, y
from proveit.logic import InSet
from proveit.numbers import Less, RealPos, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), RealPos), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), RealPos), one, j), Less(x, y))
# Out:
# expr: (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{i} in RealPos, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{j} in RealPos, x < y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{R}^+, \ldots, a_{i} \in \mathbb{R}^+, b_{1} \in \mathbb{R}^+, \ldots, b_{j} \in \mathbb{R}^+, x < y\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in RealPos, ..a_{_a} in RealPos.., a_{i} in RealPos, b_{1} in RealPos, ..b_{_a} in RealPos.., b_{j} in RealPos, x < y)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (a_{1} in RealPos), ..(a_{_a} in RealPos).., (a_{i} in RealPos)
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 7
#    end_index: 5
# 2. (b_{1} in RealPos), ..(b_{_a} in RealPos).., (b_{j} in RealPos)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 3. x < y
#    core type: Operation
#    operator: 9
#    operands: 10
# 4. _a -> (a_{_a} in RealPos)
#    core type: Lambda
#    parameter: 24
#    body: 11
# 5. i
#    core type: Variable
#    sub-expressions:
# 6. _a -> (b_{_a} in RealPos)
#    core type: Lambda
#    parameter: 24
#    body: 12
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. <
#    core type: Literal
#    sub-expressions:
# 10. (x, y)
#     core type: ExprTuple
# ...
