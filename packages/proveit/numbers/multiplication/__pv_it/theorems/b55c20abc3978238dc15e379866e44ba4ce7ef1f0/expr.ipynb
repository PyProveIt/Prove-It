# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import x, y
from proveit.core_expr_types import a_1_to_i, b_1_to_j
from proveit.logic import Forall
from proveit.numbers import LessEq, Mult, RealNonNeg

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_i, b_1_to_j], LessEq(Mult(a_1_to_i, x, b_1_to_j), Mult(a_1_to_i, y, b_1_to_j)), domain = RealNonNeg, condition = LessEq(x, y))
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in RealNonNeg | x <= y} ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{i}, b_{1}, \ldots, b_{j} \in \mathbb{R}^{\ge 0}~|~x \leq y}~\left(\left(a_{1} \cdot \ldots \cdot a_{i} \cdot x \cdot b_{1} \cdot \ldots \cdot b_{j}\right) \leq \left(a_{1} \cdot \ldots \cdot a_{i} \cdot y \cdot b_{1} \cdot \ldots \cdot b_{j}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in RealNonNeg | x <= y} ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in RealNonNeg ,  ..a_{_a} in RealNonNeg.. ,  a_{i} in RealNonNeg ,  b_{1} in RealNonNeg ,  ..b_{_a} in RealNonNeg.. ,  b_{j} in RealNonNeg ,  x <= y.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}) -> {(a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in RealNonNeg ,  ..a_{_a} in RealNonNeg.. ,  a_{i} in RealNonNeg ,  b_{1} in RealNonNeg ,  ..b_{_a} in RealNonNeg.. ,  b_{j} in RealNonNeg ,  x <= y.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j})
#    core type: ExprTuple
#    sub-expressions: 23, 24
# 5. {(a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}) if a_{1} in RealNonNeg ,  ..a_{_a} in RealNonNeg.. ,  a_{i} in RealNonNeg ,  b_{1} in RealNonNeg ,  ..b_{_a} in RealNonNeg.. ,  b_{j} in RealNonNeg ,  x <= y.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})
#    core type: Operation
#    operator: 21
#    operands: 8
# 7. (a_{1} in RealNonNeg) and ..(a_{_a} in RealNonNeg).. and (a_{i} in RealNonNeg) and (b_{1} in RealNonNeg) and ..(b_{_a} in RealNonNeg).. and (b_{j} in RealNonNeg) and (x <= y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}, a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in RealNonNeg, ..a_{_a} in RealNonNeg.., a_{i} in RealNonNeg, b_{1} in RealNonNeg, ..b_{_a} in RealNonNeg.., b_{j} in RealNonNeg, x <= y)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (a_{1} in RealNonNeg), ..(a_{_a} in RealNonNeg).., (a_{i} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 32
#     end_index: 30
# 14. (b_{1} in RealNonNeg), ..(b_{_a} in RealNonNeg).., (b_{j} in RealNonNeg)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 32
#     end_index: 33
# 15. x <= y
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (a_{1}, ..a_{_a}.., a_{i}, x, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 23, 27, 24
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (a_{1}, ..a_{_a}.., a_{i}, y, b_{1}, ..b_{_a}.., b_{j})
#     core type: ExprTuple
#     sub-expressions: 23, 28, 24
# 19. _a -> (a_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 43
#     body: 25
# 20. _a -> (b_{_a} in RealNonNeg)
#     core type: Lambda
#     parameter: 43
#     body: 26
# 21. <=
#     core type: Literal
#     sub-expressions:
# 22. (x, y)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. a_{1}, ..a_{_a}.., a_{i}
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 32
#     end_index: 30
# 24. b_{1}, ..b_{_a}.., b_{j}
#     core type: ExprRange
#     lambda_map: 31
#     start_index: 32
#     end_index: 33
# 25. a_{_a} in RealNonNeg
#     core type: Operation
#     operator: 35
#     operands: 34
# 26. b_{_a} in RealNonNeg
#     core type: Operation
#     operator: 35
#     operands: 36
# 27. x
#     core type: Variable
#     sub-expressions:
# 28. y
#     core type: Variable
#     sub-expressions:
# 29. _a -> a_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 37
# 30. i
#     core type: Variable
#     sub-expressions:
# 31. _a -> b_{_a}
#     core type: Lambda
#     parameter: 43
#     body: 38
# 32. 1
#     core type: Literal
#     sub-expressions:
# 33. j
#     core type: Variable
#     sub-expressions:
# 34. (a_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 35. in
#     core type: Literal
#     sub-expressions:
# 36. (b_{_a}, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. a_{_a}
#     core type: IndexedVar
# variable: 40
# index: 43
# 38. b_{_a}
#     core type: IndexedVar
# variable: 41
# index: 43
# 39. RealNonNeg
#     core type: Literal
#     sub-expressions:
# 40. a
#     core type: Variable
#     sub-expressions:
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. (_a)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. _a
#     core type: Variable
#     sub-expressions:
