# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, b, i, j, x, y
from proveit.logic import And, InSet
from proveit.numbers import LessEq, RealNonNeg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), RealNonNeg), one, i), ExprRange(sub_expr1, InSet(IndexedVar(b, sub_expr1), RealNonNeg), one, j), LessEq(x, y))
# Out:
# expr: (a_{1} in RealNonNeg) and ..(a_{_a} in RealNonNeg).. and (a_{i} in RealNonNeg) and (b_{1} in RealNonNeg) and ..(b_{_a} in RealNonNeg).. and (b_{j} in RealNonNeg) and (x <= y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{R}^{\ge 0}\right) \land \ldots \land \left(a_{i} \in \mathbb{R}^{\ge 0}\right) \land \left(b_{1} \in \mathbb{R}^{\ge 0}\right) \land \ldots \land \left(b_{j} \in \mathbb{R}^{\ge 0}\right) \land \left(x \leq y\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in RealNonNeg) and ..(a_{_a} in RealNonNeg).. and (a_{i} in RealNonNeg) and (b_{1} in RealNonNeg) and ..(b_{_a} in RealNonNeg).. and (b_{j} in RealNonNeg) and (x <= y)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (a_{1} in RealNonNeg, ..a_{_a} in RealNonNeg.., a_{i} in RealNonNeg, b_{1} in RealNonNeg, ..b_{_a} in RealNonNeg.., b_{j} in RealNonNeg, x <= y)
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. (a_{1} in RealNonNeg), ..(a_{_a} in RealNonNeg).., (a_{i} in RealNonNeg)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 9
#    end_index: 7
# 4. (b_{1} in RealNonNeg), ..(b_{_a} in RealNonNeg).., (b_{j} in RealNonNeg)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 5. x <= y
#    core type: Operation
#    operator: 11
#    operands: 12
# 6. _a -> (a_{_a} in RealNonNeg)
#    core type: Lambda
#    parameter: 26
#    body: 13
# 7. i
# ...
