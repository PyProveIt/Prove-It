# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, InSet, NotEquals
from proveit.numbers import ComplexNonZero, Mult, Natural, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([a_1_to_n], NotEquals(Mult(a_1_to_n), zero), domain = ComplexNonZero), InSet(n, Natural)))
# Out:
# expr: n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0) if n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{a_{1}, \ldots, a_{n} \in \mathbb{C}^{\neq 0}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \neq 0\right) \textrm{ if } n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0) if n in Natural.
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. {forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0) if n in Natural.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. n in Natural
#    core type: Operation
#    operator: 27
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, Natural)
#    core type: ExprTuple
#    sub-expressions: 26, 8
# 7. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Lambda
#    parameters: 20\n   body: 9
# 8. Natural
#    core type: Literal
#    sub-expressions:
# 9. {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. (a_{1} * ..a_{_a}.. * a_{n}) != 0
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero)
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. !=
#     core type: Literal
#     sub-expressions:
# 13. (a_{1} * ..a_{_a}.. * a_{n}, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. and
#     core type: Literal
#     sub-expressions:
# 15. (a_{1} in ComplexNonZero, ..a_{_a} in ComplexNonZero.., a_{n} in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. 0
#     core type: Literal
#     sub-expressions:
# 18. (a_{1} in ComplexNonZero), ..(a_{_a} in ComplexNonZero).., (a_{n} in ComplexNonZero)
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 25
#     end_index: 26
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 21. _a -> (a_{_a} in ComplexNonZero)
#     core type: Lambda
#     parameter: 33
#     body: 23
# 22. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 24
#     start_index: 25
#     end_index: 26
# 23. a_{_a} in ComplexNonZero
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. _a -> a_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 29
# 25. 1
#     core type: Literal
#     sub-expressions:
# 26. n
#     core type: Variable
#     sub-expressions:
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (a_{_a}, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. a_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 30. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. (_a)
#     core type: ExprTuple
#     sub-expressions: 33
# 33. _a
#     core type: Variable
#     sub-expressions:
