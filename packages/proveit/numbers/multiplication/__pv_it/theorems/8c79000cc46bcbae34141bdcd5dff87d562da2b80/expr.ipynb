# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import ComplexNonZero, Mult, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(NotEquals(Mult(a_1_to_n), zero), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), ComplexNonZero), one, n)))
# Out:
# expr: {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \neq 0 \textrm{ if } \left(a_{1} \in \mathbb{C}^{\neq 0}\right) \land \ldots \land \left(a_{n} \in \mathbb{C}^{\neq 0}\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * ..a_{_a}.. * a_{n}) != 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. !=
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} * ..a_{_a}.. * a_{n}, 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in ComplexNonZero, ..a_{_a} in ComplexNonZero.., a_{n} in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 0
#    core type: Literal
#    sub-expressions:
# ...
