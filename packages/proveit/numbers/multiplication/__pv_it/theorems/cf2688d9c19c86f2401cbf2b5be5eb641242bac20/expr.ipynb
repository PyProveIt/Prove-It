# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, n
from proveit.core_expr_types import a_1_to_n
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import ComplexNonZero, Mult, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda([a_1_to_n], Conditional(NotEquals(Mult(a_1_to_n), zero), And(ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), ComplexNonZero), one, n)))))
# Out:
# expr: ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1}, \ldots, a_{n}\right) \mapsto \left\{\left(a_{1} \cdot \ldots \cdot a_{n}\right) \neq 0 \textrm{ if } \left(a_{1} \in \mathbb{C}^{\neq 0}\right) \land \ldots \land \left(a_{n} \in \mathbb{C}^{\neq 0}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Lambda
#    parameters: 13\n   body: 2
# 2. {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * ..a_{_a}.. * a_{n}) != 0
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. !=
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} * ..a_{_a}.. * a_{n}, 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} in ComplexNonZero, ..a_{_a} in ComplexNonZero.., a_{n} in ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. a_{1} * ..a_{_a}.. * a_{n}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. 0
#     core type: Literal
#     sub-expressions:
# 11. (a_{1} in ComplexNonZero), ..(a_{_a} in ComplexNonZero).., (a_{n} in ComplexNonZero)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 18
#     end_index: 19
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. _a -> (a_{_a} in ComplexNonZero)
#     core type: Lambda
#     parameter: 26
#     body: 16
# 15. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 17
#     start_index: 18
#     end_index: 19
# 16. a_{_a} in ComplexNonZero
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. _a -> a_{_a}
#     core type: Lambda
#     parameter: 26
#     body: 22
# 18. 1
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (a_{_a}, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. a_{_a}
#     core type: IndexedVar
# variable: 24
# index: 26
# 23. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. _a
#     core type: Variable
#     sub-expressions:
