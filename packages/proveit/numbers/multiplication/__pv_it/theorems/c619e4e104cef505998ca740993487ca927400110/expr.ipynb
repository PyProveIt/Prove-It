# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.multiplication</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import a_1_to_n
from proveit.logic import Forall, NotEquals
from proveit.numbers import ComplexNonZero, Mult, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a_1_to_n], NotEquals(Mult(a_1_to_n), zero), domain = ComplexNonZero)
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{n} \in \mathbb{C}^{\neq 0}}~\left(\left(a_{1} \cdot \ldots \cdot a_{n}\right) \neq 0\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{n}) -> {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Lambda
#    parameters: 15\n   body: 4
# 4. {(a_{1} * ..a_{_a}.. * a_{n}) != 0 if (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a_{1} * ..a_{_a}.. * a_{n}) != 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a_{1} in ComplexNonZero) and ..(a_{_a} in ComplexNonZero).. and (a_{n} in ComplexNonZero)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. !=
#    core type: Literal
#    sub-expressions:
# 8. (a_{1} * ..a_{_a}.. * a_{n}, 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a_{1} in ComplexNonZero, ..a_{_a} in ComplexNonZero.., a_{n} in ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. a_{1} * ..a_{_a}.. * a_{n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. 0
#     core type: Literal
#     sub-expressions:
# 13. (a_{1} in ComplexNonZero), ..(a_{_a} in ComplexNonZero).., (a_{n} in ComplexNonZero)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 20
#     end_index: 21
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (a_{1}, ..a_{_a}.., a_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 16. _a -> (a_{_a} in ComplexNonZero)
#     core type: Lambda
#     parameter: 28
#     body: 18
# 17. a_{1}, ..a_{_a}.., a_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 18. a_{_a} in ComplexNonZero
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. _a -> a_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (a_{_a}, ComplexNonZero)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. a_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 25. ComplexNonZero
#     core type: Literal
#     sub-expressions:
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 28
# 28. _a
#     core type: Variable
#     sub-expressions:
