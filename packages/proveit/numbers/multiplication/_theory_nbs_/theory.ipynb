# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">numbers</a>.multiplication
# ========
#
# Provide description here.

# %%
import proveit
# %theory
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#mult_def">proveit.numbers.multiplication.mult_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/49ce2ffbad22fef6a9dd2a7b37460b1cf5a6e3790/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="axioms.ipynb#empty_mult">proveit.numbers.multiplication.empty_mult</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/29f634ab8bc535ea9769b2a63dea270ef266d9220/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="axioms.ipynb#multi_mult_def">proveit.numbers.multiplication.multi_mult_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/b5bbcf99949b759f59e0130c4b7c1d9a8ed88d7b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
