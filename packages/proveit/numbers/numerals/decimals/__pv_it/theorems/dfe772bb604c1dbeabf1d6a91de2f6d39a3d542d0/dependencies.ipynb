# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.numerals.decimals</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#add_0_1">add_0_1</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/add_0_1/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.numerals.decimals import add_0_1

# %%
# %dependencies add_0_1
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on add_0_1</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../core_expr_types/tuples/_theory_nbs_/proofs/tuple_eq_via_elem_eq/thm_proof.ipynb">proveit.core_expr_types.tuples.tuple_eq_via_elem_eq</a></dt><dd><a class="ProveItLink" href="../../../../../../core_expr_types/tuples/__pv_it/theorems/dfbd4ebd2517106b9810d979f0677d5902666d5f0/expr.ipynb"><img src="../../../../../../core_expr_types/tuples/__pv_it/theorems/dfbd4ebd2517106b9810d979f0677d5902666d5f0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/fail_ineq_lemma/thm_proof.ipynb">proveit.physics.quantum.QPE.fail_ineq_lemma</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/9cac7b4ead30fc7ec466f81aad0f0a3d7f700eff0/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/9cac7b4ead30fc7ec466f81aad0f0a3d7f700eff0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/neg_domain_in_full_domain_sans_zero/thm_proof.ipynb">proveit.physics.quantum.QPE.neg_domain_in_full_domain_sans_zero</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/246c40faec929908d142ddbe3fa4a414bb0b35b60/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/246c40faec929908d142ddbe3fa4a414bb0b35b60/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/pos_domain_in_full_domain_sans_zero/thm_proof.ipynb">proveit.physics.quantum.QPE.pos_domain_in_full_domain_sans_zero</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/1bcb691c3582f8bbfd8c69bc8bbf5499ad9a67f00/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/1bcb691c3582f8bbfd8c69bc8bbf5499ad9a67f00/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/scaled_delta_not_eq_nonzeroInt/thm_proof.ipynb">proveit.physics.quantum.QPE.scaled_delta_not_eq_nonzeroInt</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/6f70f327ec14ea7e4e6ad1ac4384c702cb3f0fd80/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/6f70f327ec14ea7e4e6ad1ac4384c702cb3f0fd80/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
