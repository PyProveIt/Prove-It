# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.rounding</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x
from proveit.numbers import Add, Floor, Less, LessEq, Neg, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(x, Neg(Floor(x)))
expr = ExprTuple(LessEq(zero, sub_expr1), Less(sub_expr1, one))
# Out:
# expr: (0 <= (x - floor(x)), (x - floor(x)) < 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(0 \leq \left(x - \lfloor x\rfloor\right), \left(x - \lfloor x\rfloor\right) < 1\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (0 <= (x - floor(x)), (x - floor(x)) < 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 0 <= (x - floor(x))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x - floor(x)) < 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (0, x - floor(x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. <
#    core type: Literal
#    sub-expressions:
# 6. (x - floor(x), 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. x - floor(x)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (x, -floor(x))
#     core type: ExprTuple
#     sub-expressions: 18, 12
# 12. -floor(x)
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (floor(x))
#     core type: ExprTuple
#     sub-expressions: 15
# 15. floor(x)
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. floor
#     core type: Literal
#     sub-expressions:
# 17. (x)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. x
#     core type: Variable
#     sub-expressions:
