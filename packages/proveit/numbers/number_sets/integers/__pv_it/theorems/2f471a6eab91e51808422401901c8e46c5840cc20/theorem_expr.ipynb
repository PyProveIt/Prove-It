# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#not_int_not_in_interval">not_int_not_in_interval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.integers import not_int_not_in_interval

# %%
# check that the built expression is the same as the stored expression
assert not_int_not_in_interval.expr == stored_expr
assert not_int_not_in_interval.expr._style_id == stored_expr._style_id
print("Passed sanity check: not_int_not_in_interval matches stored_expr")
# Out:
# Passed sanity check: not_int_not_in_interval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(not_int_not_in_interval.latex())
# Out:
# \vdash \forall_{a, b \in \mathbb{Z}}~\left[\forall_{x \in \mathbb{C}~|~x \notin \mathbb{Z}}~\left(x \notin \{a~\ldotp \ldotp~b\}\right)\right]

# %%
not_int_not_in_interval.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
not_int_not_in_interval.expr_info()
# Out:
# 0. forall_{a, b in Integer} [forall_{x in Complex | x not-in Integer} (x not-in {a .. b})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((a, b) -> {forall_{x in Complex | x not-in Integer} (x not-in {a .. b}) if a in Integer ,  b in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> {forall_{x in Complex | x not-in Integer} (x not-in {a .. b}) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 24\n   body: 3
# 3. {forall_{x in Complex | x not-in Integer} (x not-in {a .. b}) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in Complex | x not-in Integer} (x not-in {a .. b})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 18
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (x -> {x not-in {a .. b} if x in Complex ,  x not-in Integer.)
# ...
