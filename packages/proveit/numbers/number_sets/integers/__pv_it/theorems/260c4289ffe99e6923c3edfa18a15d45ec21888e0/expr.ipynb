# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b
from proveit.logic import And, EmptySet, Equals, InSet
from proveit.numbers import Integer, Interval, Less

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Interval(a, b), EmptySet), And(InSet(a, Integer), InSet(b, Integer), Less(b, a)))
# Out:
# expr: {{a .. b} = emptyset if a in Integer ,  b in Integer ,  b < a.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\{a~\ldotp \ldotp~b\} = \emptyset \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  b < a\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {{a .. b} = emptyset if a in Integer ,  b in Integer ,  b < a.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. {a .. b} = emptyset
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (b < a)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. ({a .. b}, emptyset)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, b < a)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. {a .. b}
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. emptyset
#    core type: Literal
#    sub-expressions:
# 9. a in Integer
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. b in Integer
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. b < a
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a, b)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 14. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. <
#     core type: Literal
#     sub-expressions:
# 18. (b, a)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. Integer
#     core type: Literal
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
