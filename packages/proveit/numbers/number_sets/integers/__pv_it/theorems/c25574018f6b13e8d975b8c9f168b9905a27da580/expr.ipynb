# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, x
from proveit.logic import And, InSet, NotInSet, Or
from proveit.numbers import Integer, Interval, Less

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b, x], Conditional(NotInSet(x, Interval(a, b)), And(InSet(a, Integer), InSet(b, Integer), InSet(x, Integer), Or(Less(x, a), Less(b, x))))))
# Out:
# expr: ((a, b, x) -> {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, x\right) \mapsto \left\{x \notin \{a~\ldotp \ldotp~b\} \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  x \in \mathbb{Z} ,  \left(x < a\right) \lor \left(b < x\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, x) -> {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, x) -> {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 31
# 3. {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x not-in {a .. b}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integer) and (b in Integer) and (x in Integer) and ((x < a) or (b < x))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. (x, {a .. b})
#    core type: ExprTuple
#    sub-expressions: 31, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integer, b in Integer, x in Integer, (x < a) or (b < x))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 10. {a .. b}
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. a in Integer
#     core type: Operation
#     operator: 19
#     operands: 17
# 12. b in Integer
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. x in Integer
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. (x < a) or (b < x)
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (a, b)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 17. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 29, 23
# 18. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 30, 23
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 21. or
#     core type: Literal
#     sub-expressions:
# 22. (x < a, b < x)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. Integer
#     core type: Literal
#     sub-expressions:
# 24. x < a
#     core type: Operation
#     operator: 27
#     operands: 26
# 25. b < x
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. (x, a)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 27. <
#     core type: Literal
#     sub-expressions:
# 28. (b, x)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
# 31. x
#     core type: Variable
#     sub-expressions:
