# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.logic import Forall, NotInSet, Or
from proveit.numbers import Integer, Interval, Less

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, x], NotInSet(x, Interval(a, b)), domain = Integer, condition = Or(Less(x, a), Less(b, x)))
# Out:
# expr: forall_{a, b, x in Integer | (x < a) or (b < x)} (x not-in {a .. b})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, x \in \mathbb{Z}~|~\left(x < a\right) \lor \left(b < x\right)}~\left(x \notin \{a~\ldotp \ldotp~b\}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, x in Integer | (x < a) or (b < x)} (x not-in {a .. b})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, x) -> {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, x) -> {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 31, 32, 33
# 5. {x not-in {a .. b} if a in Integer ,  b in Integer ,  x in Integer ,  (x < a) or (b < x).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x not-in {a .. b}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (x in Integer) and ((x < a) or (b < x))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. not-in
#    core type: Literal
#    sub-expressions:
# 9. (x, {a .. b})
#    core type: ExprTuple
#    sub-expressions: 33, 12
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (a in Integer, b in Integer, x in Integer, (x < a) or (b < x))
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 12. {a .. b}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. a in Integer
#     core type: Operation
#     operator: 21
#     operands: 19
# 14. b in Integer
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. x in Integer
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. (x < a) or (b < x)
#     core type: Operation
#     operator: 23
#     operands: 24
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (a, b)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 19. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 31, 25
# 20. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 32, 25
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 33, 25
# 23. or
#     core type: Literal
#     sub-expressions:
# 24. (x < a, b < x)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. Integer
#     core type: Literal
#     sub-expressions:
# 26. x < a
#     core type: Operation
#     operator: 29
#     operands: 28
# 27. b < x
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (x, a)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 29. <
#     core type: Literal
#     sub-expressions:
# 30. (b, x)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. a
#     core type: Variable
#     sub-expressions:
# 32. b
#     core type: Variable
#     sub-expressions:
# 33. x
#     core type: Variable
#     sub-expressions:
