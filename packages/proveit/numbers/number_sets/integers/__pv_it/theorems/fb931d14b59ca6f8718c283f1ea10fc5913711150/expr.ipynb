# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, n
from proveit.logic import Forall, InSet
from proveit.numbers import Interval, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], Forall([n], InSet(n, NaturalPos), domain = Interval(a, b)), domain = NaturalPos)
# Out:
# expr: forall_{a, b in NaturalPos} [forall_{n in {a .. b}} (n in NaturalPos)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{N}^+}~\left[\forall_{n \in \{a~\ldotp \ldotp~b\}}~\left(n \in \mathbb{N}^+\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in NaturalPos} [forall_{n in {a .. b}} (n in NaturalPos)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. ((a, b) -> {forall_{n in {a .. b}} (n in NaturalPos) if a in NaturalPos ,  b in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> {forall_{n in {a .. b}} (n in NaturalPos) if a in NaturalPos ,  b in NaturalPos.
#    core type: Lambda
#    parameters: 25\n   body: 3
# 3. {forall_{n in {a .. b}} (n in NaturalPos) if a in NaturalPos ,  b in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{n in {a .. b}} (n in NaturalPos)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (a in NaturalPos) and (b in NaturalPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (n -> {n in NaturalPos if n in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in NaturalPos, b in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. n -> {n in NaturalPos if n in {a .. b}.
#     core type: Lambda
#     parameter: 22
#     body: 13
# 11. a in NaturalPos
#     core type: Operation
#     operator: 19
#     operands: 14
# 12. b in NaturalPos
#     core type: Operation
#     operator: 19
#     operands: 15
# 13. {n in NaturalPos if n in {a .. b}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 14. (a, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 15. (b, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 16. n in NaturalPos
#     core type: Operation
#     operator: 19
#     operands: 18
# 17. n in {a .. b}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (n, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. NaturalPos
#     core type: Literal
#     sub-expressions:
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. {a .. b}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
