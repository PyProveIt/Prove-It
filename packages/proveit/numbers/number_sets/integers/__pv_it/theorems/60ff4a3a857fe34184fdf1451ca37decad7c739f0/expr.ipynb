# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Integer, Interval, Natural, greater_eq, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([n], InSet(n, Natural), domain = Interval(a, b)), And(InSet(a, Integer), InSet(b, Integer), greater_eq(a, zero)))
# Out:
# expr: {forall_{n in {a .. b}} (n in Natural) if a in Integer ,  b in Integer ,  a >= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{n \in \{a~\ldotp \ldotp~b\}}~\left(n \in \mathbb{N}\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a \geq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{n in {a .. b}} (n in Natural) if a in Integer ,  b in Integer ,  a >= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in {a .. b}} (n in Natural)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (a in Integer) and (b in Integer) and (a >= 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (n -> {n in Natural if n in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, a >= 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. n -> {n in Natural if n in {a .. b}.
#    core type: Lambda
#    parameter: 24
#    body: 11
# 8. a in Integer
#    core type: Operation
#    operator: 21
#    operands: 12
# 9. b in Integer
#    core type: Operation
#    operator: 21
#    operands: 13
# 10. a >= 0
#     core type: Operation
#     operator: 14
# ...
