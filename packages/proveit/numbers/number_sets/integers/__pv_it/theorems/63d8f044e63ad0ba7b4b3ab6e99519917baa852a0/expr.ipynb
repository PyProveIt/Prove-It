# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, x
from proveit.logic import InSet, NotInSet
from proveit.numbers import Integer, Interval

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, Integer), InSet(b, Integer), InSet(x, Integer), NotInSet(x, Interval(a, b)))
# Out:
# expr: (a in Integer, b in Integer, x in Integer, x not-in {a .. b})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{Z}, b \in \mathbb{Z}, x \in \mathbb{Z}, x \notin \{a~\ldotp \ldotp~b\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Integer, b in Integer, x in Integer, x not-in {a .. b})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. a in Integer
#    core type: Operation
#    operator: 7
#    operands: 5
# 2. b in Integer
#    core type: Operation
#    operator: 7
#    operands: 6
# 3. x in Integer
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. x not-in {a .. b}
#    core type: Operation
#    operator: 9
#    operands: 10
# 5. (a, Integer)
#    core type: ExprTuple
#    sub-expressions: 16, 11
# 6. (b, Integer)
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, Integer)
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 9. not-in
#    core type: Literal
#    sub-expressions:
# 10. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. Integer
#     core type: Literal
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. {a .. b}
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
