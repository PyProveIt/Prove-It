# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, Forall, InSet, NotInSet
from proveit.numbers import Complex, Integer, Interval

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], NotInSet(x, Interval(a, b)), domain = Complex, condition = NotInSet(x, Integer)), And(InSet(a, Integer), InSet(b, Integer)))
# Out:
# expr: {forall_{x in Complex | x not-in Integer} (x not-in {a .. b}) if a in Integer ,  b in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \mathbb{C}~|~x \notin \mathbb{Z}}~\left(x \notin \{a~\ldotp \ldotp~b\}\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in Complex | x not-in Integer} (x not-in {a .. b}) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in Complex | x not-in Integer} (x not-in {a .. b})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {x not-in {a .. b} if x in Complex ,  x not-in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> {x not-in {a .. b} if x in Complex ,  x not-in Integer.
#    core type: Lambda
#    parameter: 29
#    body: 9
# 7. a in Integer
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. b in Integer
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. {x not-in {a .. b} if x in Complex ,  x not-in Integer.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 26, 30
# 11. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 27, 30
# 12. x not-in {a .. b}
#     core type: Operation
#     operator: 24
#     operands: 14
# 13. (x in Complex) and (x not-in Integer)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 29, 17
# 15. and
#     core type: Literal
#     sub-expressions:
# 16. (x in Complex, x not-in Integer)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {a .. b}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. x in Complex
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. x not-in Integer
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (a, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 24. not-in
#     core type: Literal
#     sub-expressions:
# 25. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. a
#     core type: Variable
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. Complex
#     core type: Literal
#     sub-expressions:
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. Integer
#     core type: Literal
#     sub-expressions:
