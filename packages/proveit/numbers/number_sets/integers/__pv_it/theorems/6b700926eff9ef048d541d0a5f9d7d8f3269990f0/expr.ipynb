# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, InSet, NotInSet
from proveit.numbers import Complex, Integer, Interval

# %%
# build up the expression from sub-expressions
expr = Conditional(NotInSet(x, Interval(a, b)), And(InSet(x, Complex), NotInSet(x, Integer)))
# Out:
# expr: {x not-in {a .. b} if x in Complex ,  x not-in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \notin \{a~\ldotp \ldotp~b\} \textrm{ if } x \in \mathbb{C} ,  x \notin \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x not-in {a .. b} if x in Complex ,  x not-in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x not-in {a .. b}
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. (x in Complex) and (x not-in Integer)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (x, {a .. b})
#    core type: ExprTuple
#    sub-expressions: 18, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (x in Complex, x not-in Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {a .. b}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. x in Complex
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. x not-in Integer
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. Interval
#    core type: Literal
#    sub-expressions:
# 10. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 13. not-in
#     core type: Literal
#     sub-expressions:
# 14. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. Complex
#     core type: Literal
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. Integer
#     core type: Literal
#     sub-expressions:
