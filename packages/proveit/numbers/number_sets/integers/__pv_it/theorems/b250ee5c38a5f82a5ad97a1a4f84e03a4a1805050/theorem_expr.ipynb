# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#bounds_for_int_not_in_interval">bounds_for_int_not_in_interval</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.integers import bounds_for_int_not_in_interval

# %%
# check that the built expression is the same as the stored expression
assert bounds_for_int_not_in_interval.expr == stored_expr
assert bounds_for_int_not_in_interval.expr._style_id == stored_expr._style_id
print("Passed sanity check: bounds_for_int_not_in_interval matches stored_expr")
# Out:
# Passed sanity check: bounds_for_int_not_in_interval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(bounds_for_int_not_in_interval.latex())
# Out:
# \vdash \forall_{a, b, x \in \mathbb{Z}~|~x \notin \{a~\ldotp \ldotp~b\}}~\left(\left(x < a\right) \lor \left(b < x\right)\right)

# %%
bounds_for_int_not_in_interval.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
bounds_for_int_not_in_interval.expr_info()
# Out:
# 0. forall_{a, b, x in Integer | x not-in {a .. b}} ((x < a) or (b < x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, x) -> {(x < a) or (b < x) if a in Integer ,  b in Integer ,  x in Integer ,  x not-in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, x) -> {(x < a) or (b < x) if a in Integer ,  b in Integer ,  x in Integer ,  x not-in {a .. b}.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 32, 33, 28
# 5. {(x < a) or (b < x) if a in Integer ,  b in Integer ,  x in Integer ,  x not-in {a .. b}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (x < a) or (b < x)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (x in Integer) and (x not-in {a .. b})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. or
# ...
