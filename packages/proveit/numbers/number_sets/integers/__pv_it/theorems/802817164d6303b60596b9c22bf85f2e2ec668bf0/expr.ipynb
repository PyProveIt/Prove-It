# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import IntegerNeg, Interval

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([n], InSet(n, IntegerNeg), domain = Interval(a, b)), And(InSet(a, IntegerNeg), InSet(b, IntegerNeg)))
# Out:
# expr: {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{n \in \{a~\ldotp \ldotp~b\}}~\left(n \in \mathbb{Z}^{-}\right) \textrm{ if } a \in \mathbb{Z}^{-} ,  b \in \mathbb{Z}^{-}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{n in {a .. b}} (n in IntegerNeg)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (a in IntegerNeg) and (b in IntegerNeg)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (n -> {n in IntegerNeg if n in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in IntegerNeg, b in IntegerNeg)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. n -> {n in IntegerNeg if n in {a .. b}.
#    core type: Lambda
#    parameter: 19
#    body: 10
# 8. a in IntegerNeg
#    core type: Operation
#    operator: 16
#    operands: 11
# 9. b in IntegerNeg
#    core type: Operation
#    operator: 16
#    operands: 12
# 10. {n in IntegerNeg if n in {a .. b}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a, IntegerNeg)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 12. (b, IntegerNeg)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 13. n in IntegerNeg
#     core type: Operation
#     operator: 16
#     operands: 15
# 14. n in {a .. b}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (n, IntegerNeg)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (n, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. IntegerNeg
#     core type: Literal
#     sub-expressions:
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. {a .. b}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
