# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import IntegerNeg, Interval

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b], Conditional(Forall([n], InSet(n, IntegerNeg), domain = Interval(a, b)), And(InSet(a, IntegerNeg), InSet(b, IntegerNeg)))))
# Out:
# expr: ((a, b) -> {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\forall_{n \in \{a~\ldotp \ldotp~b\}}~\left(n \in \mathbb{Z}^{-}\right) \textrm{ if } a \in \mathbb{Z}^{-} ,  b \in \mathbb{Z}^{-}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.
#    core type: Lambda
#    parameters: 24\n   body: 2
# 2. {forall_{n in {a .. b}} (n in IntegerNeg) if a in IntegerNeg ,  b in IntegerNeg.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{n in {a .. b}} (n in IntegerNeg)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. (a in IntegerNeg) and (b in IntegerNeg)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (n -> {n in IntegerNeg if n in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in IntegerNeg, b in IntegerNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# ...
