# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.logic import Forall, NotInSet
from proveit.numbers import Complex, Integer, Interval

# %%
# build up the expression from sub-expressions
expr = Forall([x], NotInSet(x, Interval(a, b)), domain = Complex, condition = NotInSet(x, Integer))
# Out:
# expr: forall_{x in Complex | x not-in Integer} (x not-in {a .. b})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \mathbb{C}~|~x \notin \mathbb{Z}}~\left(x \notin \{a~\ldotp \ldotp~b\}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in Complex | x not-in Integer} (x not-in {a .. b})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {x not-in {a .. b} if x in Complex ,  x not-in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {x not-in {a .. b} if x in Complex ,  x not-in Integer.
#    core type: Lambda
#    parameter: 22
#    body: 4
# 4. {x not-in {a .. b} if x in Complex ,  x not-in Integer.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x not-in {a .. b}
#    core type: Operation
#    operator: 17
#    operands: 7
# 6. (x in Complex) and (x not-in Integer)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x, {a .. b})
#    core type: ExprTuple
#    sub-expressions: 22, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (x in Complex, x not-in Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {a .. b}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. x in Complex
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. x not-in Integer
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (a, b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 17. not-in
#     core type: Literal
#     sub-expressions:
# 18. (x, Integer)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. Complex
#     core type: Literal
#     sub-expressions:
# 22. x
#     core type: Variable
#     sub-expressions:
# 23. Integer
#     core type: Literal
#     sub-expressions:
