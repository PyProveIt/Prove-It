# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a
from proveit.logic import Forall, InSet
from proveit.numbers import Integer, IntegerNonPos, LessEq, zero

# %%
# build up the expression from sub-expressions
expr = Forall([a], InSet(a, IntegerNonPos), domain = Integer, condition = LessEq(a, zero))
# Out:
# expr: forall_{a in Integer | a <= 0} (a in IntegerNonPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a \in \mathbb{Z}~|~a \leq 0}~\left(a \in \mathbb{Z}^{\leq 0}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a in Integer | a <= 0} (a in IntegerNonPos)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {a in IntegerNonPos if a in Integer ,  a <= 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {a in IntegerNonPos if a in Integer ,  a <= 0.
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. {a in IntegerNonPos if a in Integer ,  a <= 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a in IntegerNonPos
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (a in Integer) and (a <= 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a, IntegerNonPos)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Integer, a <= 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. IntegerNonPos
#     core type: Literal
#     sub-expressions:
# 11. a in Integer
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. a <= 0
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. <=
#     core type: Literal
#     sub-expressions:
# 16. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Integer
#     core type: Literal
#     sub-expressions:
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. 0
#     core type: Literal
#     sub-expressions:
