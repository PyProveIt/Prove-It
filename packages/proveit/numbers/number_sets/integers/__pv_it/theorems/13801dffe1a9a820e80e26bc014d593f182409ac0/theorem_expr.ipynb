# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonzero_int_membership_is_bool">nonzero_int_membership_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.integers import nonzero_int_membership_is_bool

# %%
# check that the built expression is the same as the stored expression
assert nonzero_int_membership_is_bool.expr == stored_expr
assert nonzero_int_membership_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonzero_int_membership_is_bool matches stored_expr")
# Out:
# Passed sanity check: nonzero_int_membership_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonzero_int_membership_is_bool.latex())
# Out:
# \vdash \forall_{x}~\left(\left(x \in \mathbb{Z}^{\neq 0}\right) \in \mathbb{B}\right)

# %%
nonzero_int_membership_is_bool.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonzero_int_membership_is_bool.expr_info()
# Out:
# 0. forall_{x} ((x in IntegerNonZero) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> ((x in IntegerNonZero) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> ((x in IntegerNonZero) in BOOLEAN)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 4. (x in IntegerNonZero) in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 5
# 5. (x in IntegerNonZero, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x in IntegerNonZero
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, IntegerNonZero)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. IntegerNonZero
#     core type: Literal
#     sub-expressions:
