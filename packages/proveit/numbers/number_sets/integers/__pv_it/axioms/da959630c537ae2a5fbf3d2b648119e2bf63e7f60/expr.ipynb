# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.integers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, n
from proveit.logic import And, Forall, InSet
from proveit.numbers import Integer, Interval, LessEq

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([n], And(LessEq(a, n), LessEq(n, b)).with_total_ordering_style(), domain = Interval(a, b)), And(InSet(a, Integer), InSet(b, Integer))))
# Out:
# expr: (a, b) -> {forall_{n in {a .. b}} (a <= n <= b) if a in Integer ,  b in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{n \in \{a~\ldotp \ldotp~b\}}~\left(a \leq n \leq b\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{n in {a .. b}} (a <= n <= b) if a in Integer ,  b in Integer.
#    core type: Lambda
#    parameters: 27\n   body: 1
# 1. {forall_{n in {a .. b}} (a <= n <= b) if a in Integer ,  b in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{n in {a .. b}} (a <= n <= b)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (a in Integer) and (b in Integer)
#    core type: Operation
#    operator: 16
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (n -> {a <= n <= b if n in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a in Integer, b in Integer)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. n -> {a <= n <= b if n in {a .. b}.
#    core type: Lambda
#    parameter: 28
#    body: 10
# 8. a in Integer
#    core type: Operation
#    operator: 18
#    operands: 11
# 9. b in Integer
#    core type: Operation
#    operator: 18
#    operands: 12
# ...
