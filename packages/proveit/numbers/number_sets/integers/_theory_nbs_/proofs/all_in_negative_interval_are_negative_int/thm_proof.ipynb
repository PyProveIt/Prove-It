# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">number_sets</a>.<a class="ProveItLink" href="../../theory.ipynb">integers</a>.<a class="ProveItLink" href="../../theorems.ipynb#all_in_negative_interval_are_negative_int">all_in_negative_interval_are_negative_int</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving all_in_negative_interval_are_negative_int
# Out:
# all_in_negative_interval_are_negative_int: forall_{a, b in IntegerNeg} [forall_{n in {a .. b}} (n in IntegerNeg)]
