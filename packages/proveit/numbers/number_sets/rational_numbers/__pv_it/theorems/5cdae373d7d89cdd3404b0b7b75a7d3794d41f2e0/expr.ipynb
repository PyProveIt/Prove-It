# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, q
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Rational, RationalNonPos, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(q, Conditional(InSet(q, RationalNonPos), And(InSet(q, Rational), LessEq(q, zero))))
# Out:
# expr: q -> {q in RationalNonPos if q in Rational ,  q <= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# q \mapsto \left\{q \in \mathbb{Q}^{\leq 0} \textrm{ if } q \in \mathbb{Q} ,  q \leq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. q -> {q in RationalNonPos if q in Rational ,  q <= 0.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {q in RationalNonPos if q in Rational ,  q <= 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. q in RationalNonPos
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (q in Rational) and (q <= 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (q, RationalNonPos)
#    core type: ExprTuple
#    sub-expressions: 15, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (q in Rational, q <= 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. RationalNonPos
#    core type: Literal
#    sub-expressions:
# 8. q in Rational
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. q <= 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (q, Rational)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. <=
#     core type: Literal
#     sub-expressions:
# 13. (q, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Rational
#     core type: Literal
#     sub-expressions:
# 15. q
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
