# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonneg_rational_is_rational_nonneg">nonneg_rational_is_rational_nonneg</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.rational_numbers import nonneg_rational_is_rational_nonneg

# %%
# check that the built expression is the same as the stored expression
assert nonneg_rational_is_rational_nonneg.expr == stored_expr
assert nonneg_rational_is_rational_nonneg.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonneg_rational_is_rational_nonneg matches stored_expr")
# Out:
# Passed sanity check: nonneg_rational_is_rational_nonneg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonneg_rational_is_rational_nonneg.latex())
# Out:
# \vdash \forall_{q \in \mathbb{Q}~|~q \geq 0}~\left(q \in \mathbb{Q}^{\geq 0}\right)

# %%
nonneg_rational_is_rational_nonneg.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonneg_rational_is_rational_nonneg.expr_info()
# Out:
# 0. forall_{q in Rational | q >= 0} (q in RationalNonNeg)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (q -> {q in RationalNonNeg if q in Rational ,  q >= 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. q -> {q in RationalNonNeg if q in Rational ,  q >= 0.
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. {q in RationalNonNeg if q in Rational ,  q >= 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. q in RationalNonNeg
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (q in Rational) and (q >= 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (q, RationalNonNeg)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (q in Rational, q >= 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. RationalNonNeg
#     core type: Literal
#     sub-expressions:
# ...
