# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#nat_within_rational_nonneg">nat_within_rational_nonneg</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/nat_within_rational_nonneg/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.number_sets.rational_numbers import nat_within_rational_nonneg

# %%
# %dependencies nat_within_rational_nonneg
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on nat_within_rational_nonneg</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/alpha_l_sqrd_ineq/thm_proof.ipynb">proveit.physics.quantum.QPE.alpha_l_sqrd_ineq</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/9f743f92f8370e4a37572464aececf142e1b21290/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/9f743f92f8370e4a37572464aececf142e1b21290/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
