# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.rational_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, q
from proveit.logic import InSet
from proveit.numbers import LessEq, RationalNonPos, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(q, zero), InSet(q, RationalNonPos))
# Out:
# expr: {q <= 0 if q in RationalNonPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{q \leq 0 \textrm{ if } q \in \mathbb{Q}^{\leq 0}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {q <= 0 if q in RationalNonPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. q <= 0
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. q in RationalNonPos
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (q, 0)
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (q, RationalNonPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. q
#    core type: Variable
#    sub-expressions:
# 9. RationalNonPos
#    core type: Literal
#    sub-expressions:
