# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Variable
from proveit.logic import InSet
from proveit.numbers import IntervalCC, RealPos, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(sub_expr1, Conditional(InSet(sub_expr1, RealPos), InSet(sub_expr1, IntervalCC(one, two)))))
# Out:
# expr: (_a -> {_a in RealPos if _a in [1,2].)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left({_{-}a} \mapsto \left\{{_{-}a} \in \mathbb{R}^+ \textrm{ if } {_{-}a} \in \left[1,2\right]\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (_a -> {_a in RealPos if _a in [1,2].)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. _a -> {_a in RealPos if _a in [1,2].
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {_a in RealPos if _a in [1,2].
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. _a in RealPos
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. _a in [1,2]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (_a, RealPos)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (_a, [1,2])
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. RealPos
#    core type: Literal
#    sub-expressions:
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. [1,2]
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. IntervalCC
#     core type: Literal
#     sub-expressions:
# 12. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
