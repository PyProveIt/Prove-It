# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable
from proveit.logic import Forall, InSet
from proveit.numbers import IntervalOO, five, four, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall([sub_expr1], InSet(sub_expr1, IntervalOO(two, five)), domain = IntervalOO(three, four))
# Out:
# expr: forall_{_a in (3,4)} (_a in (2,5))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{{_{-}a} \in \left(3,4\right)}~\left({_{-}a} \in \left(2,5\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{_a in (3,4)} (_a in (2,5))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (_a -> {_a in (2,5) if _a in (3,4).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. _a -> {_a in (2,5) if _a in (3,4).
#    core type: Lambda
#    parameter: 11
#    body: 4
# 4. {_a in (2,5) if _a in (3,4).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. _a in (2,5)
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. _a in (3,4)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (_a, (2,5))
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (_a, (3,4))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (2,5)
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. (3,4)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (2, 5)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. IntervalOO
#     core type: Literal
#     sub-expressions:
# 15. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. 5
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. 4
#     core type: Literal
#     sub-expressions:
