# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Variable
from proveit.logic import InSet
from proveit.numbers import IntervalOO, five, four, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(sub_expr1, Conditional(InSet(sub_expr1, IntervalOO(two, five)), InSet(sub_expr1, IntervalOO(three, four)))))
# Out:
# expr: (_a -> {_a in (2,5) if _a in (3,4).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left({_{-}a} \mapsto \left\{{_{-}a} \in \left(2,5\right) \textrm{ if } {_{-}a} \in \left(3,4\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (_a -> {_a in (2,5) if _a in (3,4).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. _a -> {_a in (2,5) if _a in (3,4).
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {_a in (2,5) if _a in (3,4).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. _a in (2,5)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. _a in (3,4)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (_a, (2,5))
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (_a, (3,4))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. (2,5)
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. _a
#    core type: Variable
#    sub-expressions:
# 10. (3,4)
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (2, 5)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. IntervalOO
#     core type: Literal
#     sub-expressions:
# 13. (3, 4)
# ...
