# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#neg_is_real_neg_if_pos_is_real_pos">neg_is_real_neg_if_pos_is_real_pos</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import neg_is_real_neg_if_pos_is_real_pos

# %%
# check that the built expression is the same as the stored expression
assert neg_is_real_neg_if_pos_is_real_pos.expr == stored_expr
assert neg_is_real_neg_if_pos_is_real_pos.expr._style_id == stored_expr._style_id
print("Passed sanity check: neg_is_real_neg_if_pos_is_real_pos matches stored_expr")
# Out:
# Passed sanity check: neg_is_real_neg_if_pos_is_real_pos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(neg_is_real_neg_if_pos_is_real_pos.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}^+}~\left(\left(-a\right) \in \mathbb{R}^-\right)

# %%
neg_is_real_neg_if_pos_is_real_pos.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
neg_is_real_neg_if_pos_is_real_pos.expr_info()
# Out:
# 0. forall_{a in RealPos} ((-a) in RealNeg)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {(-a) in RealNeg if a in RealPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {(-a) in RealNeg if a in RealPos.
#    core type: Lambda
#    parameter: 15
#    body: 4
# 4. {(-a) in RealNeg if a in RealPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (-a) in RealNeg
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. a in RealPos
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (-a, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (a, RealPos)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 10. -a
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. RealNeg
#     core type: Literal
#     sub-expressions:
# 12. RealPos
#     core type: Literal
# ...
