# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.logic import Boolean, Forall, InSet, NotInSet
from proveit.numbers import IntervalCO

# %%
# build up the expression from sub-expressions
expr = Forall([x], InSet(NotInSet(x, IntervalCO(a, b)), Boolean))
# Out:
# expr: forall_{x} ((x not-in [a,b)) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x}~\left(\left(x \notin \left[a,b\right)\right) \in \mathbb{B}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x} ((x not-in [a,b)) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> ((x not-in [a,b)) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> ((x not-in [a,b)) in BOOLEAN)
#    core type: Lambda
#    parameter: 11
#    body: 4
# 4. (x not-in [a,b)) in BOOLEAN
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (x not-in [a,b), BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. x not-in [a,b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 9. not-in
#    core type: Literal
#    sub-expressions:
# 10. (x, [a,b))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. x
#     core type: Variable
#     sub-expressions:
# 12. [a,b)
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. IntervalCO
#     core type: Literal
#     sub-expressions:
# 14. (a, b)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
