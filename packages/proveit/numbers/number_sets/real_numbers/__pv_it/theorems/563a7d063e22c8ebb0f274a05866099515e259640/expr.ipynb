# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, Forall, InSet, NotInSet
from proveit.numbers import Complex, IntervalCO, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x], NotInSet(x, IntervalCO(a, b)), domain = Complex, condition = NotInSet(x, Real)), And(InSet(a, Real), InSet(b, Real)))
# Out:
# expr: {forall_{x in Complex | x not-in Real} (x not-in [a,b)) if a in Real ,  b in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x \in \mathbb{C}~|~x \notin \mathbb{R}}~\left(x \notin \left[a,b\right)\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x in Complex | x not-in Real} (x not-in [a,b)) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x in Complex | x not-in Real} (x not-in [a,b))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 15
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {x not-in [a,b) if x in Complex ,  x not-in Real.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> {x not-in [a,b) if x in Complex ,  x not-in Real.
#    core type: Lambda
#    parameter: 29
#    body: 9
# 7. a in Real
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. b in Real
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. {x not-in [a,b) if x in Complex ,  x not-in Real.
#    core type: Conditional
#    value: 12
#    condition: 13
# ...
