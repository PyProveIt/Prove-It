# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, InSet, NotInSet, Or
from proveit.numbers import IntervalOC, Less, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(NotInSet(x, IntervalOC(a, b)), And(InSet(a, Real), InSet(b, Real), InSet(x, Real), Or(LessEq(x, a), Less(b, x))))
# Out:
# expr: {x not-in (a,b] if a in Real ,  b in Real ,  x in Real ,  (x <= a) or (b < x).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x \notin \left(a,b\right] \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  x \in \mathbb{R} ,  \left(x \leq a\right) \lor \left(b < x\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x not-in (a,b] if a in Real ,  b in Real ,  x in Real ,  (x <= a) or (b < x).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x not-in (a,b]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Real) and (b in Real) and (x in Real) and ((x <= a) or (b < x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. not-in
#    core type: Literal
#    sub-expressions:
# 4. (x, (a,b])
#    core type: ExprTuple
#    sub-expressions: 29, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real, x in Real, (x <= a) or (b < x))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. (a,b]
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. a in Real
#    core type: Operation
#    operator: 16
#    operands: 14
# 9. b in Real
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. x in Real
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. (x <= a) or (b < x)
# ...
