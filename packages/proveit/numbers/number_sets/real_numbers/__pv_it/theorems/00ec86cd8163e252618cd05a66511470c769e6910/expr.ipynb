# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, x
from proveit.logic import And, InSet, NotInSet, Or
from proveit.numbers import IntervalCO, Less, LessEq, Real

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b, x], Conditional(NotInSet(x, IntervalCO(a, b)), And(InSet(a, Real), InSet(b, Real), InSet(x, Real), Or(Less(x, a), LessEq(b, x)))))
# Out:
# expr: (a, b, x) -> {x not-in [a,b) if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b <= x).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, x\right) \mapsto \left\{x \notin \left[a,b\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  x \in \mathbb{R} ,  \left(x < a\right) \lor \left(b \leq x\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, x) -> {x not-in [a,b) if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b <= x).
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 31
# 2. {x not-in [a,b) if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b <= x).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x not-in [a,b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Real) and (b in Real) and (x in Real) and ((x < a) or (b <= x))
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. not-in
#    core type: Literal
#    sub-expressions:
# 6. (x, [a,b))
#    core type: ExprTuple
#    sub-expressions: 31, 9
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, b in Real, x in Real, (x < a) or (b <= x))
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. [a,b)
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. a in Real
#     core type: Operation
#     operator: 18
#     operands: 16
# 11. b in Real
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. x in Real
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. (x < a) or (b <= x)
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. IntervalCO
#     core type: Literal
#     sub-expressions:
# 15. (a, b)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 16. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 29, 22
# 17. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 31, 22
# 20. or
#     core type: Literal
#     sub-expressions:
# 21. (x < a, b <= x)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. Real
#     core type: Literal
#     sub-expressions:
# 23. x < a
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. b <= x
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. <
#     core type: Literal
#     sub-expressions:
# 26. (x, a)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 27. <=
#     core type: Literal
#     sub-expressions:
# 28. (b, x)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. a
#     core type: Variable
#     sub-expressions:
# 30. b
#     core type: Variable
#     sub-expressions:
# 31. x
#     core type: Variable
#     sub-expressions:
