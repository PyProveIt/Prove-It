# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import InSet
from proveit.numbers import Less, RealNeg, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Less(x, zero), InSet(x, RealNeg)))
# Out:
# expr: x -> {x < 0 if x in RealNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x < 0 \textrm{ if } x \in \mathbb{R}^-\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x < 0 if x in RealNeg.
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. {x < 0 if x in RealNeg.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x < 0
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. x in RealNeg
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <
#    core type: Literal
#    sub-expressions:
# 5. (x, 0)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, RealNeg)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. RealNeg
#     core type: Literal
#     sub-expressions:
