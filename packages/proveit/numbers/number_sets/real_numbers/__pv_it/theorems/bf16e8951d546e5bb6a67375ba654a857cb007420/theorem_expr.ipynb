# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonzero_real_is_real_nonzero">nonzero_real_is_real_nonzero</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import nonzero_real_is_real_nonzero

# %%
# check that the built expression is the same as the stored expression
assert nonzero_real_is_real_nonzero.expr == stored_expr
assert nonzero_real_is_real_nonzero.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonzero_real_is_real_nonzero matches stored_expr")
# Out:
# Passed sanity check: nonzero_real_is_real_nonzero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonzero_real_is_real_nonzero.latex())
# Out:
# \vdash \forall_{a \in \mathbb{R}~|~a \neq 0}~\left(a \in \mathbb{R}^{\neq 0}\right)

# %%
nonzero_real_is_real_nonzero.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonzero_real_is_real_nonzero.expr_info()
# Out:
# 0. forall_{a in Real | a != 0} (a in RealNonZero)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (a -> {a in RealNonZero if a in Real ,  a != 0.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. a -> {a in RealNonZero if a in Real ,  a != 0.
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. {a in RealNonZero if a in Real ,  a != 0.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a in RealNonZero
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. (a in Real) and (a != 0)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a, RealNonZero)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. RealNonZero
#     core type: Literal
#     sub-expressions:
# 11. a in Real
#     core type: Operation
#     operator: 13
# ...
