# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Real, RealNonPos, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(a, Conditional(InSet(a, RealNonPos), And(InSet(a, Real), LessEq(a, zero)))))
# Out:
# expr: (a -> {a in RealNonPos if a in Real ,  a <= 0.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \mapsto \left\{a \in \mathbb{R}^{\le 0} \textrm{ if } a \in \mathbb{R} ,  a \leq 0\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a -> {a in RealNonPos if a in Real ,  a <= 0.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a -> {a in RealNonPos if a in Real ,  a <= 0.
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {a in RealNonPos if a in Real ,  a <= 0.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a in RealNonPos
#    core type: Operation
#    operator: 11
#    operands: 5
# 4. (a in Real) and (a <= 0)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a, RealNonPos)
#    core type: ExprTuple
#    sub-expressions: 16, 8
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Real, a <= 0)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. RealNonPos
#    core type: Literal
#    sub-expressions:
# 9. a in Real
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. a <= 0
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. <=
#     core type: Literal
#     sub-expressions:
# 14. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. 0
#     core type: Literal
#     sub-expressions:
