# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, x
from proveit.logic import And, InSet, NotInSet, Or
from proveit.numbers import IntervalCC, Less, Real

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b, x], Conditional(NotInSet(x, IntervalCC(a, b)), And(InSet(a, Real), InSet(b, Real), InSet(x, Real), Or(Less(x, a), Less(b, x))))))
# Out:
# expr: ((a, b, x) -> {x not-in [a,b] if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b < x).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, x\right) \mapsto \left\{x \notin \left[a,b\right] \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  x \in \mathbb{R} ,  \left(x < a\right) \lor \left(b < x\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, x) -> {x not-in [a,b] if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b < x).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, x) -> {x not-in [a,b] if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b < x).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 29, 30, 31
# 3. {x not-in [a,b] if a in Real ,  b in Real ,  x in Real ,  (x < a) or (b < x).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. x not-in [a,b]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Real) and (b in Real) and (x in Real) and ((x < a) or (b < x))
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. (x, [a,b])
#    core type: ExprTuple
#    sub-expressions: 31, 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (a in Real, b in Real, x in Real, (x < a) or (b < x))
#    core type: ExprTuple
# ...
