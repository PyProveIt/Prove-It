# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, x
from proveit.logic import And, InSet, NotInSet
from proveit.numbers import Complex, IntervalOC, Real

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(NotInSet(x, IntervalOC(a, b)), And(InSet(x, Complex), NotInSet(x, Real))))
# Out:
# expr: x -> {x not-in (a,b] if x in Complex ,  x not-in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x \notin \left(a,b\right] \textrm{ if } x \in \mathbb{C} ,  x \notin \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x not-in (a,b] if x in Complex ,  x not-in Real.
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. {x not-in (a,b] if x in Complex ,  x not-in Real.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x not-in (a,b]
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (x in Complex) and (x not-in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x, (a,b])
#    core type: ExprTuple
#    sub-expressions: 19, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex, x not-in Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a,b]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x in Complex
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. x not-in Real
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. IntervalOC
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 14. not-in
#     core type: Literal
#     sub-expressions:
# 15. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. Complex
#     core type: Literal
#     sub-expressions:
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. Real
#     core type: Literal
#     sub-expressions:
