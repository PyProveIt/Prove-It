# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, x
from proveit.logic import Boolean, InSet, NotInSet
from proveit.numbers import IntervalCC

# %%
# build up the expression from sub-expressions
expr = Lambda(x, InSet(NotInSet(x, IntervalCC(a, b)), Boolean))
# Out:
# expr: x -> ((x not-in [a,b]) in BOOLEAN)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left(\left(x \notin \left[a,b\right]\right) \in \mathbb{B}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> ((x not-in [a,b]) in BOOLEAN)
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. (x not-in [a,b]) in BOOLEAN
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. in
#    core type: Literal
#    sub-expressions:
# 3. (x not-in [a,b], BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. x not-in [a,b]
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 6. not-in
#    core type: Literal
#    sub-expressions:
# 7. (x, [a,b])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. [a,b]
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. IntervalCC
#     core type: Literal
#     sub-expressions:
# 11. (a, b)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. a
#     core type: Variable
#     sub-expressions:
# 13. b
#     core type: Variable
#     sub-expressions:
