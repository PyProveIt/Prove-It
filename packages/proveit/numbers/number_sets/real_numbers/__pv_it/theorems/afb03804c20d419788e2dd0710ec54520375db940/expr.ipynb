# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, x
from proveit.logic import And, Forall, InSet, NotInSet
from proveit.numbers import Complex, IntervalOO, Real

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Forall([x], NotInSet(x, IntervalOO(a, b)), domain = Complex, condition = NotInSet(x, Real)), And(InSet(a, Real), InSet(b, Real))))
# Out:
# expr: (a, b) -> {forall_{x in Complex | x not-in Real} (x not-in (a,b)) if a in Real ,  b in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\forall_{x \in \mathbb{C}~|~x \notin \mathbb{R}}~\left(x \notin \left(a,b\right)\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {forall_{x in Complex | x not-in Real} (x not-in (a,b)) if a in Real ,  b in Real.
#    core type: Lambda
#    parameters: 22\n   body: 1
# 1. {forall_{x in Complex | x not-in Real} (x not-in (a,b)) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{x in Complex | x not-in Real} (x not-in (a,b))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 16
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x -> {x not-in (a,b) if x in Complex ,  x not-in Real.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. x -> {x not-in (a,b) if x in Complex ,  x not-in Real.
#    core type: Lambda
#    parameter: 30
#    body: 10
# 8. a in Real
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. b in Real
#    core type: Operation
#    operator: 23
#    operands: 12
# 10. {x not-in (a,b) if x in Complex ,  x not-in Real.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 31
# 12. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 28, 31
# 13. x not-in (a,b)
#     core type: Operation
#     operator: 25
#     operands: 15
# 14. (x in Complex) and (x not-in Real)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (x, (a,b))
#     core type: ExprTuple
#     sub-expressions: 30, 18
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (x in Complex, x not-in Real)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. (a,b)
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. x in Complex
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. x not-in Real
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. IntervalOO
#     core type: Literal
#     sub-expressions:
# 22. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 30, 29
# 25. not-in
#     core type: Literal
#     sub-expressions:
# 26. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. x
#     core type: Variable
#     sub-expressions:
# 31. Real
#     core type: Literal
#     sub-expressions:
