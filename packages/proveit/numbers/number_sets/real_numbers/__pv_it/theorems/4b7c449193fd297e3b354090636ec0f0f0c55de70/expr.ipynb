# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Real, RealNonPos, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(a, RealNonPos), And(InSet(a, Real), LessEq(a, zero)))
# Out:
# expr: {a in RealNonPos if a in Real ,  a <= 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a \in \mathbb{R}^{\le 0} \textrm{ if } a \in \mathbb{R} ,  a \leq 0\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a in RealNonPos if a in Real ,  a <= 0.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a in RealNonPos
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. (a in Real) and (a <= 0)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, RealNonPos)
#    core type: ExprTuple
#    sub-expressions: 14, 6
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (a in Real, a <= 0)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. RealNonPos
#    core type: Literal
#    sub-expressions:
# 7. a in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. a <= 0
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. <=
#     core type: Literal
#     sub-expressions:
# 12. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. Real
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. 0
#     core type: Literal
#     sub-expressions:
