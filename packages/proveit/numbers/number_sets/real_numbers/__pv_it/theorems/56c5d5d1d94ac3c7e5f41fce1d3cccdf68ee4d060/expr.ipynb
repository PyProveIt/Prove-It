# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Real, RealNonZero, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(a, Conditional(InSet(a, RealNonZero), And(InSet(a, Real), NotEquals(a, zero))))
# Out:
# expr: a -> {a in RealNonZero if a in Real ,  a != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a \mapsto \left\{a \in \mathbb{R}^{\neq 0} \textrm{ if } a \in \mathbb{R} ,  a \neq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a -> {a in RealNonZero if a in Real ,  a != 0.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {a in RealNonZero if a in Real ,  a != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a in RealNonZero
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (a in Real) and (a != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a, RealNonZero)
#    core type: ExprTuple
#    sub-expressions: 15, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, a != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. RealNonZero
#    core type: Literal
#    sub-expressions:
# 8. a in Real
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. a != 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. !=
#     core type: Literal
#     sub-expressions:
# 13. (a, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Real
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
