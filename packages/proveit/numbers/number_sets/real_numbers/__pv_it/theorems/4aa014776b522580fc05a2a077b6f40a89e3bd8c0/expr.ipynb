# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, x
from proveit.logic import And, InSet, NotInSet, Or
from proveit.numbers import IntervalCC, Less, Real

# %%
# build up the expression from sub-expressions
expr = Conditional(Or(Less(x, a), Less(b, x)), And(InSet(a, Real), InSet(b, Real), InSet(x, Real), NotInSet(x, IntervalCC(a, b))))
# Out:
# expr: {(x < a) or (b < x) if a in Real ,  b in Real ,  x in Real ,  x not-in [a,b].

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(x < a\right) \lor \left(b < x\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R} ,  x \in \mathbb{R} ,  x \notin \left[a,b\right]\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(x < a) or (b < x) if a in Real ,  b in Real ,  x in Real ,  x not-in [a,b].
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (x < a) or (b < x)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Real) and (b in Real) and (x in Real) and (x not-in [a,b])
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. or
#    core type: Literal
#    sub-expressions:
# 4. (x < a, b < x)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Real, b in Real, x in Real, x not-in [a,b])
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12
# 7. x < a
#    core type: Operation
#    operator: 14
#    operands: 13
# 8. b < x
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. a in Real
#    core type: Operation
#    operator: 18
#    operands: 16
# 10. b in Real
#     core type: Operation
#     operator: 18
#     operands: 17
# 11. x in Real
#     core type: Operation
#     operator: 18
#     operands: 19
# 12. x not-in [a,b]
#     core type: Operation
#     operator: 20
#     operands: 21
# 13. (x, a)
#     core type: ExprTuple
#     sub-expressions: 23, 27
# 14. <
#     core type: Literal
#     sub-expressions:
# 15. (b, x)
#     core type: ExprTuple
#     sub-expressions: 28, 23
# 16. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 22
# 17. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 28, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, Real)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 20. not-in
#     core type: Literal
#     sub-expressions:
# 21. (x, [a,b])
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. Real
#     core type: Literal
#     sub-expressions:
# 23. x
#     core type: Variable
#     sub-expressions:
# 24. [a,b]
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. IntervalCC
#     core type: Literal
#     sub-expressions:
# 26. (a, b)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. a
#     core type: Variable
#     sub-expressions:
# 28. b
#     core type: Variable
#     sub-expressions:
