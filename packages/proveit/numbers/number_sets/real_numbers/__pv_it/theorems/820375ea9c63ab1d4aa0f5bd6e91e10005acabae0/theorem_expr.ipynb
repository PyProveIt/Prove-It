# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#real_not_in_interval_oc">real_not_in_interval_oc</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import real_not_in_interval_oc

# %%
# check that the built expression is the same as the stored expression
assert real_not_in_interval_oc.expr == stored_expr
assert real_not_in_interval_oc.expr._style_id == stored_expr._style_id
print("Passed sanity check: real_not_in_interval_oc matches stored_expr")
# Out:
# Passed sanity check: real_not_in_interval_oc matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(real_not_in_interval_oc.latex())
# Out:
# \vdash \forall_{a, b, x \in \mathbb{R}~|~\left(x \leq a\right) \lor \left(b < x\right)}~\left(x \notin \left(a,b\right]\right)

# %%
real_not_in_interval_oc.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
real_not_in_interval_oc.expr_info()
# Out:
# 0. forall_{a, b, x in Real | (x <= a) or (b < x)} (x not-in (a,b])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, x) -> {x not-in (a,b] if a in Real ,  b in Real ,  x in Real ,  (x <= a) or (b < x).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, x) -> {x not-in (a,b] if a in Real ,  b in Real ,  x in Real ,  (x <= a) or (b < x).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, x)
#    core type: ExprTuple
#    sub-expressions: 32, 33, 34
# 5. {x not-in (a,b] if a in Real ,  b in Real ,  x in Real ,  (x <= a) or (b < x).
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. x not-in (a,b]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Real) and (b in Real) and (x in Real) and ((x <= a) or (b < x))
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. not-in
#    core type: Literal
#    sub-expressions:
# 9. (x, (a,b])
# ...
