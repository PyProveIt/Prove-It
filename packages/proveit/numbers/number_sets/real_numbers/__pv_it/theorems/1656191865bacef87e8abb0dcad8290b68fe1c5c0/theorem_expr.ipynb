# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#nonneg_if_in_real_nonneg">nonneg_if_in_real_nonneg</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.real_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.real_numbers import nonneg_if_in_real_nonneg

# %%
# check that the built expression is the same as the stored expression
assert nonneg_if_in_real_nonneg.expr == stored_expr
assert nonneg_if_in_real_nonneg.expr._style_id == stored_expr._style_id
print("Passed sanity check: nonneg_if_in_real_nonneg matches stored_expr")
# Out:
# Passed sanity check: nonneg_if_in_real_nonneg matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(nonneg_if_in_real_nonneg.latex())
# Out:
# \vdash \forall_{x \in \mathbb{R}^{\ge 0}}~\left(x \geq 0\right)

# %%
nonneg_if_in_real_nonneg.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
nonneg_if_in_real_nonneg.expr_info()
# Out:
# 0. forall_{x in RealNonNeg} (x >= 0)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {x >= 0 if x in RealNonNeg.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {x >= 0 if x in RealNonNeg.
#    core type: Lambda
#    parameter: 12
#    body: 4
# 4. {x >= 0 if x in RealNonNeg.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x >= 0
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in RealNonNeg
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (0, x)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, RealNonNeg)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. 0
#     core type: Literal
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
# 13. RealNonNeg
#     core type: Literal
# ...
