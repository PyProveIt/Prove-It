# %% [markdown]
# Theory of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">number_sets</a>.complex_numbers
# ========
#
# Provide description here.

# %%
import proveit
# %theory
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#imaginary_number_def">proveit.numbers.number_sets.complex_numbers.imaginary_number_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/e40344e392359bd746382c596ba8896b0cf74da60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="axioms.ipynb#complex_numbers_def">proveit.numbers.number_sets.complex_numbers.complex_numbers_def</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/58b3caf14d1f8b8b18a7228fe58162d833ad001b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
