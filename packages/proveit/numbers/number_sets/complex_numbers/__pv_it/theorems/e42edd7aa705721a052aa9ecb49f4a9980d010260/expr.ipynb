# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, r, theta
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Mult, Neg, Real, e, i, pi

# %%
# build up the expression from sub-expressions
expr = Lambda([r, theta], Conditional(Equals(Mult(Neg(r), Exp(e, Mult(i, Add(theta, pi)))), Mult(r, Exp(e, Mult(i, theta)))), And(InSet(r, Real), InSet(theta, Real))))
# Out:
# expr: (r, theta) -> {((-r) * e^{i * (theta + pi)}) = (r * e^{i * theta}) if r in Real ,  theta in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(r, \theta\right) \mapsto \left\{\left(\left(-r\right) \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)}\right) = \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \theta}\right) \textrm{ if } r \in \mathbb{R} ,  \theta \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (r, theta) -> {((-r) * e^{i * (theta + pi)}) = (r * e^{i * theta}) if r in Real ,  theta in Real.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (r, theta)
#    core type: ExprTuple
#    sub-expressions: 27, 38
# 2. {((-r) * e^{i * (theta + pi)}) = (r * e^{i * theta}) if r in Real ,  theta in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((-r) * e^{i * (theta + pi)}) = (r * e^{i * theta})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (r in Real) and (theta in Real)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. ((-r) * e^{i * (theta + pi)}, r * e^{i * theta})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (r in Real, theta in Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. (-r) * e^{i * (theta + pi)}
#    core type: Operation
#    operator: 32
#    operands: 13
# 10. r * e^{i * theta}
#     core type: Operation
#     operator: 32
#     operands: 14
# 11. r in Real
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. theta in Real
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (-r, e^{i * (theta + pi)})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 14. (r, e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 15. (r, Real)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (theta, Real)
#     core type: ExprTuple
#     sub-expressions: 38, 21
# 18. -r
#     core type: Operation
#     operator: 22
#     operand: 27
# 19. e^{i * (theta + pi)}
#     core type: Operation
#     operator: 25
#     operands: 24
# 20. e^{i * theta}
#     core type: Operation
#     operator: 25
#     operands: 26
# 21. Real
#     core type: Literal
#     sub-expressions:
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (r)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. (e, i * (theta + pi))
#     core type: ExprTuple
#     sub-expressions: 29, 28
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. r
#     core type: Variable
#     sub-expressions:
# 28. i * (theta + pi)
#     core type: Operation
#     operator: 32
#     operands: 31
# 29. e
#     core type: Literal
#     sub-expressions:
# 30. i * theta
#     core type: Operation
#     operator: 32
#     operands: 33
# 31. (i, theta + pi)
#     core type: ExprTuple
#     sub-expressions: 35, 34
# 32. *
#     core type: Literal
#     sub-expressions:
# 33. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 35, 38
# 34. theta + pi
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. i
#     core type: Literal
#     sub-expressions:
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (theta, pi)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. theta
#     core type: Variable
#     sub-expressions:
# 39. pi
#     core type: Literal
#     sub-expressions:
