# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complex_polar_negation">complex_polar_negation</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.complex_numbers import complex_polar_negation

# %%
# check that the built expression is the same as the stored expression
assert complex_polar_negation.expr == stored_expr
assert complex_polar_negation.expr._style_id == stored_expr._style_id
print("Passed sanity check: complex_polar_negation matches stored_expr")
# Out:
# Passed sanity check: complex_polar_negation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(complex_polar_negation.latex())
# Out:
# \vdash \forall_{r, \theta \in \mathbb{R}}~\left(\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)}\right) = \left(-\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \theta}\right)\right)\right)

# %%
complex_polar_negation.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
complex_polar_negation.expr_info()
# Out:
# 0. forall_{r, theta in Real} ((r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((r, theta) -> {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (r, theta) -> {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (r, theta)
#    core type: ExprTuple
#    sub-expressions: 28, 42
# 5. {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (r * e^{i * (theta + pi)}) = (-(r * e^{i * theta}))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (r in Real) and (theta in Real)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
#    core type: Literal
# ...
