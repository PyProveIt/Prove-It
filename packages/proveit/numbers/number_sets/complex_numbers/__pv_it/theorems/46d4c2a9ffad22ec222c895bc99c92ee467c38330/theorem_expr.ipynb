# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#unit_length_complex_polar_negation">unit_length_complex_polar_negation</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.complex_numbers import unit_length_complex_polar_negation

# %%
# check that the built expression is the same as the stored expression
assert unit_length_complex_polar_negation.expr == stored_expr
assert unit_length_complex_polar_negation.expr._style_id == stored_expr._style_id
print("Passed sanity check: unit_length_complex_polar_negation matches stored_expr")
# Out:
# Passed sanity check: unit_length_complex_polar_negation matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(unit_length_complex_polar_negation.latex())
# Out:
# \vdash \forall_{\theta \in \mathbb{R}}~\left(\mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)} = \left(-\mathsf{e}^{\mathsf{i} \cdot \theta}\right)\right)

# %%
unit_length_complex_polar_negation.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
unit_length_complex_polar_negation.expr_info()
# Out:
# 0. forall_{theta in Real} (e^{i * (theta + pi)} = (-e^{i * theta}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (theta -> {e^{i * (theta + pi)} = (-e^{i * theta}) if theta in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. theta -> {e^{i * (theta + pi)} = (-e^{i * theta}) if theta in Real.
#    core type: Lambda
#    parameter: 31
#    body: 4
# 4. {e^{i * (theta + pi)} = (-e^{i * theta}) if theta in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. e^{i * (theta + pi)} = (-e^{i * theta})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. theta in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (e^{i * (theta + pi)}, -e^{i * theta})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (theta, Real)
#     core type: ExprTuple
#     sub-expressions: 31, 13
# 11. e^{i * (theta + pi)}
#     core type: Operation
#     operator: 20
#     operands: 14
# 12. -e^{i * theta}
#     core type: Operation
#     operator: 15
#     operand: 18
# 13. Real
#     core type: Literal
#     sub-expressions:
# 14. (e, i * (theta + pi))
#     core type: ExprTuple
#     sub-expressions: 23, 17
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 18
# 17. i * (theta + pi)
#     core type: Operation
#     operator: 27
#     operands: 19
# 18. e^{i * theta}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (i, theta + pi)
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. theta + pi
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. e
#     core type: Literal
#     sub-expressions:
# 24. i * theta
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (theta, pi)
#     core type: ExprTuple
#     sub-expressions: 31, 29
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. pi
#     core type: Literal
#     sub-expressions:
# 30. i
#     core type: Literal
#     sub-expressions:
# 31. theta
#     core type: Variable
#     sub-expressions:
