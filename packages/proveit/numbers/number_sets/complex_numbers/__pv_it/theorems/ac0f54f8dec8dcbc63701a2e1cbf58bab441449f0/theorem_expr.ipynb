# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complex_nonzero_membership_is_bool">complex_nonzero_membership_is_bool</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.number_sets.complex_numbers import complex_nonzero_membership_is_bool

# %%
# check that the built expression is the same as the stored expression
assert complex_nonzero_membership_is_bool.expr == stored_expr
assert complex_nonzero_membership_is_bool.expr._style_id == stored_expr._style_id
print("Passed sanity check: complex_nonzero_membership_is_bool matches stored_expr")
# Out:
# Passed sanity check: complex_nonzero_membership_is_bool matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(complex_nonzero_membership_is_bool.latex())
# Out:
# \vdash \forall_{x}~\left(\left(x \in \mathbb{C}^{\neq 0}\right) \in \mathbb{B}\right)

# %%
complex_nonzero_membership_is_bool.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
complex_nonzero_membership_is_bool.expr_info()
# Out:
# 0. forall_{x} ((x in ComplexNonZero) in BOOLEAN)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> ((x in ComplexNonZero) in BOOLEAN))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> ((x in ComplexNonZero) in BOOLEAN)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 4. (x in ComplexNonZero) in BOOLEAN
#    core type: Operation
#    operator: 8
#    operands: 5
# 5. (x in ComplexNonZero, BOOLEAN)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. x in ComplexNonZero
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. BOOLEAN
#    core type: Literal
#    sub-expressions:
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (x, ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. ComplexNonZero
#     core type: Literal
#     sub-expressions:
