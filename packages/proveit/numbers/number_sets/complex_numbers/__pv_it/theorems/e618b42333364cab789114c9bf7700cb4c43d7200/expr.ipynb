# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, r, theta
from proveit.numbers import Add, Exp, Mult, Neg, e, i, pi

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(r, Exp(e, Mult(i, Add(theta, pi)))), Neg(Mult(r, Exp(e, Mult(i, theta)))))
# Out:
# expr: (r * e^{i * (theta + pi)}, -(r * e^{i * theta}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)}, -\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \theta}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (r * e^{i * (theta + pi)}, -(r * e^{i * theta}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. r * e^{i * (theta + pi)}
#    core type: Operation
#    operator: 21
#    operands: 3
# 2. -(r * e^{i * theta})
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (r, e^{i * (theta + pi)})
#    core type: ExprTuple
#    sub-expressions: 11, 6
# 4. -
#    core type: Literal
#    sub-expressions:
# 5. (r * e^{i * theta})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. e^{i * (theta + pi)}
#    core type: Operation
#    operator: 14
#    operands: 8
# 7. r * e^{i * theta}
#    core type: Operation
#    operator: 21
#    operands: 9
# 8. (e, i * (theta + pi))
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 9. (r, e^{i * theta})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. i * (theta + pi)
#     core type: Operation
#     operator: 21
#     operands: 13
# 11. r
#     core type: Variable
#     sub-expressions:
# 12. e^{i * theta}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (i, theta + pi)
#     core type: ExprTuple
#     sub-expressions: 24, 16
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. theta + pi
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. e
#     core type: Literal
#     sub-expressions:
# 18. i * theta
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (theta, pi)
#     core type: ExprTuple
#     sub-expressions: 25, 23
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. pi
#     core type: Literal
#     sub-expressions:
# 24. i
#     core type: Literal
#     sub-expressions:
# 25. theta
#     core type: Variable
#     sub-expressions:
