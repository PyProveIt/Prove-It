# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, x
from proveit.logic import And, InSet, NotEquals
from proveit.numbers import Complex, ComplexNonZero, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(InSet(x, ComplexNonZero), And(InSet(x, Complex), NotEquals(x, zero))))
# Out:
# expr: x -> {x in ComplexNonZero if x in Complex ,  x != 0.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x \in \mathbb{C}^{\neq 0} \textrm{ if } x \in \mathbb{C} ,  x \neq 0\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x in ComplexNonZero if x in Complex ,  x != 0.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {x in ComplexNonZero if x in Complex ,  x != 0.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x in ComplexNonZero
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (x in Complex) and (x != 0)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x, ComplexNonZero)
#    core type: ExprTuple
#    sub-expressions: 15, 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex, x != 0)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ComplexNonZero
#    core type: Literal
#    sub-expressions:
# 8. x in Complex
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. x != 0
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (x, Complex)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. !=
#     core type: Literal
#     sub-expressions:
# 13. (x, 0)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. Complex
#     core type: Literal
#     sub-expressions:
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. 0
#     core type: Literal
#     sub-expressions:
