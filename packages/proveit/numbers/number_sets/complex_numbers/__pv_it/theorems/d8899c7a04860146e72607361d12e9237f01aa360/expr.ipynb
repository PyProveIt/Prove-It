# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, r, theta
from proveit.numbers import Add, Exp, Mult, e, i, pi

# %%
# build up the expression from sub-expressions
expr = ExprTuple(r, Exp(e, Mult(i, Add(theta, pi))))
# Out:
# expr: (r, e^{i * (theta + pi)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(r, \mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (r, e^{i * (theta + pi)})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. r
#    core type: Variable
#    sub-expressions:
# 2. e^{i * (theta + pi)}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. Exp
#    core type: Literal
#    sub-expressions:
# 4. (e, i * (theta + pi))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. e
#    core type: Literal
#    sub-expressions:
# 6. i * (theta + pi)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (i, theta + pi)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. i
#    core type: Literal
#    sub-expressions:
# 10. theta + pi
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (theta, pi)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. theta
#     core type: Variable
#     sub-expressions:
# 14. pi
#     core type: Literal
#     sub-expressions:
