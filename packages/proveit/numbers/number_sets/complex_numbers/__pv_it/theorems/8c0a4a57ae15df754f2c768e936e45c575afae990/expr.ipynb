# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, r, theta
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Mult, Neg, Real, e, i, pi

# %%
# build up the expression from sub-expressions
expr = Lambda([r, theta], Conditional(Equals(Mult(r, Exp(e, Mult(i, Add(theta, pi)))), Neg(Mult(r, Exp(e, Mult(i, theta))))), And(InSet(r, Real), InSet(theta, Real))))
# Out:
# expr: (r, theta) -> {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(r, \theta\right) \mapsto \left\{\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\theta + \pi\right)}\right) = \left(-\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot \theta}\right)\right) \textrm{ if } r \in \mathbb{R} ,  \theta \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (r, theta) -> {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (r, theta)
#    core type: ExprTuple
#    sub-expressions: 25, 39
# 2. {(r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})) if r in Real ,  theta in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (r * e^{i * (theta + pi)}) = (-(r * e^{i * theta}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (r in Real) and (theta in Real)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (r * e^{i * (theta + pi)}, -(r * e^{i * theta}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (r in Real, theta in Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. r * e^{i * (theta + pi)}
#    core type: Operation
#    operator: 35
#    operands: 13
# 10. -(r * e^{i * theta})
#     core type: Operation
#     operator: 14
#     operand: 20
# 11. r in Real
#     core type: Operation
#     operator: 17
#     operands: 16
# 12. theta in Real
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. (r, e^{i * (theta + pi)})
#     core type: ExprTuple
#     sub-expressions: 25, 19
# 14. -
#     core type: Literal
#     sub-expressions:
# 15. (r * e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 20
# 16. (r, Real)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (theta, Real)
#     core type: ExprTuple
#     sub-expressions: 39, 21
# 19. e^{i * (theta + pi)}
#     core type: Operation
#     operator: 28
#     operands: 22
# 20. r * e^{i * theta}
#     core type: Operation
#     operator: 35
#     operands: 23
# 21. Real
#     core type: Literal
#     sub-expressions:
# 22. (e, i * (theta + pi))
#     core type: ExprTuple
#     sub-expressions: 31, 24
# 23. (r, e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. i * (theta + pi)
#     core type: Operation
#     operator: 35
#     operands: 27
# 25. r
#     core type: Variable
#     sub-expressions:
# 26. e^{i * theta}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. (i, theta + pi)
#     core type: ExprTuple
#     sub-expressions: 38, 30
# 28. Exp
#     core type: Literal
#     sub-expressions:
# 29. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. theta + pi
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. e
#     core type: Literal
#     sub-expressions:
# 32. i * theta
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (theta, pi)
#     core type: ExprTuple
#     sub-expressions: 39, 37
# 35. *
#     core type: Literal
#     sub-expressions:
# 36. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. pi
#     core type: Literal
#     sub-expressions:
# 38. i
#     core type: Literal
#     sub-expressions:
# 39. theta
#     core type: Variable
#     sub-expressions:
