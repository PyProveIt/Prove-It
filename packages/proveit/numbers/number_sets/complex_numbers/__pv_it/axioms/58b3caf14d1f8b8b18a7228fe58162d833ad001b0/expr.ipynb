# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.number_sets.complex_numbers</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Complex, Mult, Real, i

# %%
# build up the expression from sub-expressions
expr = Forall([a, b], InSet(Add(a, Mult(i, b)), Complex), domain = Real)
# Out:
# expr: forall_{a, b in Real} ((a + (i * b)) in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{R}}~\left(\left(a + \left(\mathsf{i} \cdot b\right)\right) \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Real} ((a + (i * b)) in Complex)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(a + (i * b)) in Complex if a in Real ,  b in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(a + (i * b)) in Complex if a in Real ,  b in Real.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b)
#    core type: ExprTuple
#    sub-expressions: 21, 26
# 5. {(a + (i * b)) in Complex if a in Real ,  b in Real.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (a + (i * b)) in Complex
#    core type: Operation
#    operator: 18
#    operands: 8
# 7. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a + (i * b), Complex)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (a in Real, b in Real)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. a + (i * b)
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. a in Real
#     core type: Operation
#     operator: 18
#     operands: 17
# 14. b in Real
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a, i * b)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. (a, Real)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (b, Real)
#     core type: ExprTuple
#     sub-expressions: 26, 22
# 20. i * b
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. Real
#     core type: Literal
#     sub-expressions:
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (i, b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. i
#     core type: Literal
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
