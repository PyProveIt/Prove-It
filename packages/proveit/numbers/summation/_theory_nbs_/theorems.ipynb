# %% [markdown]
# Theorems (or conjectures) for the theory of <a class="ProveItLink" href="theory.ipynb">proveit.numbers.summation</a>
# ========

# %%
import proveit
# Prepare this notebook for defining the theorems of a theory:
# %theorems_notebook # Keep this at the top following 'import proveit'.
from proveit import (a, b, c, f, g, j, k, l, m, n, x, y, fa, fx,
                     gx, gy, P, Px, R, S, Q, Qx)
from proveit import Operation
from proveit.logic import Implies, Forall, Equals, InSet, Card, SetOfAll
from proveit.numbers import (Add, Abs, Exp, frac, greater, Less, LessEq,
                             Mult, number_ordering, subtract, Sum)
from proveit.numbers import Natural, NaturalPos, Integer, Real
from proveit.numbers import Complex, Interval, zero, one, two, infinity
from proveit.numbers.summation import al, ak, bl, bk

# %%
# %begin theorems
# Out:
# Defining theorems for theory 'proveit.numbers.summation'
# Subsequent end-of-cell assignments will define theorems
# '%end theorems' will finalize the definitions

# %% [markdown]
# #### Several basic closure theorems: if we sum up terms each of which belongs to set S, we generally end up with a sum in set S as well.

# %%
summation_nat_closure = Forall(
    [P, Q], Implies(Forall(x, InSet(Px, Natural), condition=Qx), 
                    InSet(Sum(x, Px, condition=Qx), domain=Natural)))
# Out:
# summation_nat_closure: forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Natural)] => (Sum_{x | Q(x)} P(x) in Natural))

# %%
summation_nat_pos_closure = Forall(
    [P, Q], Implies(Forall(x, InSet(Px, NaturalPos), condition=Qx), 
                    InSet(Sum(x, Px, condition=Qx), domain=NaturalPos)))
# Out:
# summation_nat_pos_closure: forall_{P, Q} ([forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos))

# %%
summation_int_closure = Forall(
    [P, Q], Implies(Forall(x, InSet(Px, Integer), condition=Qx), 
                    InSet(Sum(x, Px, condition=Qx), domain=Integer)))
# Out:
# summation_int_closure: forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Integer)] => (Sum_{x | Q(x)} P(x) in Integer))

# %%
summation_real_closure = Forall(
    [P, Q], Implies(Forall(x, InSet(Px, Real), condition=Qx), 
                       InSet(Sum(x, Px, condition=Qx), domain=Real)))
# Out:
# summation_real_closure: forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Real)] => (Sum_{x | Q(x)} P(x) in Real))

# %%
summation_complex_closure = Forall(
    [P, Q], Implies(Forall(x, InSet(Px, Complex), condition=Qx), 
                       InSet(Sum(x, Px, condition=Qx), domain=Complex)))
# Out:
# summation_complex_closure: forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Complex)] => (Sum_{x | Q(x)} P(x) in Complex))

# %% [markdown]
# ##### Splitting up summations

# %%
sum_split_general = (
    Forall(f,
           Forall([a, b, c],
                  Equals(Sum(x, fx, domain=Interval(a, c)),
                         Add(Sum(x, fx, domain=Interval(a, b)),
                             Sum(x, fx, domain=Interval(Add(b, one), c)))),
                   domain=Integer, conditions=[number_ordering(LessEq(a, b), LessEq(b, c))])
    ))
# Out:
# sum_split_general: forall_{f} [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]

# %%
sum_split_after = (
    Forall(f,
           Forall([a, b, c],
                  Equals(Sum(x, fx, domain=Interval(a, c)),
                         Add(Sum(x, fx, domain=Interval(a, b)),
                             Sum(x, fx, domain=Interval(Add(b, one), c)))),
                   domain=Integer, conditions=[LessEq(a, b), Less(b, c)])
    ))
# Out:
# sum_split_after: forall_{f} [forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]

# %%
sum_split_before = (
    Forall(f,
           Forall([a, b, c],
                  Equals(Sum(x, fx, domain=Interval(a, c)),
                         Add(Sum(x, fx, domain=Interval(a, subtract(b, one))),
                             Sum(x, fx, domain=Interval(b, c)))),
                  domain=Integer,
                  conditions=[Less(a, b), LessEq(b, c)])
    ))
# Out:
# sum_split_before: forall_{f} [forall_{a, b, c in Integer | a < b, b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))))]

# %%
sum_split_first = (
    Forall(f,
        Forall((a, b),
               Equals(Sum(x, fx, domain=Interval(a, b)),
                      Add(fa, Sum(x, fx, domain=Interval(Add(a, one), b)))),
        domain=Integer,
        conditions=[Less(a, b)])
      ))
# Out:
# sum_split_first: forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))]

# %% [markdown]
# #### Index shifting

# %%
index_shift = (
    Forall(f,
           Forall((a, b, c),
                  Equals(Sum(x, Operation(f, x), domain=Interval(a, b)),
                         Sum(x, Operation(f, subtract(x, c)),
                             domain=Interval(Add(a, c), Add(b, c)))),
                  domain=Integer)
    ))
# Out:
# index_shift: forall_{f} [forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))]

# %%
sum_zero_and_one = (
    Forall(f,
           Equals(Sum(n, Operation(f, n), domain=Interval(zero, one)),
                  Add(Operation(f, zero), Operation(f, one)))
    ))
# Out:
# sum_zero_and_one: forall_{f} ((Sum_{n=0}^{1} f(n)) = (f(0) + f(1)))

# %% [markdown]
# #### Some specific summation formulas

# %%
finite_geom_sum = (
    Forall([x, n],
           Equals(Sum(m, Exp(x, m), domain=Interval(zero, n)),
                  frac(subtract(one, Exp(x, Add(n, one))),
                       subtract(one, x))),
           domains=[Complex, NaturalPos]))
# Out:
# finite_geom_sum: forall_{x in Complex, n in NaturalPos} ((Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)))

# %%
gen_finite_geom_sum = (
    Forall(x, Forall((j, k),
                     Equals(Sum(m, Exp(x, m), domain=Interval(zero, k)),
                            frac(subtract(Exp(x, j), Exp(x, Add(k, one))),
                                 subtract(one, x))),
                     domain=Integer, condition=Less(j, k)),
           domain=Complex))
# Out:
# gen_finite_geom_sum: forall_{x in Complex} [forall_{j, k in Integer | j < k} ((Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)))]

# %%
inf_geom_sum = Forall(x, Equals(Sum(m,Exp(x,m),
                                  domain=Interval(zero, infinity)), 
                              frac(one,subtract(one,x))),
                    domain=Complex, condition=Less(Abs(x), one))
# Out:
# inf_geom_sum: forall_{x in Complex | |x| < 1} ((Sum_{m=0}^{infinity} x^{m}) = (1 / (1 - x)))

# %%
sum_first_n_int = Forall(n,
                       Equals( Sum(k, k, domain=Interval(one, n)),
                               frac(Mult(n, Add(n, one)), two) ),
                       domain=NaturalPos)
# Out:
# sum_first_n_int: forall_{n in NaturalPos} ((Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2))

# %%
same_sums = (
    Forall((f, g),
           Forall((m, n),
                  Implies(Forall(k,
                                 Equals(Operation(f, k), Operation(g, k)),
                                 domain=Interval(m, n)),
                          Equals(Sum(l, Operation(f, l), domain=Interval(m, n)),
                                 Sum(l, Operation(g, l), domain=Interval(m, n)))),
                  domain=Integer)))
# Out:
# same_sums: forall_{f, g} [forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))]

# %%
# Could also make such a theorem to apply whenever addition is
# commutative, not just for the Complex numbers.
equiv_sums = (
    Forall((f, g, R, S),
           Implies(Forall(a, InSet(fa, Complex), domain=R),
                   Equals(Sum(x, fx, domain=R),
                          Sum(y, Operation(f, gy), domain=S))),
           conditions=[Equals(SetOfAll(y, gy, domain=S), R)]))
# Out:
# equiv_sums: forall_{f, g, R, S | {g(y)}_{y in S} = R} ([forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))))

# %%
bounded_sum = Forall((S, f, g), Implies(Forall(x, LessEq(
    fx, gx), domain=S), LessEq(Sum(x, fx, domain=S), Sum(x, gx, domain=S))))
# Out:
# bounded_sum: forall_{S, f, g} ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))

# %%
weak_summation_from_summands_bound = Forall(
    (a, b, S), Implies(Forall(k, LessEq(ak, bk), domain=S),
                       LessEq(Sum(l, al, domain=S),
                              Sum(l, bl, domain=S))))
# Out:
# weak_summation_from_summands_bound: forall_{a, b, S} ([forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l)))

# %%
strong_summation_from_summands_bound = Forall(
    (a, b, S), Implies(Forall(k, Less(ak, bk), domain=S),
                       Less(Sum(l, al, domain=S),
                            Sum(l, bl, domain=S))),
                      condition=greater(Card(S), zero))
# Out:
# strong_summation_from_summands_bound: forall_{a, b, S | |S| > 0} ([forall_{k in S} (a(k) < b(k))] => (Sum_{l in S} a(l) < Sum_{l in S} b(l)))

# %%
# %end theorems
# Out:
# These theorems may now be imported from the theory package: proveit.numbers.summation
