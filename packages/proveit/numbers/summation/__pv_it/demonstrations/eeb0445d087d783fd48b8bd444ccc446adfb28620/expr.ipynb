# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, nine, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(k, Conditional(Add(k, Neg(two)), InSet(k, Interval(nine, nine)))))
# Out:
# expr: (k -> {k - 2 if k in {9 .. 9}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{k - 2 \textrm{ if } k \in \{9~\ldotp \ldotp~9\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {k - 2 if k in {9 .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {k - 2 if k in {9 .. 9}.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {k - 2 if k in {9 .. 9}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. k - 2
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. k in {9 .. 9}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (k, -2)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, {9 .. 9})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. -2
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. {9 .. 9}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (2)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (9, 9)
#     core type: ExprTuple
#     sub-expressions: 17, 17
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. 9
#     core type: Literal
#     sub-expressions:
