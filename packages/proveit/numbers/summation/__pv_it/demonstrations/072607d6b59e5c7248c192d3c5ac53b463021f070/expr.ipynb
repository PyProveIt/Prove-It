# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, a, c
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, one

# %%
# build up the expression from sub-expressions
expr = Equals([ExprRange(a, InSet(IndexedVar(c, a), Complex), one, one)], [InSet(IndexedVar(c, one), Complex)])
# Out:
# expr: (c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex) = (c_{1} in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c_{1} \in \mathbb{C}, \ldots, c_{1} \in \mathbb{C}\right) = \left(c_{1} \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex) = (c_{1} in Complex)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex), (c_{1} in Complex))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (c_{1} in Complex)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (c_{1} in Complex), ..(c_{a} in Complex).., (c_{1} in Complex)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 16
#    end_index: 16
# 6. c_{1} in Complex
#    core type: Operation
#    operator: 11
#    operands: 8
# 7. a -> (c_{a} in Complex)
#    core type: Lambda
#    parameter: 19
#    body: 9
# 8. (c_{1}, Complex)
#    core type: ExprTuple
#    sub-expressions: 10, 15
# 9. c_{a} in Complex
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. c_{1}
#     core type: IndexedVar
# variable: 17
# index: 16
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (c_{a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. (1)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. c_{a}
#     core type: IndexedVar
# variable: 17
# index: 19
# 15. Complex
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. (a)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. a
#     core type: Variable
#     sub-expressions:
