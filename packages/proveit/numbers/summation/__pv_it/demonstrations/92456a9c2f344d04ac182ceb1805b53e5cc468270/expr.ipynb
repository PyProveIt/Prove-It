# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, c, i
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(i, Conditional(Add(Add(i, Neg(c)), two), InSet(i, Interval(Add(a, c), Add(b, c))))))
# Out:
# expr: (i -> {(i - c) + 2 if i in {a + c .. b + c}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{\left(i - c\right) + 2 \textrm{ if } i \in \{a + c~\ldotp \ldotp~b + c\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {(i - c) + 2 if i in {a + c .. b + c}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {(i - c) + 2 if i in {a + c .. b + c}.
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. {(i - c) + 2 if i in {a + c .. b + c}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (i - c) + 2
#    core type: Operation
#    operator: 21
#    operands: 5
# 4. i in {a + c .. b + c}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (i - c, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (i, {a + c .. b + c})
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 8. i - c
#    core type: Operation
#    operator: 21
#    operands: 11
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. {a + c .. b + c}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (i, -c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. -c
#     core type: Operation
#     operator: 18
#     operand: 25
# 16. a + c
#     core type: Operation
#     operator: 21
#     operands: 20
# 17. b + c
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (c)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. (a, c)
#     core type: ExprTuple
#     sub-expressions: 23, 25
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (b, c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 23. a
#     core type: Variable
#     sub-expressions:
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. c
#     core type: Variable
#     sub-expressions:
