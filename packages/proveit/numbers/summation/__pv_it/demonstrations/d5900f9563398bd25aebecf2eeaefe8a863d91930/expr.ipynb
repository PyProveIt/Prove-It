# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, IndexedVar, Lambda, a, l
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(a, one)
sub_expr3 = Add(l, one)
expr = ExprTuple(Lambda(sub_expr2, Conditional(Equals(Mult(sub_expr2, Sum(sub_expr1, sub_expr3, domain = Integer)), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = Integer)), InSet(sub_expr2, Complex))))
# Out:
# expr: (a_{1} -> {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \mapsto \left\{\left(a_{1} \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \left(l + 1\right)\right) \textrm{ if } a_{1} \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} -> {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. a_{1} -> {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.
#    core type: Lambda
#    parameter: 24
#    body: 2
# 2. {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. a_{1} in Complex
#    core type: Operation
#    operator: 26
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a_{1} * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (a_{1}, Complex)
#    core type: ExprTuple
#    sub-expressions: 24, 10
# ...
