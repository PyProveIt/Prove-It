# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, k
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, eight, two

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Conditional(Add(k, Neg(two)), InSet(k, Interval(a, eight))))
# Out:
# expr: k -> {k - 2 if k in {a .. 8}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{k - 2 \textrm{ if } k \in \{a~\ldotp \ldotp~8\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {k - 2 if k in {a .. 8}.
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. {k - 2 if k in {a .. 8}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. k - 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in {a .. 8}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (k, -2)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {a .. 8})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. -2
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. k
#    core type: Variable
#    sub-expressions:
# 10. {a .. 8}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. (2)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (a, 8)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. a
#     core type: Variable
#     sub-expressions:
# 17. 8
#     core type: Literal
#     sub-expressions:
