# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i
from proveit.numbers import Add, Interval, Neg, Sum, one, seven, six, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = ExprTuple(Sum(sub_expr1, Add(i, two), domain = Interval(two, six)), Sum(sub_expr1, Add(Add(i, Neg(one)), two), domain = Interval(three, seven)))
# Out:
# expr: (Sum_{i=2}^{6} (i + 2), Sum_{i=3}^{7} ((i - 1) + 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{i=2}^{6} \left(i + 2\right), \sum_{i=3}^{7} \left(\left(i - 1\right) + 2\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{i=2}^{6} (i + 2), Sum_{i=3}^{7} ((i - 1) + 2))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{i=2}^{6} (i + 2)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{i=3}^{7} ((i - 1) + 2)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (i -> {i + 2 if i in {2 .. 6}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (i -> {(i - 1) + 2 if i in {3 .. 7}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. i -> {i + 2 if i in {2 .. 6}.
#    core type: Lambda
#    parameter: 29
#    body: 8
# 7. i -> {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Lambda
#    parameter: 29
#    body: 9
# 8. {i + 2 if i in {2 .. 6}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. i + 2
#     core type: Operation
#     operator: 23
#     operands: 14
# 11. i in {2 .. 6}
# ...
