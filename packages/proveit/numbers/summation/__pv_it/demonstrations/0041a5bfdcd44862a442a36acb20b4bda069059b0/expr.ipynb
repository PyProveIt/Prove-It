# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, x
from proveit.numbers import Add, Interval, Neg, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(two)
expr = ExprTuple(Sum([x], Add(x, sub_expr1), domain = Interval(a, Add(b, Neg(one)))), Add(b, sub_expr1))
# Out:
# expr: (Sum_{x=a}^{b - 1} (x - 2), b - 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b - 1} \left(x - 2\right), b - 2\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b - 1} (x - 2), b - 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x=a}^{b - 1} (x - 2)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. b - 2
#    core type: Operation
#    operator: 22
#    operands: 5
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (x -> {x - 2 if x in {a .. b - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (b, -2)
#    core type: ExprTuple
#    sub-expressions: 24, 13
# 6. x -> {x - 2 if x in {a .. b - 1}.
#    core type: Lambda
#    parameter: 14
#    body: 7
# 7. {x - 2 if x in {a .. b - 1}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. x - 2
#    core type: Operation
#    operator: 22
#    operands: 10
# 9. x in {a .. b - 1}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, -2)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (x, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. -2
#     core type: Operation
#     operator: 26
#     operand: 19
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. {a .. b - 1}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (2)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b - 1
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. b
#     core type: Variable
#     sub-expressions:
# 25. -1
#     core type: Operation
#     operator: 26
#     operand: 28
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. (1)
#     core type: ExprTuple
#     sub-expressions: 28
# 28. 1
#     core type: Literal
#     sub-expressions:
