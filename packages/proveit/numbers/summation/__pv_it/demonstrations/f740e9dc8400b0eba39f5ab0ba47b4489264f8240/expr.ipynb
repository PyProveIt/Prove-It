# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, c, l
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
sub_expr2 = InSet(l, Integer)
expr = Equals(Lambda(l, Conditional(Mult(c, sub_expr1), sub_expr2)), Lambda(l, Conditional(Mult(sub_expr1, c), sub_expr2)))
# Out:
# expr: [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[l \mapsto \left\{c \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right..\right] = \left[l \mapsto \left\{\left(l + 1\right) \cdot c \textrm{ if } l \in \mathbb{Z}\right..\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (l -> {c * (l + 1) if l in Integer., l -> {(l + 1) * c if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. l -> {c * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 20
#    body: 5
# 4. l -> {(l + 1) * c if l in Integer.
#    core type: Lambda
#    parameter: 20
#    body: 6
# 5. {c * (l + 1) if l in Integer.
#    core type: Conditional
#    value: 7
#    condition: 9
# 6. {(l + 1) * c if l in Integer.
#    core type: Conditional
#    value: 8
#    condition: 9
# 7. c * (l + 1)
#    core type: Operation
#    operator: 11
#    operands: 10
# 8. (l + 1) * c
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. l in Integer
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (l + 1, c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 20, 17
# 15. l + 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. Integer
#     core type: Literal
#     sub-expressions:
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. l
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
