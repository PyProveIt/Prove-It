# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
sub_expr2 = InSet(l, Integer)
sub_expr3 = Mult(a, b, sub_expr1)
sub_expr4 = Mult(sub_expr1, a, b)
expr = Implies(Forall([l], Equals(sub_expr3, sub_expr4), domain = Integer), Equals(Lambda(l, Conditional(sub_expr3, sub_expr2)), Lambda(l, Conditional(sub_expr4, sub_expr2))))
# Out:
# expr: [forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b))] => ([l -> {a * b * (l + 1) if l in Integer.] = [l -> {(l + 1) * a * b if l in Integer.])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{l \in \mathbb{Z}}~\left(\left(a \cdot b \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot a \cdot b\right)\right)\right] \Rightarrow \left(\left[l \mapsto \left\{a \cdot b \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right..\right] = \left[l \mapsto \left\{\left(l + 1\right) \cdot a \cdot b \textrm{ if } l \in \mathbb{Z}\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b))] => ([l -> {a * b * (l + 1) if l in Integer.] = [l -> {(l + 1) * a * b if l in Integer.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b)), [l -> {a * b * (l + 1) if l in Integer.] = [l -> {(l + 1) * a * b if l in Integer.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [l -> {a * b * (l + 1) if l in Integer.] = [l -> {(l + 1) * a * b if l in Integer.]
#    core type: Operation
#    operator: 16
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# ...
