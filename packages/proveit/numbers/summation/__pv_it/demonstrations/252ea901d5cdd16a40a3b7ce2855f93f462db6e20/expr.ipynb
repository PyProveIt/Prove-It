# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, c, l
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Add(l, one)
sub_expr3 = IndexedVar(c, one)
expr = ExprTuple(Forall(sub_expr1, InSet(sub_expr2, Complex), domain = Integer), Forall([sub_expr3], Equals(Mult(Sum(sub_expr1, sub_expr2, domain = Integer), sub_expr3), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = Integer)), domain = Complex))
# Out:
# expr: (forall_{l in Integer} ((l + 1) in Complex), forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \in \mathbb{C}\right), \forall_{c_{1} \in \mathbb{C}}~\left(\left(\sum_{l \in \mathbb{Z}}~\left(l + 1\right) \cdot c_{1}\right) = \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c_{1}\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{l in Integer} ((l + 1) in Complex), forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1})))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{l in Integer} ((l + 1) in Complex)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (l -> {(l + 1) in Complex if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (c_{1} -> {(Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}) if c_{1} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. l -> {(l + 1) in Complex if l in Integer.
#    core type: Lambda
#    parameter: 42
#    body: 8
# ...
