# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i
from proveit.numbers import Add, Interval, Sum, five, four, six, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Add(i, two)
expr = ExprTuple(Sum(sub_expr1, sub_expr2, domain = Interval(two, six)), Add(Sum(sub_expr1, sub_expr2, domain = Interval(two, four)), Sum(sub_expr1, sub_expr2, domain = Interval(five, six))))
# Out:
# expr: (Sum_{i=2}^{6} (i + 2), (Sum_{i=2}^{4} (i + 2)) + (Sum_{i=5}^{6} (i + 2)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{i=2}^{6} \left(i + 2\right), \left(\sum_{i=2}^{4} \left(i + 2\right)\right) + \left(\sum_{i=5}^{6} \left(i + 2\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{i=2}^{6} (i + 2), (Sum_{i=2}^{4} (i + 2)) + (Sum_{i=5}^{6} (i + 2)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{i=2}^{6} (i + 2)
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. (Sum_{i=2}^{4} (i + 2)) + (Sum_{i=5}^{6} (i + 2))
#    core type: Operation
#    operator: 24
#    operands: 4
# 3. (i -> {i + 2 if i in {2 .. 6}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{i=2}^{4} (i + 2), Sum_{i=5}^{6} (i + 2))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. i -> {i + 2 if i in {2 .. 6}.
#    core type: Lambda
#    parameter: 29
#    body: 8
# 6. Sum_{i=2}^{4} (i + 2)
#    core type: Operation
#    operator: 10
#    operand: 13
# 7. Sum_{i=5}^{6} (i + 2)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. {i + 2 if i in {2 .. 6}.
#    core type: Conditional
#    value: 20
#    condition: 12
# 9. (i -> {i + 2 if i in {2 .. 4}.)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. Sum
# ...
