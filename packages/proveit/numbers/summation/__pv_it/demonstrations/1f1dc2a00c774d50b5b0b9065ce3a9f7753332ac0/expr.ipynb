# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Add, DecimalSequence, Interval, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Add(Add(i, Neg(two)), one), InSet(i, Interval(two, DecimalSequence(one, one)))))
# Out:
# expr: i -> {(i - 2) + 1 if i in {2 .. 11}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\left(i - 2\right) + 1 \textrm{ if } i \in \{2~\ldotp \ldotp~11\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> {(i - 2) + 1 if i in {2 .. 11}.
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. {(i - 2) + 1 if i in {2 .. 11}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (i - 2) + 1
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. i in {2 .. 11}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (i - 2, 1)
#    core type: ExprTuple
#    sub-expressions: 7, 21
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i, {2 .. 11})
#    core type: ExprTuple
#    sub-expressions: 13, 8
# 7. i - 2
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. {2 .. 11}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (i, -2)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (2, 11)
#     core type: ExprTuple
#     sub-expressions: 20, 15
# 13. i
#     core type: Variable
# ...
