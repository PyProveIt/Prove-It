# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, c, l
from proveit.numbers import Add, Integer, Mult, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = Add(l, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, two)
expr = ExprTuple(Mult(Sum(sub_expr2, sub_expr3, domain = Integer), sub_expr4), Sum(sub_expr2, Mult(sub_expr3, sub_expr4), domain = Integer))
# Out:
# expr: (Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}, Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l \in \mathbb{Z}}~\left(l + 1\right) \cdot c_{1} \cdot \ldots \cdot c_{2}, \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c_{1} \cdot \ldots \cdot c_{2}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}, Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2})
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (Sum_{l in Integer} (l + 1), c_{1}, ..c_{_a}.., c_{2})
#    core type: ExprTuple
#    sub-expressions: 5, 17
# 4. (l -> {(l + 1) * c_{1} * ..c_{_a}.. * c_{2} if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. l -> {(l + 1) * c_{1} * ..c_{_a}.. * c_{2} if l in Integer.
#    core type: Lambda
#    parameter: 25
#    body: 9
# 7. Sum
#    core type: Literal
#    sub-expressions:
# 8. (l -> {l + 1 if l in Integer.)
#    core type: ExprTuple
# ...
