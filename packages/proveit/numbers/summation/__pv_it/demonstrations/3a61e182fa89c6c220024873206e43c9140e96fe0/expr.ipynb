# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.numbers import Add, Exp, Interval, Sum, five, nine, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(i, two)
expr = Add(Sum(sub_expr1, sub_expr2, domain = Interval(one, five)), Sum(sub_expr1, sub_expr2, domain = Interval(Add(five, one), nine)))
# Out:
# expr: (Sum_{i=1}^{5} i^{2}) + (Sum_{i=5 + 1}^{9} i^{2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{i=1}^{5} i^{2}\right) + \left(\sum_{i=5 + 1}^{9} i^{2}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{i=1}^{5} i^{2}) + (Sum_{i=5 + 1}^{9} i^{2})
#    core type: Operation
#    operator: 28
#    operands: 1
# 1. (Sum_{i=1}^{5} i^{2}, Sum_{i=5 + 1}^{9} i^{2})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{i=1}^{5} i^{2}
#    core type: Operation
#    operator: 5
#    operand: 7
# 3. Sum_{i=5 + 1}^{9} i^{2}
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (i -> {i^{2} if i in {1 .. 5}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (i -> {i^{2} if i in {5 + 1 .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. i -> {i^{2} if i in {1 .. 5}.
#    core type: Lambda
#    parameter: 21
#    body: 9
# 8. i -> {i^{2} if i in {5 + 1 .. 9}.
#    core type: Lambda
#    parameter: 21
#    body: 10
# 9. {i^{2} if i in {1 .. 5}.
#    core type: Conditional
#    value: 12
#    condition: 11
# 10. {i^{2} if i in {5 + 1 .. 9}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. i in {1 .. 5}
#     core type: Operation
#     operator: 17
#     operands: 14
# 12. i^{2}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. i in {5 + 1 .. 9}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (i, {1 .. 5})
#     core type: ExprTuple
#     sub-expressions: 21, 19
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (i, 2)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (i, {5 + 1 .. 9})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. {1 .. 5}
#     core type: Operation
#     operator: 24
#     operands: 23
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. i
#     core type: Variable
#     sub-expressions:
# 22. {5 + 1 .. 9}
#     core type: Operation
#     operator: 24
#     operands: 25
# 23. (1, 5)
#     core type: ExprTuple
#     sub-expressions: 31, 30
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (5 + 1, 9)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 5 + 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. 9
#     core type: Literal
#     sub-expressions:
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (5, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. 5
#     core type: Literal
#     sub-expressions:
# 31. 1
#     core type: Literal
#     sub-expressions:
