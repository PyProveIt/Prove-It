# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Lambda, Variable, a, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(l, Conditional(Mult(ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, two), Add(l, one)), InSet(l, Integer)))
# Out:
# expr: l -> {a_{1} * ..a_{_a}.. * a_{2} * (l + 1) if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{a_{1} \cdot \ldots \cdot a_{2} \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {a_{1} * ..a_{_a}.. * a_{2} * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {a_{1} * ..a_{_a}.. * a_{2} * (l + 1) if l in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. a_{1} * ..a_{_a}.. * a_{2} * (l + 1)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{2}, l + 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 8. a_{1}, ..a_{_a}.., a_{2}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 17
#    end_index: 12
# 9. l + 1
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. _a -> a_{_a}
#     core type: Lambda
# ...
