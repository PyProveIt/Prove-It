# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, i
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Add(Add(i, Neg(c)), one), InSet(i, Interval(Add(a, c), Add(b, c))))
# Out:
# expr: {(i - c) + 1 if i in {a + c .. b + c}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(i - c\right) + 1 \textrm{ if } i \in \{a + c~\ldotp \ldotp~b + c\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(i - c) + 1 if i in {a + c .. b + c}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (i - c) + 1
#    core type: Operation
#    operator: 19
#    operands: 3
# 2. i in {a + c .. b + c}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i - c, 1)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (i, {a + c .. b + c})
#    core type: ExprTuple
#    sub-expressions: 12, 8
# 6. i - c
#    core type: Operation
#    operator: 19
#    operands: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. {a + c .. b + c}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (i, -c)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. i
#     core type: Variable
#     sub-expressions:
# 13. -c
#     core type: Operation
#     operator: 16
#     operand: 23
# 14. a + c
#     core type: Operation
#     operator: 19
#     operands: 18
# 15. b + c
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (c)
#     core type: ExprTuple
#     sub-expressions: 23
# 18. (a, c)
#     core type: ExprTuple
#     sub-expressions: 21, 23
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (b, c)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. b
#     core type: Variable
#     sub-expressions:
# 23. c
#     core type: Variable
#     sub-expressions:
