# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Exp, Interval, nine, seven, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(i, Conditional(Exp(i, two), InSet(i, Interval(seven, nine)))))
# Out:
# expr: (i -> {i^{2} if i in {7 .. 9}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{i^{2} \textrm{ if } i \in \{7~\ldotp \ldotp~9\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {i^{2} if i in {7 .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {i^{2} if i in {7 .. 9}.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {i^{2} if i in {7 .. 9}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. i^{2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. i in {7 .. 9}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. Exp
#    core type: Literal
#    sub-expressions:
# 6. (i, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, {7 .. 9})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. 2
#    core type: Literal
#    sub-expressions:
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. {7 .. 9}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (7, 9)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 7
#     core type: Literal
#     sub-expressions:
# 15. 9
#     core type: Literal
#     sub-expressions:
