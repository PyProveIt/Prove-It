# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, Lambda, Variable, c, l
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(c, sub_expr1)
sub_expr4 = Add(l, one)
sub_expr5 = ExprRange(sub_expr1, sub_expr3, one, two)
expr = ExprTuple(Lambda([sub_expr5], Conditional(Equals(Mult(Sum(sub_expr2, sub_expr4, domain = Integer), sub_expr5), Sum(sub_expr2, Mult(sub_expr4, sub_expr5), domain = Integer)), And(ExprRange(sub_expr1, InSet(sub_expr3, Complex), one, two)))))
# Out:
# expr: ((c_{1}, ..c_{_a}.., c_{2}) -> {(Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}) = Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}) if (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{2} in Complex).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(c_{1}, \ldots, c_{2}\right) \mapsto \left\{\left(\sum_{l \in \mathbb{Z}}~\left(l + 1\right) \cdot c_{1} \cdot \ldots \cdot c_{2}\right) = \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c_{1} \cdot \ldots \cdot c_{2}\right) \textrm{ if } \left(c_{1} \in \mathbb{C}\right) \land \ldots \land \left(c_{2} \in \mathbb{C}\right)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((c_{1}, ..c_{_a}.., c_{2}) -> {(Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}) = Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}) if (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{2} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (c_{1}, ..c_{_a}.., c_{2}) -> {(Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}) = Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}) if (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{2} in Complex).
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (c_{1}, ..c_{_a}.., c_{2})
#    core type: ExprTuple
#    sub-expressions: 31
# 3. {(Sum_{l in Integer} (l + 1) * c_{1} * ..c_{_a}.. * c_{2}) = Sum_{l in Integer} ((l + 1) * c_{1} * ..c_{_a}.. * c_{2}) if (c_{1} in Complex) and ..(c_{_a} in Complex).. and (c_{2} in Complex).
#    core type: Conditional
#    value: 4
#    condition: 5
# ...
