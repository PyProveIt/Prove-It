# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, j
from proveit.numbers import Add, Interval, Neg, Sum, three

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
expr = ExprTuple(Sum(sub_expr1, j, domain = Interval(a, b)), Sum(sub_expr1, Add(j, Neg(three)), domain = Interval(Add(a, three), Add(b, three))))
# Out:
# expr: (Sum_{j=a}^{b} j, Sum_{j=a + 3}^{b + 3} (j - 3))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{j=a}^{b} j, \sum_{j=a + 3}^{b + 3} \left(j - 3\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{j=a}^{b} j, Sum_{j=a + 3}^{b + 3} (j - 3))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{j=a}^{b} j
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{j=a + 3}^{b + 3} (j - 3)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (j -> {j if j in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (j -> {j - 3 if j in {a + 3 .. b + 3}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. j -> {j if j in {a .. b}.
#    core type: Lambda
#    parameter: 19
#    body: 8
# 7. j -> {j - 3 if j in {a + 3 .. b + 3}.
#    core type: Lambda
#    parameter: 19
#    body: 9
# 8. {j if j in {a .. b}.
#    core type: Conditional
#    value: 19
#    condition: 10
# 9. {j - 3 if j in {a + 3 .. b + 3}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. j in {a .. b}
#     core type: Operation
#     operator: 15
#     operands: 13
# 11. j - 3
# ...
