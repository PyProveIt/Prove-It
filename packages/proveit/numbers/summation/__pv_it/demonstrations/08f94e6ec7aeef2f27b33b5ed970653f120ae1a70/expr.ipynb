# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, c, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Mult(Add(l, one), ExprRange(sub_expr1, IndexedVar(c, sub_expr1), one, two)), InSet(l, Integer))
# Out:
# expr: {(l + 1) * c_{1} * ..c_{_a}.. * c_{2} if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(l + 1\right) \cdot c_{1} \cdot \ldots \cdot c_{2} \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(l + 1) * c_{1} * ..c_{_a}.. * c_{2} if l in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (l + 1) * c_{1} * ..c_{_a}.. * c_{2}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. l in Integer
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (l + 1, c_{1}, ..c_{_a}.., c_{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 7. l + 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. c_{1}, ..c_{_a}.., c_{2}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 15
#    end_index: 13
# 9. Integer
#    core type: Literal
#    sub-expressions:
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. _a -> c_{_a}
#     core type: Lambda
# ...
