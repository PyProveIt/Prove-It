# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, c
from proveit.logic import InSet
from proveit.numbers import Complex, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(a, InSet(IndexedVar(c, a), Complex), one, one))
# Out:
# expr: (c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c_{1} \in \mathbb{C}, \ldots, c_{1} \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c_{1} in Complex, ..c_{a} in Complex.., c_{1} in Complex)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (c_{1} in Complex), ..(c_{a} in Complex).., (c_{1} in Complex)
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 3
#    end_index: 3
# 2. a -> (c_{a} in Complex)
#    core type: Lambda
#    parameter: 11
#    body: 4
# 3. 1
#    core type: Literal
#    sub-expressions:
# 4. c_{a} in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (c_{a}, Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. c_{a}
#    core type: IndexedVar
# variable: 9
# index: 11
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. c
#    core type: Variable
#    sub-expressions:
# 10. (a)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. a
#     core type: Variable
#     sub-expressions:
