# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import c, l
from proveit.logic import Equals
from proveit.numbers import Add, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Add(l, one)
expr = Equals(Sum(sub_expr1, Mult(c, sub_expr2), domain = Integer), Sum(sub_expr1, Mult(sub_expr2, c), domain = Integer))
# Out:
# expr: Sum_{l in Integer} (c * (l + 1)) = Sum_{l in Integer} ((l + 1) * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{l \in \mathbb{Z}}~\left(c \cdot \left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{l in Integer} (c * (l + 1)) = Sum_{l in Integer} ((l + 1) * c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{l in Integer} (c * (l + 1)), Sum_{l in Integer} ((l + 1) * c))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{l in Integer} (c * (l + 1))
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. Sum_{l in Integer} ((l + 1) * c)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l -> {c * (l + 1) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (l -> {(l + 1) * c if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. l -> {c * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 25
#    body: 10
# 9. l -> {(l + 1) * c if l in Integer.
#    core type: Lambda
#    parameter: 25
#    body: 11
# 10. {c * (l + 1) if l in Integer.
#     core type: Conditional
#     value: 12
#     condition: 14
# 11. {(l + 1) * c if l in Integer.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. c * (l + 1)
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. (l + 1) * c
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. l in Integer
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (l + 1, c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 25, 22
# 20. l + 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. c
#     core type: Variable
#     sub-expressions:
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. 1
#     core type: Literal
#     sub-expressions:
