# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, c, l
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
sub_expr2 = InSet(l, Integer)
sub_expr3 = Mult(c, sub_expr1)
sub_expr4 = Mult(sub_expr1, c)
expr = ExprTuple(Forall([l], Equals(sub_expr3, sub_expr4), domain = Integer), Equals(Lambda(l, Conditional(sub_expr3, sub_expr2)), Lambda(l, Conditional(sub_expr4, sub_expr2))))
# Out:
# expr: (forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c)), [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{l \in \mathbb{Z}}~\left(\left(c \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot c\right)\right), \left[l \mapsto \left\{c \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right..\right] = \left[l \mapsto \left\{\left(l + 1\right) \cdot c \textrm{ if } l \in \mathbb{Z}\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c)), [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.]
#    core type: Operation
#    operator: 14
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (l -> {c * (l + 1) if l in Integer., l -> {(l + 1) * c if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#    core type: Lambda
#    parameter: 28
#    body: 9
# 7. l -> {c * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 28
#    body: 10
# 8. l -> {(l + 1) * c if l in Integer.
#    core type: Lambda
#    parameter: 28
#    body: 11
# 9. {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. {c * (l + 1) if l in Integer.
#     core type: Conditional
#     value: 18
#     condition: 13
# 11. {(l + 1) * c if l in Integer.
#     core type: Conditional
#     value: 19
#     condition: 13
# 12. (c * (l + 1)) = ((l + 1) * c)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. l in Integer
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (c * (l + 1), (l + 1) * c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 28, 20
# 18. c * (l + 1)
#     core type: Operation
#     operator: 22
#     operands: 21
# 19. (l + 1) * c
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 25, 24
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (l + 1, c)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. l + 1
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. c
#     core type: Variable
#     sub-expressions:
# 26. +
#     core type: Literal
#     sub-expressions:
# 27. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. 1
#     core type: Literal
#     sub-expressions:
