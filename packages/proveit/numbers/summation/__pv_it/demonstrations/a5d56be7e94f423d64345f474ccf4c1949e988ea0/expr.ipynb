# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, i
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Neg, Sum, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
expr = Forall([a, b, c], Equals(Sum(sub_expr1, Add(i, two), domain = Interval(a, b)), Sum(sub_expr1, Add(Add(i, Neg(c)), two), domain = Interval(Add(a, c), Add(b, c)))), domain = Integer)
# Out:
# expr: forall_{a, b, c in Integer} ((Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}}~\left(\left(\sum_{i=a}^{b} \left(i + 2\right)\right) = \left(\sum_{i=a + c}^{b + c} \left(\left(i - c\right) + 2\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer} ((Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 54, 55, 56
# 5. {(Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{i=a}^{b} (i + 2)) = (Sum_{i=a + c}^{b + c} ((i - c) + 2))
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
