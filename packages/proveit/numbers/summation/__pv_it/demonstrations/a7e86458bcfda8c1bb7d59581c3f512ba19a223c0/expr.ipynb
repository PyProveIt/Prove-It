# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, k
from proveit.numbers import Add, Interval, Neg, Sum, eight, nine, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Neg(two)
sub_expr3 = Add(k, sub_expr2)
expr = ExprTuple(Sum(sub_expr1, sub_expr3, domain = Interval(a, nine)), Add(Sum(sub_expr1, sub_expr3, domain = Interval(a, eight)), Add(nine, sub_expr2)))
# Out:
# expr: (Sum_{k=a}^{9} (k - 2), (Sum_{k=a}^{8} (k - 2)) + (9 - 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{k=a}^{9} \left(k - 2\right), \left(\sum_{k=a}^{8} \left(k - 2\right)\right) + \left(9 - 2\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{k=a}^{9} (k - 2), (Sum_{k=a}^{8} (k - 2)) + (9 - 2))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=a}^{9} (k - 2)
#    core type: Operation
#    operator: 9
#    operand: 5
# 2. (Sum_{k=a}^{8} (k - 2)) + (9 - 2)
#    core type: Operation
#    operator: 20
#    operands: 4
# 3. (k -> {k - 2 if k in {a .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{k=a}^{8} (k - 2), 9 - 2)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. k -> {k - 2 if k in {a .. 9}.
#    core type: Lambda
#    parameter: 26
#    body: 8
# 6. Sum_{k=a}^{8} (k - 2)
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. 9 - 2
#    core type: Operation
#    operator: 20
#    operands: 11
# 8. {k - 2 if k in {a .. 9}.
#    core type: Conditional
#    value: 17
#    condition: 12
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (k -> {k - 2 if k in {a .. 8}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (9, -2)
# ...
