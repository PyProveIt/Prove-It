# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Add, DecimalSequence, Interval, Neg, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(i, Conditional(Add(Add(i, Neg(two)), one), InSet(i, Interval(two, DecimalSequence(one, one))))))
# Out:
# expr: (i -> {(i - 2) + 1 if i in {2 .. 11}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{\left(i - 2\right) + 1 \textrm{ if } i \in \{2~\ldotp \ldotp~11\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {(i - 2) + 1 if i in {2 .. 11}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {(i - 2) + 1 if i in {2 .. 11}.
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. {(i - 2) + 1 if i in {2 .. 11}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (i - 2) + 1
#    core type: Operation
#    operator: 10
#    operands: 5
# 4. i in {2 .. 11}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (i - 2, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 22
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (i, {2 .. 11})
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 8. i - 2
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. {2 .. 11}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (i, -2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (2, 11)
#     core type: ExprTuple
#     sub-expressions: 21, 16
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. -2
#     core type: Operation
#     operator: 17
#     operand: 21
# 16. 11
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (2)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. Decimal
#     core type: Literal
#     sub-expressions:
# 20. (1, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 22
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. 1
#     core type: Literal
#     sub-expressions:
