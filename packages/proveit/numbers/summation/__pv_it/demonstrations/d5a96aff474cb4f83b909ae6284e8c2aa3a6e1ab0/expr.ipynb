# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, l
from proveit.logic import Equals
from proveit.numbers import Add, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Add(l, one)
expr = Equals(Mult(a, b, Sum(sub_expr1, sub_expr2, domain = Integer)), Sum(sub_expr1, Mult(a, b, sub_expr2), domain = Integer))
# Out:
# expr: (a * b * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a * b * (l + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \cdot b \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(a \cdot b \cdot \left(l + 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a * b * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a * b * (l + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (a * b * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a * b * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a * b * Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 15
#    operands: 5
# 4. Sum_{l in Integer} (a * b * (l + 1))
#    core type: Operation
#    operator: 9
#    operand: 8
# 5. (a, b, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
#    sub-expressions: 18, 19, 7
# 6. (l -> {a * b * (l + 1) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. l -> {a * b * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 26
#    body: 11
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (l -> {l + 1 if l in Integer.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {a * b * (l + 1) if l in Integer.
#     core type: Conditional
#     value: 13
#     condition: 17
# 12. l -> {l + 1 if l in Integer.
#     core type: Lambda
#     parameter: 26
#     body: 14
# 13. a * b * (l + 1)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. {l + 1 if l in Integer.
#     core type: Conditional
#     value: 20
#     condition: 17
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (a, b, l + 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 20
# 17. l in Integer
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. l + 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 26, 25
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. Integer
#     core type: Literal
#     sub-expressions:
# 26. l
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
