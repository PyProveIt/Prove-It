# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, c, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
sub_expr2 = InSet(l, Integer)
sub_expr3 = Mult(c, sub_expr1)
sub_expr4 = Mult(sub_expr1, c)
expr = Implies(Forall([l], Equals(sub_expr3, sub_expr4), domain = Integer), Equals(Lambda(l, Conditional(sub_expr3, sub_expr2)), Lambda(l, Conditional(sub_expr4, sub_expr2))))
# Out:
# expr: [forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c))] => ([l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{l \in \mathbb{Z}}~\left(\left(c \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot c\right)\right)\right] \Rightarrow \left(\left[l \mapsto \left\{c \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right..\right] = \left[l \mapsto \left\{\left(l + 1\right) \cdot c \textrm{ if } l \in \mathbb{Z}\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c))] => ([l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c)), [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in Integer} ((c * (l + 1)) = ((l + 1) * c))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [l -> {c * (l + 1) if l in Integer.] = [l -> {(l + 1) * c if l in Integer.]
#    core type: Operation
#    operator: 16
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (l -> {c * (l + 1) if l in Integer., l -> {(l + 1) * c if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#    core type: Lambda
#    parameter: 30
#    body: 11
# 9. l -> {c * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 30
#    body: 12
# 10. l -> {(l + 1) * c if l in Integer.
#     core type: Lambda
#     parameter: 30
#     body: 13
# 11. {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. {c * (l + 1) if l in Integer.
#     core type: Conditional
#     value: 20
#     condition: 15
# 13. {(l + 1) * c if l in Integer.
#     core type: Conditional
#     value: 21
#     condition: 15
# 14. (c * (l + 1)) = ((l + 1) * c)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. l in Integer
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (c * (l + 1), (l + 1) * c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 30, 22
# 20. c * (l + 1)
#     core type: Operation
#     operator: 24
#     operands: 23
# 21. (l + 1) * c
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (l + 1, c)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. l + 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. l
#     core type: Variable
#     sub-expressions:
# 31. 1
#     core type: Literal
#     sub-expressions:
