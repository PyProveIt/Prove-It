# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.logic import Equals
from proveit.numbers import Add, Interval, Sum, six, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Add(i, two)
expr = Equals(Sum(sub_expr1, sub_expr2, domain = Interval(two, six)), Add(Add(two, two), Sum(sub_expr1, sub_expr2, domain = Interval(three, six))))
# Out:
# expr: (Sum_{i=2}^{6} (i + 2)) = ((2 + 2) + (Sum_{i=3}^{6} (i + 2)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{i=2}^{6} \left(i + 2\right)\right) = \left(\left(2 + 2\right) + \left(\sum_{i=3}^{6} \left(i + 2\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{i=2}^{6} (i + 2)) = ((2 + 2) + (Sum_{i=3}^{6} (i + 2)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{i=2}^{6} (i + 2), (2 + 2) + (Sum_{i=3}^{6} (i + 2)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{i=2}^{6} (i + 2)
#    core type: Operation
#    operator: 12
#    operand: 7
# 4. (2 + 2) + (Sum_{i=3}^{6} (i + 2))
#    core type: Operation
#    operator: 22
#    operands: 6
# 5. (i -> {i + 2 if i in {2 .. 6}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (2 + 2, Sum_{i=3}^{6} (i + 2))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. i -> {i + 2 if i in {2 .. 6}.
#    core type: Lambda
#    parameter: 27
#    body: 10
# 8. 2 + 2
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. Sum_{i=3}^{6} (i + 2)
#    core type: Operation
#    operator: 12
#    operand: 15
# 10. {i + 2 if i in {2 .. 6}.
#     core type: Conditional
#     value: 19
#     condition: 14
# 11. (2, 2)
#     core type: ExprTuple
#     sub-expressions: 26, 26
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. (i -> {i + 2 if i in {3 .. 6}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. i in {2 .. 6}
#     core type: Operation
#     operator: 24
#     operands: 16
# 15. i -> {i + 2 if i in {3 .. 6}.
#     core type: Lambda
#     parameter: 27
#     body: 17
# 16. (i, {2 .. 6})
#     core type: ExprTuple
#     sub-expressions: 27, 18
# 17. {i + 2 if i in {3 .. 6}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. {2 .. 6}
#     core type: Operation
#     operator: 29
#     operands: 21
# 19. i + 2
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. i in {3 .. 6}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (2, 6)
#     core type: ExprTuple
#     sub-expressions: 26, 32
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (i, 2)
#     core type: ExprTuple
#     sub-expressions: 27, 26
# 24. in
#     core type: Literal
#     sub-expressions:
# 25. (i, {3 .. 6})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. i
#     core type: Variable
#     sub-expressions:
# 28. {3 .. 6}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (3, 6)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 3
#     core type: Literal
#     sub-expressions:
# 32. 6
#     core type: Literal
#     sub-expressions:
