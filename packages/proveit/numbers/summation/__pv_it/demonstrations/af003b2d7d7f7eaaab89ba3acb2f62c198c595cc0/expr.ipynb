# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, one, seven, three, two

# %%
# build up the expression from sub-expressions
expr = Conditional(Add(Add(i, Neg(one)), two), InSet(i, Interval(three, seven)))
# Out:
# expr: {(i - 1) + 2 if i in {3 .. 7}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(i - 1\right) + 2 \textrm{ if } i \in \{3~\ldotp \ldotp~7\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (i - 1) + 2
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. i in {3 .. 7}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (i - 1, 2)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (i, {3 .. 7})
#    core type: ExprTuple
#    sub-expressions: 13, 8
# 6. i - 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 2
#    core type: Literal
#    sub-expressions:
# 8. {3 .. 7}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (3, 7)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. i
#     core type: Variable
#     sub-expressions:
# 14. -1
#     core type: Operation
#     operator: 17
#     operand: 19
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. 7
#     core type: Literal
#     sub-expressions:
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (1)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. 1
#     core type: Literal
#     sub-expressions:
