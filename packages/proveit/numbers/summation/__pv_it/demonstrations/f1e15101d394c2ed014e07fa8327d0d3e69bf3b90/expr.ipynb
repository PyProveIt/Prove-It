# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, IndexedVar, a, l
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(a, one)
sub_expr3 = Add(l, one)
expr = Conditional(Equals(Mult(sub_expr2, Sum(sub_expr1, sub_expr3, domain = Integer)), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = Integer)), InSet(sub_expr2, Complex))
# Out:
# expr: {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \left(l + 1\right)\right) \textrm{ if } a_{1} \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1)) if a_{1} in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * (l + 1))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. a_{1} in Complex
#    core type: Operation
#    operator: 24
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a_{1} * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a_{1}, Complex)
#    core type: ExprTuple
#    sub-expressions: 22, 8
# 6. a_{1} * Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 19
#    operands: 9
# 7. Sum_{l in Integer} (a_{1} * (l + 1))
#    core type: Operation
#    operator: 13
#    operand: 12
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. (a_{1}, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
# ...
