# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.numbers import Add, Interval, Neg, Sum, one, seven, three, two

# %%
# build up the expression from sub-expressions
expr = Sum([i], Add(Add(i, Neg(one)), two), domain = Interval(three, seven))
# Out:
# expr: Sum_{i=3}^{7} ((i - 1) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{i=3}^{7} \left(\left(i - 1\right) + 2\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{i=3}^{7} ((i - 1) + 2)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (i -> {(i - 1) + 2 if i in {3 .. 7}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. i -> {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (i - 1) + 2
#    core type: Operation
#    operator: 13
#    operands: 7
# 6. i in {3 .. 7}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (i - 1, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, {3 .. 7})
#    core type: ExprTuple
#    sub-expressions: 17, 12
# 10. i - 1
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. {3 .. 7}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (3, 7)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. -1
#     core type: Operation
#     operator: 21
#     operand: 23
# 19. 3
#     core type: Literal
#     sub-expressions:
# 20. 7
#     core type: Literal
#     sub-expressions:
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (1)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 1
#     core type: Literal
#     sub-expressions:
