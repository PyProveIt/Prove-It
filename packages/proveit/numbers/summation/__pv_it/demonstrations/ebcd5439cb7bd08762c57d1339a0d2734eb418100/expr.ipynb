# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, i
from proveit.numbers import Add, Interval, Neg, Sum, two

# %%
# build up the expression from sub-expressions
expr = Sum([i], Add(Add(i, Neg(c)), two), domain = Interval(Add(a, c), Add(b, c)))
# Out:
# expr: Sum_{i=a + c}^{b + c} ((i - c) + 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{i=a + c}^{b + c} \left(\left(i - c\right) + 2\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{i=a + c}^{b + c} ((i - c) + 2)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (i -> {(i - c) + 2 if i in {a + c .. b + c}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. i -> {(i - c) + 2 if i in {a + c .. b + c}.
#    core type: Lambda
#    parameter: 16
#    body: 4
# 4. {(i - c) + 2 if i in {a + c .. b + c}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (i - c) + 2
#    core type: Operation
#    operator: 23
#    operands: 7
# 6. i in {a + c .. b + c}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (i - c, 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (i, {a + c .. b + c})
#    core type: ExprTuple
#    sub-expressions: 16, 12
# 10. i - c
#     core type: Operation
#     operator: 23
#     operands: 13
# 11. 2
#     core type: Literal
#     sub-expressions:
# 12. {a + c .. b + c}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (i, -c)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. i
#     core type: Variable
#     sub-expressions:
# 17. -c
#     core type: Operation
#     operator: 20
#     operand: 27
# 18. a + c
#     core type: Operation
#     operator: 23
#     operands: 22
# 19. b + c
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (c)
#     core type: ExprTuple
#     sub-expressions: 27
# 22. (a, c)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (b, c)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
# 27. c
#     core type: Variable
#     sub-expressions:
