# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Less, Neg, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = Neg(two)
sub_expr3 = Add(x, sub_expr2)
expr = ExprTuple(Lambda([a, b], Conditional(Equals(Sum(sub_expr1, sub_expr3, domain = Interval(a, b)), Add(Sum(sub_expr1, sub_expr3, domain = Interval(a, Add(b, Neg(one)))), Add(b, sub_expr2))), And(InSet(a, Integer), InSet(b, Integer), Less(a, b)))))
# Out:
# expr: ((a, b) -> {(Sum_{x=a}^{b} (x - 2)) = ((Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)) if a in Integer ,  b in Integer ,  a < b.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\left(\sum_{x=a}^{b} \left(x - 2\right)\right) = \left(\left(\sum_{x=a}^{b - 1} \left(x - 2\right)\right) + \left(b - 2\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a < b\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {(Sum_{x=a}^{b} (x - 2)) = ((Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {(Sum_{x=a}^{b} (x - 2)) = ((Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Lambda
#    parameters: 34\n   body: 2
# 2. {(Sum_{x=a}^{b} (x - 2)) = ((Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{x=a}^{b} (x - 2)) = ((Sum_{x=a}^{b - 1} (x - 2)) + (b - 2))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Integer) and (b in Integer) and (a < b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{x=a}^{b} (x - 2), (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
# ...
