# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, x
from proveit.numbers import Add, Interval, Neg, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(two)
expr = Add(Sum([x], Add(x, sub_expr1), domain = Interval(a, Add(b, Neg(one)))), Add(b, sub_expr1))
# Out:
# expr: (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b - 1} \left(x - 2\right)\right) + \left(b - 2\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)
#    core type: Operation
#    operator: 23
#    operands: 1
# 1. (Sum_{x=a}^{b - 1} (x - 2), b - 2)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{x=a}^{b - 1} (x - 2)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. b - 2
#    core type: Operation
#    operator: 23
#    operands: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (x -> {x - 2 if x in {a .. b - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (b, -2)
#    core type: ExprTuple
#    sub-expressions: 25, 14
# 7. x -> {x - 2 if x in {a .. b - 1}.
#    core type: Lambda
#    parameter: 15
#    body: 8
# 8. {x - 2 if x in {a .. b - 1}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. x - 2
#    core type: Operation
#    operator: 23
#    operands: 11
# 10. x in {a .. b - 1}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (x, -2)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (x, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. -2
#     core type: Operation
#     operator: 27
#     operand: 20
# 15. x
#     core type: Variable
#     sub-expressions:
# 16. {a .. b - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (2)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. 2
#     core type: Literal
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. b - 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. b
#     core type: Variable
#     sub-expressions:
# 26. -1
#     core type: Operation
#     operator: 27
#     operand: 29
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. (1)
#     core type: ExprTuple
#     sub-expressions: 29
# 29. 1
#     core type: Literal
#     sub-expressions:
