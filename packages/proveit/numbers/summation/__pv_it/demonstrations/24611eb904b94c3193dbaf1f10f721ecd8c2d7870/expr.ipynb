# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, x
from proveit.numbers import Add, Interval, Neg, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
sub_expr2 = Neg(two)
sub_expr3 = Add(x, sub_expr2)
expr = ExprTuple(Sum(sub_expr1, sub_expr3, domain = Interval(a, b)), Add(Sum(sub_expr1, sub_expr3, domain = Interval(a, Add(b, Neg(one)))), Add(b, sub_expr2)))
# Out:
# expr: (Sum_{x=a}^{b} (x - 2), (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b} \left(x - 2\right), \left(\sum_{x=a}^{b - 1} \left(x - 2\right)\right) + \left(b - 2\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b} (x - 2), (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x=a}^{b} (x - 2)
#    core type: Operation
#    operator: 9
#    operand: 5
# 2. (Sum_{x=a}^{b - 1} (x - 2)) + (b - 2)
#    core type: Operation
#    operator: 32
#    operands: 4
# 3. (x -> {x - 2 if x in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{x=a}^{b - 1} (x - 2), b - 2)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. x -> {x - 2 if x in {a .. b}.
#    core type: Lambda
#    parameter: 24
#    body: 8
# 6. Sum_{x=a}^{b - 1} (x - 2)
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. b - 2
#    core type: Operation
#    operator: 32
#    operands: 11
# 8. {x - 2 if x in {a .. b}.
#    core type: Conditional
#    value: 17
#    condition: 12
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (x -> {x - 2 if x in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# ...
