# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, k
from proveit.numbers import Add, Interval, Neg, Sum, eight, nine, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Add(k, Neg(two))
expr = ExprTuple(Sum(sub_expr1, sub_expr2, domain = Interval(a, nine)), Add(Sum(sub_expr1, sub_expr2, domain = Interval(a, eight)), Sum(sub_expr1, sub_expr2, domain = Interval(nine, nine))))
# Out:
# expr: (Sum_{k=a}^{9} (k - 2), (Sum_{k=a}^{8} (k - 2)) + (Sum_{k=9}^{9} (k - 2)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{k=a}^{9} \left(k - 2\right), \left(\sum_{k=a}^{8} \left(k - 2\right)\right) + \left(\sum_{k=9}^{9} \left(k - 2\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{k=a}^{9} (k - 2), (Sum_{k=a}^{8} (k - 2)) + (Sum_{k=9}^{9} (k - 2)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=a}^{9} (k - 2)
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. (Sum_{k=a}^{8} (k - 2)) + (Sum_{k=9}^{9} (k - 2))
#    core type: Operation
#    operator: 24
#    operands: 4
# 3. (k -> {k - 2 if k in {a .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{k=a}^{8} (k - 2), Sum_{k=9}^{9} (k - 2))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. k -> {k - 2 if k in {a .. 9}.
#    core type: Lambda
#    parameter: 30
#    body: 8
# 6. Sum_{k=a}^{8} (k - 2)
#    core type: Operation
#    operator: 10
#    operand: 13
# 7. Sum_{k=9}^{9} (k - 2)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. {k - 2 if k in {a .. 9}.
#    core type: Conditional
#    value: 20
#    condition: 12
# 9. (k -> {k - 2 if k in {a .. 8}.)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. Sum
# ...
