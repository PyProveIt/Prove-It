# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i
from proveit.logic import Forall, InSet
from proveit.numbers import Add, Complex, Interval, Sum, six, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Add(i, two)
sub_expr3 = Interval(two, six)
expr = ExprTuple(Forall(sub_expr1, InSet(sub_expr2, Complex), domain = sub_expr3), InSet(Sum(sub_expr1, sub_expr2, domain = sub_expr3), Complex))
# Out:
# expr: (forall_{i in {2 .. 6}} ((i + 2) in Complex), (Sum_{i=2}^{6} (i + 2)) in Complex)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{i \in \{2~\ldotp \ldotp~6\}}~\left(\left(i + 2\right) \in \mathbb{C}\right), \left(\sum_{i=2}^{6} \left(i + 2\right)\right) \in \mathbb{C}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{i in {2 .. 6}} ((i + 2) in Complex), (Sum_{i=2}^{6} (i + 2)) in Complex)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{i in {2 .. 6}} ((i + 2) in Complex)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{i=2}^{6} (i + 2)) in Complex
#    core type: Operation
#    operator: 20
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (i -> {(i + 2) in Complex if i in {2 .. 6}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{i=2}^{6} (i + 2), Complex)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 6. i -> {(i + 2) in Complex if i in {2 .. 6}.
#    core type: Lambda
#    parameter: 22
#    body: 8
# 7. Sum_{i=2}^{6} (i + 2)
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. {(i + 2) in Complex if i in {2 .. 6}.
#    core type: Conditional
#    value: 11
#    condition: 17
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (i -> {i + 2 if i in {2 .. 6}.)
# ...
