# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, one, seven, three, two

# %%
# build up the expression from sub-expressions
expr = Lambda(i, Conditional(Add(Add(i, Neg(one)), two), InSet(i, Interval(three, seven))))
# Out:
# expr: i -> {(i - 1) + 2 if i in {3 .. 7}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# i \mapsto \left\{\left(i - 1\right) + 2 \textrm{ if } i \in \{3~\ldotp \ldotp~7\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. i -> {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Lambda
#    parameter: 14
#    body: 1
# 1. {(i - 1) + 2 if i in {3 .. 7}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (i - 1) + 2
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. i in {3 .. 7}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (i - 1, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (i, {3 .. 7})
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 7. i - 1
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. {3 .. 7}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (3, 7)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. -1
#     core type: Operation
#     operator: 18
#     operand: 20
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. 7
#     core type: Literal
#     sub-expressions:
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (1)
#     core type: ExprTuple
#     sub-expressions: 20
# 20. 1
#     core type: Literal
#     sub-expressions:
