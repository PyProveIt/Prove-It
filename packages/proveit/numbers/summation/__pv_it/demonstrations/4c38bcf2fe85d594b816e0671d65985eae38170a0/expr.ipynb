# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, x
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(Add(x, Neg(two)), InSet(x, Interval(a, b)))))
# Out:
# expr: (x -> {x - 2 if x in {a .. b}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{x - 2 \textrm{ if } x \in \{a~\ldotp \ldotp~b\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {x - 2 if x in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {x - 2 if x in {a .. b}.
#    core type: Lambda
#    parameter: 10
#    body: 2
# 2. {x - 2 if x in {a .. b}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. x - 2
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in {a .. b}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (x, -2)
#    core type: ExprTuple
#    sub-expressions: 10, 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, {a .. b})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. -2
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. {a .. b}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (2)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (a, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
