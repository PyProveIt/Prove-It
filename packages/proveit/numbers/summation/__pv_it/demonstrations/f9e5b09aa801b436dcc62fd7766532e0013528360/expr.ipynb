# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, c, l
from proveit.numbers import Add, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Add(l, one)
expr = ExprTuple(Mult(c, Sum(sub_expr1, sub_expr2, domain = Integer)), Sum(sub_expr1, Mult(c, sub_expr2), domain = Integer))
# Out:
# expr: (c * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (c * (l + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right), \sum_{l \in \mathbb{Z}}~\left(c \cdot \left(l + 1\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (c * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. c * Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. Sum_{l in Integer} (c * (l + 1))
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (c, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
#    sub-expressions: 16, 5
# 4. (l -> {c * (l + 1) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. l -> {c * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 23
#    body: 9
# 7. Sum
#    core type: Literal
#    sub-expressions:
# 8. (l -> {l + 1 if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. {c * (l + 1) if l in Integer.
#    core type: Conditional
#    value: 11
#    condition: 15
# 10. l -> {l + 1 if l in Integer.
#     core type: Lambda
#     parameter: 23
#     body: 12
# 11. c * (l + 1)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. {l + 1 if l in Integer.
#     core type: Conditional
#     value: 17
#     condition: 15
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. l in Integer
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. c
#     core type: Variable
#     sub-expressions:
# 17. l + 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. l
#     core type: Variable
#     sub-expressions:
# 24. 1
#     core type: Literal
#     sub-expressions:
