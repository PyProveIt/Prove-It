# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Mult(Add(l, one), a, b), InSet(l, Integer))
# Out:
# expr: {(l + 1) * a * b if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(l + 1\right) \cdot a \cdot b \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(l + 1) * a * b if l in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (l + 1) * a * b
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. l in Integer
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (l + 1, a, b)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 13, 10
# 7. l + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. b
#    core type: Variable
#    sub-expressions:
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. l
#     core type: Variable
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
