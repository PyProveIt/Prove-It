# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, c, l
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
expr = Lambda(l, Conditional(Equals(Mult(c, sub_expr1), Mult(sub_expr1, c)), InSet(l, Integer)))
# Out:
# expr: l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(c \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot c\right) \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {(c * (l + 1)) = ((l + 1) * c) if l in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (c * (l + 1)) = ((l + 1) * c)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (c * (l + 1), (l + 1) * c)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 18, 10
# 8. c * (l + 1)
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. (l + 1) * c
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. (c, l + 1)
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (l + 1, c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. l + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. l
#     core type: Variable
#     sub-expressions:
# 19. 1
#     core type: Literal
#     sub-expressions:
