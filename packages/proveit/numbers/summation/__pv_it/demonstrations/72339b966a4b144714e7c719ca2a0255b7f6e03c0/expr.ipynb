# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Integer, Interval, five, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(i, Conditional(InSet(i, Integer), InSet(i, Interval(one, five)))))
# Out:
# expr: (i -> {i in Integer if i in {1 .. 5}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{i \in \mathbb{Z} \textrm{ if } i \in \{1~\ldotp \ldotp~5\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {i in Integer if i in {1 .. 5}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {i in Integer if i in {1 .. 5}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {i in Integer if i in {1 .. 5}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. i in Integer
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. i in {1 .. 5}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (i, Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (i, {1 .. 5})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. i
#    core type: Variable
#    sub-expressions:
# 10. {1 .. 5}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (1, 5)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 5
#     core type: Literal
#     sub-expressions:
