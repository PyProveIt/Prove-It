# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i
from proveit.logic import InSet
from proveit.numbers import Exp, Natural, frac, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(i, Conditional(frac(one, Exp(i, two)), InSet(i, Natural))))
# Out:
# expr: (i -> {1 / i^{2} if i in Natural.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(i \mapsto \left\{\frac{1}{i^{2}} \textrm{ if } i \in \mathbb{N}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (i -> {1 / i^{2} if i in Natural.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. i -> {1 / i^{2} if i in Natural.
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. {1 / i^{2} if i in Natural.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. 1 / i^{2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. i in Natural
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (1, i^{2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (i, Natural)
#    core type: ExprTuple
#    sub-expressions: 14, 11
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. i^{2}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. Natural
#     core type: Literal
#     sub-expressions:
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (i, 2)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. i
#     core type: Variable
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
