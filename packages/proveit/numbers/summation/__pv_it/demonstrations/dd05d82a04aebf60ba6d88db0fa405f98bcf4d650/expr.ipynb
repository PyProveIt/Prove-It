# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, a, l
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = IndexedVar(a, sub_expr1)
sub_expr4 = Add(l, one)
sub_expr5 = ExprRange(sub_expr1, sub_expr3, one, two)
expr = Conditional(Equals(Mult(sub_expr5, Sum(sub_expr2, sub_expr4, domain = Integer)), Sum(sub_expr2, Mult(sub_expr5, sub_expr4), domain = Integer)), And(ExprRange(sub_expr1, InSet(sub_expr3, Complex), one, two)))
# Out:
# expr: {(a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{2} in Complex).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \ldots \cdot a_{2} \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \ldots \cdot a_{2} \cdot \left(l + 1\right)\right) \textrm{ if } \left(a_{1} \in \mathbb{C}\right) \land \ldots \land \left(a_{2} \in \mathbb{C}\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{2} in Complex).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{2} in Complex)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a_{1} in Complex, ..a_{_a} in Complex.., a_{2} in Complex)
#    core type: ExprTuple
#    sub-expressions: 9
# ...
