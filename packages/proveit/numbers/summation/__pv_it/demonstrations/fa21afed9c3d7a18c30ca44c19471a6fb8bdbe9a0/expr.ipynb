# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Equals([ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, zero)], [])
# Out:
# expr: (a_{1} in Complex, ..a_{_a} in Complex.., a_{0} in Complex) = ()

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \in \mathbb{C}, \ldots, a_{0} \in \mathbb{C}\right) = ()

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} in Complex, ..a_{_a} in Complex.., a_{0} in Complex) = ()
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1} in Complex, ..a_{_a} in Complex.., a_{0} in Complex), ())
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (a_{1} in Complex, ..a_{_a} in Complex.., a_{0} in Complex)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. ()
#    core type: ExprTuple
#    sub-expressions:
# 5. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{0} in Complex)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 6. _a -> (a_{_a} in Complex)
#    core type: Lambda
#    parameter: 16
#    body: 9
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. a_{_a} in Complex
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. a_{_a}
#     core type: IndexedVar
# variable: 14
# index: 16
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. (_a)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. _a
#     core type: Variable
#     sub-expressions:
