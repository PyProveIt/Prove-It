# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(Mult(Add(l, one), a, b), InSet(l, Integer))))
# Out:
# expr: (l -> {(l + 1) * a * b if l in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\left(l + 1\right) \cdot a \cdot b \textrm{ if } l \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {(l + 1) * a * b if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {(l + 1) * a * b if l in Integer.
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. {(l + 1) * a * b if l in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (l + 1) * a * b
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in Integer
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. *
#    core type: Literal
#    sub-expressions:
# 6. (l + 1, a, b)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 15, 12
# 9. l + 1
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. Integer
#     core type: Literal
#     sub-expressions:
# 13. +
#     core type: Literal
#     sub-expressions:
# 14. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. l
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
