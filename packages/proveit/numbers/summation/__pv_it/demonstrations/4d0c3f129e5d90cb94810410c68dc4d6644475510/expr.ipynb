# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, c, l
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Add(l, one)
sub_expr3 = IndexedVar(c, one)
expr = Implies(Forall(sub_expr1, InSet(sub_expr2, Complex), domain = Integer), Forall([sub_expr3], Equals(Mult(Sum(sub_expr1, sub_expr2, domain = Integer), sub_expr3), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = Integer)), domain = Complex))
# Out:
# expr: [forall_{l in Integer} ((l + 1) in Complex)] => [forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \in \mathbb{C}\right)\right] \Rightarrow \left[\forall_{c_{1} \in \mathbb{C}}~\left(\left(\sum_{l \in \mathbb{Z}}~\left(l + 1\right) \cdot c_{1}\right) = \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c_{1}\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{l in Integer} ((l + 1) in Complex)] => [forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{l in Integer} ((l + 1) in Complex), forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{l in Integer} ((l + 1) in Complex)
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (l -> {(l + 1) in Complex if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# ...
