# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, c, l
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(c, one)
sub_expr3 = Add(l, one)
expr = Forall([sub_expr2], Equals(Mult(Sum(sub_expr1, sub_expr3, domain = Integer), sub_expr2), Sum(sub_expr1, Mult(sub_expr3, sub_expr2), domain = Integer)), domain = Complex)
# Out:
# expr: forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{c_{1} \in \mathbb{C}}~\left(\left(\sum_{l \in \mathbb{Z}}~\left(l + 1\right) \cdot c_{1}\right) = \sum_{l \in \mathbb{Z}}~\left(\left(l + 1\right) \cdot c_{1}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{c_{1} in Complex} ((Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (c_{1} -> {(Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}) if c_{1} in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. c_{1} -> {(Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}) if c_{1} in Complex.
#    core type: Lambda
#    parameter: 27
#    body: 4
# 4. {(Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1}) if c_{1} in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{l in Integer} (l + 1) * c_{1}) = Sum_{l in Integer} ((l + 1) * c_{1})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. c_{1} in Complex
#    core type: Operation
#    operator: 28
#    operands: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# ...
