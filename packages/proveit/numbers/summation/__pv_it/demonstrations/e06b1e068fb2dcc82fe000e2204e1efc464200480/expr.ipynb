# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, IndexedVar, Lambda, c, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(Mult(Add(l, one), IndexedVar(c, one)), InSet(l, Integer)))
# Out:
# expr: l -> {(l + 1) * c_{1} if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(l + 1\right) \cdot c_{1} \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {(l + 1) * c_{1} if l in Integer.
#    core type: Lambda
#    parameter: 15
#    body: 1
# 1. {(l + 1) * c_{1} if l in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (l + 1) * c_{1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (l + 1, c_{1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 15, 10
# 8. l + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. c_{1}
#    core type: IndexedVar
# variable: 13
# index: 16
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. (1)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. l
#     core type: Variable
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
