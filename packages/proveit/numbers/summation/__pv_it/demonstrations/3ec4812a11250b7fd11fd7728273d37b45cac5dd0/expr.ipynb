# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, c, j
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(j, Conditional(Add(j, Neg(c)), InSet(j, Interval(Add(a, c), Add(b, c)))))
# Out:
# expr: j -> {j - c if j in {a + c .. b + c}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# j \mapsto \left\{j - c \textrm{ if } j \in \{a + c~\ldotp \ldotp~b + c\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. j -> {j - c if j in {a + c .. b + c}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {j - c if j in {a + c .. b + c}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. j - c
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. j in {a + c .. b + c}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (j, -c)
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j, {a + c .. b + c})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. -c
#    core type: Operation
#    operator: 10
#    operand: 21
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. {a + c .. b + c}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (c)
#     core type: ExprTuple
#     sub-expressions: 21
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. a + c
#     core type: Operation
#     operator: 17
#     operands: 16
# 15. b + c
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (a, c)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (b, c)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. c
#     core type: Variable
#     sub-expressions:
