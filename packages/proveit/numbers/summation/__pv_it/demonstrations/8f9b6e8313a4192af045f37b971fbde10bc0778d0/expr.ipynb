# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Variable, a, l
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Complex, Integer, Mult, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [l]
sub_expr3 = Add(l, one)
sub_expr4 = ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, two)
expr = Forall([sub_expr4], Equals(Mult(sub_expr4, Sum(sub_expr2, sub_expr3, domain = Integer)), Sum(sub_expr2, Mult(sub_expr4, sub_expr3), domain = Integer)), domain = Complex)
# Out:
# expr: forall_{a_{1}, ..a_{_a}.., a_{2} in Complex} ((a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a_{1}, \ldots, a_{2} \in \mathbb{C}}~\left(\left(a_{1} \cdot \ldots \cdot a_{2} \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right) = \sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \ldots \cdot a_{2} \cdot \left(l + 1\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a_{1}, ..a_{_a}.., a_{2} in Complex} ((a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a_{1}, ..a_{_a}.., a_{2}) -> {(a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{2} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a_{1}, ..a_{_a}.., a_{2}) -> {(a_{1} * ..a_{_a}.. * a_{2} * Sum_{l in Integer} (l + 1)) = Sum_{l in Integer} (a_{1} * ..a_{_a}.. * a_{2} * (l + 1)) if (a_{1} in Complex) and ..(a_{_a} in Complex).. and (a_{2} in Complex).
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a_{1}, ..a_{_a}.., a_{2})
#    core type: ExprTuple
#    sub-expressions: 32
# ...
