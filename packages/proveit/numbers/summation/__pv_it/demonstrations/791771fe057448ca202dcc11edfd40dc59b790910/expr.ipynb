# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, a, l
from proveit.numbers import Add, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(a, one)
sub_expr3 = Add(l, one)
expr = ExprTuple(Mult(sub_expr2, Sum(sub_expr1, sub_expr3, domain = Integer)), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = Integer))
# Out:
# expr: (a_{1} * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a_{1} * (l + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right), \sum_{l \in \mathbb{Z}}~\left(a_{1} \cdot \left(l + 1\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} * Sum_{l in Integer} (l + 1), Sum_{l in Integer} (a_{1} * (l + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1} * Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. Sum_{l in Integer} (a_{1} * (l + 1))
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (a_{1}, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
#    sub-expressions: 16, 5
# 4. (l -> {a_{1} * (l + 1) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. l -> {a_{1} * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 25
#    body: 9
# 7. Sum
#    core type: Literal
#    sub-expressions:
# 8. (l -> {l + 1 if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. {a_{1} * (l + 1) if l in Integer.
#    core type: Conditional
#    value: 11
#    condition: 15
# 10. l -> {l + 1 if l in Integer.
# ...
