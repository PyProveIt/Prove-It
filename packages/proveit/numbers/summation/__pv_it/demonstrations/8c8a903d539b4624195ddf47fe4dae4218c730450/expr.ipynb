# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i
from proveit.numbers import Add, Exp, Interval, Sum, five, nine, one, six, two

# %%
# build up the expression from sub-expressions
sub_expr1 = [i]
sub_expr2 = Exp(i, two)
expr = Add(Sum(sub_expr1, sub_expr2, domain = Interval(one, five)), Sum(sub_expr1, sub_expr2, domain = Interval(six, nine)))
# Out:
# expr: (Sum_{i=1}^{5} i^{2}) + (Sum_{i=6}^{9} i^{2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{i=1}^{5} i^{2}\right) + \left(\sum_{i=6}^{9} i^{2}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{i=1}^{5} i^{2}) + (Sum_{i=6}^{9} i^{2})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{i=1}^{5} i^{2}, Sum_{i=6}^{9} i^{2})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{i=1}^{5} i^{2}
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. Sum_{i=6}^{9} i^{2}
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (i -> {i^{2} if i in {1 .. 5}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (i -> {i^{2} if i in {6 .. 9}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. i -> {i^{2} if i in {1 .. 5}.
#    core type: Lambda
#    parameter: 22
#    body: 10
# 9. i -> {i^{2} if i in {6 .. 9}.
#    core type: Lambda
#    parameter: 22
#    body: 11
# 10. {i^{2} if i in {1 .. 5}.
#     core type: Conditional
#     value: 13
#     condition: 12
# 11. {i^{2} if i in {6 .. 9}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. i in {1 .. 5}
#     core type: Operation
#     operator: 18
#     operands: 15
# 13. i^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. i in {6 .. 9}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. (i, {1 .. 5})
#     core type: ExprTuple
#     sub-expressions: 22, 20
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (i, 2)
#     core type: ExprTuple
#     sub-expressions: 22, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (i, {6 .. 9})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. {1 .. 5}
#     core type: Operation
#     operator: 25
#     operands: 24
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. i
#     core type: Variable
#     sub-expressions:
# 23. {6 .. 9}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (1, 5)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (6, 9)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. 5
#     core type: Literal
#     sub-expressions:
# 29. 6
#     core type: Literal
#     sub-expressions:
# 30. 9
#     core type: Literal
#     sub-expressions:
