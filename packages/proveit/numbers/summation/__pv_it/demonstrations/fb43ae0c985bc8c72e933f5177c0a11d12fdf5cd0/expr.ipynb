# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import c, l
from proveit.numbers import Add, Integer, Mult, Sum, one

# %%
# build up the expression from sub-expressions
expr = Mult(c, Sum([l], Add(l, one), domain = Integer))
# Out:
# expr: c * Sum_{l in Integer} (l + 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# c \cdot \sum_{l \in \mathbb{Z}}~\left(l + 1\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. c * Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (c, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. c
#    core type: Variable
#    sub-expressions:
# 4. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (l -> {l + 1 if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. l -> {l + 1 if l in Integer.
#    core type: Lambda
#    parameter: 16
#    body: 8
# 8. {l + 1 if l in Integer.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. l + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. l in Integer
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. Integer
#     core type: Literal
#     sub-expressions:
