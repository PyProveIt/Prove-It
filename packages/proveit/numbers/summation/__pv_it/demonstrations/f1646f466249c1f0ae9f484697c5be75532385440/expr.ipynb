# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, l
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
expr = Lambda(l, Conditional(Equals(Mult(a, b, sub_expr1), Mult(sub_expr1, a, b)), InSet(l, Integer)))
# Out:
# expr: l -> {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(a \cdot b \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot a \cdot b\right) \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.
#    core type: Lambda
#    parameter: 19
#    body: 1
# 1. {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a * b * (l + 1)) = ((l + 1) * a * b)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. l in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a * b * (l + 1), (l + 1) * a * b)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 8. a * b * (l + 1)
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. (l + 1) * a * b
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. (a, b, l + 1)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 14
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (l + 1, a, b)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. l + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. l
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
