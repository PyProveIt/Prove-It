# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, l
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
expr = Forall([l], Equals(Mult(a, b, sub_expr1), Mult(sub_expr1, a, b)), domain = Integer)
# Out:
# expr: forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \mathbb{Z}}~\left(\left(a \cdot b \cdot \left(l + 1\right)\right) = \left(\left(l + 1\right) \cdot a \cdot b\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in Integer} ((a * b * (l + 1)) = ((l + 1) * a * b))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.
#    core type: Lambda
#    parameter: 22
#    body: 4
# 4. {(a * b * (l + 1)) = ((l + 1) * a * b) if l in Integer.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (a * b * (l + 1)) = ((l + 1) * a * b)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. l in Integer
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (a * b * (l + 1), (l + 1) * a * b)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 22, 13
# 11. a * b * (l + 1)
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. (l + 1) * a * b
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. Integer
#     core type: Literal
#     sub-expressions:
# 14. (a, b, l + 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19, 17
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (l + 1, a, b)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 17. l + 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. b
#     core type: Variable
#     sub-expressions:
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. l
#     core type: Variable
#     sub-expressions:
# 23. 1
#     core type: Literal
#     sub-expressions:
