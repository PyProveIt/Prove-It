# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, j
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(j, Conditional(Add(j, Neg(three)), InSet(j, Interval(Add(a, three), Add(b, three))))))
# Out:
# expr: (j -> {j - 3 if j in {a + 3 .. b + 3}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(j \mapsto \left\{j - 3 \textrm{ if } j \in \{a + 3~\ldotp \ldotp~b + 3\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (j -> {j - 3 if j in {a + 3 .. b + 3}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. j -> {j - 3 if j in {a + 3 .. b + 3}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {j - 3 if j in {a + 3 .. b + 3}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. j - 3
#    core type: Operation
#    operator: 18
#    operands: 5
# 4. j in {a + 3 .. b + 3}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (j, -3)
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (j, {a + 3 .. b + 3})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. -3
#    core type: Operation
#    operator: 11
#    operand: 22
# 9. j
#    core type: Variable
#    sub-expressions:
# 10. {a + 3 .. b + 3}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. (3)
#     core type: ExprTuple
#     sub-expressions: 22
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (a + 3, b + 3)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. a + 3
#     core type: Operation
#     operator: 18
#     operands: 17
# 16. b + 3
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (a, 3)
#     core type: ExprTuple
#     sub-expressions: 20, 22
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (b, 3)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. b
#     core type: Variable
#     sub-expressions:
# 22. 3
#     core type: Literal
#     sub-expressions:
