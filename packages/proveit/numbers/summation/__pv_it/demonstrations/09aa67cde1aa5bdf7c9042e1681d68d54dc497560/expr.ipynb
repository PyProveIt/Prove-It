# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a, l
from proveit.numbers import Add, Integer, Sum, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(ExprRange(sub_expr1, IndexedVar(a, sub_expr1), one, two), Sum([l], Add(l, one), domain = Integer))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{2}, Sum_{l in Integer} (l + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{2}, \sum_{l \in \mathbb{Z}}~\left(l + 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{2}, Sum_{l in Integer} (l + 1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1}, ..a_{_a}.., a_{2}
#    core type: ExprRange
#    lambda_map: 3
#    start_index: 19
#    end_index: 4
# 2. Sum_{l in Integer} (l + 1)
#    core type: Operation
#    operator: 5
#    operand: 8
# 3. _a -> a_{_a}
#    core type: Lambda
#    parameter: 12
#    body: 7
# 4. 2
#    core type: Literal
#    sub-expressions:
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (l -> {l + 1 if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. a_{_a}
#    core type: IndexedVar
# variable: 9
# index: 12
# 8. l -> {l + 1 if l in Integer.
#    core type: Lambda
#    parameter: 20
#    body: 11
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. (_a)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. {l + 1 if l in Integer.
#     core type: Conditional
#     value: 13
#     condition: 14
# 12. _a
#     core type: Variable
# ...
