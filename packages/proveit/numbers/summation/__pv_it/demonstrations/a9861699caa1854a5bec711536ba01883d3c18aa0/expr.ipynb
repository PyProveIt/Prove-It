# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(l, one)
sub_expr2 = InSet(l, Integer)
expr = ExprTuple(Lambda(l, Conditional(Mult(a, b, sub_expr1), sub_expr2)), Lambda(l, Conditional(Mult(sub_expr1, a, b), sub_expr2)))
# Out:
# expr: (l -> {a * b * (l + 1) if l in Integer., l -> {(l + 1) * a * b if l in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{a \cdot b \cdot \left(l + 1\right) \textrm{ if } l \in \mathbb{Z}\right.., l \mapsto \left\{\left(l + 1\right) \cdot a \cdot b \textrm{ if } l \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {a * b * (l + 1) if l in Integer., l -> {(l + 1) * a * b if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. l -> {a * b * (l + 1) if l in Integer.
#    core type: Lambda
#    parameter: 19
#    body: 3
# 2. l -> {(l + 1) * a * b if l in Integer.
#    core type: Lambda
#    parameter: 19
#    body: 4
# 3. {a * b * (l + 1) if l in Integer.
#    core type: Conditional
#    value: 5
#    condition: 7
# 4. {(l + 1) * a * b if l in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 5. a * b * (l + 1)
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. (l + 1) * a * b
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. l in Integer
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (a, b, l + 1)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 13
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (l + 1, a, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (l, Integer)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 13. l + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. a
#     core type: Variable
#     sub-expressions:
# 15. b
#     core type: Variable
#     sub-expressions:
# 16. Integer
#     core type: Literal
#     sub-expressions:
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. l
#     core type: Variable
#     sub-expressions:
# 20. 1
#     core type: Literal
#     sub-expressions:
