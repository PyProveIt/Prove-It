# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, l
from proveit.logic import InSet
from proveit.numbers import Add, Complex, Integer, one

# %%
# build up the expression from sub-expressions
expr = Conditional(InSet(Add(l, one), Complex), InSet(l, Integer))
# Out:
# expr: {(l + 1) in Complex if l in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(l + 1\right) \in \mathbb{C} \textrm{ if } l \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(l + 1) in Complex if l in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (l + 1) in Complex
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. l in Integer
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (l + 1, Complex)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 6. l + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. Complex
#    core type: Literal
#    sub-expressions:
# 8. Integer
#    core type: Literal
#    sub-expressions:
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (l, 1)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. l
#     core type: Variable
#     sub-expressions:
# 12. 1
#     core type: Literal
#     sub-expressions:
