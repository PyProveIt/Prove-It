# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, fb, fx, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Less, Neg, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall([a, b], Equals(Sum(sub_expr1, fx, domain = Interval(a, b)), Add(Sum(sub_expr1, fx, domain = Interval(a, Add(b, Neg(one)))), fb)), domain = Integer, condition = Less(a, b))
# Out:
# expr: forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{x=a}^{b} f(x)\right) = \left(\left(\sum_{x=a}^{b - 1} f(x)\right) + f(b)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Lambda
#    parameters: 36\n   body: 4
# 4. {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (a in Integer) and (b in Integer) and (a < b)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
# ...
