# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import InSet
from proveit.numbers import Add, Interval, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(k, Conditional(alpha_k, InSet(k, Interval(Add(b, one), c)))))
# Out:
# expr: (k -> {alpha_{k} if k in {b + 1 .. c}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\alpha_{k} \textrm{ if } k \in \{b + 1~\ldotp \ldotp~c\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {alpha_{k} if k in {b + 1 .. c}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {alpha_{k} if k in {b + 1 .. c}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {alpha_{k} if k in {b + 1 .. c}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. alpha_{k}
#    core type: IndexedVar
# variable: 5
# index: 9
# 4. k in {b + 1 .. c}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. alpha
#    core type: Variable
#    sub-expressions:
# 6. (k)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, {b + 1 .. c})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. k
#    core type: Variable
#    sub-expressions:
# 10. {b + 1 .. c}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. b + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. b
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
