# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = ExprTuple(Lambda([a, b, c], Conditional(Forall([alpha], Equals(Sum(sub_expr1, alpha_k, domain = Interval(a, c)), Add(Sum(sub_expr1, alpha_k, domain = Interval(a, b)), Sum(sub_expr1, alpha_k, domain = Interval(Add(b, one), c))))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))))
# Out:
# expr: ((a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\forall_{\alpha}~\left(\left(\sum_{k=a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k=a}^{b} \alpha_{k}\right) + \left(\sum_{k=b + 1}^{c} \alpha_{k}\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 60, 65, 62
# 3. {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 18
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Lambda
#    parameter: 50
#    body: 14
# 10. a in Integer
#     core type: Operation
#     operator: 52
#     operands: 15
# 11. b in Integer
#     core type: Operation
#     operator: 52
#     operands: 16
# 12. c in Integer
#     core type: Operation
#     operator: 52
#     operands: 17
# 13. a <= b <= c
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. (Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#     core type: Operation
#     operator: 20
#     operands: 21
# 15. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 22
# 16. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 22
# 17. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 22
# 18. and
#     core type: Literal
#     sub-expressions:
# 19. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (Sum_{k=a}^{c} alpha_{k}, (Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 22. Integer
#     core type: Literal
#     sub-expressions:
# 23. a <= b
#     core type: Operation
#     operator: 27
#     operands: 57
# 24. b <= c
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. Sum_{k=a}^{c} alpha_{k}
#     core type: Operation
#     operator: 36
#     operand: 31
# 26. (Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})
#     core type: Operation
#     operator: 63
#     operands: 30
# 27. <=
#     core type: Literal
#     sub-expressions:
# 28. (b, c)
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 29. (k -> {alpha_{k} if k in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 31
# 30. (Sum_{k=a}^{b} alpha_{k}, Sum_{k=b + 1}^{c} alpha_{k})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. k -> {alpha_{k} if k in {a .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 34
# 32. Sum_{k=a}^{b} alpha_{k}
#     core type: Operation
#     operator: 36
#     operand: 39
# 33. Sum_{k=b + 1}^{c} alpha_{k}
#     core type: Operation
#     operator: 36
#     operand: 40
# 34. {alpha_{k} if k in {a .. c}.
#     core type: Conditional
#     value: 46
#     condition: 38
# 35. (k -> {alpha_{k} if k in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 36. Sum
#     core type: Literal
#     sub-expressions:
# 37. (k -> {alpha_{k} if k in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. k in {a .. c}
#     core type: Operation
#     operator: 52
#     operands: 41
# 39. k -> {alpha_{k} if k in {a .. b}.
#     core type: Lambda
#     parameter: 55
#     body: 42
# 40. k -> {alpha_{k} if k in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 43
# 41. (k, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 44
# 42. {alpha_{k} if k in {a .. b}.
#     core type: Conditional
#     value: 46
#     condition: 45
# 43. {alpha_{k} if k in {b + 1 .. c}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 44. {a .. c}
#     core type: Operation
#     operator: 58
#     operands: 48
# 45. k in {a .. b}
#     core type: Operation
#     operator: 52
#     operands: 49
# 46. alpha_{k}
#     core type: IndexedVar
# variable: 50
# index: 55
# 47. k in {b + 1 .. c}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. (a, c)
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 49. (k, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 50. alpha
#     core type: Variable
#     sub-expressions:
# 51. (k)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (k, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. {a .. b}
#     core type: Operation
#     operator: 58
#     operands: 57
# 55. k
#     core type: Variable
#     sub-expressions:
# 56. {b + 1 .. c}
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. (a, b)
#     core type: ExprTuple
#     sub-expressions: 60, 65
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. b + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. c
#     core type: Variable
#     sub-expressions:
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
