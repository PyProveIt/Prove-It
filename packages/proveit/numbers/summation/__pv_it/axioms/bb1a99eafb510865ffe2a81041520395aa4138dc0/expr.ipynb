# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import Equals
from proveit.numbers import Add, Interval, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Lambda(alpha, Equals(Sum(sub_expr1, alpha_k, domain = Interval(a, c)), Add(Sum(sub_expr1, alpha_k, domain = Interval(a, b)), Sum(sub_expr1, alpha_k, domain = Interval(Add(b, one), c)))))
# Out:
# expr: alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \alpha \mapsto \left(\left(\sum_{k=a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k=a}^{b} \alpha_{k}\right) + \left(\sum_{k=b + 1}^{c} \alpha_{k}\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Lambda
#    parameter: 27
#    body: 1
# 1. (Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (Sum_{k=a}^{c} alpha_{k}, (Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. Sum_{k=a}^{c} alpha_{k}
#    core type: Operation
#    operator: 13
#    operand: 8
# 5. (Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})
#    core type: Operation
#    operator: 40
#    operands: 7
# 6. (k -> {alpha_{k} if k in {a .. c}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{k=a}^{b} alpha_{k}, Sum_{k=b + 1}^{c} alpha_{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k -> {alpha_{k} if k in {a .. c}.
#    core type: Lambda
# ...
