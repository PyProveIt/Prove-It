# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#sum_split_last">sum_split_last</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import sum_split_last

# %%
# check that the built expression is the same as the stored expression
assert sum_split_last.expr == stored_expr
assert sum_split_last.expr._style_id == stored_expr._style_id
print("Passed sanity check: sum_split_last matches stored_expr")
# Out:
# Passed sanity check: sum_split_last matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sum_split_last.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{x=a}^{b} f(x)\right) = \left(\left(\sum_{x=a}^{b - 1} f(x)\right) + f(b)\right)\right)\right]

# %%
sum_split_last.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
sum_split_last.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))]
#    core type: Operation
#    operator: 4
#    operand: 2
# 1. (f -> [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))]
#    core type: Lambda
#    parameter: 40
#    body: 3
# 3. forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
# ...
