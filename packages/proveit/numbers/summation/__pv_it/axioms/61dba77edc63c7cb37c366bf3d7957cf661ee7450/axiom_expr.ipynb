# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#breakup_sum">breakup_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import breakup_sum

# %%
# check that the built expression is the same as the stored expression
assert breakup_sum.expr == stored_expr
assert breakup_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: breakup_sum matches stored_expr")
# Out:
# Passed sanity check: breakup_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(breakup_sum.latex())
# Out:
# \vdash \forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left[\forall_{\alpha}~\left(\left(\sum_{k=a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k=a}^{b} \alpha_{k}\right) + \left(\sum_{k=b + 1}^{c} \alpha_{k}\right)\right)\right)\right]

# %%
breakup_sum.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
breakup_sum.expr_info()
# Out:
# 0. forall_{a, b, c in Integer | a <= b <= c} [forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 61, 66, 63
# 4. {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 5
# ...
