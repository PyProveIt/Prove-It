# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, fb, fx, x
from proveit.numbers import Add, Interval, Neg, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Sum(sub_expr1, fx, domain = Interval(a, b)), Add(Sum(sub_expr1, fx, domain = Interval(a, Add(b, Neg(one)))), fb))
# Out:
# expr: (Sum_{x=a}^{b} f(x), (Sum_{x=a}^{b - 1} f(x)) + f(b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b} f(x), \left(\sum_{x=a}^{b - 1} f(x)\right) + f(b)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b} f(x), (Sum_{x=a}^{b - 1} f(x)) + f(b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x=a}^{b} f(x)
#    core type: Operation
#    operator: 9
#    operand: 5
# 2. (Sum_{x=a}^{b - 1} f(x)) + f(b)
#    core type: Operation
#    operator: 30
#    operands: 4
# 3. (x -> {f(x) if x in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{x=a}^{b - 1} f(x), f(b))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. x -> {f(x) if x in {a .. b}.
#    core type: Lambda
#    parameter: 24
#    body: 8
# 6. Sum_{x=a}^{b - 1} f(x)
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. f(b)
#    core type: Operation
#    operator: 20
#    operand: 32
# 8. {f(x) if x in {a .. b}.
#    core type: Conditional
#    value: 17
#    condition: 12
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (x -> {f(x) if x in {a .. b - 1}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. (b)
#     core type: ExprTuple
# ...
