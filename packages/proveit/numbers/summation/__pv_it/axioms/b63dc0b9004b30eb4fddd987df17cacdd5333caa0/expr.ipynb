# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, fb, fx, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Less, Neg, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([a, b], Conditional(Equals(Sum(sub_expr1, fx, domain = Interval(a, b)), Add(Sum(sub_expr1, fx, domain = Interval(a, Add(b, Neg(one)))), fb)), And(InSet(a, Integer), InSet(b, Integer), Less(a, b))))
# Out:
# expr: (a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left(\sum_{x=a}^{b} f(x)\right) = \left(\left(\sum_{x=a}^{b - 1} f(x)\right) + f(b)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  a < b\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Lambda
#    parameters: 33\n   body: 1
# 1. {(Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b)) if a in Integer ,  b in Integer ,  a < b.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (Sum_{x=a}^{b} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + f(b))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a in Integer) and (b in Integer) and (a < b)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (Sum_{x=a}^{b} f(x), (Sum_{x=a}^{b - 1} f(x)) + f(b))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (a in Integer, b in Integer, a < b)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 8. Sum_{x=a}^{b} f(x)
#    core type: Operation
#    operator: 23
#    operand: 18
# ...
