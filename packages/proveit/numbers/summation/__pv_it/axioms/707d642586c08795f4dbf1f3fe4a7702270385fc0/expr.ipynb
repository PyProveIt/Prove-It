# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Interval, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Forall([alpha], Equals(Sum(sub_expr1, alpha_k, domain = Interval(a, c)), Add(Sum(sub_expr1, alpha_k, domain = Interval(a, b)), Sum(sub_expr1, alpha_k, domain = Interval(Add(b, one), c)))))
# Out:
# expr: forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\alpha}~\left(\left(\sum_{k=a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k=a}^{b} \alpha_{k}\right) + \left(\sum_{k=b + 1}^{c} \alpha_{k}\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. alpha -> ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Lambda
#    parameter: 30
#    body: 4
# 4. (Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{k=a}^{c} alpha_{k}, (Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. Sum_{k=a}^{c} alpha_{k}
#    core type: Operation
#    operator: 16
#    operand: 11
# ...
