# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, alpha, b, c, k
from proveit.core_expr_types import alpha_k
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Lambda([a, b, c], Conditional(Forall([alpha], Equals(Sum(sub_expr1, alpha_k, domain = Interval(a, c)), Add(Sum(sub_expr1, alpha_k, domain = Interval(a, b)), Sum(sub_expr1, alpha_k, domain = Interval(Add(b, one), c))))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style())))
# Out:
# expr: (a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\forall_{\alpha}~\left(\left(\sum_{k=a}^{c} \alpha_{k}\right) = \left(\left(\sum_{k=a}^{b} \alpha_{k}\right) + \left(\sum_{k=b + 1}^{c} \alpha_{k}\right)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c) -> {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 59, 64, 61
# 2. {forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k}))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{alpha} ((Sum_{k=a}^{c} alpha_{k}) = ((Sum_{k=a}^{b} alpha_{k}) + (Sum_{k=b + 1}^{c} alpha_{k})))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 17
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# ...
