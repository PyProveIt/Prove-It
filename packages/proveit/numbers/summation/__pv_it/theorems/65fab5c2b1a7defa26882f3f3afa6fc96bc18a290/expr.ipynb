# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, f, fx, g, gx, x
from proveit.logic import Forall, Implies
from proveit.numbers import LessEq, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall([S, f, g], Implies(Forall(sub_expr1, LessEq(fx, gx), domain = S), LessEq(Sum(sub_expr1, fx, domain = S), Sum(sub_expr1, gx, domain = S))))
# Out:
# expr: forall_{S, f, g} ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{S, f, g}~\left(\left[\forall_{x \in S}~\left(f(x) \leq g(x)\right)\right] \Rightarrow \left(\sum_{x \in S}~f(x) \leq \sum_{x \in S}~g(x)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{S, f, g} ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((S, f, g) -> ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x))))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (S, f, g) -> ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (S, f, g)
#    core type: ExprTuple
#    sub-expressions: 35, 29, 30
# 4. [forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x in S} (f(x) <= g(x)), Sum_{x in S} f(x) <= Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x in S} (f(x) <= g(x))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. Sum_{x in S} f(x) <= Sum_{x in S} g(x)
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. forall
#    core type: Literal
#    sub-expressions:
# 10. (x -> {f(x) <= g(x) if x in S.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (Sum_{x in S} f(x), Sum_{x in S} g(x))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. x -> {f(x) <= g(x) if x in S.
#     core type: Lambda
#     parameter: 34
#     body: 15
# 13. Sum_{x in S} f(x)
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Sum_{x in S} g(x)
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. {f(x) <= g(x) if x in S.
#     core type: Conditional
#     value: 19
#     condition: 28
# 16. (x -> {f(x) if x in S.)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. Sum
#     core type: Literal
#     sub-expressions:
# 18. (x -> {g(x) if x in S.)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. f(x) <= g(x)
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. x -> {f(x) if x in S.
#     core type: Lambda
#     parameter: 34
#     body: 24
# 21. x -> {g(x) if x in S.
#     core type: Lambda
#     parameter: 34
#     body: 25
# 22. <=
#     core type: Literal
#     sub-expressions:
# 23. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. {f(x) if x in S.
#     core type: Conditional
#     value: 26
#     condition: 28
# 25. {g(x) if x in S.
#     core type: Conditional
#     value: 27
#     condition: 28
# 26. f(x)
#     core type: Operation
#     operator: 29
#     operand: 34
# 27. g(x)
#     core type: Operation
#     operator: 30
#     operand: 34
# 28. x in S
#     core type: Operation
#     operator: 32
#     operands: 33
# 29. f
#     core type: Variable
#     sub-expressions:
# 30. g
#     core type: Variable
#     sub-expressions:
# 31. (x)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. in
#     core type: Literal
#     sub-expressions:
# 33. (x, S)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. x
#     core type: Variable
#     sub-expressions:
# 35. S
#     core type: Variable
#     sub-expressions:
