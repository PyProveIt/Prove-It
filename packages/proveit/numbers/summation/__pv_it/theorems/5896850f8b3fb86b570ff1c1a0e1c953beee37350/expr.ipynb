# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, n
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Interval, Mult, NaturalPos, Sum, frac, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Equals(Sum([k], k, domain = Interval(one, n)), frac(Mult(n, Add(n, one)), two)), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {(Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\left(\sum_{k=1}^{n} k\right) = \frac{n \cdot \left(n + 1\right)}{2} \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {(Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {(Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#    core type: Lambda
#    parameter: 32
#    body: 2
# 2. {(Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2) if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{k=1}^{n} k) = ((n * (n + 1)) / 2)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. n in NaturalPos
#    core type: Operation
#    operator: 23
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{k=1}^{n} k, (n * (n + 1)) / 2)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 32, 10
# 8. Sum_{k=1}^{n} k
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. (n * (n + 1)) / 2
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (k -> {k if k in {1 .. n}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (n * (n + 1), 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. k -> {k if k in {1 .. n}.
#     core type: Lambda
#     parameter: 27
#     body: 18
# 16. n * (n + 1)
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. {k if k in {1 .. n}.
#     core type: Conditional
#     value: 27
#     condition: 21
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (n, n + 1)
#     core type: ExprTuple
#     sub-expressions: 32, 22
# 21. k in {1 .. n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. n + 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (k, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 31
# 27. k
#     core type: Variable
#     sub-expressions:
# 28. {1 .. n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Interval
#     core type: Literal
#     sub-expressions:
# 30. (1, n)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. n
#     core type: Variable
#     sub-expressions:
