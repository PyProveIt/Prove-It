# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, c, fx, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([a, b, c], Conditional(Equals(Sum(sub_expr1, fx, domain = Interval(a, c)), Add(Sum(sub_expr1, fx, domain = Interval(a, b)), Sum(sub_expr1, fx, domain = Interval(Add(b, one), c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style())))
# Out:
# expr: (a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b} f(x)\right) + \left(\sum_{x=b + 1}^{c} f(x)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a \leq b \leq c\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 55, 60, 57
# 2. {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 19
#    operands: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{x=a}^{c} f(x), (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# ...
