# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sum_split_after">sum_split_after</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import sum_split_after

# %%
# check that the built expression is the same as the stored expression
assert sum_split_after.expr == stored_expr
assert sum_split_after.expr._style_id == stored_expr._style_id
print("Passed sanity check: sum_split_after matches stored_expr")
# Out:
# Passed sanity check: sum_split_after matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sum_split_after.latex())
# Out:
# \vdash \forall_{f}~\left[\forall_{a, b, c \in \mathbb{Z}~|~a \leq b, b < c}~\left(\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b} f(x)\right) + \left(\sum_{x=b + 1}^{c} f(x)\right)\right)\right)\right]

# %%
sum_split_after.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
sum_split_after.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]
#    core type: Operation
#    operator: 4
#    operand: 2
# 1. (f -> [forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]
#    core type: Lambda
#    parameter: 50
#    body: 3
# 3. forall_{a, b, c in Integer | a <= b, b < c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b ,  b < c.)
#    core type: ExprTuple
# ...
