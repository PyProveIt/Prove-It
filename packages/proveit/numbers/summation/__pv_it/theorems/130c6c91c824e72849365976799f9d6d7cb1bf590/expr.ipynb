# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, f, g, k, l, m, n
from proveit.logic import Equals, Forall
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [l]
sub_expr3 = Interval(m, n)
expr = ExprTuple(Forall(sub_expr1, Equals(Operation(f, sub_expr1), Operation(g, sub_expr1)), domain = sub_expr3), Equals(Sum(sub_expr2, Operation(f, sub_expr2), domain = sub_expr3), Sum(sub_expr2, Operation(g, sub_expr2), domain = sub_expr3)))
# Out:
# expr: (forall_{k in {m .. n}} (f(k) = g(k)), (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{k \in \{m~\ldotp \ldotp~n\}}~\left(f(k) = g(k)\right), \left(\sum_{l=m}^{n} f(l)\right) = \left(\sum_{l=m}^{n} g(l)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{k in {m .. n}} (f(k) = g(k)), (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{k in {m .. n}} (f(k) = g(k))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {f(k) = g(k) if k in {m .. n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{l=m}^{n} f(l), Sum_{l=m}^{n} g(l))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. k -> {f(k) = g(k) if k in {m .. n}.
#    core type: Lambda
#    parameter: 33
#    body: 9
# 7. Sum_{l=m}^{n} f(l)
#    core type: Operation
#    operator: 11
#    operand: 15
# 8. Sum_{l=m}^{n} g(l)
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. {f(k) = g(k) if k in {m .. n}.
#    core type: Conditional
#    value: 13
#    condition: 14
# ...
