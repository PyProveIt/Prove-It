# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, fx, x
from proveit.logic import InSet
from proveit.numbers import Add, Interval, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(fx, InSet(x, Interval(Add(a, one), b)))))
# Out:
# expr: (x -> {f(x) if x in {a + 1 .. b}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{f(x) \textrm{ if } x \in \{a + 1~\ldotp \ldotp~b\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {f(x) if x in {a + 1 .. b}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {f(x) if x in {a + 1 .. b}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {f(x) if x in {a + 1 .. b}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. f(x)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. x in {a + 1 .. b}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. f
#    core type: Variable
#    sub-expressions:
# 6. (x)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, {a + 1 .. b})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. x
#    core type: Variable
#    sub-expressions:
# 10. {a + 1 .. b}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (a + 1, b)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. a + 1
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (a, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. 1
#     core type: Literal
#     sub-expressions:
