# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Operation, a, b, c, f, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall([a, b, c], Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c)))), domain = Integer)
# Out:
# expr: forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}}~\left(\left(\sum_{x=a}^{b} f(x)\right) = \left(\sum_{x=a + c}^{b + c} f(x - c)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 54, 55, 56
# 5. {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (c in Integer)
# ...
