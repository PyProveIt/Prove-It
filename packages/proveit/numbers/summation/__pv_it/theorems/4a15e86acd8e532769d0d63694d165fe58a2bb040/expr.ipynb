# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation, f, g, k, m, n
from proveit.logic import Equals, InSet
from proveit.numbers import Interval

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
expr = Lambda(k, Conditional(Equals(Operation(f, sub_expr1), Operation(g, sub_expr1)), InSet(k, Interval(m, n))))
# Out:
# expr: k -> {f(k) = g(k) if k in {m .. n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{f(k) = g(k) \textrm{ if } k \in \{m~\ldotp \ldotp~n\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {f(k) = g(k) if k in {m .. n}.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {f(k) = g(k) if k in {m .. n}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. f(k) = g(k)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in {m .. n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (f(k), g(k))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {m .. n})
#    core type: ExprTuple
#    sub-expressions: 16, 10
# 8. f(k)
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. g(k)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. {m .. n}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. f
#     core type: Variable
#     sub-expressions:
# 12. g
#     core type: Variable
#     sub-expressions:
# 13. (k)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (m, n)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
