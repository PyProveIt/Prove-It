# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, fa, fx, x
from proveit.numbers import Add, Interval, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Sum(sub_expr1, fx, domain = Interval(a, b)), Add(fa, Sum(sub_expr1, fx, domain = Interval(Add(a, one), b))))
# Out:
# expr: (Sum_{x=a}^{b} f(x), f(a) + (Sum_{x=a + 1}^{b} f(x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b} f(x), f(a) + \left(\sum_{x=a + 1}^{b} f(x)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b} f(x), f(a) + (Sum_{x=a + 1}^{b} f(x)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x=a}^{b} f(x)
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. f(a) + (Sum_{x=a + 1}^{b} f(x))
#    core type: Operation
#    operator: 30
#    operands: 4
# 3. (x -> {f(x) if x in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f(a), Sum_{x=a + 1}^{b} f(x))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. x -> {f(x) if x in {a .. b}.
#    core type: Lambda
#    parameter: 24
#    body: 8
# 6. f(a)
#    core type: Operation
#    operator: 20
#    operand: 32
# 7. Sum_{x=a + 1}^{b} f(x)
#    core type: Operation
#    operator: 10
#    operand: 13
# 8. {f(x) if x in {a .. b}.
#    core type: Conditional
#    value: 17
#    condition: 12
# 9. (a)
#    core type: ExprTuple
#    sub-expressions: 32
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (x -> {f(x) if x in {a + 1 .. b}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. x in {a .. b}
#     core type: Operation
#     operator: 22
#     operands: 14
# 13. x -> {f(x) if x in {a + 1 .. b}.
#     core type: Lambda
#     parameter: 24
#     body: 15
# 14. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 24, 16
# 15. {f(x) if x in {a + 1 .. b}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 16. {a .. b}
#     core type: Operation
#     operator: 26
#     operands: 19
# 17. f(x)
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. x in {a + 1 .. b}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. (a, b)
#     core type: ExprTuple
#     sub-expressions: 32, 29
# 20. f
#     core type: Variable
#     sub-expressions:
# 21. (x)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (x, {a + 1 .. b})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. {a + 1 .. b}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (a + 1, b)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. a + 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (a, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. a
#     core type: Variable
#     sub-expressions:
# 33. 1
#     core type: Literal
#     sub-expressions:
