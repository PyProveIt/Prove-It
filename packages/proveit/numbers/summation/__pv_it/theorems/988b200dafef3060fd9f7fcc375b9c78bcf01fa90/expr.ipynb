# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Operation, R, S, a, f, fa, fx, g, gy, x, y
from proveit.logic import Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Forall([f, g, R, S], Implies(Forall([a], InSet(fa, Complex), domain = R), Equals(Sum([x], fx, domain = R), Sum(sub_expr1, Operation(f, [gy]), domain = S))), condition = Equals(SetOfAll(sub_expr1, gy, domain = S), R))
# Out:
# expr: forall_{f, g, R, S | {g(y)}_{y in S} = R} ([forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, g, R, S~|~\left\{g(y)\right\}_{y \in S} = R}~\left(\left[\forall_{a \in R}~\left(f(a) \in \mathbb{C}\right)\right] \Rightarrow \left(\sum_{x \in R}~f(x) = \sum_{y \in S}~f(g(y))\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f, g, R, S | {g(y)}_{y in S} = R} ([forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))))
#    core type: Operation
#    operator: 13
#    operand: 2
# 1. ((f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, g, R, S)
#    core type: ExprTuple
#    sub-expressions: 45, 54, 51, 53
# 4. {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. [forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. {g(y)}_{y in S} = R
# ...
