# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, S, fx, gx, x
from proveit.logic import Forall
from proveit.numbers import LessEq, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Forall(sub_expr1, LessEq(fx, gx), domain = S), LessEq(Sum(sub_expr1, fx, domain = S), Sum(sub_expr1, gx, domain = S)))
# Out:
# expr: (forall_{x in S} (f(x) <= g(x)), Sum_{x in S} f(x) <= Sum_{x in S} g(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x \in S}~\left(f(x) \leq g(x)\right), \sum_{x \in S}~f(x) \leq \sum_{x \in S}~g(x)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x in S} (f(x) <= g(x)), Sum_{x in S} f(x) <= Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x in S} (f(x) <= g(x))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. Sum_{x in S} f(x) <= Sum_{x in S} g(x)
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {f(x) <= g(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{x in S} f(x), Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> {f(x) <= g(x) if x in S.
#    core type: Lambda
#    parameter: 28
#    body: 9
# 7. Sum_{x in S} f(x)
#    core type: Operation
#    operator: 11
#    operand: 14
# 8. Sum_{x in S} g(x)
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. {f(x) <= g(x) if x in S.
#    core type: Conditional
#    value: 13
#    condition: 22
# 10. (x -> {f(x) if x in S.)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (x -> {g(x) if x in S.)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. f(x) <= g(x)
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. x -> {f(x) if x in S.
#     core type: Lambda
#     parameter: 28
#     body: 18
# 15. x -> {g(x) if x in S.
#     core type: Lambda
#     parameter: 28
#     body: 19
# 16. <=
#     core type: Literal
#     sub-expressions:
# 17. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. {f(x) if x in S.
#     core type: Conditional
#     value: 20
#     condition: 22
# 19. {g(x) if x in S.
#     core type: Conditional
#     value: 21
#     condition: 22
# 20. f(x)
#     core type: Operation
#     operator: 23
#     operand: 28
# 21. g(x)
#     core type: Operation
#     operator: 24
#     operand: 28
# 22. x in S
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. g
#     core type: Variable
#     sub-expressions:
# 25. (x)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. in
#     core type: Literal
#     sub-expressions:
# 27. (x, S)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. S
#     core type: Variable
#     sub-expressions:
