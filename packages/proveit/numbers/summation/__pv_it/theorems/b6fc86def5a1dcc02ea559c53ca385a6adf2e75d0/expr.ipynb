# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, fx, x
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall([a, b, c], Equals(Sum(sub_expr1, fx, domain = Interval(a, c)), Add(Sum(sub_expr1, fx, domain = Interval(a, b)), Sum(sub_expr1, fx, domain = Interval(Add(b, one), c)))), domain = Integer, condition = And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style())
# Out:
# expr: forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left(\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b} f(x)\right) + \left(\sum_{x=b + 1}^{c} f(x)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 58, 63, 60
# 5. {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 22
#    operands: 10
# 8. =
#    core type: Literal
#    sub-expressions:
# 9. (Sum_{x=a}^{c} f(x), (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#     core type: ExprTuple
#     sub-expressions: 13, 14, 15, 16
# 11. Sum_{x=a}^{c} f(x)
#     core type: Operation
#     operator: 32
#     operand: 24
# 12. (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))
#     core type: Operation
#     operator: 61
#     operands: 18
# 13. a in Integer
#     core type: Operation
#     operator: 50
#     operands: 19
# 14. b in Integer
#     core type: Operation
#     operator: 50
#     operands: 20
# 15. c in Integer
#     core type: Operation
#     operator: 50
#     operands: 21
# 16. a <= b <= c
#     core type: Operation
#     operator: 22
#     operands: 23
# 17. (x -> {f(x) if x in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 18. (Sum_{x=a}^{b} f(x), Sum_{x=b + 1}^{c} f(x))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 19. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 58, 27
# 20. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 63, 27
# 21. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 27
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 24. x -> {f(x) if x in {a .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 30
# 25. Sum_{x=a}^{b} f(x)
#     core type: Operation
#     operator: 32
#     operand: 37
# 26. Sum_{x=b + 1}^{c} f(x)
#     core type: Operation
#     operator: 32
#     operand: 38
# 27. Integer
#     core type: Literal
#     sub-expressions:
# 28. a <= b
#     core type: Operation
#     operator: 34
#     operands: 55
# 29. b <= c
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. {f(x) if x in {a .. c}.
#     core type: Conditional
#     value: 44
#     condition: 36
# 31. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. Sum
#     core type: Literal
#     sub-expressions:
# 33. (x -> {f(x) if x in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 34. <=
#     core type: Literal
#     sub-expressions:
# 35. (b, c)
#     core type: ExprTuple
#     sub-expressions: 63, 60
# 36. x in {a .. c}
#     core type: Operation
#     operator: 50
#     operands: 39
# 37. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 53
#     body: 40
# 38. x -> {f(x) if x in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 53
#     body: 41
# 39. (x, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 42
# 40. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 44
#     condition: 43
# 41. {f(x) if x in {b + 1 .. c}.
#     core type: Conditional
#     value: 44
#     condition: 45
# 42. {a .. c}
#     core type: Operation
#     operator: 56
#     operands: 46
# 43. x in {a .. b}
#     core type: Operation
#     operator: 50
#     operands: 47
# 44. f(x)
#     core type: Operation
#     operator: 48
#     operand: 53
# 45. x in {b + 1 .. c}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. (a, c)
#     core type: ExprTuple
#     sub-expressions: 58, 60
# 47. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 53, 52
# 48. f
#     core type: Variable
#     sub-expressions:
# 49. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 50. in
#     core type: Literal
#     sub-expressions:
# 51. (x, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 52. {a .. b}
#     core type: Operation
#     operator: 56
#     operands: 55
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. {b + 1 .. c}
#     core type: Operation
#     operator: 56
#     operands: 57
# 55. (a, b)
#     core type: ExprTuple
#     sub-expressions: 58, 63
# 56. Interval
#     core type: Literal
#     sub-expressions:
# 57. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 58. a
#     core type: Variable
#     sub-expressions:
# 59. b + 1
#     core type: Operation
#     operator: 61
#     operands: 62
# 60. c
#     core type: Variable
#     sub-expressions:
# 61. +
#     core type: Literal
#     sub-expressions:
# 62. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 63. b
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
