# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, S, f, fx, g, gx, x
from proveit.logic import Forall, Implies
from proveit.numbers import LessEq, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([S, f, g], Implies(Forall(sub_expr1, LessEq(fx, gx), domain = S), LessEq(Sum(sub_expr1, fx, domain = S), Sum(sub_expr1, gx, domain = S))))
# Out:
# expr: (S, f, g) -> ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S, f, g\right) \mapsto \left(\left[\forall_{x \in S}~\left(f(x) \leq g(x)\right)\right] \Rightarrow \left(\sum_{x \in S}~f(x) \leq \sum_{x \in S}~g(x)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S, f, g) -> ([forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x)))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S, f, g)
#    core type: ExprTuple
#    sub-expressions: 33, 27, 28
# 2. [forall_{x in S} (f(x) <= g(x))] => (Sum_{x in S} f(x) <= Sum_{x in S} g(x))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x in S} (f(x) <= g(x)), Sum_{x in S} f(x) <= Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x in S} (f(x) <= g(x))
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. Sum_{x in S} f(x) <= Sum_{x in S} g(x)
#    core type: Operation
#    operator: 20
#    operands: 9
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (x -> {f(x) <= g(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (Sum_{x in S} f(x), Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# ...
