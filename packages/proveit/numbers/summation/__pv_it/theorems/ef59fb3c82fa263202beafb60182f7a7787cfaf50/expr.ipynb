# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, b, c, fx, x
from proveit.logic import InSet
from proveit.numbers import Add, Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(fx, InSet(x, Interval(Add(b, one), c))))
# Out:
# expr: x -> {f(x) if x in {b + 1 .. c}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{f(x) \textrm{ if } x \in \{b + 1~\ldotp \ldotp~c\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {f(x) if x in {b + 1 .. c}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {f(x) if x in {b + 1 .. c}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. f(x)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. x in {b + 1 .. c}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. f
#    core type: Variable
#    sub-expressions:
# 5. (x)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {b + 1 .. c})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. {b + 1 .. c}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. b + 1
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. c
#     core type: Variable
#     sub-expressions:
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. b
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
