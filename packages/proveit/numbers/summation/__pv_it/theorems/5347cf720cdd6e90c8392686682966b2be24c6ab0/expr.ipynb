# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, S, fx, gx, x
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Sum(sub_expr1, fx, domain = S), Sum(sub_expr1, gx, domain = S))
# Out:
# expr: (Sum_{x in S} f(x), Sum_{x in S} g(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x \in S}~f(x), \sum_{x \in S}~g(x)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x in S} f(x), Sum_{x in S} g(x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x in S} f(x)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{x in S} g(x)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (x -> {f(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (x -> {g(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. x -> {f(x) if x in S.
#    core type: Lambda
#    parameter: 18
#    body: 8
# 7. x -> {g(x) if x in S.
#    core type: Lambda
#    parameter: 18
#    body: 9
# 8. {f(x) if x in S.
#    core type: Conditional
#    value: 10
#    condition: 12
# 9. {g(x) if x in S.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. f(x)
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. g(x)
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. x in S
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. f
#     core type: Variable
#     sub-expressions:
# 14. g
#     core type: Variable
#     sub-expressions:
# 15. (x)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x, S)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. S
#     core type: Variable
#     sub-expressions:
