# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Px, Qx, x
from proveit.logic import Forall, Implies, InSet
from proveit.numbers import NaturalPos, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Implies(Forall(sub_expr1, InSet(Px, NaturalPos), condition = Qx), InSet(Sum(sub_expr1, Px, condition = Qx), NaturalPos))
# Out:
# expr: [forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{x~|~Q(x)}~\left(P(x) \in \mathbb{N}^+\right)\right] \Rightarrow \left(\sum_{x~|~Q(x)}~P(x) \in \mathbb{N}^+\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x | Q(x)} (P(x) in NaturalPos), Sum_{x | Q(x)} P(x) in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x | Q(x)} (P(x) in NaturalPos)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. Sum_{x | Q(x)} P(x) in NaturalPos
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {P(x) in NaturalPos if Q(x).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (Sum_{x | Q(x)} P(x), NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9, 18
# 8. x -> {P(x) in NaturalPos if Q(x).
#    core type: Lambda
#    parameter: 24
#    body: 10
# 9. Sum_{x | Q(x)} P(x)
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. {P(x) in NaturalPos if Q(x).
#     core type: Conditional
#     value: 13
#     condition: 20
# 11. Sum
#     core type: Literal
#     sub-expressions:
# 12. (x -> {P(x) if Q(x).)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. P(x) in NaturalPos
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. x -> {P(x) if Q(x).
#     core type: Lambda
#     parameter: 24
#     body: 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (P(x), NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 17. {P(x) if Q(x).
#     core type: Conditional
#     value: 19
#     condition: 20
# 18. NaturalPos
#     core type: Literal
#     sub-expressions:
# 19. P(x)
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. Q(x)
#     core type: Operation
#     operator: 22
#     operand: 24
# 21. P
#     core type: Variable
#     sub-expressions:
# 22. Q
#     core type: Variable
#     sub-expressions:
# 23. (x)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. x
#     core type: Variable
#     sub-expressions:
