# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation, a, b, c, f, x
from proveit.logic import InSet
from proveit.numbers import Add, Interval, Neg

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(Operation(f, [Add(x, Neg(c))]), InSet(x, Interval(Add(a, c), Add(b, c)))))
# Out:
# expr: x -> {f(x - c) if x in {a + c .. b + c}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{f(x - c) \textrm{ if } x \in \{a + c~\ldotp \ldotp~b + c\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {f(x - c) if x in {a + c .. b + c}.
#    core type: Lambda
#    parameter: 13
#    body: 1
# 1. {f(x - c) if x in {a + c .. b + c}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. f(x - c)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. x in {a + c .. b + c}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. f
#    core type: Variable
#    sub-expressions:
# 5. (x - c)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {a + c .. b + c})
#    core type: ExprTuple
#    sub-expressions: 13, 9
# 8. x - c
#    core type: Operation
#    operator: 20
#    operands: 10
# 9. {a + c .. b + c}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, -c)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (a + c, b + c)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. -c
#     core type: Operation
#     operator: 17
#     operand: 24
# 15. a + c
#     core type: Operation
#     operator: 20
#     operands: 19
# 16. b + c
#     core type: Operation
#     operator: 20
#     operands: 21
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (c)
#     core type: ExprTuple
#     sub-expressions: 24
# 19. (a, c)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (b, c)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. a
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. c
#     core type: Variable
#     sub-expressions:
