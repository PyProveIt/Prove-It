# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Exp, Interval, NaturalPos, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Sum([m], Exp(x, m), domain = Interval(zero, n)), frac(Add(one, Neg(Exp(x, Add(n, one)))), Add(one, Neg(x)))), And(InSet(x, Complex), InSet(n, NaturalPos)))
# Out:
# expr: {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sum_{m=0}^{n} x^{m}\right) = \frac{1 - x^{n + 1}}{1 - x} \textrm{ if } x \in \mathbb{C} ,  n \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complex) and (n in NaturalPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{m=0}^{n} x^{m}, (1 - x^{n + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex, n in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. Sum_{m=0}^{n} x^{m}
#    core type: Operation
#    operator: 11
#    operand: 17
# 8. (1 - x^{n + 1}) / (1 - x)
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. x in Complex
#    core type: Operation
#    operator: 30
#    operands: 15
# 10. n in NaturalPos
#     core type: Operation
# ...
