# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, Operation, a, b, c, f, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda(f, Forall([a, b, c], Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c)))), domain = Integer)))
# Out:
# expr: (f -> [forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f \mapsto \left[\forall_{a, b, c \in \mathbb{Z}}~\left(\left(\sum_{x=a}^{b} f(x)\right) = \left(\sum_{x=a + c}^{b + c} f(x - c)\right)\right)\right]\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f -> [forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. f -> [forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))]
#    core type: Lambda
#    parameter: 36
#    body: 2
# 2. forall_{a, b, c in Integer} ((Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 56, 57, 58
# ...
