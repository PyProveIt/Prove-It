# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Operation, R, S, a, f, fa, fx, gy, x, y
from proveit.logic import Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Conditional(Implies(Forall([a], InSet(fa, Complex), domain = R), Equals(Sum([x], fx, domain = R), Sum(sub_expr1, Operation(f, [gy]), domain = S))), Equals(SetOfAll(sub_expr1, gy, domain = S), R))
# Out:
# expr: {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left[\forall_{a \in R}~\left(f(a) \in \mathbb{C}\right)\right] \Rightarrow \left(\sum_{x \in R}~f(x) = \sum_{y \in S}~f(g(y))\right) \textrm{ if } \left\{g(y)\right\}_{y \in S} = R\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. {g(y)}_{y in S} = R
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{a in R} (f(a) in Complex), Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. ({g(y)}_{y in S}, R)
#    core type: ExprTuple
#    sub-expressions: 8, 47
# 6. forall_{a in R} (f(a) in Complex)
#    core type: Operation
#    operator: 9
#    operand: 15
# 7. Sum_{x in R} f(x) = Sum_{y in S} f(g(y))
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. {g(y)}_{y in S}
#    core type: Operation
#    operator: 13
#    operand: 18
# 9. forall
#    core type: Literal
# ...
