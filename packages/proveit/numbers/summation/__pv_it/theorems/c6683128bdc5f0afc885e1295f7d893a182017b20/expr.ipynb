# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, a, b, c, f, x
from proveit.numbers import Add, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c))))
# Out:
# expr: (Sum_{x=a}^{b} f(x), Sum_{x=a + c}^{b + c} f(x - c))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b} f(x), \sum_{x=a + c}^{b + c} f(x - c)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b} f(x), Sum_{x=a + c}^{b + c} f(x - c))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{x=a}^{b} f(x)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{x=a + c}^{b + c} f(x - c)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (x -> {f(x) if x in {a .. b}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (x -> {f(x - c) if x in {a + c .. b + c}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. x -> {f(x) if x in {a .. b}.
#    core type: Lambda
#    parameter: 27
#    body: 8
# 7. x -> {f(x - c) if x in {a + c .. b + c}.
#    core type: Lambda
#    parameter: 27
#    body: 9
# 8. {f(x) if x in {a .. b}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 9. {f(x - c) if x in {a + c .. b + c}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. f(x)
#     core type: Operation
#     operator: 16
#     operand: 27
# ...
