# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Operation, a, b, c, f, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer)))
# Out:
# expr: {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sum_{x=a}^{b} f(x)\right) = \left(\sum_{x=a + c}^{b + c} f(x - c)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (c in Integer)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{x=a}^{b} f(x), Sum_{x=a + c}^{b + c} f(x - c))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, c in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. Sum_{x=a}^{b} f(x)
#    core type: Operation
#    operator: 13
#    operand: 18
# 8. Sum_{x=a + c}^{b + c} f(x - c)
#    core type: Operation
#    operator: 13
#    operand: 19
# 9. a in Integer
#    core type: Operation
#    operator: 31
#    operands: 15
# ...
