# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, m, x
from proveit.logic import InSet
from proveit.numbers import Exp, Interval, zero

# %%
# build up the expression from sub-expressions
expr = Lambda(m, Conditional(Exp(x, m), InSet(m, Interval(zero, k))))
# Out:
# expr: m -> {x^{m} if m in {0 .. k}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# m \mapsto \left\{x^{m} \textrm{ if } m \in \{0~\ldotp \ldotp~k\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. m -> {x^{m} if m in {0 .. k}.
#    core type: Lambda
#    parameter: 9
#    body: 1
# 1. {x^{m} if m in {0 .. k}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x^{m}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. m in {0 .. k}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. Exp
#    core type: Literal
#    sub-expressions:
# 5. (x, m)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (m, {0 .. k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. m
#    core type: Variable
#    sub-expressions:
# 10. {0 .. k}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Interval
#     core type: Literal
#     sub-expressions:
# 12. (0, k)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 0
#     core type: Literal
#     sub-expressions:
# 14. k
#     core type: Variable
#     sub-expressions:
