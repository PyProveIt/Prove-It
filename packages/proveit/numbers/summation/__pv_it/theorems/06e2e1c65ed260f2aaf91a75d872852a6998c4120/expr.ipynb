# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Operation, f, n
from proveit.logic import Equals
from proveit.numbers import Add, Interval, Sum, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [n]
expr = Lambda(f, Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(zero, one)), Add(Operation(f, [zero]), Operation(f, [one]))))
# Out:
# expr: f -> ((Sum_{n=0}^{1} f(n)) = (f(0) + f(1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# f \mapsto \left(\left(\sum_{n=0}^{1} f(n)\right) = \left(f(0) + f(1)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. f -> ((Sum_{n=0}^{1} f(n)) = (f(0) + f(1)))
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. (Sum_{n=0}^{1} f(n)) = (f(0) + f(1))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =
#    core type: Literal
#    sub-expressions:
# 3. (Sum_{n=0}^{1} f(n), f(0) + f(1))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. Sum_{n=0}^{1} f(n)
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. f(0) + f(1)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (n -> {f(n) if n in {0 .. 1}.)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (f(0), f(1))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. n -> {f(n) if n in {0 .. 1}.
#     core type: Lambda
#     parameter: 22
#     body: 13
# 11. f(0)
#     core type: Operation
#     operator: 18
#     operand: 26
# 12. f(1)
#     core type: Operation
# ...
