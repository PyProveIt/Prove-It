# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Operation, a, b, c, f, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda([a, b, c], Conditional(Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer)))))
# Out:
# expr: ((a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\left(\sum_{x=a}^{b} f(x)\right) = \left(\sum_{x=a + c}^{b + c} f(x - c)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 52, 53, 54
# 3. {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a in Integer) and (b in Integer) and (c in Integer)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (Sum_{x=a}^{b} f(x), Sum_{x=a + c}^{b + c} f(x - c))
#    core type: ExprTuple
# ...
