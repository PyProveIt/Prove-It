# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, f, n
from proveit.numbers import Add, Interval, Sum, one, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = [n]
expr = ExprTuple(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(zero, one)), Add(Operation(f, [zero]), Operation(f, [one])))
# Out:
# expr: (Sum_{n=0}^{1} f(n), f(0) + f(1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{n=0}^{1} f(n), f(0) + f(1)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{n=0}^{1} f(n), f(0) + f(1))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{n=0}^{1} f(n)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. f(0) + f(1)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (n -> {f(n) if n in {0 .. 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (f(0), f(1))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. n -> {f(n) if n in {0 .. 1}.
#    core type: Lambda
#    parameter: 19
#    body: 10
# 8. f(0)
#    core type: Operation
#    operator: 15
#    operand: 23
# 9. f(1)
#    core type: Operation
#    operator: 15
#    operand: 24
# 10. {f(n) if n in {0 .. 1}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (0)
#     core type: ExprTuple
#     sub-expressions: 23
# 12. (1)
#     core type: ExprTuple
#     sub-expressions: 24
# 13. f(n)
# ...
