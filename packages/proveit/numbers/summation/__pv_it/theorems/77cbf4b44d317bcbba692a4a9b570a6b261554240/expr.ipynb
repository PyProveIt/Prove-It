# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation, a, b, c, f, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Neg, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda([a, b, c], Conditional(Equals(Sum(sub_expr1, Operation(f, sub_expr1), domain = Interval(a, b)), Sum(sub_expr1, Operation(f, [Add(x, Neg(c))]), domain = Interval(Add(a, c), Add(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer))))
# Out:
# expr: (a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b, c\right) \mapsto \left\{\left(\sum_{x=a}^{b} f(x)\right) = \left(\sum_{x=a + c}^{b + c} f(x - c)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b, c) -> {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 51, 52, 53
# 2. {(Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c)) if a in Integer ,  b in Integer ,  c in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{x=a}^{b} f(x)) = (Sum_{x=a + c}^{b + c} f(x - c))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Integer) and (b in Integer) and (c in Integer)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{x=a}^{b} f(x), Sum_{x=a + c}^{b + c} f(x - c))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Integer, b in Integer, c in Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# ...
