# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, a, b, c, f, fx, x
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Lambda(f, Forall([a, b, c], Equals(Sum(sub_expr1, fx, domain = Interval(a, c)), Add(Sum(sub_expr1, fx, domain = Interval(a, b)), Sum(sub_expr1, fx, domain = Interval(Add(b, one), c)))), domain = Integer, condition = And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style()))
# Out:
# expr: f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# f \mapsto \left[\forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left(\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b} f(x)\right) + \left(\sum_{x=b + 1}^{c} f(x)\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]
#    core type: Lambda
#    parameter: 49
#    body: 1
# 1. forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. ((a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 5\n   body: 6
# 5. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 59, 64, 61
# 6. {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. (Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 23
#    operands: 11
# 9. =
#    core type: Literal
#    sub-expressions:
# 10. (Sum_{x=a}^{c} f(x), (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. Sum_{x=a}^{c} f(x)
#     core type: Operation
#     operator: 33
#     operand: 25
# 13. (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))
#     core type: Operation
#     operator: 62
#     operands: 19
# 14. a in Integer
#     core type: Operation
#     operator: 51
#     operands: 20
# 15. b in Integer
#     core type: Operation
#     operator: 51
#     operands: 21
# 16. c in Integer
#     core type: Operation
#     operator: 51
#     operands: 22
# 17. a <= b <= c
#     core type: Operation
#     operator: 23
#     operands: 24
# 18. (x -> {f(x) if x in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 25
# 19. (Sum_{x=a}^{b} f(x), Sum_{x=b + 1}^{c} f(x))
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 20. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 59, 28
# 21. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 64, 28
# 22. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 61, 28
# 23. and
#     core type: Literal
#     sub-expressions:
# 24. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 25. x -> {f(x) if x in {a .. c}.
#     core type: Lambda
#     parameter: 54
#     body: 31
# 26. Sum_{x=a}^{b} f(x)
#     core type: Operation
#     operator: 33
#     operand: 38
# 27. Sum_{x=b + 1}^{c} f(x)
#     core type: Operation
#     operator: 33
#     operand: 39
# 28. Integer
#     core type: Literal
#     sub-expressions:
# 29. a <= b
#     core type: Operation
#     operator: 35
#     operands: 56
# 30. b <= c
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. {f(x) if x in {a .. c}.
#     core type: Conditional
#     value: 45
#     condition: 37
# 32. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 33. Sum
#     core type: Literal
#     sub-expressions:
# 34. (x -> {f(x) if x in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 35. <=
#     core type: Literal
#     sub-expressions:
# 36. (b, c)
#     core type: ExprTuple
#     sub-expressions: 64, 61
# 37. x in {a .. c}
#     core type: Operation
#     operator: 51
#     operands: 40
# 38. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 54
#     body: 41
# 39. x -> {f(x) if x in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 54
#     body: 42
# 40. (x, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 54, 43
# 41. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 45
#     condition: 44
# 42. {f(x) if x in {b + 1 .. c}.
#     core type: Conditional
#     value: 45
#     condition: 46
# 43. {a .. c}
#     core type: Operation
#     operator: 57
#     operands: 47
# 44. x in {a .. b}
#     core type: Operation
#     operator: 51
#     operands: 48
# 45. f(x)
#     core type: Operation
#     operator: 49
#     operand: 54
# 46. x in {b + 1 .. c}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. (a, c)
#     core type: ExprTuple
#     sub-expressions: 59, 61
# 48. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 54, 53
# 49. f
#     core type: Variable
#     sub-expressions:
# 50. (x)
#     core type: ExprTuple
#     sub-expressions: 54
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (x, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 53. {a .. b}
#     core type: Operation
#     operator: 57
#     operands: 56
# 54. x
#     core type: Variable
#     sub-expressions:
# 55. {b + 1 .. c}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. (a, b)
#     core type: ExprTuple
#     sub-expressions: 59, 64
# 57. Interval
#     core type: Literal
#     sub-expressions:
# 58. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 59. a
#     core type: Variable
#     sub-expressions:
# 60. b + 1
#     core type: Operation
#     operator: 62
#     operands: 63
# 61. c
#     core type: Variable
#     sub-expressions:
# 62. +
#     core type: Literal
#     sub-expressions:
# 63. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 64. b
#     core type: Variable
#     sub-expressions:
# 65. 1
#     core type: Literal
#     sub-expressions:
