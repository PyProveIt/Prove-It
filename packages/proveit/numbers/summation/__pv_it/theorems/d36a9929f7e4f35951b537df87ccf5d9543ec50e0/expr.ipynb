# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, R, S, a, f, fa, fx, gy, x, y
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([a], InSet(fa, Complex), domain = R), Equals(Sum([x], fx, domain = R), Sum([y], Operation(f, [gy]), domain = S)))
# Out:
# expr: (forall_{a in R} (f(a) in Complex), Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{a \in R}~\left(f(a) \in \mathbb{C}\right), \sum_{x \in R}~f(x) = \sum_{y \in S}~f(g(y))\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{a in R} (f(a) in Complex), Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{a in R} (f(a) in Complex)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. Sum_{x in R} f(x) = Sum_{y in S} f(g(y))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (a -> {f(a) in Complex if a in R.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{x in R} f(x), Sum_{y in S} f(g(y)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. a -> {f(a) in Complex if a in R.
#    core type: Lambda
#    parameter: 35
#    body: 10
# 8. Sum_{x in R} f(x)
#    core type: Operation
#    operator: 12
#    operand: 16
# 9. Sum_{y in S} f(g(y))
#    core type: Operation
#    operator: 12
#    operand: 17
# 10. {f(a) in Complex if a in R.
#     core type: Conditional
#     value: 14
# ...
