# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Operation, f, g, k, l, m, n
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [l]
sub_expr3 = Interval(m, n)
expr = Forall([m, n], Implies(Forall(sub_expr1, Equals(Operation(f, sub_expr1), Operation(g, sub_expr1)), domain = sub_expr3), Equals(Sum(sub_expr2, Operation(f, sub_expr2), domain = sub_expr3), Sum(sub_expr2, Operation(g, sub_expr2), domain = sub_expr3))), domain = Integer)
# Out:
# expr: forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m, n \in \mathbb{Z}}~\left(\left[\forall_{k \in \{m~\ldotp \ldotp~n\}}~\left(f(k) = g(k)\right)\right] \Rightarrow \left(\left(\sum_{l=m}^{n} f(l)\right) = \left(\sum_{l=m}^{n} g(l)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))
#    core type: Operation
#    operator: 14
#    operand: 2
# 1. ((m, n) -> {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.
#    core type: Lambda
#    parameters: 51\n   body: 3
# 3. {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. [forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (m in Integer) and (n in Integer)
#    core type: Operation
#    operator: 8
#    operands: 9
# ...
