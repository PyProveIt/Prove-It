# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, a, b, c, f, fx, x
from proveit.logic import And, Equals, Forall
from proveit.numbers import Add, Integer, Interval, LessEq, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda(f, Forall([a, b, c], Equals(Sum(sub_expr1, fx, domain = Interval(a, c)), Add(Sum(sub_expr1, fx, domain = Interval(a, b)), Sum(sub_expr1, fx, domain = Interval(Add(b, one), c)))), domain = Integer, condition = And(LessEq(a, b), LessEq(b, c)).with_total_ordering_style())))
# Out:
# expr: (f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f \mapsto \left[\forall_{a, b, c \in \mathbb{Z}~|~a \leq b \leq c}~\left(\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b} f(x)\right) + \left(\sum_{x=b + 1}^{c} f(x)\right)\right)\right)\right]\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. f -> [forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))]
#    core type: Lambda
#    parameter: 50
#    body: 2
# 2. forall_{a, b, c in Integer | a <= b <= c} ((Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (a, b, c) -> {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Lambda
#    parameters: 6\n   body: 7
# 6. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 60, 65, 62
# 7. {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a <= b <= c.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. (Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (a in Integer) and (b in Integer) and (c in Integer) and (a <= b <= c)
#    core type: Operation
#    operator: 24
#    operands: 12
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (Sum_{x=a}^{c} f(x), (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x)))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (a in Integer, b in Integer, c in Integer, a <= b <= c)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 13. Sum_{x=a}^{c} f(x)
#     core type: Operation
#     operator: 34
#     operand: 26
# 14. (Sum_{x=a}^{b} f(x)) + (Sum_{x=b + 1}^{c} f(x))
#     core type: Operation
#     operator: 63
#     operands: 20
# 15. a in Integer
#     core type: Operation
#     operator: 52
#     operands: 21
# 16. b in Integer
#     core type: Operation
#     operator: 52
#     operands: 22
# 17. c in Integer
#     core type: Operation
#     operator: 52
#     operands: 23
# 18. a <= b <= c
#     core type: Operation
#     operator: 24
#     operands: 25
# 19. (x -> {f(x) if x in {a .. c}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 20. (Sum_{x=a}^{b} f(x), Sum_{x=b + 1}^{c} f(x))
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 21. (a, Integer)
#     core type: ExprTuple
#     sub-expressions: 60, 29
# 22. (b, Integer)
#     core type: ExprTuple
#     sub-expressions: 65, 29
# 23. (c, Integer)
#     core type: ExprTuple
#     sub-expressions: 62, 29
# 24. and
#     core type: Literal
#     sub-expressions:
# 25. (a <= b, b <= c)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. x -> {f(x) if x in {a .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 32
# 27. Sum_{x=a}^{b} f(x)
#     core type: Operation
#     operator: 34
#     operand: 39
# 28. Sum_{x=b + 1}^{c} f(x)
#     core type: Operation
#     operator: 34
#     operand: 40
# 29. Integer
#     core type: Literal
#     sub-expressions:
# 30. a <= b
#     core type: Operation
#     operator: 36
#     operands: 57
# 31. b <= c
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. {f(x) if x in {a .. c}.
#     core type: Conditional
#     value: 46
#     condition: 38
# 33. (x -> {f(x) if x in {a .. b}.)
#     core type: ExprTuple
#     sub-expressions: 39
# 34. Sum
#     core type: Literal
#     sub-expressions:
# 35. (x -> {f(x) if x in {b + 1 .. c}.)
#     core type: ExprTuple
#     sub-expressions: 40
# 36. <=
#     core type: Literal
#     sub-expressions:
# 37. (b, c)
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 38. x in {a .. c}
#     core type: Operation
#     operator: 52
#     operands: 41
# 39. x -> {f(x) if x in {a .. b}.
#     core type: Lambda
#     parameter: 55
#     body: 42
# 40. x -> {f(x) if x in {b + 1 .. c}.
#     core type: Lambda
#     parameter: 55
#     body: 43
# 41. (x, {a .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 44
# 42. {f(x) if x in {a .. b}.
#     core type: Conditional
#     value: 46
#     condition: 45
# 43. {f(x) if x in {b + 1 .. c}.
#     core type: Conditional
#     value: 46
#     condition: 47
# 44. {a .. c}
#     core type: Operation
#     operator: 58
#     operands: 48
# 45. x in {a .. b}
#     core type: Operation
#     operator: 52
#     operands: 49
# 46. f(x)
#     core type: Operation
#     operator: 50
#     operand: 55
# 47. x in {b + 1 .. c}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. (a, c)
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 49. (x, {a .. b})
#     core type: ExprTuple
#     sub-expressions: 55, 54
# 50. f
#     core type: Variable
#     sub-expressions:
# 51. (x)
#     core type: ExprTuple
#     sub-expressions: 55
# 52. in
#     core type: Literal
#     sub-expressions:
# 53. (x, {b + 1 .. c})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 54. {a .. b}
#     core type: Operation
#     operator: 58
#     operands: 57
# 55. x
#     core type: Variable
#     sub-expressions:
# 56. {b + 1 .. c}
#     core type: Operation
#     operator: 58
#     operands: 59
# 57. (a, b)
#     core type: ExprTuple
#     sub-expressions: 60, 65
# 58. Interval
#     core type: Literal
#     sub-expressions:
# 59. (b + 1, c)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. b + 1
#     core type: Operation
#     operator: 63
#     operands: 64
# 62. c
#     core type: Variable
#     sub-expressions:
# 63. +
#     core type: Literal
#     sub-expressions:
# 64. (b, 1)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. 1
#     core type: Literal
#     sub-expressions:
