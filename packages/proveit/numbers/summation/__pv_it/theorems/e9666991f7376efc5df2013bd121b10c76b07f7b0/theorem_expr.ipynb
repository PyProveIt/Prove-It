# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#finite_geom_sum">finite_geom_sum</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import finite_geom_sum

# %%
# check that the built expression is the same as the stored expression
assert finite_geom_sum.expr == stored_expr
assert finite_geom_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: finite_geom_sum matches stored_expr")
# Out:
# Passed sanity check: finite_geom_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(finite_geom_sum.latex())
# Out:
# \vdash \forall_{x \in \mathbb{C}, n \in \mathbb{N}^+}~\left(\left(\sum_{m=0}^{n} x^{m}\right) = \frac{1 - x^{n + 1}}{1 - x}\right)

# %%
finite_geom_sum.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
finite_geom_sum.expr_info()
# Out:
# 0. forall_{x in Complex, n in NaturalPos} ((Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, n) -> {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, n) -> {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, n)
#    core type: ExprTuple
#    sub-expressions: 48, 52
# 5. {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6. (Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Complex) and (n in NaturalPos)
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. =
# ...
