# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#same_sums">same_sums</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.summation import same_sums

# %%
# check that the built expression is the same as the stored expression
assert same_sums.expr == stored_expr
assert same_sums.expr._style_id == stored_expr._style_id
print("Passed sanity check: same_sums matches stored_expr")
# Out:
# Passed sanity check: same_sums matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(same_sums.latex())
# Out:
# \vdash \forall_{f, g}~\left[\forall_{m, n \in \mathbb{Z}}~\left(\left[\forall_{k \in \{m~\ldotp \ldotp~n\}}~\left(f(k) = g(k)\right)\right] \Rightarrow \left(\left(\sum_{l=m}^{n} f(l)\right) = \left(\sum_{l=m}^{n} g(l)\right)\right)\right)\right]

# %%
same_sums.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
same_sums.expr_info()
# Out:
# 0. forall_{f, g} [forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))]
#    core type: Operation
#    operator: 18
#    operand: 2
# 1. ((f, g) -> [forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (f, g) -> [forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (f, g)
#    core type: ExprTuple
#    sub-expressions: 46, 47
# 4. forall_{m, n in Integer} ([forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))))
#    core type: Operation
#    operator: 18
#    operand: 6
# 5. ((m, n) -> {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.)
#    core type: ExprTuple
# ...
