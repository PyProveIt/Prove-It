# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, f, g, l, m, n
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = Interval(m, n)
expr = ExprTuple(Sum(sub_expr1, Operation(f, sub_expr1), domain = sub_expr2), Sum(sub_expr1, Operation(g, sub_expr1), domain = sub_expr2))
# Out:
# expr: (Sum_{l=m}^{n} f(l), Sum_{l=m}^{n} g(l))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=m}^{n} f(l), \sum_{l=m}^{n} g(l)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=m}^{n} f(l), Sum_{l=m}^{n} g(l))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l=m}^{n} f(l)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. Sum_{l=m}^{n} g(l)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (l -> {f(l) if l in {m .. n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (l -> {g(l) if l in {m .. n}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. l -> {f(l) if l in {m .. n}.
#    core type: Lambda
#    parameter: 18
#    body: 8
# 7. l -> {g(l) if l in {m .. n}.
#    core type: Lambda
#    parameter: 18
#    body: 9
# 8. {f(l) if l in {m .. n}.
#    core type: Conditional
#    value: 10
#    condition: 12
# 9. {g(l) if l in {m .. n}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. f(l)
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. g(l)
#     core type: Operation
#     operator: 14
# ...
