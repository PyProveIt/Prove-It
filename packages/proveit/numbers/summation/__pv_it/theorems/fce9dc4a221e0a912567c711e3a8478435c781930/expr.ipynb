# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, j, k, m, x
from proveit.numbers import Add, Exp, Interval, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([m], Exp(x, m), domain = Interval(zero, k)), frac(Add(Exp(x, j), Neg(Exp(x, Add(k, one)))), Add(one, Neg(x))))
# Out:
# expr: (Sum_{m=0}^{k} x^{m}, (x^{j} - x^{k + 1}) / (1 - x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{m=0}^{k} x^{m}, \frac{x^{j} - x^{k + 1}}{1 - x}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{m=0}^{k} x^{m}, (x^{j} - x^{k + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{m=0}^{k} x^{m}
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (x^{j} - x^{k + 1}) / (1 - x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (m -> {x^{m} if m in {0 .. k}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (x^{j} - x^{k + 1}, 1 - x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. m -> {x^{m} if m in {0 .. k}.
#    core type: Lambda
#    parameter: 25
#    body: 10
# 8. x^{j} - x^{k + 1}
#    core type: Operation
#    operator: 36
#    operands: 11
# 9. 1 - x
#    core type: Operation
#    operator: 36
#    operands: 12
# 10. {x^{m} if m in {0 .. k}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (x^{j}, -x^{k + 1})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# ...
