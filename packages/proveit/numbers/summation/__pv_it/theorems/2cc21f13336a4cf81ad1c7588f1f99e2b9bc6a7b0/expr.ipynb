# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, b, c, fx, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Integer, Interval, Less, LessEq, Neg, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Conditional(Equals(Sum(sub_expr1, fx, domain = Interval(a, c)), Add(Sum(sub_expr1, fx, domain = Interval(a, Add(b, Neg(one)))), Sum(sub_expr1, fx, domain = Interval(b, c)))), And(InSet(a, Integer), InSet(b, Integer), InSet(c, Integer), Less(a, b), LessEq(b, c)))
# Out:
# expr: {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sum_{x=a}^{c} f(x)\right) = \left(\left(\sum_{x=a}^{b - 1} f(x)\right) + \left(\sum_{x=b}^{c} f(x)\right)\right) \textrm{ if } a \in \mathbb{Z} ,  b \in \mathbb{Z} ,  c \in \mathbb{Z} ,  a < b ,  b \leq c\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))) if a in Integer ,  b in Integer ,  c in Integer ,  a < b ,  b <= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{x=a}^{c} f(x)) = ((Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (a in Integer) and (b in Integer) and (c in Integer) and (a < b) and (b <= c)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{x=a}^{c} f(x), (Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (a in Integer, b in Integer, c in Integer, a < b, b <= c)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11, 12, 13
# 7. Sum_{x=a}^{c} f(x)
#    core type: Operation
#    operator: 28
#    operand: 22
# 8. (Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))
# ...
