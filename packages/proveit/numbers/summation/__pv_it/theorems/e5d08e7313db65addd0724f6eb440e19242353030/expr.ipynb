# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, S, fx, gx, x
from proveit.logic import InSet
from proveit.numbers import LessEq

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Conditional(LessEq(fx, gx), InSet(x, S))))
# Out:
# expr: (x -> {f(x) <= g(x) if x in S.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left\{f(x) \leq g(x) \textrm{ if } x \in S\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> {f(x) <= g(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> {f(x) <= g(x) if x in S.
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. {f(x) <= g(x) if x in S.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. f(x) <= g(x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. x in S
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (f(x), g(x))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (x, S)
#    core type: ExprTuple
#    sub-expressions: 15, 11
# 9. f(x)
#    core type: Operation
#    operator: 12
#    operand: 15
# 10. g(x)
#     core type: Operation
#     operator: 13
#     operand: 15
# 11. S
#     core type: Variable
#     sub-expressions:
# 12. f
#     core type: Variable
#     sub-expressions:
# 13. g
#     core type: Variable
#     sub-expressions:
# 14. (x)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. x
#     core type: Variable
#     sub-expressions:
