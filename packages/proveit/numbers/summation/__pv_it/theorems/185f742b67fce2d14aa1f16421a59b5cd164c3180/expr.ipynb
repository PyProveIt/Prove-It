# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, fx, gx, x
from proveit.logic import Forall
from proveit.numbers import LessEq

# %%
# build up the expression from sub-expressions
expr = Forall([x], LessEq(fx, gx), domain = S)
# Out:
# expr: forall_{x in S} (f(x) <= g(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in S}~\left(f(x) \leq g(x)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in S} (f(x) <= g(x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {f(x) <= g(x) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {f(x) <= g(x) if x in S.
#    core type: Lambda
#    parameter: 17
#    body: 4
# 4. {f(x) <= g(x) if x in S.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. f(x) <= g(x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (f(x), g(x))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (x, S)
#     core type: ExprTuple
#     sub-expressions: 17, 13
# 11. f(x)
#     core type: Operation
#     operator: 14
#     operand: 17
# 12. g(x)
#     core type: Operation
#     operator: 15
#     operand: 17
# 13. S
#     core type: Variable
#     sub-expressions:
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. g
#     core type: Variable
#     sub-expressions:
# 16. (x)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x
#     core type: Variable
#     sub-expressions:
