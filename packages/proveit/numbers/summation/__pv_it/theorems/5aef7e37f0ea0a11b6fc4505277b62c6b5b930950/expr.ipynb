# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, m, n, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Complex, Exp, Interval, NaturalPos, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, n], Conditional(Equals(Sum([m], Exp(x, m), domain = Interval(zero, n)), frac(Add(one, Neg(Exp(x, Add(n, one)))), Add(one, Neg(x)))), And(InSet(x, Complex), InSet(n, NaturalPos)))))
# Out:
# expr: ((x, n) -> {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, n\right) \mapsto \left\{\left(\sum_{m=0}^{n} x^{m}\right) = \frac{1 - x^{n + 1}}{1 - x} \textrm{ if } x \in \mathbb{C} ,  n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, n) -> {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, n) -> {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, n)
#    core type: ExprTuple
#    sub-expressions: 46, 50
# 3. {(Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x)) if x in Complex ,  n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. (Sum_{m=0}^{n} x^{m}) = ((1 - x^{n + 1}) / (1 - x))
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (x in Complex) and (n in NaturalPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (Sum_{m=0}^{n} x^{m}, (1 - x^{n + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. and
#    core type: Literal
#    sub-expressions:
# ...
