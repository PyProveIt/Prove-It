# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, j, k, m, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Integer, Interval, Less, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([j, k], Conditional(Equals(Sum([m], Exp(x, m), domain = Interval(zero, k)), frac(Add(Exp(x, j), Neg(Exp(x, Add(k, one)))), Add(one, Neg(x)))), And(InSet(j, Integer), InSet(k, Integer), Less(j, k)))))
# Out:
# expr: ((j, k) -> {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(j, k\right) \mapsto \left\{\left(\sum_{m=0}^{k} x^{m}\right) = \frac{x^{j} - x^{k + 1}}{1 - x} \textrm{ if } j \in \mathbb{Z} ,  k \in \mathbb{Z} ,  j < k\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((j, k) -> {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (j, k) -> {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.
#    core type: Lambda
#    parameters: 21\n   body: 2
# 2. {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (j in Integer) and (k in Integer) and (j < k)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{m=0}^{k} x^{m}, (x^{j} - x^{k + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (j in Integer, k in Integer, j < k)
# ...
