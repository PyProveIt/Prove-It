# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, m, n, x
from proveit.numbers import Add, Exp, Interval, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([m], Exp(x, m), domain = Interval(zero, n)), frac(Add(one, Neg(Exp(x, Add(n, one)))), Add(one, Neg(x))))
# Out:
# expr: (Sum_{m=0}^{n} x^{m}, (1 - x^{n + 1}) / (1 - x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{m=0}^{n} x^{m}, \frac{1 - x^{n + 1}}{1 - x}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{m=0}^{n} x^{m}, (1 - x^{n + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{m=0}^{n} x^{m}
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (1 - x^{n + 1}) / (1 - x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (m -> {x^{m} if m in {0 .. n}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (1 - x^{n + 1}, 1 - x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. m -> {x^{m} if m in {0 .. n}.
#    core type: Lambda
#    parameter: 23
#    body: 10
# 8. 1 - x^{n + 1}
#    core type: Operation
#    operator: 33
#    operands: 11
# 9. 1 - x
#    core type: Operation
#    operator: 33
#    operands: 12
# 10. {x^{m} if m in {0 .. n}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (1, -x^{n + 1})
#     core type: ExprTuple
#     sub-expressions: 36, 15
# 12. (1, -x)
#     core type: ExprTuple
#     sub-expressions: 36, 16
# 13. x^{m}
#     core type: Operation
#     operator: 28
#     operands: 17
# 14. m in {0 .. n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. -x^{n + 1}
#     core type: Operation
#     operator: 21
#     operand: 25
# 16. -x
#     core type: Operation
#     operator: 21
#     operand: 31
# 17. (x, m)
#     core type: ExprTuple
#     sub-expressions: 31, 23
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (m, {0 .. n})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. (x^{n + 1})
#     core type: ExprTuple
#     sub-expressions: 25
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (x)
#     core type: ExprTuple
#     sub-expressions: 31
# 23. m
#     core type: Variable
#     sub-expressions:
# 24. {0 .. n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. x^{n + 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (0, n)
#     core type: ExprTuple
#     sub-expressions: 30, 35
# 28. Exp
#     core type: Literal
#     sub-expressions:
# 29. (x, n + 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 30. 0
#     core type: Literal
#     sub-expressions:
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. n + 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (n, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. 1
#     core type: Literal
#     sub-expressions:
