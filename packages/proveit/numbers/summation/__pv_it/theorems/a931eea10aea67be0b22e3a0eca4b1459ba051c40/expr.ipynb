# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, f, fa, fx, x
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Integer, Interval, Less, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Forall([f], Forall([a, b], Equals(Sum(sub_expr1, fx, domain = Interval(a, b)), Add(fa, Sum(sub_expr1, fx, domain = Interval(Add(a, one), b)))), domain = Integer, condition = Less(a, b)))
# Out:
# expr: forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f}~\left[\forall_{a, b \in \mathbb{Z}~|~a < b}~\left(\left(\sum_{x=a}^{b} f(x)\right) = \left(f(a) + \left(\sum_{x=a + 1}^{b} f(x)\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))]
#    core type: Operation
#    operator: 4
#    operand: 2
# 1. (f -> [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. f -> [forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))]
#    core type: Lambda
#    parameter: 40
#    body: 3
# 3. forall_{a, b in Integer | a < b} ((Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a, b) -> {(Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))) if a in Integer ,  b in Integer ,  a < b.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (a, b) -> {(Sum_{x=a}^{b} f(x)) = (f(a) + (Sum_{x=a + 1}^{b} f(x))) if a in Integer ,  b in Integer ,  a < b.
# ...
