# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, fx, x
from proveit.numbers import Add, Interval, Neg, Sum, one

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = Add(Sum(sub_expr1, fx, domain = Interval(a, Add(b, Neg(one)))), Sum(sub_expr1, fx, domain = Interval(b, c)))
# Out:
# expr: (Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{x=a}^{b - 1} f(x)\right) + \left(\sum_{x=b}^{c} f(x)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{x=a}^{b - 1} f(x)) + (Sum_{x=b}^{c} f(x))
#    core type: Operation
#    operator: 28
#    operands: 1
# 1. (Sum_{x=a}^{b - 1} f(x), Sum_{x=b}^{c} f(x))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{x=a}^{b - 1} f(x)
#    core type: Operation
#    operator: 5
#    operand: 7
# 3. Sum_{x=b}^{c} f(x)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (x -> {f(x) if x in {a .. b - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (x -> {f(x) if x in {b .. c}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. x -> {f(x) if x in {a .. b - 1}.
#    core type: Lambda
#    parameter: 20
#    body: 9
# 8. x -> {f(x) if x in {b .. c}.
#    core type: Lambda
#    parameter: 20
#    body: 10
# 9. {f(x) if x in {a .. b - 1}.
#    core type: Conditional
#    value: 12
#    condition: 11
# 10. {f(x) if x in {b .. c}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. x in {a .. b - 1}
#     core type: Operation
#     operator: 17
#     operands: 14
# 12. f(x)
#     core type: Operation
#     operator: 15
#     operand: 20
# 13. x in {b .. c}
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (x, {a .. b - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 15. f
#     core type: Variable
#     sub-expressions:
# 16. (x)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (x, {b .. c})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. {a .. b - 1}
#     core type: Operation
#     operator: 23
#     operands: 22
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. {b .. c}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. (a, b - 1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Interval
#     core type: Literal
#     sub-expressions:
# 24. (b, c)
#     core type: ExprTuple
#     sub-expressions: 30, 27
# 25. a
#     core type: Variable
#     sub-expressions:
# 26. b - 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. c
#     core type: Variable
#     sub-expressions:
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (b, -1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. b
#     core type: Variable
#     sub-expressions:
# 31. -1
#     core type: Operation
#     operator: 32
#     operand: 34
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. (1)
#     core type: ExprTuple
#     sub-expressions: 34
# 34. 1
#     core type: Literal
#     sub-expressions:
