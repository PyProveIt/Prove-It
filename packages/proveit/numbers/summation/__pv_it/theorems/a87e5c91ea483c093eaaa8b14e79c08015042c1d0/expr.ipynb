# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, P, Px, Q, Qx, x
from proveit.logic import Forall, Implies, InSet
from proveit.numbers import NaturalPos, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [x]
expr = ExprTuple(Lambda([P, Q], Implies(Forall(sub_expr1, InSet(Px, NaturalPos), condition = Qx), InSet(Sum(sub_expr1, Px, condition = Qx), NaturalPos))))
# Out:
# expr: ((P, Q) -> ([forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(P, Q\right) \mapsto \left(\left[\forall_{x~|~Q(x)}~\left(P(x) \in \mathbb{N}^+\right)\right] \Rightarrow \left(\sum_{x~|~Q(x)}~P(x) \in \mathbb{N}^+\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((P, Q) -> ([forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (P, Q) -> ([forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (P, Q)
#    core type: ExprTuple
#    sub-expressions: 24, 25
# 3. [forall_{x | Q(x)} (P(x) in NaturalPos)] => (Sum_{x | Q(x)} P(x) in NaturalPos)
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{x | Q(x)} (P(x) in NaturalPos), Sum_{x | Q(x)} P(x) in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. forall_{x | Q(x)} (P(x) in NaturalPos)
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. Sum_{x | Q(x)} P(x) in NaturalPos
#    core type: Operation
#    operator: 18
#    operands: 10
# 8. forall
#    core type: Literal
#    sub-expressions:
# ...
