# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation, f, g, k, l, m, n
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [l]
sub_expr3 = Interval(m, n)
expr = Lambda([m, n], Conditional(Implies(Forall(sub_expr1, Equals(Operation(f, sub_expr1), Operation(g, sub_expr1)), domain = sub_expr3), Equals(Sum(sub_expr2, Operation(f, sub_expr2), domain = sub_expr3), Sum(sub_expr2, Operation(g, sub_expr2), domain = sub_expr3))), And(InSet(m, Integer), InSet(n, Integer))))
# Out:
# expr: (m, n) -> {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(m, n\right) \mapsto \left\{\left[\forall_{k \in \{m~\ldotp \ldotp~n\}}~\left(f(k) = g(k)\right)\right] \Rightarrow \left(\left(\sum_{l=m}^{n} f(l)\right) = \left(\sum_{l=m}^{n} g(l)\right)\right) \textrm{ if } m \in \mathbb{Z} ,  n \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (m, n) -> {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.
#    core type: Lambda
#    parameters: 49\n   body: 1
# 1. {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. [forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (m in Integer) and (n in Integer)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. (forall_{k in {m .. n}} (f(k) = g(k)), (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (m in Integer, n in Integer)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. forall_{k in {m .. n}} (f(k) = g(k))
#    core type: Operation
#    operator: 12
#    operand: 17
# 9. (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))
#    core type: Operation
#    operator: 29
#    operands: 14
# 10. m in Integer
#     core type: Operation
#     operator: 43
#     operands: 15
# 11. n in Integer
#     core type: Operation
#     operator: 43
#     operands: 16
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. (k -> {f(k) = g(k) if k in {m .. n}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. (Sum_{l=m}^{n} f(l), Sum_{l=m}^{n} g(l))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (m, Integer)
#     core type: ExprTuple
#     sub-expressions: 50, 20
# 16. (n, Integer)
#     core type: ExprTuple
#     sub-expressions: 51, 20
# 17. k -> {f(k) = g(k) if k in {m .. n}.
#     core type: Lambda
#     parameter: 45
#     body: 21
# 18. Sum_{l=m}^{n} f(l)
#     core type: Operation
#     operator: 23
#     operand: 27
# 19. Sum_{l=m}^{n} g(l)
#     core type: Operation
#     operator: 23
#     operand: 28
# 20. Integer
#     core type: Literal
#     sub-expressions:
# 21. {f(k) = g(k) if k in {m .. n}.
#     core type: Conditional
#     value: 25
#     condition: 26
# 22. (l -> {f(l) if l in {m .. n}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 23. Sum
#     core type: Literal
#     sub-expressions:
# 24. (l -> {g(l) if l in {m .. n}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. f(k) = g(k)
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. k in {m .. n}
#     core type: Operation
#     operator: 43
#     operands: 31
# 27. l -> {f(l) if l in {m .. n}.
#     core type: Lambda
#     parameter: 46
#     body: 32
# 28. l -> {g(l) if l in {m .. n}.
#     core type: Lambda
#     parameter: 46
#     body: 33
# 29. =
#     core type: Literal
#     sub-expressions:
# 30. (f(k), g(k))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. (k, {m .. n})
#     core type: ExprTuple
#     sub-expressions: 45, 47
# 32. {f(l) if l in {m .. n}.
#     core type: Conditional
#     value: 36
#     condition: 38
# 33. {g(l) if l in {m .. n}.
#     core type: Conditional
#     value: 37
#     condition: 38
# 34. f(k)
#     core type: Operation
#     operator: 40
#     operand: 45
# 35. g(k)
#     core type: Operation
#     operator: 41
#     operand: 45
# 36. f(l)
#     core type: Operation
#     operator: 40
#     operand: 46
# 37. g(l)
#     core type: Operation
#     operator: 41
#     operand: 46
# 38. l in {m .. n}
#     core type: Operation
#     operator: 43
#     operands: 44
# 39. (k)
#     core type: ExprTuple
#     sub-expressions: 45
# 40. f
#     core type: Variable
#     sub-expressions:
# 41. g
#     core type: Variable
#     sub-expressions:
# 42. (l)
#     core type: ExprTuple
#     sub-expressions: 46
# 43. in
#     core type: Literal
#     sub-expressions:
# 44. (l, {m .. n})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 45. k
#     core type: Variable
#     sub-expressions:
# 46. l
#     core type: Variable
#     sub-expressions:
# 47. {m .. n}
#     core type: Operation
#     operator: 48
#     operands: 49
# 48. Interval
#     core type: Literal
#     sub-expressions:
# 49. (m, n)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. m
#     core type: Variable
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
