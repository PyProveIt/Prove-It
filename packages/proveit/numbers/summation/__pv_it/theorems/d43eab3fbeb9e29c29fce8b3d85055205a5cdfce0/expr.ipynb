# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Operation, R, S, a, f, fa, fx, g, gy, x, y
from proveit.logic import Equals, Forall, Implies, InSet, SetOfAll
from proveit.numbers import Complex, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Lambda([f, g, R, S], Conditional(Implies(Forall([a], InSet(fa, Complex), domain = R), Equals(Sum([x], fx, domain = R), Sum(sub_expr1, Operation(f, [gy]), domain = S))), Equals(SetOfAll(sub_expr1, gy, domain = S), R)))
# Out:
# expr: (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f, g, R, S\right) \mapsto \left\{\left[\forall_{a \in R}~\left(f(a) \in \mathbb{C}\right)\right] \Rightarrow \left(\sum_{x \in R}~f(x) = \sum_{y \in S}~f(g(y))\right) \textrm{ if } \left\{g(y)\right\}_{y \in S} = R\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f, g, R, S) -> {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (f, g, R, S)
#    core type: ExprTuple
#    sub-expressions: 43, 52, 49, 51
# 2. {[forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y))) if {g(y)}_{y in S} = R.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. [forall_{a in R} (f(a) in Complex)] => (Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. {g(y)}_{y in S} = R
#    core type: Operation
#    operator: 13
#    operands: 7
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{a in R} (f(a) in Complex), Sum_{x in R} f(x) = Sum_{y in S} f(g(y)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ({g(y)}_{y in S}, R)
#    core type: ExprTuple
#    sub-expressions: 10, 49
# 8. forall_{a in R} (f(a) in Complex)
# ...
