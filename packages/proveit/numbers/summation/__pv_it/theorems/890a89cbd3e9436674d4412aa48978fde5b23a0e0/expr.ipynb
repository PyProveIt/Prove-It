# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, j, k, m, x
from proveit.logic import And, Equals, InSet
from proveit.numbers import Add, Exp, Integer, Interval, Less, Neg, Sum, frac, one, zero

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Sum([m], Exp(x, m), domain = Interval(zero, k)), frac(Add(Exp(x, j), Neg(Exp(x, Add(k, one)))), Add(one, Neg(x)))), And(InSet(j, Integer), InSet(k, Integer), Less(j, k)))
# Out:
# expr: {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(\sum_{m=0}^{k} x^{m}\right) = \frac{x^{j} - x^{k + 1}}{1 - x} \textrm{ if } j \in \mathbb{Z} ,  k \in \mathbb{Z} ,  j < k\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x)) if j in Integer ,  k in Integer ,  j < k.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (Sum_{m=0}^{k} x^{m}) = ((x^{j} - x^{k + 1}) / (1 - x))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (j in Integer) and (k in Integer) and (j < k)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (Sum_{m=0}^{k} x^{m}, (x^{j} - x^{k + 1}) / (1 - x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (j in Integer, k in Integer, j < k)
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 7. Sum_{m=0}^{k} x^{m}
#    core type: Operation
#    operator: 12
#    operand: 20
# 8. (x^{j} - x^{k + 1}) / (1 - x)
#    core type: Operation
#    operator: 14
#    operands: 15
# 9. j in Integer
#    core type: Operation
#    operator: 33
#    operands: 16
# 10. k in Integer
# ...
