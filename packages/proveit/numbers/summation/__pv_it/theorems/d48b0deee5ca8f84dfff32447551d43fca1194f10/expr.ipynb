# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.summation</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Operation, f, g, k, l, m, n
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = [l]
sub_expr3 = Interval(m, n)
expr = Conditional(Implies(Forall(sub_expr1, Equals(Operation(f, sub_expr1), Operation(g, sub_expr1)), domain = sub_expr3), Equals(Sum(sub_expr2, Operation(f, sub_expr2), domain = sub_expr3), Sum(sub_expr2, Operation(g, sub_expr2), domain = sub_expr3))), And(InSet(m, Integer), InSet(n, Integer)))
# Out:
# expr: {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left[\forall_{k \in \{m~\ldotp \ldotp~n\}}~\left(f(k) = g(k)\right)\right] \Rightarrow \left(\left(\sum_{l=m}^{n} f(l)\right) = \left(\sum_{l=m}^{n} g(l)\right)\right) \textrm{ if } m \in \mathbb{Z} ,  n \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {[forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))) if m in Integer ,  n in Integer.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. [forall_{k in {m .. n}} (f(k) = g(k))] => ((Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (m in Integer) and (n in Integer)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{k in {m .. n}} (f(k) = g(k)), (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l)))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (m in Integer, n in Integer)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. forall_{k in {m .. n}} (f(k) = g(k))
#    core type: Operation
#    operator: 11
#    operand: 16
# 8. (Sum_{l=m}^{n} f(l)) = (Sum_{l=m}^{n} g(l))
#    core type: Operation
#    operator: 28
#    operands: 13
# ...
