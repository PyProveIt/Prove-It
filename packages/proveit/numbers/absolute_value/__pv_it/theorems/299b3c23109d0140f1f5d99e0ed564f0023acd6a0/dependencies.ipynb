# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#abs_complex_closure_non_neg_real">abs_complex_closure_non_neg_real</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/abs_complex_closure_non_neg_real/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.numbers.absolute_value import abs_complex_closure_non_neg_real

# %%
# %dependencies abs_complex_closure_non_neg_real
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on abs_complex_closure_non_neg_real</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../physics/quantum/QPE/_theory_nbs_/proofs/all_abs_alpha_l_are_nonneg/thm_proof.ipynb">proveit.physics.quantum.QPE.all_abs_alpha_l_are_nonneg</a></dt><dd><a class="ProveItLink" href="../../../../../physics/quantum/QPE/__pv_it/theorems/8acf9f942e1e2e52b5e971bc715800a9d040ac790/expr.ipynb"><img src="../../../../../physics/quantum/QPE/__pv_it/theorems/8acf9f942e1e2e52b5e971bc715800a9d040ac790/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
