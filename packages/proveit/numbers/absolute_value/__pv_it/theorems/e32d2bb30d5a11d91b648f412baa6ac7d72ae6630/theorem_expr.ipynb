# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#complex_unit_length">complex_unit_length</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.numbers.absolute_value import complex_unit_length

# %%
# check that the built expression is the same as the stored expression
assert complex_unit_length.expr == stored_expr
assert complex_unit_length.expr._style_id == stored_expr._style_id
print("Passed sanity check: complex_unit_length matches stored_expr")
# Out:
# Passed sanity check: complex_unit_length matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(complex_unit_length.latex())
# Out:
# \vdash \forall_{\theta \in \mathbb{R}}~\left(\left|\mathsf{e}^{\mathsf{i} \cdot \theta}\right| = 1\right)

# %%
complex_unit_length.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
complex_unit_length.expr_info()
# Out:
# 0. forall_{theta in Real} (|e^{i * theta}| = 1)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (theta -> {|e^{i * theta}| = 1 if theta in Real.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. theta -> {|e^{i * theta}| = 1 if theta in Real.
#    core type: Lambda
#    parameter: 24
#    body: 4
# 4. {|e^{i * theta}| = 1 if theta in Real.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |e^{i * theta}| = 1
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. theta in Real
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|e^{i * theta}|, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (theta, Real)
#     core type: ExprTuple
#     sub-expressions: 24, 13
# 11. |e^{i * theta}|
#     core type: Operation
#     operator: 14
#     operand: 16
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. Real
#     core type: Literal
#     sub-expressions:
# 14. Abs
#     core type: Literal
#     sub-expressions:
# 15. (e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 16
# 16. e^{i * theta}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Exp
#     core type: Literal
#     sub-expressions:
# 18. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. e
#     core type: Literal
#     sub-expressions:
# 20. i * theta
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. i
#     core type: Literal
#     sub-expressions:
# 24. theta
#     core type: Variable
#     sub-expressions:
