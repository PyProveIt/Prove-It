# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, k, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.logic import Equals, Forall
from proveit.numbers import Abs, Complex, Mult, one

# %%
# build up the expression from sub-expressions
expr = Forall([x_1_to_n], Equals(Abs(Mult(x_1_to_n)), Mult(ExprRange(k, Abs(IndexedVar(x, k)), one, n))), domain = Complex)
# Out:
# expr: forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x_{1}, \ldots, x_{n} \in \mathbb{C}}~\left(\left|x_{1} \cdot \ldots \cdot x_{n}\right| = \left(\left|x_{1}\right| \cdot \ldots \cdot \left|x_{n}\right|\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x_{1}, ..x_{_a}.., x_{n}) -> {|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|) if (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x_{1}, ..x_{_a}.., x_{n}) -> {|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|) if (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex).
#    core type: Lambda
#    parameters: 21\n   body: 4
# 4. {|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|) if (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|x_{1} * ..x_{_a}.. * x_{n}|, |x_{1}| * ..|x_{k}|.. * |x_{n}|)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (x_{1} in Complex, ..x_{_a} in Complex.., x_{n} in Complex)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. |x_{1} * ..x_{_a}.. * x_{n}|
#     core type: Operation
#     operator: 31
#     operand: 17
# 12. |x_{1}| * ..|x_{k}|.. * |x_{n}|
#     core type: Operation
#     operator: 20
#     operands: 15
# 13. (x_{1} in Complex), ..(x_{_a} in Complex).., (x_{n} in Complex)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 29
#     end_index: 30
# 14. (x_{1} * ..x_{_a}.. * x_{n})
#     core type: ExprTuple
#     sub-expressions: 17
# 15. (|x_{1}|, ..|x_{k}|.., |x_{n}|)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. _a -> (x_{_a} in Complex)
#     core type: Lambda
#     parameter: 38
#     body: 19
# 17. x_{1} * ..x_{_a}.. * x_{n}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. |x_{1}|, ..|x_{k}|.., |x_{n}|
#     core type: ExprRange
#     lambda_map: 22
#     start_index: 29
#     end_index: 30
# 19. x_{_a} in Complex
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (x_{1}, ..x_{_a}.., x_{n})
#     core type: ExprTuple
#     sub-expressions: 25
# 22. k -> |x_{k}|
#     core type: Lambda
#     parameter: 39
#     body: 26
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (x_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 33, 27
# 25. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 28
#     start_index: 29
#     end_index: 30
# 26. |x_{k}|
#     core type: Operation
#     operator: 31
#     operand: 34
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. _a -> x_{_a}
#     core type: Lambda
#     parameter: 38
#     body: 33
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. n
#     core type: Variable
#     sub-expressions:
# 31. Abs
#     core type: Literal
#     sub-expressions:
# 32. (x_{k})
#     core type: ExprTuple
#     sub-expressions: 34
# 33. x_{_a}
#     core type: IndexedVar
# variable: 36
# index: 38
# 34. x_{k}
#     core type: IndexedVar
# variable: 36
# index: 39
# 35. (_a)
#     core type: ExprTuple
#     sub-expressions: 38
# 36. x
#     core type: Variable
#     sub-expressions:
# 37. (k)
#     core type: ExprTuple
#     sub-expressions: 39
# 38. _a
#     core type: Variable
#     sub-expressions:
# 39. k
#     core type: Variable
#     sub-expressions:
