# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, Variable, k, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.logic import And, InSet
from proveit.numbers import Abs, Add, Complex, LessEq, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(LessEq(Abs(Add(x_1_to_n)), Add(ExprRange(k, Abs(IndexedVar(x, k)), one, n))), And(ExprRange(sub_expr1, InSet(IndexedVar(x, sub_expr1), Complex), one, n)))
# Out:
# expr: {|x_{1} + ..x_{_a}.. + x_{n}| <= (|x_{1}| + ..|x_{k}|.. + |x_{n}|) if (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|x_{1} + \ldots + x_{n}\right| \leq \left(\left|x_{1}\right| + \ldots + \left|x_{n}\right|\right) \textrm{ if } \left(x_{1} \in \mathbb{C}\right) \land \ldots \land \left(x_{n} \in \mathbb{C}\right)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|x_{1} + ..x_{_a}.. + x_{n}| <= (|x_{1}| + ..|x_{k}|.. + |x_{n}|) if (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |x_{1} + ..x_{_a}.. + x_{n}| <= (|x_{1}| + ..|x_{k}|.. + |x_{n}|)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x_{1} in Complex) and ..(x_{_a} in Complex).. and (x_{n} in Complex)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=
#    core type: Literal
#    sub-expressions:
# 4. (|x_{1} + ..x_{_a}.. + x_{n}|, |x_{1}| + ..|x_{k}|.. + |x_{n}|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x_{1} in Complex, ..x_{_a} in Complex.., x_{n} in Complex)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. |x_{1} + ..x_{_a}.. + x_{n}|
#    core type: Operation
#    operator: 27
#    operand: 13
# 8. |x_{1}| + ..|x_{k}|.. + |x_{n}|
#    core type: Operation
#    operator: 16
# ...
