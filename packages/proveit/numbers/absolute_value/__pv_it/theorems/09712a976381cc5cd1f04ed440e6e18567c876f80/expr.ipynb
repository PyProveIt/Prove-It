# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, c
from proveit.logic import And, Forall
from proveit.numbers import Abs, Less, Neg

# %%
# build up the expression from sub-expressions
expr = Forall([a, c], Less(Abs(a), c), condition = And(Less(Neg(c), a), Less(a, c)).with_total_ordering_style())
# Out:
# expr: forall_{a, c | (-c) < a < c} (|a| < c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, c~|~\left(-c\right) < a < c}~\left(\left|a\right| < c\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, c | (-c) < a < c} (|a| < c)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, c) -> {|a| < c if (-c) < a ,  a < c.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, c) -> {|a| < c if (-c) < a ,  a < c.
#    core type: Lambda
#    parameters: 17\n   body: 4
# 4. {|a| < c if (-c) < a ,  a < c.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |a| < c
#    core type: Operation
#    operator: 16
#    operands: 7
# 6. (-c) < a < c
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (|a|, c)
#    core type: ExprTuple
#    sub-expressions: 10, 22
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. ((-c) < a, a < c)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. |a|
#     core type: Operation
#     operator: 13
#     operand: 19
# 11. (-c) < a
#     core type: Operation
#     operator: 16
#     operands: 15
# 12. a < c
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. Abs
#     core type: Literal
#     sub-expressions:
# 14. (a)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. (-c, a)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. <
#     core type: Literal
#     sub-expressions:
# 17. (a, c)
#     core type: ExprTuple
#     sub-expressions: 19, 22
# 18. -c
#     core type: Operation
#     operator: 20
#     operand: 22
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (c)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. c
#     core type: Variable
#     sub-expressions:
