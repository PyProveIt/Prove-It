# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, r, theta
from proveit.logic import And, Equals, InSet
from proveit.numbers import Abs, Exp, Mult, Real, e, i

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(Abs(Mult(r, Exp(e, Mult(i, theta)))), Abs(r)), And(InSet(r, Real), InSet(theta, Real)))
# Out:
# expr: {|r * e^{i * theta}| = |r| if r in Real ,  theta in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|r \cdot \mathsf{e}^{\mathsf{i} \cdot \theta}\right| = \left|r\right| \textrm{ if } r \in \mathbb{R} ,  \theta \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|r * e^{i * theta}| = |r| if r in Real ,  theta in Real.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |r * e^{i * theta}| = |r|
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (r in Real) and (theta in Real)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (|r * e^{i * theta}|, |r|)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (r in Real, theta in Real)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. |r * e^{i * theta}|
#    core type: Operation
#    operator: 12
#    operand: 17
# 8. |r|
#    core type: Operation
#    operator: 12
#    operand: 20
# 9. r in Real
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. theta in Real
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. (r * e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 17
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. (r)
#     core type: ExprTuple
#     sub-expressions: 20
# 14. (r, Real)
#     core type: ExprTuple
#     sub-expressions: 20, 18
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (theta, Real)
#     core type: ExprTuple
#     sub-expressions: 29, 18
# 17. r * e^{i * theta}
#     core type: Operation
#     operator: 26
#     operands: 19
# 18. Real
#     core type: Literal
#     sub-expressions:
# 19. (r, e^{i * theta})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. r
#     core type: Variable
#     sub-expressions:
# 21. e^{i * theta}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. e
#     core type: Literal
#     sub-expressions:
# 25. i * theta
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. i
#     core type: Literal
#     sub-expressions:
# 29. theta
#     core type: Variable
#     sub-expressions:
