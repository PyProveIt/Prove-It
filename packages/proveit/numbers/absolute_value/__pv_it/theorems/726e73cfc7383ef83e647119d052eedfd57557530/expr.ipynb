# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, c
from proveit.logic import And
from proveit.numbers import Abs, LessEq, Neg

# %%
# build up the expression from sub-expressions
expr = Conditional(LessEq(Abs(a), c), And(LessEq(Neg(c), a), LessEq(a, c)).with_total_ordering_style())
# Out:
# expr: {|a| <= c if (-c) <= a ,  a <= c.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left|a\right| \leq c \textrm{ if } \left(-c\right) \leq a ,  a \leq c\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {|a| <= c if (-c) <= a ,  a <= c.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. |a| <= c
#    core type: Operation
#    operator: 12
#    operands: 3
# 2. (-c) <= a <= c
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|a|, c)
#    core type: ExprTuple
#    sub-expressions: 6, 18
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. ((-c) <= a, a <= c)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. |a|
#    core type: Operation
#    operator: 9
#    operand: 15
# 7. (-c) <= a
#    core type: Operation
#    operator: 12
#    operands: 11
# 8. a <= c
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. (a)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. (-c, a)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. <=
#     core type: Literal
#     sub-expressions:
# 13. (a, c)
#     core type: ExprTuple
#     sub-expressions: 15, 18
# 14. -c
#     core type: Operation
#     operator: 16
#     operand: 18
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (c)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. c
#     core type: Variable
#     sub-expressions:
