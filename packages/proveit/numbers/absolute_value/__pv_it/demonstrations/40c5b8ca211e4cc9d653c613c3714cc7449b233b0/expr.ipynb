# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, b, c, k, n, x
from proveit.numbers import Abs, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Abs(a), Abs(b), ExprRange(k, Abs(IndexedVar(x, k)), one, n), Abs(c))
# Out:
# expr: (|a|, |b|, |x_{1}|, ..|x_{k}|.., |x_{n}|, |c|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|a\right|, \left|b\right|, \left|x_{1}\right|, \ldots, \left|x_{n}\right|, \left|c\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|a|, |b|, |x_{1}|, ..|x_{k}|.., |x_{n}|, |c|)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. |a|
#    core type: Operation
#    operator: 15
#    operand: 11
# 2. |b|
#    core type: Operation
#    operator: 15
#    operand: 12
# 3. |x_{1}|, ..|x_{k}|.., |x_{n}|
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 8
#    end_index: 9
# 4. |c|
#    core type: Operation
#    operator: 15
#    operand: 14
# 5. (a)
#    core type: ExprTuple
#    sub-expressions: 11
# 6. (b)
#    core type: ExprTuple
#    sub-expressions: 12
# 7. k -> |x_{k}|
#    core type: Lambda
#    parameter: 20
#    body: 13
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. n
#    core type: Variable
#    sub-expressions:
# 10. (c)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. |x_{k}|
#     core type: Operation
#     operator: 15
#     operand: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. Abs
#     core type: Literal
#     sub-expressions:
# 16. (x_{k})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x_{k}
#     core type: IndexedVar
# variable: 18
# index: 20
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. (k)
#     core type: ExprTuple
#     sub-expressions: 20
# 20. k
#     core type: Variable
#     sub-expressions:
