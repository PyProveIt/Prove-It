# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, r, theta
from proveit.numbers import Abs, Exp, Mult, Neg, e, i, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Abs(Mult(r, Exp(e, Neg(Mult(theta, i))))), Mult(r, one))
# Out:
# expr: (|r * e^{-(theta * i)}|, r * 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|r \cdot \mathsf{e}^{-\left(\theta \cdot \mathsf{i}\right)}\right|, r \cdot 1\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|r * e^{-(theta * i)}|, r * 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |r * e^{-(theta * i)}|
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. r * 1
#    core type: Operation
#    operator: 18
#    operands: 5
# 3. Abs
#    core type: Literal
#    sub-expressions:
# 4. (r * e^{-(theta * i)})
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (r, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 7
# 6. r * e^{-(theta * i)}
#    core type: Operation
#    operator: 18
#    operands: 8
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. (r, e^{-(theta * i)})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. r
#    core type: Variable
#    sub-expressions:
# 10. e^{-(theta * i)}
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (e, -(theta * i))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. e
#     core type: Literal
#     sub-expressions:
# 14. -(theta * i)
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (theta * i)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. theta * i
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (theta, i)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. theta
#     core type: Variable
#     sub-expressions:
# 21. i
#     core type: Literal
#     sub-expressions:
