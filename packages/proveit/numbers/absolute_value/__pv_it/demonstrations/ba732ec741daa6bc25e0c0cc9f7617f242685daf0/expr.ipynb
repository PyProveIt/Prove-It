# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, Neg, e, i

# %%
# build up the expression from sub-expressions
expr = Equals(Exp(e, Neg(Mult(theta, i))), Exp(e, Mult(i, Neg(theta))))
# Out:
# expr: e^{-(theta * i)} = e^{i * (-theta)}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{-\left(\theta \cdot \mathsf{i}\right)} = \mathsf{e}^{\mathsf{i} \cdot \left(-\theta\right)}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{-(theta * i)} = e^{i * (-theta)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (e^{-(theta * i)}, e^{i * (-theta)})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. e^{-(theta * i)}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. e^{i * (-theta)}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (e, -(theta * i))
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (e, i * (-theta))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. -(theta * i)
#    core type: Operation
#    operator: 17
#    operand: 13
# 9. e
#    core type: Literal
#    sub-expressions:
# 10. i * (-theta)
#     core type: Operation
#     operator: 15
#     operands: 12
# 11. (theta * i)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (i, -theta)
#     core type: ExprTuple
#     sub-expressions: 19, 14
# 13. theta * i
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. -theta
#     core type: Operation
#     operator: 17
#     operand: 20
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (theta, i)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (theta)
#     core type: ExprTuple
#     sub-expressions: 20
# 19. i
#     core type: Literal
#     sub-expressions:
# 20. theta
#     core type: Variable
#     sub-expressions:
