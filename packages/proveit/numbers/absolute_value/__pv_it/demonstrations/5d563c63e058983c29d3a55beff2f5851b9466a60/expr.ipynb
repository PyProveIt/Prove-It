# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, a, b, c, k, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.numbers import Abs, Add, LessEq, one

# %%
# build up the expression from sub-expressions
expr = LessEq(Abs(Add(a, b, x_1_to_n, c)), Add(Abs(a), Abs(b), ExprRange(k, Abs(IndexedVar(x, k)), one, n), Abs(c)))
# Out:
# expr: |a + b + x_{1} + ..x_{_a}.. + x_{n} + c| <= (|a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|a + b + x_{1} + \ldots + x_{n} + c\right| \leq \left(\left|a\right| + \left|b\right| + \left|x_{1}\right| + \ldots + \left|x_{n}\right| + \left|c\right|\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |a + b + x_{1} + ..x_{_a}.. + x_{n} + c| <= (|a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (|a + b + x_{1} + ..x_{_a}.. + x_{n} + c|, |a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |a + b + x_{1} + ..x_{_a}.. + x_{n} + c|
#    core type: Operation
#    operator: 26
#    operand: 7
# 4. |a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|
#    core type: Operation
#    operator: 12
#    operands: 6
# 5. (a + b + x_{1} + ..x_{_a}.. + x_{n} + c)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (|a|, |b|, |x_{1}|, ..|x_{k}|.., |x_{n}|, |c|)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. a + b + x_{1} + ..x_{_a}.. + x_{n} + c
#    core type: Operation
#    operator: 12
#    operands: 13
# 8. |a|
#    core type: Operation
#    operator: 26
#    operand: 19
# 9. |b|
#    core type: Operation
#    operator: 26
#    operand: 20
# 10. |x_{1}|, ..|x_{k}|.., |x_{n}|
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 24
#     end_index: 25
# 11. |c|
#     core type: Operation
#     operator: 26
#     operand: 22
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (a, b, x_{1}, ..x_{_a}.., x_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 18, 22
# 14. (a)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. (b)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. k -> |x_{k}|
#     core type: Lambda
#     parameter: 34
#     body: 21
# 17. (c)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 25
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. |x_{k}|
#     core type: Operation
#     operator: 26
#     operand: 29
# 22. c
#     core type: Variable
#     sub-expressions:
# 23. _a -> x_{_a}
#     core type: Lambda
#     parameter: 33
#     body: 28
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. n
#     core type: Variable
#     sub-expressions:
# 26. Abs
#     core type: Literal
#     sub-expressions:
# 27. (x_{k})
#     core type: ExprTuple
#     sub-expressions: 29
# 28. x_{_a}
#     core type: IndexedVar
# variable: 31
# index: 33
# 29. x_{k}
#     core type: IndexedVar
# variable: 31
# index: 34
# 30. (_a)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. x
#     core type: Variable
#     sub-expressions:
# 32. (k)
#     core type: ExprTuple
#     sub-expressions: 34
# 33. _a
#     core type: Variable
#     sub-expressions:
# 34. k
#     core type: Variable
#     sub-expressions:
