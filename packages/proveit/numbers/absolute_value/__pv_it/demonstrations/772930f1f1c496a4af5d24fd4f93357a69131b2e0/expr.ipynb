# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, Lambda, Variable, a, b, c, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import four, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
expr = Equals(Len([Lambda(sub_expr1, a), Lambda(sub_expr1, b), Lambda(sub_expr2, IndexedVar(x, sub_expr2)), Lambda(sub_expr1, c)]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: |(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)| = |(1, ..k.., 4)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left({_{-}b} \mapsto a, {_{-}b} \mapsto b, {_{-}a} \mapsto x_{{_{-}a}}, {_{-}b} \mapsto c\right)| = |\left(1, \ldots, 4\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)| = |(1, ..k.., 4)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((_b -> a, _b -> b, _a -> x_{_a}, _b -> c))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (_b -> a, _b -> b, _a -> x_{_a}, _b -> c)
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12, 13
# 9. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. _b -> a
#     core type: Lambda
#     parameter: 18
#     body: 15
# 11. _b -> b
# ...
