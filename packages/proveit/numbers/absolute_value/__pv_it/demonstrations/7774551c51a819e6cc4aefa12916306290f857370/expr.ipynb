# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, n
from proveit.core_expr_types import Len, x_1_to_n
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(one, sub_expr1, one)
expr = Equals(Len([a, b, x_1_to_n, c]), Add(sub_expr2, sub_expr2, Add(n, sub_expr1, one), sub_expr2))
# Out:
# expr: |(a, b, x_{1}, ..x_{_a}.., x_{n}, c)| = ((1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(a, b, x_{1}, \ldots, x_{n}, c\right)| = \left(\left(1 - 1 + 1\right) + \left(1 - 1 + 1\right) + \left(n - 1 + 1\right) + \left(1 - 1 + 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(a, b, x_{1}, ..x_{_a}.., x_{n}, c)| = ((1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(a, b, x_{1}, ..x_{_a}.., x_{n}, c)|, (1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(a, b, x_{1}, ..x_{_a}.., x_{n}, c)|
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1)
#    core type: Operation
#    operator: 16
#    operands: 7
# 5. length
#    core type: Literal
#    sub-expressions:
# 6. ((a, b, x_{1}, ..x_{_a}.., x_{n}, c))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1 - 1 + 1, 1 - 1 + 1, n - 1 + 1, 1 - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 10, 10, 9, 10
# 8. (a, b, x_{1}, ..x_{_a}.., x_{n}, c)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 9. n - 1 + 1
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. 1 - 1 + 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 26
#     end_index: 19
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. (n, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 26
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (1, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 20, 26
# 18. _a -> x_{_a}
#     core type: Lambda
#     parameter: 27
#     body: 21
# 19. n
#     core type: Variable
#     sub-expressions:
# 20. -1
#     core type: Operation
#     operator: 22
#     operand: 26
# 21. x_{_a}
#     core type: IndexedVar
# variable: 24
# index: 27
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (1)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. (_a)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. _a
#     core type: Variable
#     sub-expressions:
