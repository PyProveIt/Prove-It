# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, n
from proveit.numbers import Add, Neg, one, three

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(one, sub_expr1, one)
expr = ExprTuple(Add(sub_expr2, sub_expr2, Add(n, sub_expr1, one), sub_expr2), Add(n, three))
# Out:
# expr: ((1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1), n + 3)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(1 - 1 + 1\right) + \left(1 - 1 + 1\right) + \left(n - 1 + 1\right) + \left(1 - 1 + 1\right), n + 3\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1), n + 3)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (1 - 1 + 1) + (1 - 1 + 1) + (n - 1 + 1) + (1 - 1 + 1)
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. n + 3
#    core type: Operation
#    operator: 9
#    operands: 4
# 3. (1 - 1 + 1, 1 - 1 + 1, n - 1 + 1, 1 - 1 + 1)
#    core type: ExprTuple
#    sub-expressions: 6, 6, 5, 6
# 4. (n, 3)
#    core type: ExprTuple
#    sub-expressions: 11, 7
# 5. n - 1 + 1
#    core type: Operation
#    operator: 9
#    operands: 8
# 6. 1 - 1 + 1
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. 3
#    core type: Literal
#    sub-expressions:
# 8. (n, -1, 1)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 15
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (1, -1, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 12, 15
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. -1
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. -
#     core type: Literal
#     sub-expressions:
# 14. (1)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. 1
#     core type: Literal
#     sub-expressions:
