# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, r, theta
from proveit.core_expr_types import Len
from proveit.numbers import Exp, Mult, Neg, e, i, one, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([r, Exp(e, Neg(Mult(i, theta)))]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: (|(r, e^{-(i * theta)})|, |(1, ..k.., 2)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(r, \mathsf{e}^{-\left(\mathsf{i} \cdot \theta\right)}\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(r, e^{-(i * theta)})|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(r, e^{-(i * theta)})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((r, e^{-(i * theta)}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (r, e^{-(i * theta)})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. r
#    core type: Variable
#    sub-expressions:
# 9. e^{-(i * theta)}
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. 1, ..k.., 2
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 11. Exp
#     core type: Literal
#     sub-expressions:
# 12. (e, -(i * theta))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. k -> k
#     core type: Lambda
#     parameter: 18
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. e
#     core type: Literal
#     sub-expressions:
# 17. -(i * theta)
#     core type: Operation
#     operator: 19
#     operand: 21
# 18. k
#     core type: Variable
#     sub-expressions:
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (i * theta)
#     core type: ExprTuple
#     sub-expressions: 21
# 21. i * theta
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. i
#     core type: Literal
#     sub-expressions:
# 25. theta
#     core type: Variable
#     sub-expressions:
