# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, r, theta
from proveit.numbers import Abs, Exp, Mult, Neg, e, i

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Abs(Mult(r, Exp(e, Mult(i, Neg(theta))))), Abs(Mult(r, Exp(e, Neg(Mult(i, theta))))))
# Out:
# expr: (|r * e^{i * (-theta)}|, |r * e^{-(i * theta)}|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|r \cdot \mathsf{e}^{\mathsf{i} \cdot \left(-\theta\right)}\right|, \left|r \cdot \mathsf{e}^{-\left(\mathsf{i} \cdot \theta\right)}\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|r * e^{i * (-theta)}|, |r * e^{-(i * theta)}|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |r * e^{i * (-theta)}|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |r * e^{-(i * theta)}|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (r * e^{i * (-theta)})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Abs
#    core type: Literal
#    sub-expressions:
# 5. (r * e^{-(i * theta)})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. r * e^{i * (-theta)}
#    core type: Operation
#    operator: 25
#    operands: 8
# 7. r * e^{-(i * theta)}
#    core type: Operation
#    operator: 25
#    operands: 9
# 8. (r, e^{i * (-theta)})
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 9. (r, e^{-(i * theta)})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. e^{i * (-theta)}
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. r
#     core type: Variable
#     sub-expressions:
# 12. e^{-(i * theta)}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (e, i * (-theta))
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. Exp
#     core type: Literal
#     sub-expressions:
# 15. (e, -(i * theta))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. i * (-theta)
#     core type: Operation
#     operator: 25
#     operands: 19
# 17. e
#     core type: Literal
#     sub-expressions:
# 18. -(i * theta)
#     core type: Operation
#     operator: 23
#     operand: 22
# 19. (i, -theta)
#     core type: ExprTuple
#     sub-expressions: 27, 21
# 20. (i * theta)
#     core type: ExprTuple
#     sub-expressions: 22
# 21. -theta
#     core type: Operation
#     operator: 23
#     operand: 28
# 22. i * theta
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. (theta)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. i
#     core type: Literal
#     sub-expressions:
# 28. theta
#     core type: Variable
#     sub-expressions:
