# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, a, b, c, k, n, x
from proveit.core_expr_types import x_1_to_n
from proveit.numbers import Abs, Add, one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Abs(Add(a, b, x_1_to_n, c)), Add(Abs(a), Abs(b), ExprRange(k, Abs(IndexedVar(x, k)), one, n), Abs(c)))
# Out:
# expr: (|a + b + x_{1} + ..x_{_a}.. + x_{n} + c|, |a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|a + b + x_{1} + \ldots + x_{n} + c\right|, \left|a\right| + \left|b\right| + \left|x_{1}\right| + \ldots + \left|x_{n}\right| + \left|c\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|a + b + x_{1} + ..x_{_a}.. + x_{n} + c|, |a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |a + b + x_{1} + ..x_{_a}.. + x_{n} + c|
#    core type: Operation
#    operator: 24
#    operand: 5
# 2. |a| + |b| + |x_{1}| + ..|x_{k}|.. + |x_{n}| + |c|
#    core type: Operation
#    operator: 10
#    operands: 4
# 3. (a + b + x_{1} + ..x_{_a}.. + x_{n} + c)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (|a|, |b|, |x_{1}|, ..|x_{k}|.., |x_{n}|, |c|)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9
# 5. a + b + x_{1} + ..x_{_a}.. + x_{n} + c
#    core type: Operation
#    operator: 10
#    operands: 11
# 6. |a|
#    core type: Operation
#    operator: 24
#    operand: 17
# 7. |b|
#    core type: Operation
#    operator: 24
#    operand: 18
# 8. |x_{1}|, ..|x_{k}|.., |x_{n}|
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 22
#    end_index: 23
# 9. |c|
#    core type: Operation
#    operator: 24
#    operand: 20
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (a, b, x_{1}, ..x_{_a}.., x_{n}, c)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 16, 20
# 12. (a)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. (b)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. k -> |x_{k}|
#     core type: Lambda
#     parameter: 32
#     body: 19
# 15. (c)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. x_{1}, ..x_{_a}.., x_{n}
#     core type: ExprRange
#     lambda_map: 21
#     start_index: 22
#     end_index: 23
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b
#     core type: Variable
#     sub-expressions:
# 19. |x_{k}|
#     core type: Operation
#     operator: 24
#     operand: 27
# 20. c
#     core type: Variable
#     sub-expressions:
# 21. _a -> x_{_a}
#     core type: Lambda
#     parameter: 31
#     body: 26
# 22. 1
#     core type: Literal
#     sub-expressions:
# 23. n
#     core type: Variable
#     sub-expressions:
# 24. Abs
#     core type: Literal
#     sub-expressions:
# 25. (x_{k})
#     core type: ExprTuple
#     sub-expressions: 27
# 26. x_{_a}
#     core type: IndexedVar
# variable: 29
# index: 31
# 27. x_{k}
#     core type: IndexedVar
# variable: 29
# index: 32
# 28. (_a)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. x
#     core type: Variable
#     sub-expressions:
# 30. (k)
#     core type: ExprTuple
#     sub-expressions: 32
# 31. _a
#     core type: Variable
#     sub-expressions:
# 32. k
#     core type: Variable
#     sub-expressions:
