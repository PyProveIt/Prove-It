# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, b, c, n
from proveit.core_expr_types import Len, x_1_to_n
from proveit.numbers import Add, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a, b, x_1_to_n, c]), Len([ExprRange(a, a, one, Add(n, three))]))
# Out:
# expr: (|(a, b, x_{1}, ..x_{_a}.., x_{n}, c)|, |(1, ..a.., n + 3)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a, b, x_{1}, \ldots, x_{n}, c\right)|, |\left(1, \ldots, n + 3\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a, b, x_{1}, ..x_{_a}.., x_{n}, c)|, |(1, ..a.., n + 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a, b, x_{1}, ..x_{_a}.., x_{n}, c)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..a.., n + 3)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a, b, x_{1}, ..x_{_a}.., x_{n}, c))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..a.., n + 3))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, b, x_{1}, ..x_{_a}.., x_{n}, c)
#    core type: ExprTuple
#    sub-expressions: 17, 8, 9, 10
# 7. (1, ..a.., n + 3)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. b
#    core type: Variable
#    sub-expressions:
# 9. x_{1}, ..x_{_a}.., x_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 14
#    end_index: 22
# 10. c
#     core type: Variable
#     sub-expressions:
# 11. 1, ..a.., (n + 3)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 12. _a -> x_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 16
# 13. a -> a
#     core type: Lambda
#     parameter: 17
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. n + 3
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. x_{_a}
#     core type: IndexedVar
# variable: 20
# index: 24
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (n, 3)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. n
#     core type: Variable
#     sub-expressions:
# 23. 3
#     core type: Literal
#     sub-expressions:
# 24. _a
#     core type: Variable
#     sub-expressions:
