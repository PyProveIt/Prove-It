# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, b, k, theta
from proveit.core_expr_types import Len
from proveit.numbers import Exp, Mult, e, i, one, three

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([a, Exp(e, Mult(i, theta)), b]), Len([ExprRange(k, k, one, three)]))
# Out:
# expr: (|(a, e^{i * theta}, b)|, |(1, ..k.., 3)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(a, \mathsf{e}^{\mathsf{i} \cdot \theta}, b\right)|, |\left(1, \ldots, 3\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(a, e^{i * theta}, b)|, |(1, ..k.., 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(a, e^{i * theta}, b)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 3)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((a, e^{i * theta}, b))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 3))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, e^{i * theta}, b)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 7. (1, ..k.., 3)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. a
#    core type: Variable
#    sub-expressions:
# 9. e^{i * theta}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. 1, ..k.., 3
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 15
#     end_index: 16
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. k -> k
#     core type: Lambda
#     parameter: 19
#     body: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 3
#     core type: Literal
#     sub-expressions:
# 17. e
#     core type: Literal
#     sub-expressions:
# 18. i * theta
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. k
#     core type: Variable
#     sub-expressions:
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. i
#     core type: Literal
#     sub-expressions:
# 23. theta
#     core type: Variable
#     sub-expressions:
