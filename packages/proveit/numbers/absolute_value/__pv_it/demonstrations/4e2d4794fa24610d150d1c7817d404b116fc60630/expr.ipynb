# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Lambda, Variable, a, b, c, k, x
from proveit.core_expr_types import Len
from proveit.numbers import four, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
sub_expr2 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Len([Lambda(sub_expr1, a), Lambda(sub_expr1, b), Lambda(sub_expr2, IndexedVar(x, sub_expr2)), Lambda(sub_expr1, c)]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left({_{-}b} \mapsto a, {_{-}b} \mapsto b, {_{-}a} \mapsto x_{{_{-}a}}, {_{-}b} \mapsto c\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(_b -> a, _b -> b, _a -> x_{_a}, _b -> c)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((_b -> a, _b -> b, _a -> x_{_a}, _b -> c))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (_b -> a, _b -> b, _a -> x_{_a}, _b -> c)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. _b -> a
#    core type: Lambda
#    parameter: 16
#    body: 13
# 9. _b -> b
#    core type: Lambda
#    parameter: 16
#    body: 14
# 10. _a -> x_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 15
# 11. _b -> c
#     core type: Lambda
#     parameter: 16
# ...
