# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, theta
from proveit.logic import Equals
from proveit.numbers import Abs, Exp, Mult, e, i

# %%
# build up the expression from sub-expressions
expr = Equals(Abs(Mult(a, b, Exp(e, Mult(i, theta)), c)), Mult(Abs(a), b, c))
# Out:
# expr: |a * b * e^{i * theta} * c| = (|a| * b * c)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|a \cdot b \cdot \mathsf{e}^{\mathsf{i} \cdot \theta} \cdot c\right| = \left(\left|a\right| \cdot b \cdot c\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |a * b * e^{i * theta} * c| = (|a| * b * c)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|a * b * e^{i * theta} * c|, |a| * b * c)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |a * b * e^{i * theta} * c|
#    core type: Operation
#    operator: 10
#    operand: 7
# 4. |a| * b * c
#    core type: Operation
#    operator: 20
#    operands: 6
# 5. (a * b * e^{i * theta} * c)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (|a|, b, c)
#    core type: ExprTuple
#    sub-expressions: 8, 12, 14
# 7. a * b * e^{i * theta} * c
#    core type: Operation
#    operator: 20
#    operands: 9
# 8. |a|
#    core type: Operation
#    operator: 10
#    operand: 15
# 9. (a, b, e^{i * theta}, c)
#    core type: ExprTuple
#    sub-expressions: 15, 12, 13, 14
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. (a)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. e^{i * theta}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (e, i * theta)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. e
#     core type: Literal
#     sub-expressions:
# 19. i * theta
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. i
#     core type: Literal
#     sub-expressions:
# 23. theta
#     core type: Variable
#     sub-expressions:
