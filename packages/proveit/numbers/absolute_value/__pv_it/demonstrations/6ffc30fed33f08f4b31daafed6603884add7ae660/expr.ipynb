# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.numbers.absolute_value</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import r, theta
from proveit.logic import Equals
from proveit.numbers import Abs, Exp, Mult, Neg, e, i

# %%
# build up the expression from sub-expressions
expr = Equals(Abs(Mult(r, Exp(e, Mult(i, Neg(theta))))), Abs(Mult(r, Exp(e, Neg(Mult(i, theta))))))
# Out:
# expr: |r * e^{i * (-theta)}| = |r * e^{-(i * theta)}|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|r \cdot \mathsf{e}^{\mathsf{i} \cdot \left(-\theta\right)}\right| = \left|r \cdot \mathsf{e}^{-\left(\mathsf{i} \cdot \theta\right)}\right|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |r * e^{i * (-theta)}| = |r * e^{-(i * theta)}|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|r * e^{i * (-theta)}|, |r * e^{-(i * theta)}|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |r * e^{i * (-theta)}|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |r * e^{-(i * theta)}|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (r * e^{i * (-theta)})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. Abs
#    core type: Literal
#    sub-expressions:
# 7. (r * e^{-(i * theta)})
#    core type: ExprTuple
#    sub-expressions: 9
# 8. r * e^{i * (-theta)}
#    core type: Operation
#    operator: 27
#    operands: 10
# 9. r * e^{-(i * theta)}
#    core type: Operation
#    operator: 27
#    operands: 11
# 10. (r, e^{i * (-theta)})
#     core type: ExprTuple
#     sub-expressions: 13, 12
# 11. (r, e^{-(i * theta)})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. e^{i * (-theta)}
#     core type: Operation
#     operator: 16
#     operands: 15
# 13. r
#     core type: Variable
#     sub-expressions:
# 14. e^{-(i * theta)}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (e, i * (-theta))
#     core type: ExprTuple
#     sub-expressions: 19, 18
# 16. Exp
#     core type: Literal
#     sub-expressions:
# 17. (e, -(i * theta))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. i * (-theta)
#     core type: Operation
#     operator: 27
#     operands: 21
# 19. e
#     core type: Literal
#     sub-expressions:
# 20. -(i * theta)
#     core type: Operation
#     operator: 25
#     operand: 24
# 21. (i, -theta)
#     core type: ExprTuple
#     sub-expressions: 29, 23
# 22. (i * theta)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. -theta
#     core type: Operation
#     operator: 25
#     operand: 30
# 24. i * theta
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. (theta)
#     core type: ExprTuple
#     sub-expressions: 30
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (i, theta)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. i
#     core type: Literal
#     sub-expressions:
# 30. theta
#     core type: Variable
#     sub-expressions:
