# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">statistics</a>.<a class="ProveItLink" href="../../theorems.ipynb#prob_lower_bound">prob_lower_bound</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving prob_lower_bound
# Out:
# prob_lower_bound: forall_{P, Q, S, q} ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))
