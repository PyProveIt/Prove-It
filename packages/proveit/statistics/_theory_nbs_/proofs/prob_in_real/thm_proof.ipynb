# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">statistics</a>.<a class="ProveItLink" href="../../theorems.ipynb#prob_in_real">prob_in_real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving prob_in_real
# Out:
# prob_in_real: forall_{x, X} (Pr_{x}[X] in Real)
