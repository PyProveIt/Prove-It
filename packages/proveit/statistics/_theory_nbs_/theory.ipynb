# %% [markdown]
# Theory of <a class="ProveItLink" href="../../_theory_nbs_/theory.ipynb">proveit</a>.statistics
# ========
#
# Provide description here.

# %%
import proveit
# %theory # toggles between interactive and static modes
# Out:
# <h3>Local content of this theory</h3>
# <table><tr>
# <th><a class="ProveItLink" href="common.ipynb">common expressions</a></th>
# <th><a class="ProveItLink" href="axioms.ipynb">axioms</a></th>
# <th><a class="ProveItLink" href="theorems.ipynb">theorems</a></th>
# <th><a class="ProveItLink" href="demonstrations.ipynb">demonstrations</a></th>
# </tr></table>
# <h3>Sub-theories</h3>
# <h3>All axioms contained within this theory</h3>
# <dt><a class="ProveItLink" href="axioms.ipynb#prob_between_zero_and_one">proveit.statistics.prob_between_zero_and_one</a></dt><dd><a class="ProveItLink" href="../__pv_it/axioms/eda4ae3029d17f363911c93f66488f830f83bed80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></dd>
