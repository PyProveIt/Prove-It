# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, X, x
from proveit.logic import InSet
from proveit.numbers import IntervalCC, one, zero
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, X], InSet(Prob(X, x), IntervalCC(zero, one))))
# Out:
# expr: ((x, X) -> (Pr_{x}[X] in [0,1]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, X\right) \mapsto \left(Pr_{x}[X] \in \left[0,1\right]\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, X) -> (Pr_{x}[X] in [0,1]))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, X) -> (Pr_{x}[X] in [0,1])
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, X)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 3. Pr_{x}[X] in [0,1]
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (Pr_{x}[X], [0,1])
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. Pr_{x}[X]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. [0,1]
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. PROB
#    core type: Literal
#    sub-expressions:
# 9. (X, x)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. IntervalCC
#     core type: Literal
#     sub-expressions:
# 11. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. X
#     core type: Variable
#     sub-expressions:
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. 0
#     core type: Literal
#     sub-expressions:
# 15. 1
#     core type: Literal
#     sub-expressions:
