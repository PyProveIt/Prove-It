# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#prob_between_zero_and_one">prob_between_zero_and_one</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.statistics import prob_between_zero_and_one

# %%
# check that the built expression is the same as the stored expression
assert prob_between_zero_and_one.expr == stored_expr
assert prob_between_zero_and_one.expr._style_id == stored_expr._style_id
print("Passed sanity check: prob_between_zero_and_one matches stored_expr")
# Out:
# Passed sanity check: prob_between_zero_and_one matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(prob_between_zero_and_one.latex())
# Out:
# \vdash \forall_{x, X}~\left(Pr_{x}[X] \in \left[0,1\right]\right)

# %%
prob_between_zero_and_one.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
prob_between_zero_and_one.expr_info()
# Out:
# 0. forall_{x, X} (Pr_{x}[X] in [0,1])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, X) -> (Pr_{x}[X] in [0,1]))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, X) -> (Pr_{x}[X] in [0,1])
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, X)
#    core type: ExprTuple
#    sub-expressions: 15, 14
# 5. Pr_{x}[X] in [0,1]
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (Pr_{x}[X], [0,1])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. Pr_{x}[X]
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. [0,1]
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. PROB
#     core type: Literal
#     sub-expressions:
# 11. (X, x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. IntervalCC
#     core type: Literal
#     sub-expressions:
# 13. (0, 1)
# ...
