# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Qy, S, q, y
from proveit.logic import Equals, InSet
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Lambda(y, Conditional(Prob(Equals(q, Qy), q), InSet(y, S)))
# Out:
# expr: y -> {Pr_{q}[q = Q(y)] if y in S.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# y \mapsto \left\{Pr_{q}[q = Q(y)] \textrm{ if } y \in S\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. y -> {Pr_{q}[q = Q(y)] if y in S.
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {Pr_{q}[q = Q(y)] if y in S.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. y in S
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. PROB
#    core type: Literal
#    sub-expressions:
# 5. (q = Q(y), q)
#    core type: ExprTuple
#    sub-expressions: 8, 12
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (y, S)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 8. q = Q(y)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. S
#    core type: Variable
#    sub-expressions:
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. q
#     core type: Variable
#     sub-expressions:
# 13. Q(y)
#     core type: Operation
#     operator: 14
#     operand: 16
# 14. Q
#     core type: Variable
#     sub-expressions:
# 15. (y)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. y
#     core type: Variable
#     sub-expressions:
