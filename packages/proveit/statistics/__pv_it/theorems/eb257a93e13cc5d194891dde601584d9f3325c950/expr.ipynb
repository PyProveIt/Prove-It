# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Qy, S, q, y
from proveit.logic import Equals
from proveit.numbers import Sum
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Sum([y], Prob(Equals(q, Qy), q), domain = S)
# Out:
# expr: Sum_{y in S} Pr_{q}[q = Q(y)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{y \in S}~Pr_{q}[q = Q(y)]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (y -> {Pr_{q}[q = Q(y)] if y in S.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. y -> {Pr_{q}[q = Q(y)] if y in S.
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. {Pr_{q}[q = Q(y)] if y in S.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. y in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. PROB
#    core type: Literal
#    sub-expressions:
# 8. (q = Q(y), q)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (y, S)
#     core type: ExprTuple
#     sub-expressions: 19, 12
# 11. q = Q(y)
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. S
#     core type: Variable
#     sub-expressions:
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. q
#     core type: Variable
#     sub-expressions:
# 16. Q(y)
#     core type: Operation
#     operator: 17
#     operand: 19
# 17. Q
#     core type: Variable
#     sub-expressions:
# 18. (y)
#     core type: ExprTuple
#     sub-expressions: 19
# 19. y
#     core type: Variable
#     sub-expressions:
