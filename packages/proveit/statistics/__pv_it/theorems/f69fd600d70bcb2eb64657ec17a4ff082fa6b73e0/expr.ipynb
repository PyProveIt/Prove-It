# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, X, x
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([x, X], InSet(Prob(X, x), Real)))
# Out:
# expr: ((x, X) -> (Pr_{x}[X] in Real))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(x, X\right) \mapsto \left(Pr_{x}[X] \in \mathbb{R}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((x, X) -> (Pr_{x}[X] in Real))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x, X) -> (Pr_{x}[X] in Real)
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (x, X)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 3. Pr_{x}[X] in Real
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (Pr_{x}[X], Real)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. Pr_{x}[X]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. Real
#    core type: Literal
#    sub-expressions:
# 8. PROB
#    core type: Literal
#    sub-expressions:
# 9. (X, x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. X
#     core type: Variable
#     sub-expressions:
# 11. x
#     core type: Variable
#     sub-expressions:
