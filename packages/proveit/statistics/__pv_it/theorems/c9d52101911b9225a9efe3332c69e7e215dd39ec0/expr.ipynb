# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Operation, P, Pq, Qx, Qy, S, q, x, y
from proveit.logic import Equals, Forall
from proveit.numbers import Sum, greater_eq
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], Operation(P, [Qx]), domain = S), greater_eq(Prob(Pq, q), Sum([y], Prob(Equals(q, Qy), q), domain = S)))
# Out:
# expr: (forall_{x in S} P(Q(x)), Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x \in S}~P(Q(x)), Pr_{q}[P(q)] \geq \sum_{y \in S}~Pr_{q}[q = Q(y)]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x in S} P(Q(x)), Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x in S} P(Q(x))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {P(Q(x)) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. <=
#    core type: Literal
#    sub-expressions:
# 6. (Sum_{y in S} Pr_{q}[q = Q(y)], Pr_{q}[P(q)])
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. x -> {P(Q(x)) if x in S.
#    core type: Lambda
#    parameter: 31
#    body: 10
# 8. Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. Pr_{q}[P(q)]
#    core type: Operation
#    operator: 27
#    operands: 13
# 10. {P(Q(x)) if x in S.
#     core type: Conditional
#     value: 14
#     condition: 15
# 11. Sum
# ...
