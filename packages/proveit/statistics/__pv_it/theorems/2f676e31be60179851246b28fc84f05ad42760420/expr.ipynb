# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Pq, Qy, S, q, y
from proveit.logic import Equals
from proveit.numbers import Sum
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([y], Prob(Equals(q, Qy), q), domain = S), Prob(Pq, q))
# Out:
# expr: (Sum_{y in S} Pr_{q}[q = Q(y)], Pr_{q}[P(q)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{y \in S}~Pr_{q}[q = Q(y)], Pr_{q}[P(q)]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{y in S} Pr_{q}[q = Q(y)], Pr_{q}[P(q)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. Pr_{q}[P(q)]
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (y -> {Pr_{q}[q = Q(y)] if y in S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (P(q), q)
#    core type: ExprTuple
#    sub-expressions: 7, 21
# 6. y -> {Pr_{q}[q = Q(y)] if y in S.
#    core type: Lambda
#    parameter: 25
#    body: 8
# 7. P(q)
#    core type: Operation
#    operator: 9
#    operand: 21
# 8. {Pr_{q}[q = Q(y)] if y in S.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. P
#    core type: Variable
#    sub-expressions:
# 10. (q)
#     core type: ExprTuple
#     sub-expressions: 21
# 11. Pr_{q}[q = Q(y)]
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. y in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. PROB
#     core type: Literal
#     sub-expressions:
# 14. (q = Q(y), q)
#     core type: ExprTuple
#     sub-expressions: 17, 21
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (y, S)
#     core type: ExprTuple
#     sub-expressions: 25, 18
# 17. q = Q(y)
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. S
#     core type: Variable
#     sub-expressions:
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. q
#     core type: Variable
#     sub-expressions:
# 22. Q(y)
#     core type: Operation
#     operator: 23
#     operand: 25
# 23. Q
#     core type: Variable
#     sub-expressions:
# 24. (y)
#     core type: ExprTuple
#     sub-expressions: 25
# 25. y
#     core type: Variable
#     sub-expressions:
