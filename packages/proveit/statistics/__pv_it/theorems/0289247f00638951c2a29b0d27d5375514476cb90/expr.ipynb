# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Qy, S, q, y
from proveit.logic import Equals, InSet
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(y, Conditional(Prob(Equals(q, Qy), q), InSet(y, S))))
# Out:
# expr: (y -> {Pr_{q}[q = Q(y)] if y in S.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(y \mapsto \left\{Pr_{q}[q = Q(y)] \textrm{ if } y \in S\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (y -> {Pr_{q}[q = Q(y)] if y in S.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. y -> {Pr_{q}[q = Q(y)] if y in S.
#    core type: Lambda
#    parameter: 17
#    body: 2
# 2. {Pr_{q}[q = Q(y)] if y in S.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. y in S
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. PROB
#    core type: Literal
#    sub-expressions:
# 6. (q = Q(y), q)
#    core type: ExprTuple
#    sub-expressions: 9, 13
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (y, S)
#    core type: ExprTuple
#    sub-expressions: 17, 10
# 9. q = Q(y)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. S
#     core type: Variable
#     sub-expressions:
# 11. =
#     core type: Literal
#     sub-expressions:
# 12. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. q
#     core type: Variable
#     sub-expressions:
# 14. Q(y)
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. Q
#     core type: Variable
#     sub-expressions:
# 16. (y)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. y
#     core type: Variable
#     sub-expressions:
