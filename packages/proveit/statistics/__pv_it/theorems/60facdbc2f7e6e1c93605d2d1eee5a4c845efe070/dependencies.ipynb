# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#prob_in_real">prob_in_real</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/prob_in_real/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.statistics import prob_in_real

# %%
# %dependencies prob_in_real
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on prob_in_real</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../physics/quantum/QPE/_theory_nbs_/proofs/success_prob_is_real/thm_proof.ipynb">proveit.physics.quantum.QPE.success_prob_is_real</a></dt><dd><a class="ProveItLink" href="../../../../physics/quantum/QPE/__pv_it/theorems/e40ad87a8e92afcbb828014026eeff6ed4784f2d0/expr.ipynb"><img src="../../../../physics/quantum/QPE/__pv_it/theorems/e40ad87a8e92afcbb828014026eeff6ed4784f2d0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
