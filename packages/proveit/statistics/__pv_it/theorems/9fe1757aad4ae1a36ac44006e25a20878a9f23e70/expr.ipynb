# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Operation, P, Pq, Q, Qx, Qy, S, q, x, y
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Sum, greater_eq
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Forall([P, Q, S, q], Implies(Forall([x], Operation(P, [Qx]), domain = S), greater_eq(Prob(Pq, q), Sum([y], Prob(Equals(q, Qy), q), domain = S))))
# Out:
# expr: forall_{P, Q, S, q} ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{P, Q, S, q}~\left(\left[\forall_{x \in S}~P(Q(x))\right] \Rightarrow \left(Pr_{q}[P(q)] \geq \sum_{y \in S}~Pr_{q}[q = Q(y)]\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{P, Q, S, q} ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))
#    core type: Operation
#    operator: 9
#    operand: 2
# 1. ((P, Q, S, q) -> ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])))
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (P, Q, S, q) -> ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (P, Q, S, q)
#    core type: ExprTuple
#    sub-expressions: 27, 44, 39, 42
# 4. [forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. (forall_{x in S} P(Q(x)), Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. forall_{x in S} P(Q(x))
#    core type: Operation
#    operator: 9
#    operand: 13
# ...
