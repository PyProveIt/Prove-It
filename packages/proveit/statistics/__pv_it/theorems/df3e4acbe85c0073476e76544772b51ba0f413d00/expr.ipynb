# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Operation, P, Pq, Qx, Qy, S, q, x, y
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Sum, greater_eq
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Implies(Forall([x], Operation(P, [Qx]), domain = S), greater_eq(Prob(Pq, q), Sum([y], Prob(Equals(q, Qy), q), domain = S)))
# Out:
# expr: [forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{x \in S}~P(Q(x))\right] \Rightarrow \left(Pr_{q}[P(q)] \geq \sum_{y \in S}~Pr_{q}[q = Q(y)]\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in S} P(Q(x)), Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x in S} P(Q(x))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {P(Q(x)) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (Sum_{y in S} Pr_{q}[q = Q(y)], Pr_{q}[P(q)])
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. x -> {P(Q(x)) if x in S.
#    core type: Lambda
#    parameter: 33
#    body: 12
# 10. Sum_{y in S} Pr_{q}[q = Q(y)]
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. Pr_{q}[P(q)]
#     core type: Operation
#     operator: 29
#     operands: 15
# 12. {P(Q(x)) if x in S.
#     core type: Conditional
#     value: 16
#     condition: 17
# 13. Sum
#     core type: Literal
#     sub-expressions:
# 14. (y -> {Pr_{q}[q = Q(y)] if y in S.)
#     core type: ExprTuple
#     sub-expressions: 18
# 15. (P(q), q)
#     core type: ExprTuple
#     sub-expressions: 19, 38
# 16. P(Q(x))
#     core type: Operation
#     operator: 23
#     operand: 25
# 17. x in S
#     core type: Operation
#     operator: 31
#     operands: 21
# 18. y -> {Pr_{q}[q = Q(y)] if y in S.
#     core type: Lambda
#     parameter: 42
#     body: 22
# 19. P(q)
#     core type: Operation
#     operator: 23
#     operand: 38
# 20. (Q(x))
#     core type: ExprTuple
#     sub-expressions: 25
# 21. (x, S)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 22. {Pr_{q}[q = Q(y)] if y in S.
#     core type: Conditional
#     value: 26
#     condition: 27
# 23. P
#     core type: Variable
#     sub-expressions:
# 24. (q)
#     core type: ExprTuple
#     sub-expressions: 38
# 25. Q(x)
#     core type: Operation
#     operator: 40
#     operand: 33
# 26. Pr_{q}[q = Q(y)]
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. y in S
#     core type: Operation
#     operator: 31
#     operands: 32
# 28. (x)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. PROB
#     core type: Literal
#     sub-expressions:
# 30. (q = Q(y), q)
#     core type: ExprTuple
#     sub-expressions: 34, 38
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (y, S)
#     core type: ExprTuple
#     sub-expressions: 42, 35
# 33. x
#     core type: Variable
#     sub-expressions:
# 34. q = Q(y)
#     core type: Operation
#     operator: 36
#     operands: 37
# 35. S
#     core type: Variable
#     sub-expressions:
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. q
#     core type: Variable
#     sub-expressions:
# 39. Q(y)
#     core type: Operation
#     operator: 40
#     operand: 42
# 40. Q
#     core type: Variable
#     sub-expressions:
# 41. (y)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. y
#     core type: Variable
#     sub-expressions:
