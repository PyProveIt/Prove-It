# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, Operation, P, Pq, Q, Qx, Qy, S, q, x, y
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Sum, greater_eq
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = Lambda([P, Q, S, q], Implies(Forall([x], Operation(P, [Qx]), domain = S), greater_eq(Prob(Pq, q), Sum([y], Prob(Equals(q, Qy), q), domain = S))))
# Out:
# expr: (P, Q, S, q) -> ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(P, Q, S, q\right) \mapsto \left(\left[\forall_{x \in S}~P(Q(x))\right] \Rightarrow \left(Pr_{q}[P(q)] \geq \sum_{y \in S}~Pr_{q}[q = Q(y)]\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (P, Q, S, q) -> ([forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (P, Q, S, q)
#    core type: ExprTuple
#    sub-expressions: 25, 42, 37, 40
# 2. [forall_{x in S} P(Q(x))] => (Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =>
#    core type: Literal
#    sub-expressions:
# 4. (forall_{x in S} P(Q(x)), Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)])
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. forall_{x in S} P(Q(x))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (x -> {P(Q(x)) if x in S.)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. <=
#    core type: Literal
#    sub-expressions:
# ...
