# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Pq, Qy, S, q, y
from proveit.logic import Equals
from proveit.numbers import Sum, greater_eq
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = greater_eq(Prob(Pq, q), Sum([y], Prob(Equals(q, Qy), q), domain = S))
# Out:
# expr: Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# Pr_{q}[P(q)] \geq \sum_{y \in S}~Pr_{q}[q = Q(y)]

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: reversed
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Pr_{q}[P(q)] >= Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{y in S} Pr_{q}[q = Q(y)], Pr_{q}[P(q)])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{y in S} Pr_{q}[q = Q(y)]
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. Pr_{q}[P(q)]
#    core type: Operation
#    operator: 15
#    operands: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (y -> {Pr_{q}[q = Q(y)] if y in S.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (P(q), q)
#    core type: ExprTuple
#    sub-expressions: 9, 23
# 8. y -> {Pr_{q}[q = Q(y)] if y in S.
#    core type: Lambda
#    parameter: 27
#    body: 10
# 9. P(q)
#    core type: Operation
#    operator: 11
#    operand: 23
# 10. {Pr_{q}[q = Q(y)] if y in S.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. P
#     core type: Variable
#     sub-expressions:
# 12. (q)
#     core type: ExprTuple
#     sub-expressions: 23
# 13. Pr_{q}[q = Q(y)]
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. y in S
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. PROB
#     core type: Literal
#     sub-expressions:
# 16. (q = Q(y), q)
#     core type: ExprTuple
#     sub-expressions: 19, 23
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (y, S)
#     core type: ExprTuple
#     sub-expressions: 27, 20
# 19. q = Q(y)
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. S
#     core type: Variable
#     sub-expressions:
# 21. =
#     core type: Literal
#     sub-expressions:
# 22. (q, Q(y))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. q
#     core type: Variable
#     sub-expressions:
# 24. Q(y)
#     core type: Operation
#     operator: 25
#     operand: 27
# 25. Q
#     core type: Variable
#     sub-expressions:
# 26. (y)
#     core type: ExprTuple
#     sub-expressions: 27
# 27. y
#     core type: Variable
#     sub-expressions:
