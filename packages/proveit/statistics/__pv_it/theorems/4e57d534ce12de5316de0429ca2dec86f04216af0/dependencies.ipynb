# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.statistics</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#prob_lower_bound">prob_lower_bound</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/prob_lower_bound/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.statistics import prob_lower_bound

# %%
# %dependencies prob_lower_bound
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon prob_lower_bound</h3>
