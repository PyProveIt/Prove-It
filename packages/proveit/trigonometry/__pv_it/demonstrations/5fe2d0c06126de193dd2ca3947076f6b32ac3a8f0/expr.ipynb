# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, r
from proveit.numbers import Abs, Add, Mult, Neg, frac, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = ExprTuple(two, Mult(r, c), Sin(frac(Abs(Add(a, Neg(b))), two)))
# Out:
# expr: (2, r * c, sin(|a - b| / 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2, r \cdot c, \sin{\frac{\left|a - b\right|}{2}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2, r * c, sin(|a - b| / 2))
#    core type: ExprTuple
#    sub-expressions: 13, 1, 2
# 1. r * c
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. sin(|a - b| / 2)
#    core type: Operation
#    operator: 5
#    operand: 9
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (r, c)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. sin
#    core type: Literal
#    sub-expressions:
# 6. (|a - b| / 2)
#    core type: ExprTuple
#    sub-expressions: 9
# 7. r
#    core type: Variable
#    sub-expressions:
# 8. c
#    core type: Variable
#    sub-expressions:
# 9. |a - b| / 2
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. (|a - b|, 2)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. |a - b|
#     core type: Operation
#     operator: 14
#     operand: 16
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. Abs
#     core type: Literal
#     sub-expressions:
# 15. (a - b)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. a - b
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (a, -b)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. a
#     core type: Variable
#     sub-expressions:
# 20. -b
#     core type: Operation
#     operator: 21
#     operand: 23
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (b)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. b
#     core type: Variable
#     sub-expressions:
