# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, i, pi, two

# %%
# build up the expression from sub-expressions
expr = Equals(Exp(e, Mult(i, Mult(two, pi, theta))), Exp(e, Mult(i, two, pi, theta)))
# Out:
# expr: e^{i * (2 * pi * theta)} = e^{i * 2 * pi * theta}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{\mathsf{i} \cdot \left(2 \cdot \pi \cdot \theta\right)} = \mathsf{e}^{\mathsf{i} \cdot 2 \cdot \pi \cdot \theta}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{i * (2 * pi * theta)} = e^{i * 2 * pi * theta}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (e^{i * (2 * pi * theta)}, e^{i * 2 * pi * theta})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. e^{i * (2 * pi * theta)}
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. e^{i * 2 * pi * theta}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (e, i * (2 * pi * theta))
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. Exp
#    core type: Literal
#    sub-expressions:
# 7. (e, i * 2 * pi * theta)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. i * (2 * pi * theta)
#    core type: Operation
#    operator: 15
#    operands: 11
# 9. e
#    core type: Literal
#    sub-expressions:
# 10. i * 2 * pi * theta
#     core type: Operation
#     operator: 15
#     operands: 12
# 11. (i, 2 * pi * theta)
#     core type: ExprTuple
#     sub-expressions: 14, 13
# 12. (i, 2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 14, 17, 18, 19
# 13. 2 * pi * theta
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. i
#     core type: Literal
#     sub-expressions:
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 17, 18, 19
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. pi
#     core type: Literal
#     sub-expressions:
# 19. theta
#     core type: Variable
#     sub-expressions:
