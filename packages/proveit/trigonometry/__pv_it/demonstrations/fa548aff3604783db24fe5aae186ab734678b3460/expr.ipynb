# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Abs, Add, Neg, frac, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(frac(Abs(Add(zero, Neg(theta))), two), frac(Abs(theta), two))
# Out:
# expr: (|0 - theta| / 2, |theta| / 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{\left|0 - \theta\right|}{2}, \frac{\left|\theta\right|}{2}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|0 - theta| / 2, |theta| / 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |0 - theta| / 2
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. |theta| / 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|0 - theta|, 2)
#    core type: ExprTuple
#    sub-expressions: 6, 8
# 4. /
#    core type: Literal
#    sub-expressions:
# 5. (|theta|, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. |0 - theta|
#    core type: Operation
#    operator: 10
#    operand: 11
# 7. |theta|
#    core type: Operation
#    operator: 10
#    operand: 18
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. (0 - theta)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. 0 - theta
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (0, -theta)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 0
#     core type: Literal
#     sub-expressions:
# 15. -theta
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (theta)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. theta
#     core type: Variable
#     sub-expressions:
