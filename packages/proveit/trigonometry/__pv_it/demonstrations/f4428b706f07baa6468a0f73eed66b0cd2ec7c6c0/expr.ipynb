# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, c, r
from proveit.numbers import Exp, Mult, e, i

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(e, Mult(i, a))
expr = ExprTuple(Mult(r, sub_expr1, c), Mult(Mult(r, c), sub_expr1))
# Out:
# expr: (r * e^{i * a} * c, (r * c) * e^{i * a})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a} \cdot c, \left(r \cdot c\right) \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (r * e^{i * a} * c, (r * c) * e^{i * a})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. r * e^{i * a} * c
#    core type: Operation
#    operator: 14
#    operands: 3
# 2. (r * c) * e^{i * a}
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (r, e^{i * a}, c)
#    core type: ExprTuple
#    sub-expressions: 10, 6, 11
# 4. (r * c, e^{i * a})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. r * c
#    core type: Operation
#    operator: 14
#    operands: 7
# 6. e^{i * a}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (r, c)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. Exp
#    core type: Literal
#    sub-expressions:
# 9. (e, i * a)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. r
#     core type: Variable
#     sub-expressions:
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. e
#     core type: Literal
#     sub-expressions:
# 13. i * a
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (i, a)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. i
#     core type: Literal
#     sub-expressions:
# 17. a
#     core type: Variable
#     sub-expressions:
