# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, i, one, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Equals(Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, theta))))), Mult(two, Sin(Mult(pi, Abs(theta)))))
# Out:
# expr: |1 - e^{2 * pi * i * theta}| = (2 * sin(pi * |theta|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \theta}\right| = \left(2 \cdot \sin{\left(\pi \cdot \left|\theta\right|\right)}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |1 - e^{2 * pi * i * theta}| = (2 * sin(pi * |theta|))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|1 - e^{2 * pi * i * theta}|, 2 * sin(pi * |theta|))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |1 - e^{2 * pi * i * theta}|
#    core type: Operation
#    operator: 23
#    operand: 7
# 4. 2 * sin(pi * |theta|)
#    core type: Operation
#    operator: 27
#    operands: 6
# 5. (1 - e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (2, sin(pi * |theta|))
#    core type: ExprTuple
#    sub-expressions: 29, 8
# 7. 1 - e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. sin(pi * |theta|)
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (1, -e^{2 * pi * i * theta})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. sin
#     core type: Literal
#     sub-expressions:
# 12. (pi * |theta|)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. -e^{2 * pi * i * theta}
#     core type: Operation
#     operator: 16
#     operand: 19
# 15. pi * |theta|
#     core type: Operation
#     operator: 27
#     operands: 18
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (e^{2 * pi * i * theta})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (pi, |theta|)
#     core type: ExprTuple
#     sub-expressions: 30, 20
# 19. e^{2 * pi * i * theta}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. |theta|
#     core type: Operation
#     operator: 23
#     operand: 32
# 21. Exp
#     core type: Literal
#     sub-expressions:
# 22. (e, 2 * pi * i * theta)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Abs
#     core type: Literal
#     sub-expressions:
# 24. (theta)
#     core type: ExprTuple
#     sub-expressions: 32
# 25. e
#     core type: Literal
#     sub-expressions:
# 26. 2 * pi * i * theta
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (2, pi, i, theta)
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31, 32
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. pi
#     core type: Literal
#     sub-expressions:
# 31. i
#     core type: Literal
#     sub-expressions:
# 32. theta
#     core type: Variable
#     sub-expressions:
