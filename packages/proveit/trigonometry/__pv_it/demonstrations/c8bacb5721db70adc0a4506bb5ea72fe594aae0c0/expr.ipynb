# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Add, Exp, Mult, Neg, e, i, one, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(one, Exp(e, Mult(i, Add(Mult(two, pi, theta), pi)))), Neg(Exp(e, Mult(two, pi, i, theta))))
# Out:
# expr: (1 * e^{i * ((2 * pi * theta) + pi)}, -e^{2 * pi * i * theta})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right)}, -\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \theta}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 * e^{i * ((2 * pi * theta) + pi)}, -e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 * e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 22
#    operands: 3
# 2. -e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (1, e^{i * ((2 * pi * theta) + pi)})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. -
#    core type: Literal
#    sub-expressions:
# 5. (e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (e, i * ((2 * pi * theta) + pi))
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (e, 2 * pi * i * theta)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. i * ((2 * pi * theta) + pi)
#     core type: Operation
#     operator: 22
#     operands: 15
# 13. e
#     core type: Literal
#     sub-expressions:
# 14. 2 * pi * i * theta
#     core type: Operation
#     operator: 22
#     operands: 16
# 15. (i, (2 * pi * theta) + pi)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 16. (2, pi, i, theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 18, 26
# 17. (2 * pi * theta) + pi
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. i
#     core type: Literal
#     sub-expressions:
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 21, 25
# 21. 2 * pi * theta
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. pi
#     core type: Literal
#     sub-expressions:
# 26. theta
#     core type: Variable
#     sub-expressions:
