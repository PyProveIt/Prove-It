# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Add, Exp, Mult, e, i, one, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(one, Exp(e, Mult(i, Add(Mult(two, pi, theta), pi))))
# Out:
# expr: (1, e^{i * ((2 * pi * theta) + pi)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1, \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1, e^{i * ((2 * pi * theta) + pi)})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1
#    core type: Literal
#    sub-expressions:
# 2. e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. Exp
#    core type: Literal
#    sub-expressions:
# 4. (e, i * ((2 * pi * theta) + pi))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. e
#    core type: Literal
#    sub-expressions:
# 6. i * ((2 * pi * theta) + pi)
#    core type: Operation
#    operator: 13
#    operands: 7
# 7. (i, (2 * pi * theta) + pi)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. i
#    core type: Literal
#    sub-expressions:
# 9. (2 * pi * theta) + pi
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. +
#     core type: Literal
#     sub-expressions:
# 11. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 12, 16
# 12. 2 * pi * theta
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. pi
#     core type: Literal
#     sub-expressions:
# 17. theta
#     core type: Variable
#     sub-expressions:
