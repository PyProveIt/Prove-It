# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two, zero

# %%
# build up the expression from sub-expressions
expr = Equals(frac(Abs(Add(zero, Neg(Mult(two, pi, theta)))), two), frac(Mult(two, pi, Abs(theta)), two))
# Out:
# expr: (|0 - (2 * pi * theta)| / 2) = ((2 * pi * |theta|) / 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{\left|0 - \left(2 \cdot \pi \cdot \theta\right)\right|}{2} = \frac{2 \cdot \pi \cdot \left|\theta\right|}{2}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|0 - (2 * pi * theta)| / 2) = ((2 * pi * |theta|) / 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|0 - (2 * pi * theta)| / 2, (2 * pi * |theta|) / 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |0 - (2 * pi * theta)| / 2
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * pi * |theta|) / 2
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|0 - (2 * pi * theta)|, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 25
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (2 * pi * |theta|, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 25
# 8. |0 - (2 * pi * theta)|
#    core type: Operation
#    operator: 16
#    operand: 12
# 9. 2 * pi * |theta|
#    core type: Operation
#    operator: 23
#    operands: 11
# 10. (0 - (2 * pi * theta))
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (2, pi, |theta|)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 13
# 12. 0 - (2 * pi * theta)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. |theta|
#     core type: Operation
#     operator: 16
#     operand: 27
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (0, -(2 * pi * theta))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. Abs
#     core type: Literal
#     sub-expressions:
# 17. (theta)
#     core type: ExprTuple
#     sub-expressions: 27
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. -(2 * pi * theta)
#     core type: Operation
#     operator: 20
#     operand: 22
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (2 * pi * theta)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. 2 * pi * theta
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27
# 25. 2
#     core type: Literal
#     sub-expressions:
# 26. pi
#     core type: Literal
#     sub-expressions:
# 27. theta
#     core type: Variable
#     sub-expressions:
