# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, c, r
from proveit.numbers import Add, Exp, Mult, Neg, e, i

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(Mult(r, Exp(e, Mult(i, a)), c), Neg(Mult(r, c, Exp(e, Mult(i, b))))))
# Out:
# expr: ((r * e^{i * a} * c) - (r * c * e^{i * b}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a} \cdot c\right) - \left(r \cdot c \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((r * e^{i * a} * c) - (r * c * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (r * e^{i * a} * c) - (r * c * e^{i * b})
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. +
#    core type: Literal
#    sub-expressions:
# 3. (r * e^{i * a} * c, -(r * c * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. r * e^{i * a} * c
#    core type: Operation
#    operator: 23
#    operands: 6
# 5. -(r * c * e^{i * b})
#    core type: Operation
#    operator: 7
#    operand: 10
# 6. (r, e^{i * a}, c)
#    core type: ExprTuple
#    sub-expressions: 14, 9, 15
# 7. -
#    core type: Literal
#    sub-expressions:
# 8. (r * c * e^{i * b})
#    core type: ExprTuple
#    sub-expressions: 10
# 9. e^{i * a}
#    core type: Operation
#    operator: 18
#    operands: 11
# 10. r * c * e^{i * b}
#     core type: Operation
#     operator: 23
#     operands: 12
# 11. (e, i * a)
#     core type: ExprTuple
#     sub-expressions: 21, 13
# 12. (r, c, e^{i * b})
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 13. i * a
#     core type: Operation
#     operator: 23
#     operands: 17
# 14. r
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. e^{i * b}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (i, a)
#     core type: ExprTuple
#     sub-expressions: 25, 20
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (e, i * b)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. e
#     core type: Literal
#     sub-expressions:
# 22. i * b
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (i, b)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. i
#     core type: Literal
#     sub-expressions:
# 26. b
#     core type: Variable
#     sub-expressions:
