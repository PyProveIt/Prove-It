# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Abs, Add, Mult, Neg, pi, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(Mult(two, pi, theta))
expr = ExprTuple(Abs(Add(zero, sub_expr1)), Abs(sub_expr1))
# Out:
# expr: (|0 - (2 * pi * theta)|, |-(2 * pi * theta)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|0 - \left(2 \cdot \pi \cdot \theta\right)\right|, \left|-\left(2 \cdot \pi \cdot \theta\right)\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|0 - (2 * pi * theta)|, |-(2 * pi * theta)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |0 - (2 * pi * theta)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |-(2 * pi * theta)|
#    core type: Operation
#    operator: 4
#    operand: 10
# 3. (0 - (2 * pi * theta))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. Abs
#    core type: Literal
#    sub-expressions:
# 5. (-(2 * pi * theta))
#    core type: ExprTuple
#    sub-expressions: 10
# 6. 0 - (2 * pi * theta)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (0, -(2 * pi * theta))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. 0
#    core type: Literal
#    sub-expressions:
# 10. -(2 * pi * theta)
#     core type: Operation
#     operator: 11
#     operand: 13
# 11. -
#     core type: Literal
#     sub-expressions:
# 12. (2 * pi * theta)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. 2 * pi * theta
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. pi
#     core type: Literal
#     sub-expressions:
# 18. theta
#     core type: Variable
#     sub-expressions:
