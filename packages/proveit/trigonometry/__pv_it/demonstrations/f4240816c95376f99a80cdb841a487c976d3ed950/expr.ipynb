# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two, zero

# %%
# build up the expression from sub-expressions
expr = ExprTuple(frac(Abs(Add(zero, Neg(Mult(two, pi, theta)))), two), Mult(pi, Abs(theta)))
# Out:
# expr: (|0 - (2 * pi * theta)| / 2, pi * |theta|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{\left|0 - \left(2 \cdot \pi \cdot \theta\right)\right|}{2}, \pi \cdot \left|\theta\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|0 - (2 * pi * theta)| / 2, pi * |theta|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |0 - (2 * pi * theta)| / 2
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. pi * |theta|
#    core type: Operation
#    operator: 19
#    operands: 5
# 3. /
#    core type: Literal
#    sub-expressions:
# 4. (|0 - (2 * pi * theta)|, 2)
#    core type: ExprTuple
#    sub-expressions: 6, 21
# 5. (pi, |theta|)
#    core type: ExprTuple
#    sub-expressions: 22, 7
# 6. |0 - (2 * pi * theta)|
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. |theta|
#    core type: Operation
#    operator: 9
#    operand: 23
# 8. (0 - (2 * pi * theta))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. (theta)
#     core type: ExprTuple
#     sub-expressions: 23
# 11. 0 - (2 * pi * theta)
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. +
#     core type: Literal
#     sub-expressions:
# 13. (0, -(2 * pi * theta))
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 0
#     core type: Literal
#     sub-expressions:
# 15. -(2 * pi * theta)
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (2 * pi * theta)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. 2 * pi * theta
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. pi
#     core type: Literal
#     sub-expressions:
# 23. theta
#     core type: Variable
#     sub-expressions:
