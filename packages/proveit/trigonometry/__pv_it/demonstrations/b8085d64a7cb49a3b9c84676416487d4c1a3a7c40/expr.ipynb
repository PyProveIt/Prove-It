# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Add, Exp, Mult, Neg, e, i, one, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(one, Neg(Exp(e, Mult(two, pi, i, theta)))))
# Out:
# expr: (1 - e^{2 * pi * i * theta})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \theta}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 - e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. 1 - e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. +
#    core type: Literal
#    sub-expressions:
# 3. (1, -e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. 1
#    core type: Literal
#    sub-expressions:
# 5. -e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 6
#    operand: 8
# 6. -
#    core type: Literal
#    sub-expressions:
# 7. (e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 8
# 8. e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (e, 2 * pi * i * theta)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. e
#     core type: Literal
#     sub-expressions:
# 12. 2 * pi * i * theta
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, pi, i, theta)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. pi
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Literal
#     sub-expressions:
# 18. theta
#     core type: Variable
#     sub-expressions:
