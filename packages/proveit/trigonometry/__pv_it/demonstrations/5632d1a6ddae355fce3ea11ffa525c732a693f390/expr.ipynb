# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, theta
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(frac(Abs(Add(Add(Mult(two, pi, theta), pi), Neg(pi))), two), frac(Mult(two, pi, Abs(theta)), two))
# Out:
# expr: (|((2 * pi * theta) + pi) - pi| / 2, (2 * pi * |theta|) / 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{\left|\left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right) - \pi\right|}{2}, \frac{2 \cdot \pi \cdot \left|\theta\right|}{2}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|((2 * pi * theta) + pi) - pi| / 2, (2 * pi * |theta|) / 2)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |((2 * pi * theta) + pi) - pi| / 2
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2 * pi * |theta|) / 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (|((2 * pi * theta) + pi) - pi|, 2)
#    core type: ExprTuple
#    sub-expressions: 6, 24
# 4. /
#    core type: Literal
#    sub-expressions:
# 5. (2 * pi * |theta|, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 24
# 6. |((2 * pi * theta) + pi) - pi|
#    core type: Operation
#    operator: 13
#    operand: 10
# 7. 2 * pi * |theta|
#    core type: Operation
#    operator: 22
#    operands: 9
# 8. (((2 * pi * theta) + pi) - pi)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. (2, pi, |theta|)
#    core type: ExprTuple
#    sub-expressions: 24, 25, 11
# 10. ((2 * pi * theta) + pi) - pi
#     core type: Operation
#     operator: 17
#     operands: 12
# 11. |theta|
#     core type: Operation
#     operator: 13
#     operand: 26
# 12. ((2 * pi * theta) + pi, -pi)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. Abs
#     core type: Literal
#     sub-expressions:
# 14. (theta)
#     core type: ExprTuple
#     sub-expressions: 26
# 15. (2 * pi * theta) + pi
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. -pi
#     core type: Operation
#     operator: 19
#     operand: 25
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 21, 25
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (pi)
#     core type: ExprTuple
#     sub-expressions: 25
# 21. 2 * pi * theta
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. pi
#     core type: Literal
#     sub-expressions:
# 26. theta
#     core type: Variable
#     sub-expressions:
