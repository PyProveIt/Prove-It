# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, pi, two

# %%
# build up the expression from sub-expressions
expr = Equals(Abs(Add(Add(Mult(two, pi, theta), pi), Neg(pi))), Mult(two, pi, Abs(theta)))
# Out:
# expr: |((2 * pi * theta) + pi) - pi| = (2 * pi * |theta|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right) - \pi\right| = \left(2 \cdot \pi \cdot \left|\theta\right|\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |((2 * pi * theta) + pi) - pi| = (2 * pi * |theta|)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|((2 * pi * theta) + pi) - pi|, 2 * pi * |theta|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |((2 * pi * theta) + pi) - pi|
#    core type: Operation
#    operator: 10
#    operand: 7
# 4. 2 * pi * |theta|
#    core type: Operation
#    operator: 19
#    operands: 6
# 5. (((2 * pi * theta) + pi) - pi)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (2, pi, |theta|)
#    core type: ExprTuple
#    sub-expressions: 21, 22, 8
# 7. ((2 * pi * theta) + pi) - pi
#    core type: Operation
#    operator: 14
#    operands: 9
# 8. |theta|
#    core type: Operation
#    operator: 10
#    operand: 23
# 9. ((2 * pi * theta) + pi, -pi)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. (theta)
#     core type: ExprTuple
#     sub-expressions: 23
# 12. (2 * pi * theta) + pi
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. -pi
#     core type: Operation
#     operator: 16
#     operand: 22
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 18, 22
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (pi)
#     core type: ExprTuple
#     sub-expressions: 22
# 18. 2 * pi * theta
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. pi
#     core type: Literal
#     sub-expressions:
# 23. theta
#     core type: Variable
#     sub-expressions:
