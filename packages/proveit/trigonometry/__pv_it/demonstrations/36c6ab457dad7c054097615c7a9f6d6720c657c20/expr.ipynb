# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, e, i, one, pi, two

# %%
# build up the expression from sub-expressions
expr = Equals(Mult(one, Exp(e, Mult(i, Add(Mult(two, pi, theta), pi)))), Neg(Exp(e, Mult(two, pi, i, theta))))
# Out:
# expr: (1 * e^{i * ((2 * pi * theta) + pi)}) = (-e^{2 * pi * i * theta})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right)}\right) = \left(-\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \theta}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 * e^{i * ((2 * pi * theta) + pi)}) = (-e^{2 * pi * i * theta})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1 * e^{i * ((2 * pi * theta) + pi)}, -e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 1 * e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 24
#    operands: 5
# 4. -e^{2 * pi * i * theta}
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (1, e^{i * ((2 * pi * theta) + pi)})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. -
#    core type: Literal
#    sub-expressions:
# 7. (e^{2 * pi * i * theta})
#    core type: ExprTuple
#    sub-expressions: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. e^{2 * pi * i * theta}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (e, i * ((2 * pi * theta) + pi))
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (e, 2 * pi * i * theta)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. i * ((2 * pi * theta) + pi)
#     core type: Operation
#     operator: 24
#     operands: 17
# 15. e
#     core type: Literal
#     sub-expressions:
# 16. 2 * pi * i * theta
#     core type: Operation
#     operator: 24
#     operands: 18
# 17. (i, (2 * pi * theta) + pi)
#     core type: ExprTuple
#     sub-expressions: 20, 19
# 18. (2, pi, i, theta)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 20, 28
# 19. (2 * pi * theta) + pi
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. i
#     core type: Literal
#     sub-expressions:
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 23, 27
# 23. 2 * pi * theta
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. pi
#     core type: Literal
#     sub-expressions:
# 28. theta
#     core type: Variable
#     sub-expressions:
