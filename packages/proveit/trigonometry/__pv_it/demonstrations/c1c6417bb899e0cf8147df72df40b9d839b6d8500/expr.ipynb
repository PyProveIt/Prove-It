# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, e, i, one, pi, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(e, Mult(i, Add(Mult(two, pi, theta), pi)))
expr = Equals(Mult(one, sub_expr1), sub_expr1)
# Out:
# expr: (1 * e^{i * ((2 * pi * theta) + pi)}) = e^{i * ((2 * pi * theta) + pi)}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right)}\right) = \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right)}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 * e^{i * ((2 * pi * theta) + pi)}) = e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (1 * e^{i * ((2 * pi * theta) + pi)}, e^{i * ((2 * pi * theta) + pi)})
#    core type: ExprTuple
#    sub-expressions: 3, 6
# 3. 1 * e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 17
#    operands: 4
# 4. (1, e^{i * ((2 * pi * theta) + pi)})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. e^{i * ((2 * pi * theta) + pi)}
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (e, i * ((2 * pi * theta) + pi))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. e
#    core type: Literal
#    sub-expressions:
# 10. i * ((2 * pi * theta) + pi)
#     core type: Operation
#     operator: 17
#     operands: 11
# 11. (i, (2 * pi * theta) + pi)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. i
#     core type: Literal
#     sub-expressions:
# 13. (2 * pi * theta) + pi
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2 * pi * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 16, 20
# 16. 2 * pi * theta
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. *
#     core type: Literal
#     sub-expressions:
# 18. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. pi
#     core type: Literal
#     sub-expressions:
# 21. theta
#     core type: Variable
#     sub-expressions:
