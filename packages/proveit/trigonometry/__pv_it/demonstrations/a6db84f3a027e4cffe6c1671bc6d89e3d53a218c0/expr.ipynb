# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Abs.html">Abs</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.numbers import Abs, Add, Mult, Neg, pi, two

# %%
# build up the expression from sub-expressions
expr = Abs(Add(Add(Mult(two, pi, theta), pi), Neg(pi)))
# Out:
# expr: |((2 * pi * theta) + pi) - pi|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\left(\left(2 \cdot \pi \cdot \theta\right) + \pi\right) - \pi\right|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |((2 * pi * theta) + pi) - pi|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Abs
#    core type: Literal
#    sub-expressions:
# 2. (((2 * pi * theta) + pi) - pi)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. ((2 * pi * theta) + pi) - pi
#    core type: Operation
#    operator: 7
#    operands: 4
# 4. ((2 * pi * theta) + pi, -pi)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. (2 * pi * theta) + pi
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. -pi
#    core type: Operation
#    operator: 9
#    operand: 15
# 7. +
#    core type: Literal
#    sub-expressions:
# 8. (2 * pi * theta, pi)
#    core type: ExprTuple
#    sub-expressions: 11, 15
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (pi)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. 2 * pi * theta
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2, pi, theta)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. pi
#     core type: Literal
#     sub-expressions:
# 16. theta
#     core type: Variable
#     sub-expressions:
