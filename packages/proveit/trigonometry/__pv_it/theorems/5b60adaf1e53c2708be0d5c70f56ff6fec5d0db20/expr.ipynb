# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, r
from proveit.logic import And, Equals, InSet
from proveit.numbers import Abs, Add, Exp, Mult, Neg, Real, e, frac, i, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda([a, b], Conditional(Equals(Abs(Add(Mult(r, Exp(e, Mult(i, a))), Neg(Mult(r, Exp(e, Mult(i, b)))))), Mult(two, r, Sin(frac(Abs(Add(a, Neg(b))), two)))), And(InSet(a, Real), InSet(b, Real))))
# Out:
# expr: (a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a, b\right) \mapsto \left\{\left|\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right) - \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right| = \left(2 \cdot r \cdot \sin{\frac{\left|a - b\right|}{2}}\right) \textrm{ if } a \in \mathbb{R} ,  b \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a, b)
#    core type: ExprTuple
#    sub-expressions: 50, 57
# 2. {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. |(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (a in Real) and (b in Real)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|(r * e^{i * a}) - (r * e^{i * b})|, 2 * r * sin(|a - b| / 2))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (a in Real, b in Real)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. |(r * e^{i * a}) - (r * e^{i * b})|
#    core type: Operation
# ...
