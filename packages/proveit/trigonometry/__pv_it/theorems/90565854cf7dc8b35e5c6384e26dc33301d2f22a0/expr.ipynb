# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, theta
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Mult, RealNonNeg, frac, greater_eq, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Conditional(greater_eq(Sin(theta), frac(Mult(two, theta), pi)), And(InSet(theta, RealNonNeg), LessEq(theta, frac(pi, two))))
# Out:
# expr: {sin(theta) >= ((2 * theta) / pi) if theta in RealNonNeg ,  theta <= (pi / 2).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\sin{\theta} \geq \frac{2 \cdot \theta}{\pi} \textrm{ if } \theta \in \mathbb{R}^{\ge 0} ,  \theta \leq \frac{\pi}{2}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {sin(theta) >= ((2 * theta) / pi) if theta in RealNonNeg ,  theta <= (pi / 2).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. sin(theta) >= ((2 * theta) / pi)
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. (theta in RealNonNeg) and (theta <= (pi / 2))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((2 * theta) / pi, sin(theta))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. and
#    core type: Literal
#    sub-expressions:
# 5. (theta in RealNonNeg, theta <= (pi / 2))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. (2 * theta) / pi
#    core type: Operation
#    operator: 22
#    operands: 10
# 7. sin(theta)
#    core type: Operation
#    operator: 11
#    operand: 24
# 8. theta in RealNonNeg
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. theta <= (pi / 2)
#    core type: Operation
#    operator: 15
#    operands: 16
# 10. (2 * theta, pi)
#     core type: ExprTuple
# ...
