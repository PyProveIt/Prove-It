# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b, r
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, frac, i, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Abs(Add(Mult(r, Exp(e, Mult(i, a))), Neg(Mult(r, Exp(e, Mult(i, b)))))), Mult(two, r, Sin(frac(Abs(Add(a, Neg(b))), two))))
# Out:
# expr: (|(r * e^{i * a}) - (r * e^{i * b})|, 2 * r * sin(|a - b| / 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right) - \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right|, 2 \cdot r \cdot \sin{\frac{\left|a - b\right|}{2}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(r * e^{i * a}) - (r * e^{i * b})|, 2 * r * sin(|a - b| / 2))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(r * e^{i * a}) - (r * e^{i * b})|
#    core type: Operation
#    operator: 23
#    operand: 5
# 2. 2 * r * sin(|a - b| / 2)
#    core type: Operation
#    operator: 38
#    operands: 4
# 3. ((r * e^{i * a}) - (r * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (2, r, sin(|a - b| / 2))
#    core type: ExprTuple
#    sub-expressions: 20, 26, 6
# 5. (r * e^{i * a}) - (r * e^{i * b})
#    core type: Operation
#    operator: 32
#    operands: 7
# 6. sin(|a - b| / 2)
#    core type: Operation
#    operator: 8
#    operand: 12
# 7. (r * e^{i * a}, -(r * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. sin
#    core type: Literal
#    sub-expressions:
# 9. (|a - b| / 2)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. r * e^{i * a}
#     core type: Operation
#     operator: 38
#     operands: 13
# ...
