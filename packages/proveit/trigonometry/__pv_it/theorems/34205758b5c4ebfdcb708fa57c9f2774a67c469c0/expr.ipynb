# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import And, InSet
from proveit.numbers import Abs, LessEq, Real, frac, pi, two

# %%
# build up the expression from sub-expressions
expr = And(InSet(theta, Real), LessEq(Abs(theta), frac(pi, two)))
# Out:
# expr: (theta in Real) and (|theta| <= (pi / 2))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\theta \in \mathbb{R}\right) \land \left(\left|\theta\right| \leq \frac{\pi}{2}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (theta in Real) and (|theta| <= (pi / 2))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (theta in Real, |theta| <= (pi / 2))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. theta in Real
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. |theta| <= (pi / 2)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (theta, Real)
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. <=
#    core type: Literal
#    sub-expressions:
# 8. (|theta|, pi / 2)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. |theta|
#     core type: Operation
#     operator: 12
#     operand: 16
# 11. pi / 2
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. (theta)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (pi, 2)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. theta
#     core type: Variable
#     sub-expressions:
# 17. pi
#     core type: Literal
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
