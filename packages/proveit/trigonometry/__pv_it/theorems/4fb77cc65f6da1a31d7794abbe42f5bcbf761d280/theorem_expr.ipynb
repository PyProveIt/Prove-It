# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sine_nonneg_interval">sine_nonneg_interval</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.trigonometry import sine_nonneg_interval

# %%
# check that the built expression is the same as the stored expression
assert sine_nonneg_interval.expr == stored_expr
assert sine_nonneg_interval.expr._style_id == stored_expr._style_id
print("Passed sanity check: sine_nonneg_interval matches stored_expr")
# Out:
# Passed sanity check: sine_nonneg_interval matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sine_nonneg_interval.latex())
# Out:
# \vdash \forall_{\theta \in \left[0,\pi\right]}~\left(\sin{\theta} \in \left[0,1\right]\right)

# %%
sine_nonneg_interval.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
sine_nonneg_interval.expr_info()
# Out:
# 0. forall_{theta in [0,pi]} (sin(theta) in [0,1])
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (theta -> {sin(theta) in [0,1] if theta in [0,pi].)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. theta -> {sin(theta) in [0,1] if theta in [0,pi].
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. {sin(theta) in [0,1] if theta in [0,pi].
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. sin(theta) in [0,1]
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. theta in [0,pi]
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (sin(theta), [0,1])
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (theta, [0,pi])
#    core type: ExprTuple
#    sub-expressions: 18, 12
# 10. sin(theta)
#     core type: Operation
#     operator: 13
#     operand: 18
# 11. [0,1]
#     core type: Operation
# ...
