# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#sine_linear_bound_pos">sine_linear_bound_pos</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.trigonometry import sine_linear_bound_pos

# %%
# check that the built expression is the same as the stored expression
assert sine_linear_bound_pos.expr == stored_expr
assert sine_linear_bound_pos.expr._style_id == stored_expr._style_id
print("Passed sanity check: sine_linear_bound_pos matches stored_expr")
# Out:
# Passed sanity check: sine_linear_bound_pos matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(sine_linear_bound_pos.latex())
# Out:
# \vdash \forall_{\theta \in \mathbb{R}^+~|~\theta \leq \frac{\pi}{2}}~\left(\sin{\theta} > \frac{2 \cdot \theta}{\pi}\right)

# %%
sine_linear_bound_pos.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
sine_linear_bound_pos.expr_info()
# Out:
# 0. forall_{theta in RealPos | theta <= (pi / 2)} (sin(theta) > ((2 * theta) / pi))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (theta -> {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. theta -> {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).
#    core type: Lambda
#    parameter: 29
#    body: 4
# 4. {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. sin(theta) > ((2 * theta) / pi)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (theta in RealPos) and (theta <= (pi / 2))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. ((2 * theta) / pi, sin(theta))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
# ...
