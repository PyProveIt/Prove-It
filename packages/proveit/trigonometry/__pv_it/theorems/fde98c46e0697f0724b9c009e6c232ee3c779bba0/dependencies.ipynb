# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#sine_linear_bound_pos">sine_linear_bound_pos</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/sine_linear_bound_pos/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.trigonometry import sine_linear_bound_pos

# %%
# %dependencies sine_linear_bound_pos
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon sine_linear_bound_pos</h3>
