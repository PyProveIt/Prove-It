# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, theta
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(theta, Conditional(InSet(Sin(theta), Real), InSet(theta, Real))))
# Out:
# expr: (theta -> {sin(theta) in Real if theta in Real.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\theta \mapsto \left\{\sin{\theta} \in \mathbb{R} \textrm{ if } \theta \in \mathbb{R}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (theta -> {sin(theta) in Real if theta in Real.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. theta -> {sin(theta) in Real if theta in Real.
#    core type: Lambda
#    parameter: 12
#    body: 2
# 2. {sin(theta) in Real if theta in Real.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. sin(theta) in Real
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. theta in Real
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (sin(theta), Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (theta, Real)
#    core type: ExprTuple
#    sub-expressions: 12, 9
# 8. sin(theta)
#    core type: Operation
#    operator: 10
#    operand: 12
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. sin
#     core type: Literal
#     sub-expressions:
# 11. (theta)
#     core type: ExprTuple
#     sub-expressions: 12
# 12. theta
#     core type: Variable
#     sub-expressions:
