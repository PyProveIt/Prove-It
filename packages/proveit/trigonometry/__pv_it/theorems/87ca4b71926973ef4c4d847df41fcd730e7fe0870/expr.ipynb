# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.logic import Forall
from proveit.numbers import Less, LessEq, Mult, Neg, RealNeg, frac, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Forall([theta], Less(Sin(theta), frac(Mult(two, theta), pi)), domain = RealNeg, condition = LessEq(Neg(theta), frac(pi, two)))
# Out:
# expr: forall_{theta in RealNeg | (-theta) <= (pi / 2)} (sin(theta) < ((2 * theta) / pi))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\theta \in \mathbb{R}^-~|~\left(-\theta\right) \leq \frac{\pi}{2}}~\left(\sin{\theta} < \frac{2 \cdot \theta}{\pi}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{theta in RealNeg | (-theta) <= (pi / 2)} (sin(theta) < ((2 * theta) / pi))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (theta -> {sin(theta) < ((2 * theta) / pi) if theta in RealNeg ,  (-theta) <= (pi / 2).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. theta -> {sin(theta) < ((2 * theta) / pi) if theta in RealNeg ,  (-theta) <= (pi / 2).
#    core type: Lambda
#    parameter: 31
#    body: 4
# 4. {sin(theta) < ((2 * theta) / pi) if theta in RealNeg ,  (-theta) <= (pi / 2).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. sin(theta) < ((2 * theta) / pi)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (theta in RealNeg) and ((-theta) <= (pi / 2))
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. <
#    core type: Literal
#    sub-expressions:
# 8. (sin(theta), (2 * theta) / pi)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (theta in RealNeg, (-theta) <= (pi / 2))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. sin(theta)
#     core type: Operation
#     operator: 15
#     operand: 31
# 12. (2 * theta) / pi
#     core type: Operation
#     operator: 29
#     operands: 16
# 13. theta in RealNeg
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (-theta) <= (pi / 2)
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. sin
#     core type: Literal
#     sub-expressions:
# 16. (2 * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 21, 32
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (theta, RealNeg)
#     core type: ExprTuple
#     sub-expressions: 31, 22
# 19. <=
#     core type: Literal
#     sub-expressions:
# 20. (-theta, pi / 2)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. 2 * theta
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. RealNeg
#     core type: Literal
#     sub-expressions:
# 23. -theta
#     core type: Operation
#     operator: 27
#     operand: 31
# 24. pi / 2
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (2, theta)
#     core type: ExprTuple
#     sub-expressions: 33, 31
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. (theta)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (pi, 2)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 31. theta
#     core type: Variable
#     sub-expressions:
# 32. pi
#     core type: Literal
#     sub-expressions:
# 33. 2
#     core type: Literal
#     sub-expressions:
