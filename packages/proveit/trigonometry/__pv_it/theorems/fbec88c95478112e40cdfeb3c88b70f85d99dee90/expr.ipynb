# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, theta
from proveit.logic import InSet
from proveit.numbers import IntervalOC, IntervalOO, one, pi, zero
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda(theta, Conditional(InSet(Sin(theta), IntervalOC(zero, one)), InSet(theta, IntervalOO(zero, pi))))
# Out:
# expr: theta -> {sin(theta) in (0,1] if theta in (0,pi).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \theta \mapsto \left\{\sin{\theta} \in \left(0,1\right] \textrm{ if } \theta \in \left(0,\pi\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. theta -> {sin(theta) in (0,1] if theta in (0,pi).
#    core type: Lambda
#    parameter: 16
#    body: 1
# 1. {sin(theta) in (0,1] if theta in (0,pi).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. sin(theta) in (0,1]
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. theta in (0,pi)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (sin(theta), (0,1])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (theta, (0,pi))
#    core type: ExprTuple
#    sub-expressions: 16, 9
# 7. sin(theta)
#    core type: Operation
#    operator: 10
#    operand: 16
# 8. (0,1]
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (0,pi)
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. sin
#     core type: Literal
#     sub-expressions:
# 11. (theta)
#     core type: ExprTuple
#     sub-expressions: 16
# 12. IntervalOC
#     core type: Literal
#     sub-expressions:
# 13. (0, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 14. IntervalOO
#     core type: Literal
#     sub-expressions:
# 15. (0, pi)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. theta
#     core type: Variable
#     sub-expressions:
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 0
#     core type: Literal
#     sub-expressions:
# 19. pi
#     core type: Literal
#     sub-expressions:
