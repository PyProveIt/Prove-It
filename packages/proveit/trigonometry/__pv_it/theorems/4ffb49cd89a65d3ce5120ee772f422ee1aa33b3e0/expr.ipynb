# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, theta
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Mult, RealPos, frac, greater, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Conditional(greater(Sin(theta), frac(Mult(two, theta), pi)), And(InSet(theta, RealPos), LessEq(theta, frac(pi, two))))
# Out:
# expr: {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\sin{\theta} > \frac{2 \cdot \theta}{\pi} \textrm{ if } \theta \in \mathbb{R}^+ ,  \theta \leq \frac{\pi}{2}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. sin(theta) > ((2 * theta) / pi)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (theta in RealPos) and (theta <= (pi / 2))
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <
#    core type: Literal
#    sub-expressions:
# 4. ((2 * theta) / pi, sin(theta))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (theta in RealPos, theta <= (pi / 2))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. (2 * theta) / pi
#    core type: Operation
#    operator: 23
#    operands: 11
# 8. sin(theta)
#    core type: Operation
#    operator: 12
#    operand: 25
# 9. theta in RealPos
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. theta <= (pi / 2)
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. (2 * theta, pi)
#     core type: ExprTuple
#     sub-expressions: 18, 26
# 12. sin
#     core type: Literal
#     sub-expressions:
# 13. (theta)
#     core type: ExprTuple
#     sub-expressions: 25
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (theta, RealPos)
#     core type: ExprTuple
#     sub-expressions: 25, 19
# 16. <=
#     core type: Literal
#     sub-expressions:
# 17. (theta, pi / 2)
#     core type: ExprTuple
#     sub-expressions: 25, 20
# 18. 2 * theta
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. RealPos
#     core type: Literal
#     sub-expressions:
# 20. pi / 2
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. *
#     core type: Literal
#     sub-expressions:
# 22. (2, theta)
#     core type: ExprTuple
#     sub-expressions: 27, 25
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (pi, 2)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 25. theta
#     core type: Variable
#     sub-expressions:
# 26. pi
#     core type: Literal
#     sub-expressions:
# 27. 2
#     core type: Literal
#     sub-expressions:
