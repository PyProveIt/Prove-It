# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Abs.html">Abs</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, r
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, i

# %%
# build up the expression from sub-expressions
expr = Abs(Add(Mult(r, Exp(e, Mult(i, a))), Neg(Mult(r, Exp(e, Mult(i, b))))))
# Out:
# expr: |(r * e^{i * a}) - (r * e^{i * b})|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right) - \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(r * e^{i * a}) - (r * e^{i * b})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Abs
#    core type: Literal
#    sub-expressions:
# 2. ((r * e^{i * a}) - (r * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (r * e^{i * a}) - (r * e^{i * b})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (r * e^{i * a}, -(r * e^{i * b}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. r * e^{i * a}
#    core type: Operation
#    operator: 24
#    operands: 8
# 7. -(r * e^{i * b})
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. (r, e^{i * a})
#    core type: ExprTuple
#    sub-expressions: 16, 11
# 9. -
#    core type: Literal
#    sub-expressions:
# 10. (r * e^{i * b})
#     core type: ExprTuple
#     sub-expressions: 12
# 11. e^{i * a}
#     core type: Operation
#     operator: 19
#     operands: 13
# 12. r * e^{i * b}
#     core type: Operation
#     operator: 24
#     operands: 14
# 13. (e, i * a)
#     core type: ExprTuple
#     sub-expressions: 22, 15
# 14. (r, e^{i * b})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. i * a
#     core type: Operation
#     operator: 24
#     operands: 18
# 16. r
#     core type: Variable
#     sub-expressions:
# 17. e^{i * b}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (i, a)
#     core type: ExprTuple
#     sub-expressions: 26, 21
# 19. Exp
#     core type: Literal
#     sub-expressions:
# 20. (e, i * b)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. a
#     core type: Variable
#     sub-expressions:
# 22. e
#     core type: Literal
#     sub-expressions:
# 23. i * b
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (i, b)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. i
#     core type: Literal
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
