# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import theta
from proveit.numbers import Abs, Mult, frac, greater_eq, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(theta)
expr = greater_eq(Sin(sub_expr1), frac(Mult(two, sub_expr1), pi))
# Out:
# expr: sin(|theta|) >= ((2 * |theta|) / pi)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sin{\left|\theta\right|} \geq \frac{2 \cdot \left|\theta\right|}{\pi}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: reversed
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. sin(|theta|) >= ((2 * |theta|) / pi)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. ((2 * |theta|) / pi, sin(|theta|))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * |theta|) / pi
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. sin(|theta|)
#    core type: Operation
#    operator: 7
#    operand: 14
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (2 * |theta|, pi)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. sin
#    core type: Literal
#    sub-expressions:
# 8. (|theta|)
#    core type: ExprTuple
#    sub-expressions: 14
# 9. 2 * |theta|
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. pi
#     core type: Literal
#     sub-expressions:
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, |theta|)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2
#     core type: Literal
#     sub-expressions:
# 14. |theta|
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. Abs
#     core type: Literal
#     sub-expressions:
# 16. (theta)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. theta
#     core type: Variable
#     sub-expressions:
