# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, theta
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda(theta, Conditional(InSet(Sin(theta), Real), InSet(theta, Real)))
# Out:
# expr: theta -> {sin(theta) in Real if theta in Real.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \theta \mapsto \left\{\sin{\theta} \in \mathbb{R} \textrm{ if } \theta \in \mathbb{R}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. theta -> {sin(theta) in Real if theta in Real.
#    core type: Lambda
#    parameter: 11
#    body: 1
# 1. {sin(theta) in Real if theta in Real.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. sin(theta) in Real
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. theta in Real
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (sin(theta), Real)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (theta, Real)
#    core type: ExprTuple
#    sub-expressions: 11, 8
# 7. sin(theta)
#    core type: Operation
#    operator: 9
#    operand: 11
# 8. Real
#    core type: Literal
#    sub-expressions:
# 9. sin
#    core type: Literal
#    sub-expressions:
# 10. (theta)
#     core type: ExprTuple
#     sub-expressions: 11
# 11. theta
#     core type: Variable
#     sub-expressions:
