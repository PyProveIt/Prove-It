# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, b, r
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Abs, Add, Exp, Mult, Neg, Real, RealNonNeg, e, frac, i, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda(r, Conditional(Forall([a, b], Equals(Abs(Add(Mult(r, Exp(e, Mult(i, a))), Neg(Mult(r, Exp(e, Mult(i, b)))))), Mult(two, r, Sin(frac(Abs(Add(a, Neg(b))), two)))), domain = Real), InSet(r, RealNonNeg)))
# Out:
# expr: r -> {forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))) if r in RealNonNeg.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# r \mapsto \left\{\forall_{a, b \in \mathbb{R}}~\left(\left|\left(r \cdot \mathsf{e}^{\mathsf{i} \cdot a}\right) - \left(r \cdot \mathsf{e}^{\mathsf{i} \cdot b}\right)\right| = \left(2 \cdot r \cdot \sin{\frac{\left|a - b\right|}{2}}\right)\right) \textrm{ if } r \in \mathbb{R}^{\ge 0}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. r -> {forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))) if r in RealNonNeg.
#    core type: Lambda
#    parameter: 48
#    body: 1
# 1. {forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2))) if r in RealNonNeg.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a, b in Real} (|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)))
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. r in RealNonNeg
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (r, RealNonNeg)
#    core type: ExprTuple
#    sub-expressions: 48, 8
# 7. (a, b) -> {|(r * e^{i * a}) - (r * e^{i * b})| = (2 * r * sin(|a - b| / 2)) if a in Real ,  b in Real.
# ...
