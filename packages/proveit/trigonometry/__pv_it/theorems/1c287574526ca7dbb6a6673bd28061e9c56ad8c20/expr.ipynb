# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.trigonometry</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, theta
from proveit.logic import And, InSet
from proveit.numbers import LessEq, Mult, RealPos, frac, greater, pi, two
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Lambda(theta, Conditional(greater(Sin(theta), frac(Mult(two, theta), pi)), And(InSet(theta, RealPos), LessEq(theta, frac(pi, two)))))
# Out:
# expr: theta -> {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \theta \mapsto \left\{\sin{\theta} > \frac{2 \cdot \theta}{\pi} \textrm{ if } \theta \in \mathbb{R}^+ ,  \theta \leq \frac{\pi}{2}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. theta -> {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. {sin(theta) > ((2 * theta) / pi) if theta in RealPos ,  theta <= (pi / 2).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. sin(theta) > ((2 * theta) / pi)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (theta in RealPos) and (theta <= (pi / 2))
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. <
#    core type: Literal
#    sub-expressions:
# 5. ((2 * theta) / pi, sin(theta))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (theta in RealPos, theta <= (pi / 2))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. (2 * theta) / pi
#    core type: Operation
#    operator: 24
#    operands: 12
# 9. sin(theta)
#    core type: Operation
#    operator: 13
#    operand: 26
# 10. theta in RealPos
#     core type: Operation
# ...
