# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c, d
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Implies
from proveit.physics.quantum import pregated_controlled_ngate, pregated_controlled_ngate_with_merge

# %%
# build up the expression from sub-expressions
expr = ExprTuple(pregated_controlled_ngate, Implies(pregated_controlled_ngate_with_merge, Equals(d, TensorProd(c, b))))
# Out:
# expr: ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(d = \left(c {\otimes} b\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 11
#    operand: 6
# 2.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ((Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. =>
#    core type: Literal
#    sub-expressions:
# 5. ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE, d = (c otimes b))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE
#    core type: Operation
#    operator: 11
#    operand: 18
# 8. d = (c otimes b)
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#    core type: ExprTuple
#    sub-expressions: 30, 31, 15, 16
# 10. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 36, 37, 17, 39
# 11. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 12. ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))
#     core type: ExprTuple
#     sub-expressions: 18
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (d, c otimes b)
#     core type: ExprTuple
#     sub-expressions: 66, 19
# 15. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 55
#     operands: 20
# 16. Output(b)
#     core type: Operation
#     operator: 57
#     operand: 41
# 17. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 55
#     operands: 22
# 18. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 19. c otimes b
#     core type: Operation
#     operator: 26
#     operands: 27
# 20. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 21. (b)
#     core type: ExprTuple
#     sub-expressions: 41
# 22. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 69, 64
# 23. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 28, 29, 63, 33, 40, 40
# 24. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#     core type: ExprTuple
#     sub-expressions: 30, 31, 32, 33, 34, 35
# 25. (Input(x), MultiWire(n), MultiQubitGate(U, {2, 3}), Output(y), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38, 39, 40, 40
# 26. otimes
#     core type: Literal
#     sub-expressions:
# 27. (c, b)
#     core type: ExprTuple
#     sub-expressions: 59, 41
# 28. Input(c)
#     core type: Operation
#     operator: 51
#     operand: 59
# 29. MultiWire(k)
#     core type: Operation
#     operator: 53
#     operand: 77
# 30. Input(a)
#     core type: Operation
#     operator: 51
#     operand: 60
# 31. Gate(u)
#     core type: Operation
#     operator: 45
#     operand: 61
# 32. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 55
#     operands: 47
# 33. MultiQubitGate([I], {1, 2})
#     core type: Operation
#     operator: 55
#     operands: 48
# 34. MultiWire(k + 1)
#     core type: Operation
#     operator: 53
#     operand: 65
# 35. Output(d)
#     core type: Operation
#     operator: 57
#     operand: 66
# 36. Input(x)
#     core type: Operation
#     operator: 51
#     operand: 67
# 37. MultiWire(n)
#     core type: Operation
#     operator: 53
#     operand: 68
# 38. MultiQubitGate(U, {2, 3})
#     core type: Operation
#     operator: 55
#     operands: 56
# 39. Output(y)
#     core type: Operation
#     operator: 57
#     operand: 71
# 40. SPACE
#     core type: Literal
#     sub-expressions:
# 41. b
#     core type: Variable
#     sub-expressions:
# 42. (c)
#     core type: ExprTuple
#     sub-expressions: 59
# 43. (k)
#     core type: ExprTuple
#     sub-expressions: 77
# 44. (a)
#     core type: ExprTuple
#     sub-expressions: 60
# 45. GATE
#     core type: Literal
#     sub-expressions:
# 46. (u)
#     core type: ExprTuple
#     sub-expressions: 61
# 47. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 62, 70
# 48. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 49. (k + 1)
#     core type: ExprTuple
#     sub-expressions: 65
# 50. (d)
#     core type: ExprTuple
#     sub-expressions: 66
# 51. INPUT
#     core type: Literal
#     sub-expressions:
# 52. (x)
#     core type: ExprTuple
#     sub-expressions: 67
# 53. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 54. (n)
#     core type: ExprTuple
#     sub-expressions: 68
# 55. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 56. (U, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 57. OUTPUT
#     core type: Literal
#     sub-expressions:
# 58. (y)
#     core type: ExprTuple
#     sub-expressions: 71
# 59. c
#     core type: Variable
#     sub-expressions:
# 60. a
#     core type: Variable
#     sub-expressions:
# 61. u
#     core type: Variable
#     sub-expressions:
# 62. CONTROL
#     core type: Literal
#     sub-expressions:
# 63. --
#     core type: Literal
#     sub-expressions:
# 64. {1, 2}
#     core type: Operation
#     operator: 75
#     operands: 72
# 65. k + 1
#     core type: Operation
#     operator: 73
#     operands: 74
# 66. d
#     core type: Variable
#     sub-expressions:
# 67. x
#     core type: Variable
#     sub-expressions:
# 68. n
#     core type: Variable
#     sub-expressions:
# 69. U
#     core type: Variable
#     sub-expressions:
# 70. {2, 3}
#     core type: Operation
#     operator: 75
#     operands: 76
# 71. y
#     core type: Variable
#     sub-expressions:
# 72. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 73. +
#     core type: Literal
#     sub-expressions:
# 74. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 77, 78
# 75. Set
#     core type: Literal
#     sub-expressions:
# 76. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 77. k
#     core type: Variable
#     sub-expressions:
# 78. 1
#     core type: Literal
#     sub-expressions:
# 79. 2
#     core type: Literal
#     sub-expressions:
# 80. 3
#     core type: Literal
#     sub-expressions:
