# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, b
from proveit.logic import InSet
from proveit.physics.quantum import QubitSpace

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(a, QubitSpace), InSet(b, QubitSpace))
# Out:
# expr: (a in Complex^{2}, b in Complex^{2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a \in \mathbb{C}^{2}, b \in \mathbb{C}^{2}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a in Complex^{2}, b in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a in Complex^{2}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. b in Complex^{2}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 8
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (b, Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. a
#    core type: Variable
#    sub-expressions:
# 7. b
#    core type: Variable
#    sub-expressions:
# 8. Complex^{2}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Exp
#    core type: Literal
#    sub-expressions:
# 10. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. Complex
#     core type: Literal
#     sub-expressions:
# 12. 2
#     core type: Literal
#     sub-expressions:
