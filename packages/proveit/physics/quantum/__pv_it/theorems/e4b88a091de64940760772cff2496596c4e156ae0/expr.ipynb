# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, a, b, c, n, x, y, z
from proveit.linalg import TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, Iff, InSet, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = Conditional(Forall([x, y, z], Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), domain = TensorExp([QubitSpace], n)), And(InSet(a, QubitSpace), InSet(b, QubitSpace), InSet(c, QubitSpace)))
# Out:
# expr: {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y, z \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)\right) \textrm{ if } a \in \mathbb{C}^{2} ,  b \in \mathbb{C}^{2} ,  c \in \mathbb{C}^{2}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2})
#    core type: Operation
#    operator: 19
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 10\n   body: 11
# 7. a in Complex^{2}
#    core type: Operation
#    operator: 31
#    operands: 12
# 8. b in Complex^{2}
#    core type: Operation
#    operator: 31
#    operands: 13
# 9. c in Complex^{2}
#    core type: Operation
#    operator: 31
#    operands: 14
# 10. (x, y, z)
#     core type: ExprTuple
#     sub-expressions: 85, 81, 89
# 11. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 12. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 82, 53
# 13. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 80, 53
# 14. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 84, 53
# 15. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. <=>
#     core type: Literal
#     sub-expressions:
# 18. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 23, 24, 25
# 21.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 31
#     operands: 29
# 24. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 31
#     operands: 30
# 25. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 31
#     operands: 32
# 26. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 29. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 85, 37
# 30. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 81, 37
# 31. in
#     core type: Literal
#     sub-expressions:
# 32. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 89, 37
# 33.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 39
#     operand: 46
# 34.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 39
#     operand: 47
# 35. b otimes y
#     core type: Operation
#     operator: 42
#     operands: 41
# 36. c otimes z
#     core type: Operation
#     operator: 42
#     operands: 43
# 37. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 38. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 46
# 39. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 40. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 47
# 41. (b, y)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 42. otimes
#     core type: Literal
#     sub-expressions:
# 43. (c, z)
#     core type: ExprTuple
#     sub-expressions: 84, 89
# 44. otimes
#     core type: Literal
#     sub-expressions:
# 45. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 48, 86
# 46. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 48. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 53
# 49. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58, 54
# 50. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62, 55
# 51. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 56, 57, 58, 59
# 52. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62, 63
# 53. Complex^{2}
#     core type: Operation
#     operator: 64
#     operands: 65
# 54. Output(b)
#     core type: Operation
#     operator: 77
#     operand: 80
# 55. Output(y)
#     core type: Operation
#     operator: 77
#     operand: 81
# 56. Input(a)
#     core type: Operation
#     operator: 71
#     operand: 82
# 57. --
#     core type: Literal
#     sub-expressions:
# 58. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 75
#     operands: 69
# 59. Output(c)
#     core type: Operation
#     operator: 77
#     operand: 84
# 60. Input(x)
#     core type: Operation
#     operator: 71
#     operand: 85
# 61. MultiWire(n)
#     core type: Operation
#     operator: 73
#     operand: 86
# 62. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 75
#     operands: 76
# 63. Output(z)
#     core type: Operation
#     operator: 77
#     operand: 89
# 64. Exp
#     core type: Literal
#     sub-expressions:
# 65. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 79, 93
# 66. (b)
#     core type: ExprTuple
#     sub-expressions: 80
# 67. (y)
#     core type: ExprTuple
#     sub-expressions: 81
# 68. (a)
#     core type: ExprTuple
#     sub-expressions: 82
# 69. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 83, 88
# 70. (c)
#     core type: ExprTuple
#     sub-expressions: 84
# 71. INPUT
#     core type: Literal
#     sub-expressions:
# 72. (x)
#     core type: ExprTuple
#     sub-expressions: 85
# 73. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 74. (n)
#     core type: ExprTuple
#     sub-expressions: 86
# 75. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 76. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 87, 88
# 77. OUTPUT
#     core type: Literal
#     sub-expressions:
# 78. (z)
#     core type: ExprTuple
#     sub-expressions: 89
# 79. Complex
#     core type: Literal
#     sub-expressions:
# 80. b
#     core type: Variable
#     sub-expressions:
# 81. y
#     core type: Variable
#     sub-expressions:
# 82. a
#     core type: Variable
#     sub-expressions:
# 83. CONTROL
#     core type: Literal
#     sub-expressions:
# 84. c
#     core type: Variable
#     sub-expressions:
# 85. x
#     core type: Variable
#     sub-expressions:
# 86. n
#     core type: Variable
#     sub-expressions:
# 87. U
#     core type: Variable
#     sub-expressions:
# 88. {1, 2}
#     core type: Operation
#     operator: 90
#     operands: 91
# 89. z
#     core type: Variable
#     sub-expressions:
# 90. Set
#     core type: Literal
#     sub-expressions:
# 91. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 92, 93
# 92. 1
#     core type: Literal
#     sub-expressions:
# 93. 2
#     core type: Literal
#     sub-expressions:
