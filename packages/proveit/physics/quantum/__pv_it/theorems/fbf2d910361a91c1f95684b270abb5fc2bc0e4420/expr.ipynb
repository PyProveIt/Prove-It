# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, a, b, c, n, x, y, z
from proveit.linalg import TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Iff, InSet, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
sub_expr7 = TensorExp([QubitSpace], n)
expr = Lambda([x, y, z], Conditional(Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), And(InSet(x, sub_expr7), InSet(y, sub_expr7), InSet(z, sub_expr7))))
# Out:
# expr: (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y, z\right) \mapsto \left\{\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right) \textrm{ if } x \in \left(\mathbb{C}^{2}\right)^{\otimes n} ,  y \in \left(\mathbb{C}^{2}\right)^{\otimes n} ,  z \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y, z)
#    core type: ExprTuple
#    sub-expressions: 73, 69, 77
# 2. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#    core type: Operation
#    operator: 15
#    operands: 14
# 10. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 19
#     operands: 17
# 12. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 19
#     operands: 18
# 13. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 19
#     operands: 20
# 14. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 17. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 73, 25
# 18. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 69, 25
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 77, 25
# 21.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 27
#     operand: 34
# 22.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 27
#     operand: 35
# 23. b otimes y
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. c otimes z
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 26. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 34
# 27. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 28. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 35
# 29. (b, y)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 30. otimes
#     core type: Literal
#     sub-expressions:
# 31. (c, z)
#     core type: ExprTuple
#     sub-expressions: 72, 77
# 32. otimes
#     core type: Literal
#     sub-expressions:
# 33. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 36, 74
# 34. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 35. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 36. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46, 42
# 38. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50, 43
# 39. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 44, 45, 46, 47
# 40. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50, 51
# 41. Complex^{2}
#     core type: Operation
#     operator: 52
#     operands: 53
# 42. Output(b)
#     core type: Operation
#     operator: 65
#     operand: 68
# 43. Output(y)
#     core type: Operation
#     operator: 65
#     operand: 69
# 44. Input(a)
#     core type: Operation
#     operator: 59
#     operand: 70
# 45. --
#     core type: Literal
#     sub-expressions:
# 46. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 63
#     operands: 57
# 47. Output(c)
#     core type: Operation
#     operator: 65
#     operand: 72
# 48. Input(x)
#     core type: Operation
#     operator: 59
#     operand: 73
# 49. MultiWire(n)
#     core type: Operation
#     operator: 61
#     operand: 74
# 50. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 63
#     operands: 64
# 51. Output(z)
#     core type: Operation
#     operator: 65
#     operand: 77
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 67, 81
# 54. (b)
#     core type: ExprTuple
#     sub-expressions: 68
# 55. (y)
#     core type: ExprTuple
#     sub-expressions: 69
# 56. (a)
#     core type: ExprTuple
#     sub-expressions: 70
# 57. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 71, 76
# 58. (c)
#     core type: ExprTuple
#     sub-expressions: 72
# 59. INPUT
#     core type: Literal
#     sub-expressions:
# 60. (x)
#     core type: ExprTuple
#     sub-expressions: 73
# 61. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 62. (n)
#     core type: ExprTuple
#     sub-expressions: 74
# 63. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 64. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 65. OUTPUT
#     core type: Literal
#     sub-expressions:
# 66. (z)
#     core type: ExprTuple
#     sub-expressions: 77
# 67. Complex
#     core type: Literal
#     sub-expressions:
# 68. b
#     core type: Variable
#     sub-expressions:
# 69. y
#     core type: Variable
#     sub-expressions:
# 70. a
#     core type: Variable
#     sub-expressions:
# 71. CONTROL
#     core type: Literal
#     sub-expressions:
# 72. c
#     core type: Variable
#     sub-expressions:
# 73. x
#     core type: Variable
#     sub-expressions:
# 74. n
#     core type: Variable
#     sub-expressions:
# 75. U
#     core type: Variable
#     sub-expressions:
# 76. {1, 2}
#     core type: Operation
#     operator: 78
#     operands: 79
# 77. z
#     core type: Variable
#     sub-expressions:
# 78. Set
#     core type: Literal
#     sub-expressions:
# 79. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 80. 1
#     core type: Literal
#     sub-expressions:
# 81. 2
#     core type: Literal
#     sub-expressions:
