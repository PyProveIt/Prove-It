# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, b, c, d
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals
from proveit.physics.quantum import pregated_controlled_ngate_with_merge

# %%
# build up the expression from sub-expressions
expr = ExprTuple(pregated_controlled_ngate_with_merge, Equals(d, TensorProd(c, b)))
# Out:
# expr: ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE, d = (c otimes b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}, d = \left(c {\otimes} b\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE, d = (c otimes b))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. d = (c otimes b)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (d, c otimes b)
#    core type: ExprTuple
#    sub-expressions: 52, 8
# 7. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 8. c otimes b
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 14, 15, 49, 19, 26, 26
# 10. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#     core type: ExprTuple
#     sub-expressions: 16, 17, 18, 19, 20, 21
# 11. (Input(x), MultiWire(n), MultiQubitGate(U, {2, 3}), Output(y), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24, 25, 26, 26
# 12. otimes
#     core type: Literal
#     sub-expressions:
# 13. (c, b)
#     core type: ExprTuple
#     sub-expressions: 45, 27
# 14. Input(c)
#     core type: Operation
#     operator: 37
#     operand: 45
# 15. MultiWire(k)
#     core type: Operation
#     operator: 39
#     operand: 63
# 16. Input(a)
#     core type: Operation
#     operator: 37
#     operand: 46
# 17. Gate(u)
#     core type: Operation
#     operator: 31
#     operand: 47
# 18. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 41
#     operands: 33
# 19. MultiQubitGate([I], {1, 2})
#     core type: Operation
#     operator: 41
#     operands: 34
# 20. MultiWire(k + 1)
#     core type: Operation
#     operator: 39
#     operand: 51
# 21. Output(d)
#     core type: Operation
#     operator: 43
#     operand: 52
# 22. Input(x)
#     core type: Operation
#     operator: 37
#     operand: 53
# 23. MultiWire(n)
#     core type: Operation
#     operator: 39
#     operand: 54
# 24. MultiQubitGate(U, {2, 3})
#     core type: Operation
#     operator: 41
#     operands: 42
# 25. Output(y)
#     core type: Operation
#     operator: 43
#     operand: 57
# 26. SPACE
#     core type: Literal
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. (c)
#     core type: ExprTuple
#     sub-expressions: 45
# 29. (k)
#     core type: ExprTuple
#     sub-expressions: 63
# 30. (a)
#     core type: ExprTuple
#     sub-expressions: 46
# 31. GATE
#     core type: Literal
#     sub-expressions:
# 32. (u)
#     core type: ExprTuple
#     sub-expressions: 47
# 33. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 48, 56
# 34. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 35. (k + 1)
#     core type: ExprTuple
#     sub-expressions: 51
# 36. (d)
#     core type: ExprTuple
#     sub-expressions: 52
# 37. INPUT
#     core type: Literal
#     sub-expressions:
# 38. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 39. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 40. (n)
#     core type: ExprTuple
#     sub-expressions: 54
# 41. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 42. (U, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 43. OUTPUT
#     core type: Literal
#     sub-expressions:
# 44. (y)
#     core type: ExprTuple
#     sub-expressions: 57
# 45. c
#     core type: Variable
#     sub-expressions:
# 46. a
#     core type: Variable
#     sub-expressions:
# 47. u
#     core type: Variable
#     sub-expressions:
# 48. CONTROL
#     core type: Literal
#     sub-expressions:
# 49. --
#     core type: Literal
#     sub-expressions:
# 50. {1, 2}
#     core type: Operation
#     operator: 61
#     operands: 58
# 51. k + 1
#     core type: Operation
#     operator: 59
#     operands: 60
# 52. d
#     core type: Variable
#     sub-expressions:
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. U
#     core type: Variable
#     sub-expressions:
# 56. {2, 3}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. y
#     core type: Variable
#     sub-expressions:
# 58. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 59. +
#     core type: Literal
#     sub-expressions:
# 60. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. Set
#     core type: Literal
#     sub-expressions:
# 62. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. 1
#     core type: Literal
#     sub-expressions:
# 65. 2
#     core type: Literal
#     sub-expressions:
# 66. 3
#     core type: Literal
#     sub-expressions:
