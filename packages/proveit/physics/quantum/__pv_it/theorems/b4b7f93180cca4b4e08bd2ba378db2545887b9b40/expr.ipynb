# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, a, b, c, n, x, y, z
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Iff, InSet, Set
from proveit.numbers import Exp, NaturalPos, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = Lambda(n, Conditional(Forall([U], Forall([a, b, c], Forall([x, y, z], Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), domain = SU(Exp(two, n))), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{U in SU(2^{n})} [forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{U \in SU(2^{n})}~\left[\forall_{a, b, c \in \mathbb{C}^{2}}~\left[\forall_{x, y, z \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)\right)\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{U in SU(2^{n})} [forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 106
#    body: 1
# 1. {forall_{U in SU(2^{n})} [forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]] if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{U in SU(2^{n})} [forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]]
#    core type: Operation
#    operator: 22
#    operand: 6
# 3. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 5
# 4. (U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 106, 7
# 6. U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 107
#    body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]
#    core type: Operation
#    operator: 22
#    operand: 13
# 10. U in SU(2^{n})
#     core type: Operation
#     operator: 51
#     operands: 12
# 11. ((a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 107, 14
# 13. (a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#     core type: Lambda
#     parameters: 15\n    body: 16
# 14. SU(2^{n})
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 102, 100, 104
# 16. {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#     core type: Conditional
#     value: 19
#     condition: 20
# 17. SU
#     core type: Literal
#     sub-expressions:
# 18. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 21
# 19. forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2})
#     core type: Operation
#     operator: 39
#     operands: 24
# 21. 2^{n}
#     core type: Operation
#     operator: 84
#     operands: 25
# 22. forall
#     core type: Literal
#     sub-expressions:
# 23. ((x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 27, 28, 29
# 25. (2, n)
#     core type: ExprTuple
#     sub-expressions: 113, 106
# 26. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 30\n    body: 31
# 27. a in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 32
# 28. b in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 33
# 29. c in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 34
# 30. (x, y, z)
#     core type: ExprTuple
#     sub-expressions: 105, 101, 109
# 31. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 35
#     condition: 36
# 32. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 102, 73
# 33. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 100, 73
# 34. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 104, 73
# 35. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#     core type: Operation
#     operator: 37
#     operands: 38
# 36. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 39
#     operands: 40
# 37. <=>
#     core type: Literal
#     sub-expressions:
# 38. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 39. and
#     core type: Literal
#     sub-expressions:
# 40. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45
# 41.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 47
#     operands: 46
# 42. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 47
#     operands: 48
# 43. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 51
#     operands: 49
# 44. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 51
#     operands: 50
# 45. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 46. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 47. =
#     core type: Literal
#     sub-expressions:
# 48. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 49. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 105, 57
# 50. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 101, 57
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 109, 57
# 53.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 59
#     operand: 66
# 54.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 59
#     operand: 67
# 55. b otimes y
#     core type: Operation
#     operator: 62
#     operands: 61
# 56. c otimes z
#     core type: Operation
#     operator: 62
#     operands: 63
# 57. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 64
#     operands: 65
# 58. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 66
# 59. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 60. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 67
# 61. (b, y)
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 62. otimes
#     core type: Literal
#     sub-expressions:
# 63. (c, z)
#     core type: ExprTuple
#     sub-expressions: 104, 109
# 64. otimes
#     core type: Literal
#     sub-expressions:
# 65. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 68, 106
# 66. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 67. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 68. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 73
# 69. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 76, 77, 78, 74
# 70. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 80, 81, 82, 75
# 71. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 76, 77, 78, 79
# 72. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 80, 81, 82, 83
# 73. Complex^{2}
#     core type: Operation
#     operator: 84
#     operands: 85
# 74. Output(b)
#     core type: Operation
#     operator: 97
#     operand: 100
# 75. Output(y)
#     core type: Operation
#     operator: 97
#     operand: 101
# 76. Input(a)
#     core type: Operation
#     operator: 91
#     operand: 102
# 77. --
#     core type: Literal
#     sub-expressions:
# 78. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 95
#     operands: 89
# 79. Output(c)
#     core type: Operation
#     operator: 97
#     operand: 104
# 80. Input(x)
#     core type: Operation
#     operator: 91
#     operand: 105
# 81. MultiWire(n)
#     core type: Operation
#     operator: 93
#     operand: 106
# 82. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 95
#     operands: 96
# 83. Output(z)
#     core type: Operation
#     operator: 97
#     operand: 109
# 84. Exp
#     core type: Literal
#     sub-expressions:
# 85. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 99, 113
# 86. (b)
#     core type: ExprTuple
#     sub-expressions: 100
# 87. (y)
#     core type: ExprTuple
#     sub-expressions: 101
# 88. (a)
#     core type: ExprTuple
#     sub-expressions: 102
# 89. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 103, 108
# 90. (c)
#     core type: ExprTuple
#     sub-expressions: 104
# 91. INPUT
#     core type: Literal
#     sub-expressions:
# 92. (x)
#     core type: ExprTuple
#     sub-expressions: 105
# 93. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 94. (n)
#     core type: ExprTuple
#     sub-expressions: 106
# 95. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 96. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 107, 108
# 97. OUTPUT
#     core type: Literal
#     sub-expressions:
# 98. (z)
#     core type: ExprTuple
#     sub-expressions: 109
# 99. Complex
#     core type: Literal
#     sub-expressions:
# 100. b
#      core type: Variable
#      sub-expressions:
# 101. y
#      core type: Variable
#      sub-expressions:
# 102. a
#      core type: Variable
#      sub-expressions:
# 103. CONTROL
#      core type: Literal
#      sub-expressions:
# 104. c
#      core type: Variable
#      sub-expressions:
# 105. x
#      core type: Variable
#      sub-expressions:
# 106. n
#      core type: Variable
#      sub-expressions:
# 107. U
#      core type: Variable
#      sub-expressions:
# 108. {1, 2}
#      core type: Operation
#      operator: 110
#      operands: 111
# 109. z
#      core type: Variable
#      sub-expressions:
# 110. Set
#      core type: Literal
#      sub-expressions:
# 111. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 112, 113
# 112. 1
#      core type: Literal
#      sub-expressions:
# 113. 2
#      core type: Literal
#      sub-expressions:
