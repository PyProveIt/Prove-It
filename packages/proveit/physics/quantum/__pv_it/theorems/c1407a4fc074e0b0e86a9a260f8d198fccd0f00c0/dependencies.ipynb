# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#pregated_controlled_ngate_equiv">pregated_controlled_ngate_equiv</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/pregated_controlled_ngate_equiv/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum import pregated_controlled_ngate_equiv

# %%
# %dependencies pregated_controlled_ngate_equiv
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon pregated_controlled_ngate_equiv</h3>
