# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pregated_controlled_ngate_equiv">pregated_controlled_ngate_equiv</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import pregated_controlled_ngate_equiv

# %%
# check that the built expression is the same as the stored expression
assert pregated_controlled_ngate_equiv.expr == stored_expr
assert pregated_controlled_ngate_equiv.expr._style_id == stored_expr._style_id
print("Passed sanity check: pregated_controlled_ngate_equiv matches stored_expr")
# Out:
# Passed sanity check: pregated_controlled_ngate_equiv matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pregated_controlled_ngate_equiv.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{u \in SU(2)}~\left[\forall_{a, b \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{u \thinspace a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right]\right]\right]\right]

# %%
pregated_controlled_ngate_equiv.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
pregated_controlled_ngate_equiv.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]]]
#    core type: Operation
#    operator: 33
#    operand: 2
# 1. (n -> {forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]] if n in NaturalPos.)
#    core type: ExprTuple
# ...
