# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#superposition_controlled_ngate">superposition_controlled_ngate</a> of type <a href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, a, b, c, d, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.logic import And, Forall, Implies, Set
from proveit.numbers import Add, Exp, NaturalPos, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr3 = [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]
expr = Forall([n], Forall([U], Forall([a, b, c, d], Forall([x, y], Implies(And(Circuit(ExprArray([Input(a), I, sub_expr2, Output(c)], sub_expr3)), Circuit(ExprArray([Input(b), I, sub_expr2, Output(d)], sub_expr3))), Circuit(ExprArray([Input(Add(a, b)), I, sub_expr2, Output(Add(c, d))], sub_expr3))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), domain = SU(Exp(two, n))), domain = NaturalPos)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: superposition_controlled_ngate matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
expr.style_options()

# %%
# display the expression information
expr.expr_info()
