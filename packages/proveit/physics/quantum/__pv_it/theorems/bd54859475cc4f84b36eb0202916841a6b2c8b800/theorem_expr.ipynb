# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#superposition_controlled_ngate">superposition_controlled_ngate</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import superposition_controlled_ngate

# %%
# check that the built expression is the same as the stored expression
assert superposition_controlled_ngate.expr == stored_expr
assert superposition_controlled_ngate.expr._style_id == stored_expr._style_id
print("Passed sanity check: superposition_controlled_ngate matches stored_expr")
# Out:
# Passed sanity check: superposition_controlled_ngate matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(superposition_controlled_ngate.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{a, b, c, d \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{b} & \qw & \control \qw \qwx[1] & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right) \Rightarrow \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a + b} & \qw & \control \qw \qwx[1] & \rstick{c + d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right]\right]\right]

# %%
superposition_controlled_ngate.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
superposition_controlled_ngate.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]]
#    core type: Operation
#    operator: 24
#    operand: 2
# 1. (n -> {forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
# ...
