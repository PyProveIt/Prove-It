# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, a, b, c, d, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.logic import And, Forall, Implies, InSet, Set
from proveit.numbers import Add, Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr3 = [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]
expr = Conditional(Forall([a, b, c, d], Forall([x, y], Implies(And(Circuit(ExprArray([Input(a), I, sub_expr2, Output(c)], sub_expr3)), Circuit(ExprArray([Input(b), I, sub_expr2, Output(d)], sub_expr3))), Circuit(ExprArray([Input(Add(a, b)), I, sub_expr2, Output(Add(c, d))], sub_expr3))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), InSet(U, SU(Exp(two, n))))
# Out:
# expr: {forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if U in SU(2^{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a, b, c, d \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{b} & \qw & \control \qw \qwx[1] & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right) \Rightarrow \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a + b} & \qw & \control \qw \qwx[1] & \rstick{c + d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right] \textrm{ if } U \in SU(2^{n})\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if U in SU(2^{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]
#    core type: Operation
#    operator: 14
#    operand: 5
# 2. U in SU(2^{n})
#    core type: Operation
#    operator: 42
#    operands: 4
# 3. ((a, b, c, d) -> {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 99, 6
# 5. (a, b, c, d) -> {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.
#    core type: Lambda
#    parameters: 7\n   body: 8
# 6. SU(2^{n})
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. (a, b, c, d)
#    core type: ExprTuple
#    sub-expressions: 102, 103, 104, 105
# 8. {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. SU
#    core type: Literal
#    sub-expressions:
# 10. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 13
# 11. forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2}) and (d in Complex^{2})
#     core type: Operation
#     operator: 38
#     operands: 16
# 13. 2^{n}
#     core type: Operation
#     operator: 77
#     operands: 17
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((x, y) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2}, d in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21, 22
# 17. (2, n)
#     core type: ExprTuple
#     sub-expressions: 109, 98
# 18. (x, y) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 23\n    body: 24
# 19. a in Complex^{2}
#     core type: Operation
#     operator: 42
#     operands: 25
# 20. b in Complex^{2}
#     core type: Operation
#     operator: 42
#     operands: 26
# 21. c in Complex^{2}
#     core type: Operation
#     operator: 42
#     operands: 27
# 22. d in Complex^{2}
#     core type: Operation
#     operator: 42
#     operands: 28
# 23. (x, y)
#     core type: ExprTuple
#     sub-expressions: 97, 101
# 24. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 25. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 102, 64
# 26. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 103, 64
# 27. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 104, 64
# 28. (d, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 105, 64
# 29. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 38
#     operands: 33
# 31. =>
#     core type: Literal
#     sub-expressions:
# 32. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 33. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 38
#     operands: 39
# 35.  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 49
#     operand: 46
# 36. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 42
#     operands: 41
# 37. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. and
#     core type: Literal
#     sub-expressions:
# 39. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. ((Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 46
# 41. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 97, 47
# 42. in
#     core type: Literal
#     sub-expressions:
# 43. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 101, 47
# 44.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 49
#     operand: 54
# 45.  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 49
#     operand: 55
# 46. Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 51, 61
# 47. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 54
# 49. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 50. ((Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 55
# 51. (Input(a + b), --, MultiQubitGate(CONTROL, {1, 2}), Output(c + d))
#     core type: ExprTuple
#     sub-expressions: 56, 68, 69, 57
# 52. otimes
#     core type: Literal
#     sub-expressions:
# 53. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 58, 98
# 54. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 59, 61
# 55. Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 56. Input(a + b)
#     core type: Operation
#     operator: 84
#     operand: 75
# 57. Output(c + d)
#     core type: Operation
#     operator: 90
#     operand: 76
# 58. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 64
# 59. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 65, 68, 69, 66
# 60. (Input(b), --, MultiQubitGate(CONTROL, {1, 2}), Output(d))
#     core type: ExprTuple
#     sub-expressions: 67, 68, 69, 70
# 61. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 71, 72, 73, 74
# 62. (a + b)
#     core type: ExprTuple
#     sub-expressions: 75
# 63. (c + d)
#     core type: ExprTuple
#     sub-expressions: 76
# 64. Complex^{2}
#     core type: Operation
#     operator: 77
#     operands: 78
# 65. Input(a)
#     core type: Operation
#     operator: 84
#     operand: 102
# 66. Output(c)
#     core type: Operation
#     operator: 90
#     operand: 104
# 67. Input(b)
#     core type: Operation
#     operator: 84
#     operand: 103
# 68. --
#     core type: Literal
#     sub-expressions:
# 69. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 88
#     operands: 82
# 70. Output(d)
#     core type: Operation
#     operator: 90
#     operand: 105
# 71. Input(x)
#     core type: Operation
#     operator: 84
#     operand: 97
# 72. MultiWire(n)
#     core type: Operation
#     operator: 86
#     operand: 98
# 73. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 88
#     operands: 89
# 74. Output(y)
#     core type: Operation
#     operator: 90
#     operand: 101
# 75. a + b
#     core type: Operation
#     operator: 93
#     operands: 92
# 76. c + d
#     core type: Operation
#     operator: 93
#     operands: 94
# 77. Exp
#     core type: Literal
#     sub-expressions:
# 78. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 95, 109
# 79. (a)
#     core type: ExprTuple
#     sub-expressions: 102
# 80. (c)
#     core type: ExprTuple
#     sub-expressions: 104
# 81. (b)
#     core type: ExprTuple
#     sub-expressions: 103
# 82. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 96, 100
# 83. (d)
#     core type: ExprTuple
#     sub-expressions: 105
# 84. INPUT
#     core type: Literal
#     sub-expressions:
# 85. (x)
#     core type: ExprTuple
#     sub-expressions: 97
# 86. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 87. (n)
#     core type: ExprTuple
#     sub-expressions: 98
# 88. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 89. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 99, 100
# 90. OUTPUT
#     core type: Literal
#     sub-expressions:
# 91. (y)
#     core type: ExprTuple
#     sub-expressions: 101
# 92. (a, b)
#     core type: ExprTuple
#     sub-expressions: 102, 103
# 93. +
#     core type: Literal
#     sub-expressions:
# 94. (c, d)
#     core type: ExprTuple
#     sub-expressions: 104, 105
# 95. Complex
#     core type: Literal
#     sub-expressions:
# 96. CONTROL
#     core type: Literal
#     sub-expressions:
# 97. x
#     core type: Variable
#     sub-expressions:
# 98. n
#     core type: Variable
#     sub-expressions:
# 99. U
#     core type: Variable
#     sub-expressions:
# 100. {1, 2}
#      core type: Operation
#      operator: 106
#      operands: 107
# 101. y
#      core type: Variable
#      sub-expressions:
# 102. a
#      core type: Variable
#      sub-expressions:
# 103. b
#      core type: Variable
#      sub-expressions:
# 104. c
#      core type: Variable
#      sub-expressions:
# 105. d
#      core type: Variable
#      sub-expressions:
# 106. Set
#      core type: Literal
#      sub-expressions:
# 107. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 108, 109
# 108. 1
#      core type: Literal
#      sub-expressions:
# 109. 2
#      core type: Literal
#      sub-expressions:
