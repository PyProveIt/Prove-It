# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, a, b, c, d, n, x, y
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output
from proveit.physics.quantum.circuit import MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = ExprArray([Input(Add(a, b)), I, MultiQubitGate(CONTROL, sub_expr1), Output(Add(c, d))], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)])
# Out:
# expr: Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccc}
#  \lstick{a + b} & \qw & \control \qw & \rstick{c + d} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{y} \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Input(a + b), --, MultiQubitGate(CONTROL, {1, 2}), Output(c + d))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 2. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 3. Input(a + b)
#    core type: Operation
#    operator: 14
#    operand: 22
# 4. --
#    core type: Literal
#    sub-expressions:
# 5. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 18
#    operands: 12
# 6. Output(c + d)
#    core type: Operation
#    operator: 20
#    operand: 24
# 7. Input(x)
#    core type: Operation
#    operator: 14
#    operand: 25
# 8. MultiWire(n)
#    core type: Operation
#    operator: 16
#    operand: 26
# 9. MultiQubitGate(U, {1, 2})
#    core type: Operation
#    operator: 18
# ...
