# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, a, b, n, u, x, y
from proveit.linalg import MatrixProd, SU, TensorExp
from proveit.logic import Equals, Forall, InSet, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, pregated_controlled_ngate
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = Lambda(u, Conditional(Forall([a, b], Forall([x, y], Equals(pregated_controlled_ngate, Circuit(ExprArray([Input(MatrixProd(u, a)), I, MultiQubitGate(CONTROL, sub_expr1), Output(b)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), InSet(u, SU(two))))
# Out:
# expr: u -> {forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if u in SU(2).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# u \mapsto \left\{\forall_{a, b \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{u \thinspace a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right] \textrm{ if } u \in SU(2)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. u -> {forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if u in SU(2).
#    core type: Lambda
#    parameter: 89
#    body: 1
# 1. {forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if u in SU(2).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]
#    core type: Operation
#    operator: 14
#    operand: 6
# 3. u in SU(2)
#    core type: Operation
#    operator: 38
#    operands: 5
# 4. ((a, b) -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (u, SU(2))
#    core type: ExprTuple
#    sub-expressions: 89, 7
# 6. (a, b) -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. SU(2)
#    core type: Operation
#    operator: 10
#    operand: 92
# 8. (a, b)
#    core type: ExprTuple
#    sub-expressions: 90, 76
# 9. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. SU
#     core type: Literal
#     sub-expressions:
# 11. (2)
#     core type: ExprTuple
#     sub-expressions: 92
# 12. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. (a in Complex^{2}) and (b in Complex^{2})
#     core type: Operation
#     operator: 28
#     operands: 16
# 14. forall
#     core type: Literal
#     sub-expressions:
# 15. ((x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 17
# 16. (a in Complex^{2}, b in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. (x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 20\n    body: 21
# 18. a in Complex^{2}
#     core type: Operation
#     operator: 38
#     operands: 22
# 19. b in Complex^{2}
#     core type: Operation
#     operator: 38
#     operands: 23
# 20. (x, y)
#     core type: ExprTuple
#     sub-expressions: 77, 81
# 21. { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 24
#     condition: 25
# 22. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 90, 73
# 23. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 76, 73
# 24.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 28
#     operands: 29
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. and
#     core type: Literal
#     sub-expressions:
# 29. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 35
#     operand: 40
# 31.  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 35
#     operand: 41
# 32. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 38
#     operands: 37
# 33. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. ((Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 40
# 35. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 36. ((Input(u . a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 41
# 37. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 77, 42
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 81, 42
# 40. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 43, 45
# 41. Input(u . a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 52, 53
# 44. (Input(u . a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52, 53
# 45. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 54, 55, 56, 57
# 46. otimes
#     core type: Literal
#     sub-expressions:
# 47. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 58, 78
# 48. Input(a)
#     core type: Operation
#     operator: 65
#     operand: 90
# 49. Gate(u)
#     core type: Operation
#     operator: 60
#     operand: 89
# 50. Input(u . a)
#     core type: Operation
#     operator: 65
#     operand: 74
# 51. --
#     core type: Literal
#     sub-expressions:
# 52. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 69
#     operands: 63
# 53. Output(b)
#     core type: Operation
#     operator: 71
#     operand: 76
# 54. Input(x)
#     core type: Operation
#     operator: 65
#     operand: 77
# 55. MultiWire(n)
#     core type: Operation
#     operator: 67
#     operand: 78
# 56. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 69
#     operands: 70
# 57. Output(y)
#     core type: Operation
#     operator: 71
#     operand: 81
# 58. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 73
# 59. (a)
#     core type: ExprTuple
#     sub-expressions: 90
# 60. GATE
#     core type: Literal
#     sub-expressions:
# 61. (u)
#     core type: ExprTuple
#     sub-expressions: 89
# 62. (u . a)
#     core type: ExprTuple
#     sub-expressions: 74
# 63. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 75, 80
# 64. (b)
#     core type: ExprTuple
#     sub-expressions: 76
# 65. INPUT
#     core type: Literal
#     sub-expressions:
# 66. (x)
#     core type: ExprTuple
#     sub-expressions: 77
# 67. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 68. (n)
#     core type: ExprTuple
#     sub-expressions: 78
# 69. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 70. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 79, 80
# 71. OUTPUT
#     core type: Literal
#     sub-expressions:
# 72. (y)
#     core type: ExprTuple
#     sub-expressions: 81
# 73. Complex^{2}
#     core type: Operation
#     operator: 82
#     operands: 83
# 74. u . a
#     core type: Operation
#     operator: 84
#     operands: 85
# 75. CONTROL
#     core type: Literal
#     sub-expressions:
# 76. b
#     core type: Variable
#     sub-expressions:
# 77. x
#     core type: Variable
#     sub-expressions:
# 78. n
#     core type: Variable
#     sub-expressions:
# 79. U
#     core type: Variable
#     sub-expressions:
# 80. {1, 2}
#     core type: Operation
#     operator: 86
#     operands: 87
# 81. y
#     core type: Variable
#     sub-expressions:
# 82. Exp
#     core type: Literal
#     sub-expressions:
# 83. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 88, 92
# 84. .
#     core type: Literal
#     sub-expressions:
# 85. (u, a)
#     core type: ExprTuple
#     sub-expressions: 89, 90
# 86. Set
#     core type: Literal
#     sub-expressions:
# 87. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 91, 92
# 88. Complex
#     core type: Literal
#     sub-expressions:
# 89. u
#     core type: Variable
#     sub-expressions:
# 90. a
#     core type: Variable
#     sub-expressions:
# 91. 1
#     core type: Literal
#     sub-expressions:
# 92. 2
#     core type: Literal
#     sub-expressions:
