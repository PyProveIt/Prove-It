# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, U, a, b, c, d, n, x, y
from proveit.logic import And, Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr3 = [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]
expr = ExprTuple(And(Circuit(ExprArray([Input(a), I, sub_expr2, Output(c)], sub_expr3)), Circuit(ExprArray([Input(b), I, sub_expr2, Output(d)], sub_expr3))), Circuit(ExprArray([Input(Add(a, b)), I, sub_expr2, Output(Add(c, d))], sub_expr3)))
# Out:
# expr: ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{b} & \qw & \control \qw \qwx[1] & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a + b} & \qw & \control \qw \qwx[1] & \rstick{c + d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2.  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 10
#    operand: 8
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. ((Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 10
#    operand: 13
# 7.  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 12, 19
# 9. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 13
# 10. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 11. ((Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (Input(a + b), --, MultiQubitGate(CONTROL, {1, 2}), Output(c + d))
#     core type: ExprTuple
#     sub-expressions: 15, 25, 26, 16
# 13. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 14. Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. Input(a + b)
#     core type: Operation
#     operator: 39
#     operand: 32
# 16. Output(c + d)
#     core type: Operation
#     operator: 45
#     operand: 33
# 17. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 22, 25, 26, 23
# 18. (Input(b), --, MultiQubitGate(CONTROL, {1, 2}), Output(d))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 19. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 31
# 20. (a + b)
#     core type: ExprTuple
#     sub-expressions: 32
# 21. (c + d)
#     core type: ExprTuple
#     sub-expressions: 33
# 22. Input(a)
#     core type: Operation
#     operator: 39
#     operand: 56
# 23. Output(c)
#     core type: Operation
#     operator: 45
#     operand: 58
# 24. Input(b)
#     core type: Operation
#     operator: 39
#     operand: 57
# 25. --
#     core type: Literal
#     sub-expressions:
# 26. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 43
#     operands: 37
# 27. Output(d)
#     core type: Operation
#     operator: 45
#     operand: 59
# 28. Input(x)
#     core type: Operation
#     operator: 39
#     operand: 51
# 29. MultiWire(n)
#     core type: Operation
#     operator: 41
#     operand: 52
# 30. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 43
#     operands: 44
# 31. Output(y)
#     core type: Operation
#     operator: 45
#     operand: 55
# 32. a + b
#     core type: Operation
#     operator: 48
#     operands: 47
# 33. c + d
#     core type: Operation
#     operator: 48
#     operands: 49
# 34. (a)
#     core type: ExprTuple
#     sub-expressions: 56
# 35. (c)
#     core type: ExprTuple
#     sub-expressions: 58
# 36. (b)
#     core type: ExprTuple
#     sub-expressions: 57
# 37. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 50, 54
# 38. (d)
#     core type: ExprTuple
#     sub-expressions: 59
# 39. INPUT
#     core type: Literal
#     sub-expressions:
# 40. (x)
#     core type: ExprTuple
#     sub-expressions: 51
# 41. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 42. (n)
#     core type: ExprTuple
#     sub-expressions: 52
# 43. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 44. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 45. OUTPUT
#     core type: Literal
#     sub-expressions:
# 46. (y)
#     core type: ExprTuple
#     sub-expressions: 55
# 47. (a, b)
#     core type: ExprTuple
#     sub-expressions: 56, 57
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (c, d)
#     core type: ExprTuple
#     sub-expressions: 58, 59
# 50. CONTROL
#     core type: Literal
#     sub-expressions:
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. n
#     core type: Variable
#     sub-expressions:
# 53. U
#     core type: Variable
#     sub-expressions:
# 54. {1, 2}
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. y
#     core type: Variable
#     sub-expressions:
# 56. a
#     core type: Variable
#     sub-expressions:
# 57. b
#     core type: Variable
#     sub-expressions:
# 58. c
#     core type: Variable
#     sub-expressions:
# 59. d
#     core type: Variable
#     sub-expressions:
# 60. Set
#     core type: Literal
#     sub-expressions:
# 61. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. 2
#     core type: Literal
#     sub-expressions:
