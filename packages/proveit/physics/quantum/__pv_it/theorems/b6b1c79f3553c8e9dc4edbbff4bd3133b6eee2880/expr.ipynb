# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, a, b, c, n, x, y, z
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Iff, InSet, Set
from proveit.numbers import Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = Lambda(U, Conditional(Forall([a, b, c], Forall([x, y, z], Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), InSet(U, SU(Exp(two, n)))))
# Out:
# expr: U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# U \mapsto \left\{\forall_{a, b, c \in \mathbb{C}^{2}}~\left[\forall_{x, y, z \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)\right)\right] \textrm{ if } U \in SU(2^{n})\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 100
#    body: 1
# 1. {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]
#    core type: Operation
#    operator: 15
#    operand: 6
# 3. U in SU(2^{n})
#    core type: Operation
#    operator: 44
#    operands: 5
# 4. ((a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 100, 7
# 6. (a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. SU(2^{n})
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 95, 93, 97
# 9. {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. SU
#     core type: Literal
#     sub-expressions:
# 11. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2})
#     core type: Operation
#     operator: 32
#     operands: 17
# 14. 2^{n}
#     core type: Operation
#     operator: 77
#     operands: 18
# 15. forall
#     core type: Literal
#     sub-expressions:
# 16. ((x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 20, 21, 22
# 18. (2, n)
#     core type: ExprTuple
#     sub-expressions: 106, 99
# 19. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 23\n    body: 24
# 20. a in Complex^{2}
#     core type: Operation
#     operator: 44
#     operands: 25
# 21. b in Complex^{2}
#     core type: Operation
#     operator: 44
#     operands: 26
# 22. c in Complex^{2}
#     core type: Operation
#     operator: 44
#     operands: 27
# 23. (x, y, z)
#     core type: ExprTuple
#     sub-expressions: 98, 94, 102
# 24. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 25. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 95, 66
# 26. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 93, 66
# 27. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 97, 66
# 28. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. <=>
#     core type: Literal
#     sub-expressions:
# 31. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. and
#     core type: Literal
#     sub-expressions:
# 33. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 36, 37, 38
# 34.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 40
#     operands: 39
# 35. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 40
#     operands: 41
# 36. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 44
#     operands: 42
# 37. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 44
#     operands: 43
# 38. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 44
#     operands: 45
# 39. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 40. =
#     core type: Literal
#     sub-expressions:
# 41. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 42. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 98, 50
# 43. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 94, 50
# 44. in
#     core type: Literal
#     sub-expressions:
# 45. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 102, 50
# 46.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 52
#     operand: 59
# 47.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 52
#     operand: 60
# 48. b otimes y
#     core type: Operation
#     operator: 55
#     operands: 54
# 49. c otimes z
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 57
#     operands: 58
# 51. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 59
# 52. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 53. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 60
# 54. (b, y)
#     core type: ExprTuple
#     sub-expressions: 93, 94
# 55. otimes
#     core type: Literal
#     sub-expressions:
# 56. (c, z)
#     core type: ExprTuple
#     sub-expressions: 97, 102
# 57. otimes
#     core type: Literal
#     sub-expressions:
# 58. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 61, 99
# 59. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 61. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 66
# 62. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 69, 70, 71, 67
# 63. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 73, 74, 75, 68
# 64. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 69, 70, 71, 72
# 65. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 73, 74, 75, 76
# 66. Complex^{2}
#     core type: Operation
#     operator: 77
#     operands: 78
# 67. Output(b)
#     core type: Operation
#     operator: 90
#     operand: 93
# 68. Output(y)
#     core type: Operation
#     operator: 90
#     operand: 94
# 69. Input(a)
#     core type: Operation
#     operator: 84
#     operand: 95
# 70. --
#     core type: Literal
#     sub-expressions:
# 71. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 88
#     operands: 82
# 72. Output(c)
#     core type: Operation
#     operator: 90
#     operand: 97
# 73. Input(x)
#     core type: Operation
#     operator: 84
#     operand: 98
# 74. MultiWire(n)
#     core type: Operation
#     operator: 86
#     operand: 99
# 75. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 88
#     operands: 89
# 76. Output(z)
#     core type: Operation
#     operator: 90
#     operand: 102
# 77. Exp
#     core type: Literal
#     sub-expressions:
# 78. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 92, 106
# 79. (b)
#     core type: ExprTuple
#     sub-expressions: 93
# 80. (y)
#     core type: ExprTuple
#     sub-expressions: 94
# 81. (a)
#     core type: ExprTuple
#     sub-expressions: 95
# 82. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 96, 101
# 83. (c)
#     core type: ExprTuple
#     sub-expressions: 97
# 84. INPUT
#     core type: Literal
#     sub-expressions:
# 85. (x)
#     core type: ExprTuple
#     sub-expressions: 98
# 86. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 87. (n)
#     core type: ExprTuple
#     sub-expressions: 99
# 88. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 89. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 90. OUTPUT
#     core type: Literal
#     sub-expressions:
# 91. (z)
#     core type: ExprTuple
#     sub-expressions: 102
# 92. Complex
#     core type: Literal
#     sub-expressions:
# 93. b
#     core type: Variable
#     sub-expressions:
# 94. y
#     core type: Variable
#     sub-expressions:
# 95. a
#     core type: Variable
#     sub-expressions:
# 96. CONTROL
#     core type: Literal
#     sub-expressions:
# 97. c
#     core type: Variable
#     sub-expressions:
# 98. x
#     core type: Variable
#     sub-expressions:
# 99. n
#     core type: Variable
#     sub-expressions:
# 100. U
#      core type: Variable
#      sub-expressions:
# 101. {1, 2}
#      core type: Operation
#      operator: 103
#      operands: 104
# 102. z
#      core type: Variable
#      sub-expressions:
# 103. Set
#      core type: Literal
#      sub-expressions:
# 104. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 105, 106
# 105. 1
#      core type: Literal
#      sub-expressions:
# 106. 2
#      core type: Literal
#      sub-expressions:
