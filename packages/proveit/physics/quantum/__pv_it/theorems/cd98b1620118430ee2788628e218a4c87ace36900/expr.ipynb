# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, U, a, b, c, n, x, y, z
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Iff, InSet, Set
from proveit.numbers import Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = ExprTuple(Lambda(U, Conditional(Forall([a, b, c], Forall([x, y, z], Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), InSet(U, SU(Exp(two, n))))))
# Out:
# expr: (U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(U \mapsto \left\{\forall_{a, b, c \in \mathbb{C}^{2}}~\left[\forall_{x, y, z \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)\right)\right] \textrm{ if } U \in SU(2^{n})\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. U -> {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 101
#    body: 2
# 2. {forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))] if U in SU(2^{n}).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]
#    core type: Operation
#    operator: 16
#    operand: 7
# 4. U in SU(2^{n})
#    core type: Operation
#    operator: 45
#    operands: 6
# 5. ((a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 101, 8
# 7. (a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 8. SU(2^{n})
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 96, 94, 98
# 10. {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. SU
#     core type: Literal
#     sub-expressions:
# 12. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))
#     core type: Operation
#     operator: 16
#     operand: 20
# 14. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2})
#     core type: Operation
#     operator: 33
#     operands: 18
# 15. 2^{n}
#     core type: Operation
#     operator: 78
#     operands: 19
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. ((x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 19. (2, n)
#     core type: ExprTuple
#     sub-expressions: 107, 100
# 20. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 24\n    body: 25
# 21. a in Complex^{2}
#     core type: Operation
#     operator: 45
#     operands: 26
# 22. b in Complex^{2}
#     core type: Operation
#     operator: 45
#     operands: 27
# 23. c in Complex^{2}
#     core type: Operation
#     operator: 45
#     operands: 28
# 24. (x, y, z)
#     core type: ExprTuple
#     sub-expressions: 99, 95, 103
# 25. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 29
#     condition: 30
# 26. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 96, 67
# 27. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 94, 67
# 28. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 98, 67
# 29. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#     core type: Operation
#     operator: 31
#     operands: 32
# 30. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. <=>
#     core type: Literal
#     sub-expressions:
# 32. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. and
#     core type: Literal
#     sub-expressions:
# 34. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 35.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 41
#     operands: 40
# 36. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 41
#     operands: 42
# 37. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 45
#     operands: 43
# 38. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 45
#     operands: 44
# 39. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 41. =
#     core type: Literal
#     sub-expressions:
# 42. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 43. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 99, 51
# 44. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 95, 51
# 45. in
#     core type: Literal
#     sub-expressions:
# 46. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 103, 51
# 47.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 53
#     operand: 60
# 48.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 53
#     operand: 61
# 49. b otimes y
#     core type: Operation
#     operator: 56
#     operands: 55
# 50. c otimes z
#     core type: Operation
#     operator: 56
#     operands: 57
# 51. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 58
#     operands: 59
# 52. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 60
# 53. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 54. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 61
# 55. (b, y)
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 56. otimes
#     core type: Literal
#     sub-expressions:
# 57. (c, z)
#     core type: ExprTuple
#     sub-expressions: 98, 103
# 58. otimes
#     core type: Literal
#     sub-expressions:
# 59. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 62, 100
# 60. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 61. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 65, 66
# 62. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 67
# 63. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 70, 71, 72, 68
# 64. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 74, 75, 76, 69
# 65. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 70, 71, 72, 73
# 66. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 74, 75, 76, 77
# 67. Complex^{2}
#     core type: Operation
#     operator: 78
#     operands: 79
# 68. Output(b)
#     core type: Operation
#     operator: 91
#     operand: 94
# 69. Output(y)
#     core type: Operation
#     operator: 91
#     operand: 95
# 70. Input(a)
#     core type: Operation
#     operator: 85
#     operand: 96
# 71. --
#     core type: Literal
#     sub-expressions:
# 72. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 89
#     operands: 83
# 73. Output(c)
#     core type: Operation
#     operator: 91
#     operand: 98
# 74. Input(x)
#     core type: Operation
#     operator: 85
#     operand: 99
# 75. MultiWire(n)
#     core type: Operation
#     operator: 87
#     operand: 100
# 76. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 89
#     operands: 90
# 77. Output(z)
#     core type: Operation
#     operator: 91
#     operand: 103
# 78. Exp
#     core type: Literal
#     sub-expressions:
# 79. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 93, 107
# 80. (b)
#     core type: ExprTuple
#     sub-expressions: 94
# 81. (y)
#     core type: ExprTuple
#     sub-expressions: 95
# 82. (a)
#     core type: ExprTuple
#     sub-expressions: 96
# 83. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 97, 102
# 84. (c)
#     core type: ExprTuple
#     sub-expressions: 98
# 85. INPUT
#     core type: Literal
#     sub-expressions:
# 86. (x)
#     core type: ExprTuple
#     sub-expressions: 99
# 87. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 88. (n)
#     core type: ExprTuple
#     sub-expressions: 100
# 89. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 90. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 101, 102
# 91. OUTPUT
#     core type: Literal
#     sub-expressions:
# 92. (z)
#     core type: ExprTuple
#     sub-expressions: 103
# 93. Complex
#     core type: Literal
#     sub-expressions:
# 94. b
#     core type: Variable
#     sub-expressions:
# 95. y
#     core type: Variable
#     sub-expressions:
# 96. a
#     core type: Variable
#     sub-expressions:
# 97. CONTROL
#     core type: Literal
#     sub-expressions:
# 98. c
#     core type: Variable
#     sub-expressions:
# 99. x
#     core type: Variable
#     sub-expressions:
# 100. n
#      core type: Variable
#      sub-expressions:
# 101. U
#      core type: Variable
#      sub-expressions:
# 102. {1, 2}
#      core type: Operation
#      operator: 104
#      operands: 105
# 103. z
#      core type: Variable
#      sub-expressions:
# 104. Set
#      core type: Literal
#      sub-expressions:
# 105. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 106, 107
# 106. 1
#      core type: Literal
#      sub-expressions:
# 107. 2
#      core type: Literal
#      sub-expressions:
