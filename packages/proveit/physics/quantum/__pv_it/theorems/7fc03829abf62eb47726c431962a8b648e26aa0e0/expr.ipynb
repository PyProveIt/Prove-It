# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, a, b, n, u, x, y
from proveit.linalg import MatrixProd, TensorExp
from proveit.logic import And, Equals, Forall, InSet, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, pregated_controlled_ngate
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = Conditional(Forall([x, y], Equals(pregated_controlled_ngate, Circuit(ExprArray([Input(MatrixProd(u, a)), I, MultiQubitGate(CONTROL, sub_expr1), Output(b)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]))), domain = TensorExp([QubitSpace], n)), And(InSet(a, QubitSpace), InSet(b, QubitSpace)))
# Out:
# expr: {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{u \thinspace a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right) \textrm{ if } a \in \mathbb{C}^{2} ,  b \in \mathbb{C}^{2}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (a in Complex^{2}) and (b in Complex^{2})
#    core type: Operation
#    operator: 17
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (a in Complex^{2}, b in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. (x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 9\n   body: 10
# 7. a in Complex^{2}
#    core type: Operation
#    operator: 27
#    operands: 11
# 8. b in Complex^{2}
#    core type: Operation
#    operator: 27
#    operands: 12
# 9. (x, y)
#    core type: ExprTuple
#    sub-expressions: 66, 70
# 10. { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 79, 62
# 12. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 65, 62
# 13.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 24
#     operand: 29
# 20.  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 24
#     operand: 30
# 21. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. ((Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 29
# 24. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 25. ((Input(u . a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 30
# 26. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 66, 31
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 70, 31
# 29. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 32, 34
# 30. Input(u . a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 31. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 41, 42
# 33. (Input(u . a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 34. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45, 46
# 35. otimes
#     core type: Literal
#     sub-expressions:
# 36. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 47, 67
# 37. Input(a)
#     core type: Operation
#     operator: 54
#     operand: 79
# 38. Gate(u)
#     core type: Operation
#     operator: 49
#     operand: 78
# 39. Input(u . a)
#     core type: Operation
#     operator: 54
#     operand: 63
# 40. --
#     core type: Literal
#     sub-expressions:
# 41. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 58
#     operands: 52
# 42. Output(b)
#     core type: Operation
#     operator: 60
#     operand: 65
# 43. Input(x)
#     core type: Operation
#     operator: 54
#     operand: 66
# 44. MultiWire(n)
#     core type: Operation
#     operator: 56
#     operand: 67
# 45. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 58
#     operands: 59
# 46. Output(y)
#     core type: Operation
#     operator: 60
#     operand: 70
# 47. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 62
# 48. (a)
#     core type: ExprTuple
#     sub-expressions: 79
# 49. GATE
#     core type: Literal
#     sub-expressions:
# 50. (u)
#     core type: ExprTuple
#     sub-expressions: 78
# 51. (u . a)
#     core type: ExprTuple
#     sub-expressions: 63
# 52. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 64, 69
# 53. (b)
#     core type: ExprTuple
#     sub-expressions: 65
# 54. INPUT
#     core type: Literal
#     sub-expressions:
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 66
# 56. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 57. (n)
#     core type: ExprTuple
#     sub-expressions: 67
# 58. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 59. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 60. OUTPUT
#     core type: Literal
#     sub-expressions:
# 61. (y)
#     core type: ExprTuple
#     sub-expressions: 70
# 62. Complex^{2}
#     core type: Operation
#     operator: 71
#     operands: 72
# 63. u . a
#     core type: Operation
#     operator: 73
#     operands: 74
# 64. CONTROL
#     core type: Literal
#     sub-expressions:
# 65. b
#     core type: Variable
#     sub-expressions:
# 66. x
#     core type: Variable
#     sub-expressions:
# 67. n
#     core type: Variable
#     sub-expressions:
# 68. U
#     core type: Variable
#     sub-expressions:
# 69. {1, 2}
#     core type: Operation
#     operator: 75
#     operands: 76
# 70. y
#     core type: Variable
#     sub-expressions:
# 71. Exp
#     core type: Literal
#     sub-expressions:
# 72. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 77, 81
# 73. .
#     core type: Literal
#     sub-expressions:
# 74. (u, a)
#     core type: ExprTuple
#     sub-expressions: 78, 79
# 75. Set
#     core type: Literal
#     sub-expressions:
# 76. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 80, 81
# 77. Complex
#     core type: Literal
#     sub-expressions:
# 78. u
#     core type: Variable
#     sub-expressions:
# 79. a
#     core type: Variable
#     sub-expressions:
# 80. 1
#     core type: Literal
#     sub-expressions:
# 81. 2
#     core type: Literal
#     sub-expressions:
