# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, a, b, c, d, k, n, u, x, y
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Add, Exp, one, two
from proveit.physics.quantum import QubitSpace, pregated_controlled_ngate, pregated_controlled_ngate_with_merge

# %%
# build up the expression from sub-expressions
sub_expr1 = [QubitSpace]
expr = Forall([U], Forall([u], Forall([a, b], Forall([c], Forall([d], Forall([x, y], Implies(pregated_controlled_ngate, Implies(pregated_controlled_ngate_with_merge, Equals(d, TensorProd(c, b)))), domain = TensorExp(sub_expr1, n)), domain = TensorExp(sub_expr1, Add(k, one))), domain = TensorExp(sub_expr1, k)), domain = QubitSpace), domain = SU(two)), domain = SU(Exp(two, n)))
# Out:
# expr: forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in SU(2^{n})}~\left[\forall_{u \in SU(2)}~\left[\forall_{a, b \in \mathbb{C}^{2}}~\left[\forall_{c \in \left(\mathbb{C}^{2}\right)^{\otimes k}}~\left[\forall_{d \in \left(\mathbb{C}^{2}\right)^{\otimes \left(k + 1\right)}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(d = \left(c {\otimes} b\right)\right)\right)\right)\right]\right]\right]\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]]]
#    core type: Operation
#    operator: 44
#    operand: 2
# 1. (U -> {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. U -> {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 138
#    body: 3
# 3. {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]] if U in SU(2^{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]]
#    core type: Operation
#    operator: 44
#    operand: 8
# 5. U in SU(2^{n})
#    core type: Operation
#    operator: 65
#    operands: 7
# 6. (u -> {forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]] if u in SU(2).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 138, 9
# 8. u -> {forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]] if u in SU(2).
#    core type: Lambda
#    parameter: 130
#    body: 10
# 9. SU(2^{n})
#    core type: Operation
#    operator: 22
#    operand: 14
# 10. {forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]] if u in SU(2).
#     core type: Conditional
#     value: 12
#     condition: 13
# 11. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]
#     core type: Operation
#     operator: 44
#     operand: 18
# 13. u in SU(2)
#     core type: Operation
#     operator: 65
#     operands: 16
# 14. 2^{n}
#     core type: Operation
#     operator: 108
#     operands: 17
# 15. ((a, b) -> {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]] if a in Complex^{2} ,  b in Complex^{2}.)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. (u, SU(2))
#     core type: ExprTuple
#     sub-expressions: 130, 19
# 17. (2, n)
#     core type: ExprTuple
#     sub-expressions: 148, 137
# 18. (a, b) -> {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]] if a in Complex^{2} ,  b in Complex^{2}.
#     core type: Lambda
#     parameters: 20\n    body: 21
# 19. SU(2)
#     core type: Operation
#     operator: 22
#     operand: 148
# 20. (a, b)
#     core type: ExprTuple
#     sub-expressions: 129, 107
# 21. {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]] if a in Complex^{2} ,  b in Complex^{2}.
#     core type: Conditional
#     value: 24
#     condition: 25
# 22. SU
#     core type: Literal
#     sub-expressions:
# 23. (2)
#     core type: ExprTuple
#     sub-expressions: 148
# 24. forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]
#     core type: Operation
#     operator: 44
#     operand: 28
# 25. (a in Complex^{2}) and (b in Complex^{2})
#     core type: Operation
#     operator: 55
#     operands: 27
# 26. (c -> {forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))] if c in (Complex^{2})^{otimes k}.)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. (a in Complex^{2}, b in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. c -> {forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))] if c in (Complex^{2})^{otimes k}.
#     core type: Lambda
#     parameter: 128
#     body: 31
# 29. a in Complex^{2}
#     core type: Operation
#     operator: 65
#     operands: 32
# 30. b in Complex^{2}
#     core type: Operation
#     operator: 65
#     operands: 33
# 31. {forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))] if c in (Complex^{2})^{otimes k}.
#     core type: Conditional
#     value: 34
#     condition: 35
# 32. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 129, 93
# 33. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 107, 93
# 34. forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]
#     core type: Operation
#     operator: 44
#     operand: 38
# 35. c in (Complex^{2})^{otimes k}
#     core type: Operation
#     operator: 65
#     operands: 37
# 36. (d -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. (c, (Complex^{2})^{otimes k})
#     core type: ExprTuple
#     sub-expressions: 128, 39
# 38. d -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.
#     core type: Lambda
#     parameter: 135
#     body: 40
# 39. (Complex^{2})^{otimes k}
#     core type: Operation
#     operator: 77
#     operands: 41
# 40. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.
#     core type: Conditional
#     value: 42
#     condition: 43
# 41. ((Complex^{2}), k)
#     core type: ExprTuple
#     sub-expressions: 84, 146
# 42. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))
#     core type: Operation
#     operator: 44
#     operand: 47
# 43. d in (Complex^{2})^{otimes (k + 1)}
#     core type: Operation
#     operator: 65
#     operands: 46
# 44. forall
#     core type: Literal
#     sub-expressions:
# 45. ((x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. (d, (Complex^{2})^{otimes (k + 1)})
#     core type: ExprTuple
#     sub-expressions: 135, 48
# 47. (x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 49\n    body: 50
# 48. (Complex^{2})^{otimes (k + 1)}
#     core type: Operation
#     operator: 77
#     operands: 51
# 49. (x, y)
#     core type: ExprTuple
#     sub-expressions: 136, 140
# 50. { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 52
#     condition: 53
# 51. ((Complex^{2}), k + 1)
#     core type: ExprTuple
#     sub-expressions: 84, 134
# 52.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))
#     core type: Operation
#     operator: 62
#     operands: 54
# 53. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 55. and
#     core type: Literal
#     sub-expressions:
# 56. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 57.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 73
#     operand: 67
# 58.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 65
#     operands: 64
# 60. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. ((Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 67
# 62. =>
#     core type: Literal
#     sub-expressions:
# 63. ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE, d = (c otimes b))
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 136, 70
# 65. in
#     core type: Literal
#     sub-expressions:
# 66. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 140, 70
# 67. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 68.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE
#     core type: Operation
#     operator: 73
#     operand: 82
# 69. d = (c otimes b)
#     core type: Operation
#     operator: 75
#     operands: 76
# 70. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 77
#     operands: 78
# 71. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 96, 97, 79, 80
# 72. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 102, 103, 81, 105
# 73. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 74. ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))
#     core type: ExprTuple
#     sub-expressions: 82
# 75. =
#     core type: Literal
#     sub-expressions:
# 76. (d, c otimes b)
#     core type: ExprTuple
#     sub-expressions: 135, 83
# 77. otimes
#     core type: Literal
#     sub-expressions:
# 78. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 84, 137
# 79. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 123
#     operands: 85
# 80. Output(b)
#     core type: Operation
#     operator: 125
#     operand: 107
# 81. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 123
#     operands: 87
# 82. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#     core type: ExprTuple
#     sub-expressions: 88, 89, 90
# 83. c otimes b
#     core type: Operation
#     operator: 91
#     operands: 92
# 84. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 93
# 85. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 131, 133
# 86. (b)
#     core type: ExprTuple
#     sub-expressions: 107
# 87. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 138, 133
# 88. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 94, 95, 132, 99, 106, 106
# 89. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#     core type: ExprTuple
#     sub-expressions: 96, 97, 98, 99, 100, 101
# 90. (Input(x), MultiWire(n), MultiQubitGate(U, {2, 3}), Output(y), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 102, 103, 104, 105, 106, 106
# 91. otimes
#     core type: Literal
#     sub-expressions:
# 92. (c, b)
#     core type: ExprTuple
#     sub-expressions: 128, 107
# 93. Complex^{2}
#     core type: Operation
#     operator: 108
#     operands: 109
# 94. Input(c)
#     core type: Operation
#     operator: 119
#     operand: 128
# 95. MultiWire(k)
#     core type: Operation
#     operator: 121
#     operand: 146
# 96. Input(a)
#     core type: Operation
#     operator: 119
#     operand: 129
# 97. Gate(u)
#     core type: Operation
#     operator: 113
#     operand: 130
# 98. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 123
#     operands: 115
# 99. MultiQubitGate([I], {1, 2})
#     core type: Operation
#     operator: 123
#     operands: 116
# 100. MultiWire(k + 1)
#      core type: Operation
#      operator: 121
#      operand: 134
# 101. Output(d)
#      core type: Operation
#      operator: 125
#      operand: 135
# 102. Input(x)
#      core type: Operation
#      operator: 119
#      operand: 136
# 103. MultiWire(n)
#      core type: Operation
#      operator: 121
#      operand: 137
# 104. MultiQubitGate(U, {2, 3})
#      core type: Operation
#      operator: 123
#      operands: 124
# 105. Output(y)
#      core type: Operation
#      operator: 125
#      operand: 140
# 106. SPACE
#      core type: Literal
#      sub-expressions:
# 107. b
#      core type: Variable
#      sub-expressions:
# 108. Exp
#      core type: Literal
#      sub-expressions:
# 109. (Complex, 2)
#      core type: ExprTuple
#      sub-expressions: 127, 148
# 110. (c)
#      core type: ExprTuple
#      sub-expressions: 128
# 111. (k)
#      core type: ExprTuple
#      sub-expressions: 146
# 112. (a)
#      core type: ExprTuple
#      sub-expressions: 129
# 113. GATE
#      core type: Literal
#      sub-expressions:
# 114. (u)
#      core type: ExprTuple
#      sub-expressions: 130
# 115. (CONTROL, {2, 3})
#      core type: ExprTuple
#      sub-expressions: 131, 139
# 116. (--, {1, 2})
#      core type: ExprTuple
#      sub-expressions: 132, 133
# 117. (k + 1)
#      core type: ExprTuple
#      sub-expressions: 134
# 118. (d)
#      core type: ExprTuple
#      sub-expressions: 135
# 119. INPUT
#      core type: Literal
#      sub-expressions:
# 120. (x)
#      core type: ExprTuple
#      sub-expressions: 136
# 121. MULTI_WIRE
#      core type: Literal
#      sub-expressions:
# 122. (n)
#      core type: ExprTuple
#      sub-expressions: 137
# 123. MULTI_QUBIT_GATE
#      core type: Literal
#      sub-expressions:
# 124. (U, {2, 3})
#      core type: ExprTuple
#      sub-expressions: 138, 139
# 125. OUTPUT
#      core type: Literal
#      sub-expressions:
# 126. (y)
#      core type: ExprTuple
#      sub-expressions: 140
# 127. Complex
#      core type: Literal
#      sub-expressions:
# 128. c
#      core type: Variable
#      sub-expressions:
# 129. a
#      core type: Variable
#      sub-expressions:
# 130. u
#      core type: Variable
#      sub-expressions:
# 131. CONTROL
#      core type: Literal
#      sub-expressions:
# 132. --
#      core type: Literal
#      sub-expressions:
# 133. {1, 2}
#      core type: Operation
#      operator: 144
#      operands: 141
# 134. k + 1
#      core type: Operation
#      operator: 142
#      operands: 143
# 135. d
#      core type: Variable
#      sub-expressions:
# 136. x
#      core type: Variable
#      sub-expressions:
# 137. n
#      core type: Variable
#      sub-expressions:
# 138. U
#      core type: Variable
#      sub-expressions:
# 139. {2, 3}
#      core type: Operation
#      operator: 144
#      operands: 145
# 140. y
#      core type: Variable
#      sub-expressions:
# 141. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 147, 148
# 142. +
#      core type: Literal
#      sub-expressions:
# 143. (k, 1)
#      core type: ExprTuple
#      sub-expressions: 146, 147
# 144. Set
#      core type: Literal
#      sub-expressions:
# 145. (2, 3)
#      core type: ExprTuple
#      sub-expressions: 148, 149
# 146. k
#      core type: Variable
#      sub-expressions:
# 147. 1
#      core type: Literal
#      sub-expressions:
# 148. 2
#      core type: Literal
#      sub-expressions:
# 149. 3
#      core type: Literal
#      sub-expressions:
