# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import b, c, d, k, n, x, y
from proveit.linalg import TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Add, one
from proveit.physics.quantum import QubitSpace, pregated_controlled_ngate, pregated_controlled_ngate_with_merge

# %%
# build up the expression from sub-expressions
sub_expr1 = [QubitSpace]
expr = Forall([d], Forall([x, y], Implies(pregated_controlled_ngate, Implies(pregated_controlled_ngate_with_merge, Equals(d, TensorProd(c, b)))), domain = TensorExp(sub_expr1, n)), domain = TensorExp(sub_expr1, Add(k, one)))
# Out:
# expr: forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{d \in \left(\mathbb{C}^{2}\right)^{\otimes \left(k + 1\right)}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(d = \left(c {\otimes} b\right)\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (d -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. d -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.
#    core type: Lambda
#    parameter: 97
#    body: 3
# 3. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))) if d in (Complex^{2})^{otimes (k + 1)}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. d in (Complex^{2})^{otimes (k + 1)}
#    core type: Operation
#    operator: 27
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (d, (Complex^{2})^{otimes (k + 1)})
#    core type: ExprTuple
#    sub-expressions: 97, 10
# 9. (x, y) -> { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. (Complex^{2})^{otimes (k + 1)}
#     core type: Operation
#     operator: 39
#     operands: 13
# 11. (x, y)
#     core type: ExprTuple
#     sub-expressions: 98, 102
# 12. { Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 13. ((Complex^{2}), k + 1)
#     core type: ExprTuple
#     sub-expressions: 46, 96
# 14.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))
#     core type: Operation
#     operator: 24
#     operands: 16
# 15. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b)))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19.  Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 35
#     operand: 29
# 20.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 27
#     operands: 26
# 22. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. ((Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 29
# 24. =>
#     core type: Literal
#     sub-expressions:
# 25. ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE, d = (c otimes b))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 26. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 98, 32
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 102, 32
# 29. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 30.  Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE
#     core type: Operation
#     operator: 35
#     operand: 44
# 31. d = (c otimes b)
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 33. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 58, 59, 41, 42
# 34. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 64, 65, 43, 67
# 35. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 36. ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))
#     core type: ExprTuple
#     sub-expressions: 44
# 37. =
#     core type: Literal
#     sub-expressions:
# 38. (d, c otimes b)
#     core type: ExprTuple
#     sub-expressions: 97, 45
# 39. otimes
#     core type: Literal
#     sub-expressions:
# 40. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 46, 99
# 41. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 85
#     operands: 47
# 42. Output(b)
#     core type: Operation
#     operator: 87
#     operand: 69
# 43. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 85
#     operands: 49
# 44. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52
# 45. c otimes b
#     core type: Operation
#     operator: 53
#     operands: 54
# 46. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 55
# 47. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 93, 95
# 48. (b)
#     core type: ExprTuple
#     sub-expressions: 69
# 49. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 100, 95
# 50. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 56, 57, 94, 61, 68, 68
# 51. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#     core type: ExprTuple
#     sub-expressions: 58, 59, 60, 61, 62, 63
# 52. (Input(x), MultiWire(n), MultiQubitGate(U, {2, 3}), Output(y), SPACE, SPACE)
#     core type: ExprTuple
#     sub-expressions: 64, 65, 66, 67, 68, 68
# 53. otimes
#     core type: Literal
#     sub-expressions:
# 54. (c, b)
#     core type: ExprTuple
#     sub-expressions: 90, 69
# 55. Complex^{2}
#     core type: Operation
#     operator: 70
#     operands: 71
# 56. Input(c)
#     core type: Operation
#     operator: 81
#     operand: 90
# 57. MultiWire(k)
#     core type: Operation
#     operator: 83
#     operand: 108
# 58. Input(a)
#     core type: Operation
#     operator: 81
#     operand: 91
# 59. Gate(u)
#     core type: Operation
#     operator: 75
#     operand: 92
# 60. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 85
#     operands: 77
# 61. MultiQubitGate([I], {1, 2})
#     core type: Operation
#     operator: 85
#     operands: 78
# 62. MultiWire(k + 1)
#     core type: Operation
#     operator: 83
#     operand: 96
# 63. Output(d)
#     core type: Operation
#     operator: 87
#     operand: 97
# 64. Input(x)
#     core type: Operation
#     operator: 81
#     operand: 98
# 65. MultiWire(n)
#     core type: Operation
#     operator: 83
#     operand: 99
# 66. MultiQubitGate(U, {2, 3})
#     core type: Operation
#     operator: 85
#     operands: 86
# 67. Output(y)
#     core type: Operation
#     operator: 87
#     operand: 102
# 68. SPACE
#     core type: Literal
#     sub-expressions:
# 69. b
#     core type: Variable
#     sub-expressions:
# 70. Exp
#     core type: Literal
#     sub-expressions:
# 71. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 89, 110
# 72. (c)
#     core type: ExprTuple
#     sub-expressions: 90
# 73. (k)
#     core type: ExprTuple
#     sub-expressions: 108
# 74. (a)
#     core type: ExprTuple
#     sub-expressions: 91
# 75. GATE
#     core type: Literal
#     sub-expressions:
# 76. (u)
#     core type: ExprTuple
#     sub-expressions: 92
# 77. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 93, 101
# 78. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 94, 95
# 79. (k + 1)
#     core type: ExprTuple
#     sub-expressions: 96
# 80. (d)
#     core type: ExprTuple
#     sub-expressions: 97
# 81. INPUT
#     core type: Literal
#     sub-expressions:
# 82. (x)
#     core type: ExprTuple
#     sub-expressions: 98
# 83. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 84. (n)
#     core type: ExprTuple
#     sub-expressions: 99
# 85. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 86. (U, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 100, 101
# 87. OUTPUT
#     core type: Literal
#     sub-expressions:
# 88. (y)
#     core type: ExprTuple
#     sub-expressions: 102
# 89. Complex
#     core type: Literal
#     sub-expressions:
# 90. c
#     core type: Variable
#     sub-expressions:
# 91. a
#     core type: Variable
#     sub-expressions:
# 92. u
#     core type: Variable
#     sub-expressions:
# 93. CONTROL
#     core type: Literal
#     sub-expressions:
# 94. --
#     core type: Literal
#     sub-expressions:
# 95. {1, 2}
#     core type: Operation
#     operator: 106
#     operands: 103
# 96. k + 1
#     core type: Operation
#     operator: 104
#     operands: 105
# 97. d
#     core type: Variable
#     sub-expressions:
# 98. x
#     core type: Variable
#     sub-expressions:
# 99. n
#     core type: Variable
#     sub-expressions:
# 100. U
#      core type: Variable
#      sub-expressions:
# 101. {2, 3}
#      core type: Operation
#      operator: 106
#      operands: 107
# 102. y
#      core type: Variable
#      sub-expressions:
# 103. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 109, 110
# 104. +
#      core type: Literal
#      sub-expressions:
# 105. (k, 1)
#      core type: ExprTuple
#      sub-expressions: 108, 109
# 106. Set
#      core type: Literal
#      sub-expressions:
# 107. (2, 3)
#      core type: ExprTuple
#      sub-expressions: 110, 111
# 108. k
#      core type: Variable
#      sub-expressions:
# 109. 1
#      core type: Literal
#      sub-expressions:
# 110. 2
#      core type: Literal
#      sub-expressions:
# 111. 3
#      core type: Literal
#      sub-expressions:
