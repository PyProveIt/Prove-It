# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, U, a, b, c, n, x, y, z
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = ExprTuple(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z)))
# Out:
# expr: ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}, \left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (b otimes y) = (c otimes z)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (b otimes y, c otimes z)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#    core type: Operation
#    operator: 11
#    operand: 16
# 7.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#    core type: Operation
#    operator: 11
#    operand: 17
# 8. b otimes y
#    core type: Operation
#    operator: 14
#    operands: 13
# 9. c otimes z
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 16
# 11. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 12. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 17
# 13. (b, y)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 14. otimes
#     core type: Literal
#     sub-expressions:
# 15. (c, z)
#     core type: ExprTuple
#     sub-expressions: 49, 54
# 16. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 22
# 19. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 23
# 20. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26, 27
# 21. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 31
# 22. Output(b)
#     core type: Operation
#     operator: 43
#     operand: 45
# 23. Output(y)
#     core type: Operation
#     operator: 43
#     operand: 46
# 24. Input(a)
#     core type: Operation
#     operator: 37
#     operand: 47
# 25. --
#     core type: Literal
#     sub-expressions:
# 26. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 41
#     operands: 35
# 27. Output(c)
#     core type: Operation
#     operator: 43
#     operand: 49
# 28. Input(x)
#     core type: Operation
#     operator: 37
#     operand: 50
# 29. MultiWire(n)
#     core type: Operation
#     operator: 39
#     operand: 51
# 30. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 41
#     operands: 42
# 31. Output(z)
#     core type: Operation
#     operator: 43
#     operand: 54
# 32. (b)
#     core type: ExprTuple
#     sub-expressions: 45
# 33. (y)
#     core type: ExprTuple
#     sub-expressions: 46
# 34. (a)
#     core type: ExprTuple
#     sub-expressions: 47
# 35. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 48, 53
# 36. (c)
#     core type: ExprTuple
#     sub-expressions: 49
# 37. INPUT
#     core type: Literal
#     sub-expressions:
# 38. (x)
#     core type: ExprTuple
#     sub-expressions: 50
# 39. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 40. (n)
#     core type: ExprTuple
#     sub-expressions: 51
# 41. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 42. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 43. OUTPUT
#     core type: Literal
#     sub-expressions:
# 44. (z)
#     core type: ExprTuple
#     sub-expressions: 54
# 45. b
#     core type: Variable
#     sub-expressions:
# 46. y
#     core type: Variable
#     sub-expressions:
# 47. a
#     core type: Variable
#     sub-expressions:
# 48. CONTROL
#     core type: Literal
#     sub-expressions:
# 49. c
#     core type: Variable
#     sub-expressions:
# 50. x
#     core type: Variable
#     sub-expressions:
# 51. n
#     core type: Variable
#     sub-expressions:
# 52. U
#     core type: Variable
#     sub-expressions:
# 53. {1, 2}
#     core type: Operation
#     operator: 55
#     operands: 56
# 54. z
#     core type: Variable
#     sub-expressions:
# 55. Set
#     core type: Literal
#     sub-expressions:
# 56. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 57. 1
#     core type: Literal
#     sub-expressions:
# 58. 2
#     core type: Literal
#     sub-expressions:
