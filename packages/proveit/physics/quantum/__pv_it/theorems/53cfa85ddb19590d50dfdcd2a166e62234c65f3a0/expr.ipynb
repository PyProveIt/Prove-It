# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, b, c, d, k, n, x, y
from proveit.linalg import TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, Implies, InSet
from proveit.numbers import Add, one
from proveit.physics.quantum import QubitSpace, pregated_controlled_ngate, pregated_controlled_ngate_with_merge

# %%
# build up the expression from sub-expressions
sub_expr1 = [QubitSpace]
expr = ExprTuple(Lambda([a, b], Conditional(Forall([c], Forall([d], Forall([x, y], Implies(pregated_controlled_ngate, Implies(pregated_controlled_ngate_with_merge, Equals(d, TensorProd(c, b)))), domain = TensorExp(sub_expr1, n)), domain = TensorExp(sub_expr1, Add(k, one))), domain = TensorExp(sub_expr1, k)), And(InSet(a, QubitSpace), InSet(b, QubitSpace)))))
# Out:
# expr: ((a, b) -> {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]] if a in Complex^{2} ,  b in Complex^{2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b\right) \mapsto \left\{\forall_{c \in \left(\mathbb{C}^{2}\right)^{\otimes k}}~\left[\forall_{d \in \left(\mathbb{C}^{2}\right)^{\otimes \left(k + 1\right)}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(d = \left(c {\otimes} b\right)\right)\right)\right)\right]\right] \textrm{ if } a \in \mathbb{C}^{2} ,  b \in \mathbb{C}^{2}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b) -> {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]] if a in Complex^{2} ,  b in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b) -> {forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
# ...
