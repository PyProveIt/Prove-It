# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, U, a, b, c, n, x, y, z
from proveit.linalg import TensorExp
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, Iff, InSet, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(a)
sub_expr2 = Set(one, two)
sub_expr3 = Input(x)
sub_expr4 = MultiWire(n)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr2)
sub_expr6 = MultiQubitGate(U, sub_expr2)
expr = ExprTuple(Lambda([a, b, c], Conditional(Forall([x, y, z], Iff(Equals(Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(b)], [sub_expr3, sub_expr4, sub_expr6, Output(y)])), Circuit(ExprArray([sub_expr1, I, sub_expr5, Output(c)], [sub_expr3, sub_expr4, sub_expr6, Output(z)]))), Equals(TensorProd(b, y), TensorProd(c, z))), domain = TensorExp([QubitSpace], n)), And(InSet(a, QubitSpace), InSet(b, QubitSpace), InSet(c, QubitSpace)))))
# Out:
# expr: ((a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left\{\forall_{x, y, z \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{z} \qw
# } \hspace{2em}\right) \Leftrightarrow \left(\left(b {\otimes} y\right) = \left(c {\otimes} z\right)\right)\right) \textrm{ if } a \in \mathbb{C}^{2} ,  b \in \mathbb{C}^{2} ,  c \in \mathbb{C}^{2}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 85, 83, 87
# 3. {forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2})
#    core type: Operation
#    operator: 22
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 10, 11, 12
# 9. (x, y, z) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 13\n   body: 14
# 10. a in Complex^{2}
#     core type: Operation
#     operator: 34
#     operands: 15
# 11. b in Complex^{2}
#     core type: Operation
#     operator: 34
#     operands: 16
# 12. c in Complex^{2}
#     core type: Operation
#     operator: 34
#     operands: 17
# 13. (x, y, z)
#     core type: ExprTuple
#     sub-expressions: 88, 84, 92
# 14. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n} ,  z in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 15. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 85, 56
# 16. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 83, 56
# 17. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 87, 56
# 18. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z))
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n}) and (z in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. <=>
#     core type: Literal
#     sub-expressions:
# 21. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z), (b otimes y) = (c otimes z))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. and
#     core type: Literal
#     sub-expressions:
# 23. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n}, z in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 24.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 30
#     operands: 29
# 25. (b otimes y) = (c otimes z)
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 34
#     operands: 32
# 27. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 34
#     operands: 33
# 28. z in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 34
#     operands: 35
# 29. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z))
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 30. =
#     core type: Literal
#     sub-expressions:
# 31. (b otimes y, c otimes z)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 32. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 88, 40
# 33. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 84, 40
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (z, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 92, 40
# 36.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 42
#     operand: 49
# 37.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)
#     core type: Operation
#     operator: 42
#     operand: 50
# 38. b otimes y
#     core type: Operation
#     operator: 45
#     operands: 44
# 39. c otimes z
#     core type: Operation
#     operator: 45
#     operands: 46
# 40. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 41. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 49
# 42. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 43. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)))
#     core type: ExprTuple
#     sub-expressions: 50
# 44. (b, y)
#     core type: ExprTuple
#     sub-expressions: 83, 84
# 45. otimes
#     core type: Literal
#     sub-expressions:
# 46. (c, z)
#     core type: ExprTuple
#     sub-expressions: 87, 92
# 47. otimes
#     core type: Literal
#     sub-expressions:
# 48. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 51, 89
# 49. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(z)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 51. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 56
# 52. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(b))
#     core type: ExprTuple
#     sub-expressions: 59, 60, 61, 57
# 53. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 63, 64, 65, 58
# 54. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 59, 60, 61, 62
# 55. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(z))
#     core type: ExprTuple
#     sub-expressions: 63, 64, 65, 66
# 56. Complex^{2}
#     core type: Operation
#     operator: 67
#     operands: 68
# 57. Output(b)
#     core type: Operation
#     operator: 80
#     operand: 83
# 58. Output(y)
#     core type: Operation
#     operator: 80
#     operand: 84
# 59. Input(a)
#     core type: Operation
#     operator: 74
#     operand: 85
# 60. --
#     core type: Literal
#     sub-expressions:
# 61. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 78
#     operands: 72
# 62. Output(c)
#     core type: Operation
#     operator: 80
#     operand: 87
# 63. Input(x)
#     core type: Operation
#     operator: 74
#     operand: 88
# 64. MultiWire(n)
#     core type: Operation
#     operator: 76
#     operand: 89
# 65. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 78
#     operands: 79
# 66. Output(z)
#     core type: Operation
#     operator: 80
#     operand: 92
# 67. Exp
#     core type: Literal
#     sub-expressions:
# 68. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 82, 96
# 69. (b)
#     core type: ExprTuple
#     sub-expressions: 83
# 70. (y)
#     core type: ExprTuple
#     sub-expressions: 84
# 71. (a)
#     core type: ExprTuple
#     sub-expressions: 85
# 72. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 86, 91
# 73. (c)
#     core type: ExprTuple
#     sub-expressions: 87
# 74. INPUT
#     core type: Literal
#     sub-expressions:
# 75. (x)
#     core type: ExprTuple
#     sub-expressions: 88
# 76. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 77. (n)
#     core type: ExprTuple
#     sub-expressions: 89
# 78. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 79. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 90, 91
# 80. OUTPUT
#     core type: Literal
#     sub-expressions:
# 81. (z)
#     core type: ExprTuple
#     sub-expressions: 92
# 82. Complex
#     core type: Literal
#     sub-expressions:
# 83. b
#     core type: Variable
#     sub-expressions:
# 84. y
#     core type: Variable
#     sub-expressions:
# 85. a
#     core type: Variable
#     sub-expressions:
# 86. CONTROL
#     core type: Literal
#     sub-expressions:
# 87. c
#     core type: Variable
#     sub-expressions:
# 88. x
#     core type: Variable
#     sub-expressions:
# 89. n
#     core type: Variable
#     sub-expressions:
# 90. U
#     core type: Variable
#     sub-expressions:
# 91. {1, 2}
#     core type: Operation
#     operator: 93
#     operands: 94
# 92. z
#     core type: Variable
#     sub-expressions:
# 93. Set
#     core type: Literal
#     sub-expressions:
# 94. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 95, 96
# 95. 1
#     core type: Literal
#     sub-expressions:
# 96. 2
#     core type: Literal
#     sub-expressions:
