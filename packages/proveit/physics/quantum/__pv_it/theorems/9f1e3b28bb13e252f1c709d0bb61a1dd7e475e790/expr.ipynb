# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, U, a, b, c, d, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.logic import And, Forall, Implies, InSet, Set
from proveit.numbers import Add, Exp, NaturalPos, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr3 = [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]
expr = ExprTuple(Lambda(n, Conditional(Forall([U], Forall([a, b, c, d], Forall([x, y], Implies(And(Circuit(ExprArray([Input(a), I, sub_expr2, Output(c)], sub_expr3)), Circuit(ExprArray([Input(b), I, sub_expr2, Output(d)], sub_expr3))), Circuit(ExprArray([Input(Add(a, b)), I, sub_expr2, Output(Add(c, d))], sub_expr3))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), domain = SU(Exp(two, n))), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{U \in SU(2^{n})}~\left[\forall_{a, b, c, d \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw & \control \qw \qwx[1] & \rstick{c} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{b} & \qw & \control \qw \qwx[1] & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right) \Rightarrow \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a + b} & \qw & \control \qw \qwx[1] & \rstick{c + d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 107
#    body: 2
# 2. {forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]
#    core type: Operation
#    operator: 23
#    operand: 7
# 4. n in NaturalPos
#    core type: Operation
#    operator: 51
#    operands: 6
# 5. (U -> {forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 107, 8
# 7. U -> {forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 108
#    body: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. {forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))] if U in SU(2^{n}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]
#     core type: Operation
#     operator: 23
#     operand: 14
# 11. U in SU(2^{n})
#     core type: Operation
#     operator: 51
#     operands: 13
# 12. ((a, b, c, d) -> {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 108, 15
# 14. (a, b, c, d) -> {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.
#     core type: Lambda
#     parameters: 16\n    body: 17
# 15. SU(2^{n})
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. (a, b, c, d)
#     core type: ExprTuple
#     sub-expressions: 111, 112, 113, 114
# 17. {forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) if a in Complex^{2} ,  b in Complex^{2} ,  c in Complex^{2} ,  d in Complex^{2}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. SU
#     core type: Literal
#     sub-expressions:
# 19. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 20. forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: Operation
#     operator: 23
#     operand: 27
# 21. (a in Complex^{2}) and (b in Complex^{2}) and (c in Complex^{2}) and (d in Complex^{2})
#     core type: Operation
#     operator: 47
#     operands: 25
# 22. 2^{n}
#     core type: Operation
#     operator: 86
#     operands: 26
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. ((x, y) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. (a in Complex^{2}, b in Complex^{2}, c in Complex^{2}, d in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 31
# 26. (2, n)
#     core type: ExprTuple
#     sub-expressions: 118, 107
# 27. (x, y) -> {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 32\n    body: 33
# 28. a in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 34
# 29. b in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 35
# 30. c in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 36
# 31. d in Complex^{2}
#     core type: Operation
#     operator: 51
#     operands: 37
# 32. (x, y)
#     core type: ExprTuple
#     sub-expressions: 106, 110
# 33. {( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 38
#     condition: 39
# 34. (a, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 111, 73
# 35. (b, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 112, 73
# 36. (c, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 113, 73
# 37. (d, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 114, 73
# 38. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 40
#     operands: 41
# 39. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 47
#     operands: 42
# 40. =>
#     core type: Literal
#     sub-expressions:
# 41. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 42. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 47
#     operands: 48
# 44.  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 58
#     operand: 55
# 45. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 51
#     operands: 50
# 46. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 51
#     operands: 52
# 47. and
#     core type: Literal
#     sub-expressions:
# 48. ( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y),  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 49. ((Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 55
# 50. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 106, 56
# 51. in
#     core type: Literal
#     sub-expressions:
# 52. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 110, 56
# 53.  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 58
#     operand: 63
# 54.  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)
#     core type: Operation
#     operator: 58
#     operand: 64
# 55. Input(a + b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c + d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 60, 70
# 56. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 61
#     operands: 62
# 57. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 63
# 58. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 59. ((Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 64
# 60. (Input(a + b), --, MultiQubitGate(CONTROL, {1, 2}), Output(c + d))
#     core type: ExprTuple
#     sub-expressions: 65, 77, 78, 66
# 61. otimes
#     core type: Literal
#     sub-expressions:
# 62. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 67, 107
# 63. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 68, 70
# 64. Input(b) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 65. Input(a + b)
#     core type: Operation
#     operator: 93
#     operand: 84
# 66. Output(c + d)
#     core type: Operation
#     operator: 99
#     operand: 85
# 67. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 73
# 68. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#     core type: ExprTuple
#     sub-expressions: 74, 77, 78, 75
# 69. (Input(b), --, MultiQubitGate(CONTROL, {1, 2}), Output(d))
#     core type: ExprTuple
#     sub-expressions: 76, 77, 78, 79
# 70. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#     core type: ExprTuple
#     sub-expressions: 80, 81, 82, 83
# 71. (a + b)
#     core type: ExprTuple
#     sub-expressions: 84
# 72. (c + d)
#     core type: ExprTuple
#     sub-expressions: 85
# 73. Complex^{2}
#     core type: Operation
#     operator: 86
#     operands: 87
# 74. Input(a)
#     core type: Operation
#     operator: 93
#     operand: 111
# 75. Output(c)
#     core type: Operation
#     operator: 99
#     operand: 113
# 76. Input(b)
#     core type: Operation
#     operator: 93
#     operand: 112
# 77. --
#     core type: Literal
#     sub-expressions:
# 78. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 97
#     operands: 91
# 79. Output(d)
#     core type: Operation
#     operator: 99
#     operand: 114
# 80. Input(x)
#     core type: Operation
#     operator: 93
#     operand: 106
# 81. MultiWire(n)
#     core type: Operation
#     operator: 95
#     operand: 107
# 82. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 97
#     operands: 98
# 83. Output(y)
#     core type: Operation
#     operator: 99
#     operand: 110
# 84. a + b
#     core type: Operation
#     operator: 102
#     operands: 101
# 85. c + d
#     core type: Operation
#     operator: 102
#     operands: 103
# 86. Exp
#     core type: Literal
#     sub-expressions:
# 87. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 104, 118
# 88. (a)
#     core type: ExprTuple
#     sub-expressions: 111
# 89. (c)
#     core type: ExprTuple
#     sub-expressions: 113
# 90. (b)
#     core type: ExprTuple
#     sub-expressions: 112
# 91. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 105, 109
# 92. (d)
#     core type: ExprTuple
#     sub-expressions: 114
# 93. INPUT
#     core type: Literal
#     sub-expressions:
# 94. (x)
#     core type: ExprTuple
#     sub-expressions: 106
# 95. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 96. (n)
#     core type: ExprTuple
#     sub-expressions: 107
# 97. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 98. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 108, 109
# 99. OUTPUT
#     core type: Literal
#     sub-expressions:
# 100. (y)
#      core type: ExprTuple
#      sub-expressions: 110
# 101. (a, b)
#      core type: ExprTuple
#      sub-expressions: 111, 112
# 102. +
#      core type: Literal
#      sub-expressions:
# 103. (c, d)
#      core type: ExprTuple
#      sub-expressions: 113, 114
# 104. Complex
#      core type: Literal
#      sub-expressions:
# 105. CONTROL
#      core type: Literal
#      sub-expressions:
# 106. x
#      core type: Variable
#      sub-expressions:
# 107. n
#      core type: Variable
#      sub-expressions:
# 108. U
#      core type: Variable
#      sub-expressions:
# 109. {1, 2}
#      core type: Operation
#      operator: 115
#      operands: 116
# 110. y
#      core type: Variable
#      sub-expressions:
# 111. a
#      core type: Variable
#      sub-expressions:
# 112. b
#      core type: Variable
#      sub-expressions:
# 113. c
#      core type: Variable
#      sub-expressions:
# 114. d
#      core type: Variable
#      sub-expressions:
# 115. Set
#      core type: Literal
#      sub-expressions:
# 116. (1, 2)
#      core type: ExprTuple
#      sub-expressions: 117, 118
# 117. 1
#      core type: Literal
#      sub-expressions:
# 118. 2
#      core type: Literal
#      sub-expressions:
