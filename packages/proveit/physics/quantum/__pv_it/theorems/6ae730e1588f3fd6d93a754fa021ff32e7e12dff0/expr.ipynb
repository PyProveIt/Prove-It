# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, a, b, n, u, x, y
from proveit.linalg import MatrixProd, SU, TensorExp
from proveit.logic import Equals, Forall, InSet, Set
from proveit.numbers import Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, pregated_controlled_ngate
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = Lambda(U, Conditional(Forall([u], Forall([a, b], Forall([x, y], Equals(pregated_controlled_ngate, Circuit(ExprArray([Input(MatrixProd(u, a)), I, MultiQubitGate(CONTROL, sub_expr1), Output(b)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]))), domain = TensorExp([QubitSpace], n)), domain = QubitSpace), domain = SU(two)), InSet(U, SU(Exp(two, n)))))
# Out:
# expr: U -> {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if U in SU(2^{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# U \mapsto \left\{\forall_{u \in SU(2)}~\left[\forall_{a, b \in \mathbb{C}^{2}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} = \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{u \thinspace a} & \qw & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em}\right)\right]\right] \textrm{ if } U \in SU(2^{n})\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. U -> {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 89
#    body: 1
# 1. {forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]] if U in SU(2^{n}).
#    core type: Conditional
#    value: 2
#    condition: 3
# ...
