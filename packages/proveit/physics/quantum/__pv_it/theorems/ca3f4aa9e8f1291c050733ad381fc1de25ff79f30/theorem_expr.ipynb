# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pregated_controlled_ngate_merger">pregated_controlled_ngate_merger</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import pregated_controlled_ngate_merger

# %%
# check that the built expression is the same as the stored expression
assert pregated_controlled_ngate_merger.expr == stored_expr
assert pregated_controlled_ngate_merger.expr._style_id == stored_expr._style_id
print("Passed sanity check: pregated_controlled_ngate_merger matches stored_expr")
# Out:
# Passed sanity check: pregated_controlled_ngate_merger matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pregated_controlled_ngate_merger.latex())
# Out:
# \vdash \forall_{n, k \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{u \in SU(2)}~\left[\forall_{a, b \in \mathbb{C}^{2}}~\left[\forall_{c \in \left(\mathbb{C}^{2}\right)^{\otimes k}}~\left[\forall_{d \in \left(\mathbb{C}^{2}\right)^{\otimes \left(k + 1\right)}}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \rstick{b} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & { /^{k} } \qw & \qw & \qw \qwx[1]   \\
#   & \lstick{a} & \gate{u} & \control \qw \qwx[1] & \qw & { /^{k + 1} } \qw & \rstick{d} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Rightarrow \left(d = \left(c {\otimes} b\right)\right)\right)\right)\right]\right]\right]\right]\right]\right]

# %%
pregated_controlled_ngate_merger.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
pregated_controlled_ngate_merger.expr_info()
# Out:
# 0. forall_{n, k in NaturalPos} [forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{c in (Complex^{2})^{otimes k}} [forall_{d in (Complex^{2})^{otimes (k + 1)}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) => ( Input(c)  & MultiWire(k)  & --  & MultiQubitGate(--, {1, 2})  & SPACE  & SPACE   \\
#    Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(--, {1, 2})  & MultiWire(k + 1)  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {2, 3})  & Output(y)  & SPACE  & SPACE => (d = (c otimes b))))]]]]]]
#    core type: Operation
#    operator: 56
#    operand: 2
# ...
