# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, U, a, c, n, x, y
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output
from proveit.physics.quantum.circuit import MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = ExprTuple(ExprArray([Input(a), I, MultiQubitGate(CONTROL, sub_expr1), Output(c)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)]))
# Out:
# expr: ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccc}
#  \lstick{a} & \qw & \control \qw & \rstick{c} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{y} \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(a) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(c)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (Input(a), --, MultiQubitGate(CONTROL, {1, 2}), Output(c))
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6, 7
# 3. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 4. Input(a)
#    core type: Operation
#    operator: 15
#    operand: 23
# 5. --
#    core type: Literal
#    sub-expressions:
# 6. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 19
#    operands: 13
# 7. Output(c)
#    core type: Operation
#    operator: 21
#    operand: 25
# 8. Input(x)
#    core type: Operation
#    operator: 15
# ...
