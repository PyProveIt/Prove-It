# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Forall, Iff
from proveit.numbers import Exp, NaturalPos, two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = Forall([n], Forall([U], Forall([x, y], Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n))), domain = NaturalPos)
# Out:
# expr: forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right)\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))]]
#    core type: Operation
#    operator: 13
#    operand: 2
# 1. (n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 64
#    body: 3
# 3. {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))]
#    core type: Operation
#    operator: 13
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 39
#    operands: 7
# 6. (U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 64, 9
# 8. U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 65
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#     core type: Operation
#     operator: 13
#     operand: 16
# 12. U in SU(2^{n})
#     core type: Operation
#     operator: 39
#     operands: 15
# 13. forall
#     core type: Literal
#     sub-expressions:
# 14. ((x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 65, 17
# 16. (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 18\n    body: 19
# 17. SU(2^{n})
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. (x, y)
#     core type: ExprTuple
#     sub-expressions: 63, 66
# 19. { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 22
#     condition: 23
# 20. SU
#     core type: Literal
#     sub-expressions:
# 21. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 24
# 22.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 27
#     operands: 28
# 24. 2^{n}
#     core type: Operation
#     operator: 67
#     operands: 29
# 25. <=>
#     core type: Literal
#     sub-expressions:
# 26. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. and
#     core type: Literal
#     sub-expressions:
# 28. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 29. (2, n)
#     core type: ExprTuple
#     sub-expressions: 70, 64
# 30.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 34
#     operand: 41
# 31. y = (U . x)
#     core type: Operation
#     operator: 36
#     operands: 37
# 32. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 39
#     operands: 38
# 33. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 39
#     operands: 40
# 34. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 35. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 41
# 36. =
#     core type: Literal
#     sub-expressions:
# 37. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 66, 42
# 38. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 63, 43
# 39. in
#     core type: Literal
#     sub-expressions:
# 40. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 66, 43
# 41. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. U . x
#     core type: Operation
#     operator: 45
#     operands: 46
# 43. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 47
#     operands: 48
# 44. (Input(x), MultiWire(n), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 49, 50, 51, 52
# 45. .
#     core type: Literal
#     sub-expressions:
# 46. (U, x)
#     core type: ExprTuple
#     sub-expressions: 65, 63
# 47. otimes
#     core type: Literal
#     sub-expressions:
# 48. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 53, 64
# 49. Input(x)
#     core type: Operation
#     operator: 54
#     operand: 63
# 50. MultiWire(n)
#     core type: Operation
#     operator: 56
#     operand: 64
# 51. Gate(U)
#     core type: Operation
#     operator: 58
#     operand: 65
# 52. Output(y)
#     core type: Operation
#     operator: 60
#     operand: 66
# 53. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 62
# 54. INPUT
#     core type: Literal
#     sub-expressions:
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 63
# 56. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 57. (n)
#     core type: ExprTuple
#     sub-expressions: 64
# 58. GATE
#     core type: Literal
#     sub-expressions:
# 59. (U)
#     core type: ExprTuple
#     sub-expressions: 65
# 60. OUTPUT
#     core type: Literal
#     sub-expressions:
# 61. (y)
#     core type: ExprTuple
#     sub-expressions: 66
# 62. Complex^{2}
#     core type: Operation
#     operator: 67
#     operands: 68
# 63. x
#     core type: Variable
#     sub-expressions:
# 64. n
#     core type: Variable
#     sub-expressions:
# 65. U
#     core type: Variable
#     sub-expressions:
# 66. y
#     core type: Variable
#     sub-expressions:
# 67. Exp
#     core type: Literal
#     sub-expressions:
# 68. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 69, 70
# 69. Complex
#     core type: Literal
#     sub-expressions:
# 70. 2
#     core type: Literal
#     sub-expressions:
