# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, alpha, n, x
from proveit.linear_algebra import ScalarProd
from proveit.logic import InSet, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket0
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket0)
expr = Lambda(alpha, Conditional(Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(x)])), InSet(alpha, Complex)))
# Out:
# expr: alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \alpha \mapsto \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 0 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 0 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{x} \qw
# } \hspace{2em} \textrm{ if } \alpha \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#    core type: Lambda
#    parameter: 39
#    body: 1
# 1. { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2.  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. alpha in Complex
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. ((Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
# ...
