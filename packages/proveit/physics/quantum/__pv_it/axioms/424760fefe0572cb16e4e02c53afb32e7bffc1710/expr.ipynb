# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, x, y
from proveit.linear_algebra import MatrixProd
from proveit.logic import And, Equals, Iff, InSet
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Lambda([x, y], Conditional(Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), And(InSet(x, QubitSpace), InSet(y, QubitSpace))))
# Out:
# expr: (x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right) \textrm{ if } x \in \mathbb{C}^{2} ,  y \in \mathbb{C}^{2}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y)
#    core type: ExprTuple
#    sub-expressions: 39, 41
# 2. { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3.  Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in Complex^{2}) and (y in Complex^{2})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. ( Input(x)  & Gate(U)  & Output(y), y = (U . x))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# 8. (x in Complex^{2}, y in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9.  Input(x)  & Gate(U)  & Output(y)
#    core type: Operation
#    operator: 13
#    operand: 20
# 10. y = (U . x)
#     core type: Operation
#     operator: 15
#     operands: 16
# 11. x in Complex^{2}
#     core type: Operation
#     operator: 18
#     operands: 17
# 12. y in Complex^{2}
#     core type: Operation
#     operator: 18
#     operands: 19
# 13. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 14. ((Input(x) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 20
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 41, 21
# 17. (x, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 39, 22
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (y, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 41, 22
# 20. Input(x) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 23
# 21. U . x
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. Complex^{2}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. (Input(x), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30
# 24. .
#     core type: Literal
#     sub-expressions:
# 25. (U, x)
#     core type: ExprTuple
#     sub-expressions: 40, 39
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. Input(x)
#     core type: Operation
#     operator: 33
#     operand: 39
# 29. Gate(U)
#     core type: Operation
#     operator: 35
#     operand: 40
# 30. Output(y)
#     core type: Operation
#     operator: 37
#     operand: 41
# 31. Complex
#     core type: Literal
#     sub-expressions:
# 32. 2
#     core type: Literal
#     sub-expressions:
# 33. INPUT
#     core type: Literal
#     sub-expressions:
# 34. (x)
#     core type: ExprTuple
#     sub-expressions: 39
# 35. GATE
#     core type: Literal
#     sub-expressions:
# 36. (U)
#     core type: ExprTuple
#     sub-expressions: 40
# 37. OUTPUT
#     core type: Literal
#     sub-expressions:
# 38. (y)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. x
#     core type: Variable
#     sub-expressions:
# 40. U
#     core type: Variable
#     sub-expressions:
# 41. y
#     core type: Variable
#     sub-expressions:
