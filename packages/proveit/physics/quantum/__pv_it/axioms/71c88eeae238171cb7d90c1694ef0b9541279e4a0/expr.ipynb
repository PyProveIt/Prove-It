# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Conditional(Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), domain = Complex), InSet(x, TensorExp([QubitSpace], n)))
# Out:
# expr: {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em} \textrm{ if } x \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. x in (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 16
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x, (Complex^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 58, 7
# 6. alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Lambda
#    parameter: 54
#    body: 8
# 7. (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Conditional
#    value: 11
#    condition: 12
# 9. otimes
#    core type: Literal
#    sub-expressions:
# 10. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 13, 45
# 11.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 14
#     operand: 19
# 12. alpha in Complex
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 18
# 14. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 15. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#     core type: ExprTuple
#     sub-expressions: 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 54, 24
# 18. Complex^{2}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 56
# 22. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#     core type: ExprTuple
#     sub-expressions: 25, 26, 27, 28
# 23. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 29, 30, 31, 32
# 24. Complex
#     core type: Literal
#     sub-expressions:
# 25. Input(alpha * |1〉)
#     core type: Operation
#     operator: 35
#     operand: 44
# 26. --
#     core type: Literal
#     sub-expressions:
# 27. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 39
#     operands: 33
# 28. Output(alpha * |1〉)
#     core type: Operation
#     operator: 41
#     operand: 44
# 29. Input(x)
#     core type: Operation
#     operator: 35
#     operand: 58
# 30. MultiWire(n)
#     core type: Operation
#     operator: 37
#     operand: 45
# 31. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 39
#     operands: 40
# 32. Output(U . x)
#     core type: Operation
#     operator: 41
#     operand: 47
# 33. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 43, 46
# 34. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 44
# 35. INPUT
#     core type: Literal
#     sub-expressions:
# 36. (x)
#     core type: ExprTuple
#     sub-expressions: 58
# 37. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 38. (n)
#     core type: ExprTuple
#     sub-expressions: 45
# 39. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 40. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 57, 46
# 41. OUTPUT
#     core type: Literal
#     sub-expressions:
# 42. (U . x)
#     core type: ExprTuple
#     sub-expressions: 47
# 43. CONTROL
#     core type: Literal
#     sub-expressions:
# 44. alpha * |1〉
#     core type: Operation
#     operator: 48
#     operands: 49
# 45. n
#     core type: Variable
#     sub-expressions:
# 46. {1, 2}
#     core type: Operation
#     operator: 50
#     operands: 51
# 47. U . x
#     core type: Operation
#     operator: 52
#     operands: 53
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 50. Set
#     core type: Literal
#     sub-expressions:
# 51. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 61, 56
# 52. .
#     core type: Literal
#     sub-expressions:
# 53. (U, x)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 54. alpha
#     core type: Variable
#     sub-expressions:
# 55. |1〉
#     core type: Operation
#     operator: 59
#     operand: 61
# 56. 2
#     core type: Literal
#     sub-expressions:
# 57. U
#     core type: Variable
#     sub-expressions:
# 58. x
#     core type: Variable
#     sub-expressions:
# 59. KET
#     core type: Literal
#     sub-expressions:
# 60. (1)
#     core type: ExprTuple
#     sub-expressions: 61
# 61. 1
#     core type: Literal
#     sub-expressions:
