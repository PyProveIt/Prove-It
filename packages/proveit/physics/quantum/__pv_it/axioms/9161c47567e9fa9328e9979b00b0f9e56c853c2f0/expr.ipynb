# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), domain = Complex)
# Out:
# expr: forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Lambda
#    parameter: 44
#    body: 4
# 4. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. alpha in Complex
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 8. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 44, 12
# 11. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 14. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21, 22
# 15. Input(alpha * |1〉)
#     core type: Operation
#     operator: 25
#     operand: 34
# 16. --
#     core type: Literal
#     sub-expressions:
# 17. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 29
#     operands: 23
# 18. Output(alpha * |1〉)
#     core type: Operation
#     operator: 31
#     operand: 34
# 19. Input(x)
#     core type: Operation
#     operator: 25
#     operand: 48
# 20. MultiWire(n)
#     core type: Operation
#     operator: 27
#     operand: 35
# 21. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 29
#     operands: 30
# 22. Output(U . x)
#     core type: Operation
#     operator: 31
#     operand: 37
# 23. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 33, 36
# 24. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 34
# 25. INPUT
#     core type: Literal
#     sub-expressions:
# 26. (x)
#     core type: ExprTuple
#     sub-expressions: 48
# 27. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 28. (n)
#     core type: ExprTuple
#     sub-expressions: 35
# 29. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 30. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 47, 36
# 31. OUTPUT
#     core type: Literal
#     sub-expressions:
# 32. (U . x)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. CONTROL
#     core type: Literal
#     sub-expressions:
# 34. alpha * |1〉
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. n
#     core type: Variable
#     sub-expressions:
# 36. {1, 2}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. U . x
#     core type: Operation
#     operator: 42
#     operands: 43
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 40. Set
#     core type: Literal
#     sub-expressions:
# 41. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 51, 46
# 42. .
#     core type: Literal
#     sub-expressions:
# 43. (U, x)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 44. alpha
#     core type: Variable
#     sub-expressions:
# 45. |1〉
#     core type: Operation
#     operator: 49
#     operand: 51
# 46. 2
#     core type: Literal
#     sub-expressions:
# 47. U
#     core type: Variable
#     sub-expressions:
# 48. x
#     core type: Variable
#     sub-expressions:
# 49. KET
#     core type: Literal
#     sub-expressions:
# 50. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 51. 1
#     core type: Literal
#     sub-expressions:
