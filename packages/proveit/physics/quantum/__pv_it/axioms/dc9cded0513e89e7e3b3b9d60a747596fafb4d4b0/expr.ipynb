# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linear_algebra import ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket0
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket0)
expr = Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(x)])), domain = Complex)
# Out:
# expr: forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 0 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 0 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{x} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#    core type: Lambda
#    parameter: 42
#    body: 4
# 4. { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5.  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. alpha in Complex
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 8. ((Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 42, 12
# 11. Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. Complex
#     core type: Literal
#     sub-expressions:
# 13. (Input(alpha * |0〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |0〉))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 14. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(x))
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21, 22
# 15. Input(alpha * |0〉)
#     core type: Operation
#     operator: 25
#     operand: 33
# 16. --
#     core type: Literal
#     sub-expressions:
# 17. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 28
#     operands: 23
# 18. Output(alpha * |0〉)
#     core type: Operation
#     operator: 30
#     operand: 33
# 19. Input(x)
#     core type: Operation
#     operator: 25
#     operand: 37
# 20. MultiWire(n)
#     core type: Operation
#     operator: 26
#     operand: 34
# 21. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 28
#     operands: 29
# 22. Output(x)
#     core type: Operation
#     operator: 30
#     operand: 37
# 23. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 32, 36
# 24. (alpha * |0〉)
#     core type: ExprTuple
#     sub-expressions: 33
# 25. INPUT
#     core type: Literal
#     sub-expressions:
# 26. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 27. (n)
#     core type: ExprTuple
#     sub-expressions: 34
# 28. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 29. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 30. OUTPUT
#     core type: Literal
#     sub-expressions:
# 31. (x)
#     core type: ExprTuple
#     sub-expressions: 37
# 32. CONTROL
#     core type: Literal
#     sub-expressions:
# 33. alpha * |0〉
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. n
#     core type: Variable
#     sub-expressions:
# 35. U
#     core type: Variable
#     sub-expressions:
# 36. {1, 2}
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. x
#     core type: Variable
#     sub-expressions:
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (alpha, |0〉)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 40. Set
#     core type: Literal
#     sub-expressions:
# 41. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 42. alpha
#     core type: Variable
#     sub-expressions:
# 43. |0〉
#     core type: Operation
#     operator: 46
#     operand: 48
# 44. 1
#     core type: Literal
#     sub-expressions:
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (0)
#     core type: ExprTuple
#     sub-expressions: 48
# 48. 0
#     core type: Literal
#     sub-expressions:
