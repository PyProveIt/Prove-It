# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, U, n, x, y
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import MultiWire

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)]))
# Out:
# expr: ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccc}
#  \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (Input(x), MultiWire(n), Gate(U), Output(y))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 3. Input(x)
#    core type: Operation
#    operator: 7
#    operand: 15
# 4. MultiWire(n)
#    core type: Operation
#    operator: 9
#    operand: 16
# 5. Gate(U)
#    core type: Operation
#    operator: 11
#    operand: 17
# 6. Output(y)
#    core type: Operation
#    operator: 13
#    operand: 18
# 7. INPUT
#    core type: Literal
#    sub-expressions:
# 8. (x)
#    core type: ExprTuple
#    sub-expressions: 15
# 9. MULTI_WIRE
#    core type: Literal
#    sub-expressions:
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 16
# 11. GATE
#     core type: Literal
#     sub-expressions:
# 12. (U)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. OUTPUT
# ...
