# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, n, x, y
from proveit.linalg import TensorExp
from proveit.linear_algebra import MatrixProd
from proveit.logic import And, Equals, Iff, InSet
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = TensorExp([QubitSpace], n)
expr = Lambda([x, y], Conditional(Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), And(InSet(x, sub_expr1), InSet(y, sub_expr1))))
# Out:
# expr: (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x, y\right) \mapsto \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right) \textrm{ if } x \in \left(\mathbb{C}^{2}\right)^{\otimes n} ,  y \in \left(\mathbb{C}^{2}\right)^{\otimes n}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (x, y)
#    core type: ExprTuple
#    sub-expressions: 42, 45
# 2. { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. <=>
#    core type: Literal
#    sub-expressions:
# 6. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. and
#    core type: Literal
#    sub-expressions:
# ...
