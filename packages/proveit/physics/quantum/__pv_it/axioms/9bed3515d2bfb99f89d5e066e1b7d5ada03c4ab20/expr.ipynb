# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, U, x, y
from proveit.linear_algebra import MatrixProd, SU
from proveit.logic import Equals, Forall, Iff, InSet
from proveit.numbers import two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(U, Conditional(Forall([x, y], Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = QubitSpace), InSet(U, SU(two)))))
# Out:
# expr: (U -> {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(U \mapsto \left\{\forall_{x, y \in \mathbb{C}^{2}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right) \textrm{ if } U \in SU(2)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (U -> {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. U -> {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).
#    core type: Lambda
#    parameter: 51
#    body: 2
# 2. {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. U in SU(2)
#    core type: Operation
#    operator: 29
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (U, SU(2))
#    core type: ExprTuple
# ...
