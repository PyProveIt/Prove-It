# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, alpha
from proveit.linear_algebra import ScalarProd
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = ScalarProd(alpha, ket1)
expr = ExprTuple(Input(sub_expr1), I, MultiQubitGate(CONTROL, Set(one, two)), Output(sub_expr1))
# Out:
# expr: (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. Input(alpha * |1〉)
#    core type: Operation
#    operator: 5
#    operand: 12
# 2. --
#    core type: Literal
#    sub-expressions:
# 3. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. Output(alpha * |1〉)
#    core type: Operation
#    operator: 8
#    operand: 12
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 7. (CONTROL, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. OUTPUT
#    core type: Literal
#    sub-expressions:
# 9. (alpha * |1〉)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. CONTROL
#     core type: Literal
#     sub-expressions:
# 11. {1, 2}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. alpha * |1〉
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 22, 17
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. alpha
#     core type: Variable
#     sub-expressions:
# 19. |1〉
#     core type: Operation
#     operator: 20
#     operand: 22
# 20. KET
#     core type: Literal
#     sub-expressions:
# 21. (1)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. 1
#     core type: Literal
#     sub-expressions:
