# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#one_controlled_ngate">one_controlled_ngate</a> of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum import one_controlled_ngate

# %%
# check that the built expression is the same as the stored expression
assert one_controlled_ngate.expr == stored_expr
assert one_controlled_ngate.expr._style_id == stored_expr._style_id
print("Passed sanity check: one_controlled_ngate matches stored_expr")
# Out:
# Passed sanity check: one_controlled_ngate matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(one_controlled_ngate.latex())
# Out:
# \vdash \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em}\right]\right]\right]

# %%
one_controlled_ngate.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
one_controlled_ngate.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (n -> {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]] if n in NaturalPos.
# ...
