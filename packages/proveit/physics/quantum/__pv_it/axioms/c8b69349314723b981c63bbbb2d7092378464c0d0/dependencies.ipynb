# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#zero_controlled_ngate">zero_controlled_ngate</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum import zero_controlled_ngate

# %%
# %dependencies zero_controlled_ngate
# Out:
# <h3>No theorems/conjectures depend upon zero_controlled_ngate</h3>
