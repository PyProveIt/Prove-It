# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import MatrixProd, SU, ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Forall([U], Forall([x], Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), domain = Complex), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n)))
# Out:
# expr: forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in SU(2^{n})}~\left[\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em}\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]]
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. (U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 71
#    body: 3
# 3. {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]
#    core type: Operation
#    operator: 16
#    operand: 8
# 5. U in SU(2^{n})
#    core type: Operation
#    operator: 30
#    operands: 7
# 6. (x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 71, 9
# 8. x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameter: 72
#    body: 10
# 9. SU(2^{n})
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. SU
#     core type: Literal
#     sub-expressions:
# 12. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 16
#     operand: 20
# 14. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 30
#     operands: 18
# 15. 2^{n}
#     core type: Operation
#     operator: 34
#     operands: 19
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 72, 21
# 19. (2, n)
#     core type: ExprTuple
#     sub-expressions: 70, 59
# 20. alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#     core type: Lambda
#     parameter: 68
#     body: 22
# 21. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 27, 59
# 25.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 28
#     operand: 33
# 26. alpha in Complex
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 29. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#     core type: ExprTuple
#     sub-expressions: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 68, 38
# 32. Complex^{2}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 38, 70
# 36. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 37. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45, 46
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. Input(alpha * |1〉)
#     core type: Operation
#     operator: 49
#     operand: 58
# 40. --
#     core type: Literal
#     sub-expressions:
# 41. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 53
#     operands: 47
# 42. Output(alpha * |1〉)
#     core type: Operation
#     operator: 55
#     operand: 58
# 43. Input(x)
#     core type: Operation
#     operator: 49
#     operand: 72
# 44. MultiWire(n)
#     core type: Operation
#     operator: 51
#     operand: 59
# 45. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 53
#     operands: 54
# 46. Output(U . x)
#     core type: Operation
#     operator: 55
#     operand: 61
# 47. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 57, 60
# 48. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 58
# 49. INPUT
#     core type: Literal
#     sub-expressions:
# 50. (x)
#     core type: ExprTuple
#     sub-expressions: 72
# 51. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 52. (n)
#     core type: ExprTuple
#     sub-expressions: 59
# 53. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 54. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 71, 60
# 55. OUTPUT
#     core type: Literal
#     sub-expressions:
# 56. (U . x)
#     core type: ExprTuple
#     sub-expressions: 61
# 57. CONTROL
#     core type: Literal
#     sub-expressions:
# 58. alpha * |1〉
#     core type: Operation
#     operator: 62
#     operands: 63
# 59. n
#     core type: Variable
#     sub-expressions:
# 60. {1, 2}
#     core type: Operation
#     operator: 64
#     operands: 65
# 61. U . x
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 64. Set
#     core type: Literal
#     sub-expressions:
# 65. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 75, 70
# 66. .
#     core type: Literal
#     sub-expressions:
# 67. (U, x)
#     core type: ExprTuple
#     sub-expressions: 71, 72
# 68. alpha
#     core type: Variable
#     sub-expressions:
# 69. |1〉
#     core type: Operation
#     operator: 73
#     operand: 75
# 70. 2
#     core type: Literal
#     sub-expressions:
# 71. U
#     core type: Variable
#     sub-expressions:
# 72. x
#     core type: Variable
#     sub-expressions:
# 73. KET
#     core type: Literal
#     sub-expressions:
# 74. (1)
#     core type: ExprTuple
#     sub-expressions: 75
# 75. 1
#     core type: Literal
#     sub-expressions:
