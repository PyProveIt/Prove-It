# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, x, y
from proveit.linear_algebra import MatrixProd
from proveit.logic import And, Equals, Iff, InSet
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Conditional(Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), And(InSet(x, QubitSpace), InSet(y, QubitSpace)))
# Out:
# expr: { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right) \textrm{ if } x \in \mathbb{C}^{2} ,  y \in \mathbb{C}^{2}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1.  Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (x in Complex^{2}) and (y in Complex^{2})
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. ( Input(x)  & Gate(U)  & Output(y), y = (U . x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (x in Complex^{2}, y in Complex^{2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7.  Input(x)  & Gate(U)  & Output(y)
#    core type: Operation
#    operator: 11
#    operand: 18
# 8. y = (U . x)
#    core type: Operation
#    operator: 13
#    operands: 14
# 9. x in Complex^{2}
#    core type: Operation
#    operator: 16
#    operands: 15
# 10. y in Complex^{2}
#     core type: Operation
#     operator: 16
#     operands: 17
# 11. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 12. ((Input(x) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 18
# 13. =
#     core type: Literal
#     sub-expressions:
# 14. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 39, 19
# 15. (x, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 37, 20
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (y, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 39, 20
# 18. Input(x) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. U . x
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. Complex^{2}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (Input(x), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 22. .
#     core type: Literal
#     sub-expressions:
# 23. (U, x)
#     core type: ExprTuple
#     sub-expressions: 38, 37
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. Input(x)
#     core type: Operation
#     operator: 31
#     operand: 37
# 27. Gate(U)
#     core type: Operation
#     operator: 33
#     operand: 38
# 28. Output(y)
#     core type: Operation
#     operator: 35
#     operand: 39
# 29. Complex
#     core type: Literal
#     sub-expressions:
# 30. 2
#     core type: Literal
#     sub-expressions:
# 31. INPUT
#     core type: Literal
#     sub-expressions:
# 32. (x)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. GATE
#     core type: Literal
#     sub-expressions:
# 34. (U)
#     core type: ExprTuple
#     sub-expressions: 38
# 35. OUTPUT
#     core type: Literal
#     sub-expressions:
# 36. (y)
#     core type: ExprTuple
#     sub-expressions: 39
# 37. x
#     core type: Variable
#     sub-expressions:
# 38. U
#     core type: Variable
#     sub-expressions:
# 39. y
#     core type: Variable
#     sub-expressions:
