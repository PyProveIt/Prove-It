# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, Lambda, U, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Forall, Iff, InSet
from proveit.numbers import Exp, NaturalPos, two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = Lambda(n, Conditional(Forall([U], Forall([x, y], Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n))), InSet(n, NaturalPos)))
# Out:
# expr: n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# n \mapsto \left\{\forall_{U \in SU(2^{n})}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 62
#    body: 1
# 1. {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))]
#    core type: Operation
#    operator: 11
#    operand: 6
# 3. n in NaturalPos
#    core type: Operation
#    operator: 37
#    operands: 5
# 4. (U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 62, 7
# 6. U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 63
#    body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. U in SU(2^{n})
#     core type: Operation
#     operator: 37
#     operands: 13
# 11. forall
#     core type: Literal
#     sub-expressions:
# 12. ((x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 63, 15
# 14. (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 16\n    body: 17
# 15. SU(2^{n})
#     core type: Operation
#     operator: 18
#     operand: 22
# 16. (x, y)
#     core type: ExprTuple
#     sub-expressions: 61, 64
# 17. { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. SU
#     core type: Literal
#     sub-expressions:
# 19. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 20.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 23
#     operands: 24
# 21. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 25
#     operands: 26
# 22. 2^{n}
#     core type: Operation
#     operator: 65
#     operands: 27
# 23. <=>
#     core type: Literal
#     sub-expressions:
# 24. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. and
#     core type: Literal
#     sub-expressions:
# 26. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 27. (2, n)
#     core type: ExprTuple
#     sub-expressions: 68, 62
# 28.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 32
#     operand: 39
# 29. y = (U . x)
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 37
#     operands: 36
# 31. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 33. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 39
# 34. =
#     core type: Literal
#     sub-expressions:
# 35. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 64, 40
# 36. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 61, 41
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 64, 41
# 39. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. U . x
#     core type: Operation
#     operator: 43
#     operands: 44
# 41. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 45
#     operands: 46
# 42. (Input(x), MultiWire(n), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 47, 48, 49, 50
# 43. .
#     core type: Literal
#     sub-expressions:
# 44. (U, x)
#     core type: ExprTuple
#     sub-expressions: 63, 61
# 45. otimes
#     core type: Literal
#     sub-expressions:
# 46. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 51, 62
# 47. Input(x)
#     core type: Operation
#     operator: 52
#     operand: 61
# 48. MultiWire(n)
#     core type: Operation
#     operator: 54
#     operand: 62
# 49. Gate(U)
#     core type: Operation
#     operator: 56
#     operand: 63
# 50. Output(y)
#     core type: Operation
#     operator: 58
#     operand: 64
# 51. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 60
# 52. INPUT
#     core type: Literal
#     sub-expressions:
# 53. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 54. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 55. (n)
#     core type: ExprTuple
#     sub-expressions: 62
# 56. GATE
#     core type: Literal
#     sub-expressions:
# 57. (U)
#     core type: ExprTuple
#     sub-expressions: 63
# 58. OUTPUT
#     core type: Literal
#     sub-expressions:
# 59. (y)
#     core type: ExprTuple
#     sub-expressions: 64
# 60. Complex^{2}
#     core type: Operation
#     operator: 65
#     operands: 66
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. n
#     core type: Variable
#     sub-expressions:
# 63. U
#     core type: Variable
#     sub-expressions:
# 64. y
#     core type: Variable
#     sub-expressions:
# 65. Exp
#     core type: Literal
#     sub-expressions:
# 66. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 67, 68
# 67. Complex
#     core type: Literal
#     sub-expressions:
# 68. 2
#     core type: Literal
#     sub-expressions:
