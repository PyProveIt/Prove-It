# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, x, y
from proveit.linear_algebra import MatrixProd, SU
from proveit.logic import Equals, Forall, Iff, InSet
from proveit.numbers import two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, y], Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = QubitSpace), InSet(U, SU(two)))
# Out:
# expr: {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y \in \mathbb{C}^{2}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right) \textrm{ if } U \in SU(2)\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. U in SU(2)
#    core type: Operation
#    operator: 27
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (U, SU(2))
#    core type: ExprTuple
#    sub-expressions: 49, 7
# 6. (x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. SU(2)
#    core type: Operation
#    operator: 10
#    operand: 41
# 8. (x, y)
#    core type: ExprTuple
#    sub-expressions: 48, 50
# 9. { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. SU
#     core type: Literal
#     sub-expressions:
# 11. (2)
#     core type: ExprTuple
#     sub-expressions: 41
# 12.  Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (x in Complex^{2}) and (y in Complex^{2})
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. <=>
#     core type: Literal
#     sub-expressions:
# 15. ( Input(x)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. and
#     core type: Literal
#     sub-expressions:
# 17. (x in Complex^{2}, y in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18.  Input(x)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 22
#     operand: 29
# 19. y = (U . x)
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. x in Complex^{2}
#     core type: Operation
#     operator: 27
#     operands: 26
# 21. y in Complex^{2}
#     core type: Operation
#     operator: 27
#     operands: 28
# 22. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 23. ((Input(x) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 29
# 24. =
#     core type: Literal
#     sub-expressions:
# 25. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 50, 30
# 26. (x, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 48, 31
# 27. in
#     core type: Literal
#     sub-expressions:
# 28. (y, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 50, 31
# 29. Input(x) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. U . x
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. Complex^{2}
#     core type: Operation
#     operator: 35
#     operands: 36
# 32. (Input(x), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 37, 38, 39
# 33. .
#     core type: Literal
#     sub-expressions:
# 34. (U, x)
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 35. Exp
#     core type: Literal
#     sub-expressions:
# 36. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 37. Input(x)
#     core type: Operation
#     operator: 42
#     operand: 48
# 38. Gate(U)
#     core type: Operation
#     operator: 44
#     operand: 49
# 39. Output(y)
#     core type: Operation
#     operator: 46
#     operand: 50
# 40. Complex
#     core type: Literal
#     sub-expressions:
# 41. 2
#     core type: Literal
#     sub-expressions:
# 42. INPUT
#     core type: Literal
#     sub-expressions:
# 43. (x)
#     core type: ExprTuple
#     sub-expressions: 48
# 44. GATE
#     core type: Literal
#     sub-expressions:
# 45. (U)
#     core type: ExprTuple
#     sub-expressions: 49
# 46. OUTPUT
#     core type: Literal
#     sub-expressions:
# 47. (y)
#     core type: ExprTuple
#     sub-expressions: 50
# 48. x
#     core type: Variable
#     sub-expressions:
# 49. U
#     core type: Variable
#     sub-expressions:
# 50. y
#     core type: Variable
#     sub-expressions:
