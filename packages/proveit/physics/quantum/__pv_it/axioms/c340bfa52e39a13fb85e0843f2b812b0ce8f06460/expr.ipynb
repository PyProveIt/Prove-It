# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import SU, ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, Exp, NaturalPos, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket0
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket0)
expr = Forall([n], Forall([U], Forall([x], Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(x)])), domain = Complex), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n))), domain = NaturalPos)
# Out:
# expr: forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n \in \mathbb{N}^+}~\left[\forall_{U \in SU(2^{n})}~\left[\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 0 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 0 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{x} \qw
# } \hspace{2em}\right]\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]]]
#    core type: Operation
#    operator: 23
#    operand: 2
# 1. (n -> {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. n -> {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]] if n in NaturalPos.
#    core type: Lambda
#    parameter: 65
#    body: 3
# 3. {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]] if n in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]]
#    core type: Operation
#    operator: 23
#    operand: 8
# 5. n in NaturalPos
#    core type: Operation
#    operator: 37
#    operands: 7
# 6. (U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 65, 9
# 8. U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 66
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]
#     core type: Operation
#     operator: 23
#     operand: 15
# 12. U in SU(2^{n})
#     core type: Operation
#     operator: 37
#     operands: 14
# 13. (x -> {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 66, 16
# 15. x -> {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameter: 68
#     body: 17
# 16. SU(2^{n})
#     core type: Operation
#     operator: 18
#     operand: 22
# 17. {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 20
#     condition: 21
# 18. SU
#     core type: Literal
#     sub-expressions:
# 19. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 22
# 20. forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#     core type: Operation
#     operator: 23
#     operand: 27
# 21. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 37
#     operands: 25
# 22. 2^{n}
#     core type: Operation
#     operator: 41
#     operands: 26
# 23. forall
#     core type: Literal
#     sub-expressions:
# 24. (alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.)
#     core type: ExprTuple
#     sub-expressions: 27
# 25. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 68, 28
# 26. (2, n)
#     core type: ExprTuple
#     sub-expressions: 76, 65
# 27. alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#     core type: Lambda
#     parameter: 73
#     body: 29
# 28. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#     core type: Conditional
#     value: 32
#     condition: 33
# 30. otimes
#     core type: Literal
#     sub-expressions:
# 31. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 34, 65
# 32.  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#     core type: Operation
#     operator: 35
#     operand: 40
# 33. alpha in Complex
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 39
# 35. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 36. ((Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)))
#     core type: ExprTuple
#     sub-expressions: 40
# 37. in
#     core type: Literal
#     sub-expressions:
# 38. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 73, 45
# 39. Complex^{2}
#     core type: Operation
#     operator: 41
#     operands: 42
# 40. Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 45, 76
# 43. (Input(alpha * |0〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |0〉))
#     core type: ExprTuple
#     sub-expressions: 46, 47, 48, 49
# 44. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(x))
#     core type: ExprTuple
#     sub-expressions: 50, 51, 52, 53
# 45. Complex
#     core type: Literal
#     sub-expressions:
# 46. Input(alpha * |0〉)
#     core type: Operation
#     operator: 56
#     operand: 64
# 47. --
#     core type: Literal
#     sub-expressions:
# 48. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 59
#     operands: 54
# 49. Output(alpha * |0〉)
#     core type: Operation
#     operator: 61
#     operand: 64
# 50. Input(x)
#     core type: Operation
#     operator: 56
#     operand: 68
# 51. MultiWire(n)
#     core type: Operation
#     operator: 57
#     operand: 65
# 52. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 59
#     operands: 60
# 53. Output(x)
#     core type: Operation
#     operator: 61
#     operand: 68
# 54. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 63, 67
# 55. (alpha * |0〉)
#     core type: ExprTuple
#     sub-expressions: 64
# 56. INPUT
#     core type: Literal
#     sub-expressions:
# 57. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 58. (n)
#     core type: ExprTuple
#     sub-expressions: 65
# 59. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 60. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 61. OUTPUT
#     core type: Literal
#     sub-expressions:
# 62. (x)
#     core type: ExprTuple
#     sub-expressions: 68
# 63. CONTROL
#     core type: Literal
#     sub-expressions:
# 64. alpha * |0〉
#     core type: Operation
#     operator: 69
#     operands: 70
# 65. n
#     core type: Variable
#     sub-expressions:
# 66. U
#     core type: Variable
#     sub-expressions:
# 67. {1, 2}
#     core type: Operation
#     operator: 71
#     operands: 72
# 68. x
#     core type: Variable
#     sub-expressions:
# 69. *
#     core type: Literal
#     sub-expressions:
# 70. (alpha, |0〉)
#     core type: ExprTuple
#     sub-expressions: 73, 74
# 71. Set
#     core type: Literal
#     sub-expressions:
# 72. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 73. alpha
#     core type: Variable
#     sub-expressions:
# 74. |0〉
#     core type: Operation
#     operator: 77
#     operand: 79
# 75. 1
#     core type: Literal
#     sub-expressions:
# 76. 2
#     core type: Literal
#     sub-expressions:
# 77. KET
#     core type: Literal
#     sub-expressions:
# 78. (0)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. 0
#     core type: Literal
#     sub-expressions:
