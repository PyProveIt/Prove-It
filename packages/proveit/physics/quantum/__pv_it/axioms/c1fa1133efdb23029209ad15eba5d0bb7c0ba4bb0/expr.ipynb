# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, x, y
from proveit.linear_algebra import MatrixProd, SU
from proveit.logic import Equals, Forall, Iff
from proveit.numbers import two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Forall([U], Forall([x, y], Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = QubitSpace), domain = SU(two))
# Out:
# expr: forall_{U in SU(2)} [forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in SU(2)}~\left[\forall_{x, y \in \mathbb{C}^{2}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{U in SU(2)} [forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (U -> {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. U -> {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).
#    core type: Lambda
#    parameter: 52
#    body: 3
# 3. {forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. U in SU(2)
#    core type: Operation
#    operator: 30
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. ((x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (U, SU(2))
#    core type: ExprTuple
#    sub-expressions: 52, 10
# 9. (x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Lambda
#    parameters: 11\n   body: 12
# 10. SU(2)
#     core type: Operation
#     operator: 13
#     operand: 44
# 11. (x, y)
#     core type: ExprTuple
#     sub-expressions: 51, 53
# 12. { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#     core type: Conditional
#     value: 15
#     condition: 16
# 13. SU
#     core type: Literal
#     sub-expressions:
# 14. (2)
#     core type: ExprTuple
#     sub-expressions: 44
# 15.  Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (x in Complex^{2}) and (y in Complex^{2})
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. <=>
#     core type: Literal
#     sub-expressions:
# 18. ( Input(x)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. and
#     core type: Literal
#     sub-expressions:
# 20. (x in Complex^{2}, y in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21.  Input(x)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 25
#     operand: 32
# 22. y = (U . x)
#     core type: Operation
#     operator: 27
#     operands: 28
# 23. x in Complex^{2}
#     core type: Operation
#     operator: 30
#     operands: 29
# 24. y in Complex^{2}
#     core type: Operation
#     operator: 30
#     operands: 31
# 25. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 26. ((Input(x) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 32
# 27. =
#     core type: Literal
#     sub-expressions:
# 28. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 53, 33
# 29. (x, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 51, 34
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (y, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 53, 34
# 32. Input(x) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 35
# 33. U . x
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. Complex^{2}
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. (Input(x), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 40, 41, 42
# 36. .
#     core type: Literal
#     sub-expressions:
# 37. (U, x)
#     core type: ExprTuple
#     sub-expressions: 52, 51
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. Input(x)
#     core type: Operation
#     operator: 45
#     operand: 51
# 41. Gate(U)
#     core type: Operation
#     operator: 47
#     operand: 52
# 42. Output(y)
#     core type: Operation
#     operator: 49
#     operand: 53
# 43. Complex
#     core type: Literal
#     sub-expressions:
# 44. 2
#     core type: Literal
#     sub-expressions:
# 45. INPUT
#     core type: Literal
#     sub-expressions:
# 46. (x)
#     core type: ExprTuple
#     sub-expressions: 51
# 47. GATE
#     core type: Literal
#     sub-expressions:
# 48. (U)
#     core type: ExprTuple
#     sub-expressions: 52
# 49. OUTPUT
#     core type: Literal
#     sub-expressions:
# 50. (y)
#     core type: ExprTuple
#     sub-expressions: 53
# 51. x
#     core type: Variable
#     sub-expressions:
# 52. U
#     core type: Variable
#     sub-expressions:
# 53. y
#     core type: Variable
#     sub-expressions:
