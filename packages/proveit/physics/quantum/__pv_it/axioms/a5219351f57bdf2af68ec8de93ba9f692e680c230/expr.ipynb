# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, x, y
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Forall, Iff
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Forall([x, y], Iff(Circuit(ExprArray([Input(x), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = QubitSpace)
# Out:
# expr: forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x, y \in \mathbb{C}^{2}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x, y in Complex^{2}} ( Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (x, y) -> { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (x, y)
#    core type: ExprTuple
#    sub-expressions: 42, 44
# 5. { Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in Complex^{2} ,  y in Complex^{2}.
#    core type: Conditional
#    value: 6
#    condition: 7
# 6.  Input(x)  & Gate(U)  & Output(y) <=> (y = (U . x))
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (x in Complex^{2}) and (y in Complex^{2})
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. <=>
#    core type: Literal
#    sub-expressions:
# 9. ( Input(x)  & Gate(U)  & Output(y), y = (U . x))
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. and
#     core type: Literal
#     sub-expressions:
# 11. (x in Complex^{2}, y in Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12.  Input(x)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 16
#     operand: 23
# 13. y = (U . x)
#     core type: Operation
#     operator: 18
#     operands: 19
# 14. x in Complex^{2}
#     core type: Operation
#     operator: 21
#     operands: 20
# 15. y in Complex^{2}
#     core type: Operation
#     operator: 21
#     operands: 22
# 16. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 17. ((Input(x) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 23
# 18. =
#     core type: Literal
#     sub-expressions:
# 19. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 44, 24
# 20. (x, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 42, 25
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (y, Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 44, 25
# 23. Input(x) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. U . x
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. Complex^{2}
#     core type: Operation
#     operator: 29
#     operands: 30
# 26. (Input(x), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 31, 32, 33
# 27. .
#     core type: Literal
#     sub-expressions:
# 28. (U, x)
#     core type: ExprTuple
#     sub-expressions: 43, 42
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 31. Input(x)
#     core type: Operation
#     operator: 36
#     operand: 42
# 32. Gate(U)
#     core type: Operation
#     operator: 38
#     operand: 43
# 33. Output(y)
#     core type: Operation
#     operator: 40
#     operand: 44
# 34. Complex
#     core type: Literal
#     sub-expressions:
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. INPUT
#     core type: Literal
#     sub-expressions:
# 37. (x)
#     core type: ExprTuple
#     sub-expressions: 42
# 38. GATE
#     core type: Literal
#     sub-expressions:
# 39. (U)
#     core type: ExprTuple
#     sub-expressions: 43
# 40. OUTPUT
#     core type: Literal
#     sub-expressions:
# 41. (y)
#     core type: ExprTuple
#     sub-expressions: 44
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. U
#     core type: Variable
#     sub-expressions:
# 44. y
#     core type: Variable
#     sub-expressions:
