# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Forall([x], Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), domain = Complex), domain = TensorExp([QubitSpace], n))
# Out:
# expr: forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em}\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameter: 61
#    body: 3
# 3. {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. x in (Complex^{2})^{otimes n}
#    core type: Operation
#    operator: 19
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (x, (Complex^{2})^{otimes n})
#    core type: ExprTuple
#    sub-expressions: 61, 10
# 9. alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Lambda
#    parameter: 57
#    body: 11
# 10. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. otimes
#     core type: Literal
#     sub-expressions:
# 13. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 16, 48
# 14.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 17
#     operand: 22
# 15. alpha in Complex
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 21
# 17. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 18. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#     core type: ExprTuple
#     sub-expressions: 22
# 19. in
#     core type: Literal
#     sub-expressions:
# 20. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 57, 27
# 21. Complex^{2}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. Exp
#     core type: Literal
#     sub-expressions:
# 24. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 27, 59
# 25. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#     core type: ExprTuple
#     sub-expressions: 28, 29, 30, 31
# 26. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 32, 33, 34, 35
# 27. Complex
#     core type: Literal
#     sub-expressions:
# 28. Input(alpha * |1〉)
#     core type: Operation
#     operator: 38
#     operand: 47
# 29. --
#     core type: Literal
#     sub-expressions:
# 30. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 42
#     operands: 36
# 31. Output(alpha * |1〉)
#     core type: Operation
#     operator: 44
#     operand: 47
# 32. Input(x)
#     core type: Operation
#     operator: 38
#     operand: 61
# 33. MultiWire(n)
#     core type: Operation
#     operator: 40
#     operand: 48
# 34. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 42
#     operands: 43
# 35. Output(U . x)
#     core type: Operation
#     operator: 44
#     operand: 50
# 36. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 46, 49
# 37. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 47
# 38. INPUT
#     core type: Literal
#     sub-expressions:
# 39. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 40. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 41. (n)
#     core type: ExprTuple
#     sub-expressions: 48
# 42. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 43. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 60, 49
# 44. OUTPUT
#     core type: Literal
#     sub-expressions:
# 45. (U . x)
#     core type: ExprTuple
#     sub-expressions: 50
# 46. CONTROL
#     core type: Literal
#     sub-expressions:
# 47. alpha * |1〉
#     core type: Operation
#     operator: 51
#     operands: 52
# 48. n
#     core type: Variable
#     sub-expressions:
# 49. {1, 2}
#     core type: Operation
#     operator: 53
#     operands: 54
# 50. U . x
#     core type: Operation
#     operator: 55
#     operands: 56
# 51. *
#     core type: Literal
#     sub-expressions:
# 52. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 57, 58
# 53. Set
#     core type: Literal
#     sub-expressions:
# 54. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 64, 59
# 55. .
#     core type: Literal
#     sub-expressions:
# 56. (U, x)
#     core type: ExprTuple
#     sub-expressions: 60, 61
# 57. alpha
#     core type: Variable
#     sub-expressions:
# 58. |1〉
#     core type: Operation
#     operator: 62
#     operand: 64
# 59. 2
#     core type: Literal
#     sub-expressions:
# 60. U
#     core type: Variable
#     sub-expressions:
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. KET
#     core type: Literal
#     sub-expressions:
# 63. (1)
#     core type: ExprTuple
#     sub-expressions: 64
# 64. 1
#     core type: Literal
#     sub-expressions:
