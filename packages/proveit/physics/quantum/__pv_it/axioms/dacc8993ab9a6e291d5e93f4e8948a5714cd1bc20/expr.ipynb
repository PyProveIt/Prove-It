# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Forall, Iff, InSet
from proveit.numbers import Exp, two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x, y], Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = TensorExp([QubitSpace], n)), InSet(U, SU(Exp(two, n))))
# Out:
# expr: {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right) \textrm{ if } U \in SU(2^{n})\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. U in SU(2^{n})
#    core type: Operation
#    operator: 29
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 55, 7
# 6. (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameters: 8\n   body: 9
# 7. SU(2^{n})
#    core type: Operation
#    operator: 10
#    operand: 14
# 8. (x, y)
#    core type: ExprTuple
#    sub-expressions: 53, 56
# 9. { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. SU
#     core type: Literal
#     sub-expressions:
# 11. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 14
# 12.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. 2^{n}
#     core type: Operation
#     operator: 57
#     operands: 19
# 15. <=>
#     core type: Literal
#     sub-expressions:
# 16. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 17. and
#     core type: Literal
#     sub-expressions:
# 18. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 19. (2, n)
#     core type: ExprTuple
#     sub-expressions: 60, 54
# 20.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 24
#     operand: 31
# 21. y = (U . x)
#     core type: Operation
#     operator: 26
#     operands: 27
# 22. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 29
#     operands: 28
# 23. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 29
#     operands: 30
# 24. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 25. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 31
# 26. =
#     core type: Literal
#     sub-expressions:
# 27. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 56, 32
# 28. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 53, 33
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 56, 33
# 31. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 34
# 32. U . x
#     core type: Operation
#     operator: 35
#     operands: 36
# 33. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 37
#     operands: 38
# 34. (Input(x), MultiWire(n), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 35. .
#     core type: Literal
#     sub-expressions:
# 36. (U, x)
#     core type: ExprTuple
#     sub-expressions: 55, 53
# 37. otimes
#     core type: Literal
#     sub-expressions:
# 38. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 43, 54
# 39. Input(x)
#     core type: Operation
#     operator: 44
#     operand: 53
# 40. MultiWire(n)
#     core type: Operation
#     operator: 46
#     operand: 54
# 41. Gate(U)
#     core type: Operation
#     operator: 48
#     operand: 55
# 42. Output(y)
#     core type: Operation
#     operator: 50
#     operand: 56
# 43. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 52
# 44. INPUT
#     core type: Literal
#     sub-expressions:
# 45. (x)
#     core type: ExprTuple
#     sub-expressions: 53
# 46. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 47. (n)
#     core type: ExprTuple
#     sub-expressions: 54
# 48. GATE
#     core type: Literal
#     sub-expressions:
# 49. (U)
#     core type: ExprTuple
#     sub-expressions: 55
# 50. OUTPUT
#     core type: Literal
#     sub-expressions:
# 51. (y)
#     core type: ExprTuple
#     sub-expressions: 56
# 52. Complex^{2}
#     core type: Operation
#     operator: 57
#     operands: 58
# 53. x
#     core type: Variable
#     sub-expressions:
# 54. n
#     core type: Variable
#     sub-expressions:
# 55. U
#     core type: Variable
#     sub-expressions:
# 56. y
#     core type: Variable
#     sub-expressions:
# 57. Exp
#     core type: Literal
#     sub-expressions:
# 58. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 59. Complex
#     core type: Literal
#     sub-expressions:
# 60. 2
#     core type: Literal
#     sub-expressions:
