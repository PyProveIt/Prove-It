# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket1
from proveit.physics.quantum.circuit import MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])
# Out:
# expr: Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccc}
#  \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{U \thinspace x} \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 2. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 3. Input(alpha * |1〉)
#    core type: Operation
#    operator: 13
#    operand: 22
# 4. --
#    core type: Literal
#    sub-expressions:
# 5. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 17
#    operands: 11
# 6. Output(alpha * |1〉)
#    core type: Operation
#    operator: 19
#    operand: 22
# 7. Input(x)
#    core type: Operation
#    operator: 13
#    operand: 36
# 8. MultiWire(n)
#    core type: Operation
#    operator: 15
#    operand: 23
# 9. MultiQubitGate(U, {1, 2})
# ...
