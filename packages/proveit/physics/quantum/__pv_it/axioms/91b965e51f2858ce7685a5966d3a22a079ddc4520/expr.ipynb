# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import MatrixProd, SU, ScalarProd
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Complex, Exp, NaturalPos, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Conditional(Forall([U], Forall([x], Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), domain = Complex), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n))), InSet(n, NaturalPos))
# Out:
# expr: {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]] if n in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{U \in SU(2^{n})}~\left[\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em}\right]\right] \textrm{ if } n \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]] if n in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]]
#    core type: Operation
#    operator: 20
#    operand: 5
# 2. n in NaturalPos
#    core type: Operation
#    operator: 34
#    operands: 4
# 3. (U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 63, 6
# 5. U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 75
#    body: 7
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)] if U in SU(2^{n}).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)]
#    core type: Operation
#    operator: 20
#    operand: 12
# 9. U in SU(2^{n})
#    core type: Operation
#    operator: 34
#    operands: 11
# 10. (x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 75, 13
# 12. x -> {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameter: 76
#     body: 14
# 13. SU(2^{n})
#     core type: Operation
#     operator: 15
#     operand: 19
# 14. {forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if x in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. SU
#     core type: Literal
#     sub-expressions:
# 16. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 19
# 17. forall_{alpha in Complex}  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 34
#     operands: 22
# 19. 2^{n}
#     core type: Operation
#     operator: 38
#     operands: 23
# 20. forall
#     core type: Literal
#     sub-expressions:
# 21. (alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 76, 25
# 23. (2, n)
#     core type: ExprTuple
#     sub-expressions: 74, 63
# 24. alpha -> { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#     core type: Lambda
#     parameter: 72
#     body: 26
# 25. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#     core type: Conditional
#     value: 29
#     condition: 30
# 27. otimes
#     core type: Literal
#     sub-expressions:
# 28. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 31, 63
# 29.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#     core type: Operation
#     operator: 32
#     operand: 37
# 30. alpha in Complex
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 36
# 32. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 33. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#     core type: ExprTuple
#     sub-expressions: 37
# 34. in
#     core type: Literal
#     sub-expressions:
# 35. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 72, 42
# 36. Complex^{2}
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 42, 74
# 40. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45, 46
# 41. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 47, 48, 49, 50
# 42. Complex
#     core type: Literal
#     sub-expressions:
# 43. Input(alpha * |1〉)
#     core type: Operation
#     operator: 53
#     operand: 62
# 44. --
#     core type: Literal
#     sub-expressions:
# 45. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 57
#     operands: 51
# 46. Output(alpha * |1〉)
#     core type: Operation
#     operator: 59
#     operand: 62
# 47. Input(x)
#     core type: Operation
#     operator: 53
#     operand: 76
# 48. MultiWire(n)
#     core type: Operation
#     operator: 55
#     operand: 63
# 49. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 57
#     operands: 58
# 50. Output(U . x)
#     core type: Operation
#     operator: 59
#     operand: 65
# 51. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 61, 64
# 52. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 62
# 53. INPUT
#     core type: Literal
#     sub-expressions:
# 54. (x)
#     core type: ExprTuple
#     sub-expressions: 76
# 55. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 56. (n)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 58. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 75, 64
# 59. OUTPUT
#     core type: Literal
#     sub-expressions:
# 60. (U . x)
#     core type: ExprTuple
#     sub-expressions: 65
# 61. CONTROL
#     core type: Literal
#     sub-expressions:
# 62. alpha * |1〉
#     core type: Operation
#     operator: 66
#     operands: 67
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. {1, 2}
#     core type: Operation
#     operator: 68
#     operands: 69
# 65. U . x
#     core type: Operation
#     operator: 70
#     operands: 71
# 66. *
#     core type: Literal
#     sub-expressions:
# 67. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 72, 73
# 68. Set
#     core type: Literal
#     sub-expressions:
# 69. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 79, 74
# 70. .
#     core type: Literal
#     sub-expressions:
# 71. (U, x)
#     core type: ExprTuple
#     sub-expressions: 75, 76
# 72. alpha
#     core type: Variable
#     sub-expressions:
# 73. |1〉
#     core type: Operation
#     operator: 77
#     operand: 79
# 74. 2
#     core type: Literal
#     sub-expressions:
# 75. U
#     core type: Variable
#     sub-expressions:
# 76. x
#     core type: Variable
#     sub-expressions:
# 77. KET
#     core type: Literal
#     sub-expressions:
# 78. (1)
#     core type: ExprTuple
#     sub-expressions: 79
# 79. 1
#     core type: Literal
#     sub-expressions:
