# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, U, alpha, n, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import InSet, Set
from proveit.numbers import Complex, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, ket1
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket1)
expr = Conditional(Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(MatrixProd(U, x))])), InSet(alpha, Complex))
# Out:
# expr: { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 1 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 1 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{U \thinspace x} \qw
# } \hspace{2em} \textrm{ if } \alpha \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. { Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x) if alpha in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1.  Input(alpha * |1〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |1〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(U . x)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. alpha in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 4. ((Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (alpha, Complex)
#    core type: ExprTuple
#    sub-expressions: 40, 8
# 7. Input(alpha * |1〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |1〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(U . x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. (Input(alpha * |1〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |1〉))
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13, 14
# 10. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(U . x))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18
# 11. Input(alpha * |1〉)
#     core type: Operation
#     operator: 21
#     operand: 30
# 12. --
#     core type: Literal
#     sub-expressions:
# 13. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 25
#     operands: 19
# 14. Output(alpha * |1〉)
#     core type: Operation
#     operator: 27
#     operand: 30
# 15. Input(x)
#     core type: Operation
#     operator: 21
#     operand: 44
# 16. MultiWire(n)
#     core type: Operation
#     operator: 23
#     operand: 31
# 17. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 25
#     operands: 26
# 18. Output(U . x)
#     core type: Operation
#     operator: 27
#     operand: 33
# 19. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 29, 32
# 20. (alpha * |1〉)
#     core type: ExprTuple
#     sub-expressions: 30
# 21. INPUT
#     core type: Literal
#     sub-expressions:
# 22. (x)
#     core type: ExprTuple
#     sub-expressions: 44
# 23. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 24. (n)
#     core type: ExprTuple
#     sub-expressions: 31
# 25. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 26. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 43, 32
# 27. OUTPUT
#     core type: Literal
#     sub-expressions:
# 28. (U . x)
#     core type: ExprTuple
#     sub-expressions: 33
# 29. CONTROL
#     core type: Literal
#     sub-expressions:
# 30. alpha * |1〉
#     core type: Operation
#     operator: 34
#     operands: 35
# 31. n
#     core type: Variable
#     sub-expressions:
# 32. {1, 2}
#     core type: Operation
#     operator: 36
#     operands: 37
# 33. U . x
#     core type: Operation
#     operator: 38
#     operands: 39
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (alpha, |1〉)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 47, 42
# 38. .
#     core type: Literal
#     sub-expressions:
# 39. (U, x)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 40. alpha
#     core type: Variable
#     sub-expressions:
# 41. |1〉
#     core type: Operation
#     operator: 45
#     operand: 47
# 42. 2
#     core type: Literal
#     sub-expressions:
# 43. U
#     core type: Variable
#     sub-expressions:
# 44. x
#     core type: Variable
#     sub-expressions:
# 45. KET
#     core type: Literal
#     sub-expressions:
# 46. (1)
#     core type: ExprTuple
#     sub-expressions: 47
# 47. 1
#     core type: Literal
#     sub-expressions:
