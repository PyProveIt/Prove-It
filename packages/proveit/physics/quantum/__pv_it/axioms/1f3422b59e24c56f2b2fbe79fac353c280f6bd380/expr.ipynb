# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Iff.html">Iff</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, n, x, y
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Iff
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x)))
# Out:
# expr:  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=>
#    core type: Literal
#    sub-expressions:
# 2. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y)
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. y = (U . x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 6. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (y, U . x)
#    core type: ExprTuple
#    sub-expressions: 29, 10
# 9. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. U . x
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (Input(x), MultiWire(n), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16, 17
# 12. .
#     core type: Literal
#     sub-expressions:
# 13. (U, x)
#     core type: ExprTuple
#     sub-expressions: 28, 26
# 14. Input(x)
#     core type: Operation
#     operator: 18
#     operand: 26
# 15. MultiWire(n)
#     core type: Operation
#     operator: 20
#     operand: 27
# 16. Gate(U)
#     core type: Operation
#     operator: 22
#     operand: 28
# 17. Output(y)
#     core type: Operation
#     operator: 24
#     operand: 29
# 18. INPUT
#     core type: Literal
#     sub-expressions:
# 19. (x)
#     core type: ExprTuple
#     sub-expressions: 26
# 20. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 21. (n)
#     core type: ExprTuple
#     sub-expressions: 27
# 22. GATE
#     core type: Literal
#     sub-expressions:
# 23. (U)
#     core type: ExprTuple
#     sub-expressions: 28
# 24. OUTPUT
#     core type: Literal
#     sub-expressions:
# 25. (y)
#     core type: ExprTuple
#     sub-expressions: 29
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. n
#     core type: Variable
#     sub-expressions:
# 28. U
#     core type: Variable
#     sub-expressions:
# 29. y
#     core type: Variable
#     sub-expressions:
