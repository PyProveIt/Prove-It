# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprArray, ExprTuple, Lambda, U, n, x, y
from proveit.linalg import SU, TensorExp
from proveit.linear_algebra import MatrixProd
from proveit.logic import Equals, Forall, Iff, InSet
from proveit.numbers import Exp, NaturalPos, two
from proveit.physics.quantum import Gate, Input, Output, QubitSpace
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(n, Conditional(Forall([U], Forall([x, y], Iff(Circuit(ExprArray([Input(x), MultiWire(n), Gate(U), Output(y)])), Equals(y, MatrixProd(U, x))), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n))), InSet(n, NaturalPos))))
# Out:
# expr: (n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(n \mapsto \left\{\forall_{U \in SU(2^{n})}~\left[\forall_{x, y \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{y} \qw
# } \hspace{2em} \Leftrightarrow \left(y = \left(U \thinspace x\right)\right)\right)\right] \textrm{ if } n \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. n -> {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Lambda
#    parameter: 63
#    body: 2
# 2. {forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))] if n in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{U in SU(2^{n})} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))]
#    core type: Operation
#    operator: 12
#    operand: 7
# 4. n in NaturalPos
#    core type: Operation
#    operator: 38
#    operands: 6
# 5. (U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (n, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 63, 8
# 7. U -> {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 64
#    body: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. {forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))) if U in SU(2^{n}).
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. forall_{x, y in (Complex^{2})^{otimes n}} ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)))
#     core type: Operation
#     operator: 12
#     operand: 15
# 11. U in SU(2^{n})
#     core type: Operation
#     operator: 38
#     operands: 14
# 12. forall
#     core type: Literal
#     sub-expressions:
# 13. ((x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (U, SU(2^{n}))
#     core type: ExprTuple
#     sub-expressions: 64, 16
# 15. (x, y) -> { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Lambda
#     parameters: 17\n    body: 18
# 16. SU(2^{n})
#     core type: Operation
#     operator: 19
#     operand: 23
# 17. (x, y)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 18. { Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x)) if x in (Complex^{2})^{otimes n} ,  y in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. SU
#     core type: Literal
#     sub-expressions:
# 20. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 23
# 21.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y) <=> (y = (U . x))
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. (x in (Complex^{2})^{otimes n}) and (y in (Complex^{2})^{otimes n})
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. 2^{n}
#     core type: Operation
#     operator: 66
#     operands: 28
# 24. <=>
#     core type: Literal
#     sub-expressions:
# 25. ( Input(x)  & MultiWire(n)  & Gate(U)  & Output(y), y = (U . x))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. and
#     core type: Literal
#     sub-expressions:
# 27. (x in (Complex^{2})^{otimes n}, y in (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 28. (2, n)
#     core type: ExprTuple
#     sub-expressions: 69, 63
# 29.  Input(x)  & MultiWire(n)  & Gate(U)  & Output(y)
#     core type: Operation
#     operator: 33
#     operand: 40
# 30. y = (U . x)
#     core type: Operation
#     operator: 35
#     operands: 36
# 31. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 38
#     operands: 37
# 32. y in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 38
#     operands: 39
# 33. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 34. ((Input(x) & MultiWire(n) & Gate(U) & Output(y)))
#     core type: ExprTuple
#     sub-expressions: 40
# 35. =
#     core type: Literal
#     sub-expressions:
# 36. (y, U . x)
#     core type: ExprTuple
#     sub-expressions: 65, 41
# 37. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 62, 42
# 38. in
#     core type: Literal
#     sub-expressions:
# 39. (y, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 65, 42
# 40. Input(x) & MultiWire(n) & Gate(U) & Output(y)
#     core type: ExprTuple
#     sub-expressions: 43
# 41. U . x
#     core type: Operation
#     operator: 44
#     operands: 45
# 42. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 46
#     operands: 47
# 43. (Input(x), MultiWire(n), Gate(U), Output(y))
#     core type: ExprTuple
#     sub-expressions: 48, 49, 50, 51
# 44. .
#     core type: Literal
#     sub-expressions:
# 45. (U, x)
#     core type: ExprTuple
#     sub-expressions: 64, 62
# 46. otimes
#     core type: Literal
#     sub-expressions:
# 47. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 52, 63
# 48. Input(x)
#     core type: Operation
#     operator: 53
#     operand: 62
# 49. MultiWire(n)
#     core type: Operation
#     operator: 55
#     operand: 63
# 50. Gate(U)
#     core type: Operation
#     operator: 57
#     operand: 64
# 51. Output(y)
#     core type: Operation
#     operator: 59
#     operand: 65
# 52. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 61
# 53. INPUT
#     core type: Literal
#     sub-expressions:
# 54. (x)
#     core type: ExprTuple
#     sub-expressions: 62
# 55. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 56. (n)
#     core type: ExprTuple
#     sub-expressions: 63
# 57. GATE
#     core type: Literal
#     sub-expressions:
# 58. (U)
#     core type: ExprTuple
#     sub-expressions: 64
# 59. OUTPUT
#     core type: Literal
#     sub-expressions:
# 60. (y)
#     core type: ExprTuple
#     sub-expressions: 65
# 61. Complex^{2}
#     core type: Operation
#     operator: 66
#     operands: 67
# 62. x
#     core type: Variable
#     sub-expressions:
# 63. n
#     core type: Variable
#     sub-expressions:
# 64. U
#     core type: Variable
#     sub-expressions:
# 65. y
#     core type: Variable
#     sub-expressions:
# 66. Exp
#     core type: Literal
#     sub-expressions:
# 67. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 68. Complex
#     core type: Literal
#     sub-expressions:
# 69. 2
#     core type: Literal
#     sub-expressions:
