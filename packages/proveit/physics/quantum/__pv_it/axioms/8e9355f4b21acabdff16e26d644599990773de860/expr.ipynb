# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, U, alpha, n, x
from proveit.linalg import TensorExp
from proveit.linear_algebra import SU, ScalarProd
from proveit.logic import Forall, Set
from proveit.numbers import Complex, Exp, one, two
from proveit.physics.quantum import CONTROL, I, Input, Output, QubitSpace, ket0
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = ScalarProd(alpha, ket0)
expr = Forall([U], Forall([x], Forall([alpha], Circuit(ExprArray([Input(sub_expr2), I, MultiQubitGate(CONTROL, sub_expr1), Output(sub_expr2)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(x)])), domain = Complex), domain = TensorExp([QubitSpace], n)), domain = SU(Exp(two, n)))
# Out:
# expr: forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in SU(2^{n})}~\left[\forall_{x \in \left(\mathbb{C}^{2}\right)^{\otimes n}}~\left[\forall_{\alpha \in \mathbb{C}}~\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\alpha \thinspace \lvert 0 \rangle} & \qw & \control \qw \qwx[1] & \rstick{\alpha \thinspace \lvert 0 \rangle} \qw   \\
#   & \lstick{x} & { /^{n} } \qw & \gate{U} & \rstick{x} \qw
# } \hspace{2em}\right]\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{U in SU(2^{n})} [forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]]
#    core type: Operation
#    operator: 16
#    operand: 2
# 1. (U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. U -> {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).
#    core type: Lambda
#    parameter: 59
#    body: 3
# 3. {forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)] if U in SU(2^{n}).
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{x in (Complex^{2})^{otimes n}} [forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)]
#    core type: Operation
#    operator: 16
#    operand: 8
# 5. U in SU(2^{n})
#    core type: Operation
#    operator: 30
#    operands: 7
# 6. (x -> {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (U, SU(2^{n}))
#    core type: ExprTuple
#    sub-expressions: 59, 9
# 8. x -> {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.
#    core type: Lambda
#    parameter: 61
#    body: 10
# 9. SU(2^{n})
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. {forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if x in (Complex^{2})^{otimes n}.
#     core type: Conditional
#     value: 13
#     condition: 14
# 11. SU
#     core type: Literal
#     sub-expressions:
# 12. (2^{n})
#     core type: ExprTuple
#     sub-expressions: 15
# 13. forall_{alpha in Complex}  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#     core type: Operation
#     operator: 16
#     operand: 20
# 14. x in (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 30
#     operands: 18
# 15. 2^{n}
#     core type: Operation
#     operator: 34
#     operands: 19
# 16. forall
#     core type: Literal
#     sub-expressions:
# 17. (alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. (x, (Complex^{2})^{otimes n})
#     core type: ExprTuple
#     sub-expressions: 61, 21
# 19. (2, n)
#     core type: ExprTuple
#     sub-expressions: 69, 58
# 20. alpha -> { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#     core type: Lambda
#     parameter: 66
#     body: 22
# 21. (Complex^{2})^{otimes n}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. { Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x) if alpha in Complex.
#     core type: Conditional
#     value: 25
#     condition: 26
# 23. otimes
#     core type: Literal
#     sub-expressions:
# 24. ((Complex^{2}), n)
#     core type: ExprTuple
#     sub-expressions: 27, 58
# 25.  Input(alpha * |0〉)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(alpha * |0〉)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(x)
#     core type: Operation
#     operator: 28
#     operand: 33
# 26. alpha in Complex
#     core type: Operation
#     operator: 30
#     operands: 31
# 27. (Complex^{2})
#     core type: ExprTuple
#     sub-expressions: 32
# 28. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 29. ((Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)))
#     core type: ExprTuple
#     sub-expressions: 33
# 30. in
#     core type: Literal
#     sub-expressions:
# 31. (alpha, Complex)
#     core type: ExprTuple
#     sub-expressions: 66, 38
# 32. Complex^{2}
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. Input(alpha * |0〉) & -- & MultiQubitGate(CONTROL, {1, 2}) & Output(alpha * |0〉)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(x)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (Complex, 2)
#     core type: ExprTuple
#     sub-expressions: 38, 69
# 36. (Input(alpha * |0〉), --, MultiQubitGate(CONTROL, {1, 2}), Output(alpha * |0〉))
#     core type: ExprTuple
#     sub-expressions: 39, 40, 41, 42
# 37. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(x))
#     core type: ExprTuple
#     sub-expressions: 43, 44, 45, 46
# 38. Complex
#     core type: Literal
#     sub-expressions:
# 39. Input(alpha * |0〉)
#     core type: Operation
#     operator: 49
#     operand: 57
# 40. --
#     core type: Literal
#     sub-expressions:
# 41. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 52
#     operands: 47
# 42. Output(alpha * |0〉)
#     core type: Operation
#     operator: 54
#     operand: 57
# 43. Input(x)
#     core type: Operation
#     operator: 49
#     operand: 61
# 44. MultiWire(n)
#     core type: Operation
#     operator: 50
#     operand: 58
# 45. MultiQubitGate(U, {1, 2})
#     core type: Operation
#     operator: 52
#     operands: 53
# 46. Output(x)
#     core type: Operation
#     operator: 54
#     operand: 61
# 47. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 56, 60
# 48. (alpha * |0〉)
#     core type: ExprTuple
#     sub-expressions: 57
# 49. INPUT
#     core type: Literal
#     sub-expressions:
# 50. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 51. (n)
#     core type: ExprTuple
#     sub-expressions: 58
# 52. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 53. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 59, 60
# 54. OUTPUT
#     core type: Literal
#     sub-expressions:
# 55. (x)
#     core type: ExprTuple
#     sub-expressions: 61
# 56. CONTROL
#     core type: Literal
#     sub-expressions:
# 57. alpha * |0〉
#     core type: Operation
#     operator: 62
#     operands: 63
# 58. n
#     core type: Variable
#     sub-expressions:
# 59. U
#     core type: Variable
#     sub-expressions:
# 60. {1, 2}
#     core type: Operation
#     operator: 64
#     operands: 65
# 61. x
#     core type: Variable
#     sub-expressions:
# 62. *
#     core type: Literal
#     sub-expressions:
# 63. (alpha, |0〉)
#     core type: ExprTuple
#     sub-expressions: 66, 67
# 64. Set
#     core type: Literal
#     sub-expressions:
# 65. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 68, 69
# 66. alpha
#     core type: Variable
#     sub-expressions:
# 67. |0〉
#     core type: Operation
#     operator: 70
#     operand: 72
# 68. 1
#     core type: Literal
#     sub-expressions:
# 69. 2
#     core type: Literal
#     sub-expressions:
# 70. KET
#     core type: Literal
#     sub-expressions:
# 71. (0)
#     core type: ExprTuple
#     sub-expressions: 72
# 72. 0
#     core type: Literal
#     sub-expressions:
