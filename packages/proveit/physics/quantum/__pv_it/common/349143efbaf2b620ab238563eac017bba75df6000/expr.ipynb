# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, Literal, U, a, c, d, k, n, u, x, y
from proveit.logic import Set
from proveit.numbers import Add, one, three, two
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import IdentityOp, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = ExprTuple(ExprArray([Input(c), MultiWire(k), IdentityOp(), sub_expr2, Literal("SPACE", theory = "proveit.physics.quantum"), Literal("SPACE", theory = "proveit.physics.quantum")], [Input(a), Gate(u), MultiQubitGate(Literal("CONTROL", theory = "proveit.physics.quantum"), sub_expr1), sub_expr2, MultiWire(Add(k, one)), Output(d)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y), Literal("SPACE", theory = "proveit.physics.quantum"), Literal("SPACE", theory = "proveit.physics.quantum")]))
# Out:
# expr: ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccccc}
#  \lstick{c} & { /^{k} } \qw & \qw & \qw & SPACE & SPACE  \\
#   \lstick{a} & \gate{u} & \control \qw & \qw & { /^{k + 1} } \qw & \rstick{d} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{y} \qw & SPACE & SPACE \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 5, 6, 39, 10, 17, 17
# 3. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#    core type: ExprTuple
# ...
