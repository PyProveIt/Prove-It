# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal, c, k
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import Input
from proveit.physics.quantum.circuit import IdentityOp, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(c), MultiWire(k), IdentityOp(), MultiQubitGate(IdentityOp(), Set(one, two)), Literal("SPACE", theory = "proveit.physics.quantum"), Literal("SPACE", theory = "proveit.physics.quantum"))
# Out:
# expr: (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{c} & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & { /^{k} } \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, SPACE, SPACE\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 13, 3, 4, 4
# 1. Input(c)
#    core type: Operation
#    operator: 5
#    operand: 11
# 2. MultiWire(k)
#    core type: Operation
#    operator: 7
#    operand: 12
# 3. MultiQubitGate([I], {1, 2})
#    core type: Operation
#    operator: 9
#    operands: 10
# 4. SPACE
#    core type: Literal
#    sub-expressions:
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. (c)
#    core type: ExprTuple
#    sub-expressions: 11
# 7. MULTI_WIRE
#    core type: Literal
#    sub-expressions:
# 8. (k)
#    core type: ExprTuple
#    sub-expressions: 12
# 9. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 10. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. c
#     core type: Variable
#     sub-expressions:
# 12. k
#     core type: Variable
#     sub-expressions:
# 13. --
#     core type: Literal
#     sub-expressions:
# ...
