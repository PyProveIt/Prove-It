# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, Literal, U, a, b, n, u, x, y
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = ExprArray([Input(a), Gate(u), MultiQubitGate(Literal("CONTROL", theory = "proveit.physics.quantum"), sub_expr1), Output(b)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y)])
# Out:
# Unable to use 'dvipng' backend to compile LaTeX.
# Be sure a LaTeX distribution is installed.
# expr: Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccc}
#  \lstick{a} & \gate{u} & \control \qw & \rstick{b} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{y} \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr_info.py in _repr_html_(self)
#     182                     str(expr_num_map[sub_expr]) for sub_expr in expr._sub_expressions)
#     183             html += '<tr><td>%d</td><td>%s</td><td>%s</td><td>%s</td></tr>\n' % (
# --> 184                 k, expr._core_info[0], sub_expressions, expr._repr_html_())
#     185             if self.show_details and expr.__class__ not in \
#     186                     (Variable, Literal, Operation, Lambda, IndexedVar,
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in _repr_html_(self, unofficial_name_kind_theory)
#    1197         if not hasattr(self._style_data, 'png'):
#    1198             self._style_data.png, png_url = Theory._stored_png(
# -> 1199                 self, self.latex(), self._config_latex_tool)
#    1200             self._style_data.png_url = png_url
#    1201         if self._style_data.png_url is not None:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/theory.py in _stored_png(expr, latex, config_latex_tool_fn)
#     564         '''
#     565         return TheoryFolderStorage.retrieve_png(
# --> 566             expr, latex, config_latex_tool_fn)
#     567
#     568     def _theory_folder_storage(self, folder=None):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in retrieve_png(expr, latex, config_latex_tool_fn)
#     998                             "expressions")
#     999         return theory_folder_storage._retrieve_png(
# -> 1000             expr, latex, config_latex_tool_fn)
#    1001
#    1002     def _retrieve_png(self, expr, latex, config_latex_tool_fn):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in _retrieve_png(self, expr, latex, config_latex_tool_fn)
#    1028             latex_file.write(latex.encode('ascii'))
#    1029         # generate, store and return the png file
# -> 1030         png = self._generate_png(latex, config_latex_tool_fn)
#    1031         with open(png_path, 'wb') as png_file:
#    1032             png_file.write(png)
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in _generate_png(self, latex, config_latex_tool_fn)
#    1048         if png is None:
#    1049             raise Exception(
# -> 1050                 "Unable to use 'dvipng' backend to compile LaTeX.\n"
#    1051                 "Be sure a LaTeX distribution is installed.")
#    1052         return png
#
# Exception: Unable to use 'dvipng' backend to compile LaTeX.
# Be sure a LaTeX distribution is installed.
# 0. Input(a) & Gate(u) & MultiQubitGate(CONTROL, {1, 2}) & Output(b)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {1, 2}) & Output(y)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (Input(a), Gate(u), MultiQubitGate(CONTROL, {1, 2}), Output(b))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5, 6
# 2. (Input(x), MultiWire(n), MultiQubitGate(U, {1, 2}), Output(y))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 10
# 3. Input(a)
#    core type: Operation
#    operator: 16
#    operand: 24
# 4. Gate(u)
#    core type: Operation
#    operator: 12
#    operand: 25
# 5. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 20
#    operands: 14
# 6. Output(b)
#    core type: Operation
#    operator: 22
#    operand: 27
# 7. Input(x)
#    core type: Operation
#    operator: 16
#    operand: 28
# 8. MultiWire(n)
#    core type: Operation
#    operator: 18
#    operand: 29
# 9. MultiQubitGate(U, {1, 2})
#    core type: Operation
#    operator: 20
#    operands: 21
# 10. Output(y)
#     core type: Operation
#     operator: 22
#     operand: 32
# 11. (a)
#     core type: ExprTuple
#     sub-expressions: 24
# 12. GATE
#     core type: Literal
#     sub-expressions:
# 13. (u)
#     core type: ExprTuple
#     sub-expressions: 25
# 14. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 26, 31
# 15. (b)
#     core type: ExprTuple
#     sub-expressions: 27
# 16. INPUT
#     core type: Literal
#     sub-expressions:
# 17. (x)
#     core type: ExprTuple
#     sub-expressions: 28
# 18. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 19. (n)
#     core type: ExprTuple
#     sub-expressions: 29
# 20. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 21. (U, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 22. OUTPUT
#     core type: Literal
#     sub-expressions:
# 23. (y)
#     core type: ExprTuple
#     sub-expressions: 32
# 24. a
#     core type: Variable
#     sub-expressions:
# 25. u
#     core type: Variable
#     sub-expressions:
# 26. CONTROL
#     core type: Literal
#     sub-expressions:
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. n
#     core type: Variable
#     sub-expressions:
# 30. U
#     core type: Variable
#     sub-expressions:
# 31. {1, 2}
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. y
#     core type: Variable
#     sub-expressions:
# 33. Set
#     core type: Literal
#     sub-expressions:
# 34. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 1
#     core type: Literal
#     sub-expressions:
# 36. 2
#     core type: Literal
#     sub-expressions:
