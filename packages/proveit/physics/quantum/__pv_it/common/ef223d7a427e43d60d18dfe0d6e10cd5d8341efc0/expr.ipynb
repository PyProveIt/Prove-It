# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, Literal, U, a, c, d, k, n, u, x, y
from proveit.logic import Set
from proveit.numbers import Add, one, three, two
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import IdentityOp, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(two, three)
sub_expr2 = MultiQubitGate(IdentityOp(), Set(one, two))
expr = ExprArray([Input(c), MultiWire(k), IdentityOp(), sub_expr2, Literal("SPACE", theory = "proveit.physics.quantum"), Literal("SPACE", theory = "proveit.physics.quantum")], [Input(a), Gate(u), MultiQubitGate(Literal("CONTROL", theory = "proveit.physics.quantum"), sub_expr1), sub_expr2, MultiWire(Add(k, one)), Output(d)], [Input(x), MultiWire(n), MultiQubitGate(U, sub_expr1), Output(y), Literal("SPACE", theory = "proveit.physics.quantum"), Literal("SPACE", theory = "proveit.physics.quantum")])
# Out:
# expr: Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccccc}
#  \lstick{c} & { /^{k} } \qw & \qw & \qw & SPACE & SPACE  \\
#   \lstick{a} & \gate{u} & \control \qw & \qw & { /^{k + 1} } \qw & \rstick{d} \qw  \\
#   \lstick{x} & { /^{n} } \qw & U & \rstick{y} \qw & SPACE & SPACE \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(c) & MultiWire(k) & -- & MultiQubitGate(--, {1, 2}) & SPACE & SPACE  \\
#   Input(a) & Gate(u) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(--, {1, 2}) & MultiWire(k + 1) & Output(d)  \\
#   Input(x) & MultiWire(n) & MultiQubitGate(U, {2, 3}) & Output(y) & SPACE & SPACE
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (Input(c), MultiWire(k), --, MultiQubitGate([I], {1, 2}), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 38, 9, 16, 16
# 2. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8, 9, 10, 11
# 3. (Input(x), MultiWire(n), MultiQubitGate(U, {2, 3}), Output(y), SPACE, SPACE)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14, 15, 16, 16
# 4. Input(c)
#    core type: Operation
#    operator: 26
#    operand: 34
# 5. MultiWire(k)
#    core type: Operation
#    operator: 28
#    operand: 52
# 6. Input(a)
#    core type: Operation
#    operator: 26
#    operand: 35
# 7. Gate(u)
#    core type: Operation
#    operator: 20
#    operand: 36
# 8. MultiQubitGate(CONTROL, {2, 3})
#    core type: Operation
#    operator: 30
#    operands: 22
# 9. MultiQubitGate([I], {1, 2})
#    core type: Operation
#    operator: 30
#    operands: 23
# 10. MultiWire(k + 1)
#     core type: Operation
#     operator: 28
#     operand: 40
# 11. Output(d)
#     core type: Operation
#     operator: 32
#     operand: 41
# 12. Input(x)
#     core type: Operation
#     operator: 26
#     operand: 42
# 13. MultiWire(n)
#     core type: Operation
#     operator: 28
#     operand: 43
# 14. MultiQubitGate(U, {2, 3})
#     core type: Operation
#     operator: 30
#     operands: 31
# 15. Output(y)
#     core type: Operation
#     operator: 32
#     operand: 46
# 16. SPACE
#     core type: Literal
#     sub-expressions:
# 17. (c)
#     core type: ExprTuple
#     sub-expressions: 34
# 18. (k)
#     core type: ExprTuple
#     sub-expressions: 52
# 19. (a)
#     core type: ExprTuple
#     sub-expressions: 35
# 20. GATE
#     core type: Literal
#     sub-expressions:
# 21. (u)
#     core type: ExprTuple
#     sub-expressions: 36
# 22. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 37, 45
# 23. (--, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 24. (k + 1)
#     core type: ExprTuple
#     sub-expressions: 40
# 25. (d)
#     core type: ExprTuple
#     sub-expressions: 41
# 26. INPUT
#     core type: Literal
#     sub-expressions:
# 27. (x)
#     core type: ExprTuple
#     sub-expressions: 42
# 28. MULTI_WIRE
#     core type: Literal
#     sub-expressions:
# 29. (n)
#     core type: ExprTuple
#     sub-expressions: 43
# 30. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 31. (U, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 44, 45
# 32. OUTPUT
#     core type: Literal
#     sub-expressions:
# 33. (y)
#     core type: ExprTuple
#     sub-expressions: 46
# 34. c
#     core type: Variable
#     sub-expressions:
# 35. a
#     core type: Variable
#     sub-expressions:
# 36. u
#     core type: Variable
#     sub-expressions:
# 37. CONTROL
#     core type: Literal
#     sub-expressions:
# 38. --
#     core type: Literal
#     sub-expressions:
# 39. {1, 2}
#     core type: Operation
#     operator: 50
#     operands: 47
# 40. k + 1
#     core type: Operation
#     operator: 48
#     operands: 49
# 41. d
#     core type: Variable
#     sub-expressions:
# 42. x
#     core type: Variable
#     sub-expressions:
# 43. n
#     core type: Variable
#     sub-expressions:
# 44. U
#     core type: Variable
#     sub-expressions:
# 45. {2, 3}
#     core type: Operation
#     operator: 50
#     operands: 51
# 46. y
#     core type: Variable
#     sub-expressions:
# 47. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 48. +
#     core type: Literal
#     sub-expressions:
# 49. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 50. Set
#     core type: Literal
#     sub-expressions:
# 51. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 52. k
#     core type: Variable
#     sub-expressions:
# 53. 1
#     core type: Literal
#     sub-expressions:
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. 3
#     core type: Literal
#     sub-expressions:
