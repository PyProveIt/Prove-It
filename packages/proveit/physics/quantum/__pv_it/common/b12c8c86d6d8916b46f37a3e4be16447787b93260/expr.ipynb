# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Literal, a, d, k, u
from proveit.logic import Set
from proveit.numbers import Add, one, three, two
from proveit.physics.quantum import Gate, Input, Output
from proveit.physics.quantum.circuit import IdentityOp, MultiQubitGate, MultiWire

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Input(a), Gate(u), MultiQubitGate(Literal("CONTROL", theory = "proveit.physics.quantum"), Set(two, three)), MultiQubitGate(IdentityOp(), Set(one, two)), MultiWire(Add(k, one)), Output(d))
# Out:
# expr: (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{a} & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{u}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{I{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & { /^{k + 1} } \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{d} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(a), Gate(u), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate([I], {1, 2}), MultiWire(k + 1), Output(d))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4, 5, 6
# 1. Input(a)
#    core type: Operation
#    operator: 7
#    operand: 18
# 2. Gate(u)
#    core type: Operation
#    operator: 9
#    operand: 19
# 3. MultiQubitGate(CONTROL, {2, 3})
#    core type: Operation
#    operator: 12
#    operands: 11
# 4. MultiQubitGate([I], {1, 2})
#    core type: Operation
#    operator: 12
#    operands: 13
# 5. MultiWire(k + 1)
#    core type: Operation
#    operator: 14
#    operand: 24
# 6. Output(d)
#    core type: Operation
#    operator: 16
#    operand: 25
# 7. INPUT
#    core type: Literal
#    sub-expressions:
# 8. (a)
#    core type: ExprTuple
#    sub-expressions: 18
# 9. GATE
#    core type: Literal
#    sub-expressions:
# 10. (u)
#     core type: ExprTuple
#     sub-expressions: 19
# 11. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# ...
