# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, i
from proveit.core_expr_types import Len
from proveit.numbers import four, one
from proveit.physics.quantum import CONTROL, Gate, X

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(X)
expr = ExprTuple(Len([sub_expr1, CONTROL, sub_expr1, CONTROL]), Len([ExprRange(a, [i, a], one, four)]))
# Out:
# expr: (|(Gate(X), CONTROL, Gate(X), CONTROL)|, |((i, 1), ..(i, a).., (i, 4))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL\right)|, |\left(\left(i, 1\right), \ldots, \left(i, 4\right)\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(Gate(X), CONTROL, Gate(X), CONTROL)|, |((i, 1), ..(i, a).., (i, 4))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(Gate(X), CONTROL, Gate(X), CONTROL)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((i, 1), ..(i, a).., (i, 4))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((Gate(X), CONTROL, Gate(X), CONTROL))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((i, 1), ..(i, a).., (i, 4)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (Gate(X), CONTROL, Gate(X), CONTROL)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 8, 9
# 7. ((i, 1), ..(i, a).., (i, 4))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Gate(X)
#    core type: Operation
#    operator: 11
#    operand: 16
# 9. CONTROL
#    core type: Literal
#    sub-expressions:
# 10. (i, 1), ..(i, a).., (i, 4)
#     core type: ExprRange
#     lambda_map: 13
#     start_index: 14
#     end_index: 15
# 11. GATE
#     core type: Literal
#     sub-expressions:
# 12. (X)
#     core type: ExprTuple
#     sub-expressions: 16
# 13. a -> (i, a)
#     core type: Lambda
#     parameter: 19
#     body: 17
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. 4
#     core type: Literal
#     sub-expressions:
# 16. X
#     core type: Literal
#     sub-expressions:
# 17. (i, a)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. i
#     core type: Variable
#     sub-expressions:
# 19. a
#     core type: Variable
#     sub-expressions:
