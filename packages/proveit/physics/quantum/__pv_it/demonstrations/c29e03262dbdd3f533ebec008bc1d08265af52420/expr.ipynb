# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Lambda, Variable, a, k
from proveit.core_expr_types import Len
from proveit.numbers import one, three

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
expr = ExprTuple(Len([ExprRange(a, Lambda(sub_expr1, [a, sub_expr1]), one, three)]), Len([ExprRange(k, k, one, three)]))
# Out:
# expr: (|(_b -> (1, _b), .._b -> (a, _b).., _b -> (3, _b))|, |(1, ..k.., 3)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left({_{-}b} \mapsto \left(1, {_{-}b}\right), \ldots, {_{-}b} \mapsto \left(3, {_{-}b}\right)\right)|, |\left(1, \ldots, 3\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(_b -> (1, _b), .._b -> (a, _b).., _b -> (3, _b))|, |(1, ..k.., 3)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(_b -> (1, _b), .._b -> (a, _b).., _b -> (3, _b))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 3)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((_b -> (1, _b), .._b -> (a, _b).., _b -> (3, _b)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 3))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (_b -> (1, _b), .._b -> (a, _b).., _b -> (3, _b))
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (1, ..k.., 3)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. [_b -> (1, _b)], ..[_b -> (a, _b)].., [_b -> (3, _b)]
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 12
#    end_index: 13
# 9. 1, ..k.., 3
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 12
#    end_index: 13
# 10. a -> [_b -> (a, _b)]
#     core type: Lambda
#     parameter: 17
#     body: 14
# 11. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. 3
#     core type: Literal
#     sub-expressions:
# 14. _b -> (a, _b)
#     core type: Lambda
#     parameter: 18
#     body: 16
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. (a, _b)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. _b
#     core type: Variable
#     sub-expressions:
