# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, X
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Gate(I)
sub_expr3 = Gate(X)
sub_expr4 = Set(two, three)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr6 = MultiQubitGate(sub_expr3, sub_expr1)
sub_expr7 = MultiQubitGate(CONTROL, sub_expr4)
sub_expr8 = MultiQubitGate(sub_expr3, sub_expr4)
expr = ExprTuple(ExprArray([sub_expr5, sub_expr2, sub_expr5, sub_expr2], [sub_expr6, sub_expr7, sub_expr6, sub_expr7], [sub_expr2, sub_expr8, sub_expr2, sub_expr8]))
# Out:
# expr: ((MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {cccc}
#  \control \qw & \qw & \control \qw & \qw  \\
#   \targ & \control \qw & \targ & \control \qw  \\
#   \qw & \targ & \qw & \targ \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. (MultiQubitGate(CONTROL, {1, 2}), Gate(--), MultiQubitGate(CONTROL, {1, 2}), Gate(--))
#    core type: ExprTuple
#    sub-expressions: 5, 8, 5, 8
# 3. (MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 6, 7
# 4. (Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 8, 9
# 5. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 14
#    operands: 10
# 6. MultiQubitGate(Gate(X), {1, 2})
#    core type: Operation
#    operator: 14
#    operands: 11
# 7. MultiQubitGate(CONTROL, {2, 3})
#    core type: Operation
#    operator: 14
#    operands: 12
# 8. Gate(--)
#    core type: Operation
#    operator: 22
#    operand: 18
# 9. MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 11. (Gate(X), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 12. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 17, 20
# 13. (--)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 15. (Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. {1, 2}
#     core type: Operation
#     operator: 24
#     operands: 21
# 17. CONTROL
#     core type: Literal
#     sub-expressions:
# 18. --
#     core type: Literal
#     sub-expressions:
# 19. Gate(X)
#     core type: Operation
#     operator: 22
#     operand: 27
# 20. {2, 3}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 22. GATE
#     core type: Literal
#     sub-expressions:
# 23. (X)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. Set
#     core type: Literal
#     sub-expressions:
# 25. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 26. 1
#     core type: Literal
#     sub-expressions:
# 27. X
#     core type: Literal
#     sub-expressions:
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. 3
#     core type: Literal
#     sub-expressions:
