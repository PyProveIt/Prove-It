# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Set
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(one)
sub_expr3 = Set(two, three)
sub_expr4 = Set(three)
expr = Equals(Len([sub_expr1, sub_expr2, sub_expr1, sub_expr2, sub_expr1, sub_expr3, sub_expr1, sub_expr3, sub_expr4, sub_expr3, sub_expr4, sub_expr3]), Len([ExprRange(k, ExprRange(x, [k, x], one, four), one, three)]))
# Out:
# expr: |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})| = |((1, 1), ..(1, x).., (1, 4), ....(k, 1), ..(k, x).., (k, 4)...., (3, 1), ..(3, x).., (3, 4))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}\right)| = |\left(\left(1, 1\right), \ldots, \left(1, 4\right), \ldots\ldots, \left(3, 1\right), \ldots, \left(3, 4\right)\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})| = |((1, 1), ..(1, x).., (1, 4), ....(k, 1), ..(k, x).., (k, 4)...., (3, 1), ..(3, x).., (3, 4))|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})|, |((1, 1), ..(1, x).., (1, 4), ....(k, 1), ..(k, x).., (k, 4)...., (3, 1), ..(3, x).., (3, 4))|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |((1, 1), ..(1, x).., (1, 4), ....(k, 1), ..(k, x).., (k, 4)...., (3, 1), ..(3, x).., (3, 4))|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 8
# ...
