# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, three
from proveit.physics.quantum import CONTROL
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(three, four)
expr = ExprTuple(MultiQubitGate(MultiQubitGate(CONTROL, sub_expr1), sub_expr1))
# Out:
# expr: (MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\control \qw{\Big \{} \left\{3, 4\right\}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#    core type: Operation
#    operator: 4
#    operands: 2
# 2. (MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#    core type: ExprTuple
#    sub-expressions: 3, 7
# 3. MultiQubitGate(CONTROL, {3, 4})
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 5. (CONTROL, {3, 4})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 6. CONTROL
#    core type: Literal
#    sub-expressions:
# 7. {3, 4}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. Set
#    core type: Literal
#    sub-expressions:
# 9. (3, 4)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. 3
#     core type: Literal
#     sub-expressions:
# 11. 4
#     core type: Literal
#     sub-expressions:
