# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Gate, H, X, Z
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
sub_expr3 = Gate(H)
sub_expr4 = Gate(X)
sub_expr5 = MultiQubitGate(MultiQubitGate(CONTROL, sub_expr1), sub_expr1)
sub_expr6 = MultiQubitGate(MultiQubitGate(Z, sub_expr1), sub_expr1)
sub_expr7 = MultiQubitGate(MultiQubitGate(CONTROL, sub_expr2), sub_expr2)
sub_expr8 = MultiQubitGate(MultiQubitGate(Z, sub_expr2), sub_expr2)
sub_expr9 = [sub_expr5]
sub_expr10 = [sub_expr6]
sub_expr11 = [sub_expr7]
sub_expr12 = [sub_expr8]
sub_expr13 = [sub_expr3, sub_expr5, sub_expr4]
sub_expr14 = [sub_expr3, sub_expr6, sub_expr4]
sub_expr15 = [sub_expr3, sub_expr7, sub_expr4]
sub_expr16 = [sub_expr3, sub_expr8, sub_expr4]
expr = ExprTuple(CircuitEquiv(Circuit(ExprArray(sub_expr9, sub_expr10, sub_expr11, sub_expr12)), Circuit(ExprArray(sub_expr10, sub_expr9, sub_expr12, sub_expr11))), CircuitEquiv(Circuit(ExprArray(sub_expr13, sub_expr14, sub_expr15, sub_expr16)), Circuit(ExprArray(sub_expr14, sub_expr13, sub_expr16, sub_expr15))))
# Out:
# expr: ( MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})   \\
#    MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) equiv  MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}),  Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X) equiv  Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
# ...

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1]   \\
#   & \gate{Z}   \\
#   & \control \qw \qwx[1]   \\
#   & \gate{Z}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z} \qwx[1]   \\
#   & \control \qw   \\
#   & \gate{Z} \qwx[1]   \\
#   & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \control \qw \qwx[1] & \gate{X}   \\
#   & \gate{H} & \gate{Z} & \gate{X}   \\
#   & \gate{H} & \control \qw \qwx[1] & \gate{X}   \\
#   & \gate{H} & \gate{Z} & \gate{X}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{Z} \qwx[1] & \gate{X}   \\
#   & \gate{H} & \control \qw & \gate{X}   \\
#   & \gate{H} & \gate{Z} \qwx[1] & \gate{X}   \\
#   & \gate{H} & \control \qw & \gate{X}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})   \\
#    MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) equiv  MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})   \\
#    MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})   \\
#    MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}),  Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X) equiv  Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
# ...
