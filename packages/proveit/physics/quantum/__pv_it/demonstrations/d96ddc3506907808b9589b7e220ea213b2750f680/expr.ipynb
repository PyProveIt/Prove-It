# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Len
from proveit.physics.quantum import CONTROL, Gate, X

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(X)
expr = Len([sub_expr1, CONTROL, sub_expr1, CONTROL])
# Out:
# expr: |(Gate(X), CONTROL, Gate(X), CONTROL)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(Gate(X), CONTROL, Gate(X), CONTROL)|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((Gate(X), CONTROL, Gate(X), CONTROL))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (Gate(X), CONTROL, Gate(X), CONTROL)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 4, 5
# 4. Gate(X)
#    core type: Operation
#    operator: 6
#    operand: 8
# 5. CONTROL
#    core type: Literal
#    sub-expressions:
# 6. GATE
#    core type: Literal
#    sub-expressions:
# 7. (X)
#    core type: ExprTuple
#    sub-expressions: 8
# 8. X
#    core type: Literal
#    sub-expressions:
