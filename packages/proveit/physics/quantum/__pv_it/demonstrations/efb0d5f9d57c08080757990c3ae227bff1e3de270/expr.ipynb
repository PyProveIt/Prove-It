# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, X, Z
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
sub_expr2 = Gate(I)
sub_expr3 = Set(one, two)
sub_expr4 = Gate(X)
sub_expr5 = Set(two, three)
sub_expr6 = MultiQubitGate(CONTROL, sub_expr3)
sub_expr7 = MultiQubitGate(sub_expr4, sub_expr3)
sub_expr8 = MultiQubitGate(CONTROL, sub_expr5)
sub_expr9 = MultiQubitGate(sub_expr4, sub_expr5)
expr = ExprTuple(Circuit(ExprArray([MultiQubitGate(CONTROL, sub_expr1)], [sub_expr2], [MultiQubitGate(Z, sub_expr1)])), Circuit(ExprArray([sub_expr6, sub_expr2, sub_expr6, sub_expr2], [sub_expr7, sub_expr8, sub_expr7, sub_expr8], [sub_expr2, sub_expr9, sub_expr2, sub_expr9])))
# Out:
# expr: ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}),  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[2]   \\
#   & \qw   \\
#   & \gate{Z}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1] & \qw & \control \qw \qwx[1] & \qw   \\
#   & \targ & \control \qw \qwx[1] & \targ & \control \qw \qwx[1]   \\
#   & \qw & \targ & \qw & \targ
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}),  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3})
#    core type: Operation
#    operator: 4
#    operand: 6
# 2.  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
# ...
