# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Gate, H, X, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Set(one, two)
sub_expr3 = Gate(X)
sub_expr4 = Set(three, four)
expr = ExprArray([sub_expr1, MultiQubitGate(MultiQubitGate(CONTROL, sub_expr2), sub_expr2), sub_expr3], [sub_expr1, MultiQubitGate(MultiQubitGate(Z, sub_expr2), sub_expr2), sub_expr3], [sub_expr1, MultiQubitGate(MultiQubitGate(CONTROL, sub_expr4), sub_expr4), sub_expr3], [sub_expr1, MultiQubitGate(MultiQubitGate(Z, sub_expr4), sub_expr4), sub_expr3])
# Out:
# expr: Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  \gate{H} & \control \qw & \gate{X}  \\
#   \gate{H} & Z & \gate{X}  \\
#   \gate{H} & \control \qw & \gate{X}  \\
#   \gate{H} & Z & \gate{X} \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 4
# 1. (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 8, 5, 10
# 2. (Gate(H), MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 8, 6, 10
# 3. (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10
# 4. (Gate(H), MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 5. MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})
# ...
