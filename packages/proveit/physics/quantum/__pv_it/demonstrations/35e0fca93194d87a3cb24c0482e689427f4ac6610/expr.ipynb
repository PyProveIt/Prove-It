# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals, Set
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
expr = Equals(Len([sub_expr1, Set(two), sub_expr1]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, three)]))
# Out:
# expr: |({1, 3}, {2}, {1, 3})| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left\{1, 3\right\}, \left\{2\right\}, \left\{1, 3\right\}\right)| = |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(3, 1\right), \ldots, \left(3, 1\right)\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |({1, 3}, {2}, {1, 3})| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|({1, 3}, {2}, {1, 3})|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |({1, 3}, {2}, {1, 3})|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. (({1, 3}, {2}, {1, 3}))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. ({1, 3}, {2}, {1, 3})
#    core type: ExprTuple
#    sub-expressions: 11, 10, 11
# 9. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))
#    core type: ExprTuple
#    sub-expressions: 12
# 10. {2}
#     core type: Operation
#     operator: 14
#     operand: 17
# 11. {1, 3}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 21
#     end_index: 18
# 13. (2)
#     core type: ExprTuple
#     sub-expressions: 17
# 14. Set
#     core type: Literal
#     sub-expressions:
# 15. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 21, 18
# 16. k -> (k, 1), ..(k, x).., (k, 1)
#     core type: Lambda
#     parameter: 23
#     body: 19
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. (k, 1), ..(k, x).., (k, 1)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 21
# 20. x -> (k, x)
#     core type: Lambda
#     parameter: 24
#     body: 22
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. (k, x)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. k
#     core type: Variable
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
