# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, X
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = MultiQubitGate(Gate(X), Set(one, two))
sub_expr2 = MultiQubitGate(CONTROL, Set(two, three))
expr = ExprTuple(sub_expr1, sub_expr2, sub_expr1, sub_expr2)
# Out:
# expr: (MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\targ{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\targ{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 1, 2
# 1. MultiQubitGate(Gate(X), {1, 2})
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. MultiQubitGate(CONTROL, {2, 3})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (Gate(X), {1, 2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 5. (CONTROL, {2, 3})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. Gate(X)
#    core type: Operation
#    operator: 10
#    operand: 15
# 7. {1, 2}
#    core type: Operation
#    operator: 13
#    operands: 12
# 8. CONTROL
#    core type: Literal
#    sub-expressions:
# 9. {2, 3}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. GATE
#     core type: Literal
#     sub-expressions:
# 11. (X)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. X
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
