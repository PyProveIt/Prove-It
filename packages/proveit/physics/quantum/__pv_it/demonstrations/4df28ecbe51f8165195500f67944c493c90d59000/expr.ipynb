# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import one, three
from proveit.physics.quantum import Output, ket_psi

# %%
# build up the expression from sub-expressions
sub_expr1 = Output(ket_psi)
expr = Equals(Len([sub_expr1, sub_expr1, sub_expr1]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, three)]))
# Out:
# expr: |(Output(|psi〉), Output(|psi〉), Output(|psi〉))| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}\right)| = |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(3, 1\right), \ldots, \left(3, 1\right)\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(Output(|psi〉), Output(|psi〉), Output(|psi〉))| = |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(Output(|psi〉), Output(|psi〉), Output(|psi〉))|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(Output(|psi〉), Output(|psi〉), Output(|psi〉))|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((Output(|psi〉), Output(|psi〉), Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (Output(|psi〉), Output(|psi〉), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 10, 10, 10
# 9. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))
#    core type: ExprTuple
#    sub-expressions: 11
# 10. Output(|psi〉)
#     core type: Operation
#     operator: 12
#     operand: 16
# 11. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 21
#     end_index: 15
# 12. OUTPUT
#     core type: Literal
#     sub-expressions:
# 13. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. k -> (k, 1), ..(k, x).., (k, 1)
#     core type: Lambda
#     parameter: 24
#     body: 17
# 15. 3
#     core type: Literal
#     sub-expressions:
# 16. |psi〉
#     core type: Operation
#     operator: 18
#     operand: 22
# 17. (k, 1), ..(k, x).., (k, 1)
#     core type: ExprRange
#     lambda_map: 20
#     start_index: 21
#     end_index: 21
# 18. KET
#     core type: Literal
#     sub-expressions:
# 19. (psi)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. x -> (k, x)
#     core type: Lambda
#     parameter: 25
#     body: 23
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. psi
#     core type: Literal
#     sub-expressions:
# 23. (k, x)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. k
#     core type: Variable
#     sub-expressions:
# 25. x
#     core type: Variable
#     sub-expressions:
