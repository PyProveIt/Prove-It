# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.physics.quantum import Gate, H, X, Z

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(Z)
sub_expr2 = Gate(H)
expr = ExprTuple(ExprArray([sub_expr1, sub_expr2, Gate(X), sub_expr2, sub_expr1]))
# Out:
# expr: ((Gate(Z) & Gate(H) & Gate(X) & Gate(H) & Gate(Z)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccccc}
#  \gate{Z} & \gate{H} & \gate{X} & \gate{H} & \gate{Z} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Gate(Z) & Gate(H) & Gate(X) & Gate(H) & Gate(Z)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Gate(Z) & Gate(H) & Gate(X) & Gate(H) & Gate(Z)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (Gate(Z), Gate(H), Gate(X), Gate(H), Gate(Z))
#    core type: ExprTuple
#    sub-expressions: 5, 4, 3, 4, 5
# 3. Gate(X)
#    core type: Operation
#    operator: 8
#    operand: 10
# 4. Gate(H)
#    core type: Operation
#    operator: 8
#    operand: 11
# 5. Gate(Z)
#    core type: Operation
#    operator: 8
#    operand: 12
# 6. (X)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. (H)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. GATE
#    core type: Literal
#    sub-expressions:
# 9. (Z)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. X
#     core type: Literal
#     sub-expressions:
# 11. H
#     core type: Literal
#     sub-expressions:
# 12. Z
#     core type: Literal
#     sub-expressions:
