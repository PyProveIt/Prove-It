# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, x
from proveit.core_expr_types import Len
from proveit.numbers import one, two
from proveit.physics.quantum import Input, ket_psi

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(ket_psi)
expr = ExprTuple(Len([sub_expr1, sub_expr1]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, two)]))
# Out:
# expr: (|(Input(|psi〉), Input(|psi〉))|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (2, 1), ..(2, x).., (2, 1))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \qw
# } \hspace{2em}\right)|, |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(2, 1\right), \ldots, \left(2, 1\right)\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(Input(|psi〉), Input(|psi〉))|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (2, 1), ..(2, x).., (2, 1))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(Input(|psi〉), Input(|psi〉))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (2, 1), ..(2, x).., (2, 1))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((Input(|psi〉), Input(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (2, 1), ..(2, x).., (2, 1)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (Input(|psi〉), Input(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 8, 8
# 7. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (2, 1), ..(2, x).., (2, 1))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. Input(|psi〉)
# ...
