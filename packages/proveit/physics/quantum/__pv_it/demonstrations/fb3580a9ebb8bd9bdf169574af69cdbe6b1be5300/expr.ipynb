# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket_psi
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Input(ket_psi)
sub_expr3 = Output(ket_psi)
expr = ExprTuple(ExprArray([sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3], [sub_expr2, MultiQubitGate(Z, sub_expr1), sub_expr3]))
# Out:
# expr: ((Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 2}) & Output(|psi〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \lstick{\lvert \psi \rangle} & \control \qw & \rstick{\lvert \psi \rangle} \qw  \\
#   \lstick{\lvert \psi \rangle} & Z & \rstick{\lvert \psi \rangle} \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 2}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 2}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 2}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 5, 4, 7
# 3. (Input(|psi〉), MultiQubitGate(Z, {1, 2}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 4. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 10
#    operands: 8
# 5. Input(|psi〉)
#    core type: Operation
#    operator: 9
#    operand: 17
# 6. MultiQubitGate(Z, {1, 2})
#    core type: Operation
#    operator: 10
#    operands: 11
# 7. Output(|psi〉)
#    core type: Operation
#    operator: 12
#    operand: 17
# 8. (CONTROL, {1, 2})
# ...
