# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.CircuitEquiv.html">CircuitEquiv</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.physics.quantum import Gate, H, SPACE, X
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Gate(X)
sub_expr3 = Gate(SPACE)
expr = CircuitEquiv(Circuit(ExprArray([sub_expr1, sub_expr2, sub_expr1])), Circuit(ExprArray([sub_expr3, sub_expr2, sub_expr3])))
# Out:
# expr:  Gate(H)  & Gate(X)  & Gate(H) equiv  Gate(SPACE)  & Gate(X)  & Gate(SPACE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{X} & \gate{H}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X}
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Gate(H)  & Gate(X)  & Gate(H) equiv  Gate(SPACE)  & Gate(X)  & Gate(SPACE)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. equiv
#    core type: Literal
#    sub-expressions:
# 2. ( Gate(H)  & Gate(X)  & Gate(H),  Gate(SPACE)  & Gate(X)  & Gate(SPACE))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3.  Gate(H)  & Gate(X)  & Gate(H)
#    core type: Operation
#    operator: 6
#    operand: 8
# 4.  Gate(SPACE)  & Gate(X)  & Gate(SPACE)
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((Gate(H) & Gate(X) & Gate(H)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 7. ((Gate(SPACE) & Gate(X) & Gate(SPACE)))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. Gate(H) & Gate(X) & Gate(H)
#    core type: ExprTuple
#    sub-expressions: 10
# 9. Gate(SPACE) & Gate(X) & Gate(SPACE)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. (Gate(H), Gate(X), Gate(H))
#     core type: ExprTuple
#     sub-expressions: 12, 13, 12
# 11. (Gate(SPACE), Gate(X), Gate(SPACE))
#     core type: ExprTuple
#     sub-expressions: 14, 13, 14
# 12. Gate(H)
#     core type: Operation
#     operator: 17
#     operand: 19
# 13. Gate(X)
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. Gate(SPACE)
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. (H)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. (X)
#     core type: ExprTuple
#     sub-expressions: 20
# 17. GATE
#     core type: Literal
#     sub-expressions:
# 18. (SPACE)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. H
#     core type: Literal
#     sub-expressions:
# 20. X
#     core type: Literal
#     sub-expressions:
# 21. SPACE
#     core type: Literal
#     sub-expressions:
