# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a, i
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(two, three)
expr = ExprTuple(Len([sub_expr1, sub_expr2, sub_expr1, sub_expr2]), Len([ExprRange(a, [i, a], one, four)]))
# Out:
# expr: (|({1, 2}, {2, 3}, {1, 2}, {2, 3})|, |((i, 1), ..(i, a).., (i, 4))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\left\{1, 2\right\}, \left\{2, 3\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}\right)|, |\left(\left(i, 1\right), \ldots, \left(i, 4\right)\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|({1, 2}, {2, 3}, {1, 2}, {2, 3})|, |((i, 1), ..(i, a).., (i, 4))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |({1, 2}, {2, 3}, {1, 2}, {2, 3})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((i, 1), ..(i, a).., (i, 4))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (({1, 2}, {2, 3}, {1, 2}, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((i, 1), ..(i, a).., (i, 4)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ({1, 2}, {2, 3}, {1, 2}, {2, 3})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 8, 9
# 7. ((i, 1), ..(i, a).., (i, 4))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. {1, 2}
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. {2, 3}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. (i, 1), ..(i, a).., (i, 4)
#     core type: ExprRange
#     lambda_map: 14
#     start_index: 16
#     end_index: 15
# 11. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. Set
#     core type: Literal
#     sub-expressions:
# 13. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. a -> (i, a)
#     core type: Lambda
#     parameter: 21
#     body: 19
# 15. 4
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. 3
#     core type: Literal
#     sub-expressions:
# 19. (i, a)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. i
#     core type: Variable
#     sub-expressions:
# 21. a
#     core type: Variable
#     sub-expressions:
