# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, three
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, Z, ket_psi
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
sub_expr2 = Input(ket_psi)
sub_expr3 = Output(ket_psi)
expr = Circuit(ExprArray([sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3], [sub_expr2, Gate(I), sub_expr3], [sub_expr2, MultiQubitGate(Z, sub_expr1), sub_expr3]))
# Out:
# expr:  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \control \qw \qwx[2] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \qw & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \gate{Z} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 4, 5, 6
# 4. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 3}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 9, 7, 11
# 5. (Input(|psi〉), Gate(--), Output(|psi〉))
#    core type: ExprTuple
# ...
