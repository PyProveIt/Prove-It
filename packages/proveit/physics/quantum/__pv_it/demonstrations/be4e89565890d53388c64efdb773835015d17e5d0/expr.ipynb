# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
expr = ExprTuple(ExprArray([MultiQubitGate(MultiQubitGate(Z, sub_expr1), sub_expr1)], [MultiQubitGate(MultiQubitGate(CONTROL, sub_expr1), sub_expr1)], [MultiQubitGate(MultiQubitGate(Z, sub_expr2), sub_expr2)], [MultiQubitGate(MultiQubitGate(CONTROL, sub_expr2), sub_expr2)]))
# Out:
# expr: ((MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {c}
#  Z  \\
#   \control \qw  \\
#   Z  \\
#   \control \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  \\
#   MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  \\
#   MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. (MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}))
#    core type: ExprTuple
#    sub-expressions: 6
# 3. (MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}))
#    core type: ExprTuple
#    sub-expressions: 7
# 4. (MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}))
#    core type: ExprTuple
#    sub-expressions: 8
# 5. (MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}))
# ...
