# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Gate, H, X, Z
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Set(one, two)
sub_expr3 = Gate(X)
sub_expr4 = Set(three, four)
sub_expr5 = [sub_expr1, MultiQubitGate(MultiQubitGate(CONTROL, sub_expr2), sub_expr2), sub_expr3]
sub_expr6 = [sub_expr1, MultiQubitGate(MultiQubitGate(Z, sub_expr2), sub_expr2), sub_expr3]
sub_expr7 = [sub_expr1, MultiQubitGate(MultiQubitGate(CONTROL, sub_expr4), sub_expr4), sub_expr3]
sub_expr8 = [sub_expr1, MultiQubitGate(MultiQubitGate(Z, sub_expr4), sub_expr4), sub_expr3]
expr = ExprTuple(Circuit(ExprArray(sub_expr5, sub_expr6, sub_expr7, sub_expr8)), Circuit(ExprArray(sub_expr6, sub_expr5, sub_expr8, sub_expr7)))
# Out:
# expr: ( Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X),  Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \control \qw \qwx[1] & \gate{X}   \\
#   & \gate{H} & \gate{Z} & \gate{X}   \\
#   & \gate{H} & \control \qw \qwx[1] & \gate{X}   \\
#   & \gate{H} & \gate{Z} & \gate{X}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{Z} \qwx[1] & \gate{X}   \\
#   & \gate{H} & \control \qw & \gate{X}   \\
#   & \gate{H} & \gate{Z} \qwx[1] & \gate{X}   \\
#   & \gate{H} & \control \qw & \gate{X}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X),  Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X)
#    core type: Operation
#    operator: 4
#    operand: 6
# 2.  Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})  & Gate(X)   \\
#    Gate(H)  & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})  & Gate(X)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 5. ((Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)
#    core type: ExprTuple
#    sub-expressions: 9, 8, 11, 10
# 7. Gate(H) & MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}) & Gate(X)  \\
#   Gate(H) & MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}) & Gate(X)
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 8. (Gate(H), MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 15, 12, 17
# 9. (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 15, 13, 17
# 10. (Gate(H), MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4}), Gate(X))
#     core type: ExprTuple
#     sub-expressions: 15, 14, 17
# 11. (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}), Gate(X))
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17
# 12. MultiQubitGate(MultiQubitGate(Z, {1, 2}), {1, 2})
#     core type: Operation
#     operator: 34
#     operands: 18
# 13. MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})
#     core type: Operation
#     operator: 34
#     operands: 19
# 14. MultiQubitGate(MultiQubitGate(Z, {3, 4}), {3, 4})
#     core type: Operation
#     operator: 34
#     operands: 20
# 15. Gate(H)
#     core type: Operation
#     operator: 23
#     operand: 28
# 16. MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#     core type: Operation
#     operator: 34
#     operands: 22
# 17. Gate(X)
#     core type: Operation
#     operator: 23
#     operand: 30
# 18. (MultiQubitGate(Z, {1, 2}), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 25, 36
# 19. (MultiQubitGate(CONTROL, {1, 2}), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 26, 36
# 20. (MultiQubitGate(Z, {3, 4}), {3, 4})
#     core type: ExprTuple
#     sub-expressions: 27, 39
# 21. (H)
#     core type: ExprTuple
#     sub-expressions: 28
# 22. (MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#     core type: ExprTuple
#     sub-expressions: 29, 39
# 23. GATE
#     core type: Literal
#     sub-expressions:
# 24. (X)
#     core type: ExprTuple
#     sub-expressions: 30
# 25. MultiQubitGate(Z, {1, 2})
#     core type: Operation
#     operator: 34
#     operands: 31
# 26. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 34
#     operands: 32
# 27. MultiQubitGate(Z, {3, 4})
#     core type: Operation
#     operator: 34
#     operands: 33
# 28. H
#     core type: Literal
#     sub-expressions:
# 29. MultiQubitGate(CONTROL, {3, 4})
#     core type: Operation
#     operator: 34
#     operands: 35
# 30. X
#     core type: Literal
#     sub-expressions:
# 31. (Z, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 37, 36
# 32. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 38, 36
# 33. (Z, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 37, 39
# 34. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 35. (CONTROL, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. {1, 2}
#     core type: Operation
#     operator: 41
#     operands: 40
# 37. Z
#     core type: Literal
#     sub-expressions:
# 38. CONTROL
#     core type: Literal
#     sub-expressions:
# 39. {3, 4}
#     core type: Operation
#     operator: 41
#     operands: 42
# 40. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 41. Set
#     core type: Literal
#     sub-expressions:
# 42. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. 1
#     core type: Literal
#     sub-expressions:
# 44. 2
#     core type: Literal
#     sub-expressions:
# 45. 3
#     core type: Literal
#     sub-expressions:
# 46. 4
#     core type: Literal
#     sub-expressions:
