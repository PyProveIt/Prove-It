# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import nine, one
from proveit.physics.quantum import CONTROL, Gate, I, X

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(X)
expr = Equals(Len([CONTROL, I, CONTROL, I, sub_expr1, CONTROL, sub_expr1, CONTROL, I]), Len([ExprRange(k, k, one, nine)]))
# Out:
# expr: |(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --)| = |(1, ..k.., 9)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}\right)| = |\left(1, \ldots, 9\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --)| = |(1, ..k.., 9)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --)|, |(1, ..k.., 9)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 9)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 9))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --)
#    core type: ExprTuple
#    sub-expressions: 11, 12, 11, 12, 10, 11, 10, 11, 12
# 9. (1, ..k.., 9)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. Gate(X)
#     core type: Operation
#     operator: 14
#     operand: 19
# 11. CONTROL
#     core type: Literal
#     sub-expressions:
# 12. --
#     core type: Literal
#     sub-expressions:
# 13. 1, ..k.., 9
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 14. GATE
#     core type: Literal
#     sub-expressions:
# 15. (X)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. k -> k
#     core type: Lambda
#     parameter: 20
#     body: 20
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 9
#     core type: Literal
#     sub-expressions:
# 19. X
#     core type: Literal
#     sub-expressions:
# 20. k
#     core type: Variable
#     sub-expressions:
