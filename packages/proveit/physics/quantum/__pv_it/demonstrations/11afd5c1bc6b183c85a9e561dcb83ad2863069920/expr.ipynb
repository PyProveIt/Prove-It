# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, x
from proveit.core_expr_types import Len
from proveit.numbers import one, three

# %%
# build up the expression from sub-expressions
expr = Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, three)])
# Out:
# expr: |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(3, 1\right), \ldots, \left(3, 1\right)\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (3, 1), ..(3, x).., (3, 1)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 9
#    end_index: 6
# 5. k -> (k, 1), ..(k, x).., (k, 1)
#    core type: Lambda
#    parameter: 11
#    body: 7
# 6. 3
#    core type: Literal
#    sub-expressions:
# 7. (k, 1), ..(k, x).., (k, 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 9
# 8. x -> (k, x)
#    core type: Lambda
#    parameter: 12
#    body: 10
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. (k, x)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. x
#     core type: Variable
#     sub-expressions:
