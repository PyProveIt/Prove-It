# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import And
from proveit.physics.quantum import Gate, H, I, Input, Output, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
expr = And(CircuitEquiv(Circuit(ExprArray([sub_expr1, sub_expr1])), Circuit(ExprArray([Gate(I)]))), Circuit(ExprArray([Input(ket_psi), sub_expr1, sub_expr1, Output(ket_psi)])))
# Out:
# expr: ( Gate(H)  & Gate(H) equiv  Gate(--)) and  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{H}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \gate{H} & \gate{H} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Gate(H)  & Gate(H) equiv  Gate(--)) and  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ( Gate(H)  & Gate(H) equiv  Gate(--),  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3.  Gate(H)  & Gate(H) equiv  Gate(--)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4.  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉)
#    core type: Operation
#    operator: 12
#    operand: 10
# 5. equiv
#    core type: Literal
#    sub-expressions:
# 6. ( Gate(H)  & Gate(H),  Gate(--))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ((Input(|psi〉) & Gate(H) & Gate(H) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 10
# 8.  Gate(H)  & Gate(H)
#    core type: Operation
#    operator: 12
#    operand: 15
# 9.  Gate(--)
#    core type: Operation
#    operator: 12
# ...
