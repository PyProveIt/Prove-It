# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
expr = ExprTuple(Len([MultiQubitGate(Z, sub_expr1), MultiQubitGate(CONTROL, sub_expr1), MultiQubitGate(Z, sub_expr2), MultiQubitGate(CONTROL, sub_expr2)]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: (|(MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4}))|, |(1, ..k.., 4)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{3, 4\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}\right)|, |\left(1, \ldots, 4\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4}))|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4}))|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4})))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4}))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. (1, ..k.., 4)
# ...
