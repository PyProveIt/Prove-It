# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.physics.quantum import Gate, SPACE, X, Z

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(Z)
sub_expr2 = Gate(SPACE)
expr = ExprArray([sub_expr1, sub_expr2, Gate(X), sub_expr2, sub_expr1])
# Out:
# expr: Gate(Z) & Gate(SPACE) & Gate(X) & Gate(SPACE) & Gate(Z)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccccc}
#  \gate{Z} & SPACE & \gate{X} & SPACE & \gate{Z} \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Gate(Z) & Gate(SPACE) & Gate(X) & Gate(SPACE) & Gate(Z)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (Gate(Z), Gate(SPACE), Gate(X), Gate(SPACE), Gate(Z))
#    core type: ExprTuple
#    sub-expressions: 4, 3, 2, 3, 4
# 2. Gate(X)
#    core type: Operation
#    operator: 7
#    operand: 9
# 3. Gate(SPACE)
#    core type: Operation
#    operator: 7
#    operand: 10
# 4. Gate(Z)
#    core type: Operation
#    operator: 7
#    operand: 11
# 5. (X)
#    core type: ExprTuple
#    sub-expressions: 9
# 6. (SPACE)
#    core type: ExprTuple
#    sub-expressions: 10
# 7. GATE
#    core type: Literal
#    sub-expressions:
# 8. (Z)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. X
#    core type: Literal
#    sub-expressions:
# 10. SPACE
#     core type: Literal
#     sub-expressions:
# 11. Z
#     core type: Literal
#     sub-expressions:
