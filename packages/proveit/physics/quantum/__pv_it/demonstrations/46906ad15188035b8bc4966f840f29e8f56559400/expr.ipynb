# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, I, Input, Output, X, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two, three)
sub_expr2 = Input(ket0)
sub_expr3 = Output(ket0)
sub_expr4 = Input(ket1)
sub_expr5 = Output(ket1)
sub_expr6 = [sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3]
sub_expr7 = [sub_expr4, MultiQubitGate(X, Set(four, six)), sub_expr5]
expr = ExprTuple(ExprArray(sub_expr6, sub_expr6, [sub_expr2, MultiQubitGate(Z, sub_expr1), sub_expr3], sub_expr7, [sub_expr2, I, sub_expr3], sub_expr7, [sub_expr4, MultiQubitGate(Z, Set(seven)), sub_expr5]))
# Out:
# expr: ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|0〉) & -- & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7}) & Output(|1〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & Z & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & X & \rstick{\lvert 1 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & X & \rstick{\lvert 1 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & Z & \rstick{\lvert 1 \rangle} \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|0〉) & -- & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7}) & Output(|1〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|0〉) & -- & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 2, 2, 3, 5, 4, 5, 6
# 2. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2, 3}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 9, 7, 11
# 3. (Input(|0〉), MultiQubitGate(Z, {1, 2, 3}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 9, 8, 11
# 4. (Input(|0〉), --, Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 5. (Input(|1〉), MultiQubitGate(X, {4, 6}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 13, 12, 15
# 6. (Input(|1〉), MultiQubitGate(Z, {7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 13, 14, 15
# 7. MultiQubitGate(CONTROL, {1, 2, 3})
#    core type: Operation
#    operator: 21
#    operands: 16
# 8. MultiQubitGate(Z, {1, 2, 3})
#    core type: Operation
#    operator: 21
#    operands: 17
# 9. Input(|0〉)
#    core type: Operation
#    operator: 20
#    operand: 27
# 10. --
#     core type: Literal
#     sub-expressions:
# 11. Output(|0〉)
#     core type: Operation
#     operator: 23
#     operand: 27
# 12. MultiQubitGate(X, {4, 6})
#     core type: Operation
#     operator: 21
#     operands: 19
# 13. Input(|1〉)
#     core type: Operation
#     operator: 20
#     operand: 32
# 14. MultiQubitGate(Z, {7})
#     core type: Operation
#     operator: 21
#     operands: 22
# 15. Output(|1〉)
#     core type: Operation
#     operator: 23
#     operand: 32
# 16. (CONTROL, {1, 2, 3})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 17. (Z, {1, 2, 3})
#     core type: ExprTuple
#     sub-expressions: 30, 26
# 18. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 27
# 19. (X, {4, 6})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 20. INPUT
#     core type: Literal
#     sub-expressions:
# 21. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 22. (Z, {7})
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 23. OUTPUT
#     core type: Literal
#     sub-expressions:
# 24. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 32
# 25. CONTROL
#     core type: Literal
#     sub-expressions:
# 26. {1, 2, 3}
#     core type: Operation
#     operator: 36
#     operands: 33
# 27. |0〉
#     core type: Operation
#     operator: 38
#     operand: 42
# 28. X
#     core type: Literal
#     sub-expressions:
# 29. {4, 6}
#     core type: Operation
#     operator: 36
#     operands: 35
# 30. Z
#     core type: Literal
#     sub-expressions:
# 31. {7}
#     core type: Operation
#     operator: 36
#     operand: 45
# 32. |1〉
#     core type: Operation
#     operator: 38
#     operand: 46
# 33. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 46, 40, 41
# 34. (0)
#     core type: ExprTuple
#     sub-expressions: 42
# 35. (4, 6)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 36. Set
#     core type: Literal
#     sub-expressions:
# 37. (7)
#     core type: ExprTuple
#     sub-expressions: 45
# 38. KET
#     core type: Literal
#     sub-expressions:
# 39. (1)
#     core type: ExprTuple
#     sub-expressions: 46
# 40. 2
#     core type: Literal
#     sub-expressions:
# 41. 3
#     core type: Literal
#     sub-expressions:
# 42. 0
#     core type: Literal
#     sub-expressions:
# 43. 4
#     core type: Literal
#     sub-expressions:
# 44. 6
#     core type: Literal
#     sub-expressions:
# 45. 7
#     core type: Literal
#     sub-expressions:
# 46. 1
#     core type: Literal
#     sub-expressions:
