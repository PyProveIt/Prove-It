# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, X, Z, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
sub_expr2 = Gate(I)
sub_expr3 = Set(one, two)
sub_expr4 = Gate(X)
sub_expr5 = Set(two, three)
sub_expr6 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr7 = MultiQubitGate(Z, sub_expr1)
sub_expr8 = MultiQubitGate(CONTROL, sub_expr3)
sub_expr9 = MultiQubitGate(sub_expr4, sub_expr3)
sub_expr10 = MultiQubitGate(CONTROL, sub_expr5)
sub_expr11 = MultiQubitGate(sub_expr4, sub_expr5)
sub_expr12 = Input(ket_psi)
sub_expr13 = Output(ket_psi)
expr = ExprTuple(CircuitEquiv(Circuit(ExprArray([sub_expr6], [sub_expr2], [sub_expr7])), Circuit(ExprArray([sub_expr8, sub_expr2, sub_expr8, sub_expr2], [sub_expr9, sub_expr10, sub_expr9, sub_expr10], [sub_expr2, sub_expr11, sub_expr2, sub_expr11]))), Circuit(ExprArray([sub_expr12, sub_expr6, sub_expr13], [sub_expr12, sub_expr2, sub_expr13], [sub_expr12, sub_expr7, sub_expr13])))
# Out:
# expr: ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}),  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[2]   \\
#   & \qw   \\
#   & \gate{Z}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1] & \qw & \control \qw \qwx[1] & \qw   \\
#   & \targ & \control \qw \qwx[1] & \targ & \control \qw \qwx[1]   \\
#   & \qw & \targ & \qw & \targ
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \control \qw \qwx[2] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \qw & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \gate{Z} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}),  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2.  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)
#    core type: Operation
#    operator: 10
#    operand: 8
# 3. equiv
#    core type: Literal
#    sub-expressions:
# 4. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}),  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. ((Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6.  MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3})
#    core type: Operation
#    operator: 10
#    operand: 15
# 7.  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 10
#    operand: 16
# 8. Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 9. ((MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})))
#    core type: ExprTuple
#    sub-expressions: 15
# 10. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 11. ((MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})))
#     core type: ExprTuple
#     sub-expressions: 16
# 12. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 3}), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 17, 28, 18
# 13. (Input(|psi〉), Gate(--), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 17, 33, 18
# 14. (Input(|psi〉), MultiQubitGate(Z, {1, 3}), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 17, 29, 18
# 15. MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 19, 20, 21
# 16. MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 22, 23, 24
# 17. Input(|psi〉)
#     core type: Operation
#     operator: 25
#     operand: 35
# 18. Output(|psi〉)
#     core type: Operation
#     operator: 26
#     operand: 35
# 19. (MultiQubitGate(CONTROL, {1, 3}))
#     core type: ExprTuple
#     sub-expressions: 28
# 20. (Gate(--))
#     core type: ExprTuple
#     sub-expressions: 33
# 21. (MultiQubitGate(Z, {1, 3}))
#     core type: ExprTuple
#     sub-expressions: 29
# 22. (MultiQubitGate(CONTROL, {1, 2}), Gate(--), MultiQubitGate(CONTROL, {1, 2}), Gate(--))
#     core type: ExprTuple
#     sub-expressions: 30, 33, 30, 33
# 23. (MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}))
#     core type: ExprTuple
#     sub-expressions: 31, 32, 31, 32
# 24. (Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}))
#     core type: ExprTuple
#     sub-expressions: 33, 34, 33, 34
# 25. INPUT
#     core type: Literal
#     sub-expressions:
# 26. OUTPUT
#     core type: Literal
#     sub-expressions:
# 27. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 35
# 28. MultiQubitGate(CONTROL, {1, 3})
#     core type: Operation
#     operator: 42
#     operands: 36
# 29. MultiQubitGate(Z, {1, 3})
#     core type: Operation
#     operator: 42
#     operands: 37
# 30. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 42
#     operands: 38
# 31. MultiQubitGate(Gate(X), {1, 2})
#     core type: Operation
#     operator: 42
#     operands: 39
# 32. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 42
#     operands: 40
# 33. Gate(--)
#     core type: Operation
#     operator: 56
#     operand: 50
# 34. MultiQubitGate(Gate(X), {2, 3})
#     core type: Operation
#     operator: 42
#     operands: 43
# 35. |psi〉
#     core type: Operation
#     operator: 44
#     operand: 53
# 36. (CONTROL, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 49, 47
# 37. (Z, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 38. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 49, 48
# 39. (Gate(X), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 51, 48
# 40. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 49, 52
# 41. (--)
#     core type: ExprTuple
#     sub-expressions: 50
# 42. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 43. (Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 51, 52
# 44. KET
#     core type: Literal
#     sub-expressions:
# 45. (psi)
#     core type: ExprTuple
#     sub-expressions: 53
# 46. Z
#     core type: Literal
#     sub-expressions:
# 47. {1, 3}
#     core type: Operation
#     operator: 58
#     operands: 54
# 48. {1, 2}
#     core type: Operation
#     operator: 58
#     operands: 55
# 49. CONTROL
#     core type: Literal
#     sub-expressions:
# 50. --
#     core type: Literal
#     sub-expressions:
# 51. Gate(X)
#     core type: Operation
#     operator: 56
#     operand: 61
# 52. {2, 3}
#     core type: Operation
#     operator: 58
#     operands: 59
# 53. psi
#     core type: Literal
#     sub-expressions:
# 54. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 60, 63
# 55. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 60, 62
# 56. GATE
#     core type: Literal
#     sub-expressions:
# 57. (X)
#     core type: ExprTuple
#     sub-expressions: 61
# 58. Set
#     core type: Literal
#     sub-expressions:
# 59. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 62, 63
# 60. 1
#     core type: Literal
#     sub-expressions:
# 61. X
#     core type: Literal
#     sub-expressions:
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. 3
#     core type: Literal
#     sub-expressions:
