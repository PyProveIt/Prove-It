# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a
from proveit.core_expr_types import Len
from proveit.numbers import DecimalSequence, one
from proveit.physics.quantum import CONTROL, Gate, I, X

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(X)
expr = ExprTuple(Len([CONTROL, I, CONTROL, I, sub_expr1, CONTROL, sub_expr1, CONTROL, I, sub_expr1, I]), Len([ExprRange(a, a, one, DecimalSequence(one, one))]))
# Out:
# expr: (|(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --)|, |(1, ..a.., 11)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}\right)|, |\left(1, \ldots, 11\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --)|, |(1, ..a.., 11)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..a.., 11)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..a.., 11))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --)
#    core type: ExprTuple
#    sub-expressions: 8, 10, 8, 10, 9, 8, 9, 8, 10, 9, 10
# 7. (1, ..a.., 11)
#    core type: ExprTuple
#    sub-expressions: 11
# 8. CONTROL
#    core type: Literal
#    sub-expressions:
# 9. Gate(X)
#    core type: Operation
# ...
