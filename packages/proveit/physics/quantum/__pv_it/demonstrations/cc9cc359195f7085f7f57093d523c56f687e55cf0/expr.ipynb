# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(one)
sub_expr3 = Set(two, three)
sub_expr4 = Set(three)
expr = Len([sub_expr1, sub_expr2, sub_expr1, sub_expr2, sub_expr1, sub_expr3, sub_expr1, sub_expr3, sub_expr4, sub_expr3, sub_expr4])
# Out:
# expr: |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3})|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(\left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}, \left\{3\right\}\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3})|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. (({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. ({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3})
#    core type: ExprTuple
#    sub-expressions: 5, 4, 5, 4, 5, 6, 5, 6, 7, 6, 7
# 4. {1}
#    core type: Operation
#    operator: 11
#    operand: 13
# 5. {1, 2}
#    core type: Operation
#    operator: 11
#    operands: 9
# 6. {2, 3}
#    core type: Operation
#    operator: 11
#    operands: 10
# 7. {3}
#    core type: Operation
#    operator: 11
#    operand: 15
# 8. (1)
#    core type: ExprTuple
#    sub-expressions: 13
# 9. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 13, 14
# 10. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 11. Set
#     core type: Literal
#     sub-expressions:
# 12. (3)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. 3
#     core type: Literal
#     sub-expressions:
