# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.physics.quantum import Gate, I, Input, Output, ket0, ket1, ket_minus, ket_plus
from proveit.physics.quantum.circuit import Circuit

# %%
# build up the expression from sub-expressions
expr = Circuit(ExprArray([Input(ket0), I, Output(ket_plus)], [Input(ket1), Gate(), Output(ket_minus)]))
# Out:
# expr:  Input(|0〉)  & --  & Output(|+〉)   \\
#    Input(|1〉)  & Gate([])  & Output(|-〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert 0 \rangle} & \qw & \rstick{\lvert + \rangle} \qw   \\
#   & \lstick{\lvert 1 \rangle} & \gate{[]} & \rstick{\lvert - \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|0〉)  & --  & Output(|+〉)   \\
#    Input(|1〉)  & Gate([])  & Output(|-〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|0〉) & -- & Output(|+〉)  \\
#   Input(|1〉) & Gate([]) & Output(|-〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|0〉) & -- & Output(|+〉)  \\
#   Input(|1〉) & Gate([]) & Output(|-〉)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (Input(|0〉), --, Output(|+〉))
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 5. (Input(|1〉), Gate([]), Output(|-〉))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 11
# 6. Input(|0〉)
#    core type: Operation
#    operator: 14
#    operand: 20
# 7. --
#    core type: Literal
#    sub-expressions:
# 8. Output(|+〉)
#    core type: Operation
#    operator: 18
#    operand: 21
# 9. Input(|1〉)
#    core type: Operation
#    operator: 14
#    operand: 22
# 10. Gate([])
#     core type: Operation
# ...
