# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, three
from proveit.physics.quantum import CONTROL, Gate, H, X
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(three, four)
expr = ExprTuple(Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, sub_expr1), sub_expr1), Gate(X))
# Out:
# expr: (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}), Gate(X))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\control \qw{\Big \{} \left\{3, 4\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Gate(H), MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4}), Gate(X))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. Gate(H)
#    core type: Operation
#    operator: 6
#    operand: 8
# 2. MultiQubitGate(MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#    core type: Operation
#    operator: 11
#    operands: 5
# 3. Gate(X)
#    core type: Operation
#    operator: 6
#    operand: 10
# 4. (H)
#    core type: ExprTuple
#    sub-expressions: 8
# 5. (MultiQubitGate(CONTROL, {3, 4}), {3, 4})
#    core type: ExprTuple
#    sub-expressions: 9, 14
# 6. GATE
#    core type: Literal
#    sub-expressions:
# 7. (X)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. H
#    core type: Literal
#    sub-expressions:
# 9. MultiQubitGate(CONTROL, {3, 4})
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. X
#     core type: Literal
#     sub-expressions:
# 11. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 12. (CONTROL, {3, 4})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. CONTROL
#     core type: Literal
#     sub-expressions:
# 14. {3, 4}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Set
#     core type: Literal
#     sub-expressions:
# 16. (3, 4)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 3
#     core type: Literal
#     sub-expressions:
# 18. 4
#     core type: Literal
#     sub-expressions:
