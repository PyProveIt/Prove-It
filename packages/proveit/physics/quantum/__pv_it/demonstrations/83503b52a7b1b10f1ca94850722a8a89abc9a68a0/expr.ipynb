# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, X, ket_psi
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Gate(I)
sub_expr3 = Gate(X)
sub_expr4 = Set(two, three)
sub_expr5 = Input(ket_psi)
sub_expr6 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr7 = Output(ket_psi)
sub_expr8 = MultiQubitGate(sub_expr3, sub_expr1)
sub_expr9 = MultiQubitGate(CONTROL, sub_expr4)
sub_expr10 = MultiQubitGate(sub_expr3, sub_expr4)
expr = ExprArray([sub_expr5, sub_expr6, sub_expr2, sub_expr6, sub_expr2, sub_expr7], [sub_expr5, sub_expr8, sub_expr9, sub_expr8, sub_expr9, sub_expr7], [sub_expr5, sub_expr2, sub_expr10, sub_expr2, sub_expr10, sub_expr7])
# Out:
# expr: Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cccccc}
#  \lstick{\lvert \psi \rangle} & \control \qw & \qw & \control \qw & \qw & \rstick{\lvert \psi \rangle} \qw  \\
#   \lstick{\lvert \psi \rangle} & \targ & \control \qw & \targ & \control \qw & \rstick{\lvert \psi \rangle} \qw  \\
#   \lstick{\lvert \psi \rangle} & \qw & \targ & \qw & \targ & \rstick{\lvert \psi \rangle} \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 2}), Gate(--), MultiQubitGate(CONTROL, {1, 2}), Gate(--), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 4, 8, 4, 8, 10
# 2. (Input(|psi〉), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 5, 6, 5, 6, 10
# 3. (Input(|psi〉), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9, 8, 9, 10
# 4. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 16
#    operands: 11
# 5. MultiQubitGate(Gate(X), {1, 2})
#    core type: Operation
#    operator: 16
#    operands: 12
# 6. MultiQubitGate(CONTROL, {2, 3})
#    core type: Operation
#    operator: 16
#    operands: 13
# 7. Input(|psi〉)
#    core type: Operation
#    operator: 14
#    operand: 25
# 8. Gate(--)
#    core type: Operation
#    operator: 27
#    operand: 22
# 9. MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 16
#    operands: 17
# 10. Output(|psi〉)
#     core type: Operation
#     operator: 18
#     operand: 25
# 11. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 21, 20
# 12. (Gate(X), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 23, 20
# 13. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 21, 24
# 14. INPUT
#     core type: Literal
#     sub-expressions:
# 15. (--)
#     core type: ExprTuple
#     sub-expressions: 22
# 16. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 17. (Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 18. OUTPUT
#     core type: Literal
#     sub-expressions:
# 19. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 25
# 20. {1, 2}
#     core type: Operation
#     operator: 29
#     operands: 26
# 21. CONTROL
#     core type: Literal
#     sub-expressions:
# 22. --
#     core type: Literal
#     sub-expressions:
# 23. Gate(X)
#     core type: Operation
#     operator: 27
#     operand: 34
# 24. {2, 3}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. |psi〉
#     core type: Operation
#     operator: 31
#     operand: 37
# 26. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 33, 35
# 27. GATE
#     core type: Literal
#     sub-expressions:
# 28. (X)
#     core type: ExprTuple
#     sub-expressions: 34
# 29. Set
#     core type: Literal
#     sub-expressions:
# 30. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 31. KET
#     core type: Literal
#     sub-expressions:
# 32. (psi)
#     core type: ExprTuple
#     sub-expressions: 37
# 33. 1
#     core type: Literal
#     sub-expressions:
# 34. X
#     core type: Literal
#     sub-expressions:
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. 3
#     core type: Literal
#     sub-expressions:
# 37. psi
#     core type: Literal
#     sub-expressions:
