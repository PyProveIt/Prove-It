# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import four, one, seven, six, three, two
from proveit.physics.quantum import CONTROL, I, Input, Output, X, Z, ket0, ket1
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two, three)
sub_expr2 = Input(ket0)
sub_expr3 = Output(ket0)
sub_expr4 = Input(ket1)
sub_expr5 = Output(ket1)
sub_expr6 = [sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3]
sub_expr7 = [sub_expr4, MultiQubitGate(X, Set(four, six)), sub_expr5]
expr = ExprArray(sub_expr6, sub_expr6, [sub_expr2, MultiQubitGate(Z, sub_expr1), sub_expr3], sub_expr7, [sub_expr2, I, sub_expr3], sub_expr7, [sub_expr4, MultiQubitGate(Z, Set(seven)), sub_expr5])
# Out:
# expr: Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|0〉) & -- & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7}) & Output(|1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {ccc}
#  \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & \control \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & Z & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & X & \rstick{\lvert 1 \rangle} \qw  \\
#   \lstick{\lvert 0 \rangle} & \qw & \rstick{\lvert 0 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & X & \rstick{\lvert 1 \rangle} \qw  \\
#   \lstick{\lvert 1 \rangle} & Z & \rstick{\lvert 1 \rangle} \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(CONTROL, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|0〉) & MultiQubitGate(Z, {1, 2, 3}) & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|0〉) & -- & Output(|0〉)  \\
#   Input(|1〉) & MultiQubitGate(X, {4, 6}) & Output(|1〉)  \\
#   Input(|1〉) & MultiQubitGate(Z, {7}) & Output(|1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 1, 2, 4, 3, 4, 5
# 1. (Input(|0〉), MultiQubitGate(CONTROL, {1, 2, 3}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 6, 10
# 2. (Input(|0〉), MultiQubitGate(Z, {1, 2, 3}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 7, 10
# 3. (Input(|0〉), --, Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10
# 4. (Input(|1〉), MultiQubitGate(X, {4, 6}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 12, 11, 14
# 5. (Input(|1〉), MultiQubitGate(Z, {7}), Output(|1〉))
#    core type: ExprTuple
#    sub-expressions: 12, 13, 14
# 6. MultiQubitGate(CONTROL, {1, 2, 3})
#    core type: Operation
#    operator: 20
#    operands: 15
# 7. MultiQubitGate(Z, {1, 2, 3})
#    core type: Operation
#    operator: 20
#    operands: 16
# 8. Input(|0〉)
#    core type: Operation
#    operator: 19
#    operand: 26
# 9. --
#    core type: Literal
#    sub-expressions:
# 10. Output(|0〉)
#     core type: Operation
#     operator: 22
#     operand: 26
# 11. MultiQubitGate(X, {4, 6})
#     core type: Operation
#     operator: 20
#     operands: 18
# 12. Input(|1〉)
#     core type: Operation
#     operator: 19
#     operand: 31
# 13. MultiQubitGate(Z, {7})
#     core type: Operation
#     operator: 20
#     operands: 21
# 14. Output(|1〉)
#     core type: Operation
#     operator: 22
#     operand: 31
# 15. (CONTROL, {1, 2, 3})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 16. (Z, {1, 2, 3})
#     core type: ExprTuple
#     sub-expressions: 29, 25
# 17. (|0〉)
#     core type: ExprTuple
#     sub-expressions: 26
# 18. (X, {4, 6})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 19. INPUT
#     core type: Literal
#     sub-expressions:
# 20. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 21. (Z, {7})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 22. OUTPUT
#     core type: Literal
#     sub-expressions:
# 23. (|1〉)
#     core type: ExprTuple
#     sub-expressions: 31
# 24. CONTROL
#     core type: Literal
#     sub-expressions:
# 25. {1, 2, 3}
#     core type: Operation
#     operator: 35
#     operands: 32
# 26. |0〉
#     core type: Operation
#     operator: 37
#     operand: 41
# 27. X
#     core type: Literal
#     sub-expressions:
# 28. {4, 6}
#     core type: Operation
#     operator: 35
#     operands: 34
# 29. Z
#     core type: Literal
#     sub-expressions:
# 30. {7}
#     core type: Operation
#     operator: 35
#     operand: 44
# 31. |1〉
#     core type: Operation
#     operator: 37
#     operand: 45
# 32. (1, 2, 3)
#     core type: ExprTuple
#     sub-expressions: 45, 39, 40
# 33. (0)
#     core type: ExprTuple
#     sub-expressions: 41
# 34. (4, 6)
#     core type: ExprTuple
#     sub-expressions: 42, 43
# 35. Set
#     core type: Literal
#     sub-expressions:
# 36. (7)
#     core type: ExprTuple
#     sub-expressions: 44
# 37. KET
#     core type: Literal
#     sub-expressions:
# 38. (1)
#     core type: ExprTuple
#     sub-expressions: 45
# 39. 2
#     core type: Literal
#     sub-expressions:
# 40. 3
#     core type: Literal
#     sub-expressions:
# 41. 0
#     core type: Literal
#     sub-expressions:
# 42. 4
#     core type: Literal
#     sub-expressions:
# 43. 6
#     core type: Literal
#     sub-expressions:
# 44. 7
#     core type: Literal
#     sub-expressions:
# 45. 1
#     core type: Literal
#     sub-expressions:
