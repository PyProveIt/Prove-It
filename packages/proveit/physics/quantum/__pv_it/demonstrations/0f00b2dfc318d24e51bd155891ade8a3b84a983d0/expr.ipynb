# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.MultiQubitGate.html">MultiQubitGate</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
expr = MultiQubitGate(MultiQubitGate(CONTROL, sub_expr1), sub_expr1)
# Out:
# expr: MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\control \qw{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: representation
# description: 'implicit' representation displays X gates as a target, while 'explicit' representation always displays the type of gate in a box. Ex. |X|. 'Block' displays the MultiQubitGate as a block gate assuming all other gates within the MultiQubitGate are the same.
# default: explicit
# current value: explicit
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. MultiQubitGate(MultiQubitGate(CONTROL, {1, 2}), {1, 2})
#    core type: Operation
#    operator: 3
#    operands: 1
# 1. (MultiQubitGate(CONTROL, {1, 2}), {1, 2})
#    core type: ExprTuple
#    sub-expressions: 2, 6
# 2. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 4. (CONTROL, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. CONTROL
#    core type: Literal
#    sub-expressions:
# 6. {1, 2}
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. Set
#    core type: Literal
#    sub-expressions:
# 8. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. 2
#     core type: Literal
#     sub-expressions:
