# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
expr = ExprTuple([sub_expr1, sub_expr1, sub_expr2, sub_expr2])
# Out:
# expr: (({1, 2}, {1, 2}, {3, 4}, {3, 4}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\left\{1, 2\right\}, \left\{1, 2\right\}, \left\{3, 4\right\}, \left\{3, 4\right\}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (({1, 2}, {1, 2}, {3, 4}, {3, 4}))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. ({1, 2}, {1, 2}, {3, 4}, {3, 4})
#    core type: ExprTuple
#    sub-expressions: 2, 2, 3, 3
# 2. {1, 2}
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. {3, 4}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (1, 2)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. Set
#    core type: Literal
#    sub-expressions:
# 6. (3, 4)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. 2
#    core type: Literal
#    sub-expressions:
# 9. 3
#    core type: Literal
#    sub-expressions:
# 10. 4
#     core type: Literal
#     sub-expressions:
