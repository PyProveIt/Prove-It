# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import four, one, three, two
from proveit.physics.quantum import CONTROL, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(three, four)
expr = ExprTuple([MultiQubitGate(Z, sub_expr1), MultiQubitGate(CONTROL, sub_expr1), MultiQubitGate(Z, sub_expr2), MultiQubitGate(CONTROL, sub_expr2)])
# Out:
# expr: ((MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{1, 2\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z{\Big \{} \left\{3, 4\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw
# } \hspace{2em}\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (MultiQubitGate(Z, {1, 2}), MultiQubitGate(CONTROL, {1, 2}), MultiQubitGate(Z, {3, 4}), MultiQubitGate(CONTROL, {3, 4}))
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5
# 2. MultiQubitGate(Z, {1, 2})
#    core type: Operation
#    operator: 9
#    operands: 6
# 3. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 9
#    operands: 7
# 4. MultiQubitGate(Z, {3, 4})
#    core type: Operation
#    operator: 9
#    operands: 8
# 5. MultiQubitGate(CONTROL, {3, 4})
#    core type: Operation
#    operator: 9
#    operands: 10
# 6. (Z, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 12, 11
# 7. (CONTROL, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 13, 11
# 8. (Z, {3, 4})
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 9. MULTI_QUBIT_GATE
# ...
