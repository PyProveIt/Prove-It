# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.core_expr_types import Len
from proveit.numbers import Add, DecimalSequence, one
from proveit.physics.quantum import CONTROL, Gate, I, X

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(X)
expr = ExprTuple(Len([CONTROL, I, CONTROL, I, sub_expr1, CONTROL, sub_expr1, CONTROL, I, sub_expr1, I, sub_expr1]), Add(DecimalSequence(one, one), one))
# Out:
# expr: (|(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --, Gate(X))|, 11 + 1)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, CONTROL, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \targ
# } \hspace{2em}\right)|, 11 + 1\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --, Gate(X))|, 11 + 1)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --, Gate(X))|
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. 11 + 1
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. ((CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --, Gate(X)))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (11, 1)
#    core type: ExprTuple
#    sub-expressions: 8, 16
# 7. (CONTROL, --, CONTROL, --, Gate(X), CONTROL, Gate(X), CONTROL, --, Gate(X), --, Gate(X))
#    core type: ExprTuple
#    sub-expressions: 9, 10, 9, 10, 11, 9, 11, 9, 10, 11, 10, 11
# 8. 11
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. CONTROL
# ...
