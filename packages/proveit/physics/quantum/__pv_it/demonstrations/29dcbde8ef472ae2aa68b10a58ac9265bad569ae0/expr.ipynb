# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, X
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Gate(I)
sub_expr3 = Gate(X)
sub_expr4 = Set(two, three)
sub_expr5 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr6 = MultiQubitGate(sub_expr3, sub_expr1)
sub_expr7 = MultiQubitGate(CONTROL, sub_expr4)
sub_expr8 = MultiQubitGate(sub_expr3, sub_expr4)
expr = Circuit(ExprArray([sub_expr5, sub_expr2, sub_expr5, sub_expr2], [sub_expr6, sub_expr7, sub_expr6, sub_expr7], [sub_expr2, sub_expr8, sub_expr2, sub_expr8]))
# Out:
# expr:  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1] & \qw & \control \qw \qwx[1] & \qw   \\
#   & \targ & \control \qw \qwx[1] & \targ & \control \qw \qwx[1]   \\
#   & \qw & \targ & \qw & \targ
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
# ...
