# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, D, ExprArray, ExprRange, ExprTuple, IndexedVar, i, j, k, m, n, p
from proveit.core_expr_types.expr_arrays import Aij, Cij, Eij, Rij
from proveit.logic import Set
from proveit.numbers import Add, one, two
from proveit.physics.quantum import Gate
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(Add(m, one), Add(m, k, two))
expr = ExprTuple(ExprArray(ExprRange(i, [ExprRange(j, Gate(Aij), one, n)], one, m), [ExprRange(j, MultiQubitGate(IndexedVar(B, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, MultiQubitGate(Cij, Rij), one, n)], one, k), [ExprRange(j, MultiQubitGate(IndexedVar(D, j), sub_expr1), one, n)], ExprRange(i, [ExprRange(j, Gate(Eij), one, n)], one, p)))
# Out:
# expr: ((Gate(A_{1, 1}) & ..Gate(A_{1, j}).. & Gate(A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{i, 1}) & ..Gate(A_{i, j}).. & Gate(A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{m, 1}) & ..Gate(A_{m, j}).. & Gate(A_{m, n})  \\
#   MultiQubitGate(B_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(B_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})  \\
#   MultiQubitGate(D_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(D_{n}, {m + 1, m + k + 2})  \\
#   Gate(E_{1, 1}) & ..Gate(E_{1, j}).. & Gate(E_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{i, 1}) & ..Gate(E_{i, j}).. & Gate(E_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{p, 1}) & ..Gate(E_{p, j}).. & Gate(E_{p, n})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \gate{A_{1, 1}} & \cdots & \gate{A_{1, n}}  \\
#   \vdots & \gate{A_{i, j}} & \vdots  \\
#   \gate{A_{m, 1}} & \cdots & \gate{A_{m, n}}  \\
#   \gate{B_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \cdots & \gate{B_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}  \\
#   \gate{C_{1, 1}{\Big \{} R_{1, 1}} & \cdots & \gate{C_{1, n}{\Big \{} R_{1, n}}  \\
#   \vdots & \gate{C_{i, j}{\Big \{} R_{i, j}} & \vdots  \\
#   \gate{C_{k, 1}{\Big \{} R_{k, 1}} & \cdots & \gate{C_{k, n}{\Big \{} R_{k, n}}  \\
#   \gate{D_{1}{\Big \{} \left\{m + 1, m + k + 2\right\}} & \cdots & \gate{D_{n}{\Big \{} \left\{m + 1, m + k + 2\right\}}  \\
#   \gate{E_{1, 1}} & \cdots & \gate{E_{1, n}}  \\
#   \vdots & \gate{E_{i, j}} & \vdots  \\
#   \gate{E_{p, 1}} & \cdots & \gate{E_{p, n}} \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Gate(A_{1, 1}) & ..Gate(A_{1, j}).. & Gate(A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{i, 1}) & ..Gate(A_{i, j}).. & Gate(A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{m, 1}) & ..Gate(A_{m, j}).. & Gate(A_{m, n})  \\
#   MultiQubitGate(B_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(B_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})  \\
#   MultiQubitGate(D_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(D_{n}, {m + 1, m + k + 2})  \\
#   Gate(E_{1, 1}) & ..Gate(E_{1, j}).. & Gate(E_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{i, 1}) & ..Gate(E_{i, j}).. & Gate(E_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{p, 1}) & ..Gate(E_{p, j}).. & Gate(E_{p, n})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Gate(A_{1, 1}) & ..Gate(A_{1, j}).. & Gate(A_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{i, 1}) & ..Gate(A_{i, j}).. & Gate(A_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(A_{m, 1}) & ..Gate(A_{m, j}).. & Gate(A_{m, n})  \\
#   MultiQubitGate(B_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(B_{n}, {m + 1, m + k + 2})  \\
#   MultiQubitGate(C_{1, 1}, R_{1, 1}) & ..MultiQubitGate(C_{1, j}, R_{1, j}).. & MultiQubitGate(C_{1, n}, R_{1, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{i, 1}, R_{i, 1}) & ..MultiQubitGate(C_{i, j}, R_{i, j}).. & MultiQubitGate(C_{i, n}, R_{i, n})  \\
#   \colon & \colon & \colon  \\
#   MultiQubitGate(C_{k, 1}, R_{k, 1}) & ..MultiQubitGate(C_{k, j}, R_{k, j}).. & MultiQubitGate(C_{k, n}, R_{k, n})  \\
#   MultiQubitGate(D_{1}, {m + 1, m + k + 2}) & ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).. & MultiQubitGate(D_{n}, {m + 1, m + k + 2})  \\
#   Gate(E_{1, 1}) & ..Gate(E_{1, j}).. & Gate(E_{1, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{i, 1}) & ..Gate(E_{i, j}).. & Gate(E_{i, n})  \\
#   \colon & \colon & \colon  \\
#   Gate(E_{p, 1}) & ..Gate(E_{p, j}).. & Gate(E_{p, n})
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4, 5, 6
# 2. (Gate(A_{1, 1}), ..Gate(A_{1, j}).., Gate(A_{1, n})), ..(Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n})).., (Gate(A_{m, 1}), ..Gate(A_{m, j}).., Gate(A_{m, n}))
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 59
#    end_index: 60
# 3. (MultiQubitGate(B_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).., MultiQubitGate(B_{n}, {m + 1, m + k + 2}))
#    core type: ExprTuple
#    sub-expressions: 8
# 4. (MultiQubitGate(C_{1, 1}, R_{1, 1}), ..MultiQubitGate(C_{1, j}, R_{1, j}).., MultiQubitGate(C_{1, n}, R_{1, n})), ..(MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})).., (MultiQubitGate(C_{k, 1}, R_{k, 1}), ..MultiQubitGate(C_{k, j}, R_{k, j}).., MultiQubitGate(C_{k, n}, R_{k, n}))
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 59
#    end_index: 61
# 5. (MultiQubitGate(D_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).., MultiQubitGate(D_{n}, {m + 1, m + k + 2}))
#    core type: ExprTuple
#    sub-expressions: 10
# 6. (Gate(E_{1, 1}), ..Gate(E_{1, j}).., Gate(E_{1, n})), ..(Gate(E_{i, 1}), ..Gate(E_{i, j}).., Gate(E_{i, n})).., (Gate(E_{p, 1}), ..Gate(E_{p, j}).., Gate(E_{p, n}))
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 59
#    end_index: 12
# 7. i -> (Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n}))
#    core type: Lambda
#    parameter: 63
#    body: 13
# 8. MultiQubitGate(B_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(B_{j}, {m + 1, m + k + 2}).., MultiQubitGate(B_{n}, {m + 1, m + k + 2})
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 59
#    end_index: 28
# 9. i -> (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#    core type: Lambda
#    parameter: 63
#    body: 15
# 10. MultiQubitGate(D_{1}, {m + 1, m + k + 2}), ..MultiQubitGate(D_{j}, {m + 1, m + k + 2}).., MultiQubitGate(D_{n}, {m + 1, m + k + 2})
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 59
#     end_index: 28
# 11. i -> (Gate(E_{i, 1}), ..Gate(E_{i, j}).., Gate(E_{i, n}))
#     core type: Lambda
#     parameter: 63
#     body: 17
# 12. p
#     core type: Variable
#     sub-expressions:
# 13. (Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 18
# 14. j -> MultiQubitGate(B_{j}, {m + 1, m + k + 2})
#     core type: Lambda
#     parameter: 64
#     body: 19
# 15. (MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 20
# 16. j -> MultiQubitGate(D_{j}, {m + 1, m + k + 2})
#     core type: Lambda
#     parameter: 64
#     body: 21
# 17. (Gate(E_{i, 1}), ..Gate(E_{i, j}).., Gate(E_{i, n}))
#     core type: ExprTuple
#     sub-expressions: 22
# 18. Gate(A_{i, 1}), ..Gate(A_{i, j}).., Gate(A_{i, n})
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 59
#     end_index: 28
# 19. MultiQubitGate(B_{j}, {m + 1, m + k + 2})
#     core type: Operation
#     operator: 37
#     operands: 24
# 20. MultiQubitGate(C_{i, 1}, R_{i, 1}), ..MultiQubitGate(C_{i, j}, R_{i, j}).., MultiQubitGate(C_{i, n}, R_{i, n})
#     core type: ExprRange
#     lambda_map: 25
#     start_index: 59
#     end_index: 28
# 21. MultiQubitGate(D_{j}, {m + 1, m + k + 2})
#     core type: Operation
#     operator: 37
#     operands: 26
# 22. Gate(E_{i, 1}), ..Gate(E_{i, j}).., Gate(E_{i, n})
#     core type: ExprRange
#     lambda_map: 27
#     start_index: 59
#     end_index: 28
# 23. j -> Gate(A_{i, j})
#     core type: Lambda
#     parameter: 64
#     body: 29
# 24. (B_{j}, {m + 1, m + k + 2})
#     core type: ExprTuple
#     sub-expressions: 30, 33
# 25. j -> MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Lambda
#     parameter: 64
#     body: 31
# 26. (D_{j}, {m + 1, m + k + 2})
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 27. j -> Gate(E_{i, j})
#     core type: Lambda
#     parameter: 64
#     body: 34
# 28. n
#     core type: Variable
#     sub-expressions:
# 29. Gate(A_{i, j})
#     core type: Operation
#     operator: 43
#     operand: 45
# 30. B_{j}
#     core type: IndexedVar
# variable: 36
# index: 64
# 31. MultiQubitGate(C_{i, j}, R_{i, j})
#     core type: Operation
#     operator: 37
#     operands: 38
# 32. D_{j}
#     core type: IndexedVar
# variable: 39
# index: 64
# 33. {m + 1, m + k + 2}
#     core type: Operation
#     operator: 41
#     operands: 42
# 34. Gate(E_{i, j})
#     core type: Operation
#     operator: 43
#     operand: 50
# 35. (A_{i, j})
#     core type: ExprTuple
#     sub-expressions: 45
# 36. B
#     core type: Variable
#     sub-expressions:
# 37. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 38. (C_{i, j}, R_{i, j})
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 39. D
#     core type: Variable
#     sub-expressions:
# 40. (j)
#     core type: ExprTuple
#     sub-expressions: 64
# 41. Set
#     core type: Literal
#     sub-expressions:
# 42. (m + 1, m + k + 2)
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 43. GATE
#     core type: Literal
#     sub-expressions:
# 44. (E_{i, j})
#     core type: ExprTuple
#     sub-expressions: 50
# 45. A_{i, j}
#     core type: IndexedVar
# variable: 51
# indices: 58
# 46. C_{i, j}
#     core type: IndexedVar
# variable: 52
# indices: 58
# 47. R_{i, j}
#     core type: IndexedVar
# variable: 53
# indices: 58
# 48. m + 1
#     core type: Operation
#     operator: 55
#     operands: 54
# 49. m + k + 2
#     core type: Operation
#     operator: 55
#     operands: 56
# 50. E_{i, j}
#     core type: IndexedVar
# variable: 57
# indices: 58
# 51. A
#     core type: Variable
#     sub-expressions:
# 52. C
#     core type: Variable
#     sub-expressions:
# 53. R
#     core type: Variable
#     sub-expressions:
# 54. (m, 1)
#     core type: ExprTuple
#     sub-expressions: 60, 59
# 55. +
#     core type: Literal
#     sub-expressions:
# 56. (m, k, 2)
#     core type: ExprTuple
#     sub-expressions: 60, 61, 62
# 57. E
#     core type: Variable
#     sub-expressions:
# 58. (i, j)
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 59. 1
#     core type: Literal
#     sub-expressions:
# 60. m
#     core type: Variable
#     sub-expressions:
# 61. k
#     core type: Variable
#     sub-expressions:
# 62. 2
#     core type: Literal
#     sub-expressions:
# 63. i
#     core type: Variable
#     sub-expressions:
# 64. j
#     core type: Variable
#     sub-expressions:
