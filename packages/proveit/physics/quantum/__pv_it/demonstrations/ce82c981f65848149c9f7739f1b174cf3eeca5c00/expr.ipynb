# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import Set
from proveit.numbers import one, three
from proveit.physics.quantum import CONTROL, Gate, I, Z
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
expr = ExprTuple(ExprArray([MultiQubitGate(CONTROL, sub_expr1)], [Gate(I)], [MultiQubitGate(Z, sub_expr1)]))
# Out:
# expr: ((MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {c}
#  \control \qw  \\
#   \qw  \\
#   Z \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})
#    core type: ExprTuple
#    sub-expressions: 2, 3, 4
# 2. (MultiQubitGate(CONTROL, {1, 3}))
#    core type: ExprTuple
#    sub-expressions: 5
# 3. (Gate(--))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. (MultiQubitGate(Z, {1, 3}))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. MultiQubitGate(CONTROL, {1, 3})
#    core type: Operation
#    operator: 11
#    operands: 8
# 6. Gate(--)
#    core type: Operation
#    operator: 9
#    operand: 14
# 7. MultiQubitGate(Z, {1, 3})
#    core type: Operation
#    operator: 11
#    operands: 12
# 8. (CONTROL, {1, 3})
#    core type: ExprTuple
#    sub-expressions: 13, 16
# 9. GATE
#    core type: Literal
#    sub-expressions:
# 10. (--)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 12. (Z, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. CONTROL
#     core type: Literal
#     sub-expressions:
# 14. --
#     core type: Literal
#     sub-expressions:
# 15. Z
#     core type: Literal
#     sub-expressions:
# 16. {1, 3}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Set
#     core type: Literal
#     sub-expressions:
# 18. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. 1
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
