# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprArray.html">ExprArray</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import I, Input, ket_psi
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [Input(ket_psi), MultiQubitGate(I, Set(one, two))]
expr = ExprArray(sub_expr1, sub_expr1)
# Out:
# expr: Input(|psi〉) & MultiQubitGate(--, {1, 2})  \\
#   Input(|psi〉) & MultiQubitGate(--, {1, 2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \begin{array} {cc}
#  \lstick{\lvert \psi \rangle} & \qw  \\
#   \lstick{\lvert \psi \rangle} & \qw \end{array}

# %%
expr.style_options()
# Out:
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: with_justification
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Input(|psi〉) & MultiQubitGate(--, {1, 2})  \\
#   Input(|psi〉) & MultiQubitGate(--, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 1, 1
# 1. (Input(|psi〉), MultiQubitGate([I], {1, 2}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Input(|psi〉)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. MultiQubitGate([I], {1, 2})
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. INPUT
#    core type: Literal
#    sub-expressions:
# 5. (|psi〉)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 7. (--, {1, 2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. |psi〉
#    core type: Operation
#    operator: 11
#    operand: 15
# 9. --
#    core type: Literal
#    sub-expressions:
# 10. {1, 2}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. (psi)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. psi
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. 2
#     core type: Literal
#     sub-expressions:
