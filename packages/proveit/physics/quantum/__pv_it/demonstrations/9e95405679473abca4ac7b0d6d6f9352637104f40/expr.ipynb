# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket_psi
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Input(ket_psi)
sub_expr3 = Output(ket_psi)
expr = Circuit(ExprArray([sub_expr2, MultiQubitGate(Z, sub_expr1), sub_expr3], [sub_expr2, MultiQubitGate(CONTROL, sub_expr1), sub_expr3]))
# Out:
# expr:  Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \control \qw & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|psi〉) & MultiQubitGate(Z, {1, 2}) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|psi〉) & MultiQubitGate(Z, {1, 2}) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(CONTROL, {1, 2}) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (Input(|psi〉), MultiQubitGate(Z, {1, 2}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 6, 9
# 5. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 2}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. MultiQubitGate(Z, {1, 2})
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. Input(|psi〉)
#    core type: Operation
#    operator: 11
#    operand: 19
# 8. MultiQubitGate(CONTROL, {1, 2})
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. Output(|psi〉)
#    core type: Operation
#    operator: 14
#    operand: 19
# 10. (Z, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 11. INPUT
#     core type: Literal
#     sub-expressions:
# 12. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 13. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. OUTPUT
#     core type: Literal
#     sub-expressions:
# 15. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. Z
#     core type: Literal
#     sub-expressions:
# 17. CONTROL
#     core type: Literal
#     sub-expressions:
# 18. {1, 2}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. |psi〉
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. Set
#     core type: Literal
#     sub-expressions:
# 21. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. KET
#     core type: Literal
#     sub-expressions:
# 23. (psi)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. 2
#     core type: Literal
#     sub-expressions:
# 26. psi
#     core type: Literal
#     sub-expressions:
