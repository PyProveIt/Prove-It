# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import And, Set
from proveit.numbers import one, two
from proveit.physics.quantum import CONTROL, Input, Output, Z, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr3 = MultiQubitGate(Z, sub_expr1)
sub_expr4 = Input(ket_psi)
sub_expr5 = Output(ket_psi)
sub_expr6 = [sub_expr2]
sub_expr7 = [sub_expr3]
sub_expr8 = [sub_expr4, sub_expr2, sub_expr5]
sub_expr9 = [sub_expr4, sub_expr3, sub_expr5]
expr = ExprTuple(And(CircuitEquiv(Circuit(ExprArray(sub_expr6, sub_expr7)), Circuit(ExprArray(sub_expr7, sub_expr6))), Circuit(ExprArray(sub_expr8, sub_expr9))), Circuit(ExprArray(sub_expr9, sub_expr8)))
# Out:
# expr: (( MultiQubitGate(CONTROL, {1, 2})   \\
#    MultiQubitGate(Z, {1, 2}) equiv  MultiQubitGate(Z, {1, 2})   \\
#    MultiQubitGate(CONTROL, {1, 2})) and  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉),  Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1]   \\
#   & \gate{Z}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z} \qwx[1]   \\
#   & \control \qw
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \control \qw \qwx[1] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \gate{Z} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \gate{Z} \qwx[1] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \control \qw & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (( MultiQubitGate(CONTROL, {1, 2})   \\
#    MultiQubitGate(Z, {1, 2}) equiv  MultiQubitGate(Z, {1, 2})   \\
#    MultiQubitGate(CONTROL, {1, 2})) and  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉),  Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ( MultiQubitGate(CONTROL, {1, 2})   \\
#    MultiQubitGate(Z, {1, 2}) equiv  MultiQubitGate(Z, {1, 2})   \\
#    MultiQubitGate(CONTROL, {1, 2})) and  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2.  Input(|psi〉)  & MultiQubitGate(Z, {1, 2})  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 2})  & Output(|psi〉)
#    core type: Operation
# ...
