# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple, n
from proveit.physics.quantum import Input, Output, ket_psi
from proveit.physics.quantum.circuit import MultiWire

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprArray([Input(ket_psi), MultiWire(n), Output(ket_psi)]))
# Out:
# expr: ((Input(|psi〉) & MultiWire(n) & Output(|psi〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\begin{array} {ccc}
#  \lstick{\lvert \psi \rangle} & { /^{n} } \qw & \rstick{\lvert \psi \rangle} \qw \end{array}
# \right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((Input(|psi〉) & MultiWire(n) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. Input(|psi〉) & MultiWire(n) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (Input(|psi〉), MultiWire(n), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. Input(|psi〉)
#    core type: Operation
#    operator: 6
#    operand: 12
# 4. MultiWire(n)
#    core type: Operation
#    operator: 7
#    operand: 11
# 5. Output(|psi〉)
#    core type: Operation
#    operator: 9
#    operand: 12
# 6. INPUT
#    core type: Literal
#    sub-expressions:
# 7. MULTI_WIRE
#    core type: Literal
#    sub-expressions:
# 8. (n)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. OUTPUT
#    core type: Literal
#    sub-expressions:
# 10. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. n
#     core type: Variable
#     sub-expressions:
# 12. |psi〉
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. KET
# ...
