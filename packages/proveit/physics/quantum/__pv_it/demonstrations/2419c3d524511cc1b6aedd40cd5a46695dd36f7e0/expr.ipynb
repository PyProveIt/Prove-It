# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.core_expr_types.Len.html">Len</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Lambda, Variable, a
from proveit.core_expr_types import Len
from proveit.numbers import four, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_b", latex_format = r"{_{-}b}")
expr = Len([ExprRange(a, Lambda(sub_expr1, [a, sub_expr1]), one, four)])
# Out:
# expr: |(_b -> (1, _b), .._b -> (a, _b).., _b -> (4, _b))|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left({_{-}b} \mapsto \left(1, {_{-}b}\right), \ldots, {_{-}b} \mapsto \left(4, {_{-}b}\right)\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: function
# current value: function
# related methods: ()

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(_b -> (1, _b), .._b -> (a, _b).., _b -> (4, _b))|
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. length
#    core type: Literal
#    sub-expressions:
# 2. ((_b -> (1, _b), .._b -> (a, _b).., _b -> (4, _b)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (_b -> (1, _b), .._b -> (a, _b).., _b -> (4, _b))
#    core type: ExprTuple
#    sub-expressions: 4
# 4. [_b -> (1, _b)], ..[_b -> (a, _b)].., [_b -> (4, _b)]
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 5. a -> [_b -> (a, _b)]
#    core type: Lambda
#    parameter: 10
#    body: 8
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. 4
#    core type: Literal
#    sub-expressions:
# 8. _b -> (a, _b)
#    core type: Lambda
#    parameter: 11
#    body: 9
# 9. (a, _b)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. a
#     core type: Variable
#     sub-expressions:
# 11. _b
#     core type: Variable
#     sub-expressions:
