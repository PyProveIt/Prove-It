# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.logic import And
from proveit.physics.quantum import Gate, H, I, Input, Output, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Gate(I)
sub_expr3 = Input(ket_psi)
sub_expr4 = Output(ket_psi)
expr = ExprTuple(And(CircuitEquiv(Circuit(ExprArray([sub_expr1, sub_expr1])), Circuit(ExprArray([sub_expr2]))), Circuit(ExprArray([sub_expr3, sub_expr1, sub_expr1, sub_expr4]))), Circuit(ExprArray([sub_expr3, sub_expr2, sub_expr4])))
# Out:
# expr: (( Gate(H)  & Gate(H) equiv  Gate(--)) and  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉),  Input(|psi〉)  & Gate(--)  & Output(|psi〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{H}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \gate{H} & \gate{H} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \qw & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (( Gate(H)  & Gate(H) equiv  Gate(--)) and  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉),  Input(|psi〉)  & Gate(--)  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. ( Gate(H)  & Gate(H) equiv  Gate(--)) and  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉)
#    core type: Operation
#    operator: 3
#    operands: 4
# 2.  Input(|psi〉)  & Gate(--)  & Output(|psi〉)
#    core type: Operation
#    operator: 17
#    operand: 8
# 3. and
#    core type: Literal
#    sub-expressions:
# 4. ( Gate(H)  & Gate(H) equiv  Gate(--),  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. ((Input(|psi〉) & Gate(--) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 8
# 6.  Gate(H)  & Gate(H) equiv  Gate(--)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7.  Input(|psi〉)  & Gate(H)  & Gate(H)  & Output(|psi〉)
#    core type: Operation
#    operator: 17
#    operand: 15
# ...
