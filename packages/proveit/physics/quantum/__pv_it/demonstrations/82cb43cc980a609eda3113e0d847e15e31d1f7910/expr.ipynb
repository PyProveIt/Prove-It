# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import And, Set
from proveit.numbers import one, three, two
from proveit.physics.quantum import CONTROL, Gate, I, Input, Output, X, Z, ket_psi
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, three)
sub_expr2 = Gate(I)
sub_expr3 = Set(one, two)
sub_expr4 = Gate(X)
sub_expr5 = Set(two, three)
sub_expr6 = MultiQubitGate(CONTROL, sub_expr1)
sub_expr7 = MultiQubitGate(Z, sub_expr1)
sub_expr8 = MultiQubitGate(CONTROL, sub_expr3)
sub_expr9 = MultiQubitGate(sub_expr4, sub_expr3)
sub_expr10 = MultiQubitGate(CONTROL, sub_expr5)
sub_expr11 = MultiQubitGate(sub_expr4, sub_expr5)
sub_expr12 = Input(ket_psi)
sub_expr13 = Output(ket_psi)
expr = And(CircuitEquiv(Circuit(ExprArray([sub_expr6], [sub_expr2], [sub_expr7])), Circuit(ExprArray([sub_expr8, sub_expr2, sub_expr8, sub_expr2], [sub_expr9, sub_expr10, sub_expr9, sub_expr10], [sub_expr2, sub_expr11, sub_expr2, sub_expr11]))), Circuit(ExprArray([sub_expr12, sub_expr6, sub_expr13], [sub_expr12, sub_expr2, sub_expr13], [sub_expr12, sub_expr7, sub_expr13])))
# Out:
# expr: ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})) and  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[2]   \\
#   & \qw   \\
#   & \gate{Z}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \control \qw \qwx[1] & \qw & \control \qw \qwx[1] & \qw   \\
#   & \targ & \control \qw \qwx[1] & \targ & \control \qw \qwx[1]   \\
#   & \qw & \targ & \qw & \targ
# } \hspace{2em}\right) \land \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \control \qw \qwx[2] & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \qw & \rstick{\lvert \psi \rangle} \qw   \\
#   & \lstick{\lvert \psi \rangle} & \gate{Z} & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})) and  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}),  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3.  MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}) equiv  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4.  Input(|psi〉)  & MultiQubitGate(CONTROL, {1, 3})  & Output(|psi〉)   \\
#    Input(|psi〉)  & Gate(--)  & Output(|psi〉)   \\
#    Input(|psi〉)  & MultiQubitGate(Z, {1, 3})  & Output(|psi〉)
#    core type: Operation
#    operator: 12
#    operand: 10
# 5. equiv
#    core type: Literal
#    sub-expressions:
# 6. ( MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3}),  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. ((Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 10
# 8.  MultiQubitGate(CONTROL, {1, 3})   \\
#    Gate(--)   \\
#    MultiQubitGate(Z, {1, 3})
#    core type: Operation
#    operator: 12
#    operand: 17
# 9.  MultiQubitGate(CONTROL, {1, 2})  & Gate(--)  & MultiQubitGate(CONTROL, {1, 2})  & Gate(--)   \\
#    MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})  & MultiQubitGate(Gate(X), {1, 2})  & MultiQubitGate(CONTROL, {2, 3})   \\
#    Gate(--)  & MultiQubitGate(Gate(X), {2, 3})  & Gate(--)  & MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 12
#    operand: 18
# 10. Input(|psi〉) & MultiQubitGate(CONTROL, {1, 3}) & Output(|psi〉)  \\
#   Input(|psi〉) & Gate(--) & Output(|psi〉)  \\
#   Input(|psi〉) & MultiQubitGate(Z, {1, 3}) & Output(|psi〉)
#     core type: ExprTuple
#     sub-expressions: 14, 15, 16
# 11. ((MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})))
#     core type: ExprTuple
#     sub-expressions: 17
# 12. CIRCUIT
#     core type: Literal
#     sub-expressions:
# 13. ((MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})))
#     core type: ExprTuple
#     sub-expressions: 18
# 14. (Input(|psi〉), MultiQubitGate(CONTROL, {1, 3}), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 19, 30, 20
# 15. (Input(|psi〉), Gate(--), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 19, 35, 20
# 16. (Input(|psi〉), MultiQubitGate(Z, {1, 3}), Output(|psi〉))
#     core type: ExprTuple
#     sub-expressions: 19, 31, 20
# 17. MultiQubitGate(CONTROL, {1, 3})  \\
#   Gate(--)  \\
#   MultiQubitGate(Z, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 21, 22, 23
# 18. MultiQubitGate(CONTROL, {1, 2}) & Gate(--) & MultiQubitGate(CONTROL, {1, 2}) & Gate(--)  \\
#   MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3}) & MultiQubitGate(Gate(X), {1, 2}) & MultiQubitGate(CONTROL, {2, 3})  \\
#   Gate(--) & MultiQubitGate(Gate(X), {2, 3}) & Gate(--) & MultiQubitGate(Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 24, 25, 26
# 19. Input(|psi〉)
#     core type: Operation
#     operator: 27
#     operand: 37
# 20. Output(|psi〉)
#     core type: Operation
#     operator: 28
#     operand: 37
# 21. (MultiQubitGate(CONTROL, {1, 3}))
#     core type: ExprTuple
#     sub-expressions: 30
# 22. (Gate(--))
#     core type: ExprTuple
#     sub-expressions: 35
# 23. (MultiQubitGate(Z, {1, 3}))
#     core type: ExprTuple
#     sub-expressions: 31
# 24. (MultiQubitGate(CONTROL, {1, 2}), Gate(--), MultiQubitGate(CONTROL, {1, 2}), Gate(--))
#     core type: ExprTuple
#     sub-expressions: 32, 35, 32, 35
# 25. (MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}), MultiQubitGate(Gate(X), {1, 2}), MultiQubitGate(CONTROL, {2, 3}))
#     core type: ExprTuple
#     sub-expressions: 33, 34, 33, 34
# 26. (Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}))
#     core type: ExprTuple
#     sub-expressions: 35, 36, 35, 36
# 27. INPUT
#     core type: Literal
#     sub-expressions:
# 28. OUTPUT
#     core type: Literal
#     sub-expressions:
# 29. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 37
# 30. MultiQubitGate(CONTROL, {1, 3})
#     core type: Operation
#     operator: 44
#     operands: 38
# 31. MultiQubitGate(Z, {1, 3})
#     core type: Operation
#     operator: 44
#     operands: 39
# 32. MultiQubitGate(CONTROL, {1, 2})
#     core type: Operation
#     operator: 44
#     operands: 40
# 33. MultiQubitGate(Gate(X), {1, 2})
#     core type: Operation
#     operator: 44
#     operands: 41
# 34. MultiQubitGate(CONTROL, {2, 3})
#     core type: Operation
#     operator: 44
#     operands: 42
# 35. Gate(--)
#     core type: Operation
#     operator: 58
#     operand: 52
# 36. MultiQubitGate(Gate(X), {2, 3})
#     core type: Operation
#     operator: 44
#     operands: 45
# 37. |psi〉
#     core type: Operation
#     operator: 46
#     operand: 55
# 38. (CONTROL, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 51, 49
# 39. (Z, {1, 3})
#     core type: ExprTuple
#     sub-expressions: 48, 49
# 40. (CONTROL, {1, 2})
#     core type: ExprTuple
#     sub-expressions: 51, 50
# 41. (Gate(X), {1, 2})
#     core type: ExprTuple
#     sub-expressions: 53, 50
# 42. (CONTROL, {2, 3})
#     core type: ExprTuple
#     sub-expressions: 51, 54
# 43. (--)
#     core type: ExprTuple
#     sub-expressions: 52
# 44. MULTI_QUBIT_GATE
#     core type: Literal
#     sub-expressions:
# 45. (Gate(X), {2, 3})
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 46. KET
#     core type: Literal
#     sub-expressions:
# 47. (psi)
#     core type: ExprTuple
#     sub-expressions: 55
# 48. Z
#     core type: Literal
#     sub-expressions:
# 49. {1, 3}
#     core type: Operation
#     operator: 60
#     operands: 56
# 50. {1, 2}
#     core type: Operation
#     operator: 60
#     operands: 57
# 51. CONTROL
#     core type: Literal
#     sub-expressions:
# 52. --
#     core type: Literal
#     sub-expressions:
# 53. Gate(X)
#     core type: Operation
#     operator: 58
#     operand: 63
# 54. {2, 3}
#     core type: Operation
#     operator: 60
#     operands: 61
# 55. psi
#     core type: Literal
#     sub-expressions:
# 56. (1, 3)
#     core type: ExprTuple
#     sub-expressions: 62, 65
# 57. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 64
# 58. GATE
#     core type: Literal
#     sub-expressions:
# 59. (X)
#     core type: ExprTuple
#     sub-expressions: 63
# 60. Set
#     core type: Literal
#     sub-expressions:
# 61. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 64, 65
# 62. 1
#     core type: Literal
#     sub-expressions:
# 63. X
#     core type: Literal
#     sub-expressions:
# 64. 2
#     core type: Literal
#     sub-expressions:
# 65. 3
#     core type: Literal
#     sub-expressions:
