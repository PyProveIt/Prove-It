# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, n
from proveit.physics.quantum import Input, Output, ket_psi
from proveit.physics.quantum.circuit import Circuit, MultiWire

# %%
# build up the expression from sub-expressions
expr = Circuit(ExprArray([Input(ket_psi), MultiWire(n), Output(ket_psi)]))
# Out:
# expr:  Input(|psi〉)  & MultiWire(n)  & Output(|psi〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & { /^{n} } \qw & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=1em @R=.7em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|psi〉)  & MultiWire(n)  & Output(|psi〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|psi〉) & MultiWire(n) & Output(|psi〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|psi〉) & MultiWire(n) & Output(|psi〉)
#    core type: ExprTuple
#    sub-expressions: 4
# 4. (Input(|psi〉), MultiWire(n), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 5, 6, 7
# 5. Input(|psi〉)
#    core type: Operation
#    operator: 8
#    operand: 14
# 6. MultiWire(n)
#    core type: Operation
#    operator: 9
#    operand: 13
# 7. Output(|psi〉)
#    core type: Operation
#    operator: 11
#    operand: 14
# 8. INPUT
#    core type: Literal
#    sub-expressions:
# 9. MULTI_WIRE
#    core type: Literal
#    sub-expressions:
# 10. (n)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. OUTPUT
#     core type: Literal
#     sub-expressions:
# 12. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. n
#     core type: Variable
#     sub-expressions:
# 14. |psi〉
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. KET
#     core type: Literal
#     sub-expressions:
# 16. (psi)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. psi
#     core type: Literal
#     sub-expressions:
