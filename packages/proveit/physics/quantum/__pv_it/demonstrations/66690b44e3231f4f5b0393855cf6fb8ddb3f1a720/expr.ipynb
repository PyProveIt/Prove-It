# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray, ExprTuple
from proveit.physics.quantum import Gate, H, SPACE, X, Z
from proveit.physics.quantum.circuit import Circuit, CircuitEquiv

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(H)
sub_expr2 = Gate(X)
sub_expr3 = Gate(SPACE)
sub_expr4 = Gate(Z)
expr = ExprTuple(CircuitEquiv(Circuit(ExprArray([sub_expr1, sub_expr2, sub_expr1])), Circuit(ExprArray([sub_expr3, sub_expr2, sub_expr3]))), CircuitEquiv(Circuit(ExprArray([sub_expr4, sub_expr1, sub_expr2, sub_expr1, sub_expr4])), Circuit(ExprArray([sub_expr4, sub_expr3, sub_expr2, sub_expr3, sub_expr4]))))
# Out:
# expr: ( Gate(H)  & Gate(X)  & Gate(H) equiv  Gate(SPACE)  & Gate(X)  & Gate(SPACE),  Gate(Z)  & Gate(H)  & Gate(X)  & Gate(H)  & Gate(Z) equiv  Gate(Z)  & Gate(SPACE)  & Gate(X)  & Gate(SPACE)  & Gate(Z))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{H} & \gate{X} & \gate{H}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{X}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z} & \gate{H} & \gate{X} & \gate{H} & \gate{Z}
# } \hspace{2em} \cong \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{Z} & \gate{X} & \gate{Z}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ( Gate(H)  & Gate(X)  & Gate(H) equiv  Gate(SPACE)  & Gate(X)  & Gate(SPACE),  Gate(Z)  & Gate(H)  & Gate(X)  & Gate(H)  & Gate(Z) equiv  Gate(Z)  & Gate(SPACE)  & Gate(X)  & Gate(SPACE)  & Gate(Z))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1.  Gate(H)  & Gate(X)  & Gate(H) equiv  Gate(SPACE)  & Gate(X)  & Gate(SPACE)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2.  Gate(Z)  & Gate(H)  & Gate(X)  & Gate(H)  & Gate(Z) equiv  Gate(Z)  & Gate(SPACE)  & Gate(X)  & Gate(SPACE)  & Gate(Z)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. ( Gate(H)  & Gate(X)  & Gate(H),  Gate(SPACE)  & Gate(X)  & Gate(SPACE))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. equiv
#    core type: Literal
#    sub-expressions:
# 5. ( Gate(Z)  & Gate(H)  & Gate(X)  & Gate(H)  & Gate(Z),  Gate(Z)  & Gate(SPACE)  & Gate(X)  & Gate(SPACE)  & Gate(Z))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6.  Gate(H)  & Gate(X)  & Gate(H)
# ...
