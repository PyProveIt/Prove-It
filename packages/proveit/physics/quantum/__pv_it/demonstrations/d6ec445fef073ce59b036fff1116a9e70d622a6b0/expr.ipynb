# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, a
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import DecimalSequence, one, three, two, zero

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(one)
sub_expr3 = Set(two, three)
expr = ExprTuple(Len([sub_expr1, sub_expr2, sub_expr1, sub_expr2, sub_expr1, sub_expr3, sub_expr1, sub_expr3, Set(three), sub_expr3]), Len([ExprRange(a, a, one, DecimalSequence(one, zero))]))
# Out:
# expr: (|({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3})|, |(1, ..a.., 10)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}\right)|, |\left(1, \ldots, 10\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3})|, |(1, ..a.., 10)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..a.., 10)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..a.., 10))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3})
#    core type: ExprTuple
#    sub-expressions: 9, 8, 9, 8, 9, 11, 9, 11, 10, 11
# 7. (1, ..a.., 10)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. {1}
#    core type: Operation
#    operator: 16
#    operand: 25
# 9. {1, 2}
#    core type: Operation
#    operator: 16
# ...
