# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.physics.quantum.circuit.Circuit.html">Circuit</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprArray
from proveit.logic import Set
from proveit.numbers import one, two
from proveit.physics.quantum import I, Input, Output, SPACE, ket0
from proveit.physics.quantum.circuit import Circuit, MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Input(ket0)
sub_expr2 = MultiQubitGate(I, Set(one, two))
expr = Circuit(ExprArray([sub_expr1, sub_expr2, SPACE], [sub_expr1, sub_expr2, Output(ket0)])).with_styles(spacing = '@C=3em @R=2.5em')
# Out:
# expr:  Input(|0〉)  & MultiQubitGate(--, {1, 2})  & SPACE   \\
#    Input(|0〉)  & MultiQubitGate(--, {1, 2})  & Output(|0〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \hspace{2em} \Qcircuit@C=3em @R=2.5em{
# & \lstick{\lvert 0 \rangle} & \qw \qwx[1]   \\
#   & \lstick{\lvert 0 \rangle} & \qw & \rstick{\lvert 0 \rangle} \qw
# } \hspace{2em}

# %%
expr.style_options()
# Out:
# style name: spacing
# description: change the spacing of a circuit using the format '@C=1em @R=.7em' where C is the column spacing and R is the row spacing
# default: @C=1em @R=.7em
# current value: @C=3em @R=2.5em
# related methods: ()
# style name: orientation
# description: to be read from left to right then top to bottom ('horizontal') or to be read top to bottom then left to right ('vertical')
# default: horizontal
# current value: horizontal
# related methods: with_orientation

# %%
# display the expression information
expr.expr_info()
# Out:
# 0.  Input(|0〉)  & MultiQubitGate(--, {1, 2})  & SPACE   \\
#    Input(|0〉)  & MultiQubitGate(--, {1, 2})  & Output(|0〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. CIRCUIT
#    core type: Literal
#    sub-expressions:
# 2. ((Input(|0〉) & MultiQubitGate(--, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(--, {1, 2}) & Output(|0〉)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. Input(|0〉) & MultiQubitGate(--, {1, 2}) & SPACE  \\
#   Input(|0〉) & MultiQubitGate(--, {1, 2}) & Output(|0〉)
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (Input(|0〉), MultiQubitGate([I], {1, 2}), SPACE)
#    core type: ExprTuple
#    sub-expressions: 7, 8, 6
# 5. (Input(|0〉), MultiQubitGate([I], {1, 2}), Output(|0〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. SPACE
#    core type: Literal
#    sub-expressions:
# 7. Input(|0〉)
#    core type: Operation
#    operator: 10
#    operand: 17
# 8. MultiQubitGate([I], {1, 2})
#    core type: Operation
# ...
