# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import one, three, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Set(one, two)
sub_expr2 = Set(one)
sub_expr3 = Set(two, three)
sub_expr4 = Set(three)
expr = ExprTuple(Len([sub_expr1, sub_expr2, sub_expr1, sub_expr2, sub_expr1, sub_expr3, sub_expr1, sub_expr3, sub_expr4, sub_expr3, sub_expr4, sub_expr3]), Variable("_a", latex_format = r"{_{-}a}"))
# Out:
# expr: (|({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})|, _a)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{1\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{1, 2\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}, \left\{3\right\}, \left\{2, 3\right\}\right)|, {_{-}a}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})|, _a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})|
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. _a
#    core type: Variable
#    sub-expressions:
# 3. length
#    core type: Literal
#    sub-expressions:
# 4. (({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3}))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. ({1, 2}, {1}, {1, 2}, {1}, {1, 2}, {2, 3}, {1, 2}, {2, 3}, {3}, {2, 3}, {3}, {2, 3})
#    core type: ExprTuple
#    sub-expressions: 7, 6, 7, 6, 7, 9, 7, 9, 8, 9, 8, 9
# 6. {1}
#    core type: Operation
#    operator: 13
#    operand: 15
# 7. {1, 2}
#    core type: Operation
#    operator: 13
#    operands: 11
# 8. {3}
#    core type: Operation
#    operator: 13
#    operand: 17
# 9. {2, 3}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (1)
#     core type: ExprTuple
#     sub-expressions: 15
# 11. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 12. (3)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. Set
#     core type: Literal
#     sub-expressions:
# 14. (2, 3)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2
#     core type: Literal
#     sub-expressions:
# 17. 3
#     core type: Literal
#     sub-expressions:
