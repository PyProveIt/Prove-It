# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import B, ExprRange, IndexedVar, Q, a, i
from proveit.logic import Equals
from proveit.numbers import one
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = [i, a]
sub_expr2 = [i, one]
expr = Equals([ExprRange(a, MultiQubitGate(IndexedVar(B, sub_expr1), IndexedVar(Q, sub_expr1)), one, one)], [MultiQubitGate(IndexedVar(B, sub_expr2), IndexedVar(Q, sub_expr2))])
# Out:
# expr: (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, a}, Q_{i, a}).., MultiQubitGate(B_{i, 1}, Q_{i, 1})) = (MultiQubitGate(B_{i, 1}, Q_{i, 1}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{i, 1}{\Big \{} Q_{i, 1}}
# } \hspace{2em}, \ldots, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{i, 1}{\Big \{} Q_{i, 1}}
# } \hspace{2em}\right) = \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{B_{i, 1}{\Big \{} Q_{i, 1}}
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, a}, Q_{i, a}).., MultiQubitGate(B_{i, 1}, Q_{i, 1})) = (MultiQubitGate(B_{i, 1}, Q_{i, 1}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, a}, Q_{i, a}).., MultiQubitGate(B_{i, 1}, Q_{i, 1})), (MultiQubitGate(B_{i, 1}, Q_{i, 1})))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, a}, Q_{i, a}).., MultiQubitGate(B_{i, 1}, Q_{i, 1}))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (MultiQubitGate(B_{i, 1}, Q_{i, 1}))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. MultiQubitGate(B_{i, 1}, Q_{i, 1}), ..MultiQubitGate(B_{i, a}, Q_{i, a}).., MultiQubitGate(B_{i, 1}, Q_{i, 1})
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 17
#    end_index: 17
# 6. MultiQubitGate(B_{i, 1}, Q_{i, 1})
# ...
