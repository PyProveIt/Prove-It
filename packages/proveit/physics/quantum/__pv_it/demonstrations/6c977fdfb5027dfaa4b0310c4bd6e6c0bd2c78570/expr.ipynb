# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.logic import Set
from proveit.numbers import three, two
from proveit.physics.quantum import Gate, I, Input, Output, X, ket_psi
from proveit.physics.quantum.circuit import MultiQubitGate

# %%
# build up the expression from sub-expressions
sub_expr1 = Gate(I)
sub_expr2 = MultiQubitGate(Gate(X), Set(two, three))
expr = ExprTuple(Input(ket_psi), sub_expr1, sub_expr2, sub_expr1, sub_expr2, Output(ket_psi))
# Out:
# expr: (Input(|psi〉), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Output(|psi〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \lstick{\lvert \psi \rangle} & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\targ{\Big \{} \left\{2, 3\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \qw
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \gate{\targ{\Big \{} \left\{2, 3\right\}}
# } \hspace{2em}, \hspace{2em} \Qcircuit@C=1em @R=.7em{
# & \rstick{\lvert \psi \rangle} \qw
# } \hspace{2em}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Input(|psi〉), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Gate(--), MultiQubitGate(Gate(X), {2, 3}), Output(|psi〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3, 2, 3, 4
# 1. Input(|psi〉)
#    core type: Operation
#    operator: 5
#    operand: 14
# 2. Gate(--)
#    core type: Operation
#    operator: 15
#    operand: 11
# 3. MultiQubitGate(Gate(X), {2, 3})
#    core type: Operation
#    operator: 7
#    operands: 8
# 4. Output(|psi〉)
#    core type: Operation
#    operator: 9
#    operand: 14
# 5. INPUT
#    core type: Literal
#    sub-expressions:
# 6. (--)
#    core type: ExprTuple
#    sub-expressions: 11
# 7. MULTI_QUBIT_GATE
#    core type: Literal
#    sub-expressions:
# 8. (Gate(X), {2, 3})
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 9. OUTPUT
#    core type: Literal
#    sub-expressions:
# 10. (|psi〉)
#     core type: ExprTuple
#     sub-expressions: 14
# 11. --
#     core type: Literal
#     sub-expressions:
# 12. Gate(X)
# ...
