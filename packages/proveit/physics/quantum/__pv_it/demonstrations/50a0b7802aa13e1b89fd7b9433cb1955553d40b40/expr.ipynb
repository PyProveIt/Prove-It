# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, x
from proveit.core_expr_types import Len
from proveit.logic import Set
from proveit.numbers import four, one, three, two

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([Set(one), Set(two), Set(three), Set(four)]), Len([ExprRange(k, ExprRange(x, [k, x], one, one), one, four)]))
# Out:
# expr: (|({1}, {2}, {3}, {4})|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(\left\{1\right\}, \left\{2\right\}, \left\{3\right\}, \left\{4\right\}\right)|, |\left(\left(1, 1\right), \ldots, \left(1, 1\right), \ldots\ldots, \left(4, 1\right), \ldots, \left(4, 1\right)\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|({1}, {2}, {3}, {4})|, |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |({1}, {2}, {3}, {4})|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1))|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (({1}, {2}, {3}, {4}))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. (((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1)))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. ({1}, {2}, {3}, {4})
#    core type: ExprTuple
#    sub-expressions: 8, 9, 10, 11
# 7. ((1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1))
#    core type: ExprTuple
#    sub-expressions: 12
# 8. {1}
#    core type: Operation
#    operator: 16
#    operand: 24
# 9. {2}
#    core type: Operation
#    operator: 16
#    operand: 19
# 10. {3}
#     core type: Operation
#     operator: 16
#     operand: 20
# 11. {4}
#     core type: Operation
#     operator: 16
#     operand: 21
# 12. (1, 1), ..(1, x).., (1, 1), ....(k, 1), ..(k, x).., (k, 1)...., (4, 1), ..(4, x).., (4, 1)
#     core type: ExprRange
#     lambda_map: 18
#     start_index: 24
#     end_index: 21
# 13. (1)
#     core type: ExprTuple
#     sub-expressions: 24
# 14. (2)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. (3)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. Set
#     core type: Literal
#     sub-expressions:
# 17. (4)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. k -> (k, 1), ..(k, x).., (k, 1)
#     core type: Lambda
#     parameter: 26
#     body: 22
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. 3
#     core type: Literal
#     sub-expressions:
# 21. 4
#     core type: Literal
#     sub-expressions:
# 22. (k, 1), ..(k, x).., (k, 1)
#     core type: ExprRange
#     lambda_map: 23
#     start_index: 24
#     end_index: 24
# 23. x -> (k, x)
#     core type: Lambda
#     parameter: 27
#     body: 25
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. (k, x)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. k
#     core type: Variable
#     sub-expressions:
# 27. x
#     core type: Variable
#     sub-expressions:
