# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theorems.ipynb#controlled_ngate_equiv">controlled_ngate_equiv</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving controlled_ngate_equiv
# Out:
# controlled_ngate_equiv: forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{a, b, c in Complex^{2}} [forall_{x, y, z in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(z)) <=> ((b otimes y) = (c otimes z)))]]]
