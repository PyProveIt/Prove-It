# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theorems.ipynb#superposition_controlled_ngate">superposition_controlled_ngate</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving superposition_controlled_ngate
# Out:
# superposition_controlled_ngate: forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{a, b, c, d in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} (( Input(a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) and  Input(b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y)) =>  Input(a + b)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(c + d)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]]
