# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theorems.ipynb#pregated_controlled_ngate_equiv">pregated_controlled_ngate_equiv</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving pregated_controlled_ngate_equiv
# Out:
# pregated_controlled_ngate_equiv: forall_{n in NaturalPos} [forall_{U in SU(2^{n})} [forall_{u in SU(2)} [forall_{a, b in Complex^{2}} [forall_{x, y in (Complex^{2})^{otimes n}} ( Input(a)  & Gate(u)  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y) =  Input(u . a)  & --  & MultiQubitGate(CONTROL, {1, 2})  & Output(b)   \\
#    Input(x)  & MultiWire(n)  & MultiQubitGate(U, {1, 2})  & Output(y))]]]]
