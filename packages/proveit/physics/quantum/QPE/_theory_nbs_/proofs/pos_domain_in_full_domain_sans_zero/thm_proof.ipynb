# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#pos_domain_in_full_domain_sans_zero">pos_domain_in_full_domain_sans_zero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, a, eps, l
from proveit.logic import InSet, NotEquals
from proveit.numbers import zero, one, two
from proveit.numbers import Add, greater, Integer, Less, LessEq, Neg
from proveit.numbers.negation import negated_positive_is_negative
from proveit.physics.quantum.QPE import (eps_domain, full_domain, full_domain_sans_zero,
                                         pos_domain, two_pow_t_minus_one)
from proveit.physics.quantum.QPE import two_pow_t_minus_one_is_nat_pos

# %%
# %proving pos_domain_in_full_domain_sans_zero
# Out:
# pos_domain_in_full_domain_sans_zero: forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %% [markdown]
# The basic approach is to show that<br>
# $\ell\in\{\epsilon+1\ldots 2^{t-1}\}$ means $\ell\in\{-2^{t-1}+1\ldots 2^{t-1}\}$ and $\ell\ne 0$<br>
# More specifically:<br>
# (1) $\ell\in\{\epsilon+1\ldots 2^{t-1}\}$ means $\ell \le 2^{t-1}$ (and $\ell\in\mathbb{Z}$) (both auto side-effect)<br>
# (2) $\ell\in\{\epsilon+1\ldots 2^{t-1}\}$ means $\epsilon+1 \le \ell$ (auto side-effect)<br>
# (3) $\epsilon\in\{1\ldots 2^{t-1}-2\}$ means $\epsilon + 1 > 0$<br>
# (4) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell>0$.<br/>
# (5) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell\ne 0$.<br/>
# (6) Thus $\ell\in\{-2^{t-1 + 1}\ldots 2^{t-1}\}-\{0\}$

# %%
defaults.assumptions = pos_domain_in_full_domain_sans_zero.all_conditions()
# Out:
# Entering the ProperSubset.conclude() method!
# defaults.assumptions: (eps in {1 .. 2^{t - 1} - 2})

# %%
defaults.assumptions = [*defaults.assumptions, InSet(l, pos_domain)]
# Out:
# Entering the ProperSubset.conclude() method!
# defaults.assumptions: (eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}})

# %%
two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# From the default assumptions, we know 1 <= eps, and thus also 0 < eps
ineq_01 = Less(zero, eps).prove()
# Out:
# ineq_01: {eps in {1 .. 2^{t - 1} - 2}} |- 0 < eps

# %%
ineq_02 = ineq_01.derive_shifted(one).inner_expr().lhs.simplify()
# Out:
# ineq_02: {eps in {1 .. 2^{t - 1} - 2}} |- 1 < (eps + 1)

# %%
# From the default assumptions, prove 0 < ell. Also then gives us ell != 0
# The lower and upper bounds on ell are automatic side-effects
Less(zero, l).prove()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- 0 < l

# %%
negated_positive_is_negative
# Out:
# |- forall_{a in Real | a > 0} ((-a) < 0)

# %%
negated_positive_is_negative.instantiate({a:two_pow_t_minus_one})
# Out:
# |- (-2^{t - 1}) < 0

# %%
ineq_03 = Less(Neg(two_pow_t_minus_one), eps).prove()
# Out:
# ineq_03: {eps in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1}) < eps

# %%
ineq_03.derive_shifted(one)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) < (eps + 1)

# %%
# %qed
# Out:
# Entering the ProperSubset.conclude() method!
# Entering the ProperSubset.conclude() method!
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 1	instantiation	2, 3	{eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	A : {eps + 1 .. 2^{t - 1}}, B : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalizaton	4	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {eps + 1 .. 2^{t - 1}}} (_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 4	instantiation	5, 6, 7	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : _a
# 5	conjecture		|- forall_{S, y} [forall_{x in S | x != y} (x in (S - {y}))]
# 6	instantiation	8, 9, 65, 10, 11	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : _a
# 7	instantiation	12, 13	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a != 0
# 	n : _a
# 8	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 9	instantiation	64, 14, 59	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 10	instantiation	55, 32, 65, 33	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a in Integer
# 	a : eps + 1, b : 2^{t - 1}, n : _a
# 11	instantiation	15, 16, 17	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- ((-2^{t - 1} + 1) <= _a) and (_a <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= _a, B : _a <= 2^{t - 1}
# 12	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 13	instantiation	58, 32, 65, 18, 33	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a in NaturalPos
# 	a : eps + 1, b : 2^{t - 1}, n : _a
# 14	instantiation	69, 65	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 15	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 16	instantiation	19, 20	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) <= _a
# 	x : -2^{t - 1} + 1, y : _a
# 17	instantiation	21, 32, 65, 33	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a <= 2^{t - 1}
# 	a : eps + 1, b : 2^{t - 1}, n : _a
# 18	instantiation	39, 61, 22	{eps in {1 .. 2^{t - 1} - 2}} |- 0 < (eps + 1)
# 	x : 0, y : 1, z : eps + 1
# 19	conjecture		|- forall_{x, y | x < y} (x <= y)
# 20	instantiation	23, 24, 25	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) < _a
# 	x : -2^{t - 1} + 1, y : eps + 1, z : _a
# 21	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 22	instantiation	26, 27, 28	{eps in {1 .. 2^{t - 1} - 2}} |- 1 < (eps + 1)
# 	P(_a) : _a < (eps + 1), x : 0 + 1, y : 1
# 23	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 24	instantiation	34, 29, 36, 37, 30	{eps in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) < (eps + 1)
# 	a : -2^{t - 1}, b : eps, c : 1
# 25	instantiation	31, 32, 65, 33	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- (eps + 1) <= _a
# 	a : eps + 1, b : 2^{t - 1}, n : _a
# 26	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 27	instantiation	34, 35, 36, 37, 41	{eps in {1 .. 2^{t - 1} - 2}} |- (0 + 1) < (eps + 1)
# 	a : 0, b : eps, c : 1
# 28	conjecture		|- (0 + 1) = 1
# 29	instantiation	38, 46	|- (-2^{t - 1}) in Real
# 	a : 2^{t - 1}
# 30	instantiation	39, 40, 41	{eps in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1}) < eps
# 	x : -2^{t - 1}, y : 0, z : eps
# 31	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 32	instantiation	64, 49, 59	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Integer
# 	a : eps, b : 1
# 33	assumption		{_a in {eps + 1 .. 2^{t - 1}}} |- _a in {eps + 1 .. 2^{t - 1}}
# 34	conjecture		|- forall_{a, b, c in Real | a < b} ((a + c) < (b + c))
# 35	instantiation	71, 50, 42	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 36	instantiation	71, 50, 43	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Real
# 	A : Rational, B : Real, x : eps
# 37	instantiation	71, 50, 44	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 38	conjecture		|- forall_{a in Real} ((-a) in Real)
# 39	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 40	instantiation	45, 46, 47	|- (-2^{t - 1}) < 0
# 	a : 2^{t - 1}
# 41	instantiation	52, 48	{eps in {1 .. 2^{t - 1} - 2}} |- 0 < eps
# 	q : eps
# 42	conjecture		|- 0 in Rational
# 43	instantiation	71, 56, 49	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Rational
# 	A : Integer, B : Rational, x : eps
# 44	instantiation	71, 56, 59	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 45	conjecture		|- forall_{a in Real | a > 0} ((-a) < 0)
# 46	instantiation	71, 50, 51	|- 2^{t - 1} in Real
# 	A : Rational, B : Real, x : 2^{t - 1}
# 47	instantiation	52, 53	|- 0 < 2^{t - 1}
# 	q : 2^{t - 1}
# 48	instantiation	71, 57, 54	{eps in {1 .. 2^{t - 1} - 2}} |- eps in RationalPos
# 	A : NaturalPos, B : RationalPos, x : eps
# 49	instantiation	55, 59, 60, 62	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Integer
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 50	conjecture		|- Rational proper_subset Real
# 51	instantiation	71, 56, 65	|- 2^{t - 1} in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1}
# 52	conjecture		|- forall_{q in RationalPos} (q > 0)
# 53	instantiation	71, 57, 68	|- 2^{t - 1} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t - 1}
# 54	instantiation	58, 59, 60, 61, 62	{eps in {1 .. 2^{t - 1} - 2}} |- eps in NaturalPos
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 55	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n in Integer)]
# 56	conjecture		|- Integer proper_subset Rational
# 57	conjecture		|- NaturalPos proper_subset RationalPos
# 58	conjecture		|- forall_{a, b in Integer | a > 0} [forall_{n in {a .. b}} (n in NaturalPos)]
# 59	instantiation	71, 72, 63	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 60	instantiation	64, 65, 66	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 61	conjecture		|- 0 < 1
# 62	assumption		{eps in {1 .. 2^{t - 1} - 2}} |- eps in {1 .. 2^{t - 1} - 2}
# 63	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 64	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 65	instantiation	71, 67, 68	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 66	instantiation	69, 70	|- (-2) in Integer
# 	a : 2
# 67	conjecture		|- NaturalPos proper_subset Integer
# 68	conjecture		|- 2^{t - 1} in NaturalPos
# 69	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 70	instantiation	71, 72, 73	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 71	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 72	conjecture		|- Natural proper_subset Integer
# 73	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
