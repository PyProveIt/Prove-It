# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#all_abs_alpha_l_sqrd_are_real">all_abs_alpha_l_sqrd_are_real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, l
from proveit.physics.quantum.QPE import all_abs_alpha_l_are_nonneg

# %%
# %proving all_abs_alpha_l_sqrd_are_real
# Out:
# all_abs_alpha_l_sqrd_are_real: forall_{l in Integer} (|alpha_{l}|^{2} in Real)

# %%
defaults.assumptions = all_abs_alpha_l_sqrd_are_real.conditions
# Out:
# defaults.assumptions: (l in Integer)

# %%
all_abs_alpha_l_are_nonneg
# Out:
# |- forall_{l in Integer} (|alpha_{l}| in RealNonNeg)

# %%
expr = all_abs_alpha_l_are_nonneg.instantiate({l: l})
# Out:
# expr: {l in Integer} |- |alpha_{l}| in RealNonNeg

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{l in Integer} (|alpha_{l}|^{2} in Real)
# 1	instantiation	2, 3, 4	{l in Integer} |- |alpha_{l}|^{2} in Real
# 	a : |alpha_{l}|, b : 2
# 2	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 3	instantiation	5, 6, 7	{l in Integer} |- |alpha_{l}| in Real
# 	A : RealNonNeg, B : Real, x : |alpha_{l}|
# 4	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 5	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 6	conjecture		|- RealNonNeg proper_subset Real
# 7	instantiation	8, 9	{l in Integer} |- |alpha_{l}| in RealNonNeg
# 	l : l
# 8	conjecture		|- forall_{l in Integer} (|alpha_{l}| in RealNonNeg)
# 9	assumption		{l in Integer} |- l in Integer
