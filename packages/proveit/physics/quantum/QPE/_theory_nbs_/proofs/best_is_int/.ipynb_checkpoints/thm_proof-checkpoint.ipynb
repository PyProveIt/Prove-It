# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#best_is_int">best_is_int</a> theorem
# ========

# %%
import proveit
from proveit.logic import InSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import best_def
from proveit.physics.quantum.QPE import phase_is_real, two_pow_t_is_nat_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving best_is_int
# Out:
# best_is_int: b in Integer

# %%
best_def
# Out:
# |- b = floor(phase * 2^{t})

# %%
phase_is_real
# Out:
# |- phase in Real

# %%
two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
InSet(best_def.rhs, Integer).prove()
# Out:
# |- floor(phase * 2^{t}) in Integer

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- b in Integer
# 	P(_a) : _a in Integer, x : floor(phase * 2^{t}), y : b
# 1	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 2	instantiation	4, 5	|- floor(phase * 2^{t}) in Integer
# 	x : phase * 2^{t}
# 3	instantiation	6, 7	|- floor(phase * 2^{t}) = b
# 	x : b, y : floor(phase * 2^{t})
# 4	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 5	instantiation	8, 9, 10	|- (phase * 2^{t}) in Real
# 	a : phase, b : 2^{t}
# 6	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 7	axiom		|- b = floor(phase * 2^{t})
# 	proveit.physics.quantum.QPE.best_def
# 8	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 9	conjecture		|- phase in Real
# 10	instantiation	15, 11, 12	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 11	conjecture		|- Rational proper_subset Real
# 12	instantiation	15, 13, 14	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 13	conjecture		|- Integer proper_subset Rational
# 14	instantiation	15, 16, 17	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 15	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 16	conjecture		|- NaturalPos proper_subset Integer
# 17	conjecture		|- 2^{t} in NaturalPos
