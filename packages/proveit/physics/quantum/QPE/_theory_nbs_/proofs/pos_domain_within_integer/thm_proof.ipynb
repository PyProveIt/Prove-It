# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#pos_domain_within_integer">pos_domain_within_integer</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import two_pow_t_minus_one_is_nat_pos

# %%
# %proving pos_domain_within_integer
# Out:
# pos_domain_within_integer: forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq Integer)

# %%
two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# %qed
# Out:
# Entering the ProperSubset.conclude() method!
# Entering the ProperSubset.conclude() method!
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq Integer)
# 1	instantiation	2, 3	{eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq Integer
# 	A : {eps + 1 .. 2^{t - 1}}, B : Integer, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalizaton	4	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {eps + 1 .. 2^{t - 1}}} (_a in Integer)
# 4	instantiation	8, 5, 14, 6	{eps in {1 .. 2^{t - 1} - 2}, _a in {eps + 1 .. 2^{t - 1}}} |- _a in Integer
# 	a : eps + 1, b : 2^{t - 1}, n : _a
# 5	instantiation	13, 7, 9	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Integer
# 	a : eps, b : 1
# 6	assumption		{_a in {eps + 1 .. 2^{t - 1}}} |- _a in {eps + 1 .. 2^{t - 1}}
# 7	instantiation	8, 9, 10, 11	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Integer
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 8	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n in Integer)]
# 9	instantiation	20, 21, 12	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 10	instantiation	13, 14, 15	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 11	assumption		{eps in {1 .. 2^{t - 1} - 2}} |- eps in {1 .. 2^{t - 1} - 2}
# 12	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 13	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 14	instantiation	20, 16, 17	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 15	instantiation	18, 19	|- (-2) in Integer
# 	a : 2
# 16	conjecture		|- NaturalPos proper_subset Integer
# 17	conjecture		|- 2^{t - 1} in NaturalPos
# 18	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 19	instantiation	20, 21, 22	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 20	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 21	conjecture		|- Natural proper_subset Integer
# 22	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
