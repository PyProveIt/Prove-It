# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#non_int_delta_diff">non_int_delta_diff</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving non_int_delta_diff
# Out:
# non_int_delta_diff: forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((delta - (l / 2^{t})) not-in Integer)
