# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#neg_domain_in_full_domain_sans_zero">neg_domain_in_full_domain_sans_zero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, defaults, eps, l
from proveit.logic import InSet, NotEquals
from proveit.numbers import zero, one, Add, Less, Neg
from proveit.numbers import RealNeg
from proveit.numbers.negation import negated_positive_is_negative
from proveit.physics.quantum.QPE import (eps_domain, full_domain, full_domain_sans_zero,
                                         neg_domain, two_pow_t_minus_one)
from proveit.physics.quantum.QPE import two_pow_t_minus_one_is_nat_pos

# %%
# %proving neg_domain_in_full_domain_sans_zero
# Out:
# neg_domain_in_full_domain_sans_zero: forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %% [markdown]
# This theorem is very similar to its companion theorem `pos_domain_in_full_domain_sans_zero` and the approach is essentially the same.<br>
# The basic approach is to show that<br>
# $\ell\in\{-2^{t-1}+1 \ldots -(\epsilon+1)\}$ means $\ell\in\{-2^{t-1}+1\ldots 2^{t-1}\}$ and $\ell\ne 0$<br>
# More specifically:<br>
# (1) $\ell\in\{-2^{t-1}+1 \ldots -(\epsilon+1)\}$ means $\ell \ge -2^{t-1}+1$ (and $\ell\in\mathbb{Z}$)<br>
# (2) $\ell\in\{\epsilon+1\ldots 2^{t-1}\}$ means $\ell \le -(\epsilon+1)$<br>
# (3) $\epsilon\in\{1\ldots 2^{t-1}-2\}$ means $-(\epsilon + 1) < 0$<br>
# (4) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell<0$.<br/>
# (5) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell\ne 0$.<br/>
# (6) Thus $\ell\in\{-2^{t-1 + 1}\ldots 2^{t-1}\}-\{0\}$

# %%
defaults.assumptions = neg_domain_in_full_domain_sans_zero.all_conditions()
# Out:
# Entering the ProperSubset.conclude() method!
# defaults.assumptions: (eps in {1 .. 2^{t - 1} - 2})

# %%
defaults.assumptions = [*defaults.assumptions, InSet(l, neg_domain)]
# Out:
# Entering the ProperSubset.conclude() method!
# defaults.assumptions: (eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)})

# %%
two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
ineq_01 = Less(zero, eps).prove()
# Out:
# ineq_01: {eps in {1 .. 2^{t - 1} - 2}} |- 0 < eps

# %%
ineq_01.derive_shifted(one).inner_expr().lhs.simplify()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- 1 < (eps + 1)

# %%
# Some way to automate related info? 
negated_positive_is_negative
# Out:
# |- forall_{a in Real | a > 0} ((-a) < 0)

# %%
neg_domain_upper_bound_ineq = negated_positive_is_negative.instantiate({a: Add(eps, one)})
# Out:
# neg_domain_upper_bound_ineq: {eps in {1 .. 2^{t - 1} - 2}} |- (-(eps + 1)) < 0

# %%
# not currently the default … consider?
Less(l, zero).conclude_via_transitivity()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l < 0

# %%
# %qed
# Out:
# Entering the ProperSubset.conclude() method!
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 1	instantiation	2, 3	{eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	A : {-2^{t - 1} + 1 .. -(eps + 1)}, B : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalizaton	4	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {-2^{t - 1} + 1 .. -(eps + 1)}} (_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 4	instantiation	5, 6, 7	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : _a
# 5	conjecture		|- forall_{S, y} [forall_{x in S | x != y} (x in (S - {y}))]
# 6	instantiation	8, 27, 64, 19, 9	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : _a
# 7	instantiation	10, 11, 42, 20	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a != 0
# 	a : _a, b : 0
# 8	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 9	instantiation	12, 13, 14	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- ((-2^{t - 1} + 1) <= _a) and (_a <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= _a, B : _a <= 2^{t - 1}
# 10	conjecture		|- forall_{a, b in Real | a < b} (a != b)
# 11	instantiation	70, 48, 15	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in Real
# 	A : Rational, B : Real, x : _a
# 12	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 13	instantiation	16, 27, 28, 29	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (-2^{t - 1} + 1) <= _a
# 	a : -2^{t - 1} + 1, b : -(eps + 1), n : _a
# 14	instantiation	17, 18	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a <= 2^{t - 1}
# 	x : _a, y : 2^{t - 1}
# 15	instantiation	70, 53, 19	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in Rational
# 	A : Integer, B : Rational, x : _a
# 16	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 17	conjecture		|- forall_{x, y | x < y} (x <= y)
# 18	instantiation	35, 20, 21	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a < 2^{t - 1}
# 	x : _a, y : 0, z : 2^{t - 1}
# 19	instantiation	56, 27, 28, 29	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in Integer
# 	a : -2^{t - 1} + 1, b : -(eps + 1), n : _a
# 20	instantiation	22, 23, 24	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a < 0
# 	x : _a, y : -(eps + 1), z : 0
# 21	instantiation	50, 25	|- 0 < 2^{t - 1}
# 	q : 2^{t - 1}
# 22	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 23	instantiation	26, 27, 28, 29	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a <= (-(eps + 1))
# 	a : -2^{t - 1} + 1, b : -(eps + 1), n : _a
# 24	instantiation	30, 31, 32	{eps in {1 .. 2^{t - 1} - 2}} |- (-(eps + 1)) < 0
# 	a : eps + 1
# 25	instantiation	70, 54, 67	|- 2^{t - 1} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t - 1}
# 26	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 27	instantiation	63, 33, 58	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 28	instantiation	68, 37	{eps in {1 .. 2^{t - 1} - 2}} |- (-(eps + 1)) in Integer
# 	a : eps + 1
# 29	assumption		{_a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in {-2^{t - 1} + 1 .. -(eps + 1)}
# 30	conjecture		|- forall_{a in Real | a > 0} ((-a) < 0)
# 31	instantiation	70, 48, 34	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Real
# 	A : Rational, B : Real, x : eps + 1
# 32	instantiation	35, 60, 36	{eps in {1 .. 2^{t - 1} - 2}} |- 0 < (eps + 1)
# 	x : 0, y : 1, z : eps + 1
# 33	instantiation	68, 64	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 34	instantiation	70, 53, 37	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Rational
# 	A : Integer, B : Rational, x : eps + 1
# 35	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 36	instantiation	38, 39, 40	{eps in {1 .. 2^{t - 1} - 2}} |- 1 < (eps + 1)
# 	P(_a) : _a < (eps + 1), x : 0 + 1, y : 1
# 37	instantiation	63, 52, 58	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Integer
# 	a : eps, b : 1
# 38	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 39	instantiation	41, 42, 43, 44, 45	{eps in {1 .. 2^{t - 1} - 2}} |- (0 + 1) < (eps + 1)
# 	a : 0, b : eps, c : 1
# 40	conjecture		|- (0 + 1) = 1
# 41	conjecture		|- forall_{a, b, c in Real | a < b} ((a + c) < (b + c))
# 42	instantiation	70, 48, 46	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 43	instantiation	70, 48, 47	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Real
# 	A : Rational, B : Real, x : eps
# 44	instantiation	70, 48, 49	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 45	instantiation	50, 51	{eps in {1 .. 2^{t - 1} - 2}} |- 0 < eps
# 	q : eps
# 46	conjecture		|- 0 in Rational
# 47	instantiation	70, 53, 52	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Rational
# 	A : Integer, B : Rational, x : eps
# 48	conjecture		|- Rational proper_subset Real
# 49	instantiation	70, 53, 58	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 50	conjecture		|- forall_{q in RationalPos} (q > 0)
# 51	instantiation	70, 54, 55	{eps in {1 .. 2^{t - 1} - 2}} |- eps in RationalPos
# 	A : NaturalPos, B : RationalPos, x : eps
# 52	instantiation	56, 58, 59, 61	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Integer
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 53	conjecture		|- Integer proper_subset Rational
# 54	conjecture		|- NaturalPos proper_subset RationalPos
# 55	instantiation	57, 58, 59, 60, 61	{eps in {1 .. 2^{t - 1} - 2}} |- eps in NaturalPos
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 56	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n in Integer)]
# 57	conjecture		|- forall_{a, b in Integer | a > 0} [forall_{n in {a .. b}} (n in NaturalPos)]
# 58	instantiation	70, 71, 62	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 59	instantiation	63, 64, 65	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 60	conjecture		|- 0 < 1
# 61	assumption		{eps in {1 .. 2^{t - 1} - 2}} |- eps in {1 .. 2^{t - 1} - 2}
# 62	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 63	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 64	instantiation	70, 66, 67	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 65	instantiation	68, 69	|- (-2) in Integer
# 	a : 2
# 66	conjecture		|- NaturalPos proper_subset Integer
# 67	conjecture		|- 2^{t - 1} in NaturalPos
# 68	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 69	instantiation	70, 71, 72	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 70	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 71	conjecture		|- Natural proper_subset Integer
# 72	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
