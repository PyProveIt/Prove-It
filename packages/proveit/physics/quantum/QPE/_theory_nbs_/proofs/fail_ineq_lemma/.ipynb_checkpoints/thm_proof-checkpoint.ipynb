# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#fail_ineq_lemma">fail_ineq_lemma</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit.logic import InSet, NotEquals
from proveit import l, eps
from proveit.numbers import frac, zero, one, four, Integer, Less, NaturalPos, IntegerNeg
# import common exrpessions
from proveit.physics.quantum.QPE import alpha_l, alpha_l_sqrd, t_, delta_, two_pow_t_minus_one, \
    full_domain, neg_domain, pos_domain, eps_domain
# import axioms
from proveit.physics.quantum.QPE import t_in_natural_pos, mod_add_def
# import theorems
from proveit.physics.quantum.QPE import (
    pos_domain_in_full_domain_sans_zero, neg_domain_in_full_domain_sans_zero,
    pos_domain_within_integer, neg_domain_within_integer,
    two_pow_t_minus_one_is_nat_pos, phase_is_real, all_alpha_l_is_complex, 
    all_abs_alpha_l_sqrd_are_real,
    delta_is_real, scaled_delta_in_interval,
    scaled_delta_not_eq_nonzeroInt, alpha_l_sqrd_ineq, fail_sum,
    pos_domain_within_natpos, neg_domain_within_negint)
from proveit.physics.quantum.QPE.phase_est_ops import Psuccess, Pfail, ModAdd

# %%
# %proving fail_ineq_lemma
# Out:
# fail_ineq_lemma: forall_{eps in {1 .. 2^{t - 1} - 2}} (Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))))

# %%
defaults.assumptions = fail_ineq_lemma.conditions
# Out:
# defaults.assumptions: (eps in {1 .. 2^{t - 1} - 2})

# %%
fail_sum
# Out:
# |- forall_{eps in {1 .. 2^{t - 1} - 2}} (Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})))

# %%
fail_sum_inst = fail_sum.instantiate()
# Out:
# fail_sum_inst: {eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))

# %%
first_sum = fail_sum_inst.rhs.terms[0]
# Out:
# first_sum: Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}

# %%
second_sum = fail_sum_inst.rhs.terms[1]
# Out:
# second_sum: Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}

# %%
alpha_l_sqrd_ineq
# Out:
# |- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
pos_domain_in_full_domain_sans_zero
# Out:
# |- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %%
pos_domain_in_full_domain_sans_zero.instantiate()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})

# %%
neg_domain_in_full_domain_sans_zero
# Out:
# |- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %%
neg_domain_in_full_domain_sans_zero.instantiate()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})

# %%
first_sum_bound = first_sum.deduce_bound(alpha_l_sqrd_ineq)
# Out:
# first_sum_bound: {eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) <= (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
second_sum_bound = second_sum.deduce_bound(alpha_l_sqrd_ineq)
# Out:
# second_sum_bound: {eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}) <= (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
pos_domain_within_natpos
# Out:
# |- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq NaturalPos)

# %%
pos_domain_within_natpos.instantiate()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq NaturalPos

# %%
neg_domain_within_negint
# Out:
# |- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq IntegerNeg)

# %%
neg_domain_within_negint.instantiate()
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq IntegerNeg

# %%
all_abs_alpha_l_sqrd_are_real
# Out:
# |- forall_{l in Integer} (|alpha_{l}|^{2} in Real)

# %%
InSet(l, NaturalPos).prove(assumptions=(InSet(l, pos_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l in NaturalPos

# %%
InSet(l, IntegerNeg).prove(assumptions=(InSet(l, neg_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in IntegerNeg

# %%
all_abs_alpha_l_sqrd_are_real.instantiate(assumptions=(InSet(l, pos_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- |alpha_{l}|^{2} in Real

# %%
all_abs_alpha_l_sqrd_are_real.instantiate(assumptions=(InSet(l, neg_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- |alpha_{l}|^{2} in Real

# %%
scaled_delta_not_eq_nonzeroInt
# Out:
# |- forall_{l in Integer | l != 0} ((2^{t} * delta) != l)

# %%
scaled_delta_not_eq_nonzeroInt.instantiate(assumptions=(InSet(l, pos_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (2^{t} * delta) != l

# %%
scaled_delta_not_eq_nonzeroInt.instantiate(assumptions=(InSet(l, neg_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (2^{t} * delta) != l

# %%
from proveit.numbers import Real, Complex, ComplexNonZero
InSet(second_sum_bound.rhs.summand.denominator.factors[1], ComplexNonZero).prove((InSet(l, neg_domain),)+defaults.assumptions)
# Out:
# {eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta))^{2} in ComplexNonZero

# %%
bound_rhs = fail_sum_inst.rhs.deduce_bound([first_sum_bound, second_sum_bound])
# Out:
# bound_rhs: {eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))

# %%
not_yet_factored = fail_sum_inst.apply_transitivity(bound_rhs)
# Out:
# not_yet_factored: {eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))

# %%
not_yet_factored.inner_expr().rhs.factor(frac(one, four))
# Out:
# {eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in {1 .. 2^{t - 1} - 2}} (Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))))
# 1	instantiation	2, 3, 4	{eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	P(_a) : Pfail(eps) <= _a, x : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))), y : (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 2	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 3	instantiation	10, 5, 6	{eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	x : Pfail(eps), y : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}), z : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))
# 4	instantiation	45, 7, 8	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))) = ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	x : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))), y : ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))), z : (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 5	instantiation	9, 209	{eps in {1 .. 2^{t - 1} - 2}} |- Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
# 	eps : eps
# 6	instantiation	10, 11, 12	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	x : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}), y : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}), z : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))
# 7	instantiation	45, 13, 14	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))) = (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	x : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))), y : ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))), z : ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 8	instantiation	102, 15	{eps in {1 .. 2^{t - 1} - 2}} |- (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) = ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	x : (1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))), y : ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 9	conjecture		|- forall_{eps in {1 .. 2^{t - 1} - 2}} (Pfail(eps) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})))
# 10	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 11	instantiation	16, 21, 17, 20, 18	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}))
# 	a : Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}, x : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}, y : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (4 * (l - (2^{t} * delta))^{2})
# 12	instantiation	19, 20, 21, 22, 23	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2})) <= ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	a : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (4 * (l - (2^{t} * delta))^{2}), x : Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}, y : Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2})
# 13	instantiation	62, 24	{eps in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))) = (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	f(_a) : _a + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))), x : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (4 * (l - (2^{t} * delta))^{2}), y : (1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))
# 14	instantiation	62, 25	{eps in {1 .. 2^{t - 1} - 2}} |- (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))) = (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	f(_a) : ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + _a, x : Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2}), y : (1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))
# 15	instantiation	26, 199, 179, 105, 27, 28, 81, 82, 29, 30	{eps in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) = (((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) + ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
# 	i : 1, j : 2, k : 0, a : (1 / 4), b : (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))^{2}, Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta))^{2}), c : ()
# 16	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 17	modus ponens	31, 32	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) in Real
# 18	modus ponens	33, 34	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) <= (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2})))
# 19	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 20	modus ponens	35, 36	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real
# 21	modus ponens	37, 38	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}) in Real
# 22	modus ponens	39, 40	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real
# 23	modus ponens	41, 42	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}) <= (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})))
# 24	instantiation	45, 43, 44	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) = ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})))
# 	x : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (4 * (l - (2^{t} * delta))^{2}), y : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), z : (1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))
# 25	instantiation	45, 46, 47	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) = ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 	x : Sum_{l=eps + 1}^{2^{t - 1}} 1 / (4 * (l - (2^{t} * delta))^{2}), y : Sum_{l=eps + 1}^{2^{t - 1}} (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), z : (1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))
# 26	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} + ..b_{_a}.. + b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * c_{1} * ..c_{_a}.. * c_{k}) + ..(a_{1} * ..a_{_a}.. * a_{i} * b_{n} * c_{1} * ..c_{_a}.. * c_{k}).. + (a_{1} * ..a_{_a}.. * a_{i} * b_{j} * c_{1} * ..c_{_a}.. * c_{k})))]
# 27	instantiation	48	|- |(1 / 4)| = |(1, ..k.., 1)|
# 	a : 1 / 4
# 28	instantiation	99	|- |(Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))^{2}, Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta))^{2})| = |(1, ..k.., 2)|
# 	a : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} 1 / (l - (2^{t} * delta))^{2}, b : Sum_{l=eps + 1}^{2^{t - 1}} 1 / (l - (2^{t} * delta))^{2}
# 29	modus ponens	49, 90	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) in Complex
# 30	modus ponens	50, 96	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})) in Complex
# 31	instantiation	55	|- [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (|alpha_{l}|^{2} in Real)] => ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) in Real)
# 	P(l) : |alpha_{l}|^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(eps + 1)}, x : l
# 32	generalizaton	51	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (|alpha_{l}|^{2} in Real)
# 33	instantiation	57	|- [forall_{k in {-2^{t - 1} + 1 .. -(eps + 1)}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}) <= (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	a(l) : |alpha_{l}|^{2}, b(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), S : {-2^{t - 1} + 1 .. -(eps + 1)}
# 34	modus ponens	52, 59	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{y in {-2^{t - 1} + 1 .. -(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))
# 35	instantiation	55	|- [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)] => ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real)
# 	P(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), Q(l) : l in {-2^{t - 1} + 1 .. -(eps + 1)}, x : l
# 36	generalizaton	53	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)
# 37	instantiation	55	|- [forall_{l in {eps + 1 .. 2^{t - 1}}} (|alpha_{l}|^{2} in Real)] => ((Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}) in Real)
# 	P(l) : |alpha_{l}|^{2}, Q(l) : l in {eps + 1 .. 2^{t - 1}}, x : l
# 38	generalizaton	54	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {eps + 1 .. 2^{t - 1}}} (|alpha_{l}|^{2} in Real)
# 39	instantiation	55	|- [forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)] => ((Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real)
# 	P(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), Q(l) : l in {eps + 1 .. 2^{t - 1}}, x : l
# 40	generalizaton	56	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)
# 41	instantiation	57	|- [forall_{k in {eps + 1 .. 2^{t - 1}}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => ((Sum_{l=eps + 1}^{2^{t - 1}} |alpha_{l}|^{2}) <= (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))))
# 	a(l) : |alpha_{l}|^{2}, b(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), S : {eps + 1 .. 2^{t - 1}}
# 42	modus ponens	58, 59	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{y in {eps + 1 .. 2^{t - 1}}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))
# 43	instantiation	62, 60	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (4 * (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 	f(_a) : Sum(_a), x(l) : {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}., y(l) : {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
# 44	instantiation	102, 61	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))) = ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})))
# 	x : (1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})), y : Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / 4) * (1 / (l - (2^{t} * delta))^{2})
# 45	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 46	instantiation	62, 63	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 	f(_a) : Sum(_a), x(l) : {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}., y(l) : {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
# 47	instantiation	102, 64	{eps in {1 .. 2^{t - 1} - 2}} |- (Sum_{l=eps + 1}^{2^{t - 1}} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))) = ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))
# 	x : (1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})), y : Sum_{l=eps + 1}^{2^{t - 1}} (1 / 4) * (1 / (l - (2^{t} * delta))^{2})
# 48	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 49	instantiation	65	|- [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)] => ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) in Complex)
# 	P(l) : 1 / (l - (2^{t} * delta))^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(eps + 1)}, x : l
# 50	instantiation	65	|- [forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)] => ((Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})) in Complex)
# 	P(l) : 1 / (l - (2^{t} * delta))^{2}, Q(l) : l in {eps + 1 .. 2^{t - 1}}, x : l
# 51	instantiation	69, 180	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- |alpha_{l}|^{2} in Real
# 	l : l
# 52	instantiation	73, 66	{eps in {1 .. 2^{t - 1} - 2}} |- [forall_{k in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => [forall_{y in {-2^{t - 1} + 1 .. -(eps + 1)}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))]
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, B : {-2^{t - 1} + 1 .. -(eps + 1)}, P(k) : |alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})), x : k
# 53	instantiation	70, 187, 67, 68	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (1 / (4 * (l - (2^{t} * delta))^{2})) in Real
# 	a : 1, b : 4 * (l - (2^{t} * delta))^{2}
# 54	instantiation	69, 184	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- |alpha_{l}|^{2} in Real
# 	l : l
# 55	conjecture		|- forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Real)] => (Sum_{x | Q(x)} P(x) in Real))
# 56	instantiation	70, 187, 71, 72	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (1 / (4 * (l - (2^{t} * delta))^{2})) in Real
# 	a : 1, b : 4 * (l - (2^{t} * delta))^{2}
# 57	conjecture		|- forall_{a, b, S} ([forall_{k in S} (a(k) <= b(k))] => (Sum_{l in S} a(l) <= Sum_{l in S} b(l)))
# 58	instantiation	73, 74	{eps in {1 .. 2^{t - 1} - 2}} |- [forall_{k in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})))] => [forall_{y in {eps + 1 .. 2^{t - 1}}} (|alpha_{y}|^{2} <= (1 / (4 * (y - (2^{t} * delta))^{2})))]
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, B : {eps + 1 .. 2^{t - 1}}, P(k) : |alpha_{k}|^{2} <= (1 / (4 * (k - (2^{t} * delta))^{2})), x : k
# 59	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))
# 60	modus ponens	75, 76	{eps in {1 .. 2^{t - 1} - 2}} |- [l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.] = [l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.]
# 61	instantiation	77, 81, 82	{eps in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 	a_{1} : 1 / 4
# 62	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 63	modus ponens	78, 79	{eps in {1 .. 2^{t - 1} - 2}} |- [l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.] = [l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.]
# 64	instantiation	80, 81, 82	{eps in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 	a_{1} : 1 / 4
# 65	conjecture		|- forall_{P, Q} ([forall_{x | Q(x)} (P(x) in Complex)] => (Sum_{x | Q(x)} P(x) in Complex))
# 66	instantiation	83, 209	{eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	eps : eps
# 67	instantiation	84, 113, 129	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (4 * (l - (2^{t} * delta))^{2}) in Real
# 	a : 4, b : (l - (2^{t} * delta))^{2}
# 68	instantiation	85, 179, 86, 117, 130	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (4 * (l - (2^{t} * delta))^{2}) != 0
# 	n : 2, a : (4, (l - (2^{t} * delta))^{2})
# 69	conjecture		|- forall_{l in Integer} (|alpha_{l}|^{2} in Real)
# 70	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 71	instantiation	84, 113, 134	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (4 * (l - (2^{t} * delta))^{2}) in Real
# 	a : 4, b : (l - (2^{t} * delta))^{2}
# 72	instantiation	85, 179, 86, 117, 136	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (4 * (l - (2^{t} * delta))^{2}) != 0
# 	n : 2, a : (4, (l - (2^{t} * delta))^{2})
# 73	conjecture		|- forall_{A, B, P | A superset_eq B} ([forall_{x in A} P(x)] => [forall_{y in B} P(y)])
# 74	instantiation	87, 209	{eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	eps : eps
# 75	instantiation	91, 92, 107, 106, 93	|- [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))] => ([l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.] = [l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.])
# 	i : 1, f(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), g(l) : (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), Q(l) : l in {-2^{t - 1} + 1 .. -(eps + 1)}, a_{1} : l, b_{1} : l, c_{1} : l
# 76	generalizaton	88	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 77	modus ponens	89, 90	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{a_{1} in Complex} ((a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))))
# 78	instantiation	91, 92, 107, 106, 93	|- [forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))] => ([l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.] = [l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.])
# 	i : 1, f(l) : 1 / (4 * (l - (2^{t} * delta))^{2}), g(l) : (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), Q(l) : l in {eps + 1 .. 2^{t - 1}}, a_{1} : l, b_{1} : l, c_{1} : l
# 79	generalizaton	94	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})))
# 80	modus ponens	95, 96	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{a_{1} in Complex} ((a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))))
# 81	conjecture		|- |()| = |(1, ..a.., 0)|
# 82	instantiation	124, 125, 97, 98	|- (1 / 4) in Complex
# 	a : 1, b : 4
# 83	conjecture		|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 84	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 85	conjecture		|- forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)]
# 86	instantiation	99	|- |(4, (l - (2^{t} * delta))^{2})| = |(1, ..k.., 2)|
# 	a : 4, b : (l - (2^{t} * delta))^{2}
# 87	conjecture		|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 88	instantiation	102, 100	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
# 	x : (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), y : 1 / (4 * (l - (2^{t} * delta))^{2})
# 89	instantiation	104, 199, 105, 106, 107, 108, 109, 110, 111*	|- [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)] => [forall_{a_{1} in Complex} ((a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))))]
# 	i : 1, j : 1, k : 0, P(l) : 1 / (l - (2^{t} * delta))^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(eps + 1)}, b_{1} : l
# 90	generalizaton	101	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)
# 91	conjecture		|- forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, ..a_{_a}.., a_{i} | Q(a_{1}, ..a_{_a}.., a_{i})} (f(a_{1}, ..a_{_a}.., a_{i}) = g(a_{1}, ..a_{_a}.., a_{i}))] =>  \\ ([(b_{1}, ..b_{_a}.., b_{i}) -> {f(b_{1}, ..b_{_a}.., b_{i}) if Q(b_{1}, ..b_{_a}.., b_{i}).] =  \\ [(c_{1}, ..c_{_a}.., c_{i}) -> {g(c_{1}, ..c_{_a}.., c_{i}) if Q(c_{1}, ..c_{_a}.., c_{i}).]))]
# 92	conjecture		|- 1 in NaturalPos
# 93	instantiation	119	|- (c_{1}, ..c_{a}.., c_{1}) = (c_{1})
# 	f(_a) : c_{_a}, i : 1
# 94	instantiation	102, 103	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
# 	x : (1 / 4) * (1 / (l - (2^{t} * delta))^{2}), y : 1 / (4 * (l - (2^{t} * delta))^{2})
# 95	instantiation	104, 199, 105, 106, 107, 108, 109, 110, 111*	|- [forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)] => [forall_{a_{1} in Complex} ((a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))))]
# 	i : 1, j : 1, k : 0, P(l) : 1 / (l - (2^{t} * delta))^{2}, Q(l) : l in {eps + 1 .. 2^{t - 1}}, b_{1} : l
# 96	generalizaton	112	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta))^{2}) in Complex)
# 97	instantiation	195, 158, 113	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 98	instantiation	189, 157	|- 4 != 0
# 	n : 4
# 99	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 100	instantiation	116, 125, 117, 130, 118*	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) = (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	x : 1, y : 1, z : 4, w : (l - (2^{t} * delta))^{2}
# 101	instantiation	124, 125, 114, 115	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (1 / (l - (2^{t} * delta))^{2}) in Complex
# 	a : 1, b : (l - (2^{t} * delta))^{2}
# 102	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 103	instantiation	116, 125, 117, 136, 118*	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) = (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	x : 1, y : 1, z : 4, w : (l - (2^{t} * delta))^{2}
# 104	conjecture		|- forall_{i, j, k in Natural} [forall_{P, Q} ([forall_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (P(b_{1}, ..b_{_a}.., b_{j}) in Complex)] => [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ Sum_{b_{1}, ..b_{_a}.., b_{j} | Q(b_{1}, ..b_{_a}.., b_{j})} (a_{1} * ..a_{_a}.. * a_{i} * P(b_{1}, ..b_{_a}.., b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))])]
# 105	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 106	instantiation	119	|- (b_{1}, ..b_{a}.., b_{1}) = (b_{1})
# 	f(_a) : b_{_a}, i : 1
# 107	instantiation	119	|- (a_{1}, ..a_{_a}.., a_{1}) = (a_{1})
# 	f(_a) : a_{_a}, i : 1
# 108	instantiation	120, 121	|- (c_{1}, ..c_{a}.., c_{0}) = ()
# 	f(_a) : c_{_a}, i : 1, j : 0
# 109	instantiation	119	|- (a_{1} in Complex, ..a_{_a} in Complex.., a_{1} in Complex) = (a_{1} in Complex)
# 	f(_a) : a_{_a} in Complex, i : 1
# 110	instantiation	120, 121	|- (c_{1} in Complex, ..c_{a} in Complex.., c_{0} in Complex) = ()
# 	f(_a) : c_{_a} in Complex, i : 1, j : 0
# 111	instantiation	122, 123	|- and(a_{1} in Complex) = (a_{1} in Complex)
# 	A : a_{1} in Complex
# 112	instantiation	124, 125, 126, 127	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (1 / (l - (2^{t} * delta))^{2}) in Complex
# 	a : 1, b : (l - (2^{t} * delta))^{2}
# 113	instantiation	195, 196, 128	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 114	instantiation	195, 158, 129	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta))^{2} in Complex
# 	A : Real, B : Complex, x : (l - (2^{t} * delta))^{2}
# 115	instantiation	135, 130	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta))^{2} != 0
# 	x : (l - (2^{t} * delta))^{2}
# 116	conjecture		|- forall_{x, y in Complex} [forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w)))]
# 117	instantiation	195, 131, 132	|- 4 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 4
# 118	conjecture		|- (1 * 1) = 1
# 119	conjecture		|- forall_{f, i} ((f(i), ..f(a).., f(i)) = (f(i)))
# 120	axiom		|- forall_{f, i, j | (j + 1) = i} ((f(i), ..f(a).., f(j)) = ())
# 	proveit.core_expr_types.tuples.empty_range_def
# 121	conjecture		|- (0 + 1) = 1
# 122	conjecture		|- forall_{A in BOOLEAN} (and(A) = A)
# 123	instantiation	133	|- (a_{1} in Complex) in BOOLEAN
# 	x : a_{1}
# 124	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 125	instantiation	195, 158, 187	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 126	instantiation	195, 158, 134	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta))^{2} in Complex
# 	A : Real, B : Complex, x : (l - (2^{t} * delta))^{2}
# 127	instantiation	135, 136	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta))^{2} != 0
# 	x : (l - (2^{t} * delta))^{2}
# 128	instantiation	195, 183, 137	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 129	instantiation	141, 154, 179	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta))^{2} in Real
# 	a : l - (2^{t} * delta), b : 2
# 130	instantiation	142, 138, 144	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta))^{2} in ComplexNonZero
# 	a : l - (2^{t} * delta), b : 2
# 131	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 132	instantiation	195, 139, 140	|- 4 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 4
# 133	conjecture		|- forall_{x} ((x in Complex) in BOOLEAN)
# 134	instantiation	141, 159, 179	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta))^{2} in Real
# 	a : l - (2^{t} * delta), b : 2
# 135	conjecture		|- forall_{x in ComplexNonZero} (x != 0)
# 136	instantiation	142, 143, 144	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta))^{2} in ComplexNonZero
# 	a : l - (2^{t} * delta), b : 2
# 137	instantiation	195, 178, 145	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 138	instantiation	150, 146, 147	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta)) in ComplexNonZero
# 	x : l - (2^{t} * delta)
# 139	conjecture		|- RationalNonZero proper_subset RealNonZero
# 140	instantiation	195, 148, 149	|- 4 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 4
# 141	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 142	conjecture		|- forall_{a in ComplexNonZero, b in Complex} (a^{b} in ComplexNonZero)
# 143	instantiation	150, 151, 152	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta)) in ComplexNonZero
# 	x : l - (2^{t} * delta)
# 144	instantiation	195, 158, 153	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 145	conjecture		|- 4 in Natural
# 146	instantiation	195, 158, 154	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta)) in Complex
# 	A : Real, B : Complex, x : l - (2^{t} * delta)
# 147	instantiation	160, 155	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta)) != 0
# 	a : l, b : 2^{t} * delta
# 148	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 149	instantiation	195, 156, 157	|- 4 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 4
# 150	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 151	instantiation	195, 158, 159	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta)) in Complex
# 	A : Real, B : Complex, x : l - (2^{t} * delta)
# 152	instantiation	160, 161	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta)) != 0
# 	a : l, b : 2^{t} * delta
# 153	instantiation	195, 196, 162	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 154	instantiation	165, 163, 167	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (l - (2^{t} * delta)) in Real
# 	a : l, b : -(2^{t} * delta)
# 155	instantiation	168, 164	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l != (2^{t} * delta)
# 	x : 2^{t} * delta, y : l
# 156	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 157	conjecture		|- 4 in NaturalPos
# 158	conjecture		|- Real proper_subset Complex
# 159	instantiation	165, 166, 167	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (l - (2^{t} * delta)) in Real
# 	a : l, b : -(2^{t} * delta)
# 160	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 161	instantiation	168, 169	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l != (2^{t} * delta)
# 	x : 2^{t} * delta, y : l
# 162	instantiation	195, 183, 170	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 163	instantiation	195, 196, 171	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in Real
# 	A : Rational, B : Real, x : l
# 164	instantiation	176, 180, 172	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- (2^{t} * delta) != l
# 	l : l
# 165	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 166	instantiation	195, 196, 173	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 167	instantiation	174, 175	|- (-(2^{t} * delta)) in Real
# 	a : 2^{t} * delta
# 168	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 169	instantiation	176, 184, 177	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- (2^{t} * delta) != l
# 	l : l
# 170	instantiation	195, 178, 179	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 171	instantiation	195, 183, 180	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 172	instantiation	181, 182	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l != 0
# 	a : l
# 173	instantiation	195, 183, 184	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 174	conjecture		|- forall_{a in Real} ((-a) in Real)
# 175	instantiation	185, 186, 187, 188	|- (2^{t} * delta) in Real
# 	a : 0, b : 1, x : 2^{t} * delta
# 176	conjecture		|- forall_{l in Integer | l != 0} ((2^{t} * delta) != l)
# 177	instantiation	189, 194	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l != 0
# 	n : l
# 178	conjecture		|- Natural proper_subset Integer
# 179	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 180	instantiation	195, 190, 192	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in Integer
# 	A : IntegerNeg, B : Integer, x : l
# 181	conjecture		|- forall_{a in IntegerNonZero} (a != 0)
# 182	instantiation	195, 191, 192	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in IntegerNonZero
# 	A : IntegerNeg, B : IntegerNonZero, x : l
# 183	conjecture		|- Integer proper_subset Rational
# 184	instantiation	195, 193, 194	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : NaturalPos, B : Integer, x : l
# 185	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 186	instantiation	195, 196, 197	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 187	instantiation	202, 198, 199	|- 1 in Real
# 	A : Natural, B : Real, x : 1
# 188	conjecture		|- (2^{t} * delta) in [0,1)
# 189	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 190	conjecture		|- IntegerNeg proper_subset Integer
# 191	conjecture		|- IntegerNeg proper_subset IntegerNonZero
# 192	instantiation	202, 200, 201	{eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in IntegerNeg
# 	A : {-2^{t - 1} + 1 .. -(eps + 1)}, B : IntegerNeg, x : l
# 193	conjecture		|- NaturalPos proper_subset Integer
# 194	instantiation	202, 203, 204	{eps in {1 .. 2^{t - 1} - 2}, l in {eps + 1 .. 2^{t - 1}}} |- l in NaturalPos
# 	A : {eps + 1 .. 2^{t - 1}}, B : NaturalPos, x : l
# 195	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 196	conjecture		|- Rational proper_subset Real
# 197	conjecture		|- 0 in Rational
# 198	instantiation	205, 206	|- Natural subset_eq Real
# 	A : Natural, B : Real
# 199	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 200	instantiation	207, 209	{eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq IntegerNeg
# 	eps : eps
# 201	assumption		{l in {-2^{t - 1} + 1 .. -(eps + 1)}} |- l in {-2^{t - 1} + 1 .. -(eps + 1)}
# 202	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 203	instantiation	208, 209	{eps in {1 .. 2^{t - 1} - 2}} |- {eps + 1 .. 2^{t - 1}} subset_eq NaturalPos
# 	eps : eps
# 204	assumption		{l in {eps + 1 .. 2^{t - 1}}} |- l in {eps + 1 .. 2^{t - 1}}
# 205	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 206	conjecture		|- Natural proper_subset Real
# 207	conjecture		|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq IntegerNeg)
# 208	conjecture		|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({eps + 1 .. 2^{t - 1}} subset_eq NaturalPos)
# 209	assumption		{eps in {1 .. 2^{t - 1} - 2}} |- eps in {1 .. 2^{t - 1} - 2}
