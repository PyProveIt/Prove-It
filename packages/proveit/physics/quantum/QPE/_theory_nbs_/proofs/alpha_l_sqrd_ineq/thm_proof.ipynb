# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#alpha_l_sqrd_ineq">alpha_l_sqrd_ineq</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit.numbers import zero, greater
from proveit.physics.quantum.QPE import (
    alpha_l_summed_abs, delta_is_real, two_pow_t_is_nat_pos, 
    scaled_delta_minus_l__in__real, scaled_abs_delta_diff_interval,
    delta_not_eq_scaledNonzeroInt, delta_is_real,
    l_non_zero, all_abs_alpha_l_sqrd_are_real,
    all_abs_alpha_l_are_nonneg)
theory = proveit.Theory() # the theorem's theory

# %%
# %proving alpha_l_sqrd_ineq
# Out:
# alpha_l_sqrd_ineq: forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
defaults.assumptions = alpha_l_sqrd_ineq.conditions
# Out:
# defaults.assumptions: (l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %% [markdown]
# ## Instantiate some needed theorems of this package

# %%
l_non_zero.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in IntegerNonZero

# %%
scaled_delta_minus_l__in__real.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in Real

# %%
scaled_abs_delta_diff_interval.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in (0,pi / 2]

# %%
delta_not_eq_scaledNonzeroInt.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- delta != (l / 2^{t})

# %%
all_abs_alpha_l_are_nonneg.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in RealNonNeg

# %%
all_abs_alpha_l_sqrd_are_real.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} in Real

# %%
alpha_l_summed_abs_inst = alpha_l_summed_abs.instantiate()
# Out:
# alpha_l_summed_abs_inst: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))

# %% [markdown]
# ## Perform a chord length simplification (for a circle in the complex plane) in the denominator

# %%
alpha_l_summed_abs_inst_v2 = \
    alpha_l_summed_abs_inst.inner_expr().rhs.denominator.operands[1].chord_length_simplify()
alpha_l_summed_abs_inst_v2 = alpha_l_summed_abs_inst_v2.inner_expr().rhs.denominator.simplify()
# Out:
# alpha_l_summed_abs_inst_v2: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))

# %% [markdown]
# ## Bound the numerator and the denominator of the above right hand side

# %% [markdown]
# ### Use a triangle inequality for the numerator

# %%
numerator = alpha_l_summed_abs_inst_v2.rhs.numerator
# Out:
# numerator: |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|

# %%
numer_bound = numerator.deduce_triangle_bound()
# Out:
# numer_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= 2

# %% [markdown]
# ### Bound the sine in the denominator by a line

# %%
sin_factor = alpha_l_summed_abs_inst_v2.rhs.denominator.operands[2]
# Out:
# sin_factor: sin(pi * |delta - (l / 2^{t})|)

# %%
sin_factor_bound = sin_factor.deduce_linear_bound()
# Out:
# sin_factor_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) >= (2 * |delta - (l / 2^{t})|)

# %%
bound_is_positive = sin_factor_bound.rhs.deduce_positive()
# Out:
# bound_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) > 0

# %%
sin_factor_is_positive = sin_factor_bound.apply_transitivity(bound_is_positive)
# Out:
# sin_factor_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) > 0

# %%
demoninator = alpha_l_summed_abs_inst_v2.rhs.denominator
# Out:
# demoninator: 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)

# %%
denom_bound = demoninator.deduce_bound(sin_factor_bound)
# Out:
# denom_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) >= (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))

# %%
denom_is_positive = demoninator.deduce_bound(sin_factor_is_positive).inner_expr().normal_lhs.simplify()
# Out:
# denom_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))

# %% [markdown]
# ### Now we use the numerator and denominator bounds to bound $|\alpha_l|$

# %%
rhs_bound = alpha_l_summed_abs_inst_v2.rhs.deduce_bound([numer_bound, denom_bound]).inner_expr().rhs.simplify()
# Out:
# rhs_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))

# %%
alpha_l_bound = alpha_l_summed_abs_inst_v2.apply_transitivity(rhs_bound)
# Out:
# alpha_l_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))

# %% [markdown]
# ## Simplify (rearrange) and square both sides

# %%
alpha_l_bound_v2 = alpha_l_bound.inner_expr().rhs.denominator.commute(0, 1)
# Out:
# alpha_l_bound_v2: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))

# %%
alpha_l_bound_v3 = alpha_l_bound_v2.inner_expr().rhs.denominator.associate(1, 2)
# Out:
# alpha_l_bound_v3: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * (2^{t} * |delta - (l / 2^{t})|)))

# %%
alpha_l_bound_v4 = alpha_l_bound_v3.inner_expr().rhs.denominator.operands[1].distribute(1)
alpha_l_bound_v4 = alpha_l_bound_v4.inner_expr().rhs.simplify()
# Out:
# alpha_l_bound_v4: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * |(2^{t} * delta) - l|))

# %%
alpha_l_bound_v5 = alpha_l_bound_v4.inner_expr().rhs.denominator.operands[1].reverse_difference()
# Out:
# alpha_l_bound_v5: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * |l - (2^{t} * delta)|))

# %%
alpha_l_sqrd_bound_v1 = alpha_l_bound_v5.square_both_sides()
# Out:
# alpha_l_sqrd_bound_v1: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1 / (2 * |l - (2^{t} * delta)|))^{2}

# %%
alpha_l_sqrd_bound_v2 = alpha_l_sqrd_bound_v1.inner_expr().rhs.distribute()
# Out:
# alpha_l_sqrd_bound_v2: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1^{2} / (2 * |l - (2^{t} * delta)|)^{2})

# %%
alpha_l_sqrd_bound_v3 = alpha_l_sqrd_bound_v2.inner_expr().rhs.denominator.distribute()
alpha_l_sqrd_bound_v3 = alpha_l_sqrd_bound_v3.inner_expr().rhs.simplify()
# Out:
# alpha_l_sqrd_bound_v3: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2}))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))
# 1	instantiation	206, 2, 3	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	P(_a) : |alpha_{l}|^{2} <= _a, x : 1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}), y : 1 / (4 * (l - (2^{t} * delta))^{2})
# 2	instantiation	206, 4, 5	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}))
# 	P(_a) : |alpha_{l}|^{2} <= (1^{2} / _a), x : (2 * |l - (2^{t} * delta)|)^{2}, y : 2^{2} * |l - (2^{t} * delta)|^{2}
# 3	instantiation	365, 6, 7	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2})) = (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	x : 1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}), y : 1 / (2^{2} * |l - (2^{t} * delta)|^{2}), z : 1 / (4 * (l - (2^{t} * delta))^{2})
# 4	instantiation	206, 8, 9	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1^{2} / (2 * |l - (2^{t} * delta)|)^{2})
# 	P(_a) : |alpha_{l}|^{2} <= _a, x : (1 / (2 * |l - (2^{t} * delta)|))^{2}, y : 1^{2} / (2 * |l - (2^{t} * delta)|)^{2}
# 5	instantiation	10, 389, 11, 396	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|)^{2} = (2^{2} * |l - (2^{t} * delta)|^{2})
# 	a : 2, b : |l - (2^{t} * delta)|, n : 2
# 6	instantiation	337, 12	|- (1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2})) = (1 / (2^{2} * |l - (2^{t} * delta)|^{2}))
# 	f(_a) : _a / (2^{2} * |l - (2^{t} * delta)|^{2}), x : 1^{2}, y : 1
# 7	instantiation	337, 13	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2^{2} * |l - (2^{t} * delta)|^{2})) = (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	f(_a) : 1 / _a, x : 2^{2} * |l - (2^{t} * delta)|^{2}, y : 4 * (l - (2^{t} * delta))^{2}
# 8	instantiation	14, 402, 15, 16, 17, 18	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1 / (2 * |l - (2^{t} * delta)|))^{2}
# 	a : 2, x : |alpha_{l}|, y : 1 / (2 * |l - (2^{t} * delta)|)
# 9	instantiation	19, 231, 20, 396, 25	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |l - (2^{t} * delta)|))^{2} = (1^{2} / (2 * |l - (2^{t} * delta)|)^{2})
# 	a : 1, b : 2 * |l - (2^{t} * delta)|, n : 2
# 10	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos} ((a * b)^{n} = (a^{n} * b^{n}))
# 11	instantiation	435, 413, 38	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in Complex
# 	A : Real, B : Complex, x : |l - (2^{t} * delta)|
# 12	instantiation	21, 389	|- 1^{2} = 1
# 	x : 2
# 13	instantiation	365, 22, 23	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{2} * |l - (2^{t} * delta)|^{2}) = (4 * (l - (2^{t} * delta))^{2})
# 	x : 2^{2} * |l - (2^{t} * delta)|^{2}, y : 4 * |l - (2^{t} * delta)|^{2}, z : 4 * (l - (2^{t} * delta))^{2}
# 14	conjecture		|- forall_{a, x, y in Real | 0 <= x <= y, a > 0} (x^{a} <= y^{a})
# 15	instantiation	435, 24, 36	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in Real
# 	A : RealNonNeg, B : Real, x : |alpha_{l}|
# 16	instantiation	422, 258, 30, 25	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |l - (2^{t} * delta)|)) in Real
# 	a : 1, b : 2 * |l - (2^{t} * delta)|
# 17	instantiation	26, 27, 28	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (0 <= |alpha_{l}|) and (|alpha_{l}| <= (1 / (2 * |l - (2^{t} * delta)|)))
# 	A : 0 <= |alpha_{l}|, B : |alpha_{l}| <= (1 / (2 * |l - (2^{t} * delta)|))
# 18	instantiation	29, 302	|- 0 < 2
# 	q : 2
# 19	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos | b != 0} ((a / b)^{n} = (a^{n} / b^{n}))
# 20	instantiation	435, 413, 30	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in Complex
# 	A : Real, B : Complex, x : 2 * |l - (2^{t} * delta)|
# 21	conjecture		|- forall_{x in Complex} (1^{x} = 1)
# 22	instantiation	337, 31	|- (2^{2} * |l - (2^{t} * delta)|^{2}) = (4 * |l - (2^{t} * delta)|^{2})
# 	f(_a) : _a * |l - (2^{t} * delta)|^{2}, x : 2^{2}, y : 4
# 23	instantiation	337, 32	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (4 * |l - (2^{t} * delta)|^{2}) = (4 * (l - (2^{t} * delta))^{2})
# 	f(_a) : 4 * _a, x : |l - (2^{t} * delta)|^{2}, y : (l - (2^{t} * delta))^{2}
# 24	conjecture		|- RealNonNeg proper_subset Real
# 25	instantiation	186, 416, 33, 189, 34	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) != 0
# 	n : 2, a : (2, |l - (2^{t} * delta)|)
# 26	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 27	instantiation	35, 36	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 <= |alpha_{l}|
# 	x : |alpha_{l}|
# 28	instantiation	206, 37, 53	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * |l - (2^{t} * delta)|))
# 	P(_a) : |alpha_{l}| <= (1 / (2 * _a)), x : |(2^{t} * delta) - l|, y : |l - (2^{t} * delta)|
# 29	conjecture		|- forall_{q in RationalPos} (q > 0)
# 30	instantiation	327, 402, 38	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in Real
# 	a : 2, b : |l - (2^{t} * delta)|
# 31	instantiation	365, 39, 40	|- 2^{2} = 4
# 	x : 2^{2}, y : 2 * 2, z : 4
# 32	instantiation	41, 42	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)|^{2} = (l - (2^{t} * delta))^{2}
# 	a : l - (2^{t} * delta)
# 33	instantiation	400	|- |(2, |l - (2^{t} * delta)|)| = |(1, ..k.., 2)|
# 	a : 2, b : |l - (2^{t} * delta)|
# 34	instantiation	206, 43, 44	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in ComplexNonZero
# 	P(_a) : _a in ComplexNonZero, x : 2^{t} * |delta - (l / 2^{t})|, y : |l - (2^{t} * delta)|
# 35	conjecture		|- forall_{x in RealNonNeg} (x >= 0)
# 36	instantiation	45, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in RealNonNeg
# 	l : l
# 37	instantiation	206, 46, 47	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * |(2^{t} * delta) - l|))
# 	P(_a) : |alpha_{l}| <= _a, x : 1 / (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|), y : 1 / (2 * |(2^{t} * delta) - l|)
# 38	instantiation	206, 328, 53	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in Real
# 	P(_a) : _a in Real, x : |(2^{t} * delta) - l|, y : |l - (2^{t} * delta)|
# 39	instantiation	365, 48, 49	|- 2^{2} = (2 * 2)
# 	x : 2^{2}, y : 2 * ..2 repeats.. * 2, z : 2 * 2
# 40	conjecture		|- (2 * 2) = 4
# 41	conjecture		|- forall_{a in Real} (|a|^{2} = a^{2})
# 42	instantiation	417, 423, 50	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l - (2^{t} * delta)) in Real
# 	a : l, b : -(2^{t} * delta)
# 43	instantiation	435, 221, 51	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t} * |delta - (l / 2^{t})|
# 44	instantiation	365, 52, 53	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) = |l - (2^{t} * delta)|
# 	x : 2^{t} * |delta - (l / 2^{t})|, y : |(2^{t} * delta) - l|, z : |l - (2^{t} * delta)|
# 45	conjecture		|- forall_{l in Integer} (|alpha_{l}| in RealNonNeg)
# 46	instantiation	206, 54, 62	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|))
# 	P(_a) : |alpha_{l}| <= (1 / (2 * _a)), x : 2^{t} * |delta - (l / 2^{t})|, y : |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
# 47	instantiation	337, 55	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)) = (1 / (2 * |(2^{t} * delta) - l|))
# 	f(_a) : 1 / _a, x : 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|, y : 2 * |(2^{t} * delta) - l|
# 48	instantiation	56, 396, 389	|- 2^{2} = (2 * ..2 repeats.. * 2)
# 	n : 2, x : 2
# 49	instantiation	57, 416, 58, 59, 60	|- (2 * ..2 repeats.. * 2) = (2 * 2)
# 	n : 2, f(_a_{1}, .._a_{_b}.., _a_{2}) : _a_{1} * .._a_{_b}.. * _a_{2}, x : (2, ..2 repeats.., 2), y : (2, 2)
# 50	instantiation	420, 75	|- (-(2^{t} * delta)) in Real
# 	a : 2^{t} * delta
# 51	instantiation	435, 391, 61	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2^{t} * |delta - (l / 2^{t})|
# 52	instantiation	365, 62, 67	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) = |(2^{t} * delta) - l|
# 	x : 2^{t} * |delta - (l / 2^{t})|, y : |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|, z : |(2^{t} * delta) - l|
# 53	instantiation	63, 64, 232	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| = |l - (2^{t} * delta)|
# 	a : 2^{t} * delta, b : l
# 54	instantiation	206, 65, 66	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * (2^{t} * |delta - (l / 2^{t})|)))
# 	P(_a) : |alpha_{l}| <= (1 / _a), x : 2 * 2^{t} * |delta - (l / 2^{t})|, y : 2 * (2^{t} * |delta - (l / 2^{t})|)
# 55	instantiation	337, 67	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|) = (2 * |(2^{t} * delta) - l|)
# 	f(_a) : 2 * _a, x : |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|, y : |(2^{t} * delta) - l|
# 56	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} (x^{n} = (x * ..n repeats.. * x))]
# 57	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, ..x_{_a}.., x_{n}, y_{1}, ..y_{_a}.., y_{n} | (x_{1}, ..x_{_a}.., x_{n}) = (y_{1}, ..y_{_a}.., y_{n})} (f(x_{1}, ..x_{_a}.., x_{n}) =  \\ f(y_{1}, ..y_{_a}.., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 58	instantiation	68, 416	|- |(2, ..2 repeats.., 2)| = |(1, ..k.., 2)|
# 	i : 2, f(i) : 2
# 59	instantiation	400	|- |(2, 2)| = |(1, ..k.., 2)|
# 	a : 2, b : 2
# 60	instantiation	69	|- (2, ..2 repeats.., 2) = (2, 2)
# 	x : 2
# 61	instantiation	271, 180, 273	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) in RealPos
# 	a : 2^{t}, b : |delta - (l / 2^{t})|
# 62	instantiation	70, 383, 416, 384, 185, 387, 71*, 131, 72, 73, 74	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) = |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
# 	i : 1, j : 2, k : 0, a : (2^{t}), c : (), b : (delta, -(l / 2^{t}))
# 63	conjecture		|- forall_{a, b in Complex} (|a - b| = |b - a|)
# 64	instantiation	435, 413, 75	|- (2^{t} * delta) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta
# 65	instantiation	206, 76, 77	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	P(_a) : |alpha_{l}| <= (1 / _a), x : 2^{t} * 2 * |delta - (l / 2^{t})|, y : 2 * 2^{t} * |delta - (l / 2^{t})|
# 66	instantiation	382, 383, 416, 384, 380, 78, 387, 389, 284, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * |delta - (l / 2^{t})|) = (2 * (2^{t} * |delta - (l / 2^{t})|))
# 	i : 1, j : 2, k : 0, a : (2), b : (2^{t}, |delta - (l / 2^{t})|), c : ()
# 67	instantiation	337, 79	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))| = |(2^{t} * delta) - l|
# 	f(_a) : |_a|, x : (2^{t} * delta) + (2^{t} * (-(l / 2^{t}))), y : (2^{t} * delta) - l
# 68	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), ..f(a).., f(i))| = |(1, ..k.., i)|)]
# 69	conjecture		|- forall_{x} ((x, ..2 repeats.., x) = (x, x))
# 70	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, c_{1}, ..c_{_a}.., c_{k} in RealNonNeg} [forall_{b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * |b_{1} + ..b_{_a}.. + b_{j}| * c_{1} * ..c_{_a}.. * c_{k}) =  \\ |(a_{1} * ..a_{_a}.. * a_{i} * b_{1} * c_{1} * ..c_{_a}.. * c_{k}) + ..(a_{1} * ..a_{_a}.. * a_{i} * b_{n} * c_{1} * ..c_{_a}.. * c_{k}).. + (a_{1} * ..a_{_a}.. * a_{i} * b_{j} * c_{1} * ..c_{_a}.. * c_{k})|)]]
# 71	instantiation	80, 81	|- and(2^{t} in RealNonNeg) = (2^{t} in RealNonNeg)
# 	A : 2^{t} in RealNonNeg
# 72	instantiation	400	|- |(delta, -(l / 2^{t}))| = |(1, ..k.., 2)|
# 	a : delta, b : -(l / 2^{t})
# 73	instantiation	435, 413, 418	|- delta in Complex
# 	A : Real, B : Complex, x : delta
# 74	instantiation	371, 104	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in Complex
# 	a : l / 2^{t}
# 75	instantiation	327, 424, 418	|- (2^{t} * delta) in Real
# 	a : 2^{t}, b : delta
# 76	instantiation	124, 82, 83	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| <= (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	P(_a) : _a <= (1 / (2^{t} * 2 * |delta - (l / 2^{t})|)), x : |alpha_{l}|, y : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 77	instantiation	84, 384, 383, 387, 380, 381, 284, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * |delta - (l / 2^{t})|) = (2 * 2^{t} * |delta - (l / 2^{t})|)
# 	i : 0, j : 1, k : 1, a : (), b : 2^{t}, c : (2), d : (|delta - (l / 2^{t})|)
# 78	instantiation	400	|- |(2^{t}, |delta - (l / 2^{t})|)| = |(1, ..k.., 2)|
# 	a : 2^{t}, b : |delta - (l / 2^{t})|
# 79	instantiation	337, 85	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) + (2^{t} * (-(l / 2^{t})))) = ((2^{t} * delta) - l)
# 	f(_a) : (2^{t} * delta) + _a, x : 2^{t} * (-(l / 2^{t})), y : -l
# 80	conjecture		|- forall_{A in BOOLEAN} (and(A) = A)
# 81	instantiation	86, 87, 131	|- (2^{t} in RealNonNeg) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : 2^{t} in RealNonNeg
# 82	instantiation	206, 88, 89	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	P(_a) : (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= _a, x : 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)), y : 1 / (2^{t} * 2 * |delta - (l / 2^{t})|)
# 83	instantiation	206, 90, 91	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
# 	P(_a) : |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / _a), x : 2^{t} * (2 * sin(pi * |delta - (l / 2^{t})|)), y : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
# 84	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b, c_{1}, ..c_{_a}.., c_{j}, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b * c_{1} * ..c_{_a}.. * c_{j} * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c_{1} * ..c_{_a}.. * c_{j} * b * d_{1} * ..d_{_a}.. * d_{k}))]
# 85	instantiation	365, 92, 93	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (-(l / 2^{t}))) = (-l)
# 	x : 2^{t} * (-(l / 2^{t})), y : -(2^{t} * (l / 2^{t})), z : -l
# 86	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 87	conjecture		|- TRUE in BOOLEAN
# 88	instantiation	94, 95, 96	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)))
# 	x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), y : 2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), z : 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))
# 89	instantiation	365, 97, 98	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))) = (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	x : 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)), y : 2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|), z : 1 / (2^{t} * 2 * |delta - (l / 2^{t})|)
# 90	instantiation	206, 99, 100	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * (2 * sin(pi * |delta - (l / 2^{t})|))))
# 	P(_a) : |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * _a)), x : |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|, y : 2 * sin(pi * |delta - (l / 2^{t})|)
# 91	instantiation	335, 383, 416, 384, 185, 101, 387, 284, 389, 102	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (2 * sin(pi * |delta - (l / 2^{t})|))) = (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	i : 1, j : 2, k : 0, a : (2^{t}), b : (2, sin(pi * |delta - (l / 2^{t})|)), c : ()
# 92	instantiation	103, 284, 104	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (-(l / 2^{t}))) = (-(2^{t} * (l / 2^{t})))
# 	x : 2^{t}, y : l / 2^{t}
# 93	instantiation	337, 105	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(2^{t} * (l / 2^{t}))) = (-l)
# 	f(_a) : -_a, x : 2^{t} * (l / 2^{t}), y : l
# 94	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 95	instantiation	106, 128, 107, 402, 108, 129	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
# 	a : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|), x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : 2
# 96	instantiation	109, 324, 110, 111, 112	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)))
# 	a : 2, x : 2^{t} * 2 * (2 * |delta - (l / 2^{t})|), y : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
# 97	instantiation	337, 126	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))) = (2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|))
# 	f(_a) : 2 / _a, x : 2^{t} * 2 * (2 * |delta - (l / 2^{t})|), y : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|
# 98	instantiation	365, 113, 114	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)) = (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	x : 2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|), y : 2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|)), z : 1 / (2^{t} * 2 * |delta - (l / 2^{t})|)
# 99	instantiation	115, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|))
# 	l : l
# 100	instantiation	171, 362, 312, 238*, 116*, 117*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}| = (2 * sin(pi * |delta - (l / 2^{t})|))
# 	a : 0, b : 2 * pi * (delta - (l / 2^{t}))
# 101	instantiation	400	|- |(2, sin(pi * |delta - (l / 2^{t})|))| = |(1, ..k.., 2)|
# 	a : 2, b : sin(pi * |delta - (l / 2^{t})|)
# 102	instantiation	435, 413, 151	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) in Complex
# 	A : Real, B : Complex, x : sin(pi * |delta - (l / 2^{t})|)
# 103	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 104	instantiation	435, 413, 421	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in Complex
# 	A : Real, B : Complex, x : l / 2^{t}
# 105	instantiation	206, 118, 119	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (l / 2^{t})) = l
# 	P(_a) : (2^{t} * (l / 2^{t})) = _a, x : (1 / 1) * (l / 1), y : l
# 106	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 107	instantiation	124, 120, 121	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| in Real
# 	P(_a) : _a in Real, x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : 2 * sin(pi * |(2^{t} * delta) - l|)
# 108	instantiation	206, 122, 123	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= 2
# 	P(_a) : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= _a, x : 1 + 1, y : 2
# 109	conjecture		|- forall_{a in RealNonNeg} [forall_{x, y in RealPos | x <= y} ((a / x) >= (a / y))]
# 110	instantiation	124, 125, 126	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) in RealPos
# 	P(_a) : _a in RealPos, x : 2^{t} * 2 * (2 * |delta - (l / 2^{t})|), y : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|
# 111	instantiation	127, 128, 129	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) in RealPos
# 	a : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
# 112	instantiation	130, 416, 384, 183, 387, 131, 324, 217	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) <= (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	i : 2, j : 0, x : 2 * |delta - (l / 2^{t})|, y : sin(pi * |delta - (l / 2^{t})|), a : (2^{t}, 2), b : ()
# 113	instantiation	337, 132	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)) = (2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|)))
# 	f(_a) : 2 / _a, x : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|, y : 2 * (2^{t} * 2 * |delta - (l / 2^{t})|)
# 114	instantiation	133, 189, 134	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|))) = (1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	x : 2, y : 2^{t} * 2 * |delta - (l / 2^{t})|
# 115	conjecture		|- forall_{l in Integer} (|alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|)))
# 116	instantiation	259, 135	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * (2 * pi * (delta - (l / 2^{t})))} = e^{2 * pi * i * (delta - (l / 2^{t}))}
# 	x : e^{2 * pi * i * (delta - (l / 2^{t}))}, y : e^{i * (2 * pi * (delta - (l / 2^{t})))}
# 117	instantiation	365, 136, 137	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|0 - (2 * pi * (delta - (l / 2^{t})))| / 2) = (pi * |delta - (l / 2^{t})|)
# 	x : |0 - (2 * pi * (delta - (l / 2^{t})))| / 2, y : (2 * pi * |delta - (l / 2^{t})|) / 2, z : pi * |delta - (l / 2^{t})|
# 118	instantiation	206, 138, 139	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (l / 2^{t})) = ((1 / 1) * (l / 1))
# 	P(_a) : _a = ((1 / 1) * (l / 1)), x : ((1 * 2^{t}) / 1) * (l / (2^{t} * 1)), y : 2^{t} * (l / 2^{t})
# 119	instantiation	365, 140, 141	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((1 / 1) * (l / 1)) = l
# 	x : (1 / 1) * (l / 1), y : 1 * l, z : l
# 120	instantiation	327, 402, 142	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin(pi * |(2^{t} * delta) - l|)) in Real
# 	a : 2, b : sin(pi * |(2^{t} * delta) - l|)
# 121	instantiation	365, 143, 144	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| = (2 * sin(pi * |(2^{t} * delta) - l|))
# 	x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1|, z : 2 * sin(pi * |(2^{t} * delta) - l|)
# 122	instantiation	145, 231, 203, 146*, 147*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= (1 + 1)
# 	a : 1, b : -e^{2 * pi * i * ((2^{t} * delta) - l)}
# 123	conjecture		|- (1 + 1) = 2
# 124	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 125	instantiation	148, 317, 149, 180, 272, 273	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) in RealPos
# 	n : 4, a : (2^{t}, 2, 2, |delta - (l / 2^{t})|)
# 126	instantiation	335, 416, 384, 183, 386, 387, 284, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) = (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
# 	i : 2, j : 2, k : 0, a : (2^{t}, 2), b : (2, |delta - (l / 2^{t})|), c : ()
# 127	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 128	instantiation	392, 393, 150, 424, 402, 151	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) in Real
# 	n : 3, a : (2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))
# 129	instantiation	206, 152, 153	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	P(_a) : _a < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), x : 2^{t} * 2 * 0, y : 0
# 130	conjecture		|- forall_{i, j in Natural} [forall_{x, y} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in RealNonNeg | x <= y} ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) <= (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))]]
# 131	instantiation	435, 355, 154	|- 2^{t} in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 2^{t}
# 132	instantiation	365, 155, 156	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) = (2 * (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	x : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|, y : 2 * 2^{t} * 2 * |delta - (l / 2^{t})|, z : 2 * (2^{t} * 2 * |delta - (l / 2^{t})|)
# 133	conjecture		|- forall_{x, y in ComplexNonZero} ((x / (x * y)) = (1 / y))
# 134	instantiation	157, 158, 159	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * |delta - (l / 2^{t})|) in ComplexNonZero
# 	x : 2^{t} * 2 * |delta - (l / 2^{t})|
# 135	instantiation	337, 160	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * (delta - (l / 2^{t}))} = e^{i * (2 * pi * (delta - (l / 2^{t})))}
# 	f(_a) : e^{_a}, x : 2 * pi * i * (delta - (l / 2^{t})), y : i * (2 * pi * (delta - (l / 2^{t})))
# 136	instantiation	337, 161	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|0 - (2 * pi * (delta - (l / 2^{t})))| / 2) = ((2 * pi * |delta - (l / 2^{t})|) / 2)
# 	f(_a) : _a / 2, x : |0 - (2 * pi * (delta - (l / 2^{t})))|, y : 2 * pi * |delta - (l / 2^{t})|
# 137	instantiation	365, 162, 163	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / 2) = (pi * |delta - (l / 2^{t})|)
# 	x : (2 * pi * |delta - (l / 2^{t})|) / 2, y : (2 * (pi * |delta - (l / 2^{t})|)) / 2, z : pi * |delta - (l / 2^{t})|
# 138	instantiation	164, 231, 232, 188, 165	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = ((1 / 1) * (l / 1))
# 	a : 1, d : l, b : 2^{t}, c : 1, e : 1
# 139	instantiation	365, 166, 167	|- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = (2^{t} * (l / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (l / (2^{t} * 1)), y : 2^{t} * (l / (2^{t} * 1)), z : 2^{t} * (l / 2^{t})
# 140	instantiation	365, 168, 169	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((1 / 1) * (l / 1)) = (1 * l)
# 	x : (1 / 1) * (l / 1), y : 1 * (l / 1), z : 1 * l
# 141	instantiation	283, 232	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * l) = l
# 	x : l
# 142	instantiation	178, 300	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |(2^{t} * delta) - l|) in Real
# 	theta : pi * |(2^{t} * delta) - l|
# 143	instantiation	337, 170	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| = |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1|
# 	f(_a) : |_a|, x : 1 - e^{2 * pi * i * ((2^{t} * delta) - l)}, y : -e^{2 * pi * i * ((2^{t} * delta) - l)} + 1
# 144	instantiation	171, 319, 401, 172*, 173*, 174*, 175*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1| = (2 * sin(pi * |(2^{t} * delta) - l|))
# 	a : (2 * pi * ((2^{t} * delta) - l)) + pi, b : pi
# 145	conjecture		|- forall_{a, b in Complex} (|a + b| <= (|a| + |b|))
# 146	instantiation	325, 176	|- |1| = 1
# 	x : 1
# 147	instantiation	225, 261, 177*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |-e^{2 * pi * i * ((2^{t} * delta) - l)}| = 1
# 	x : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 148	conjecture		|- forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in RealPos} ((a_{1} * ..a_{_a}.. * a_{n}) in RealPos)]
# 149	instantiation	347	|- |(2^{t}, 2, 2, |delta - (l / 2^{t})|)| = |(1, ..k.., 4)|
# 	a : 2^{t}, b : 2, c : 2, d : |delta - (l / 2^{t})|
# 150	instantiation	404	|- |(2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))| = |(1, ..k.., 3)|
# 	a : 2^{t}, b : 2, c : sin(pi * |delta - (l / 2^{t})|)
# 151	instantiation	178, 306	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) in Real
# 	theta : pi * |delta - (l / 2^{t})|
# 152	instantiation	179, 416, 384, 183, 387, 180, 272, 181	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 0) < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	i : 2, j : 0, x : 0, y : sin(pi * |delta - (l / 2^{t})|), a : (2^{t}, 2), b : ()
# 153	instantiation	182, 416, 384, 183, 387, 284, 389	|- (2^{t} * 2 * 0) = 0
# 	i : 2, j : 0, a : (2^{t}, 2), b : ()
# 154	instantiation	435, 373, 184	|- 2^{t} in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 2^{t}
# 155	instantiation	379, 384, 383, 416, 387, 185, 386, 284, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) = (2 * 2^{t} * 2 * |delta - (l / 2^{t})|)
# 	i : 0, j : 1, k : 2, a : (), b : (2^{t}), c : 2, d : (2, |delta - (l / 2^{t})|)
# 156	instantiation	382, 383, 393, 384, 380, 187, 387, 389, 284, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * 2 * |delta - (l / 2^{t})|) = (2 * (2^{t} * 2 * |delta - (l / 2^{t})|))
# 	i : 1, j : 3, k : 0, a : (2), b : (2^{t}, 2, |delta - (l / 2^{t})|), c : ()
# 157	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 158	instantiation	316, 393, 187, 284, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * |delta - (l / 2^{t})|) in Complex
# 	n : 3, a : (2^{t}, 2, |delta - (l / 2^{t})|)
# 159	instantiation	186, 393, 187, 188, 189, 190	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * |delta - (l / 2^{t})|) != 0
# 	n : 3, a : (2^{t}, 2, |delta - (l / 2^{t})|)
# 160	instantiation	365, 191, 192	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * (delta - (l / 2^{t}))) = (i * (2 * pi * (delta - (l / 2^{t}))))
# 	x : 2 * pi * i * (delta - (l / 2^{t})), y : i * 2 * pi * (delta - (l / 2^{t})), z : i * (2 * pi * (delta - (l / 2^{t})))
# 161	instantiation	365, 193, 194	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |0 - (2 * pi * (delta - (l / 2^{t})))| = (2 * pi * |delta - (l / 2^{t})|)
# 	x : |0 - (2 * pi * (delta - (l / 2^{t})))|, y : |-(2 * pi * (delta - (l / 2^{t})))|, z : 2 * pi * |delta - (l / 2^{t})|
# 162	instantiation	337, 195	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / 2) = ((2 * (pi * |delta - (l / 2^{t})|)) / 2)
# 	f(_a) : _a / 2, x : 2 * pi * |delta - (l / 2^{t})|, y : 2 * (pi * |delta - (l / 2^{t})|)
# 163	instantiation	339, 389, 196, 376	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |delta - (l / 2^{t})|)) / 2) = (pi * |delta - (l / 2^{t})|)
# 	x : 2, y : pi * |delta - (l / 2^{t})|
# 164	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 165	instantiation	435, 221, 197	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 166	instantiation	337, 198	|- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = (2^{t} * (l / (2^{t} * 1)))
# 	f(_a) : _a * (l / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 167	instantiation	337, 199	|- (2^{t} * (l / (2^{t} * 1))) = (2^{t} * (l / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : l / (2^{t} * 1), y : l / 2^{t}
# 168	instantiation	337, 200	|- ((1 / 1) * (l / 1)) = (1 * (l / 1))
# 	f(_a) : _a * (l / 1), x : 1 / 1, y : 1
# 169	instantiation	337, 201	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * (l / 1)) = (1 * l)
# 	f(_a) : 1 * _a, x : l / 1, y : l
# 170	instantiation	202, 231, 203	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) = (-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1)
# 	a : 1, b : -e^{2 * pi * i * ((2^{t} * delta) - l)}
# 171	conjecture		|- forall_{a, b in Real} (|e^{i * a} - e^{i * b}| = (2 * sin(|a - b| / 2)))
# 172	instantiation	206, 204, 205	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)} = (-e^{2 * pi * i * ((2^{t} * delta) - l)})
# 	P(_a) : _a = (-e^{2 * pi * i * ((2^{t} * delta) - l)}), x : 1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}, y : e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
# 173	instantiation	206, 207, 208	|- e^{i * pi} = (-1)
# 	P(_a) : _a = (-1), x : 1 * e^{i * pi}, y : e^{i * pi}
# 174	instantiation	209, 231	|- (-(-1)) = 1
# 	x : 1
# 175	instantiation	365, 210, 211	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2) = (pi * |(2^{t} * delta) - l|)
# 	x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2, y : (2 * pi * |(2^{t} * delta) - l|) / 2, z : pi * |(2^{t} * delta) - l|
# 176	instantiation	435, 355, 212	|- 1 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 1
# 177	instantiation	213, 372, 233*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |e^{2 * pi * i * ((2^{t} * delta) - l)}| = 1
# 	theta : 2 * pi * ((2^{t} * delta) - l)
# 178	conjecture		|- forall_{theta in Real} (sin(theta) in Real)
# 179	conjecture		|- forall_{i, j in Natural} [forall_{x, y} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in RealPos | x < y} ((a_{1} * ..a_{_a}.. * a_{i} * x * b_{1} * ..b_{_a}.. * b_{j}) < (a_{1} * ..a_{_a}.. * a_{i} * y * b_{1} * ..b_{_a}.. * b_{j}))]]
# 180	instantiation	435, 301, 214	|- 2^{t} in RealPos
# 	A : RationalPos, B : RealPos, x : 2^{t}
# 181	instantiation	215, 216, 217	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < sin(pi * |delta - (l / 2^{t})|)
# 	x : 0, y : 2 * |delta - (l / 2^{t})|, z : sin(pi * |delta - (l / 2^{t})|)
# 182	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * 0 * b_{1} * ..b_{_a}.. * b_{j}) = 0)]
# 183	instantiation	400	|- |(2^{t}, 2)| = |(1, ..k.., 2)|
# 	a : 2^{t}, b : 2
# 184	instantiation	435, 218, 437	|- 2^{t} in Natural
# 	A : NaturalPos, B : Natural, x : 2^{t}
# 185	instantiation	399	|- |(2^{t})| = |(1, ..k.., 1)|
# 	a : 2^{t}
# 186	conjecture		|- forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in ComplexNonZero} ((a_{1} * ..a_{_a}.. * a_{n}) != 0)]
# 187	instantiation	404	|- |(2^{t}, 2, |delta - (l / 2^{t})|)| = |(1, ..k.., 3)|
# 	a : 2^{t}, b : 2, c : |delta - (l / 2^{t})|
# 188	instantiation	435, 221, 219	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 189	instantiation	435, 221, 220	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 190	instantiation	435, 221, 222	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : |delta - (l / 2^{t})|
# 191	instantiation	379, 384, 416, 383, 387, 343, 223, 389, 388, 346, 411	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * (delta - (l / 2^{t}))) = (i * 2 * pi * (delta - (l / 2^{t})))
# 	i : 0, j : 2, k : 1, a : (), b : (2, pi), c : i, d : (delta - (l / 2^{t}))
# 192	instantiation	382, 383, 393, 384, 345, 342, 387, 346, 389, 388, 411	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (i * 2 * pi * (delta - (l / 2^{t}))) = (i * (2 * pi * (delta - (l / 2^{t}))))
# 	i : 1, j : 3, k : 0, a : (i), b : (2, pi, delta - (l / 2^{t})), c : ()
# 193	instantiation	337, 224	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |0 - (2 * pi * (delta - (l / 2^{t})))| = |-(2 * pi * (delta - (l / 2^{t})))|
# 	f(_a) : |_a|, x : 0 - (2 * pi * (delta - (l / 2^{t}))), y : -(2 * pi * (delta - (l / 2^{t})))
# 194	instantiation	225, 281, 226*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |-(2 * pi * (delta - (l / 2^{t})))| = (2 * pi * |delta - (l / 2^{t})|)
# 	x : 2 * pi * (delta - (l / 2^{t}))
# 195	instantiation	382, 383, 416, 384, 380, 336, 387, 389, 388, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |delta - (l / 2^{t})|) = (2 * (pi * |delta - (l / 2^{t})|))
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |delta - (l / 2^{t})|), c : ()
# 196	instantiation	435, 413, 306	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in Complex
# 	A : Real, B : Complex, x : pi * |delta - (l / 2^{t})|
# 197	instantiation	435, 251, 227	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 198	instantiation	365, 228, 229	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 199	instantiation	337, 230	|- (l / (2^{t} * 1)) = (l / 2^{t})
# 	f(_a) : l / _a, x : 2^{t} * 1, y : 2^{t}
# 200	instantiation	256, 231	|- (1 / 1) = 1
# 	x : 1
# 201	instantiation	256, 232	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 1) = l
# 	x : l
# 202	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 203	instantiation	371, 261	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-e^{2 * pi * i * ((2^{t} * delta) - l)}) in Complex
# 	a : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 204	instantiation	236, 258, 372, 233*, 234*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}) = (-e^{2 * pi * i * ((2^{t} * delta) - l)})
# 	r : 1, theta : 2 * pi * ((2^{t} * delta) - l)
# 205	instantiation	283, 235	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}) = e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
# 	x : e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
# 206	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 207	instantiation	236, 258, 362, 237*, 238*, 239*	|- (1 * e^{i * pi}) = (-1)
# 	r : 1, theta : 0
# 208	instantiation	283, 240	|- (1 * e^{i * pi}) = e^{i * pi}
# 	x : e^{i * pi}
# 209	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 210	instantiation	337, 241	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2) = ((2 * pi * |(2^{t} * delta) - l|) / 2)
# 	f(_a) : _a / 2, x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|, y : 2 * pi * |(2^{t} * delta) - l|
# 211	instantiation	365, 242, 243	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |(2^{t} * delta) - l|) / 2) = (pi * |(2^{t} * delta) - l|)
# 	x : (2 * pi * |(2^{t} * delta) - l|) / 2, y : (2 * (pi * |(2^{t} * delta) - l|)) / 2, z : pi * |(2^{t} * delta) - l|
# 212	instantiation	435, 373, 383	|- 1 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 1
# 213	conjecture		|- forall_{theta in Real} (|e^{i * theta}| = 1)
# 214	instantiation	435, 329, 437	|- 2^{t} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t}
# 215	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 216	instantiation	244, 245	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < (2 * |delta - (l / 2^{t})|)
# 	x : 2 * |delta - (l / 2^{t})|
# 217	instantiation	246, 247*, 306, 248, 249*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) <= sin(pi * |delta - (l / 2^{t})|)
# 	theta : |pi * |delta - (l / 2^{t})||
# 218	conjecture		|- NaturalPos proper_subset Natural
# 219	instantiation	435, 251, 250	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 220	instantiation	435, 251, 252	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 221	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 222	instantiation	435, 391, 273	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in RealNonZero
# 	A : RealPos, B : RealNonZero, x : |delta - (l / 2^{t})|
# 223	instantiation	399	|- |(delta - (l / 2^{t}))| = |(1, ..k.., 1)|
# 	a : delta - (l / 2^{t})
# 224	instantiation	263, 253	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (0 - (2 * pi * (delta - (l / 2^{t})))) = (-(2 * pi * (delta - (l / 2^{t}))))
# 	a : -(2 * pi * (delta - (l / 2^{t})))
# 225	conjecture		|- forall_{x in Complex} (|-x| = |x|)
# 226	instantiation	294, 295, 342, 389, 388, 411, 296*, 297*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |2 * pi * (delta - (l / 2^{t}))| = (2 * pi * |delta - (l / 2^{t})|)
# 	n : 3, x : (2, pi, delta - (l / 2^{t}))
# 227	instantiation	435, 279, 254	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 228	instantiation	337, 255	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 229	instantiation	256, 284	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 230	instantiation	257, 284	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 231	instantiation	435, 413, 258	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 232	instantiation	435, 413, 423	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Complex
# 	A : Real, B : Complex, x : l
# 233	instantiation	259, 260	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * (2 * pi * ((2^{t} * delta) - l))} = e^{2 * pi * i * ((2^{t} * delta) - l)}
# 	x : e^{2 * pi * i * ((2^{t} * delta) - l)}, y : e^{i * (2 * pi * ((2^{t} * delta) - l))}
# 234	instantiation	283, 261	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * e^{2 * pi * i * ((2^{t} * delta) - l)}) = e^{2 * pi * i * ((2^{t} * delta) - l)}
# 	x : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 235	instantiation	287, 292, 262	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)} in Complex
# 	a : e, b : i * ((2 * pi * ((2^{t} * delta) - l)) + pi)
# 236	conjecture		|- forall_{r, theta in Real} ((r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})))
# 237	instantiation	263, 388	|- (0 + pi) = pi
# 	a : pi
# 238	instantiation	365, 264, 265	|- e^{i * 0} = 1
# 	x : e^{i * 0}, y : e^{0}, z : 1
# 239	conjecture		|- (1 * 1) = 1
# 240	instantiation	287, 292, 266	|- e^{i * pi} in Complex
# 	a : e, b : i * pi
# 241	instantiation	365, 267, 268	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| = (2 * pi * |(2^{t} * delta) - l|)
# 	x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|, y : |2 * pi * ((2^{t} * delta) - l)|, z : 2 * pi * |(2^{t} * delta) - l|
# 242	instantiation	337, 269	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |(2^{t} * delta) - l|) / 2) = ((2 * (pi * |(2^{t} * delta) - l|)) / 2)
# 	f(_a) : _a / 2, x : 2 * pi * |(2^{t} * delta) - l|, y : 2 * (pi * |(2^{t} * delta) - l|)
# 243	instantiation	339, 389, 270, 376	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |(2^{t} * delta) - l|)) / 2) = (pi * |(2^{t} * delta) - l|)
# 	x : 2, y : pi * |(2^{t} * delta) - l|
# 244	conjecture		|- forall_{x in RealPos} (x > 0)
# 245	instantiation	271, 272, 273	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) in RealPos
# 	a : 2, b : |delta - (l / 2^{t})|
# 246	conjecture		|- forall_{theta in Real | |theta| <= (pi / 2)} (sin(|theta|) >= ((2 * |theta|) / pi))
# 247	instantiation	325, 274	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |pi * |delta - (l / 2^{t})|| = (pi * |delta - (l / 2^{t})|)
# 	x : pi * |delta - (l / 2^{t})|
# 248	instantiation	275, 362, 363, 364	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) <= (pi / 2)
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 249	instantiation	365, 276, 277	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |delta - (l / 2^{t})|)) / pi) = (2 * |delta - (l / 2^{t})|)
# 	x : (2 * (pi * |delta - (l / 2^{t})|)) / pi, y : (2 * pi * |delta - (l / 2^{t})|) / pi, z : 2 * |delta - (l / 2^{t})|
# 250	instantiation	435, 279, 278	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 251	conjecture		|- RationalNonZero proper_subset RealNonZero
# 252	instantiation	435, 279, 280	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 253	instantiation	371, 281	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(2 * pi * (delta - (l / 2^{t})))) in Complex
# 	a : 2 * pi * (delta - (l / 2^{t}))
# 254	instantiation	435, 311, 282	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 255	instantiation	283, 284	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 256	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 257	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 258	instantiation	435, 427, 285	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 259	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 260	instantiation	337, 286	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * ((2^{t} * delta) - l)} = e^{i * (2 * pi * ((2^{t} * delta) - l))}
# 	f(_a) : e^{_a}, x : 2 * pi * i * ((2^{t} * delta) - l), y : i * (2 * pi * ((2^{t} * delta) - l))
# 261	instantiation	287, 292, 288	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * ((2^{t} * delta) - l)} in Complex
# 	a : e, b : 2 * pi * i * ((2^{t} * delta) - l)
# 262	instantiation	368, 346, 289	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (i * ((2 * pi * ((2^{t} * delta) - l)) + pi)) in Complex
# 	a : i, b : (2 * pi * ((2^{t} * delta) - l)) + pi
# 263	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 264	instantiation	337, 290	|- e^{i * 0} = e^{0}
# 	f(_a) : e^{_a}, x : i * 0, y : 0
# 265	instantiation	291, 292	|- e^{0} = 1
# 	a : e
# 266	instantiation	368, 346, 388	|- (i * pi) in Complex
# 	a : i, b : pi
# 267	instantiation	337, 293	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| = |2 * pi * ((2^{t} * delta) - l)|
# 	f(_a) : |_a|, x : ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi, y : 2 * pi * ((2^{t} * delta) - l)
# 268	instantiation	294, 295, 394, 389, 388, 358, 296*, 297*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |2 * pi * ((2^{t} * delta) - l)| = (2 * pi * |(2^{t} * delta) - l|)
# 	n : 3, x : (2, pi, (2^{t} * delta) - l)
# 269	instantiation	382, 383, 416, 384, 380, 298, 387, 389, 388, 299	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |(2^{t} * delta) - l|) = (2 * (pi * |(2^{t} * delta) - l|))
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |(2^{t} * delta) - l|), c : ()
# 270	instantiation	435, 413, 300	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |(2^{t} * delta) - l|) in Complex
# 	A : Real, B : Complex, x : pi * |(2^{t} * delta) - l|
# 271	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 272	instantiation	435, 301, 302	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 273	instantiation	303, 411, 304	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in RealPos
# 	a : delta - (l / 2^{t})
# 274	instantiation	305, 306, 307	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in RealNonNeg
# 	a : pi * |delta - (l / 2^{t})|
# 275	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 276	instantiation	337, 308	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |delta - (l / 2^{t})|)) / pi) = ((2 * pi * |delta - (l / 2^{t})|) / pi)
# 	f(_a) : _a / pi, x : 2 * (pi * |delta - (l / 2^{t})|), y : 2 * pi * |delta - (l / 2^{t})|
# 277	instantiation	365, 309, 310	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / pi) = (2 * |delta - (l / 2^{t})|)
# 	x : (2 * pi * |delta - (l / 2^{t})|) / pi, y : (pi * (2 * |delta - (l / 2^{t})|)) / pi, z : 2 * |delta - (l / 2^{t})|
# 278	instantiation	435, 311, 437	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 279	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 280	instantiation	435, 311, 396	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 281	instantiation	435, 413, 312	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * (delta - (l / 2^{t}))) in Complex
# 	A : Real, B : Complex, x : 2 * pi * (delta - (l / 2^{t}))
# 282	conjecture		|- 1 in NaturalPos
# 283	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 284	instantiation	435, 413, 424	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 285	instantiation	435, 431, 313	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 286	instantiation	365, 314, 315	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) = (i * (2 * pi * ((2^{t} * delta) - l)))
# 	x : 2 * pi * i * ((2^{t} * delta) - l), y : i * 2 * pi * ((2^{t} * delta) - l), z : i * (2 * pi * ((2^{t} * delta) - l))
# 287	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 288	instantiation	316, 317, 318, 389, 388, 346, 358	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) in Complex
# 	n : 4, a : (2, pi, i, (2^{t} * delta) - l)
# 289	instantiation	435, 413, 319	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * ((2^{t} * delta) - l)) + pi) in Complex
# 	A : Real, B : Complex, x : (2 * pi * ((2^{t} * delta) - l)) + pi
# 290	instantiation	320, 346	|- (i * 0) = 0
# 	x : i
# 291	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 292	instantiation	435, 413, 321	|- e in Complex
# 	A : Real, B : Complex, x : e
# 293	instantiation	365, 322, 323	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi) = (2 * pi * ((2^{t} * delta) - l))
# 	x : ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi, y : (2 * pi * ((2^{t} * delta) - l)) + pi - pi, z : 2 * pi * ((2^{t} * delta) - l)
# 294	conjecture		|- forall_{n in NaturalPos} [forall_{x_{1}, ..x_{_a}.., x_{n} in Complex} (|x_{1} * ..x_{_a}.. * x_{n}| = (|x_{1}| * ..|x_{k}|.. * |x_{n}|))]
# 295	conjecture		|- 3 in NaturalPos
# 296	instantiation	325, 324	|- |2| = 2
# 	x : 2
# 297	instantiation	325, 326	|- |pi| = pi
# 	x : pi
# 298	instantiation	400	|- |(pi, |(2^{t} * delta) - l|)| = |(1, ..k.., 2)|
# 	a : pi, b : |(2^{t} * delta) - l|
# 299	instantiation	435, 413, 328	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| in Complex
# 	A : Real, B : Complex, x : |(2^{t} * delta) - l|
# 300	instantiation	327, 401, 328	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |(2^{t} * delta) - l|) in Real
# 	a : pi, b : |(2^{t} * delta) - l|
# 301	conjecture		|- RationalPos proper_subset RealPos
# 302	instantiation	435, 329, 396	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 303	conjecture		|- forall_{a in Complex | a != 0} (|a| in RealPos)
# 304	instantiation	330, 331	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) != 0
# 	a : delta, b : l / 2^{t}
# 305	conjecture		|- forall_{a in Real | a >= 0} (a in RealNonNeg)
# 306	instantiation	332, 362, 363, 364	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in Real
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 307	instantiation	333, 334	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 <= (pi * |delta - (l / 2^{t})|)
# 	x : 0, y : pi * |delta - (l / 2^{t})|
# 308	instantiation	335, 383, 416, 384, 380, 336, 387, 389, 388, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * (pi * |delta - (l / 2^{t})|)) = (2 * pi * |delta - (l / 2^{t})|)
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |delta - (l / 2^{t})|), c : ()
# 309	instantiation	337, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / pi) = ((pi * (2 * |delta - (l / 2^{t})|)) / pi)
# 	f(_a) : _a / pi, x : 2 * pi * |delta - (l / 2^{t})|, y : pi * (2 * |delta - (l / 2^{t})|)
# 310	instantiation	339, 388, 340, 341	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((pi * (2 * |delta - (l / 2^{t})|)) / pi) = (2 * |delta - (l / 2^{t})|)
# 	x : pi, y : 2 * |delta - (l / 2^{t})|
# 311	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 312	instantiation	392, 393, 342, 402, 401, 414	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * (delta - (l / 2^{t}))) in Real
# 	n : 3, a : (2, pi, delta - (l / 2^{t}))
# 313	instantiation	435, 415, 383	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 314	instantiation	379, 384, 416, 383, 387, 343, 344, 389, 388, 346, 358	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) = (i * 2 * pi * ((2^{t} * delta) - l))
# 	i : 0, j : 2, k : 1, a : (), b : (2, pi), c : i, d : ((2^{t} * delta) - l)
# 315	instantiation	382, 383, 393, 384, 345, 394, 387, 346, 389, 388, 358	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (i * 2 * pi * ((2^{t} * delta) - l)) = (i * (2 * pi * ((2^{t} * delta) - l)))
# 	i : 1, j : 3, k : 0, a : (i), b : (2, pi, (2^{t} * delta) - l), c : ()
# 316	conjecture		|- forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Complex} ((a_{1} * ..a_{_a}.. * a_{n}) in Complex)]
# 317	conjecture		|- 4 in Natural
# 318	instantiation	347	|- |(2, pi, i, (2^{t} * delta) - l)| = |(1, ..k.., 4)|
# 	a : 2, b : pi, c : i, d : (2^{t} * delta) - l
# 319	instantiation	417, 372, 401	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * ((2^{t} * delta) - l)) + pi) in Real
# 	a : 2 * pi * ((2^{t} * delta) - l), b : pi
# 320	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 321	instantiation	435, 407, 348	|- e in Real
# 	A : RealPos, B : Real, x : e
# 322	instantiation	349, 384, 416, 383, 387, 350, 351, 354, 388, 352	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi) = ((2 * pi * ((2^{t} * delta) - l)) + pi - pi)
# 	i : 0, j : 2, k : 1, a : (), b : (2 * pi * ((2^{t} * delta) - l), pi), c : (-pi)
# 323	instantiation	353, 388, 354	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * ((2^{t} * delta) - l)) + pi - pi) = (2 * pi * ((2^{t} * delta) - l))
# 	a : pi, b : 2 * pi * ((2^{t} * delta) - l)
# 324	instantiation	435, 355, 356	|- 2 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 2
# 325	conjecture		|- forall_{x in RealNonNeg} (|x| = x)
# 326	instantiation	435, 357, 408	|- pi in RealNonNeg
# 	A : RealPos, B : RealNonNeg, x : pi
# 327	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 328	instantiation	410, 358	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| in Real
# 	a : (2^{t} * delta) - l
# 329	conjecture		|- NaturalPos proper_subset RationalPos
# 330	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 331	instantiation	359, 430, 360	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- delta != (l / 2^{t})
# 	l : l
# 332	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 333	conjecture		|- forall_{x, y | x < y} (x <= y)
# 334	instantiation	361, 362, 363, 364	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < (pi * |delta - (l / 2^{t})|)
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 335	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k}))]
# 336	instantiation	400	|- |(pi, |delta - (l / 2^{t})|)| = |(1, ..k.., 2)|
# 	a : pi, b : |delta - (l / 2^{t})|
# 337	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 338	instantiation	365, 366, 367	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |delta - (l / 2^{t})|) = (pi * (2 * |delta - (l / 2^{t})|))
# 	x : 2 * pi * |delta - (l / 2^{t})|, y : pi * 2 * |delta - (l / 2^{t})|, z : pi * (2 * |delta - (l / 2^{t})|)
# 339	conjecture		|- forall_{x, y in Complex | x != 0} (((x * y) / x) = y)
# 340	instantiation	368, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) in Complex
# 	a : 2, b : |delta - (l / 2^{t})|
# 341	instantiation	369, 370	|- pi != 0
# 	x : pi
# 342	instantiation	404	|- |(2, pi, delta - (l / 2^{t}))| = |(1, ..k.., 3)|
# 	a : 2, b : pi, c : delta - (l / 2^{t})
# 343	instantiation	400	|- |(2, pi)| = |(1, ..k.., 2)|
# 	a : 2, b : pi
# 344	instantiation	399	|- |((2^{t} * delta) - l)| = |(1, ..k.., 1)|
# 	a : (2^{t} * delta) - l
# 345	instantiation	399	|- |(i)| = |(1, ..k.., 1)|
# 	a : i
# 346	conjecture		|- i in Complex
# 347	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, ..k.., 4)|)
# 348	conjecture		|- e in RealPos
# 349	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} + ..a_{_a}.. + a_{i} + (b_{1} + ..b_{_a}.. + b_{j}) + c_{1} + ..c_{_a}.. + c_{k}) =  \\ (a_{1} + ..a_{_a}.. + a_{i} + b_{1} + ..b_{_a}.. + b_{j} + c_{1} + ..c_{_a}.. + c_{k}))]
# 350	instantiation	400	|- |(2 * pi * ((2^{t} * delta) - l), pi)| = |(1, ..k.., 2)|
# 	a : 2 * pi * ((2^{t} * delta) - l), b : pi
# 351	instantiation	399	|- |(-pi)| = |(1, ..k.., 1)|
# 	a : -pi
# 352	instantiation	371, 388	|- (-pi) in Complex
# 	a : pi
# 353	conjecture		|- forall_{a, b in Complex} ((b + a - a) = b)
# 354	instantiation	435, 413, 372	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * ((2^{t} * delta) - l)) in Complex
# 	A : Real, B : Complex, x : 2 * pi * ((2^{t} * delta) - l)
# 355	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 356	instantiation	435, 373, 416	|- 2 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 2
# 357	conjecture		|- RealPos proper_subset RealNonNeg
# 358	instantiation	435, 413, 395	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in Complex
# 	A : Real, B : Complex, x : (2^{t} * delta) - l
# 359	conjecture		|- forall_{l in Integer | l != 0} (delta != (l / 2^{t}))
# 360	instantiation	374, 398	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l != 0
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : l != 0
# 361	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 362	instantiation	435, 427, 375	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 363	instantiation	422, 401, 402, 376	|- (pi / 2) in Real
# 	a : pi, b : 2
# 364	instantiation	377, 378	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in (0,pi / 2]
# 	l : l
# 365	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 366	instantiation	379, 384, 383, 387, 380, 381, 389, 388, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |delta - (l / 2^{t})|) = (pi * 2 * |delta - (l / 2^{t})|)
# 	i : 0, j : 1, k : 1, a : (), b : (2), c : pi, d : (|delta - (l / 2^{t})|)
# 367	instantiation	382, 383, 416, 384, 385, 386, 387, 388, 389, 390	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * 2 * |delta - (l / 2^{t})|) = (pi * (2 * |delta - (l / 2^{t})|))
# 	i : 1, j : 2, k : 0, a : (pi), b : (2, |delta - (l / 2^{t})|), c : ()
# 368	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 369	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 370	instantiation	435, 391, 408	|- pi in RealNonZero
# 	A : RealPos, B : RealNonZero, x : pi
# 371	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 372	instantiation	392, 393, 394, 402, 401, 395	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * ((2^{t} * delta) - l)) in Real
# 	n : 3, a : (2, pi, (2^{t} * delta) - l)
# 373	conjecture		|- Natural proper_subset RationalNonNeg
# 374	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 375	conjecture		|- 0 in Rational
# 376	instantiation	429, 396	|- 2 != 0
# 	n : 2
# 377	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((pi * |delta - (l / 2^{t})|) in (0,pi / 2])
# 378	instantiation	397, 398	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : l != 0
# 379	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c, d_{1}, ..d_{_a}.., d_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c * d_{1} * ..d_{_a}.. * d_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * c * b_{1} * ..b_{_a}.. * b_{j} * d_{1} * ..d_{_a}.. * d_{k}))]
# 380	instantiation	399	|- |(2)| = |(1, ..k.., 1)|
# 	a : 2
# 381	instantiation	399	|- |(|delta - (l / 2^{t})|)| = |(1, ..k.., 1)|
# 	a : |delta - (l / 2^{t})|
# 382	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, ..a_{_a}.., a_{i}, b_{1}, ..b_{_a}.., b_{j}, c_{1}, ..c_{_a}.., c_{k} in Complex} ((a_{1} * ..a_{_a}.. * a_{i} * b_{1} * ..b_{_a}.. * b_{j} * c_{1} * ..c_{_a}.. * c_{k}) =  \\ (a_{1} * ..a_{_a}.. * a_{i} * (b_{1} * ..b_{_a}.. * b_{j}) * c_{1} * ..c_{_a}.. * c_{k}))]
# 383	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 384	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 385	instantiation	399	|- |(pi)| = |(1, ..k.., 1)|
# 	a : pi
# 386	instantiation	400	|- |(2, |delta - (l / 2^{t})|)| = |(1, ..k.., 2)|
# 	a : 2, b : |delta - (l / 2^{t})|
# 387	conjecture		|- |()| = |(1, ..a.., 0)|
# 388	instantiation	435, 413, 401	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 389	instantiation	435, 413, 402	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 390	instantiation	435, 413, 403	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in Complex
# 	A : Real, B : Complex, x : |delta - (l / 2^{t})|
# 391	conjecture		|- RealPos proper_subset RealNonZero
# 392	conjecture		|- forall_{n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{n} in Real} ((a_{1} * ..a_{_a}.. * a_{n}) in Real)]
# 393	conjecture		|- 3 in Natural
# 394	instantiation	404	|- |(2, pi, (2^{t} * delta) - l)| = |(1, ..k.., 3)|
# 	a : 2, b : pi, c : (2^{t} * delta) - l
# 395	instantiation	405, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in Real
# 	l : l
# 396	conjecture		|- 2 in NaturalPos
# 397	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 398	instantiation	406, 439	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : l
# 399	conjecture		|- forall_{a} (|(a)| = |(1, ..k.., 1)|)
# 400	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..k.., 2)|)
# 401	instantiation	435, 407, 408	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 402	instantiation	435, 427, 409	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 403	instantiation	410, 411	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in Real
# 	a : delta - (l / 2^{t})
# 404	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, ..k.., 3)|)
# 405	conjecture		|- forall_{l in Integer} (((2^{t} * delta) - l) in Real)
# 406	conjecture		|- forall_{S, y} [forall_{x in S - {y}} ((x in S) and (x != y))]
# 407	conjecture		|- RealPos proper_subset Real
# 408	conjecture		|- pi in RealPos
# 409	instantiation	435, 431, 412	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 410	conjecture		|- forall_{a in Complex} (|a| in Real)
# 411	instantiation	435, 413, 414	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) in Complex
# 	A : Real, B : Complex, x : delta - (l / 2^{t})
# 412	instantiation	435, 415, 416	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 413	conjecture		|- Real proper_subset Complex
# 414	instantiation	417, 418, 419	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) in Real
# 	a : delta, b : -(l / 2^{t})
# 415	conjecture		|- Natural proper_subset Integer
# 416	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 417	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 418	conjecture		|- delta in Real
# 419	instantiation	420, 421	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in Real
# 	a : l / 2^{t}
# 420	conjecture		|- forall_{a in Real} ((-a) in Real)
# 421	instantiation	422, 423, 424, 425	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in Real
# 	a : l, b : 2^{t}
# 422	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 423	instantiation	435, 427, 426	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Real
# 	A : Rational, B : Real, x : l
# 424	instantiation	435, 427, 428	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 425	instantiation	429, 437	|- 2^{t} != 0
# 	n : 2^{t}
# 426	instantiation	435, 431, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 427	conjecture		|- Rational proper_subset Real
# 428	instantiation	435, 431, 432	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 429	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 430	instantiation	435, 433, 434	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Integer
# 	A : IntegerNonZero, B : Integer, x : l
# 431	conjecture		|- Integer proper_subset Rational
# 432	instantiation	435, 436, 437	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 433	conjecture		|- IntegerNonZero proper_subset Integer
# 434	instantiation	438, 439	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in IntegerNonZero
# 	l : l
# 435	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 436	conjecture		|- NaturalPos proper_subset Integer
# 437	conjecture		|- 2^{t} in NaturalPos
# 438	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (l in IntegerNonZero)
# 439	assumption		{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
