# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#success_prob_is_real">success_prob_is_real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, eps
from proveit.physics.quantum.QPE import success_def

# %%
# %proving success_prob_is_real
# Out:
# success_prob_is_real: forall_{eps in NaturalPos} (Psuccess(eps) in Real)

# %%
defaults.assumptions = success_prob_is_real.conditions
# Out:
# defaults.assumptions: (eps in NaturalPos)

# %%
success_def
# Out:
# |- forall_{eps in NaturalPos} (Psuccess(eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps])

# %%
success_def.instantiate({eps: eps})
# Out:
# {eps in NaturalPos} |- Psuccess(eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps]

# %%
prob_expr = success_def.instance_expr.rhs
# Out:
# prob_expr: Pr_{m}[|m - b|_{mod 2^{t}} <= eps]

# %%
prob_expr.deduce_in_real()
# Out:
# |- Pr_{m}[|m - b|_{mod 2^{t}} <= eps] in Real

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in NaturalPos} (Psuccess(eps) in Real)
# 1	instantiation	2, 3, 4	{eps in NaturalPos} |- Psuccess(eps) in Real
# 	P(_a) : _a in Real, x : Psuccess(eps), y : Pr_{m}[|m - b|_{mod 2^{t}} <= eps]
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5	|- Pr_{m}[|m - b|_{mod 2^{t}} <= eps] in Real
# 	x : m, X : |m - b|_{mod 2^{t}} <= eps
# 4	instantiation	6, 7	{eps in NaturalPos} |- Psuccess(eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps]
# 	eps : eps
# 5	conjecture		|- forall_{x, X} (Pr_{x}[X] in Real)
# 6	axiom		|- forall_{eps in NaturalPos} (Psuccess(eps) = Pr_{m}[|m - b|_{mod 2^{t}} <= eps])
# 	proveit.physics.quantum.QPE.success_def
# 7	assumption		{eps in NaturalPos} |- eps in NaturalPos
