# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#scaled_delta_not_eq_nonzeroInt">scaled_delta_not_eq_nonzeroInt</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, l, n, x
from proveit.logic import Equals
from proveit.numbers import zero, one, IntervalOO, Mult
from proveit.numbers.number_sets.real_numbers import not_int_if_between_successive_int
from proveit.physics.quantum.QPE import delta_, scaled_delta_in_interval, two_pow_t

# %%
# %proving scaled_delta_not_eq_nonzeroInt
# Out:
# scaled_delta_not_eq_nonzeroInt: forall_{l in Integer | l != 0} ((2^{t} * delta) != l)

# %%
defaults.assumptions = scaled_delta_not_eq_nonzeroInt.conditions
# Out:
# defaults.assumptions: (l in Integer, l != 0)

# %%
scaled_delta = Mult(two_pow_t, delta_)
# Out:
# scaled_delta: 2^{t} * delta

# %%
# This will include automatic side effects about the lower and upper bounds
scaled_delta_in_interval
# Out:
# |- (2^{t} * delta) in [0,1)

# %%
# Assume to the contrary that scaled_delta = ell
contradictory_assumption = Equals(scaled_delta, l)
# Out:
# contradictory_assumption: (2^{t} * delta) = l

# %%
# We apparently need this to be explicitly included! This affects how
# the last step (.derive_via_contradiction) performs
contradictory_assumption.deduce_in_bool()
# Out:
# |- ((2^{t} * delta) = l) in BOOLEAN

# %%
l_lower_bound_loose = (
    contradictory_assumption.sub_right_side_into(
        scaled_delta_in_interval.domain.deduce_member_lower_bound(scaled_delta),
        assumptions=[contradictory_assumption]))
# Out:
# l_lower_bound_loose: {(2^{t} * delta) = l} |- 0 <= l

# %%
l_upper_bound = (
    contradictory_assumption.sub_right_side_into(
        scaled_delta_in_interval.domain.deduce_member_upper_bound(scaled_delta),
        assumptions=[contradictory_assumption]))
# Out:
# l_upper_bound: {(2^{t} * delta) = l} |- l < 1

# %%
temp_01 = l_lower_bound_loose.unfold(defaults.assumptions)
# Out:
# temp_01: |- (0 <= l) = ((0 < l) or (0 = l))

# %%
temp_02 = temp_01.sub_right_side_into(l_lower_bound_loose, assumptions=[contradictory_assumption])
# Out:
# temp_02: {(2^{t} * delta) = l} |- (0 < l) or (0 = l)

# %%
l_lower_bound_tight = temp_02.derive_left_if_not_right()
# Out:
# l_lower_bound_tight: {(2^{t} * delta) = l, l != 0} |- 0 < l

# %%
ell_in_o0_o1 = IntervalOO(zero, one).deduce_elem_in_set(l, assumptions=[contradictory_assumption, *defaults.assumptions])
# Out:
# ell_in_o0_o1: {l in Integer, (2^{t} * delta) = l, l != 0} |- l in (0,1)

# %%
not_int_if_between_successive_int
# Out:
# |- forall_{n in Integer} [forall_{x in (n,n + 1)} (x not-in Integer)]

# %%
ell_not_int = not_int_if_between_successive_int.instantiate(
    {n: zero, x: l}, assumptions=[contradictory_assumption, *defaults.assumptions])
# Out:
# ell_not_int: {l in Integer, (2^{t} * delta) = l, l != 0} |- l not-in Integer

# %%
contradictory_assumption_implies_false = (
    ell_not_int.unfold().derive_contradiction().as_implication(
        hypothesis=contradictory_assumption))
# Out:
# contradictory_assumption_implies_false: {l in Integer, l != 0} |- ((2^{t} * delta) = l) => FALSE

# %%
contradictory_assumption_implies_false.derive_via_contradiction()
# Out:
# {l in Integer, l != 0} |- not((2^{t} * delta) = l)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{l in Integer | l != 0} ((2^{t} * delta) != l)
# 1	instantiation	2, 3	{l in Integer, l != 0} |- (2^{t} * delta) != l
# 	x : 2^{t} * delta, y : l
# 2	theorem		|- forall_{x, y | not(x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 3	instantiation	4, 5, 6	{l in Integer, l != 0} |- not((2^{t} * delta) = l)
# 	A : (2^{t} * delta) = l
# 4	axiom		|- forall_{A in BOOLEAN | A => FALSE} not(A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 5	instantiation	7	|- ((2^{t} * delta) = l) in BOOLEAN
# 	x : 2^{t} * delta, y : l
# 6	deduction	8	{l in Integer, l != 0} |- ((2^{t} * delta) = l) => FALSE
# 7	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 8	instantiation	9, 25, 10	{l in Integer, (2^{t} * delta) = l, l != 0} |- FALSE
# 	A : l in Integer
# 9	theorem		|- forall_{A | A, not(A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 10	instantiation	11, 12	{l in Integer, (2^{t} * delta) = l, l != 0} |- not(l in Integer)
# 	x : l, S : Integer
# 11	theorem		|- forall_{x, S | x not-in S} not(x in S)
# 	proveit.logic.sets.membership.unfold_not_in_set
# 12	instantiation	13, 14, 15	{l in Integer, (2^{t} * delta) = l, l != 0} |- l not-in Integer
# 	n : 0, x : l
# 13	conjecture		|- forall_{n in Integer} [forall_{x in (n,n + 1)} (x not-in Integer)]
# 14	instantiation	61, 62, 16	|- 0 in Integer
# 	A : Natural, B : Integer, x : 0
# 15	instantiation	17, 53, 18, 19, 20	{l in Integer, (2^{t} * delta) = l, l != 0} |- l in (0,0 + 1)
# 	a : 0, b : 0 + 1, x : l
# 16	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 17	conjecture		|- forall_{a, b, x in Real | a < x < b} (x in (a,b))
# 18	instantiation	29, 54, 31	|- (0 + 1) in Real
# 	P(_a) : _a in Real, x : 0 + 1, y : 1
# 19	instantiation	61, 57, 21	{l in Integer} |- l in Real
# 	A : Rational, B : Real, x : l
# 20	instantiation	22, 23, 24	{(2^{t} * delta) = l, l != 0} |- (0 < l) and (l < (0 + 1))
# 	A : 0 < l, B : l < (0 + 1)
# 21	instantiation	61, 59, 25	{l in Integer} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 22	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 23	instantiation	26, 27, 28, 37, 40	{(2^{t} * delta) = l, l != 0} |- 0 < l
# 	A : 0 < l, B : 0 = l
# 24	instantiation	29, 30, 31	{(2^{t} * delta) = l} |- l < (0 + 1)
# 	P(_a) : l < _a, x : 0 + 1, y : 1
# 25	assumption		{l in Integer} |- l in Integer
# 26	theorem		|- forall_{A, B in BOOLEAN | A or B, not(B)} A
# 	proveit.logic.booleans.disjunction.left_if_not_right
# 27	instantiation	32, 33	{(2^{t} * delta) = l} |- (0 < l) in BOOLEAN
# 	A : 0 < l, B : 0 = l
# 28	instantiation	34, 35	{l != 0} |- (0 = l) in BOOLEAN
# 	A : 0 = l
# 29	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 30	instantiation	46, 36, 48	{(2^{t} * delta) = l} |- l < 1
# 	P(_a) : _a < 1, x : 2^{t} * delta, y : l
# 31	conjecture		|- (0 + 1) = 1
# 32	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 33	instantiation	38, 39, 37	{(2^{t} * delta) = l} |- ((0 < l) or (0 = l)) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : (0 < l) or (0 = l)
# 34	axiom		|- forall_{A | not(A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 35	instantiation	38, 39, 40	{l != 0} |- not(0 = l) in BOOLEAN
# 	P(_a) : _a in BOOLEAN, x : not(0 = l)
# 36	instantiation	41, 53, 54, 55	|- (2^{t} * delta) < 1
# 	a : 0, b : 1, x : 2^{t} * delta
# 37	instantiation	46, 42, 43	{(2^{t} * delta) = l} |- (0 < l) or (0 = l)
# 	P(_a) : _a, x : 0 <= l, y : (0 < l) or (0 = l)
# 38	theorem		|- forall_{P, x | P(TRUE), x} P(x)
# 	proveit.logic.equality.substitute_truth
# 39	conjecture		|- TRUE in BOOLEAN
# 40	instantiation	44, 45	{l != 0} |- not(0 = l)
# 	x : 0, y : l
# 41	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 42	instantiation	46, 47, 48	{(2^{t} * delta) = l} |- 0 <= l
# 	P(_a) : 0 <= _a, x : 2^{t} * delta, y : l
# 43	instantiation	49	|- (0 <= l) = ((0 < l) or (0 = l))
# 	x : 0, y : l
# 44	theorem		|- forall_{x, y | x != y} not(x = y)
# 	proveit.logic.equality.unfold_not_equals
# 45	instantiation	50, 51	{l != 0} |- 0 != l
# 	x : l, y : 0
# 46	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 47	instantiation	52, 53, 54, 55	|- 0 <= (2^{t} * delta)
# 	a : 0, b : 1, x : 2^{t} * delta
# 48	assumption		{(2^{t} * delta) = l} |- (2^{t} * delta) = l
# 49	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
# 50	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 51	assumption		{l != 0} |- l != 0
# 52	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 53	instantiation	61, 57, 56	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 54	instantiation	61, 57, 58	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 55	conjecture		|- (2^{t} * delta) in [0,1)
# 56	conjecture		|- 0 in Rational
# 57	conjecture		|- Rational proper_subset Real
# 58	instantiation	61, 59, 60	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 59	conjecture		|- Integer proper_subset Rational
# 60	instantiation	61, 62, 63	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 61	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 62	conjecture		|- Natural proper_subset Integer
# 63	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
