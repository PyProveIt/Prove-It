# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#neg_domain_within_integer">neg_domain_within_integer</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import two_pow_t_minus_one_is_nat_pos

# %%
# %proving neg_domain_within_integer
# Out:
# neg_domain_within_integer: forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq Integer)

# %%
two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# %qed
# Out:
# Entering the ProperSubset.conclude() method!
# Entering the ProperSubset.conclude() method!
# 	step type	requirements	statement
# 0	generalizaton	1	|- forall_{eps in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(eps + 1)} subset_eq Integer)
# 1	instantiation	2, 3	{eps in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(eps + 1)} subset_eq Integer
# 	A : {-2^{t - 1} + 1 .. -(eps + 1)}, B : Integer, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalizaton	4	{eps in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {-2^{t - 1} + 1 .. -(eps + 1)}} (_a in Integer)
# 4	instantiation	11, 5, 6, 7	{eps in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in Integer
# 	a : -2^{t - 1} + 1, b : -(eps + 1), n : _a
# 5	instantiation	16, 8, 12	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 6	instantiation	21, 9	{eps in {1 .. 2^{t - 1} - 2}} |- (-(eps + 1)) in Integer
# 	a : eps + 1
# 7	assumption		{_a in {-2^{t - 1} + 1 .. -(eps + 1)}} |- _a in {-2^{t - 1} + 1 .. -(eps + 1)}
# 8	instantiation	21, 17	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 9	instantiation	16, 10, 12	{eps in {1 .. 2^{t - 1} - 2}} |- (eps + 1) in Integer
# 	a : eps, b : 1
# 10	instantiation	11, 12, 13, 14	{eps in {1 .. 2^{t - 1} - 2}} |- eps in Integer
# 	a : 1, b : 2^{t - 1} - 2, n : eps
# 11	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n in Integer)]
# 12	instantiation	23, 24, 15	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 13	instantiation	16, 17, 18	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 14	assumption		{eps in {1 .. 2^{t - 1} - 2}} |- eps in {1 .. 2^{t - 1} - 2}
# 15	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 16	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 17	instantiation	23, 19, 20	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 18	instantiation	21, 22	|- (-2) in Integer
# 	a : 2
# 19	conjecture		|- NaturalPos proper_subset Integer
# 20	conjecture		|- 2^{t - 1} in NaturalPos
# 21	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 22	instantiation	23, 24, 25	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 23	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 24	conjecture		|- Natural proper_subset Integer
# 25	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
