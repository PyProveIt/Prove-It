# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Variable
from proveit.logic import InSet
from proveit.physics.quantum.QPE import full_domain_sans_zero, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(sub_expr1, Conditional(InSet(sub_expr1, full_domain_sans_zero), InSet(sub_expr1, pos_domain)))
# Out:
# expr: _a -> {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {eps + 1 .. 2^{t - 1}}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \mapsto \left\{{_{-}a} \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} - \left\{0\right\}\right) \textrm{ if } {_{-}a} \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a -> {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. _a in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (_a, {-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (_a, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. _a
#    core type: Variable
#    sub-expressions:
# 9. {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 16
#    operands: 12
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. ({-2^{t - 1} + 1 .. 2^{t - 1}}, {0})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 15, 27
# 13. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. {0}
#     core type: Operation
#     operator: 18
#     operand: 22
# 15. eps + 1
#     core type: Operation
#     operator: 32
#     operands: 20
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 18. Set
#     core type: Literal
#     sub-expressions:
# 19. (0)
#     core type: ExprTuple
#     sub-expressions: 22
# 20. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 23, 38
# 21. -2^{t - 1} + 1
#     core type: Operation
#     operator: 32
#     operands: 24
# 22. 0
#     core type: Literal
#     sub-expressions:
# 23. eps
#     core type: Variable
#     sub-expressions:
# 24. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 38
# 25. -2^{t - 1}
#     core type: Operation
#     operator: 36
#     operand: 27
# 26. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 27. 2^{t - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 28. Exp
#     core type: Literal
#     sub-expressions:
# 29. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. 2
#     core type: Literal
#     sub-expressions:
# 31. t - 1
#     core type: Operation
#     operator: 32
#     operands: 33
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. t
#     core type: Literal
#     sub-expressions:
# 35. -1
#     core type: Operation
#     operator: 36
#     operand: 38
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. (1)
#     core type: ExprTuple
#     sub-expressions: 38
# 38. 1
#     core type: Literal
#     sub-expressions:
