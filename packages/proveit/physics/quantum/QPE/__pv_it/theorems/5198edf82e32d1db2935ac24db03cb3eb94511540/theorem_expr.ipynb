# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#a17">a17</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import a17

# %%
# check that the built expression is the same as the stored expression
assert a17.expr == stored_expr
assert a17.expr._style_id == stored_expr._style_id
print("Passed sanity check: a17 matches stored_expr")
# Out:
# Passed sanity check: a17 matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(a17.latex())
# Out:
# \vdash \forall_{t \in \mathbb{N}^+}~\left[\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1}\right)\right]

# %%
a17.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
a17.expr_info()
# Out:
# 0. forall_{t in NaturalPos} [forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (t -> {forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}) if t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. t -> {forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}) if t in NaturalPos.
#    core type: Lambda
#    parameter: 47
#    body: 3
# 3. {forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}) if t in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. t in NaturalPos
#    core type: Operation
#    operator: 16
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# ...
