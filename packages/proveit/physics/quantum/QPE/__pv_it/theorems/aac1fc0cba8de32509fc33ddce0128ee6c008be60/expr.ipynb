# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = Forall([eps], Forall([l], InSet(l, full_domain), domain = neg_domain), domain = NaturalPos)
# Out:
# expr: forall_{eps in NaturalPos} [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\varepsilon \in \mathbb{N}^+}~\left[\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{eps in NaturalPos} [forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (eps -> {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. eps -> {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 32
#    body: 3
# 3. {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. eps in NaturalPos
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 32, 10
# 9. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 18
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. l
#     core type: Variable
#     sub-expressions:
# 19. {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 23, 31
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. -2^{t - 1} + 1
#     core type: Operation
#     operator: 37
#     operands: 25
# 24. -(eps + 1)
#     core type: Operation
#     operator: 41
#     operand: 28
# 25. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 43
# 26. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 28
# 27. -2^{t - 1}
#     core type: Operation
#     operator: 41
#     operand: 31
# 28. eps + 1
#     core type: Operation
#     operator: 37
#     operands: 30
# 29. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 43
# 31. 2^{t - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. eps
#     core type: Variable
#     sub-expressions:
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. t - 1
#     core type: Operation
#     operator: 37
#     operands: 38
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 39. t
#     core type: Literal
#     sub-expressions:
# 40. -1
#     core type: Operation
#     operator: 41
#     operand: 43
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. 1
#     core type: Literal
#     sub-expressions:
