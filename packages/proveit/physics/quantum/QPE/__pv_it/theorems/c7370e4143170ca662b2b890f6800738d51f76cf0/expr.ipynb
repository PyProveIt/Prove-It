# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import InSet
from proveit.numbers import Abs, Add, IntervalOC, Mult, Neg, frac, pi, two, zero
from proveit.physics.quantum.QPE import delta_, full_domain, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(InSet(Mult(pi, Abs(Add(delta_, Neg(frac(l, two_pow_t))))), IntervalOC(zero, frac(pi, two))), InSet(l, full_domain)))
# Out:
# expr: l -> {(pi * |delta - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{\left(\pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right) \in \left(0,\frac{\pi}{2}\right] \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {(pi * |delta - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 40
#    body: 1
# 1. {(pi * |delta - (l / 2^{t})|) in (0,pi / 2] if l in {-2^{t - 1} + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (pi * |delta - (l / 2^{t})|) in (0,pi / 2]
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (pi * |delta - (l / 2^{t})|, (0,pi / 2])
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 40, 9
# 7. pi * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (0,pi / 2]
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. {-2^{t - 1} + 1 .. 2^{t - 1}}
#    core type: Operation
# ...
