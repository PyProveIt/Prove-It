# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k, t
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Add, Exp, Interval, NaturalPos, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet, ket1

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, t)
expr = Conditional(Forall([k], Equals(TensorProd(ket1, RegisterKet(k, t)), RegisterKet(Add(sub_expr1, k), Add(t, one))), domain = Interval(zero, Add(sub_expr1, Neg(one)))), InSet(t, NaturalPos))
# Out:
# expr: {forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}) if t in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1}\right) \textrm{ if } t \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}) if t in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. t in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (t, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 44, 7
# 6. k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 36
#    body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 9
#    condition: 10
# ...
