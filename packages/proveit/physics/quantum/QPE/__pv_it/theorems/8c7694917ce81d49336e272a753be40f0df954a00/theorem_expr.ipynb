# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#l_non_zero">l_non_zero</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import l_non_zero

# %%
# check that the built expression is the same as the stored expression
assert l_non_zero.expr == stored_expr
assert l_non_zero.expr._style_id == stored_expr._style_id
print("Passed sanity check: l_non_zero matches stored_expr")
# Out:
# Passed sanity check: l_non_zero matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(l_non_zero.latex())
# Out:
# \vdash \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} - \left\{0\right\}}~\left(l \in \mathbb{Z}^{\neq 0}\right)

# %%
l_non_zero.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
l_non_zero.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (l in IntegerNonZero)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).
#    core type: Lambda
#    parameter: 11
#    body: 4
# 4. {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. l in IntegerNonZero
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (l, IntegerNonZero)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: ExprTuple
# ...
