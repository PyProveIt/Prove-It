# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#pos_domain_in_full_domain">pos_domain_in_full_domain</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import pos_domain_in_full_domain

# %%
# check that the built expression is the same as the stored expression
assert pos_domain_in_full_domain.expr == stored_expr
assert pos_domain_in_full_domain.expr._style_id == stored_expr._style_id
print("Passed sanity check: pos_domain_in_full_domain matches stored_expr")
# Out:
# Passed sanity check: pos_domain_in_full_domain matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(pos_domain_in_full_domain.latex())
# Out:
# \vdash \forall_{\varepsilon \in \mathbb{N}^+}~\left[\forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right)\right]

# %%
pos_domain_in_full_domain.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
pos_domain_in_full_domain.expr_info()
# Out:
# 0. forall_{eps in NaturalPos} [forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})]
#    core type: Operation
#    operator: 6
#    operand: 2
# 1. (eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 28
#    body: 3
# 3. {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. eps in NaturalPos
#    core type: Operation
#    operator: 15
#    operands: 8
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 28, 10
# 9. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 18
#    body: 11
# 10. NaturalPos
#     core type: Literal
#     sub-expressions:
# 11. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 12
#     condition: 13
# 12. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 14
# 13. l in {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. l
#     core type: Variable
#     sub-expressions:
# 19. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 23, 30
# 21. Interval
#     core type: Literal
#     sub-expressions:
# 22. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 24, 30
# 23. -2^{t - 1} + 1
#     core type: Operation
#     operator: 35
#     operands: 25
# 24. eps + 1
#     core type: Operation
#     operator: 35
#     operands: 26
# 25. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 41
# 26. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 41
# 27. -2^{t - 1}
#     core type: Operation
#     operator: 39
#     operand: 30
# 28. eps
#     core type: Variable
#     sub-expressions:
# 29. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 30
# 30. 2^{t - 1}
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. 2
#     core type: Literal
#     sub-expressions:
# 34. t - 1
#     core type: Operation
#     operator: 35
#     operands: 36
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 37, 38
# 37. t
#     core type: Literal
#     sub-expressions:
# 38. -1
#     core type: Operation
#     operator: 39
#     operand: 41
# 39. -
#     core type: Literal
#     sub-expressions:
# 40. (1)
#     core type: ExprTuple
#     sub-expressions: 41
# 41. 1
#     core type: Literal
#     sub-expressions:
