# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, pos_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(eps, Conditional(Forall([l], InSet(l, full_domain), domain = pos_domain), InSet(eps, NaturalPos))))
# Out:
# expr: (eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{\forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \textrm{ if } \varepsilon \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. eps in NaturalPos
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 8. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 17
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. l in {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. l
#     core type: Variable
#     sub-expressions:
# 18. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 29
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 23, 29
# 22. -2^{t - 1} + 1
#     core type: Operation
#     operator: 34
#     operands: 24
# 23. eps + 1
#     core type: Operation
#     operator: 34
#     operands: 25
# 24. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 40
# 25. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 40
# 26. -2^{t - 1}
#     core type: Operation
#     operator: 38
#     operand: 29
# 27. eps
#     core type: Variable
#     sub-expressions:
# 28. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 29
# 29. 2^{t - 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 2
#     core type: Literal
#     sub-expressions:
# 33. t - 1
#     core type: Operation
#     operator: 34
#     operands: 35
# 34. +
#     core type: Literal
#     sub-expressions:
# 35. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. t
#     core type: Literal
#     sub-expressions:
# 37. -1
#     core type: Operation
#     operator: 38
#     operand: 40
# 38. -
#     core type: Literal
#     sub-expressions:
# 39. (1)
#     core type: ExprTuple
#     sub-expressions: 40
# 40. 1
#     core type: Literal
#     sub-expressions:
