# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, pos_domain

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([l], InSet(l, full_domain), domain = pos_domain), InSet(eps, NaturalPos))
# Out:
# expr: {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. eps in NaturalPos
#    core type: Operation
#    operator: 12
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 25, 7
# 6. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 15
#    body: 8
# 7. NaturalPos
#    core type: Literal
#    sub-expressions:
# 8. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. l in {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 15, 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 18
#     operands: 17
# 15. l
#     core type: Variable
#     sub-expressions:
# 16. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 27
# 18. Interval
#     core type: Literal
#     sub-expressions:
# 19. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 21, 27
# 20. -2^{t - 1} + 1
#     core type: Operation
#     operator: 32
#     operands: 22
# 21. eps + 1
#     core type: Operation
#     operator: 32
#     operands: 23
# 22. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 38
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 38
# 24. -2^{t - 1}
#     core type: Operation
#     operator: 36
#     operand: 27
# 25. eps
#     core type: Variable
#     sub-expressions:
# 26. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 27
# 27. 2^{t - 1}
#     core type: Operation
#     operator: 28
#     operands: 29
# 28. Exp
#     core type: Literal
#     sub-expressions:
# 29. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. 2
#     core type: Literal
#     sub-expressions:
# 31. t - 1
#     core type: Operation
#     operator: 32
#     operands: 33
# 32. +
#     core type: Literal
#     sub-expressions:
# 33. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. t
#     core type: Literal
#     sub-expressions:
# 35. -1
#     core type: Operation
#     operator: 36
#     operand: 38
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. (1)
#     core type: ExprTuple
#     sub-expressions: 38
# 38. 1
#     core type: Literal
#     sub-expressions:
