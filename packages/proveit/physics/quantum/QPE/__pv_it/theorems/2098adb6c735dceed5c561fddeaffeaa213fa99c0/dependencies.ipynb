# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#pos_domain_in_full_domain_sans_zero">pos_domain_in_full_domain_sans_zero</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/pos_domain_in_full_domain_sans_zero/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import pos_domain_in_full_domain_sans_zero

# %%
# %dependencies pos_domain_in_full_domain_sans_zero
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove pos_domain_in_full_domain_sans_zero</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../logic/sets/enumeration/_theory_nbs_/proofs/fold/thm_proof.ipynb">proveit.logic.sets.enumeration.fold</a></dt><dd><a class="ProveItLink" href="../../../../../../logic/sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.ipynb"><img src="../../../../../../logic/sets/enumeration/__pv_it/theorems/22e34c6090b35d0e995aaf11b862758af5d969170/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
