# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps, l
from proveit.logic import InSet
from proveit.numbers import Add, Exp, LessEq, Mult, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import Pfail, diff_l_scaled_delta, eps_domain, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Exp(diff_l_scaled_delta, two))
expr = ExprTuple(Lambda(eps, Conditional(LessEq(Pfail(eps), Mult(frac(one, four), Add(Sum(sub_expr1, sub_expr2, domain = neg_domain), Sum(sub_expr1, sub_expr2, domain = pos_domain)))), InSet(eps, eps_domain))))
# Out:
# expr: (eps -> {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) if eps in {1 .. 2^{t - 1} - 2}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{P_{\rm fail}(\varepsilon) \leq \left(\frac{1}{4} \cdot \left(\left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right)\right) \textrm{ if } \varepsilon \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) if eps in {1 .. 2^{t - 1} - 2}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) if eps in {1 .. 2^{t - 1} - 2}.
#    core type: Lambda
#    parameter: 62
#    body: 2
# 2. {Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})))) if eps in {1 .. 2^{t - 1} - 2}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. Pfail(eps) <= ((1 / 4) * ((Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))))
#    core type: Operation
#    operator: 5
# ...
