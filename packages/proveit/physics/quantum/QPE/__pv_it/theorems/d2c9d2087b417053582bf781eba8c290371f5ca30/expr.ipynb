# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k, t
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet, ket1

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, t)
expr = Lambda(k, Conditional(Equals(TensorProd(ket1, RegisterKet(k, t)), RegisterKet(Add(sub_expr1, k), Add(t, one))), InSet(k, Interval(zero, Add(sub_expr1, Neg(one))))))
# Out:
# expr: k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 29
#    body: 1
# 1. {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (|1〉 otimes |k〉_{t}, |2^{t} + k〉_{t + 1})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 29, 10
# 8. |1〉 otimes |k〉_{t}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 23
#    operands: 13
# 10. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 14
# ...
