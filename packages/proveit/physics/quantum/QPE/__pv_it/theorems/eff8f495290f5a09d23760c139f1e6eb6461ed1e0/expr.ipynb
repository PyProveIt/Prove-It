# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Add, Exp, Sum, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Exp(diff_l_scaled_delta, two))
expr = Add(Sum(sub_expr1, sub_expr2, domain = neg_domain), Sum(sub_expr1, sub_expr2, domain = pos_domain))
# Out:
# expr: (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right) + \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})) + (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 48
#    operands: 1
# 1. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}), Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 5
#    operand: 7
# 3. Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (l -> {1 / (l - (2^{t} * delta))^{2} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (l -> {1 / (l - (2^{t} * delta))^{2} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 8
# ...
