# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, pos_domain

# %%
# build up the expression from sub-expressions
expr = Lambda(eps, Conditional(Forall([l], InSet(l, full_domain), domain = pos_domain), InSet(eps, NaturalPos)))
# Out:
# expr: eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \varepsilon \mapsto \left\{\forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \textrm{ if } \varepsilon \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. eps -> {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. {forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{l in {eps + 1 .. 2^{t - 1}}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. eps in NaturalPos
#    core type: Operation
#    operator: 13
#    operands: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 26, 8
# 7. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 8. NaturalPos
#    core type: Literal
#    sub-expressions:
# 9. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 10
#    condition: 11
# 10. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. l in {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 15. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 19
#     operands: 18
# 16. l
#     core type: Variable
#     sub-expressions:
# 17. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 21, 28
# 19. Interval
#     core type: Literal
#     sub-expressions:
# 20. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 28
# 21. -2^{t - 1} + 1
#     core type: Operation
#     operator: 33
#     operands: 23
# 22. eps + 1
#     core type: Operation
#     operator: 33
#     operands: 24
# 23. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 39
# 24. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 39
# 25. -2^{t - 1}
#     core type: Operation
#     operator: 37
#     operand: 28
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 28
# 28. 2^{t - 1}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 2
#     core type: Literal
#     sub-expressions:
# 32. t - 1
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. +
#     core type: Literal
#     sub-expressions:
# 34. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. t
#     core type: Literal
#     sub-expressions:
# 36. -1
#     core type: Operation
#     operator: 37
#     operand: 39
# 37. -
#     core type: Literal
#     sub-expressions:
# 38. (1)
#     core type: ExprTuple
#     sub-expressions: 39
# 39. 1
#     core type: Literal
#     sub-expressions:
