# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, NaturalPos, Neg, Sum, e, frac, i, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, psi_t, t_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Forall([t], Equals(psi_t, Mult(frac(one, Exp(two, frac(t_, two))), Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), domain = Interval(zero, Add(two_pow_t, Neg(one)))))), domain = NaturalPos)
# Out:
# expr: forall_{t in NaturalPos} (psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{t \in \mathbb{N}^+}~\left(\psi_{t} = \left(\frac{1}{2^{\frac{t}{2}}} \cdot \left(\sum_{k=0}^{2^{t} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{t in NaturalPos} (psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (t -> {psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))) if t in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. t -> {psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))) if t in NaturalPos.
#    core type: Lambda
#    parameter: 12
#    body: 4
# 4. {psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))) if t in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. psi_{t} = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. t in NaturalPos
#    core type: Operation
#    operator: 33
#    operands: 9
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (psi_{t}, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (t, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. psi_{t}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: Operation
#     operator: 47
#     operands: 16
# 12. t
#     core type: Variable
#     sub-expressions:
# 13. NaturalPos
#     core type: Literal
#     sub-expressions:
# 14. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 15. (psi, t)
#     core type: ExprTuple
#     sub-expressions: 17, 62
# 16. (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. psi
#     core type: Literal
#     sub-expressions:
# 18. 1 / 2^{t / 2}
#     core type: Operation
#     operator: 30
#     operands: 20
# 19. Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#     core type: Operation
#     operator: 21
#     operand: 24
# 20. (1, 2^{t / 2})
#     core type: ExprTuple
#     sub-expressions: 63, 23
# 21. Sum
#     core type: Literal
#     sub-expressions:
# 22. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 24
# 23. 2^{t / 2}
#     core type: Operation
#     operator: 57
#     operands: 25
# 24. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t} - 1}.
#     core type: Lambda
#     parameter: 54
#     body: 26
# 25. (2, t / 2)
#     core type: ExprTuple
#     sub-expressions: 61, 27
# 26. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t} - 1}.
#     core type: Conditional
#     value: 28
#     condition: 29
# 27. t / 2
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 47
#     operands: 32
# 29. k in {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 30. /
#     core type: Literal
#     sub-expressions:
# 31. (t, 2)
#     core type: ExprTuple
#     sub-expressions: 62, 61
# 32. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 33. in
#     core type: Literal
#     sub-expressions:
# 34. (k, {0 .. 2^{t} - 1})
#     core type: ExprTuple
#     sub-expressions: 54, 37
# 35. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 57
#     operands: 38
# 36. |k〉
#     core type: Operation
#     operator: 39
#     operand: 54
# 37. {0 .. 2^{t} - 1}
#     core type: Operation
#     operator: 41
#     operands: 42
# 38. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 39. KET
#     core type: Literal
#     sub-expressions:
# 40. (k)
#     core type: ExprTuple
#     sub-expressions: 54
# 41. Interval
#     core type: Literal
#     sub-expressions:
# 42. (0, 2^{t} - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 43. e
#     core type: Literal
#     sub-expressions:
# 44. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 47
#     operands: 48
# 45. 0
#     core type: Literal
#     sub-expressions:
# 46. 2^{t} - 1
#     core type: Operation
#     operator: 49
#     operands: 50
# 47. *
#     core type: Literal
#     sub-expressions:
# 48. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 61, 51, 52, 53, 54
# 49. +
#     core type: Literal
#     sub-expressions:
# 50. (2^{t}, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 56
# 51. pi
#     core type: Literal
#     sub-expressions:
# 52. i
#     core type: Literal
#     sub-expressions:
# 53. phase
#     core type: Literal
#     sub-expressions:
# 54. k
#     core type: Variable
#     sub-expressions:
# 55. 2^{t}
#     core type: Operation
#     operator: 57
#     operands: 58
# 56. -1
#     core type: Operation
#     operator: 59
#     operand: 63
# 57. Exp
#     core type: Literal
#     sub-expressions:
# 58. (2, t)
#     core type: ExprTuple
#     sub-expressions: 61, 62
# 59. -
#     core type: Literal
#     sub-expressions:
# 60. (1)
#     core type: ExprTuple
#     sub-expressions: 63
# 61. 2
#     core type: Literal
#     sub-expressions:
# 62. t
#     core type: Literal
#     sub-expressions:
# 63. 1
#     core type: Literal
#     sub-expressions:
