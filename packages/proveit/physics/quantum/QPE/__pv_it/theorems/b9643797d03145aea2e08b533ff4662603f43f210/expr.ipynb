# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import InSet
from proveit.numbers import Add, Integer, Mult, Neg, Real
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(InSet(Add(Mult(two_pow_t, delta_), Neg(l)), Real), InSet(l, Integer))))
# Out:
# expr: (l -> {((2^{t} * delta) - l) in Real if l in Integer.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\left(\left(2^{t} \cdot \delta\right) - l\right) \in \mathbb{R} \textrm{ if } l \in \mathbb{Z}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {((2^{t} * delta) - l) in Real if l in Integer.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {((2^{t} * delta) - l) in Real if l in Integer.
#    core type: Lambda
#    parameter: 21
#    body: 2
# 2. {((2^{t} * delta) - l) in Real if l in Integer.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. ((2^{t} * delta) - l) in Real
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. l in Integer
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. ((2^{t} * delta) - l, Real)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, Integer)
#    core type: ExprTuple
#    sub-expressions: 21, 10
# 8. (2^{t} * delta) - l
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. Real
#    core type: Literal
#    sub-expressions:
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2^{t} * delta
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. -l
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (l)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. delta
#     core type: Literal
#     sub-expressions:
# 21. l
#     core type: Variable
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t
#     core type: Literal
#     sub-expressions:
