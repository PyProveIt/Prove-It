# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet, ket1

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, t)
expr = Forall([k], Equals(TensorProd(ket1, RegisterKet(k, t)), RegisterKet(Add(sub_expr1, k), Add(t, one))), domain = Interval(zero, Add(sub_expr1, Neg(one))))
# Out:
# expr: forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{k \in \{0~\ldotp \ldotp~2^{t} - 1\}}~\left(\left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{k in {0 .. 2^{t} - 1}} ((|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 32
#    body: 4
# 4. {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. k in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (|1〉 otimes |k〉_{t}, |2^{t} + k〉_{t + 1})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
# ...
