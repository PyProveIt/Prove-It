# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#scaled_delta_minus_l__in__real">scaled_delta_minus_l__in__real</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/scaled_delta_minus_l__in__real/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import scaled_delta_minus_l__in__real

# %%
# %dependencies scaled_delta_minus_l__in__real
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on scaled_delta_minus_l__in__real</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/alpha_l_sqrd_ineq/thm_proof.ipynb">proveit.physics.quantum.QPE.alpha_l_sqrd_ineq</a></dt><dd><a class="ProveItLink" href="../9f743f92f8370e4a37572464aececf142e1b21290/expr.ipynb"><img src="../9f743f92f8370e4a37572464aececf142e1b21290/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
