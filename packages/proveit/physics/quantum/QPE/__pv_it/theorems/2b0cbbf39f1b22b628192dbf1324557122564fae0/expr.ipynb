# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, k, t
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Interval, Neg, one, two, zero
from proveit.physics.quantum import RegisterKet, ket1

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(two, t)
expr = ExprTuple(Lambda(k, Conditional(Equals(TensorProd(ket1, RegisterKet(k, t)), RegisterKet(Add(sub_expr1, k), Add(t, one))), InSet(k, Interval(zero, Add(sub_expr1, Neg(one)))))))
# Out:
# expr: (k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1} \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t} - 1\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Lambda
#    parameter: 30
#    body: 2
# 2. {(|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1} if k in {0 .. 2^{t} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. k in {0 .. 2^{t} - 1}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (|1〉 otimes |k〉_{t}, |2^{t} + k〉_{t + 1})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (k, {0 .. 2^{t} - 1})
#    core type: ExprTuple
#    sub-expressions: 30, 11
# 9. |1〉 otimes |k〉_{t}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. |2^{t} + k〉_{t + 1}
# ...
