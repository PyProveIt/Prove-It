# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#all_abs_alpha_l_are_nonneg">all_abs_alpha_l_are_nonneg</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_abs_alpha_l_are_nonneg/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import all_abs_alpha_l_are_nonneg

# %%
# %dependencies all_abs_alpha_l_are_nonneg
# Out:
# <h3>Unproven conjectures required (directly or indirectly) to prove all_abs_alpha_l_are_nonneg</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../numbers/absolute_value/_theory_nbs_/proofs/abs_complex_closure_non_neg_real/thm_proof.ipynb">proveit.numbers.absolute_value.abs_complex_closure_non_neg_real</a></dt><dd><a class="ProveItLink" href="../../../../../../numbers/absolute_value/__pv_it/theorems/27904c7e42907e8af2c98d482a0dbea524104c260/expr.ipynb"><img src="../../../../../../numbers/absolute_value/__pv_it/theorems/27904c7e42907e8af2c98d482a0dbea524104c260/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_alpha_l_is_complex/thm_proof.ipynb">proveit.physics.quantum.QPE.all_alpha_l_is_complex</a></dt><dd><a class="ProveItLink" href="../263cfe4ac9113e0fbd77ca66a9172fbe085509a00/expr.ipynb"><img src="../263cfe4ac9113e0fbd77ca66a9172fbe085509a00/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
# <h3>Theorems/conjectures that depend directly on all_abs_alpha_l_are_nonneg</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_abs_alpha_l_sqrd_are_real/thm_proof.ipynb">proveit.physics.quantum.QPE.all_abs_alpha_l_sqrd_are_real</a></dt><dd><a class="ProveItLink" href="../5b8a7360996bf4708b971d54bd270430105bc8e90/expr.ipynb"><img src="../5b8a7360996bf4708b971d54bd270430105bc8e90/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/alpha_l_sqrd_ineq/thm_proof.ipynb">proveit.physics.quantum.QPE.alpha_l_sqrd_ineq</a></dt><dd><a class="ProveItLink" href="../9f743f92f8370e4a37572464aececf142e1b21290/expr.ipynb"><img src="../9f743f92f8370e4a37572464aececf142e1b21290/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
