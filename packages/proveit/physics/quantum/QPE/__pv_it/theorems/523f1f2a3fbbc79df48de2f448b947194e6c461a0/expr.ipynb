# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, InSet
from proveit.physics.quantum.QPE import full_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = Forall([l], InSet(l, full_domain), domain = neg_domain)
# Out:
# expr: forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 11
#    body: 4
# 4. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. l
#     core type: Variable
#     sub-expressions:
# 12. {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 16, 24
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. -2^{t - 1} + 1
#     core type: Operation
#     operator: 30
#     operands: 18
# 17. -(eps + 1)
#     core type: Operation
#     operator: 34
#     operand: 21
# 18. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 36
# 19. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 21
# 20. -2^{t - 1}
#     core type: Operation
#     operator: 34
#     operand: 24
# 21. eps + 1
#     core type: Operation
#     operator: 30
#     operands: 23
# 22. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 36
# 24. 2^{t - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. eps
#     core type: Variable
#     sub-expressions:
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. t - 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. t
#     core type: Literal
#     sub-expressions:
# 33. -1
#     core type: Operation
#     operator: 34
#     operand: 36
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (1)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. 1
#     core type: Literal
#     sub-expressions:
