# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, l
from proveit.logic import InSet
from proveit.numbers import IntegerNonZero
from proveit.physics.quantum.QPE import full_domain_sans_zero

# %%
# build up the expression from sub-expressions
expr = Lambda(l, Conditional(InSet(l, IntegerNonZero), InSet(l, full_domain_sans_zero)))
# Out:
# expr: l -> {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# l \mapsto \left\{l \in \mathbb{Z}^{\neq 0} \textrm{ if } l \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} - \left\{0\right\}\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. l -> {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {l in IntegerNonZero if l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. l in IntegerNonZero
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (l, IntegerNonZero)
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (l, {-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. IntegerNonZero
#    core type: Literal
#    sub-expressions:
# 8. l
#    core type: Variable
#    sub-expressions:
# 9. {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. ({-2^{t - 1} + 1 .. 2^{t - 1}}, {0})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. {0}
#     core type: Operation
#     operator: 16
#     operand: 19
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 18, 23
# 16. Set
#     core type: Literal
#     sub-expressions:
# 17. (0)
#     core type: ExprTuple
#     sub-expressions: 19
# 18. -2^{t - 1} + 1
#     core type: Operation
#     operator: 28
#     operands: 20
# 19. 0
#     core type: Literal
#     sub-expressions:
# 20. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 21, 34
# 21. -2^{t - 1}
#     core type: Operation
#     operator: 32
#     operand: 23
# 22. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 2^{t - 1}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t - 1
#     core type: Operation
#     operator: 28
#     operands: 29
# 28. +
#     core type: Literal
#     sub-expressions:
# 29. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. t
#     core type: Literal
#     sub-expressions:
# 31. -1
#     core type: Operation
#     operator: 32
#     operand: 34
# 32. -
#     core type: Literal
#     sub-expressions:
# 33. (1)
#     core type: ExprTuple
#     sub-expressions: 34
# 34. 1
#     core type: Literal
#     sub-expressions:
