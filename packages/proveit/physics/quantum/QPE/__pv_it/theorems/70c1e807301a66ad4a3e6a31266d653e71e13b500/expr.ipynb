# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k, t
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals
from proveit.numbers import Add, Exp, one, two
from proveit.physics.quantum import RegisterKet, ket1

# %%
# build up the expression from sub-expressions
expr = Equals(TensorProd(ket1, RegisterKet(k, t)), RegisterKet(Add(Exp(two, t), k), Add(t, one)))
# Out:
# expr: (|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\lvert 1 \rangle {\otimes} \lvert k \rangle_{t}\right) = \lvert 2^{t} + k \rangle_{t + 1}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|1〉 otimes |k〉_{t}) = |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|1〉 otimes |k〉_{t}, |2^{t} + k〉_{t + 1})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |1〉 otimes |k〉_{t}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. |2^{t} + k〉_{t + 1}
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. otimes
#    core type: Literal
#    sub-expressions:
# 6. (|1〉, |k〉_{t})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. (2^{t} + k, t + 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. |1〉
#    core type: Operation
#    operator: 12
#    operand: 21
# 9. |k〉_{t}
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. 2^{t} + k
#     core type: Operation
#     operator: 17
#     operands: 16
# 11. t + 1
#     core type: Operation
#     operator: 17
#     operands: 18
# 12. KET
#     core type: Literal
#     sub-expressions:
# 13. (1)
#     core type: ExprTuple
#     sub-expressions: 21
# 14. REGISTER_KET
#     core type: Literal
#     sub-expressions:
# 15. (k, t)
#     core type: ExprTuple
#     sub-expressions: 20, 25
# 16. (2^{t}, k)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (t, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 21
# 19. 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. k
#     core type: Variable
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t
#     core type: Variable
#     sub-expressions:
