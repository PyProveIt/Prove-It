# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, eps, l
from proveit.logic import Forall, InSet
from proveit.numbers import NaturalPos
from proveit.physics.quantum.QPE import full_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(eps, Conditional(Forall([l], InSet(l, full_domain), domain = neg_domain), InSet(eps, NaturalPos))))
# Out:
# expr: (eps -> {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \mapsto \left\{\forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}}~\left(l \in \{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\}\right) \textrm{ if } \varepsilon \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps -> {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. eps -> {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Lambda
#    parameter: 31
#    body: 2
# 2. {forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) if eps in NaturalPos.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. eps in NaturalPos
#    core type: Operation
#    operator: 14
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (eps, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 31, 9
# 8. l -> {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 17
#    body: 10
# 9. NaturalPos
#    core type: Literal
#    sub-expressions:
# 10. {l in {-2^{t - 1} + 1 .. 2^{t - 1}} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#     core type: Conditional
#     value: 11
#     condition: 12
# 11. l in {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (l, {-2^{t - 1} + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 14. in
#     core type: Literal
#     sub-expressions:
# 15. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {-2^{t - 1} + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. l
#     core type: Variable
#     sub-expressions:
# 18. {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. (-2^{t - 1} + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 22, 30
# 20. Interval
#     core type: Literal
#     sub-expressions:
# 21. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. -2^{t - 1} + 1
#     core type: Operation
#     operator: 36
#     operands: 24
# 23. -(eps + 1)
#     core type: Operation
#     operator: 40
#     operand: 27
# 24. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 42
# 25. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 27
# 26. -2^{t - 1}
#     core type: Operation
#     operator: 40
#     operand: 30
# 27. eps + 1
#     core type: Operation
#     operator: 36
#     operands: 29
# 28. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 30
# 29. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 31, 42
# 30. 2^{t - 1}
#     core type: Operation
#     operator: 32
#     operands: 33
# 31. eps
#     core type: Variable
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 2
#     core type: Literal
#     sub-expressions:
# 35. t - 1
#     core type: Operation
#     operator: 36
#     operands: 37
# 36. +
#     core type: Literal
#     sub-expressions:
# 37. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 38. t
#     core type: Literal
#     sub-expressions:
# 39. -1
#     core type: Operation
#     operator: 40
#     operand: 42
# 40. -
#     core type: Literal
#     sub-expressions:
# 41. (1)
#     core type: ExprTuple
#     sub-expressions: 42
# 42. 1
#     core type: Literal
#     sub-expressions:
