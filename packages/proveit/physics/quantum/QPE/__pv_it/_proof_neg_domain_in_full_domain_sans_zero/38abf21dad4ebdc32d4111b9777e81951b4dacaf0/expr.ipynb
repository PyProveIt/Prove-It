# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, eps, l
from proveit.logic import InSet
from proveit.physics.quantum.QPE import eps_domain, neg_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(InSet(eps, eps_domain), InSet(l, neg_domain))
# Out:
# expr: (eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\varepsilon \in \{1~\ldotp \ldotp~2^{t - 1} - 2\}, l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (eps in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. eps in {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (eps, {1 .. 2^{t - 1} - 2})
#    core type: ExprTuple
#    sub-expressions: 25, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. {1 .. 2^{t - 1} - 2}
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. l
#    core type: Variable
#    sub-expressions:
# 8. {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (1, 2^{t - 1} - 2)
#    core type: ExprTuple
#    sub-expressions: 36, 12
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 2^{t - 1} - 2
#     core type: Operation
#     operator: 30
#     operands: 15
# 13. -2^{t - 1} + 1
#     core type: Operation
#     operator: 30
#     operands: 16
# 14. -(eps + 1)
#     core type: Operation
#     operator: 34
#     operand: 20
# 15. (2^{t - 1}, -2)
#     core type: ExprTuple
#     sub-expressions: 24, 18
# 16. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 36
# 17. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. -2
#     core type: Operation
#     operator: 34
#     operand: 28
# 19. -2^{t - 1}
#     core type: Operation
#     operator: 34
#     operand: 24
# 20. eps + 1
#     core type: Operation
#     operator: 30
#     operands: 23
# 21. (2)
#     core type: ExprTuple
#     sub-expressions: 28
# 22. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 24
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 36
# 24. 2^{t - 1}
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. eps
#     core type: Variable
#     sub-expressions:
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. t - 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. t
#     core type: Literal
#     sub-expressions:
# 33. -1
#     core type: Operation
#     operator: 34
#     operand: 36
# 34. -
#     core type: Literal
#     sub-expressions:
# 35. (1)
#     core type: ExprTuple
#     sub-expressions: 36
# 36. 1
#     core type: Literal
#     sub-expressions:
