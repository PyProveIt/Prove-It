# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Variable
from proveit.logic import InSet
from proveit.physics.quantum.QPE import full_domain_sans_zero, neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(Lambda(sub_expr1, Conditional(InSet(sub_expr1, full_domain_sans_zero), InSet(sub_expr1, neg_domain))))
# Out:
# expr: (_a -> {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left({_{-}a} \mapsto \left\{{_{-}a} \in \left(\{-2^{t - 1} + 1~\ldotp \ldotp~2^{t - 1}\} - \left\{0\right\}\right) \textrm{ if } {_{-}a} \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (_a -> {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. _a -> {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 9
#    body: 2
# 2. {_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}) if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. _a in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (_a, {-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (_a, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}
#    core type: Operation
#    operator: 11
# ...
