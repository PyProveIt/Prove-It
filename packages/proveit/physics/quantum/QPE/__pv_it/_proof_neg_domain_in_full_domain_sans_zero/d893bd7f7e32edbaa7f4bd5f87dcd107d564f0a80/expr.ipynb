# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable
from proveit.numbers import Add, LessEq, Neg, one
from proveit.physics.quantum.QPE import two_pow_t_minus_one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple(LessEq(Add(Neg(two_pow_t_minus_one), one), sub_expr1), LessEq(sub_expr1, two_pow_t_minus_one))
# Out:
# expr: ((-2^{t - 1} + 1) <= _a, _a <= 2^{t - 1})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(-2^{t - 1} + 1\right) \leq {_{-}a}, {_{-}a} \leq 2^{t - 1}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((-2^{t - 1} + 1) <= _a, _a <= 2^{t - 1})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (-2^{t - 1} + 1) <= _a
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. _a <= 2^{t - 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (-2^{t - 1} + 1, _a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. <=
#    core type: Literal
#    sub-expressions:
# 5. (_a, 2^{t - 1})
#    core type: ExprTuple
#    sub-expressions: 7, 11
# 6. -2^{t - 1} + 1
#    core type: Operation
#    operator: 16
#    operands: 8
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. (-2^{t - 1}, 1)
#    core type: ExprTuple
#    sub-expressions: 9, 22
# 9. -2^{t - 1}
#    core type: Operation
#    operator: 20
#    operand: 11
# 10. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 11
# 11. 2^{t - 1}
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. t - 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. t
#     core type: Literal
#     sub-expressions:
# 19. -1
#     core type: Operation
#     operator: 20
#     operand: 22
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (1)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. 1
#     core type: Literal
#     sub-expressions:
