# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k
from proveit.numbers import Add, Exp, Interval, Neg, one, two
from proveit.physics.quantum.QPE import t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(Add(Exp(two, t_prime), sub_expr1), one)
sub_expr3 = Neg(sub_expr2)
expr = ExprTuple(k, Interval(Add(sub_expr2, sub_expr3), Add(Add(Exp(two, t_star), sub_expr1), sub_expr3)))
# Out:
# expr: (k, {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k, \{\left(\left(2^{t^{\prime}} - 1\right) + 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)~\ldotp \ldotp~\left(2^{t^{*}} - 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)\}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k, {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. k
#    core type: Variable
#    sub-expressions:
# 2. {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. Interval
#    core type: Literal
#    sub-expressions:
# 4. (((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1), (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. ((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)
#    core type: Operation
#    operator: 19
#    operands: 7
# 6. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)
#    core type: Operation
#    operator: 19
#    operands: 8
# 7. ((2^{t_prime} - 1) + 1, -((2^{t_prime} - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 14, 10
# 8. (2^{t_star} - 1, -((2^{t_prime} - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. 2^{t_star} - 1
#    core type: Operation
#    operator: 19
#    operands: 11
# 10. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 25
#     operand: 14
# 11. (2^{t_star}, -1)
#     core type: ExprTuple
#     sub-expressions: 13, 22
# 12. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. 2^{t_star}
#     core type: Operation
#     operator: 23
#     operands: 15
# 14. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 19
#     operands: 16
# 15. (2, t_star)
#     core type: ExprTuple
#     sub-expressions: 27, 17
# 16. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 29
# 17. t_star
#     core type: Literal
#     sub-expressions:
# 18. 2^{t_prime} - 1
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. 2^{t_prime}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. -1
#     core type: Operation
#     operator: 25
#     operand: 29
# 23. Exp
#     core type: Literal
#     sub-expressions:
# 24. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. (1)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t_prime
#     core type: Literal
#     sub-expressions:
# 29. 1
#     core type: Literal
#     sub-expressions:
