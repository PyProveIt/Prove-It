# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = ExprTuple(Lambda(k, Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), InSet(k, Interval(Add(Add(Exp(two, t_prime), sub_expr1), one), Add(Exp(two, t_star), sub_expr1))))))
# Out:
# expr: (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle \textrm{ if } k \in \{\left(2^{t^{\prime}} - 1\right) + 1~\ldotp \ldotp~2^{t^{*}} - 1\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1})
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 8. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 36
#    operands: 11
# 9. |k〉
#    core type: Operation
#    operator: 12
#    operand: 27
# 10. {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 12. KET
#     core type: Literal
#     sub-expressions:
# 13. (k)
#     core type: ExprTuple
#     sub-expressions: 27
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. ((2^{t_prime} - 1) + 1, 2^{t_star} - 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. e
#     core type: Literal
#     sub-expressions:
# 17. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 30
#     operands: 22
# 19. 2^{t_star} - 1
#     core type: Operation
#     operator: 30
#     operands: 23
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 40, 24, 25, 26, 27
# 22. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 42
# 23. (2^{t_star}, -1)
#     core type: ExprTuple
#     sub-expressions: 29, 34
# 24. pi
#     core type: Literal
#     sub-expressions:
# 25. i
#     core type: Variable
#     sub-expressions:
# 26. phase
#     core type: Literal
#     sub-expressions:
# 27. k
#     core type: Variable
#     sub-expressions:
# 28. 2^{t_prime} - 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. 2^{t_star}
#     core type: Operation
#     operator: 36
#     operands: 32
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 32. (2, t_star)
#     core type: ExprTuple
#     sub-expressions: 40, 35
# 33. 2^{t_prime}
#     core type: Operation
#     operator: 36
#     operands: 37
# 34. -1
#     core type: Operation
#     operator: 38
#     operand: 42
# 35. t_star
#     core type: Literal
#     sub-expressions:
# 36. Exp
#     core type: Literal
#     sub-expressions:
# 37. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. -
#     core type: Literal
#     sub-expressions:
# 39. (1)
#     core type: ExprTuple
#     sub-expressions: 42
# 40. 2
#     core type: Literal
#     sub-expressions:
# 41. t_prime
#     core type: Literal
#     sub-expressions:
# 42. 1
#     core type: Literal
#     sub-expressions:
