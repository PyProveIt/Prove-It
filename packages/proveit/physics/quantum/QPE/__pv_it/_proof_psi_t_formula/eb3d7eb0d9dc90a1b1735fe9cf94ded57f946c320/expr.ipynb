# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(Add(Exp(two, t_prime), sub_expr1), one)
sub_expr3 = Neg(sub_expr2)
sub_expr4 = Add(k, Neg(sub_expr3))
expr = ExprTuple(Lambda(k, Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, sub_expr4)), Ket(sub_expr4)), InSet(k, Interval(Add(sub_expr2, sub_expr3), Add(Add(Exp(two, t_star), sub_expr1), sub_expr3))))))
# Out:
# expr: (k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)} \cdot \lvert k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right) \rangle \textrm{ if } k \in \{\left(\left(2^{t^{\prime}} - 1\right) + 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)~\ldotp \ldotp~\left(2^{t^{*}} - 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#    core type: Lambda
#    parameter: 31
#    body: 2
# 2. {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉
#    core type: Operation
#    operator: 20
#    operands: 5
# ...
