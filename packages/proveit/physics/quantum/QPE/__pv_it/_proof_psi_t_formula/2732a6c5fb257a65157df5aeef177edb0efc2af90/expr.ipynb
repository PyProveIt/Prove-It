# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k
from proveit.numbers import Add, Exp, Neg, one, two
from proveit.physics.quantum.QPE import t_prime

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(k, Neg(Neg(Add(Add(Exp(two, t_prime), Neg(one)), one)))))
# Out:
# expr: (k - (-((2^{t_prime} - 1) + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k - (-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k - (-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 11
#    operands: 2
# 2. (k, -(-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. k
#    core type: Variable
#    sub-expressions:
# 4. -(-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 17
#    operand: 6
# 5. (-((2^{t_prime} - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. -((2^{t_prime} - 1) + 1)
#    core type: Operation
#    operator: 17
#    operand: 8
# 7. ((2^{t_prime} - 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 8
# 8. (2^{t_prime} - 1) + 1
#    core type: Operation
#    operator: 11
#    operands: 9
# 9. (2^{t_prime} - 1, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 21
# 10. 2^{t_prime} - 1
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. 2^{t_prime}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. -1
#     core type: Operation
#     operator: 17
#     operand: 21
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (1)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. 2
#     core type: Literal
#     sub-expressions:
# 20. t_prime
#     core type: Literal
#     sub-expressions:
# 21. 1
#     core type: Literal
#     sub-expressions:
