# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Exp.html">Exp</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.numbers import Add, Exp, Mult, Neg, e, one, pi, two
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
expr = Exp(e, Mult(two, pi, i, phase_, Add(k, Neg(Neg(Add(Add(Exp(two, t_prime), Neg(one)), one))))))
# Out:
# expr: e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)}

# %%
expr.style_options()
# Out:
# style name: exponent
# description: 'raised': exponent as a superscript; 'radical': using a radical sign
# default: raised
# current value: raised
# related methods: ('with_radical', 'without_radical')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}
#    core type: Operation
#    operator: 23
#    operands: 1
# 1. (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. e
#    core type: Literal
#    sub-expressions:
# 3. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (2, pi, i, phase, k - (-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 27, 6, 7, 8, 9
# 6. pi
#    core type: Literal
#    sub-expressions:
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. phase
#    core type: Literal
#    sub-expressions:
# 9. k - (-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 19
#    operands: 10
# 10. (k, -(-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. k
#     core type: Variable
#     sub-expressions:
# 12. -(-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 25
#     operand: 14
# 13. (-((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 14
# 14. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 25
#     operand: 16
# 15. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 19
#     operands: 17
# 17. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 18, 29
# 18. 2^{t_prime} - 1
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. 2^{t_prime}
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. -1
#     core type: Operation
#     operator: 25
#     operand: 29
# 23. Exp
#     core type: Literal
#     sub-expressions:
# 24. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. (1)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t_prime
#     core type: Literal
#     sub-expressions:
# 29. 1
#     core type: Literal
#     sub-expressions:
