# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.logic import Equals
from proveit.numbers import Exp, Mult, e, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k))
expr = Equals(sub_expr1, sub_expr1)
# Out:
# expr: (e^{2 * pi * i * phase * k} * |k〉) = (e^{2 * pi * i * phase * k} * |k〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right) = \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (e^{2 * pi * i * phase * k} * |k〉) = (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (e^{2 * pi * i * phase * k} * |k〉, e^{2 * pi * i * phase * k} * |k〉)
#    core type: ExprTuple
#    sub-expressions: 3, 3
# 3. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 13
#    operands: 4
# 4. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 5. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. |k〉
#    core type: Operation
#    operator: 9
#    operand: 19
# 7. Exp
#    core type: Literal
#    sub-expressions:
# 8. (e, 2 * pi * i * phase * k)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. KET
#    core type: Literal
#    sub-expressions:
# 10. (k)
#     core type: ExprTuple
#     sub-expressions: 19
# 11. e
#     core type: Literal
#     sub-expressions:
# 12. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 15, 16, 17, 18, 19
# 15. 2
#     core type: Literal
#     sub-expressions:
# 16. pi
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Variable
#     sub-expressions:
# 18. phase
#     core type: Literal
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
