# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(Add(Exp(two, t_prime), sub_expr1), one)
sub_expr3 = Neg(sub_expr2)
sub_expr4 = Add(k, Neg(sub_expr3))
expr = Lambda(k, Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, sub_expr4)), Ket(sub_expr4)), InSet(k, Interval(Add(sub_expr2, sub_expr3), Add(Add(Exp(two, t_star), sub_expr1), sub_expr3)))))
# Out:
# expr: k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)} \cdot \lvert k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right) \rangle \textrm{ if } k \in \{\left(\left(2^{t^{\prime}} - 1\right) + 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)~\ldotp \ldotp~\left(2^{t^{*}} - 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#    core type: Lambda
#    parameter: 30
#    body: 1
# 1. {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉
#    core type: Operation
#    operator: 19
#    operands: 4
# 3. k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}, |k - (-((2^{t_prime} - 1) + 1))〉)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)})
#    core type: ExprTuple
#    sub-expressions: 30, 9
# 7. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}
#    core type: Operation
#    operator: 45
#    operands: 10
# 8. |k - (-((2^{t_prime} - 1) + 1))〉
#    core type: Operation
#    operator: 11
#    operand: 26
# 9. {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. (k - (-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 26
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1), (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. e
#     core type: Literal
#     sub-expressions:
# 16. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#     core type: Operation
#     operator: 19
#     operands: 20
# 17. ((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 41
#     operands: 21
# 18. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 41
#     operands: 22
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (2, pi, i, phase, k - (-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 49, 23, 24, 25, 26
# 21. ((2^{t_prime} - 1) + 1, -((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 38, 35
# 22. (2^{t_star} - 1, -((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 27, 35
# 23. pi
#     core type: Literal
#     sub-expressions:
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. phase
#     core type: Literal
#     sub-expressions:
# 26. k - (-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 41
#     operands: 28
# 27. 2^{t_star} - 1
#     core type: Operation
#     operator: 41
#     operands: 29
# 28. (k, -(-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 29. (2^{t_star}, -1)
#     core type: ExprTuple
#     sub-expressions: 32, 44
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. -(-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 47
#     operand: 35
# 32. 2^{t_star}
#     core type: Operation
#     operator: 45
#     operands: 34
# 33. (-((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 35
# 34. (2, t_star)
#     core type: ExprTuple
#     sub-expressions: 49, 36
# 35. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 47
#     operand: 38
# 36. t_star
#     core type: Literal
#     sub-expressions:
# 37. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 38
# 38. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 41
#     operands: 39
# 39. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 40, 51
# 40. 2^{t_prime} - 1
#     core type: Operation
#     operator: 41
#     operands: 42
# 41. +
#     core type: Literal
#     sub-expressions:
# 42. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. 2^{t_prime}
#     core type: Operation
#     operator: 45
#     operands: 46
# 44. -1
#     core type: Operation
#     operator: 47
#     operand: 51
# 45. Exp
#     core type: Literal
#     sub-expressions:
# 46. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 47. -
#     core type: Literal
#     sub-expressions:
# 48. (1)
#     core type: ExprTuple
#     sub-expressions: 51
# 49. 2
#     core type: Literal
#     sub-expressions:
# 50. t_prime
#     core type: Literal
#     sub-expressions:
# 51. 1
#     core type: Literal
#     sub-expressions:
