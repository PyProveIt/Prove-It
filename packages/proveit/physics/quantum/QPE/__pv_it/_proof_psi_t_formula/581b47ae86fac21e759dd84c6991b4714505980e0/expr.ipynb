# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable, i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Neg(one)
sub_expr3 = Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k))
expr = ExprTuple(Sum(sub_expr1, sub_expr3, domain = Interval(zero, Add(Exp(two, t_star), sub_expr2))), Add(Sum(sub_expr1, sub_expr3, domain = Interval(zero, Add(Exp(two, t_prime), sub_expr2))), Variable("_a", latex_format = r"{_{-}a}")))
# Out:
# expr: (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉), (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + _a)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right), \left(\sum_{k=0}^{2^{t^{\prime}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) + {_{-}a}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉), (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + _a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 9
#    operand: 5
# 2. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + _a
#    core type: Operation
#    operator: 40
#    operands: 4
# 3. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉), _a)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 46
#    body: 8
# 6. Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 9
#    operand: 12
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#    core type: Conditional
#    value: 16
#    condition: 11
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. k in {0 .. 2^{t_star} - 1}
#     core type: Operation
#     operator: 20
#     operands: 13
# 12. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#     core type: Lambda
#     parameter: 46
#     body: 14
# 13. (k, {0 .. 2^{t_star} - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 15
# 14. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. {0 .. 2^{t_star} - 1}
#     core type: Operation
#     operator: 30
#     operands: 18
# 16. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 38
#     operands: 19
# 17. k in {0 .. 2^{t_prime} - 1}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. (0, 2^{t_star} - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 22
# 19. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (k, {0 .. 2^{t_prime} - 1})
#     core type: ExprTuple
#     sub-expressions: 46, 25
# 22. 2^{t_star} - 1
#     core type: Operation
#     operator: 40
#     operands: 26
# 23. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 49
#     operands: 27
# 24. |k〉
#     core type: Operation
#     operator: 28
#     operand: 46
# 25. {0 .. 2^{t_prime} - 1}
#     core type: Operation
#     operator: 30
#     operands: 31
# 26. (2^{t_star}, -1)
#     core type: ExprTuple
#     sub-expressions: 32, 48
# 27. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 28. KET
#     core type: Literal
#     sub-expressions:
# 29. (k)
#     core type: ExprTuple
#     sub-expressions: 46
# 30. Interval
#     core type: Literal
#     sub-expressions:
# 31. (0, 2^{t_prime} - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 32. 2^{t_star}
#     core type: Operation
#     operator: 49
#     operands: 37
# 33. e
#     core type: Literal
#     sub-expressions:
# 34. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 38
#     operands: 39
# 35. 0
#     core type: Literal
#     sub-expressions:
# 36. 2^{t_prime} - 1
#     core type: Operation
#     operator: 40
#     operands: 41
# 37. (2, t_star)
#     core type: ExprTuple
#     sub-expressions: 53, 42
# 38. *
#     core type: Literal
#     sub-expressions:
# 39. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 53, 43, 44, 45, 46
# 40. +
#     core type: Literal
#     sub-expressions:
# 41. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 42. t_star
#     core type: Literal
#     sub-expressions:
# 43. pi
#     core type: Literal
#     sub-expressions:
# 44. i
#     core type: Variable
#     sub-expressions:
# 45. phase
#     core type: Literal
#     sub-expressions:
# 46. k
#     core type: Variable
#     sub-expressions:
# 47. 2^{t_prime}
#     core type: Operation
#     operator: 49
#     operands: 50
# 48. -1
#     core type: Operation
#     operator: 51
#     operand: 55
# 49. Exp
#     core type: Literal
#     sub-expressions:
# 50. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 53, 54
# 51. -
#     core type: Literal
#     sub-expressions:
# 52. (1)
#     core type: ExprTuple
#     sub-expressions: 55
# 53. 2
#     core type: Literal
#     sub-expressions:
# 54. t_prime
#     core type: Literal
#     sub-expressions:
# 55. 1
#     core type: Literal
#     sub-expressions:
