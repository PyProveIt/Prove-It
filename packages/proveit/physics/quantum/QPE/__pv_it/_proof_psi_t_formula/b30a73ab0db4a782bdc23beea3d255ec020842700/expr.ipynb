# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = Lambda(k, Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), InSet(k, Interval(Add(Add(Exp(two, t_prime), sub_expr1), one), Add(Exp(two, t_star), sub_expr1)))))
# Out:
# expr: k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle \textrm{ if } k \in \{\left(2^{t^{\prime}} - 1\right) + 1~\ldotp \ldotp~2^{t^{*}} - 1\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 26
#    body: 1
# 1. {e^{2 * pi * i * phase * k} * |k〉 if k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 19
#    operands: 4
# 3. k in {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1})
#    core type: ExprTuple
#    sub-expressions: 26, 9
# 7. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 35
#    operands: 10
# 8. |k〉
#    core type: Operation
#    operator: 11
#    operand: 26
# 9. {(2^{t_prime} - 1) + 1 .. 2^{t_star} - 1}
#    core type: Operation
# ...
