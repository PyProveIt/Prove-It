# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.numbers import Add, Exp, Mult, Neg, one, pi, two
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
expr = Mult(two, pi, i, phase_, Add(k, Neg(Neg(Add(Add(Exp(two, t_prime), Neg(one)), one)))))
# Out:
# expr: 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# 2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. *
#    core type: Literal
#    sub-expressions:
# 2. (2, pi, i, phase, k - (-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 24, 3, 4, 5, 6
# 3. pi
#    core type: Literal
#    sub-expressions:
# 4. i
#    core type: Variable
#    sub-expressions:
# 5. phase
#    core type: Literal
#    sub-expressions:
# 6. k - (-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 16
#    operands: 7
# 7. (k, -(-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. k
#    core type: Variable
#    sub-expressions:
# 9. -(-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 22
#    operand: 11
# 10. (-((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 11
# 11. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 22
#     operand: 13
# 12. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 16
#     operands: 14
# 14. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 26
# 15. 2^{t_prime} - 1
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 2^{t_prime}
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. -1
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (1)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t_prime
#     core type: Literal
#     sub-expressions:
# 26. 1
#     core type: Literal
#     sub-expressions:
