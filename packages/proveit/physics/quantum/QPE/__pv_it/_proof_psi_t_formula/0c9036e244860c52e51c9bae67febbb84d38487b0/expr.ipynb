# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Neg(one)
sub_expr3 = Add(Exp(two, t_star), sub_expr2)
sub_expr4 = Add(Exp(two, t_prime), sub_expr2)
sub_expr5 = Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k))
expr = ExprTuple(Sum(sub_expr1, sub_expr5, domain = Interval(zero, sub_expr3)), Add(Sum(sub_expr1, sub_expr5, domain = Interval(zero, sub_expr4)), Sum(sub_expr1, sub_expr5, domain = Interval(Add(sub_expr4, one), sub_expr3))))
# Out:
# expr: (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉), (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=(2^{t_prime} - 1) + 1}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right), \left(\sum_{k=0}^{2^{t^{\prime}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) + \left(\sum_{k=\left(2^{t^{\prime}} - 1\right) + 1}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉), (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=(2^{t_prime} - 1) + 1}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=(2^{t_prime} - 1) + 1}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 52
#    operands: 4
# 3. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉), Sum_{k=(2^{t_prime} - 1) + 1}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# ...
