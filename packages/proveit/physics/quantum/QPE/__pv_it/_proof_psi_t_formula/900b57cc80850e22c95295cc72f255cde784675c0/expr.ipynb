# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable, i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_star

# %%
# build up the expression from sub-expressions
expr = Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), domain = Interval(Variable("_a", latex_format = r"{_{-}a}"), Add(Exp(two, t_star), Neg(one))))
# Out:
# expr: Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{k={_{-}a}}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 29
#    body: 4
# 4. {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 22
#    operands: 7
# 6. k in {_a .. 2^{t_star} - 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (k, {_a .. 2^{t_star} - 1})
#    core type: ExprTuple
#    sub-expressions: 29, 12
# ...
