# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, frac, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
expr = Mult(frac(one, Exp(two, frac(t_prime, two))), Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), domain = Interval(zero, Add(Exp(two, t_prime), Neg(one)))))
# Out:
# expr: (1 / 2^{t_prime / 2}) * (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{1}{2^{\frac{t^{\prime}}{2}}} \cdot \left(\sum_{k=0}^{2^{t^{\prime}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 / 2^{t_prime / 2}) * (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 31
#    operands: 1
# 1. (1 / 2^{t_prime / 2}, Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. 1 / 2^{t_prime / 2}
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. (1, 2^{t_prime / 2})
#    core type: ExprTuple
#    sub-expressions: 47, 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. 2^{t_prime / 2}
#    core type: Operation
#    operator: 41
#    operands: 9
# 8. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#    core type: Lambda
#    parameter: 38
#    body: 10
# ...
