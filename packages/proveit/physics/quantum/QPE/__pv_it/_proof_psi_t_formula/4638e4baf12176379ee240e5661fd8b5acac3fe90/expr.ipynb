# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(Add(Exp(two, t_prime), sub_expr1), one)
sub_expr3 = Neg(sub_expr2)
sub_expr4 = Add(k, Neg(sub_expr3))
expr = Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, sub_expr4)), Ket(sub_expr4)), domain = Interval(Add(sub_expr2, sub_expr3), Add(Add(Exp(two, t_star), sub_expr1), sub_expr3)))
# Out:
# expr: Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{k=\left(\left(2^{t^{\prime}} - 1\right) + 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)}^{\left(2^{t^{*}} - 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)} \cdot \lvert k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right) \rangle\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#    core type: Lambda
#    parameter: 33
#    body: 4
# ...
