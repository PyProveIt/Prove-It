# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.numbers import Add, Exp, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(k, Neg(Neg(Add(Add(Exp(two, t_prime), Neg(one)), one))))
expr = Mult(Exp(e, Mult(two, pi, i, phase_, sub_expr1)), Ket(sub_expr1))
# Out:
# expr: e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)} \cdot \lvert k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right) \rangle

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉
#    core type: Operation
#    operator: 9
#    operands: 1
# 1. (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}, |k - (-((2^{t_prime} - 1) + 1))〉)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}
#    core type: Operation
#    operator: 28
#    operands: 4
# 3. |k - (-((2^{t_prime} - 1) + 1))〉
#    core type: Operation
#    operator: 5
#    operand: 14
# 4. (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. KET
#    core type: Literal
#    sub-expressions:
# 6. (k - (-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 14
# 7. e
#    core type: Literal
#    sub-expressions:
# 8. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. *
#    core type: Literal
# ...
