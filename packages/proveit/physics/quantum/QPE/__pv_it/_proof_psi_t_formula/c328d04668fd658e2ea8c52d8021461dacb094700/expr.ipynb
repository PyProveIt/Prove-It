# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, frac, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_star

# %%
# build up the expression from sub-expressions
expr = ExprTuple(frac(one, Exp(two, frac(t_star, two))), Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), domain = Interval(zero, Add(Exp(two, t_star), Neg(one)))))
# Out:
# expr: (1 / 2^{t_star / 2}, Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{1}{2^{\frac{t^{*}}{2}}}, \sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 / 2^{t_star / 2}, Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 / 2^{t_star / 2}
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. (1, 2^{t_star / 2})
#    core type: ExprTuple
#    sub-expressions: 46, 6
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. 2^{t_star / 2}
#    core type: Operation
#    operator: 40
#    operands: 8
# 7. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 37
#    body: 9
# 8. (2, t_star / 2)
#    core type: ExprTuple
#    sub-expressions: 44, 10
# 9. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#    core type: Conditional
# ...
