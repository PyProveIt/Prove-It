# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.And.html">And</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.logic import And
from proveit.numbers import Add, Exp, LessEq, Neg, one, two, zero
from proveit.physics.quantum.QPE import t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Add(Exp(two, t_prime), sub_expr1)
expr = And(LessEq(zero, sub_expr2), LessEq(sub_expr2, Add(Exp(two, t_star), sub_expr1)))
# Out:
# expr: (0 <= (2^{t_prime} - 1)) and ((2^{t_prime} - 1) <= (2^{t_star} - 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(0 \leq \left(2^{t^{\prime}} - 1\right)\right) \land \left(\left(2^{t^{\prime}} - 1\right) \leq \left(2^{t^{*}} - 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: as_total_ordering
# description: When 'True', style the conjunction as a total ordering (e.g. x < y < z from (x < y) and (y < z))
# default: None
# current value: None/False
# related methods: ('with_total_ordering_style',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (0 <= (2^{t_prime} - 1)) and ((2^{t_prime} - 1) <= (2^{t_star} - 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. and
#    core type: Literal
#    sub-expressions:
# 2. (0 <= (2^{t_prime} - 1), (2^{t_prime} - 1) <= (2^{t_star} - 1))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 0 <= (2^{t_prime} - 1)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2^{t_prime} - 1) <= (2^{t_star} - 1)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (0, 2^{t_prime} - 1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (2^{t_prime} - 1, 2^{t_star} - 1)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 0
#    core type: Literal
#    sub-expressions:
# 9. 2^{t_prime} - 1
#    core type: Operation
#    operator: 12
#    operands: 11
# 10. 2^{t_star} - 1
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. (2^{t_prime}, -1)
# ...
