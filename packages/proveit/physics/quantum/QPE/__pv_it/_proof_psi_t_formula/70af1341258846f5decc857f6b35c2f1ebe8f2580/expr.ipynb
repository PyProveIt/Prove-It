# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
expr = Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), InSet(k, Interval(zero, Add(Exp(two, t_prime), Neg(one)))))
# Out:
# expr: {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle \textrm{ if } k \in \{0~\ldotp \ldotp~2^{t^{\prime}} - 1\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. k in {0 .. 2^{t_prime} - 1}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (k, {0 .. 2^{t_prime} - 1})
#    core type: ExprTuple
#    sub-expressions: 25, 8
# 6. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 28
#    operands: 9
# 7. |k〉
#    core type: Operation
#    operator: 10
#    operand: 25
# 8. {0 .. 2^{t_prime} - 1}
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. (e, 2 * pi * i * phase * k)
#    core type: ExprTuple
#    sub-expressions: 14, 15
# 10. KET
#     core type: Literal
#     sub-expressions:
# 11. (k)
#     core type: ExprTuple
# ...
