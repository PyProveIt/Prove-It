# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Add, Exp, Neg, one, two
from proveit.physics.quantum.QPE import t_prime

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Add(Exp(two, t_prime), Neg(one)), one)
expr = ExprTuple(sub_expr1, Neg(sub_expr1))
# Out:
# expr: ((2^{t_prime} - 1) + 1, -((2^{t_prime} - 1) + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2^{t^{\prime}} - 1\right) + 1, -\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2^{t_prime} - 1) + 1, -((2^{t_prime} - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 3, 1
# 1. -((2^{t_prime} - 1) + 1)
#    core type: Operation
#    operator: 12
#    operand: 3
# 2. ((2^{t_prime} - 1) + 1)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (2^{t_prime} - 1) + 1
#    core type: Operation
#    operator: 6
#    operands: 4
# 4. (2^{t_prime} - 1, 1)
#    core type: ExprTuple
#    sub-expressions: 5, 16
# 5. 2^{t_prime} - 1
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2^{t_prime}, -1)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. 2^{t_prime}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. -1
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. -
#     core type: Literal
#     sub-expressions:
# 13. (1)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. 2
#     core type: Literal
#     sub-expressions:
# 15. t_prime
#     core type: Literal
#     sub-expressions:
# 16. 1
#     core type: Literal
#     sub-expressions:
