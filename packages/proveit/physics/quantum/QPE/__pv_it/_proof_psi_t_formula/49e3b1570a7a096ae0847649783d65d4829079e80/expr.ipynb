# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Variable, i, k
from proveit.logic import InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, one, pi, two
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_star

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(k, Conditional(Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), InSet(k, Interval(Variable("_a", latex_format = r"{_{-}a}"), Add(Exp(two, t_star), Neg(one)))))))
# Out:
# expr: (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(k \mapsto \left\{\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle \textrm{ if } k \in \{{_{-}a}~\ldotp \ldotp~2^{t^{*}} - 1\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 27
#    body: 2
# 2. {e^{2 * pi * i * phase * k} * |k〉 if k in {_a .. 2^{t_star} - 1}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. e^{2 * pi * i * phase * k} * |k〉
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. k in {_a .. 2^{t_star} - 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (e^{2 * pi * i * phase * k}, |k〉)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {_a .. 2^{t_star} - 1})
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 8. e^{2 * pi * i * phase * k}
#    core type: Operation
#    operator: 30
#    operands: 11
# 9. |k〉
#    core type: Operation
#    operator: 12
#    operand: 27
# ...
