# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, k
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, frac, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, psi_t_star, t_star

# %%
# build up the expression from sub-expressions
expr = ExprTuple(psi_t_star, Mult(frac(one, Exp(two, frac(t_star, two))), Sum([k], Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k)), domain = Interval(zero, Add(Exp(two, t_star), Neg(one))))))
# Out:
# expr: (psi_{t_star}, (1 / 2^{t_star / 2}) * (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\psi_{t^{*}}, \frac{1}{2^{\frac{t^{*}}{2}}} \cdot \left(\sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (psi_{t_star}, (1 / 2^{t_star / 2}) * (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. psi_{t_star}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. (1 / 2^{t_star / 2}) * (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: Operation
#    operator: 36
#    operands: 5
# 3. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 4. (psi, t_star)
#    core type: ExprTuple
#    sub-expressions: 6, 51
# 5. (1 / 2^{t_star / 2}, Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. psi
#    core type: Literal
#    sub-expressions:
# 7. 1 / 2^{t_star / 2}
#    core type: Operation
#    operator: 19
#    operands: 9
# 8. Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. (1, 2^{t_star / 2})
#    core type: ExprTuple
# ...
