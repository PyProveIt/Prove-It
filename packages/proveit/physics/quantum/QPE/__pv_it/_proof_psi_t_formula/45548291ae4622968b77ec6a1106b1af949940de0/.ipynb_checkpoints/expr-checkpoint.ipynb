# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.NamedExprs.html">NamedExprs</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, NamedExprs, Variable, i, k
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
sub_expr2 = [k]
sub_expr3 = Neg(one)
sub_expr4 = Add(Exp(two, t_star), sub_expr3)
sub_expr5 = Add(Exp(two, t_prime), sub_expr3)
sub_expr6 = Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k))
expr = NamedExprs([("lambda", Lambda(sub_expr1, Equals(Sum(sub_expr2, sub_expr6, domain = Interval(zero, sub_expr4)), Add(Sum(sub_expr2, sub_expr6, domain = Interval(zero, sub_expr5)), Sum(sub_expr2, sub_expr6, domain = Interval(sub_expr1, sub_expr4)))))), ("${_{-}a}$", Add(sub_expr5, one))])
# Out:
# expr: {lambda:[_a -> ((Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))))], ${_{-}a}$:((2^{t_prime} - 1) + 1)}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{ \begin{array}{l}
# {\rm lambda}: \left[{_{-}a} \mapsto \left(\left(\sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) = \left(\left(\sum_{k=0}^{2^{t^{\prime}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) + \left(\sum_{k={_{-}a}}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right)\right)\right)\right]\\
# {_{-}a}: \left(\left(2^{t^{\prime}} - 1\right) + 1\right)\\
# \end{array} \right\}

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {lambda:[_a -> ((Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))))], ${_{-}a}$:((2^{t_prime} - 1) + 1)}
#    core type: NamedExprs
#    lambda: 1
#    ${_{-}a}$: 2
# 1. _a -> ((Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉))))
#    core type: Lambda
#    parameter: 47
#    body: 3
# 2. (2^{t_prime} - 1) + 1
#    core type: Operation
#    operator: 52
#    operands: 4
# 3. (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=_a}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (2^{t_prime} - 1, 1)
#    core type: ExprTuple
# ...
