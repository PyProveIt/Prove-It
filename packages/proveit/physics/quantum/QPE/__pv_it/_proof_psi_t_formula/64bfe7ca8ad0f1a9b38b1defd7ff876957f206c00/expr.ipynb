# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import i, k
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Interval, Mult, Neg, Sum, e, one, pi, two, zero
from proveit.physics.quantum import Ket
from proveit.physics.quantum.QPE import phase_, t_prime, t_star

# %%
# build up the expression from sub-expressions
sub_expr1 = [k]
sub_expr2 = Neg(one)
sub_expr3 = Add(Exp(two, t_star), sub_expr2)
sub_expr4 = Add(Exp(two, t_prime), sub_expr2)
sub_expr5 = Mult(Exp(e, Mult(two, pi, i, phase_, k)), Ket(k))
sub_expr6 = Add(sub_expr4, one)
sub_expr7 = Neg(sub_expr6)
sub_expr8 = Add(k, Neg(sub_expr7))
expr = Equals(Sum(sub_expr1, sub_expr5, domain = Interval(zero, sub_expr3)), Add(Sum(sub_expr1, sub_expr5, domain = Interval(zero, sub_expr4)), Sum(sub_expr1, Mult(Exp(e, Mult(two, pi, i, phase_, sub_expr8)), Ket(sub_expr8)), domain = Interval(Add(sub_expr6, sub_expr7), Add(sub_expr3, sub_expr7)))))
# Out:
# expr: (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{k=0}^{2^{t^{*}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) = \left(\left(\sum_{k=0}^{2^{t^{\prime}} - 1} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot k} \cdot \lvert k \rangle\right)\right) + \left(\sum_{k=\left(\left(2^{t^{\prime}} - 1\right) + 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)}^{\left(2^{t^{*}} - 1\right) - \left(\left(2^{t^{\prime}} - 1\right) + 1\right)} \left(\mathsf{e}^{2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)} \cdot \lvert k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right) \rangle\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)) = ((Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉), (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{k=0}^{2^{t_star} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 12
#    operand: 7
# 4. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)) + (Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉))
#    core type: Operation
#    operator: 74
#    operands: 6
# 5. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉), Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#    core type: Lambda
#    parameter: 63
#    body: 10
# 8. Sum_{k=0}^{2^{t_prime} - 1} (e^{2 * pi * i * phase * k} * |k〉)
#    core type: Operation
#    operator: 12
#    operand: 15
# 9. Sum_{k=((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)}^{(2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)} (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_star} - 1}.
#     core type: Conditional
#     value: 21
#     condition: 14
# 11. (k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.)
#     core type: ExprTuple
#     sub-expressions: 15
# 12. Sum
#     core type: Literal
#     sub-expressions:
# 13. (k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. k in {0 .. 2^{t_star} - 1}
#     core type: Operation
#     operator: 29
#     operands: 17
# 15. k -> {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#     core type: Lambda
#     parameter: 63
#     body: 18
# 16. k -> {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#     core type: Lambda
#     parameter: 63
#     body: 19
# 17. (k, {0 .. 2^{t_star} - 1})
#     core type: ExprTuple
#     sub-expressions: 63, 20
# 18. {e^{2 * pi * i * phase * k} * |k〉 if k in {0 .. 2^{t_prime} - 1}.
#     core type: Conditional
#     value: 21
#     condition: 22
# 19. {e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉 if k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}.
#     core type: Conditional
#     value: 23
#     condition: 24
# 20. {0 .. 2^{t_star} - 1}
#     core type: Operation
#     operator: 43
#     operands: 25
# 21. e^{2 * pi * i * phase * k} * |k〉
#     core type: Operation
#     operator: 52
#     operands: 26
# 22. k in {0 .. 2^{t_prime} - 1}
#     core type: Operation
#     operator: 29
#     operands: 27
# 23. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))} * |k - (-((2^{t_prime} - 1) + 1))〉
#     core type: Operation
#     operator: 52
#     operands: 28
# 24. k in {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}
#     core type: Operation
#     operator: 29
#     operands: 30
# 25. (0, 2^{t_star} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 60
# 26. (e^{2 * pi * i * phase * k}, |k〉)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 27. (k, {0 .. 2^{t_prime} - 1})
#     core type: ExprTuple
#     sub-expressions: 63, 33
# 28. (e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}, |k - (-((2^{t_prime} - 1) + 1))〉)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 29. in
#     core type: Literal
#     sub-expressions:
# 30. (k, {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)})
#     core type: ExprTuple
#     sub-expressions: 63, 36
# 31. e^{2 * pi * i * phase * k}
#     core type: Operation
#     operator: 78
#     operands: 37
# 32. |k〉
#     core type: Operation
#     operator: 41
#     operand: 63
# 33. {0 .. 2^{t_prime} - 1}
#     core type: Operation
#     operator: 43
#     operands: 39
# 34. e^{2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))}
#     core type: Operation
#     operator: 78
#     operands: 40
# 35. |k - (-((2^{t_prime} - 1) + 1))〉
#     core type: Operation
#     operator: 41
#     operand: 59
# 36. {((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1) .. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)}
#     core type: Operation
#     operator: 43
#     operands: 44
# 37. (e, 2 * pi * i * phase * k)
#     core type: ExprTuple
#     sub-expressions: 47, 45
# 38. (k)
#     core type: ExprTuple
#     sub-expressions: 63
# 39. (0, 2^{t_prime} - 1)
#     core type: ExprTuple
#     sub-expressions: 46, 73
# 40. (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 41. KET
#     core type: Literal
#     sub-expressions:
# 42. (k - (-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 59
# 43. Interval
#     core type: Literal
#     sub-expressions:
# 44. (((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1), (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 49, 50
# 45. 2 * pi * i * phase * k
#     core type: Operation
#     operator: 52
#     operands: 51
# 46. 0
#     core type: Literal
#     sub-expressions:
# 47. e
#     core type: Literal
#     sub-expressions:
# 48. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#     core type: Operation
#     operator: 52
#     operands: 53
# 49. ((2^{t_prime} - 1) + 1) - ((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 74
#     operands: 54
# 50. (2^{t_star} - 1) - ((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 74
#     operands: 55
# 51. (2, pi, i, phase, k)
#     core type: ExprTuple
#     sub-expressions: 82, 56, 57, 58, 63
# 52. *
#     core type: Literal
#     sub-expressions:
# 53. (2, pi, i, phase, k - (-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 82, 56, 57, 58, 59
# 54. ((2^{t_prime} - 1) + 1, -((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 71, 68
# 55. (2^{t_star} - 1, -((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 60, 68
# 56. pi
#     core type: Literal
#     sub-expressions:
# 57. i
#     core type: Variable
#     sub-expressions:
# 58. phase
#     core type: Literal
#     sub-expressions:
# 59. k - (-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 74
#     operands: 61
# 60. 2^{t_star} - 1
#     core type: Operation
#     operator: 74
#     operands: 62
# 61. (k, -(-((2^{t_prime} - 1) + 1)))
#     core type: ExprTuple
#     sub-expressions: 63, 64
# 62. (2^{t_star}, -1)
#     core type: ExprTuple
#     sub-expressions: 65, 77
# 63. k
#     core type: Variable
#     sub-expressions:
# 64. -(-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 80
#     operand: 68
# 65. 2^{t_star}
#     core type: Operation
#     operator: 78
#     operands: 67
# 66. (-((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 68
# 67. (2, t_star)
#     core type: ExprTuple
#     sub-expressions: 82, 69
# 68. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 80
#     operand: 71
# 69. t_star
#     core type: Literal
#     sub-expressions:
# 70. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 71
# 71. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 74
#     operands: 72
# 72. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 73, 84
# 73. 2^{t_prime} - 1
#     core type: Operation
#     operator: 74
#     operands: 75
# 74. +
#     core type: Literal
#     sub-expressions:
# 75. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 76, 77
# 76. 2^{t_prime}
#     core type: Operation
#     operator: 78
#     operands: 79
# 77. -1
#     core type: Operation
#     operator: 80
#     operand: 84
# 78. Exp
#     core type: Literal
#     sub-expressions:
# 79. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 82, 83
# 80. -
#     core type: Literal
#     sub-expressions:
# 81. (1)
#     core type: ExprTuple
#     sub-expressions: 84
# 82. 2
#     core type: Literal
#     sub-expressions:
# 83. t_prime
#     core type: Literal
#     sub-expressions:
# 84. 1
#     core type: Literal
#     sub-expressions:
