# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, i, k
from proveit.numbers import Add, Exp, Mult, Neg, e, one, pi, two
from proveit.physics.quantum.QPE import phase_, t_prime

# %%
# build up the expression from sub-expressions
expr = ExprTuple(e, Mult(two, pi, i, phase_, Add(k, Neg(Neg(Add(Add(Exp(two, t_prime), Neg(one)), one))))))
# Out:
# expr: (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathsf{e}, 2 \cdot \pi \cdot i \cdot \varphi \cdot \left(k - \left(-\left(\left(2^{t^{\prime}} - 1\right) + 1\right)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (e, 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1))))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e
#    core type: Literal
#    sub-expressions:
# 2. 2 * pi * i * phase * (k - (-((2^{t_prime} - 1) + 1)))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. *
#    core type: Literal
#    sub-expressions:
# 4. (2, pi, i, phase, k - (-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 26, 5, 6, 7, 8
# 5. pi
#    core type: Literal
#    sub-expressions:
# 6. i
#    core type: Variable
#    sub-expressions:
# 7. phase
#    core type: Literal
#    sub-expressions:
# 8. k - (-((2^{t_prime} - 1) + 1))
#    core type: Operation
#    operator: 18
#    operands: 9
# 9. (k, -(-((2^{t_prime} - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. k
#     core type: Variable
#     sub-expressions:
# 11. -(-((2^{t_prime} - 1) + 1))
#     core type: Operation
#     operator: 24
#     operand: 13
# 12. (-((2^{t_prime} - 1) + 1))
#     core type: ExprTuple
#     sub-expressions: 13
# 13. -((2^{t_prime} - 1) + 1)
#     core type: Operation
#     operator: 24
#     operand: 15
# 14. ((2^{t_prime} - 1) + 1)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. (2^{t_prime} - 1) + 1
#     core type: Operation
#     operator: 18
#     operands: 16
# 16. (2^{t_prime} - 1, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 28
# 17. 2^{t_prime} - 1
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (2^{t_prime}, -1)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 2^{t_prime}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. -1
#     core type: Operation
#     operator: 24
#     operand: 28
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t_prime)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. -
#     core type: Literal
#     sub-expressions:
# 25. (1)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t_prime
#     core type: Literal
#     sub-expressions:
# 28. 1
#     core type: Literal
#     sub-expressions:
