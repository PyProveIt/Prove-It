# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, IndexedVar, a, l
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, Exp, Mult, Sum, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(a, one)
sub_expr3 = frac(one, Exp(diff_l_scaled_delta, two))
expr = Conditional(Equals(Mult(sub_expr2, Sum(sub_expr1, sub_expr3, domain = neg_domain)), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = neg_domain)), InSet(sub_expr2, Complex))
# Out:
# expr: {(a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))) if a_{1} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\left(a_{1} \cdot \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right) = \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right) \textrm{ if } a_{1} \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {(a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))) if a_{1} in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. (a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. a_{1} in Complex
#    core type: Operation
#    operator: 23
#    operands: 5
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2})), Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (a_{1} * (1 / (l - (2^{t} * delta))^{2})))
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. (a_{1}, Complex)
#    core type: ExprTuple
#    sub-expressions: 21, 8
# 6. a_{1} * (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} (1 / (l - (2^{t} * delta))^{2}))
# ...
