# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, InSet
from proveit.numbers import Real
from proveit.physics.quantum.QPE import alpha_l_sqrd, pos_domain

# %%
# build up the expression from sub-expressions
expr = Forall([l], InSet(alpha_l_sqrd, Real), domain = pos_domain)
# Out:
# expr: forall_{l in {eps + 1 .. 2^{t - 1}}} (|alpha_{l}|^{2} in Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\left|\alpha_{l}\right|^{2} \in \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {eps + 1 .. 2^{t - 1}}} (|alpha_{l}|^{2} in Real)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {|alpha_{l}|^{2} in Real if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {|alpha_{l}|^{2} in Real if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 33
#    body: 4
# 4. {|alpha_{l}|^{2} in Real if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. |alpha_{l}|^{2} in Real
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (|alpha_{l}|^{2}, Real)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 33, 12
# 10. |alpha_{l}|^{2}
#     core type: Operation
#     operator: 22
#     operands: 13
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (|alpha_{l}|, 2)
#     core type: ExprTuple
#     sub-expressions: 16, 26
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. |alpha_{l}|
#     core type: Operation
#     operator: 19
#     operand: 24
# 17. eps + 1
#     core type: Operation
#     operator: 30
#     operands: 21
# 18. 2^{t - 1}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. Abs
#     core type: Literal
#     sub-expressions:
# 20. (alpha_{l})
#     core type: ExprTuple
#     sub-expressions: 24
# 21. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 38
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. alpha_{l}
#     core type: Operation
#     operator: 28
#     operands: 29
# 25. eps
#     core type: Variable
#     sub-expressions:
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t - 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 29. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 32. alpha
#     core type: Literal
#     sub-expressions:
# 33. l
#     core type: Variable
#     sub-expressions:
# 34. t
#     core type: Literal
#     sub-expressions:
# 35. -1
#     core type: Operation
#     operator: 36
#     operand: 38
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. (1)
#     core type: ExprTuple
#     sub-expressions: 38
# 38. 1
#     core type: Literal
#     sub-expressions:
