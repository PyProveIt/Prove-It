# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, Variable, a
from proveit.logic import InSet
from proveit.numbers import Complex, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = ExprTuple([ExprRange(sub_expr1, InSet(IndexedVar(a, sub_expr1), Complex), one, one)], [InSet(IndexedVar(a, one), Complex)])
# Out:
# expr: ((a_{1} in Complex, ..a_{_a} in Complex.., a_{1} in Complex), (a_{1} in Complex))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a_{1} \in \mathbb{C}, \ldots, a_{1} \in \mathbb{C}\right), \left(a_{1} \in \mathbb{C}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a_{1} in Complex, ..a_{_a} in Complex.., a_{1} in Complex), (a_{1} in Complex))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (a_{1} in Complex, ..a_{_a} in Complex.., a_{1} in Complex)
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (a_{1} in Complex)
#    core type: ExprTuple
#    sub-expressions: 4
# 3. (a_{1} in Complex), ..(a_{_a} in Complex).., (a_{1} in Complex)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 14
#    end_index: 14
# 4. a_{1} in Complex
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. _a -> (a_{_a} in Complex)
#    core type: Lambda
#    parameter: 17
#    body: 7
# 6. (a_{1}, Complex)
#    core type: ExprTuple
#    sub-expressions: 8, 13
# 7. a_{_a} in Complex
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. a_{1}
#    core type: IndexedVar
# variable: 15
# index: 14
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (a_{_a}, Complex)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (1)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. a_{_a}
#     core type: IndexedVar
# variable: 15
# index: 17
# 13. Complex
#     core type: Literal
#     sub-expressions:
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. a
#     core type: Variable
#     sub-expressions:
# 16. (_a)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. _a
#     core type: Variable
#     sub-expressions:
