# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import InSet
from proveit.numbers import Complex, Exp, Sum, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
expr = InSet(Sum([l], frac(one, Exp(diff_l_scaled_delta, two)), domain = pos_domain), Complex)
# Out:
# expr: (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})) in Complex

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right) \in \mathbb{C}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})) in Complex
#    core type: Operation
#    operator: 12
#    operands: 1
# 1. (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}), Complex)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 4
#    operand: 6
# 3. Complex
#    core type: Literal
#    sub-expressions:
# 4. Sum
#    core type: Literal
#    sub-expressions:
# 5. (l -> {1 / (l - (2^{t} * delta))^{2} if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. l -> {1 / (l - (2^{t} * delta))^{2} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 25
#    body: 7
# 7. {1 / (l - (2^{t} * delta))^{2} if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. 1 / (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. l in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. (1, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 40, 14
# 12. in
#     core type: Literal
#     sub-expressions:
# 13. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 25, 15
# 14. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 41
#     operands: 16
# 15. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 17
#     operands: 18
# 16. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 19, 43
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. l - (2^{t} * delta)
#     core type: Operation
#     operator: 30
#     operands: 22
# 20. eps + 1
#     core type: Operation
#     operator: 30
#     operands: 23
# 21. 2^{t - 1}
#     core type: Operation
#     operator: 41
#     operands: 24
# 22. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 40
# 24. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 43, 28
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. -(2^{t} * delta)
#     core type: Operation
#     operator: 36
#     operand: 32
# 27. eps
#     core type: Variable
#     sub-expressions:
# 28. t - 1
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. +
#     core type: Literal
#     sub-expressions:
# 31. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 44, 33
# 32. 2^{t} * delta
#     core type: Operation
#     operator: 34
#     operands: 35
# 33. -1
#     core type: Operation
#     operator: 36
#     operand: 40
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 36. -
#     core type: Literal
#     sub-expressions:
# 37. (1)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. 2^{t}
#     core type: Operation
#     operator: 41
#     operands: 42
# 39. delta
#     core type: Literal
#     sub-expressions:
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. Exp
#     core type: Literal
#     sub-expressions:
# 42. (2, t)
#     core type: ExprTuple
#     sub-expressions: 43, 44
# 43. 2
#     core type: Literal
#     sub-expressions:
# 44. t
#     core type: Literal
#     sub-expressions:
