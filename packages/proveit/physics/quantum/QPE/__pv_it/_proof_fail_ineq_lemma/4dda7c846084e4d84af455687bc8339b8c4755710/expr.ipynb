# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Forall, InSet
from proveit.numbers import Exp, Mult, Real, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain

# %%
# build up the expression from sub-expressions
expr = Forall([l], InSet(frac(one, Mult(four, Exp(diff_l_scaled_delta, two))), Real), domain = neg_domain)
# Out:
# expr: forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}}~\left(\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}} \in \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{l in {-2^{t - 1} + 1 .. -(eps + 1)}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 35
#    body: 4
# 4. {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (1 / (4 * (l - (2^{t} * delta))^{2})) in Real
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (1 / (4 * (l - (2^{t} * delta))^{2}), Real)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 35, 12
# 10. 1 / (4 * (l - (2^{t} * delta))^{2})
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. Real
#     core type: Literal
#     sub-expressions:
# 12. {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. /
#     core type: Literal
#     sub-expressions:
# 14. (1, 4 * (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 49, 17
# 15. Interval
#     core type: Literal
#     sub-expressions:
# 16. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. 4 * (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 43
#     operands: 20
# 18. -2^{t - 1} + 1
#     core type: Operation
#     operator: 39
#     operands: 21
# 19. -(eps + 1)
#     core type: Operation
#     operator: 45
#     operand: 26
# 20. (4, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 25, 49
# 22. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 26
# 23. 4
#     core type: Literal
#     sub-expressions:
# 24. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 50
#     operands: 27
# 25. -2^{t - 1}
#     core type: Operation
#     operator: 45
#     operand: 31
# 26. eps + 1
#     core type: Operation
#     operator: 39
#     operands: 29
# 27. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 30, 52
# 28. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 31
# 29. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 49
# 30. l - (2^{t} * delta)
#     core type: Operation
#     operator: 39
#     operands: 33
# 31. 2^{t - 1}
#     core type: Operation
#     operator: 50
#     operands: 34
# 32. eps
#     core type: Variable
#     sub-expressions:
# 33. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 34. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 52, 37
# 35. l
#     core type: Variable
#     sub-expressions:
# 36. -(2^{t} * delta)
#     core type: Operation
#     operator: 45
#     operand: 41
# 37. t - 1
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 41
# 39. +
#     core type: Literal
#     sub-expressions:
# 40. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 53, 42
# 41. 2^{t} * delta
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. -1
#     core type: Operation
#     operator: 45
#     operand: 49
# 43. *
#     core type: Literal
#     sub-expressions:
# 44. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 47, 48
# 45. -
#     core type: Literal
#     sub-expressions:
# 46. (1)
#     core type: ExprTuple
#     sub-expressions: 49
# 47. 2^{t}
#     core type: Operation
#     operator: 50
#     operands: 51
# 48. delta
#     core type: Literal
#     sub-expressions:
# 49. 1
#     core type: Literal
#     sub-expressions:
# 50. Exp
#     core type: Literal
#     sub-expressions:
# 51. (2, t)
#     core type: ExprTuple
#     sub-expressions: 52, 53
# 52. 2
#     core type: Literal
#     sub-expressions:
# 53. t
#     core type: Literal
#     sub-expressions:
