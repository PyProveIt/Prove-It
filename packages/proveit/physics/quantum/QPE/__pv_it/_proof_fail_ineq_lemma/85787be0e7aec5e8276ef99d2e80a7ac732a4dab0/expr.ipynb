# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Exp, Mult, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
expr = Sum([l], Mult(frac(one, four), frac(one, Exp(diff_l_scaled_delta, two))), domain = pos_domain)
# Out:
# expr: Sum_{l=eps + 1}^{2^{t - 1}} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{l=\varepsilon + 1}^{2^{t - 1}} \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{l=eps + 1}^{2^{t - 1}} ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. l -> {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 31
#    body: 4
# 4. {(1 / 4) * (1 / (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (1 / 4) * (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 39
#    operands: 7
# 6. l in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (1 / 4, 1 / (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (l, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 31, 12
# 10. 1 / 4
#     core type: Operation
#     operator: 14
#     operands: 13
# 11. 1 / (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 13. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 38, 18
# 14. /
#     core type: Literal
#     sub-expressions:
# 15. (1, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 38, 19
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. 4
#     core type: Literal
#     sub-expressions:
# 19. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 43
#     operands: 22
# 20. eps + 1
#     core type: Operation
#     operator: 29
#     operands: 23
# 21. 2^{t - 1}
#     core type: Operation
#     operator: 43
#     operands: 24
# 22. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 25, 45
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 38
# 24. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 27
# 25. l - (2^{t} * delta)
#     core type: Operation
#     operator: 29
#     operands: 28
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. t - 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 46, 33
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. -(2^{t} * delta)
#     core type: Operation
#     operator: 35
#     operand: 37
# 33. -1
#     core type: Operation
#     operator: 35
#     operand: 38
# 34. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (1)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. 2^{t} * delta
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 2^{t}
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. delta
#     core type: Literal
#     sub-expressions:
# 43. Exp
#     core type: Literal
#     sub-expressions:
# 44. (2, t)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. t
#     core type: Literal
#     sub-expressions:
