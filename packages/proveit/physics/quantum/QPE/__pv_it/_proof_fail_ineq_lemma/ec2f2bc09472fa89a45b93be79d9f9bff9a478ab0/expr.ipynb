# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, IndexedVar, a
from proveit.numbers import Exp, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta

# %%
# build up the expression from sub-expressions
expr = ExprTuple(IndexedVar(a, one), frac(one, Exp(diff_l_scaled_delta, two)))
# Out:
# expr: (a_{1}, 1 / (l - (2^{t} * delta))^{2})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, 1 / (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1}
#    core type: IndexedVar
# variable: 3
# index: 7
# 2. 1 / (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. a
#    core type: Variable
#    sub-expressions:
# 4. (1)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (1, (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. 1
#    core type: Literal
#    sub-expressions:
# 8. (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 22
#    operands: 9
# 9. (l - (2^{t} * delta), 2)
#    core type: ExprTuple
#    sub-expressions: 10, 24
# 10. l - (2^{t} * delta)
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. l
#     core type: Variable
#     sub-expressions:
# 14. -(2^{t} * delta)
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. 2^{t} * delta
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 21. delta
#     core type: Literal
#     sub-expressions:
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t
#     core type: Literal
#     sub-expressions:
