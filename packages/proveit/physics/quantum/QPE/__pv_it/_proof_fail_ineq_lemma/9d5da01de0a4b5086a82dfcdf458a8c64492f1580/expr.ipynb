# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Exp, Mult, Real, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([l], frac(one, Mult(four, Exp(diff_l_scaled_delta, two))), domain = pos_domain), Real)
# Out:
# expr: (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})), Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}, \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})), Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. Real
#    core type: Literal
#    sub-expressions:
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 31
#    body: 6
# 6. {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. 1 / (4 * (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. l in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. /
#    core type: Literal
#    sub-expressions:
# 10. (1, 4 * (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 38, 13
# 11. in
#     core type: Literal
#     sub-expressions:
# 12. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 31, 14
# 13. 4 * (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 39
#     operands: 15
# 14. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. (4, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. 4
#     core type: Literal
#     sub-expressions:
# 19. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 43
#     operands: 22
# 20. eps + 1
#     core type: Operation
#     operator: 29
#     operands: 23
# 21. 2^{t - 1}
#     core type: Operation
#     operator: 43
#     operands: 24
# 22. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 25, 45
# 23. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 38
# 24. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 45, 27
# 25. l - (2^{t} * delta)
#     core type: Operation
#     operator: 29
#     operands: 28
# 26. eps
#     core type: Variable
#     sub-expressions:
# 27. t - 1
#     core type: Operation
#     operator: 29
#     operands: 30
# 28. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. +
#     core type: Literal
#     sub-expressions:
# 30. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 46, 33
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. -(2^{t} * delta)
#     core type: Operation
#     operator: 35
#     operand: 37
# 33. -1
#     core type: Operation
#     operator: 35
#     operand: 38
# 34. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 37
# 35. -
#     core type: Literal
#     sub-expressions:
# 36. (1)
#     core type: ExprTuple
#     sub-expressions: 38
# 37. 2^{t} * delta
#     core type: Operation
#     operator: 39
#     operands: 40
# 38. 1
#     core type: Literal
#     sub-expressions:
# 39. *
#     core type: Literal
#     sub-expressions:
# 40. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 41, 42
# 41. 2^{t}
#     core type: Operation
#     operator: 43
#     operands: 44
# 42. delta
#     core type: Literal
#     sub-expressions:
# 43. Exp
#     core type: Literal
#     sub-expressions:
# 44. (2, t)
#     core type: ExprTuple
#     sub-expressions: 45, 46
# 45. 2
#     core type: Literal
#     sub-expressions:
# 46. t
#     core type: Literal
#     sub-expressions:
