# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, IndexedVar, Lambda, a, l
from proveit.logic import InSet
from proveit.numbers import Exp, Mult, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, neg_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(l, Conditional(Mult(IndexedVar(a, one), frac(one, Exp(diff_l_scaled_delta, two))), InSet(l, neg_domain))))
# Out:
# expr: (l -> {a_{1} * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}} \textrm{ if } l \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {a_{1} * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {a_{1} * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 28
#    body: 2
# 2. {a_{1} * (1 / (l - (2^{t} * delta))^{2}) if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a_{1} * (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 36
#    operands: 5
# 4. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (a_{1}, 1 / (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 28, 10
# 8. a_{1}
#    core type: IndexedVar
# variable: 11
# index: 49
# 9. 1 / (l - (2^{t} * delta))^{2}
# ...
