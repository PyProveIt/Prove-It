# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(diff_l_scaled_delta, two)
expr = ExprTuple(frac(one, Mult(four, sub_expr1)), Mult(frac(one, four), frac(one, sub_expr1)))
# Out:
# expr: (1 / (4 * (l - (2^{t} * delta))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta))^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}, \frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 / (4 * (l - (2^{t} * delta))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 / (4 * (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 10
#    operands: 3
# 2. (1 / 4) * (1 / (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 24
#    operands: 4
# 3. (1, 4 * (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 13, 5
# 4. (1 / 4, 1 / (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. 4 * (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 24
#    operands: 8
# 6. 1 / 4
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. 1 / (l - (2^{t} * delta))^{2}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. (4, (l - (2^{t} * delta))^{2})
#    core type: ExprTuple
#    sub-expressions: 12, 14
# 9. (1, 4)
#    core type: ExprTuple
#    sub-expressions: 13, 12
# 10. /
#     core type: Literal
#     sub-expressions:
# 11. (1, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 12. 4
#     core type: Literal
#     sub-expressions:
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 28
#     operands: 15
# 15. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 16, 30
# 16. l - (2^{t} * delta)
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. +
#     core type: Literal
#     sub-expressions:
# 18. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. l
#     core type: Variable
#     sub-expressions:
# 20. -(2^{t} * delta)
#     core type: Operation
#     operator: 21
#     operand: 23
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. 2^{t} * delta
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. *
#     core type: Literal
#     sub-expressions:
# 25. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 2^{t}
#     core type: Operation
#     operator: 28
#     operands: 29
# 27. delta
#     core type: Literal
#     sub-expressions:
# 28. Exp
#     core type: Literal
#     sub-expressions:
# 29. (2, t)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 30. 2
#     core type: Literal
#     sub-expressions:
# 31. t
#     core type: Literal
#     sub-expressions:
