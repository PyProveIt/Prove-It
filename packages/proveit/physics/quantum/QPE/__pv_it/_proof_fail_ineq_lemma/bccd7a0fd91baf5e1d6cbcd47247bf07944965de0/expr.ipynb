# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.logic import Forall, InSet
from proveit.numbers import Exp, Mult, Real, Sum, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = frac(one, Mult(four, Exp(diff_l_scaled_delta, two)))
expr = ExprTuple(Forall(sub_expr1, InSet(sub_expr2, Real), domain = pos_domain), InSet(Sum(sub_expr1, sub_expr2, domain = pos_domain), Real))
# Out:
# expr: (forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real), (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left(\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}} \in \mathbb{R}\right), \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right) \in \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real), (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{l in {eps + 1 .. 2^{t - 1}}} ((1 / (4 * (l - (2^{t} * delta))^{2})) in Real)
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))) in Real
#    core type: Operation
#    operator: 20
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2})), Real)
#    core type: ExprTuple
#    sub-expressions: 7, 15
# 6. l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 40
#    body: 8
# 7. Sum_{l=eps + 1}^{2^{t - 1}} (1 / (4 * (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 9
#    operand: 12
# 8. {(1 / (4 * (l - (2^{t} * delta))^{2})) in Real if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 11
#    condition: 17
# 9. Sum
#    core type: Literal
#    sub-expressions:
# 10. (l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.)
#     core type: ExprTuple
#     sub-expressions: 12
# 11. (1 / (4 * (l - (2^{t} * delta))^{2})) in Real
#     core type: Operation
#     operator: 20
#     operands: 13
# 12. l -> {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#     core type: Lambda
#     parameter: 40
#     body: 14
# 13. (1 / (4 * (l - (2^{t} * delta))^{2}), Real)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 14. {1 / (4 * (l - (2^{t} * delta))^{2}) if l in {eps + 1 .. 2^{t - 1}}.
#     core type: Conditional
#     value: 16
#     condition: 17
# 15. Real
#     core type: Literal
#     sub-expressions:
# 16. 1 / (4 * (l - (2^{t} * delta))^{2})
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. l in {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. /
#     core type: Literal
#     sub-expressions:
# 19. (1, 4 * (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 47, 22
# 20. in
#     core type: Literal
#     sub-expressions:
# 21. (l, {eps + 1 .. 2^{t - 1}})
#     core type: ExprTuple
#     sub-expressions: 40, 23
# 22. 4 * (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 48
#     operands: 24
# 23. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. (4, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. Interval
#     core type: Literal
#     sub-expressions:
# 26. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. 4
#     core type: Literal
#     sub-expressions:
# 28. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 52
#     operands: 31
# 29. eps + 1
#     core type: Operation
#     operator: 38
#     operands: 32
# 30. 2^{t - 1}
#     core type: Operation
#     operator: 52
#     operands: 33
# 31. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 34, 54
# 32. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 35, 47
# 33. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 54, 36
# 34. l - (2^{t} * delta)
#     core type: Operation
#     operator: 38
#     operands: 37
# 35. eps
#     core type: Variable
#     sub-expressions:
# 36. t - 1
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 38. +
#     core type: Literal
#     sub-expressions:
# 39. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 55, 42
# 40. l
#     core type: Variable
#     sub-expressions:
# 41. -(2^{t} * delta)
#     core type: Operation
#     operator: 44
#     operand: 46
# 42. -1
#     core type: Operation
#     operator: 44
#     operand: 47
# 43. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 46
# 44. -
#     core type: Literal
#     sub-expressions:
# 45. (1)
#     core type: ExprTuple
#     sub-expressions: 47
# 46. 2^{t} * delta
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. 1
#     core type: Literal
#     sub-expressions:
# 48. *
#     core type: Literal
#     sub-expressions:
# 49. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. 2^{t}
#     core type: Operation
#     operator: 52
#     operands: 53
# 51. delta
#     core type: Literal
#     sub-expressions:
# 52. Exp
#     core type: Literal
#     sub-expressions:
# 53. (2, t)
#     core type: ExprTuple
#     sub-expressions: 54, 55
# 54. 2
#     core type: Literal
#     sub-expressions:
# 55. t
#     core type: Literal
#     sub-expressions:
