# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, l
from proveit.logic import Equals, InSet
from proveit.numbers import Exp, Mult, four, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Exp(diff_l_scaled_delta, two)
expr = ExprTuple(Lambda(l, Conditional(Equals(frac(one, Mult(four, sub_expr1)), Mult(frac(one, four), frac(one, sub_expr1))), InSet(l, pos_domain))))
# Out:
# expr: (l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) if l in {eps + 1 .. 2^{t - 1}}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(l \mapsto \left\{\frac{1}{4 \cdot \left(l - \left(2^{t} \cdot \delta\right)\right)^{2}} = \left(\frac{1}{4} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right) \textrm{ if } l \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) if l in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. l -> {(1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 38
#    body: 2
# 2. {(1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2})) if l in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. (1 / (4 * (l - (2^{t} * delta))^{2})) = ((1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. l in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (1 / (4 * (l - (2^{t} * delta))^{2}), (1 / 4) * (1 / (l - (2^{t} * delta))^{2}))
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (l, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 38, 11
# 9. 1 / (4 * (l - (2^{t} * delta))^{2})
#    core type: Operation
#    operator: 23
#    operands: 12
# 10. (1 / 4) * (1 / (l - (2^{t} * delta))^{2})
#     core type: Operation
#     operator: 44
#     operands: 13
# 11. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. (1, 4 * (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 40, 16
# 13. (1 / 4, 1 / (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. 4 * (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 44
#     operands: 21
# 17. 1 / 4
#     core type: Operation
#     operator: 23
#     operands: 22
# 18. 1 / (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. eps + 1
#     core type: Operation
#     operator: 35
#     operands: 25
# 20. 2^{t - 1}
#     core type: Operation
#     operator: 48
#     operands: 26
# 21. (4, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 22. (1, 4)
#     core type: ExprTuple
#     sub-expressions: 40, 27
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (1, (l - (2^{t} * delta))^{2})
#     core type: ExprTuple
#     sub-expressions: 40, 28
# 25. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 29, 40
# 26. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 50, 30
# 27. 4
#     core type: Literal
#     sub-expressions:
# 28. (l - (2^{t} * delta))^{2}
#     core type: Operation
#     operator: 48
#     operands: 31
# 29. eps
#     core type: Variable
#     sub-expressions:
# 30. t - 1
#     core type: Operation
#     operator: 35
#     operands: 32
# 31. (l - (2^{t} * delta), 2)
#     core type: ExprTuple
#     sub-expressions: 33, 50
# 32. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 51, 34
# 33. l - (2^{t} * delta)
#     core type: Operation
#     operator: 35
#     operands: 36
# 34. -1
#     core type: Operation
#     operator: 41
#     operand: 40
# 35. +
#     core type: Literal
#     sub-expressions:
# 36. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 38, 39
# 37. (1)
#     core type: ExprTuple
#     sub-expressions: 40
# 38. l
#     core type: Variable
#     sub-expressions:
# 39. -(2^{t} * delta)
#     core type: Operation
#     operator: 41
#     operand: 43
# 40. 1
#     core type: Literal
#     sub-expressions:
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. 2^{t} * delta
#     core type: Operation
#     operator: 44
#     operands: 45
# 44. *
#     core type: Literal
#     sub-expressions:
# 45. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 46, 47
# 46. 2^{t}
#     core type: Operation
#     operator: 48
#     operands: 49
# 47. delta
#     core type: Literal
#     sub-expressions:
# 48. Exp
#     core type: Literal
#     sub-expressions:
# 49. (2, t)
#     core type: ExprTuple
#     sub-expressions: 50, 51
# 50. 2
#     core type: Literal
#     sub-expressions:
# 51. t
#     core type: Literal
#     sub-expressions:
