# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, IndexedVar, Lambda, a, l
from proveit.logic import Equals, InSet
from proveit.numbers import Complex, Exp, Mult, Sum, frac, one, two
from proveit.physics.quantum.QPE import diff_l_scaled_delta, pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = [l]
sub_expr2 = IndexedVar(a, one)
sub_expr3 = frac(one, Exp(diff_l_scaled_delta, two))
expr = Lambda(sub_expr2, Conditional(Equals(Mult(sub_expr2, Sum(sub_expr1, sub_expr3, domain = pos_domain)), Sum(sub_expr1, Mult(sub_expr2, sub_expr3), domain = pos_domain)), InSet(sub_expr2, Complex)))
# Out:
# expr: a_{1} -> {(a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))) if a_{1} in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a_{1} \mapsto \left\{\left(a_{1} \cdot \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right) = \left(\sum_{l=\varepsilon + 1}^{2^{t - 1}} \left(a_{1} \cdot \frac{1}{\left(l - \left(2^{t} \cdot \delta\right)\right)^{2}}\right)\right) \textrm{ if } a_{1} \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a_{1} -> {(a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))) if a_{1} in Complex.
#    core type: Lambda
#    parameter: 22
#    body: 1
# 1. {(a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2}))) if a_{1} in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2}))) = (Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2})))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. a_{1} in Complex
#    core type: Operation
#    operator: 24
#    operands: 6
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} * (Sum_{l=eps + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta))^{2})), Sum_{l=eps + 1}^{2^{t - 1}} (a_{1} * (1 / (l - (2^{t} * delta))^{2})))
#    core type: ExprTuple
# ...
