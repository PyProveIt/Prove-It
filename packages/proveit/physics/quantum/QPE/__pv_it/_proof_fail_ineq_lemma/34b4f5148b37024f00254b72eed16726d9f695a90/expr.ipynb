# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Real, Sum
from proveit.physics.quantum.QPE import alpha_l_sqrd, neg_domain

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Sum([l], alpha_l_sqrd, domain = neg_domain), Real)
# Out:
# expr: (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}, Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{l=-2^{t - 1} + 1}^{-\left(\varepsilon + 1\right)} \left|\alpha_{l}\right|^{2}, \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}, Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{l=-2^{t - 1} + 1}^{-(eps + 1)} |alpha_{l}|^{2}
#    core type: Operation
#    operator: 3
#    operand: 5
# 2. Real
#    core type: Literal
#    sub-expressions:
# 3. Sum
#    core type: Literal
#    sub-expressions:
# 4. (l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. l -> {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Lambda
#    parameter: 26
#    body: 6
# 6. {|alpha_{l}|^{2} if l in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. |alpha_{l}|^{2}
#    core type: Operation
#    operator: 33
#    operands: 9
# 8. l in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (|alpha_{l}|, 2)
#    core type: ExprTuple
#    sub-expressions: 12, 35
# 10. in
#     core type: Literal
#     sub-expressions:
# 11. (l, {-2^{t - 1} + 1 .. -(eps + 1)})
#     core type: ExprTuple
#     sub-expressions: 26, 13
# 12. |alpha_{l}|
#     core type: Operation
#     operator: 14
#     operand: 18
# 13. {-2^{t - 1} + 1 .. -(eps + 1)}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. Abs
#     core type: Literal
#     sub-expressions:
# 15. (alpha_{l})
#     core type: ExprTuple
#     sub-expressions: 18
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. alpha_{l}
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. -2^{t - 1} + 1
#     core type: Operation
#     operator: 37
#     operands: 23
# 20. -(eps + 1)
#     core type: Operation
#     operator: 41
#     operand: 28
# 21. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 22. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 23. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 43
# 24. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 28
# 25. alpha
#     core type: Literal
#     sub-expressions:
# 26. l
#     core type: Variable
#     sub-expressions:
# 27. -2^{t - 1}
#     core type: Operation
#     operator: 41
#     operand: 31
# 28. eps + 1
#     core type: Operation
#     operator: 37
#     operands: 30
# 29. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 31
# 30. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 32, 43
# 31. 2^{t - 1}
#     core type: Operation
#     operator: 33
#     operands: 34
# 32. eps
#     core type: Variable
#     sub-expressions:
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. t - 1
#     core type: Operation
#     operator: 37
#     operands: 38
# 37. +
#     core type: Literal
#     sub-expressions:
# 38. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 39, 40
# 39. t
#     core type: Literal
#     sub-expressions:
# 40. -1
#     core type: Operation
#     operator: 41
#     operand: 43
# 41. -
#     core type: Literal
#     sub-expressions:
# 42. (1)
#     core type: ExprTuple
#     sub-expressions: 43
# 43. 1
#     core type: Literal
#     sub-expressions:
