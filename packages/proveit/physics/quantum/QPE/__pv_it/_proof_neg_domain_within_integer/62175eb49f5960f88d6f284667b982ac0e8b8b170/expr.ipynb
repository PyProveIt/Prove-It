# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Variable
from proveit.logic import InSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import neg_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(InSet(sub_expr1, Integer), InSet(sub_expr1, neg_domain))
# Out:
# expr: {_a in Integer if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{{_{-}a} \in \mathbb{Z} \textrm{ if } {_{-}a} \in \{-2^{t - 1} + 1~\ldotp \ldotp~-\left(\varepsilon + 1\right)\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {_a in Integer if _a in {-2^{t - 1} + 1 .. -(eps + 1)}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. _a in Integer
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. _a in {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (_a, Integer)
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. in
#    core type: Literal
#    sub-expressions:
# 5. (_a, {-2^{t - 1} + 1 .. -(eps + 1)})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. Integer
#    core type: Literal
#    sub-expressions:
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. {-2^{t - 1} + 1 .. -(eps + 1)}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Interval
#    core type: Literal
#    sub-expressions:
# 10. (-2^{t - 1} + 1, -(eps + 1))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. -2^{t - 1} + 1
#     core type: Operation
#     operator: 25
#     operands: 13
# 12. -(eps + 1)
#     core type: Operation
#     operator: 29
#     operand: 16
# 13. (-2^{t - 1}, 1)
#     core type: ExprTuple
#     sub-expressions: 15, 31
# 14. (eps + 1)
#     core type: ExprTuple
#     sub-expressions: 16
# 15. -2^{t - 1}
#     core type: Operation
#     operator: 29
#     operand: 19
# 16. eps + 1
#     core type: Operation
#     operator: 25
#     operands: 18
# 17. (2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 19
# 18. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 31
# 19. 2^{t - 1}
#     core type: Operation
#     operator: 21
#     operands: 22
# 20. eps
#     core type: Variable
#     sub-expressions:
# 21. Exp
#     core type: Literal
#     sub-expressions:
# 22. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. 2
#     core type: Literal
#     sub-expressions:
# 24. t - 1
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. +
#     core type: Literal
#     sub-expressions:
# 26. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. t
#     core type: Literal
#     sub-expressions:
# 28. -1
#     core type: Operation
#     operator: 29
#     operand: 31
# 29. -
#     core type: Literal
#     sub-expressions:
# 30. (1)
#     core type: ExprTuple
#     sub-expressions: 31
# 31. 1
#     core type: Literal
#     sub-expressions:
