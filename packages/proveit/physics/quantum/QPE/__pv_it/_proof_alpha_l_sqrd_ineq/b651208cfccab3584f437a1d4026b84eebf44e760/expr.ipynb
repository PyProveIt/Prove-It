# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(two_pow_t, two, Abs(Add(delta_, Neg(frac(l, two_pow_t)))))
expr = ExprTuple(frac(two, Mult(two, sub_expr1)), frac(one, sub_expr1))
# Out:
# expr: (2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|)), 1 / (2^{t} * 2 * |delta - (l / 2^{t})|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{2}{2 \cdot \left(2^{t} \cdot 2 \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}, \frac{1}{2^{t} \cdot 2 \cdot \left|\delta - \frac{l}{2^{t}}\right|}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|)), 1 / (2^{t} * 2 * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 / (2 * (2^{t} * 2 * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 22
#    operands: 3
# 2. 1 / (2^{t} * 2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 22
#    operands: 4
# 3. (2, 2 * (2^{t} * 2 * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 28, 5
# 4. (1, 2^{t} * 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 6, 8
# 5. 2 * (2^{t} * 2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 9
#    operands: 7
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. (2, 2^{t} * 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 28, 8
# 8. 2^{t} * 2 * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2^{t}, 2, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 25, 28, 11
# 11. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 12
#     operand: 14
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 14
# 14. delta - (l / 2^{t})
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. delta
#     core type: Literal
#     sub-expressions:
# 18. -(l / 2^{t})
#     core type: Operation
#     operator: 19
#     operand: 21
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. l / 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. l
#     core type: Variable
#     sub-expressions:
# 25. 2^{t}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (2, t)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. t
#     core type: Literal
#     sub-expressions:
