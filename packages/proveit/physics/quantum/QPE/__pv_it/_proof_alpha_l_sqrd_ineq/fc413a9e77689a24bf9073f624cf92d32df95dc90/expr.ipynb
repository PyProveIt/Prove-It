# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(Add(Mult(two_pow_t, delta_), Neg(l)))
expr = Equals(frac(Mult(two, pi, sub_expr1), two), frac(Mult(two, Mult(pi, sub_expr1)), two))
# Out:
# expr: ((2 * pi * |(2^{t} * delta) - l|) / 2) = ((2 * (pi * |(2^{t} * delta) - l|)) / 2)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{2 \cdot \pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|}{2} = \frac{2 \cdot \left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)}{2}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * pi * |(2^{t} * delta) - l|) / 2) = ((2 * (pi * |(2^{t} * delta) - l|)) / 2)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * pi * |(2^{t} * delta) - l|) / 2, (2 * (pi * |(2^{t} * delta) - l|)) / 2)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2 * pi * |(2^{t} * delta) - l|) / 2
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2 * (pi * |(2^{t} * delta) - l|)) / 2
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2 * pi * |(2^{t} * delta) - l|, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 32
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (2 * (pi * |(2^{t} * delta) - l|), 2)
#    core type: ExprTuple
#    sub-expressions: 9, 32
# 8. 2 * pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 23
#    operands: 10
# 9. 2 * (pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 23
#    operands: 11
# 10. (2, pi, |(2^{t} * delta) - l|)
#     core type: ExprTuple
#     sub-expressions: 32, 14, 15
# 11. (2, pi * |(2^{t} * delta) - l|)
#     core type: ExprTuple
#     sub-expressions: 32, 12
# 12. pi * |(2^{t} * delta) - l|
#     core type: Operation
#     operator: 23
#     operands: 13
# 13. (pi, |(2^{t} * delta) - l|)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 14. pi
#     core type: Literal
#     sub-expressions:
# 15. |(2^{t} * delta) - l|
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. Abs
#     core type: Literal
#     sub-expressions:
# 17. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 18
# 18. (2^{t} * delta) - l
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. 2^{t} * delta
#     core type: Operation
#     operator: 23
#     operands: 24
# 22. -l
#     core type: Operation
#     operator: 25
#     operand: 29
# 23. *
#     core type: Literal
#     sub-expressions:
# 24. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 25. -
#     core type: Literal
#     sub-expressions:
# 26. (l)
#     core type: ExprTuple
#     sub-expressions: 29
# 27. 2^{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 28. delta
#     core type: Literal
#     sub-expressions:
# 29. l
#     core type: Variable
#     sub-expressions:
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (2, t)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 2
#     core type: Literal
#     sub-expressions:
# 33. t
#     core type: Literal
#     sub-expressions:
