# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = ExprTuple(two, Mult(two_pow_t, two, Sin(Mult(pi, Abs(Add(delta_, Neg(frac(l, two_pow_t))))))))
# Out:
# expr: (2, 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2, 2^{t} \cdot 2 \cdot \sin{\left(\pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2, 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 27, 1
# 1. 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 7
#    operands: 2
# 2. (2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 24, 27, 3
# 3. sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. sin
#    core type: Literal
#    sub-expressions:
# 5. (pi * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. pi * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. *
#    core type: Literal
#    sub-expressions:
# 8. (pi, |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. pi
#    core type: Literal
#    sub-expressions:
# 10. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 11
#     operand: 13
# 11. Abs
#     core type: Literal
#     sub-expressions:
# 12. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 13
# 13. delta - (l / 2^{t})
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. delta
#     core type: Literal
#     sub-expressions:
# 17. -(l / 2^{t})
#     core type: Operation
#     operator: 18
#     operand: 20
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 20
# 20. l / 2^{t}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. /
#     core type: Literal
#     sub-expressions:
# 22. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. l
#     core type: Variable
#     sub-expressions:
# 24. 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (2, t)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t
#     core type: Literal
#     sub-expressions:
