# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(Add(delta_, Neg(frac(l, two_pow_t))))
expr = Equals(Mult(two_pow_t, two, Mult(two, sub_expr1)), Mult(two_pow_t, two, two, sub_expr1))
# Out:
# expr: (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) = (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2^{t} \cdot 2 \cdot \left(2 \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)\right) = \left(2^{t} \cdot 2 \cdot 2 \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) = (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2^{t} * 2 * (2 * |delta - (l / 2^{t})|), 2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2^{t} * 2 * (2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 8
#    operands: 5
# 4. 2^{t} * 2 * 2 * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 8
#    operands: 6
# 5. (2^{t}, 2, 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 24, 27, 7
# 6. (2^{t}, 2, 2, |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 24, 27, 27, 10
# 7. 2 * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. *
#    core type: Literal
#    sub-expressions:
# 9. (2, |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 27, 10
# 10. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 11
#     operand: 13
# 11. Abs
#     core type: Literal
#     sub-expressions:
# 12. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 13
# 13. delta - (l / 2^{t})
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. delta
#     core type: Literal
#     sub-expressions:
# 17. -(l / 2^{t})
#     core type: Operation
#     operator: 18
#     operand: 20
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 20
# 20. l / 2^{t}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. /
#     core type: Literal
#     sub-expressions:
# 22. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. l
#     core type: Variable
#     sub-expressions:
# 24. 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (2, t)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t
#     core type: Literal
#     sub-expressions:
