# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Div.html">Div</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Abs, Add, Mult, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = frac(one, Mult(two, Abs(Add(Mult(two_pow_t, delta_), Mult(two_pow_t, Neg(frac(l, two_pow_t)))))))
# Out:
# expr: 1 / (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{1}{2 \cdot \left|\left(2^{t} \cdot \delta\right) + \left(2^{t} \cdot \left(-\frac{l}{2^{t}}\right)\right)\right|}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: division
# description: 'inline': uses '/'; 'fraction': numerator over the denominator (also see 'frac' function)
# default: fraction
# current value: fraction
# related methods: ('with_inline_style', 'with_fraction_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. 1 / (2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)
#    core type: Operation
#    operator: 21
#    operands: 1
# 1. (1, 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. 1
#    core type: Literal
#    sub-expressions:
# 3. 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
#    core type: Operation
#    operator: 14
#    operands: 4
# 4. (2, |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)
#    core type: ExprTuple
#    sub-expressions: 27, 5
# 5. |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
#    core type: Operation
#    operator: 6
#    operand: 8
# 6. Abs
#    core type: Literal
#    sub-expressions:
# 7. ((2^{t} * delta) + (2^{t} * (-(l / 2^{t}))))
#    core type: ExprTuple
#    sub-expressions: 8
# 8. (2^{t} * delta) + (2^{t} * (-(l / 2^{t})))
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2^{t} * delta, 2^{t} * (-(l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 2^{t} * delta
#     core type: Operation
#     operator: 14
#     operands: 13
# 12. 2^{t} * (-(l / 2^{t}))
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 24, 16
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2^{t}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 24, 17
# 16. delta
#     core type: Literal
#     sub-expressions:
# 17. -(l / 2^{t})
#     core type: Operation
#     operator: 18
#     operand: 20
# 18. -
#     core type: Literal
#     sub-expressions:
# 19. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 20
# 20. l / 2^{t}
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. /
#     core type: Literal
#     sub-expressions:
# 22. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. l
#     core type: Variable
#     sub-expressions:
# 24. 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (2, t)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t
#     core type: Literal
#     sub-expressions:
