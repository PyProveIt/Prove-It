# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Add, Mult, Neg, frac
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(two_pow_t, delta_)
expr = Equals(Add(sub_expr1, Mult(two_pow_t, Neg(frac(l, two_pow_t)))), Add(sub_expr1, Neg(l)))
# Out:
# expr: ((2^{t} * delta) + (2^{t} * (-(l / 2^{t})))) = ((2^{t} * delta) - l)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2^{t} \cdot \delta\right) + \left(2^{t} \cdot \left(-\frac{l}{2^{t}}\right)\right)\right) = \left(\left(2^{t} \cdot \delta\right) - l\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2^{t} * delta) + (2^{t} * (-(l / 2^{t})))) = ((2^{t} * delta) - l)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2^{t} * delta) + (2^{t} * (-(l / 2^{t}))), (2^{t} * delta) - l)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (2^{t} * delta) + (2^{t} * (-(l / 2^{t})))
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (2^{t} * delta) - l
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (2^{t} * delta, 2^{t} * (-(l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 9, 8
# 6. +
#    core type: Literal
#    sub-expressions:
# 7. (2^{t} * delta, -l)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. 2^{t} * (-(l / 2^{t}))
#    core type: Operation
#    operator: 12
#    operands: 11
# 9. 2^{t} * delta
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. -l
#     core type: Operation
#     operator: 17
#     operand: 22
# 11. (2^{t}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 23, 16
# 14. (l)
#     core type: ExprTuple
#     sub-expressions: 22
# 15. -(l / 2^{t})
#     core type: Operation
#     operator: 17
#     operand: 19
# 16. delta
#     core type: Literal
#     sub-expressions:
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 19
# 19. l / 2^{t}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. /
#     core type: Literal
#     sub-expressions:
# 21. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. l
#     core type: Variable
#     sub-expressions:
# 23. 2^{t}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (2, t)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t
#     core type: Literal
#     sub-expressions:
