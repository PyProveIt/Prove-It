# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(delta_, Neg(frac(l, two_pow_t)))
expr = ExprTuple(Abs(Neg(Mult(two, pi, sub_expr1))), Mult(two, pi, Abs(sub_expr1)))
# Out:
# expr: (|-(2 * pi * (delta - (l / 2^{t})))|, 2 * pi * |delta - (l / 2^{t})|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|-\left(2 \cdot \pi \cdot \left(\delta - \frac{l}{2^{t}}\right)\right)\right|, 2 \cdot \pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|-(2 * pi * (delta - (l / 2^{t})))|, 2 * pi * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |-(2 * pi * (delta - (l / 2^{t})))|
#    core type: Operation
#    operator: 8
#    operand: 5
# 2. 2 * pi * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 11
#    operands: 4
# 3. (-(2 * pi * (delta - (l / 2^{t}))))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (2, pi, |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 28, 13, 6
# 5. -(2 * pi * (delta - (l / 2^{t})))
#    core type: Operation
#    operator: 19
#    operand: 10
# 6. |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 8
#    operand: 14
# 7. (2 * pi * (delta - (l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 10
# 8. Abs
#    core type: Literal
#    sub-expressions:
# 9. (delta - (l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 14
# 10. 2 * pi * (delta - (l / 2^{t}))
#     core type: Operation
#     operator: 11
#     operands: 12
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (2, pi, delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 28, 13, 14
# 13. pi
#     core type: Literal
#     sub-expressions:
# 14. delta - (l / 2^{t})
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. delta
#     core type: Literal
#     sub-expressions:
# 18. -(l / 2^{t})
#     core type: Operation
#     operator: 19
#     operand: 21
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 21
# 21. l / 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. /
#     core type: Literal
#     sub-expressions:
# 23. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. l
#     core type: Variable
#     sub-expressions:
# 25. 2^{t}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (2, t)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. t
#     core type: Literal
#     sub-expressions:
