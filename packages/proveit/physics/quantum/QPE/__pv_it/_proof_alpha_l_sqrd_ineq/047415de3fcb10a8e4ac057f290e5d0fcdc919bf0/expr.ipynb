# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(Add(delta_, Neg(frac(l, two_pow_t))))
expr = Equals(frac(two, Mult(two_pow_t, two, Mult(two, sub_expr1))), frac(two, Mult(two_pow_t, two, two, sub_expr1)))
# Out:
# expr: (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))) = (2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{2}{2^{t} \cdot 2 \cdot \left(2 \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)} = \frac{2}{2^{t} \cdot 2 \cdot 2 \cdot \left|\delta - \frac{l}{2^{t}}\right|}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))) = (2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)), 2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 25
#    operands: 5
# 4. 2 / (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 25
#    operands: 6
# 5. (2, 2^{t} * 2 * (2 * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 31, 7
# 6. (2, 2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 31, 8
# 7. 2^{t} * 2 * (2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 12
#    operands: 9
# 8. 2^{t} * 2 * 2 * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 12
#    operands: 10
# 9. (2^{t}, 2, 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 28, 31, 11
# 10. (2^{t}, 2, 2, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 28, 31, 31, 14
# 11. 2 * |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 12
#     operands: 13
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 31, 14
# 14. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 15
#     operand: 17
# 15. Abs
#     core type: Literal
#     sub-expressions:
# 16. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 17
# 17. delta - (l / 2^{t})
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. +
#     core type: Literal
#     sub-expressions:
# 19. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. delta
#     core type: Literal
#     sub-expressions:
# 21. -(l / 2^{t})
#     core type: Operation
#     operator: 22
#     operand: 24
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 24
# 24. l / 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 25. /
#     core type: Literal
#     sub-expressions:
# 26. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. l
#     core type: Variable
#     sub-expressions:
# 28. 2^{t}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, t)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 2
#     core type: Literal
#     sub-expressions:
# 32. t
#     core type: Literal
#     sub-expressions:
