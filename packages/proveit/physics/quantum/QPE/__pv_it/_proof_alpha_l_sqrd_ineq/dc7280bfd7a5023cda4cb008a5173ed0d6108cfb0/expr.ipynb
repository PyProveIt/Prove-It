# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.InSet.html">InSet</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import InSet
from proveit.numbers import Abs, Add, Mult, Neg, Real, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = InSet(Mult(two, Sin(Mult(pi, Abs(Add(Mult(two_pow_t, delta_), Neg(l)))))), Real)
# Out:
# expr: (2 * sin(pi * |(2^{t} * delta) - l|)) in Real

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot \sin{\left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)}\right) \in \mathbb{R}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * sin(pi * |(2^{t} * delta) - l|)) in Real
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. in
#    core type: Literal
#    sub-expressions:
# 2. (2 * sin(pi * |(2^{t} * delta) - l|), Real)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. 2 * sin(pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 20
#    operands: 5
# 4. Real
#    core type: Literal
#    sub-expressions:
# 5. (2, sin(pi * |(2^{t} * delta) - l|))
#    core type: ExprTuple
#    sub-expressions: 29, 6
# 6. sin(pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 7
#    operand: 9
# 7. sin
#    core type: Literal
#    sub-expressions:
# 8. (pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 9
# 9. pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 20
#    operands: 10
# 10. (pi, |(2^{t} * delta) - l|)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. pi
#     core type: Literal
#     sub-expressions:
# 12. |(2^{t} * delta) - l|
#     core type: Operation
#     operator: 13
#     operand: 15
# 13. Abs
#     core type: Literal
#     sub-expressions:
# 14. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 15
# 15. (2^{t} * delta) - l
#     core type: Operation
#     operator: 16
#     operands: 17
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. 2^{t} * delta
#     core type: Operation
#     operator: 20
#     operands: 21
# 19. -l
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (l)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. 2^{t}
#     core type: Operation
#     operator: 27
#     operands: 28
# 25. delta
#     core type: Literal
#     sub-expressions:
# 26. l
#     core type: Variable
#     sub-expressions:
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (2, t)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. t
#     core type: Literal
#     sub-expressions:
