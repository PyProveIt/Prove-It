# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(one, Mult(two, Abs(Add(Mult(two_pow_t, delta_), Mult(two_pow_t, Neg(frac(l, two_pow_t)))))))
# Out:
# expr: (1, 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1, 2 \cdot \left|\left(2^{t} \cdot \delta\right) + \left(2^{t} \cdot \left(-\frac{l}{2^{t}}\right)\right)\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1, 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1
#    core type: Literal
#    sub-expressions:
# 2. 2 * |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
#    core type: Operation
#    operator: 13
#    operands: 3
# 3. (2, |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|)
#    core type: ExprTuple
#    sub-expressions: 26, 4
# 4. |(2^{t} * delta) + (2^{t} * (-(l / 2^{t})))|
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. Abs
#    core type: Literal
#    sub-expressions:
# 6. ((2^{t} * delta) + (2^{t} * (-(l / 2^{t}))))
#    core type: ExprTuple
#    sub-expressions: 7
# 7. (2^{t} * delta) + (2^{t} * (-(l / 2^{t})))
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. +
#    core type: Literal
#    sub-expressions:
# 9. (2^{t} * delta, 2^{t} * (-(l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. 2^{t} * delta
#     core type: Operation
#     operator: 13
#     operands: 12
# 11. 2^{t} * (-(l / 2^{t}))
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 23, 15
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2^{t}, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 23, 16
# 15. delta
#     core type: Literal
#     sub-expressions:
# 16. -(l / 2^{t})
#     core type: Operation
#     operator: 17
#     operand: 19
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 19
# 19. l / 2^{t}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. /
#     core type: Literal
#     sub-expressions:
# 21. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. l
#     core type: Variable
#     sub-expressions:
# 23. 2^{t}
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. Exp
#     core type: Literal
#     sub-expressions:
# 25. (2, t)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. 2
#     core type: Literal
#     sub-expressions:
# 27. t
#     core type: Literal
#     sub-expressions:
