# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, Real, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Mult(two, Sin(Mult(pi, Abs(Add(Mult(two_pow_t, delta_), Neg(l)))))), Real)
# Out:
# expr: (2 * sin(pi * |(2^{t} * delta) - l|), Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(2 \cdot \sin{\left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)}, \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 * sin(pi * |(2^{t} * delta) - l|), Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 * sin(pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 18
#    operands: 3
# 2. Real
#    core type: Literal
#    sub-expressions:
# 3. (2, sin(pi * |(2^{t} * delta) - l|))
#    core type: ExprTuple
#    sub-expressions: 27, 4
# 4. sin(pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. sin
#    core type: Literal
#    sub-expressions:
# 6. (pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 18
#    operands: 8
# 8. (pi, |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. pi
#    core type: Literal
#    sub-expressions:
# 10. |(2^{t} * delta) - l|
#     core type: Operation
#     operator: 11
#     operand: 13
# 11. Abs
#     core type: Literal
#     sub-expressions:
# 12. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 13
# 13. (2^{t} * delta) - l
#     core type: Operation
#     operator: 14
#     operands: 15
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 16. 2^{t} * delta
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. -l
#     core type: Operation
#     operator: 20
#     operand: 24
# 18. *
#     core type: Literal
#     sub-expressions:
# 19. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (l)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. 2^{t}
#     core type: Operation
#     operator: 25
#     operands: 26
# 23. delta
#     core type: Literal
#     sub-expressions:
# 24. l
#     core type: Variable
#     sub-expressions:
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (2, t)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 27. 2
#     core type: Literal
#     sub-expressions:
# 28. t
#     core type: Literal
#     sub-expressions:
