# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
sub_expr1 = Abs(Add(delta_, Neg(frac(l, two_pow_t))))
expr = ExprTuple(frac(two, Mult(two_pow_t, two, Sin(Mult(pi, sub_expr1)))), frac(two, Mult(two_pow_t, two, Mult(two, sub_expr1))))
# Out:
# expr: (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{2}{2^{t} \cdot 2 \cdot \sin{\left(\pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}}, \frac{2}{2^{t} \cdot 2 \cdot \left(2 \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 29
#    operands: 3
# 2. 2 / (2^{t} * 2 * (2 * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 29
#    operands: 4
# 3. (2, 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 35, 5
# 4. (2, 2^{t} * 2 * (2 * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 35, 6
# 5. 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 15
#    operands: 7
# 6. 2^{t} * 2 * (2 * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 15
#    operands: 8
# 7. (2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 32, 35, 9
# 8. (2^{t}, 2, 2 * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 32, 35, 10
# 9. sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 11
#    operand: 14
# 10. 2 * |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 15
#     operands: 13
# 11. sin
#     core type: Literal
#     sub-expressions:
# 12. (pi * |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 14
# 13. (2, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 35, 18
# 14. pi * |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (pi, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. pi
#     core type: Literal
#     sub-expressions:
# 18. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 19
#     operand: 21
# 19. Abs
#     core type: Literal
#     sub-expressions:
# 20. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 21
# 21. delta - (l / 2^{t})
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. delta
#     core type: Literal
#     sub-expressions:
# 25. -(l / 2^{t})
#     core type: Operation
#     operator: 26
#     operand: 28
# 26. -
#     core type: Literal
#     sub-expressions:
# 27. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 28
# 28. l / 2^{t}
#     core type: Operation
#     operator: 29
#     operands: 30
# 29. /
#     core type: Literal
#     sub-expressions:
# 30. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. 2^{t}
#     core type: Operation
#     operator: 33
#     operands: 34
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (2, t)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. t
#     core type: Literal
#     sub-expressions:
