# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Mult, Neg, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Add(Mult(two, pi, Add(Mult(two_pow_t, delta_), Neg(l))), pi), Neg(pi))
# Out:
# expr: ((2 * pi * ((2^{t} * delta) - l)) + pi, -pi)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2 \cdot \pi \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)\right) + \pi, -\pi\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * pi * ((2^{t} * delta) - l)) + pi, -pi)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2 * pi * ((2^{t} * delta) - l)) + pi
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. -pi
#    core type: Operation
#    operator: 15
#    operand: 7
# 3. (2 * pi * ((2^{t} * delta) - l), pi)
#    core type: ExprTuple
#    sub-expressions: 5, 7
# 4. (pi)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. 2 * pi * ((2^{t} * delta) - l)
#    core type: Operation
#    operator: 13
#    operands: 6
# 6. (2, pi, (2^{t} * delta) - l)
#    core type: ExprTuple
#    sub-expressions: 22, 7, 8
# 7. pi
#    core type: Literal
#    sub-expressions:
# 8. (2^{t} * delta) - l
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. +
#    core type: Literal
#    sub-expressions:
# 10. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 2^{t} * delta
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. -l
#     core type: Operation
#     operator: 15
#     operand: 19
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (l)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. 2^{t}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. delta
#     core type: Literal
#     sub-expressions:
# 19. l
#     core type: Variable
#     sub-expressions:
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (2, t)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. t
#     core type: Literal
#     sub-expressions:
