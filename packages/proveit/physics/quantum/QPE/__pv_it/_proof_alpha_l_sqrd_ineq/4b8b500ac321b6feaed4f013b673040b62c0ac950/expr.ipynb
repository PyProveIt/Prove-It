# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Exp, Mult, Neg, e, i, one, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Mult(two_pow_t, delta_), Neg(l))
expr = ExprTuple(Mult(one, Exp(e, Mult(i, Add(Mult(two, pi, sub_expr1), pi)))), Neg(Exp(e, Mult(two, pi, i, sub_expr1))))
# Out:
# expr: (1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}, -e^{2 * pi * i * ((2^{t} * delta) - l)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(1 \cdot \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)\right) + \pi\right)}, -\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}, -e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. 1 * e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
#    core type: Operation
#    operator: 26
#    operands: 3
# 2. -e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 28
#    operand: 7
# 3. (1, e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)})
#    core type: ExprTuple
#    sub-expressions: 5, 6
# 4. (e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: ExprTuple
#    sub-expressions: 7
# 5. 1
#    core type: Literal
#    sub-expressions:
# 6. e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
#    core type: Operation
#    operator: 33
#    operands: 8
# 7. e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 33
#    operands: 9
# 8. (e, i * ((2 * pi * ((2^{t} * delta) - l)) + pi))
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 9. (e, 2 * pi * i * ((2^{t} * delta) - l))
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. i * ((2 * pi * ((2^{t} * delta) - l)) + pi)
#     core type: Operation
#     operator: 26
#     operands: 13
# 11. e
#     core type: Literal
#     sub-expressions:
# 12. 2 * pi * i * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 26
#     operands: 14
# 13. (i, (2 * pi * ((2^{t} * delta) - l)) + pi)
#     core type: ExprTuple
#     sub-expressions: 16, 15
# 14. (2, pi, i, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 35, 20, 16, 21
# 15. (2 * pi * ((2^{t} * delta) - l)) + pi
#     core type: Operation
#     operator: 22
#     operands: 17
# 16. i
#     core type: Literal
#     sub-expressions:
# 17. (2 * pi * ((2^{t} * delta) - l), pi)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 18. 2 * pi * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 26
#     operands: 19
# 19. (2, pi, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 35, 20, 21
# 20. pi
#     core type: Literal
#     sub-expressions:
# 21. (2^{t} * delta) - l
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2^{t} * delta
#     core type: Operation
#     operator: 26
#     operands: 27
# 25. -l
#     core type: Operation
#     operator: 28
#     operand: 32
# 26. *
#     core type: Literal
#     sub-expressions:
# 27. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 30, 31
# 28. -
#     core type: Literal
#     sub-expressions:
# 29. (l)
#     core type: ExprTuple
#     sub-expressions: 32
# 30. 2^{t}
#     core type: Operation
#     operator: 33
#     operands: 34
# 31. delta
#     core type: Literal
#     sub-expressions:
# 32. l
#     core type: Variable
#     sub-expressions:
# 33. Exp
#     core type: Literal
#     sub-expressions:
# 34. (2, t)
#     core type: ExprTuple
#     sub-expressions: 35, 36
# 35. 2
#     core type: Literal
#     sub-expressions:
# 36. t
#     core type: Literal
#     sub-expressions:
