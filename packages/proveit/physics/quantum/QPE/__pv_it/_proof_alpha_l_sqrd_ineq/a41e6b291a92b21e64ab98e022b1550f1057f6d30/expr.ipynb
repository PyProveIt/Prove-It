# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Add, Mult, Neg, frac
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(two_pow_t, delta_)
expr = ExprTuple(Add(sub_expr1, Mult(two_pow_t, Neg(frac(l, two_pow_t)))), Add(sub_expr1, Neg(l)))
# Out:
# expr: ((2^{t} * delta) + (2^{t} * (-(l / 2^{t}))), (2^{t} * delta) - l)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(2^{t} \cdot \delta\right) + \left(2^{t} \cdot \left(-\frac{l}{2^{t}}\right)\right), \left(2^{t} \cdot \delta\right) - l\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2^{t} * delta) + (2^{t} * (-(l / 2^{t}))), (2^{t} * delta) - l)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (2^{t} * delta) + (2^{t} * (-(l / 2^{t})))
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (2^{t} * delta) - l
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (2^{t} * delta, 2^{t} * (-(l / 2^{t})))
#    core type: ExprTuple
#    sub-expressions: 7, 6
# 4. +
#    core type: Literal
#    sub-expressions:
# 5. (2^{t} * delta, -l)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. 2^{t} * (-(l / 2^{t}))
#    core type: Operation
#    operator: 10
#    operands: 9
# 7. 2^{t} * delta
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. -l
#    core type: Operation
#    operator: 15
#    operand: 20
# 9. (2^{t}, -(l / 2^{t}))
#    core type: ExprTuple
#    sub-expressions: 21, 13
# 10. *
#     core type: Literal
#     sub-expressions:
# 11. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 21, 14
# 12. (l)
#     core type: ExprTuple
#     sub-expressions: 20
# 13. -(l / 2^{t})
#     core type: Operation
#     operator: 15
#     operand: 17
# 14. delta
#     core type: Literal
#     sub-expressions:
# 15. -
#     core type: Literal
#     sub-expressions:
# 16. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 17
# 17. l / 2^{t}
#     core type: Operation
#     operator: 18
#     operands: 19
# 18. /
#     core type: Literal
#     sub-expressions:
# 19. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 20. l
#     core type: Variable
#     sub-expressions:
# 21. 2^{t}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, t)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. t
#     core type: Literal
#     sub-expressions:
