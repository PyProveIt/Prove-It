# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Add, Exp, Mult, Neg, e, i, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Mult(two_pow_t, delta_), Neg(l))
expr = Equals(Exp(e, Mult(i, Add(Mult(two, pi, sub_expr1), pi))), Neg(Exp(e, Mult(two, pi, i, sub_expr1))))
# Out:
# expr: e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)} = (-e^{2 * pi * i * ((2^{t} * delta) - l)})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{\mathsf{i} \cdot \left(\left(2 \cdot \pi \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)\right) + \pi\right)} = \left(-\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)} = (-e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}, -e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)}
#    core type: Operation
#    operator: 32
#    operands: 5
# 4. -e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 27
#    operand: 8
# 5. (e, i * ((2 * pi * ((2^{t} * delta) - l)) + pi))
#    core type: ExprTuple
#    sub-expressions: 12, 7
# 6. (e^{2 * pi * i * ((2^{t} * delta) - l)})
#    core type: ExprTuple
#    sub-expressions: 8
# 7. i * ((2 * pi * ((2^{t} * delta) - l)) + pi)
#    core type: Operation
#    operator: 25
#    operands: 9
# 8. e^{2 * pi * i * ((2^{t} * delta) - l)}
#    core type: Operation
#    operator: 32
#    operands: 10
# 9. (i, (2 * pi * ((2^{t} * delta) - l)) + pi)
#    core type: ExprTuple
#    sub-expressions: 17, 11
# 10. (e, 2 * pi * i * ((2^{t} * delta) - l))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (2 * pi * ((2^{t} * delta) - l)) + pi
#     core type: Operation
#     operator: 21
#     operands: 14
# 12. e
#     core type: Literal
#     sub-expressions:
# 13. 2 * pi * i * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 25
#     operands: 15
# 14. (2 * pi * ((2^{t} * delta) - l), pi)
#     core type: ExprTuple
#     sub-expressions: 16, 19
# 15. (2, pi, i, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 34, 19, 17, 20
# 16. 2 * pi * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 25
#     operands: 18
# 17. i
#     core type: Literal
#     sub-expressions:
# 18. (2, pi, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 34, 19, 20
# 19. pi
#     core type: Literal
#     sub-expressions:
# 20. (2^{t} * delta) - l
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. 2^{t} * delta
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. -l
#     core type: Operation
#     operator: 27
#     operand: 31
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. (l)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. 2^{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. delta
#     core type: Literal
#     sub-expressions:
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (2, t)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 2
#     core type: Literal
#     sub-expressions:
# 35. t
#     core type: Literal
#     sub-expressions:
