# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, k, l
from proveit.core_expr_types import Len
from proveit.numbers import Abs, Add, Neg, frac, one, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Len([two_pow_t, Abs(Add(delta_, Neg(frac(l, two_pow_t))))]), Len([ExprRange(k, k, one, two)]))
# Out:
# expr: (|(2^{t}, |delta - (l / 2^{t})|)|, |(1, ..k.., 2)|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(|\left(2^{t}, \left|\delta - \frac{l}{2^{t}}\right|\right)|, |\left(1, \ldots, 2\right)|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|(2^{t}, |delta - (l / 2^{t})|)|, |(1, ..k.., 2)|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |(2^{t}, |delta - (l / 2^{t})|)|
#    core type: Operation
#    operator: 4
#    operand: 6
# 2. |(1, ..k.., 2)|
#    core type: Operation
#    operator: 4
#    operand: 7
# 3. ((2^{t}, |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 6
# 4. length
#    core type: Literal
#    sub-expressions:
# 5. ((1, ..k.., 2))
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (2^{t}, |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 26, 8
# 7. (1, ..k.., 2)
#    core type: ExprTuple
#    sub-expressions: 9
# 8. |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 10
#    operand: 14
# 9. 1, ..k.., 2
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 29
# 10. Abs
#     core type: Literal
#     sub-expressions:
# 11. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 14
# 12. k -> k
#     core type: Lambda
#     parameter: 15
#     body: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. delta - (l / 2^{t})
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. +
#     core type: Literal
#     sub-expressions:
# 17. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 18. delta
#     core type: Literal
#     sub-expressions:
# 19. -(l / 2^{t})
#     core type: Operation
#     operator: 20
#     operand: 22
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 22
# 22. l / 2^{t}
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. /
#     core type: Literal
#     sub-expressions:
# 24. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. 2^{t}
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. Exp
#     core type: Literal
#     sub-expressions:
# 28. (2, t)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. 2
#     core type: Literal
#     sub-expressions:
# 30. t
#     core type: Literal
#     sub-expressions:
