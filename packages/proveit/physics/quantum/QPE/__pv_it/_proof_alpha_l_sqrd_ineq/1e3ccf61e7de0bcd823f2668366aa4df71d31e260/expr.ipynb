# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.numbers import Abs, Exp, LessEq, Mult, frac, one, two
from proveit.physics.quantum.QPE import alpha_l_sqrd, diff_l_scaled_delta

# %%
# build up the expression from sub-expressions
expr = LessEq(alpha_l_sqrd, frac(Exp(one, two), Mult(Exp(two, two), Exp(Abs(diff_l_scaled_delta), two))))
# Out:
# expr: |alpha_{l}|^{2} <= (1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\alpha_{l}\right|^{2} \leq \frac{1^{2}}{2^{2} \cdot \left|l - \left(2^{t} \cdot \delta\right)\right|^{2}}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |alpha_{l}|^{2} <= (1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (|alpha_{l}|^{2}, 1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |alpha_{l}|^{2}
#    core type: Operation
#    operator: 38
#    operands: 5
# 4. 1^{2} / (2^{2} * |l - (2^{t} * delta)|^{2})
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (|alpha_{l}|, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 40
# 6. /
#    core type: Literal
#    sub-expressions:
# 7. (1^{2}, 2^{2} * |l - (2^{t} * delta)|^{2})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. |alpha_{l}|
#    core type: Operation
#    operator: 24
#    operand: 14
# 9. 1^{2}
#    core type: Operation
#    operator: 38
#    operands: 12
# 10. 2^{2} * |l - (2^{t} * delta)|^{2}
#     core type: Operation
#     operator: 34
#     operands: 13
# 11. (alpha_{l})
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 15, 40
# 13. (2^{2}, |l - (2^{t} * delta)|^{2})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. alpha_{l}
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. 2^{2}
#     core type: Operation
#     operator: 38
#     operands: 20
# 17. |l - (2^{t} * delta)|^{2}
#     core type: Operation
#     operator: 38
#     operands: 21
# 18. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 19. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 22, 29
# 20. (2, 2)
#     core type: ExprTuple
#     sub-expressions: 40, 40
# 21. (|l - (2^{t} * delta)|, 2)
#     core type: ExprTuple
#     sub-expressions: 23, 40
# 22. alpha
#     core type: Literal
#     sub-expressions:
# 23. |l - (2^{t} * delta)|
#     core type: Operation
#     operator: 24
#     operand: 26
# 24. Abs
#     core type: Literal
#     sub-expressions:
# 25. (l - (2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 26
# 26. l - (2^{t} * delta)
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (l, -(2^{t} * delta))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. l
#     core type: Variable
#     sub-expressions:
# 30. -(2^{t} * delta)
#     core type: Operation
#     operator: 31
#     operand: 33
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. (2^{t} * delta)
#     core type: ExprTuple
#     sub-expressions: 33
# 33. 2^{t} * delta
#     core type: Operation
#     operator: 34
#     operands: 35
# 34. *
#     core type: Literal
#     sub-expressions:
# 35. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. 2^{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 37. delta
#     core type: Literal
#     sub-expressions:
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (2, t)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. 2
#     core type: Literal
#     sub-expressions:
# 41. t
#     core type: Literal
#     sub-expressions:
