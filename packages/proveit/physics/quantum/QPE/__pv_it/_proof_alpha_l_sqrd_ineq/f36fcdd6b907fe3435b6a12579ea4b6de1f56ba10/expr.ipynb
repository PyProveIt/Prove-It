# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import abs_alpha_l, delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
expr = Equals(abs_alpha_l, frac(Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Mult(two_pow_t, delta_), Neg(l))))))), Mult(two_pow_t, two, Sin(Mult(pi, Abs(Add(delta_, Neg(frac(l, two_pow_t)))))))))
# Out:
# expr: |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\alpha_{l}\right| = \frac{\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right|}{2^{t} \cdot 2 \cdot \sin{\left(\pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |alpha_{l}|
#    core type: Operation
#    operator: 28
#    operand: 7
# 4. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 49
#    operands: 6
# 5. (alpha_{l})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. alpha_{l}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|
#    core type: Operation
# ...
