# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.LessEq.html">LessEq</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.numbers import Abs, Add, LessEq, Mult, Neg, frac, one, two
from proveit.physics.quantum.QPE import abs_alpha_l, delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = LessEq(abs_alpha_l, frac(one, Mult(two, two_pow_t, Abs(Add(delta_, Neg(frac(l, two_pow_t)))))))
# Out:
# expr: |alpha_{l}| <= (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left|\alpha_{l}\right| \leq \frac{1}{2 \cdot 2^{t} \cdot \left|\delta - \frac{l}{2^{t}}\right|}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |alpha_{l}| <= (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. <=
#    core type: Literal
#    sub-expressions:
# 2. (|alpha_{l}|, 1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |alpha_{l}|
#    core type: Operation
#    operator: 16
#    operand: 7
# 4. 1 / (2 * 2^{t} * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 26
#    operands: 6
# 5. (alpha_{l})
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (1, 2 * 2^{t} * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. alpha_{l}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. 2 * 2^{t} * |delta - (l / 2^{t})|
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 11. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 14, 28
# 12. *
#     core type: Literal
#     sub-expressions:
# 13. (2, 2^{t}, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 32, 29, 15
# 14. alpha
#     core type: Literal
#     sub-expressions:
# 15. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 16
#     operand: 18
# 16. Abs
#     core type: Literal
#     sub-expressions:
# 17. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 18
# 18. delta - (l / 2^{t})
#     core type: Operation
#     operator: 19
#     operands: 20
# 19. +
#     core type: Literal
#     sub-expressions:
# 20. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 21. delta
#     core type: Literal
#     sub-expressions:
# 22. -(l / 2^{t})
#     core type: Operation
#     operator: 23
#     operand: 25
# 23. -
#     core type: Literal
#     sub-expressions:
# 24. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 25
# 25. l / 2^{t}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. /
#     core type: Literal
#     sub-expressions:
# 27. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. 2^{t}
#     core type: Operation
#     operator: 30
#     operands: 31
# 30. Exp
#     core type: Literal
#     sub-expressions:
# 31. (2, t)
#     core type: ExprTuple
#     sub-expressions: 32, 33
# 32. 2
#     core type: Literal
#     sub-expressions:
# 33. t
#     core type: Literal
#     sub-expressions:
