# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Mult(pi, Abs(Add(Mult(two_pow_t, delta_), Neg(l))))
expr = Equals(frac(Mult(two, sub_expr1), two), sub_expr1)
# Out:
# expr: ((2 * (pi * |(2^{t} * delta) - l|)) / 2) = (pi * |(2^{t} * delta) - l|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{2 \cdot \left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)}{2} = \left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((2 * (pi * |(2^{t} * delta) - l|)) / 2) = (pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((2 * (pi * |(2^{t} * delta) - l|)) / 2, pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 3, 8
# 3. (2 * (pi * |(2^{t} * delta) - l|)) / 2
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. /
#    core type: Literal
#    sub-expressions:
# 5. (2 * (pi * |(2^{t} * delta) - l|), 2)
#    core type: ExprTuple
#    sub-expressions: 6, 28
# 6. 2 * (pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 19
#    operands: 7
# 7. (2, pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 28, 8
# 8. pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 19
#    operands: 9
# 9. (pi, |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. pi
#     core type: Literal
#     sub-expressions:
# 11. |(2^{t} * delta) - l|
#     core type: Operation
#     operator: 12
#     operand: 14
# 12. Abs
#     core type: Literal
#     sub-expressions:
# 13. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 14
# 14. (2^{t} * delta) - l
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. +
#     core type: Literal
#     sub-expressions:
# 16. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 2^{t} * delta
#     core type: Operation
#     operator: 19
#     operands: 20
# 18. -l
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. *
#     core type: Literal
#     sub-expressions:
# 20. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. -
#     core type: Literal
#     sub-expressions:
# 22. (l)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. 2^{t}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. delta
#     core type: Literal
#     sub-expressions:
# 25. l
#     core type: Variable
#     sub-expressions:
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (2, t)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. 2
#     core type: Literal
#     sub-expressions:
# 29. t
#     core type: Literal
#     sub-expressions:
