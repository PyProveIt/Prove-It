# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, k, l
from proveit.core_expr_types import Len
from proveit.logic import Equals
from proveit.numbers import Add, Mult, Neg, four, i, one, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = Equals(Len([two, pi, i, Add(Mult(two_pow_t, delta_), Neg(l))]), Len([ExprRange(k, k, one, four)]))
# Out:
# expr: |(2, pi, i, (2^{t} * delta) - l)| = |(1, ..k.., 4)|

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# |\left(2, \pi, \mathsf{i}, \left(2^{t} \cdot \delta\right) - l\right)| = |\left(1, \ldots, 4\right)|

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |(2, pi, i, (2^{t} * delta) - l)| = |(1, ..k.., 4)|
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|(2, pi, i, (2^{t} * delta) - l)|, |(1, ..k.., 4)|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |(2, pi, i, (2^{t} * delta) - l)|
#    core type: Operation
#    operator: 6
#    operand: 8
# 4. |(1, ..k.., 4)|
#    core type: Operation
#    operator: 6
#    operand: 9
# 5. ((2, pi, i, (2^{t} * delta) - l))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. length
#    core type: Literal
#    sub-expressions:
# 7. ((1, ..k.., 4))
#    core type: ExprTuple
#    sub-expressions: 9
# 8. (2, pi, i, (2^{t} * delta) - l)
#    core type: ExprTuple
#    sub-expressions: 31, 10, 11, 12
# 9. (1, ..k.., 4)
#    core type: ExprTuple
#    sub-expressions: 13
# 10. pi
#     core type: Literal
#     sub-expressions:
# 11. i
#     core type: Literal
#     sub-expressions:
# 12. (2^{t} * delta) - l
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. 1, ..k.., 4
#     core type: ExprRange
#     lambda_map: 16
#     start_index: 17
#     end_index: 18
# 14. +
#     core type: Literal
#     sub-expressions:
# 15. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 16. k -> k
#     core type: Lambda
#     parameter: 21
#     body: 21
# 17. 1
#     core type: Literal
#     sub-expressions:
# 18. 4
#     core type: Literal
#     sub-expressions:
# 19. 2^{t} * delta
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. -l
#     core type: Operation
#     operator: 24
#     operand: 28
# 21. k
#     core type: Variable
#     sub-expressions:
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 24. -
#     core type: Literal
#     sub-expressions:
# 25. (l)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. 2^{t}
#     core type: Operation
#     operator: 29
#     operands: 30
# 27. delta
#     core type: Literal
#     sub-expressions:
# 28. l
#     core type: Variable
#     sub-expressions:
# 29. Exp
#     core type: Literal
#     sub-expressions:
# 30. (2, t)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 31. 2
#     core type: Literal
#     sub-expressions:
# 32. t
#     core type: Literal
#     sub-expressions:
