# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Variable, l
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import abs_alpha_l, delta_, two_pow_t

# %%
# build up the expression from sub-expressions
expr = ExprTuple(abs_alpha_l, frac(Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, Add(Mult(two_pow_t, delta_), Neg(l))))))), Variable("_a", latex_format = r"{_{-}a}")))
# Out:
# expr: (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / _a)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|\alpha_{l}\right|, \frac{\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)}\right|}{{_{-}a}}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|alpha_{l}|, |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / _a)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |alpha_{l}|
#    core type: Operation
#    operator: 11
#    operand: 6
# 2. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / _a
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (alpha_{l})
#    core type: ExprTuple
#    sub-expressions: 6
# 4. /
#    core type: Literal
#    sub-expressions:
# 5. (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, _a)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. alpha_{l}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|
#    core type: Operation
#    operator: 11
#    operand: 14
# 8. _a
#    core type: Variable
#    sub-expressions:
# 9. SUB_INDEXED
#    core type: Literal
#    sub-expressions:
# 10. (alpha, l)
#     core type: ExprTuple
#     sub-expressions: 13, 37
# 11. Abs
#     core type: Literal
#     sub-expressions:
# ...
