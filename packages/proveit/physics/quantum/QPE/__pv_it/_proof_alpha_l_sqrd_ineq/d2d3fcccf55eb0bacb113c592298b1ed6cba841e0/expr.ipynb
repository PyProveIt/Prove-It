# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Exp, Mult, Neg, e, frac, i, one, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t
from proveit.trigonometry import Sin

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(delta_, Neg(frac(l, two_pow_t)))
expr = ExprTuple(Abs(Add(one, Neg(Exp(e, Mult(two, pi, i, sub_expr1))))), Mult(two, Sin(Mult(pi, Abs(sub_expr1)))))
# Out:
# expr: (|1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|, 2 * sin(pi * |delta - (l / 2^{t})|))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left|1 - \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \left(\delta - \frac{l}{2^{t}}\right)}\right|, 2 \cdot \sin{\left(\pi \cdot \left|\delta - \frac{l}{2^{t}}\right|\right)}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|, 2 * sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |1 - e^{2 * pi * i * (delta - (l / 2^{t}))}|
#    core type: Operation
#    operator: 18
#    operand: 5
# 2. 2 * sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 22
#    operands: 4
# 3. (1 - e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (2, sin(pi * |delta - (l / 2^{t})|))
#    core type: ExprTuple
#    sub-expressions: 40, 6
# 5. 1 - e^{2 * pi * i * (delta - (l / 2^{t}))}
#    core type: Operation
#    operator: 27
#    operands: 7
# 6. sin(pi * |delta - (l / 2^{t})|)
#    core type: Operation
#    operator: 8
#    operand: 12
# 7. (1, -e^{2 * pi * i * (delta - (l / 2^{t}))})
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. sin
#    core type: Literal
#    sub-expressions:
# 9. (pi * |delta - (l / 2^{t})|)
#    core type: ExprTuple
#    sub-expressions: 12
# 10. 1
#     core type: Literal
#     sub-expressions:
# 11. -e^{2 * pi * i * (delta - (l / 2^{t}))}
#     core type: Operation
#     operator: 31
#     operand: 15
# 12. pi * |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 22
#     operands: 14
# 13. (e^{2 * pi * i * (delta - (l / 2^{t}))})
#     core type: ExprTuple
#     sub-expressions: 15
# 14. (pi, |delta - (l / 2^{t})|)
#     core type: ExprTuple
#     sub-expressions: 24, 16
# 15. e^{2 * pi * i * (delta - (l / 2^{t}))}
#     core type: Operation
#     operator: 38
#     operands: 17
# 16. |delta - (l / 2^{t})|
#     core type: Operation
#     operator: 18
#     operand: 26
# 17. (e, 2 * pi * i * (delta - (l / 2^{t})))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. Abs
#     core type: Literal
#     sub-expressions:
# 19. (delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 26
# 20. e
#     core type: Literal
#     sub-expressions:
# 21. 2 * pi * i * (delta - (l / 2^{t}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. *
#     core type: Literal
#     sub-expressions:
# 23. (2, pi, i, delta - (l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 40, 24, 25, 26
# 24. pi
#     core type: Literal
#     sub-expressions:
# 25. i
#     core type: Literal
#     sub-expressions:
# 26. delta - (l / 2^{t})
#     core type: Operation
#     operator: 27
#     operands: 28
# 27. +
#     core type: Literal
#     sub-expressions:
# 28. (delta, -(l / 2^{t}))
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 29. delta
#     core type: Literal
#     sub-expressions:
# 30. -(l / 2^{t})
#     core type: Operation
#     operator: 31
#     operand: 33
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. (l / 2^{t})
#     core type: ExprTuple
#     sub-expressions: 33
# 33. l / 2^{t}
#     core type: Operation
#     operator: 34
#     operands: 35
# 34. /
#     core type: Literal
#     sub-expressions:
# 35. (l, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. l
#     core type: Variable
#     sub-expressions:
# 37. 2^{t}
#     core type: Operation
#     operator: 38
#     operands: 39
# 38. Exp
#     core type: Literal
#     sub-expressions:
# 39. (2, t)
#     core type: ExprTuple
#     sub-expressions: 40, 41
# 40. 2
#     core type: Literal
#     sub-expressions:
# 41. t
#     core type: Literal
#     sub-expressions:
