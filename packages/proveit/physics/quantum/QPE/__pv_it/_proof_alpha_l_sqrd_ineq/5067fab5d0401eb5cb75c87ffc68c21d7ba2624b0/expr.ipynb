# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, l
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Mult(two_pow_t, delta_), Neg(l))
expr = ExprTuple(frac(Abs(Add(Add(Mult(two, pi, sub_expr1), pi), Neg(pi))), two), Mult(pi, Abs(sub_expr1)))
# Out:
# expr: (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2, pi * |(2^{t} * delta) - l|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\frac{\left|\left(\left(2 \cdot \pi \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)\right) + \pi\right) - \pi\right|}{2}, \pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2, pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 25
#    operands: 5
# 3. /
#    core type: Literal
#    sub-expressions:
# 4. (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|, 2)
#    core type: ExprTuple
#    sub-expressions: 6, 34
# 5. (pi, |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 19, 7
# 6. |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|
#    core type: Operation
#    operator: 9
#    operand: 11
# 7. |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 9
#    operand: 20
# 8. (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. Abs
#    core type: Literal
#    sub-expressions:
# 10. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 20
# 11. ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi
#     core type: Operation
#     operator: 21
#     operands: 12
# 12. ((2 * pi * ((2^{t} * delta) - l)) + pi, -pi)
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 13. (2 * pi * ((2^{t} * delta) - l)) + pi
#     core type: Operation
#     operator: 21
#     operands: 15
# 14. -pi
#     core type: Operation
#     operator: 27
#     operand: 19
# 15. (2 * pi * ((2^{t} * delta) - l), pi)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 16. (pi)
#     core type: ExprTuple
#     sub-expressions: 19
# 17. 2 * pi * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 25
#     operands: 18
# 18. (2, pi, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 34, 19, 20
# 19. pi
#     core type: Literal
#     sub-expressions:
# 20. (2^{t} * delta) - l
#     core type: Operation
#     operator: 21
#     operands: 22
# 21. +
#     core type: Literal
#     sub-expressions:
# 22. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 23. 2^{t} * delta
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. -l
#     core type: Operation
#     operator: 27
#     operand: 31
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. (l)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. 2^{t}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. delta
#     core type: Literal
#     sub-expressions:
# 31. l
#     core type: Variable
#     sub-expressions:
# 32. Exp
#     core type: Literal
#     sub-expressions:
# 33. (2, t)
#     core type: ExprTuple
#     sub-expressions: 34, 35
# 34. 2
#     core type: Literal
#     sub-expressions:
# 35. t
#     core type: Literal
#     sub-expressions:
