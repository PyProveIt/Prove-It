# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import l
from proveit.logic import Equals
from proveit.numbers import Abs, Add, Mult, Neg, frac, pi, two
from proveit.physics.quantum.QPE import delta_, two_pow_t

# %%
# build up the expression from sub-expressions
sub_expr1 = Add(Mult(two_pow_t, delta_), Neg(l))
expr = Equals(frac(Abs(Add(Add(Mult(two, pi, sub_expr1), pi), Neg(pi))), two), Mult(pi, Abs(sub_expr1)))
# Out:
# expr: (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2) = (pi * |(2^{t} * delta) - l|)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{\left|\left(\left(2 \cdot \pi \cdot \left(\left(2^{t} \cdot \delta\right) - l\right)\right) + \pi\right) - \pi\right|}{2} = \left(\pi \cdot \left|\left(2^{t} \cdot \delta\right) - l\right|\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2) = (pi * |(2^{t} * delta) - l|)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2, pi * |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi| / 2
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. pi * |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 27
#    operands: 7
# 5. /
#    core type: Literal
#    sub-expressions:
# 6. (|((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|, 2)
#    core type: ExprTuple
#    sub-expressions: 8, 36
# 7. (pi, |(2^{t} * delta) - l|)
#    core type: ExprTuple
#    sub-expressions: 21, 9
# 8. |((2 * pi * ((2^{t} * delta) - l)) + pi) - pi|
#    core type: Operation
#    operator: 11
#    operand: 13
# 9. |(2^{t} * delta) - l|
#    core type: Operation
#    operator: 11
#    operand: 22
# 10. (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. Abs
#     core type: Literal
#     sub-expressions:
# 12. ((2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 22
# 13. ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi
#     core type: Operation
#     operator: 23
#     operands: 14
# 14. ((2 * pi * ((2^{t} * delta) - l)) + pi, -pi)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. (2 * pi * ((2^{t} * delta) - l)) + pi
#     core type: Operation
#     operator: 23
#     operands: 17
# 16. -pi
#     core type: Operation
#     operator: 29
#     operand: 21
# 17. (2 * pi * ((2^{t} * delta) - l), pi)
#     core type: ExprTuple
#     sub-expressions: 19, 21
# 18. (pi)
#     core type: ExprTuple
#     sub-expressions: 21
# 19. 2 * pi * ((2^{t} * delta) - l)
#     core type: Operation
#     operator: 27
#     operands: 20
# 20. (2, pi, (2^{t} * delta) - l)
#     core type: ExprTuple
#     sub-expressions: 36, 21, 22
# 21. pi
#     core type: Literal
#     sub-expressions:
# 22. (2^{t} * delta) - l
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (2^{t} * delta, -l)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. 2^{t} * delta
#     core type: Operation
#     operator: 27
#     operands: 28
# 26. -l
#     core type: Operation
#     operator: 29
#     operand: 33
# 27. *
#     core type: Literal
#     sub-expressions:
# 28. (2^{t}, delta)
#     core type: ExprTuple
#     sub-expressions: 31, 32
# 29. -
#     core type: Literal
#     sub-expressions:
# 30. (l)
#     core type: ExprTuple
#     sub-expressions: 33
# 31. 2^{t}
#     core type: Operation
#     operator: 34
#     operands: 35
# 32. delta
#     core type: Literal
#     sub-expressions:
# 33. l
#     core type: Variable
#     sub-expressions:
# 34. Exp
#     core type: Literal
#     sub-expressions:
# 35. (2, t)
#     core type: ExprTuple
#     sub-expressions: 36, 37
# 36. 2
#     core type: Literal
#     sub-expressions:
# 37. t
#     core type: Literal
#     sub-expressions:
