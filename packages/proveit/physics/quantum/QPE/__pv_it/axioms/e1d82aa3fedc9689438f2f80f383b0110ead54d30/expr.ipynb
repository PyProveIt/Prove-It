# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import p_k, phase_, t_

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Conditional(Equals(p_k, Mult(frac(one, sqrt(two)), Add(ket0, Mult(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1)))), InSet(k, Interval(zero, Add(t_, Neg(one))))))
# Out:
# expr: k -> {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{p_{k} = \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}} \cdot \lvert 1 \rangle\right)\right)\right) \textrm{ if } k \in \{0~\ldotp \ldotp~t - 1\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.
#    core type: Lambda
#    parameter: 54
#    body: 1
# 1. {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in {0 .. t - 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (p_{k}, (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {0 .. t - 1})
#    core type: ExprTuple
#    sub-expressions: 54, 10
# 8. p_{k}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))
# ...
