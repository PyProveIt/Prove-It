# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k
from proveit.numbers import Exp, Mult, e, i, pi, two
from proveit.physics.quantum import ket1
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1)
# Out:
# expr: (e^{2 * pi * i * phase * 2^{k}}, |1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}}, \lvert 1 \rangle\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (e^{2 * pi * i * phase * 2^{k}}, |1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. e^{2 * pi * i * phase * 2^{k}}
#    core type: Operation
#    operator: 15
#    operands: 3
# 2. |1〉
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. (e, 2 * pi * i * phase * 2^{k})
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. KET
#    core type: Literal
#    sub-expressions:
# 5. (1)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. e
#    core type: Literal
#    sub-expressions:
# 7. 2 * pi * i * phase * 2^{k}
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. 1
#    core type: Literal
#    sub-expressions:
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (2, pi, i, phase, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 17, 11, 12, 13, 14
# 11. pi
#     core type: Literal
#     sub-expressions:
# 12. i
#     core type: Literal
#     sub-expressions:
# 13. phase
#     core type: Literal
#     sub-expressions:
# 14. 2^{k}
#     core type: Operation
#     operator: 15
#     operands: 16
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (2, k)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 17. 2
#     core type: Literal
#     sub-expressions:
# 18. k
#     core type: Variable
#     sub-expressions:
