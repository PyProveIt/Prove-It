# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, k
from proveit.linalg import TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Interval, Neg, one
from proveit.physics.quantum.QPE import p_k, psi_k, psi_next, t_

# %%
# build up the expression from sub-expressions
expr = Lambda(k, Conditional(Equals(psi_next, TensorProd(p_k, psi_k)), InSet(k, Interval(one, Add(t_, Neg(one))))))
# Out:
# expr: k -> {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# k \mapsto \left\{\psi_{k + 1} = \left(p_{k} {\otimes} \psi_{k}\right) \textrm{ if } k \in \{1~\ldotp \ldotp~t - 1\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. k -> {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.
#    core type: Lambda
#    parameter: 28
#    body: 1
# 1. {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. psi_{k + 1} = (p_{k} otimes psi_{k})
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. k in {1 .. t - 1}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (psi_{k + 1}, p_{k} otimes psi_{k})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (k, {1 .. t - 1})
#    core type: ExprTuple
#    sub-expressions: 28, 10
# 8. psi_{k + 1}
#    core type: Operation
#    operator: 22
#    operands: 11
# 9. p_{k} otimes psi_{k}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. {1 .. t - 1}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 27, 16
# 12. otimes
#     core type: Literal
#     sub-expressions:
# 13. (p_{k}, psi_{k})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (1, t - 1)
#     core type: ExprTuple
#     sub-expressions: 33, 19
# 16. k + 1
#     core type: Operation
#     operator: 24
#     operands: 20
# 17. p_{k}
#     core type: Operation
#     operator: 22
#     operands: 21
# 18. psi_{k}
#     core type: Operation
#     operator: 22
#     operands: 23
# 19. t - 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 20. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 28, 33
# 21. (p, k)
#     core type: ExprTuple
#     sub-expressions: 26, 28
# 22. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 23. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 26. p
#     core type: Literal
#     sub-expressions:
# 27. psi
#     core type: Literal
#     sub-expressions:
# 28. k
#     core type: Variable
#     sub-expressions:
# 29. t
#     core type: Literal
#     sub-expressions:
# 30. -1
#     core type: Operation
#     operator: 31
#     operand: 33
# 31. -
#     core type: Literal
#     sub-expressions:
# 32. (1)
#     core type: ExprTuple
#     sub-expressions: 33
# 33. 1
#     core type: Literal
#     sub-expressions:
