# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Mult.html">Mult</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.numbers import Add, Exp, Mult, e, frac, i, one, pi, sqrt, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
expr = Mult(frac(one, sqrt(two)), Add(ket0, Mult(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1)))
# Out:
# expr: (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}} \cdot \lvert 1 \rangle\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))
#    core type: Operation
#    operator: 25
#    operands: 1
# 1. (1 / sqrt(2), |0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. 1 / sqrt(2)
#    core type: Operation
#    operator: 17
#    operands: 4
# 3. |0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (1, sqrt(2))
#    core type: ExprTuple
#    sub-expressions: 24, 7
# 5. +
#    core type: Literal
#    sub-expressions:
# 6. (|0〉, e^{2 * pi * i * phase * 2^{k}} * |1〉)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. sqrt(2)
#    core type: Operation
#    operator: 31
#    operands: 10
# 8. |0〉
#    core type: Operation
#    operator: 20
#    operand: 14
# 9. e^{2 * pi * i * phase * 2^{k}} * |1〉
#    core type: Operation
#    operator: 25
#    operands: 12
# 10. (2, 1 / 2)
#     core type: ExprTuple
#     sub-expressions: 33, 13
# 11. (0)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. (e^{2 * pi * i * phase * 2^{k}}, |1〉)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 13. 1 / 2
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. 0
#     core type: Literal
#     sub-expressions:
# 15. e^{2 * pi * i * phase * 2^{k}}
#     core type: Operation
#     operator: 31
#     operands: 19
# 16. |1〉
#     core type: Operation
#     operator: 20
#     operand: 24
# 17. /
#     core type: Literal
#     sub-expressions:
# 18. (1, 2)
#     core type: ExprTuple
#     sub-expressions: 24, 33
# 19. (e, 2 * pi * i * phase * 2^{k})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 20. KET
#     core type: Literal
#     sub-expressions:
# 21. (1)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. e
#     core type: Literal
#     sub-expressions:
# 23. 2 * pi * i * phase * 2^{k}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. 1
#     core type: Literal
#     sub-expressions:
# 25. *
#     core type: Literal
#     sub-expressions:
# 26. (2, pi, i, phase, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 33, 27, 28, 29, 30
# 27. pi
#     core type: Literal
#     sub-expressions:
# 28. i
#     core type: Literal
#     sub-expressions:
# 29. phase
#     core type: Literal
#     sub-expressions:
# 30. 2^{k}
#     core type: Operation
#     operator: 31
#     operands: 32
# 31. Exp
#     core type: Literal
#     sub-expressions:
# 32. (2, k)
#     core type: ExprTuple
#     sub-expressions: 33, 34
# 33. 2
#     core type: Literal
#     sub-expressions:
# 34. k
#     core type: Variable
#     sub-expressions:
