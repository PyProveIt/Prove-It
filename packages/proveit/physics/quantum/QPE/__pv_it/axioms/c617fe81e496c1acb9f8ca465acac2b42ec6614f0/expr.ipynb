# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Add.html">Add</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.numbers import Add, Exp, Mult, e, i, pi, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
expr = Add(ket0, Mult(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1))
# Out:
# expr: |0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}} \cdot \lvert 1 \rangle\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: subtraction_positions
# description: Position(s) to use subtraction notation instead of adding the negation at the specified indices
# default: ()
# current value: ()
# related methods: ('with_subtraction_at', 'subtraction_positions')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. |0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. +
#    core type: Literal
#    sub-expressions:
# 2. (|0〉, e^{2 * pi * i * phase * 2^{k}} * |1〉)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. |0〉
#    core type: Operation
#    operator: 11
#    operand: 7
# 4. e^{2 * pi * i * phase * 2^{k}} * |1〉
#    core type: Operation
#    operator: 16
#    operands: 6
# 5. (0)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (e^{2 * pi * i * phase * 2^{k}}, |1〉)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. 0
#    core type: Literal
#    sub-expressions:
# 8. e^{2 * pi * i * phase * 2^{k}}
#    core type: Operation
#    operator: 22
#    operands: 10
# 9. |1〉
#    core type: Operation
#    operator: 11
#    operand: 15
# 10. (e, 2 * pi * i * phase * 2^{k})
#     core type: ExprTuple
#     sub-expressions: 13, 14
# 11. KET
#     core type: Literal
#     sub-expressions:
# 12. (1)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. e
#     core type: Literal
#     sub-expressions:
# 14. 2 * pi * i * phase * 2^{k}
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (2, pi, i, phase, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 24, 18, 19, 20, 21
# 18. pi
#     core type: Literal
#     sub-expressions:
# 19. i
#     core type: Literal
#     sub-expressions:
# 20. phase
#     core type: Literal
#     sub-expressions:
# 21. 2^{k}
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (2, k)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. 2
#     core type: Literal
#     sub-expressions:
# 25. k
#     core type: Variable
#     sub-expressions:
