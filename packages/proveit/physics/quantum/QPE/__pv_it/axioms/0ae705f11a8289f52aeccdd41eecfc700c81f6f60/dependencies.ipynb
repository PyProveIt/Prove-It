# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#success_def">success_def</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import success_def

# %%
# %dependencies success_def
# Out:
# <h3>Theorems/conjectures that depend directly on success_def</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../_theory_nbs_/proofs/success_prob_is_real/thm_proof.ipynb">proveit.physics.quantum.QPE.success_prob_is_real</a></dt><dd><a class="ProveItLink" href="../../theorems/e40ad87a8e92afcbb828014026eeff6ed4784f2d0/expr.ipynb"><img src="../../theorems/e40ad87a8e92afcbb828014026eeff6ed4784f2d0/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# </dl>
