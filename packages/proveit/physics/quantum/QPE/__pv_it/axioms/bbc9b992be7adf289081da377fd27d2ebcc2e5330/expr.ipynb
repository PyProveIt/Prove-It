# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, k
from proveit.numbers import Exp, Mult, e, i, pi, two
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ket0, Mult(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1))
# Out:
# expr: (|0〉, e^{2 * pi * i * phase * 2^{k}} * |1〉)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\lvert 0 \rangle, \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}} \cdot \lvert 1 \rangle\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (|0〉, e^{2 * pi * i * phase * 2^{k}} * |1〉)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. |0〉
#    core type: Operation
#    operator: 9
#    operand: 5
# 2. e^{2 * pi * i * phase * 2^{k}} * |1〉
#    core type: Operation
#    operator: 14
#    operands: 4
# 3. (0)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (e^{2 * pi * i * phase * 2^{k}}, |1〉)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 5. 0
#    core type: Literal
#    sub-expressions:
# 6. e^{2 * pi * i * phase * 2^{k}}
#    core type: Operation
#    operator: 20
#    operands: 8
# 7. |1〉
#    core type: Operation
#    operator: 9
#    operand: 13
# 8. (e, 2 * pi * i * phase * 2^{k})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. KET
#    core type: Literal
#    sub-expressions:
# 10. (1)
#     core type: ExprTuple
#     sub-expressions: 13
# 11. e
#     core type: Literal
#     sub-expressions:
# 12. 2 * pi * i * phase * 2^{k}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (2, pi, i, phase, 2^{k})
#     core type: ExprTuple
#     sub-expressions: 22, 16, 17, 18, 19
# 16. pi
#     core type: Literal
#     sub-expressions:
# 17. i
#     core type: Literal
#     sub-expressions:
# 18. phase
#     core type: Literal
#     sub-expressions:
# 19. 2^{k}
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (2, k)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. 2
#     core type: Literal
#     sub-expressions:
# 23. k
#     core type: Variable
#     sub-expressions:
