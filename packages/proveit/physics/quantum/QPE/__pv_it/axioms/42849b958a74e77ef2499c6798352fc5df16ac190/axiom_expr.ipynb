# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#psi_k_def">psi_k_def</a> of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.physics.quantum.QPE import psi_k_def

# %%
# check that the built expression is the same as the stored expression
assert psi_k_def.expr == stored_expr
assert psi_k_def.expr._style_id == stored_expr._style_id
print("Passed sanity check: psi_k_def matches stored_expr")
# Out:
# Passed sanity check: psi_k_def matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(psi_k_def.latex())
# Out:
# \vdash \forall_{k \in \{1~\ldotp \ldotp~t - 1\}}~\left(\psi_{k + 1} = \left(p_{k} {\otimes} \psi_{k}\right)\right)

# %%
psi_k_def.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
psi_k_def.expr_info()
# Out:
# 0. forall_{k in {1 .. t - 1}} (psi_{k + 1} = (p_{k} otimes psi_{k}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.
#    core type: Lambda
#    parameter: 31
#    body: 4
# 4. {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. psi_{k + 1} = (p_{k} otimes psi_{k})
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. k in {1 .. t - 1}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (psi_{k + 1}, p_{k} otimes psi_{k})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (k, {1 .. t - 1})
#     core type: ExprTuple
# ...
