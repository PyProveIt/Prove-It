# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_axioms_.ipynb#psi_k_def">psi_k_def</a> of type <a href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official axiom from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.linalg import TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Interval, Neg, one
from proveit.physics.quantum.QPE import p_k, psi_k, psi_next, t_

# %%
# build up the expression from sub-expressions
expr = Forall([k], Equals(psi_next, TensorProd(p_k, psi_k)), domain = Interval(one, Add(t_, Neg(one))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: psi_k_def matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
expr.style_options()

# %%
# display the expression information
expr.expr_info()
