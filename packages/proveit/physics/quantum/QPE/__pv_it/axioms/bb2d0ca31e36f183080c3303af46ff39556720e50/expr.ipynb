# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.numbers.Exp.html">Exp</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.numbers import Exp, Mult, e, i, pi, two
from proveit.physics.quantum.QPE import phase_

# %%
# build up the expression from sub-expressions
expr = Exp(e, Mult(two, pi, i, phase_, Exp(two, k)))
# Out:
# expr: e^{2 * pi * i * phase * 2^{k}}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}}

# %%
expr.style_options()
# Out:
# style name: exponent
# description: 'raised': exponent as a superscript; 'radical': using a radical sign
# default: raised
# current value: raised
# related methods: ('with_radical', 'without_radical')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. e^{2 * pi * i * phase * 2^{k}}
#    core type: Operation
#    operator: 10
#    operands: 1
# 1. (e, 2 * pi * i * phase * 2^{k})
#    core type: ExprTuple
#    sub-expressions: 2, 3
# 2. e
#    core type: Literal
#    sub-expressions:
# 3. 2 * pi * i * phase * 2^{k}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. *
#    core type: Literal
#    sub-expressions:
# 5. (2, pi, i, phase, 2^{k})
#    core type: ExprTuple
#    sub-expressions: 12, 6, 7, 8, 9
# 6. pi
#    core type: Literal
#    sub-expressions:
# 7. i
#    core type: Literal
#    sub-expressions:
# 8. phase
#    core type: Literal
#    sub-expressions:
# 9. 2^{k}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (2, k)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 2
#     core type: Literal
#     sub-expressions:
# 13. k
#     core type: Variable
#     sub-expressions:
