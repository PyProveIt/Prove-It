# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit.linalg import TensorProd
from proveit.logic import Equals
from proveit.physics.quantum.QPE import p_k, psi_k, psi_next

# %%
# build up the expression from sub-expressions
expr = Equals(psi_next, TensorProd(p_k, psi_k))
# Out:
# expr: psi_{k + 1} = (p_{k} otimes psi_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \psi_{k + 1} = \left(p_{k} {\otimes} \psi_{k}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. psi_{k + 1} = (p_{k} otimes psi_{k})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (psi_{k + 1}, p_{k} otimes psi_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. psi_{k + 1}
#    core type: Operation
#    operator: 14
#    operands: 5
# 4. p_{k} otimes psi_{k}
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (psi, k + 1)
#    core type: ExprTuple
#    sub-expressions: 18, 8
# 6. otimes
#    core type: Literal
#    sub-expressions:
# 7. (p_{k}, psi_{k})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. k + 1
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. p_{k}
#    core type: Operation
#    operator: 14
#    operands: 13
# 10. psi_{k}
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. +
#     core type: Literal
#     sub-expressions:
# 12. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 19, 16
# 13. (p, k)
#     core type: ExprTuple
#     sub-expressions: 17, 19
# 14. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 15. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. p
#     core type: Literal
#     sub-expressions:
# 18. psi
#     core type: Literal
#     sub-expressions:
# 19. k
#     core type: Variable
#     sub-expressions:
