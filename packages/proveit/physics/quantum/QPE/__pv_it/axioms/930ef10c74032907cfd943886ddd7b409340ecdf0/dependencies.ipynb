# %% [markdown]
# Axiom Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>.<a class="ProveItLink" href="../../../_axioms_.ipynb#psi_1_equals_p_0">psi_1_equals_p_0</a>

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.physics.quantum.QPE import psi_1_equals_p_0

# %%
# %dependencies psi_1_equals_p_0
# Out:
# <h3>No theorems/conjectures depend upon psi_1_equals_p_0</h3>
