# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import k
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Exp, Interval, Mult, Neg, e, frac, i, one, pi, sqrt, two, zero
from proveit.physics.quantum import ket0, ket1
from proveit.physics.quantum.QPE import p_k, phase_, t_

# %%
# build up the expression from sub-expressions
expr = Forall([k], Equals(p_k, Mult(frac(one, sqrt(two)), Add(ket0, Mult(Exp(e, Mult(two, pi, i, phase_, Exp(two, k))), ket1)))), domain = Interval(zero, Add(t_, Neg(one))))
# Out:
# expr: forall_{k in {0 .. t - 1}} (p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{k \in \{0~\ldotp \ldotp~t - 1\}}~\left(p_{k} = \left(\frac{1}{\sqrt{2}} \cdot \left(\lvert 0 \rangle + \left(\mathsf{e}^{2 \cdot \pi \cdot \mathsf{i} \cdot \varphi \cdot 2^{k}} \cdot \lvert 1 \rangle\right)\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{k in {0 .. t - 1}} (p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (k -> {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. k -> {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.
#    core type: Lambda
#    parameter: 57
#    body: 4
# 4. {p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉))) if k in {0 .. t - 1}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. p_{k} = ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * phase * 2^{k}} * |1〉)))
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. k in {0 .. t - 1}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. =
#    core type: Literal
#    sub-expressions:
# ...
