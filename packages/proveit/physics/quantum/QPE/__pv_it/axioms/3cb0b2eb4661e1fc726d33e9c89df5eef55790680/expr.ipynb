# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, k
from proveit.linalg import TensorProd
from proveit.logic import Equals, InSet
from proveit.numbers import Add, Interval, Neg, one
from proveit.physics.quantum.QPE import p_k, psi_k, psi_next, t_

# %%
# build up the expression from sub-expressions
expr = Conditional(Equals(psi_next, TensorProd(p_k, psi_k)), InSet(k, Interval(one, Add(t_, Neg(one)))))
# Out:
# expr: {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\psi_{k + 1} = \left(p_{k} {\otimes} \psi_{k}\right) \textrm{ if } k \in \{1~\ldotp \ldotp~t - 1\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {psi_{k + 1} = (p_{k} otimes psi_{k}) if k in {1 .. t - 1}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. psi_{k + 1} = (p_{k} otimes psi_{k})
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. k in {1 .. t - 1}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. =
#    core type: Literal
#    sub-expressions:
# 4. (psi_{k + 1}, p_{k} otimes psi_{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (k, {1 .. t - 1})
#    core type: ExprTuple
#    sub-expressions: 27, 9
# 7. psi_{k + 1}
#    core type: Operation
#    operator: 21
#    operands: 10
# 8. p_{k} otimes psi_{k}
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. {1 .. t - 1}
#    core type: Operation
#    operator: 13
#    operands: 14
# 10. (psi, k + 1)
#     core type: ExprTuple
#     sub-expressions: 26, 15
# 11. otimes
#     core type: Literal
#     sub-expressions:
# 12. (p_{k}, psi_{k})
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (1, t - 1)
#     core type: ExprTuple
#     sub-expressions: 32, 18
# 15. k + 1
#     core type: Operation
#     operator: 23
#     operands: 19
# 16. p_{k}
#     core type: Operation
#     operator: 21
#     operands: 20
# 17. psi_{k}
#     core type: Operation
#     operator: 21
#     operands: 22
# 18. t - 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 19. (k, 1)
#     core type: ExprTuple
#     sub-expressions: 27, 32
# 20. (p, k)
#     core type: ExprTuple
#     sub-expressions: 25, 27
# 21. SUB_INDEXED
#     core type: Literal
#     sub-expressions:
# 22. (psi, k)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 25. p
#     core type: Literal
#     sub-expressions:
# 26. psi
#     core type: Literal
#     sub-expressions:
# 27. k
#     core type: Variable
#     sub-expressions:
# 28. t
#     core type: Literal
#     sub-expressions:
# 29. -1
#     core type: Operation
#     operator: 30
#     operand: 32
# 30. -
#     core type: Literal
#     sub-expressions:
# 31. (1)
#     core type: ExprTuple
#     sub-expressions: 32
# 32. 1
#     core type: Literal
#     sub-expressions:
