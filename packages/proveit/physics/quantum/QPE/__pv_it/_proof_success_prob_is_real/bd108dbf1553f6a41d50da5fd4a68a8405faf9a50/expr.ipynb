# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, eps
from proveit.numbers import Add, LessEq, ModAbs, Neg, Real
from proveit.physics.quantum.QPE import b_, m_, two_pow_t
from proveit.statistics import Prob

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Prob(LessEq(ModAbs(Add(m_, Neg(b_)), two_pow_t), eps), m_), Real)
# Out:
# expr: (Pr_{m}[|m - b|_{mod 2^{t}} <= eps], Real)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(Pr_{m}[\left|m - b\right|_{\textup{mod}\thinspace 2^{t}} \leq \varepsilon], \mathbb{R}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Pr_{m}[|m - b|_{mod 2^{t}} <= eps], Real)
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Pr_{m}[|m - b|_{mod 2^{t}} <= eps]
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. Real
#    core type: Literal
#    sub-expressions:
# 3. PROB
#    core type: Literal
#    sub-expressions:
# 4. (|m - b|_{mod 2^{t}} <= eps, m)
#    core type: ExprTuple
#    sub-expressions: 5, 18
# 5. |m - b|_{mod 2^{t}} <= eps
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. <=
#    core type: Literal
#    sub-expressions:
# 7. (|m - b|_{mod 2^{t}}, eps)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. |m - b|_{mod 2^{t}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. eps
#    core type: Variable
#    sub-expressions:
# 10. ModAbs
#     core type: Literal
#     sub-expressions:
# 11. (m - b, 2^{t})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. m - b
#     core type: Operation
#     operator: 14
#     operands: 15
# ...
