# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, Variable
from proveit.logic import InSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Lambda(sub_expr1, Conditional(InSet(sub_expr1, Integer), InSet(sub_expr1, pos_domain)))
# Out:
# expr: _a -> {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# {_{-}a} \mapsto \left\{{_{-}a} \in \mathbb{Z} \textrm{ if } {_{-}a} \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. _a -> {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. _a in Integer
#    core type: Operation
#    operator: 5
#    operands: 4
# 3. _a in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (_a, Integer)
#    core type: ExprTuple
#    sub-expressions: 8, 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (_a, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. Integer
#    core type: Literal
#    sub-expressions:
# 8. _a
#    core type: Variable
#    sub-expressions:
# 9. {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. eps + 1
#     core type: Operation
#     operator: 20
#     operands: 14
# 13. 2^{t - 1}
#     core type: Operation
#     operator: 15
#     operands: 16
# 14. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 17, 26
# 15. Exp
#     core type: Literal
#     sub-expressions:
# 16. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. eps
#     core type: Variable
#     sub-expressions:
# 18. 2
#     core type: Literal
#     sub-expressions:
# 19. t - 1
#     core type: Operation
#     operator: 20
#     operands: 21
# 20. +
#     core type: Literal
#     sub-expressions:
# 21. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 22. t
#     core type: Literal
#     sub-expressions:
# 23. -1
#     core type: Operation
#     operator: 24
#     operand: 26
# 24. -
#     core type: Literal
#     sub-expressions:
# 25. (1)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. 1
#     core type: Literal
#     sub-expressions:
