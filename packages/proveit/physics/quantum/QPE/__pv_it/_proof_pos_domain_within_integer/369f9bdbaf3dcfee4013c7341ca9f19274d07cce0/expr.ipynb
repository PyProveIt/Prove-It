# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.physics.quantum.QPE</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Variable
from proveit.logic import Forall, InSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import pos_domain

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Forall([sub_expr1], InSet(sub_expr1, Integer), domain = pos_domain)
# Out:
# expr: forall_{_a in {eps + 1 .. 2^{t - 1}}} (_a in Integer)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{{_{-}a} \in \{\varepsilon + 1~\ldotp \ldotp~2^{t - 1}\}}~\left({_{-}a} \in \mathbb{Z}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{_a in {eps + 1 .. 2^{t - 1}}} (_a in Integer)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (_a -> {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. _a -> {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Lambda
#    parameter: 11
#    body: 4
# 4. {_a in Integer if _a in {eps + 1 .. 2^{t - 1}}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. _a in Integer
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. _a in {eps + 1 .. 2^{t - 1}}
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (_a, Integer)
#    core type: ExprTuple
#    sub-expressions: 11, 10
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (_a, {eps + 1 .. 2^{t - 1}})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. Integer
#     core type: Literal
#     sub-expressions:
# 11. _a
#     core type: Variable
#     sub-expressions:
# 12. {eps + 1 .. 2^{t - 1}}
#     core type: Operation
#     operator: 13
#     operands: 14
# 13. Interval
#     core type: Literal
#     sub-expressions:
# 14. (eps + 1, 2^{t - 1})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. eps + 1
#     core type: Operation
#     operator: 23
#     operands: 17
# 16. 2^{t - 1}
#     core type: Operation
#     operator: 18
#     operands: 19
# 17. (eps, 1)
#     core type: ExprTuple
#     sub-expressions: 20, 29
# 18. Exp
#     core type: Literal
#     sub-expressions:
# 19. (2, t - 1)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 20. eps
#     core type: Variable
#     sub-expressions:
# 21. 2
#     core type: Literal
#     sub-expressions:
# 22. t - 1
#     core type: Operation
#     operator: 23
#     operands: 24
# 23. +
#     core type: Literal
#     sub-expressions:
# 24. (t, -1)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. t
#     core type: Literal
#     sub-expressions:
# 26. -1
#     core type: Operation
#     operator: 27
#     operand: 29
# 27. -
#     core type: Literal
#     sub-expressions:
# 28. (1)
#     core type: ExprTuple
#     sub-expressions: 29
# 29. 1
#     core type: Literal
#     sub-expressions:
