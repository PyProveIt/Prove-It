# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#distribute_tensor_prod_over_sum">distribute_tensor_prod_over_sum</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving distribute_tensor_prod_over_sum
# Out:
# distribute_tensor_prod_over_sum: forall_{i, j, k in Natural} [forall_{x_{1}, ..x_{_a}.., x_{i}, y_{1}, ..y_{_a}.., y_{j}, z_{1}, ..z_{_a}.., z_{k}} ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes (y_{1} + ..y_{_a}.. + y_{j}) otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) = ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) + ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).. + (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})))]
