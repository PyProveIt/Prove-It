# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#doubly_scaled_as_singly_scaled">doubly_scaled_as_singly_scaled</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving doubly_scaled_as_singly_scaled
# Out:
# doubly_scaled_as_singly_scaled: forall_{x} [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))]
