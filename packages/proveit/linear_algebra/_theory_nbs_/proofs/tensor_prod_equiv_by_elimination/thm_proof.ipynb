# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#tensor_prod_equiv_by_elimination">tensor_prod_equiv_by_elimination</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tensor_prod_equiv_by_elimination
# Out:
# tensor_prod_equiv_by_elimination: forall_{m, n in Natural} [forall_{a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}} (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y))]
