# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#distribute_tensor_prod_over_summation">distribute_tensor_prod_over_summation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving distribute_tensor_prod_over_summation
# Out:
# distribute_tensor_prod_over_summation: forall_{m, n in Natural} [forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))]
