# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#int_pow_s_uclosure">int_pow_s_uclosure</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving int_pow_s_uclosure
# Out:
# int_pow_s_uclosure: forall_{n, k in NaturalPos} [forall_{U in SU(n)} (U^{k} in SU(n))]
