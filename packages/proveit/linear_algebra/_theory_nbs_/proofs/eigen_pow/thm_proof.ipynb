# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#eigen_pow">eigen_pow</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving eigen_pow
# Out:
# eigen_pow: forall_{k in NaturalPos} [forall_{b in Complex} [forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))]]
