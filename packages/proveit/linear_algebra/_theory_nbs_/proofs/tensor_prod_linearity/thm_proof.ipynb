# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#tensor_prod_linearity">tensor_prod_linearity</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving tensor_prod_linearity
# Out:
# tensor_prod_linearity: forall_{a, b} [forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))]
