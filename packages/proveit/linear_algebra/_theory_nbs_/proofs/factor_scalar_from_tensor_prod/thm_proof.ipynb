# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../theory.ipynb">linear_algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#factor_scalar_from_tensor_prod">factor_scalar_from_tensor_prod</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving factor_scalar_from_tensor_prod
# Out:
# factor_scalar_from_tensor_prod: forall_{m, n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]]
