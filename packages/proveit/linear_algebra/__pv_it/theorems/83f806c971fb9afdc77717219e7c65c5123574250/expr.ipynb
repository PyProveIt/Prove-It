# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, alpha, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import ScalarProd, TensorProd
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = Lambda([x_1_to_m, y, z_1_to_n], Forall([alpha], Equals(TensorProd(x_1_to_m, ScalarProd(alpha, y), z_1_to_n), ScalarProd(alpha, TensorProd(x_1_to_m, y, z_1_to_n)))))
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}) -> [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{m}, y, z_{1}, \ldots, z_{n}\right) \mapsto \left[\forall_{\alpha}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \left(\alpha \thinspace y\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \left(\alpha \thinspace \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}) -> [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]
#    core type: Lambda
#    parameters: 17\n   body: 1
# 1. forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#    core type: Operation
#    operator: 2
#    operand: 4
# 2. forall
#    core type: Literal
#    sub-expressions:
# 3. (alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))))
#    core type: ExprTuple
#    sub-expressions: 4
# ...
