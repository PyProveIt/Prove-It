# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, Implies
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
expr = Forall([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x))))
# Out:
# expr: forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{A, x}~\left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Lambda
#    parameters: 16\n   body: 4
# 4. ((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =>
#    core type: Literal
#    sub-expressions:
# 6. ((A . x) = (b * x), (A^{k} . x) = (b^{k} * x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. (A . x) = (b * x)
#    core type: Operation
#    operator: 10
#    operands: 9
# 8. (A^{k} . x) = (b^{k} * x)
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. (A . x, b * x)
#    core type: ExprTuple
#    sub-expressions: 12, 13
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (A^{k} . x, b^{k} * x)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. A . x
#     core type: Operation
#     operator: 18
#     operands: 16
# 13. b * x
#     core type: Operation
#     operator: 20
#     operands: 17
# 14. A^{k} . x
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. b^{k} * x
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. (A, x)
#     core type: ExprTuple
#     sub-expressions: 28, 24
# 17. (b, x)
#     core type: ExprTuple
#     sub-expressions: 29, 24
# 18. .
#     core type: Literal
#     sub-expressions:
# 19. (A^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 20. *
#     core type: Literal
#     sub-expressions:
# 21. (b^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. A^{k}
#     core type: Operation
#     operator: 26
#     operands: 25
# 23. b^{k}
#     core type: Operation
#     operator: 26
#     operands: 27
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. (A, k)
#     core type: ExprTuple
#     sub-expressions: 28, 30
# 26. Exp
#     core type: Literal
#     sub-expressions:
# 27. (b, k)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. A
#     core type: Variable
#     sub-expressions:
# 29. b
#     core type: Variable
#     sub-expressions:
# 30. k
#     core type: Variable
#     sub-expressions:
