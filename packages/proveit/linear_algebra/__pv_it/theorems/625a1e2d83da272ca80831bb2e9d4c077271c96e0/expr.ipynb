# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Lambda, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Implies
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
expr = Lambda([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x))))
# Out:
# expr: (A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(A, x\right) \mapsto \left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Lambda
#    parameters: 13\n   body: 1
# 1. ((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))
#    core type: Operation
#    operator: 2
#    operands: 3
# 2. =>
#    core type: Literal
#    sub-expressions:
# 3. ((A . x) = (b * x), (A^{k} . x) = (b^{k} * x))
#    core type: ExprTuple
#    sub-expressions: 4, 5
# 4. (A . x) = (b * x)
#    core type: Operation
#    operator: 7
#    operands: 6
# 5. (A^{k} . x) = (b^{k} * x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. (A . x, b * x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (A^{k} . x, b^{k} * x)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. A . x
#    core type: Operation
#    operator: 15
#    operands: 13
# 10. b * x
#     core type: Operation
#     operator: 17
#     operands: 14
# 11. A^{k} . x
#     core type: Operation
#     operator: 15
# ...
