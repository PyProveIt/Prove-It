# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, S, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = ExprTuple(TensorProd(x_1_to_m, Sum(sub_expr1, fy, domain = S), z_1_to_n), Sum(sub_expr1, TensorProd(x_1_to_m, fy, z_1_to_n), domain = S))
# Out:
# expr: (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \sum_{y \in S}~f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}, \sum_{y \in S}~\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 13
#    operands: 3
# 2. Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#    core type: Operation
#    operator: 7
#    operand: 6
# 3. (x_{1}, ..x_{_a}.., x_{m}, Sum_{y in S} f(y), z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 16, 5, 18
# 4. (y -> {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. Sum_{y in S} f(y)
#    core type: Operation
#    operator: 7
# ...
