# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Implies
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
expr = Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))
# Out:
# expr: ((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. ((A . x) = (b * x), (A^{k} . x) = (b^{k} * x))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (A . x) = (b * x)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. (A^{k} . x) = (b^{k} * x)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (A . x, b * x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. =
#    core type: Literal
#    sub-expressions:
# 7. (A^{k} . x, b^{k} * x)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. A . x
#    core type: Operation
#    operator: 14
#    operands: 12
# 9. b * x
#    core type: Operation
#    operator: 16
#    operands: 13
# 10. A^{k} . x
#     core type: Operation
#     operator: 14
#     operands: 15
# 11. b^{k} * x
#     core type: Operation
#     operator: 16
#     operands: 17
# 12. (A, x)
#     core type: ExprTuple
#     sub-expressions: 24, 20
# 13. (b, x)
#     core type: ExprTuple
#     sub-expressions: 25, 20
# 14. .
#     core type: Literal
#     sub-expressions:
# 15. (A^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 18, 20
# 16. *
#     core type: Literal
#     sub-expressions:
# 17. (b^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. A^{k}
#     core type: Operation
#     operator: 22
#     operands: 21
# 19. b^{k}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. (A, k)
#     core type: ExprTuple
#     sub-expressions: 24, 26
# 22. Exp
#     core type: Literal
#     sub-expressions:
# 23. (b, k)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 24. A
#     core type: Variable
#     sub-expressions:
# 25. b
#     core type: Variable
#     sub-expressions:
# 26. k
#     core type: Variable
#     sub-expressions:
