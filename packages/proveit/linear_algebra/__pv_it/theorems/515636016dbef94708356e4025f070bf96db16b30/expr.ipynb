# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))), InSet(b, Complex))
# Out:
# expr: {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{A, x}~\left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right) \textrm{ if } b \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. b in Complex
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 34, 8
# 7. (A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Lambda
#    parameters: 21\n   body: 9
# 8. Complex
#    core type: Literal
#    sub-expressions:
# 9. ((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =>
#     core type: Literal
# ...
