# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, k, n
from proveit.linear_algebra import SU
from proveit.logic import Forall, InSet
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
sub_expr1 = SU(n)
expr = Forall([U], InSet(Exp(U, k), sub_expr1), domain = sub_expr1)
# Out:
# expr: forall_{U in SU(n)} (U^{k} in SU(n))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{U \in SU(n)}~\left(U^{k} \in SU(n)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{U in SU(n)} (U^{k} in SU(n))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (U -> {U^{k} in SU(n) if U in SU(n).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. U -> {U^{k} in SU(n) if U in SU(n).
#    core type: Lambda
#    parameter: 16
#    body: 4
# 4. {U^{k} in SU(n) if U in SU(n).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. U^{k} in SU(n)
#    core type: Operation
#    operator: 8
#    operands: 7
# 6. U in SU(n)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. (U^{k}, SU(n))
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. in
#    core type: Literal
#    sub-expressions:
# 9. (U, SU(n))
#    core type: ExprTuple
#    sub-expressions: 16, 11
# 10. U^{k}
#     core type: Operation
#     operator: 12
#     operands: 13
# 11. SU(n)
#     core type: Operation
#     operator: 14
#     operand: 18
# 12. Exp
#     core type: Literal
#     sub-expressions:
# 13. (U, k)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 14. SU
#     core type: Literal
#     sub-expressions:
# 15. (n)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. U
#     core type: Variable
#     sub-expressions:
# 17. k
#     core type: Variable
#     sub-expressions:
# 18. n
#     core type: Variable
#     sub-expressions:
