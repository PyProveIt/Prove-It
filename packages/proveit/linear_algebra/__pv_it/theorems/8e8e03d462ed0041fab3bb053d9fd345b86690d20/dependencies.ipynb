# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#factor_scalar_from_tensor_prod">factor_scalar_from_tensor_prod</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/factor_scalar_from_tensor_prod/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.linear_algebra import factor_scalar_from_tensor_prod

# %%
# %dependencies factor_scalar_from_tensor_prod
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon factor_scalar_from_tensor_prod</h3>
