# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#factor_scalar_from_tensor_prod">factor_scalar_from_tensor_prod</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra import factor_scalar_from_tensor_prod

# %%
# check that the built expression is the same as the stored expression
assert factor_scalar_from_tensor_prod.expr == stored_expr
assert factor_scalar_from_tensor_prod.expr._style_id == stored_expr._style_id
print("Passed sanity check: factor_scalar_from_tensor_prod matches stored_expr")
# Out:
# Passed sanity check: factor_scalar_from_tensor_prod matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(factor_scalar_from_tensor_prod.latex())
# Out:
# \vdash \forall_{m, n \in \mathbb{N}}~\left[\forall_{x_{1}, \ldots, x_{m}, y, z_{1}, \ldots, z_{n}}~\left[\forall_{\alpha}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \left(\alpha \thinspace y\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \left(\alpha \thinspace \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)\right)\right]\right]

# %%
factor_scalar_from_tensor_prod.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
factor_scalar_from_tensor_prod.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]]
#    core type: Operation
#    operator: 17
#    operand: 2
# 1. ((m, n) -> {forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))] if m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))] if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 39, 42
# 4. {forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))] if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}} [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]
#    core type: Operation
#    operator: 17
#    operand: 10
# 6. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 8
#    operands: 9
# 7. ((x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}) -> [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))])
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 10. (x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n}) -> [forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))]
#     core type: Lambda
#     parameters: 33\n    body: 13
# 11. m in Natural
#     core type: Operation
#     operator: 15
#     operands: 14
# 12. n in Natural
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. forall_{alpha} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#     core type: Operation
#     operator: 17
#     operand: 20
# 14. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 39, 19
# 15. in
#     core type: Literal
#     sub-expressions:
# 16. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 42, 19
# 17. forall
#     core type: Literal
#     sub-expressions:
# 18. (alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))))
#     core type: ExprTuple
#     sub-expressions: 20
# 19. Natural
#     core type: Literal
#     sub-expressions:
# 20. alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#     core type: Lambda
#     parameter: 34
#     body: 21
# 21. (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#     core type: Operation
#     operator: 22
#     operands: 23
# 22. =
#     core type: Literal
#     sub-expressions:
# 23. (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#     core type: Operation
#     operator: 32
#     operands: 26
# 25. alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#     core type: Operation
#     operator: 30
#     operands: 27
# 26. (x_{1}, ..x_{_a}.., x_{m}, alpha * y, z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 28, 37
# 27. (alpha, x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#     core type: ExprTuple
#     sub-expressions: 34, 29
# 28. alpha * y
#     core type: Operation
#     operator: 30
#     operands: 31
# 29. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#     core type: Operation
#     operator: 32
#     operands: 33
# 30. *
#     core type: Literal
#     sub-expressions:
# 31. (alpha, y)
#     core type: ExprTuple
#     sub-expressions: 34, 36
# 32. otimes
#     core type: Literal
#     sub-expressions:
# 33. (x_{1}, ..x_{_a}.., x_{m}, y, z_{1}, ..z_{_a}.., z_{n})
#     core type: ExprTuple
#     sub-expressions: 35, 36, 37
# 34. alpha
#     core type: Variable
#     sub-expressions:
# 35. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 38
#     start_index: 41
#     end_index: 39
# 36. y
#     core type: Variable
#     sub-expressions:
# 37. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 40
#     start_index: 41
#     end_index: 42
# 38. _a -> x_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 43
# 39. m
#     core type: Variable
#     sub-expressions:
# 40. _a -> z_{_a}
#     core type: Lambda
#     parameter: 48
#     body: 44
# 41. 1
#     core type: Literal
#     sub-expressions:
# 42. n
#     core type: Variable
#     sub-expressions:
# 43. x_{_a}
#     core type: IndexedVar
# variable: 45
# index: 48
# 44. z_{_a}
#     core type: IndexedVar
# variable: 46
# index: 48
# 45. x
#     core type: Variable
#     sub-expressions:
# 46. z
#     core type: Variable
#     sub-expressions:
# 47. (_a)
#     core type: ExprTuple
#     sub-expressions: 48
# 48. _a
#     core type: Variable
#     sub-expressions:
