# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import U, k, n
from proveit.linear_algebra import SU
from proveit.logic import Forall, InSet
from proveit.numbers import Exp, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = SU(n)
expr = Forall([n, k], Forall([U], InSet(Exp(U, k), sub_expr1), domain = sub_expr1), domain = NaturalPos)
# Out:
# expr: forall_{n, k in NaturalPos} [forall_{U in SU(n)} (U^{k} in SU(n))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{n, k \in \mathbb{N}^+}~\left[\forall_{U \in SU(n)}~\left(U^{k} \in SU(n)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{n, k in NaturalPos} [forall_{U in SU(n)} (U^{k} in SU(n))]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((n, k) -> {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (n, k) -> {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (n, k)
#    core type: ExprTuple
#    sub-expressions: 31, 30
# 4. {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{U in SU(n)} (U^{k} in SU(n))
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (n in NaturalPos) and (k in NaturalPos)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. (U -> {U^{k} in SU(n) if U in SU(n).)
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (n in NaturalPos, k in NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. U -> {U^{k} in SU(n) if U in SU(n).
#     core type: Lambda
#     parameter: 29
#     body: 14
# 12. n in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 15
# 13. k in NaturalPos
#     core type: Operation
#     operator: 21
#     operands: 16
# 14. {U^{k} in SU(n) if U in SU(n).
#     core type: Conditional
#     value: 17
#     condition: 18
# 15. (n, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 31, 19
# 16. (k, NaturalPos)
#     core type: ExprTuple
#     sub-expressions: 30, 19
# 17. U^{k} in SU(n)
#     core type: Operation
#     operator: 21
#     operands: 20
# 18. U in SU(n)
#     core type: Operation
#     operator: 21
#     operands: 22
# 19. NaturalPos
#     core type: Literal
#     sub-expressions:
# 20. (U^{k}, SU(n))
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 21. in
#     core type: Literal
#     sub-expressions:
# 22. (U, SU(n))
#     core type: ExprTuple
#     sub-expressions: 29, 24
# 23. U^{k}
#     core type: Operation
#     operator: 25
#     operands: 26
# 24. SU(n)
#     core type: Operation
#     operator: 27
#     operand: 31
# 25. Exp
#     core type: Literal
#     sub-expressions:
# 26. (U, k)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 27. SU
#     core type: Literal
#     sub-expressions:
# 28. (n)
#     core type: ExprTuple
#     sub-expressions: 31
# 29. U
#     core type: Variable
#     sub-expressions:
# 30. k
#     core type: Variable
#     sub-expressions:
# 31. n
#     core type: Variable
#     sub-expressions:
