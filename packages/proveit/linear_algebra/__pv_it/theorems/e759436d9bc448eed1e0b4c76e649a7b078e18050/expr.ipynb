# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, f, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Forall([f, S, x_1_to_m, z_1_to_n], Equals(TensorProd(x_1_to_m, Sum(sub_expr1, fy, domain = S), z_1_to_n), Sum(sub_expr1, TensorProd(x_1_to_m, fy, z_1_to_n), domain = S)))
# Out:
# expr: forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{f, S, x_{1}, \ldots, x_{m}, z_{1}, \ldots, z_{n}}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \sum_{y \in S}~f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \sum_{y \in S}~\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}) -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#    core type: ExprTuple
#    sub-expressions: 3
# ...
