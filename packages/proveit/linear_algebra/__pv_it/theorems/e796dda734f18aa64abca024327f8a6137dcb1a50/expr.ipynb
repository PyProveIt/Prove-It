# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, ExprTuple, Lambda, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(b, Conditional(Forall([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))), InSet(b, Complex))))
# Out:
# expr: (b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(b \mapsto \left\{\forall_{A, x}~\left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right) \textrm{ if } b \in \mathbb{C}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Lambda
#    parameter: 36
#    body: 2
# 2. {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Operation
#    operator: 5
#    operand: 9
# 4. b in Complex
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))))
#    core type: ExprTuple
#    sub-expressions: 9
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 36, 10
# ...
