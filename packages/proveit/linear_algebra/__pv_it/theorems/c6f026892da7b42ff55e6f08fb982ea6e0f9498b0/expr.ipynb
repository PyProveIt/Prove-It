# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, alpha, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import ScalarProd, TensorProd
from proveit.logic import Equals

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(alpha, Equals(TensorProd(x_1_to_m, ScalarProd(alpha, y), z_1_to_n), ScalarProd(alpha, TensorProd(x_1_to_m, y, z_1_to_n)))))
# Out:
# expr: (alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha \mapsto \left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \left(\alpha \thinspace y\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \left(\alpha \thinspace \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. alpha -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#    core type: Lambda
#    parameter: 15
#    body: 2
# 2. (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. =
#    core type: Literal
#    sub-expressions:
# ...
