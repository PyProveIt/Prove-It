# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_tensor_prod_over_summation">distribute_tensor_prod_over_summation</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/distribute_tensor_prod_over_summation/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.linear_algebra import distribute_tensor_prod_over_summation

# %%
# %dependencies distribute_tensor_prod_over_summation
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>No theorems/conjectures depend upon distribute_tensor_prod_over_summation</h3>
