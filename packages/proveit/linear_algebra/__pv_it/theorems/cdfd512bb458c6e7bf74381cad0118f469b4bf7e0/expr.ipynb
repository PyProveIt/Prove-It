# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, S, f, fy, m, n, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Natural, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = Conditional(Forall([f, S, x_1_to_m, z_1_to_n], Equals(TensorProd(x_1_to_m, Sum(sub_expr1, fy, domain = S), z_1_to_n), Sum(sub_expr1, TensorProd(x_1_to_m, fy, z_1_to_n), domain = S))), And(InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) if m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{f, S, x_{1}, \ldots, x_{m}, z_{1}, \ldots, z_{n}}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \sum_{y \in S}~f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \sum_{y \in S}~\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}} ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# ...
