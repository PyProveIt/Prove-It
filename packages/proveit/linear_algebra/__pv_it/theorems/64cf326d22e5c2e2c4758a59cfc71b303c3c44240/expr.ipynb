# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, alpha, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import ScalarProd, TensorProd

# %%
# build up the expression from sub-expressions
expr = ExprTuple(TensorProd(x_1_to_m, ScalarProd(alpha, y), z_1_to_n), ScalarProd(alpha, TensorProd(x_1_to_m, y, z_1_to_n)))
# Out:
# expr: (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \left(\alpha \thinspace y\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}, \alpha \thinspace \left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes (alpha * y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 9
#    operands: 3
# 2. alpha * (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#    core type: Operation
#    operator: 7
#    operands: 4
# 3. (x_{1}, ..x_{_a}.., x_{m}, alpha * y, z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 12, 5, 14
# 4. (alpha, x_{1} otimes ..x_{_a}.. otimes x_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 6
# 5. alpha * y
#    core type: Operation
#    operator: 7
#    operands: 8
# ...
