# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.linear_algebra.TensorProd.html">TensorProd</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
expr = TensorProd(a, Sum([j], bj, domain = Interval(c, d)))
# Out:
# expr: a otimes (Sum_{j=c}^{d} b_{j})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# a {\otimes} \left(\sum_{j=c}^{d} b_{j}\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. a otimes (Sum_{j=c}^{d} b_{j})
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. otimes
#    core type: Literal
#    sub-expressions:
# 2. (a, Sum_{j=c}^{d} b_{j})
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. a
#    core type: Variable
#    sub-expressions:
# 4. Sum_{j=c}^{d} b_{j}
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. Sum
#    core type: Literal
#    sub-expressions:
# 6. (j -> {b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 7. j -> {b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 15
#    body: 8
# 8. {b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 9
#    condition: 10
# 9. b_{j}
#    core type: IndexedVar
# variable: 11
# index: 15
# 10. j in {c .. d}
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. b
#     core type: Variable
#     sub-expressions:
# 12. (j)
#     core type: ExprTuple
#     sub-expressions: 15
# 13. in
#     core type: Literal
#     sub-expressions:
# 14. (j, {c .. d})
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 15. j
#     core type: Variable
#     sub-expressions:
# 16. {c .. d}
#     core type: Operation
#     operator: 17
#     operands: 18
# 17. Interval
#     core type: Literal
#     sub-expressions:
# 18. (c, d)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. d
#     core type: Variable
#     sub-expressions:
