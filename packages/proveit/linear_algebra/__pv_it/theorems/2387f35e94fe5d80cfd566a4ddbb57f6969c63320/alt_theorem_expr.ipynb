# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_tensor_prod_over_sum">distribute_tensor_prod_over_sum</a> of type <a href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, i, j, k, m, y
from proveit.core_expr_types import x_1_to_i, y_1_to_j, z_1_to_k
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Add, Natural, one

# %%
# build up the expression from sub-expressions
expr = Forall([i, j, k], Forall([x_1_to_i, y_1_to_j, z_1_to_k], Equals(TensorProd(x_1_to_i, Add(y_1_to_j), z_1_to_k), Add(ExprRange(m, TensorProd(x_1_to_i, IndexedVar(y, m), z_1_to_k), one, j)))), domain = Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: distribute_tensor_prod_over_sum matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
expr.style_options()

# %%
# display the expression information
expr.expr_info()
