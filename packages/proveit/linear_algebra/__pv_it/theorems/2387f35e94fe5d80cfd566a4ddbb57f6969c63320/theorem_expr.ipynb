# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#distribute_tensor_prod_over_sum">distribute_tensor_prod_over_sum</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra import distribute_tensor_prod_over_sum

# %%
# check that the built expression is the same as the stored expression
assert distribute_tensor_prod_over_sum.expr == stored_expr
assert distribute_tensor_prod_over_sum.expr._style_id == stored_expr._style_id
print("Passed sanity check: distribute_tensor_prod_over_sum matches stored_expr")
# Out:
# Passed sanity check: distribute_tensor_prod_over_sum matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(distribute_tensor_prod_over_sum.latex())
# Out:
# \vdash \forall_{i, j, k \in \mathbb{N}}~\left[\forall_{x_{1}, \ldots, x_{i}, y_{1}, \ldots, y_{j}, z_{1}, \ldots, z_{k}}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} \left(y_{1} + \ldots + y_{j}\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right) = \left(\left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{1} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right) + \ldots + \left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{j} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right)\right)\right)\right]

# %%
distribute_tensor_prod_over_sum.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
distribute_tensor_prod_over_sum.expr_info()
# Out:
# 0. forall_{i, j, k in Natural} [forall_{x_{1}, ..x_{_a}.., x_{i}, y_{1}, ..y_{_a}.., y_{j}, z_{1}, ..z_{_a}.., z_{k}} ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes (y_{1} + ..y_{_a}.. + y_{j}) otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) = ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) + ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).. + (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})))]
#    core type: Operation
#    operator: 7
#    operand: 2
# ...
