# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, k, n
from proveit.linear_algebra import SU
from proveit.logic import InSet
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
sub_expr1 = SU(n)
expr = ExprTuple(Lambda(U, Conditional(InSet(Exp(U, k), sub_expr1), InSet(U, sub_expr1))))
# Out:
# expr: (U -> {U^{k} in SU(n) if U in SU(n).)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(U \mapsto \left\{U^{k} \in SU(n) \textrm{ if } U \in SU(n)\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (U -> {U^{k} in SU(n) if U in SU(n).)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. U -> {U^{k} in SU(n) if U in SU(n).
#    core type: Lambda
#    parameter: 14
#    body: 2
# 2. {U^{k} in SU(n) if U in SU(n).
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. U^{k} in SU(n)
#    core type: Operation
#    operator: 6
#    operands: 5
# 4. U in SU(n)
#    core type: Operation
#    operator: 6
#    operands: 7
# 5. (U^{k}, SU(n))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (U, SU(n))
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 8. U^{k}
#    core type: Operation
#    operator: 10
#    operands: 11
# 9. SU(n)
#    core type: Operation
#    operator: 12
#    operand: 16
# 10. Exp
#     core type: Literal
#     sub-expressions:
# 11. (U, k)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 12. SU
#     core type: Literal
#     sub-expressions:
# 13. (n)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. U
#     core type: Variable
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. n
#     core type: Variable
#     sub-expressions:
