# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, S, f, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [y]
expr = ExprTuple(Lambda([f, S, x_1_to_m, z_1_to_n], Equals(TensorProd(x_1_to_m, Sum(sub_expr1, fy, domain = S), z_1_to_n), Sum(sub_expr1, TensorProd(x_1_to_m, fy, z_1_to_n), domain = S))))
# Out:
# expr: ((f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}) -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f, S, x_{1}, \ldots, x_{m}, z_{1}, \ldots, z_{n}\right) \mapsto \left(\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} \sum_{y \in S}~f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \sum_{y \in S}~\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}) -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n}) -> ((x_{1} otimes ..x_{_a}.. otimes x_{m} otimes Sum_{y in S} f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}))
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (f, S, x_{1}, ..x_{_a}.., x_{m}, z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 28, 33, 21, 23
# ...
