# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp, NaturalPos

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([b], Forall([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))), domain = Complex), InSet(k, NaturalPos))
# Out:
# expr: {forall_{b in Complex} [forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))] if k in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{b \in \mathbb{C}}~\left[\forall_{A, x}~\left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right)\right] \textrm{ if } k \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{b in Complex} [forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))] if k in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{b in Complex} [forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))]
#    core type: Operation
#    operator: 10
#    operand: 5
# 2. k in NaturalPos
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. (b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (k, NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 42, 6
# 5. b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Lambda
#    parameter: 41
#    body: 7
# 6. NaturalPos
#    core type: Literal
#    sub-expressions:
# 7. {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Conditional
#    value: 8
#    condition: 9
# ...
