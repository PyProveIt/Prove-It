# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
expr = Sum([j], TensorProd(a, bj), domain = Interval(c, d))
# Out:
# expr: Sum_{j=c}^{d} (a otimes b_{j})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{j=c}^{d} \left(a {\otimes} b_{j}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{j=c}^{d} (a otimes b_{j})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (j -> {a otimes b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. j -> {a otimes b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 18
#    body: 4
# 4. {a otimes b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. a otimes b_{j}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. j in {c .. d}
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. otimes
#    core type: Literal
#    sub-expressions:
# 8. (a, b_{j})
#    core type: ExprTuple
#    sub-expressions: 11, 12
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (j, {c .. d})
#     core type: ExprTuple
#     sub-expressions: 18, 13
# 11. a
#     core type: Variable
#     sub-expressions:
# 12. b_{j}
#     core type: IndexedVar
# variable: 14
# index: 18
# 13. {c .. d}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. b
#     core type: Variable
#     sub-expressions:
# 15. (j)
#     core type: ExprTuple
#     sub-expressions: 18
# 16. Interval
#     core type: Literal
#     sub-expressions:
# 17. (c, d)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 18. j
#     core type: Variable
#     sub-expressions:
# 19. c
#     core type: Variable
#     sub-expressions:
# 20. d
#     core type: Variable
#     sub-expressions:
