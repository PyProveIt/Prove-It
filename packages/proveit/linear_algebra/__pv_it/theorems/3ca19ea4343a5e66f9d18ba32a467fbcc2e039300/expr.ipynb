# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, x, y
from proveit.core_expr_types import a_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd

# %%
# build up the expression from sub-expressions
expr = ExprTuple(TensorProd(a_1_to_m, x, z_1_to_n), TensorProd(a_1_to_m, y, z_1_to_n))
# Out:
# expr: (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} x {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}, a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}, a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (a_{1}, ..a_{_a}.., a_{m}, x, z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 6, 9
# 4. otimes
#    core type: Literal
#    sub-expressions:
# 5. (a_{1}, ..a_{_a}.., a_{m}, y, z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 6. x
#    core type: Variable
#    sub-expressions:
# 7. a_{1}, ..a_{_a}.., a_{m}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 13
#    end_index: 11
# 8. y
#    core type: Variable
#    sub-expressions:
# 9. z_{1}, ..z_{_a}.., z_{n}
#    core type: ExprRange
#    lambda_map: 12
#    start_index: 13
#    end_index: 14
# 10. _a -> a_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 15
# 11. m
#     core type: Variable
#     sub-expressions:
# 12. _a -> z_{_a}
#     core type: Lambda
#     parameter: 20
#     body: 16
# 13. 1
#     core type: Literal
#     sub-expressions:
# 14. n
#     core type: Variable
#     sub-expressions:
# 15. a_{_a}
#     core type: IndexedVar
# variable: 17
# index: 20
# 16. z_{_a}
#     core type: IndexedVar
# variable: 18
# index: 20
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. z
#     core type: Variable
#     sub-expressions:
# 19. (_a)
#     core type: ExprTuple
#     sub-expressions: 20
# 20. _a
#     core type: Variable
#     sub-expressions:
