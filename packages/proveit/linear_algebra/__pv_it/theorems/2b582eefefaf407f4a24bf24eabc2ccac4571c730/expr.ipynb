# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import alpha, beta, x
from proveit.linear_algebra import ScalarProd
from proveit.logic import Equals
from proveit.numbers import Mult

# %%
# build up the expression from sub-expressions
expr = Equals(ScalarProd(alpha, ScalarProd(beta, x)), ScalarProd(Mult(alpha, beta), x))
# Out:
# expr: (alpha * (beta * x)) = ((alpha * beta) * x)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\alpha \thinspace \left(\beta \thinspace x\right)\right) = \left(\left(\alpha \cdot \beta\right) \thinspace x\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (alpha * (beta * x)) = ((alpha * beta) * x)
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (alpha * (beta * x), (alpha * beta) * x)
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. alpha * (beta * x)
#    core type: Operation
#    operator: 9
#    operands: 5
# 4. (alpha * beta) * x
#    core type: Operation
#    operator: 9
#    operands: 6
# 5. (alpha, beta * x)
#    core type: ExprTuple
#    sub-expressions: 14, 7
# 6. (alpha * beta, x)
#    core type: ExprTuple
#    sub-expressions: 8, 13
# 7. beta * x
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. alpha * beta
#    core type: Operation
#    operator: 11
#    operands: 12
# 9. *
#    core type: Literal
#    sub-expressions:
# 10. (beta, x)
#     core type: ExprTuple
#     sub-expressions: 15, 13
# 11. *
#     core type: Literal
#     sub-expressions:
# 12. (alpha, beta)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. x
#     core type: Variable
#     sub-expressions:
# 14. alpha
#     core type: Variable
#     sub-expressions:
# 15. beta
#     core type: Variable
#     sub-expressions:
