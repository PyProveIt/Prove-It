# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import alpha, beta, x
from proveit.linear_algebra import ScalarProd
from proveit.logic import Equals, Forall
from proveit.numbers import Mult

# %%
# build up the expression from sub-expressions
expr = Forall([alpha, beta], Equals(ScalarProd(alpha, ScalarProd(beta, x)), ScalarProd(Mult(alpha, beta), x)))
# Out:
# expr: forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{\alpha, \beta}~\left(\left(\alpha \thinspace \left(\beta \thinspace x\right)\right) = \left(\left(\alpha \cdot \beta\right) \thinspace x\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x)))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Lambda
#    parameters: 16\n   body: 4
# 4. (alpha * (beta * x)) = ((alpha * beta) * x)
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (alpha * (beta * x), (alpha * beta) * x)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. alpha * (beta * x)
#    core type: Operation
#    operator: 13
#    operands: 9
# 8. (alpha * beta) * x
#    core type: Operation
#    operator: 13
#    operands: 10
# 9. (alpha, beta * x)
#    core type: ExprTuple
#    sub-expressions: 18, 11
# 10. (alpha * beta, x)
#     core type: ExprTuple
#     sub-expressions: 12, 17
# 11. beta * x
#     core type: Operation
#     operator: 13
#     operands: 14
# 12. alpha * beta
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. *
#     core type: Literal
#     sub-expressions:
# 14. (beta, x)
#     core type: ExprTuple
#     sub-expressions: 19, 17
# 15. *
#     core type: Literal
#     sub-expressions:
# 16. (alpha, beta)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 17. x
#     core type: Variable
#     sub-expressions:
# 18. alpha
#     core type: Variable
#     sub-expressions:
# 19. beta
#     core type: Variable
#     sub-expressions:
