# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, alpha, beta, x
from proveit.linear_algebra import ScalarProd
from proveit.logic import Equals, Forall
from proveit.numbers import Mult

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(x, Forall([alpha, beta], Equals(ScalarProd(alpha, ScalarProd(beta, x)), ScalarProd(Mult(alpha, beta), x)))))
# Out:
# expr: (x -> [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x \mapsto \left[\forall_{\alpha, \beta}~\left(\left(\alpha \thinspace \left(\beta \thinspace x\right)\right) = \left(\left(\alpha \cdot \beta\right) \thinspace x\right)\right)\right]\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x -> [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. x -> [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))]
#    core type: Lambda
#    parameter: 19
#    body: 2
# 2. forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x)))
#    core type: ExprTuple
#    sub-expressions: 5
# 5. (alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Lambda
#    parameters: 18\n   body: 6
# 6. (alpha * (beta * x)) = ((alpha * beta) * x)
#    core type: Operation
#    operator: 7
#    operands: 8
# 7. =
#    core type: Literal
#    sub-expressions:
# 8. (alpha * (beta * x), (alpha * beta) * x)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 9. alpha * (beta * x)
# ...
