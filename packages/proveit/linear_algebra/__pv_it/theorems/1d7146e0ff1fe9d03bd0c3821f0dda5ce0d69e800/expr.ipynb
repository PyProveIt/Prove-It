# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, c, d, j
from proveit.core_expr_types import bj
from proveit.logic import InSet
from proveit.numbers import Interval

# %%
# build up the expression from sub-expressions
expr = Lambda(j, Conditional(bj, InSet(j, Interval(c, d))))
# Out:
# expr: j -> {b_{j} if j in {c .. d}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# j \mapsto \left\{b_{j} \textrm{ if } j \in \{c~\ldotp \ldotp~d\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. j -> {b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. b_{j}
#    core type: IndexedVar
# variable: 4
# index: 8
# 3. j in {c .. d}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. b
#    core type: Variable
#    sub-expressions:
# 5. (j)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (j, {c .. d})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. j
#    core type: Variable
#    sub-expressions:
# 9. {c .. d}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (c, d)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. c
#     core type: Variable
#     sub-expressions:
# 13. d
#     core type: Variable
#     sub-expressions:
