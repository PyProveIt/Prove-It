# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprRange.html">ExprRange</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, IndexedVar, j, m, y
from proveit.core_expr_types import x_1_to_i, z_1_to_k
from proveit.linear_algebra import TensorProd
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprRange(m, TensorProd(x_1_to_i, IndexedVar(y, m), z_1_to_k), one, j)
# Out:
# expr: (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}), ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).., (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{1} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right), \ldots, \left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{j} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right)

# %%
expr.style_options()
# Out:
# style name: parameterization
# description: 'implicit' (default for LaTeX formatting) hides the parameter the ExprRange so the parameterization may be ambiguous (e.g., x_{1+1}, ..., x_{n+1}); 'explicit' (default for string formatting) reveals the parameterization (e.g. x_{1+1}, ..x_{k+1}.., x_{n+1}).
# default: None
# current value: None/False
# related methods: ('with_explicit_parameterization', 'with_implicit_parameterization', 'with_default_parameterization_style')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}), ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).., (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})
#    core type: ExprRange
#    lambda_map: 1
#    start_index: 14
#    end_index: 2
# 1. m -> (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})
#    core type: Lambda
#    parameter: 17
#    body: 3
# 2. j
#    core type: Variable
#    sub-expressions:
# 3. x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. otimes
#    core type: Literal
#    sub-expressions:
# 5. (x_{1}, ..x_{_a}.., x_{i}, y_{m}, z_{1}, ..z_{_a}.., z_{k})
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. x_{1}, ..x_{_a}.., x_{i}
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 14
#    end_index: 10
# 7. y_{m}
#    core type: IndexedVar
# variable: 11
# index: 17
# 8. z_{1}, ..z_{_a}.., z_{k}
#    core type: ExprRange
#    lambda_map: 13
#    start_index: 14
#    end_index: 15
# 9. _a -> x_{_a}
#    core type: Lambda
#    parameter: 22
#    body: 16
# 10. i
#     core type: Variable
#     sub-expressions:
# 11. y
#     core type: Variable
#     sub-expressions:
# 12. (m)
#     core type: ExprTuple
#     sub-expressions: 17
# 13. _a -> z_{_a}
#     core type: Lambda
#     parameter: 22
#     body: 18
# 14. 1
#     core type: Literal
#     sub-expressions:
# 15. k
#     core type: Variable
#     sub-expressions:
# 16. x_{_a}
#     core type: IndexedVar
# variable: 19
# index: 22
# 17. m
#     core type: Variable
#     sub-expressions:
# 18. z_{_a}
#     core type: IndexedVar
# variable: 20
# index: 22
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. z
#     core type: Variable
#     sub-expressions:
# 21. (_a)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. _a
#     core type: Variable
#     sub-expressions:
