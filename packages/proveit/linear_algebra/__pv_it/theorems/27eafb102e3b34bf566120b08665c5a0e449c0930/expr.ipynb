# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, S, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import InSet

# %%
# build up the expression from sub-expressions
expr = Conditional(TensorProd(x_1_to_m, fy, z_1_to_n), InSet(y, S))
# Out:
# expr: {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n} \textrm{ if } y \in S\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. y in S
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. otimes
#    core type: Literal
#    sub-expressions:
# 4. (x_{1}, ..x_{_a}.., x_{m}, f(y), z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (y, S)
#    core type: ExprTuple
#    sub-expressions: 19, 10
# 7. x_{1}, ..x_{_a}.., x_{m}
#    core type: ExprRange
#    lambda_map: 11
#    start_index: 16
#    end_index: 12
# 8. f(y)
#    core type: Operation
#    operator: 13
#    operand: 19
# 9. z_{1}, ..z_{_a}.., z_{n}
#    core type: ExprRange
#    lambda_map: 15
#    start_index: 16
#    end_index: 17
# 10. S
#     core type: Variable
#     sub-expressions:
# 11. _a -> x_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 18
# 12. m
#     core type: Variable
#     sub-expressions:
# 13. f
#     core type: Variable
#     sub-expressions:
# 14. (y)
#     core type: ExprTuple
#     sub-expressions: 19
# 15. _a -> z_{_a}
#     core type: Lambda
#     parameter: 24
#     body: 20
# 16. 1
#     core type: Literal
#     sub-expressions:
# 17. n
#     core type: Variable
#     sub-expressions:
# 18. x_{_a}
#     core type: IndexedVar
# variable: 21
# index: 24
# 19. y
#     core type: Variable
#     sub-expressions:
# 20. z_{_a}
#     core type: IndexedVar
# variable: 22
# index: 24
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. z
#     core type: Variable
#     sub-expressions:
# 23. (_a)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. _a
#     core type: Variable
#     sub-expressions:
