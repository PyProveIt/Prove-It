# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.logic import InSet
from proveit.numbers import Interval

# %%
# build up the expression from sub-expressions
expr = Conditional(TensorProd(a, bj), InSet(j, Interval(c, d)))
# Out:
# expr: {a otimes b_{j} if j in {c .. d}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{a {\otimes} b_{j} \textrm{ if } j \in \{c~\ldotp \ldotp~d\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {a otimes b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. a otimes b_{j}
#    core type: Operation
#    operator: 3
#    operands: 4
# 2. j in {c .. d}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. otimes
#    core type: Literal
#    sub-expressions:
# 4. (a, b_{j})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (j, {c .. d})
#    core type: ExprTuple
#    sub-expressions: 14, 9
# 7. a
#    core type: Variable
#    sub-expressions:
# 8. b_{j}
#    core type: IndexedVar
# variable: 10
# index: 14
# 9. {c .. d}
#    core type: Operation
#    operator: 12
#    operands: 13
# 10. b
#     core type: Variable
#     sub-expressions:
# 11. (j)
#     core type: ExprTuple
#     sub-expressions: 14
# 12. Interval
#     core type: Literal
#     sub-expressions:
# 13. (c, d)
#     core type: ExprTuple
#     sub-expressions: 15, 16
# 14. j
#     core type: Variable
#     sub-expressions:
# 15. c
#     core type: Variable
#     sub-expressions:
# 16. d
#     core type: Variable
#     sub-expressions:
