# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, IndexedVar, j, m, y
from proveit.core_expr_types import x_1_to_i, z_1_to_k
from proveit.linear_algebra import TensorProd
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(m, TensorProd(x_1_to_i, IndexedVar(y, m), z_1_to_k), one, j))
# Out:
# expr: (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}, ..x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}.., x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{1} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}, \ldots, x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{j} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}, ..x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}.., x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}), ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).., (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})
#    core type: ExprRange
#    lambda_map: 2
#    start_index: 15
#    end_index: 3
# 2. m -> (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k})
#    core type: Lambda
#    parameter: 18
#    body: 4
# 3. j
#    core type: Variable
#    sub-expressions:
# 4. x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. otimes
#    core type: Literal
#    sub-expressions:
# 6. (x_{1}, ..x_{_a}.., x_{i}, y_{m}, z_{1}, ..z_{_a}.., z_{k})
#    core type: ExprTuple
#    sub-expressions: 7, 8, 9
# 7. x_{1}, ..x_{_a}.., x_{i}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 15
#    end_index: 11
# 8. y_{m}
#    core type: IndexedVar
# variable: 12
# index: 18
# 9. z_{1}, ..z_{_a}.., z_{k}
#    core type: ExprRange
#    lambda_map: 14
#    start_index: 15
#    end_index: 16
# 10. _a -> x_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 17
# 11. i
#     core type: Variable
#     sub-expressions:
# 12. y
#     core type: Variable
#     sub-expressions:
# 13. (m)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. _a -> z_{_a}
#     core type: Lambda
#     parameter: 23
#     body: 19
# 15. 1
#     core type: Literal
#     sub-expressions:
# 16. k
#     core type: Variable
#     sub-expressions:
# 17. x_{_a}
#     core type: IndexedVar
# variable: 20
# index: 23
# 18. m
#     core type: Variable
#     sub-expressions:
# 19. z_{_a}
#     core type: IndexedVar
# variable: 21
# index: 23
# 20. x
#     core type: Variable
#     sub-expressions:
# 21. z
#     core type: Variable
#     sub-expressions:
# 22. (_a)
#     core type: ExprTuple
#     sub-expressions: 23
# 23. _a
#     core type: Variable
#     sub-expressions:
