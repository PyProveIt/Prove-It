# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, S, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
expr = ExprTuple(x_1_to_m, Sum([y], fy, domain = S), z_1_to_n)
# Out:
# expr: (x_{1}, ..x_{_a}.., x_{m}, Sum_{y in S} f(y), z_{1}, ..z_{_a}.., z_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(x_{1}, \ldots, x_{m}, \sum_{y \in S}~f(y), z_{1}, \ldots, z_{n}\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (x_{1}, ..x_{_a}.., x_{m}, Sum_{y in S} f(y), z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. x_{1}, ..x_{_a}.., x_{m}
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 9
#    end_index: 5
# 2. Sum_{y in S} f(y)
#    core type: Operation
#    operator: 6
#    operand: 12
# 3. z_{1}, ..z_{_a}.., z_{n}
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 4. _a -> x_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 11
# 5. m
#    core type: Variable
#    sub-expressions:
# 6. Sum
#    core type: Literal
#    sub-expressions:
# 7. (y -> {f(y) if y in S.)
#    core type: ExprTuple
#    sub-expressions: 12
# 8. _a -> z_{_a}
#    core type: Lambda
#    parameter: 20
#    body: 13
# 9. 1
#    core type: Literal
#    sub-expressions:
# 10. n
#     core type: Variable
#     sub-expressions:
# 11. x_{_a}
#     core type: IndexedVar
# variable: 14
# index: 20
# 12. y -> {f(y) if y in S.
#     core type: Lambda
#     parameter: 25
#     body: 15
# 13. z_{_a}
#     core type: IndexedVar
# variable: 16
# index: 20
# 14. x
#     core type: Variable
#     sub-expressions:
# 15. {f(y) if y in S.
#     core type: Conditional
#     value: 18
#     condition: 19
# 16. z
#     core type: Variable
#     sub-expressions:
# 17. (_a)
#     core type: ExprTuple
#     sub-expressions: 20
# 18. f(y)
#     core type: Operation
#     operator: 21
#     operand: 25
# 19. y in S
#     core type: Operation
#     operator: 23
#     operands: 24
# 20. _a
#     core type: Variable
#     sub-expressions:
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. (y)
#     core type: ExprTuple
#     sub-expressions: 25
# 23. in
#     core type: Literal
#     sub-expressions:
# 24. (y, S)
#     core type: ExprTuple
#     sub-expressions: 25, 26
# 25. y
#     core type: Variable
#     sub-expressions:
# 26. S
#     core type: Variable
#     sub-expressions:
