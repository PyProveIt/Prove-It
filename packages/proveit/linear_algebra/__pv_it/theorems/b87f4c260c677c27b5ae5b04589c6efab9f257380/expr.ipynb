# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, U, k, n
from proveit.linear_algebra import SU
from proveit.logic import And, Forall, InSet
from proveit.numbers import Exp, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = SU(n)
expr = ExprTuple(Lambda([n, k], Conditional(Forall([U], InSet(Exp(U, k), sub_expr1), domain = sub_expr1), And(InSet(n, NaturalPos), InSet(k, NaturalPos)))))
# Out:
# expr: ((n, k) -> {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(n, k\right) \mapsto \left\{\forall_{U \in SU(n)}~\left(U^{k} \in SU(n)\right) \textrm{ if } n \in \mathbb{N}^+ ,  k \in \mathbb{N}^+\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((n, k) -> {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (n, k) -> {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (n, k)
#    core type: ExprTuple
#    sub-expressions: 30, 29
# 3. {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.
#    core type: Conditional
#    value: 4
#    condition: 5
# 4. forall_{U in SU(n)} (U^{k} in SU(n))
#    core type: Operation
#    operator: 6
#    operand: 10
# 5. (n in NaturalPos) and (k in NaturalPos)
#    core type: Operation
#    operator: 8
#    operands: 9
# 6. forall
#    core type: Literal
#    sub-expressions:
# 7. (U -> {U^{k} in SU(n) if U in SU(n).)
#    core type: ExprTuple
#    sub-expressions: 10
# 8. and
#    core type: Literal
#    sub-expressions:
# 9. (n in NaturalPos, k in NaturalPos)
#    core type: ExprTuple
# ...
