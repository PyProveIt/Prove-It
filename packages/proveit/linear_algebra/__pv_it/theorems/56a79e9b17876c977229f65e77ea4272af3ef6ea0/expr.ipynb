# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = ExprTuple(Sum(sub_expr1, TensorProd(a, bj), domain = sub_expr2), TensorProd(a, Sum(sub_expr1, bj, domain = sub_expr2)))
# Out:
# expr: (Sum_{j=c}^{d} (a otimes b_{j}), a otimes (Sum_{j=c}^{d} b_{j}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{j=c}^{d} \left(a {\otimes} b_{j}\right), a {\otimes} \left(\sum_{j=c}^{d} b_{j}\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{j=c}^{d} (a otimes b_{j}), a otimes (Sum_{j=c}^{d} b_{j}))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. Sum_{j=c}^{d} (a otimes b_{j})
#    core type: Operation
#    operator: 8
#    operand: 5
# 2. a otimes (Sum_{j=c}^{d} b_{j})
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. (j -> {a otimes b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (a, Sum_{j=c}^{d} b_{j})
#    core type: ExprTuple
#    sub-expressions: 15, 6
# 5. j -> {a otimes b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 22
#    body: 7
# 6. Sum_{j=c}^{d} b_{j}
#    core type: Operation
#    operator: 8
#    operand: 11
# 7. {a otimes b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 10
#    condition: 17
# 8. Sum
#    core type: Literal
#    sub-expressions:
# 9. (j -> {b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 11
# 10. a otimes b_{j}
#     core type: Operation
#     operator: 12
# ...
