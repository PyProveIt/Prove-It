# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, m, n, x, y
from proveit.core_expr_types import a_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, Iff, InSet
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a_1_to_m, x, y, z_1_to_n], Iff(Equals(TensorProd(a_1_to_m, x, z_1_to_n), TensorProd(a_1_to_m, y, z_1_to_n)), Equals(x, y))), And(InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}} (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y)) if m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a_{1}, \ldots, a_{m}, x, y, z_{1}, \ldots, z_{n}}~\left(\left(\left(a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} x {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \left(a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right) \Leftrightarrow \left(x = y\right)\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}} (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y)) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}} (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# ...
