# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.logic import InSet
from proveit.numbers import Interval

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda(j, Conditional(TensorProd(a, bj), InSet(j, Interval(c, d)))))
# Out:
# expr: (j -> {a otimes b_{j} if j in {c .. d}.)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(j \mapsto \left\{a {\otimes} b_{j} \textrm{ if } j \in \{c~\ldotp \ldotp~d\}\right..\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (j -> {a otimes b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 1
# 1. j -> {a otimes b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 16
#    body: 2
# 2. {a otimes b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 3
#    condition: 4
# 3. a otimes b_{j}
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. j in {c .. d}
#    core type: Operation
#    operator: 7
#    operands: 8
# 5. otimes
#    core type: Literal
#    sub-expressions:
# 6. (a, b_{j})
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 7. in
#    core type: Literal
#    sub-expressions:
# 8. (j, {c .. d})
#    core type: ExprTuple
#    sub-expressions: 16, 11
# 9. a
#    core type: Variable
#    sub-expressions:
# 10. b_{j}
#     core type: IndexedVar
# variable: 12
# index: 16
# 11. {c .. d}
#     core type: Operation
#     operator: 14
#     operands: 15
# 12. b
#     core type: Variable
#     sub-expressions:
# 13. (j)
#     core type: ExprTuple
#     sub-expressions: 16
# 14. Interval
#     core type: Literal
#     sub-expressions:
# 15. (c, d)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. j
#     core type: Variable
#     sub-expressions:
# 17. c
#     core type: Variable
#     sub-expressions:
# 18. d
#     core type: Variable
#     sub-expressions:
