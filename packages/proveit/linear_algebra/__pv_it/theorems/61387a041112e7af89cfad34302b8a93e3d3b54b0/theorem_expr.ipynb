# %% [markdown]
# Theorem <a class="ProveItLink" href="../../../_theorems_.ipynb#doubly_scaled_as_singly_scaled">doubly_scaled_as_singly_scaled</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra import doubly_scaled_as_singly_scaled

# %%
# check that the built expression is the same as the stored expression
assert doubly_scaled_as_singly_scaled.expr == stored_expr
assert doubly_scaled_as_singly_scaled.expr._style_id == stored_expr._style_id
print("Passed sanity check: doubly_scaled_as_singly_scaled matches stored_expr")
# Out:
# Passed sanity check: doubly_scaled_as_singly_scaled matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(doubly_scaled_as_singly_scaled.latex())
# Out:
# \vdash \forall_{x}~\left[\forall_{\alpha, \beta}~\left(\left(\alpha \thinspace \left(\beta \thinspace x\right)\right) = \left(\left(\alpha \cdot \beta\right) \thinspace x\right)\right)\right]

# %%
doubly_scaled_as_singly_scaled.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
doubly_scaled_as_singly_scaled.expr_info()
# Out:
# 0. forall_{x} [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))]
#    core type: Operation
#    operator: 4
#    operand: 2
# 1. (x -> [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. x -> [forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))]
#    core type: Lambda
#    parameter: 20
#    body: 3
# 3. forall_{alpha, beta} ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x)))
#    core type: ExprTuple
#    sub-expressions: 6
# 6. (alpha, beta) -> ((alpha * (beta * x)) = ((alpha * beta) * x))
#    core type: Lambda
#    parameters: 19\n   body: 7
# 7. (alpha * (beta * x)) = ((alpha * beta) * x)
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. =
#    core type: Literal
# ...
