# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.linear_algebra.TensorProd.html">TensorProd</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import IndexedVar, m, y
from proveit.core_expr_types import x_1_to_i, z_1_to_k
from proveit.linear_algebra import TensorProd

# %%
# build up the expression from sub-expressions
expr = TensorProd(x_1_to_i, IndexedVar(y, m), z_1_to_k)
# Out:
# expr: x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{m} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. otimes
#    core type: Literal
#    sub-expressions:
# 2. (x_{1}, ..x_{_a}.., x_{i}, y_{m}, z_{1}, ..z_{_a}.., z_{k})
#    core type: ExprTuple
#    sub-expressions: 3, 4, 5
# 3. x_{1}, ..x_{_a}.., x_{i}
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 11
#    end_index: 7
# 4. y_{m}
#    core type: IndexedVar
# variable: 8
# index: 14
# 5. z_{1}, ..z_{_a}.., z_{k}
#    core type: ExprRange
#    lambda_map: 10
#    start_index: 11
#    end_index: 12
# 6. _a -> x_{_a}
#    core type: Lambda
#    parameter: 19
#    body: 13
# 7. i
#    core type: Variable
#    sub-expressions:
# 8. y
#    core type: Variable
#    sub-expressions:
# 9. (m)
#    core type: ExprTuple
#    sub-expressions: 14
# 10. _a -> z_{_a}
#     core type: Lambda
#     parameter: 19
#     body: 15
# 11. 1
#     core type: Literal
# ...
