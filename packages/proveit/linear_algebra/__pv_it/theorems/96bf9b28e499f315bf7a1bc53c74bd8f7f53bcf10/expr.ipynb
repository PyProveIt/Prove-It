# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.numbers.Sum.html">Sum</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, fy, y
from proveit.core_expr_types import x_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.numbers import Sum

# %%
# build up the expression from sub-expressions
expr = Sum([y], TensorProd(x_1_to_m, fy, z_1_to_n), domain = S)
# Out:
# expr: Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \sum_{y \in S}~\left(x_{1} {\otimes} \ldots {\otimes} x_{m} {\otimes} f(y) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. Sum_{y in S} (x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n})
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. Sum
#    core type: Literal
#    sub-expressions:
# 2. (y -> {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. y -> {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.
#    core type: Lambda
#    parameter: 23
#    body: 4
# 4. {x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n} if y in S.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. x_{1} otimes ..x_{_a}.. otimes x_{m} otimes f(y) otimes z_{1} otimes ..z_{_a}.. otimes z_{n}
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. y in S
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. otimes
#    core type: Literal
#    sub-expressions:
# 8. (x_{1}, ..x_{_a}.., x_{m}, f(y), z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 11, 12, 13
# 9. in
#    core type: Literal
#    sub-expressions:
# 10. (y, S)
#     core type: ExprTuple
#     sub-expressions: 23, 14
# 11. x_{1}, ..x_{_a}.., x_{m}
#     core type: ExprRange
#     lambda_map: 15
#     start_index: 20
#     end_index: 16
# 12. f(y)
#     core type: Operation
#     operator: 17
#     operand: 23
# 13. z_{1}, ..z_{_a}.., z_{n}
#     core type: ExprRange
#     lambda_map: 19
#     start_index: 20
#     end_index: 21
# 14. S
#     core type: Variable
#     sub-expressions:
# 15. _a -> x_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 22
# 16. m
#     core type: Variable
#     sub-expressions:
# 17. f
#     core type: Variable
#     sub-expressions:
# 18. (y)
#     core type: ExprTuple
#     sub-expressions: 23
# 19. _a -> z_{_a}
#     core type: Lambda
#     parameter: 28
#     body: 24
# 20. 1
#     core type: Literal
#     sub-expressions:
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. x_{_a}
#     core type: IndexedVar
# variable: 25
# index: 28
# 23. y
#     core type: Variable
#     sub-expressions:
# 24. z_{_a}
#     core type: IndexedVar
# variable: 26
# index: 28
# 25. x
#     core type: Variable
#     sub-expressions:
# 26. z
#     core type: Variable
#     sub-expressions:
# 27. (_a)
#     core type: ExprTuple
#     sub-expressions: 28
# 28. _a
#     core type: Variable
#     sub-expressions:
