# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, Conditional, Lambda, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Complex, Exp

# %%
# build up the expression from sub-expressions
expr = Lambda(b, Conditional(Forall([A, x], Implies(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))), InSet(b, Complex)))
# Out:
# expr: b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# b \mapsto \left\{\forall_{A, x}~\left(\left(\left(A \thinspace x\right) = \left(b \thinspace x\right)\right) \Rightarrow \left(\left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)\right) \textrm{ if } b \in \mathbb{C}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. b -> {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Lambda
#    parameter: 35
#    body: 1
# 1. {forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))) if b in Complex.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. forall_{A, x} (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. b in Complex
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. ((A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x))))
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (b, Complex)
#    core type: ExprTuple
#    sub-expressions: 35, 9
# 8. (A, x) -> (((A . x) = (b * x)) => ((A^{k} . x) = (b^{k} * x)))
#    core type: Lambda
#    parameters: 22\n   body: 10
# 9. Complex
#    core type: Literal
#    sub-expressions:
# ...
