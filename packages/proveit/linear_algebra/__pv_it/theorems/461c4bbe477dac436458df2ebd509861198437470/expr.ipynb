# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, U, k, n
from proveit.linear_algebra import SU
from proveit.logic import And, Forall, InSet
from proveit.numbers import Exp, NaturalPos

# %%
# build up the expression from sub-expressions
sub_expr1 = SU(n)
expr = Conditional(Forall([U], InSet(Exp(U, k), sub_expr1), domain = sub_expr1), And(InSet(n, NaturalPos), InSet(k, NaturalPos)))
# Out:
# expr: {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{U \in SU(n)}~\left(U^{k} \in SU(n)\right) \textrm{ if } n \in \mathbb{N}^+ ,  k \in \mathbb{N}^+\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{U in SU(n)} (U^{k} in SU(n)) if n in NaturalPos ,  k in NaturalPos.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{U in SU(n)} (U^{k} in SU(n))
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (n in NaturalPos) and (k in NaturalPos)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (U -> {U^{k} in SU(n) if U in SU(n).)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (n in NaturalPos, k in NaturalPos)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. U -> {U^{k} in SU(n) if U in SU(n).
#    core type: Lambda
#    parameter: 25
#    body: 10
# 8. n in NaturalPos
#    core type: Operation
#    operator: 17
#    operands: 11
# 9. k in NaturalPos
#    core type: Operation
#    operator: 17
#    operands: 12
# 10. {U^{k} in SU(n) if U in SU(n).
#     core type: Conditional
#     value: 13
# ...
