# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, IndexedVar, i, j, k, m, y
from proveit.core_expr_types import x_1_to_i, y_1_to_j, z_1_to_k
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, Forall, InSet
from proveit.numbers import Add, Natural, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([x_1_to_i, y_1_to_j, z_1_to_k], Equals(TensorProd(x_1_to_i, Add(y_1_to_j), z_1_to_k), Add(ExprRange(m, TensorProd(x_1_to_i, IndexedVar(y, m), z_1_to_k), one, j)))), And(InSet(i, Natural), InSet(j, Natural), InSet(k, Natural)))
# Out:
# expr: {forall_{x_{1}, ..x_{_a}.., x_{i}, y_{1}, ..y_{_a}.., y_{j}, z_{1}, ..z_{_a}.., z_{k}} ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes (y_{1} + ..y_{_a}.. + y_{j}) otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) = ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) + ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).. + (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}))) if i in Natural ,  j in Natural ,  k in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{x_{1}, \ldots, x_{i}, y_{1}, \ldots, y_{j}, z_{1}, \ldots, z_{k}}~\left(\left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} \left(y_{1} + \ldots + y_{j}\right) {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right) = \left(\left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{1} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right) + \ldots + \left(x_{1} {\otimes} \ldots {\otimes} x_{i} {\otimes} y_{j} {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{k}\right)\right)\right) \textrm{ if } i \in \mathbb{N} ,  j \in \mathbb{N} ,  k \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{x_{1}, ..x_{_a}.., x_{i}, y_{1}, ..y_{_a}.., y_{j}, z_{1}, ..z_{_a}.., z_{k}} ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes (y_{1} + ..y_{_a}.. + y_{j}) otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) = ((x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{1} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}) + ..(x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{m} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}).. + (x_{1} otimes ..x_{_a}.. otimes x_{i} otimes y_{j} otimes z_{1} otimes ..z_{_a}.. otimes z_{k}))) if i in Natural ,  j in Natural ,  k in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# ...
