# %% [markdown]
# Temporary notebook for <a class="ProveItLink" href="../../../_theorems_.ipynb#tensor_prod_equiv_by_elimination">tensor_prod_equiv_by_elimination</a> of type <a href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # a not-yet-official theorem from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_theorem_expr # Load the stored theorem expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import m, n, x, y
from proveit.core_expr_types import a_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall, Iff
from proveit.numbers import Natural

# %%
# build up the expression from sub-expressions
expr = Forall([m, n], Forall([a_1_to_m, x, y, z_1_to_n], Iff(Equals(TensorProd(a_1_to_m, x, z_1_to_n), TensorProd(a_1_to_m, y, z_1_to_n)), Equals(x, y))), domain = Natural)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: tensor_prod_equiv_by_elimination matches stored_expr")

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())

# %%
expr.style_options()

# %%
# display the expression information
expr.expr_info()
