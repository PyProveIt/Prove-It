# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals
from proveit.numbers import Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = Equals(Sum(sub_expr1, TensorProd(a, bj), domain = sub_expr2), TensorProd(a, Sum(sub_expr1, bj, domain = sub_expr2)))
# Out:
# expr: (Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j}))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\sum_{j=c}^{d} \left(a {\otimes} b_{j}\right)\right) = \left(a {\otimes} \left(\sum_{j=c}^{d} b_{j}\right)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j}))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. (Sum_{j=c}^{d} (a otimes b_{j}), a otimes (Sum_{j=c}^{d} b_{j}))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. Sum_{j=c}^{d} (a otimes b_{j})
#    core type: Operation
#    operator: 10
#    operand: 7
# 4. a otimes (Sum_{j=c}^{d} b_{j})
#    core type: Operation
#    operator: 14
#    operands: 6
# 5. (j -> {a otimes b_{j} if j in {c .. d}.)
#    core type: ExprTuple
#    sub-expressions: 7
# 6. (a, Sum_{j=c}^{d} b_{j})
#    core type: ExprTuple
#    sub-expressions: 17, 8
# 7. j -> {a otimes b_{j} if j in {c .. d}.
#    core type: Lambda
#    parameter: 24
#    body: 9
# 8. Sum_{j=c}^{d} b_{j}
#    core type: Operation
#    operator: 10
#    operand: 13
# 9. {a otimes b_{j} if j in {c .. d}.
#    core type: Conditional
#    value: 12
#    condition: 19
# 10. Sum
#     core type: Literal
#     sub-expressions:
# 11. (j -> {b_{j} if j in {c .. d}.)
#     core type: ExprTuple
#     sub-expressions: 13
# 12. a otimes b_{j}
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. j -> {b_{j} if j in {c .. d}.
#     core type: Lambda
#     parameter: 24
#     body: 16
# 14. otimes
#     core type: Literal
#     sub-expressions:
# 15. (a, b_{j})
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. {b_{j} if j in {c .. d}.
#     core type: Conditional
#     value: 18
#     condition: 19
# 17. a
#     core type: Variable
#     sub-expressions:
# 18. b_{j}
#     core type: IndexedVar
# variable: 20
# index: 24
# 19. j in {c .. d}
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. b
#     core type: Variable
#     sub-expressions:
# 21. (j)
#     core type: ExprTuple
#     sub-expressions: 24
# 22. in
#     core type: Literal
#     sub-expressions:
# 23. (j, {c .. d})
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. j
#     core type: Variable
#     sub-expressions:
# 25. {c .. d}
#     core type: Operation
#     operator: 26
#     operands: 27
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (c, d)
#     core type: ExprTuple
#     sub-expressions: 28, 29
# 28. c
#     core type: Variable
#     sub-expressions:
# 29. d
#     core type: Variable
#     sub-expressions:
