# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import A, ExprTuple, b, k, x
from proveit.linear_algebra import MatrixProd, ScalarProd
from proveit.logic import Equals
from proveit.numbers import Exp

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Equals(MatrixProd(A, x), ScalarProd(b, x)), Equals(MatrixProd(Exp(A, k), x), ScalarProd(Exp(b, k), x)))
# Out:
# expr: ((A . x) = (b * x), (A^{k} . x) = (b^{k} * x))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(A \thinspace x\right) = \left(b \thinspace x\right), \left(A^{k} \thinspace x\right) = \left(b^{k} \thinspace x\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((A . x) = (b * x), (A^{k} . x) = (b^{k} * x))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (A . x) = (b * x)
#    core type: Operation
#    operator: 4
#    operands: 3
# 2. (A^{k} . x) = (b^{k} * x)
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (A . x, b * x)
#    core type: ExprTuple
#    sub-expressions: 6, 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (A^{k} . x, b^{k} * x)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. A . x
#    core type: Operation
#    operator: 12
#    operands: 10
# 7. b * x
#    core type: Operation
#    operator: 14
#    operands: 11
# 8. A^{k} . x
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. b^{k} * x
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. (A, x)
#     core type: ExprTuple
#     sub-expressions: 22, 18
# 11. (b, x)
#     core type: ExprTuple
#     sub-expressions: 23, 18
# 12. .
#     core type: Literal
#     sub-expressions:
# 13. (A^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 16, 18
# 14. *
#     core type: Literal
#     sub-expressions:
# 15. (b^{k}, x)
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. A^{k}
#     core type: Operation
#     operator: 20
#     operands: 19
# 17. b^{k}
#     core type: Operation
#     operator: 20
#     operands: 21
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. (A, k)
#     core type: ExprTuple
#     sub-expressions: 22, 24
# 20. Exp
#     core type: Literal
#     sub-expressions:
# 21. (b, k)
#     core type: ExprTuple
#     sub-expressions: 23, 24
# 22. A
#     core type: Variable
#     sub-expressions:
# 23. b
#     core type: Variable
#     sub-expressions:
# 24. k
#     core type: Variable
#     sub-expressions:
