# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import a, b, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Forall
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = Forall([a, b], Forall([c, d], Equals(Sum(sub_expr1, TensorProd(a, bj), domain = sub_expr2), TensorProd(a, Sum(sub_expr1, bj, domain = sub_expr2))), domain = Integer))
# Out:
# expr: forall_{a, b} [forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b}~\left[\forall_{c, d \in \mathbb{Z}}~\left(\left(\sum_{j=c}^{d} \left(a {\otimes} b_{j}\right)\right) = \left(a {\otimes} \left(\sum_{j=c}^{d} b_{j}\right)\right)\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b} [forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))]
#    core type: Operation
#    operator: 5
#    operand: 2
# 1. ((a, b) -> [forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))])
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (a, b) -> [forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))]
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (a, b)
#    core type: ExprTuple
#    sub-expressions: 34, 37
# 4. forall_{c, d in Integer} ((Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})))
#    core type: Operation
#    operator: 5
#    operand: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. ((c, d) -> {(Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})) if c in Integer ,  d in Integer.)
#    core type: ExprTuple
#    sub-expressions: 7
# ...
