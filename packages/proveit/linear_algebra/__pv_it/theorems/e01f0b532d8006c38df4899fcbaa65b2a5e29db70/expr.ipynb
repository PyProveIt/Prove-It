# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, x, y
from proveit.core_expr_types import a_1_to_m, z_1_to_n
from proveit.linear_algebra import TensorProd
from proveit.logic import Equals, Iff

# %%
# build up the expression from sub-expressions
expr = Lambda([a_1_to_m, x, y, z_1_to_n], Iff(Equals(TensorProd(a_1_to_m, x, z_1_to_n), TensorProd(a_1_to_m, y, z_1_to_n)), Equals(x, y)))
# Out:
# expr: (a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}) -> (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1}, \ldots, a_{m}, x, y, z_{1}, \ldots, z_{n}\right) \mapsto \left(\left(\left(a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} x {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right) = \left(a_{1} {\otimes} \ldots {\otimes} a_{m} {\otimes} y {\otimes} z_{1} {\otimes} \ldots {\otimes} z_{n}\right)\right) \Leftrightarrow \left(x = y\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n}) -> (((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y))
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (a_{1}, ..a_{_a}.., a_{m}, x, y, z_{1}, ..z_{_a}.., z_{n})
#    core type: ExprTuple
#    sub-expressions: 16, 15, 17, 18
# 2. ((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n})) <=> (x = y)
#    core type: Operation
#    operator: 3
#    operands: 4
# 3. <=>
#    core type: Literal
#    sub-expressions:
# 4. ((a_{1} otimes ..a_{_a}.. otimes a_{m} otimes x otimes z_{1} otimes ..z_{_a}.. otimes z_{n}) = (a_{1} otimes ..a_{_a}.. otimes a_{m} otimes y otimes z_{1} otimes ..z_{_a}.. otimes z_{n}), x = y)
#    core type: ExprTuple
# ...
