# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, a, c, d, j
from proveit.core_expr_types import bj
from proveit.linear_algebra import TensorProd
from proveit.logic import And, Equals, InSet
from proveit.numbers import Integer, Interval, Sum

# %%
# build up the expression from sub-expressions
sub_expr1 = [j]
sub_expr2 = Interval(c, d)
expr = Lambda([c, d], Conditional(Equals(Sum(sub_expr1, TensorProd(a, bj), domain = sub_expr2), TensorProd(a, Sum(sub_expr1, bj, domain = sub_expr2))), And(InSet(c, Integer), InSet(d, Integer))))
# Out:
# expr: (c, d) -> {(Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})) if c in Integer ,  d in Integer.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(c, d\right) \mapsto \left\{\left(\sum_{j=c}^{d} \left(a {\otimes} b_{j}\right)\right) = \left(a {\otimes} \left(\sum_{j=c}^{d} b_{j}\right)\right) \textrm{ if } c \in \mathbb{Z} ,  d \in \mathbb{Z}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (c, d) -> {(Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})) if c in Integer ,  d in Integer.
#    core type: Lambda
#    parameters: 37\n   body: 1
# 1. {(Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j})) if c in Integer ,  d in Integer.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. (Sum_{j=c}^{d} (a otimes b_{j})) = (a otimes (Sum_{j=c}^{d} b_{j}))
#    core type: Operation
#    operator: 4
#    operands: 5
# 3. (c in Integer) and (d in Integer)
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. (Sum_{j=c}^{d} (a otimes b_{j}), a otimes (Sum_{j=c}^{d} b_{j}))
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 6. and
#    core type: Literal
#    sub-expressions:
# 7. (c in Integer, d in Integer)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 8. Sum_{j=c}^{d} (a otimes b_{j})
#    core type: Operation
#    operator: 20
#    operand: 16
# ...
