# %% [markdown]
# Axiom <a class="ProveItLink" href="../../../_axioms_.ipynb#tensor_exp_one">tensor_exp_one</a> of type <a class="ProveItLink" href="../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.linear_algebra</a>
# *** see <a class="ProveItLink" href="dependencies.ipynb">dependencies</a> ***

# %%
import proveit
# Automation is not needed when only building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_axiom_expr # Load the stored axiom expression as 'stored_expr'
# import the special expression
from proveit.linear_algebra import tensor_exp_one

# %%
# check that the built expression is the same as the stored expression
assert tensor_exp_one.expr == stored_expr
assert tensor_exp_one.expr._style_id == stored_expr._style_id
print("Passed sanity check: tensor_exp_one matches stored_expr")
# Out:
# Passed sanity check: tensor_exp_one matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(tensor_exp_one.latex())
# Out:
# \vdash \forall_{x}~\left(x^{\otimes 1} = x\right)

# %%
tensor_exp_one.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
tensor_exp_one.expr_info()
# Out:
# 0. forall_{x} (x^{otimes 1} = x)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> (x^{otimes 1} = x))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> (x^{otimes 1} = x)
#    core type: Lambda
#    parameter: 10
#    body: 4
# 4. x^{otimes 1} = x
#    core type: Operation
#    operator: 5
#    operands: 6
# 5. =
#    core type: Literal
#    sub-expressions:
# 6. (x^{otimes 1}, x)
#    core type: ExprTuple
#    sub-expressions: 7, 10
# 7. x^{otimes 1}
#    core type: Operation
#    operator: 8
#    operands: 9
# 8. otimes
#    core type: Literal
#    sub-expressions:
# 9. (x, 1)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 10. x
#     core type: Variable
#     sub-expressions:
# 11. 1
#     core type: Literal
#     sub-expressions:
