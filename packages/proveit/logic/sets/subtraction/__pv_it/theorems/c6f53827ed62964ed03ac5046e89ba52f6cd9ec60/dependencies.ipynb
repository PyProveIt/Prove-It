# %% [markdown]
# Theorem Dependencies
# =======================
#
# ## <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>.<a class="ProveItLink" href="../../../_theorems_.ipynb#all_but_one_membership_folding">all_but_one_membership_folding</a>
# ***see <a class="ProveItLink" href="../../../_theory_nbs_/proofs/all_but_one_membership_folding/thm_proof.ipynb">proof</a>***

# %%
import proveit
# Automation is not needed when querying dependencies:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
from proveit.logic.sets.subtraction import all_but_one_membership_folding

# %%
# %dependencies all_but_one_membership_folding
# Out:
# <h3>This theorem has not been proven yet.</h3>
# <h3>Theorems/conjectures that depend directly on all_but_one_membership_folding</h3>
# <dl>
# <dt><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/_theory_nbs_/proofs/neg_domain_in_full_domain_sans_zero/thm_proof.ipynb">proveit.physics.quantum.QPE.neg_domain_in_full_domain_sans_zero</a></dt><dd><a class="ProveItLink" href="../../../../../../physics/quantum/QPE/__pv_it/theorems/246c40faec929908d142ddbe3fa4a414bb0b35b60/expr.ipynb"><img src="../../../../../../physics/quantum/QPE/__pv_it/theorems/246c40faec929908d142ddbe3fa4a414bb0b35b60/expr.png" style="display:inline;vertical-align:middle;" /></a></dd>
# ...
