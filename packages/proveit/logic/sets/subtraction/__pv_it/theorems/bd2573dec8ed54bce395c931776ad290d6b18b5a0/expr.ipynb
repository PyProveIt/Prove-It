# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, S, x, y
from proveit.logic import Difference, Equals, Forall, NotInSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([S, y], Forall([x], NotInSet(x, Difference(S, Set(y))), condition = Or(NotInSet(x, S), Equals(x, y)))))
# Out:
# expr: ((S, y) -> [forall_{x | (x not-in S) or (x = y)} (x not-in (S - {y}))])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(S, y\right) \mapsto \left[\forall_{x~|~\left(x \notin S\right) \lor \left(x = y\right)}~\left(x \notin \left(S - \left\{y\right\}\right)\right)\right]\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((S, y) -> [forall_{x | (x not-in S) or (x = y)} (x not-in (S - {y}))])
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (S, y) -> [forall_{x | (x not-in S) or (x = y)} (x not-in (S - {y}))]
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (S, y)
#    core type: ExprTuple
#    sub-expressions: 23, 27
# 3. forall_{x | (x not-in S) or (x = y)} (x not-in (S - {y}))
#    core type: Operation
#    operator: 4
#    operand: 6
# 4. forall
#    core type: Literal
#    sub-expressions:
# 5. (x -> {x not-in (S - {y}) if (x not-in S) or (x = y).)
#    core type: ExprTuple
#    sub-expressions: 6
# 6. x -> {x not-in (S - {y}) if (x not-in S) or (x = y).
#    core type: Lambda
#    parameter: 24
#    body: 7
# 7. {x not-in (S - {y}) if (x not-in S) or (x = y).
#    core type: Conditional
#    value: 8
#    condition: 9
# 8. x not-in (S - {y})
#    core type: Operation
#    operator: 18
#    operands: 10
# 9. (x not-in S) or (x = y)
#    core type: Operation
#    operator: 11
#    operands: 12
# 10. (x, S - {y})
#     core type: ExprTuple
#     sub-expressions: 24, 13
# 11. or
#     core type: Literal
#     sub-expressions:
# 12. (x not-in S, x = y)
#     core type: ExprTuple
#     sub-expressions: 14, 15
# 13. S - {y}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. x not-in S
#     core type: Operation
#     operator: 18
#     operands: 19
# 15. x = y
#     core type: Operation
#     operator: 20
#     operands: 21
# 16. -
#     core type: Literal
#     sub-expressions:
# 17. (S, {y})
#     core type: ExprTuple
#     sub-expressions: 23, 22
# 18. not-in
#     core type: Literal
#     sub-expressions:
# 19. (x, S)
#     core type: ExprTuple
#     sub-expressions: 24, 23
# 20. =
#     core type: Literal
#     sub-expressions:
# 21. (x, y)
#     core type: ExprTuple
#     sub-expressions: 24, 27
# 22. {y}
#     core type: Operation
#     operator: 25
#     operand: 27
# 23. S
#     core type: Variable
#     sub-expressions:
# 24. x
#     core type: Variable
#     sub-expressions:
# 25. Set
#     core type: Literal
#     sub-expressions:
# 26. (y)
#     core type: ExprTuple
#     sub-expressions: 27
# 27. y
#     core type: Variable
#     sub-expressions:
