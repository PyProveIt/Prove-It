# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import S, x, y
from proveit.logic import Difference, Equals, Forall, NotInSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Forall([x], Or(NotInSet(x, S), Equals(x, y)), condition = NotInSet(x, Difference(S, Set(y))))
# Out:
# expr: forall_{x | x not-in (S - {y})} ((x not-in S) or (x = y))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{x~|~x \notin \left(S - \left\{y\right\}\right)}~\left(\left(x \notin S\right) \lor \left(x = y\right)\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{x | x not-in (S - {y})} ((x not-in S) or (x = y))
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. (x -> {(x not-in S) or (x = y) if x not-in (S - {y}).)
#    core type: ExprTuple
#    sub-expressions: 3
# 3. x -> {(x not-in S) or (x = y) if x not-in (S - {y}).
#    core type: Lambda
#    parameter: 19
#    body: 4
# 4. {(x not-in S) or (x = y) if x not-in (S - {y}).
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. (x not-in S) or (x = y)
#    core type: Operation
#    operator: 7
#    operands: 8
# 6. x not-in (S - {y})
#    core type: Operation
#    operator: 13
#    operands: 9
# 7. or
#    core type: Literal
#    sub-expressions:
# 8. (x not-in S, x = y)
#    core type: ExprTuple
#    sub-expressions: 10, 11
# 9. (x, S - {y})
#    core type: ExprTuple
#    sub-expressions: 19, 12
# 10. x not-in S
#     core type: Operation
#     operator: 13
#     operands: 14
# 11. x = y
#     core type: Operation
#     operator: 15
#     operands: 16
# 12. S - {y}
#     core type: Operation
#     operator: 17
#     operands: 18
# 13. not-in
#     core type: Literal
#     sub-expressions:
# 14. (x, S)
#     core type: ExprTuple
#     sub-expressions: 19, 20
# 15. =
#     core type: Literal
#     sub-expressions:
# 16. (x, y)
#     core type: ExprTuple
#     sub-expressions: 19, 24
# 17. -
#     core type: Literal
#     sub-expressions:
# 18. (S, {y})
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 19. x
#     core type: Variable
#     sub-expressions:
# 20. S
#     core type: Variable
#     sub-expressions:
# 21. {y}
#     core type: Operation
#     operator: 22
#     operand: 24
# 22. Set
#     core type: Literal
#     sub-expressions:
# 23. (y)
#     core type: ExprTuple
#     sub-expressions: 24
# 24. y
#     core type: Variable
#     sub-expressions:
