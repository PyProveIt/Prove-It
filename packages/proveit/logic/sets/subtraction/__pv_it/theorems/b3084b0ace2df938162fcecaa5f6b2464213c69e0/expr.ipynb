# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Lambda, S, x, y
from proveit.logic import Difference, Equals, Forall, NotInSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Lambda([S, y], Forall([x], Or(NotInSet(x, S), Equals(x, y)), condition = NotInSet(x, Difference(S, Set(y)))))
# Out:
# expr: (S, y) -> [forall_{x | x not-in (S - {y})} ((x not-in S) or (x = y))]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(S, y\right) \mapsto \left[\forall_{x~|~x \notin \left(S - \left\{y\right\}\right)}~\left(\left(x \notin S\right) \lor \left(x = y\right)\right)\right]

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (S, y) -> [forall_{x | x not-in (S - {y})} ((x not-in S) or (x = y))]
#    core type: Lambda
#    parameters: 1\n   body: 2
# 1. (S, y)
#    core type: ExprTuple
#    sub-expressions: 22, 26
# 2. forall_{x | x not-in (S - {y})} ((x not-in S) or (x = y))
#    core type: Operation
#    operator: 3
#    operand: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {(x not-in S) or (x = y) if x not-in (S - {y}).)
#    core type: ExprTuple
#    sub-expressions: 5
# 5. x -> {(x not-in S) or (x = y) if x not-in (S - {y}).
#    core type: Lambda
#    parameter: 21
#    body: 6
# 6. {(x not-in S) or (x = y) if x not-in (S - {y}).
#    core type: Conditional
#    value: 7
#    condition: 8
# 7. (x not-in S) or (x = y)
#    core type: Operation
#    operator: 9
#    operands: 10
# 8. x not-in (S - {y})
#    core type: Operation
#    operator: 15
#    operands: 11
# 9. or
#    core type: Literal
#    sub-expressions:
# 10. (x not-in S, x = y)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (x, S - {y})
#     core type: ExprTuple
#     sub-expressions: 21, 14
# 12. x not-in S
#     core type: Operation
#     operator: 15
#     operands: 16
# 13. x = y
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. S - {y}
#     core type: Operation
#     operator: 19
#     operands: 20
# 15. not-in
#     core type: Literal
#     sub-expressions:
# 16. (x, S)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 17. =
#     core type: Literal
#     sub-expressions:
# 18. (x, y)
#     core type: ExprTuple
#     sub-expressions: 21, 26
# 19. -
#     core type: Literal
#     sub-expressions:
# 20. (S, {y})
#     core type: ExprTuple
#     sub-expressions: 22, 23
# 21. x
#     core type: Variable
#     sub-expressions:
# 22. S
#     core type: Variable
#     sub-expressions:
# 23. {y}
#     core type: Operation
#     operator: 24
#     operand: 26
# 24. Set
#     core type: Literal
#     sub-expressions:
# 25. (y)
#     core type: ExprTuple
#     sub-expressions: 26
# 26. y
#     core type: Variable
#     sub-expressions:
