# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.logic.sets.subtraction</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, S, x, y
from proveit.logic import Difference, Equals, NotInSet, Or, Set

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(NotInSet(x, Difference(S, Set(y))), Or(NotInSet(x, S), Equals(x, y))))
# Out:
# expr: x -> {x not-in (S - {y}) if (x not-in S) or (x = y).

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{x \notin \left(S - \left\{y\right\}\right) \textrm{ if } \left(x \notin S\right) \lor \left(x = y\right)\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {x not-in (S - {y}) if (x not-in S) or (x = y).
#    core type: Lambda
#    parameter: 18
#    body: 1
# 1. {x not-in (S - {y}) if (x not-in S) or (x = y).
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. x not-in (S - {y})
#    core type: Operation
#    operator: 12
#    operands: 4
# 3. (x not-in S) or (x = y)
#    core type: Operation
#    operator: 5
#    operands: 6
# 4. (x, S - {y})
#    core type: ExprTuple
#    sub-expressions: 18, 7
# 5. or
#    core type: Literal
#    sub-expressions:
# 6. (x not-in S, x = y)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 7. S - {y}
#    core type: Operation
#    operator: 10
#    operands: 11
# 8. x not-in S
#    core type: Operation
#    operator: 12
#    operands: 13
# 9. x = y
#    core type: Operation
#    operator: 14
#    operands: 15
# 10. -
#     core type: Literal
#     sub-expressions:
# 11. (S, {y})
#     core type: ExprTuple
#     sub-expressions: 17, 16
# 12. not-in
#     core type: Literal
#     sub-expressions:
# 13. (x, S)
#     core type: ExprTuple
#     sub-expressions: 18, 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (x, y)
#     core type: ExprTuple
#     sub-expressions: 18, 21
# 16. {y}
#     core type: Operation
#     operator: 19
#     operand: 21
# 17. S
#     core type: Variable
#     sub-expressions:
# 18. x
#     core type: Variable
#     sub-expressions:
# 19. Set
#     core type: Literal
#     sub-expressions:
# 20. (y)
#     core type: ExprTuple
#     sub-expressions: 21
# 21. y
#     core type: Variable
#     sub-expressions:
