# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprTuple, Lambda, fx, gx, x
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], Equals(fx, gx)), Equals(Lambda(x, fx), Lambda(x, gx)))
# Out:
# expr: (forall_{x} (f(x) = g(x)), [x -> f(x)] = [x -> g(x)])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x}~\left(f(x) = g(x)\right), \left[x \mapsto f(x)\right] = \left[x \mapsto g(x)\right]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x} (f(x) = g(x)), [x -> f(x)] = [x -> g(x)])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x} (f(x) = g(x))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [x -> f(x)] = [x -> g(x)]
#    core type: Operation
#    operator: 10
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> (f(x) = g(x)))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x -> f(x), x -> g(x))
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> (f(x) = g(x))
#    core type: Lambda
#    parameter: 17
#    body: 9
# 7. x -> f(x)
#    core type: Lambda
#    parameter: 17
#    body: 12
# 8. x -> g(x)
#    core type: Lambda
#    parameter: 17
#    body: 13
# 9. f(x) = g(x)
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. =
#     core type: Literal
#     sub-expressions:
# 11. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. f(x)
#     core type: Operation
#     operator: 14
#     operand: 17
# 13. g(x)
#     core type: Operation
#     operator: 15
#     operand: 17
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. g
#     core type: Variable
#     sub-expressions:
# 16. (x)
#     core type: ExprTuple
#     sub-expressions: 17
# 17. x
#     core type: Variable
#     sub-expressions:
