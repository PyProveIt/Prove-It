# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.lambda_maps</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, Qx, fx, gx, x
from proveit.logic import Equals, Forall

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Forall([x], Equals(fx, gx), condition = Qx), Equals(Lambda(x, Conditional(fx, Qx)), Lambda(x, Conditional(gx, Qx))))
# Out:
# expr: (forall_{x | Q(x)} (f(x) = g(x)), [x -> {f(x) if Q(x).] = [x -> {g(x) if Q(x).])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x~|~Q(x)}~\left(f(x) = g(x)\right), \left[x \mapsto \left\{f(x) \textrm{ if } Q(x)\right..\right] = \left[x \mapsto \left\{g(x) \textrm{ if } Q(x)\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x | Q(x)} (f(x) = g(x)), [x -> {f(x) if Q(x).] = [x -> {g(x) if Q(x).])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x | Q(x)} (f(x) = g(x))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [x -> {f(x) if Q(x).] = [x -> {g(x) if Q(x).]
#    core type: Operation
#    operator: 14
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {f(x) = g(x) if Q(x).)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x -> {f(x) if Q(x)., x -> {g(x) if Q(x).)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> {f(x) = g(x) if Q(x).
#    core type: Lambda
#    parameter: 22
#    body: 9
# 7. x -> {f(x) if Q(x).
#    core type: Lambda
#    parameter: 22
#    body: 10
# 8. x -> {g(x) if Q(x).
#    core type: Lambda
#    parameter: 22
#    body: 11
# 9. {f(x) = g(x) if Q(x).
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. {f(x) if Q(x).
#     core type: Conditional
#     value: 17
#     condition: 13
# 11. {g(x) if Q(x).
#     core type: Conditional
#     value: 18
#     condition: 13
# 12. f(x) = g(x)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. Q(x)
#     core type: Operation
#     operator: 16
#     operand: 22
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 17, 18
# 16. Q
#     core type: Variable
#     sub-expressions:
# 17. f(x)
#     core type: Operation
#     operator: 19
#     operand: 22
# 18. g(x)
#     core type: Operation
#     operator: 20
#     operand: 22
# 19. f
#     core type: Variable
#     sub-expressions:
# 20. g
#     core type: Variable
#     sub-expressions:
# 21. (x)
#     core type: ExprTuple
#     sub-expressions: 22
# 22. x
#     core type: Variable
#     sub-expressions:
