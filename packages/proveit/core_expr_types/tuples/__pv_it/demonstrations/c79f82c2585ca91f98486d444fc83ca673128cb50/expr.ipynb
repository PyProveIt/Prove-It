# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function, f, i, j
from proveit.core_expr_types import f_i_to_j
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = ExprTuple([f_i_to_j], [ExprRange(i, Function(f, [Add(i, one)]), Add(i, sub_expr1), Add(j, sub_expr1))])
# Out:
# expr: ((f(i), ..f(a).., f(j)), (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f(i), \ldots, f(j)\right), \left(f(\left(i - 1\right) + 1), \ldots, f(\left(j - 1\right) + 1)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f(i), ..f(a).., f(j)), (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (f(i), ..f(a).., f(j))
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 24
#    end_index: 16
# 4. f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1)
#    core type: ExprRange
#    lambda_map: 6
#    start_index: 7
#    end_index: 8
# 5. a -> f(a)
#    core type: Lambda
#    parameter: 18
#    body: 9
# 6. i -> f(i + 1)
#    core type: Lambda
#    parameter: 24
#    body: 10
# 7. i - 1
#    core type: Operation
#    operator: 22
#    operands: 11
# 8. j - 1
#    core type: Operation
#    operator: 22
#    operands: 12
# 9. f(a)
#    core type: Operation
#    operator: 14
#    operand: 18
# 10. f(i + 1)
#     core type: Operation
#     operator: 14
#     operand: 19
# 11. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 24, 17
# 12. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 16, 17
# 13. (a)
#     core type: ExprTuple
#     sub-expressions: 18
# 14. f
#     core type: Variable
#     sub-expressions:
# 15. (i + 1)
#     core type: ExprTuple
#     sub-expressions: 19
# 16. j
#     core type: Variable
#     sub-expressions:
# 17. -1
#     core type: Operation
#     operator: 20
#     operand: 25
# 18. a
#     core type: Variable
#     sub-expressions:
# 19. i + 1
#     core type: Operation
#     operator: 22
#     operands: 23
# 20. -
#     core type: Literal
#     sub-expressions:
# 21. (1)
#     core type: ExprTuple
#     sub-expressions: 25
# 22. +
#     core type: Literal
#     sub-expressions:
# 23. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 24, 25
# 24. i
#     core type: Variable
#     sub-expressions:
# 25. 1
#     core type: Literal
#     sub-expressions:
