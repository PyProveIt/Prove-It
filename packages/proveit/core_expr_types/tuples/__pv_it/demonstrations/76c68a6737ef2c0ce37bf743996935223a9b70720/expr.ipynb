# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, ExprTuple, Function, f, i, j, k
from proveit.numbers import Add, Neg, one, two

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
sub_expr2 = Neg(two)
expr = ExprTuple([ExprRange(k, Function(f, [Add(k, one)]), Add(i, sub_expr1), Add(j, sub_expr1))], [ExprRange(i, Function(f, [Add(i, two)]), Add(i, sub_expr2), Add(j, sub_expr2))])
# Out:
# expr: ((f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)), (f((i - 2) + 2), ..f(i + 2).., f((j - 2) + 2)))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(f(\left(i - 1\right) + 1), \ldots, f(\left(j - 1\right) + 1)\right), \left(f(\left(i - 2\right) + 2), \ldots, f(\left(j - 2\right) + 2)\right)\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)), (f((i - 2) + 2), ..f(i + 2).., f((j - 2) + 2)))
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. (f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 3
# 2. (f((i - 2) + 2), ..f(i + 2).., f((j - 2) + 2))
#    core type: ExprTuple
#    sub-expressions: 4
# 3. f((i - 1) + 1), ..f(k + 1).., f((j - 1) + 1)
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 4. f((i - 2) + 2), ..f(i + 2).., f((j - 2) + 2)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 5. k -> f(k + 1)
#    core type: Lambda
#    parameter: 31
#    body: 11
# 6. i - 1
#    core type: Operation
#    operator: 29
#    operands: 12
# 7. j - 1
#    core type: Operation
#    operator: 29
#    operands: 13
# 8. i -> f(i + 2)
#    core type: Lambda
#    parameter: 33
#    body: 14
# 9. i - 2
#    core type: Operation
#    operator: 29
#    operands: 15
# ...
