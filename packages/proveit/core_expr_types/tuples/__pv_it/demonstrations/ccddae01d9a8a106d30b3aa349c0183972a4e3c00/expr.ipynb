# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.tuples</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import ExprRange, Function, f, i, j
from proveit.core_expr_types import f_i_to_j
from proveit.logic import Equals
from proveit.numbers import Add, Neg, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Neg(one)
expr = Equals([f_i_to_j], [ExprRange(i, Function(f, [Add(i, one)]), Add(i, sub_expr1), Add(j, sub_expr1))])
# Out:
# expr: (f(i), ..f(a).., f(j)) = (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(f(i), \ldots, f(j)\right) = \left(f(\left(i - 1\right) + 1), \ldots, f(\left(j - 1\right) + 1)\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (f(i), ..f(a).., f(j)) = (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1))
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ((f(i), ..f(a).., f(j)), (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1)))
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. (f(i), ..f(a).., f(j))
#    core type: ExprTuple
#    sub-expressions: 5
# 4. (f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1))
#    core type: ExprTuple
#    sub-expressions: 6
# 5. f(i), ..f(a).., f(j)
#    core type: ExprRange
#    lambda_map: 7
#    start_index: 26
#    end_index: 18
# 6. f((i - 1) + 1), ..f(i + 1).., f((j - 1) + 1)
#    core type: ExprRange
#    lambda_map: 8
#    start_index: 9
#    end_index: 10
# 7. a -> f(a)
#    core type: Lambda
#    parameter: 20
#    body: 11
# 8. i -> f(i + 1)
#    core type: Lambda
#    parameter: 26
#    body: 12
# 9. i - 1
#    core type: Operation
#    operator: 24
#    operands: 13
# 10. j - 1
#     core type: Operation
#     operator: 24
#     operands: 14
# 11. f(a)
#     core type: Operation
#     operator: 16
#     operand: 20
# 12. f(i + 1)
#     core type: Operation
#     operator: 16
#     operand: 21
# 13. (i, -1)
#     core type: ExprTuple
#     sub-expressions: 26, 19
# 14. (j, -1)
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 15. (a)
#     core type: ExprTuple
#     sub-expressions: 20
# 16. f
#     core type: Variable
#     sub-expressions:
# 17. (i + 1)
#     core type: ExprTuple
#     sub-expressions: 21
# 18. j
#     core type: Variable
#     sub-expressions:
# 19. -1
#     core type: Operation
#     operator: 22
#     operand: 27
# 20. a
#     core type: Variable
#     sub-expressions:
# 21. i + 1
#     core type: Operation
#     operator: 24
#     operands: 25
# 22. -
#     core type: Literal
#     sub-expressions:
# 23. (1)
#     core type: ExprTuple
#     sub-expressions: 27
# 24. +
#     core type: Literal
#     sub-expressions:
# 25. (i, 1)
#     core type: ExprTuple
#     sub-expressions: 26, 27
# 26. i
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
