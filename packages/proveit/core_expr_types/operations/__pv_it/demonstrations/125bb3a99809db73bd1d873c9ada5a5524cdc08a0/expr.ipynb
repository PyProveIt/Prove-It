# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprTuple, Lambda, fx, gx, n, x
from proveit.logic import Equals, Forall, InSet
from proveit.numbers import Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(one, n)
sub_expr2 = InSet(x, sub_expr1)
expr = ExprTuple(Forall([x], Equals(fx, gx), domain = sub_expr1), Equals(Lambda(x, Conditional(fx, sub_expr2)), Lambda(x, Conditional(gx, sub_expr2))))
# Out:
# expr: (forall_{x in {1 .. n}} (f(x) = g(x)), [x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\forall_{x \in \{1~\ldotp \ldotp~n\}}~\left(f(x) = g(x)\right), \left[x \mapsto \left\{f(x) \textrm{ if } x \in \{1~\ldotp \ldotp~n\}\right..\right] = \left[x \mapsto \left\{g(x) \textrm{ if } x \in \{1~\ldotp \ldotp~n\}\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (forall_{x in {1 .. n}} (f(x) = g(x)), [x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.])
#    core type: ExprTuple
#    sub-expressions: 1, 2
# 1. forall_{x in {1 .. n}} (f(x) = g(x))
#    core type: Operation
#    operator: 3
#    operand: 6
# 2. [x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.]
#    core type: Operation
#    operator: 14
#    operands: 5
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. (x -> {f(x) = g(x) if x in {1 .. n}.)
#    core type: ExprTuple
#    sub-expressions: 6
# 5. (x -> {f(x) if x in {1 .. n}., x -> {g(x) if x in {1 .. n}.)
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 6. x -> {f(x) = g(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 26
#    body: 9
# 7. x -> {f(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 26
#    body: 10
# 8. x -> {g(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 26
#    body: 11
# 9. {f(x) = g(x) if x in {1 .. n}.
#    core type: Conditional
#    value: 12
#    condition: 13
# 10. {f(x) if x in {1 .. n}.
#     core type: Conditional
#     value: 18
#     condition: 13
# 11. {g(x) if x in {1 .. n}.
#     core type: Conditional
#     value: 19
#     condition: 13
# 12. f(x) = g(x)
#     core type: Operation
#     operator: 14
#     operands: 15
# 13. x in {1 .. n}
#     core type: Operation
#     operator: 16
#     operands: 17
# 14. =
#     core type: Literal
#     sub-expressions:
# 15. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 18, 19
# 16. in
#     core type: Literal
#     sub-expressions:
# 17. (x, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 26, 20
# 18. f(x)
#     core type: Operation
#     operator: 21
#     operand: 26
# 19. g(x)
#     core type: Operation
#     operator: 22
#     operand: 26
# 20. {1 .. n}
#     core type: Operation
#     operator: 24
#     operands: 25
# 21. f
#     core type: Variable
#     sub-expressions:
# 22. g
#     core type: Variable
#     sub-expressions:
# 23. (x)
#     core type: ExprTuple
#     sub-expressions: 26
# 24. Interval
#     core type: Literal
#     sub-expressions:
# 25. (1, n)
#     core type: ExprTuple
#     sub-expressions: 27, 28
# 26. x
#     core type: Variable
#     sub-expressions:
# 27. 1
#     core type: Literal
#     sub-expressions:
# 28. n
#     core type: Variable
#     sub-expressions:
