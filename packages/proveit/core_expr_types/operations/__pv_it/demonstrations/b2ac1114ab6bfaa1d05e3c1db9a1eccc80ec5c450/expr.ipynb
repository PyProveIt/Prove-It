# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Lambda.html">Lambda</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, gx, n, x
from proveit.logic import InSet
from proveit.numbers import Interval, one

# %%
# build up the expression from sub-expressions
expr = Lambda(x, Conditional(gx, InSet(x, Interval(one, n))))
# Out:
# expr: x -> {g(x) if x in {1 .. n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# x \mapsto \left\{g(x) \textrm{ if } x \in \{1~\ldotp \ldotp~n\}\right..

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. x -> {g(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 8
#    body: 1
# 1. {g(x) if x in {1 .. n}.
#    core type: Conditional
#    value: 2
#    condition: 3
# 2. g(x)
#    core type: Operation
#    operator: 4
#    operand: 8
# 3. x in {1 .. n}
#    core type: Operation
#    operator: 6
#    operands: 7
# 4. g
#    core type: Variable
#    sub-expressions:
# 5. (x)
#    core type: ExprTuple
#    sub-expressions: 8
# 6. in
#    core type: Literal
#    sub-expressions:
# 7. (x, {1 .. n})
#    core type: ExprTuple
#    sub-expressions: 8, 9
# 8. x
#    core type: Variable
#    sub-expressions:
# 9. {1 .. n}
#    core type: Operation
#    operator: 10
#    operands: 11
# 10. Interval
#     core type: Literal
#     sub-expressions:
# 11. (1, n)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 12. 1
#     core type: Literal
#     sub-expressions:
# 13. n
#     core type: Variable
#     sub-expressions:
