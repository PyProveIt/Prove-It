# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Implies.html">Implies</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Lambda, fx, gx, n, x
from proveit.logic import Equals, Forall, Implies, InSet
from proveit.numbers import Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Interval(one, n)
sub_expr2 = InSet(x, sub_expr1)
expr = Implies(Forall([x], Equals(fx, gx), domain = sub_expr1), Equals(Lambda(x, Conditional(fx, sub_expr2)), Lambda(x, Conditional(gx, sub_expr2))))
# Out:
# expr: [forall_{x in {1 .. n}} (f(x) = g(x))] => ([x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.])

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left[\forall_{x \in \{1~\ldotp \ldotp~n\}}~\left(f(x) = g(x)\right)\right] \Rightarrow \left(\left[x \mapsto \left\{f(x) \textrm{ if } x \in \{1~\ldotp \ldotp~n\}\right..\right] = \left[x \mapsto \left\{g(x) \textrm{ if } x \in \{1~\ldotp \ldotp~n\}\right..\right]\right)

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. [forall_{x in {1 .. n}} (f(x) = g(x))] => ([x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.])
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =>
#    core type: Literal
#    sub-expressions:
# 2. (forall_{x in {1 .. n}} (f(x) = g(x)), [x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.])
#    core type: ExprTuple
#    sub-expressions: 3, 4
# 3. forall_{x in {1 .. n}} (f(x) = g(x))
#    core type: Operation
#    operator: 5
#    operand: 8
# 4. [x -> {f(x) if x in {1 .. n}.] = [x -> {g(x) if x in {1 .. n}.]
#    core type: Operation
#    operator: 16
#    operands: 7
# 5. forall
#    core type: Literal
#    sub-expressions:
# 6. (x -> {f(x) = g(x) if x in {1 .. n}.)
#    core type: ExprTuple
#    sub-expressions: 8
# 7. (x -> {f(x) if x in {1 .. n}., x -> {g(x) if x in {1 .. n}.)
#    core type: ExprTuple
#    sub-expressions: 9, 10
# 8. x -> {f(x) = g(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 28
#    body: 11
# 9. x -> {f(x) if x in {1 .. n}.
#    core type: Lambda
#    parameter: 28
#    body: 12
# 10. x -> {g(x) if x in {1 .. n}.
#     core type: Lambda
#     parameter: 28
#     body: 13
# 11. {f(x) = g(x) if x in {1 .. n}.
#     core type: Conditional
#     value: 14
#     condition: 15
# 12. {f(x) if x in {1 .. n}.
#     core type: Conditional
#     value: 20
#     condition: 15
# 13. {g(x) if x in {1 .. n}.
#     core type: Conditional
#     value: 21
#     condition: 15
# 14. f(x) = g(x)
#     core type: Operation
#     operator: 16
#     operands: 17
# 15. x in {1 .. n}
#     core type: Operation
#     operator: 18
#     operands: 19
# 16. =
#     core type: Literal
#     sub-expressions:
# 17. (f(x), g(x))
#     core type: ExprTuple
#     sub-expressions: 20, 21
# 18. in
#     core type: Literal
#     sub-expressions:
# 19. (x, {1 .. n})
#     core type: ExprTuple
#     sub-expressions: 28, 22
# 20. f(x)
#     core type: Operation
#     operator: 23
#     operand: 28
# 21. g(x)
#     core type: Operation
#     operator: 24
#     operand: 28
# 22. {1 .. n}
#     core type: Operation
#     operator: 26
#     operands: 27
# 23. f
#     core type: Variable
#     sub-expressions:
# 24. g
#     core type: Variable
#     sub-expressions:
# 25. (x)
#     core type: ExprTuple
#     sub-expressions: 28
# 26. Interval
#     core type: Literal
#     sub-expressions:
# 27. (1, n)
#     core type: ExprTuple
#     sub-expressions: 29, 30
# 28. x
#     core type: Variable
#     sub-expressions:
# 29. 1
#     core type: Literal
#     sub-expressions:
# 30. n
#     core type: Variable
#     sub-expressions:
