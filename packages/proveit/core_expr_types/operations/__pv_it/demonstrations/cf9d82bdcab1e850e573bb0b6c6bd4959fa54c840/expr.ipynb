# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.operations</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, Function, Variable, f, n
from proveit.logic import InSet
from proveit.numbers import Interval, one

# %%
# build up the expression from sub-expressions
sub_expr1 = Variable("_a", latex_format = r"{_{-}a}")
expr = Conditional(Function(f, [sub_expr1]), InSet(sub_expr1, Interval(one, n)))
# Out:
# expr: {f(_a) if _a in {1 .. n}.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{f({_{-}a}) \textrm{ if } {_{-}a} \in \{1~\ldotp \ldotp~n\}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {f(_a) if _a in {1 .. n}.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. f(_a)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. _a in {1 .. n}
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. f
#    core type: Variable
#    sub-expressions:
# 4. (_a)
#    core type: ExprTuple
#    sub-expressions: 7
# 5. in
#    core type: Literal
#    sub-expressions:
# 6. (_a, {1 .. n})
#    core type: ExprTuple
#    sub-expressions: 7, 8
# 7. _a
#    core type: Variable
#    sub-expressions:
# 8. {1 .. n}
#    core type: Operation
#    operator: 9
#    operands: 10
# 9. Interval
#    core type: Literal
#    sub-expressions:
# 10. (1, n)
#     core type: ExprTuple
#     sub-expressions: 11, 12
# 11. 1
#     core type: Literal
#     sub-expressions:
# 12. n
#     core type: Variable
#     sub-expressions:
