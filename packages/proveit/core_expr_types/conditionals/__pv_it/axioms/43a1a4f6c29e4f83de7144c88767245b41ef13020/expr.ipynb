# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ExprRange, ExprTuple, IndexedVar, a, b, c, i, m
from proveit.logic import FALSE
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m))
# Out:
# expr: (a_{1} if FALSE, ..a_{i} if FALSE.., a_{m} if FALSE, b, c_{1} if FALSE, ..c_{i} if FALSE.., c_{m} if FALSE)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(a_{1} \textrm{ if } \bot, \ldots, a_{m} \textrm{ if } \bot, b, c_{1} \textrm{ if } \bot, \ldots, c_{m} \textrm{ if } \bot\right)

# %%
expr.style_options()
# Out:
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; 'n' is after the nth comma.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at',)
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: left
# current value: left
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. (a_{1} if FALSE, ..a_{i} if FALSE.., a_{m} if FALSE, b, c_{1} if FALSE, ..c_{i} if FALSE.., c_{m} if FALSE)
#    core type: ExprTuple
#    sub-expressions: 1, 2, 3
# 1. {a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.
#    core type: ExprRange
#    lambda_map: 4
#    start_index: 6
#    end_index: 7
# 2. b
#    core type: Variable
#    sub-expressions:
# 3. {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.
#    core type: ExprRange
#    lambda_map: 5
#    start_index: 6
#    end_index: 7
# 4. i -> {a_{i} if FALSE.
#    core type: Lambda
#    parameter: 16
#    body: 8
# 5. i -> {c_{i} if FALSE.
#    core type: Lambda
#    parameter: 16
#    body: 9
# 6. 1
#    core type: Literal
#    sub-expressions:
# 7. m
#    core type: Variable
#    sub-expressions:
# 8. {a_{i} if FALSE.
#    core type: Conditional
#    value: 10
#    condition: 12
# 9. {c_{i} if FALSE.
#    core type: Conditional
#    value: 11
#    condition: 12
# 10. a_{i}
#     core type: IndexedVar
# variable: 13
# index: 16
# 11. c_{i}
#     core type: IndexedVar
# variable: 14
# index: 16
# 12. FALSE
#     core type: Literal
#     sub-expressions:
# 13. a
#     core type: Variable
#     sub-expressions:
# 14. c
#     core type: Variable
#     sub-expressions:
# 15. (i)
#     core type: ExprTuple
#     sub-expressions: 16
# 16. i
#     core type: Variable
#     sub-expressions:
