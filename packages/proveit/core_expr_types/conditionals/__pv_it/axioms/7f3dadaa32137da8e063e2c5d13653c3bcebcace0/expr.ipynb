# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Equals.html">Equals</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, IndexedVar, a, b, c, i, m
from proveit.logic import Equals, FALSE
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Equals(ConditionalSet(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m)), b)
# Out:
# expr: {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\begin{array}{ccc}\left\{a_{1} \textrm{ if } \bot\right.., \ldots, \left\{a_{m} \textrm{ if } \bot\right.. \\ b \\ \left\{c_{1} \textrm{ if } \bot\right.., \ldots, \left\{c_{m} \textrm{ if } \bot\right..\end{array}\right.. = b

# %%
expr.style_options()
# Out:
# style name: operation
# description: 'infix' or 'function' style formatting
# default: infix
# current value: infix
# related methods: ()
# style name: wrap_positions
# description: position(s) at which wrapping is to occur; '2 n - 1' is after the nth operand, '2 n' is after the nth operation.
# default: ()
# current value: ()
# related methods: ('with_wrapping_at', 'with_wrap_before_operator', 'with_wrap_after_operator', 'wrap_positions')
# style name: justification
# description: if any wrap positions are set, justify to the 'left', 'center', or 'right'
# default: center
# current value: center
# related methods: ('with_justification',)
# style name: direction
# description: Direction of the relation (normal or reversed)
# default: normal
# current value: normal
# related methods: ('with_direction_reversed', 'is_reversed')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b
#    core type: Operation
#    operator: 1
#    operands: 2
# 1. =
#    core type: Literal
#    sub-expressions:
# 2. ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.., b)
#    core type: ExprTuple
#    sub-expressions: 3, 7
# 3. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE..
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. CondSet
#    core type: Literal
#    sub-expressions:
# 5. (a_{1} if FALSE, ..a_{i} if FALSE.., a_{m} if FALSE, b, c_{1} if FALSE, ..c_{i} if FALSE.., c_{m} if FALSE)
#    core type: ExprTuple
#    sub-expressions: 6, 7, 8
# 6. {a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.
#    core type: ExprRange
#    lambda_map: 9
#    start_index: 11
#    end_index: 12
# 7. b
# ...
