# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, IndexedVar, a, b, c, i, m, n
from proveit.logic import Equals, FALSE, Forall
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Forall([m, n], Forall([a, b, c], Equals(ConditionalSet(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m)), b)), domain = Natural)
# Out:
# expr: forall_{m, n in Natural} [forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)]

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{m, n \in \mathbb{N}}~\left[\forall_{a, b, c}~\left(\left\{\begin{array}{ccc}\left\{a_{1} \textrm{ if } \bot\right.., \ldots, \left\{a_{m} \textrm{ if } \bot\right.. \\ b \\ \left\{c_{1} \textrm{ if } \bot\right.., \ldots, \left\{c_{m} \textrm{ if } \bot\right..\end{array}\right.. = b\right)\right]

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{m, n in Natural} [forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)]
#    core type: Operation
#    operator: 7
#    operand: 2
# 1. ((m, n) -> {forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b) if m in Natural ,  n in Natural.)
#    core type: ExprTuple
#    sub-expressions: 2
# 2. (m, n) -> {forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b) if m in Natural ,  n in Natural.
#    core type: Lambda
#    parameters: 3\n   body: 4
# 3. (m, n)
#    core type: ExprTuple
#    sub-expressions: 32, 21
# 4. {forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 5
#    condition: 6
# 5. forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#    core type: Operation
#    operator: 7
#    operand: 11
# 6. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 9
#    operands: 10
# 7. forall
#    core type: Literal
#    sub-expressions:
# 8. ((a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b))
#    core type: ExprTuple
#    sub-expressions: 11
# 9. and
#    core type: Literal
#    sub-expressions:
# 10. (m in Natural, n in Natural)
#     core type: ExprTuple
#     sub-expressions: 12, 13
# 11. (a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#     core type: Lambda
#     parameters: 14\n    body: 15
# 12. m in Natural
#     core type: Operation
#     operator: 17
#     operands: 16
# 13. n in Natural
#     core type: Operation
#     operator: 17
#     operands: 18
# 14. (a, b, c)
#     core type: ExprTuple
#     sub-expressions: 38, 27, 39
# 15. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b
#     core type: Operation
#     operator: 19
#     operands: 20
# 16. (m, Natural)
#     core type: ExprTuple
#     sub-expressions: 32, 22
# 17. in
#     core type: Literal
#     sub-expressions:
# 18. (n, Natural)
#     core type: ExprTuple
#     sub-expressions: 21, 22
# 19. =
#     core type: Literal
#     sub-expressions:
# 20. ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.., b)
#     core type: ExprTuple
#     sub-expressions: 23, 27
# 21. n
#     core type: Variable
#     sub-expressions:
# 22. Natural
#     core type: Literal
#     sub-expressions:
# 23. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE..
#     core type: Operation
#     operator: 24
#     operands: 25
# 24. CondSet
#     core type: Literal
#     sub-expressions:
# 25. (a_{1} if FALSE, ..a_{i} if FALSE.., a_{m} if FALSE, b, c_{1} if FALSE, ..c_{i} if FALSE.., c_{m} if FALSE)
#     core type: ExprTuple
#     sub-expressions: 26, 27, 28
# 26. {a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.
#     core type: ExprRange
#     lambda_map: 29
#     start_index: 31
#     end_index: 32
# 27. b
#     core type: Variable
#     sub-expressions:
# 28. {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.
#     core type: ExprRange
#     lambda_map: 30
#     start_index: 31
#     end_index: 32
# 29. i -> {a_{i} if FALSE.
#     core type: Lambda
#     parameter: 41
#     body: 33
# 30. i -> {c_{i} if FALSE.
#     core type: Lambda
#     parameter: 41
#     body: 34
# 31. 1
#     core type: Literal
#     sub-expressions:
# 32. m
#     core type: Variable
#     sub-expressions:
# 33. {a_{i} if FALSE.
#     core type: Conditional
#     value: 35
#     condition: 37
# 34. {c_{i} if FALSE.
#     core type: Conditional
#     value: 36
#     condition: 37
# 35. a_{i}
#     core type: IndexedVar
# variable: 38
# index: 41
# 36. c_{i}
#     core type: IndexedVar
# variable: 39
# index: 41
# 37. FALSE
#     core type: Literal
#     sub-expressions:
# 38. a
#     core type: Variable
#     sub-expressions:
# 39. c
#     core type: Variable
#     sub-expressions:
# 40. (i)
#     core type: ExprTuple
#     sub-expressions: 41
# 41. i
#     core type: Variable
#     sub-expressions:
