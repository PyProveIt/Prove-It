# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.logic.Forall.html">Forall</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, IndexedVar, a, b, c, i, m
from proveit.logic import Equals, FALSE, Forall
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = Forall([a, b, c], Equals(ConditionalSet(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m)), b))
# Out:
# expr: forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \forall_{a, b, c}~\left(\left\{\begin{array}{ccc}\left\{a_{1} \textrm{ if } \bot\right.., \ldots, \left\{a_{m} \textrm{ if } \bot\right.. \\ b \\ \left\{c_{1} \textrm{ if } \bot\right.., \ldots, \left\{c_{m} \textrm{ if } \bot\right..\end{array}\right.. = b\right)

# %%
expr.style_options()
# Out:
# style name: with_wrapping
# description: If 'True', wrap the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_wrapping',)
# style name: wrap_params
# description: If 'True', wraps every two parameters AND wraps the Expression after the parameters
# default: None
# current value: None/False
# related methods: ('with_params',)
# style name: justification
# description: justify to the 'left', 'center', or 'right' in the array cells
# default: center
# current value: center
# related methods: ('with_justification',)

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#    core type: Operation
#    operator: 1
#    operand: 3
# 1. forall
#    core type: Literal
#    sub-expressions:
# 2. ((a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b))
#    core type: ExprTuple
#    sub-expressions: 3
# 3. (a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#    core type: Lambda
#    parameters: 4\n   body: 5
# 4. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 23, 12, 24
# 5. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b
#    core type: Operation
#    operator: 6
#    operands: 7
# 6. =
#    core type: Literal
#    sub-expressions:
# ...
