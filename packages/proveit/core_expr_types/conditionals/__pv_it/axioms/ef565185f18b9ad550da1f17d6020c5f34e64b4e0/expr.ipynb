# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.ExprTuple.html">ExprTuple</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, ExprTuple, IndexedVar, Lambda, a, b, c, i, m
from proveit.logic import Equals, FALSE
from proveit.numbers import one

# %%
# build up the expression from sub-expressions
expr = ExprTuple(Lambda([a, b, c], Equals(ConditionalSet(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m)), b)))
# Out:
# expr: ((a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b))

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left(\left(a, b, c\right) \mapsto \left(\left\{\begin{array}{ccc}\left\{a_{1} \textrm{ if } \bot\right.., \ldots, \left\{a_{m} \textrm{ if } \bot\right.. \\ b \\ \left\{c_{1} \textrm{ if } \bot\right.., \ldots, \left\{c_{m} \textrm{ if } \bot\right..\end{array}\right.. = b\right)\right)

# %%
expr.style_options()
# Out:
# no style options

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. ((a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b))
#    core type: ExprTuple
#    sub-expressions: 1
# 1. (a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#    core type: Lambda
#    parameters: 2\n   body: 3
# 2. (a, b, c)
#    core type: ExprTuple
#    sub-expressions: 21, 10, 22
# 3. {{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b
#    core type: Operation
#    operator: 4
#    operands: 5
# 4. =
#    core type: Literal
#    sub-expressions:
# 5. ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.., b)
#    core type: ExprTuple
#    sub-expressions: 6, 10
# ...
