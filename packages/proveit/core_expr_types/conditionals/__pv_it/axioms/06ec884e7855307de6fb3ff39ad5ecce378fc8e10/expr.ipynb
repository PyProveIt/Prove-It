# %% [markdown]
# Expression of type <a class="ProveItLink" href="../../../../../../../doc/html/api/proveit.Conditional.html">Conditional</a>
# =======================
# # from the theory of <a class="ProveItLink" href="../../../_theory_nbs_/theory.ipynb">proveit.core_expr_types.conditionals</a>

# %%
import proveit
# Automation is not needed when building an expression:
proveit.defaults.automation = False # This will speed things up.
proveit.defaults.inline_pngs = False # Makes files smaller.
# %load_expr # Load the stored expression as 'stored_expr'
# import Expression classes needed to build the expression
from proveit import Conditional, ConditionalSet, ExprRange, IndexedVar, a, b, c, i, m, n
from proveit.logic import And, Equals, FALSE, Forall, InSet
from proveit.numbers import Natural, one

# %%
# build up the expression from sub-expressions
expr = Conditional(Forall([a, b, c], Equals(ConditionalSet(ExprRange(i, Conditional(IndexedVar(a, i), FALSE), one, m), b, ExprRange(i, Conditional(IndexedVar(c, i), FALSE), one, m)), b)), And(InSet(m, Natural), InSet(n, Natural)))
# Out:
# expr: {forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b) if m in Natural ,  n in Natural.

# %%
# check that the built expression is the same as the stored expression
assert expr == stored_expr
assert expr._style_id == stored_expr._style_id
print("Passed sanity check: expr matches stored_expr")
# Out:
# Passed sanity check: expr matches stored_expr

# %%
# Show the LaTeX representation of the expression for convenience if you need it.
print(expr.latex())
# Out:
# \left\{\forall_{a, b, c}~\left(\left\{\begin{array}{ccc}\left\{a_{1} \textrm{ if } \bot\right.., \ldots, \left\{a_{m} \textrm{ if } \bot\right.. \\ b \\ \left\{c_{1} \textrm{ if } \bot\right.., \ldots, \left\{c_{m} \textrm{ if } \bot\right..\end{array}\right.. = b\right) \textrm{ if } m \in \mathbb{N} ,  n \in \mathbb{N}\right..

# %%
expr.style_options()
# Out:
# style name: condition_delimiter
# description: 'comma' or 'and'
# default: comma
# current value: comma
# related methods: ('with_comma_delimiter', 'with_conjunction_delimiter')

# %%
# display the expression information
expr.expr_info()
# Out:
# 0. {forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b) if m in Natural ,  n in Natural.
#    core type: Conditional
#    value: 1
#    condition: 2
# 1. forall_{a, b, c} ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b)
#    core type: Operation
#    operator: 3
#    operand: 7
# 2. (m in Natural) and (n in Natural)
#    core type: Operation
#    operator: 5
#    operands: 6
# 3. forall
#    core type: Literal
#    sub-expressions:
# 4. ((a, b, c) -> ({{a_{1} if FALSE., ..{a_{i} if FALSE..., {a_{m} if FALSE.; b; {c_{1} if FALSE., ..{c_{i} if FALSE..., {c_{m} if FALSE.. = b))
#    core type: ExprTuple
#    sub-expressions: 7
# 5. and
#    core type: Literal
#    sub-expressions:
# 6. (m in Natural, n in Natural)
#    core type: ExprTuple
#    sub-expressions: 8, 9
# ...
