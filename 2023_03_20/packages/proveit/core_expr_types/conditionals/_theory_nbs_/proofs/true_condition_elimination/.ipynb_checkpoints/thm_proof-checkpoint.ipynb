# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">core_expr_types</a>.<a class="ProveItLink" href="../../theory.ipynb">conditionals</a>.<a class="ProveItLink" href="../../theorems.ipynb#true_condition_elimination">true_condition_elimination</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving true_condition_elimination
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="true_condition_elimination">true_condition_elimination:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/dfdfde917b38e9d3835ee0574a0f576076b03f5b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/0ec8f2cc0d4f80b2a925259a7024509be2bf08ca0/dependencies.ipynb">dependencies</a>)<br>
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     962                     concluded_truth = self.conclude_via_implication(
# --> 963                             assumptions=assumptions)
#     964                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#    1135         from proveit.logic import conclude_via_implication
# -> 1136         return conclude_via_implication(self)
#    1137
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     448         defaults.assumptions,
# --> 449         'Unable to conclude via implications')
#     450
#
# ProofFailure: Unable to prove 0 in Real assuming {m in Natural, n in Natural}:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_number_set(self, number_set, **defaults_config)
#     119                 else:
# --> 120                     InSet(self, Natural).prove(automation=False)
#     121                     InSet(self, IntegerNonPos).prove(automation=False)
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     913         if not automation:
# --> 914             raise ProofFailure(self, assumptions, "No pre-existing proof")
#     915
#
# ProofFailure: Unable to prove 0 in Natural without automation assuming {m in Natural, n in Natural}:
# No pre-existing proof
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     962                     concluded_truth = self.conclude_via_implication(
# --> 963                             assumptions=assumptions)
#     964                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#    1135         from proveit.logic import conclude_via_implication
# -> 1136         return conclude_via_implication(self)
#    1137
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     448         defaults.assumptions,
# --> 449         'Unable to conclude via implications')
#     450
#
# ProofFailure: Unable to prove 0 in Real assuming {m in Natural, n in Natural, _a in {0}}:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_number_set(self, number_set, **defaults_config)
#     120                     InSet(self, Natural).prove(automation=False)
# --> 121                     InSet(self, IntegerNonPos).prove(automation=False)
#     122             except BaseException:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     913         if not automation:
# --> 914             raise ProofFailure(self, assumptions, "No pre-existing proof")
#     915
#
# ProofFailure: Unable to prove 0 in IntegerNonPos without automation assuming {m in Natural, n in Natural, _a in {0}}:
# No pre-existing proof
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/less_eq.py in derive_complement(self, **defaults_config)
#     242         return not_less_from_less_eq.instantiate(
# --> 243                 {x: self.lower, y: self.upper})
#     244
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1542                 simplify_only_where_marked, markers_and_marked_expr,
# -> 1543                 requirements, equality_repl_requirements)
#    1544         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr, requirements, equality_repl_requirements)
#    1864                         try:
# -> 1865                             requirements.append(subbed_cond.prove())
#    1866                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     966                     # class
# --> 967                     concluded_truth = self.conclude(assumptions=assumptions)
#     968             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/membership/in_set.py in conclude(self, **defaults_config)
#      81
# ---> 82         return InClass.conclude(self)
#      83
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     188         if hasattr(self, 'membership_object'):
# --> 189             return self.membership_object.conclude()
#     190
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/number_set.py in conclude(self, **defaults_config)
#     214             try:
# --> 215                 return element.deduce_in_number_set(self.number_set)
#     216             except (NotImplementedError, UnsatisfiedPrerequisites) as e:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_number_set(self, number_set, **defaults_config)
#     129                     self.deduce_in_natural()
# --> 130                     self.deduce_in_integer_nonpos()
#     131             if self.n > 0:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_integer_nonpos(self, **defaults_config)
#     160                                 "%s is positive"%self)
# --> 161         from proveit.numbers.number_sets.integers import zero_is_nonpos
#     162         return zero_is_nonpos
#
# ImportError: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/natural_numbers/natural_membership.py in derive_element_lower_bound(self, **defaults_config)
#      62         return natural_lower_bound.instantiate(
# ---> 63             {n: self.element}, auto_simplify=False)
#      64
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1577         Proof.__init__(self, instantiated_truth, requirements,
# -> 1578                        marked_req_indices)
#    1579
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, proven_truth, required_truths, marked_required_truth_indices)
#     228         # Derive obvious consequences from this truth.
# --> 229         self._derive_side_effects()
#     230
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _derive_side_effects(self)
#     249                     temp_defaults.replacements = []
# --> 250                 proven_truth.derive_side_effects()
#     251
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#
# Exception: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/less_eq.py in derive_complement(self, **defaults_config)
#     242         return not_less_from_less_eq.instantiate(
# --> 243                 {x: self.lower, y: self.upper})
#     244
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1542                 simplify_only_where_marked, markers_and_marked_expr,
# -> 1543                 requirements, equality_repl_requirements)
#    1544         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr, requirements, equality_repl_requirements)
#    1864                         try:
# -> 1865                             requirements.append(subbed_cond.prove())
#    1866                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     915
# --> 916         if not self._readily_provable():
#     917             # Maybe this Expression isn't readily provable by
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/membership/in_set.py in _readily_provable(self)
#      41         '''
# ---> 42         if InClass._readily_provable(self):
#      43             return True
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in _readily_provable(self)
#     149         if hasattr(self, 'membership_object'):
# --> 150             if self.membership_object._readily_provable():
#     151                 return True
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/number_set.py in _readily_provable(self)
#     175         if provable_number_set is None: return False
# --> 176         return self.number_set.includes(provable_number_set)
#     177
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/number_set.py in includes(self, other_set)
#      74             #deduce_number_set(_x, assumptions=assumptions)
# ---> 75             if InSet(_x, self).readily_provable(assumptions=assumptions):
#      76                 #if not SubsetEq(other_set, self).proven():
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1025             assumptions = defaults.assumptions
# -> 1026             Assumption.make_assumptions(assumptions)
#    1027
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in make_assumptions(assumptions)
#     837                 # useful for deriving side-effects.
# --> 838                 Assumption.make_assumption(assumption, assumptions)
#     839             if not defaults.sideeffect_automation:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in make_assumption(expr, assumptions)
#     816                 temp_defaults.assumptions = assumptions
# --> 817                 preexisting.proven_truth.derive_side_effects()
#     818             return preexisting
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#
# Exception: Side effect failure for n in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace1ec6d8>>: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/natural_numbers/natural_membership.py in derive_element_lower_bound(self, **defaults_config)
#      62         return natural_lower_bound.instantiate(
# ---> 63             {n: self.element}, auto_simplify=False)
#      64
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1577         Proof.__init__(self, instantiated_truth, requirements,
# -> 1578                        marked_req_indices)
#    1579
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, proven_truth, required_truths, marked_required_truth_indices)
#     228         # Derive obvious consequences from this truth.
# --> 229         self._derive_side_effects()
#     230
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _derive_side_effects(self)
#     249                     temp_defaults.replacements = []
# --> 250                 proven_truth.derive_side_effects()
#     251
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#
# Exception: Side effect failure for 0 >= 0, while running <bound method LessEq.derive_complement of 0 >= 0>: Side effect failure for n in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace1ec6d8>>: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/less_eq.py in derive_complement(self, **defaults_config)
#     242         return not_less_from_less_eq.instantiate(
# --> 243                 {x: self.lower, y: self.upper})
#     244
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1542                 simplify_only_where_marked, markers_and_marked_expr,
# -> 1543                 requirements, equality_repl_requirements)
#    1544         except LambdaApplicationError as e:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr, requirements, equality_repl_requirements)
#    1864                         try:
# -> 1865                             requirements.append(subbed_cond.prove())
#    1866                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     966                     # class
# --> 967                     concluded_truth = self.conclude(assumptions=assumptions)
#     968             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/membership/in_set.py in conclude(self, **defaults_config)
#      81
# ---> 82         return InClass.conclude(self)
#      83
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     188         if hasattr(self, 'membership_object'):
# --> 189             return self.membership_object.conclude()
#     190
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/number_set.py in conclude(self, **defaults_config)
#     214             try:
# --> 215                 return element.deduce_in_number_set(self.number_set)
#     216             except (NotImplementedError, UnsatisfiedPrerequisites) as e:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_number_set(self, number_set, **defaults_config)
#     128                 else:
# --> 129                     self.deduce_in_natural()
#     130                     self.deduce_in_integer_nonpos()
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/numeral.py in deduce_in_natural(self, **defaults_config)
#     146         if Numeral._inNaturalStmts is None:
# --> 147             from proveit.numbers.number_sets.natural_numbers import zero_in_nats
#     148             from .decimals import nat1, nat2, nat3, nat4, nat5, nat6, nat7, nat8, nat9
#
# /projects/percept/linux_rhel6/anaconda3/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/theory.py in __getattr__(self, name)
#     649         if kind == 'axiom':
# --> 650             return self._theory.get_axiom(name).proven_truth
#     651         elif kind == 'theorem':
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/theory.py in get_axiom(self, name)
#     328         '''
# --> 329         return self._storage.get_axiom(name)
#     330
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in get_axiom(self, name)
#     588             return self._loadedAxioms[name]
# --> 589         axiom = self._getSpecialObject('axiom', name)
#     590         self._loadedAxioms[name] = axiom
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in _getSpecialObject(self, kind, name)
#     630             elif kind == 'axiom':
# --> 631                 obj = theory_folder_storage.make_judgment_or_proof(obj_id)
#     632                 if not isinstance(obj, Axiom):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/_theory_storage.py in make_judgment_or_proof(self, storage_id)
#    2121                 judgment = self.make_judgment_or_proof(judgment_id)
# -> 2122                 obj = Axiom(judgment.expr, theory, name)
#    2123             elif kind == 'theorem':
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, expr, theory, name)
#     855         self.name = name
# --> 856         Proof.__init__(self, Judgment(expr, frozenset()), [])
#     857
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, proven_truth, required_truths, marked_required_truth_indices)
#     228         # Derive obvious consequences from this truth.
# --> 229         self._derive_side_effects()
#     230
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _derive_side_effects(self)
#     249                     temp_defaults.replacements = []
# --> 250                 proven_truth.derive_side_effects()
#     251
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#
# Exception: Side effect failure for 0 in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace0815f8>>: Side effect failure for 0 >= 0, while running <bound method LessEq.derive_complement of 0 >= 0>: Side effect failure for n in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace1ec6d8>>: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     266                         # in the last derivation step.
# --> 267                         side_effect()
#     268                     except (ProofFailure, UnsatisfiedPrerequisites):
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     153             # Now call the prover function.
# --> 154             proven_truth = checked_truth(func(*args, **kwargs))
#     155
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/natural_numbers/natural_membership.py in derive_element_lower_bound(self, **defaults_config)
#      62         return natural_lower_bound.instantiate(
# ---> 63             {n: self.element}, auto_simplify=False)
#      64
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     146                 # Now call the prover function.
# --> 147                 proven_truth = checked_truth(func(*args, **kwargs))
#     148         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, simplify_only_where_marked, markers_and_marked_expr, **defaults_config)
#    1089                         simplify_only_where_marked=simplify_only_where_marked,
# -> 1090                         markers_and_marked_expr=markers_and_marked_expr))
#    1091         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in get_instantiation(orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, simplify_only_where_marked, markers_and_marked_expr)
#    1342                              simplify_only_where_marked,
# -> 1343                              markers_and_marked_expr)
#    1344         assert inst.mapping == mapping
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, mapping, mapping_key_order, simplify_only_where_marked, markers_and_marked_expr)
#    1577         Proof.__init__(self, instantiated_truth, requirements,
# -> 1578                        marked_req_indices)
#    1579
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, proven_truth, required_truths, marked_required_truth_indices)
#     228         # Derive obvious consequences from this truth.
# --> 229         self._derive_side_effects()
#     230
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _derive_side_effects(self)
#     249                     temp_defaults.replacements = []
# --> 250                 proven_truth.derive_side_effects()
#     251
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#
# Exception: Side effect failure for m >= 0, while running <bound method LessEq.derive_complement of m >= 0>: Side effect failure for 0 in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace0815f8>>: Side effect failure for 0 >= 0, while running <bound method LessEq.derive_complement of 0 >= 0>: Side effect failure for n in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace1ec6d8>>: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-badd8f6b607c> in <module>
# ----> 1 get_ipython().run_line_magic('proving', 'true_condition_elimination')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2415                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416             with self.builtin_trap:
# -> 2417                 result = fn(*args, **kwargs)
#    2418             return result
#    2419
#
# <decorator-gen-179> in proving(self, line)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in proving(self, line)
#    1012         self.shell.user_ns[theorem_name] = begin_proof_result
#    1013         display_assignments([theorem_name], [begin_proof_result],
# -> 1014                             beginning_proof=True)
#    1015
#    1016     @line_magic
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in display_assignments(names, right_sides, beginning_proof)
#    1111     # is being proven is readily provable; if so, indicate that
#    1112     # '%qed' is all that is needed.
# -> 1113     Judgment._check_if_ready_for_qed()
#    1114
#    1115
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in _check_if_ready_for_qed()
#     641         theorem_being_proven = Judgment.theorem_being_proven
#     642         theorem_expr = Judgment.theorem_being_proven.proven_truth.expr
# --> 643         if theorem_expr.readily_provable():
#     644             if not Judgment.theorem_readily_provable:
#     645                 Judgment.theorem_readily_provable = True
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1048                 Expression.in_progress_to_check_provability.add(
#    1049                         in_progress_key)
# -> 1050                 return self._readily_provable()
#    1051             finally:
#    1052                 Expression.in_progress_to_check_provability.remove(
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable(self)
#      67         been proven with a more inclusive domain.
#      68         '''
# ---> 69         if self._readily_provable_via_generalization():
#      70             return True
#      71         return False
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable_via_generalization(self)
#      87         # Add the conditions as assumptions.
#      88         inner_assumptions += list(conditions.entries)
# ---> 89         return expr.readily_provable(assumptions=inner_assumptions)
#      90
#      91     @prover
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1024                 tmp_defaults.assumptions = assumptions
#    1025             assumptions = defaults.assumptions
# -> 1026             Assumption.make_assumptions(assumptions)
#    1027
#    1028             if self.proven(): # this will "make" the assumptions
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in make_assumptions(assumptions)
#     836                 # itself, having the other assumptions around can be
#     837                 # useful for deriving side-effects.
# --> 838                 Assumption.make_assumption(assumption, assumptions)
#     839             if not defaults.sideeffect_automation:
#     840                 # consideration doesn't fully count if automation is off
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in make_assumption(expr, assumptions)
#     817                 preexisting.proven_truth.derive_side_effects()
#     818             return preexisting
# --> 819         return Assumption(expr, assumptions)
#     820
#     821     @staticmethod
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, expr, assumptions)
#     793             assumed_truth = expr
#     794         try:
# --> 795             Proof.__init__(self, Judgment(assumed_truth, {expr}), [])
#     796         finally:
#     797             # Restore the original default assumptions
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, proven_truth, required_truths, marked_required_truth_indices)
#     227
#     228         # Derive obvious consequences from this truth.
# --> 229         self._derive_side_effects()
#     230
#     231     def _derive_side_effects(self):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _derive_side_effects(self)
#     248                 if len(defaults.replacements) > 0:
#     249                     temp_defaults.replacements = []
# --> 250                 proven_truth.derive_side_effects()
#     251
#     252     def _update_dependencies(self, newproof):
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in derive_side_effects(self)
#     274                                 self.expr),
#     275                                 str(side_effect)) +
# --> 276                             str(e))
#     277             finally:
#     278                 Judgment.in_progress_to_derive_sideeffects.remove(self)
#
# Exception: Side effect failure for m in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace25ac18>>: Side effect failure for m >= 0, while running <bound method LessEq.derive_complement of m >= 0>: Side effect failure for 0 in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace0815f8>>: Side effect failure for 0 >= 0, while running <bound method LessEq.derive_complement of 0 >= 0>: Side effect failure for n in Natural, while running <bound method NaturalMembership.derive_element_lower_bound of <proveit.numbers.number_sets.natural_numbers.natural_membership.NaturalMembership object at 0x7f0ace1ec6d8>>: Side effect failure for n >= 0, while running <bound method LessEq.derive_complement of n >= 0>: cannot import name 'zero_is_nonpos' from 'proveit.numbers.number_sets.integers' (/home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/integers/__init__.py)
