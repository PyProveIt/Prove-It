# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">sets</a>.<a class="ProveItLink" href="../../theory.ipynb">equivalence</a>.<a class="ProveItLink" href="../../theorems.ipynb#set_not_equiv_reversal">set_not_equiv_reversal</a> theorem
# ========

# %%
import proveit
from proveit import A, B
from proveit.logic import Not, SetNotEquiv
from proveit.logic.sets import SetEquiv
from proveit.logic.sets.equivalence  import set_equiv_def, set_not_equiv_def
from proveit.logic.sets.equivalence import set_equiv_reversal
theory = proveit.Theory() # the theorem's theory

# %%
# %proving set_not_equiv_reversal
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="set_not_equiv_reversal">set_not_equiv_reversal:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ef98e0ef0799a001c2c99e5b452826df78eea09a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ef1f57f4989d7d88cb59878642c5c90d7ea0a6e00/dependencies.ipynb">dependencies</a>)<br>

# %%
set_not_equiv_def
# Out:
# |- forall_{A, B} ((A not_equiv B) = [not](A equiv B))

# %%
set_not_equiv_def_inst_AB = set_not_equiv_def.instantiate()
# Out:
# <strong id="set_not_equiv_def_inst_AB">set_not_equiv_def_inst_AB:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/24edf29d73bd63828f995a7a1e6fbeacb00839ce0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/b0bcc8f24b80642a25521f93ec65bd4aafc04ce50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
set_not_equiv_def_inst_BA = set_not_equiv_def.instantiate({A:B, B:A})
# Out:
# <strong id="set_not_equiv_def_inst_BA">set_not_equiv_def_inst_BA:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/e9c534f53dfc11f150bcb7f5de48b968c49226ca0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/a8c5c66e5c64b96de04f56f253222496db3207fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
set_equiv_reversal
# Out:
# |- forall_{A, B | A equiv B} (B equiv A)

# %%
set_equiv_reversal_inst_BA = set_equiv_reversal.instantiate({A:B, B:A}, assumptions=[SetEquiv(B, A)])
# Out:
# <strong id="set_equiv_reversal_inst_BA">set_equiv_reversal_inst_BA:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/64ce83c197b559a3346c83d03b24881cab5757470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/76f26289e0977dda379b49a0a68707ef6a6688be0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/2ee8dc2018014830ed832e2e3d65a4df89f102480/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
set_equiv_reversal_inst_BA_as_implication = set_equiv_reversal_inst_BA.as_implication(hypothesis=SetEquiv(B, A))
# Out:
# <strong id="set_equiv_reversal_inst_BA_as_implication">set_equiv_reversal_inst_BA_as_implication:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/82b4a0053965eecce26ca9966f26549206a674500/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/9ffa51eca21349bd410672f1c2dc695846c7e20e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_AEquivB_gives_not_BEquivA = set_equiv_reversal_inst_BA_as_implication.deny_antecedent(assumptions=[Not(SetEquiv(A, B))])
# Out:
# <strong id="not_AEquivB_gives_not_BEquivA">not_AEquivB_gives_not_BEquivA:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/bb2eac1bdd2ce216d9324209ccfd47261e333bcc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/ad89214e414ca6430ad18c6df11cdae717c170ae0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/ef03d21f486a7cfde41fcdf25591d9f24101ed970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
not_AEquivB_gives_not_BEquivA_as_implication = not_AEquivB_gives_not_BEquivA.as_implication(hypothesis=Not(SetEquiv(A, B)))
# Out:
# <strong id="not_AEquivB_gives_not_BEquivA_as_implication">not_AEquivB_gives_not_BEquivA_as_implication:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/bb86ba617753a750f849589c7b899d8b0f42c75e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/410bba07a6f4ac29786b7e5926608773bc5f23eb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
c_1 = set_not_equiv_def_inst_AB.sub_left_side_into(not_AEquivB_gives_not_BEquivA_as_implication)
# Out:
# <strong id="c_1">c_1:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/44e9de59e52c1224e759df5d0528d66f8a5960c10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/779601cfacde41ccc1e7046acbe5692ca100c38b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
c_2 = set_not_equiv_def_inst_BA.sub_left_side_into(c_1)
# Out:
# <strong id="c_2">c_2:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/a0ca59c76789c1abc277bfe0828841dfc4d998f80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_set_not_equiv_reversal/03bc531f5d240de7f6754339f9780bbe0838a31e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# set_not_equiv_reversal is now readily provable.  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.sets.equivalence.set_not_equiv_reversal has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{A, B | A not_equiv B} (B not_equiv A)
# 1	modus ponens	2, 3	{A not_equiv B} |- B not_equiv A
# 2	instantiation	6, 4, 5	|- (A not_equiv B) => (B not_equiv A)
# 	P(_a) : (A not_equiv B) => _a, x : B not_equiv A, y : [not](B equiv A)
# 3	assumption		{A not_equiv B} |- A not_equiv B
# 4	instantiation	6, 7, 8	|- (A not_equiv B) => [not](B equiv A)
# 	P(_a) : _a => [not](B equiv A), x : A not_equiv B, y : [not](A equiv B)
# 5	instantiation	10	|- (B not_equiv A) = [not](B equiv A)
# 	A : B, B : A
# 6	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 7	deduction	9	|- [not](A equiv B) => [not](B equiv A)
# 8	instantiation	10	|- (A not_equiv B) = [not](A equiv B)
# 	A : A, B : B
# 9	instantiation	11, 12, 13, 14	{[not](A equiv B)} |- [not](B equiv A)
# 	A : B equiv A, B : A equiv B
# 10	axiom		|- forall_{A, B} ((A not_equiv B) = [not](A equiv B))
# 	proveit.logic.sets.equivalence.set_not_equiv_def
# 11	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 12	instantiation	15	|- (B equiv A) in BOOLEAN
# 	A : B, B : A
# 13	deduction	16	|- (B equiv A) => (A equiv B)
# 14	assumption		{[not](A equiv B)} |- [not](A equiv B)
# 15	conjecture		|- forall_{A, B} ((A equiv B) in BOOLEAN)
# 	proveit.logic.sets.equivalence.set_equiv_is_bool
# 16	instantiation	17, 18	{B equiv A} |- A equiv B
# 	A : B, B : A
# 17	theorem		|- forall_{A, B | A equiv B} (B equiv A)
# 	proveit.logic.sets.equivalence.set_equiv_reversal
# 18	assumption		{B equiv A} |- B equiv A
