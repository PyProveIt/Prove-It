# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">implication</a>.<a class="ProveItLink" href="../../theorems.ipynb#eq_from_iff">eq_from_iff</a> theorem
# ========

# %%
import proveit
# we need to import these to derive their side-effects:
from proveit.logic.booleans.implication import true_iff_false_negated, false_iff_true_negated
theory = proveit.Theory() # the theorem's theory

# %%
# %proving eq_from_iff
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="eq_from_iff">eq_from_iff:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/94b3684bf36fa23b87838182d9d4aa33823135890/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/286974f51f5888baa4e6d0554ab9382f7787420e0/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.implication.eq_from_iff has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | A <=> B} (A = B)
# 1	instantiation	3, 4, 5*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A <=> B} (A = B)]] \\  => [forall_{A, B in BOOLEAN | A <=> B} (A = B)]
# 	m : 1, n : 1, P(A, B) : A = B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and (A <=> B), x_{1} : A, y_{1} : B
# 2	instantiation	6, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | A <=> B} (A = B)]
# 	P(A) : forall_{B in BOOLEAN | A <=> B} (A = B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 10, 11	|- {A = B if A in BOOLEAN ,  (B in BOOLEAN) and (A <=> B). \\  = {A = B if A in BOOLEAN ,  B in BOOLEAN ,  A <=> B.
# 	n : 2, a : A = B, Q : A in BOOLEAN, R : (B in BOOLEAN, A <=> B)
# 6	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 7	instantiation	14, 12, 13	|- forall_{B in BOOLEAN | TRUE <=> B} (TRUE = B)
# 	P(B) : TRUE = B, Q(B) : TRUE <=> B, A : B
# 8	instantiation	14, 15, 16	|- forall_{B in BOOLEAN | FALSE <=> B} (FALSE = B)
# 	P(B) : FALSE = B, Q(B) : FALSE <=> B, A : B
# 9	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, R_{2}, ..., R_{n}} ({a if Q ,  R_{1} and  R_{2} and  ... and  R_{n}. \\  = {a if Q, R_{1} ,  R_{2} ,  ... ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 10	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 11	instantiation	17	|- |(B in BOOLEAN, A <=> B)| = |(1, ..., 2)|
# 	a : B in BOOLEAN, b : A <=> B
# 12	deduction	18	|- (TRUE <=> TRUE) => (TRUE = TRUE)
# 13	instantiation	20, 19	|- (TRUE <=> FALSE) => (TRUE = FALSE)
# 	A : TRUE <=> FALSE, B : TRUE = FALSE
# 14	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 	proveit.logic.booleans.conditioned_forall_over_bool_by_cases
# 15	instantiation	20, 21	|- (FALSE <=> TRUE) => (FALSE = TRUE)
# 	A : FALSE <=> TRUE, B : FALSE = TRUE
# 16	deduction	22	|- (FALSE <=> FALSE) => (FALSE = FALSE)
# 17	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 18	theorem		|- TRUE = TRUE
# 	proveit.logic.booleans.true_eq_true
# 19	instantiation	24, 23	|- (TRUE <=> FALSE) != TRUE
# 	A : TRUE <=> FALSE
# 20	theorem		|- forall_{A, B | A != TRUE} (A => B)
# 	proveit.logic.booleans.implication.untrue_antecedent_implication
# 21	instantiation	24, 25	|- (FALSE <=> TRUE) != TRUE
# 	A : FALSE <=> TRUE
# 22	theorem		|- FALSE = FALSE
# 	proveit.logic.booleans.false_eq_false
# 23	conjecture		|- [not](TRUE <=> FALSE)
# 	proveit.logic.booleans.implication.true_iff_false_negated
# 24	theorem		|- forall_{A | [not](A)} (A != TRUE)
# 	proveit.logic.booleans.negation.untrue_from_negation
# 25	conjecture		|- [not](FALSE <=> TRUE)
# 	proveit.logic.booleans.implication.false_iff_true_negated
