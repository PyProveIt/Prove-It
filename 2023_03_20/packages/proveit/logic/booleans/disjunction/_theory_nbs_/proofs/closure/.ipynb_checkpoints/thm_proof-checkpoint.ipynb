# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#closure">closure</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import Judgment
from proveit.logic.sets import EmptySet
from proveit.logic.sets.cardinality  import empty_card
from proveit import Operation, IndexedVar
from proveit.logic import Forall, InSet, Or, Boolean, in_bool, And
from proveit import A, B, Q, x, i, l, m, n, P,S
from proveit.core_expr_types import A_1_to_m
from proveit.numbers import num, Exp, Add, one, Natural, Less, zero, greater
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural_pos
#from proveit.numbers.number_sets.integers  import empty_nat_def
from proveit.logic.booleans.disjunction  import multi_disjunction_def, empty_disjunction
from proveit.logic.booleans.disjunction import binary_closure
theory = proveit.Theory() # the theorem's theory

# %%
# %proving closure
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="closure">closure:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/89d3d97dc4360142d43d01b2b868737402f7ad940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3e1ecb6eef0e0999454e77d07044437c933735840/dependencies.ipynb">dependencies</a>)<br>

# %%
closure.instance_expr
# Out:
# forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)

# %%
fold_forall_natural_pos
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])

# %%
from proveit import Function
from proveit import P, m
induction_inst = \
    fold_forall_natural_pos.instantiate({Function(P, m):closure.instance_expr})
# Out:
# <strong id="induction_inst">induction_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/de804017469c54b19eb92e76aca16d88d22e1fde0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/19ddedad41d3d9792e6e10e095c1f04a370515fd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### First prove the base case of the induction.

# %%
induction_base = induction_inst.antecedent.operands[0]
# Out:
# <strong id="induction_base">induction_base:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/cd71c7c486c775166f8524ac0270ead0bac3a8350/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
induction_base.prove()
# Out:
# |- forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)

# %% [markdown]
# ### Now prove the induction step assuming the induction hypothesis

# %%
induction_step = induction_inst.antecedent.operands[1]
# Out:
# <strong id="induction_step">induction_step:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/4bbaa2926df15cd0fd83b135fdcc51bbc5116ef20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
in_bool_conds = induction_step.instance_expr.conditions[0]
# Out:
# <strong id="in_bool_conds">in_bool_conds:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = (induction_step.conditions + [in_bool_conds])
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/88e9c64b9dd1687282f76ab28715d0d9abd799610/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
induction_hyp = induction_step.conditions[1]
# Out:
# <strong id="induction_hyp">induction_hyp:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/396b7a0f9445240bbc3cec8e6d5c93d8e58ee8830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ***Splitting apart the conjunction of "in Bool" conditions is an important step***

# %%
in_bool_cond_partition = in_bool_conds.partition(m)
# Out:
# <strong id="in_bool_cond_partition">in_bool_cond_partition:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/00a3f9664a29052a53dfb09a3ccb3a58f97b88940/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/586c045049f825a9055aff8153de4b54c4b235640/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
in_bool_conds_conjunction = And(in_bool_conds).prove()
# Out:
# <strong id="in_bool_conds_conjunction">in_bool_conds_conjunction:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/c16f4159a41833de03f75ffd4d0654f8f69bb59b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/7ac52c29804415020222a058edebbb8e472f71810/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
in_bool_conds_conjunction_partition = \
    in_bool_cond_partition.sub_right_side_into(in_bool_conds_conjunction)
# Out:
# <strong id="in_bool_conds_conjunction_partition">in_bool_conds_conjunction_partition:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/95c05171dbce7d60fb88151106122a60e85c38710/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/4225886b0d2c6b6076c566726e32af191e3903d60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
in_bool_conds_conjunction_partition.derive_some(0)
# Out:
# {m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)

# %% [markdown]
# ***Now we can instantiate the induction hypothesis***

# %%
induction_hyp.instantiate()
# Out:
# {forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN), m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN

# %% [markdown]
# ***And now we will be able to prove the induction step via binary_closure and multi_disjunction_def***

# %%
last_in_bool_cond = in_bool_conds_conjunction_partition.derive_any(1)
# Out:
# <strong id="last_in_bool_cond">last_in_bool_cond:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/a3d1da18c13ce35e736ebf0cc79ffd183ac124f50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/c04834127afce0673fb7afbef0ebc270c2f0879c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
A_mp1 = last_in_bool_cond.element
# Out:
# <strong id="A_mp1">A_mp1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/da7aa8ac0208e05ac67bc9c26f05b10020b22a9c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
binary_closure
# Out:
# |- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)

# %%
binary_conclusion = binary_closure.instantiate({A:Or(A_1_to_m), B:A_mp1})
# Out:
# <strong id="binary_conclusion">binary_conclusion:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/396b7a0f9445240bbc3cec8e6d5c93d8e58ee8830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f3ab8fcb9609a0115141278edcc3315341d080a80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/214b3139213ca3942fc22acb6c376b269e8789a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
multi_disjunction_eq = multi_disjunction_def.instantiate({B:A_mp1})
# Out:
# <strong id="multi_disjunction_eq">multi_disjunction_eq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/e5206cb665d1ecc7982e68bb8f6ef18974424ef60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/e729e3dd4e2a0f6b3a3ae741714fc5b3f481de830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
pre_merge_conclusion = multi_disjunction_eq.sub_left_side_into(binary_conclusion)
# Out:
# <strong id="pre_merge_conclusion">pre_merge_conclusion:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/396b7a0f9445240bbc3cec8e6d5c93d8e58ee8830/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../../numbers/number_sets/natural_numbers/__pv_it/theorems/5fb53e9c076547ad508281e2a2445cff05af57920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_closure/f7b76cbfd2ec8e1494f857e5a9eb22921626124e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_closure/45611e4636769ed8a25a243ce05c688865114d370/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_closure/23048964a28c8afddfd73ccc64929c60bebebdb80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
pre_merge_conclusion.inner_expr().element.operands.merge()
# Out:
# {m in NaturalPos, forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN),(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN

# %%
induction_step
# Out:
# forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]

# %%
induction_step.prove()
# Out:
# |- forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]

# %% [markdown]
# ### With the base case and the induction step proven, the induction proof is easily finished.

# %%
induction_inst.derive_consequent()
# Out:
# |- forall_{n in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)]
# closure has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.closure has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{m in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]
# 1	instantiation	3, 4, 5*	|- ([forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]]) => [forall_{n in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{n} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{n}) in BOOLEAN)]]
# 	P(m) : forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)
# 2	instantiation	6, 7, 8	|- [forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)] and [forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]]
# 	A : forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN), B : forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]
# 3	conjecture		|- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])
# 	proveit.numbers.number_sets.natural_numbers.fold_forall_natural_pos
# 4	instantiation	9, 10, 11	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- ((m + 1) + 1) = (m + 2)
# 	x : (m + 1) + 1, y : m + 1 + 1, z : m + 2
# 5	instantiation	12, 13	{A_{1} in BOOLEAN} |- [or](A_{1}) = A_{1}
# 	A : A_{1}
# 6	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 7	generalization	13	|- forall_{A_{1} in BOOLEAN} (A_{1} in BOOLEAN)
# 8	generalization	14	|- forall_{m in NaturalPos | forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} [forall_{A_{1}, A_{2}, ..., A_{m + 2} | (A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} ((A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN)]
# 9	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 10	instantiation	15, 53, 18, 70, 54, 16, 20, 21	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- ((m + 1) + 1) =  \\ (m + 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (m, 1), c : (1)
# 11	instantiation	17, 70, 18, 53, 19, 54, 20, 21, 22*	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- (m + 1 + 1) =  \\ (m + 2)
# 	i : 1, j : 2, k : 0, a : (m), b : (1, 1), c : ()
# 12	conjecture		|- forall_{A in BOOLEAN} ([or](A) = A)
# 	proveit.logic.booleans.disjunction.unary_or_reduction
# 13	assumption		{A_{1} in BOOLEAN} |- A_{1} in BOOLEAN
# 14	instantiation	59, 65, 23, 24, 25, 26	{m in NaturalPos, forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN),(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} or  A_{2} or  ... or  A_{m + 1}) in BOOLEAN
# 	n : m + 1, P(_b_{1}, _b_{2}, ..., _b_{m + 1}) : (_b_{1} or  _b_{2} or  ... or  _b_{m + 1}) in BOOLEAN, x : (A_{1}, A_{2}, ..., A_{m}, A_{m + 1}), y : (A_{1}, A_{2}, ..., A_{m + 1})
# 15	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 16	instantiation	27	|- |(m, 1)| = |(1, ..., 2)|
# 	a : m, b : 1
# 17	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 18	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 19	instantiation	27	|- |(1, 1)| = |(1, ..., 2)|
# 	a : 1, b : 1
# 20	instantiation	73, 29, 28	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- m in Complex
# 	A : Real, B : Complex, x : m
# 21	instantiation	73, 29, 30	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 22	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 23	instantiation	66, 72	{m in NaturalPos} |- |(A_{1}, A_{2}, ..., A_{m}, A_{m + 1})| = |(1, 2, ..., (m + 1))|
# 	f(_a) : A_{_a}, x : A_{m + 1}, i : m
# 24	instantiation	64, 65	{m in NaturalPos} |- |(A_{1}, A_{2}, ..., A_{m + 1})| = |(1, 2, ..., (m + 1))|
# 	i : m + 1, f(_a) : A_{_a}
# 25	instantiation	31, 32, 33	{forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN), m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} or  A_{2} or  ... or  A_{m} or A_{m + 1}) in BOOLEAN
# 	P(_b) : _b in BOOLEAN, x : A_{1} or  A_{2} or  ... or  A_{m} or A_{m + 1}, y : (A_{1} or  A_{2} or  ... or  A_{m}) or A_{m + 1}
# 26	instantiation	34, 35	{m in NaturalPos} |- (A_{1}, A_{2}, ..., A_{m}, A_{m + 1}) = (A_{1}, A_{2}, ..., A_{m + 1})
# 	f(_a) : A_{_a}, i : 1, j : m
# 27	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 28	instantiation	73, 37, 36	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- m in Real
# 	A : Rational, B : Real, x : m
# 29	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 30	instantiation	73, 37, 38	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 31	conjecture		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 32	instantiation	39, 40, 41	{forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN), m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- ((A_{1} or  A_{2} or  ... or  A_{m}) or A_{m + 1}) in BOOLEAN
# 	A : A_{1} or  A_{2} or  ... or  A_{m}, B : A_{m + 1}
# 33	instantiation	42, 72	{m in NaturalPos} |- (A_{1} or  A_{2} or  ... or  A_{m} or A_{m + 1}) =  \\ ((A_{1} or  A_{2} or  ... or  A_{m}) or A_{m + 1})
# 	m : m, A : A, B : A_{m + 1}
# 34	conjecture		|- forall_{f, i, j | |(f(i), f(i + 1), ..., f(j))| in Natural} ((f(i), f(i + 1), ..., f(j), f(j + 1)) = (f(i), f(i + 1), ..., f(j + 1)))
# 	proveit.core_expr_types.tuples.merge_extension
# 35	instantiation	71, 72	{m in NaturalPos} |- |(A_{1}, A_{2}, ..., A_{m})| in Natural
# 	i : m, f(_a) : A_{_a}
# 36	instantiation	73, 44, 43	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- m in Rational
# 	A : Integer, B : Rational, x : m
# 37	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 38	instantiation	73, 44, 45	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 39	conjecture		|- forall_{A, B in BOOLEAN} ((A or B) in BOOLEAN)
# 	proveit.logic.booleans.disjunction.binary_closure
# 40	instantiation	46, 47	{forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN), m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN
# 	A : A
# 41	instantiation	48, 72, 53, 55, 54, 56	{m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- A_{m + 1} in BOOLEAN
# 	m : m, n : 0, A : ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)), B : A_{m + 1} in BOOLEAN, C : ()
# 42	axiom		|- forall_{m in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, B} ((A_{1} or  A_{2} or  ... or  A_{m} or B) =  \\ ((A_{1} or  A_{2} or  ... or  A_{m}) or B))]
# 	proveit.logic.booleans.disjunction.multi_disjunction_def
# 43	instantiation	73, 49, 50	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- m in Integer
# 	A : NaturalPos, B : Integer, x : m
# 44	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 45	instantiation	73, 51, 70	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 46	assumption		{forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)} |- forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)
# 47	instantiation	52, 53, 72, 70, 54, 55, 56	{m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN)
# 	l : 0, m : m, n : 1, A : (), B : ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN)), C : (A_{m + 1} in BOOLEAN)
# 48	conjecture		|- forall_{m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, B, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{m}, B,C_{1}, C_{2}, ..., C_{n}} B]
# 	proveit.logic.booleans.conjunction.any_from_and
# 49	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 50	instantiation	57, 58	{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- m in NaturalPos
# 	A : m in NaturalPos, B : forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)
# 51	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 52	conjecture		|- forall_{l, m, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{l}, B_{1}, B_{2}, ..., B_{m}, C_{1}, C_{2}, ..., C_{n} | A_{1}, A_{2}, ..., A_{l},B_{1}, B_{2}, ..., B_{m},C_{1}, C_{2}, ..., C_{n}} (B_{1} and  B_{2} and  ... and  B_{m})]
# 	proveit.logic.booleans.conjunction.some_from_and
# 53	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 54	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 55	instantiation	64, 72	{m in NaturalPos} |- |((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN))| = |(1, 2, ..., m)|
# 	i : m, f(_a) : A_{_a} in BOOLEAN
# 56	instantiation	59, 65, 60, 61, 62, 63	{m in NaturalPos,(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m} in BOOLEAN) and (A_{m + 1} in BOOLEAN)
# 	n : m + 1, P(_b_{1}, _b_{2}, ..., _b_{m + 1}) : _b_{1} and  _b_{2} and  ... and  _b_{m + 1}, x : ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)), y : ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN), A_{m + 1} in BOOLEAN)
# 57	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 58	assumption		{(m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]} |- (m in NaturalPos) and [forall_{A_{1}, A_{2}, ..., A_{m} in BOOLEAN} ((A_{1} or  A_{2} or  ... or  A_{m}) in BOOLEAN)]
# 59	conjecture		|- forall_{n in Natural} [forall_{P, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | P(x_{1}, x_{2}, ..., x_{n}), (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})]
# 	proveit.logic.equality.sub_in_right_operands_via_tuple
# 60	instantiation	64, 65	{m in NaturalPos} |- |((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN))| = |(1, 2, ..., (m + 1))|
# 	i : m + 1, f(_a) : A_{_a} in BOOLEAN
# 61	instantiation	66, 72	{m in NaturalPos} |- |((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN), A_{m + 1} in BOOLEAN)| = |(1, 2, ..., (m + 1))|
# 	f(_a) : A_{_a} in BOOLEAN, x : A_{m + 1} in BOOLEAN, i : m
# 62	assumption		{(A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)} |- (A_{1} in BOOLEAN) and  (A_{2} in BOOLEAN) and  ... and  (A_{m + 1} in BOOLEAN)
# 63	instantiation	67, 68	{m in NaturalPos} |- ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m + 1} in BOOLEAN)) =  \\ ((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN), A_{m + 1} in BOOLEAN)
# 	f(_a) : A_{_a} in BOOLEAN, i : 1, j : m
# 64	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 65	instantiation	69, 72, 70	{m in NaturalPos} |- (m + 1) in Natural
# 	a : m, b : 1
# 66	conjecture		|- forall_{f, x} [forall_{i in Natural} (|(f(1), f(2), ..., f(i), x)| = |(1, 2, ..., (i + 1))|)]
# 	proveit.core_expr_types.tuples.extended_range_from1_len_typical_eq
# 67	axiom		|- forall_{f, i, j | |(f(i), f(i + 1), ..., f(j))| in Natural} ((f(i), f(i + 1), ..., f(j + 1)) =  \\ (f(i), f(i + 1), ..., f(j), f(j + 1)))
# 	proveit.core_expr_types.tuples.range_extension_def
# 68	instantiation	71, 72	{m in NaturalPos} |- |((A_{1} in BOOLEAN), (A_{2} in BOOLEAN), ..., (A_{m} in BOOLEAN))| in Natural
# 	i : m, f(_a) : A_{_a} in BOOLEAN
# 69	conjecture		|- forall_{a, b in Natural} ((a + b) in Natural)
# 	proveit.numbers.addition.add_nat_closure_bin
# 70	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 71	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| in Natural)]
# 	proveit.core_expr_types.tuples.range_from1_len_is_nat
# 72	instantiation	73, 74, 75	{m in NaturalPos} |- m in Natural
# 	A : NaturalPos, B : Natural, x : m
# 73	conjecture		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 74	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 75	assumption		{m in NaturalPos} |- m in NaturalPos
