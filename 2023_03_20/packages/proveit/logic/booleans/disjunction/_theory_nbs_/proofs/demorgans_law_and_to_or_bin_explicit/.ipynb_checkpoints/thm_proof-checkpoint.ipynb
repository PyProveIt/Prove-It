# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">logic</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">booleans</a>.<a class="ProveItLink" href="../../theory.ipynb">disjunction</a>.<a class="ProveItLink" href="../../theorems.ipynb#demorgans_law_and_to_or_bin_explicit">demorgans_law_and_to_or_bin_explicit</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving demorgans_law_and_to_or_bin_explicit
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="demorgans_law_and_to_or_bin_explicit">demorgans_law_and_to_or_bin_explicit:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/23b797b1f949e11ccaae46b16e1a7b526c0743dd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/60c1c12f92b8e577caa7b15011abda708c795c990/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.logic.booleans.disjunction.demorgans_law_and_to_or_bin_explicit has been proven.
# 	step type	requirements	statement
# 0	modus ponens	1, 2	|- forall_{A, B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)
# 1	instantiation	3, 4, 5*	|- [forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)]] \\  => [forall_{A, B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)]
# 	m : 1, n : 1, P(A, B) : A or B, Q(A) : A in BOOLEAN, R(A, B) : (B in BOOLEAN) and [not]([not](A) and [not](B)), x_{1} : A, y_{1} : B
# 2	instantiation	6, 7, 8	|- forall_{A in BOOLEAN} [forall_{B in BOOLEAN | [not]([not](A) and [not](B))} (A or B)]
# 	P(A) : forall_{B in BOOLEAN | [not]([not](A) and [not](B))} (A or B), A : A
# 3	conjecture		|- forall_{m, n in NaturalPos} [forall_{P, Q, R} ([forall_{x_{1}, x_{2}, ..., x_{m} | Q(x_{1}, x_{2}, ..., x_{m})} [forall_{y_{1}, y_{2}, ..., y_{n} | R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})]] \\  => [forall_{x_{1}, x_{2}, ..., x_{m}, y_{1}, y_{2}, ..., y_{n} | Q(x_{1}, x_{2}, ..., x_{m}), R(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})} P(x_{1}, x_{2}, ..., x_{m},y_{1}, y_{2}, ..., y_{n})])]
# 	proveit.logic.booleans.quantification.universality.bundle
# 4	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 5	instantiation	9, 10, 11	|- {A or B if A in BOOLEAN ,  (B in BOOLEAN) and [not]([not](A) and [not](B)). \\  = {A or B if A in BOOLEAN ,  B in BOOLEAN ,  [not]([not](A) and [not](B)).
# 	n : 2, a : A or B, Q : A in BOOLEAN, R : (B in BOOLEAN, [not]([not](A) and [not](B)))
# 6	conjecture		|- forall_{P | P(TRUE), P(FALSE)} [forall_{A in BOOLEAN} P(A)]
# 	proveit.logic.booleans.forall_over_bool_by_cases
# 7	instantiation	14, 12, 13	|- forall_{B in BOOLEAN | [not]([not](TRUE) and [not](B))} (TRUE or B)
# 	P(B) : TRUE or B, Q(B) : [not]([not](TRUE) and [not](B)), A : B
# 8	instantiation	14, 15, 16	|- forall_{B in BOOLEAN | [not]([not](FALSE) and [not](B))} (FALSE or B)
# 	P(B) : FALSE or B, Q(B) : [not]([not](FALSE) and [not](B)), A : B
# 9	conjecture		|- forall_{n in Natural} [forall_{a, Q, R_{1}, R_{2}, ..., R_{n}} ({a if Q ,  R_{1} and  R_{2} and  ... and  R_{n}. \\  = {a if Q, R_{1} ,  R_{2} ,  ... ,  R_{n}.)]
# 	proveit.core_expr_types.conditionals.condition_prepend_reduction
# 10	instantiation	17, 18, 19	|- 2 in Natural
# 	A : NaturalPos, B : Natural, x : 2
# 11	instantiation	20	|- |(B in BOOLEAN, [not]([not](A) and [not](B)))| = |(1, ..., 2)|
# 	a : B in BOOLEAN, b : [not]([not](A) and [not](B))
# 12	deduction	21	|- [not]([not](TRUE) and [not](TRUE)) => (TRUE or TRUE)
# 13	deduction	22	|- [not]([not](TRUE) and [not](FALSE)) => (TRUE or FALSE)
# 14	conjecture		|- forall_{P, Q | Q(TRUE) => P(TRUE), Q(FALSE) => P(FALSE)} [forall_{A in BOOLEAN | Q(A)} P(A)]
# 	proveit.logic.booleans.conditioned_forall_over_bool_by_cases
# 15	deduction	23	|- [not]([not](FALSE) and [not](TRUE)) => (FALSE or TRUE)
# 16	instantiation	24, 25	|- [not]([not](FALSE) and [not](FALSE)) => (FALSE or FALSE)
# 	A : [not]([not](FALSE) and [not](FALSE)), B : FALSE or FALSE
# 17	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 18	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 19	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 20	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 21	instantiation	31, 26	|- TRUE or TRUE
# 	A : TRUE or TRUE
# 22	instantiation	31, 27	|- TRUE or FALSE
# 	A : TRUE or FALSE
# 23	instantiation	31, 28	|- FALSE or TRUE
# 	A : FALSE or TRUE
# 24	theorem		|- forall_{A, B | [not](A)} (A => B)
# 	proveit.logic.booleans.implication.falsified_antecedent_implication
# 25	instantiation	29, 30	|- [not]([not]([not](FALSE) and [not](FALSE)))
# 	A : [not](FALSE) and [not](FALSE)
# 26	axiom		|- (TRUE or TRUE) = TRUE
# 	proveit.logic.booleans.disjunction.or_t_t
# 27	axiom		|- (TRUE or FALSE) = TRUE
# 	proveit.logic.booleans.disjunction.or_t_f
# 28	axiom		|- (FALSE or TRUE) = TRUE
# 	proveit.logic.booleans.disjunction.or_f_t
# 29	theorem		|- forall_{A | A} [not]([not](A))
# 	proveit.logic.booleans.negation.double_negation_intro
# 30	instantiation	31, 32	|- [not](FALSE)
# 	A : [not](FALSE)
# 31	axiom		|- forall_{A | A = TRUE} A
# 	proveit.logic.booleans.eq_true_elim
# 32	axiom		|- [not](FALSE) = TRUE
# 	proveit.logic.booleans.negation.not_f
