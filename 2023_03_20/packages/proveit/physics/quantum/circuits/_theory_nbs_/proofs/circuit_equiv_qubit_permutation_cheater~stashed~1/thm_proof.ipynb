# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">circuits</a>.<a class="ProveItLink" href="../../theorems.ipynb#circuit_equiv_qubit_permutation_cheater">circuit_equiv_qubit_permutation_cheater</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving circuit_equiv_qubit_permutation_cheater
# Out:
# circuit_equiv_qubit_permutation_cheater: forall_{k, m, n in NaturalPos} [forall_{A_{1, 1}, A_{1, 2}, ..., A_{1, m}, A_{2, 1}, A_{2, 2}, ..., A_{2, m}, ......, A_{k, 1}, A_{k, 2}, ..., A_{k, m}, B_{1, 1}, B_{1, 2}, ..., B_{1, n}, B_{2, 1}, B_{2, 2}, ..., B_{2, n}, ......, B_{k, 1}, B_{k, 2}, ..., B_{k, n}, C_{1, 1}, C_{1, 2}, ..., C_{1, m}, C_{2, 1}, C_{2, 2}, ..., C_{2, m}, ......, C_{k, 1}, C_{k, 2}, ..., C_{k, m}, D_{1, 1}, D_{1, 2}, ..., D_{1, n}, D_{2, 1}, D_{2, 2}, ..., D_{2, n}, ......, D_{k, 1}, D_{k, 2}, ..., D_{k, n}} [forall_{R_{1, 1}, R_{1, 2}, ..., R_{1, m}, R_{2, 1}, R_{2, 2}, ..., R_{2, m}, ......, R_{k, 1}, R_{k, 2}, ..., R_{k, m}, S_{1, 1}, S_{1, 2}, ..., S_{1, n}, S_{2, 1}, S_{2, 2}, ..., S_{2, n}, ......, S_{k, 1}, S_{k, 2}, ..., S_{k, n}, T_{1, 1}, T_{1, 2}, ..., T_{1, m}, T_{2, 1}, T_{2, 2}, ..., T_{2, m}, ......, T_{k, 1}, T_{k, 2}, ..., T_{k, m}, U_{1, 1}, U_{1, 2}, ..., U_{1, n}, U_{2, 1}, U_{2, 2}, ..., U_{2, n}, ......, U_{k, 1}, U_{k, 2}, ..., U_{k, n}} ((QC
# ...
