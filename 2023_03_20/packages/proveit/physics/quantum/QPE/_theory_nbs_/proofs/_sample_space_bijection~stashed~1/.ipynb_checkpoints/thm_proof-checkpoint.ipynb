# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_sample_space_bijection">_sample_space_bijection</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit import f, m, n, x, y, A
from proveit.logic import InSet, NotEquals
from proveit.logic.sets.functions.bijections import bijective_by_uniqueness
from proveit.physics.quantum.QPE import (_t, _s, _t_in_natural_pos, _s_in_nat_pos,
                                         _sample_space_def)

# %%
# %proving _sample_space_bijection
# Out:
# _sample_space_bijection: [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in Bijections({0 .. 2^{t} - 1}, Omega)

# %%
_sample_space_def
# Out:
# |- Omega = {QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))}_{m in {0 .. 2^{t} - 1}}

# %% [markdown]
# We want to use $\Omega$ as our shorthand for the sample space:

# %%
defaults.replacements = set([_sample_space_def.derive_reversed()])
# Out:
# defaults.replacements: ({QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))}_{m in {0 .. 2^{t} - 1}} = Omega)

# %%
lambda_map = _sample_space_bijection.element
# Out:
# lambda_map: m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))

# %%
domain = _sample_space_bijection.domain.domain
# Out:
# domain: {0 .. 2^{t} - 1}

# %% [markdown]
# In order to show that the image of the map is a bijection, we want to show that distinct elements of the domain map to distinct quantum circuits.

# %%
defaults.assumptions = [InSet(m, domain), InSet(n, domain), NotEquals(m, n)]
# Out:
# defaults.assumptions: (m in {0 .. 2^{t} - 1}, n in {0 .. 2^{t} - 1}, m != n)

# %% [markdown]
# We need this for some reason.  It would be nice to handle this automatically.

# %%
from proveit.numbers import Add, Mult, four
Mult(four, Add(_t, _s)).distribution(1)
# Out:
# |- (4 * (t + s)) =  \\ ((4 * t) + (4 * s))

# %%
NotEquals(lambda_map.apply(m), lambda_map.apply(n)).prove()
# Out:
# {m in {0 .. 2^{t} - 1}, n in {0 .. 2^{t} - 1}, m != n} |- QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) != QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|n〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))

# %%
bijective_by_uniqueness
# Out:
# |- forall_{f, A} ([forall_{x, y in A | x != y} (f(x) != f(y))] => (f in Bijections(A, f^*(A))))

# %%
defaults.assumptions = []
# Out:
# defaults.assumptions: ()

# %%
bijective_by_uniqueness.instantiate(
    {f:lambda_map, A:domain, x:m, y:n}).derive_consequent()
# Out:
# _sample_space_bijection has been proven.  Now simply execute "%qed".
# |- [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in Bijections({0 .. 2^{t} - 1}, Omega)

# %%
# %qed
# Out:
# ---------------------------------------------------------------------------
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     812                     concluded_truth = self.conclude_via_implication(
# --> 813                             assumptions=assumptions)
#     814                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#     907         from proveit.logic import conclude_via_implication
# --> 908         return conclude_via_implication(self)
#     909
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     433         defaults.assumptions,
# --> 434         'Unable to conclude via implications')
#     435
#
# ProofFailure: Unable to prove [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in Bijections({0 .. 2^{t} - 1}, Omega):
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     812                     concluded_truth = self.conclude_via_implication(
# --> 813                             assumptions=assumptions)
#     814                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#     907         from proveit.logic import conclude_via_implication
# --> 908         return conclude_via_implication(self)
#     909
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     433         defaults.assumptions,
# --> 434         'Unable to conclude via implications')
#     435
#
# ProofFailure: Unable to prove [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in Injections({0 .. 2^{t} - 1}, Omega):
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     812                     concluded_truth = self.conclude_via_implication(
# --> 813                             assumptions=assumptions)
#     814                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#     907         from proveit.logic import conclude_via_implication
# --> 908         return conclude_via_implication(self)
#     909
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     433         defaults.assumptions,
# --> 434         'Unable to conclude via implications')
#     435
#
# ProofFailure: Unable to prove [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in [{0 .. 2^{t} - 1} -> Omega]:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     812                     concluded_truth = self.conclude_via_implication(
# --> 813                             assumptions=assumptions)
#     814                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#     907         from proveit.logic import conclude_via_implication
# --> 908         return conclude_via_implication(self)
#     909
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     433         defaults.assumptions,
# --> 434         'Unable to conclude via implications')
#     435
#
# ProofFailure: Unable to prove forall_{x in {0 .. 2^{t} - 1}} (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) in Omega):
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     812                     concluded_truth = self.conclude_via_implication(
# --> 813                             assumptions=assumptions)
#     814                 except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in conclude_via_implication(self, **defaults_config)
#     907         from proveit.logic import conclude_via_implication
# --> 908         return conclude_via_implication(self)
#     909
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/implication/implies.py in conclude_via_implication(consequent, **defaults_config)
#     433         defaults.assumptions,
# --> 434         'Unable to conclude via implications')
#     435
#
# ProofFailure: Unable to prove QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) in Omega assuming {x in {0 .. 2^{t} - 1}}:
# Unable to conclude via implications
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in conclude(self, **defaults_config)
#     124             try:
# --> 125                 return self.conclude_via_generalization(automation=True)
#     126             except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in conclude_via_generalization(self, **defaults_config)
#     202                 if automation and not isinstance(expr, Forall):
# --> 203                     expr.prove()
#     204                 if expr.proven():
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     816                     # class
# --> 817                     concluded_truth = self.conclude(assumptions=assumptions)
#     818             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     198                            "method with a strategy for proving "
# --> 199                            "membership." % self.domain)
#     200
#
# ProofFailure: Unable to prove QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) in Omega assuming {x in {0 .. 2^{t} - 1}}:
# Unable to conclude automatically; the domain, Omega, has no 'membership_object' method with a strategy for proving membership.
#
# During handling of the above exception, another exception occurred:
#
# ProofFailure                              Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1586                             requirements.append(subbed_cond.prove(
# -> 1587                                     assumptions=assumptions))
#    1588                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     816                     # class
# --> 817                     concluded_truth = self.conclude(assumptions=assumptions)
#     818             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in conclude(self, **defaults_config)
#     127                 raise ProofFailure(self, defaults.assumptions,
# --> 128                                    "Unable to conclude automatically; "
#     129                                    "the domain has no 'prove_by_cases' method "
#
# ProofFailure: Unable to prove forall_{x in {0 .. 2^{t} - 1}} (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) in Omega):
# Unable to conclude automatically; the domain has no 'prove_by_cases' method and automated generalization failed.
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1586                             requirements.append(subbed_cond.prove(
# -> 1587                                     assumptions=assumptions))
#    1588                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     816                     # class
# --> 817                     concluded_truth = self.conclude(assumptions=assumptions)
#     818             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     192         if hasattr(self, 'membership_object'):
# --> 193             return self.membership_object.conclude()
#     194
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/functions/functions_membership.py in conclude(self, **defaults_config)
#      31         return membership_folding.instantiate(
# ---> 32                 {A:_A, B:_B, f:_f}, auto_simplify=False)
#      33
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, **defaults_config)
#     999                               equiv_alt_expansions=equiv_alt_expansions,
# -> 1000                               assumptions=defaults.assumptions))
#    1001         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1186                     equiv_alt_expansions, assumptions, requirements,
# -> 1187                     equality_repl_requirements)
#    1188
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1589                             raise_failure('Unsatisfied condition: %s'
# -> 1590                                           % str(subbed_cond))
#    1591
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in raise_failure(msg)
#    1401             raise InstantiationFailure(original_judgment, repl_map,
# -> 1402                                        assumptions, msg)
#    1403
#
# InstantiationFailure: Proof step failed:
# Attempting to instantiate |- forall_{A, B} [forall_{f | forall_{x in A} (f(x) in B)} (f in [A -> B])] with {A: {0 .. 2^{t} - 1}, B: Omega, f: m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))}:
# Unsatisfied condition: forall_{x in {0 .. 2^{t} - 1}} (QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|x〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}))) in Omega)
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1586                             requirements.append(subbed_cond.prove(
# -> 1587                                     assumptions=assumptions))
#    1588                         except ProofFailure:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     816                     # class
# --> 817                     concluded_truth = self.conclude(assumptions=assumptions)
#     818             if concluded_truth is None:
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     192         if hasattr(self, 'membership_object'):
# --> 193             return self.membership_object.conclude()
#     194
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/functions/injections/injections_membership.py in conclude(self, **defaults_config)
#      32         return membership_folding.instantiate(
# ---> 33                 {A:_A, B:_B, f:_f}, auto_simplify=False)
#      34
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, **defaults_config)
#     999                               equiv_alt_expansions=equiv_alt_expansions,
# -> 1000                               assumptions=defaults.assumptions))
#    1001         finally:
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1186                     equiv_alt_expansions, assumptions, requirements,
# -> 1187                     equality_repl_requirements)
#    1188
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1589                             raise_failure('Unsatisfied condition: %s'
# -> 1590                                           % str(subbed_cond))
#    1591
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in raise_failure(msg)
#    1401             raise InstantiationFailure(original_judgment, repl_map,
# -> 1402                                        assumptions, msg)
#    1403
#
# InstantiationFailure: Proof step failed:
# Attempting to instantiate |- forall_{A, B} [forall_{f in [A -> B] | forall_{a, b in A | a != b} (f(a) != f(b))} (f in Injections(A, B))] with {A: {0 .. 2^{t} - 1}, B: Omega, f: m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))}:
# Unsatisfied condition: [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in [{0 .. 2^{t} - 1} -> Omega]
#
# During handling of the above exception, another exception occurred:
#
# InstantiationFailure                      Traceback (most recent call last)
# <ipython-input-12-b046f9677097> in <module>
# ----> 1 get_ipython().run_line_magic('qed', '')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <decorator-gen-143> in qed(self, line)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in qed(self, line)
#     978     @line_magic
#     979     def qed(self, line):
# --> 980         return ProveItMagicCommands.qed(self)
#     981
#     982     @line_magic
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in qed(self)
#     650     def qed(self):
#     651         import proveit
# --> 652         proof = Judgment.theorem_being_proven.proven_truth._qed()
#     653         proof._repr_html_()  # generate expressions that should be referenced
#     654         # clean unreferenced expressions, but only when "display latex"
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in _qed(self)
#     336         Judgment.qed_in_progress = True
#     337         try:
# --> 338             proof = self.expr.prove(assumptions=[]).proof()
#     339             if not proof.is_usable():
#     340                 proof.proven_truth.raise_unusable_proof()
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     137                         setattr(temp_defaults, key, kwargs[key])
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#     141             # No defaults reconfiguration.
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in prove(self, **defaults_config)
#     815                     # try the 'conclude' method of the specific Expression
#     816                     # class
# --> 817                     concluded_truth = self.conclude(assumptions=assumptions)
#     818             if concluded_truth is None:
#     819                 raise ProofFailure(
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     137                         setattr(temp_defaults, key, kwargs[key])
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#     141             # No defaults reconfiguration.
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in conclude(self, **defaults_config)
#     191         # the 'membership_object' if there is one.
#     192         if hasattr(self, 'membership_object'):
# --> 193             return self.membership_object.conclude()
#     194
#     195         raise ProofFailure(self, defaults.assumptions,
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     141             # No defaults reconfiguration.
#     142             kwargs.update(public_attributes_dict(defaults))
# --> 143             proven_truth = checked_truth(func(*args, **kwargs))
#     144
#     145         if is_conclude_method:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/functions/bijections/bijections_membership.py in conclude(self, **defaults_config)
#      32         _f = self.element
#      33         return membership_folding.instantiate(
# ---> 34                 {A:_A, B:_B, f:_f}, auto_simplify=False)
#      35
#      36     @equality_prover('defined', 'define')
#
# /home/wwitzel/Prove-It/packages/proveit/decorators.py in decorated_prover(*args, **kwargs)
#     137                         setattr(temp_defaults, key, kwargs[key])
#     138                 kwargs.update(public_attributes_dict(defaults))
# --> 139                 proven_truth = checked_truth(func(*args, **kwargs))
#     140         else:
#     141             # No defaults reconfiguration.
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in instantiate(self, repl_map, num_forall_eliminations, **defaults_config)
#     998                               repl_map=processed_repl_map,
#     999                               equiv_alt_expansions=equiv_alt_expansions,
# -> 1000                               assumptions=defaults.assumptions))
#    1001         finally:
#    1002             # Revert the preserved_exprs set back to what it was.
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in __init__(self, orig_judgment, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions)
#    1185                     num_forall_eliminations, repl_map,
#    1186                     equiv_alt_expansions, assumptions, requirements,
# -> 1187                     equality_repl_requirements)
#    1188
#    1189             # Remove duplicates in the requirements.
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in _instantiated_expr(original_judgment, relabel_params, relabel_param_replacements, param_to_num_operand_entries, num_forall_eliminations, repl_map, equiv_alt_expansions, assumptions, requirements, equality_repl_requirements)
#    1588                         except ProofFailure:
#    1589                             raise_failure('Unsatisfied condition: %s'
# -> 1590                                           % str(subbed_cond))
#    1591
#    1592         # Make final instantiations in the inner instance expression.
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/proof.py in raise_failure(msg)
#    1400         def raise_failure(msg):
#    1401             raise InstantiationFailure(original_judgment, repl_map,
# -> 1402                                        assumptions, msg)
#    1403
#    1404         def instantiate(expr):
#
# InstantiationFailure: Proof step failed:
# Attempting to instantiate |- forall_{A, B} [forall_{f in Injections(A, B) | f in Surjections(A, B)} (f in Bijections(A, B))] with {A: {0 .. 2^{t} - 1}, B: Omega, f: m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))}:
# Unsatisfied condition: [m -> QCIRCUIT(VertExprArray(([INPUT]{state:|+〉}, [INPUT]{state:|+〉}, ..(t - 3) ×.., [INPUT]{state:|+〉},[MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[INPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}}), ([MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:1}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:2}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:t}, targets:{1 .. t + s}},[MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 1)}, targets:{1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + 2)}, targets:{1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[GATE]{operation:QPE(U, t), part:(t + s)}, targets:{1 .. t + s}}), ([MEASURE]{basis:Z}, [MEASURE]{basis:Z}, ..(t - 3) ×.., [MEASURE]{basis:Z},[GATE]{operation:I}, [GATE]{operation:I}, ..(s - 3) ×.., [GATE]{operation:I}), ([MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:1}, targets:{1 .. t}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:2}, targets:{1 .. t}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|m〉_{t}, part:t}, targets:{1 .. t}},[MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:1}, targets:{t + 1 .. t + s}}, [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:2}, targets:{t + 1 .. t + s}}, ..., [MULTI_QUBIT_ELEM]{element:[OUTPUT]{state:|u>, part:s}, targets:{t + 1 .. t + s}})))] in Injections({0 .. 2^{t} - 1}, Omega)
