# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_pos_domain_within_integer">_pos_domain_within_integer</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _pos_domain_within_integer
# Out:
# _pos_domain_within_integer: forall_{e in {2 .. 2^{t - 1} - 2}} ({e + 1 .. 2^{t - 1}} subset_eq Integer)

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {2 .. 2^{t - 1} - 2}} ({e + 1 .. 2^{t - 1}} subset_eq Integer)
# 1	instantiation	2, 3	{e in {2 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} subset_eq Integer
# 	A : {e + 1 .. 2^{t - 1}}, B : Integer
# 2	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 3	instantiation	10, 4, 13	{e in {2 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : e + 1, b : 2^{t - 1}
# 4	instantiation	12, 5, 6	{e in {2 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 5	instantiation	18, 7, 8	{e in {2 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {2 .. 2^{t - 1} - 2}, B : Integer, x : e
# 6	instantiation	18, 19, 9	|- 1 in Integer
# 	A : NaturalPos, B : Integer, x : 1
# 7	instantiation	10, 17, 11	|- {2 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 2, b : 2^{t - 1} - 2
# 8	assumption		{e in {2 .. 2^{t - 1} - 2}} |- e in {2 .. 2^{t - 1} - 2}
# 9	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 10	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 11	instantiation	12, 13, 14	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 12	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 13	instantiation	18, 19, 15	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 14	instantiation	16, 17	|- (-2) in Integer
# 	a : 2
# 15	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 16	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 17	instantiation	18, 19, 20	|- 2 in Integer
# 	A : NaturalPos, B : Integer, x : 2
# 18	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 19	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 20	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
