# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_delta_b_floor_diff_in_interval">_delta_b_floor_diff_in_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import l, defaults
from proveit.numbers import subtract
from proveit.physics.quantum.QPE import _full_domain, _t, _two_pow_t, _two_pow__t_minus_one
from proveit.physics.quantum.QPE import (
    _delta_b_is_real, _scaled_delta_b_floor_in_interval,
    _t_in_natural_pos, _two_pow_t_is_nat_pos, _two_pow_t_minus_one_is_nat_pos)

# %%
# %proving _delta_b_floor_diff_in_interval
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_delta_b_floor_diff_in_interval">_delta_b_floor_diff_in_interval:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/677e792593b37ab24ecd06f87d2df52cf4c74c420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/0b50b41ebcf119dc609e2e26048768a6d7b0bd350/dependencies.ipynb">dependencies</a>)<br>

# %%
# interesting issue here: cascading "side effect failures" leading to
# max recursion error if we haven't already imported at least one of the
# following: _full_domain, _t, _two_pow_t, _two_pow__t_minus_one
defaults.assumptions = _delta_b_floor_diff_in_interval.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/9d44703202c90bf74d9fdb2fd6b052ac5a74ac8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# previously proven
_scaled_delta_b_floor_in_interval
# Out:
# |- (2^{t} * delta_{b_{f}}) in [0,1)

# %%
scaled_delta_less_than_one = (
    _scaled_delta_b_floor_in_interval.derive_element_upper_bound())
# Out:
# <strong id="scaled_delta_less_than_one">scaled_delta_less_than_one:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/803edd45a2856b66f298f0c8165b320fa03ce4dd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/836886304e3cc5055b636c1e745bc55ef4bf40060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_delta_greatereq_than_zero = (
    _scaled_delta_b_floor_in_interval.derive_element_lower_bound())
# Out:
# <strong id="scaled_delta_greatereq_than_zero">scaled_delta_greatereq_than_zero:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/19997034cd1380359f418ec5a889d57f76b689cf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/af8a7e90f4abc302ce926bf99e2f34ce3796c4870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# for convenience, name the product 2^t * delta
scaled_delta = _scaled_delta_b_floor_in_interval.element
# Out:
# <strong id="scaled_delta">scaled_delta:</strong> <a class="ProveItLink" href="../../../__pv_it/common/940fcad8977dd953271c0334bf6744ba39a895a30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the difference 2^t * delta - ell
scaled_delta_minus_ell = subtract(scaled_delta, l)
# Out:
# <strong id="scaled_delta_minus_ell">scaled_delta_minus_ell:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/6f1e4d5ced2b9f326d873f5748ee844b5bf956220/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
# This allows a distribution() method to proceed further below
from proveit import b
from proveit.physics.quantum.QPE import _b_floor, _best_floor_is_int
_delta_b_floor_is_real = _delta_b_is_real.instantiate({b: _b_floor})
# Out:
# <strong id="_delta_b_floor_is_real">_delta_b_floor_is_real:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/7f543d1c91666131131785fa776c43582ecee68c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/095b6b0473620ad3472027b86aeaee8b29e1dad50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# for convenience, name the ell membership obj
ell_in_full_domain = defaults.assumptions[0]
# Out:
# <strong id="ell_in_full_domain">ell_in_full_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
ell_upper_bound = ell_in_full_domain.derive_element_upper_bound()
# Out:
# <strong id="ell_upper_bound">ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/137c2805f54bd37dbcf2ebc503f8ec8d9369f3b10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/d959c94c6b67001a2d9a6245fbea5be37f398c430/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ell_lower_bound = ell_in_full_domain.derive_element_lower_bound()
# Out:
# <strong id="ell_lower_bound">ell_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/23c22fe1298bc06b01c6ef3d3b8c79f884e1d8620/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/df26de15e6281c28c9df783cf413d8b0c3c4c5990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Upper Bound
# Develop upper bound, using information about the bounds on the individual pieces …

# %%
from proveit.numbers import one, Neg
negative_ell_upper_bound = ell_lower_bound.left_mult_both_sides(Neg(one)).simplify()
# Out:
# <strong id="negative_ell_upper_bound">negative_ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/2400c46df4d7dd778940a585db140468169e3c250/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/739525e667f207f920fc07a464f30e59e3df38440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# rewrite the bounding inequality so -ell is on the left
negative_ell_upper_bound = negative_ell_upper_bound.with_styles(direction='normal')
# Out:
# <strong id="negative_ell_upper_bound">negative_ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/2400c46df4d7dd778940a585db140468169e3c250/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/b7ede4f6de038dd70bae466f5a75f0c185d4de2f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_delta_minus_ell_upper_bound = (
    scaled_delta_minus_ell.deduce_bound(
        [scaled_delta_less_than_one, negative_ell_upper_bound]))
# Out:
# <strong id="scaled_delta_minus_ell_upper_bound">scaled_delta_minus_ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/982cfbab6431013493cdcf8db0080833988ccadf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/63c53764e966174d12d72b2bb7ffbf06b61eaf6c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Divide through by $2^t$ and Simplify

# %%
upper_bound_judgment = scaled_delta_minus_ell_upper_bound.divide_both_sides(_two_pow_t)
# Out:
# <strong id="upper_bound_judgment">upper_bound_judgment:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/4cd3c3a8ae8fc051a681d9c7bbd685dadbdda27b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/5efbf7f7279de8438b5041ebdd46a6e1e0d935940/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
upper_bound_one_half_02 = upper_bound_judgment.inner_expr().lhs.distribute()
# Out:
# <strong id="upper_bound_one_half_02">upper_bound_one_half_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/257bcfc178e6132dc3e3aadcea318decb89727d10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/dbbdc8b47e43e2523695f34542ebfd9cc19626a10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Lower Bound
# Develop lower bound using information about the bounds on the individual pieces …

# %%
# recall from earlier:
ell_upper_bound
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l <= 2^{t - 1}

# %%
negative_ell_lower_bound = ell_upper_bound.left_mult_both_sides(Neg(one))
# Out:
# <strong id="negative_ell_lower_bound">negative_ell_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/601e05226a4d157ed0159d7842ee5621f469a7620/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/ea18aa55bc910a62d1f953337718bc6b200ef2730/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# recall from earlier:
scaled_delta_minus_ell
# Out:
# (2^{t} * delta_{b_{f}}) - l

# %%
scaled_delta_minus_ell_lower_bound = (
    scaled_delta_minus_ell.deduce_bound(
        [scaled_delta_greatereq_than_zero.with_styles(direction='reversed'),
         negative_ell_lower_bound]))
# Out:
# <strong id="scaled_delta_minus_ell_lower_bound">scaled_delta_minus_ell_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/064cbc1ec6db362e2ea64875a8026c83fb50caab0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/883fd496d3ab0ccd72f13b79db9107e84b952f7a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Divide through by $2^t$ and Simplify

# %%
lower_bound_judgment = scaled_delta_minus_ell_lower_bound.divide_both_sides(_two_pow_t)
# Out:
# <strong id="lower_bound_judgment">lower_bound_judgment:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/c88179d3a27d1061b50fef2f4050eecd2ef936870/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_floor_diff_in_interval/fc0e1249b789fbc48ea1a0abb22eda02b2d2bd620/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _delta_b_floor_diff_in_interval may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._delta_b_floor_diff_in_interval has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2))
# 1	instantiation	2, 3, 6, 4, 5	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b_{f}} - (l / 2^{t})
# 2	conjecture		|- forall_{a, b, x in Real | a <= x < b} (x in [a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalCO
# 3	instantiation	169, 6	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 4	instantiation	102, 79, 7	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in Real
# 	a : delta_{b_{f}}, b : -(l / 2^{t})
# 5	instantiation	8, 9, 10	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-(1 / 2)) <= (delta_{b_{f}} - (l / 2^{t}))) and ((delta_{b_{f}} - (l / 2^{t})) < (1 / 2))
# 	A : (-(1 / 2)) <= (delta_{b_{f}} - (l / 2^{t})), B : (delta_{b_{f}} - (l / 2^{t})) < (1 / 2)
# 6	instantiation	16, 138, 152, 100	|- (1 / 2) in Real
# 	a : 1, b : 2
# 7	instantiation	169, 11	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(l / 2^{t})) in Real
# 	a : l / 2^{t}
# 8	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 9	instantiation	13, 12, 15	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(1 / 2)) <= (delta_{b_{f}} - (l / 2^{t}))
# 	P(_a) : (-(1 / 2)) <= _a, x : ((2^{t} * delta_{b_{f}}) - l) / 2^{t}, y : delta_{b_{f}} - (l / 2^{t})
# 10	instantiation	13, 14, 15	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) < (1 / 2)
# 	P(_a) : _a < (1 / 2), x : ((2^{t} * delta_{b_{f}}) - l) / 2^{t}, y : delta_{b_{f}} - (l / 2^{t})
# 11	instantiation	16, 118, 96, 43	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 2^{t}) in Real
# 	a : l, b : 2^{t}
# 12	instantiation	17, 96, 137, 21, 18, 23, 19*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(1 / 2)) <= (((2^{t} * delta_{b_{f}}) - l) / 2^{t})
# 	a : 2^{t}, x : -2^{t - 1}, y : (2^{t} * delta_{b_{f}}) - l
# 13	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 14	instantiation	20, 96, 21, 157, 22, 23, 31*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (((2^{t} * delta_{b_{f}}) - l) / 2^{t}) < (1 / 2)
# 	a : 2^{t}, x : (2^{t} * delta_{b_{f}}) - l, y : 2^{t - 1}
# 15	instantiation	24, 25, 106, 78, 43, 26*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (((2^{t} * delta_{b_{f}}) - l) / 2^{t}) = (delta_{b_{f}} - (l / 2^{t}))
# 	x : 2^{t} * delta_{b_{f}}, y : l, z : 2^{t}
# 16	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 17	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 	proveit.numbers.division.weak_div_from_numer_bound__pos_denom
# 18	instantiation	27, 28, 29	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-2^{t - 1}) <= ((2^{t} * delta_{b_{f}}) - l)
# 	x : -2^{t - 1}, y : 0 - l, z : (2^{t} * delta_{b_{f}}) - l
# 19	instantiation	30, 140, 78, 43, 31*	|- ((-2^{t - 1}) / 2^{t}) = (-(1 / 2))
# 	x : 2^{t - 1}, y : 2^{t}
# 20	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((x / a) < (y / a))
# 	proveit.numbers.division.strong_div_from_numer_bound__pos_denom
# 21	instantiation	102, 46, 49	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2^{t} * delta_{b_{f}}) - l) in Real
# 	a : 2^{t} * delta_{b_{f}}, b : -l
# 22	instantiation	32, 33, 34	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2^{t} * delta_{b_{f}}) - l) < 2^{t - 1}
# 	x : (2^{t} * delta_{b_{f}}) - l, y : 1 - l, z : 2^{t - 1}
# 23	instantiation	35, 125	|- 2^{t} > 0
# 	n : 2^{t}
# 24	conjecture		|- forall_{x, y, z in Complex | z != 0} (((x - y) / z) = ((x / z) - (y / z)))
# 	proveit.numbers.division.distribute_frac_through_subtract
# 25	instantiation	197, 160, 46	|- (2^{t} * delta_{b_{f}}) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta_{b_{f}}
# 26	instantiation	127, 36, 37	|- ((2^{t} * delta_{b_{f}}) / 2^{t}) = delta_{b_{f}}
# 	x : (2^{t} * delta_{b_{f}}) / 2^{t}, y : delta_{b_{f}} / 1, z : delta_{b_{f}}
# 27	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 28	instantiation	48, 67, 137, 49, 38, 39*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-2^{t - 1}) <= (0 - l)
# 	a : 0, x : -2^{t - 1}, y : -l
# 29	instantiation	40, 49, 67, 46, 41	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (0 - l) <= ((2^{t} * delta_{b_{f}}) - l)
# 	a : -l, x : 0, y : 2^{t} * delta_{b_{f}}
# 30	conjecture		|- forall_{x, y in Complex | y != 0} (((-x) / y) = (-(x / y)))
# 	proveit.numbers.division.neg_frac_neg_numerator
# 31	instantiation	42, 140, 78, 43, 44*	|- (2^{t - 1} / 2^{t}) = (1 / 2)
# 	x : 2^{t - 1}, y : 2^{t}
# 32	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 33	instantiation	45, 49, 46, 138, 47	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2^{t} * delta_{b_{f}}) - l) < (1 - l)
# 	a : -l, x : 2^{t} * delta_{b_{f}}, y : 1
# 34	instantiation	48, 138, 49, 50, 51, 52*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 - l) <= 2^{t - 1}
# 	a : 1, x : -l, y : 2^{t - 1} - 1
# 35	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 36	instantiation	53, 54, 55, 58, 56*	|- ((2^{t} * delta_{b_{f}}) / 2^{t}) = (delta_{b_{f}} / 1)
# 	x : 2^{t}, z : 1, y : delta_{b_{f}}
# 37	instantiation	57, 58	|- (delta_{b_{f}} / 1) = delta_{b_{f}}
# 	x : delta_{b_{f}}
# 38	instantiation	69, 161, 118, 157, 59, 71, 60*, 72*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-l) >= (-2^{t - 1})
# 	a : -1, x : l, y : 2^{t - 1}
# 39	instantiation	61, 122	|- (0 - 2^{t - 1}) = (-2^{t - 1})
# 	a : -2^{t - 1}
# 40	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 41	instantiation	62, 67, 138, 68	|- 0 <= (2^{t} * delta_{b_{f}})
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 42	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 43	instantiation	111, 125	|- 2^{t} != 0
# 	n : 2^{t}
# 44	instantiation	127, 63, 64	|- (2^{t - 1} * (2^{t})^{-1}) = (1 / 2)
# 	x : 2^{t - 1} * (2^{t})^{-1}, y : 2^{t - 1} * 2^{-t}, z : 1 / 2
# 45	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 46	instantiation	65, 67, 138, 68	|- (2^{t} * delta_{b_{f}}) in Real
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 47	instantiation	66, 67, 138, 68	|- (2^{t} * delta_{b_{f}}) < 1
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 48	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 49	instantiation	169, 118	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-l) in Real
# 	a : l
# 50	instantiation	102, 157, 161	|- (2^{t - 1} - 1) in Real
# 	a : 2^{t - 1}, b : -1
# 51	instantiation	69, 161, 154, 118, 70, 71, 72*, 73*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2^{t - 1} - 1) >= (-l)
# 	a : -1, x : -2^{t - 1} + 1, y : l
# 52	instantiation	127, 74, 75	|- (1 + (2^{t - 1} - 1)) = 2^{t - 1}
# 	x : 1 + (2^{t - 1} - 1), y : 1 + 2^{t - 1} - 1, z : 2^{t - 1}
# 53	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 54	instantiation	197, 130, 76	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 55	instantiation	197, 130, 77	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 56	instantiation	126, 78	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 57	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 58	instantiation	197, 160, 79	|- delta_{b_{f}} in Complex
# 	A : Real, B : Complex, x : delta_{b_{f}}
# 59	instantiation	80, 177, 192, 167	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l <= 2^{t - 1}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 60	instantiation	90, 123, 140, 81*	|- ((-1) * 2^{t - 1}) = (-2^{t - 1})
# 	x : 1, y : 2^{t - 1}
# 61	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 62	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 63	instantiation	119, 82	|- (2^{t - 1} * (2^{t})^{-1}) = (2^{t - 1} * 2^{-t})
# 	f(_a) : 2^{t - 1} * _a, x : (2^{t})^{-1}, y : 2^{-t}
# 64	instantiation	83, 133, 84, 159, 100, 85*	|- (2^{t - 1} * 2^{-t}) = (1 / 2)
# 	a : 2, b : t - 1, c : -t
# 65	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 66	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 67	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 68	conjecture		|- (2^{t} * delta_{b_{f}}) in [0,1)
# 	proveit.physics.quantum.QPE._scaled_delta_b_floor_in_interval
# 69	conjecture		|- forall_{a, x, y in Real | x <= y, a <= 0} ((a * x) >= (a * y))
# 	proveit.numbers.multiplication.reversed_weak_bound_via_right_factor_bound
# 70	instantiation	86, 177, 192, 167	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) <= l
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 71	instantiation	87, 88	|- (-1) <= 0
# 	x : -1, y : 0
# 72	instantiation	90, 123, 106, 89*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-1) * l) = (-l)
# 	x : 1, y : l
# 73	instantiation	90, 123, 136, 91*	|- ((-1) * (-2^{t - 1} + 1)) = (2^{t - 1} - 1)
# 	x : 1, y : -2^{t - 1} + 1
# 74	instantiation	141, 194, 183, 142, 92, 143, 123, 140, 148	|- (1 + (2^{t - 1} - 1)) =  \\ (1 + 2^{t - 1} - 1)
# 	i : 1, j : 2, k : 0, a : (1), b : (2^{t - 1}, -1), c : ()
# 75	instantiation	146, 123, 140, 93	|- (1 + 2^{t - 1} - 1) = 2^{t - 1}
# 	a : 1, b : 1, c : 2^{t - 1}
# 76	instantiation	197, 150, 94	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 77	instantiation	197, 150, 95	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 78	instantiation	197, 160, 96	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 79	instantiation	97, 98	|- delta_{b_{f}} in Real
# 	b : b_{f}
# 80	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 81	instantiation	135, 140	|- (1 * 2^{t - 1}) = 2^{t - 1}
# 	x : 2^{t - 1}
# 82	instantiation	99, 133, 170, 161, 100, 101*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 83	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 84	instantiation	102, 170, 161	|- (t - 1) in Real
# 	a : t, b : -1
# 85	instantiation	127, 103, 104	|- 2^{(t - 1) - t} = (1 / 2)
# 	x : 2^{(t - 1) - t}, y : 2^{-1}, z : 1 / 2
# 86	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 87	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 88	instantiation	105, 190	|- (-1) < 0
# 	a : -1
# 89	instantiation	135, 106	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 * l) = l
# 	x : l
# 90	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 91	instantiation	127, 107, 108	|- (-(1 * (-2^{t - 1} + 1))) = (2^{t - 1} - 1)
# 	x : -(1 * (-2^{t - 1} + 1)), y : -(-2^{t - 1} + 1), z : 2^{t - 1} - 1
# 92	instantiation	158	|- |(2^{t - 1}, -1)| = |(1, ..., 2)|
# 	a : 2^{t - 1}, b : -1
# 93	instantiation	162	|- 1 = 1
# 	x : 1
# 94	instantiation	197, 163, 109	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 95	instantiation	197, 163, 110	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 96	instantiation	178, 179, 125	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 97	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 98	conjecture		|- b_{f} in Integer
# 	proveit.physics.quantum.QPE._best_floor_is_int
# 99	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 100	instantiation	111, 174	|- 2 != 0
# 	n : 2
# 101	instantiation	112, 147, 123, 113*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 102	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 103	instantiation	119, 114	|- 2^{(t - 1) - t} = 2^{-1}
# 	f(_a) : 2^{_a}, x : (t - 1) - t, y : -1
# 104	instantiation	115, 116, 196, 117*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 105	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 106	instantiation	197, 160, 118	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Complex
# 	A : Real, B : Complex, x : l
# 107	instantiation	119, 120	|- (-(1 * (-2^{t - 1} + 1))) = (-(-2^{t - 1} + 1))
# 	f(_a) : -_a, x : 1 * (-2^{t - 1} + 1), y : -2^{t - 1} + 1
# 108	instantiation	121, 122, 123, 124*	|- (-(-2^{t - 1} + 1)) = (2^{t - 1} - 1)
# 	a : -2^{t - 1}, b : 1
# 109	instantiation	197, 173, 125	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 110	instantiation	197, 173, 196	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 111	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 112	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 113	instantiation	126, 147	|- (t * 1) = t
# 	x : t
# 114	instantiation	127, 128, 129	|- ((t - 1) - t) = (-1)
# 	x : (t - 1) - t, y : t - 1 - t, z : -1
# 115	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 116	instantiation	197, 130, 131	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 117	instantiation	132, 133	|- 2^{1} = 2
# 	x : 2
# 118	instantiation	197, 171, 134	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 119	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 120	instantiation	135, 136	|- (1 * (-2^{t - 1} + 1)) = (-2^{t - 1} + 1)
# 	x : -2^{t - 1} + 1
# 121	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 122	instantiation	197, 160, 137	|- (-2^{t - 1}) in Complex
# 	A : Real, B : Complex, x : -2^{t - 1}
# 123	instantiation	197, 160, 138	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 124	instantiation	139, 140	|- (-(-2^{t - 1})) = 2^{t - 1}
# 	x : 2^{t - 1}
# 125	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 126	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 127	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 128	instantiation	141, 142, 183, 194, 143, 144, 147, 148, 145	|- ((t - 1) - t) =  \\ (t - 1 - t)
# 	i : 0, j : 2, k : 1, a : (), b : (t, -1), c : (-t)
# 129	instantiation	146, 147, 148, 149	|- (t - 1 - t) = (-1)
# 	a : t, b : t, c : -1
# 130	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 131	instantiation	197, 150, 151	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 132	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 133	instantiation	197, 160, 152	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 134	instantiation	197, 181, 153	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 135	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 136	instantiation	197, 160, 154	|- (-2^{t - 1} + 1) in Complex
# 	A : Real, B : Complex, x : -2^{t - 1} + 1
# 137	instantiation	197, 171, 155	|- (-2^{t - 1}) in Real
# 	A : Rational, B : Real, x : -2^{t - 1}
# 138	instantiation	197, 171, 156	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 139	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 	proveit.numbers.negation.double_negation
# 140	instantiation	197, 160, 157	|- 2^{t - 1} in Complex
# 	A : Real, B : Complex, x : 2^{t - 1}
# 141	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 142	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 143	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 144	instantiation	158	|- |(t, -1)| = |(1, ..., 2)|
# 	a : t, b : -1
# 145	instantiation	197, 160, 159	|- (-t) in Complex
# 	A : Real, B : Complex, x : -t
# 146	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 147	instantiation	197, 160, 170	|- t in Complex
# 	A : Real, B : Complex, x : t
# 148	instantiation	197, 160, 161	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 149	instantiation	162	|- t = t
# 	x : t
# 150	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 151	instantiation	197, 163, 164	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 152	instantiation	197, 171, 165	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 153	instantiation	197, 166, 167	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 154	instantiation	197, 171, 168	|- (-2^{t - 1} + 1) in Real
# 	A : Rational, B : Real, x : -2^{t - 1} + 1
# 155	instantiation	197, 181, 185	|- (-2^{t - 1}) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1}
# 156	instantiation	197, 181, 186	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 157	instantiation	178, 179, 199	|- 2^{t - 1} in Real
# 	A : NaturalPos, B : Real, x : 2^{t - 1}
# 158	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 159	instantiation	169, 170	|- (-t) in Real
# 	a : t
# 160	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 161	instantiation	197, 171, 172	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 162	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 163	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 164	instantiation	197, 173, 174	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 165	instantiation	197, 181, 175	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 166	instantiation	176, 177, 192	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 167	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 168	instantiation	197, 181, 177	|- (-2^{t - 1} + 1) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1} + 1
# 169	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 170	instantiation	178, 179, 180	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 171	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 172	instantiation	197, 181, 182	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 173	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 174	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 175	instantiation	197, 193, 183	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 176	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 177	instantiation	184, 185, 186	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 178	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 179	instantiation	187, 188	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 180	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 181	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 182	instantiation	197, 189, 190	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 183	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 184	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 185	instantiation	191, 192	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 186	instantiation	197, 193, 194	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 187	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 188	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 189	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 190	instantiation	195, 196	|- (-1) in IntegerNeg
# 	a : 1
# 191	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 192	instantiation	197, 198, 199	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 193	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 194	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 195	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 196	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 197	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 198	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 199	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
