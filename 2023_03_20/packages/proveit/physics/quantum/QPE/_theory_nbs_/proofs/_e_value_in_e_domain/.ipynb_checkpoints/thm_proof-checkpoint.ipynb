# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_e_value_in_e_domain">_e_value_in_e_domain</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b # used in an instantiation dict
from proveit.numbers import (
        zero, one, two, Add, frac, greater, Integer, Mult,
        NaturalPos, Neg, Real, subtract)
from proveit.physics.quantum.QPE import (
        _e_domain, _eps_in_interval, _e_value, _e_value_ge_two,
        _n, _n_ge_two, _n_in_natural_pos, _t, _t_in_natural_pos, _t_req)

# %%
# %proving _e_value_in_e_domain
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_e_value_in_e_domain">_e_value_in_e_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/49db90fec0aa3a848ce1be0ddb300cf33a6495e90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/c0aefc43fdc0354c9d823be56f34e93f9629a9eb0/dependencies.ipynb">dependencies</a>)<br>

# %%
_n_in_natural_pos
# Out:
# |- n in NaturalPos

# %%
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
_n_ge_two
# Out:
# |- n >= 2

# %%
_t_req
# Out:
# |- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))

# %%
_eps_in_interval
# Out:
# |- eps in (0,1]

# %%
bound_01 = _t_req.right_add_both_sides(Neg(_n))
# Out:
# <strong id="bound_01">bound_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/cd82fea7812e08de0c65d376a32107953d1d17a60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/df08ca495ec940b462f05d440965e495db460bcc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_eps_le_one = _eps_in_interval.derive_element_upper_bound()
# Out:
# <strong id="_eps_le_one">_eps_le_one:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/ffc83ca6f10f62281ed42ffbfa9cfa41addb86520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/ff24096d2b1d72376aed268b9700cde0af9715870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
greater(Add(two, frac(one, two)), zero).prove()
# Out:
# |- (2 + (1 / 2)) > 0

# %%
bound_02 = bound_01.rhs.deduce_bound(_eps_le_one)
# Out:
# <strong id="bound_02">bound_02:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/fabe85d045c36561b260802621fd79c22426b2030/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/294908053b32e19be21d1fb9394488a1da7300470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_03 = bound_01.apply_transitivity(bound_02)
# Out:
# <strong id="bound_03">bound_03:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/2ae0bdf25c4d86dd92b3c6f4d8ba5ac6f9be1ce80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/cd9874521139c8a988ad320c8950c01f077ef6050/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers.logarithms import log_base_large_a_greater_one
log_base_large_a_greater_one
# Out:
# |- forall_{a, b in RealPos | 1 < a < b} (log_a(b) > 1)

# %%
_a_sub, _b_sub = (
    bound_03.rhs.operand.base,
    bound_03.rhs.operand.antilog)
log_base_2_of_stuff_greater_than_one = log_base_large_a_greater_one.instantiate(
    {a: _a_sub, b: _b_sub})
# Out:
# <strong id="log_base_2_of_stuff_greater_than_one">log_base_2_of_stuff_greater_than_one:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/ff89639f1fbdaadb9a71b54751d4facbc82f729b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/f67e54083b73012bddca25d5cbb4dd81a348f7570/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_04 = bound_03.rhs.deduce_bound(log_base_2_of_stuff_greater_than_one)
# Out:
# <strong id="bound_04">bound_04:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/d6b6bab43e3b4ad1985d82f1f34156265a88d4a50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/90392a83cdc72c595064ee4e8066e695b0ea82fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_05 = bound_03.apply_transitivity(bound_04)
# Out:
# <strong id="bound_05">bound_05:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/f4765a5efae99ae1581eb0138e839822b60607d40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/2a6433a2fc1c59030cc708d473a250797ce31cf60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_e_value_ge_two
# Out:
# |- (2^{t - n} - 1) >= 2

# %%
_n_ge_two
# Out:
# |- n >= 2

# %%
bound_06 = _e_value.deduce_bound(_n_ge_two)
# Out:
# <strong id="bound_06">bound_06:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/576337714c6d1ec1af4dfe547881d7ee9ba18aba0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/d99a24dcfcbe4e1296addcce23fd4fdb67f4c51e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_07 = bound_06.add_right(bound_06.rhs).inner_expr().rhs.simplify()
# Out:
# <strong id="bound_07">bound_07:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/99e246db7eebcfb9b6a751c04758bdf3f9559a1f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__e_value_in_e_domain/039498511a27c4fdcc8fe653a55219b5c5ee3e3b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _e_value_in_e_domain may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._e_value_in_e_domain has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 310, 2, 3, 4	|- (2^{t - n} - 1) in {1 .. 2^{t - 1} - 2}
# 	a : 1, b : 2^{t - 1} - 2, n : 2^{t - n} - 1
# 1	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 2	instantiation	106, 5, 108	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 3	instantiation	106, 6, 29	|- (2^{t - n} - 1) in Integer
# 	a : 2^{t - n}, b : -1
# 4	instantiation	166, 7, 8	|- (1 <= (2^{t - n} - 1)) and ((2^{t - n} - 1) <= (2^{t - 1} - 2))
# 	A : 1 <= (2^{t - n} - 1), B : (2^{t - n} - 1) <= (2^{t - 1} - 2)
# 5	instantiation	10, 290, 9	|- 2^{t - 1} in Integer
# 	a : 2, b : t - 1
# 6	instantiation	10, 290, 65	|- 2^{t - n} in Integer
# 	a : 2, b : t - n
# 7	instantiation	154, 86, 281, 11, 12, 13*, 14*	|- 1 <= (2^{t - n} - 1)
# 	a : -1, x : 2, y : (2^{t - n} - 1) + 1
# 8	instantiation	15, 16, 17	|- (2^{t - n} - 1) <= (2^{t - 1} - 2)
# 	P(_a) : (2^{t - n} - 1) <= _a, x : 2^{-1 + t} - 2, y : 2^{t - 1} - 2
# 9	instantiation	99, 18, 19	|- (t - 1) in Natural
# 	a : t - 1
# 10	conjecture		|- forall_{a in Integer, b in Natural} (a^{b} in Integer)
# 	proveit.numbers.exponentiation.exp_int_closure
# 11	instantiation	173, 24, 305	|- ((2^{t - n} - 1) + 1) in Real
# 	a : 2^{t - n} - 1, b : 1
# 12	instantiation	122, 281, 24, 305, 20, 21	|- 2 <= ((2^{t - n} - 1) + 1)
# 	a : 2, b : 2^{t - n} - 1, c : 1
# 13	instantiation	22, 265, 245, 138	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 14	instantiation	218, 23	|- (((2^{t - n} - 1) + 1) - 1) = (2^{t - n} - 1)
# 	f(_a) : _a - 1, x : (2^{t - n} - 1) + 1, y : 2^{t - n}
# 15	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 16	instantiation	122, 24, 58, 25, 26, 27*	|- (2^{t - n} - 1) <= (2^{-1 + t} - 2)
# 	a : 2^{t - n} - 1, b : 2^{t - 2} - 1, c : 2^{t - 2} - 1
# 17	instantiation	218, 28	|- (2^{-1 + t} - 2) = (2^{t - 1} - 2)
# 	f(_a) : _a - 2, x : 2^{-1 + t}, y : 2^{t - 1}
# 18	instantiation	106, 107, 29	|- (t - 1) in Integer
# 	a : t, b : -1
# 19	instantiation	109, 30	|- (t - 1) >= 0
# 	a : t, b : 1
# 20	conjecture		|- (2^{t - n} - 1) >= 2
# 	proveit.physics.quantum.QPE._e_value_ge_two
# 21	instantiation	244, 313	|- 1 >= 0
# 	n : 1
# 22	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 23	instantiation	239, 31, 32	|- ((2^{t - n} - 1) + 1) = 2^{t - n}
# 	x : (2^{t - n} - 1) + 1, y : 2^{t - n} - 1 + 1, z : 2^{t - n}
# 24	instantiation	173, 55, 86	|- (2^{t - n} - 1) in Real
# 	a : 2^{t - n}, b : -1
# 25	instantiation	154, 86, 55, 88, 33	|- (2^{t - n} - 1) <= (2^{t - 2} - 1)
# 	a : -1, x : 2^{t - n}, y : 2^{t - 2}
# 26	instantiation	154, 86, 305, 88, 34, 35*	|- 0 <= (2^{t - 2} - 1)
# 	a : -1, x : 1, y : 2^{t - 2}
# 27	instantiation	132, 36, 37, 38	|- ((2^{t - 2} - 1) + (2^{t - 2} - 1)) = (2^{-1 + t} - 2)
# 	a : (2^{t - 2} - 1) + (2^{t - 2} - 1), b : 2^{t - 2} - 1 + (2^{t - 2} - 1), c : 2^{t - 2} - 1 + 2^{t - 2} - 1, d : 2^{-1 + t} - 2
# 28	instantiation	218, 39	|- 2^{-1 + t} = 2^{t - 1}
# 	f(_a) : 2^{_a}, x : -1 + t, y : t - 1
# 29	instantiation	311, 113, 40	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 30	instantiation	45, 196	|- t >= 1
# 	n : t
# 31	instantiation	187, 188, 294, 313, 189, 41, 42, 63, 265	|- ((2^{t - n} - 1) + 1) =  \\ (2^{t - n} - 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t - n}, -1), c : (1)
# 32	instantiation	164, 265, 42, 48	|- (2^{t - n} - 1 + 1) = 2^{t - n}
# 	a : 1, b : 1, c : 2^{t - n}
# 33	instantiation	43, 281, 123, 82, 282, 44	|- 2^{t - n} <= 2^{t - 2}
# 	a : 2, x : t - n, y : t - 2
# 34	instantiation	45, 46	|- 2^{t - 2} >= 1
# 	n : 2^{t - 2}
# 35	instantiation	47, 265, 48	|- (1 - 1) = 0
# 	a : 1, b : 1
# 36	instantiation	187, 188, 294, 313, 189, 50, 80, 63, 49	|- ((2^{t - 2} - 1) + (2^{t - 2} - 1)) =  \\ (2^{t - 2} - 1 + (2^{t - 2} - 1))
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t - 2}, -1), c : (2^{t - 2} - 1)
# 37	instantiation	187, 294, 188, 50, 189, 80, 63	|- (2^{t - 2} - 1 + (2^{t - 2} - 1)) =  \\ (2^{t - 2} - 1 + 2^{t - 2} - 1)
# 	i : 2, j : 2, k : 0, a : (2^{t - 2}, -1), b : (2^{t - 2}, -1), c : ()
# 38	instantiation	132, 51, 52, 53	|- (2^{t - 2} - 1 + 2^{t - 2} - 1) = (2^{-1 + t} - 2)
# 	a : 2^{t - 2} - 1 + 2^{t - 2} - 1, b : 2^{t - 2} + 2^{t - 2} - 1 - 1, c : 2^{-1 + t} - 1 - 1, d : 2^{-1 + t} - 2
# 39	instantiation	54, 63, 165	|- (-1 + t) = (t - 1)
# 	a : -1, b : t
# 40	instantiation	117, 287	|- (-1) in IntegerNeg
# 	a : 1
# 41	instantiation	263	|- |(2^{t - n}, -1)| = |(1, ..., 2)|
# 	a : 2^{t - n}, b : -1
# 42	instantiation	311, 271, 55	|- 2^{t - n} in Complex
# 	A : Real, B : Complex, x : 2^{t - n}
# 43	conjecture		|- forall_{a, x, y in Real | a > 1, x <= y} (a^{x} <= a^{y})
# 	proveit.numbers.exponentiation.exp_monotonicity_large_base_less_eq
# 44	instantiation	183, 175, 212, 174, 56	|- (t - n) <= (t - 2)
# 	a : t, x : -n, y : -2
# 45	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 46	instantiation	57, 294, 95	|- 2^{t - 2} in NaturalPos
# 	a : 2, b : t - 2
# 47	conjecture		|- forall_{a, b in Complex | a = b} ((a - b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_basic
# 48	instantiation	214	|- 1 = 1
# 	x : 1
# 49	instantiation	311, 271, 58	|- (2^{t - 2} - 1) in Complex
# 	A : Real, B : Complex, x : 2^{t - 2} - 1
# 50	instantiation	263	|- |(2^{t - 2}, -1)| = |(1, ..., 2)|
# 	a : 2^{t - 2}, b : -1
# 51	instantiation	102, 313, 80, 63	|- (2^{t - 2} - 1 + 2^{t - 2} - 1) =  \\ (2^{t - 2} + 2^{t - 2} - 1 - 1)
# 	i : 1, j : 1, k : 1, a : (2^{t - 2}), b : (-1), c : 2^{t - 2}, d : (-1)
# 52	instantiation	103, 188, 294, 189, 59, 61, 80, 63, 60*	|- (2^{t - 2} + 2^{t - 2} - 1 - 1) =  \\ (2^{-1 + t} - 1 - 1)
# 	i : 0, j : 2, k : 2, a : (), b : (2^{t - 2}, 2^{t - 2}), c : (-1, -1)
# 53	instantiation	103, 313, 294, 188, 61, 189, 62, 63, 64*	|- (2^{-1 + t} - 1 - 1) =  \\ (2^{-1 + t} - 2)
# 	i : 1, j : 2, k : 0, a : (2^{-1 + t}), b : (-1, -1), c : ()
# 54	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 55	instantiation	94, 281, 65	|- 2^{t - n} in Real
# 	a : 2, b : t - n
# 56	instantiation	66, 281, 234, 115	|- (-2) >= (-n)
# 	x : 2, y : n
# 57	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 58	instantiation	173, 88, 86	|- (2^{t - 2} - 1) in Real
# 	a : 2^{t - 2}, b : -1
# 59	instantiation	263	|- |(2^{t - 2}, 2^{t - 2})| = |(1, ..., 2)|
# 	a : 2^{t - 2}, b : 2^{t - 2}
# 60	instantiation	67, 68	|- (2^{t - 2} + 2^{t - 2}) = 2^{-1 + t}
# 	x : 2^{-1 + t}, y : 2^{t - 2} + 2^{t - 2}
# 61	instantiation	263	|- |(-1, -1)| = |(1, ..., 2)|
# 	a : -1, b : -1
# 62	instantiation	69, 245, 70	|- 2^{-1 + t} in Complex
# 	a : 2, b : -1 + t
# 63	instantiation	160, 265	|- (-1) in Complex
# 	a : 1
# 64	instantiation	71, 265, 245, 138	|- (-1 - 1) = (-2)
# 	a : 1, b : 1, c : 2
# 65	instantiation	99, 72, 73	|- (t - n) in Natural
# 	a : t - n
# 66	conjecture		|- forall_{x, y in Real | x <= y} ((-x) >= (-y))
# 	proveit.numbers.negation.negated_weak_bound
# 67	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 68	instantiation	74, 188, 294, 313, 189, 75, 265, 80, 138*, 76*, 77*	|- 2^{-1 + t} =  \\ (2^{t - 2} + 2^{t - 2})
# 	i : 0, j : 2, k : 1, a : (), b : (1, 1), c : (2^{t - 2})
# 69	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 70	instantiation	311, 271, 78	|- (-1 + t) in Complex
# 	A : Real, B : Complex, x : -1 + t
# 71	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((-a - b) = (-c))
# 	proveit.numbers.addition.subtraction.negated_add
# 72	instantiation	106, 107, 79	|- (t - n) in Integer
# 	a : t, b : -n
# 73	instantiation	109, 116	|- (t - n) >= 0
# 	a : t, b : n
# 74	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 75	instantiation	263	|- |(1, 1)| = |(1, ..., 2)|
# 	a : 1, b : 1
# 76	instantiation	232, 80	|- (1 * 2^{t - 2}) = 2^{t - 2}
# 	x : 2^{t - 2}
# 77	instantiation	81, 245, 305, 82, 83, 84*, 85*	|- (2 * 2^{t - 2}) = 2^{-1 + t}
# 	a : 2, b : 1, c : t - 2
# 78	instantiation	173, 86, 175	|- (-1 + t) in Real
# 	a : -1, b : t
# 79	instantiation	311, 113, 87	|- (-n) in Integer
# 	A : IntegerNeg, B : Integer, x : -n
# 80	instantiation	311, 271, 88	|- 2^{t - 2} in Complex
# 	A : Real, B : Complex, x : 2^{t - 2}
# 81	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 82	instantiation	311, 307, 89	|- (t - 2) in Real
# 	A : Rational, B : Real, x : t - 2
# 83	instantiation	90, 301	|- 2 != 0
# 	n : 2
# 84	instantiation	91, 245	|- 2^{1} = 2
# 	x : 2
# 85	instantiation	239, 92, 93	|- (1 + (t - 2)) = (-1 + t)
# 	x : 1 + (t - 2), y : 1 + t - 2, z : -1 + t
# 86	instantiation	233, 305	|- (-1) in Real
# 	a : 1
# 87	instantiation	117, 250	|- (-n) in IntegerNeg
# 	a : n
# 88	instantiation	94, 281, 95	|- 2^{t - 2} in Real
# 	a : 2, b : t - 2
# 89	instantiation	311, 309, 100	|- (t - 2) in Rational
# 	A : Integer, B : Rational, x : t - 2
# 90	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 91	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 92	instantiation	187, 313, 294, 188, 96, 189, 265, 165, 146	|- (1 + (t - 2)) =  \\ (1 + t - 2)
# 	i : 1, j : 2, k : 0, a : (1), b : (t, -2), c : ()
# 93	instantiation	239, 97, 98	|- (1 + t - 2) = (-1 + t)
# 	x : 1 + t - 2, y : 1 - 2 + t, z : -1 + t
# 94	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 95	instantiation	99, 100, 101	|- (t - 2) in Natural
# 	a : t - 2
# 96	instantiation	263	|- |(t, -2)| = |(1, ..., 2)|
# 	a : t, b : -2
# 97	instantiation	102, 313, 188, 189, 265, 165, 146	|- (1 + t - 2) =  \\ (1 - 2 + t)
# 	i : 1, j : 1, k : 0, a : (1), b : (t), c : -2, d : ()
# 98	instantiation	103, 188, 294, 313, 189, 104, 265, 146, 165, 105*	|- (1 - 2 + t) =  \\ (-1 + t)
# 	i : 0, j : 2, k : 1, a : (), b : (1, -2), c : (t)
# 99	conjecture		|- forall_{a in Integer | a >= 0} (a in Natural)
# 	proveit.numbers.number_sets.integers.nonneg_int_is_natural
# 100	instantiation	106, 107, 108	|- (t - 2) in Integer
# 	a : t, b : -2
# 101	instantiation	109, 110	|- (t - 2) >= 0
# 	a : t, b : 2
# 102	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
# 	proveit.numbers.addition.leftward_commutation
# 103	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 104	instantiation	263	|- |(1, -2)| = |(1, ..., 2)|
# 	a : 1, b : -2
# 105	instantiation	111, 265, 245, 138	|- (1 - 2) = (-1)
# 	a : 1, b : 1, c : 2
# 106	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 107	instantiation	311, 112, 196	|- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 108	instantiation	311, 113, 114	|- (-2) in Integer
# 	A : IntegerNeg, B : Integer, x : -2
# 109	conjecture		|- forall_{a, b | a >= b} ((a - b) >= 0)
# 	proveit.numbers.addition.subtraction.nonneg_difference
# 110	instantiation	139, 115, 116	|- 2 <= t
# 	x : 2, y : n, z : t
# 111	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((b - c) = (-a))
# 	proveit.numbers.addition.subtraction.subtract_from_add_reversed
# 112	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 113	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 114	instantiation	117, 301	|- (-2) in IntegerNeg
# 	a : 2
# 115	axiom		|- n >= 2
# 	proveit.physics.quantum.QPE._n_ge_two
# 116	instantiation	154, 158, 281, 118, 119, 120*, 121*	|- n <= t
# 	a : n - 2, x : 2, y : (t - n) + 2
# 117	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 118	instantiation	173, 123, 281	|- ((t - n) + 2) in Real
# 	a : t - n, b : 2
# 119	instantiation	122, 281, 123, 124, 228	|- 2 <= ((t - n) + 2)
# 	a : 2, b : t - n, c : 2
# 120	instantiation	239, 125, 126	|- (2 + (n - 2)) = n
# 	x : 2 + (n - 2), y : 2 + n - 2, z : n
# 121	instantiation	239, 127, 128	|- (((t - n) + 2) + (n - 2)) = t
# 	x : ((t - n) + 2) + (n - 2), y : (t - n + 2) + (n - 2), z : t
# 122	conjecture		|- forall_{a, b, c in Real | a <= b, 0 <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_eq_add_right
# 123	instantiation	173, 175, 212	|- (t - n) in Real
# 	a : t, b : -n
# 124	instantiation	139, 129, 130	|- 2 <= (t - n)
# 	x : 2, y : ceil(log_2(5 / 2)), z : t - n
# 125	instantiation	187, 313, 294, 188, 145, 189, 245, 193, 146	|- (2 + (n - 2)) =  \\ (2 + n - 2)
# 	i : 1, j : 2, k : 0, a : (2), b : (n, -2), c : ()
# 126	instantiation	192, 245, 193, 163	|- (2 + n - 2) = n
# 	a : 2, b : 2, c : n
# 127	instantiation	218, 131	|- (((t - n) + 2) + (n - 2)) = ((t - n + 2) + (n - 2))
# 	f(_a) : _a + (n - 2), x : (t - n) + 2, y : t - n + 2
# 128	instantiation	132, 133, 134, 135	|- ((t - n + 2) + (n - 2)) = t
# 	a : (t - n + 2) + (n - 2), b : t - n + 2 + (n - 2), c : t - n + 2 + n - 2, d : t
# 129	instantiation	136, 310, 152, 137, 138*	|- 2 <= ceil(log_2(5 / 2))
# 	x : 1, y : log_2(5 / 2)
# 130	instantiation	139, 140, 141	|- ceil(log_2(5 / 2)) <= (t - n)
# 	x : ceil(log_2(5 / 2)), y : ceil(log_2(2 + (1 / (2 * eps)))), z : t - n
# 131	instantiation	187, 188, 294, 313, 189, 162, 165, 191, 245	|- ((t - n) + 2) =  \\ (t - n + 2)
# 	i : 0, j : 2, k : 1, a : (), b : (t, -n), c : (2)
# 132	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 133	instantiation	187, 188, 143, 313, 189, 144, 165, 191, 245, 142	|- ((t - n + 2) + (n - 2)) =  \\ (t - n + 2 + (n - 2))
# 	i : 0, j : 3, k : 1, a : (), b : (t, -n, 2), c : (n - 2)
# 134	instantiation	187, 143, 294, 188, 144, 145, 189, 165, 191, 245, 193, 146	|- (t - n + 2 + (n - 2)) =  \\ (t - n + 2 + n - 2)
# 	i : 3, j : 2, k : 0, a : (t, -n, 2), b : (n, -2), c : ()
# 135	instantiation	239, 147, 148	|- (t - n + 2 + n - 2) = t
# 	x : t - n + 2 + n - 2, y : t - n + n, z : t
# 136	conjecture		|- forall_{x in Integer, y in Real | x < y} ((x + 1) <= ceil(y))
# 	proveit.numbers.rounding.ceil_of_real_above_int
# 137	instantiation	149, 292, 169, 150	|- log_2(5 / 2) > 1
# 	a : 2, b : 5 / 2
# 138	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 139	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 140	instantiation	151, 152, 261, 153	|- ceil(log_2(5 / 2)) <= ceil(log_2(2 + (1 / (2 * eps))))
# 	x : log_2(5 / 2), y : log_2(2 + (1 / (2 * eps)))
# 141	instantiation	154, 212, 155, 175, 156, 157*	|- ceil(log_2(2 + (1 / (2 * eps)))) <= (t - n)
# 	a : -n, x : n + ceil(log_2(2 + (1 / (2 * eps)))), y : t
# 142	instantiation	311, 271, 158	|- (n - 2) in Complex
# 	A : Real, B : Complex, x : n - 2
# 143	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 144	instantiation	159	|- |(t, -n, 2)| = |(1, 2, ..., 3)|
# 	a : t, b : -n, c : 2
# 145	instantiation	263	|- |(n, -2)| = |(1, ..., 2)|
# 	a : n, b : -2
# 146	instantiation	160, 245	|- (-2) in Complex
# 	a : 2
# 147	instantiation	161, 294, 313, 188, 162, 189, 165, 191, 245, 193, 163	|- (t - n + 2 + n - 2) = (t - n + n)
# 	i : 2, j : 1, k : 0, a : (t, -n), b : 2, c : (n), d : 2, e : ()
# 148	instantiation	164, 193, 165, 195	|- (t - n + n) = t
# 	a : n, b : n, c : t
# 149	conjecture		|- forall_{a, b in RealPos | 1 < a < b} (log_a(b) > 1)
# 	proveit.numbers.logarithms.log_base_large_a_greater_one
# 150	instantiation	166, 282, 167	|- (1 < 2) and (2 < (5 / 2))
# 	A : 1 < 2, B : 2 < (5 / 2)
# 151	conjecture		|- forall_{x, y in Real | x <= y} (ceil(x) <= ceil(y))
# 	proveit.numbers.rounding.ceil_increasing_less_eq
# 152	instantiation	266, 292, 169, 268	|- log_2(5 / 2) in Real
# 	a : 2, b : 5 / 2
# 153	instantiation	168, 292, 169, 267, 170, 282	|- log_2(5 / 2) <= log_2(2 + (1 / (2 * eps)))
# 	a : 2, x : 5 / 2, y : 2 + (1 / (2 * eps))
# 154	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 155	instantiation	173, 234, 213	|- (n + ceil(log_2(2 + (1 / (2 * eps))))) in Real
# 	a : n, b : ceil(log_2(2 + (1 / (2 * eps))))
# 156	axiom		|- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))
# 	proveit.physics.quantum.QPE._t_req
# 157	instantiation	239, 171, 172	|- ((n + ceil(log_2(2 + (1 / (2 * eps))))) - n) = ceil(log_2(2 + (1 / (2 * eps))))
# 	x : (n + ceil(log_2(2 + (1 / (2 * eps))))) - n, y : n + ceil(log_2(2 + (1 / (2 * eps)))) - n, z : ceil(log_2(2 + (1 / (2 * eps))))
# 158	instantiation	173, 234, 174	|- (n - 2) in Real
# 	a : n, b : -2
# 159	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 160	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 161	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 162	instantiation	263	|- |(t, -n)| = |(1, ..., 2)|
# 	a : t, b : -n
# 163	instantiation	214	|- 2 = 2
# 	x : 2
# 164	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 165	instantiation	311, 271, 175	|- t in Complex
# 	A : Real, B : Complex, x : t
# 166	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 167	instantiation	176, 281, 177, 178, 179, 180*, 181*	|- 2 < (5 / 2)
# 	a : 2, x : (1 / 2) * 0, y : (1 / 2) * 1
# 168	conjecture		|- forall_{a, x, y in RealPos | x <= y, a > 1} (log_a(x) <= log_a(y))
# 	proveit.numbers.logarithms.log_increasing_less_eq
# 169	instantiation	311, 295, 182	|- (5 / 2) in RealPos
# 	A : RationalPos, B : RealPos, x : 5 / 2
# 170	instantiation	183, 281, 252, 184, 185, 186*	|- (5 / 2) <= (2 + (1 / (2 * eps)))
# 	a : 2, x : 1 / 2, y : 1 / (2 * eps)
# 171	instantiation	187, 188, 294, 313, 189, 190, 193, 194, 191	|- ((n + ceil(log_2(2 + (1 / (2 * eps))))) - n) =  \\ (n + ceil(log_2(2 + (1 / (2 * eps)))) - n)
# 	i : 0, j : 2, k : 1, a : (), b : (n, ceil(log_2(2 + (1 / (2 * eps))))), c : (-n)
# 172	instantiation	192, 193, 194, 195	|- (n + ceil(log_2(2 + (1 / (2 * eps)))) - n) = ceil(log_2(2 + (1 / (2 * eps))))
# 	a : n, b : n, c : ceil(log_2(2 + (1 / (2 * eps))))
# 173	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 174	instantiation	233, 281	|- (-2) in Real
# 	a : 2
# 175	instantiation	248, 249, 196	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 176	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 177	instantiation	197, 252, 304	|- ((1 / 2) * 0) in Real
# 	a : 1 / 2, b : 0
# 178	instantiation	197, 252, 305	|- ((1 / 2) * 1) in Real
# 	a : 1 / 2, b : 1
# 179	instantiation	198, 252, 304, 305, 199, 200	|- ((1 / 2) * 0) < ((1 / 2) * 1)
# 	a : 1 / 2, x : 0, y : 1
# 180	instantiation	239, 201, 202	|- (((1 / 2) * 0) + 2) = 2
# 	x : ((1 / 2) * 0) + 2, y : 0 + 2, z : 2
# 181	instantiation	239, 203, 204	|- (((1 / 2) * 1) + 2) = (5 / 2)
# 	x : ((1 / 2) * 1) + 2, y : (1 / 2) + 2, z : 5 / 2
# 182	instantiation	276, 205, 296	|- (5 / 2) in RationalPos
# 	a : 5, b : 2
# 183	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 184	instantiation	311, 206, 273	|- (1 / (2 * eps)) in Real
# 	A : RealPos, B : Real, x : 1 / (2 * eps)
# 185	instantiation	207, 208, 289, 292, 209	|- (1 / (2 * eps)) >= (1 / 2)
# 	a : 1, x : 2 * eps, y : 2
# 186	instantiation	220, 290, 310, 221*, 210*, 211*	|- (2 + (1 / 2)) = (5 / 2)
# 	a : 2, b : 1, c : 1, d : 2
# 187	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 188	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 189	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 190	instantiation	263	|- |(n, ceil(log_2(2 + (1 / (2 * eps)))))| = |(1, ..., 2)|
# 	a : n, b : ceil(log_2(2 + (1 / (2 * eps))))
# 191	instantiation	311, 271, 212	|- (-n) in Complex
# 	A : Real, B : Complex, x : -n
# 192	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 193	instantiation	311, 271, 234	|- n in Complex
# 	A : Real, B : Complex, x : n
# 194	instantiation	311, 271, 213	|- ceil(log_2(2 + (1 / (2 * eps)))) in Complex
# 	A : Real, B : Complex, x : ceil(log_2(2 + (1 / (2 * eps))))
# 195	instantiation	214	|- n = n
# 	x : n
# 196	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 197	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 198	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 199	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 200	instantiation	215, 270	|- (1 / 2) > 0
# 	q : 1 / 2
# 201	instantiation	218, 216	|- (((1 / 2) * 0) + 2) = (0 + 2)
# 	f(_a) : _a + 2, x : (1 / 2) * 0, y : 0
# 202	instantiation	217, 245	|- (0 + 2) = 2
# 	a : 2
# 203	instantiation	218, 219	|- (((1 / 2) * 1) + 2) = ((1 / 2) + 2)
# 	f(_a) : _a + 2, x : (1 / 2) * 1, y : 1 / 2
# 204	instantiation	220, 310, 290, 221*, 222*, 229*	|- ((1 / 2) + 2) = (5 / 2)
# 	a : 1, b : 2, c : 2, d : 1
# 205	instantiation	311, 300, 223	|- 5 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 5
# 206	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 207	conjecture		|- forall_{a in RealNonNeg} [forall_{x, y in RealPos | x <= y} ((a / x) >= (a / y))]
# 	proveit.numbers.division.weak_div_from_denom_bound__all_pos
# 208	instantiation	311, 224, 225	|- 1 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 1
# 209	instantiation	226, 281, 298, 305, 227, 228, 229*	|- (2 * eps) <= 2
# 	a : 2, x : eps, y : 1
# 210	instantiation	239, 230, 231	|- ((2 * 2) + (1 * 1)) = 5
# 	x : (2 * 2) + (1 * 1), y : 4 + 1, z : 5
# 211	instantiation	232, 245	|- (1 * 2) = 2
# 	x : 2
# 212	instantiation	233, 234	|- (-n) in Real
# 	a : n
# 213	instantiation	311, 307, 235	|- ceil(log_2(2 + (1 / (2 * eps)))) in Real
# 	A : Rational, B : Real, x : ceil(log_2(2 + (1 / (2 * eps))))
# 214	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 215	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 216	instantiation	236, 237	|- ((1 / 2) * 0) = 0
# 	x : 1 / 2
# 217	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 218	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 219	instantiation	264, 237	|- ((1 / 2) * 1) = (1 / 2)
# 	x : 1 / 2
# 220	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 221	instantiation	238, 245	|- (2 / 1) = 2
# 	x : 2
# 222	instantiation	239, 240, 241	|- ((1 * 1) + (2 * 2)) = 5
# 	x : (1 * 1) + (2 * 2), y : 1 + 4, z : 5
# 223	conjecture		|- 5 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat5
# 224	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.rational_nonneg_within_real_nonneg
# 225	instantiation	311, 242, 313	|- 1 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 1
# 226	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 227	instantiation	243, 304, 305, 306	|- eps <= 1
# 	a : 0, b : 1, x : eps
# 228	instantiation	244, 294	|- 0 <= 2
# 	n : 2
# 229	instantiation	264, 245	|- (2 * 1) = 2
# 	x : 2
# 230	instantiation	253, 294, 246, 247, 257, 256	|- ((2 * 2) + (1 * 1)) =  \\ (4 + 1)
# 	n : 2, f(_a, _b) : _a + _b, x : (2 * 2, 1 * 1), y : (4, 1)
# 231	conjecture		|- (4 + 1) = 5
# 	proveit.numbers.numerals.decimals.add_4_1
# 232	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 233	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 234	instantiation	248, 249, 250	|- n in Real
# 	A : NaturalPos, B : Real, x : n
# 235	instantiation	311, 309, 251	|- ceil(log_2(2 + (1 / (2 * eps)))) in Rational
# 	A : Integer, B : Rational, x : ceil(log_2(2 + (1 / (2 * eps))))
# 236	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 237	instantiation	311, 271, 252	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 238	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 239	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 240	instantiation	253, 294, 254, 255, 256, 257	|- ((1 * 1) + (2 * 2)) =  \\ (1 + 4)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 1, 2 * 2), y : (1, 4)
# 241	conjecture		|- (1 + 4) = 5
# 	proveit.numbers.numerals.decimals.add_1_4
# 242	conjecture		|- Natural proper_subset RationalNonNeg
# 	proveit.numbers.number_sets.rational_numbers.nat_within_rational_nonneg
# 243	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_upper_bound
# 244	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 245	instantiation	311, 271, 281	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 246	instantiation	263	|- |(2 * 2, 1 * 1)| = |(1, ..., 2)|
# 	a : 2 * 2, b : 1 * 1
# 247	instantiation	263	|- |(4, 1)| = |(1, ..., 2)|
# 	a : 4, b : 1
# 248	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 249	instantiation	258, 259	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 250	axiom		|- n in NaturalPos
# 	proveit.physics.quantum.QPE._n_in_natural_pos
# 251	instantiation	260, 261	|- ceil(log_2(2 + (1 / (2 * eps)))) in Integer
# 	x : log_2(2 + (1 / (2 * eps)))
# 252	instantiation	311, 307, 262	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 253	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 254	instantiation	263	|- |(1 * 1, 2 * 2)| = |(1, ..., 2)|
# 	a : 1 * 1, b : 2 * 2
# 255	instantiation	263	|- |(1, 4)| = |(1, ..., 2)|
# 	a : 1, b : 4
# 256	instantiation	264, 265	|- (1 * 1) = 1
# 	x : 1
# 257	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 258	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 259	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 260	axiom		|- forall_{x in Real} (ceil(x) in Integer)
# 	proveit.numbers.rounding.ceil_is_an_int
# 261	instantiation	266, 292, 267, 268	|- log_2(2 + (1 / (2 * eps))) in Real
# 	a : 2, b : 2 + (1 / (2 * eps))
# 262	instantiation	311, 269, 270	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 263	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 264	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 265	instantiation	311, 271, 305	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 266	conjecture		|- forall_{a, b in RealPos | a != 1} (log_a(b) in Real)
# 	proveit.numbers.logarithms.log_real_pos_real_closure
# 267	instantiation	272, 292, 273	|- (2 + (1 / (2 * eps))) in RealPos
# 	a : 2, b : 1 / (2 * eps)
# 268	instantiation	274, 275	|- 2 != 1
# 	x : 1, y : 2
# 269	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 270	instantiation	276, 283, 296	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 271	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 272	conjecture		|- forall_{a, b in RealPos} ((a + b) in RealPos)
# 	proveit.numbers.addition.add_real_pos_closure_bin
# 273	instantiation	277, 278, 289, 279	|- (1 / (2 * eps)) in RealPos
# 	a : 1, b : 2 * eps
# 274	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 275	instantiation	280, 305, 281, 282	|- 1 != 2
# 	a : 1, b : 2
# 276	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 277	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 278	instantiation	311, 295, 283	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 279	instantiation	284, 285	|- (2 * eps) != 0
# 	x : 2 * eps
# 280	conjecture		|- forall_{a, b in Real | a < b} (a != b)
# 	proveit.numbers.ordering.less_is_not_eq
# 281	instantiation	311, 307, 286	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 282	conjecture		|- 1 < 2
# 	proveit.numbers.numerals.decimals.less_1_2
# 283	instantiation	311, 300, 287	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 284	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 285	instantiation	311, 288, 289	|- (2 * eps) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2 * eps
# 286	instantiation	311, 309, 290	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 287	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 288	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 289	instantiation	291, 292, 293	|- (2 * eps) in RealPos
# 	a : 2, b : eps
# 290	instantiation	311, 312, 294	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 291	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 	proveit.numbers.multiplication.mult_real_pos_closure_bin
# 292	instantiation	311, 295, 296	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 293	instantiation	297, 298, 299	|- eps in RealPos
# 	a : eps
# 294	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 295	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 296	instantiation	311, 300, 301	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 297	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 298	instantiation	302, 304, 305, 306	|- eps in Real
# 	a : 0, b : 1, x : eps
# 299	instantiation	303, 304, 305, 306	|- 0 < eps
# 	a : 0, b : 1, x : eps
# 300	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 301	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 302	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 303	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 304	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 305	instantiation	311, 307, 308	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 306	axiom		|- eps in (0,1]
# 	proveit.physics.quantum.QPE._eps_in_interval
# 307	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 308	instantiation	311, 309, 310	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 309	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 310	instantiation	311, 312, 313	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 311	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 312	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 313	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
