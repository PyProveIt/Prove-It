# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_summed">_alpha_summed</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, k, l, m, defaults
from proveit.logic import Forall, InSet, Set
from proveit.numbers import two, pi, i, Add, Integer, Mult, Exp
from proveit.physics.quantum.QPE import ModAdd
from proveit.physics.quantum.QPE import (
        _alpha_m_mod_as_geometric_sum,
        _b_floor, _b_round, _best_floor_is_int, _best_round_is_int,
        _non_int_delta_b_diff, _delta_b_is_real,
        _phase_from_best_with_delta_b, _phase_is_real, _t_in_natural_pos,
        _two_pow_t, _two_pow_t_is_nat_pos, _two_pow_t_minus_one_is_nat_pos)

# %%
# %proving _alpha_summed
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_alpha_summed">_alpha_summed:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e6e94fed89e82e045a0621116513134ffe726e030/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d8b9bc34ee2ce64014e467311dc30b37e90ee3d80/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _alpha_summed.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c4ce15397e5d747ea86f6d6143ae86209e6857980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Disable reducing double exponents for now and keep a factor of $2$ from combining with $2^t$ in the steps below:

# %%
Exp.change_simplification_directives(reduce_double_exponent=False)
Exp.change_simplification_directives(factor_numeric_rational=True)

# %%
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %% [markdown]
# To instantiate the `_alpha_l_mod_two_pow_t_evaluation_as_geo_sum` theorem we want $\ell \mapsto (b + \ell)$, but this requires that we establish that $(b+\ell) \in \mathbb{Z}$. This we accomplish by noting that $b \in \{b_f, b_r\}$ and both $b_f$ and $b_r$ are integers. We might want to eventually convert the next few steps into its own QPE theorem/lemma:

# %%
_best_floor_is_int
# Out:
# |- b_{f} in Integer

# %%
_best_round_is_int
# Out:
# |- b_{r} in Integer

# %%
all_b_in_best_set_are_int = Forall(b, InSet(b, Integer), domain=Set(_b_floor, _b_round)).prove()
# Out:
# <strong id="all_b_in_best_set_are_int">all_b_in_best_set_are_int:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/4f3aefa235945d8d9581d53b3aea16c23e2976600/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/6b2d7875162d7ec534a9e0c577c028d646610f540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
all_b_in_best_set_are_int_inst = all_b_in_best_set_are_int.instantiate()
# Out:
# <strong id="all_b_in_best_set_are_int_inst">all_b_in_best_set_are_int_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/89159b9cbe40a202a87e3c2b66c5c7cbb49554ff0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/035e0ae7bd8c0fe127ee5d2062443d6c874adcdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_l_eq_01_alt = _alpha_m_mod_as_geometric_sum.instantiate({m: Add(b, l)})
# Out:
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. 2^{t - 1}}, Integer)
# Expression notebook is being updated for {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# Expression notebook is being updated for {(e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{(b + l) mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{(b + l) mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# <strong id="alpha_l_eq_01_alt">alpha_l_eq_01_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/de256191190e846af6eb8d33ba09e3059b14220c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/0c46b15b4dffd9e53435f120d09d1071061100ee0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# $(b+\ell)\,\text{mod}\,2^t$ is the definition of $b \oplus \ell$, so we can clean up the $\alpha$ subscript/indexing on the lhs:

# %%
b_modadd_l__def = ModAdd(b, l).definition()
# Out:
# <strong id="b_modadd_l__def">b_modadd_l__def:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/c8a9595db78f3b87226f2fadee148952f934bf4b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/af6e92606733f5455c701db1dc018f34e7f901500/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_l_eq_02_alt = alpha_l_eq_01_alt.inner_expr().lhs.index.substitute(
    b_modadd_l__def.derive_reversed())
# Out:
# Expression notebook is being updated for (alpha_{_a}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{_a} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for (alpha_{b MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# <strong id="alpha_l_eq_02_alt">alpha_l_eq_02_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/88652f472615b53bf799fe1d68f1d907fa26e5f70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/71f9312390428284839dc06fbb0c9e2d4677755f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Next we substitute in for the phase $\varphi$ in terms of $b$ and $\delta_{b}$.

# %%
_phase_from_best_with_delta_b
# Out:
# |- forall_{b in Integer} (phase = ((b / 2^{t}) + delta_{b}))

# %%
_phase_from_best_with_delta_b_inst = _phase_from_best_with_delta_b.instantiate()
# Out:
# <strong id="_phase_from_best_with_delta_b_inst">_phase_from_best_with_delta_b_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/480b877edc0bee4b423389be38828b125b9804260/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/4d42476213e33a3b548eb6e621e4dbeaa4cc05c30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# proactively recall _delta_b is real, so auto simplification will work
# as expected in the in next major step or two
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
_delta_b_is_real.instantiate()
# Out:
# {b in {b_{f}, b_{r}}} |- delta_{b} in Real

# %% [markdown]
# Now we're ready to substitute back into our summation formula:

# %%
alpha_l_eq_03_alt = (
        alpha_l_eq_02_alt.inner_expr().rhs.factors[1].summand.
        base.exponent.factors[3].operands[0].
        substitute(_phase_from_best_with_delta_b_inst.rhs))
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{b MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{b MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k}))
# <strong id="alpha_l_eq_03_alt">alpha_l_eq_03_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/c59edc9dbe7cda6ccda602ce78d57d39a761f0760/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/0274511ef1c1e4141453e8b721e59d68d90dd8340/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_l_eq_04_alt = (
        alpha_l_eq_03_alt.inner_expr().rhs.factors[1].summand.
        base.exponent.factors[3].operands[2].operand.distribute())
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k})
# Expression notebook is being updated for (alpha_{b MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k}))
# Expression notebook is being updated for alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k}))
# Expression notebook is being updated for {(e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{b MOD_ADD l}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}))
# <strong id="alpha_l_eq_04_alt">alpha_l_eq_04_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/b85f4a1d0c02d57080c7d207df801892a04f5cad0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/26da95e158dda49e3c7eda082ec6366a0f7b9ea30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# We want to evaluate the summation as a finite geometric sum, but we need to establish that our exponential base $e^{2\pi i (\delta_{b} - \ell/{2^t})}$ is not equal to 1, which can be proven automatically given $\delta_{b} - \ell/{2^t} \notin \mathbb{Z}$.

# %%
_non_int_delta_b_diff
# Out:
# |- forall_{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((delta_{b} - (l / 2^{t})) not-in Integer)

# %%
_non_int_delta_b_diff.instantiate()
# Out:
# {b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b} - (l / 2^{t})) not-in Integer

# %% [markdown]
# Now we're ready to evaluate the summation as a finite geometric sum, while we tweak the auto-simplification directives just a bit to keep things from being over-simplified:

# %%
# For this step, we re-enable the reduction of double exponentiation
# and disable combining exponents (to keep 2 and 2^t from combining into 2^{t+1}).
Exp.change_simplification_directives(reduce_double_exponent=True)
#Mult.change_simplification_directives(combine_exponents=False)
alpha_l_eq_05_alt = alpha_l_eq_04_alt.inner_expr().rhs.factors[1].geom_sum_reduce()
# Out:
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}, (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}) = ((1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))
# <strong id="alpha_l_eq_05_alt">alpha_l_eq_05_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/62bf6b68f406ad0cd93f84cdddd99076743f1d540/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/2025983ad6d4c64bbc703a8a24fb9c145b3b5c3c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_l_eq_06_alt = (
        alpha_l_eq_05_alt.inner_expr().rhs.factors[1].numerator.operands[1].
        operand.exponent.distribute(3, right_factors=[_two_pow_t]))
# Out:
# <strong id="alpha_l_eq_06_alt">alpha_l_eq_06_alt:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/9515bda777d25da1b7530c8e6eb33f87c47d86e70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_summed/5e331d66736d137a94793b83260d3c599a8553f40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _alpha_summed may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_summed has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} (alpha_{b MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))))
# 1	instantiation	378, 2, 3	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})))
# 	x : alpha_{b MOD_ADD l}, y : (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})), z : (1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))
# 2	instantiation	322, 4, 5	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})))
# 	P(_a) : alpha_{b MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{_a}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))), x : 2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}, y : 2 * pi * i * ((delta_{b} * 2^{t}) - l)
# 3	instantiation	391, 6	{b in {b_{f}, b_{r}}} |- ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))) = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})))
# 	f(_a) : (1 / 2^{t}) * _a, x : (1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}), y : (1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})
# 4	instantiation	322, 7, 8	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})))
# 	P(_a) : alpha_{b MOD_ADD l} = ((1 / 2^{t}) * _a), x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}, y : (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})
# 5	instantiation	278, 279, 430, 335, 9, 10, 336, 404, 332, 186, 148, 231, 11*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}) =  \\ (2 * pi * i * ((delta_{b} * 2^{t}) - l))
# 	i : 3, j : 2, k : 0, a : (2, pi, i), b : (delta_{b} - (l / 2^{t}), 2^{t}), c : ()
# 6	instantiation	391, 12	{b in {b_{f}, b_{r}}} |- ((1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})) = ((1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))
# 	f(_a) : _a / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}), x : 1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}, y : 1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}
# 7	instantiation	322, 13, 14, 15*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}))
# 	P(_a) : alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - _a)})^{k})), x : (b + l) / 2^{t}, y : (b / 2^{t}) + (l / 2^{t})
# 8	instantiation	16, 38, 17, 18, 19, 20, 21*, 22*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{k}) = ((1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}) / (1 - e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}))
# 	x : e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}, j : 0, k : 2^{t} - 1, i : k
# 9	instantiation	301	|- |(2, pi, i)| = |(1, 2, ..., 3)|
# 	a : 2, b : pi, c : i
# 10	instantiation	386	|- |(delta_{b} - (l / 2^{t}), 2^{t})| = |(1, ..., 2)|
# 	a : delta_{b} - (l / 2^{t}), b : 2^{t}
# 11	instantiation	23, 335, 423, 336, 292, 198, 231, 24*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((delta_{b} - (l / 2^{t})) * 2^{t}) =  \\ ((delta_{b} * 2^{t}) - l)
# 	i : 0, j : 1, a : (), x : delta_{b}, y : l / 2^{t}, b : (2^{t})
# 12	instantiation	391, 25	{b in {b_{f}, b_{r}}} |- (1 - e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) = (1 - e^{2 * pi * i * ((2^{t} * delta_{b}) - l)})
# 	f(_a) : 1 + _a, x : -e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}, y : -e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}
# 13	instantiation	322, 26, 27, 28*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))})^{k}))
# 	P(_a) : alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - ((b + l) / 2^{t}))})^{k})), x : phase, y : (b / 2^{t}) + delta_{b}
# 14	instantiation	29, 406, 30, 129, 339, 231, 222	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b + l) / 2^{t}) = ((b / 2^{t}) + (l / 2^{t}))
# 	n : 2, x : (b, l), y : 2^{t}
# 15	instantiation	378, 31, 32	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b / 2^{t}) + delta_{b} - ((b / 2^{t}) + (l / 2^{t}))) = (delta_{b} - (l / 2^{t}))
# 	x : (b / 2^{t}) + delta_{b} - ((b / 2^{t}) + (l / 2^{t})), y : (b / 2^{t}) + delta_{b} + (-(b / 2^{t}) - (l / 2^{t})), z : delta_{b} - (l / 2^{t})
# 16	conjecture		|- forall_{x in Complex | x != 1} [forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))]
# 	proveit.numbers.summation.gen_finite_geom_sum
# 17	instantiation	297, 33, 34	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}, l != 0} |- e^{2 * pi * i * (delta_{b} - (l / 2^{t}))} != 1
# 	P(_a) : _a != 1, x : e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}, y : e^{2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i}
# 18	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 19	instantiation	416, 35, 358	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 20	instantiation	36, 37	|- 0 <= (2^{t} - 1)
# 	x : 0, y : 2^{t} - 1
# 21	instantiation	331, 38	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{0} = 1
# 	a : e^{2 * pi * i * (delta_{b} - (l / 2^{t}))}
# 22	instantiation	378, 39, 40	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{(2^{t} - 1) + 1} = e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}
# 	x : (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{(2^{t} - 1) + 1}, y : (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{2^{t}}, z : e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}
# 23	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))]
# 	proveit.numbers.multiplication.distribute_through_subtract
# 24	instantiation	322, 41, 42	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((l / 2^{t}) * 2^{t}) = l
# 	P(_a) : ((l / 2^{t}) * 2^{t}) = _a, x : (l / 1) * (1 / 1), y : l
# 25	instantiation	391, 43	{b in {b_{f}, b_{r}}} |- (-e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}) = (-e^{2 * pi * i * ((2^{t} * delta_{b}) - l)})
# 	f(_a) : -_a, x : e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)}, y : e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}
# 26	instantiation	297, 44, 45	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- alpha_{b MOD_ADD l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# 	P(_a) : alpha_{_a} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k})), x : b MOD_ADD l, y : (b + l) mod 2^{t}
# 27	instantiation	46, 342	{b in {b_{f}, b_{r}}} |- phase = ((b / 2^{t}) + delta_{b})
# 	b : b
# 28	instantiation	191, 335, 430, 423, 336, 71, 101, 292, 47	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (((b / 2^{t}) + delta_{b}) - ((b + l) / 2^{t})) =  \\ ((b / 2^{t}) + delta_{b} - ((b + l) / 2^{t}))
# 	i : 0, j : 2, k : 1, a : (), b : (b / 2^{t}, delta_{b}), c : (-((b + l) / 2^{t}))
# 29	conjecture		|- forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)))]
# 	proveit.numbers.division.distribute_frac_through_sum
# 30	instantiation	386	|- |(b, l)| = |(1, ..., 2)|
# 	a : b, b : l
# 31	instantiation	391, 48	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b / 2^{t}) + delta_{b} - ((b / 2^{t}) + (l / 2^{t}))) = ((b / 2^{t}) + delta_{b} + (-(b / 2^{t}) - (l / 2^{t})))
# 	f(_a) : (b / 2^{t}) + delta_{b} + _a, x : -((b / 2^{t}) + (l / 2^{t})), y : -(b / 2^{t}) - (l / 2^{t})
# 32	instantiation	378, 49, 50	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b / 2^{t}) + delta_{b} + (-(b / 2^{t}) - (l / 2^{t}))) = (delta_{b} - (l / 2^{t}))
# 	x : (b / 2^{t}) + delta_{b} + (-(b / 2^{t}) - (l / 2^{t})), y : (b / 2^{t}) + delta_{b} - (b / 2^{t}) - (l / 2^{t}), z : delta_{b} - (l / 2^{t})
# 33	instantiation	297, 51, 52	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}, l != 0} |- e^{2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i} != 1
# 	P(_a) : _a != 1, x : e^{2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i}, y : e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i}
# 34	instantiation	391, 53	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- e^{2 * pi * i * (delta_{b} - (l / 2^{t}))} = e^{2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i}
# 	f(_a) : e^{_a}, x : 2 * pi * i * (delta_{b} - (l / 2^{t})), y : 2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i
# 35	instantiation	428, 426, 273	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 36	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 37	instantiation	54, 55	|- (2^{t} - 1) > 0
# 	a : 2^{t}, b : 1
# 38	instantiation	305, 56, 59	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- e^{2 * pi * i * (delta_{b} - (l / 2^{t}))} in Complex
# 	a : e, b : 2 * pi * i * (delta_{b} - (l / 2^{t}))
# 39	instantiation	391, 57	|- (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{(2^{t} - 1) + 1} = (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{2^{t}}
# 	f(_a) : (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{_a}, x : (2^{t} - 1) + 1, y : 2^{t}
# 40	instantiation	58, 117, 59, 231, 60*	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (e^{2 * pi * i * (delta_{b} - (l / 2^{t}))})^{2^{t}} = e^{2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t}}
# 	a : e, b : 2 * pi * i * (delta_{b} - (l / 2^{t})), c : 2^{t}
# 41	instantiation	322, 61, 62	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((l / 2^{t}) * 2^{t}) = ((l / 1) * (1 / 1))
# 	P(_a) : _a = ((l / 1) * (1 / 1)), x : (l / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (l / 2^{t}) * 2^{t}
# 42	instantiation	325, 63, 64, 65	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((l / 1) * (1 / 1)) = l
# 	a : (l / 1) * (1 / 1), b : l * (1 / 1), c : l * 1, d : l
# 43	instantiation	391, 66	{b in {b_{f}, b_{r}}} |- e^{2 * pi * i * ((delta_{b} * 2^{t}) - l)} = e^{2 * pi * i * ((2^{t} * delta_{b}) - l)}
# 	f(_a) : e^{_a}, x : 2 * pi * i * ((delta_{b} * 2^{t}) - l), y : 2 * pi * i * ((2^{t} * delta_{b}) - l)
# 44	instantiation	67, 176	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- alpha_{(b + l) mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - ((b + l) / 2^{t}))})^{k}))
# 	m : b + l
# 45	instantiation	68, 342, 385	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (b MOD_ADD l) = ((b + l) mod 2^{t})
# 	a : b, b : l
# 46	conjecture		|- forall_{b in Integer} (phase = ((b / 2^{t}) + delta_{b}))
# 	proveit.physics.quantum.QPE._phase_from_best_with_delta_b
# 47	instantiation	197, 69	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-((b + l) / 2^{t})) in Complex
# 	a : (b + l) / 2^{t}
# 48	instantiation	70, 101, 198	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-((b / 2^{t}) + (l / 2^{t}))) = (-(b / 2^{t}) - (l / 2^{t}))
# 	a : b / 2^{t}, b : l / 2^{t}
# 49	instantiation	191, 430, 335, 71, 72, 336, 101, 292, 73, 173	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b / 2^{t}) + delta_{b} + (-(b / 2^{t}) - (l / 2^{t}))) =  \\ ((b / 2^{t}) + delta_{b} - (b / 2^{t}) - (l / 2^{t}))
# 	i : 2, j : 2, k : 0, a : (b / 2^{t}, delta_{b}), b : (-(b / 2^{t}), -(l / 2^{t})), c : ()
# 50	instantiation	74, 335, 423, 336, 101, 292, 173, 75	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b / 2^{t}) + delta_{b} - (b / 2^{t}) - (l / 2^{t})) = (delta_{b} - (l / 2^{t}))
# 	i : 0, j : 1, k : 1, a : (), b : b / 2^{t}, c : (delta_{b}), d : b / 2^{t}, e : (-(l / 2^{t}))
# 51	instantiation	76, 77, 78, 79*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}, l != 0} |- e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i} != 1
# 	theta : 2 * (-(2^{-t} * l) + delta_{b}) * pi
# 52	instantiation	391, 80	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- e^{2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i} = e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i}
# 	f(_a) : e^{_a}, x : 2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i, y : 2 * (-(2^{-t} * l) + delta_{b}) * pi * i
# 53	instantiation	378, 81, 82	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2 * pi * i * (delta_{b} - (l / 2^{t}))) = (2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i)
# 	x : 2 * pi * i * (delta_{b} - (l / 2^{t})), y : 2 * (delta_{b} - (l / 2^{t})) * pi * i, z : 2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i
# 54	conjecture		|- forall_{a, b | a > b} ((a - b) > 0)
# 	proveit.numbers.addition.subtraction.pos_difference
# 55	instantiation	83, 321, 108, 84, 85, 86*, 87*	|- 1 < 2^{t}
# 	a : -1, x : 2 * 1, y : (2 * 2^{t - 1}) + 1
# 56	instantiation	428, 412, 88	|- e in Complex
# 	A : Real, B : Complex, x : e
# 57	instantiation	378, 89, 90	|- ((2^{t} - 1) + 1) = 2^{t}
# 	x : (2^{t} - 1) + 1, y : 2^{t} - 1 + 1, z : 2^{t}
# 58	conjecture		|- forall_{a in RealPos, b in Complex, c in Complex} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.complex_power_of_complex_power
# 59	instantiation	322, 91, 92	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2 * pi * i * (delta_{b} - (l / 2^{t}))) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * (delta_{b} - (l / 2^{t}))), y : 2 * pi * i * (delta_{b} - (l / 2^{t}))
# 60	instantiation	333, 335, 93, 423, 336, 94, 404, 332, 186, 148, 231	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2 * pi * i * (delta_{b} - (l / 2^{t}))) * 2^{t}) =  \\ (2 * pi * i * (delta_{b} - (l / 2^{t})) * 2^{t})
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, delta_{b} - (l / 2^{t})), c : (2^{t})
# 61	instantiation	344, 339, 364, 345, 95	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((l / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((l / 1) * (1 / 1))
# 	a : l, d : 1, b : 1, c : 2^{t}, e : 1
# 62	instantiation	378, 96, 97	|- ((l / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((l / 2^{t}) * 2^{t})
# 	x : (l / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (l / 2^{t}) * ((2^{t} * 1) / 1), z : (l / 2^{t}) * 2^{t}
# 63	instantiation	391, 98	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((l / 1) * (1 / 1)) = (l * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : l / 1, y : l
# 64	instantiation	391, 349	|- (l * (1 / 1)) = (l * 1)
# 	f(_a) : l * _a, x : 1 / 1, y : 1
# 65	instantiation	403, 339	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l * 1) = l
# 	x : l
# 66	instantiation	391, 99	{b in {b_{f}, b_{r}}} |- (2 * pi * i * ((delta_{b} * 2^{t}) - l)) = (2 * pi * i * ((2^{t} * delta_{b}) - l))
# 	f(_a) : 2 * pi * i * _a, x : (delta_{b} * 2^{t}) - l, y : (2^{t} * delta_{b}) - l
# 67	conjecture		|- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# 	proveit.physics.quantum.QPE._alpha_m_mod_as_geometric_sum
# 68	axiom		|- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod 2^{t}))
# 	proveit.physics.quantum.QPE._mod_add_def
# 69	instantiation	302, 100, 231, 222	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((b + l) / 2^{t}) in Complex
# 	a : b + l, b : 2^{t}
# 70	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 71	instantiation	386	|- |(b / 2^{t}, delta_{b})| = |(1, ..., 2)|
# 	a : b / 2^{t}, b : delta_{b}
# 72	instantiation	386	|- |(-(b / 2^{t}), -(l / 2^{t}))| = |(1, ..., 2)|
# 	a : -(b / 2^{t}), b : -(l / 2^{t})
# 73	instantiation	197, 101	{b in {b_{f}, b_{r}}} |- (-(b / 2^{t})) in Complex
# 	a : b / 2^{t}
# 74	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 75	instantiation	365	|- (b / 2^{t}) = (b / 2^{t})
# 	x : b / 2^{t}
# 76	conjecture		|- forall_{theta in Real | (theta / (2 * pi)) not-in Integer} (e^{i * theta} != 1)
# 	proveit.numbers.exponentiation.unit_complex_polar_num_neq_one
# 77	instantiation	322, 199, 179	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi) in Real
# 	P(_a) : _a in Real, x : (2 * (-(2^{-t} * l) + delta_{b})) * pi, y : 2 * (-(2^{-t} * l) + delta_{b}) * pi
# 78	instantiation	297, 102, 103	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) / (2 * pi)) not-in Integer
# 	P(_a) : _a not-in Integer, x : (2 * (-(2^{-t} * l) + delta_{b}) * pi) / (2 * pi), y : delta_{b} - (l / 2^{t})
# 79	instantiation	268, 104	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- e^{i * (2 * (-(2^{-t} * l) + delta_{b}) * pi)} = e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i}
# 	x : e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i}, y : e^{i * (2 * (-(2^{-t} * l) + delta_{b}) * pi)}
# 80	instantiation	391, 163	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i) = (2 * (-(2^{-t} * l) + delta_{b}) * pi * i)
# 	f(_a) : 2 * _a * pi * i, x : ((-1) * 2^{(-1) * t} * l) + delta_{b}, y : -(2^{-t} * l) + delta_{b}
# 81	instantiation	252, 423, 430, 335, 105, 336, 404, 332, 186, 148	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2 * pi * i * (delta_{b} - (l / 2^{t}))) =  \\ (2 * (delta_{b} - (l / 2^{t})) * pi * i)
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, i), c : delta_{b} - (l / 2^{t}), d : ()
# 82	instantiation	391, 106	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (delta_{b} - (l / 2^{t})) * pi * i) = (2 * (((-1) * 2^{(-1) * t} * l) + delta_{b}) * pi * i)
# 	f(_a) : 2 * _a * pi * i, x : delta_{b} - (l / 2^{t}), y : ((-1) * 2^{(-1) * t} * l) + delta_{b}
# 83	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 84	instantiation	318, 109, 381	|- ((2 * 2^{t - 1}) + 1) in Real
# 	a : 2 * 2^{t - 1}, b : 1
# 85	instantiation	107, 108, 109, 381, 110, 111	|- (2 * 1) < ((2 * 2^{t - 1}) + 1)
# 	a : 2 * 1, b : 2 * 2^{t - 1}, c : 1
# 86	instantiation	378, 112, 113	|- ((2 * 1) - 1) = 1
# 	x : (2 * 1) - 1, y : 2 - 1, z : 1
# 87	instantiation	325, 114, 115, 116	|- (((2 * 2^{t - 1}) + 1) - 1) = 2^{t}
# 	a : ((2 * 2^{t - 1}) + 1) - 1, b : 2 * (1 / 2^{1}) * 2^{t}, c : 2^{t}, d : 2^{t}
# 88	instantiation	428, 367, 117	|- e in Real
# 	A : RealPos, B : Real, x : e
# 89	instantiation	191, 335, 430, 423, 336, 118, 231, 306, 364	|- ((2^{t} - 1) + 1) =  \\ (2^{t} - 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t}, -1), c : (1)
# 90	instantiation	119, 364, 231, 351	|- (2^{t} - 1 + 1) = 2^{t}
# 	a : 1, b : 1, c : 2^{t}
# 91	instantiation	277, 156, 120	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2 * pi) * (i * (delta_{b} - (l / 2^{t})))) in Complex
# 	a : 2 * pi, b : i * (delta_{b} - (l / 2^{t}))
# 92	instantiation	378, 121, 122	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2 * pi) * (i * (delta_{b} - (l / 2^{t})))) = (2 * pi * i * (delta_{b} - (l / 2^{t})))
# 	x : (2 * pi) * (i * (delta_{b} - (l / 2^{t}))), y : (2 * pi) * i * (delta_{b} - (l / 2^{t})), z : 2 * pi * i * (delta_{b} - (l / 2^{t}))
# 93	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 94	instantiation	123	|- |(2, pi, i, delta_{b} - (l / 2^{t}))| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : delta_{b} - (l / 2^{t})
# 95	instantiation	428, 360, 124	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 96	instantiation	391, 125	|- ((l / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((l / 2^{t}) * ((2^{t} * 1) / 1))
# 	f(_a) : _a * ((2^{t} * 1) / 1), x : l / (1 * 2^{t}), y : l / 2^{t}
# 97	instantiation	391, 126	|- ((l / 2^{t}) * ((2^{t} * 1) / 1)) = ((l / 2^{t}) * 2^{t})
# 	f(_a) : (l / 2^{t}) * _a, x : (2^{t} * 1) / 1, y : 2^{t}
# 98	instantiation	393, 339	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 1) = l
# 	x : l
# 99	instantiation	391, 127	{b in {b_{f}, b_{r}}} |- ((delta_{b} * 2^{t}) - l) = ((2^{t} * delta_{b}) - l)
# 	f(_a) : _a - l, x : delta_{b} * 2^{t}, y : 2^{t} * delta_{b}
# 100	instantiation	428, 412, 128	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (b + l) in Complex
# 	A : Real, B : Complex, x : b + l
# 101	instantiation	302, 129, 231, 222	{b in {b_{f}, b_{r}}} |- (b / 2^{t}) in Complex
# 	a : b, b : 2^{t}
# 102	instantiation	130, 357, 400, 131	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b} - (l / 2^{t})) not-in Integer
# 	b : b, l : l
# 103	instantiation	325, 132, 162, 133	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) / (2 * pi)) = (delta_{b} - (l / 2^{t}))
# 	a : (2 * (-(2^{-t} * l) + delta_{b}) * pi) / (2 * pi), b : -(2^{-t} * l) + delta_{b}, c : delta_{b} - (l * 2^{-t}), d : delta_{b} - (l / 2^{t})
# 104	instantiation	391, 134	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- e^{2 * (-(2^{-t} * l) + delta_{b}) * pi * i} = e^{i * (2 * (-(2^{-t} * l) + delta_{b}) * pi)}
# 	f(_a) : e^{_a}, x : 2 * (-(2^{-t} * l) + delta_{b}) * pi * i, y : i * (2 * (-(2^{-t} * l) + delta_{b}) * pi)
# 105	instantiation	386	|- |(pi, i)| = |(1, ..., 2)|
# 	a : pi, b : i
# 106	instantiation	325, 159, 135, 136	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) = (((-1) * 2^{(-1) * t} * l) + delta_{b})
# 	a : delta_{b} - (l / 2^{t}), b : delta_{b} - (l * 2^{-t}), c : -(2^{-t} * l) + delta_{b}, d : ((-1) * 2^{(-1) * t} * l) + delta_{b}
# 107	conjecture		|- forall_{a, b, c in Real | a <= b, 0 < c} (a < (b + c))
# 	proveit.numbers.ordering.less_eq_add_right_strong
# 108	instantiation	353, 413, 381	|- (2 * 1) in Real
# 	a : 2, b : 1
# 109	instantiation	353, 413, 138	|- (2 * 2^{t - 1}) in Real
# 	a : 2, b : 2^{t - 1}
# 110	instantiation	137, 413, 381, 138, 139, 140	|- (2 * 1) <= (2 * 2^{t - 1})
# 	a : 2, x : 1, y : 2^{t - 1}
# 111	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 112	instantiation	391, 392	|- ((2 * 1) - 1) = (2 - 1)
# 	f(_a) : _a - 1, x : 2 * 1, y : 2
# 113	instantiation	141, 364, 404, 142	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 114	instantiation	378, 143, 144	|- (((2 * 2^{t - 1}) + 1) - 1) = (2 * (1 / 2^{1}) * 2^{t})
# 	x : ((2 * 2^{t - 1}) + 1) - 1, y : ((2 * (1 / 2^{1}) * 2^{t}) + 1) - 1, z : 2 * (1 / 2^{1}) * 2^{t}
# 115	instantiation	378, 145, 146	|- (2 * (1 / 2^{1}) * 2^{t}) = 2^{t}
# 	x : 2 * (1 / 2^{1}) * 2^{t}, y : 2 * (1 / 2) * 2^{t}, z : 2^{t}
# 116	instantiation	365	|- 2^{t} = 2^{t}
# 	x : 2^{t}
# 117	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 118	instantiation	386	|- |(2^{t}, -1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : -1
# 119	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 120	instantiation	277, 186, 148	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (i * (delta_{b} - (l / 2^{t}))) in Complex
# 	a : i, b : delta_{b} - (l / 2^{t})
# 121	instantiation	333, 423, 430, 335, 147, 336, 156, 186, 148	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2 * pi) * (i * (delta_{b} - (l / 2^{t})))) =  \\ ((2 * pi) * i * (delta_{b} - (l / 2^{t})))
# 	i : 1, j : 2, k : 0, a : (2 * pi), b : (i, delta_{b} - (l / 2^{t})), c : ()
# 122	instantiation	333, 335, 430, 336, 181, 147, 404, 332, 186, 148	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((2 * pi) * i * (delta_{b} - (l / 2^{t}))) =  \\ (2 * pi * i * (delta_{b} - (l / 2^{t})))
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : (i, delta_{b} - (l / 2^{t}))
# 123	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, 2, ..., 4)|)
# 	proveit.numbers.numerals.decimals.tuple_len_4_typical_eq
# 124	instantiation	428, 375, 149	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 125	instantiation	391, 171	|- (l / (1 * 2^{t})) = (l / 2^{t})
# 	f(_a) : l / _a, x : 1 * 2^{t}, y : 2^{t}
# 126	instantiation	378, 150, 151	|- ((2^{t} * 1) / 1) = 2^{t}
# 	x : (2^{t} * 1) / 1, y : 2^{t} / 1, z : 2^{t}
# 127	instantiation	268, 152	{b in {b_{f}, b_{r}}} |- (delta_{b} * 2^{t}) = (2^{t} * delta_{b})
# 	x : 2^{t} * delta_{b}, y : delta_{b} * 2^{t}
# 128	instantiation	428, 419, 153	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (b + l) in Real
# 	A : Rational, B : Real, x : b + l
# 129	instantiation	428, 412, 154	{b in {b_{f}, b_{r}}} |- b in Complex
# 	A : Real, B : Complex, x : b
# 130	conjecture		|- forall_{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((delta_{b} - (l / 2^{t})) not-in Integer)
# 	proveit.physics.quantum.QPE._non_int_delta_b_diff
# 131	assumption		{l != 0} |- l != 0
# 132	instantiation	221, 155, 156, 157, 158*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) / (2 * pi)) = (-(2^{-t} * l) + delta_{b})
# 	x : 2 * (-(2^{-t} * l) + delta_{b}) * pi, y : 2 * pi
# 133	instantiation	268, 159	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l * 2^{-t})) = (delta_{b} - (l / 2^{t}))
# 	x : delta_{b} - (l / 2^{t}), y : delta_{b} - (l * 2^{-t})
# 134	instantiation	378, 160, 161	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi * i) = (i * (2 * (-(2^{-t} * l) + delta_{b}) * pi))
# 	x : 2 * (-(2^{-t} * l) + delta_{b}) * pi * i, y : i * 2 * (-(2^{-t} * l) + delta_{b}) * pi, z : i * (2 * (-(2^{-t} * l) + delta_{b}) * pi)
# 135	instantiation	268, 162	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l * 2^{-t})) = (-(2^{-t} * l) + delta_{b})
# 	x : -(2^{-t} * l) + delta_{b}, y : delta_{b} - (l * 2^{-t})
# 136	instantiation	268, 163	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(2^{-t} * l) + delta_{b}) = (((-1) * 2^{(-1) * t} * l) + delta_{b})
# 	x : ((-1) * 2^{(-1) * t} * l) + delta_{b}, y : -(2^{-t} * l) + delta_{b}
# 137	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 138	instantiation	407, 408, 427	|- 2^{t - 1} in Real
# 	A : NaturalPos, B : Real, x : 2^{t - 1}
# 139	instantiation	164, 427	|- 2^{t - 1} >= 1
# 	n : 2^{t - 1}
# 140	instantiation	165, 430	|- 0 <= 2
# 	n : 2
# 141	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 142	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 143	instantiation	391, 166	|- (((2 * 2^{t - 1}) + 1) - 1) = (((2 * (1 / 2^{1}) * 2^{t}) + 1) - 1)
# 	f(_a) : _a - 1, x : (2 * 2^{t - 1}) + 1, y : (2 * (1 / 2^{1}) * 2^{t}) + 1
# 144	instantiation	378, 167, 168	|- (((2 * (1 / 2^{1}) * 2^{t}) + 1) - 1) = (2 * (1 / 2^{1}) * 2^{t})
# 	x : ((2 * (1 / 2^{1}) * 2^{t}) + 1) - 1, y : (2 * (1 / 2^{1}) * 2^{t}) + 1 - 1, z : 2 * (1 / 2^{1}) * 2^{t}
# 145	instantiation	391, 169	|- (2 * (1 / 2^{1}) * 2^{t}) = (2 * (1 / 2) * 2^{t})
# 	f(_a) : 2 * _a * 2^{t}, x : 1 / 2^{1}, y : 1 / 2
# 146	instantiation	378, 170, 171	|- (2 * (1 / 2) * 2^{t}) = 2^{t}
# 	x : 2 * (1 / 2) * 2^{t}, y : 1 * 2^{t}, z : 2^{t}
# 147	instantiation	386	|- |(i, delta_{b} - (l / 2^{t}))| = |(1, ..., 2)|
# 	a : i, b : delta_{b} - (l / 2^{t})
# 148	instantiation	172, 292, 173	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l / 2^{t})) in Complex
# 	a : delta_{b}, b : -(l / 2^{t})
# 149	instantiation	428, 388, 174	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 150	instantiation	391, 175	|- ((2^{t} * 1) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 2^{t} * 1, y : 2^{t}
# 151	instantiation	393, 231	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 152	instantiation	258, 231, 292	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) = (delta_{b} * 2^{t})
# 	a : 2^{t}, b : delta_{b}
# 153	instantiation	428, 424, 176	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (b + l) in Rational
# 	A : Integer, B : Rational, x : b + l
# 154	instantiation	428, 419, 177	{b in {b_{f}, b_{r}}} |- b in Real
# 	A : Rational, B : Real, x : b
# 155	instantiation	322, 178, 179	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi) in Complex
# 	P(_a) : _a in Complex, x : (2 * (-(2^{-t} * l) + delta_{b})) * pi, y : 2 * (-(2^{-t} * l) + delta_{b}) * pi
# 156	instantiation	277, 404, 332	|- (2 * pi) in Complex
# 	a : 2, b : pi
# 157	instantiation	180, 430, 181, 346, 182	|- (2 * pi) != 0
# 	n : 2, a : (2, pi)
# 158	instantiation	378, 183, 184	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * (2 * pi)^{-1}) = (-(2^{-t} * l) + delta_{b})
# 	x : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * (2 * pi)^{-1}, y : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1}), z : -(2^{-t} * l) + delta_{b}
# 159	instantiation	391, 185	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l / 2^{t})) = (delta_{b} - (l * 2^{-t}))
# 	f(_a) : delta_{b} + _a, x : -(l / 2^{t}), y : -(l * 2^{-t})
# 160	instantiation	252, 335, 279, 336, 253, 404, 283, 332, 186	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi * i) =  \\ (i * 2 * (-(2^{-t} * l) + delta_{b}) * pi)
# 	i : 0, j : 3, k : 0, a : (), b : (2, -(2^{-t} * l) + delta_{b}, pi), c : i, d : ()
# 161	instantiation	278, 423, 279, 335, 253, 336, 186, 404, 283, 332	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (i * 2 * (-(2^{-t} * l) + delta_{b}) * pi) =  \\ (i * (2 * (-(2^{-t} * l) + delta_{b}) * pi))
# 	i : 1, j : 3, k : 0, a : (i), b : (2, -(2^{-t} * l) + delta_{b}, pi), c : ()
# 162	instantiation	378, 187, 188	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-(2^{-t} * l) + delta_{b}) = (delta_{b} - (l * 2^{-t}))
# 	x : -(2^{-t} * l) + delta_{b}, y : delta_{b} - (2^{-t} * l), z : delta_{b} - (l * 2^{-t})
# 163	instantiation	391, 189	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (((-1) * 2^{(-1) * t} * l) + delta_{b}) = (-(2^{-t} * l) + delta_{b})
# 	f(_a) : _a + delta_{b}, x : (-1) * 2^{(-1) * t} * l, y : -(2^{-t} * l)
# 164	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 165	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 166	instantiation	391, 190	|- ((2 * 2^{t - 1}) + 1) = ((2 * (1 / 2^{1}) * 2^{t}) + 1)
# 	f(_a) : _a + 1, x : 2 * 2^{t - 1}, y : 2 * (1 / 2^{1}) * 2^{t}
# 167	instantiation	191, 335, 430, 423, 336, 192, 194, 364, 306	|- (((2 * (1 / 2^{1}) * 2^{t}) + 1) - 1) =  \\ ((2 * (1 / 2^{1}) * 2^{t}) + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2 * (1 / 2^{1}) * 2^{t}, 1), c : (-1)
# 168	instantiation	193, 364, 194, 351	|- ((2 * (1 / 2^{1}) * 2^{t}) + 1 - 1) = (2 * (1 / 2^{1}) * 2^{t})
# 	a : 1, b : 1, c : 2 * (1 / 2^{1}) * 2^{t}
# 169	instantiation	391, 298	|- (1 / 2^{1}) = (1 / 2)
# 	f(_a) : 1 / _a, x : 2^{1}, y : 2
# 170	instantiation	378, 195, 196	|- (2 * (1 / 2) * 2^{t}) = (1 * 2^{t})
# 	x : 2 * (1 / 2) * 2^{t}, y : (2 * (1 / 2)) * 2^{t}, z : 1 * 2^{t}
# 171	instantiation	390, 231	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 172	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 173	instantiation	197, 198	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(l / 2^{t})) in Complex
# 	a : l / 2^{t}
# 174	instantiation	428, 402, 273	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 175	instantiation	403, 231	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 176	instantiation	416, 342, 385	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (b + l) in Integer
# 	a : b, b : l
# 177	instantiation	428, 424, 342	{b in {b_{f}, b_{r}}} |- b in Rational
# 	A : Integer, B : Rational, x : b
# 178	instantiation	428, 412, 199	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b})) * pi) in Complex
# 	A : Real, B : Complex, x : (2 * (-(2^{-t} * l) + delta_{b})) * pi
# 179	instantiation	333, 335, 430, 423, 336, 200, 404, 283, 332	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b})) * pi) =  \\ (2 * (-(2^{-t} * l) + delta_{b}) * pi)
# 	i : 0, j : 2, k : 1, a : (), b : (2, -(2^{-t} * l) + delta_{b}), c : (pi)
# 180	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in ComplexNonZero} ((a_{1} *  a_{2} *  ... *  a_{n}) != 0)]
# 	proveit.numbers.multiplication.mult_not_eq_zero
# 181	instantiation	386	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 182	instantiation	428, 360, 310	|- pi in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : pi
# 183	instantiation	391, 201	|- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * (2 * pi)^{-1}) = ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1}))
# 	f(_a) : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * _a, x : (2 * pi)^{-1}, y : (1 / 2) * pi^{-1}
# 184	instantiation	378, 202, 203	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1})) = (-(2^{-t} * l) + delta_{b})
# 	x : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1}), y : 1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, z : -(2^{-t} * l) + delta_{b}
# 185	instantiation	391, 204	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(l / 2^{t})) = (-(l * 2^{-t}))
# 	f(_a) : -_a, x : l / 2^{t}, y : l * 2^{-t}
# 186	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 187	instantiation	293, 261, 292	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-(2^{-t} * l) + delta_{b}) = (delta_{b} - (2^{-t} * l))
# 	a : -(2^{-t} * l), b : delta_{b}
# 188	instantiation	391, 205	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (2^{-t} * l)) = (delta_{b} - (l * 2^{-t}))
# 	f(_a) : delta_{b} + _a, x : -(2^{-t} * l), y : -(l * 2^{-t})
# 189	instantiation	378, 206, 207	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-1) * 2^{(-1) * t} * l) = (-(2^{-t} * l))
# 	x : (-1) * 2^{(-1) * t} * l, y : (-1) * 2^{-t} * l, z : -(2^{-t} * l)
# 190	instantiation	378, 208, 209	|- (2 * 2^{t - 1}) = (2 * (1 / 2^{1}) * 2^{t})
# 	x : 2 * 2^{t - 1}, y : 2 * ((1 / 2^{1}) * 2^{t}), z : 2 * (1 / 2^{1}) * 2^{t}
# 191	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 192	instantiation	386	|- |(2 * (1 / 2^{1}) * 2^{t}, 1)| = |(1, ..., 2)|
# 	a : 2 * (1 / 2^{1}) * 2^{t}, b : 1
# 193	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 194	instantiation	322, 210, 211	|- (2 * (1 / 2^{1}) * 2^{t}) in Complex
# 	P(_a) : _a in Complex, x : (2 * (1 / 2^{1})) * 2^{t}, y : 2 * (1 / 2^{1}) * 2^{t}
# 195	instantiation	278, 335, 430, 423, 336, 212, 404, 282, 231	|- (2 * (1 / 2) * 2^{t}) =  \\ ((2 * (1 / 2)) * 2^{t})
# 	i : 0, j : 2, k : 1, a : (), b : (2, 1 / 2), c : (2^{t})
# 196	instantiation	391, 213	|- ((2 * (1 / 2)) * 2^{t}) = (1 * 2^{t})
# 	f(_a) : _a * 2^{t}, x : 2 * (1 / 2), y : 1
# 197	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 198	instantiation	302, 339, 231, 222	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 2^{t}) in Complex
# 	a : l, b : 2^{t}
# 199	instantiation	353, 214, 352	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b})) * pi) in Real
# 	a : 2 * (-(2^{-t} * l) + delta_{b}), b : pi
# 200	instantiation	386	|- |(2, -(2^{-t} * l) + delta_{b})| = |(1, ..., 2)|
# 	a : 2, b : -(2^{-t} * l) + delta_{b}
# 201	instantiation	215, 404, 332, 321, 303, 286, 216*	|- (2 * pi)^{-1} = ((1 / 2) * pi^{-1})
# 	a : 2, b : pi, c : -1
# 202	instantiation	378, 217, 218	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1})) = (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	x : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1}), y : 2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1}, z : 1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}
# 203	instantiation	378, 219, 220	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) = (-(2^{-t} * l) + delta_{b})
# 	x : 1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, y : (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, z : -(2^{-t} * l) + delta_{b}
# 204	instantiation	221, 339, 231, 222, 223*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 2^{t}) = (l * 2^{-t})
# 	x : l, y : 2^{t}
# 205	instantiation	391, 224	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(2^{-t} * l)) = (-(l * 2^{-t}))
# 	f(_a) : -_a, x : 2^{-t} * l, y : l * 2^{-t}
# 206	instantiation	391, 225	|- ((-1) * 2^{(-1) * t} * l) = ((-1) * 2^{-t} * l)
# 	f(_a) : (-1) * _a * l, x : 2^{(-1) * t}, y : 2^{-t}
# 207	instantiation	226, 335, 430, 336, 337, 364, 338, 339, 314*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-1) * 2^{-t} * l) = (-(2^{-t} * l))
# 	i : 0, j : 2, a : (), b : 1, c : (2^{-t}, l)
# 208	instantiation	391, 227	|- (2 * 2^{t - 1}) = (2 * ((1 / 2^{1}) * 2^{t}))
# 	f(_a) : 2 * _a, x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 209	instantiation	333, 423, 430, 335, 228, 336, 404, 246, 231	|- (2 * ((1 / 2^{1}) * 2^{t})) =  \\ (2 * (1 / 2^{1}) * 2^{t})
# 	i : 1, j : 2, k : 0, a : (2), b : (1 / 2^{1}, 2^{t}), c : ()
# 210	instantiation	277, 229, 231	|- ((2 * (1 / 2^{1})) * 2^{t}) in Complex
# 	a : 2 * (1 / 2^{1}), b : 2^{t}
# 211	instantiation	333, 335, 430, 423, 336, 230, 404, 246, 231	|- ((2 * (1 / 2^{1})) * 2^{t}) =  \\ (2 * (1 / 2^{1}) * 2^{t})
# 	i : 0, j : 2, k : 1, a : (), b : (2, 1 / 2^{1}), c : (2^{t})
# 212	instantiation	386	|- |(2, 1 / 2)| = |(1, ..., 2)|
# 	a : 2, b : 1 / 2
# 213	instantiation	322, 232, 308	|- (2 * (1 / 2)) = 1
# 	P(_a) : (2 * (1 / 2)) = _a, x : (1 / 1) * (1 / 1), y : 1
# 214	instantiation	353, 413, 304	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b})) in Real
# 	a : 2, b : -(2^{-t} * l) + delta_{b}
# 215	conjecture		|- forall_{a in Complex, b in Complex, c in Real | a != 0, b != 0} ((a * b)^{c} = (a^{c} * b^{c}))
# 	proveit.numbers.exponentiation.real_power_of_product
# 216	instantiation	296, 346, 401, 298*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 217	instantiation	378, 233, 234	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1})) = (2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1})
# 	x : (2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1}), y : 2 * (-(2^{-t} * l) + delta_{b}) * pi * ((1 / 2) * pi^{-1}), z : 2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1}
# 218	instantiation	378, 235, 236	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1}) = (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	x : 2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1}, y : (1 / 2) * 2 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, z : 1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}
# 219	instantiation	334, 335, 279, 336, 281, 283, 332, 284	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) = ((-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	i : 0, j : 3, a : (), b : (-(2^{-t} * l) + delta_{b}, pi, pi^{-1})
# 220	instantiation	325, 237, 238, 239	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) = (-(2^{-t} * l) + delta_{b})
# 	a : (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, b : (-(2^{-t} * l) + delta_{b}) * 1, c : 1 * (-(2^{-t} * l) + delta_{b}), d : -(2^{-t} * l) + delta_{b}
# 221	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 222	instantiation	317, 273	|- 2^{t} != 0
# 	n : 2^{t}
# 223	instantiation	240, 404, 398, 321, 303, 241*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 224	instantiation	258, 338, 339	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2^{-t} * l) = (l * 2^{-t})
# 	a : 2^{-t}, b : l
# 225	instantiation	391, 242	|- 2^{(-1) * t} = 2^{-t}
# 	f(_a) : 2^{_a}, x : (-1) * t, y : -t
# 226	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (-b)* c_{1} *  c_{2} *  ... *  c_{j}) = (-(a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j})))]
# 	proveit.numbers.multiplication.mult_neg_any
# 227	instantiation	325, 243, 244, 245	|- 2^{t - 1} = ((1 / 2^{1}) * 2^{t})
# 	a : 2^{t - 1}, b : 2^{-1 + t}, c : 2^{-1} * 2^{t}, d : (1 / 2^{1}) * 2^{t}
# 228	instantiation	386	|- |(1 / 2^{1}, 2^{t})| = |(1, ..., 2)|
# 	a : 1 / 2^{1}, b : 2^{t}
# 229	instantiation	277, 404, 246	|- (2 * (1 / 2^{1})) in Complex
# 	a : 2, b : 1 / 2^{1}
# 230	instantiation	386	|- |(2, 1 / 2^{1})| = |(1, ..., 2)|
# 	a : 2, b : 1 / 2^{1}
# 231	instantiation	428, 412, 247	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 232	instantiation	322, 248, 249	|- (2 * (1 / 2)) = ((1 / 1) * (1 / 1))
# 	P(_a) : _a = ((1 / 1) * (1 / 1)), x : ((1 * 2) / 1) * (1 / (2 * 1)), y : 2 * (1 / 2)
# 233	instantiation	333, 335, 279, 423, 336, 253, 404, 283, 332, 250	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((2 * (-(2^{-t} * l) + delta_{b}) * pi) * ((1 / 2) * pi^{-1})) =  \\ (2 * (-(2^{-t} * l) + delta_{b}) * pi * ((1 / 2) * pi^{-1}))
# 	i : 0, j : 3, k : 1, a : (), b : (2, -(2^{-t} * l) + delta_{b}, pi), c : ((1 / 2) * pi^{-1})
# 234	instantiation	333, 279, 430, 335, 253, 251, 336, 404, 283, 332, 282, 284	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi * ((1 / 2) * pi^{-1})) =  \\ (2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1})
# 	i : 3, j : 2, k : 0, a : (2, -(2^{-t} * l) + delta_{b}, pi), b : (1 / 2, pi^{-1}), c : ()
# 235	instantiation	252, 335, 279, 423, 336, 253, 404, 283, 332, 282, 284	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (2 * (-(2^{-t} * l) + delta_{b}) * pi * (1 / 2) * pi^{-1}) =  \\ ((1 / 2) * 2 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	i : 0, j : 3, k : 1, a : (), b : (2, -(2^{-t} * l) + delta_{b}, pi), c : 1 / 2, d : (pi^{-1})
# 236	instantiation	378, 254, 255	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((1 / 2) * 2 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) = (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	x : (1 / 2) * 2 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, y : ((1 / 2) * 2) * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, z : 1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}
# 237	instantiation	278, 423, 430, 335, 256, 336, 283, 332, 284, 257*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) =  \\ ((-(2^{-t} * l) + delta_{b}) * 1)
# 	i : 1, j : 2, k : 0, a : (-(2^{-t} * l) + delta_{b}), b : (pi, pi^{-1}), c : ()
# 238	instantiation	258, 283, 364	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((-(2^{-t} * l) + delta_{b}) * 1) = (1 * (-(2^{-t} * l) + delta_{b}))
# 	a : -(2^{-t} * l) + delta_{b}, b : 1
# 239	instantiation	259, 423, 430, 335, 260, 336, 364, 261, 292, 262*, 263*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (1 * (-(2^{-t} * l) + delta_{b})) =  \\ (-(2^{-t} * l) + delta_{b})
# 	i : 1, j : 2, k : 0, a : (1), b : (-(2^{-t} * l), delta_{b}), c : ()
# 240	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 241	instantiation	289, 294, 364, 264*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 242	instantiation	265, 364, 294, 266*	|- ((-1) * t) = (-t)
# 	x : 1, y : t
# 243	instantiation	391, 267	|- 2^{t - 1} = 2^{-1 + t}
# 	f(_a) : 2^{_a}, x : t - 1, y : -1 + t
# 244	instantiation	268, 269	|- 2^{-1 + t} = (2^{-1} * 2^{t})
# 	x : 2^{-1} * 2^{t}, y : 2^{-1 + t}
# 245	instantiation	391, 270	|- (2^{-1} * 2^{t}) = ((1 / 2^{1}) * 2^{t})
# 	f(_a) : _a * 2^{t}, x : 2^{-1}, y : 1 / 2^{1}
# 246	instantiation	302, 364, 271, 272	|- (1 / 2^{1}) in Complex
# 	a : 1, b : 2^{1}
# 247	instantiation	407, 408, 273	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 248	instantiation	274, 364, 346, 345	|- (((1 * 2) / 1) * (1 / (2 * 1))) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 2, c : 1, e : 1
# 249	instantiation	378, 275, 276	|- (((1 * 2) / 1) * (1 / (2 * 1))) = (2 * (1 / 2))
# 	x : ((1 * 2) / 1) * (1 / (2 * 1)), y : 2 * (1 / (2 * 1)), z : 2 * (1 / 2)
# 250	instantiation	277, 282, 284	|- ((1 / 2) * pi^{-1}) in Complex
# 	a : 1 / 2, b : pi^{-1}
# 251	instantiation	386	|- |(1 / 2, pi^{-1})| = |(1, ..., 2)|
# 	a : 1 / 2, b : pi^{-1}
# 252	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 253	instantiation	301	|- |(2, -(2^{-t} * l) + delta_{b}, pi)| = |(1, 2, ..., 3)|
# 	a : 2, b : -(2^{-t} * l) + delta_{b}, c : pi
# 254	instantiation	278, 335, 430, 279, 336, 280, 281, 282, 404, 283, 332, 284	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((1 / 2) * 2 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) =  \\ (((1 / 2) * 2) * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	i : 0, j : 2, k : 3, a : (), b : (1 / 2, 2), c : (-(2^{-t} * l) + delta_{b}, pi, pi^{-1})
# 255	instantiation	391, 285	|- (((1 / 2) * 2) * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}) = (1 * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1})
# 	f(_a) : _a * (-(2^{-t} * l) + delta_{b}) * pi * pi^{-1}, x : (1 / 2) * 2, y : 1
# 256	instantiation	386	|- |(pi, pi^{-1})| = |(1, ..., 2)|
# 	a : pi, b : pi^{-1}
# 257	instantiation	295, 332, 381, 321, 286, 287*, 288*	|- (pi * pi^{-1}) = 1
# 	a : pi, b : 1, c : -1
# 258	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 259	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 260	instantiation	386	|- |(-(2^{-t} * l), delta_{b})| = |(1, ..., 2)|
# 	a : -(2^{-t} * l), b : delta_{b}
# 261	instantiation	428, 412, 319	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(2^{-t} * l)) in Complex
# 	A : Real, B : Complex, x : -(2^{-t} * l)
# 262	instantiation	289, 364, 290, 291*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 * (-(2^{-t} * l))) = (-(2^{-t} * l))
# 	x : 1, y : 2^{-t} * l
# 263	instantiation	390, 292	{b in {b_{f}, b_{r}}} |- (1 * delta_{b}) = delta_{b}
# 	x : delta_{b}
# 264	instantiation	403, 294	|- (t * 1) = t
# 	x : t
# 265	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 266	instantiation	390, 294	|- (1 * t) = t
# 	x : t
# ...
# 	proveit.numbers.multiplication.association
# 279	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 280	instantiation	386	|- |(1 / 2, 2)| = |(1, ..., 2)|
# 	a : 1 / 2, b : 2
# 281	instantiation	301	|- |(-(2^{-t} * l) + delta_{b}, pi, pi^{-1})| = |(1, 2, ..., 3)|
# 	a : -(2^{-t} * l) + delta_{b}, b : pi, c : pi^{-1}
# 282	instantiation	302, 364, 404, 303	|- (1 / 2) in Complex
# 	a : 1, b : 2
# 283	instantiation	428, 412, 304	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-(2^{-t} * l) + delta_{b}) in Complex
# 	A : Real, B : Complex, x : -(2^{-t} * l) + delta_{b}
# 284	instantiation	305, 332, 306	|- pi^{-1} in Complex
# 	a : pi, b : -1
# 285	instantiation	322, 307, 308	|- ((1 / 2) * 2) = 1
# 	P(_a) : ((1 / 2) * 2) = _a, x : (1 / 1) * (1 / 1), y : 1
# 286	instantiation	309, 310	|- pi != 0
# 	x : pi
# 287	instantiation	315, 332	|- pi^{1} = pi
# 	x : pi
# 288	instantiation	378, 311, 312	|- pi^{1 - 1} = 1
# 	x : pi^{1 - 1}, y : pi^{0}, z : 1
# 289	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 290	instantiation	428, 412, 340	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2^{-t} * l) in Complex
# 	A : Real, B : Complex, x : 2^{-t} * l
# 291	instantiation	378, 313, 314	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 * (2^{-t} * l)) = (2^{-t} * l)
# 	x : 1 * (2^{-t} * l), y : 1 * 2^{-t} * l, z : 2^{-t} * l
# 292	instantiation	428, 412, 320	{b in {b_{f}, b_{r}}} |- delta_{b} in Complex
# 	A : Real, B : Complex, x : delta_{b}
# 293	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 294	instantiation	428, 412, 398	|- t in Complex
# 	A : Real, B : Complex, x : t
# 295	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 296	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 297	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 298	instantiation	315, 404	|- 2^{1} = 2
# 	x : 2
# 299	instantiation	378, 316, 380	|- ((1 * 2) / 1) = 2
# 	x : (1 * 2) / 1, y : 2 / 1, z : 2
# 300	instantiation	391, 392	|- (1 / (2 * 1)) = (1 / 2)
# 	f(_a) : 1 / _a, x : 2 * 1, y : 2
# 301	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 302	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 303	instantiation	317, 406	|- 2 != 0
# 	n : 2
# 304	instantiation	318, 319, 320	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-(2^{-t} * l) + delta_{b}) in Real
# 	a : -(2^{-t} * l), b : delta_{b}
# 305	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 306	instantiation	428, 412, 321	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 307	instantiation	322, 323, 324	|- ((1 / 2) * 2) = ((1 / 1) * (1 / 1))
# 	P(_a) : _a = ((1 / 1) * (1 / 1)), x : (1 / (1 * 2)) * ((2 * 1) / 1), y : (1 / 2) * 2
# 308	instantiation	325, 326, 327, 328	|- ((1 / 1) * (1 / 1)) = 1
# 	a : (1 / 1) * (1 / 1), b : 1 * (1 / 1), c : 1 * 1, d : 1
# 309	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 310	instantiation	428, 329, 366	|- pi in RealNonZero
# 	A : RealPos, B : RealNonZero, x : pi
# 311	instantiation	391, 330	|- pi^{1 - 1} = pi^{0}
# 	f(_a) : pi^{_a}, x : 1 - 1, y : 0
# 312	instantiation	331, 332	|- pi^{0} = 1
# 	a : pi
# 313	instantiation	333, 423, 430, 335, 337, 336, 364, 338, 339	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 * (2^{-t} * l)) =  \\ (1 * 2^{-t} * l)
# 	i : 1, j : 2, k : 0, a : (1), b : (2^{-t}, l), c : ()
# 314	instantiation	334, 335, 430, 336, 337, 338, 339	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (1 * 2^{-t} * l) = (2^{-t} * l)
# 	i : 0, j : 2, a : (), b : (2^{-t}, l)
# 315	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 316	instantiation	391, 377	|- ((1 * 2) / 1) = (2 / 1)
# 	f(_a) : _a / 1, x : 1 * 2, y : 2
# 317	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 318	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 319	instantiation	397, 340	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(2^{-t} * l)) in Real
# 	a : 2^{-t} * l
# 320	instantiation	341, 342	{b in {b_{f}, b_{r}}} |- delta_{b} in Real
# 	b : b
# 321	instantiation	428, 419, 343	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 322	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 323	instantiation	344, 364, 345, 346	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 1, c : 2, e : 1
# 324	instantiation	378, 347, 348	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 2) * 2)
# 	x : (1 / (1 * 2)) * ((2 * 1) / 1), y : (1 / 2) * ((2 * 1) / 1), z : (1 / 2) * 2
# 325	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 326	instantiation	391, 349	|- ((1 / 1) * (1 / 1)) = (1 * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : 1 / 1, y : 1
# 327	instantiation	391, 349	|- (1 * (1 / 1)) = (1 * 1)
# 	f(_a) : 1 * _a, x : 1 / 1, y : 1
# 328	instantiation	403, 364	|- (1 * 1) = 1
# 	x : 1
# 329	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 330	instantiation	350, 364, 351	|- (1 - 1) = 0
# 	a : 1, b : 1
# 331	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 	proveit.numbers.exponentiation.exp_zero_eq_one
# 332	instantiation	428, 412, 352	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 333	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 334	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 1* b_{1} *  b_{2} *  ... *  b_{j}) = (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}))]
# 	proveit.numbers.multiplication.elim_one_any
# 335	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 336	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 337	instantiation	386	|- |(2^{-t}, l)| = |(1, ..., 2)|
# 	a : 2^{-t}, b : l
# 338	instantiation	428, 412, 354	|- 2^{-t} in Complex
# 	A : Real, B : Complex, x : 2^{-t}
# 339	instantiation	428, 412, 355	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Complex
# 	A : Real, B : Complex, x : l
# 340	instantiation	353, 354, 355	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (2^{-t} * l) in Real
# 	a : 2^{-t}, b : l
# 341	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 342	instantiation	356, 357	{b in {b_{f}, b_{r}}} |- b in Integer
# 	b : b
# 343	instantiation	428, 424, 358	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 344	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 345	instantiation	428, 360, 359	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 346	instantiation	428, 360, 361	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 347	instantiation	391, 362	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 2) * ((2 * 1) / 1))
# 	f(_a) : _a * ((2 * 1) / 1), x : 1 / (1 * 2), y : 1 / 2
# 348	instantiation	391, 363	|- ((1 / 2) * ((2 * 1) / 1)) = ((1 / 2) * 2)
# 	f(_a) : (1 / 2) * _a, x : (2 * 1) / 1, y : 2
# 349	instantiation	393, 364	|- (1 / 1) = 1
# 	x : 1
# 350	conjecture		|- forall_{a, b in Complex | a = b} ((a - b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_basic
# 351	instantiation	365	|- 1 = 1
# 	x : 1
# 352	instantiation	428, 367, 366	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 353	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 354	instantiation	428, 367, 368	|- 2^{-t} in Real
# 	A : RealPos, B : Real, x : 2^{-t}
# 355	instantiation	428, 419, 369	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 356	instantiation	370, 430, 371, 372, 373	|- forall_{b in {b_{f}, b_{r}}} (b in Integer)
# 	n : 2, (a_{1}, ..., a_{2}) : (b_{f}, b_{r}), P(b) : b in Integer, x : b
# 357	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 358	instantiation	421, 418	|- (-1) in Integer
# 	a : 1
# 359	instantiation	428, 375, 374	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 360	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 361	instantiation	428, 375, 376	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 362	instantiation	391, 377	|- (1 / (1 * 2)) = (1 / 2)
# 	f(_a) : 1 / _a, x : 1 * 2, y : 2
# 363	instantiation	378, 379, 380	|- ((2 * 1) / 1) = 2
# 	x : (2 * 1) / 1, y : 2 / 1, z : 2
# 364	instantiation	428, 412, 381	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 365	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 366	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 367	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 368	instantiation	382, 383, 384	|- 2^{-t} in RealPos
# 	a : 2, b : -t
# 369	instantiation	428, 424, 385	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 370	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P | P(a_{1}), P(a_{2}), ..., P(a_{n})} [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]]]
# 	proveit.logic.sets.enumeration.true_for_each_then_true_for_all
# 371	instantiation	386	|- |(b_{f}, b_{r})| = |(1, ..., 2)|
# 	a : b_{f}, b : b_{r}
# 372	conjecture		|- b_{f} in Integer
# 	proveit.physics.quantum.QPE._best_floor_is_int
# 373	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
# 374	instantiation	428, 388, 387	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 375	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 376	instantiation	428, 388, 389	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 377	instantiation	390, 404	|- (1 * 2) = 2
# 	x : 2
# 378	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 379	instantiation	391, 392	|- ((2 * 1) / 1) = (2 / 1)
# 	f(_a) : _a / 1, x : 2 * 1, y : 2
# 380	instantiation	393, 404	|- (2 / 1) = 2
# 	x : 2
# 381	instantiation	428, 419, 394	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 382	conjecture		|- forall_{a in RealPos, b in Real} (a^{b} in RealPos)
# 	proveit.numbers.exponentiation.exp_real_pos_closure
# 383	instantiation	428, 395, 396	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 384	instantiation	397, 398	|- (-t) in Real
# 	a : t
# 385	instantiation	428, 399, 400	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 386	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 387	instantiation	428, 402, 401	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 388	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 389	instantiation	428, 402, 406	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 390	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 391	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 392	instantiation	403, 404	|- (2 * 1) = 2
# 	x : 2
# 393	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 394	instantiation	428, 424, 418	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 395	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 396	instantiation	428, 405, 406	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 397	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 398	instantiation	407, 408, 409	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 399	instantiation	410, 411, 422	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 400	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 401	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 402	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 403	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 404	instantiation	428, 412, 413	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 405	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 406	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 407	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 408	instantiation	414, 415	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 409	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 410	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 411	instantiation	416, 417, 418	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 412	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 413	instantiation	428, 419, 420	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 414	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 415	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 416	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 417	instantiation	421, 422	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 418	instantiation	428, 429, 423	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 419	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 420	instantiation	428, 424, 425	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 421	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 422	instantiation	428, 426, 427	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 423	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 424	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 425	instantiation	428, 429, 430	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 426	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 427	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 428	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 429	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 430	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
