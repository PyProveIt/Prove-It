# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_abs_delta_b_floor_diff_interval">_scaled_abs_delta_b_floor_diff_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, defaults
from proveit.logic import NotEquals
from proveit.numbers import zero, one, two, pi, Abs, frac, Neg
from proveit.physics.quantum.QPE import (
        _b_floor, _delta_b_floor_diff_in_interval,
        _delta_b_not_eq_scaledNonzeroInt, _two_pow_t_minus_one_is_nat_pos)

# %%
# %proving _scaled_abs_delta_b_floor_diff_interval
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_abs_delta_b_floor_diff_interval">_scaled_abs_delta_b_floor_diff_interval:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/4317879975eb36cf6de283bedff1fdcc5132a3b80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/61ad1d5541ccb1a1c83bc906a637218e0e19f3970/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _scaled_abs_delta_b_floor_diff_interval.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e291f82fba5781cb778dc66b129aea3d3d4197760/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
defaults.assumptions[0].derive_element_in_integer()
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer

# %%
_delta_b_floor_diff_in_interval
# Out:
# |- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2))

# %%
_delta_b_floor_diff_in_interval_inst = _delta_b_floor_diff_in_interval.instantiate()
# Out:
# <strong id="_delta_b_floor_diff_in_interval_inst">_delta_b_floor_diff_in_interval_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_floor_diff_interval/81be729b161023e9c9f09466783badbbc6d1bd340/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/dd0a85742edfffe040e7a0ac89be733fdb9f61ec0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
delta_diff = _delta_b_floor_diff_in_interval_inst.element
# Out:
# <strong id="delta_diff">delta_diff:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2228158b78aa92fcfb8b2e84364951b48aac82970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_floor_diff_in_interval_inst.domain.deduce_relaxed_membership(delta_diff)
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2]

# %%
# for convenience, label the abs value component
abs_val_delta_diff = Abs(delta_diff)
# Out:
# <strong id="abs_val_delta_diff">abs_val_delta_diff:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/831c4d5a8674ac1589f87cc2751d3031b5ab0fd80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
abs_val_leq_one_half = abs_val_delta_diff.deduce_weak_upper_bound(frac(one, two))
# Out:
# <strong id="abs_val_leq_one_half">abs_val_leq_one_half:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_floor_diff_interval/e49755b319fdd6dd68937e6515aedc4a036d3b200/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_floor_diff_interval/50812fc82ae59d56f8231d23ae0ed37f69f30c8a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
upper_bound = (
        abs_val_leq_one_half.left_mult_both_sides(pi).
        inner_expr().rhs.distribute())
# Out:
# <strong id="upper_bound">upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_floor_diff_interval/550cf007f0ec1b431e0e008f2c36d166b1c259f90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_floor_diff_interval/a7454da7131626913405d080137f1715188f98970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_delta_b_not_eq_scaledNonzeroInt.instantiate({b: _b_floor})
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- delta_{b_{f}} != (l / 2^{t})

# %%
NotEquals(delta_diff, zero).prove()
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b_{f}} - (l / 2^{t})) != 0
# _scaled_abs_delta_b_floor_diff_interval may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
abs_val_delta_diff.deduce_positive().left_mult_both_sides(pi)
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta_{b_{f}} - (l / 2^{t})|) > 0

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_abs_delta_b_floor_diff_interval has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2])
# 1	instantiation	2, 11, 3, 4, 5	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta_{b_{f}} - (l / 2^{t})|) in (0,pi / 2]
# 	a : 0, b : pi / 2, x : pi * |delta_{b_{f}} - (l / 2^{t})|
# 2	conjecture		|- forall_{a, b, x in Real | a < x <= b} (x in (a,b])
# 	proveit.numbers.number_sets.real_numbers.in_IntervalOC
# 3	instantiation	73, 48, 75, 76	|- (pi / 2) in Real
# 	a : pi, b : 2
# 4	instantiation	6, 48, 20	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta_{b_{f}} - (l / 2^{t})|) in Real
# 	a : pi, b : |delta_{b_{f}} - (l / 2^{t})|
# 5	instantiation	7, 8, 9	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (0 < (pi * |delta_{b_{f}} - (l / 2^{t})|)) and ((pi * |delta_{b_{f}} - (l / 2^{t})|) <= (pi / 2))
# 	A : 0 < (pi * |delta_{b_{f}} - (l / 2^{t})|), B : (pi * |delta_{b_{f}} - (l / 2^{t})|) <= (pi / 2)
# 6	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 7	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 8	instantiation	10, 48, 11, 20, 12, 35, 13*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- 0 < (pi * |delta_{b_{f}} - (l / 2^{t})|)
# 	a : pi, x : 0, y : |delta_{b_{f}} - (l / 2^{t})|
# 9	instantiation	14, 15, 16	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta_{b_{f}} - (l / 2^{t})|) <= (pi / 2)
# 	P(_a) : (pi * |delta_{b_{f}} - (l / 2^{t})|) <= _a, x : (1 / 2) * pi, y : pi / 2
# 10	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 11	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 12	instantiation	47, 17	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- |delta_{b_{f}} - (l / 2^{t})| > 0
# 	x : |delta_{b_{f}} - (l / 2^{t})|
# 13	instantiation	18, 39	|- (pi * 0) = 0
# 	x : pi
# 14	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 15	instantiation	19, 48, 20, 68, 21, 22, 23*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta_{b_{f}} - (l / 2^{t})|) <= ((1 / 2) * pi)
# 	a : pi, x : |delta_{b_{f}} - (l / 2^{t})|, y : 1 / 2
# 16	instantiation	24, 25, 39, 26, 76, 27*	|- ((1 / 2) * pi) = (pi / 2)
# 	x : 1, y : pi, z : 2
# 17	instantiation	28, 29	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- |delta_{b_{f}} - (l / 2^{t})| in RealPos
# 	a : delta_{b_{f}} - (l / 2^{t})
# 18	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 19	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 20	instantiation	92, 30, 31	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta_{b_{f}} - (l / 2^{t})| in Real
# 	A : RealNonNeg, B : Real, x : |delta_{b_{f}} - (l / 2^{t})|
# 21	instantiation	32, 33, 34	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta_{b_{f}} - (l / 2^{t})| <= (1 / 2)
# 	a : delta_{b_{f}} - (l / 2^{t}), c : 1 / 2
# 22	instantiation	45, 35	|- 0 <= pi
# 	x : 0, y : pi
# 23	instantiation	36, 39, 37	|- (pi * (1 / 2)) = ((1 / 2) * pi)
# 	a : pi, b : 1 / 2
# 24	conjecture		|- forall_{x, y, z in Complex | z != 0} (((x / z) * y) = ((x * y) / z))
# 	proveit.numbers.division.mult_frac_left
# 25	instantiation	92, 51, 74	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 26	instantiation	92, 51, 75	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 27	instantiation	38, 39	|- (1 * pi) = pi
# 	x : pi
# 28	conjecture		|- forall_{a in ComplexNonZero} (|a| in RealPos)
# 	proveit.numbers.absolute_value.abs_nonzero_closure
# 29	instantiation	40, 43, 41	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b_{f}} - (l / 2^{t})) in ComplexNonZero
# 	x : delta_{b_{f}} - (l / 2^{t})
# 30	conjecture		|- RealNonNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_nonneg_within_real
# 31	instantiation	42, 43	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta_{b_{f}} - (l / 2^{t})| in RealNonNeg
# 	a : delta_{b_{f}} - (l / 2^{t})
# 32	conjecture		|- forall_{a, c | (-c) <= a, a <= c} (|a| <= c)
# 	proveit.numbers.absolute_value.weak_upper_bound
# 33	instantiation	44, 61, 68, 62	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(1 / 2)) <= (delta_{b_{f}} - (l / 2^{t}))
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b_{f}} - (l / 2^{t})
# 34	instantiation	45, 46	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) <= (1 / 2)
# 	x : delta_{b_{f}} - (l / 2^{t}), y : 1 / 2
# 35	instantiation	47, 55	|- pi > 0
# 	x : pi
# 36	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 37	instantiation	92, 51, 68	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 38	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 39	instantiation	92, 51, 48	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 40	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 	proveit.numbers.number_sets.complex_numbers.nonzero_complex_is_complex_nonzero
# 41	instantiation	49, 50	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b_{f}} - (l / 2^{t})) != 0
# 	a : delta_{b_{f}}, b : l / 2^{t}
# 42	conjecture		|- forall_{a in Complex} (|a| in RealNonNeg)
# 	proveit.numbers.absolute_value.abs_complex_closure
# 43	instantiation	92, 51, 52	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in Complex
# 	A : Real, B : Complex, x : delta_{b_{f}} - (l / 2^{t})
# 44	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 45	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 46	instantiation	53, 61, 68, 62	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) < (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b_{f}} - (l / 2^{t})
# 47	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 48	instantiation	92, 54, 55	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 49	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 50	instantiation	56, 57, 58, 59	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- delta_{b_{f}} != (l / 2^{t})
# 	b : b_{f}, l : l
# 51	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 52	instantiation	60, 61, 68, 62	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in Real
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b_{f}} - (l / 2^{t})
# 53	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 54	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 55	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 56	conjecture		|- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} (delta_{b} != (l / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_b_not_eq_scaledNonzeroInt
# 57	instantiation	63, 64, 91, 65	|- b_{f} in {b_{f}, b_{r}}
# 	m : 0, n : 1, a : (), b : b_{f}, c : (b_{r})
# 58	instantiation	92, 66, 70	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 59	assumption		{l != 0} |- l != 0
# 60	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 61	instantiation	67, 68	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 62	instantiation	69, 70	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2)
# 	l : l
# 63	conjecture		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} (b in {a_{1}, a_{2}, ..., a_{m}, b,c_{1}, c_{2}, ..., c_{n}})]
# 	proveit.logic.sets.enumeration.in_enumerated_set
# 64	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 65	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 66	instantiation	71, 72, 85	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 67	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 68	instantiation	73, 74, 75, 76	|- (1 / 2) in Real
# 	a : 1, b : 2
# 69	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((delta_{b_{f}} - (l / 2^{t})) in [-(1 / 2),1 / 2))
# 	proveit.physics.quantum.QPE._delta_b_floor_diff_in_interval
# 70	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 71	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 72	instantiation	77, 78, 86	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 73	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 74	instantiation	92, 80, 79	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 75	instantiation	92, 80, 81	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 76	instantiation	82, 83	|- 2 != 0
# 	n : 2
# 77	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 78	instantiation	84, 85	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 79	instantiation	92, 87, 86	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 80	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 81	instantiation	92, 87, 88	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 82	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 83	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 84	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 85	instantiation	92, 89, 90	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 86	instantiation	92, 93, 91	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 87	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 88	instantiation	92, 93, 94	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 89	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 90	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 91	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 92	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 93	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 94	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
