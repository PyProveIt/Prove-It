# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_phase_is_real">_phase_is_real</a> theorem
# ========

# %%
import proveit
from proveit.physics.quantum.QPE import _phase_in_interval
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _phase_is_real
# Out:
# _phase_is_real has been proven.  Now simply execute "%qed".
# _phase_is_real: phase in Real

# %%
# axiomatically:
_phase_in_interval
# Out:
# |- phase in [0,1)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3, 4	|- phase in Real
# 	a : 0, b : 1, x : phase
# 1	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 2	instantiation	5, 6, 7	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 3	instantiation	8, 9, 10	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 4	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 5	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 6	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 7	conjecture		|- 0 in Rational
# 	proveit.numbers.number_sets.rational_numbers.zero_is_rational
# 8	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 9	instantiation	11, 12	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 10	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 11	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 12	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
