# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_fail_sum_prob_conds_equiv_lemma">_fail_sum_prob_conds_equiv_lemma</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, e, l, x, y, defaults
from proveit.logic import Iff, InSet, Or, SubsetEq, Union
from proveit.numbers import zero, Add, subtract, greater_eq, Less, Neg, NaturalPos
from proveit.numbers.ordering import less_or_greater_eq
from proveit.physics.quantum.QPE import (
    _full_domain, _modabs_in_full_domain_simp, _neg_domain, _pos_domain)
from proveit.physics.quantum.QPE import (
    _two_pow_t, _two_pow_t__minus_one, _t_in_natural_pos, _two_pow_t_minus_one_is_nat_pos)

# %%
# %proving _fail_sum_prob_conds_equiv_lemma
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_fail_sum_prob_conds_equiv_lemma">_fail_sum_prob_conds_equiv_lemma:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a9f52a1a7200300f91e40b642d5258aa1eee8ab20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/51fd333c7283b5fe748115ec160fae5d2869f4760/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _fail_sum_prob_conds_equiv_lemma.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__fail_sum_prob_conds_equiv_lemma/d6451ebca630c456e1c1f2777c5439c1c43bd4fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# We want to derive the logical equivalence (if and only if) between the following conditions:

# %%
lhs_condition = _fail_sum_prob_conds_equiv_lemma.instance_expr.instance_expr.lhs
# Out:
# <strong id="lhs_condition">lhs_condition:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d570945498fa4a79f144d2199fe08adc64fd082b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
rhs_condition = _fail_sum_prob_conds_equiv_lemma.instance_expr.instance_expr.rhs
# Out:
# <strong id="rhs_condition">rhs_condition:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2ebfd21fc3cc86d291f74b933bbd5e76277d27730/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# (1) $\text{lhs} \Rightarrow \text{rhs}$. This direction is straightforward using the fact that $\{-2^{t-1}+1~\ldotp \ldotp~-(e+1)\} \cup \{e + 1~\ldotp \ldotp~2^{t-1}\} \subseteq \{-2^{t-1}+1~\ldotp \ldotp~2^{t-2}\}$.

# %%
SubsetEq(Union(_neg_domain, _pos_domain), _full_domain).prove()
# Out:
# Expression notebook is being updated for |({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})|
# Expression notebook is being updated for (|({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})|, |(1, ..., 2)|)
# Expression notebook is being updated for |({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})| = |(1, ..., 2)|
# Expression notebook is being updated for ({1 .. 2^{t - 1} - 2}, Integer)
# Expression notebook is being updated for {1 .. 2^{t - 1} - 2} proper_subset Integer
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. -(e + 1)}, {-2^{t - 1} + 1 .. 2^{t - 1}})
# Expression notebook is being updated for {-2^{t - 1} + 1 .. -(e + 1)} subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# Expression notebook is being updated for ({e + 1 .. 2^{t - 1}}, {-2^{t - 1} + 1 .. 2^{t - 1}})
# Expression notebook is being updated for {e + 1 .. 2^{t - 1}} subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}, {-2^{t - 1} + 1 .. 2^{t - 1}})
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}) subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# {e in {1 .. 2^{t - 1} - 2}} |- ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}) subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}

# %%
rhs_condition.prove(assumptions=defaults.assumptions + (lhs_condition,))
# Out:
# {e in {1 .. 2^{t - 1} - 2}, (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)

# %% [markdown]
# (2) $\text{lhs} \Leftarrow \text{rhs}$.
#
# Going from rhs to lhs requires us to consider the non-negative/negative cases separately.

# %% [markdown]
# 2(a): $\text{lhs} \Leftarrow \text{rhs}$. The NON-NEGATIVE case.

# %%
# update our default assumptions
defaults.assumptions = _fail_sum_prob_conds_equiv_lemma.all_conditions() + [rhs_condition, greater_eq(l, zero)]
# Out:
# Expression notebook is being updated for (e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0)
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__fail_sum_prob_conds_equiv_lemma/937b2a38597734b173b1cc47d2fbbceb2530388f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_modabs_in_full_domain_simp
# Out:
# |- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} (|l|_{mod 2^{t}} = |l|)

# %%
_modabs_in_full_domain_simp.instantiate().sub_right_side_into(rhs_condition.operands[1])
# Out:
# {(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- l > e

# %%
InSet(subtract(l, e), NaturalPos).prove()
# Out:
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. 2^{t - 1}}, Integer)
# Expression notebook is being updated for {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# {(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l >= 0} |- (l - e) in NaturalPos

# %%
lhs_condition.prove()
# Out:
# Expression notebook is being updated for (l, {-2^{t - 1} + 1 .. -(e + 1)})
# Expression notebook is being updated for l not-in {-2^{t - 1} + 1 .. -(e + 1)}
# Expression notebook is being updated for l in {-2^{t - 1} + 1 .. -(e + 1)}
# Expression notebook is being updated for (l in {-2^{t - 1} + 1 .. -(e + 1)})
# Expression notebook is being updated for [not](l in {-2^{t - 1} + 1 .. -(e + 1)})
# Expression notebook is being updated for (l, {e + 1 .. 2^{t - 1}})
# Expression notebook is being updated for l in {e + 1 .. 2^{t - 1}}
# Expression notebook is being updated for (l in {-2^{t - 1} + 1 .. -(e + 1)}, l in {e + 1 .. 2^{t - 1}})
# Expression notebook is being updated for (l in {-2^{t - 1} + 1 .. -(e + 1)}) or (l in {e + 1 .. 2^{t - 1}})
# {e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)

# %% [markdown]
# 2(b): $\text{lhs} \Leftarrow \text{rhs}$. The NEGATIVE case.

# %%
# update our default assumptions
defaults.assumptions = _fail_sum_prob_conds_equiv_lemma.all_conditions() + [rhs_condition, Less(l, zero)]
# Out:
# Expression notebook is being updated for (e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0)
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__fail_sum_prob_conds_equiv_lemma/30eed34d4a9410e4a2c6348bb87d8aa196db41f40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_modabs_in_full_domain_simp.instantiate().sub_right_side_into(rhs_condition.operands[1])
# Out:
# {(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-l) > e

# %%
InSet(Neg(Add(e, l)), NaturalPos).prove()
# Out:
# {e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-(e + l)) in NaturalPos

# %%
lhs_condition.prove()
# Out:
# Expression notebook is being updated for l not-in {e + 1 .. 2^{t - 1}}
# Expression notebook is being updated for (l in {e + 1 .. 2^{t - 1}})
# Expression notebook is being updated for [not](l in {e + 1 .. 2^{t - 1}})
# {e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)

# %% [markdown]
# Since either $l \geq 0$ or $l < 0$ but we can derive `lhs_condition` either way, then `lhs_condition` must be true (under these assumptions).

# %%
# update our default assumptions (removing the specifics about ell being negative or non-negative)
defaults.assumptions = _fail_sum_prob_conds_equiv_lemma.all_conditions() + [rhs_condition]
# Out:
# Expression notebook is being updated for (e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__fail_sum_prob_conds_equiv_lemma/28966db720fe398cb2040ce21ee4e3734de4c3890/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
less_or_greater_eq
# Out:
# |- forall_{x, y in Real} ((x < y) or (x >= y))

# %%
less_or_greater_eq.instantiate({x:l, y:zero})
# Out:
# {(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l < 0) or (l >= 0)

# %%
Or(Less(l, zero), greater_eq(l, zero)).derive_via_dilemma(lhs_condition)
# Out:
# Expression notebook is being updated for (l < 0, (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for (l < 0) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for (l >= 0, (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for (l >= 0) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# {(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# _fail_sum_prob_conds_equiv_lemma may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._fail_sum_prob_conds_equiv_lemma has been proven.
# Expression notebook is being updated for ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) => ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# Expression notebook is being updated for ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l} [forall_{e in {1 .. 2^{t - 1} - 2}} (((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) \\  <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)))]
# 1	instantiation	2, 3, 4	{e in {1 .. 2^{t - 1} - 2}} |- ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) <=> ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
# 	A : (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e), B : (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
# 2	theorem		|- forall_{A, B | A => B, B => A} (A <=> B)
# 	proveit.logic.booleans.implication.iff_intro
# 3	deduction	5	{e in {1 .. 2^{t - 1} - 2}} |- ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)) => ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e))
# 4	deduction	6	{e in {1 .. 2^{t - 1} - 2}} |- ((l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# 5	instantiation	85, 7, 8	{e in {1 .. 2^{t - 1} - 2}, (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : |l|_{mod 2^{t}} > e
# 6	instantiation	9, 10, 11, 26, 12, 13	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# 	A : l < 0, B : l >= 0, C : (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# 7	instantiation	360, 14, 15	{e in {1 .. 2^{t - 1} - 2}, (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	A : {-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}, B : {-2^{t - 1} + 1 .. 2^{t - 1}}, x : l
# 8	instantiation	278, 24	{(l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- |l|_{mod 2^{t}} > e
# 	A : l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), B : |l|_{mod 2^{t}} > e
# 9	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 10	instantiation	16, 18	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l < 0) in BOOLEAN
# 	A : l < 0, B : l >= 0
# 11	instantiation	17, 18	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l >= 0) in BOOLEAN
# 	A : l < 0, B : l >= 0
# 12	deduction	19	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l < 0) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# 13	deduction	20	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l >= 0) => ((l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e))
# 14	instantiation	21, 389, 35, 22, 23	{e in {1 .. 2^{t - 1} - 2}} |- ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}) subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	m : 2, A : ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}}), S : {-2^{t - 1} + 1 .. 2^{t - 1}}
# 15	instantiation	373, 24	{(l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
# 	A : l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), B : |l|_{mod 2^{t}} > e
# 16	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 17	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 18	instantiation	25, 26	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- ((l < 0) or (l >= 0)) in BOOLEAN
# 	A : (l < 0) or (l >= 0)
# 19	instantiation	85, 27, 253	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# 	A : l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), B : |l|_{mod 2^{t}} > e
# 20	instantiation	85, 28, 253	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# 	A : l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}}), B : |l|_{mod 2^{t}} > e
# 21	conjecture		|- forall_{m in NaturalPos} [forall_{A_{1}, A_{2}, ..., A_{m}, S | (A_{1} subset_eq S), (A_{2} subset_eq S), ..., (A_{m} subset_eq S)} ((A_{1} union  A_{2} union  ... union  A_{m}) subset_eq S)]
# 	proveit.logic.sets.unification.union_inclusion
# 22	instantiation	30, 372, 83, 399, 29	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : -2^{t - 1} + 1, c : -(e + 1), d : 2^{t - 1}
# 23	instantiation	30, 372, 113, 399, 31	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} subset_eq {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : e + 1, c : 2^{t - 1}, d : 2^{t - 1}
# 24	assumption		{(l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)} |- (l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})) and (|l|_{mod 2^{t}} > e)
# 25	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 26	instantiation	32, 323, 131	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l < 0) or (l >= 0)
# 	x : l, y : 0
# 27	instantiation	34, 389, 35, 33	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
# 	m : 2, x : l, A : ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})
# 28	instantiation	34, 389, 35, 36	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- l in ({-2^{t - 1} + 1 .. -(e + 1)} union {e + 1 .. 2^{t - 1}})
# 	m : 2, x : l, A : ({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})
# 29	instantiation	40, 314, 37, 38, 52, 39	{e in {1 .. 2^{t - 1} - 2}} |- ((-2^{t - 1} + 1) <= (-2^{t - 1} + 1)) and ((-2^{t - 1} + 1) <= (-(e + 1))) and ((-(e + 1)) <= 2^{t - 1})
# 	m : 3, A : ((-2^{t - 1} + 1) <= (-2^{t - 1} + 1), (-2^{t - 1} + 1) <= (-(e + 1)), (-(e + 1)) <= 2^{t - 1})
# 30	conjecture		|- forall_{a, b, c, d in Integer | a <= b <= c <= d} ({b .. c} subset_eq {a .. d})
# 	proveit.numbers.number_sets.integers.interval_subset_eq
# 31	instantiation	40, 314, 41, 42, 43, 44	{e in {1 .. 2^{t - 1} - 2}} |- ((-2^{t - 1} + 1) <= (e + 1)) and ((e + 1) <= 2^{t - 1}) and (2^{t - 1} <= 2^{t - 1})
# 	m : 3, A : ((-2^{t - 1} + 1) <= (e + 1), (e + 1) <= 2^{t - 1}, 2^{t - 1} <= 2^{t - 1})
# 32	conjecture		|- forall_{x, y in Real} ((x < y) or (x >= y))
# 	proveit.numbers.ordering.less_or_greater_eq
# 33	instantiation	110, 45, 46	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (l in {-2^{t - 1} + 1 .. -(e + 1)}) or (l in {e + 1 .. 2^{t - 1}})
# 	A : l in {-2^{t - 1} + 1 .. -(e + 1)}, B : l in {e + 1 .. 2^{t - 1}}
# 34	conjecture		|- forall_{m in NaturalPos} [forall_{x, A_{1}, A_{2}, ..., A_{m} | (x in A_{1}) or  (x in A_{2}) or  ... or  (x in A_{m})} (x in (A_{1} union  A_{2} union  ... union  A_{m}))]
# 	proveit.logic.sets.unification.membership_folding
# 35	instantiation	318	|- |({-2^{t - 1} + 1 .. -(e + 1)}, {e + 1 .. 2^{t - 1}})| = |(1, ..., 2)|
# 	a : {-2^{t - 1} + 1 .. -(e + 1)}, b : {e + 1 .. 2^{t - 1}}
# 36	instantiation	114, 47, 48	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- (l in {-2^{t - 1} + 1 .. -(e + 1)}) or (l in {e + 1 .. 2^{t - 1}})
# 	A : l in {-2^{t - 1} + 1 .. -(e + 1)}, B : l in {e + 1 .. 2^{t - 1}}
# 37	instantiation	330	|- |((-2^{t - 1} + 1) <= (-2^{t - 1} + 1), (-2^{t - 1} + 1) <= (-(e + 1)), (-(e + 1)) <= 2^{t - 1})| = |(1, 2, ..., 3)|
# 	a : (-2^{t - 1} + 1) <= (-2^{t - 1} + 1), b : (-2^{t - 1} + 1) <= (-(e + 1)), c : (-(e + 1)) <= 2^{t - 1}
# 38	instantiation	57, 153, 49	|- (-2^{t - 1} + 1) <= (-2^{t - 1} + 1)
# 	x : -2^{t - 1} + 1, y : -2^{t - 1} + 1
# 39	instantiation	320, 50	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) <= 2^{t - 1}
# 	x : -(e + 1), y : 2^{t - 1}
# 40	conjecture		|- forall_{m in Natural} [forall_{A_{1}, A_{2}, ..., A_{m} | A_{1}, A_{2}, ..., A_{m}} (A_{1} and  A_{2} and  ... and  A_{m})]
# 	proveit.logic.booleans.conjunction.and_if_all
# 41	instantiation	330	|- |((-2^{t - 1} + 1) <= (e + 1), (e + 1) <= 2^{t - 1}, 2^{t - 1} <= 2^{t - 1})| = |(1, 2, ..., 3)|
# 	a : (-2^{t - 1} + 1) <= (e + 1), b : (e + 1) <= 2^{t - 1}, c : 2^{t - 1} <= 2^{t - 1}
# 42	instantiation	51, 52, 53	{e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) <= (e + 1)
# 	x : -2^{t - 1} + 1, y : -(e + 1), z : e + 1
# 43	instantiation	130, 379, 346, 54, 55, 56*	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) <= 2^{t - 1}
# 	a : 1, x : e, y : (2^{t - 1} - 2) + 1
# 44	instantiation	57, 150, 58	|- 2^{t - 1} <= 2^{t - 1}
# 	x : 2^{t - 1}, y : 2^{t - 1}
# 45	instantiation	63, 372, 83, 347, 59	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- l in {-2^{t - 1} + 1 .. -(e + 1)}
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : l
# 46	instantiation	61, 60	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- [not](l in {e + 1 .. 2^{t - 1}})
# 	x : l, S : {e + 1 .. 2^{t - 1}}
# 47	instantiation	61, 62	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- [not](l in {-2^{t - 1} + 1 .. -(e + 1)})
# 	x : l, S : {-2^{t - 1} + 1 .. -(e + 1)}
# 48	instantiation	63, 113, 399, 347, 64	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- l in {e + 1 .. 2^{t - 1}}
# 	a : e + 1, b : 2^{t - 1}, n : l
# 49	instantiation	298	|- (-2^{t - 1} + 1) = (-2^{t - 1} + 1)
# 	x : -2^{t - 1} + 1
# 50	instantiation	148, 155, 65	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) < 2^{t - 1}
# 	x : -(e + 1), y : 0, z : 2^{t - 1}
# 51	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 52	instantiation	130, 66, 346, 75, 76, 67*, 68*	{e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) <= (-(e + 1))
# 	a : -2^{t - 1} + 1 - e, x : e, y : 2^{t - 1} - 2
# 53	instantiation	130, 169, 69, 70, 71, 72*, 73*	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) <= (e + 1)
# 	a : -e - 1, x : 2 * 0, y : (2 * e) + 2
# 54	instantiation	322, 75, 379	|- ((2^{t - 1} - 2) + 1) in Real
# 	a : 2^{t - 1} - 2, b : 1
# 55	instantiation	74, 346, 75, 379, 76, 77	{e in {1 .. 2^{t - 1} - 2}} |- e <= ((2^{t - 1} - 2) + 1)
# 	a : e, b : 2^{t - 1} - 2, c : 1
# 56	instantiation	309, 78, 270, 79	|- (((2^{t - 1} - 2) + 1) + 1) = 2^{t - 1}
# 	a : ((2^{t - 1} - 2) + 1) + 1, b : (1 / 2^{1}) * 2^{t}, c : (1 / 2^{1}) * 2^{t}, d : 2^{t - 1}
# 57	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 58	instantiation	298	|- 2^{t - 1} = 2^{t - 1}
# 	x : 2^{t - 1}
# 59	instantiation	85, 154, 80	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l < 0} |- ((-2^{t - 1} + 1) <= l) and (l <= (-(e + 1)))
# 	A : (-2^{t - 1} + 1) <= l, B : l <= (-(e + 1))
# 60	instantiation	82, 113, 399, 347, 81	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- l not-in {e + 1 .. 2^{t - 1}}
# 	a : e + 1, b : 2^{t - 1}, x : l
# 61	theorem		|- forall_{x, S | x not-in S} [not](x in S)
# 	proveit.logic.sets.membership.unfold_not_in_set
# 62	instantiation	82, 372, 83, 347, 84	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- l not-in {-2^{t - 1} + 1 .. -(e + 1)}
# 	a : -2^{t - 1} + 1, b : -(e + 1), x : l
# 63	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 64	instantiation	85, 86, 151	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- ((e + 1) <= l) and (l <= 2^{t - 1})
# 	A : (e + 1) <= l, B : l <= 2^{t - 1}
# 65	instantiation	184, 404	|- 2^{t - 1} > 0
# 	n : 2^{t - 1}
# 66	instantiation	87, 314, 88, 89, 379, 201	{e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1 - e) in Real
# 	i : 3, a : (-2^{t - 1}, 1, -e)
# 67	instantiation	309, 90, 91, 92	{e in {1 .. 2^{t - 1} - 2}} |- (e + (-2^{t - 1} + 1 - e)) = (-2^{t - 1} + 1)
# 	a : e + (-2^{t - 1} + 1 - e), b : -((1 / 2^{1}) * 2^{t}) + 1, c : -((1 / 2^{1}) * 2^{t}) + 1, d : -2^{t - 1} + 1
# 68	instantiation	326, 93	{e in {1 .. 2^{t - 1} - 2}} |- ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)) = (-(e + 1))
# 	x : -(e + 1), y : (2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)
# 69	instantiation	94, 392, 131	|- (2 * 0) in Real
# 	a : 2, b : 0
# 70	instantiation	322, 202, 392	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) + 2) in Real
# 	a : 2 * e, b : 2
# 71	instantiation	95, 96, 247, 406, 97, 98	{e in {1 .. 2^{t - 1} - 2}} |- (2 * 0) <= ((2 * e) + 2)
# 	a : 2 * 0, b : 2 * e, c : 2
# 72	instantiation	326, 99	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * 0) + (-e - 1)) = (-(e + 1))
# 	x : -(e + 1), y : (2 * 0) + (-e - 1)
# 73	instantiation	309, 100, 101, 102	{e in {1 .. 2^{t - 1} - 2}} |- (((2 * e) + 2) + (-e - 1)) = (e + 1)
# 	a : ((2 * e) + 2) + (-e - 1), b : (2 * e) + 2 + (-e - 1), c : (2 * e) + 2 - e - 1, d : e + 1
# 74	conjecture		|- forall_{a, b, c in Real | a <= b, 0 <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_eq_add_right
# 75	instantiation	407, 396, 103	|- (2^{t - 1} - 2) in Real
# 	A : Rational, B : Real, x : 2^{t - 1} - 2
# 76	instantiation	185, 395, 394, 386	{e in {1 .. 2^{t - 1} - 2}} |- e <= (2^{t - 1} - 2)
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 77	instantiation	163, 401	|- 1 >= 0
# 	n : 1
# 78	instantiation	265, 104, 105	|- (((2^{t - 1} - 2) + 1) + 1) = ((1 / 2^{1}) * 2^{t})
# 	x : ((2^{t - 1} - 2) + 1) + 1, y : (((1 / 2^{1}) * 2^{t}) - 1) + 1, z : (1 / 2^{1}) * 2^{t}
# 79	instantiation	326, 292	|- ((1 / 2^{1}) * 2^{t}) = 2^{t - 1}
# 	x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 80	instantiation	130, 304, 379, 106, 107, 108*, 109*	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l < 0} |- l <= (-(e + 1))
# 	a : l - 1, x : 1, y : -(e + l)
# 81	instantiation	110, 111, 112	{l < 0, e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l < (e + 1)) or (2^{t - 1} < l)
# 	A : l < (e + 1), B : 2^{t - 1} < l
# 82	conjecture		|- forall_{a, b, x in Integer | (x < a) or (b < x)} (x not-in {a .. b})
# 	proveit.numbers.number_sets.integers.int_not_in_interval
# 83	instantiation	405, 113	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	a : e + 1
# 84	instantiation	114, 115, 116	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l >= 0} |- (l < (-2^{t - 1} + 1)) or ((-(e + 1)) < l)
# 	A : l < (-2^{t - 1} + 1), B : (-(e + 1)) < l
# 85	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 86	instantiation	130, 346, 379, 117, 118, 119*, 120*	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- (e + 1) <= l
# 	a : e, x : 1, y : l - e
# 87	conjecture		|- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i} in Real} ((a_{1} +  a_{2} +  ... +  a_{i}) in Real)]
# 	proveit.numbers.addition.add_real_closure
# 88	instantiation	330	|- |(-2^{t - 1}, 1, -e)| = |(1, 2, ..., 3)|
# 	a : -2^{t - 1}, b : 1, c : -e
# 89	instantiation	407, 396, 121	|- (-2^{t - 1}) in Real
# 	A : Rational, B : Real, x : -2^{t - 1}
# 90	instantiation	265, 122, 123	{e in {1 .. 2^{t - 1} - 2}} |- (e + (-2^{t - 1} + 1 - e)) = (-((1 / 2^{1}) * 2^{t}) + 1)
# 	x : e + (-2^{t - 1} + 1 - e), y : e + (-((1 / 2^{1}) * 2^{t}) + 1 - e), z : -((1 / 2^{1}) * 2^{t}) + 1
# 91	instantiation	298	|- (-((1 / 2^{1}) * 2^{t}) + 1) = (-((1 / 2^{1}) * 2^{t}) + 1)
# 	x : -((1 / 2^{1}) * 2^{t}) + 1
# 92	instantiation	326, 124	|- (-((1 / 2^{1}) * 2^{t}) + 1) = (-2^{t - 1} + 1)
# 	x : -2^{t - 1} + 1, y : -((1 / 2^{1}) * 2^{t}) + 1
# 93	instantiation	309, 181, 125, 126	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) = ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e))
# 	a : -(e + 1), b : -e - 1, c : -1 - e, d : (2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)
# 94	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 95	conjecture		|- forall_{a, b, c in Integer | a < b, (-1) <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_add_right_weak_int
# 96	instantiation	274, 406, 127	|- (2 * 0) in Integer
# 	a : 2, b : 0
# 97	instantiation	128, 392, 131, 346, 289, 129	{e in {1 .. 2^{t - 1} - 2}} |- (2 * 0) < (2 * e)
# 	a : 2, x : 0, y : e
# 98	instantiation	130, 339, 131, 198, 132, 133*, 134*	|- (-1) <= 2
# 	a : -1, x : 0, y : 3
# 99	instantiation	309, 181, 182, 135	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) = ((2 * 0) + (-e - 1))
# 	a : -(e + 1), b : -e - 1, c : -e - 1, d : (2 * 0) + (-e - 1)
# 100	instantiation	294, 295, 409, 401, 297, 137, 172, 382, 136	{e in {1 .. 2^{t - 1} - 2}} |- (((2 * e) + 2) + (-e - 1)) =  \\ ((2 * e) + 2 + (-e - 1))
# 	i : 0, j : 2, k : 1, a : (), b : (2 * e, 2), c : (-e - 1)
# 101	instantiation	294, 409, 295, 137, 246, 297, 172, 382, 317, 337	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) + 2 + (-e - 1)) =  \\ ((2 * e) + 2 - e - 1)
# 	i : 2, j : 2, k : 0, a : (2 * e, 2), b : (-e, -1), c : ()
# 102	instantiation	309, 138, 139, 140	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) + 2 - e - 1) = (e + 1)
# 	a : (2 * e) + 2 - e - 1, b : (2 * e) - e + 2 - 1, c : e + 2 - 1, d : e + 1
# 103	instantiation	407, 402, 394	|- (2^{t - 1} - 2) in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1} - 2
# 104	instantiation	328, 141	|- (((2^{t - 1} - 2) + 1) + 1) = ((((1 / 2^{1}) * 2^{t}) - 1) + 1)
# 	f(_a) : _a + 1, x : (2^{t - 1} - 2) + 1, y : ((1 / 2^{1}) * 2^{t}) - 1
# 105	instantiation	265, 142, 143	|- ((((1 / 2^{1}) * 2^{t}) - 1) + 1) = ((1 / 2^{1}) * 2^{t})
# 	x : (((1 / 2^{1}) * 2^{t}) - 1) + 1, y : ((1 / 2^{1}) * 2^{t}) - 1 + 1, z : (1 / 2^{1}) * 2^{t}
# 106	instantiation	360, 361, 144	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-(e + l)) in Real
# 	A : NaturalPos, B : Real, x : -(e + l)
# 107	instantiation	156, 144	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-(e + l)) >= 1
# 	n : -(e + l)
# 108	instantiation	265, 145, 146	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (1 + (l - 1)) = l
# 	x : 1 + (l - 1), y : 1 + l - 1, z : l
# 109	instantiation	326, 147	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-(e + l) + (l - 1)) = (-(e + 1))
# 	x : -(e + 1), y : -(e + l) + (l - 1)
# 110	theorem		|- forall_{A, B | A, [not](B)} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_left
# 111	instantiation	148, 321, 149	{l < 0, e in {1 .. 2^{t - 1} - 2}} |- l < (e + 1)
# 	x : l, y : 0, z : e + 1
# 112	instantiation	152, 323, 150, 151	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- [not](2^{t - 1} < l)
# 	x : l, y : 2^{t - 1}
# 113	instantiation	398, 371, 395	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 114	theorem		|- forall_{A, B | [not](A), B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_right
# 115	instantiation	152, 153, 323, 154	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- [not](l < (-2^{t - 1} + 1))
# 	x : -2^{t - 1} + 1, y : l
# 116	instantiation	306, 155, 291	{e in {1 .. 2^{t - 1} - 2}, l >= 0} |- (-(e + 1)) < l
# 	x : -(e + 1), y : 0, z : l
# 117	instantiation	322, 323, 201	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- (l - e) in Real
# 	a : l, b : -e
# 118	instantiation	156, 157	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l >= 0} |- (l - e) >= 1
# 	n : l - e
# 119	instantiation	335, 365, 332	{e in {1 .. 2^{t - 1} - 2}} |- (1 + e) = (e + 1)
# 	a : 1, b : e
# 120	instantiation	265, 158, 159	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- ((l - e) + e) = l
# 	x : (l - e) + e, y : l - e + e, z : l
# 121	instantiation	407, 402, 387	|- (-2^{t - 1}) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1}
# 122	instantiation	328, 236	|- (e + (-2^{t - 1} + 1 - e)) = (e + (-((1 / 2^{1}) * 2^{t}) + 1 - e))
# 	f(_a) : e + _a, x : -2^{t - 1} + 1 - e, y : -((1 / 2^{1}) * 2^{t}) + 1 - e
# 123	instantiation	265, 160, 161	{e in {1 .. 2^{t - 1} - 2}} |- (e + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) = (-((1 / 2^{1}) * 2^{t}) + 1)
# 	x : e + (-((1 / 2^{1}) * 2^{t}) + 1 - e), y : e - ((1 / 2^{1}) * 2^{t}) + 1 - e, z : -((1 / 2^{1}) * 2^{t}) + 1
# 124	instantiation	328, 264	|- (-2^{t - 1} + 1) = (-((1 / 2^{1}) * 2^{t}) + 1)
# 	f(_a) : _a + 1, x : -2^{t - 1}, y : -((1 / 2^{1}) * 2^{t})
# 125	instantiation	335, 317, 337	{e in {1 .. 2^{t - 1} - 2}} |- (-e - 1) = (-1 - e)
# 	a : -e, b : -1
# 126	instantiation	326, 162	{e in {1 .. 2^{t - 1} - 2}} |- (-1 - e) = ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e))
# 	x : (2^{t - 1} - 2) + (-2^{t - 1} + 1 - e), y : -1 - e
# 127	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 128	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 129	instantiation	184, 389	|- 2 > 0
# 	n : 2
# 130	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 131	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 132	instantiation	163, 314	|- 3 >= 0
# 	n : 3
# 133	instantiation	271, 164, 165	|- (0 - 1) = (-1)
# 	P(_a) : _a = (-1), x : -1 + 0, y : 0 - 1
# 134	instantiation	276, 382, 365, 166, 167	|- (3 - 1) = 2
# 	a : 2, b : 1, c : 3
# 135	instantiation	326, 168	{e in {1 .. 2^{t - 1} - 2}} |- (-e - 1) = ((2 * 0) + (-e - 1))
# 	x : (2 * 0) + (-e - 1), y : -e - 1
# 136	instantiation	407, 391, 169	{e in {1 .. 2^{t - 1} - 2}} |- (-e - 1) in Complex
# 	A : Real, B : Complex, x : -e - 1
# 137	instantiation	318	|- |(2 * e, 2)| = |(1, ..., 2)|
# 	a : 2 * e, b : 2
# 138	instantiation	170, 401, 172, 382, 317, 337	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) + 2 - e - 1) =  \\ ((2 * e) - e + 2 - 1)
# 	i : 1, j : 1, k : 1, a : (2 * e), b : (2), c : -e, d : (-1)
# 139	instantiation	239, 295, 409, 297, 171, 250, 172, 317, 382, 337, 173*	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) - e + 2 - 1) =  \\ (e + 2 - 1)
# 	i : 0, j : 2, k : 2, a : (), b : (2 * e, -e), c : (2, -1)
# 140	instantiation	239, 401, 409, 295, 250, 297, 332, 382, 337, 251*	{e in {1 .. 2^{t - 1} - 2}} |- (e + 2 - 1) =  \\ (e + 1)
# 	i : 1, j : 2, k : 0, a : (e), b : (2, -1), c : ()
# 141	instantiation	265, 174, 175	|- ((2^{t - 1} - 2) + 1) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	x : (2^{t - 1} - 2) + 1, y : (((1 / 2^{1}) * 2^{t}) - 2) + 1, z : ((1 / 2^{1}) * 2^{t}) - 1
# 142	instantiation	294, 295, 409, 401, 297, 176, 331, 337, 365	|- ((((1 / 2^{1}) * 2^{t}) - 1) + 1) =  \\ (((1 / 2^{1}) * 2^{t}) - 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : ((1 / 2^{1}) * 2^{t}, -1), c : (1)
# 143	instantiation	192, 365, 331, 180	|- (((1 / 2^{1}) * 2^{t}) - 1 + 1) = ((1 / 2^{1}) * 2^{t})
# 	a : 1, b : 1, c : (1 / 2^{1}) * 2^{t}
# 144	instantiation	177, 178	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-(e + l)) in NaturalPos
# 	a : e + l
# 145	instantiation	294, 401, 409, 295, 284, 297, 365, 287, 337	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (1 + (l - 1)) =  \\ (1 + l - 1)
# 	i : 1, j : 2, k : 0, a : (1), b : (l, -1), c : ()
# 146	instantiation	179, 365, 287, 180	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (1 + l - 1) = l
# 	a : 1, b : 1, c : l
# 147	instantiation	309, 181, 182, 183	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-(e + 1)) = (-(e + l) + (l - 1))
# 	a : -(e + 1), b : -e - 1, c : -e - 1, d : -(e + l) + (l - 1)
# 148	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 149	instantiation	184, 211	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) > 0
# 	n : e + 1
# 150	instantiation	360, 361, 404	|- 2^{t - 1} in Real
# 	A : NaturalPos, B : Real, x : 2^{t - 1}
# 151	instantiation	185, 372, 399, 359	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l <= 2^{t - 1}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 152	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 153	instantiation	407, 396, 186	|- (-2^{t - 1} + 1) in Real
# 	A : Rational, B : Real, x : -2^{t - 1} + 1
# 154	instantiation	324, 372, 399, 359	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-2^{t - 1} + 1) <= l
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 155	instantiation	187, 188	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) < 0
# 	a : -(e + 1)
# 156	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 157	instantiation	288, 189, 190	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l >= 0} |- (l - e) in NaturalPos
# 	a : l - e
# 158	instantiation	294, 295, 409, 401, 297, 191, 287, 317, 332	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- ((l - e) + e) =  \\ (l - e + e)
# 	i : 0, j : 2, k : 1, a : (), b : (l, -e), c : (e)
# 159	instantiation	192, 332, 287, 194	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l - e + e) = l
# 	a : e, b : e, c : l
# 160	instantiation	294, 401, 314, 295, 315, 297, 332, 316, 365, 317	{e in {1 .. 2^{t - 1} - 2}} |- (e + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) =  \\ (e - ((1 / 2^{1}) * 2^{t}) + 1 - e)
# 	i : 1, j : 3, k : 0, a : (e), b : (-((1 / 2^{1}) * 2^{t}), 1, -e), c : ()
# 161	instantiation	268, 295, 409, 297, 193, 332, 316, 365, 194	{e in {1 .. 2^{t - 1} - 2}} |- (e - ((1 / 2^{1}) * 2^{t}) + 1 - e) = (-((1 / 2^{1}) * 2^{t}) + 1)
# 	i : 0, j : 2, k : 0, a : (), b : e, c : (-((1 / 2^{1}) * 2^{t}), 1), d : e, e : ()
# 162	instantiation	265, 195, 196	{e in {1 .. 2^{t - 1} - 2}} |- ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)) = (-1 - e)
# 	x : (2^{t - 1} - 2) + (-2^{t - 1} + 1 - e), y : (((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e), z : -1 - e
# 163	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 164	instantiation	197, 337	|- (-1 + 0) = (-1)
# 	a : -1
# 165	instantiation	335, 337, 244	|- (-1 + 0) = (0 - 1)
# 	a : -1, b : 0
# 166	instantiation	407, 391, 198	|- 3 in Complex
# 	A : Real, B : Complex, x : 3
# 167	conjecture		|- (2 + 1) = 3
# 	proveit.numbers.numerals.decimals.add_2_1
# 168	instantiation	265, 199, 200	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * 0) + (-e - 1)) = (-e - 1)
# 	x : (2 * 0) + (-e - 1), y : 0 + (-e - 1), z : -e - 1
# 169	instantiation	322, 201, 339	{e in {1 .. 2^{t - 1} - 2}} |- (-e - 1) in Real
# 	a : -e, b : -1
# 170	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
# 	proveit.numbers.addition.leftward_commutation
# 171	instantiation	318	|- |(2 * e, -e)| = |(1, ..., 2)|
# 	a : 2 * e, b : -e
# 172	instantiation	407, 391, 202	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Complex
# 	A : Real, B : Complex, x : 2 * e
# 173	instantiation	265, 203, 204	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) - e) = e
# 	x : (2 * e) - e, y : (2 * e) + ((-1) * e), z : e
# 174	instantiation	328, 235	|- ((2^{t - 1} - 2) + 1) = ((((1 / 2^{1}) * 2^{t}) - 2) + 1)
# 	f(_a) : _a + 1, x : 2^{t - 1} - 2, y : ((1 / 2^{1}) * 2^{t}) - 2
# 175	instantiation	265, 205, 206	|- ((((1 / 2^{1}) * 2^{t}) - 2) + 1) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	x : (((1 / 2^{1}) * 2^{t}) - 2) + 1, y : ((1 / 2^{1}) * 2^{t}) - 2 + 1, z : ((1 / 2^{1}) * 2^{t}) - 1
# 176	instantiation	318	|- |((1 / 2^{1}) * 2^{t}, -1)| = |(1, ..., 2)|
# 	a : (1 / 2^{1}) * 2^{t}, b : -1
# 177	conjecture		|- forall_{a in IntegerNeg} ((-a) in NaturalPos)
# 	proveit.numbers.negation.nat_pos_closure
# 178	instantiation	207, 208, 209	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (e + l) in IntegerNeg
# 	a : e + l
# 179	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 180	instantiation	298	|- 1 = 1
# 	x : 1
# 181	instantiation	281, 332, 365	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) = (-e - 1)
# 	a : e, b : 1
# 182	instantiation	298	|- (-e - 1) = (-e - 1)
# 	x : -e - 1
# 183	instantiation	326, 210	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-e - 1) = (-(e + l) + (l - 1))
# 	x : -(e + l) + (l - 1), y : -e - 1
# 184	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 185	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 186	instantiation	407, 402, 372	|- (-2^{t - 1} + 1) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1} + 1
# 187	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 188	instantiation	261, 211	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in IntegerNeg
# 	a : e + 1
# 189	instantiation	398, 347, 212	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}} |- (l - e) in Integer
# 	a : l, b : -e
# 190	instantiation	213, 214	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- (l - e) > 0
# 	a : l, b : e
# 191	instantiation	318	|- |(l, -e)| = |(1, ..., 2)|
# 	a : l, b : -e
# 192	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 193	instantiation	318	|- |(-((1 / 2^{1}) * 2^{t}), 1)| = |(1, ..., 2)|
# 	a : -((1 / 2^{1}) * 2^{t}), b : 1
# 194	instantiation	298	|- e = e
# 	x : e
# 195	instantiation	265, 215, 216	|- ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)) = ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e))
# 	x : (2^{t - 1} - 2) + (-2^{t - 1} + 1 - e), y : (((1 / 2^{1}) * 2^{t}) - 2) + (-2^{t - 1} + 1 - e), z : (((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e)
# 196	instantiation	265, 217, 218	{e in {1 .. 2^{t - 1} - 2}} |- ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) = (-1 - e)
# 	x : (((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e), y : -2 + 1 - e, z : -1 - e
# 197	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 198	instantiation	407, 396, 219	|- 3 in Real
# 	A : Rational, B : Real, x : 3
# 199	instantiation	328, 220	|- ((2 * 0) + (-e - 1)) = (0 + (-e - 1))
# 	f(_a) : _a + (-e - 1), x : 2 * 0, y : 0
# 200	instantiation	265, 221, 222	{e in {1 .. 2^{t - 1} - 2}} |- (0 + (-e - 1)) = (-e - 1)
# 	x : 0 + (-e - 1), y : 0 - e - 1, z : -e - 1
# 201	instantiation	350, 346	{e in {1 .. 2^{t - 1} - 2}} |- (-e) in Real
# 	a : e
# 202	instantiation	407, 396, 223	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Real
# 	A : Rational, B : Real, x : 2 * e
# 203	instantiation	328, 224	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) - e) = ((2 * e) + ((-1) * e))
# 	f(_a) : (2 * e) + _a, x : -e, y : (-1) * e
# 204	instantiation	326, 225	{e in {1 .. 2^{t - 1} - 2}} |- ((2 * e) + ((-1) * e)) = e
# 	x : e, y : (2 * e) + ((-1) * e)
# 205	instantiation	294, 295, 409, 401, 297, 296, 331, 301, 365	|- ((((1 / 2^{1}) * 2^{t}) - 2) + 1) =  \\ (((1 / 2^{1}) * 2^{t}) - 2 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : ((1 / 2^{1}) * 2^{t}, -2), c : (1)
# 206	instantiation	239, 401, 409, 295, 240, 297, 331, 301, 365, 241*	|- (((1 / 2^{1}) * 2^{t}) - 2 + 1) =  \\ (((1 / 2^{1}) * 2^{t}) - 1)
# 	i : 1, j : 2, k : 0, a : ((1 / 2^{1}) * 2^{t}), b : (-2, 1), c : ()
# 207	conjecture		|- forall_{a in Integer | a < 0} (a in IntegerNeg)
# 	proveit.numbers.number_sets.integers.neg_int_is_int_neg
# 208	instantiation	398, 371, 347	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (e + l) in Integer
# 	a : e, b : l
# 209	instantiation	226, 323, 346, 305, 227, 228*	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), e in {1 .. 2^{t - 1} - 2}, l < 0} |- (e + l) < 0
# 	a : l, x : e, y : -l
# 210	instantiation	265, 229, 230	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-(e + l) + (l - 1)) = (-e - 1)
# 	x : -(e + l) + (l - 1), y : (-e - l) + (l - 1), z : -e - 1
# 211	instantiation	231, 262, 342	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 212	instantiation	407, 232, 233	{e in {1 .. 2^{t - 1} - 2}} |- (-e) in Integer
# 	A : IntegerNeg, B : Integer, x : -e
# 213	conjecture		|- forall_{a, b | a > b} ((a - b) > 0)
# 	proveit.numbers.addition.subtraction.pos_difference
# 214	instantiation	271, 253, 234	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- l > e
# 	P(_a) : _a > e, x : |l|_{mod 2^{t}}, y : l
# 215	instantiation	328, 235	|- ((2^{t - 1} - 2) + (-2^{t - 1} + 1 - e)) = ((((1 / 2^{1}) * 2^{t}) - 2) + (-2^{t - 1} + 1 - e))
# 	f(_a) : _a + (-2^{t - 1} + 1 - e), x : 2^{t - 1} - 2, y : ((1 / 2^{1}) * 2^{t}) - 2
# 216	instantiation	328, 236	|- ((((1 / 2^{1}) * 2^{t}) - 2) + (-2^{t - 1} + 1 - e)) = ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e))
# 	f(_a) : (((1 / 2^{1}) * 2^{t}) - 2) + _a, x : -2^{t - 1} + 1 - e, y : -((1 / 2^{1}) * 2^{t}) + 1 - e
# 217	instantiation	265, 237, 238	{e in {1 .. 2^{t - 1} - 2}} |- ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) = (-2 + 1 - e)
# 	x : (((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e), y : ((1 / 2^{1}) * 2^{t}) - 2 - ((1 / 2^{1}) * 2^{t}) + 1 - e, z : -2 + 1 - e
# 218	instantiation	239, 295, 409, 401, 297, 240, 301, 365, 317, 241*	{e in {1 .. 2^{t - 1} - 2}} |- (-2 + 1 - e) =  \\ (-1 - e)
# 	i : 0, j : 2, k : 1, a : (), b : (-2, 1), c : (-e)
# 219	instantiation	407, 402, 242	|- 3 in Rational
# 	A : Integer, B : Rational, x : 3
# 220	instantiation	243, 382	|- (2 * 0) = 0
# 	x : 2
# 221	instantiation	294, 401, 409, 295, 246, 297, 244, 317, 337	{e in {1 .. 2^{t - 1} - 2}} |- (0 + (-e - 1)) =  \\ (0 - e - 1)
# 	i : 1, j : 2, k : 0, a : (0), b : (-e, -1), c : ()
# 222	instantiation	245, 295, 409, 297, 246, 317, 337	{e in {1 .. 2^{t - 1} - 2}} |- (0 - e - 1) = (-e - 1)
# 	i : 0, j : 2, a : (), b : (-e, -1)
# 223	instantiation	407, 402, 247	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Rational
# 	A : Integer, B : Rational, x : 2 * e
# 224	instantiation	326, 248	{e in {1 .. 2^{t - 1} - 2}} |- (-e) = ((-1) * e)
# 	x : (-1) * e, y : -e
# 225	instantiation	249, 295, 409, 401, 297, 250, 382, 337, 332, 251*, 252*	{e in {1 .. 2^{t - 1} - 2}} |- e =  \\ ((2 * e) + ((-1) * e))
# 	i : 0, j : 2, k : 1, a : (), b : (2, -1), c : (e)
# 226	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 227	instantiation	271, 253, 254	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- (-l) > e
# 	P(_a) : _a > e, x : |l|_{mod 2^{t}}, y : -l
# 228	instantiation	255, 287, 256	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-l + l) = 0
# 	a : l, b : l
# 229	instantiation	328, 257	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-(e + l) + (l - 1)) = ((-e - l) + (l - 1))
# 	f(_a) : _a + (l - 1), x : -(e + l), y : -e - l
# 230	instantiation	309, 258, 259, 260	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- ((-e - l) + (l - 1)) = (-e - 1)
# 	a : (-e - l) + (l - 1), b : -e - l + (l - 1), c : -e - l + l - 1, d : -e - 1
# 231	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 232	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 233	instantiation	261, 262	{e in {1 .. 2^{t - 1} - 2}} |- (-e) in IntegerNeg
# 	a : e
# 234	instantiation	279, 359, 263*	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l >= 0} |- |l|_{mod 2^{t}} = l
# 	l : l
# 235	instantiation	328, 292	|- (2^{t - 1} - 2) = (((1 / 2^{1}) * 2^{t}) - 2)
# 	f(_a) : _a - 2, x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 236	instantiation	328, 264	|- (-2^{t - 1} + 1 - e) = (-((1 / 2^{1}) * 2^{t}) + 1 - e)
# 	f(_a) : _a + 1 - e, x : -2^{t - 1}, y : -((1 / 2^{1}) * 2^{t})
# 237	instantiation	265, 266, 267	{e in {1 .. 2^{t - 1} - 2}} |- ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) = (((1 / 2^{1}) * 2^{t}) - 2 - ((1 / 2^{1}) * 2^{t}) + 1 - e)
# 	x : (((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e), y : ((1 / 2^{1}) * 2^{t}) - 2 + (-((1 / 2^{1}) * 2^{t}) + 1 - e), z : ((1 / 2^{1}) * 2^{t}) - 2 - ((1 / 2^{1}) * 2^{t}) + 1 - e
# 238	instantiation	268, 295, 401, 409, 297, 269, 331, 301, 365, 317, 270	{e in {1 .. 2^{t - 1} - 2}} |- (((1 / 2^{1}) * 2^{t}) - 2 - ((1 / 2^{1}) * 2^{t}) + 1 - e) = (-2 + 1 - e)
# 	i : 0, j : 1, k : 2, a : (), b : (1 / 2^{1}) * 2^{t}, c : (-2), d : (1 / 2^{1}) * 2^{t}, e : (1, -e)
# 239	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 240	instantiation	318	|- |(-2, 1)| = |(1, ..., 2)|
# 	a : -2, b : 1
# 241	instantiation	271, 272, 273	|- (-2 + 1) = (-1)
# 	P(_a) : _a = (-1), x : 1 - 2, y : -2 + 1
# 242	instantiation	407, 408, 314	|- 3 in Integer
# 	A : Natural, B : Integer, x : 3
# 243	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 244	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 245	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
# 	proveit.numbers.addition.elim_zero_any
# 246	instantiation	318	|- |(-e, -1)| = |(1, ..., 2)|
# 	a : -e, b : -1
# 247	instantiation	274, 406, 371	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Integer
# 	a : 2, b : e
# 248	instantiation	275, 332	{e in {1 .. 2^{t - 1} - 2}} |- ((-1) * e) = (-e)
# 	x : e
# 249	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 250	instantiation	318	|- |(2, -1)| = |(1, ..., 2)|
# 	a : 2, b : -1
# 251	instantiation	276, 365, 382, 300	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 252	instantiation	277, 332	{e in {1 .. 2^{t - 1} - 2}} |- (1 * e) = e
# 	x : e
# 253	instantiation	278, 374	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- |l|_{mod 2^{t}} > e
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : |l|_{mod 2^{t}} > e
# 254	instantiation	279, 359, 280*	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e), l < 0} |- |l|_{mod 2^{t}} = (-l)
# 	l : l
# 255	conjecture		|- forall_{a, b in Complex | a = b} ((-a + b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_reverse
# 256	instantiation	298	|- l = l
# 	x : l
# 257	instantiation	281, 332, 287	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-(e + l)) = (-e - l)
# 	a : e, b : l
# 258	instantiation	294, 295, 409, 401, 297, 283, 317, 285, 282	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- ((-e - l) + (l - 1)) =  \\ (-e - l + (l - 1))
# 	i : 0, j : 2, k : 1, a : (), b : (-e, -l), c : (l - 1)
# 259	instantiation	294, 409, 295, 283, 284, 297, 317, 285, 287, 337	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-e - l + (l - 1)) =  \\ (-e - l + l - 1)
# 	i : 2, j : 2, k : 0, a : (-e, -l), b : (l, -1), c : ()
# 260	instantiation	286, 401, 295, 297, 317, 287, 337	{e in {1 .. 2^{t - 1} - 2}, (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-e - l + l - 1) = (-e - 1)
# 	i : 1, j : 0, k : 1, a : (-e), b : l, c : (), d : l, e : (-1)
# 261	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 262	instantiation	288, 371, 289	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 263	instantiation	290, 291	{l >= 0} |- |l| = l
# 	x : l
# 264	instantiation	328, 292	|- (-2^{t - 1}) = (-((1 / 2^{1}) * 2^{t}))
# 	f(_a) : -_a, x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 265	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 266	instantiation	294, 295, 409, 401, 297, 296, 331, 301, 293	{e in {1 .. 2^{t - 1} - 2}} |- ((((1 / 2^{1}) * 2^{t}) - 2) + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) =  \\ (((1 / 2^{1}) * 2^{t}) - 2 + (-((1 / 2^{1}) * 2^{t}) + 1 - e))
# 	i : 0, j : 2, k : 1, a : (), b : ((1 / 2^{1}) * 2^{t}, -2), c : (-((1 / 2^{1}) * 2^{t}) + 1 - e)
# 267	instantiation	294, 409, 314, 295, 296, 315, 297, 331, 301, 316, 365, 317	{e in {1 .. 2^{t - 1} - 2}} |- (((1 / 2^{1}) * 2^{t}) - 2 + (-((1 / 2^{1}) * 2^{t}) + 1 - e)) =  \\ (((1 / 2^{1}) * 2^{t}) - 2 - ((1 / 2^{1}) * 2^{t}) + 1 - e)
# 	i : 2, j : 3, k : 0, a : ((1 / 2^{1}) * 2^{t}, -2), b : (-((1 / 2^{1}) * 2^{t}), 1, -e), c : ()
# 268	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 269	instantiation	318	|- |(1, -e)| = |(1, ..., 2)|
# 	a : 1, b : -e
# 270	instantiation	298	|- ((1 / 2^{1}) * 2^{t}) = ((1 / 2^{1}) * 2^{t})
# 	x : (1 / 2^{1}) * 2^{t}
# 271	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 272	instantiation	299, 365, 382, 300	|- (1 - 2) = (-1)
# 	a : 1, b : 1, c : 2
# 273	instantiation	335, 365, 301	|- (1 - 2) = (-2 + 1)
# 	a : 1, b : -2
# 274	conjecture		|- forall_{a, b in Integer} ((a * b) in Integer)
# 	proveit.numbers.multiplication.mult_int_closure_bin
# 275	conjecture		|- forall_{x in Complex} (((-1) * x) = (-x))
# 	proveit.numbers.negation.mult_neg_one_left
# 276	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 277	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 278	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 279	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} (|l|_{mod 2^{t}} = |l|)
# 	proveit.physics.quantum.QPE._modabs_in_full_domain_simp
# 280	instantiation	302, 303	{l < 0} |- |l| = (-l)
# 	x : l
# 281	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 282	instantiation	407, 391, 304	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l - 1) in Complex
# 	A : Real, B : Complex, x : l - 1
# 283	instantiation	318	|- |(-e, -l)| = |(1, ..., 2)|
# 	a : -e, b : -l
# 284	instantiation	318	|- |(l, -1)| = |(1, ..., 2)|
# 	a : l, b : -1
# 285	instantiation	407, 391, 305	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-l) in Complex
# 	A : Real, B : Complex, x : -l
# 286	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} - b+ c_{1} +  c_{2} +  ... +  c_{j} + d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general_rev
# 287	instantiation	407, 391, 323	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l in Complex
# 	A : Real, B : Complex, x : l
# 288	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 289	instantiation	306, 307, 308	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 290	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 291	assumption		{l >= 0} |- l >= 0
# 292	instantiation	309, 310, 311, 312	|- 2^{t - 1} = ((1 / 2^{1}) * 2^{t})
# 	a : 2^{t - 1}, b : 2^{-1 + t}, c : 2^{-1} * 2^{t}, d : (1 / 2^{1}) * 2^{t}
# 293	instantiation	313, 314, 315, 316, 365, 317	{e in {1 .. 2^{t - 1} - 2}} |- (-((1 / 2^{1}) * 2^{t}) + 1 - e) in Complex
# 	i : 3, a : (-((1 / 2^{1}) * 2^{t}), 1, -e)
# 294	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 295	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 296	instantiation	318	|- |((1 / 2^{1}) * 2^{t}, -2)| = |(1, ..., 2)|
# 	a : (1 / 2^{1}) * 2^{t}, b : -2
# 297	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 298	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 299	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((b - c) = (-a))
# 	proveit.numbers.addition.subtraction.subtract_from_add_reversed
# 300	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 301	instantiation	407, 391, 319	|- (-2) in Complex
# 	A : Real, B : Complex, x : -2
# 302	conjecture		|- forall_{x | x <= 0} (|x| = (-x))
# 	proveit.numbers.absolute_value.abs_neg_elim
# 303	instantiation	320, 321	{l < 0} |- l <= 0
# 	x : l, y : 0
# 304	instantiation	322, 323, 339	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l - 1) in Real
# 	a : l, b : -1
# 305	instantiation	350, 323	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (-l) in Real
# 	a : l
# 306	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 307	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 308	instantiation	324, 395, 394, 386	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 309	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 310	instantiation	328, 325	|- 2^{t - 1} = 2^{-1 + t}
# 	f(_a) : 2^{_a}, x : t - 1, y : -1 + t
# 311	instantiation	326, 327	|- 2^{-1 + t} = (2^{-1} * 2^{t})
# 	x : 2^{-1} * 2^{t}, y : 2^{-1 + t}
# 312	instantiation	328, 329	|- (2^{-1} * 2^{t}) = ((1 / 2^{1}) * 2^{t})
# 	f(_a) : _a * 2^{t}, x : 2^{-1}, y : 1 / 2^{1}
# 313	conjecture		|- forall_{i in Natural} [forall_{a_{1}, a_{2}, ..., a_{i} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}) in Complex)]
# 	proveit.numbers.addition.add_complex_closure
# 314	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 315	instantiation	330	|- |(-((1 / 2^{1}) * 2^{t}), 1, -e)| = |(1, 2, ..., 3)|
# 	a : -((1 / 2^{1}) * 2^{t}), b : 1, c : -e
# 316	instantiation	349, 331	|- (-((1 / 2^{1}) * 2^{t})) in Complex
# 	a : (1 / 2^{1}) * 2^{t}
# 317	instantiation	349, 332	{e in {1 .. 2^{t - 1} - 2}} |- (-e) in Complex
# 	a : e
# 318	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 319	instantiation	407, 396, 333	|- (-2) in Real
# 	A : Rational, B : Real, x : -2
# 320	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 321	assumption		{l < 0} |- l < 0
# 322	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 323	instantiation	407, 396, 334	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l in Real
# 	A : Rational, B : Real, x : l
# 324	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 325	instantiation	335, 336, 337	|- (t - 1) = (-1 + t)
# 	a : t, b : -1
# 326	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 327	instantiation	338, 382, 339, 348, 367	|- (2^{-1} * 2^{t}) = 2^{-1 + t}
# 	a : 2, b : -1, c : t
# 328	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 329	instantiation	340, 341, 342	|- 2^{-1} = (1 / 2^{1})
# 	a : 2, n : 1
# 330	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 331	instantiation	343, 344, 345	|- ((1 / 2^{1}) * 2^{t}) in Complex
# 	a : 1 / 2^{1}, b : 2^{t}
# 332	instantiation	407, 391, 346	{e in {1 .. 2^{t - 1} - 2}} |- e in Complex
# 	A : Real, B : Complex, x : e
# 333	instantiation	407, 402, 400	|- (-2) in Rational
# 	A : Integer, B : Rational, x : -2
# 334	instantiation	407, 402, 347	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 335	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 336	instantiation	407, 391, 348	|- t in Complex
# 	A : Real, B : Complex, x : t
# 337	instantiation	349, 365	|- (-1) in Complex
# 	a : 1
# 338	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 339	instantiation	350, 379	|- (-1) in Real
# 	a : 1
# 340	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 341	instantiation	407, 351, 352	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 342	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 343	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 344	instantiation	353, 365, 354, 355	|- (1 / 2^{1}) in Complex
# 	a : 1, b : 2^{1}
# 345	instantiation	407, 391, 356	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 346	instantiation	407, 396, 357	{e in {1 .. 2^{t - 1} - 2}} |- e in Real
# 	A : Rational, B : Real, x : e
# 347	instantiation	407, 358, 359	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 348	instantiation	360, 361, 384	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 349	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 350	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 351	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 352	instantiation	407, 362, 363	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 353	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 354	instantiation	364, 382, 365	|- 2^{1} in Complex
# 	a : 2, b : 1
# 355	instantiation	366, 367, 368	|- 2^{1} != 0
# 	P(_a) : _a != 0, x : 2^{1}, y : 2
# 356	instantiation	369, 392, 370	|- 2^{t} in Real
# 	a : 2, b : t
# 357	instantiation	407, 402, 371	{e in {1 .. 2^{t - 1} - 2}} |- e in Rational
# 	A : Integer, B : Rational, x : e
# 358	instantiation	393, 372, 399	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 359	instantiation	373, 374	{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : |l|_{mod 2^{t}} > e
# 360	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 361	instantiation	375, 376	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 362	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 363	instantiation	407, 377, 378	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 364	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 365	instantiation	407, 391, 379	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 366	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 367	instantiation	380, 389	|- 2 != 0
# 	n : 2
# 368	instantiation	381, 382	|- 2^{1} = 2
# 	x : 2
# 369	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 370	instantiation	407, 383, 384	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 371	instantiation	407, 385, 386	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 372	instantiation	398, 387, 395	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 373	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 374	assumption		{(l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)} |- (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (|l|_{mod 2^{t}} > e)
# 375	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 376	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 377	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 378	instantiation	407, 388, 389	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 379	instantiation	407, 396, 390	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 380	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 381	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 382	instantiation	407, 391, 392	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 383	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 384	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 385	instantiation	393, 395, 394	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 386	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 387	instantiation	405, 399	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 388	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 389	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 390	instantiation	407, 402, 395	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 391	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 392	instantiation	407, 396, 397	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 393	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 394	instantiation	398, 399, 400	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 395	instantiation	407, 408, 401	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 396	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 397	instantiation	407, 402, 406	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 398	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 399	instantiation	407, 403, 404	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 400	instantiation	405, 406	|- (-2) in Integer
# 	a : 2
# 401	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 402	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 403	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 404	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 405	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 406	instantiation	407, 408, 409	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 407	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 408	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 409	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
