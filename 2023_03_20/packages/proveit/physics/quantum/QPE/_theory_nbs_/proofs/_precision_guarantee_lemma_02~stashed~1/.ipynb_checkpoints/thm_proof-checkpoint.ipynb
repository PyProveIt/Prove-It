# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_precision_guarantee_lemma_02">_precision_guarantee_lemma_02</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, m, x, N, defaults
from proveit.logic import InSet
from proveit.numbers import Floor, LessEq, ModAbs, Mult, Real, subtract
from proveit.numbers.modular import mod_abs_of_difference_bound, mod_abs_scaled
from proveit.numbers.rounding import floor_x_le_x
from proveit.physics.quantum.QPE import (
    _best_floor_def, _n_in_natural_pos, _phase,
    _phase_in_interval, _t_in_natural_pos, _two_pow_t,
    _two_pow_t__minus_one)

# %%
# %proving _precision_guarantee_lemma_02
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_precision_guarantee_lemma_02">_precision_guarantee_lemma_02:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86fe93f886b08cd35fddcfe70a26bebd6bd69afc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/64150ffec76dd24e798462b3cc77387f3e2cd62e0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _precision_guarantee_lemma_02.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/bc609f409460d764c98800ff8beef62e376e73d30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience
_thm_expr = _precision_guarantee_lemma_02.instance_expr
# Out:
# <strong id="_thm_expr">_thm_expr:</strong> <a class="ProveItLink" href="../../../__pv_it/common/bcbd6b9d4ad35855001dc2b200dcea87f75c697e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Import some basic local assumptions and local definitions

# %%
# some basic assumptions and definitions
display(_t_in_natural_pos)
display(_n_in_natural_pos)
display(_phase_in_interval)
display(_best_floor_def)
# Out:
# |- t in NaturalPos
# |- n in NaturalPos
# |- phase in [0,1)
# |- b_{f} = floor(2^{t} * phase)

# %% [markdown]
# It is useful generally to establish that $2^{t}\varphi \ge \lfloor 2^{t}\varphi\rfloor$ (this is then used implicitly in some auto_simplification further below) (might be nice to convert this to a method of some sort in the Floor class?):

# %%
floor_x_le_x
# Out:
# |- forall_{x in Real} (floor(x) <= x)

# %%
_x_sub = Mult(_two_pow_t, _phase)
floor_int_phase_bound = floor_x_le_x.instantiate({x: _x_sub}).reversed()
# Out:
# <strong id="floor_int_phase_bound">floor_int_phase_bound:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/02992b4d32d116c43b7f89d11adc6eac0764da2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# We gradually transform the assumed condition $|m-b|_{\text{mod}\;2^t} \le 2^{t-1}-1$ into the desired condition $|\frac{m}{2^{t}}-1|_{\text{mod}\;1} \le 2^{-n}$:

# %%
condition_01 = _precision_guarantee_lemma_02.condition.operands[1].prove()
# Out:
# <strong id="condition_01">condition_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/32dd9021c3d0f1530be619232b78a2c486f107790/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
condition_02 = (
    condition_01.inner_expr().lhs.value.operands[1].
    operand.substitute(_best_floor_def))
# Out:
# <strong id="condition_02">condition_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/ff99e51e760c505e950a01b38ab58f09d83ee5f50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/6172b6b66832318713c1d1c915009c3ee556177f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
mod_abs_of_difference_bound
# Out:
# |- forall_{a in Real, b in Real, N in RealPos} (|a - b|_{mod N} >= (|a|_{mod N} - |b|_{mod N}))

# %% [markdown]
# Then for later auto-simplification to work well, we want to establish that $|\lfloor 2^{t}\varphi\rfloor - 2^{t}\varphi| \le 2^{t}/2$

# %%
from proveit.numbers import two, Div
div_mult_id = Div(_two_pow_t, two).cancelation(two)
# Out:
# <strong id="div_mult_id">div_mult_id:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/36a27437fc34ec3702dc3436b27cef457d82b4170/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/6907994657797688ae253c70fd57c94dc11ce63e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
from proveit.numbers import one, greater_eq
two_pow_t_minus_1_ge_1 = greater_eq(_two_pow_t_minus_one_is_nat_pos.element, one).prove()
# Out:
# <strong id="two_pow_t_minus_1_ge_1">two_pow_t_minus_1_ge_1:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/400cd32035d07f3df6806822866a284965a1f4f70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/a957daf9a595d3506a225f18654f6dae5ef8bc6c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers.rounding import real_minus_floor_interval
real_minus_floor_interval
# Out:
# |- forall_{x in Real} ((x - floor(x)) in [0,1))

# %%
from proveit import x
from proveit.numbers import two, Exp
from proveit.physics.quantum.QPE import _t
_x_sub = Mult(Exp(two, _t), _phase)
real_minus_floor = real_minus_floor_interval.instantiate({x: _x_sub})
# Out:
# <strong id="real_minus_floor">real_minus_floor:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/4a69af7824be08cf3333c5f6ec2d49c7cb96b05e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/db00c9e3bbb8e3e26dc0f72c145c5b7ee5da85990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers import zero, one, Abs, IntervalCO
real_minus_floor_abs = InSet(Abs(real_minus_floor.element), IntervalCO(zero, one)).prove()
# Out:
# <strong id="real_minus_floor_abs">real_minus_floor_abs:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/83d524720f6250fe8397ca3cdce699f9cbcba8710/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/d04980c1ec90b0c122f583ffa73e12a1e4a53efe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
real_minus_floor_abs.inner_expr().element.reverse_difference(auto_simplify=False)
# Out:
# |- |floor(2^{t} * phase) - (2^{t} * phase)| in [0,1)

# %% [markdown]
# Notice in the result of the following instantiation the ModAbs that would have appeared on the lhs with respect to $2^{t}$ has been automatically simplified to a non-modular (and non-absolute-value) expression:

# %%
_a_sub, _b_sub, _N_sub = (
    subtract(m, Mult(_two_pow_t, _phase)),
    subtract(m, Floor(Mult(_two_pow_t, _phase))),
    _two_pow_t)
condition_03 = mod_abs_of_difference_bound.instantiate(
        {a: _a_sub, b: _b_sub, N: _N_sub}).inner_expr().lhs.dividend.commute(0,1)
# Out:
# Expression notebook is being updated for ({0 .. 2^{t} - 1}, Integer)
# Expression notebook is being updated for {0 .. 2^{t} - 1} proper_subset Integer
# <strong id="condition_03">condition_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/0e4763976f4d74991a490e578185cdfec53404c60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/b4f5df74eb16178405c68c2b9da9cd3ec72a66140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
condition_04 = condition_03.inner_expr().lhs.commute(0, 1).with_styles(direction='normal')
# Out:
# <strong id="condition_04">condition_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/dae63a37dae5ac8702feb619dd21cbf6ccfa11fc0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/264ed2c8dbc48a7c047e68ffa18785f57f4850c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# But we also know from our work above that $2^{t}\varphi - \lfloor 2^{t}\varphi \rfloor < 1$, so Prove-It can now give us the following:

# %%
condition_05 = LessEq(condition_04.lhs, one).prove()
# Out:
# <strong id="condition_05">condition_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/caa125c92272790382a2cfd2a30c0ef4f4d309790/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/605ff9b2f7370e1be38b2cf8a6253baa0e4823f50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# And then we rearrange a bit:

# %%
condition_06 = condition_05.left_add_both_sides(condition_05.lhs.operands[1].operand)
# Out:
# <strong id="condition_06">condition_06:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/50255942d93028644163d9195dcdac2182eced230/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/c061da1779bfc0816ce1d23bf04931fc31572e220/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# From an earlier condition, we can derive a bound on the rhs of `condition_06` above:

# %%
condition_07 = condition_02.right_add_both_sides(one)
# Out:
# <strong id="condition_07">condition_07:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/a790f113db2e2c65d5b0b41cffb840f46fcfd9a40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/5491e85810984783ddaed392a9a0760a48d114c90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Then apply transitivity to obtain the following:

# %%
condition_08 = condition_06.apply_transitivity(condition_07)
# Out:
# <strong id="condition_08">condition_08:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/3eb1a2b5e916ceae9b200a6977a0a57c70453aa40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/4ccc84aa6336d0b4691348b0ddd5c6f5e4d4866a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# We want to transform the $\text{mod}\;2^{t}$ on the lhs to the $\text{mod}\;1$ that we want in the eventual desired expression.<br/>
# We can utilize the following theorem and subsequent instantiation to do that:

# %%
mod_abs_scaled
# Out:
# |- forall_{a, b, c in Real} ((a * |b|_{mod c}) = |a * b|_{mod a * c})

# %%
from proveit import a, b, c
_a_sub, _b_sub, _c_sub = _two_pow_t, _thm_expr.lhs.operands[0], one
condition_equality_01 = mod_abs_scaled.instantiate({a: _a_sub, b: _b_sub, c: _c_sub})
# Out:
# <strong id="condition_equality_01">condition_equality_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/be6fefb637cb14c9297ff78a286d6a4472de51fe0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/57b2be5a3eaa49e58b537bc9755729c1ef9612290/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# clean up rhs side by distributing that factor of 2^t
condition_equality_02 = condition_equality_01.inner_expr().rhs.operands[0].distribute(1)
# Out:
# <strong id="condition_equality_02">condition_equality_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/1a86bba44903c5bfd9ac634cf27f536ec7b24de10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/eeabf10e85643f162b6310540d5eb269b59f4a700/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now we utilize that result, substituting the lhs for the rhs in our previous result:

# %%
condition_09 = condition_equality_02.sub_left_side_into(condition_08)
# Out:
# <strong id="condition_09">condition_09:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/d1b413495f3e84bb6b759295e402adbea98c3eaf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/4bcd61f6cd3debd2c475dfe6d48d94e6381df4960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# We can then divide both sides by the factor $2^{t}$ and simplify, and we are done:

# %%
condition_10 = condition_09.divide_both_sides(_two_pow_t)
# Out:
# <strong id="condition_10">condition_10:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/abcbd2de57d09c2db5d9cf8b86accc4d415058fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/b81d74d2ae365d5101edc3b77a34eefc431433070/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__precision_guarantee_lemma_02/942f0b15f07ca85c03a9d72355439a67990f65a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _precision_guarantee_lemma_02 may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._precision_guarantee_lemma_02 has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{m in {0 .. 2^{t} - 1} | |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} (|(m / 2^{t}) - phase|_{mod 1} <= 2^{-n})
# 1	instantiation	172, 2, 3	{m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- |(m / 2^{t}) - phase|_{mod 1} <= 2^{-n}
# 	P(_a) : |(m / 2^{t}) - phase|_{mod 1} <= _a, x : 2^{t - n} / 2^{t}, y : 2^{-n}
# 2	instantiation	4, 252, 5, 102, 6, 7, 8*	{m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- |(m / 2^{t}) - phase|_{mod 1} <= (2^{t - n} / 2^{t})
# 	a : 2^{t}, x : 2^{t} * |(m / 2^{t}) - phase|_{mod 1}, y : 2^{t - n}
# 3	instantiation	9, 78, 181, 138, 10*	|- (2^{t - n} / 2^{t}) = 2^{-n}
# 	x : 2^{t - n}, y : 2^{t}
# 4	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 	proveit.numbers.division.weak_div_from_numer_bound__pos_denom
# 5	instantiation	251, 252, 39	{m in {0 .. 2^{t} - 1}} |- (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) in Real
# 	a : 2^{t}, b : |(m / 2^{t}) - phase|_{mod 1}
# 6	instantiation	185, 11, 12	{m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) <= 2^{t - n}
# 	P(_a) : _a <= 2^{t - n}, x : 2^{t} * |(m / 2^{t}) - phase|_{mod 1}, y : |m - (2^{t} * phase)|_{mod 2^{t}}
# 7	instantiation	13, 141	|- 2^{t} > 0
# 	x : 2^{t}
# 8	instantiation	201, 14, 15	{m in {0 .. 2^{t} - 1}} |- ((2^{t} * |(m / 2^{t}) - phase|_{mod 1}) / 2^{t}) = |(m / 2^{t}) - phase|_{mod 1}
# 	x : (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) / 2^{t}, y : |(m / 2^{t}) - phase|_{mod 1} / 1, z : |(m / 2^{t}) - phase|_{mod 1}
# 9	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 10	instantiation	201, 16, 17	|- (2^{t - n} * (2^{t})^{-1}) = 2^{-n}
# 	x : 2^{t - n} * (2^{t})^{-1}, y : 2^{t - n} * 2^{-t}, z : 2^{-n}
# 11	instantiation	45, 18, 19	{m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- |m - (2^{t} * phase)|_{mod 2^{t}} <= 2^{t - n}
# 	x : |m - (2^{t} * phase)|_{mod 2^{t}}, y : |m - floor(2^{t} * phase)|_{mod 2^{t}} + 1, z : 2^{t - n}
# 12	instantiation	172, 20, 21	{m in {0 .. 2^{t} - 1}} |- (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) = |m - (2^{t} * phase)|_{mod 2^{t}}
# 	P(_a) : (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) = |_a|_{mod 2^{t}}, x : 2^{t} * ((m / 2^{t}) - phase), y : m - (2^{t} * phase)
# 13	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 14	instantiation	191, 104, 193, 22, 144*	{m in {0 .. 2^{t} - 1}} |- ((2^{t} * |(m / 2^{t}) - phase|_{mod 1}) / 2^{t}) = (|(m / 2^{t}) - phase|_{mod 1} / 1)
# 	x : 2^{t}, z : 1, y : |(m / 2^{t}) - phase|_{mod 1}
# 15	instantiation	208, 22	{m in {0 .. 2^{t} - 1}} |- (|(m / 2^{t}) - phase|_{mod 1} / 1) = |(m / 2^{t}) - phase|_{mod 1}
# 	x : |(m / 2^{t}) - phase|_{mod 1}
# 16	instantiation	217, 23	|- (2^{t - n} * (2^{t})^{-1}) = (2^{t - n} * 2^{-t})
# 	f(_a) : 2^{t - n} * _a, x : (2^{t})^{-1}, y : 2^{-t}
# 17	instantiation	24, 229, 139, 89, 41, 25*	|- (2^{t - n} * 2^{-t}) = 2^{-n}
# 	a : 2, b : t - n, c : -t
# 18	instantiation	26, 117, 27, 260, 28, 29*	{m in {0 .. 2^{t} - 1}} |- |m - (2^{t} * phase)|_{mod 2^{t}} <= (|m - floor(2^{t} * phase)|_{mod 2^{t}} + 1)
# 	a : |m - floor(2^{t} * phase)|_{mod 2^{t}}, x : |m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}, y : 1
# 19	instantiation	30, 260, 117, 31, 32, 33*	{m in {0 .. 2^{t} - 1}, |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- (|m - floor(2^{t} * phase)|_{mod 2^{t}} + 1) <= 2^{t - n}
# 	a : 1, x : |m - floor(2^{t} * phase)|_{mod 2^{t}}, y : 2^{t - n} - 1
# 20	instantiation	34, 252, 56, 260, 144*	{m in {0 .. 2^{t} - 1}} |- (2^{t} * |(m / 2^{t}) - phase|_{mod 1}) = |2^{t} * ((m / 2^{t}) - phase)|_{mod 2^{t}}
# 	a : 2^{t}, b : (m / 2^{t}) - phase, c : 1
# 21	instantiation	35, 276, 151, 152, 181, 36, 37, 38*	{m in {0 .. 2^{t} - 1}} |- (2^{t} * ((m / 2^{t}) - phase)) =  \\ (m - (2^{t} * phase))
# 	i : 1, j : 0, a : (2^{t}), x : m / 2^{t}, y : phase, b : ()
# 22	instantiation	274, 241, 39	{m in {0 .. 2^{t} - 1}} |- |(m / 2^{t}) - phase|_{mod 1} in Complex
# 	A : Real, B : Complex, x : |(m / 2^{t}) - phase|_{mod 1}
# 23	instantiation	40, 229, 216, 101, 41, 42*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 24	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 25	instantiation	201, 43, 44	|- ((t - n) - t) = (-n)
# 	x : (t - n) - t, y : t - n - t, z : -n
# 26	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 27	instantiation	163, 100, 99	{m in {0 .. 2^{t} - 1}} |- (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}) in Real
# 	a : |m - (2^{t} * phase)|_{mod 2^{t}}, b : -|m - floor(2^{t} * phase)|_{mod 2^{t}}
# 28	instantiation	45, 46, 47	{m in {0 .. 2^{t} - 1}} |- (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}) <= 1
# 	x : |m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}, y : -floor(2^{t} * phase) + (2^{t} * phase), z : 1
# 29	instantiation	201, 48, 49	{m in {0 .. 2^{t} - 1}} |- (|m - floor(2^{t} * phase)|_{mod 2^{t}} + (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}})) = |m - (2^{t} * phase)|_{mod 2^{t}}
# 	x : |m - floor(2^{t} * phase)|_{mod 2^{t}} + (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}), y : |m - floor(2^{t} * phase)|_{mod 2^{t}} + |m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}, z : |m - (2^{t} * phase)|_{mod 2^{t}}
# 30	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 31	instantiation	163, 102, 101	|- (2^{t - n} - 1) in Real
# 	a : 2^{t - n}, b : -1
# 32	instantiation	172, 50, 51	{|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- |m - floor(2^{t} * phase)|_{mod 2^{t}} <= (2^{t - n} - 1)
# 	P(_a) : |m - _a|_{mod 2^{t}} <= (2^{t - n} - 1), x : b_{f}, y : floor(2^{t} * phase)
# 33	instantiation	201, 52, 53	|- ((2^{t - n} - 1) + 1) = 2^{t - n}
# 	x : (2^{t - n} - 1) + 1, y : 2^{t - n} - 1 + 1, z : 2^{t - n}
# 34	conjecture		|- forall_{a, b, c in Real} ((a * |b|_{mod c}) = |a * b|_{mod a * c})
# 	proveit.numbers.modular.mod_abs_scaled
# 35	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))]
# 	proveit.numbers.multiplication.distribute_through_subtract
# 36	instantiation	274, 241, 85	{m in {0 .. 2^{t} - 1}} |- (m / 2^{t}) in Complex
# 	A : Real, B : Complex, x : m / 2^{t}
# 37	instantiation	274, 241, 253	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 38	instantiation	172, 54, 55	{m in {0 .. 2^{t} - 1}} |- (2^{t} * (m / 2^{t})) = m
# 	P(_a) : (2^{t} * (m / 2^{t})) = _a, x : (1 / 1) * (m / 1), y : m
# 39	instantiation	136, 56, 260, 57	{m in {0 .. 2^{t} - 1}} |- |(m / 2^{t}) - phase|_{mod 1} in Real
# 	a : (m / 2^{t}) - phase, b : 1
# 40	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 41	instantiation	87, 243	|- 2 != 0
# 	n : 2
# 42	instantiation	58, 88, 125, 59*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 43	instantiation	147, 151, 271, 276, 152, 60, 88, 62, 61	|- ((t - n) - t) =  \\ (t - n - t)
# 	i : 0, j : 2, k : 1, a : (), b : (t, -n), c : (-t)
# 44	instantiation	71, 88, 62, 63	|- (t - n - t) = (-n)
# 	a : t, b : t, c : -n
# 45	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 46	instantiation	172, 64, 65, 66*	{m in {0 .. 2^{t} - 1}} |- (-floor(2^{t} * phase) + (2^{t} * phase)) >= (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}})
# 	P(_a) : |_a|_{mod 2^{t}} >= (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}), x : -(2^{t} * phase) + floor(2^{t} * phase), y : floor(2^{t} * phase) - (2^{t} * phase)
# 47	instantiation	185, 67, 68	|- (-floor(2^{t} * phase) + (2^{t} * phase)) <= 1
# 	P(_a) : _a <= 1, x : -floor(2^{t} * phase) + (2^{t} * phase), y : (2^{t} * phase) - floor(2^{t} * phase)
# 48	instantiation	147, 276, 271, 151, 69, 152, 72, 73, 70	{m in {0 .. 2^{t} - 1}} |- (|m - floor(2^{t} * phase)|_{mod 2^{t}} + (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}})) =  \\ (|m - floor(2^{t} * phase)|_{mod 2^{t}} + |m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}})
# 	i : 1, j : 2, k : 0, a : (|m - floor(2^{t} * phase)|_{mod 2^{t}}), b : (|m - (2^{t} * phase)|_{mod 2^{t}}, -|m - floor(2^{t} * phase)|_{mod 2^{t}}), c : ()
# 49	instantiation	71, 72, 73, 74	{m in {0 .. 2^{t} - 1}} |- (|m - floor(2^{t} * phase)|_{mod 2^{t}} + |m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}}) = |m - (2^{t} * phase)|_{mod 2^{t}}
# 	a : |m - floor(2^{t} * phase)|_{mod 2^{t}}, b : |m - floor(2^{t} * phase)|_{mod 2^{t}}, c : |m - (2^{t} * phase)|_{mod 2^{t}}
# 50	assumption		{|m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)} |- |m - b_{f}|_{mod 2^{t}} <= (2^{t - n} - 1)
# 51	axiom		|- b_{f} = floor(2^{t} * phase)
# 	proveit.physics.quantum.QPE._best_floor_def
# 52	instantiation	147, 151, 271, 276, 152, 75, 78, 76, 125	|- ((2^{t - n} - 1) + 1) =  \\ (2^{t - n} - 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t - n}, -1), c : (1)
# 53	instantiation	77, 125, 78, 79	|- (2^{t - n} - 1 + 1) = 2^{t - n}
# 	a : 1, b : 1, c : 2^{t - n}
# 54	instantiation	172, 80, 81	{m in {0 .. 2^{t} - 1}} |- (2^{t} * (m / 2^{t})) = ((1 / 1) * (m / 1))
# 	P(_a) : _a = ((1 / 1) * (m / 1)), x : ((1 * 2^{t}) / 1) * (m / (2^{t} * 1)), y : 2^{t} * (m / 2^{t})
# 55	instantiation	127, 82, 83, 84	{m in {0 .. 2^{t} - 1}} |- ((1 / 1) * (m / 1)) = m
# 	a : (1 / 1) * (m / 1), b : 1 * (m / 1), c : 1 * m, d : m
# 56	instantiation	163, 85, 86	{m in {0 .. 2^{t} - 1}} |- ((m / 2^{t}) - phase) in Real
# 	a : m / 2^{t}, b : -phase
# 57	instantiation	87, 245	|- 1 != 0
# 	n : 1
# 58	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 59	instantiation	207, 88	|- (t * 1) = t
# 	x : t
# 60	instantiation	169	|- |(t, -n)| = |(1, ..., 2)|
# 	a : t, b : -n
# 61	instantiation	274, 241, 89	|- (-t) in Complex
# 	A : Real, B : Complex, x : -t
# 62	instantiation	274, 241, 164	|- (-n) in Complex
# 	A : Real, B : Complex, x : -n
# 63	instantiation	171	|- t = t
# 	x : t
# 64	instantiation	90, 118, 137, 141, 91*	{m in {0 .. 2^{t} - 1}} |- |-(2^{t} * phase) + floor(2^{t} * phase)|_{mod 2^{t}} >= (|m - (2^{t} * phase)|_{mod 2^{t}} - |m - floor(2^{t} * phase)|_{mod 2^{t}})
# 	a : m - (2^{t} * phase), b : m - floor(2^{t} * phase), N : 2^{t}
# 65	instantiation	97, 153, 189	|- (-(2^{t} * phase) + floor(2^{t} * phase)) = (floor(2^{t} * phase) - (2^{t} * phase))
# 	a : -(2^{t} * phase), b : floor(2^{t} * phase)
# 66	instantiation	92, 93, 141, 94, 95*	|- |floor(2^{t} * phase) - (2^{t} * phase)|_{mod 2^{t}} = (-floor(2^{t} * phase) + (2^{t} * phase))
# 	x : floor(2^{t} * phase) - (2^{t} * phase), N : 2^{t}
# 67	instantiation	112, 96	|- ((2^{t} * phase) - floor(2^{t} * phase)) <= 1
# 	x : (2^{t} * phase) - floor(2^{t} * phase), y : 1
# 68	instantiation	97, 98, 188	|- (-floor(2^{t} * phase) + (2^{t} * phase)) = ((2^{t} * phase) - floor(2^{t} * phase))
# 	a : -floor(2^{t} * phase), b : 2^{t} * phase
# 69	instantiation	169	|- |(|m - (2^{t} * phase)|_{mod 2^{t}}, -|m - floor(2^{t} * phase)|_{mod 2^{t}})| = |(1, ..., 2)|
# 	a : |m - (2^{t} * phase)|_{mod 2^{t}}, b : -|m - floor(2^{t} * phase)|_{mod 2^{t}}
# 70	instantiation	274, 241, 99	{m in {0 .. 2^{t} - 1}} |- (-|m - floor(2^{t} * phase)|_{mod 2^{t}}) in Complex
# 	A : Real, B : Complex, x : -|m - floor(2^{t} * phase)|_{mod 2^{t}}
# 71	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 72	instantiation	274, 241, 117	{m in {0 .. 2^{t} - 1}} |- |m - floor(2^{t} * phase)|_{mod 2^{t}} in Complex
# 	A : Real, B : Complex, x : |m - floor(2^{t} * phase)|_{mod 2^{t}}
# 73	instantiation	274, 241, 100	{m in {0 .. 2^{t} - 1}} |- |m - (2^{t} * phase)|_{mod 2^{t}} in Complex
# 	A : Real, B : Complex, x : |m - (2^{t} * phase)|_{mod 2^{t}}
# 74	instantiation	171	|- |m - floor(2^{t} * phase)|_{mod 2^{t}} = |m - floor(2^{t} * phase)|_{mod 2^{t}}
# 	x : |m - floor(2^{t} * phase)|_{mod 2^{t}}
# 75	instantiation	169	|- |(2^{t - n}, -1)| = |(1, ..., 2)|
# 	a : 2^{t - n}, b : -1
# 76	instantiation	274, 241, 101	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 77	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 78	instantiation	274, 241, 102	|- 2^{t - n} in Complex
# 	A : Real, B : Complex, x : 2^{t - n}
# 79	instantiation	171	|- 1 = 1
# 	x : 1
# 80	instantiation	103, 125, 183, 104, 193	{m in {0 .. 2^{t} - 1}} |- (((1 * 2^{t}) / 1) * (m / (2^{t} * 1))) = ((1 / 1) * (m / 1))
# 	a : 1, d : m, b : 2^{t}, c : 1, e : 1
# 81	instantiation	201, 105, 106	|- (((1 * 2^{t}) / 1) * (m / (2^{t} * 1))) = (2^{t} * (m / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (m / (2^{t} * 1)), y : 2^{t} * (m / (2^{t} * 1)), z : 2^{t} * (m / 2^{t})
# 82	instantiation	217, 107	|- ((1 / 1) * (m / 1)) = (1 * (m / 1))
# 	f(_a) : _a * (m / 1), x : 1 / 1, y : 1
# 83	instantiation	217, 108	{m in {0 .. 2^{t} - 1}} |- (1 * (m / 1)) = (1 * m)
# 	f(_a) : 1 * _a, x : m / 1, y : m
# 84	instantiation	180, 183	{m in {0 .. 2^{t} - 1}} |- (1 * m) = m
# 	x : m
# 85	instantiation	109, 197, 252, 138	{m in {0 .. 2^{t} - 1}} |- (m / 2^{t}) in Real
# 	a : m, b : 2^{t}
# 86	instantiation	184, 253	|- (-phase) in Real
# 	a : phase
# 87	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 88	instantiation	274, 241, 216	|- t in Complex
# 	A : Real, B : Complex, x : t
# 89	instantiation	184, 216	|- (-t) in Real
# 	a : t
# 90	conjecture		|- forall_{a in Real, b in Real, N in RealPos} (|a - b|_{mod N} >= (|a|_{mod N} - |b|_{mod N}))
# 	proveit.numbers.modular.mod_abs_of_difference_bound
# 91	instantiation	201, 110, 111	{m in {0 .. 2^{t} - 1}} |- ((m - (2^{t} * phase)) - (m - floor(2^{t} * phase))) = (-(2^{t} * phase) + floor(2^{t} * phase))
# 	x : (m - (2^{t} * phase)) - (m - floor(2^{t} * phase)), y : (m - (2^{t} * phase)) + (-m + floor(2^{t} * phase)), z : -(2^{t} * phase) + floor(2^{t} * phase)
# 92	conjecture		|- forall_{x in Real, N in RealPos | |x| <= (N / 2)} (|x|_{mod N} = |x|)
# 	proveit.numbers.modular.mod_abs_x_reduce_to_abs_x
# 93	instantiation	163, 200, 170	|- (floor(2^{t} * phase) - (2^{t} * phase)) in Real
# 	a : floor(2^{t} * phase), b : -(2^{t} * phase)
# 94	instantiation	112, 113	|- |floor(2^{t} * phase) - (2^{t} * phase)| <= (2^{t} / 2)
# 	x : |floor(2^{t} * phase) - (2^{t} * phase)|, y : 2^{t} / 2
# 95	instantiation	114, 115, 116*	|- |floor(2^{t} * phase) - (2^{t} * phase)| = (-floor(2^{t} * phase) + (2^{t} * phase))
# 	x : floor(2^{t} * phase) - (2^{t} * phase)
# 96	instantiation	155, 259, 260, 212	|- ((2^{t} * phase) - floor(2^{t} * phase)) < 1
# 	a : 0, b : 1, x : (2^{t} * phase) - floor(2^{t} * phase)
# 97	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 98	instantiation	274, 241, 160	|- (-floor(2^{t} * phase)) in Complex
# 	A : Real, B : Complex, x : -floor(2^{t} * phase)
# 99	instantiation	184, 117	{m in {0 .. 2^{t} - 1}} |- (-|m - floor(2^{t} * phase)|_{mod 2^{t}}) in Real
# 	a : |m - floor(2^{t} * phase)|_{mod 2^{t}}
# 100	instantiation	136, 118, 252, 138	{m in {0 .. 2^{t} - 1}} |- |m - (2^{t} * phase)|_{mod 2^{t}} in Real
# 	a : m - (2^{t} * phase), b : 2^{t}
# 101	instantiation	274, 264, 119	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 102	instantiation	274, 120, 121	|- 2^{t - n} in Real
# 	A : RealPos, B : Real, x : 2^{t - n}
# 103	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_numer_left
# 104	instantiation	274, 205, 122	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 105	instantiation	217, 123	|- (((1 * 2^{t}) / 1) * (m / (2^{t} * 1))) = (2^{t} * (m / (2^{t} * 1)))
# 	f(_a) : _a * (m / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 106	instantiation	217, 124	|- (2^{t} * (m / (2^{t} * 1))) = (2^{t} * (m / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : m / (2^{t} * 1), y : m / 2^{t}
# 107	instantiation	208, 125	|- (1 / 1) = 1
# 	x : 1
# 108	instantiation	208, 183	{m in {0 .. 2^{t} - 1}} |- (m / 1) = m
# 	x : m
# 109	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 110	instantiation	217, 126	{m in {0 .. 2^{t} - 1}} |- ((m - (2^{t} * phase)) - (m - floor(2^{t} * phase))) = ((m - (2^{t} * phase)) + (-m + floor(2^{t} * phase)))
# 	f(_a) : (m - (2^{t} * phase)) + _a, x : -(m - floor(2^{t} * phase)), y : -m + floor(2^{t} * phase)
# 111	instantiation	127, 128, 129, 130	{m in {0 .. 2^{t} - 1}} |- ((m - (2^{t} * phase)) + (-m + floor(2^{t} * phase))) = (-(2^{t} * phase) + floor(2^{t} * phase))
# 	a : (m - (2^{t} * phase)) + (-m + floor(2^{t} * phase)), b : m - (2^{t} * phase) + (-m + floor(2^{t} * phase)), c : m - (2^{t} * phase) - m + floor(2^{t} * phase), d : -(2^{t} * phase) + floor(2^{t} * phase)
# 112	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 113	instantiation	131, 132, 133	|- |floor(2^{t} * phase) - (2^{t} * phase)| < (2^{t} / 2)
# 	x : |floor(2^{t} * phase) - (2^{t} * phase)|, y : 1, z : 2^{t} / 2
# 114	conjecture		|- forall_{x | x <= 0} (|x| = (-x))
# 	proveit.numbers.absolute_value.abs_neg_elim
# 115	instantiation	134, 135	|- (floor(2^{t} * phase) - (2^{t} * phase)) <= 0
# 	a : floor(2^{t} * phase), b : 2^{t} * phase
# 116	instantiation	145, 189, 188	|- (-(floor(2^{t} * phase) - (2^{t} * phase))) = (-floor(2^{t} * phase) + (2^{t} * phase))
# 	a : floor(2^{t} * phase), b : 2^{t} * phase
# 117	instantiation	136, 137, 252, 138	{m in {0 .. 2^{t} - 1}} |- |m - floor(2^{t} * phase)|_{mod 2^{t}} in Real
# 	a : m - floor(2^{t} * phase), b : 2^{t}
# 118	instantiation	163, 197, 170	{m in {0 .. 2^{t} - 1}} |- (m - (2^{t} * phase)) in Real
# 	a : m, b : -(2^{t} * phase)
# 119	instantiation	274, 269, 256	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 120	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 121	instantiation	165, 215, 139	|- 2^{t - n} in RealPos
# 	a : 2, b : t - n
# 122	instantiation	274, 140, 141	|- 2^{t} in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2^{t}
# 123	instantiation	201, 142, 143	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 124	instantiation	217, 144	|- (m / (2^{t} * 1)) = (m / 2^{t})
# 	f(_a) : m / _a, x : 2^{t} * 1, y : 2^{t}
# 125	instantiation	274, 241, 260	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 126	instantiation	145, 183, 189	{m in {0 .. 2^{t} - 1}} |- (-(m - floor(2^{t} * phase))) = (-m + floor(2^{t} * phase))
# 	a : m, b : floor(2^{t} * phase)
# 127	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 128	instantiation	147, 151, 271, 276, 152, 148, 183, 153, 146	{m in {0 .. 2^{t} - 1}} |- ((m - (2^{t} * phase)) + (-m + floor(2^{t} * phase))) =  \\ (m - (2^{t} * phase) + (-m + floor(2^{t} * phase)))
# 	i : 0, j : 2, k : 1, a : (), b : (m, -(2^{t} * phase)), c : (-m + floor(2^{t} * phase))
# 129	instantiation	147, 271, 151, 148, 149, 152, 183, 153, 168, 189	{m in {0 .. 2^{t} - 1}} |- (m - (2^{t} * phase) + (-m + floor(2^{t} * phase))) =  \\ (m - (2^{t} * phase) - m + floor(2^{t} * phase))
# 	i : 2, j : 2, k : 0, a : (m, -(2^{t} * phase)), b : (-m, floor(2^{t} * phase)), c : ()
# 130	instantiation	150, 151, 276, 152, 183, 153, 189, 154	{m in {0 .. 2^{t} - 1}} |- (m - (2^{t} * phase) - m + floor(2^{t} * phase)) = (-(2^{t} * phase) + floor(2^{t} * phase))
# 	i : 0, j : 1, k : 1, a : (), b : m, c : (-(2^{t} * phase)), d : m, e : (floor(2^{t} * phase))
# 131	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 132	instantiation	155, 259, 260, 156	|- |floor(2^{t} * phase) - (2^{t} * phase)| < 1
# 	a : 0, b : 1, x : |floor(2^{t} * phase) - (2^{t} * phase)|
# 133	instantiation	185, 157, 158	|- (2^{t} / 2) >= 1
# 	P(_a) : _a >= 1, x : 2^{t} / 2, y : 2^{t - 1}
# 134	conjecture		|- forall_{a, b | a <= b} ((a - b) <= 0)
# 	proveit.numbers.addition.subtraction.nonpos_difference
# 135	instantiation	159, 239	|- floor(2^{t} * phase) <= (2^{t} * phase)
# 	x : 2^{t} * phase
# 136	conjecture		|- forall_{a, b in Real | b != 0} (|a|_{mod b} in Real)
# 	proveit.numbers.modular.mod_abs_real_closure
# 137	instantiation	163, 197, 160	{m in {0 .. 2^{t} - 1}} |- (m - floor(2^{t} * phase)) in Real
# 	a : m, b : -floor(2^{t} * phase)
# 138	instantiation	161, 219, 162	|- 2^{t} != 0
# 	a : 2, b : t
# 139	instantiation	163, 216, 164	|- (t - n) in Real
# 	a : t, b : -n
# 140	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 141	instantiation	165, 215, 216	|- 2^{t} in RealPos
# 	a : 2, b : t
# 142	instantiation	217, 166	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 143	instantiation	208, 181	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 144	instantiation	207, 181	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 145	conjecture		|- forall_{a, b in Complex} ((-(a - b)) = (-a + b))
# 	proveit.numbers.negation.distribute_neg_through_subtract
# 146	instantiation	167, 168, 189	{m in {0 .. 2^{t} - 1}} |- (-m + floor(2^{t} * phase)) in Complex
# 	a : -m, b : floor(2^{t} * phase)
# 147	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 148	instantiation	169	|- |(m, -(2^{t} * phase))| = |(1, ..., 2)|
# 	a : m, b : -(2^{t} * phase)
# 149	instantiation	169	|- |(-m, floor(2^{t} * phase))| = |(1, ..., 2)|
# 	a : -m, b : floor(2^{t} * phase)
# 150	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 151	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 152	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 153	instantiation	274, 241, 170	|- (-(2^{t} * phase)) in Complex
# 	A : Real, B : Complex, x : -(2^{t} * phase)
# 154	instantiation	171	|- m = m
# 	x : m
# 155	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 156	instantiation	172, 173, 174	|- |floor(2^{t} * phase) - (2^{t} * phase)| in [0,1)
# 	P(_a) : _a in [0,1), x : |(2^{t} * phase) - floor(2^{t} * phase)|, y : |floor(2^{t} * phase) - (2^{t} * phase)|
# 157	instantiation	175, 235	|- 2^{t - 1} >= 1
# 	n : 2^{t - 1}
# 158	instantiation	201, 176, 177	|- (2^{t} / 2) = 2^{t - 1}
# 	x : 2^{t} / 2, y : (2 * 2^{t - 1}) / 2, z : 2^{t - 1}
# 159	conjecture		|- forall_{x in Real} (floor(x) <= x)
# 	proveit.numbers.rounding.floor_x_le_x
# 160	instantiation	184, 200	|- (-floor(2^{t} * phase)) in Real
# 	a : floor(2^{t} * phase)
# 161	conjecture		|- forall_{a, b in RationalNonZero} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_rational_non_zero__not_zero
# 162	instantiation	274, 231, 178	|- t in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : t
# 163	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 164	instantiation	184, 179	|- (-n) in Real
# 	a : n
# 165	conjecture		|- forall_{a in RealPos, b in Real} (a^{b} in RealPos)
# 	proveit.numbers.exponentiation.exp_real_pos_closure
# 166	instantiation	180, 181	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 167	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 168	instantiation	182, 183	{m in {0 .. 2^{t} - 1}} |- (-m) in Complex
# 	a : m
# 169	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 170	instantiation	184, 239	|- (-(2^{t} * phase)) in Real
# 	a : 2^{t} * phase
# 171	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 172	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 173	instantiation	185, 212, 186	|- |(2^{t} * phase) - floor(2^{t} * phase)| in [0,1)
# 	P(_a) : _a in [0,1), x : |(2^{t} * phase) - floor(2^{t} * phase)|, y : (2^{t} * phase) - floor(2^{t} * phase)
# 174	instantiation	187, 188, 189	|- |(2^{t} * phase) - floor(2^{t} * phase)| = |floor(2^{t} * phase) - (2^{t} * phase)|
# 	a : 2^{t} * phase, b : floor(2^{t} * phase)
# 175	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 176	instantiation	217, 190	|- (2^{t} / 2) = ((2 * 2^{t - 1}) / 2)
# 	f(_a) : _a / 2, x : 2^{t}, y : 2 * 2^{t - 1}
# 177	instantiation	191, 192, 193, 209, 194*, 195*	|- ((2 * 2^{t - 1}) / 2) = 2^{t - 1}
# 	x : 2, z : 1, y : 2^{t - 1}
# 178	instantiation	274, 244, 273	|- t in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : t
# 179	instantiation	233, 234, 196	|- n in Real
# 	A : NaturalPos, B : Real, x : n
# 180	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 181	instantiation	274, 241, 252	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 182	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 183	instantiation	274, 241, 197	{m in {0 .. 2^{t} - 1}} |- m in Complex
# 	A : Real, B : Complex, x : m
# 184	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 185	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 186	instantiation	198, 199	|- |(2^{t} * phase) - floor(2^{t} * phase)| = ((2^{t} * phase) - floor(2^{t} * phase))
# 	x : (2^{t} * phase) - floor(2^{t} * phase)
# 187	conjecture		|- forall_{a, b in Complex} (|a - b| = |b - a|)
# 	proveit.numbers.absolute_value.abs_diff_reversal
# 188	instantiation	274, 241, 239	|- (2^{t} * phase) in Complex
# 	A : Real, B : Complex, x : 2^{t} * phase
# 189	instantiation	274, 241, 200	|- floor(2^{t} * phase) in Complex
# 	A : Real, B : Complex, x : floor(2^{t} * phase)
# 190	instantiation	201, 202, 203	|- 2^{t} = (2 * 2^{t - 1})
# 	x : 2^{t}, y : 2^{1} * 2^{t - 1}, z : 2 * 2^{t - 1}
# 191	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 192	instantiation	274, 205, 204	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 193	instantiation	274, 205, 206	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 194	instantiation	207, 229	|- (2 * 1) = 2
# 	x : 2
# 195	instantiation	208, 209	|- (2^{t - 1} / 1) = 2^{t - 1}
# 	x : 2^{t - 1}
# 196	axiom		|- n in NaturalPos
# 	proveit.physics.quantum.QPE._n_in_natural_pos
# 197	instantiation	274, 264, 210	{m in {0 .. 2^{t} - 1}} |- m in Real
# 	A : Rational, B : Real, x : m
# 198	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 199	instantiation	211, 259, 260, 212	|- 0 <= ((2^{t} * phase) - floor(2^{t} * phase))
# 	a : 0, b : 1, x : (2^{t} * phase) - floor(2^{t} * phase)
# 200	instantiation	274, 264, 213	|- floor(2^{t} * phase) in Real
# 	A : Rational, B : Real, x : floor(2^{t} * phase)
# 201	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 202	instantiation	214, 215, 216, 260	|- 2^{t} = (2^{1} * 2^{t - 1})
# 	a : 2, b : t, c : 1
# 203	instantiation	217, 218	|- (2^{1} * 2^{t - 1}) = (2 * 2^{t - 1})
# 	f(_a) : _a * 2^{t - 1}, x : 2^{1}, y : 2
# 204	instantiation	274, 220, 219	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 205	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 206	instantiation	274, 220, 221	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 207	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 208	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 209	instantiation	274, 241, 222	|- 2^{t - 1} in Complex
# 	A : Real, B : Complex, x : 2^{t - 1}
# 210	instantiation	274, 269, 223	{m in {0 .. 2^{t} - 1}} |- m in Rational
# 	A : Integer, B : Rational, x : m
# 211	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 212	instantiation	224, 239	|- ((2^{t} * phase) - floor(2^{t} * phase)) in [0,1)
# 	x : 2^{t} * phase
# 213	instantiation	274, 269, 225	|- floor(2^{t} * phase) in Rational
# 	A : Integer, B : Rational, x : floor(2^{t} * phase)
# 214	conjecture		|- forall_{a in RealPos, b in Real, c in Real} (a^{b} = (a^{c} * a^{b - c}))
# 	proveit.numbers.exponentiation.exp_factored_real
# 215	instantiation	274, 226, 227	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 216	instantiation	233, 234, 273	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 217	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 218	instantiation	228, 229	|- 2^{1} = 2
# 	x : 2
# 219	instantiation	274, 231, 230	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 220	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 221	instantiation	274, 231, 232	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 222	instantiation	233, 234, 235	|- 2^{t - 1} in Real
# 	A : NaturalPos, B : Real, x : 2^{t - 1}
# 223	instantiation	274, 236, 237	{m in {0 .. 2^{t} - 1}} |- m in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : m
# 224	conjecture		|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 	proveit.numbers.rounding.real_minus_floor_interval
# 225	instantiation	238, 239	|- floor(2^{t} * phase) in Integer
# 	x : 2^{t} * phase
# 226	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 227	instantiation	274, 240, 243	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 228	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 229	instantiation	274, 241, 242	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 230	instantiation	274, 244, 243	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 231	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 232	instantiation	274, 244, 245	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 233	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 234	instantiation	246, 247	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 235	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 236	instantiation	248, 249, 250	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 237	assumption		{m in {0 .. 2^{t} - 1}} |- m in {0 .. 2^{t} - 1}
# 238	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 239	instantiation	251, 252, 253	|- (2^{t} * phase) in Real
# 	a : 2^{t}, b : phase
# 240	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 241	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 242	instantiation	274, 264, 254	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 243	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 244	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 245	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 246	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 247	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 248	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 249	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 250	instantiation	255, 263, 256	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 251	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 252	instantiation	274, 264, 257	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 253	instantiation	258, 259, 260, 261	|- phase in Real
# 	a : 0, b : 1, x : phase
# 254	instantiation	274, 269, 267	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 255	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 256	instantiation	262, 270	|- (-1) in Integer
# 	a : 1
# 257	instantiation	274, 269, 263	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 258	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 259	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 260	instantiation	274, 264, 265	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 261	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 262	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 263	instantiation	266, 267, 268	|- 2^{t} in Integer
# 	a : 2, b : t
# 264	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 265	instantiation	274, 269, 270	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 266	conjecture		|- forall_{a in Integer, b in Natural} (a^{b} in Integer)
# 	proveit.numbers.exponentiation.exp_int_closure
# 267	instantiation	274, 275, 271	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 268	instantiation	274, 272, 273	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 269	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 270	instantiation	274, 275, 276	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 271	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 272	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 273	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 274	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 275	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 276	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
