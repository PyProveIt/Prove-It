# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_m_evaluation">_alpha_m_evaluation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import k, l, m, n, t, defaults
from proveit.logic import InSet
from proveit.numbers import Mult
from proveit.physics.quantum.QPE import ( _m_domain, _t ) # QPE Common Expressions
from proveit.physics.quantum.QPE import (                 # QPE Axioms
    _alpha_m_def, _Psi_def )
from proveit.physics.quantum.QPE import (                 # QPE Theorems
    _phase_is_real, _psi_t_var_formula, _t_in_natural_pos )
from proveit.physics.quantum.QFT import invFT_on_matrix_elem

# %%
# %proving _alpha_m_evaluation
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_alpha_m_evaluation">_alpha_m_evaluation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1973ff1b37f0d1edf492e28b66d82bc0f5a63a3e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/caf49173b3711e4a248a8274f0b087173d02bcf60/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _alpha_m_evaluation.conditions
# Out:
# Expression notebook is being updated for (m in {0 .. 2^{t} - 1})
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/553d5598dac26513c310f953cbd1ba9111fc3e510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_alpha_m_def
# Out:
# |- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))

# %%
alpha_m_eq_01 = _alpha_m_def.instantiate()
# Out:
# <strong id="alpha_m_eq_01">alpha_m_eq_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/9adccdb9d9131ba21104ad193c835362a79e02460/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/7ef73f638b7eceb945bc406413dceae5b95f80cf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_Psi_def
# Out:
# |- |Psi> = (FT^{dag}_{t} . |psi_{t}>)

# %%
alpha_m_eq_02 = _Psi_def.sub_right_side_into(alpha_m_eq_01)
# Out:
# <strong id="alpha_m_eq_02">alpha_m_eq_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/ab51eddf4957b930414a7eed9ae5cf8c9e5deed80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/033cd799473c4cdc43def70fba3942f96382d44f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_psi_t_var_formula
# Out:
# |- forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))

# %%
# This instantiation requires we know that _t is in NaturalPos
psi_formula = _psi_t_var_formula.instantiate({t:_t})
# Out:
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * |k〉_{t} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# Expression notebook is being updated for (1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (|psi_{t}>, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# <strong id="psi_formula">psi_formula:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/d893f96d5486b3e6bd7dcb045c3c6491324b97380/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/38c13344ce5f2bea1b766a9506da5b294db378e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Auto_simplification here pulls the constant coefficient
# out to the front of the bra-ket; for that auto-simplification
# factoring to work, however, we need the _phase_is_real theorem
# and the correct domain assumption for m.
alpha_m_eq_03 = psi_formula.sub_right_side_into(alpha_m_eq_02)
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}})
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}), Complex^{2^{t}})
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}}
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}}), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}})
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * |k〉_{t}) in Complex^{2^{t}})] =>  \\ ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})) in Complex^{2^{t}})
# Expression notebook is being updated for ({0 .. 2^{t} - 1}, Integer)
# Expression notebook is being updated for {0 .. 2^{t} - 1} proper_subset Integer
# Expression notebook is being updated for (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
# Expression notebook is being updated for (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# Expression notebook is being updated for (FT^{dag}_{t}, (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (FT^{dag}_{t}, 1 / 2^{t / 2}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (1 / 2^{t / 2}, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for |(FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))|
# Expression notebook is being updated for (|(FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))|, |(1, ..., 2)|)
# Expression notebook is being updated for |(FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))| = |(1, ..., 2)|
# Expression notebook is being updated for (1 / 2^{t / 2}, FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m|, FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for {t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m|, (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# Expression notebook is being updated for ({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), ({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# Expression notebook is being updated for ({t}_〈m|, FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for {t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), Q*)
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) in_c Q*
# Expression notebook is being updated for ({t}_〈m|, 1 / 2^{t / 2}, FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for {t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), {t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
# Expression notebook is being updated for (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# Expression notebook is being updated for ({t}_〈m|, 1 / 2^{t / 2}, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Q*)
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (1 / 2^{t / 2}, {t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for |({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))|
# Expression notebook is being updated for (|({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))|, |(1, 2, ..., 3)|)
# Expression notebook is being updated for |({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))| = |(1, 2, ..., 3)|
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Complex)
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Complex)
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# Expression notebook is being updated for (1 / 2^{t / 2}, {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for (alpha_{m}, (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# Expression notebook is being updated for alpha_{m} = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# <strong id="alpha_m_eq_03">alpha_m_eq_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/c175be1a525a3c2f096ffc22b2d959a57849844c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/aab9802102c90c7d83dc490cc59403160aeb9ef40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha_m_eq_04 = alpha_m_eq_03.inner_expr().rhs.operands[1].distribute(2)
# Out:
# Expression notebook is being updated for {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}., k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))), [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}, {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}, e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}. = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# Expression notebook is being updated for {_a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {_a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {_a(k) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k=0}^{2^{t} - 1} _a(k)
# Expression notebook is being updated for (k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for {(e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})), Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex), (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)] =>  \\ ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*, ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# Expression notebook is being updated for (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*) =>  \\ (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# Expression notebook is being updated for (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# Expression notebook is being updated for (alpha_{m}, (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# Expression notebook is being updated for alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# <strong id="alpha_m_eq_04">alpha_m_eq_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/c653c05099a2e1758d1ff79d75193daca618998c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/94f12783feabc9770f5df255c445eb151d7e72840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# for convenience and clarity we name the summation domain
k_domain = psi_formula.rhs.operands[1].domain
# Out:
# <strong id="k_domain">k_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/common/0107914a254b4cba063b4849ea3d536e6979ec8c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
invFT_on_matrix_elem
# Out:
# |- forall_{n in NaturalPos} [forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]

# %%
matrix_elem = invFT_on_matrix_elem.instantiate(
    {n:_t, l:m}, assumptions=[InSet(k, k_domain), InSet(m, _m_domain)])
# Out:
# <strong id="matrix_elem">matrix_elem:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/bebbf1fc88eed6e2163d89d1b1d816b81b88d16c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/c019d655b17ea3d5ae40460ffa476136a76add270/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# We don't want to combine the two different exponentials through auto-simplification.
Mult.change_simplification_directives(combine_all_exponents=False)
alpha_m_eq_05 = (alpha_m_eq_04.inner_expr().rhs.operands[1]
               .summand.operands[1].substitute(matrix_elem))
# Out:
# Expression notebook is being updated for {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}., k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for [k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.]
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})), [k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for ({t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}, {t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# Expression notebook is being updated for {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# Expression notebook is being updated for ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}, (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# Expression notebook is being updated for {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * _a(k) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))
# Expression notebook is being updated for (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k)))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k)))
# Expression notebook is being updated for (alpha_{m}, (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))))
# Expression notebook is being updated for alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k))))
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# Expression notebook is being updated for (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (alpha_{m}, (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))), alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))))
# Expression notebook is being updated for (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))) = (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))))
# <strong id="alpha_m_eq_05">alpha_m_eq_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/cb3c59ef31117833eb58f5c290b2d5e3b50c37d40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/5aa81649d713ec9dd50dd0e258bd46dd0089e0cd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
const_factor = alpha_m_eq_05.rhs.operands[0]
# Out:
# <strong id="const_factor">const_factor:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/ccd7d4513d46801d00c037e7baf45aec8b2653590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
alpha_m_eq_06 = alpha_m_eq_05.inner_expr().rhs.operands[1].factor(const_factor)
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.]
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for (k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# Expression notebook is being updated for (a_{1}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}),c_{1}, c_{2}, ..., c_{0})
# Expression notebook is being updated for a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}
# Expression notebook is being updated for {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})
# Expression notebook is being updated for (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}, Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
# Expression notebook is being updated for (a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))
# Expression notebook is being updated for {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
# Expression notebook is being updated for (a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).
# Expression notebook is being updated for ((a_{1}, c_{1}, c_{2}, ..., c_{0}) -> {(a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})) if a_{1} in Complex, (c_{1} in Complex) ,  (c_{2} in Complex) ,  ... ,  (c_{0} in Complex).)
# Expression notebook is being updated for forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex), forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0}))))
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] =>  \\ [forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))]
# Expression notebook is being updated for (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for |(1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))|
# Expression notebook is being updated for (|(1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))|, |(1, ..., 2)|)
# Expression notebook is being updated for |(1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}), Complex)
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex), (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex)
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] => ((Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex)
# Expression notebook is being updated for (1 / 2^{t / 2}, (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (1 / 2^{t / 2}, 1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), (1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) =  \\ ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for ((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for (alpha_{m}, (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# Expression notebook is being updated for alpha_{m} = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# <strong id="alpha_m_eq_06">alpha_m_eq_06:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/common/89d0188c50f606a85186776fad8a95883dbde6470/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/aaae4cff3f35c88178765a054acd906a4d5ab6c40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_evaluation/117f77989ae224f6ce19547513b32827728802a00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _alpha_m_evaluation may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_m_evaluation has been proven.
# Expression notebook is being updated for |((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))|
# Expression notebook is being updated for (|((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))|, |(1, ..., 2)|)
# Expression notebook is being updated for |((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# Expression notebook is being updated for |(1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))|
# Expression notebook is being updated for (|(1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))|, |(1, ..., 2)|)
# Expression notebook is being updated for |(1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))| = |(1, ..., 2)|
# Expression notebook is being updated for (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}, e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1})
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for (k -> ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.))
# Expression notebook is being updated for forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for (k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for [k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.]
# Expression notebook is being updated for (forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.), [k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for [forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for (k in {0 .. 2^{t} - 1}, (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# Expression notebook is being updated for (k in {0 .. 2^{t} - 1}) => ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# Expression notebook is being updated for {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. \\  = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}), Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# Expression notebook is being updated for ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# Expression notebook is being updated for ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))
# 1	instantiation	326, 2, 3	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	x : alpha_{m}, y : (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 2	instantiation	302, 4, 5, 6*	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	P(_a) : alpha_{m} = ((1 / 2^{t / 2}) * _a), x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), y : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 3	instantiation	7, 390, 8, 9, 10, 11	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	n : 2, f(_a, _b) : _a * _b, x : ((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), y : (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 4	instantiation	12, 13, 14	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	P : alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))), Q : alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 5	instantiation	326, 15, 16	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}), y : Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 6	instantiation	326, 17, 18	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) = ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : (1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))), y : (1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), z : (1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 7	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 8	instantiation	332	|- |((1 / 2^{t / 2})^{2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# 	a : (1 / 2^{t / 2})^{2}, b : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 9	instantiation	332	|- |(1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))| = |(1, ..., 2)|
# 	a : 1 / 2^{t}, b : Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# 10	instantiation	71, 19	|- (1 / 2^{t / 2})^{2} = (1 / 2^{t})
# 	x : 1 / 2^{t}, y : (1 / 2^{t / 2})^{2}
# 11	instantiation	335, 20	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 	f(_a) : Sum_{k} _a(k), x(k) : {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., y(k) : {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# 12	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 13	instantiation	302, 21, 22	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	P(_a) : alpha_{m} = ((1 / 2^{t / 2}) * _a), x : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 14	instantiation	335, 23, 24*, 25*, 26*	{m in {0 .. 2^{t} - 1}} |- (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))) = (alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))))
# 	f(_a) : alpha_{m} = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * _a(k)))), x(k) : {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}., y(k) : {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.
# 15	instantiation	335, 27	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) = (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	f(_a) : Sum(_a), x(k) : {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., y(k) : {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.
# 16	instantiation	71, 28	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) = ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	x : (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), y : Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 17	instantiation	316, 395, 390, 317, 29, 318, 252, 31	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))) =  \\ ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	i : 1, j : 2, k : 0, a : (1 / 2^{t / 2}), b : (1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})), c : ()
# 18	instantiation	153, 317, 390, 395, 318, 30, 252, 31, 32*	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ ((1 / 2^{t / 2})^{2} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 2^{t / 2}, 1 / 2^{t / 2}), c : (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 19	instantiation	189, 33, 34, 35	|- (1 / 2^{t}) = (1 / 2^{t / 2})^{2}
# 	a : 1 / 2^{t}, b : 2^{-t}, c : 2^{(-((1 / 2) * t)) * 2}, d : (1 / 2^{t / 2})^{2}
# 20	modus ponens	36, 37	{m in {0 .. 2^{t} - 1}} |- [k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.]
# 21	instantiation	302, 38, 39, 40*	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	P(_a) : alpha_{m} = ({t}_〈m| . (FT^{dag}_{t} . _a)), x : |psi_{t}>, y : (1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 22	modus ponens	41, 163	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 23	modus ponens	42, 43	{m in {0 .. 2^{t} - 1}} |- [k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.]
# 24	instantiation	125, 358	{k in {0 .. 2^{t} - 1}} |- {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# 	a : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, Q : k in {0 .. 2^{t} - 1}
# 25	instantiation	125, 358	{k in {0 .. 2^{t} - 1}} |- {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	a : (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, Q : k in {0 .. 2^{t} - 1}
# 26	instantiation	316, 395, 390, 317, 44, 318, 249, 252, 118	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})) =  \\ (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	i : 1, j : 2, k : 0, a : (e^{2 * pi * i * phase * k}), b : (1 / 2^{t / 2}, e^{-((2 * pi * i * k * m) / 2^{t})}), c : ()
# 27	modus ponens	45, 46	{m in {0 .. 2^{t} - 1}} |- [k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.]
# 28	instantiation	47, 318, 252	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))) =  \\ (Sum_{k = 0}^{2^{t} - 1} ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 	a : (1 / 2^{t / 2}), c : ()
# 29	instantiation	332	|- |(1 / 2^{t / 2}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))| = |(1, ..., 2)|
# 	a : 1 / 2^{t / 2}, b : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 30	instantiation	332	|- |(1 / 2^{t / 2}, 1 / 2^{t / 2})| = |(1, ..., 2)|
# 	a : 1 / 2^{t / 2}, b : 1 / 2^{t / 2}
# 31	modus ponens	48, 67	{m in {0 .. 2^{t} - 1}} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex
# 32	instantiation	49, 252, 382, 50*, 51*	|- ((1 / 2^{t / 2}) * (1 / 2^{t / 2})) = (1 / 2^{t / 2})^{2}
# 	a : 1 / 2^{t / 2}, m : 1, n : 1
# 33	instantiation	311, 265, 159, 160, 52*	|- (1 / 2^{t}) = 2^{-t}
# 	x : 1, y : 2^{t}
# 34	instantiation	335, 53	|- 2^{-t} = 2^{(-((1 / 2) * t)) * 2}
# 	f(_a) : 2^{_a}, x : -t, y : (-((1 / 2) * t)) * 2
# 35	instantiation	71, 54	|- 2^{(-((1 / 2) * t)) * 2} = (1 / 2^{t / 2})^{2}
# 	x : (1 / 2^{t / 2})^{2}, y : 2^{(-((1 / 2) * t)) * 2}
# 36	instantiation	55, 382	|- [forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}., g(k) : {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., a : (k), b : (k), c : (k)
# 37	generalization	56	{m in {0 .. 2^{t} - 1}} |- forall_{k} ({e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.)
# 38	instantiation	302, 57, 58	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ({t}_〈m| . (FT^{dag}_{t} . |psi_{t}>))
# 	P(_a) : alpha_{m} = ({t}_〈m| . _a), x : |Psi>, y : FT^{dag}_{t} . |psi_{t}>
# 39	instantiation	59, 392	|- |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	t : t
# 40	instantiation	326, 60, 61	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	x : {t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), z : (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 41	instantiation	62, 382, 390, 317, 226, 318, 63*	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*) =>  \\ (({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) \\  = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	j : 1, m : 2, n : 0, A : ({t}_〈m|, FT^{dag}_{t}), C : (), f(k) : e^{2 * pi * i * phase * k} * |k〉_{t}, Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 42	instantiation	138, 382	|- [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . |k〉_{t} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, g(k) : (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 43	generalization	64	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 44	instantiation	332	|- |(1 / 2^{t / 2}, e^{-((2 * pi * i * k * m) / 2^{t})})| = |(1, ..., 2)|
# 	a : 1 / 2^{t / 2}, b : e^{-((2 * pi * i * k * m) / 2^{t})}
# 45	instantiation	138, 382	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))] =>  \\ ([k -> {e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, g(k) : (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}), Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 46	generalization	65	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})))
# 47	modus ponens	66, 67	{m in {0 .. 2^{t} - 1}} |- forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))
# 48	instantiation	68	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] => ((Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})) in Complex)
# 	f(k) : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, x : k
# 49	conjecture		|- forall_{a in Complex, m in NaturalPos, n in NaturalPos} ((a^{m} * a^{n}) = a^{m + n})
# 	proveit.numbers.exponentiation.product_of_posnat_powers
# 50	instantiation	352, 252	|- (1 / 2^{t / 2})^{1} = (1 / 2^{t / 2})
# 	x : 1 / 2^{t / 2}
# 51	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 52	instantiation	326, 69, 70	|- (1 * (2^{t})^{-1}) = 2^{-t}
# 	x : 1 * (2^{t})^{-1}, y : 1 * 2^{-t}, z : 2^{-t}
# 53	instantiation	71, 72	|- (-t) = ((-((1 / 2) * t)) * 2)
# 	x : (-((1 / 2) * t)) * 2, y : -t
# 54	instantiation	326, 73, 74	|- (1 / 2^{t / 2})^{2} = 2^{(-((1 / 2) * t)) * 2}
# 	x : (1 / 2^{t / 2})^{2}, y : (2^{-((1 / 2) * t)})^{2}, z : 2^{(-((1 / 2) * t)) * 2}
# 55	axiom		|- forall_{i in NaturalPos} [forall_{f, g} ([forall_{a_{1}, a_{2}, ..., a_{i}} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> f(b_{1}, b_{2}, ..., b_{i})] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> g(c_{1}, c_{2}, ..., c_{i})]))]
# 	proveit.core_expr_types.lambda_maps.lambda_substitution
# 56	instantiation	75, 76	{m in {0 .. 2^{t} - 1}} |- {e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})} if k in {0 .. 2^{t} - 1}. \\  = {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.
# 	a : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, b : e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, Q : k in {0 .. 2^{t} - 1}
# 57	instantiation	77, 289	{m in {0 .. 2^{t} - 1}} |- alpha_{m} = ({t}_〈m| . |Psi>)
# 	m : m
# 58	axiom		|- |Psi> = (FT^{dag}_{t} . |psi_{t}>)
# 	proveit.physics.quantum.QPE._Psi_def
# 59	conjecture		|- forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	proveit.physics.quantum.QPE._psi_t_var_formula
# 60	instantiation	335, 78	|- ({t}_〈m| . (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))))
# 	f(_a) : {t}_〈m| . _a, x : FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), y : (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 61	instantiation	326, 79, 80	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), z : (1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 62	conjecture		|- forall_{j in NaturalPos, m in Natural, n in Natural} [forall_{A_{1}, A_{2}, ..., A_{m}, C_{1}, C_{2}, ..., C_{n}, f, Q} (((A_{1} .  A_{2} .  ... .  A_{m} . [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]. C_{1} .  C_{2} .  ... .  C_{n}) in_c Q*) =>  \\ ((A_{1} .  A_{2} .  ... .  A_{m} . [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]. C_{1} .  C_{2} .  ... .  C_{n}) \\  = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (A_{1} .  A_{2} .  ... .  A_{m} . f(b_{1}, b_{2}, ..., b_{j}). C_{1} .  C_{2} .  ... .  C_{n})]))]
# 	proveit.physics.quantum.algebra.qmult_distribution_over_summation
# 63	instantiation	326, 81, 82	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 	x : Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})), y : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})), z : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 64	instantiation	83, 392, 358, 289, 84*	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) = ((1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	n : t, k : k, l : m
# 65	instantiation	326, 85, 86	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) = ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 	x : e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}, y : (1 / 2^{t / 2}) * e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, z : (1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 66	instantiation	87, 395, 382, 317	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)] =>  \\ [forall_{a_{1}, c_{1}, c_{2}, ..., c_{0} in Complex} ((a_{1} * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))* c_{1} *  c_{2} *  ... *  c_{0}) =  \\ (Sum_{k = 0}^{2^{t} - 1} (a_{1} * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})* c_{1} *  c_{2} *  ... *  c_{0})))]
# 	i : 1, j : 1, k : 0, f(k) : e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}, Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 67	generalization	88	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex)
# 68	conjecture		|- forall_{f, Q} ([forall_{x | Q(x)} (f(x) in Complex)] => ([Sum_{x | Q(x)} f(x)] in Complex))
# 	proveit.numbers.summation.summation_complex_closure
# 69	instantiation	335, 89	|- (1 * (2^{t})^{-1}) = (1 * 2^{-t})
# 	f(_a) : 1 * _a, x : (2^{t})^{-1}, y : 2^{-t}
# 70	instantiation	274, 90	|- (1 * 2^{-t}) = 2^{-t}
# 	x : 2^{-t}
# 71	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 72	instantiation	91, 196, 353, 92*	|- ((-((1 / 2) * t)) * 2) = (-t)
# 	x : (1 / 2) * t, y : 2
# 73	instantiation	335, 93	|- (1 / 2^{t / 2})^{2} = (2^{-((1 / 2) * t)})^{2}
# 	f(_a) : _a^{2}, x : 1 / 2^{t / 2}, y : 2^{-((1 / 2) * t)}
# 74	instantiation	175, 353, 94, 362, 312	|- (2^{-((1 / 2) * t)})^{2} = 2^{(-((1 / 2) * t)) * 2}
# 	a : 2, b : -((1 / 2) * t), c : 2
# 75	axiom		|- forall_{a, b, Q | Q => (a = b)} ({a if Q. \\  = {b if Q.)
# 	proveit.core_expr_types.conditionals.conditional_substitution
# 76	deduction	95	{m in {0 .. 2^{t} - 1}} |- (k in {0 .. 2^{t} - 1}) => ((e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))
# 77	axiom		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} = ({t}_〈m| . |Psi>))
# 	proveit.physics.quantum.QPE._alpha_m_def
# 78	instantiation	189, 96, 97, 98	|- (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	a : FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), b : FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), c : (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), d : (1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 79	instantiation	326, 99, 100	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), z : (1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 80	instantiation	168, 169, 252, 101, 163, 102*	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	j : 3, a : 1 / 2^{t / 2}, B : ({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 81	instantiation	335, 103, 104*, 105*	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))) = (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 	f(_a) : Sum_{k=0}^{2^{t} - 1} _a(k), x(k) : {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}., y(k) : {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.
# 82	modus ponens	106, 107	{m in {0 .. 2^{t} - 1}} |- (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 83	conjecture		|- forall_{n in NaturalPos} [forall_{k, l in {0 .. 2^{n} - 1}} (({n}_〈l| . FT^{dag}_{n} . |k〉_{n}) = ((1 / 2^{n / 2}) * e^{(-(2 * pi * i * k * l)) / 2^{n}}))]
# 	proveit.physics.quantum.QFT.invFT_on_matrix_elem
# 84	instantiation	108, 158, 159, 160	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((-(2 * pi * i * k * m)) / 2^{t}) = (-((2 * pi * i * k * m) / 2^{t}))
# 	x : 2 * pi * i * k * m, y : 2^{t}
# 85	instantiation	109, 317, 395, 318, 249, 252, 118	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * (1 / 2^{t / 2}) * e^{-((2 * pi * i * k * m) / 2^{t})}) =  \\ ((1 / 2^{t / 2}) * e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})})
# 	i : 0, j : 1, k : 1, a : (), b : (e^{2 * pi * i * phase * k}), c : 1 / 2^{t / 2}, d : (e^{-((2 * pi * i * k * m) / 2^{t})})
# 86	instantiation	153, 395, 390, 317, 110, 318, 252, 249, 118	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) =  \\ ((1 / 2^{t / 2}) * (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}))
# 	i : 1, j : 2, k : 0, a : (1 / 2^{t / 2}), b : (e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})}), c : ()
# 87	conjecture		|- forall_{i in Natural, j in NaturalPos, k in Natural} [forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (a_{1} *  a_{2} *  ... *  a_{i} * f(b_{1}, b_{2}, ..., b_{j})* c_{1} *  c_{2} *  ... *  c_{k})])])]
# 	proveit.numbers.multiplication.distribute_through_summation
# 88	instantiation	329, 249, 118	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) in Complex
# 	a : e^{2 * pi * i * phase * k}, b : e^{-((2 * pi * i * k * m) / 2^{t})}
# 89	instantiation	175, 353, 347, 230, 312, 111*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 90	instantiation	280, 353, 112	|- 2^{-t} in Complex
# 	a : 2, b : -t
# 91	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 92	instantiation	189, 113, 114, 129	|- (((1 / 2) * t) * 2) = t
# 	a : ((1 / 2) * t) * 2, b : (1 / 2) * t * 2, c : t * 1, d : t
# 93	instantiation	326, 115, 116	|- (1 / 2^{t / 2}) = 2^{-((1 / 2) * t)}
# 	x : 1 / 2^{t / 2}, y : 1 / 2^{(1 / 2) * t}, z : 2^{-((1 / 2) * t)}
# 94	instantiation	117, 215	|- (-((1 / 2) * t)) in Real
# 	a : (1 / 2) * t
# 95	instantiation	337, 249, 118	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * e^{-((2 * pi * i * k * m) / 2^{t})}) = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# 	a : e^{2 * pi * i * phase * k}, b : e^{-((2 * pi * i * k * m) / 2^{t})}
# 96	instantiation	166, 252, 395, 317, 318, 119	|- (FT^{dag}_{t} . ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	alpha : 1 / 2^{t / 2}, l : 1, n : 0, A : (FT^{dag}_{t}), B : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}), C : ()
# 97	instantiation	167, 395, 252, 119	|- (FT^{dag}_{t} . (1 / 2^{t / 2}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, n : 1, b : 1 / 2^{t / 2}, A : (FT^{dag}_{t}), C : (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 98	instantiation	168, 384, 252, 162, 119	|- ((1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	j : 2, a : 1 / 2^{t / 2}, B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 99	instantiation	326, 120, 121	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) = ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	x : {t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))), y : {t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), z : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 100	instantiation	167, 395, 390, 252, 162, 163	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) =  \\ ((1 / 2^{t / 2}) . {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, n : 2, b : 1 / 2^{t / 2}, A : ({t}_〈m|), C : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 101	instantiation	322	|- |({t}_〈m|, FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))| = |(1, 2, ..., 3)|
# 	a : {t}_〈m|, b : FT^{dag}_{t}, c : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 102	instantiation	185, 252, 122	{m in {0 .. 2^{t} - 1}} |- ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) = ((1 / 2^{t / 2}) * ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	a : 1 / 2^{t / 2}, b : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 103	modus ponens	123, 124	{m in {0 .. 2^{t} - 1}} |- [k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.]
# 104	instantiation	125, 358	{k in {0 .. 2^{t} - 1}} |- {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}. = ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 	a : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), Q : k in {0 .. 2^{t} - 1}
# 105	instantiation	125, 358	{k in {0 .. 2^{t} - 1}} |- {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}. = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 	a : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q : k in {0 .. 2^{t} - 1}
# 106	instantiation	126, 382	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)] =>  \\ ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))) = (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))))
# 	j : 1, f(k) : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q(k) : k in {0 .. 2^{t} - 1}, b : (k)
# 107	generalization	127	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex)
# 108	conjecture		|- forall_{x, y in Complex | y != 0} (((-x) / y) = (-(x / y)))
# 	proveit.numbers.division.neg_frac_neg_numerator
# 109	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 110	instantiation	332	|- |(e^{2 * pi * i * phase * k}, e^{-((2 * pi * i * k * m) / 2^{t})})| = |(1, ..., 2)|
# 	a : e^{2 * pi * i * phase * k}, b : e^{-((2 * pi * i * k * m) / 2^{t})}
# 111	instantiation	128, 338, 265, 129*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 112	instantiation	195, 338	|- (-t) in Complex
# 	a : t
# 113	instantiation	316, 317, 390, 395, 318, 232, 339, 338, 353	|- (((1 / 2) * t) * 2) =  \\ ((1 / 2) * t * 2)
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 2, t), c : (2)
# 114	instantiation	326, 130, 131	|- ((1 / 2) * t * 2) = (t * 1)
# 	x : (1 / 2) * t * 2, y : t * 2 * (1 / 2), z : t * 1
# 115	instantiation	335, 284	|- (1 / 2^{t / 2}) = (1 / 2^{(1 / 2) * t})
# 	f(_a) : 1 / _a, x : 2^{t / 2}, y : 2^{(1 / 2) * t}
# 116	instantiation	311, 265, 132, 283, 133*	|- (1 / 2^{(1 / 2) * t}) = 2^{-((1 / 2) * t)}
# 	x : 1, y : 2^{(1 / 2) * t}
# 117	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 118	instantiation	280, 262, 134	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- e^{-((2 * pi * i * k * m) / 2^{t})} in Complex
# 	a : e, b : -((2 * pi * i * k * m) / 2^{t})
# 119	instantiation	204, 269, 255, 201	|- (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	H : Complex^{2^{t}}, X : Complex^{2^{t}}, A : FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 120	instantiation	166, 252, 395, 317, 318, 135	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . ((1 / 2^{t / 2}) * (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# 	alpha : 1 / 2^{t / 2}, l : 1, n : 0, A : ({t}_〈m|), B : FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 121	instantiation	161, 390, 384, 317, 222, 162, 318, 136	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 2, m : 2, n : 0, A : ({t}_〈m|, 1 / 2^{t / 2}), B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 122	instantiation	282, 137, 182	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# 	P(_a) : _a in Complex, x : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : ({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 123	instantiation	138, 382	|- [forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))] =>  \\ ([k -> {{t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}) if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}) if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), g(k) : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}), Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 124	generalization	139	{m in {0 .. 2^{t} - 1}} |- forall_{k in {0 .. 2^{t} - 1}} (({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})))
# 125	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 126	axiom		|- forall_{j in NaturalPos} [forall_{f, Q} ([forall_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} (f(b_{1}, b_{2}, ..., b_{j}) in Complex)] =>  \\ ([Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})] = [Sum_{b_{1}, b_{2}, ..., b_{j} | Q(b_{1}, b_{2}, ..., b_{j})} f(b_{1}, b_{2}, ..., b_{j})]))]
# 	proveit.linear_algebra.addition.scalar_sum_extends_number_sum
# 127	instantiation	329, 249, 186	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})) in Complex
# 	a : e^{2 * pi * i * phase * k}, b : {t}_〈m| . FT^{dag}_{t} . |k〉_{t}
# 128	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 129	instantiation	259, 338	|- (t * 1) = t
# 	x : t
# 130	instantiation	140, 317, 390, 318, 141, 339, 338, 353	|- ((1 / 2) * t * 2) =  \\ (t * 2 * (1 / 2))
# 	i : 0, j : 2, k : 0, a : (), b : 1 / 2, c : (t, 2), d : ()
# 131	instantiation	326, 142, 143	|- (t * 2 * (1 / 2)) = (t * 1)
# 	x : t * 2 * (1 / 2), y : t * (2 * (1 / 2)), z : t * 1
# 132	instantiation	280, 353, 196	|- 2^{(1 / 2) * t} in Complex
# 	a : 2, b : (1 / 2) * t
# 133	instantiation	326, 144, 145	|- (1 * (2^{(1 / 2) * t})^{-1}) = 2^{-((1 / 2) * t)}
# 	x : 1 * (2^{(1 / 2) * t})^{-1}, y : 1 * 2^{-((1 / 2) * t)}, z : 2^{-((1 / 2) * t)}
# 134	instantiation	195, 146	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- (-((2 * pi * i * k * m) / 2^{t})) in Complex
# 	a : (2 * pi * i * k * m) / 2^{t}
# 135	instantiation	282, 163, 147	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))), y : {t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 136	instantiation	282, 148, 149	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	P(_a) : _a in_c Q*, x : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), y : ({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))
# 137	instantiation	223, 269, 270, 224, 201	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in Complex
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m| . FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# 138	conjecture		|- forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))]
# 	proveit.core_expr_types.lambda_maps.general_lambda_substitution
# 139	instantiation	189, 150, 151, 152	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t})) = (e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t}))
# 	a : {t}_〈m| . FT^{dag}_{t} . (e^{2 * pi * i * phase * k} * |k〉_{t}), b : {t}_〈m| . FT^{dag}_{t} . e^{2 * pi * i * phase * k} . |k〉_{t}, c : e^{2 * pi * i * phase * k} . {t}_〈m| . FT^{dag}_{t} . |k〉_{t}, d : e^{2 * pi * i * phase * k} * ({t}_〈m| . FT^{dag}_{t} . |k〉_{t})
# 140	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* c_{1} *  c_{2} *  ... *  c_{j} * b* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.rightward_commutation
# 141	instantiation	332	|- |(t, 2)| = |(1, ..., 2)|
# 	a : t, b : 2
# 142	instantiation	153, 395, 390, 317, 154, 318, 338, 353, 339	|- (t * 2 * (1 / 2)) =  \\ (t * (2 * (1 / 2)))
# 	i : 1, j : 2, k : 0, a : (t), b : (2, 1 / 2), c : ()
# 143	instantiation	335, 155	|- (t * (2 * (1 / 2))) = (t * 1)
# 	f(_a) : t * _a, x : 2 * (1 / 2), y : 1
# 144	instantiation	335, 156	|- (1 * (2^{(1 / 2) * t})^{-1}) = (1 * 2^{-((1 / 2) * t)})
# 	f(_a) : 1 * _a, x : (2^{(1 / 2) * t})^{-1}, y : 2^{-((1 / 2) * t)}
# 145	instantiation	274, 157	|- (1 * 2^{-((1 / 2) * t)}) = 2^{-((1 / 2) * t)}
# 	x : 2^{-((1 / 2) * t)}
# 146	instantiation	295, 158, 159, 160	{k in {0 .. 2^{t} - 1}, m in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * m) / 2^{t}) in Complex
# 	a : 2 * pi * i * k * m, b : 2^{t}
# 147	instantiation	161, 395, 384, 317, 162, 318, 163	{m in {0 .. 2^{t} - 1}} |- ({t}_〈m| . (FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))) =  \\ ({t}_〈m| . FT^{dag}_{t} . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))
# 	l : 1, m : 2, n : 0, A : ({t}_〈m|), B : (FT^{dag}_{t}, Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})), C : ()
# 148	instantiation	204, 269, 270, 164, 201	{m in {0 .. 2^{t} - 1}} |- (({t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}) . (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))) in_c Q*
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m| . (1 / 2^{t / 2}) . FT^{dag}_{t}, |psi> : Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})
# ...
# 	proveit.linear_algebra.scalar_multiplication.scalar_mult_closure
# 248	instantiation	261, 300	|- Complex^{2^{t}} in_c VecSpaces(Complex)
# 	n : 2^{t}
# 249	instantiation	280, 262, 263	{k in {0 .. 2^{t} - 1}} |- e^{2 * pi * i * phase * k} in Complex
# 	a : e, b : 2 * pi * i * phase * k
# 250	instantiation	264, 392, 358	{k in {0 .. 2^{t} - 1}} |- |k〉_{t} in Complex^{2^{t}}
# 	n : t, k : k
# 251	conjecture		|- forall_{c in Complex} [forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} ((A . c) in LINMAP(H, X))]]
# 	proveit.physics.quantum.algebra.qmult_op_complex_closure
# 252	instantiation	295, 265, 266, 267	|- (1 / 2^{t / 2}) in Complex
# 	a : 1, b : 2^{t / 2}
# 253	conjecture		|- forall_{H, X, Y in_c HilbertSpaces} [forall_{A, B | [A] in LINMAP(X, Y), [B] in LINMAP(H, X)} ((A . B) in LINMAP(H, Y))]
# 	proveit.physics.quantum.algebra.qmult_op_op_is_op
# 254	instantiation	268, 269, 270, 271	{m in {0 .. 2^{t} - 1}} |- [{t}_〈m|] in LINMAP(Complex^{2^{t}}, Complex)
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈m|
# 255	instantiation	272, 300, 273	|- [FT^{dag}_{t}] in LINMAP(Complex^{2^{t}}, Complex^{2^{t}})
# 	m : 2^{t}, n : 2^{t}, M : FT^{dag}_{t}
# 256	instantiation	393, 380, 382	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 257	instantiation	274, 353	|- (1 * 2) = 2
# 	x : 2
# 258	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 259	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 260	instantiation	393, 381, 275	{m in {0 .. 2^{t} - 1}} |- m in Rational
# 	A : Integer, B : Rational, x : m
# 261	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c VecSpaces(Complex))
# 	proveit.linear_algebra.complex_vec_set_is_vec_space
# 262	instantiation	393, 361, 276	|- e in Complex
# 	A : Real, B : Complex, x : e
# 263	instantiation	302, 277, 278	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * phase * k) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * phase * k), y : 2 * pi * i * phase * k
# 264	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} (|k〉_{n} in Complex^{2^{n}})]
# 	proveit.physics.quantum.algebra.num_ket_in_register_space
# 265	instantiation	393, 361, 279	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 266	instantiation	280, 353, 281	|- 2^{t / 2} in Complex
# 	a : 2, b : t / 2
# 267	instantiation	282, 283, 284	|- 2^{t / 2} != 0
# 	P(_a) : _a != 0, x : 2^{t / 2}, y : 2^{(1 / 2) * t}
# 268	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A in LINMAP(H, X)} ([A] in LINMAP(H, X))]
# 	proveit.physics.quantum.algebra.qmult_op_is_linmap
# 269	instantiation	285, 300	|- Complex^{2^{t}} in_c HilbertSpaces
# 	n : 2^{t}
# 270	conjecture		|- Complex in_c HilbertSpaces
# 	proveit.physics.quantum.algebra.complex_set_is_hilbert_space
# 271	instantiation	286, 392, 289	{m in {0 .. 2^{t} - 1}} |- {t}_〈m| in LINMAP(Complex^{2^{t}}, Complex)
# 	n : t, k : m
# 272	conjecture		|- forall_{m, n in NaturalPos} [forall_{M in Complex^{m x n}} ([M] in LINMAP(Complex^{n}, Complex^{m}))]
# 	proveit.physics.quantum.algebra.qmult_matrix_is_linmap
# 273	instantiation	354, 287, 288	|- FT^{dag}_{t} in Complex^{2^{t} x 2^{t}}
# 	A : U(2^{t}), B : Complex^{2^{t} x 2^{t}}, x : FT^{dag}_{t}
# 274	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 275	instantiation	393, 357, 289	{m in {0 .. 2^{t} - 1}} |- m in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : m
# 276	instantiation	393, 342, 290	|- e in Real
# 	A : RealPos, B : Real, x : e
# 277	instantiation	329, 305, 291	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) in Complex
# 	a : 2 * pi, b : i * phase * k
# 278	instantiation	326, 292, 293	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) = (2 * pi * i * phase * k)
# 	x : (2 * pi) * (i * phase * k), y : (2 * pi) * i * phase * k, z : 2 * pi * i * phase * k
# 279	instantiation	393, 372, 294	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 280	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 281	instantiation	295, 338, 353, 312	|- (t / 2) in Complex
# 	a : t, b : 2
# 282	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 283	instantiation	296, 360, 297	|- 2^{(1 / 2) * t} != 0
# 	a : 2, b : (1 / 2) * t
# 284	instantiation	335, 298	|- 2^{t / 2} = 2^{(1 / 2) * t}
# 	f(_a) : 2^{_a}, x : t / 2, y : (1 / 2) * t
# 285	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c HilbertSpaces)
# 	proveit.physics.quantum.algebra.complex_vec_set_is_hilbert_space
# 286	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} ({n}_〈k| in LINMAP(Complex^{2^{n}}, Complex))]
# 	proveit.physics.quantum.algebra.num_bra_is_lin_map
# 287	instantiation	299, 300	|- U(2^{t}) subset_eq Complex^{2^{t} x 2^{t}}
# 	n : 2^{t}
# 288	instantiation	301, 392	|- FT^{dag}_{t} in U(2^{t})
# 	n : t
# 289	assumption		{m in {0 .. 2^{t} - 1}} |- m in {0 .. 2^{t} - 1}
# 290	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 291	instantiation	302, 303, 304	{k in {0 .. 2^{t} - 1}} |- (i * phase * k) in Complex
# 	P(_a) : _a in Complex, x : (i * phase) * k, y : i * phase * k
# 292	instantiation	316, 395, 306, 317, 308, 318, 305, 330, 331, 320	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * (i * phase * k)) =  \\ ((2 * pi) * i * phase * k)
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, phase, k), c : ()
# 293	instantiation	316, 317, 390, 306, 318, 307, 308, 353, 321, 330, 331, 320	{k in {0 .. 2^{t} - 1}} |- ((2 * pi) * i * phase * k) =  \\ (2 * pi * i * phase * k)
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, phase, k)
# 294	instantiation	393, 381, 389	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 295	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 296	conjecture		|- forall_{a, b in RationalNonZero} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_rational_non_zero__not_zero
# 297	instantiation	393, 309, 310	|- ((1 / 2) * t) in RationalNonZero
# 	A : RationalPos, B : RationalNonZero, x : (1 / 2) * t
# 298	instantiation	311, 338, 353, 312, 313*	|- (t / 2) = ((1 / 2) * t)
# 	x : t, y : 2
# 299	conjecture		|- forall_{n in NaturalPos} (U(n) subset_eq Complex^{n x n})
# 	proveit.linear_algebra.matrices.unitaries_are_matrices
# 300	instantiation	314, 390, 387	|- 2^{t} in NaturalPos
# 	a : 2, b : t
# 301	conjecture		|- forall_{n in NaturalPos} (FT^{dag}_{n} in U(2^{n}))
# 	proveit.physics.quantum.QFT.invFT_is_unitary
# 302	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 303	instantiation	329, 315, 320	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) in Complex
# 	a : i * phase, b : k
# 304	instantiation	316, 317, 390, 395, 318, 319, 330, 331, 320	{k in {0 .. 2^{t} - 1}} |- ((i * phase) * k) =  \\ (i * phase * k)
# 	i : 0, j : 2, k : 1, a : (), b : (i, phase), c : (k)
# 305	instantiation	329, 353, 321	|- (2 * pi) in Complex
# 	a : 2, b : pi
# 306	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 307	instantiation	332	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 308	instantiation	322	|- |(i, phase, k)| = |(1, 2, ..., 3)|
# 	a : i, b : phase, c : k
# 309	conjecture		|- RationalPos proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational_nonzero
# 310	instantiation	323, 366, 324	|- ((1 / 2) * t) in RationalPos
# 	a : 1 / 2, b : t
# 311	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 312	instantiation	325, 384	|- 2 != 0
# 	n : 2
# 313	instantiation	326, 327, 328	|- (t * 2^{-1}) = ((1 / 2) * t)
# 	x : t * 2^{-1}, y : t * (1 / 2), z : (1 / 2) * t
# 314	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 315	instantiation	329, 330, 331	|- (i * phase) in Complex
# 	a : i, b : phase
# 316	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 317	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 318	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 319	instantiation	332	|- |(i, phase)| = |(1, ..., 2)|
# 	a : i, b : phase
# 320	instantiation	393, 361, 333	{k in {0 .. 2^{t} - 1}} |- k in Complex
# 	A : Real, B : Complex, x : k
# 321	instantiation	393, 361, 334	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 322	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 323	conjecture		|- forall_{a, b in RationalPos} ((a * b) in RationalPos)
# 	proveit.numbers.multiplication.mult_rational_pos_closure_bin
# 324	instantiation	393, 383, 392	|- t in RationalPos
# 	A : NaturalPos, B : RationalPos, x : t
# 325	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 326	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 327	instantiation	335, 336	|- (t * 2^{-1}) = (t * (1 / 2))
# 	f(_a) : t * _a, x : 2^{-1}, y : 1 / 2
# 328	instantiation	337, 338, 339	|- (t * (1 / 2)) = ((1 / 2) * t)
# 	a : t, b : 1 / 2
# 329	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 330	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 331	instantiation	393, 361, 340	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 332	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 333	instantiation	393, 372, 341	{k in {0 .. 2^{t} - 1}} |- k in Real
# 	A : Rational, B : Real, x : k
# 334	instantiation	393, 342, 343	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 335	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 336	instantiation	344, 345, 382, 346*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 337	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 338	instantiation	393, 361, 347	|- t in Complex
# 	A : Real, B : Complex, x : t
# 339	instantiation	393, 361, 348	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 340	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 341	instantiation	393, 381, 349	{k in {0 .. 2^{t} - 1}} |- k in Rational
# 	A : Integer, B : Rational, x : k
# 342	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 343	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 344	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 345	instantiation	393, 350, 351	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 346	instantiation	352, 353	|- 2^{1} = 2
# 	x : 2
# 347	instantiation	354, 355, 392	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 348	instantiation	393, 372, 356	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 349	instantiation	393, 357, 358	{k in {0 .. 2^{t} - 1}} |- k in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : k
# 350	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 351	instantiation	393, 359, 360	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 352	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 353	instantiation	393, 361, 362	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 354	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 355	instantiation	363, 364	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 356	instantiation	393, 365, 366	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 357	instantiation	367, 368, 369	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 358	assumption		{k in {0 .. 2^{t} - 1}} |- k in {0 .. 2^{t} - 1}
# 359	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 360	instantiation	393, 370, 371	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 361	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 362	instantiation	393, 372, 373	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 363	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 364	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 365	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 366	instantiation	374, 375, 376	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 367	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 368	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 369	instantiation	377, 378, 379	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 370	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 371	instantiation	393, 380, 384	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 372	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 373	instantiation	393, 381, 386	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 374	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 375	instantiation	393, 383, 382	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 376	instantiation	393, 383, 384	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 377	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 378	instantiation	385, 386, 387	|- 2^{t} in Integer
# 	a : 2, b : t
# 379	instantiation	388, 389	|- (-1) in Integer
# 	a : 1
# 380	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 381	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 382	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 383	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 384	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 385	conjecture		|- forall_{a in Integer, b in Natural} (a^{b} in Integer)
# 	proveit.numbers.exponentiation.exp_int_closure
# 386	instantiation	393, 394, 390	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 387	instantiation	393, 391, 392	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 388	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 389	instantiation	393, 394, 395	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 390	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 391	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 392	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 393	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 394	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 395	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
