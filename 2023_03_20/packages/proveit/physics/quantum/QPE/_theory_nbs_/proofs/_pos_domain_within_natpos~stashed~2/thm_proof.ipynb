# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_pos_domain_within_natpos">_pos_domain_within_natpos</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import k, defaults
from proveit.logic import InSet
from proveit.numbers import one
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _pos_domain_within_natpos
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_pos_domain_within_natpos">_pos_domain_within_natpos:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/64b4aafc84244fe7d30c2dfc4d2a5472633ba35b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ca507851e885b72a01507fa950d6f1a69183ae240/dependencies.ipynb">dependencies</a>)<br>

# %%
# acknowledge this previously proven fact
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos
# _pos_domain_within_natpos may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._pos_domain_within_natpos has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({e + 1 .. 2^{t - 1}} subset_eq NaturalPos)
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} subset_eq NaturalPos
# 	A : {e + 1 .. 2^{t - 1}}, B : NaturalPos, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalization	4	{e in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {e + 1 .. 2^{t - 1}}} (_a in NaturalPos)
# 4	instantiation	17, 5, 6	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in NaturalPos
# 	a : _a
# 5	instantiation	37, 7, 13	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in Integer
# 	A : {e + 1 .. 2^{t - 1}}, B : Integer, x : _a
# 6	instantiation	21, 8, 9	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- 0 < _a
# 	x : 0, y : e + 1, z : _a
# 7	instantiation	24, 12, 31	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : e + 1, b : 2^{t - 1}
# 8	instantiation	10, 11	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) > 0
# 	n : e + 1
# 9	instantiation	25, 12, 31, 13	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- (e + 1) <= _a
# 	a : e + 1, b : 2^{t - 1}, n : _a
# 10	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 11	instantiation	14, 15, 16	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 12	instantiation	30, 18, 26	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 13	assumption		{_a in {e + 1 .. 2^{t - 1}}} |- _a in {e + 1 .. 2^{t - 1}}
# 14	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 15	instantiation	17, 18, 19	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 16	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 17	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 18	instantiation	37, 20, 28	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 19	instantiation	21, 22, 23	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 20	instantiation	24, 26, 27	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 21	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 22	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 23	instantiation	25, 26, 27, 28	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 24	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 25	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 26	instantiation	37, 38, 29	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 27	instantiation	30, 31, 32	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 28	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 29	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 30	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 31	instantiation	37, 33, 34	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 32	instantiation	35, 36	|- (-2) in Integer
# 	a : 2
# 33	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 34	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 35	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 36	instantiation	37, 38, 39	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 37	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 38	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 39	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
