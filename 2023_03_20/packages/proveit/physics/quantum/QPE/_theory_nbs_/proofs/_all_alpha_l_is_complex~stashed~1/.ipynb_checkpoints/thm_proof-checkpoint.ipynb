# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_all_alpha_l_is_complex">_all_alpha_l_is_complex</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, k, l, n, defaults, Psi
from proveit.logic import InSet
from proveit.numbers import Add, Integer
#from proveit.physics.quantum import register_qubit_complex_amplitude
from proveit.physics.quantum.QPE.phase_est_ops import ModAdd
from proveit.physics.quantum.QPE import _b, _Psi, _t # common
from proveit.physics.quantum.QPE import (
    _alpha_def, _mod_add_def, _Psi_ket_in_qreg_space, _t_in_natural_pos) # axioms
from proveit.physics.quantum.QPE import _best_is_int, _two_pow_t_is_nat_pos # theorems

# %%
# %proving _all_alpha_l_is_complex
# Out:
# _all_alpha_l_is_complex: forall_{l in Integer} (alpha_{l} in Complex)

# %%
defaults.assumptions = _all_alpha_l_is_complex.all_conditions()
# Out:
# defaults.assumptions: (l in Integer)

# %%
_alpha_def_inst = _alpha_def.instantiate({l:l})
# Out:
# _alpha_def_inst: {l in Integer} |- alpha_{l} = ({t}_〈b MOD_ADD l| . |Psi〉)

# %% [markdown]
# Recall our $\_b$, the value for $m$ that gives the closest $\varphi_m$ to $\varphi$ without exceeding it

# %%
_best_is_int
# Out:
# |- b in Integer

# %%
_mod_add_def
# Out:
# |- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod 2^{t}))

# %%
_mod_add_unfolding = _mod_add_def.instantiate({a: _b, b:l})
# Out:
# _mod_add_unfolding: {l in Integer} |- (b MOD_ADD l) = ((b + l) mod 2^{t})

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in Integer} (alpha_{l} in Complex)
# 1	instantiation	2, 3, 4	{l in Integer} |- alpha_{l} in Complex
# 	P(_a) : _a in Complex, x : alpha_{l}, y : {t}_〈b MOD_ADD l| . |Psi〉
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 10, 11, 6, 7	{l in Integer} |- ({t}_〈b MOD_ADD l| . |Psi〉) in Complex
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈b MOD_ADD l|, |psi> : |Psi〉
# 4	instantiation	8, 20	{l in Integer} |- alpha_{l} = ({t}_〈b MOD_ADD l| . |Psi〉)
# 	l : l
# 5	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A | [A] in LINMAP(H, X)} [forall_{|psi> in H} ((A . |psi>) in X)]]
# 	proveit.physics.quantum.algebra.qmult_op_ket_is_ket
# 6	instantiation	9, 10, 11, 12	{l in Integer} |- [{t}_〈b MOD_ADD l|] in LINMAP(Complex^{2^{t}}, Complex)
# 	H : Complex^{2^{t}}, X : Complex, A : {t}_〈b MOD_ADD l|
# 7	axiom		|- |Psi〉 in Complex^{2^{t}}
# 	proveit.physics.quantum.QPE._Psi_ket_in_qreg_space
# 8	axiom		|- forall_{l in Integer} (alpha_{l} = ({t}_〈b MOD_ADD l| . |Psi〉))
# 	proveit.physics.quantum.QPE._alpha_def
# 9	conjecture		|- forall_{H, X in_c HilbertSpaces} [forall_{A in LINMAP(H, X)} ([A] in LINMAP(H, X))]
# 	proveit.physics.quantum.algebra.qmult_op_is_linmap
# 10	instantiation	13, 14	|- Complex^{2^{t}} in_c HilbertSpaces
# 	n : 2^{t}
# 11	conjecture		|- Complex in_c HilbertSpaces
# 	proveit.physics.quantum.algebra.complex_set_is_hilbert_space
# 12	instantiation	15, 16, 17	{l in Integer} |- {t}_〈b MOD_ADD l| in LINMAP(Complex^{2^{t}}, Complex)
# 	n : t, k : b MOD_ADD l
# 13	conjecture		|- forall_{n in NaturalPos} (Complex^{n} in_c HilbertSpaces)
# 	proveit.physics.quantum.algebra.complex_vec_set_is_hilbert_space
# 14	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 15	conjecture		|- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} ({n}_〈k| in LINMAP(Complex^{2^{n}}, Complex))]
# 	proveit.physics.quantum.algebra.num_bra_is_lin_map
# 16	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 17	instantiation	18, 19, 20	{l in Integer} |- (b MOD_ADD l) in {0 .. 2^{t} - 1}
# 	a : b, b : l
# 18	conjecture		|- forall_{a, b in Integer} ((a MOD_ADD b) in {0 .. 2^{t} - 1})
# 	proveit.physics.quantum.QPE._mod_add_closure
# 19	conjecture		|- b in Integer
# 	proveit.physics.quantum.QPE._best_is_int
# 20	assumption		{l in Integer} |- l in Integer
