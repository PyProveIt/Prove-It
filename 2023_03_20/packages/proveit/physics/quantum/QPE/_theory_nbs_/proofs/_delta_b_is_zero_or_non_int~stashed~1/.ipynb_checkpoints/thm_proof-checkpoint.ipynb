# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_delta_b_is_zero_or_non_int">_delta_b_is_zero_or_non_int</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import n, x, A, defaults
from proveit.logic import Equals, Implies, InSet, Not, NotEquals, Or
from proveit.logic.booleans import unfold_is_bool
from proveit.numbers import zero, one, two, frac, IntervalOO, Less, Neg
from proveit.numbers.number_sets.real_numbers import not_int_if_not_int_in_interval
from proveit.physics.quantum.QPE import _delta_b, _delta_b_in_interval

# %%
# %proving _delta_b_is_zero_or_non_int
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_delta_b_is_zero_or_non_int">_delta_b_is_zero_or_non_int:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7b1e38c84df2b01305024ef242bd49d4034b64bf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/9d7ee87ad003bc18eba01192c396bc9b4be62b780/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _delta_b_is_zero_or_non_int.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/fc94743a44fa455c6682a16aed1c93018554f7bc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_in_interval
# Out:
# |- forall_{b in {b_{f}, b_{r}}} (delta_{b} in (-(1 / 2),1 / 2])

# %%
_delta_b_in_interval_inst = _delta_b_in_interval.instantiate()
# Out:
# <strong id="_delta_b_in_interval_inst">_delta_b_in_interval_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/891d554379ae8acea5dc5bfc295f64ba6a26988d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0b9e90686cc9b38cd6279d1c28569daacc8ff4b60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# To avoid an error in the next cell:
# ProofFailure: Unable to prove ((-1) / 1) = (-1) assuming {b in {b_{f}, b_{r}}}:
# Infinite 'conclude' recursion blocked.
frac(Neg(one), one).factorization(one).inner_expr().rhs.simplify()
# Out:
# |- ((-1) / 1) = (-1)

# %%
neg_one_less_neg_one_half = Less(Neg(one), Neg(frac(one, two))).prove()
# Out:
# <strong id="neg_one_less_neg_one_half">neg_one_less_neg_one_half:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/2e8cdfdbecb6d809e7a883644e883c1f143459b10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/904c6c7c1021449d6b8e2e94d945cf03ddabb6ff0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Less(frac(one, two), one).prove()
# Out:
# |- (1 / 2) < 1

# %% [markdown]
# Now Prove-It can derive the expanded interval membership for $\delta_{b_r}$:

# %%
InSet(_delta_b, IntervalOO(Neg(one), one)).prove()
# Out:
# {b in {b_{f}, b_{r}}} |- delta_{b} in (-1,1)

# %% [markdown]
# ### Establish that $(\delta = 0) \lor (\lnot[\delta = 0])$ using a version of the Law of the Excluded Middle

# %%
unfold_is_bool
# Out:
# |- forall_{A in BOOLEAN} (A or [not](A))

# %%
non_zero_assumption = NotEquals(_delta_b, zero)
# Out:
# <strong id="non_zero_assumption">non_zero_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/8c61220b9cf103f9da6385c5e22430830212aae80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
zero_assumption = Equals(_delta_b, zero)
# Out:
# <strong id="zero_assumption">zero_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f6a870f41eb795fa87bdca3868fd966b1a8b4ee90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
delta_b_is_zero_or_not = unfold_is_bool.instantiate({A: zero_assumption})
# Out:
# <strong id="delta_b_is_zero_or_not">delta_b_is_zero_or_not:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/5da04973b05439729768448b2266056af0a0b4980/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/63eb3282fc6ed39a03332583eda5b661bea33b060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Establish that the assumptions $(\delta = 0)$ and $(\lnot[\delta = 0])$ _each_ imply that $(\delta = 0) \lor (\delta_{b} \notin \mathbb{Z})$

# %% [markdown]
# #### First, assuming that $\delta_b \ne 0$

# %%
not_int_if_not_int_in_interval
# Out:
# |- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]

# %%
not_zero_assumption_gives_not_int = not_int_if_not_int_in_interval.instantiate(
    {n: zero, x: _delta_b},
    assumptions=[*defaults.assumptions, non_zero_assumption])
# Out:
# <strong id="not_zero_assumption_gives_not_int">not_zero_assumption_gives_not_int:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/8c61220b9cf103f9da6385c5e22430830212aae80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/f4658c037994aa0376051602b1e5521caee76f9c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0994358e9471ef90ce92be24481301082a581d1f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Or(zero_assumption, not_zero_assumption_gives_not_int.expr).prove(
        assumptions=[*defaults.assumptions, non_zero_assumption]).as_implication(hypothesis=non_zero_assumption)
# Out:
# {b in {b_{f}, b_{r}}} |- (delta_{b} != 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))

# %%
not_zero_implies_not_eq_zero = non_zero_assumption.conclude_as_folded(
        assumptions = [Not(zero_assumption)]).as_implication(hypothesis=Not(zero_assumption))
# Out:
# <strong id="not_zero_implies_not_eq_zero">not_zero_implies_not_eq_zero:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/3033e93187a5241bf79c845f2cd5300437955a0e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/9665c288e80f0bde47559604470f196bd43236dd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Implies(Not(zero_assumption), Or(zero_assumption, not_zero_assumption_gives_not_int.expr)).prove()
# Out:
# {b in {b_{f}, b_{r}}} |- [not](delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))

# %% [markdown]
# #### Second, assuming that $\delta_b = 0$ (the trivial case)

# %%
zero_assumption_gives_zero = zero_assumption.prove(assumptions=[*defaults.assumptions, zero_assumption])
# Out:
# <strong id="zero_assumption_gives_zero">zero_assumption_gives_zero:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/f6a870f41eb795fa87bdca3868fd966b1a8b4ee90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__delta_b_is_zero_or_non_int/3a59ba2bdbc002155bb77a29b7ea3320ae04f62f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/f6a870f41eb795fa87bdca3868fd966b1a8b4ee90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Or(zero_assumption_gives_zero.expr, not_zero_assumption_gives_not_int.expr).prove(
        assumptions=[*defaults.assumptions, zero_assumption]).as_implication(hypothesis=zero_assumption)
# Out:
# |- (delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))

# %% [markdown]
# ### Thus in all cases we have the desired conclusion:

# %%
delta_b_is_zero_or_not.derive_via_singular_dilemma(_delta_b_is_zero_or_non_int.instance_expr)
# Out:
# {b in {b_{f}, b_{r}}} |- (delta_{b} = 0) or (delta_{b} not-in Integer)
# _delta_b_is_zero_or_non_int may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._delta_b_is_zero_or_non_int has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}} ((delta_{b} = 0) or (delta_{b} not-in Integer))
# 1	instantiation	2, 9, 3, 4, 5, 6	{b in {b_{f}, b_{r}}} |- (delta_{b} = 0) or (delta_{b} not-in Integer)
# 	A : delta_{b} = 0, B : [not](delta_{b} = 0), C : (delta_{b} = 0) or (delta_{b} not-in Integer)
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	|- [not](delta_{b} = 0) in BOOLEAN
# 	A : delta_{b} = 0
# 4	instantiation	8, 9	|- (delta_{b} = 0) or [not](delta_{b} = 0)
# 	A : delta_{b} = 0
# 5	deduction	10	|- (delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))
# 6	instantiation	11, 12, 13	{b in {b_{f}, b_{r}}} |- [not](delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))
# 	P : (delta_{b} != 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer)), Q : [not](delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))
# 7	conjecture		|- forall_{A in BOOLEAN} ([not](A) in BOOLEAN)
# 	proveit.logic.booleans.negation.closure
# 8	conjecture		|- forall_{A in BOOLEAN} (A or [not](A))
# 	proveit.logic.booleans.unfold_is_bool
# 9	instantiation	14	|- (delta_{b} = 0) in BOOLEAN
# 	x : delta_{b}, y : 0
# 10	instantiation	15, 27, 16	{delta_{b} = 0} |- (delta_{b} = 0) or (delta_{b} not-in Integer)
# 	A : delta_{b} = 0, B : delta_{b} not-in Integer
# 11	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 12	deduction	17	{b in {b_{f}, b_{r}}} |- (delta_{b} != 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))
# 13	instantiation	18, 19	|- ((delta_{b} != 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer))) = ([not](delta_{b} = 0) => ((delta_{b} = 0) or (delta_{b} not-in Integer)))
# 	f(_a) : _a => ((delta_{b} = 0) or (delta_{b} not-in Integer)), x : delta_{b} != 0, y : [not](delta_{b} = 0)
# 14	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 15	theorem		|- forall_{A, B | A, [not](B)} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_left
# 16	instantiation	20, 21	{delta_{b} = 0} |- [not](delta_{b} not-in Integer)
# 	x : delta_{b}, S : Integer
# 17	instantiation	22, 23, 24	{delta_{b} != 0, b in {b_{f}, b_{r}}} |- (delta_{b} = 0) or (delta_{b} not-in Integer)
# 	A : delta_{b} = 0, B : delta_{b} not-in Integer
# 18	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 19	instantiation	25	|- (delta_{b} != 0) = [not](delta_{b} = 0)
# 	x : delta_{b}, y : 0
# 20	conjecture		|- forall_{x, S | x in S} [not](x not-in S)
# 	proveit.logic.sets.membership.double_negated_membership
# 21	instantiation	26, 30, 27	{delta_{b} = 0} |- delta_{b} in Integer
# 	P(_a) : _a in Integer, x : delta_{b}, y : 0
# 22	theorem		|- forall_{A, B | [not](A), B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_right
# 23	instantiation	28, 32	{delta_{b} != 0} |- [not](delta_{b} = 0)
# 	x : delta_{b}, y : 0
# 24	instantiation	29, 30, 31, 32	{b in {b_{f}, b_{r}}, delta_{b} != 0} |- delta_{b} not-in Integer
# 	n : 0, x : delta_{b}
# 25	axiom		|- forall_{x, y} ((x != y) = [not](x = y))
# 	proveit.logic.equality.not_equals_def
# 26	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 27	assumption		{delta_{b} = 0} |- delta_{b} = 0
# 28	theorem		|- forall_{x, y | x != y} [not](x = y)
# 	proveit.logic.equality.unfold_not_equals
# 29	conjecture		|- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]
# 	proveit.numbers.number_sets.real_numbers.not_int_if_not_int_in_interval
# 30	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 31	instantiation	33, 34, 35, 89, 36	{b in {b_{f}, b_{r}}} |- delta_{b} in (0 - 1,0 + 1)
# 	a : 0 - 1, b : 0 + 1, x : delta_{b}
# 32	assumption		{delta_{b} != 0} |- delta_{b} != 0
# 33	conjecture		|- forall_{a, b, x in Real | a < x < b} (x in (a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalOO
# 34	instantiation	52, 38, 37	|- (0 - 1) in Real
# 	a : 0, b : -1
# 35	instantiation	52, 38, 106	|- (0 + 1) in Real
# 	a : 0, b : 1
# 36	instantiation	39, 40, 41	{b in {b_{f}, b_{r}}} |- ((0 - 1) < delta_{b}) and (delta_{b} < (0 + 1))
# 	A : (0 - 1) < delta_{b}, B : delta_{b} < (0 + 1)
# 37	instantiation	147, 143, 42	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 38	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 39	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 40	instantiation	43, 97, 44, 45, 46*, 47*	{b in {b_{f}, b_{r}}} |- (0 - 1) < delta_{b}
# 	a : -(1 / 2), x : -(1 / 2), y : delta_{b} + (1 / 2)
# 41	instantiation	48, 49, 50	{b in {b_{f}, b_{r}}} |- delta_{b} < (0 + 1)
# 	P(_a) : delta_{b} < _a, x : (1 / 2) + (1 / 2), y : 0 + 1
# 42	instantiation	147, 145, 51	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 43	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 44	instantiation	52, 89, 108	{b in {b_{f}, b_{r}}} |- (delta_{b} + (1 / 2)) in Real
# 	a : delta_{b}, b : 1 / 2
# 45	instantiation	53, 97, 89, 108, 54, 55	{b in {b_{f}, b_{r}}} |- (-(1 / 2)) < (delta_{b} + (1 / 2))
# 	a : -(1 / 2), b : delta_{b}, c : 1 / 2
# 46	instantiation	63, 56, 57, 58	|- (-(1 / 2) - (1 / 2)) = (0 - 1)
# 	a : -(1 / 2) - (1 / 2), b : -1, c : -1, d : 0 - 1
# 47	instantiation	111, 59, 60	{b in {b_{f}, b_{r}}} |- ((delta_{b} + (1 / 2)) - (1 / 2)) = delta_{b}
# 	x : (delta_{b} + (1 / 2)) - (1 / 2), y : delta_{b} + (1 / 2) - (1 / 2), z : delta_{b}
# 48	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 49	instantiation	61, 89, 108, 62, 69	{b in {b_{f}, b_{r}}} |- delta_{b} < ((1 / 2) + (1 / 2))
# 	a : delta_{b}, b : 1 / 2, c : 1 / 2
# 50	instantiation	63, 71, 64, 65	|- ((1 / 2) + (1 / 2)) = (0 + 1)
# 	a : (1 / 2) + (1 / 2), b : 1, c : 1, d : 0 + 1
# 51	instantiation	66, 125	|- (-1) in Integer
# 	a : 1
# 52	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 53	conjecture		|- forall_{a, b, c in Real | a < b, 0 <= c} (a < (b + c))
# 	proveit.numbers.ordering.less_add_right
# 54	instantiation	67, 97, 108, 98	{b in {b_{f}, b_{r}}} |- (-(1 / 2)) < delta_{b}
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 55	instantiation	68, 69	|- 0 <= (1 / 2)
# 	x : 0, y : 1 / 2
# 56	instantiation	70, 79, 95, 71	|- (-(1 / 2) - (1 / 2)) = (-1)
# 	a : 1 / 2, b : 1 / 2, c : 1
# 57	instantiation	90	|- (-1) = (-1)
# 	x : -1
# 58	instantiation	83, 72	|- (-1) = (0 - 1)
# 	x : 0 - 1, y : -1
# 59	instantiation	73, 74, 149, 133, 75, 76, 80, 79, 77	{b in {b_{f}, b_{r}}} |- ((delta_{b} + (1 / 2)) - (1 / 2)) =  \\ (delta_{b} + (1 / 2) - (1 / 2))
# 	i : 0, j : 2, k : 1, a : (), b : (delta_{b}, 1 / 2), c : (-(1 / 2))
# 60	instantiation	78, 79, 80, 81	{b in {b_{f}, b_{r}}} |- (delta_{b} + (1 / 2) - (1 / 2)) = delta_{b}
# 	a : 1 / 2, b : 1 / 2, c : delta_{b}
# 61	conjecture		|- forall_{a, b, c in Real | a <= b, 0 < c} (a < (b + c))
# 	proveit.numbers.ordering.less_eq_add_right_strong
# 62	instantiation	82, 97, 108, 98	{b in {b_{f}, b_{r}}} |- delta_{b} <= (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 63	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 64	instantiation	90	|- 1 = 1
# 	x : 1
# 65	instantiation	83, 84	|- 1 = (0 + 1)
# 	x : 0 + 1, y : 1
# 66	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 67	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 68	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 69	instantiation	85, 127	|- (1 / 2) > 0
# 	q : 1 / 2
# 70	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((-a - b) = (-c))
# 	proveit.numbers.addition.subtraction.negated_add
# 71	instantiation	86, 125, 146, 87*	|- ((1 / 2) + (1 / 2)) = 1
# 	a : 1, b : 2, c : 1, d : 2
# 72	instantiation	91, 88	|- (0 - 1) = (-1)
# 	a : -1
# 73	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 74	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 75	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 76	instantiation	128	|- |(delta_{b}, 1 / 2)| = |(1, ..., 2)|
# 	a : delta_{b}, b : 1 / 2
# 77	instantiation	147, 137, 97	|- (-(1 / 2)) in Complex
# 	A : Real, B : Complex, x : -(1 / 2)
# 78	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 79	instantiation	147, 137, 108	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 80	instantiation	147, 137, 89	{b in {b_{f}, b_{r}}} |- delta_{b} in Complex
# 	A : Real, B : Complex, x : delta_{b}
# 81	instantiation	90	|- (1 / 2) = (1 / 2)
# 	x : 1 / 2
# 82	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_upper_bound
# 83	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 84	instantiation	91, 95	|- (0 + 1) = 1
# 	a : 1
# 85	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 86	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 87	instantiation	111, 92, 93	|- (((1 * 2) + (2 * 1)) / (2 * 2)) = 1
# 	x : ((1 * 2) + (2 * 1)) / (2 * 2), y : 4 / 4, z : 1
# 88	instantiation	94, 95	|- (-1) in Complex
# 	a : 1
# 89	instantiation	96, 97, 108, 98	{b in {b_{f}, b_{r}}} |- delta_{b} in Real
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 90	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 91	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 92	instantiation	119, 149, 99, 100, 101, 102	|- (((1 * 2) + (2 * 1)) / (2 * 2)) =  \\ (4 / 4)
# 	n : 2, f(_a, _b) : _a / _b, x : ((1 * 2) + (2 * 1), 2 * 2), y : (4, 4)
# 93	instantiation	103, 104, 105	|- (4 / 4) = 1
# 	x : 4
# 94	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 95	instantiation	147, 137, 106	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 96	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 97	instantiation	107, 108	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 98	instantiation	109, 110	{b in {b_{f}, b_{r}}} |- delta_{b} in (-(1 / 2),1 / 2]
# 	b : b
# 99	instantiation	128	|- |((1 * 2) + (2 * 1), 2 * 2)| = |(1, ..., 2)|
# 	a : (1 * 2) + (2 * 1), b : 2 * 2
# 100	instantiation	128	|- |(4, 4)| = |(1, ..., 2)|
# 	a : 4, b : 4
# 101	instantiation	111, 112, 113	|- ((1 * 2) + (2 * 1)) = 4
# 	x : (1 * 2) + (2 * 1), y : 2 + 2, z : 4
# 102	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 103	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 104	instantiation	147, 137, 114	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 105	instantiation	115, 116	|- 4 != 0
# 	n : 4
# 106	instantiation	147, 143, 117	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 107	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 108	instantiation	147, 143, 118	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 109	conjecture		|- forall_{b in {b_{f}, b_{r}}} (delta_{b} in (-(1 / 2),1 / 2])
# 	proveit.physics.quantum.QPE._delta_b_in_interval
# 110	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 111	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 112	instantiation	119, 149, 120, 121, 122, 123	|- ((1 * 2) + (2 * 1)) =  \\ (2 + 2)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 2, 2 * 1), y : (2, 2)
# 113	conjecture		|- (2 + 2) = 4
# 	proveit.numbers.numerals.decimals.add_2_2
# 114	instantiation	147, 143, 124	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 115	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 116	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 117	instantiation	147, 145, 125	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 118	instantiation	147, 126, 127	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 119	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 120	instantiation	128	|- |(1 * 2, 2 * 1)| = |(1, ..., 2)|
# 	a : 1 * 2, b : 2 * 1
# 121	instantiation	128	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 122	instantiation	129, 131	|- (1 * 2) = 2
# 	x : 2
# 123	instantiation	130, 131	|- (2 * 1) = 2
# 	x : 2
# 124	instantiation	147, 145, 132	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 125	instantiation	147, 148, 133	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 126	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 127	instantiation	134, 135, 136	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 128	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 129	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 130	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 131	instantiation	147, 137, 138	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 132	instantiation	147, 148, 139	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 133	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 134	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 135	instantiation	147, 141, 140	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 136	instantiation	147, 141, 142	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 137	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 138	instantiation	147, 143, 144	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 139	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 140	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 141	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 142	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 143	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 144	instantiation	147, 145, 146	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 145	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 146	instantiation	147, 148, 149	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 147	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 148	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 149	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
