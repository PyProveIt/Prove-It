# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_b_round_in_interval">_scaled_delta_b_round_in_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, x
from proveit.logic import Equals
from proveit.numbers import one, two, Add, frac, Neg
from proveit.numbers.rounding import (
    real_minus_floor_interval, round_in_terms_of_floor)
from proveit.physics.quantum.QPE import (
    _b_floor, _b_round, _best_round_def, _best_round_is_int,
    _delta_b_def, _phase_is_real, _t_in_natural_pos,
    _two_pow_t, _two_pow_t_is_nat_pos)

# %%
# %proving _scaled_delta_b_round_in_interval
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_delta_b_round_in_interval">_scaled_delta_b_round_in_interval:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0d98a9c7004ccbb1cf9b6cae8b361ba76ff3be2c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/1d352e4987d73278be7cc00b5086124af0938ae70/dependencies.ipynb">dependencies</a>)<br>

# %%
_scaled_delta = _scaled_delta_b_round_in_interval.operands[0]
# Out:
# <strong id="_scaled_delta">_scaled_delta:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/772e1208ebe58b7c393c8b20dcadafaf2422b4540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
display(_delta_b_def)
display(_best_round_def)
# Out:
# |- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))
# |- b_{r} = round(2^{t} * phase)

# %%
_best_round_is_int
# Out:
# |- b_{r} in Integer

# %%
_scaled_phase = _best_round_def.rhs.operand
# Out:
# <strong id="_scaled_phase">_scaled_phase:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/53fb19711fbef1d96169a35f6e09557e8a08d2160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
round_in_terms_of_floor
# Out:
# |- forall_{x in Real} (round(x) = floor(x + (1 / 2)))

# %%
round_in_terms_of_floor_inst = round_in_terms_of_floor.instantiate({x: _scaled_phase })
# Out:
# <strong id="round_in_terms_of_floor_inst">round_in_terms_of_floor_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/dffdd78c94272d4988f8a423ec8160ab54c0f8310/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/2ac7b3b759b662a4506d552241751d58e0b7e6d60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
b_round_as_floor = round_in_terms_of_floor_inst.sub_right_side_into(_best_round_def)
# Out:
# <strong id="b_round_as_floor">b_round_as_floor:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/4c34a30c94b95bdd7aeb105ebd44b17d13c3fbb70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/b00a00f37a7a9e0605a65630a127f85f004e5d450/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_delta_b_def_inst = _delta_b_def.instantiate({b: _b_round})
# Out:
# <strong id="_delta_b_def_inst">_delta_b_def_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/9b4db18b030f63e0644749830636922ef479f0230/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/f45cf5ac56673965388fbb89521a287c82895d4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_01 = _delta_b_def_inst.substitution(_scaled_delta)
# Out:
# <strong id="eq_01">eq_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/41d37cc43f976e641d1dc58d35dd4ab56aa645a90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/fb9bfe275ba5714227ded2be2aed964cba5343590/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_02 = eq_01.inner_expr().rhs.distribute(1)
# Out:
# <strong id="eq_02">eq_02:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/369f1f3961878396794f0922ed44ac08440af2250/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/2d725816d1a29631423551cb69bf5f4c2b26f6230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
b_round_as_floor
# Out:
# |- b_{r} = floor((2^{t} * phase) + (1 / 2))

# %%
eq_03 = (eq_02.inner_expr().rhs.operands[1].
         operand.substitute(b_round_as_floor.rhs))
# Out:
# <strong id="eq_03">eq_03:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/9dac26cb1b5b50fb3db29b6639c54f26675fc93e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/5997b53dca34de14f0a06ef34a8ff96ec4d40e5e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
desired_expr = Add(eq_03.rhs.operands[0], frac(one, two),
                   eq_03.rhs.operands[1], Neg(frac(one, two)))
# Out:
# <strong id="desired_expr">desired_expr:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/a8e3aa7694282a99856186b50608a30d5eee195d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_scaled_delta_expr_manipulated = Equals(desired_expr, eq_03.rhs).prove()
# Out:
# <strong id="_scaled_delta_expr_manipulated">_scaled_delta_expr_manipulated:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/4057aeff3ef2cc8cdebb09ae779098715024fa900/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/2e3c581c092bc52983554c52593873422a581f4b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
eq_04 = _scaled_delta_expr_manipulated.sub_left_side_into(eq_03)
# Out:
# <strong id="eq_04">eq_04:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/4c92a134781daabc0f7c35597b1facb5438b6c380/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/602e12c69f37b62601040d9a060533acb98733d30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
real_minus_floor_interval
# Out:
# |- forall_{x in Real} ((x - floor(x)) in [0,1))

# %%
diff_domain = real_minus_floor_interval.instantiate(
    {x : Add(eq_03.rhs.operands[0], frac(one, two))})
# Out:
# <strong id="diff_domain">diff_domain:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/3b750800931f9110a99078ee709bfa1a2b9ff4850/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/0b89f6ee6eb143e4f900fb4ee5e38cde168602e70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
diff_lower_bound = diff_domain.derive_element_lower_bound()
# Out:
# <strong id="diff_lower_bound">diff_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/218e94de5626d12c463d529a97bb12ea15655aff0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/31927789434458e9859198698ecefa60f65201fc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
diff_upper_bound = diff_domain.derive_element_upper_bound()
# Out:
# <strong id="diff_upper_bound">diff_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/cea4003256216b6627528e3b1fe650d33ccb02280/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/30649c1a6fae80e54c8bf949096cddee4e7fa8390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# This works, but the auto_simplify=False is needed to keep the eq_04.rhs expression
# from being simplified (by canceling the introduced ±1/2 terms)
upper_bound = (
    eq_04.rhs.bound_via_term_bound(diff_upper_bound, auto_simplify=False).
    inner_expr().rhs.simplify())
# Out:
# <strong id="upper_bound">upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/ef65b2368b867b0b7737afd69c32c9d303a050db0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_round_in_interval/432acabea28f4efabde4decd82329b94915882cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
upper_bound.inner_expr().lhs.substitute(eq_04)
# Out:
# |- (2^{t} * delta_{b_{r}}) < (1 / 2)
# _scaled_delta_b_round_in_interval may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_delta_b_round_in_interval has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 18, 118, 2, 3	|- (2^{t} * delta_{b_{r}}) in [-(1 / 2),1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 1	conjecture		|- forall_{a, b, x in Real | a <= x < b} (x in [a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalCO
# 2	instantiation	10, 4, 39	|- (2^{t} * delta_{b_{r}}) in Real
# 	P(_a) : _a in Real, x : 2^{t} * delta_{b_{r}}, y : 2^{t} * (phase - (b_{r} / 2^{t}))
# 3	instantiation	5, 6, 7	|- ((-(1 / 2)) <= (2^{t} * delta_{b_{r}})) and ((2^{t} * delta_{b_{r}}) < (1 / 2))
# 	A : (-(1 / 2)) <= (2^{t} * delta_{b_{r}}), B : (2^{t} * delta_{b_{r}}) < (1 / 2)
# 4	instantiation	127, 155, 8	|- (2^{t} * (phase - (b_{r} / 2^{t}))) in Real
# 	a : 2^{t}, b : phase - (b_{r} / 2^{t})
# 5	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 6	instantiation	10, 9, 12	|- (-(1 / 2)) <= (2^{t} * delta_{b_{r}})
# 	P(_a) : (-(1 / 2)) <= _a, x : 2^{t} * delta_{b_{r}}, y : (2^{t} * phase) - floor((2^{t} * phase) + (1 / 2))
# 7	instantiation	10, 11, 12	|- (2^{t} * delta_{b_{r}}) < (1 / 2)
# 	P(_a) : _a < (1 / 2), x : 2^{t} * delta_{b_{r}}, y : (2^{t} * phase) - floor((2^{t} * phase) + (1 / 2))
# 8	instantiation	116, 128, 13	|- (phase - (b_{r} / 2^{t})) in Real
# 	a : phase, b : -(b_{r} / 2^{t})
# 9	instantiation	14, 18, 31, 19, 15, 16*, 21*	|- (-(1 / 2)) <= ((2^{t} * phase) - floor((2^{t} * phase) + (1 / 2)))
# 	a : -(1 / 2), x : 0, y : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))
# 10	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 11	instantiation	17, 18, 19, 130, 20, 21*, 22*	|- ((2^{t} * phase) - floor((2^{t} * phase) + (1 / 2))) < (1 / 2)
# 	a : -(1 / 2), x : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)), y : 1
# 12	instantiation	90, 23, 24	|- (2^{t} * delta_{b_{r}}) = ((2^{t} * phase) - floor((2^{t} * phase) + (1 / 2)))
# 	P(_a) : (2^{t} * delta_{b_{r}}) = ((2^{t} * phase) - _a), x : b_{r}, y : floor((2^{t} * phase) + (1 / 2))
# 13	instantiation	28, 80	|- (-(b_{r} / 2^{t})) in Real
# 	a : b_{r} / 2^{t}
# 14	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 15	instantiation	25, 31, 130, 32	|- 0 <= ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)))
# 	a : 0, b : 1, x : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))
# 16	instantiation	90, 26, 27	|- (0 - (1 / 2)) = (-(1 / 2))
# 	P(_a) : _a = (-(1 / 2)), x : -(1 / 2) + 0, y : 0 - (1 / 2)
# 17	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 18	instantiation	28, 118	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 19	instantiation	29, 31, 130, 32	|- ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) in Real
# 	a : 0, b : 1, x : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))
# 20	instantiation	30, 31, 130, 32	|- ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) < 1
# 	a : 0, b : 1, x : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))
# 21	instantiation	122, 33, 34	|- (((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) - (1 / 2)) = ((2^{t} * phase) - floor((2^{t} * phase) + (1 / 2)))
# 	x : ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) - (1 / 2), y : (2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)) - (1 / 2), z : (2^{t} * phase) - floor((2^{t} * phase) + (1 / 2))
# 22	instantiation	35, 151, 36, 153, 104*, 37*, 38*	|- (1 - (1 / 2)) = (1 / 2)
# 	a : 1, b : 1, c : -1, d : 2
# 23	instantiation	90, 39, 40	|- (2^{t} * delta_{b_{r}}) = ((2^{t} * phase) - b_{r})
# 	P(_a) : (2^{t} * delta_{b_{r}}) = _a, x : 2^{t} * (phase - (b_{r} / 2^{t})), y : (2^{t} * phase) - b_{r}
# 24	instantiation	90, 41, 42	|- b_{r} = floor((2^{t} * phase) + (1 / 2))
# 	P(_a) : b_{r} = _a, x : round(2^{t} * phase), y : floor((2^{t} * phase) + (1 / 2))
# 25	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 26	instantiation	43, 50	|- (-(1 / 2) + 0) = (-(1 / 2))
# 	a : -(1 / 2)
# 27	instantiation	44, 50, 45	|- (-(1 / 2) + 0) = (0 - (1 / 2))
# 	a : -(1 / 2), b : 0
# 28	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 29	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 30	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 31	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 32	instantiation	46, 108, 47*	|- ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) in [0,1)
# 	x : (2^{t} * phase) + (1 / 2)
# 33	instantiation	63, 64, 48, 156, 65, 49, 67, 70, 68, 50	|- (((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2))) - (1 / 2)) =  \\ ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)) - (1 / 2))
# 	i : 0, j : 3, k : 1, a : (), b : (2^{t} * phase, 1 / 2, -floor((2^{t} * phase) + (1 / 2))), c : (-(1 / 2))
# 34	instantiation	51, 156, 64, 65, 67, 70, 68, 52	|- ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)) - (1 / 2)) = ((2^{t} * phase) - floor((2^{t} * phase) + (1 / 2)))
# 	i : 1, j : 1, k : 0, a : (2^{t} * phase), b : 1 / 2, c : (-floor((2^{t} * phase) + (1 / 2))), d : 1 / 2, e : ()
# 35	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 36	instantiation	53, 151	|- (-1) in Integer
# 	a : 1
# 37	instantiation	54, 114, 86, 132	|- ((-1) / 2) = (-(1 / 2))
# 	x : 1, y : 2
# 38	instantiation	122, 55, 56	|- ((1 * 2) + (1 * (-1))) = 1
# 	x : (1 * 2) + (1 * (-1)), y : 2 - 1, z : 1
# 39	instantiation	136, 57	|- (2^{t} * delta_{b_{r}}) = (2^{t} * (phase - (b_{r} / 2^{t})))
# 	f(_a) : 2^{t} * _a, x : delta_{b_{r}}, y : phase - (b_{r} / 2^{t})
# 40	instantiation	58, 156, 64, 65, 149, 59, 60, 61*	|- (2^{t} * (phase - (b_{r} / 2^{t}))) =  \\ ((2^{t} * phase) - b_{r})
# 	i : 1, j : 0, a : (2^{t}), x : phase, y : b_{r} / 2^{t}, b : ()
# 41	axiom		|- b_{r} = round(2^{t} * phase)
# 	proveit.physics.quantum.QPE._best_round_def
# 42	instantiation	62, 117	|- round(2^{t} * phase) = floor((2^{t} * phase) + (1 / 2))
# 	x : 2^{t} * phase
# 43	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 44	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 45	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 46	conjecture		|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 	proveit.numbers.rounding.real_minus_floor_interval
# 47	instantiation	63, 64, 159, 156, 65, 66, 67, 70, 68	|- (((2^{t} * phase) + (1 / 2)) - floor((2^{t} * phase) + (1 / 2))) =  \\ ((2^{t} * phase) + (1 / 2) - floor((2^{t} * phase) + (1 / 2)))
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t} * phase, 1 / 2), c : (-floor((2^{t} * phase) + (1 / 2)))
# 48	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 49	instantiation	69	|- |(2^{t} * phase, 1 / 2, -floor((2^{t} * phase) + (1 / 2)))| = |(1, 2, ..., 3)|
# 	a : 2^{t} * phase, b : 1 / 2, c : -floor((2^{t} * phase) + (1 / 2))
# 50	instantiation	83, 70	|- (-(1 / 2)) in Complex
# 	a : 1 / 2
# 51	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d, e_{1}, e_{2}, ..., e_{k} in Complex | b = d} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j} - d+ e_{1} +  e_{2} +  ... +  e_{k}) = (a_{1} +  a_{2} +  ... +  a_{i}+ c_{1} +  c_{2} +  ... +  c_{j}+ e_{1} +  e_{2} +  ... +  e_{k}))]
# 	proveit.numbers.addition.subtraction.add_cancel_general
# 52	instantiation	71	|- (1 / 2) = (1 / 2)
# 	x : 1 / 2
# 53	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 54	conjecture		|- forall_{x, y in Complex | y != 0} (((-x) / y) = (-(x / y)))
# 	proveit.numbers.division.neg_frac_neg_numerator
# 55	instantiation	72, 159, 73, 74, 75, 76	|- ((1 * 2) + (1 * (-1))) =  \\ (2 - 1)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 2, 1 * (-1)), y : (2, -1)
# 56	instantiation	77, 114, 86, 78	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 57	instantiation	79, 150	|- delta_{b_{r}} = (phase - (b_{r} / 2^{t}))
# 	b : b_{r}
# 58	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))]
# 	proveit.numbers.multiplication.distribute_through_subtract
# 59	instantiation	157, 154, 128	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 60	instantiation	157, 154, 80	|- (b_{r} / 2^{t}) in Complex
# 	A : Real, B : Complex, x : b_{r} / 2^{t}
# 61	instantiation	90, 81, 82	|- (2^{t} * (b_{r} / 2^{t})) = b_{r}
# 	P(_a) : (2^{t} * (b_{r} / 2^{t})) = _a, x : (1 / 1) * (b_{r} / 1), y : b_{r}
# 62	conjecture		|- forall_{x in Real} (round(x) = floor(x + (1 / 2)))
# 	proveit.numbers.rounding.round_in_terms_of_floor
# 63	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 64	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 65	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 66	instantiation	85	|- |(2^{t} * phase, 1 / 2)| = |(1, ..., 2)|
# 	a : 2^{t} * phase, b : 1 / 2
# 67	instantiation	157, 154, 117	|- (2^{t} * phase) in Complex
# 	A : Real, B : Complex, x : 2^{t} * phase
# 68	instantiation	83, 84	|- (-floor((2^{t} * phase) + (1 / 2))) in Complex
# 	a : floor((2^{t} * phase) + (1 / 2))
# 69	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 70	instantiation	157, 154, 118	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 71	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 72	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 73	instantiation	85	|- |(1 * 2, 1 * (-1))| = |(1, ..., 2)|
# 	a : 1 * 2, b : 1 * (-1)
# 74	instantiation	85	|- |(2, -1)| = |(1, ..., 2)|
# 	a : 2, b : -1
# 75	instantiation	148, 86	|- (1 * 2) = 2
# 	x : 2
# 76	instantiation	87, 114, 88*	|- (1 * (-1)) = (-1)
# 	x : 1, y : 1
# 77	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 78	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 79	axiom		|- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))
# 	proveit.physics.quantum.QPE._delta_b_def
# 80	instantiation	129, 126, 155, 89	|- (b_{r} / 2^{t}) in Real
# 	a : b_{r}, b : 2^{t}
# 81	instantiation	90, 91, 92	|- (2^{t} * (b_{r} / 2^{t})) = ((1 / 1) * (b_{r} / 1))
# 	P(_a) : _a = ((1 / 1) * (b_{r} / 1)), x : ((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1)), y : 2^{t} * (b_{r} / 2^{t})
# 82	instantiation	93, 94, 95, 96	|- ((1 / 1) * (b_{r} / 1)) = b_{r}
# 	a : (1 / 1) * (b_{r} / 1), b : 1 * (b_{r} / 1), c : 1 * b_{r}, d : b_{r}
# 83	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 84	instantiation	160, 97, 98	|- floor((2^{t} * phase) + (1 / 2)) in Complex
# 	A : Integer, B : Complex, x : floor((2^{t} * phase) + (1 / 2))
# 85	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 86	instantiation	157, 154, 131	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 87	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 88	instantiation	139, 114	|- (1 * 1) = 1
# 	x : 1
# 89	instantiation	144, 162	|- 2^{t} != 0
# 	n : 2^{t}
# 90	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 91	instantiation	99, 114, 115, 100, 101	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = ((1 / 1) * (b_{r} / 1))
# 	a : 1, d : b_{r}, b : 2^{t}, c : 1, e : 1
# 92	instantiation	122, 102, 103	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1)), y : 2^{t} * (b_{r} / (2^{t} * 1)), z : 2^{t} * (b_{r} / 2^{t})
# 93	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 94	instantiation	136, 104	|- ((1 / 1) * (b_{r} / 1)) = (1 * (b_{r} / 1))
# 	f(_a) : _a * (b_{r} / 1), x : 1 / 1, y : 1
# 95	instantiation	136, 105	|- (1 * (b_{r} / 1)) = (1 * b_{r})
# 	f(_a) : 1 * _a, x : b_{r} / 1, y : b_{r}
# 96	instantiation	148, 115	|- (1 * b_{r}) = b_{r}
# 	x : b_{r}
# 97	instantiation	163, 106	|- Integer subset_eq Complex
# 	A : Integer, B : Complex
# 98	instantiation	107, 108	|- floor((2^{t} * phase) + (1 / 2)) in Integer
# 	x : (2^{t} * phase) + (1 / 2)
# 99	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_numer_left
# 100	instantiation	157, 110, 109	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 101	instantiation	157, 110, 111	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 102	instantiation	136, 112	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / (2^{t} * 1)))
# 	f(_a) : _a * (b_{r} / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 103	instantiation	136, 113	|- (2^{t} * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : b_{r} / (2^{t} * 1), y : b_{r} / 2^{t}
# 104	instantiation	138, 114	|- (1 / 1) = 1
# 	x : 1
# 105	instantiation	138, 115	|- (b_{r} / 1) = b_{r}
# 	x : b_{r}
# 106	conjecture		|- Integer proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.int_within_complex
# 107	axiom		|- forall_{x in Real} (floor(x) in Integer)
# 	proveit.numbers.rounding.floor_is_an_int
# 108	instantiation	116, 117, 118	|- ((2^{t} * phase) + (1 / 2)) in Real
# 	a : 2^{t} * phase, b : 1 / 2
# 109	instantiation	157, 120, 119	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 110	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 111	instantiation	157, 120, 121	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 112	instantiation	122, 123, 124	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 113	instantiation	136, 125	|- (b_{r} / (2^{t} * 1)) = (b_{r} / 2^{t})
# 	f(_a) : b_{r} / _a, x : 2^{t} * 1, y : 2^{t}
# 114	instantiation	157, 154, 130	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 115	instantiation	157, 154, 126	|- b_{r} in Complex
# 	A : Real, B : Complex, x : b_{r}
# 116	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 117	instantiation	127, 155, 128	|- (2^{t} * phase) in Real
# 	a : 2^{t}, b : phase
# 118	instantiation	129, 130, 131, 132	|- (1 / 2) in Real
# 	a : 1, b : 2
# 119	instantiation	157, 134, 133	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 120	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 121	instantiation	157, 134, 135	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 122	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 123	instantiation	136, 137	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 124	instantiation	138, 149	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 125	instantiation	139, 149	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 126	instantiation	157, 142, 140	|- b_{r} in Real
# 	A : Rational, B : Real, x : b_{r}
# 127	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 128	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 129	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 130	instantiation	157, 142, 141	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 131	instantiation	157, 142, 143	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 132	instantiation	144, 145	|- 2 != 0
# 	n : 2
# 133	instantiation	157, 146, 162	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 134	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 135	instantiation	157, 146, 147	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 136	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 137	instantiation	148, 149	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 138	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 139	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 140	instantiation	157, 152, 150	|- b_{r} in Rational
# 	A : Integer, B : Rational, x : b_{r}
# 141	instantiation	157, 152, 151	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 142	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 143	instantiation	157, 152, 153	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 144	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 145	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 146	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 147	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 148	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 149	instantiation	157, 154, 155	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 150	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
# 151	instantiation	157, 158, 156	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 152	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 153	instantiation	157, 158, 159	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 154	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 155	instantiation	160, 161, 162	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 156	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 157	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 158	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 159	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 160	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 161	instantiation	163, 164	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 162	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 163	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 164	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
