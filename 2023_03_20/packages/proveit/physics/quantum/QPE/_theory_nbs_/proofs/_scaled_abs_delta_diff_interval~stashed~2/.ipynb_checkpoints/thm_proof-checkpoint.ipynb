# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_abs_delta_diff_interval">_scaled_abs_delta_diff_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, l, x, y, z
from proveit.logic import InSet, NotEquals
from proveit.numbers import (zero, one, two, pi, Abs, frac, IntervalOC, Mult)
from proveit.numbers.division import mult_frac_right
from proveit.physics.quantum.QPE import (
        _delta_diff_in_interval, _delta_not_eq_scaledNonzeroInt, _two_pow_t_minus_one_is_nat_pos)

# %%
# %proving _scaled_abs_delta_diff_interval
# Out:
# _scaled_abs_delta_diff_interval: forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((pi * |delta - (l / 2^{t})|) in (0,pi / 2])

# %%
defaults.assumptions = _scaled_abs_delta_diff_interval.all_conditions()
# Out:
# defaults.assumptions: (l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0)

# %%
# previously proven
_delta_diff_in_interval
# Out:
# |- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))

# %%
delta_diff_in_interval_inst = _delta_diff_in_interval.instantiate({l: l})
# Out:
# delta_diff_in_interval_inst: {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)

# %%
# for convenience, label the delta diff component for convenience
delta_diff = delta_diff_in_interval_inst.element
# Out:
# delta_diff: delta - (l / 2^{t})

# %%
delta_diff_in_interval_inst.domain.deduce_relaxed_membership(delta_diff)
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) in [-(1 / 2),1 / 2]

# %%
# for convenience, label the abs value component
abs_val_delta_diff = Abs(delta_diff)
# Out:
# abs_val_delta_diff: |delta - (l / 2^{t})|

# %%
abs_val_leq_one_half = abs_val_delta_diff.deduce_weak_upper_bound(frac(one, two))
# Out:
# abs_val_leq_one_half: {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta - (l / 2^{t})| <= (1 / 2)

# %%
upper_bound = abs_val_leq_one_half.left_mult_both_sides(pi)
# Out:
# upper_bound: {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta - (l / 2^{t})|) <= (pi * (1 / 2))

# %%
mult_frac_right
# Out:
# |- forall_{x, y, z in Complex | z != 0} ((x * (y / z)) = ((x * y) / z))

# %%
pi_one_half_is_pi_over_two = mult_frac_right.instantiate({x: pi, y:one, z: two})
# Out:
# pi_one_half_is_pi_over_two: |- (pi * (1 / 2)) = (pi / 2)

# %%
pi_one_half_is_pi_over_two.sub_right_side_into(upper_bound)
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta - (l / 2^{t})|) <= (pi / 2)

# %%
# previously proven
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# previously proven
_delta_not_eq_scaledNonzeroInt
# Out:
# |- forall_{l in Integer | l != 0} (delta != (l / 2^{t}))

# %%
_delta_not_eq_scaledNonzeroInt.instantiate()
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- delta != (l / 2^{t})

# %%
NotEquals(delta_diff, zero).prove()
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta - (l / 2^{t})) != 0

# %%
abs_val_delta_diff.deduce_positive().left_mult_both_sides(pi)
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta - (l / 2^{t})|) > 0

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((pi * |delta - (l / 2^{t})|) in (0,pi / 2])
# 1	instantiation	2, 3, 4, 5, 6	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta - (l / 2^{t})|) in (0,pi / 2]
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 2	conjecture		|- forall_{a, b, x in Real | a < x <= b} (x in (a,b])
# 	proveit.numbers.number_sets.real_numbers.in_IntervalOC
# 3	instantiation	99, 76, 7	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 4	instantiation	99, 64, 8	|- (pi / 2) in Real
# 	A : RealPos, B : Real, x : pi / 2
# 5	instantiation	99, 64, 14	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta - (l / 2^{t})|) in Real
# 	A : RealPos, B : Real, x : pi * |delta - (l / 2^{t})|
# 6	instantiation	9, 10, 11	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (0 < (pi * |delta - (l / 2^{t})|)) and ((pi * |delta - (l / 2^{t})|) <= (pi / 2))
# 	A : 0 < (pi * |delta - (l / 2^{t})|), B : (pi * |delta - (l / 2^{t})|) <= (pi / 2)
# 7	conjecture		|- 0 in Rational
# 	proveit.numbers.number_sets.rational_numbers.zero_is_rational
# 8	instantiation	12, 65, 13, 28	|- (pi / 2) in RealPos
# 	a : pi, b : 2
# 9	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 10	instantiation	50, 14	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- 0 < (pi * |delta - (l / 2^{t})|)
# 	x : pi * |delta - (l / 2^{t})|
# 11	instantiation	15, 16, 17	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta - (l / 2^{t})|) <= (pi / 2)
# 	P(_a) : (pi * |delta - (l / 2^{t})|) <= _a, x : pi * (1 / 2), y : pi / 2
# 12	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 13	instantiation	99, 18, 94	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 14	instantiation	19, 65, 20	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (pi * |delta - (l / 2^{t})|) in RealPos
# 	a : pi, b : |delta - (l / 2^{t})|
# 15	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 16	instantiation	21, 54, 22, 70, 23, 24	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (pi * |delta - (l / 2^{t})|) <= (pi * (1 / 2))
# 	a : pi, x : |delta - (l / 2^{t})|, y : 1 / 2
# 17	instantiation	25, 42, 26, 27, 28, 29*	|- (pi * (1 / 2)) = (pi / 2)
# 	x : pi, y : 1, z : 2
# 18	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 19	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 	proveit.numbers.multiplication.mult_real_pos_closure_bin
# 20	instantiation	30, 31	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- |delta - (l / 2^{t})| in RealPos
# 	a : delta - (l / 2^{t})
# 21	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 22	instantiation	99, 32, 33	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta - (l / 2^{t})| in Real
# 	A : RealNonNeg, B : Real, x : |delta - (l / 2^{t})|
# 23	instantiation	34, 35, 36	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta - (l / 2^{t})| <= (1 / 2)
# 	a : delta - (l / 2^{t}), c : 1 / 2
# 24	instantiation	48, 37	|- 0 <= pi
# 	x : 0, y : pi
# 25	conjecture		|- forall_{x, y, z in Complex | z != 0} ((x * (y / z)) = ((x * y) / z))
# 	proveit.numbers.division.mult_frac_right
# 26	instantiation	99, 57, 38	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 27	instantiation	99, 57, 39	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 28	instantiation	40, 101	|- 2 != 0
# 	n : 2
# 29	instantiation	41, 42	|- (pi * 1) = pi
# 	x : pi
# 30	conjecture		|- forall_{a in ComplexNonZero} (|a| in RealPos)
# 	proveit.numbers.absolute_value.abs_nonzero_closure
# 31	instantiation	99, 43, 44	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta - (l / 2^{t})) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : delta - (l / 2^{t})
# 32	conjecture		|- RealNonNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_nonneg_within_real
# 33	instantiation	45, 46	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |delta - (l / 2^{t})| in RealNonNeg
# 	a : delta - (l / 2^{t})
# 34	conjecture		|- forall_{a, c | (-c) <= a, a <= c} (|a| <= c)
# 	proveit.numbers.absolute_value.weak_upper_bound
# 35	instantiation	47, 69, 70, 71	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(1 / 2)) <= (delta - (l / 2^{t}))
# 	a : -(1 / 2), b : 1 / 2, x : delta - (l / 2^{t})
# 36	instantiation	48, 49	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) <= (1 / 2)
# 	x : delta - (l / 2^{t}), y : 1 / 2
# 37	instantiation	50, 65	|- pi > 0
# 	x : pi
# 38	instantiation	51, 52, 98	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 39	instantiation	99, 76, 53	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 40	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 41	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 42	instantiation	99, 57, 54	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 43	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 44	instantiation	55, 58, 56	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta - (l / 2^{t})) in RealNonZero
# 	a : delta - (l / 2^{t})
# 45	conjecture		|- forall_{a in Complex} (|a| in RealNonNeg)
# 	proveit.numbers.absolute_value.abs_complex_closure
# 46	instantiation	99, 57, 58	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) in Complex
# 	A : Real, B : Complex, x : delta - (l / 2^{t})
# 47	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 48	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 49	instantiation	59, 69, 70, 71	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) < (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : delta - (l / 2^{t})
# 50	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 51	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 52	instantiation	60, 61	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 53	instantiation	99, 62, 63	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 54	instantiation	99, 64, 65	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 55	conjecture		|- forall_{a in Real | a != 0} (a in RealNonZero)
# 	proveit.numbers.number_sets.real_numbers.nonzero_real_is_real_nonzero
# 56	instantiation	66, 67	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta - (l / 2^{t})) != 0
# 	a : delta, b : l / 2^{t}
# 57	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 58	instantiation	68, 69, 70, 71	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) in Real
# 	a : -(1 / 2), b : 1 / 2, x : delta - (l / 2^{t})
# 59	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 60	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 61	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 62	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 63	instantiation	99, 97, 101	|- 2 in Integer
# 	A : NaturalPos, B : Integer, x : 2
# 64	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 65	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 66	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 67	instantiation	72, 73, 74	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- delta != (l / 2^{t})
# 	l : l
# 68	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 69	instantiation	99, 76, 75	|- (-(1 / 2)) in Real
# 	A : Rational, B : Real, x : -(1 / 2)
# 70	instantiation	99, 76, 77	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 71	instantiation	78, 80	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta - (l / 2^{t})) in [-(1 / 2),1 / 2)
# 	l : l
# 72	conjecture		|- forall_{l in Integer | l != 0} (delta != (l / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_not_eq_scaledNonzeroInt
# 73	instantiation	99, 79, 80	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 74	assumption		{l != 0} |- l != 0
# 75	instantiation	99, 81, 82	|- (-(1 / 2)) in Rational
# 	A : RationalNeg, B : Rational, x : -(1 / 2)
# 76	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 77	instantiation	99, 83, 88	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 78	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((delta - (l / 2^{t})) in [-(1 / 2),1 / 2))
# 	proveit.physics.quantum.QPE._delta_diff_in_interval
# 79	instantiation	84, 85, 86	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 80	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 81	conjecture		|- RationalNeg proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_neg_within_rational
# 82	instantiation	87, 88	|- (-(1 / 2)) in RationalNeg
# 	a : 1 / 2
# 83	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 84	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 85	instantiation	89, 90, 91	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 86	instantiation	99, 97, 103	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 87	conjecture		|- forall_{a in RationalPos} ((-a) in RationalNeg)
# 	proveit.numbers.negation.rational_neg_closure
# 88	instantiation	92, 93, 94	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 89	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 90	instantiation	99, 95, 96	|- (-2^{t - 1}) in Integer
# 	A : IntegerNeg, B : Integer, x : -2^{t - 1}
# 91	instantiation	99, 97, 98	|- 1 in Integer
# 	A : NaturalPos, B : Integer, x : 1
# 92	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 93	instantiation	99, 100, 98	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 94	instantiation	99, 100, 101	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 95	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 96	instantiation	102, 103	|- (-2^{t - 1}) in IntegerNeg
# 	a : 2^{t - 1}
# 97	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 98	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 99	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 100	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 101	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 102	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 103	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
