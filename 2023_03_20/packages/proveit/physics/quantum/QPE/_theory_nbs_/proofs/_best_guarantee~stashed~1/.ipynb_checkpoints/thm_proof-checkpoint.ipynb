# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_best_guarantee">_best_guarantee</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit import b, m
from proveit.logic import Or, Equals, InSet
from proveit.numbers import zero, one, Integer, Neg, Abs, Mod, sqrd
from proveit.numbers.number_sets.real_numbers import pi_between_3_and_4
from proveit.physics.quantum.QPE import (
    _best_guarantee_delta_nonzero, _alpha_ideal_case, 
    _phase_is_real, _phase_in_interval,
    _b_round, _best_round_def, _best_round_is_int, _delta_b_round, _delta_b_def,
    _two_pow_t, _t_in_natural_pos, _two_pow_t_is_nat_pos)

# %%
# %proving _best_guarantee
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_best_guarantee">_best_guarantee:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fc97bbf53a0eacfbb4c8cfa1990ab1578e0ba7bf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/cb2ea2c54bb7fb469c9881c12363a8ad55c21fa60/dependencies.ipynb">dependencies</a>)<br>

# %%
_best_guarantee_delta_nonzero
# Out:
# |- (delta_{b_{r}} != 0) => (|alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2}))

# %%
four_over_pi_sqrd = _best_guarantee_delta_nonzero.consequent.rhs
# Out:
# <strong id="four_over_pi_sqrd">four_over_pi_sqrd:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/98d50f85748d48c31912b45d0692f0f9bf62f0260/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_alpha_ideal_case
# Out:
# |- ((2^{t} * phase) in {0 .. 2^{t} - 1}) => (alpha_{2^{t} * phase} = 1)

# %% [markdown]
# ### Show that when $\delta_{b_r}=0$ then $(2^t \varphi) \in \{0 .. 2^t - 1\}$

# %%
defaults.assumptions = [Equals(_delta_b_round, zero)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/2be4729ead810aac0158c25107b1cf003db261df0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_def
# Out:
# |- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))

# %%
delta_b_definition = _delta_b_def.instantiate({b:_b_round})
# Out:
# <strong id="delta_b_definition">delta_b_definition:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/b447b1f84f1e88af8fcfcc4e6df4402183ca55550/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/de11e047e7bbe87cff61f714d8e0af7e0b2c00260/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
phase_rel_01 = _delta_b_def.instantiate({b:_b_round}).inner_expr().lhs.substitute(zero)
# Out:
# <strong id="phase_rel_01">phase_rel_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/7835670b0d98d36799ba3a6c2ac63264f08902f90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/5007a498f120d02222201157066d234d5bfd5ee30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
phase_rel_02 = phase_rel_01.right_add_both_sides(phase_rel_01.rhs.operands[1].operand).derive_reversed()
# Out:
# <strong id="phase_rel_02">phase_rel_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/31de0b7dafa172774753dad798fbf1d8901b3ad70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/969978e95a1494591a89688da159c851f7ac80100/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
phase_rel_03 = phase_rel_02.left_mult_both_sides(_two_pow_t)
# Out:
# <strong id="phase_rel_03">phase_rel_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/6190c4f7582026ec679fadfd0b04817a05f4b35b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/83aed03223924c8a34729d283996dcc7c322707b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_best_round_def
# Out:
# |- b_{r} = round(2^{t} * phase)

# %%
InSet(phase_rel_03.lhs, Integer).prove()
# Out:
# {delta_{b_{r}} = 0} |- (2^{t} * phase) in Integer

# %%
_phase_in_interval
# Out:
# |- phase in [0,1)

# %%
phase_lower_bound = _phase_in_interval.derive_element_lower_bound()
# Out:
# <strong id="phase_lower_bound">phase_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/0064ba32a8b3370dc6147fa8654807c16d2ce8350/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/ae02d4d05b521fe54b74cf64571b99633b6f52db0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
phase_lower_bound.left_mult_both_sides(_two_pow_t)
# Out:
# |- 0 <= (2^{t} * phase)

# %%
phase_upper_bound = _phase_in_interval.derive_element_upper_bound()
# Out:
# <strong id="phase_upper_bound">phase_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4fb3caad640e151d33b04938955c218400f1001f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/dc9d1f7921c722a2710280fcb79a51993f569bbb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_phase_upper_bound = phase_upper_bound.left_mult_both_sides(_two_pow_t)
# Out:
# <strong id="scaled_phase_upper_bound">scaled_phase_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4f2f871d838cacfd67a779d0718a4f63ef4021bf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/3b68c61b4018d393a829437c22636a5e44f8a6ee0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
scaled_phase_upper_bound.add_right(Neg(one), strong=False)
# Out:
# {delta_{b_{r}} = 0} |- (2^{t} * phase) <= (2^{t} - 1)

# %%
ideal_alpha_01 = _alpha_ideal_case.derive_consequent()
# Out:
# <strong id="ideal_alpha_01">ideal_alpha_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/c963caf67af025262471bf82e2cdf8b39b8a87e30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0c578b359940001aca5868475b467854cfe2b7920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Replace $2^t \varphi$ with $b_r~\textrm{mod}~2^t$ assuming $\delta_{b_r} = 0$

# %%
ideal_alpha_02 = phase_rel_03.sub_right_side_into(ideal_alpha_01)
# Out:
# <strong id="ideal_alpha_02">ideal_alpha_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/23e5b49e998a52495e14bfb11d599255e6513b120/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/edd30e098450cae6b31eca61ea3c5f41c6dab1160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_alpha_ideal_case.antecedent
# Out:
# (2^{t} * phase) in {0 .. 2^{t} - 1}

# %%
InSet(_b_round, _alpha_ideal_case.antecedent.domain).prove()
# Out:
# {delta_{b_{r}} = 0} |- b_{r} in {0 .. 2^{t} - 1}

# %%
b_r_mod__eq__br = Mod(_b_round, _two_pow_t).simplification()
# Out:
# <strong id="b_r_mod__eq__br">b_r_mod__eq__br:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/7f66e1825d5011eca629ca5398ffc7e757ba75410/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/5b4f691c7b9c9fd69745dd5b2c9975bc70fd52400/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ideal_alpha_03 = b_r_mod__eq__br.sub_left_side_into(ideal_alpha_02)
# Out:
# <strong id="ideal_alpha_03">ideal_alpha_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/4056f43c0242580d7ab86324c24d6c0c330a0d7d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/28d806e4d09bc657cf5e8d5b8e7e50f1e9a3b3790/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/960ceb23b55c9228f566480ce7a741e18aa65c0a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Now we can prove that $|\alpha_{b_r~\textrm{mod}~2^t}|^2 > 4/\pi^2$ whether or not $\delta_{b_r} = 0$

# %%
defaults.preserved_exprs={Abs(ideal_alpha_03.lhs), sqrd(Abs(ideal_alpha_03.lhs))}
ideal_alpha_03.abs_both_sides().square_both_sides()
# Out:
# {delta_{b_{r}} = 0} |- |alpha_{b_{r} mod 2^{t}}|^{2} = 1

# %%
pi_between_3_and_4
# Out:
# |- 3 < pi < 4

# %%
four_over_pi_sqrd_bound = four_over_pi_sqrd.deduce_bound(pi_between_3_and_4.operands[0].reversed())
# Out:
# <strong id="four_over_pi_sqrd_bound">four_over_pi_sqrd_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/97cfce845552fa4f07566458d0e1cef970e07fbb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/568863e5f40dc81006e77aa9dc0645f257f8ab580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers import Less, num
Less(num(4), num(9)).prove().divide_both_sides(num(9))
# Out:
# |- (4 / 9) < 1

# %%
eq_or_not = Or(defaults.assumptions[0], _best_guarantee_delta_nonzero.antecedent)
# Out:
# <strong id="eq_or_not">eq_or_not:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/9ced7d503a9d210b21f45df804673342c1ad71550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = []
alpha_sqrd_bound = eq_or_not.derive_via_dilemma(_best_guarantee_delta_nonzero.consequent)
# Out:
# <strong id="alpha_sqrd_bound">alpha_sqrd_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee/054f66422efe4d4ecfceb7d809ed52f0480db01b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/e631225ed9003b00eb1a57a53887a3df670230d40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_best_round_def.sub_right_side_into(alpha_sqrd_bound)
# Out:
# |- |alpha_{round(2^{t} * phase) mod 2^{t}}|^{2} > (4 / pi^{2})
# _best_guarantee has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._best_guarantee has been proven.
# 	step type	requirements	statement
# 0	instantiation	189, 1, 2	|- |alpha_{round(2^{t} * phase) mod 2^{t}}|^{2} > (4 / pi^{2})
# 	P(_a) : |alpha_{_a mod 2^{t}}|^{2} > (4 / pi^{2}), x : b_{r}, y : round(2^{t} * phase)
# 1	instantiation	3, 14, 4, 5, 6, 7	|- |alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2})
# 	A : delta_{b_{r}} = 0, B : delta_{b_{r}} != 0, C : |alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2})
# 2	axiom		|- b_{r} = round(2^{t} * phase)
# 	proveit.physics.quantum.QPE._best_round_def
# 3	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 4	instantiation	8	|- (delta_{b_{r}} != 0) in BOOLEAN
# 	x : delta_{b_{r}}, y : 0
# 5	instantiation	9, 10, 11	|- (delta_{b_{r}} = 0) or (delta_{b_{r}} != 0)
# 	P : (delta_{b_{r}} = 0) or [not](delta_{b_{r}} = 0), Q : (delta_{b_{r}} = 0) or (delta_{b_{r}} != 0)
# 6	deduction	12	|- (delta_{b_{r}} = 0) => (|alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2}))
# 7	conjecture		|- (delta_{b_{r}} != 0) => (|alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2}))
# 	proveit.physics.quantum.QPE._best_guarantee_delta_nonzero
# 8	conjecture		|- forall_{x, y} ((x != y) in BOOLEAN)
# 	proveit.logic.equality.not_equals_is_bool
# 9	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 10	instantiation	13, 14	|- (delta_{b_{r}} = 0) or [not](delta_{b_{r}} = 0)
# 	A : delta_{b_{r}} = 0
# 11	instantiation	227, 15	|- ((delta_{b_{r}} = 0) or [not](delta_{b_{r}} = 0)) = ((delta_{b_{r}} = 0) or (delta_{b_{r}} != 0))
# 	f(_a) : (delta_{b_{r}} = 0) or _a, x : [not](delta_{b_{r}} = 0), y : delta_{b_{r}} != 0
# 12	instantiation	43, 16, 17	{delta_{b_{r}} = 0} |- (4 / pi^{2}) < |alpha_{b_{r} mod 2^{t}}|^{2}
# 	x : 4 / pi^{2}, y : 4 / 9, z : |alpha_{b_{r} mod 2^{t}}|^{2}
# 13	conjecture		|- forall_{A in BOOLEAN} (A or [not](A))
# 	proveit.logic.booleans.unfold_is_bool
# 14	instantiation	18	|- (delta_{b_{r}} = 0) in BOOLEAN
# 	x : delta_{b_{r}}, y : 0
# 15	instantiation	161, 19	|- [not](delta_{b_{r}} = 0) = (delta_{b_{r}} != 0)
# 	x : delta_{b_{r}} != 0, y : [not](delta_{b_{r}} = 0)
# 16	instantiation	20, 21, 22, 23, 60	|- (4 / 9) > (4 / pi^{2})
# 	a : 4, x : 9, y : pi^{2}
# 17	instantiation	145, 24, 25	{delta_{b_{r}} = 0} |- (4 / 9) < |alpha_{b_{r} mod 2^{t}}|^{2}
# 	P(_a) : (4 / 9) < _a, x : |alpha_{b_{r} mod 2^{t}}|^{2}, y : 1
# 18	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 19	instantiation	26	|- (delta_{b_{r}} != 0) = [not](delta_{b_{r}} = 0)
# 	x : delta_{b_{r}}, y : 0
# 20	conjecture		|- forall_{a, x, y in RealPos | x < y} ((a / x) > (a / y))
# 	proveit.numbers.division.strong_div_from_denom_bound__all_pos
# 21	instantiation	253, 28, 27	|- 4 in RealPos
# 	A : RationalPos, B : RealPos, x : 4
# 22	instantiation	253, 28, 29	|- 9 in RealPos
# 	A : RationalPos, B : RealPos, x : 9
# 23	instantiation	30, 31, 32	|- pi^{2} in RealPos
# 	a : pi^{2}
# 24	instantiation	33, 65, 93, 34, 59, 35*	|- (4 / 9) < 1
# 	a : 9, x : 4, y : 9
# 25	instantiation	36, 72, 37, 221, 38, 39*	{delta_{b_{r}} = 0} |- |alpha_{b_{r} mod 2^{t}}|^{2} = 1
# 	a : 2, x : |alpha_{b_{r} mod 2^{t}}|, y : 1
# 26	axiom		|- forall_{x, y} ((x != y) = [not](x = y))
# 	proveit.logic.equality.not_equals_def
# 27	instantiation	253, 41, 40	|- 4 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 4
# 28	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 29	instantiation	253, 41, 70	|- 9 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 9
# 30	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 31	instantiation	42, 73, 194	|- pi^{2} in Real
# 	a : pi, b : 2
# 32	instantiation	43, 44	|- 0 < pi^{2}
# 	x : 0, y : 9, z : pi^{2}
# 33	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((x / a) < (y / a))
# 	proveit.numbers.division.strong_div_from_numer_bound__pos_denom
# 34	instantiation	45, 93, 157, 46, 47, 48*, 49*	|- 4 < 9
# 	a : 4, x : 0, y : 5
# 35	instantiation	50, 51, 52	|- (9 / 9) = 1
# 	x : 9
# 36	conjecture		|- forall_{a, x, y in Real | x = y} (x^{a} = y^{a})
# 	proveit.numbers.exponentiation.exp_eq_real
# 37	instantiation	253, 53, 54	{delta_{b_{r}} = 0} |- |alpha_{b_{r} mod 2^{t}}| in Real
# 	A : RealNonNeg, B : Real, x : |alpha_{b_{r} mod 2^{t}}|
# 38	instantiation	55, 67, 206, 83, 56*	{delta_{b_{r}} = 0} |- |alpha_{b_{r} mod 2^{t}}| = 1
# 	x : alpha_{b_{r} mod 2^{t}}, y : 1
# 39	instantiation	57, 58	|- 1^{2} = 1
# 	x : 2
# 40	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 41	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 42	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 43	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 44	instantiation	130, 59, 60	|- (0 < 9) and (9 < pi^{2})
# 	A : 0 < 9, B : 9 < pi^{2}
# 45	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 46	instantiation	253, 232, 61	|- 5 in Real
# 	A : Rational, B : Real, x : 5
# 47	instantiation	159, 62	|- 5 > 0
# 	n : 5
# 48	instantiation	189, 63, 64	|- (0 + 4) = 4
# 	P(_a) : _a = 4, x : 4 + 0, y : 0 + 4
# 49	conjecture		|- (5 + 4) = 9
# 	proveit.numbers.numerals.decimals.add_5_4
# 50	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 51	instantiation	253, 243, 65	|- 9 in Complex
# 	A : Real, B : Complex, x : 9
# 52	instantiation	250, 70	|- 9 != 0
# 	n : 9
# 53	conjecture		|- RealNonNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_nonneg_within_real
# 54	instantiation	66, 67	{delta_{b_{r}} = 0} |- |alpha_{b_{r} mod 2^{t}}| in RealNonNeg
# 	a : alpha_{b_{r} mod 2^{t}}
# 55	conjecture		|- forall_{x, y in Complex | x = y} (|x| = |y|)
# 	proveit.numbers.absolute_value.abs_eq
# 56	instantiation	68, 69	|- |1| = 1
# 	x : 1
# 57	conjecture		|- forall_{x in Complex} (1^{x} = 1)
# 	proveit.numbers.exponentiation.exponentiated_one
# 58	instantiation	253, 243, 72	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 59	instantiation	159, 70	|- 9 > 0
# 	n : 9
# 60	instantiation	71, 72, 113, 73, 74, 75, 76*	|- 9 < pi^{2}
# 	a : 2, x : 3, y : pi
# 61	instantiation	253, 248, 77	|- 5 in Rational
# 	A : Integer, B : Rational, x : 5
# 62	conjecture		|- 5 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat5
# 63	instantiation	78, 80	|- (4 + 0) = 4
# 	a : 4
# 64	instantiation	79, 80, 81	|- (4 + 0) = (0 + 4)
# 	a : 4, b : 0
# 65	instantiation	253, 232, 82	|- 9 in Real
# 	A : Rational, B : Real, x : 9
# 66	conjecture		|- forall_{a in Complex} (|a| in RealNonNeg)
# 	proveit.numbers.absolute_value.abs_complex_closure
# 67	instantiation	145, 206, 83	{delta_{b_{r}} = 0} |- alpha_{b_{r} mod 2^{t}} in Complex
# 	P(_a) : _a in Complex, x : alpha_{b_{r} mod 2^{t}}, y : 1
# 68	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 69	instantiation	98, 246	|- 1 >= 0
# 	n : 1
# 70	conjecture		|- 9 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat9
# 71	conjecture		|- forall_{a, x, y in Real | 0 <= x < y, a > 0} (x^{a} < y^{a})
# 	proveit.numbers.exponentiation.exp_pos_less
# 72	instantiation	253, 232, 84	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 73	instantiation	253, 85, 86	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 74	instantiation	130, 87, 88	|- (0 <= 3) and (3 < pi)
# 	A : 0 <= 3, B : 3 < pi
# 75	instantiation	159, 102	|- 2 > 0
# 	n : 2
# 76	instantiation	172, 89, 90, 91	|- 3^{2} = 9
# 	a : 3^{2}, b : 3 *  ..0 ×.. *  3, c : 3 * 3, d : 9
# 77	instantiation	253, 245, 92	|- 5 in Integer
# 	A : Natural, B : Integer, x : 5
# 78	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 79	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 80	instantiation	253, 243, 93	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 81	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 82	instantiation	253, 248, 94	|- 9 in Rational
# 	A : Integer, B : Rational, x : 9
# 83	instantiation	145, 95, 96	{delta_{b_{r}} = 0} |- alpha_{b_{r} mod 2^{t}} = 1
# 	P(_a) : alpha_{_a} = 1, x : b_{r} mod 2^{t}, y : b_{r}
# 84	instantiation	253, 248, 97	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 85	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 86	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 87	instantiation	98, 133	|- 3 >= 0
# 	n : 3
# 88	instantiation	99, 100	|- 3 < pi
# 	A : 3 < pi, B : pi < 4
# 89	instantiation	101, 102, 103	|- 3^{2} = (3 *  ..0 ×.. *  3)
# 	n : 2, x : 3
# 90	instantiation	104, 194, 105, 106, 107	|- (3 *  ..0 ×.. *  3) =  \\ (3 * 3)
# 	n : 2, f(_b_{1}, ..., _b_{2}) : _b_{1} *  ... *  _b_{2}, x : (3, ..0 ×.., 3), y : (3, 3)
# 91	conjecture		|- (3 * 3) = 9
# 	proveit.numbers.numerals.decimals.mult_3_3
# 92	conjecture		|- 5 in Natural
# 	proveit.numbers.numerals.decimals.nat5
# 93	instantiation	253, 232, 108	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 94	instantiation	253, 245, 109	|- 9 in Integer
# 	A : Natural, B : Integer, x : 9
# 95	instantiation	189, 110, 146	{delta_{b_{r}} = 0} |- alpha_{b_{r}} = 1
# 	P(_a) : alpha_{_a} = 1, x : 2^{t} * phase, y : b_{r}
# 96	instantiation	111, 255, 112	{delta_{b_{r}} = 0} |- (b_{r} mod 2^{t}) = b_{r}
# 	L : 2^{t}, x : b_{r}
# 97	instantiation	253, 245, 194	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 98	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 99	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 100	conjecture		|- 3 < pi < 4
# 	proveit.numbers.number_sets.real_numbers.pi_between_3_and_4
# 101	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} (x^{n} = (x *  x *  ..(n - 3) ×.. *  x))]
# 	proveit.numbers.exponentiation.exp_nat_pos_expansion
# 102	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 103	instantiation	253, 243, 113	|- 3 in Complex
# 	A : Real, B : Complex, x : 3
# 104	conjecture		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution_via_tuple
# 105	instantiation	114, 194	|- |(3, ..0 ×.., 3)| = |(1, ..., 2)|
# 	i : 2, f(_a) : 3
# 106	instantiation	209	|- |(3, 3)| = |(1, ..., 2)|
# 	a : 3, b : 3
# 107	instantiation	115	|- (3, ..0 ×.., 3) = (3, 3)
# 	x : 3
# 108	instantiation	253, 248, 116	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 109	conjecture		|- 9 in Natural
# 	proveit.numbers.numerals.decimals.nat9
# 110	modus ponens	117, 118	{delta_{b_{r}} = 0} |- alpha_{2^{t} * phase} = 1
# 111	conjecture		|- forall_{L in NaturalPos} [forall_{x in {0 .. L - 1}} ((x mod L) = x)]
# 	proveit.numbers.modular.int_mod_elimination
# 112	instantiation	122, 123, 124, 247, 119	{delta_{b_{r}} = 0} |- b_{r} in {0 .. 2^{t} - 1}
# 	a : 0, b : 2^{t} - 1, n : b_{r}
# 113	instantiation	253, 232, 120	|- 3 in Real
# 	A : Rational, B : Real, x : 3
# 114	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 115	conjecture		|- forall_{x} ((x, ..0 ×.., x) = (x, x))
# 	proveit.numbers.numerals.decimals.reduce_2_repeats
# 116	instantiation	253, 245, 121	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 117	conjecture		|- ((2^{t} * phase) in {0 .. 2^{t} - 1}) => (alpha_{2^{t} * phase} = 1)
# 	proveit.physics.quantum.QPE._alpha_ideal_case
# 118	instantiation	122, 123, 124, 139, 125	{delta_{b_{r}} = 0} |- (2^{t} * phase) in {0 .. 2^{t} - 1}
# 	a : 0, b : 2^{t} - 1, n : 2^{t} * phase
# 119	instantiation	130, 126, 127	{delta_{b_{r}} = 0} |- (0 <= b_{r}) and (b_{r} <= (2^{t} - 1))
# 	A : 0 <= b_{r}, B : b_{r} <= (2^{t} - 1)
# 120	instantiation	253, 248, 128	|- 3 in Rational
# 	A : Integer, B : Rational, x : 3
# 121	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 122	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 123	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 124	instantiation	129, 249, 165	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 125	instantiation	130, 131, 132	{delta_{b_{r}} = 0} |- (0 <= (2^{t} * phase)) and ((2^{t} * phase) <= (2^{t} - 1))
# 	A : 0 <= (2^{t} * phase), B : (2^{t} * phase) <= (2^{t} - 1)
# 126	instantiation	189, 131, 146	{delta_{b_{r}} = 0} |- 0 <= b_{r}
# 	P(_a) : 0 <= _a, x : 2^{t} * phase, y : b_{r}
# 127	instantiation	189, 132, 146	{delta_{b_{r}} = 0} |- b_{r} <= (2^{t} - 1)
# 	P(_a) : _a <= (2^{t} - 1), x : 2^{t} * phase, y : b_{r}
# 128	instantiation	253, 245, 133	|- 3 in Integer
# 	A : Natural, B : Integer, x : 3
# 129	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 130	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 131	instantiation	134, 244, 157, 212, 135, 136, 137*	|- 0 <= (2^{t} * phase)
# 	a : 2^{t}, x : 0, y : phase
# 132	instantiation	138, 139, 249, 165, 140, 141	{delta_{b_{r}} = 0} |- (2^{t} * phase) <= (2^{t} - 1)
# 	a : 2^{t} * phase, b : 2^{t}, c : -1
# 133	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 134	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 135	instantiation	142, 157, 221, 158	|- 0 <= phase
# 	a : 0, b : 1, x : phase
# 136	instantiation	143, 149	|- 0 <= 2^{t}
# 	x : 0, y : 2^{t}
# 137	instantiation	144, 237	|- (2^{t} * 0) = 0
# 	x : 2^{t}
# 138	conjecture		|- forall_{a, b, c in Integer | a < b, (-1) <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_add_right_weak_int
# 139	instantiation	145, 247, 146	{delta_{b_{r}} = 0} |- (2^{t} * phase) in Integer
# 	P(_a) : _a in Integer, x : 2^{t} * phase, y : b_{r}
# 140	instantiation	147, 244, 212, 221, 148, 149, 220*	|- (2^{t} * phase) < 2^{t}
# 	a : 2^{t}, x : phase, y : 1
# 141	instantiation	150, 151, 152	|- (-1) <= (-1)
# 	x : -1, y : -1
# 142	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 143	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 144	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 145	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 146	instantiation	153, 244, 212, 223, 154, 155*	{delta_{b_{r}} = 0} |- (2^{t} * phase) = b_{r}
# 	a : 2^{t}, x : phase, y : b_{r} / 2^{t}
# 147	conjecture		|- forall_{a, x, y in Real | x < y, a > 0} ((a * x) < (a * y))
# 	proveit.numbers.multiplication.strong_bound_via_right_factor_bound
# 148	instantiation	156, 157, 221, 158	|- phase < 1
# 	a : 0, b : 1, x : phase
# 149	instantiation	159, 255	|- 2^{t} > 0
# 	n : 2^{t}
# 150	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 151	instantiation	253, 232, 160	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 152	instantiation	213	|- (-1) = (-1)
# 	x : -1
# 153	conjecture		|- forall_{a, x, y in Real | x = y} ((a * x) = (a * y))
# 	proveit.numbers.multiplication.left_mult_eq_real
# 154	instantiation	161, 162	{delta_{b_{r}} = 0} |- phase = (b_{r} / 2^{t})
# 	x : b_{r} / 2^{t}, y : phase
# 155	instantiation	189, 163, 164	|- (2^{t} * (b_{r} / 2^{t})) = b_{r}
# 	P(_a) : (2^{t} * (b_{r} / 2^{t})) = _a, x : (1 / 1) * (b_{r} / 1), y : b_{r}
# 156	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 157	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 158	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 159	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 160	instantiation	253, 248, 165	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 161	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 162	instantiation	166, 233, 177, 167, 178, 168*, 169*	{delta_{b_{r}} = 0} |- (b_{r} / 2^{t}) = phase
# 	a : b_{r} / 2^{t}, x : 0, y : phase - (b_{r} / 2^{t})
# 163	instantiation	189, 170, 171	|- (2^{t} * (b_{r} / 2^{t})) = ((1 / 1) * (b_{r} / 1))
# 	P(_a) : _a = ((1 / 1) * (b_{r} / 1)), x : ((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1)), y : 2^{t} * (b_{r} / 2^{t})
# 164	instantiation	172, 173, 174, 175	|- ((1 / 1) * (b_{r} / 1)) = b_{r}
# 	a : (1 / 1) * (b_{r} / 1), b : 1 * (b_{r} / 1), c : 1 * b_{r}, d : b_{r}
# 165	instantiation	176, 238	|- (-1) in Integer
# 	a : 1
# 166	conjecture		|- forall_{a, x, y in Rational | x = y} ((x + a) = (y + a))
# 	proveit.numbers.addition.right_add_eq_rational
# 167	instantiation	189, 177, 178	{delta_{b_{r}} = 0} |- (phase - (b_{r} / 2^{t})) in Rational
# 	P(_a) : _a in Rational, x : 0, y : phase - (b_{r} / 2^{t})
# 168	instantiation	179, 211	|- (0 + (b_{r} / 2^{t})) = (b_{r} / 2^{t})
# 	a : b_{r} / 2^{t}
# 169	instantiation	217, 180, 181	|- ((phase - (b_{r} / 2^{t})) + (b_{r} / 2^{t})) = phase
# 	x : (phase - (b_{r} / 2^{t})) + (b_{r} / 2^{t}), y : phase - (b_{r} / 2^{t}) + (b_{r} / 2^{t}), z : phase
# 170	instantiation	182, 206, 207, 183, 184	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = ((1 / 1) * (b_{r} / 1))
# 	a : 1, d : b_{r}, b : 2^{t}, c : 1, e : 1
# 171	instantiation	217, 185, 186	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1)), y : 2^{t} * (b_{r} / (2^{t} * 1)), z : 2^{t} * (b_{r} / 2^{t})
# 172	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 173	instantiation	227, 187	|- ((1 / 1) * (b_{r} / 1)) = (1 * (b_{r} / 1))
# 	f(_a) : _a * (b_{r} / 1), x : 1 / 1, y : 1
# 174	instantiation	227, 188	|- (1 * (b_{r} / 1)) = (1 * b_{r})
# 	f(_a) : 1 * _a, x : b_{r} / 1, y : b_{r}
# 175	instantiation	236, 207	|- (1 * b_{r}) = b_{r}
# 	x : b_{r}
# 176	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 177	conjecture		|- 0 in Rational
# 	proveit.numbers.number_sets.rational_numbers.zero_is_rational
# 178	instantiation	189, 190, 191	{delta_{b_{r}} = 0} |- 0 = (phase - (b_{r} / 2^{t}))
# 	P(_a) : _a = (phase - (b_{r} / 2^{t})), x : delta_{b_{r}}, y : 0
# 179	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 180	instantiation	192, 193, 194, 246, 195, 196, 199, 197, 211	|- ((phase - (b_{r} / 2^{t})) + (b_{r} / 2^{t})) =  \\ (phase - (b_{r} / 2^{t}) + (b_{r} / 2^{t}))
# 	i : 0, j : 2, k : 1, a : (), b : (phase, -(b_{r} / 2^{t})), c : (b_{r} / 2^{t})
# 181	instantiation	198, 211, 199, 200	|- (phase - (b_{r} / 2^{t}) + (b_{r} / 2^{t})) = phase
# 	a : b_{r} / 2^{t}, b : b_{r} / 2^{t}, c : phase
# 182	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_numer_left
# 183	instantiation	253, 202, 201	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 184	instantiation	253, 202, 203	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 185	instantiation	227, 204	|- (((1 * 2^{t}) / 1) * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / (2^{t} * 1)))
# 	f(_a) : _a * (b_{r} / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 186	instantiation	227, 205	|- (2^{t} * (b_{r} / (2^{t} * 1))) = (2^{t} * (b_{r} / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : b_{r} / (2^{t} * 1), y : b_{r} / 2^{t}
# 187	instantiation	229, 206	|- (1 / 1) = 1
# 	x : 1
# 188	instantiation	229, 207	|- (b_{r} / 1) = b_{r}
# 	x : b_{r}
# 189	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 190	instantiation	208, 247	|- delta_{b_{r}} = (phase - (b_{r} / 2^{t}))
# 	b : b_{r}
# 191	assumption		{delta_{b_{r}} = 0} |- delta_{b_{r}} = 0
# 192	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 193	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 194	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 195	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 196	instantiation	209	|- |(phase, -(b_{r} / 2^{t}))| = |(1, ..., 2)|
# 	a : phase, b : -(b_{r} / 2^{t})
# 197	instantiation	210, 211	|- (-(b_{r} / 2^{t})) in Complex
# 	a : b_{r} / 2^{t}
# 198	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 199	instantiation	253, 243, 212	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 200	instantiation	213	|- (b_{r} / 2^{t}) = (b_{r} / 2^{t})
# 	x : b_{r} / 2^{t}
# 201	instantiation	253, 215, 214	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 202	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 203	instantiation	253, 215, 216	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 204	instantiation	217, 218, 219	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 205	instantiation	227, 220	|- (b_{r} / (2^{t} * 1)) = (b_{r} / 2^{t})
# 	f(_a) : b_{r} / _a, x : 2^{t} * 1, y : 2^{t}
# 206	instantiation	253, 243, 221	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 207	instantiation	253, 243, 222	|- b_{r} in Complex
# 	A : Real, B : Complex, x : b_{r}
# 208	axiom		|- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))
# 	proveit.physics.quantum.QPE._delta_b_def
# 209	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 210	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 211	instantiation	253, 243, 223	|- (b_{r} / 2^{t}) in Complex
# 	A : Real, B : Complex, x : b_{r} / 2^{t}
# 212	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 213	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 214	instantiation	253, 225, 224	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 215	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 216	instantiation	253, 225, 226	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 217	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 218	instantiation	227, 228	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 219	instantiation	229, 237	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 220	instantiation	230, 237	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 221	instantiation	253, 232, 231	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 222	instantiation	253, 232, 240	|- b_{r} in Real
# 	A : Rational, B : Real, x : b_{r}
# 223	instantiation	253, 232, 233	|- (b_{r} / 2^{t}) in Real
# 	A : Rational, B : Real, x : b_{r} / 2^{t}
# 224	instantiation	253, 234, 255	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 225	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 226	instantiation	253, 234, 235	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 227	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 228	instantiation	236, 237	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 229	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 230	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 231	instantiation	253, 248, 238	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 232	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 233	instantiation	239, 240, 241, 242	|- (b_{r} / 2^{t}) in Rational
# 	a : b_{r}, b : 2^{t}
# 234	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 235	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 236	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 237	instantiation	253, 243, 244	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 238	instantiation	253, 245, 246	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 239	conjecture		|- forall_{a, b in Rational | b != 0} ((a / b) in Rational)
# 	proveit.numbers.division.div_rational_closure
# 240	instantiation	253, 248, 247	|- b_{r} in Rational
# 	A : Integer, B : Rational, x : b_{r}
# 241	instantiation	253, 248, 249	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 242	instantiation	250, 255	|- 2^{t} != 0
# 	n : 2^{t}
# 243	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 244	instantiation	251, 252, 255	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 245	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 246	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 247	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
# 248	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 249	instantiation	253, 254, 255	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 250	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 251	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 252	instantiation	256, 257	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 253	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 254	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 255	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 256	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 257	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
