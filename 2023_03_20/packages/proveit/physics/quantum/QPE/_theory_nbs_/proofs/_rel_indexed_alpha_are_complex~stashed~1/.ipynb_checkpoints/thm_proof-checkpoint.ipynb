# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_rel_indexed_alpha_are_complex">_rel_indexed_alpha_are_complex</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit import l, m
from proveit.physics.quantum.QPE import ModAdd
from proveit.physics.quantum.QPE import (_alpha_are_complex, _b_floor, _best_floor_is_in_m_domain,
                                        _two_pow_t_is_nat_pos, _two_pow_t_less_one_is_nat_pos)

# %%
# %proving _rel_indexed_alpha_are_complex
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_rel_indexed_alpha_are_complex">_rel_indexed_alpha_are_complex:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/36cffb86a43477281237716673e8b34bb9d44e710/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/930690a0f4a9a50cc6d53e4c8938bd2a32b4d5c30/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _rel_indexed_alpha_are_complex.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__rel_indexed_alpha_are_complex/9d653541d73b93ecf37ec47732c843513b4cabea0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_best_floor_is_in_m_domain
# Out:
# |- b_{f} in {0 .. 2^{t} - 1}

# %%
_alpha_are_complex
# Out:
# |- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} in Complex)

# %%
_alpha_are_complex.instantiate({m:ModAdd(_b_floor, l)})
# Out:
# Expression notebook is being updated for ({0 .. 2^{t} - 1}, Integer)
# Expression notebook is being updated for {0 .. 2^{t} - 1} proper_subset Integer
# Expression notebook is being updated for (b_{f} MOD_ADD l, {0 .. 2^{t} - 1})
# Expression notebook is being updated for (b_{f} MOD_ADD l) in {0 .. 2^{t} - 1}
# {l in Integer} |- alpha_{b_{f} MOD_ADD l} in Complex
# _rel_indexed_alpha_are_complex may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._rel_indexed_alpha_are_complex has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in Integer} (alpha_{b_{f} MOD_ADD l} in Complex)
# 1	instantiation	2, 3	{l in Integer} |- alpha_{b_{f} MOD_ADD l} in Complex
# 	m : b_{f} MOD_ADD l
# 2	conjecture		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} in Complex)
# 	proveit.physics.quantum.QPE._alpha_are_complex
# 3	instantiation	4, 5, 6	{l in Integer} |- (b_{f} MOD_ADD l) in {0 .. 2^{t} - 1}
# 	a : b_{f}, b : l
# 4	conjecture		|- forall_{a, b in Integer} ((a MOD_ADD b) in {0 .. 2^{t} - 1})
# 	proveit.physics.quantum.QPE._mod_add_closure
# 5	instantiation	12, 7, 8	|- b_{f} in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : b_{f}
# 6	assumption		{l in Integer} |- l in Integer
# 7	instantiation	9, 10, 11	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 8	conjecture		|- b_{f} in {0 .. 2^{t} - 1}
# 	proveit.physics.quantum.QPE._best_floor_is_in_m_domain
# 9	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 10	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 11	instantiation	12, 13, 14	|- (2^{t} - 1) in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t} - 1
# 12	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 13	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 14	conjecture		|- (2^{t} - 1) in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_less_one_is_nat_pos
