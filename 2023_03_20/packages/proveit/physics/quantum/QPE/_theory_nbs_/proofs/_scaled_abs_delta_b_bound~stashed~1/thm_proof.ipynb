# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_abs_delta_b_bound">_scaled_abs_delta_b_bound</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit import b
from proveit.numbers import one, two, pi, Abs, Less, greater, Mult, frac
from proveit.physics.quantum.QPE import _two_pow_t, _b_round, _delta_b_round
from proveit.physics.quantum.QPE import (_t_in_natural_pos, _best_round_is_int, _delta_b_is_real,
                                         _scaled_delta_b_round_in_interval)

# %%
# %proving _scaled_abs_delta_b_bound
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_abs_delta_b_bound">_scaled_abs_delta_b_bound:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1a0774081dee8f51c79e0ca23e965773fcd6f3e60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/ca5ba9e5062173d5e5073ac372da8d0c85769b300/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [_scaled_abs_delta_b_bound.antecedent]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_bound/ecdd50710244b3da50fc52266bb53cd5a701a6980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
_delta_b_is_real.instantiate({b:_b_round})
# Out:
# |- delta_{b_{r}} in Real

# %%
_scaled_delta_b_round_in_interval
# Out:
# |- (2^{t} * delta_{b_{r}}) in [-(1 / 2),1 / 2)

# %%
bound = (Abs(_scaled_delta_b_round_in_interval.element).deduce_weak_upper_bound(frac(one, two))
         .inner_expr().lhs.simplify())
# Out:
# <strong id="bound">bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_bound/ff2f92560a4c72bc41a3815ccf5aad16051293bd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_abs_delta_b_bound/78e2f63ffd309713f9fa4a73b8b88a5101648c350/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound.right_mult_both_sides(pi)
# Out:
# |- (2^{t} * |delta_{b_{r}}| * pi) <= ((1 / 2) * pi)
# _scaled_abs_delta_b_bound may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_abs_delta_b_bound has been proven.
# 	step type	requirements	statement
# 0	deduction	1	|- (delta_{b_{r}} != 0) => ((2^{t} * pi * |delta_{b_{r}}|) <= (pi / 2))
# 1	instantiation	4, 2, 3	|- (2^{t} * pi * |delta_{b_{r}}|) <= (pi / 2)
# 	P(_a) : (2^{t} * pi * |delta_{b_{r}}|) <= _a, x : pi / 2, y : (1 / 2) * pi
# 2	instantiation	4, 5, 6	|- (2^{t} * pi * |delta_{b_{r}}|) <= ((1 / 2) * pi)
# 	P(_a) : _a <= ((1 / 2) * pi), x : 2^{t} * pi * |delta_{b_{r}}|, y : 2^{t} * |delta_{b_{r}}| * pi
# 3	instantiation	7, 31, 59, 85, 8*	|- (pi / 2) = ((1 / 2) * pi)
# 	x : pi, y : 2
# 4	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 5	instantiation	9, 46, 10, 74, 11, 12, 13*	|- (2^{t} * |delta_{b_{r}}| * pi) <= ((1 / 2) * pi)
# 	a : pi, x : 2^{t} * |delta_{b_{r}}|, y : 1 / 2
# 6	instantiation	14, 101, 24, 25, 38, 31, 27	|- (2^{t} * pi * |delta_{b_{r}}|) =  \\ (2^{t} * |delta_{b_{r}}| * pi)
# ...
