# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_neg_domain_within_negint">_neg_domain_within_negint</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import k, defaults
from proveit.logic import InSet
from proveit.numbers import one
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _neg_domain_within_negint
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_neg_domain_within_negint">_neg_domain_within_negint:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/00124637608d2a6d5c48e147a6bf248b77666e840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/0355ee57474a7fa76ff6532e43edda2676b236030/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _neg_domain_within_negint.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_within_negint/d6451ebca630c456e1c1f2777c5439c1c43bd4fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# _neg_domain_within_negint may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
e_in_e_domain = defaults.assumptions[0]
# Out:
# <strong id="e_in_e_domain">e_in_e_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# acknowledge previously proven fact
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# Interestingly, this one helps establish that the 'k' used further below is an Integer
one_less_eq_e = e_in_e_domain.derive_element_lower_bound()
# Out:
# <strong id="one_less_eq_e">one_less_eq_e:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_within_negint/dc2d2d5105fb0a0280c97ba54b8caa75fb4bd37a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_within_negint/83008cca5ff2e11d3153d96dcfee7a0a45729aca0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# for convenience name our subset
the_subset = _neg_domain_within_negint.instance_expr.lhs
# Out:
# <strong id="the_subset">the_subset:</strong> <a class="ProveItLink" href="../../../__pv_it/common/11daab29f734f33d5a9a3b7497304dd7d5b19a6e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
InSet(k, the_subset).derive_element_in_integer_neg(assumptions=[InSet(k, the_subset), e_in_e_domain])
# Out:
# {e in {1 .. 2^{t - 1} - 2}, k in {-2^{t - 1} + 1 .. -(e + 1)}} |- k in IntegerNeg

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._neg_domain_within_negint has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(e + 1)} subset_eq IntegerNeg)
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} subset_eq IntegerNeg
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : IntegerNeg, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalization	4	{e in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {-2^{t - 1} + 1 .. -(e + 1)}} (_a in IntegerNeg)
# 4	instantiation	5, 6, 7	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in IntegerNeg
# 	a : _a
# 5	conjecture		|- forall_{a in Integer | a < 0} (a in IntegerNeg)
# 	proveit.numbers.number_sets.integers.neg_int_is_int_neg
# 6	instantiation	45, 8, 15	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer, x : _a
# 7	instantiation	9, 10, 11	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a < 0
# 	x : _a, y : -(e + 1), z : 0
# 8	instantiation	32, 13, 14	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 9	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_eq_less
# 10	instantiation	12, 13, 14, 15	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a <= (-(e + 1))
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : _a
# 11	instantiation	16, 17	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) < 0
# 	a : -(e + 1)
# 12	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 13	instantiation	38, 18, 34	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 14	instantiation	43, 19	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	a : e + 1
# 15	assumption		{_a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in {-2^{t - 1} + 1 .. -(e + 1)}
# 16	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 17	instantiation	20, 21	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in IntegerNeg
# 	a : e + 1
# 18	instantiation	43, 39	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 19	instantiation	38, 26, 34	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 20	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 21	instantiation	22, 23, 24	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 22	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 23	instantiation	25, 26, 27	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 24	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 25	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 26	instantiation	45, 28, 36	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 27	instantiation	29, 30, 31	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 28	instantiation	32, 34, 35	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 29	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 30	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 31	instantiation	33, 34, 35, 36	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 32	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 33	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 34	instantiation	45, 46, 37	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 35	instantiation	38, 39, 40	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 36	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 37	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 38	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 39	instantiation	45, 41, 42	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 40	instantiation	43, 44	|- (-2) in Integer
# 	a : 2
# 41	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 42	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 43	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 44	instantiation	45, 46, 47	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 45	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 46	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 47	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
