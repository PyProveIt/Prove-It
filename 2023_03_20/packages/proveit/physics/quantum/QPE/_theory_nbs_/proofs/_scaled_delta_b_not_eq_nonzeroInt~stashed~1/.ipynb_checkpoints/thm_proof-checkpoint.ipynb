# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_b_not_eq_nonzeroInt">_scaled_delta_b_not_eq_nonzeroInt</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import l, defaults
from proveit.logic import Equals, InSet, Not, NotInSet
from proveit.numbers import Integer
from proveit.physics.quantum.QPE import _scaled_delta_b_is_zero_or_non_int

# %%
# %proving _scaled_delta_b_not_eq_nonzeroInt
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_delta_b_not_eq_nonzeroInt">_scaled_delta_b_not_eq_nonzeroInt:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/55c52b0dda7ff4e74258b575d93ebd6d2f0ff9c00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/94b4326cc9015d9b3e49b1a56a9592a5fa18a4400/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _scaled_delta_b_not_eq_nonzeroInt.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86269d40e585e2eb6333037b5a3024092ebe10140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the individual assumptions
ell_in_integers = defaults.assumptions[1]
# Out:
# <strong id="ell_in_integers">ell_in_integers:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the individual assumptions
ell_not_zero = defaults.assumptions[2]
# Out:
# <strong id="ell_not_zero">ell_not_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the scaled delta expression
_scaled_delta = _scaled_delta_b_not_eq_nonzeroInt.instance_expr.lhs
# Out:
# <strong id="_scaled_delta">_scaled_delta:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/70022aaf188bb04f6bba5ff51566ec6109260fab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_scaled_delta_b_is_zero_or_non_int
# Out:
# |- forall_{b in {b_{f}, b_{r}}} (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))

# %%
_scaled_delta_b_is_zero_or_non_int_inst = (
        _scaled_delta_b_is_zero_or_non_int.instantiate())
# Out:
# <strong id="_scaled_delta_b_is_zero_or_non_int_inst">_scaled_delta_b_is_zero_or_non_int_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/08ffaf7139b40197219d0d57a58c1216a59566150/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a24f8a7da68096e7531ccb0c281edeeafa16da490/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Assume to the contrary that _scaled_delta_b = ell
contradictory_assumption = Equals(_scaled_delta, l)
# Out:
# <strong id="contradictory_assumption">contradictory_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# Need to explicitly include this, otherwise one of the final steps
# fails, with a generic, unhelpful error message.
contradictory_assumption.deduce_in_bool()
# Out:
# |- ((2^{t} * delta_{b}) = l) in BOOLEAN

# %%
l_notin_ints_implies_not_l_in_ints = (
    NotInSet(l, Integer).unfold(assumptions=[NotInSet(l, Integer)]).
    as_implication(hypothesis=NotInSet(l, Integer)))
# Out:
# <strong id="l_notin_ints_implies_not_l_in_ints">l_notin_ints_implies_not_l_in_ints:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/7a74ad8d0c7f6174b2dae99476064a6fe0cbeea70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/53922c15d03e87665ddb2100ef682cf925f4d27c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Must include this and previous cell; helps deal with a double negation later
l_notin_ints_implies_not_l_in_ints.contrapose()
# Out:
# {l in Integer} |- (l in Integer) => [not](l not-in Integer)

# %%
contradictory_assumption_disjunction = (
        contradictory_assumption.sub_right_side_into(
                _scaled_delta_b_is_zero_or_non_int_inst,
                assumptions=[*defaults.assumptions, contradictory_assumption]))
# Out:
# <strong id="contradictory_assumption_disjunction">contradictory_assumption_disjunction:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/bcab9e2dd70d69cf2b7f19cf1005be9255c6745d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/01640e3da8199a2add3691d1cde2a6a0b11b00c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradictory_assumption_gives_false = contradictory_assumption_disjunction.derive_contradiction()
# Out:
# <strong id="contradictory_assumption_gives_false">contradictory_assumption_gives_false:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/7f533d2cbb7be7fc57dcd27fea8ec2b19c97b7bb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../../logic/booleans/__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradictory_assumption_gives_false.as_implication(hypothesis=contradictory_assumption)
# Out:
# {b in {b_{f}, b_{r}}, l != 0, l in Integer} |- ((2^{t} * delta_{b}) = l) => FALSE
# _scaled_delta_b_not_eq_nonzeroInt may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
not_contradictory_assumption = Not(contradictory_assumption).prove()
# Out:
# <strong id="not_contradictory_assumption">not_contradictory_assumption:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/dedf8d2e9f20dd3d2782c8f50c9e94c7430d7c5e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_not_eq_nonzeroInt/e67da8ddaf9c4c0414eadfaf17a01ec0530dd8ae0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_scaled_delta_b_not_eq_nonzeroInt.instance_expr.conclude_as_folded()
# Out:
# {b in {b_{f}, b_{r}}, l != 0, l in Integer} |- (2^{t} * delta_{b}) != l

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_delta_b_not_eq_nonzeroInt has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} ((2^{t} * delta_{b}) != l)
# 1	instantiation	2, 3	{b in {b_{f}, b_{r}}, l != 0, l in Integer} |- (2^{t} * delta_{b}) != l
# 	x : 2^{t} * delta_{b}, y : l
# 2	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 3	instantiation	4, 5, 6	{b in {b_{f}, b_{r}}, l != 0, l in Integer} |- [not]((2^{t} * delta_{b}) = l)
# 	A : (2^{t} * delta_{b}) = l
# 4	axiom		|- forall_{A in BOOLEAN | A => FALSE} [not](A)
# 	proveit.logic.booleans.implication.denial_via_contradiction
# 5	instantiation	7	|- ((2^{t} * delta_{b}) = l) in BOOLEAN
# 	x : 2^{t} * delta_{b}, y : l
# 6	deduction	8	{b in {b_{f}, b_{r}}, l != 0, l in Integer} |- ((2^{t} * delta_{b}) = l) => FALSE
# 7	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 8	instantiation	9, 10, 11, 12	{b in {b_{f}, b_{r}}, (2^{t} * delta_{b}) = l, l != 0, l in Integer} |- FALSE
# 	A : l = 0, B : l not-in Integer
# 9	theorem		|- forall_{A, B | A or B, [not](A), [not](B)} FALSE
# 	proveit.logic.booleans.disjunction.binary_or_contradiction
# 10	instantiation	13, 14, 15	{b in {b_{f}, b_{r}}, (2^{t} * delta_{b}) = l} |- (l = 0) or (l not-in Integer)
# 	P(_a) : (_a = 0) or (_a not-in Integer), x : 2^{t} * delta_{b}, y : l
# 11	instantiation	16, 17	{l != 0} |- [not](l = 0)
# 	x : l, y : 0
# 12	modus ponens	18, 30	{l in Integer} |- [not](l not-in Integer)
# 13	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 14	instantiation	19, 20	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 	b : b
# 15	assumption		{(2^{t} * delta_{b}) = l} |- (2^{t} * delta_{b}) = l
# 16	theorem		|- forall_{x, y | x != y} [not](x = y)
# 	proveit.logic.equality.unfold_not_equals
# 17	assumption		{l != 0} |- l != 0
# 18	instantiation	21, 22, 23	{l in Integer} |- (l in Integer) => [not](l not-in Integer)
# 	A : l not-in Integer, B : l in Integer
# 19	conjecture		|- forall_{b in {b_{f}, b_{r}}} (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 	proveit.physics.quantum.QPE._scaled_delta_b_is_zero_or_non_int
# 20	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 21	theorem		|- forall_{A, B | A => [not](B), A in BOOLEAN} (B => [not](A))
# 	proveit.logic.booleans.implication.contrapose_neg_consequent
# 22	deduction	24	|- (l not-in Integer) => [not](l in Integer)
# 23	instantiation	25, 26	{l in Integer} |- (l not-in Integer) in BOOLEAN
# 	x : l, S : Integer
# 24	instantiation	27, 28	{l not-in Integer} |- [not](l in Integer)
# 	x : l, S : Integer
# 25	conjecture		|- forall_{x, S | (x in S) in BOOLEAN} ((x not-in S) in BOOLEAN)
# 	proveit.logic.sets.membership.not_in_set_is_bool
# 26	instantiation	29, 30	{l in Integer} |- (l in Integer) in BOOLEAN
# 	A : l in Integer
# 27	theorem		|- forall_{x, S | x not-in S} [not](x in S)
# 	proveit.logic.sets.membership.unfold_not_in_set
# 28	assumption		{l not-in Integer} |- l not-in Integer
# 29	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 30	assumption		{l in Integer} |- l in Integer
