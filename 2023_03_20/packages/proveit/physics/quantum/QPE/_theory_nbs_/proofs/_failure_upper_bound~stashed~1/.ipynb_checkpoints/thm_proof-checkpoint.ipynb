# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_failure_upper_bound">_failure_upper_bound</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, e, f, i, l, x, defaults, Lambda
from proveit.logic import Equals, InSet, NotEquals
from proveit.numbers import (
    zero, one, two, four, Add, Exp, frac, greater, greater_eq,
    Less, Mult, NaturalPos, Neg, Real, RealPos, subtract)
from proveit.numbers.functions import MonDecFuncs
from proveit.physics.quantum.QPE import (
    _t_in_natural_pos, _two_pow_t, _two_pow_t_minus_one_is_nat_pos, _phase_is_real,
    _mod_add_def, _b_floor, _best_floor_is_int, _delta_b_floor, _delta_b_is_real, 
    _scaled_delta_b_floor_in_interval, _diff_l_scaled_delta_floor)
from proveit.physics.quantum.QPE.phase_est_ops import Psuccess, Pfail, ModAdd

# %%
# %proving _failure_upper_bound
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_failure_upper_bound">_failure_upper_bound:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a6157de4c5444c5a5dbbab9b2fcdbe64e328db540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dab15506ed44e496fef5b23b955f66655119a6710/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _failure_upper_bound.conditions
# Out:
# Expression notebook is being updated for (e in {1 .. 2^{t - 1} - 2})
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d6451ebca630c456e1c1f2777c5439c1c43bd4fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ### (1) Import & Instantiate the `_failure_upper_bound_lemma`

# %%
from proveit.physics.quantum.QPE import _failure_upper_bound_lemma
_failure_upper_bound_lemma
# Out:
# |- forall_{e in {1 .. 2^{t - 1} - 2}} ([Pfail](e) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))))

# %%
_failure_upper_bound_lemma_inst = (
        _failure_upper_bound_lemma.instantiate(preserve_expr=Neg(Add(e, one))))
# Out:
# <strong id="_failure_upper_bound_lemma_inst">_failure_upper_bound_lemma_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/68e5d42f37211bafffb35499a63fa23236d87e210/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/4033b04cf15a92d046bed36ce750819920b12d5e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### (2) Establish some convenient labels for important expressions

# %%
first_sum = _failure_upper_bound_lemma_inst.rhs.operands[1].operands[0]
# Out:
# <strong id="first_sum">first_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a8f4738a60d4d9249e6bda7859629ccd80d6040b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
second_sum = _failure_upper_bound_lemma_inst.rhs.operands[1].operands[1]
# Out:
# <strong id="second_sum">second_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/3c079adf2bef5d242889f191cdede33db9f29f0b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
the_summand = first_sum.summand
# Out:
# <strong id="the_summand">the_summand:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c542d2f08dbaf3f44ac7f82f4e0020814a307c960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
first_sum_conditions = first_sum.conditions[0]
# Out:
# <strong id="first_sum_conditions">first_sum_conditions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
second_sum_conditions = second_sum.conditions[0]
# Out:
# <strong id="second_sum_conditions">second_sum_conditions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
e_conditions = _failure_upper_bound.conditions[0]
# Out:
# <strong id="e_conditions">e_conditions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ### (3) Some Initial Bounding of the Summand Denominator and variables $\ell$ and $e$

# %%
_scaled_delta_b_floor_in_interval
# Out:
# |- (2^{t} * delta_{b_{f}}) in [0,1)

# %%
_delta_b_is_real.instantiate({b:_b_floor})
# Out:
# |- delta_{b_{f}} in Real

# %%
# Automatic incidental derivation, but want to label the result for later use
scaled_delta_lower_bound = _scaled_delta_b_floor_in_interval.derive_element_lower_bound()
# Out:
# <strong id="scaled_delta_lower_bound">scaled_delta_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/19997034cd1380359f418ec5a889d57f76b689cf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/af8a7e90f4abc302ce926bf99e2f34ce3796c4870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Automatic incidental derivation, but want to label the result for later use
scaled_delta_upper_bound = _scaled_delta_b_floor_in_interval.derive_element_upper_bound()
# Out:
# <strong id="scaled_delta_upper_bound">scaled_delta_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/803edd45a2856b66f298f0c8165b320fa03ce4dd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/836886304e3cc5055b636c1e745bc55ef4bf40060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
neg_scaled_delta_lower_bound = scaled_delta_upper_bound.left_mult_both_sides(Neg(one))
# Out:
# <strong id="neg_scaled_delta_lower_bound">neg_scaled_delta_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/562e50ce1d2d5f5639f9c2869551f2240e7584080/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/bd4a5a66cb64c499790fe5af9aace6a55214cb200/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
neg_scaled_delta_upper_bound = scaled_delta_lower_bound.left_mult_both_sides(Neg(one))
# Out:
# <strong id="neg_scaled_delta_upper_bound">neg_scaled_delta_upper_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/2c8de2c40340d27a0437c312db8589529abc461c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/4cf6bd152c0f232a042415b71cf5394a34066e760/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_diff_l_scaled_delta_floor.deduce_bound(neg_scaled_delta_lower_bound,
        assumptions=defaults.assumptions + (first_sum_conditions,))
# Out:
# Expression notebook is being updated for ({1 .. 2^{t - 1} - 2}, Integer)
# Expression notebook is being updated for {1 .. 2^{t - 1} - 2} proper_subset Integer
# Expression notebook is being updated for ({-2^{t - 1} + 1 .. -(e + 1)}, Integer)
# Expression notebook is being updated for {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# {e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- (l - (2^{t} * delta_{b_{f}})) > (l - 1)

# %%
# For the 1st Summation
diff_l_scaled_delta_upper_bound = _diff_l_scaled_delta_floor.deduce_bound(
        neg_scaled_delta_upper_bound.reversed(),
        assumptions=defaults.assumptions + (first_sum_conditions,))
# Out:
# <strong id="diff_l_scaled_delta_upper_bound">diff_l_scaled_delta_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/c4956432ed5da62cc18f2dcae16853a22eb663480/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/ebaf6b917d3cba941ef6d4d31e197f521f8025d50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# For the 2nd Summation
diff_l_scaled_delta_upper_bound_2 = _diff_l_scaled_delta_floor.deduce_bound(
        neg_scaled_delta_lower_bound,
        assumptions=defaults.assumptions + (second_sum_conditions,))
# Out:
# Expression notebook is being updated for ({e + 1 .. 2^{t - 1}}, Integer)
# Expression notebook is being updated for {e + 1 .. 2^{t - 1}} proper_subset Integer
# <strong id="diff_l_scaled_delta_upper_bound_2">diff_l_scaled_delta_upper_bound_2:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/aed348235544af344a7cafcc79bad63bed3070ef0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/ea52f7bc059c4100f0d0433c7f904a7ce4c5bc540/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Also need to demonstrate that we have:
#
# (1) For the 1st Summation: $\ell < 0$ and $\ell^2 \in \mathbb{R}^{+}$
#
# (2) For the 2nd Summation: $\ell - 1 > 0$ and $\ell^2 \in \mathbb{R}^{+}$

# %%
e_greater_eq_one = greater_eq(e, one).prove()
# Out:
# <strong id="e_greater_eq_one">e_greater_eq_one:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/dc2d2d5105fb0a0280c97ba54b8caa75fb4bd37a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/c0a6f74b25992685041de600e5936dfbf7adfacf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
e_plus_one_greater_eq_two = e_greater_eq_one.right_add_both_sides(one)
# Out:
# <strong id="e_plus_one_greater_eq_two">e_plus_one_greater_eq_two:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/e9ddb174e988bb42a15239efc532a846bc6281a50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d2d5a90cb2b7e254c200cb65bd6b3a6b1bcbda130/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
neg_e_plus_one_less_eq_neg_two = Neg(Add(e, one)).bound_via_operand_bound(e_plus_one_greater_eq_two)
# Out:
# <strong id="neg_e_plus_one_less_eq_neg_two">neg_e_plus_one_less_eq_neg_two:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/34fd0e7e178b1e614986d9591766d14bdab39d300/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/5a9a8058e776c22b15923b752334d975689460a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# For 1st summation
ell_upper_bound = first_sum_conditions.derive_element_upper_bound(
    assumptions=defaults.assumptions + (first_sum_conditions,))
# Out:
# <strong id="ell_upper_bound">ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/02c89271a1d1f6492b21b67886b0c24b68bfb8070/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/00b40a66b98546cce6225d23810b2d8b64e09b730/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# For 2nd Summation
ell_lower_bound_02 = second_sum_conditions.derive_element_lower_bound(
        assumptions = defaults.assumptions + (second_sum_conditions, ))
# Out:
# <strong id="ell_lower_bound_02">ell_lower_bound_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/68d573d6a1dcb3fadda3fb1628a93422b5d4aba50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f0c2092a2ee576e7f433cef4e612c988e19ccde60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# For 1st Summation
ell_upper_bound_neg_two = ell_upper_bound.apply_transitivity(neg_e_plus_one_less_eq_neg_two)
# Out:
# <strong id="ell_upper_bound_neg_two">ell_upper_bound_neg_two:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/88641d23ca774312ced85331ad4f59a4bf944cd00/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/310cd4d3bc5a419162a16d449cb8d8505af1f7e30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# For Second Summation
ell_lower_bound_two_2 = ell_lower_bound_02.apply_transitivity(e_plus_one_greater_eq_two)
# Out:
# <strong id="ell_lower_bound_two_2">ell_lower_bound_two_2:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/b054cd160f3e1121d927ec443da0ffeb284b6ba80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/8289302b32190865efad74fdeb60a385847599110/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
temp_bound_03 = ell_upper_bound_neg_two.right_add_both_sides(
    neg_scaled_delta_lower_bound.lhs)
# Out:
# <strong id="temp_bound_03">temp_bound_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/b0827f21541dae6b67a5004bde860db49708fdf80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/4d5f878aec87de33b070ef3f47f480a205ccff390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ell_lower_bound_two_2.right_add_both_sides(neg_scaled_delta_lower_bound.lhs)
# Out:
# {e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- (2 - (2^{t} * delta_{b_{f}})) <= (l - (2^{t} * delta_{b_{f}}))

# %%
display(scaled_delta_lower_bound)
display(scaled_delta_upper_bound)
# Out:
# |- 0 <= (2^{t} * delta_{b_{f}})
# |- (2^{t} * delta_{b_{f}}) < 1

# %%
scaled_delta_plus_2_lower_bound = scaled_delta_lower_bound.left_add_both_sides(two)
# Out:
# <strong id="scaled_delta_plus_2_lower_bound">scaled_delta_plus_2_lower_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/b5c25ec1607f9c71e0e49ba34ab3949addc59bba0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f36cd8c3672c257cffd4a8a668c7a04657e450770/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
temp_bound_06 = scaled_delta_plus_2_lower_bound.left_mult_both_sides(Neg(one)).with_styles(direction='normal')
# Out:
# <strong id="temp_bound_06">temp_bound_06:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/5a4f11dcd9576d709fb09251c30dc3aee7793a8e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/9f68eb32c075a0fcf0c2b974b8a51f3d59a378550/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
temp_bound_07 = temp_bound_03.apply_transitivity(temp_bound_06)
# Out:
# <strong id="temp_bound_07">temp_bound_07:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/13d2d9cbfab1bee2798a7a8c09332912628580ad0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/2523fde570e90bb1ed8750005e25eb11457b7dff0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### (4) Bound on the First Summand and First Sum
# We can find an $\ell$-dependent upper bound on the first summand, then an upper bound on the first summation.

# %%
first_summand_bound_02 = the_summand.deduce_bound(scaled_delta_lower_bound.reversed(),
        assumptions=defaults.assumptions + (first_sum_conditions,))
# Out:
# <strong id="first_summand_bound_02">first_summand_bound_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d30ecd5e0fe5ec1e7b6d074fefca28ae2fb4cb670/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/a7a01af9fd1dac7fe29ea40f8e1e0a3b5711dd0a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
first_summand_bound_generalized = first_summand_bound_02.generalize((l), conditions=[first_sum_conditions])
# Out:
# Expression notebook is being updated for {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / l^{2}))
# <strong id="first_summand_bound_generalized">first_summand_bound_generalized:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f3bf470a80074d41980386ba01e3a0ee6122a45f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/9e853ca4a236e81f1a4b57d7d1cbbc14804121560/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
first_sum_bound = first_sum.deduce_bound(first_summand_bound_generalized)
# Out:
# Expression notebook is being updated for (k, {-2^{t - 1} + 1 .. -(e + 1)})
# Expression notebook is being updated for k in {-2^{t - 1} + 1 .. -(e + 1)}
# Expression notebook is being updated for {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}) if k in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}))
# Expression notebook is being updated for {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}))
# Expression notebook is being updated for (forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2})), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})))
# Expression notebook is being updated for [forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}))] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})))
# <strong id="first_sum_bound">first_sum_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/946e247c7b7c1c05dc14832dcef3cfb1408d10200/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/1c5e6179c991b4a4ccbccec48e64ae78ab5e5cc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### (5) Bound on the Second Summand and Second Sum
# We can find an $\ell$-dependent upper bound on the second summand, then an upper bound on the second summation.

# %%
second_summand_bound_02 = the_summand.deduce_bound(diff_l_scaled_delta_upper_bound_2,
        assumptions=defaults.assumptions + (second_sum_conditions,))
# Out:
# <strong id="second_summand_bound_02">second_summand_bound_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/ffc774fee23a27e332dd8e402591f9061c3fadc30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/64b2e7ee3e05a513ea155c3ef969000b9632ed0f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
second_summand_bound_02_relaxed = second_summand_bound_02.derive_relaxed()
# Out:
# <strong id="second_summand_bound_02_relaxed">second_summand_bound_02_relaxed:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f01e5817c994f42806cb80f31cb3ebf09f18f49a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/8900372b13f0b9345c0266ce0ded19f3159003640/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/274290b0b9c34f59c59b6566666922b9a97e8c1d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
second_summand_bound_generalized = second_summand_bound_02.generalize([l], conditions=[second_sum_conditions])
# Out:
# Expression notebook is being updated for {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) < (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) < (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) < (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) < (1 / (l - 1)^{2}))
# <strong id="second_summand_bound_generalized">second_summand_bound_generalized:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f9f86a4e1c335abcc99d97960d441c2a721273150/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/6719dc813a6551f1dfb6e482a8e9388518243b750/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
second_summand_bound_relaxed_generalized = second_summand_bound_02_relaxed.generalize([l], conditions=[second_sum_conditions])
# Out:
# Expression notebook is being updated for {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (l - 1)^{2}) if l in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (l - 1)^{2}))
# <strong id="second_summand_bound_relaxed_generalized">second_summand_bound_relaxed_generalized:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/158d401b38ea6447688d5f7261d32d9b0be1408d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/c266527b2eed4f60e89b4746b4330d6313fcc0b50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
second_sum_bound = second_sum.deduce_bound(second_summand_bound_relaxed_generalized)
# Out:
# Expression notebook is being updated for (k, {e + 1 .. 2^{t - 1}})
# Expression notebook is being updated for k in {e + 1 .. 2^{t - 1}}
# Expression notebook is being updated for {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (k -> {(1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}) if k in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))
# Expression notebook is being updated for {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for l -> {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (l -> {1 / (l - 1)^{2} if l in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# Expression notebook is being updated for (forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2})), (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# Expression notebook is being updated for [forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# <strong id="second_sum_bound">second_sum_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/3a8b5f221981d2bdb18e4fb52461cf2c8047b4080/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/287051db1a127dd85183d9c764b48f881f018a3d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### (6) Bound on the Sum of Summations

# %% [markdown]
# Now we're ready to invoke our `deduce_bound()` method utilizing the bounds we've established on each separate summation.<br/>
# The following three steps correspond to the transition from (5.30) to (5.31) in Nielsen & Chuang (pg 224):

# %%
_failure_upper_bound_lemma_inst_bound_01 = _failure_upper_bound_lemma_inst.rhs.deduce_bound(first_sum_bound)
# Out:
# Expression notebook is being updated for {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real
# Expression notebook is being updated for (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# Expression notebook is being updated for [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# Expression notebook is being updated for {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (l -> {(1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), Real)
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real
# Expression notebook is being updated for (forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real), (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# Expression notebook is being updated for [forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), Real)
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) in Real
# Expression notebook is being updated for {(1 / l^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {(1 / l^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {(1 / l^{2}) in Real if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l^{2}) in Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) in Real
# Expression notebook is being updated for (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l^{2}) in Real), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) in Real)
# Expression notebook is being updated for [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l^{2}) in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) in Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), Real)
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) in Real
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) <= ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
# Expression notebook is being updated for (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
# Expression notebook is being updated for (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))
# <strong id="_failure_upper_bound_lemma_inst_bound_01">_failure_upper_bound_lemma_inst_bound_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d7da79669de8425d8ae04db475c261d62c759d7c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/bae4487e58753c557527caa6435d31601a3088f30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_failure_upper_bound_lemma_inst_bound_02 = _failure_upper_bound_lemma_inst_bound_01.rhs.deduce_bound(second_sum_bound)
# Out:
# Expression notebook is being updated for {(1 / (l - 1)^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for l -> {(1 / (l - 1)^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.
# Expression notebook is being updated for (l -> {(1 / (l - 1)^{2}) in Real if l in {e + 1 .. 2^{t - 1}}.)
# Expression notebook is being updated for forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - 1)^{2}) in Real)
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}), Real)
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) in Real
# Expression notebook is being updated for (forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - 1)^{2}) in Real), (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) in Real)
# Expression notebook is being updated for [forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - 1)^{2}) in Real)] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) in Real)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})), Real)
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))) in Real
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) <= ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# Expression notebook is being updated for (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# Expression notebook is being updated for (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# <strong id="_failure_upper_bound_lemma_inst_bound_02">_failure_upper_bound_lemma_inst_bound_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/2c64e00813c934c82904397c73f373dc0f4670920/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f5da68b2c91d2bb76c9bbc55d13ca756b18011c70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_failure_upper_bound_lemma_inst_bound_03 = (
    _failure_upper_bound_lemma_inst_bound_01.apply_transitivity(_failure_upper_bound_lemma_inst_bound_02))
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# <strong id="_failure_upper_bound_lemma_inst_bound_03">_failure_upper_bound_lemma_inst_bound_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d55201f17e0224ce532b93f1a1e0b7cb11a978710/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/a88cc0c68172b88650c3a595864b5730426af8670/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Next, shift the index of the second summation to create identical summands in each of the summations:

# %%
_failure_upper_bound_lemma_inst_bound_04 = (
    _failure_upper_bound_lemma_inst_bound_03.inner_expr().rhs.operands[1].
    operands[1].shift(Neg(one)))
# Out:
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}), Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) = (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), _a)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a
# Expression notebook is being updated for (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a)
# Expression notebook is being updated for (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a)
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for (1 / 4, (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2})))
# Expression notebook is being updated for (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# <strong id="_failure_upper_bound_lemma_inst_bound_04">_failure_upper_bound_lemma_inst_bound_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/a470a8e9ddc0b4e2d58251d9cac7769d3614c3600/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/5267c36530ebe65593aa83199cb4bf661c62a38d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Then negate and flip the order of indices on the first summation (possible because the summand is an even function).

# %%
# ACTUALLY, this theorem is FALSE, so this is quite annoying
# This works for something like x^2 or even 1/x^2 (as we have),
# but not more generally for something like (x-1)^2.
# In other words, we need f(x) \in EvenFuncs.
from proveit.numbers.summation import even_fxn_sum
even_fxn_sum
# Out:
# |- forall_{f} [forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)^{2}) = (Sum_{x = -b}^{-a} f(x)^{2}))]

# %%
_a_sub, _b_sub, _x_sub, _f_sub = (
    first_sum_conditions.domain.lower_bound,
    first_sum_conditions.domain.upper_bound,
    l,
    Lambda(l, frac(one, l)))
# Out:
# <strong id="_a_sub">_a_sub:</strong> <a class="ProveItLink" href="../../../__pv_it/common/784dee04278eb5ffb26c65868b9ae69e9c68b9da0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="_b_sub">_b_sub:</strong> <a class="ProveItLink" href="../../../__pv_it/common/fc88928b08a114ef2e12ee095c5cd52f956d6baa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="_x_sub">_x_sub:</strong> <a class="ProveItLink" href="../../../../../../__pv_it/common/27cc275d44b4f4499fb9ccfb3fab1a98165d2fa60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>
# <strong id="_f_sub">_f_sub:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/1c7f7084ef09f0ee23fc29a868eeaae0b93028e00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
even_fxn_sum_inst = even_fxn_sum.instantiate({a: _a_sub, b: _b_sub, x: _x_sub, f: _f_sub})
# Out:
# Expression notebook is being updated for {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}, Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# <strong id="even_fxn_sum_inst">even_fxn_sum_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/7b3fe18162f4a7ce5dc54ea2737adad6ad1ecd440/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/4b53e5ded8899f947599c267f93daff89edc32df0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
first_sum_conditions_reversed = even_fxn_sum_inst.rhs.conditions[0]
# Out:
# <strong id="first_sum_conditions_reversed">first_sum_conditions_reversed:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/470501f70769bf6f1f127008e68b9ba9ad84aeb50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
fxn_sqrd_eq_one_over_sqr_01 = Exp(frac(one, l), two).distribution(assumptions=defaults.assumptions+(first_sum_conditions,))
# Out:
# <strong id="fxn_sqrd_eq_one_over_sqr_01">fxn_sqrd_eq_one_over_sqr_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/bb8428576c5e9aef5059458d15ab082fff89783c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/6b8b2ceac482c63e597604d1c45489f0e4e01ef10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/36deac0b086493ce62d8d640916c3fabe4c03c9d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# under the reversed index conditions, need to know that ell is still real?
InSet(l, Real).prove(assumptions=defaults.assumptions+(first_sum_conditions_reversed,))
# Out:
# {e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1} - 1}} |- l in Real

# %%
# and under the reversed index conditions, need to know the substitution works
fxn_sqrd_eq_one_over_sqr_02 = Exp(frac(one, l), two).distribution(assumptions=defaults.assumptions+(first_sum_conditions_reversed,))
# Out:
# <strong id="fxn_sqrd_eq_one_over_sqr_02">fxn_sqrd_eq_one_over_sqr_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/470501f70769bf6f1f127008e68b9ba9ad84aeb50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/c0d87e143c3c0bebbfc26b169123f73f8f81079e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/36deac0b086493ce62d8d640916c3fabe4c03c9d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
even_fxn_sum_inst_sub_lhs = even_fxn_sum_inst.inner_expr().lhs.summand.substitute(
    fxn_sqrd_eq_one_over_sqr_01,
    assumptions=defaults.assumptions+(first_sum_conditions,))
# Out:
# Expression notebook is being updated for {(1 / l)^{2} = (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {(1 / l)^{2} = (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {(1 / l)^{2} = (1 / l^{2}) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l)^{2} = (1 / l^{2}))
# Expression notebook is being updated for (l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}., l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for [l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.]
# Expression notebook is being updated for (forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l)^{2} = (1 / l^{2})), [l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.])
# Expression notebook is being updated for [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l)^{2} = (1 / l^{2}))] =>  \\ ([l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.])
# Expression notebook is being updated for ((1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}, (1 / l)^{2})
# Expression notebook is being updated for {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}. = (1 / l)^{2}
# Expression notebook is being updated for (1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}, 1 / l^{2})
# Expression notebook is being updated for {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}. = (1 / l^{2})
# Expression notebook is being updated for {_a(l) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for l -> {_a(l) if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# Expression notebook is being updated for (l -> {_a(l) if l in {-2^{t - 1} + 1 .. -(e + 1)}.)
# Expression notebook is being updated for Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} _a(l)
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} _a(l), Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} _a(l)) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}))
# <strong id="even_fxn_sum_inst_sub_lhs">even_fxn_sum_inst_sub_lhs:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/4cbadc12fc66a302a26c5168e785870040205cb40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/143f1d41a815462a67bbc4cbb69cd1c1c1b2d6210/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
even_fxn_sum_inst_sub_lhs_rhs = even_fxn_sum_inst_sub_lhs.inner_expr().rhs.summand.substitute(
    fxn_sqrd_eq_one_over_sqr_02,
    assumptions=defaults.assumptions+(first_sum_conditions_reversed,))
# Out:
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1} - 1} _a(l))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} _a(l))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}), (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# Expression notebook is being updated for ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# <strong id="even_fxn_sum_inst_sub_lhs_rhs">even_fxn_sum_inst_sub_lhs_rhs:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/04a94a522f64be0088f32d6f08a73d31c1d55d860/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/03e3978d421e359ba32f9fda98d86db798be527b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# recall the state of our bound thus far
_failure_upper_bound_lemma_inst_bound_04
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))

# %%
_failure_upper_bound_lemma_inst_bound_05 = (
    _failure_upper_bound_lemma_inst_bound_04.inner_expr().rhs.operands[1].
    operands[0].substitute(even_fxn_sum_inst_sub_lhs_rhs))
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * (_a + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * (_a + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# <strong id="_failure_upper_bound_lemma_inst_bound_05">_failure_upper_bound_lemma_inst_bound_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/b2bebe737f24cdcf77ca2cdde3fbb2cd057888c90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/9113a1b6167d501448967911c2427e0641732df50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# To split the first term off the 2nd summation on the rhs, we need to first explicitly establish that $e \le 2^{t-1} - 1$ (otherwise there is no “first” term to peel off).

# %%
e_upper_bound = e_conditions.derive_element_upper_bound()
# Out:
# <strong id="e_upper_bound">e_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/81022e5ecd1781546cd9dfee77d4b3ec2c912d8e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/92c4047f37de3a05d422fce2a3b515a7f6bd67360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
e_new_upper_bound = e_upper_bound.add_right(one)
# Out:
# <strong id="e_new_upper_bound">e_new_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/bc11e9f0e1664c4a6e85e3f8e78dc3e582a58a880/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/124e7bfc8d3d56cd0985613b422d89a8f8c19f4a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now we're ready to split off the first element of the second summation.<br/>
# Nielsen & Chuang originally split off the first element of the _first_ summation, eventually leading to a bound requiring $e \ge 2$.<br/>
# Instead, we split off the first term of the _second_ summation, allowing us to eventually derive a bound valid for $e \ge 1$.<br/>
# In doing so, the resulting expression is auto-simplified to combine the two resulting like-summations:

# %%
bound_07 = _failure_upper_bound_lemma_inst_bound_05.inner_expr().rhs.factors[1].operands[1].split_first()
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + _a))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + _a))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), (1 / 4) * ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})))
# <strong id="bound_07">bound_07:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/983d5c66c07fb1d6908cd68303b669e34d9d7d5f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/81089d12bb61c63f1b0f8d2b0ed697591acbd3060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_08 = bound_07.inner_expr().rhs.distribute(1)
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), _a)
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= _a
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2})))
# <strong id="bound_08">bound_08:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/db05f73bfa2ce254e53d309dda25d56738aafc7a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/8666a499a3526315726dab709f1607c3bdfee1910/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# summation-to-integral bounding theorem consistent with
# Nielsen & Chuang's step from 5.32 to 5.33 (pg 224):
from proveit.numbers.summation import sum_integrate_ineq_NC
sum_integrate_ineq_NC
# Out:
# |- forall_{S} [forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, {a .. b} subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]]

# %%
from proveit.numbers.functions import one_over_x_sqrd_in_mon_dec_fxns
one_over_x_sqrd_in_mon_dec_fxns
# Out:
# |- [x -> (1 / x^{2})] in MonDecFuncs(RealPos)

# %%
summand_in_mon_dec_funcs = one_over_x_sqrd_in_mon_dec_fxns.instantiate({x:l})
# Out:
# <strong id="summand_in_mon_dec_funcs">summand_in_mon_dec_funcs:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../../../../numbers/functions/_theory_nbs_/proofs/one_over_x_sqrd_in_mon_dec_fxns/thm_proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/59c9425555c4aead14b9e0c23771e6cf74f82c1e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# instantiate our summation-bounding integral theorem
from proveit import S
from proveit.numbers import RealPos
_S_sub, _f_sub, _a_sub, _b_sub, _x_sub = (
    RealPos, summand_in_mon_dec_funcs.element,
    bound_08.rhs.operands[0].operands[1].domain.lower_bound,
    bound_08.rhs.operands[0].operands[1].domain.upper_bound,
    l)
sum_integrate_ineq_NC_inst = sum_integrate_ineq_NC.instantiate(
    {S: _S_sub, f: _f_sub, a: _a_sub, b: _b_sub, x: _x_sub})
# Out:
# <strong id="sum_integrate_ineq_NC_inst">sum_integrate_ineq_NC_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/82a1e0138b338863f0156cbfca93edb4b263e6bd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/c2a8df150425dda63a17c0f14cfbecd700974fc30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
InSet(l, sum_integrate_ineq_NC_inst.rhs.domain).derive_element_lower_bound(
    assumptions=defaults.assumptions + (InSet(l, sum_integrate_ineq_NC_inst.rhs.domain),))
# Out:
# {e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- e <= l

# %%
sum_integrate_ineq_NC_inst.rhs.deduce_in_number_set(
    Real, assumptions=defaults.assumptions + (InSet(l, sum_integrate_ineq_NC_inst.rhs.domain),))
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl) in Real

# %%
bound_10 = bound_08.rhs.deduce_bound(sum_integrate_ineq_NC_inst,
            assumptions=defaults.assumptions + (InSet(l, sum_integrate_ineq_NC_inst.rhs.domain),))
# Out:
# <strong id="bound_10">bound_10:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/12edc25aa28017a3859caae1a4c11a9173c319100/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/205d8f6f73563a8cf82811f4bd485dc8027f5d3d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_11 = bound_08.apply_transitivity(bound_10)
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2})))
# <strong id="bound_11">bound_11:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/e6764f0eb092ad63828bdc3dd5fe3ae14a89bce50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/992a8fb2d5db16ba58b9a31a5853a4b65d0580ac0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers.integration import boundedInvSqrdIntegral
boundedInvSqrdIntegral
# Out:
# |- forall_{a, b in RealPos | a <= b} ((Integrate_{a}^{b} (1 / l^{2})\,dl) <= (1 / a))

# %% [markdown]
# Need to establish that $2^{t-1}-1$ is in RealPos.

# %%
integral_domain = bound_11.rhs.operands[0].operands[1].domain
_a_sub = integral_domain.lower_bound
_b_sub = integral_domain.upper_bound
integral_bound = boundedInvSqrdIntegral.instantiate({a: _a_sub, b: _b_sub})
# Out:
# <strong id="integral_bound">integral_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/0d5f2055b21116dc892f17b76160d281d02c39c50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/2433c7844c7da03cf6c6e840b0f18cdf74e73e9e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_12 = bound_11.rhs.deduce_bound(integral_bound)
# Out:
# <strong id="bound_12">bound_12:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/39f45fb8f6c5be52f23fdece8820d50a1ef873290/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/672c377f582ed5fba180a86e94239cff24d582800/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
bound_13 = bound_11.apply_transitivity(bound_12)
# Out:
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), ((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})))
# Expression notebook is being updated for ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})))
# <strong id="bound_13">bound_13:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/d7d7b3cfd9c00fb859f96d551b935ce0cb8c23730/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/45a1f1f7c3775a9aeca60e7ebe98c6b3e368e51e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _failure_upper_bound may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# qed fails here, with the following error:
# Sum simplification only implemented for a summation over an integer
# Interval of one instance variable where the upper and lower bounds are the same.
# %qed

# %%
# then we need this before using transitivity futher below
from proveit.physics.quantum.QPE import _pfail_in_real
_pfail_in_real
# Out:
# |- forall_{e in {1 .. 2^{t - 1} - 2}} ([Pfail](e) in Real)

# %%
# fail_ineq_lemma_inst
_failure_upper_bound_lemma_inst
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- [Pfail](e) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))

# %%
# bound_14 = fail_ineq_lemma_inst.apply_transitivity(bound_13)
bound_14 = _failure_upper_bound_lemma_inst.apply_transitivity(bound_13)
# Out:
# <strong id="bound_14">bound_14:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/e6928acc9717f141793f0abfbb0f242f340f62980/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__failure_upper_bound/f25b418fe51d27bc3959cf833675000ab129fbcd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._failure_upper_bound has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ([Pfail](e) <= ((1 / (2 * e)) + (1 / (4 * e^{2}))))
# 1	instantiation	285, 2, 3	{e in {1 .. 2^{t - 1} - 2}} |- [Pfail](e) <= ((1 / (2 * e)) + (1 / (4 * e^{2})))
# 	P(_a) : [Pfail](e) <= _a, x : ((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})), y : (1 / (2 * e)) + (1 / (4 * e^{2}))
# 2	instantiation	509, 4, 5	{e in {1 .. 2^{t - 1} - 2}} |- [Pfail](e) <= (((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})))
# 	x : [Pfail](e), y : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), z : ((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2}))
# 3	instantiation	230, 604, 6, 7, 8, 9	{e in {1 .. 2^{t - 1} - 2}} |- (((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2}))) =  \\ ((1 / (2 * e)) + (1 / (4 * e^{2})))
# 	n : 2, f(_a, _b) : _a + _b, x : ((1 / 2) * (1 / e), (1 / 4) * (1 / e^{2})), y : (1 / (2 * e), 1 / (4 * e^{2}))
# 4	instantiation	10, 589	{e in {1 .. 2^{t - 1} - 2}} |- [Pfail](e) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))
# 	e : e
# 5	instantiation	509, 11, 12	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})))
# 	x : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), y : ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2})), z : ((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2}))
# 6	instantiation	537	|- |((1 / 2) * (1 / e), (1 / 4) * (1 / e^{2}))| = |(1, ..., 2)|
# 	a : (1 / 2) * (1 / e), b : (1 / 4) * (1 / e^{2})
# 7	instantiation	537	|- |(1 / (2 * e), 1 / (4 * e^{2}))| = |(1, ..., 2)|
# 	a : 1 / (2 * e), b : 1 / (4 * e^{2})
# 8	instantiation	184, 13	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (1 / e)) = (1 / (2 * e))
# 	x : 1 / (2 * e), y : (1 / 2) * (1 / e)
# 9	instantiation	184, 14	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (1 / e^{2})) = (1 / (4 * e^{2}))
# 	x : 1 / (4 * e^{2}), y : (1 / 4) * (1 / e^{2})
# 10	conjecture		|- forall_{e in {1 .. 2^{t - 1} - 2}} ([Pfail](e) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))))
# 	proveit.physics.quantum.QPE._failure_upper_bound_lemma
# 11	instantiation	509, 15, 16	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2})))
# 	x : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), y : ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2})), z : ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2}))
# 12	instantiation	546, 28, 30, 17, 18	{e in {1 .. 2^{t - 1} - 2}} |- (((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2}))) <= (((1 / 2) * (1 / e)) + ((1 / 4) * (1 / e^{2})))
# 	a : (1 / 4) * (1 / e^{2}), x : (1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl), y : (1 / 2) * (1 / e)
# 13	instantiation	22, 19, 20, 21	{e in {1 .. 2^{t - 1} - 2}} |- (1 / (2 * e)) = ((1 / 2) * (1 / e))
# 	a : 1 / (2 * e), b : (1 / 2) * e^{-1}, c : (1 / 2) * e^{-1}, d : (1 / 2) * (1 / e)
# 14	instantiation	22, 23, 24, 25	{e in {1 .. 2^{t - 1} - 2}} |- (1 / (4 * e^{2})) = ((1 / 4) * (1 / e^{2}))
# 	a : 1 / (4 * e^{2}), b : (1 / 4) * e^{-2}, c : (1 / 4) * e^{-2}, d : (1 / 4) * (1 / e^{2})
# 15	instantiation	285, 26, 27	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= (((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2})))
# 	P(_a) : ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= _a, x : (1 / 4) * ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})), y : ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2}))
# 16	instantiation	546, 28, 29, 30, 31	{e in {1 .. 2^{t - 1} - 2}} |- (((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2}))) <= (((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) + ((1 / 4) * (1 / e^{2})))
# 	a : (1 / 4) * (1 / e^{2}), x : (1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), y : (1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)
# 17	instantiation	107, 157, 32	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (1 / e)) in Real
# 	a : 1 / 2, b : 1 / e
# 18	instantiation	165, 157, 48, 32, 33, 50	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) <= ((1 / 2) * (1 / e))
# 	a : 1 / 2, x : Integrate_{e}^{2^{t - 1} - 1} 1 / l^{2}\,dl, y : 1 / e
# 19	instantiation	98, 539, 34, 35, 36*	{e in {1 .. 2^{t - 1} - 2}} |- (1 / (2 * e)) = ((1 / 2) * e^{-1})
# 	x : 1, y : 2 * e
# 20	instantiation	541	|- ((1 / 2) * e^{-1}) = ((1 / 2) * e^{-1})
# 	x : (1 / 2) * e^{-1}
# 21	instantiation	184, 37	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * e^{-1}) = ((1 / 2) * (1 / e))
# 	x : (1 / 2) * (1 / e), y : (1 / 2) * e^{-1}
# 22	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 23	instantiation	98, 539, 38, 39, 40*	{e in {1 .. 2^{t - 1} - 2}} |- (1 / (4 * e^{2})) = ((1 / 4) * e^{-2})
# 	x : 1, y : 4 * e^{2}
# 24	instantiation	541	|- ((1 / 4) * e^{-2}) = ((1 / 4) * e^{-2})
# 	x : (1 / 4) * e^{-2}
# 25	instantiation	184, 41	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * e^{-2}) = ((1 / 4) * (1 / e^{2}))
# 	x : (1 / 4) * (1 / e^{2}), y : (1 / 4) * e^{-2}
# 26	instantiation	285, 42, 43, 44*	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})))
# 	P(_a) : ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + _a)), x : Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}), y : (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 27	instantiation	226, 594, 604, 512, 45, 513, 129, 46, 145, 47*	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2}))) =  \\ (((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + ((1 / 4) * (1 / e^{2})))
# 	i : 1, j : 2, k : 0, a : (1 / 4), b : (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), 1 / e^{2}), c : ()
# 28	instantiation	107, 166, 183	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (1 / e^{2})) in Real
# 	a : 1 / 4, b : 1 / e^{2}
# 29	instantiation	107, 157, 307	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) in Real
# 	a : 1 / 2, b : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 30	instantiation	107, 157, 48	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)) in Real
# 	a : 1 / 2, b : Integrate_{e}^{2^{t - 1} - 1} 1 / l^{2}\,dl
# 31	instantiation	165, 157, 307, 48, 49, 50	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) <= ((1 / 2) * (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl))
# 	a : 1 / 2, x : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}), y : Integrate_{e}^{2^{t - 1} - 1} 1 / l^{2}\,dl
# 32	instantiation	369, 583, 547, 202	{e in {1 .. 2^{t - 1} - 2}} |- (1 / e) in Real
# 	a : 1, b : e
# 33	instantiation	51, 52, 53, 54	{e in {1 .. 2^{t - 1} - 2}} |- (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl) <= (1 / e)
# 	a : e, b : 2^{t - 1} - 1
# 34	instantiation	602, 571, 55	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Complex
# 	A : Real, B : Complex, x : 2 * e
# 35	instantiation	62, 604, 56, 235, 57	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) != 0
# 	n : 2, a : (2, e)
# 36	instantiation	531, 58, 59	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (2 * e)^{-1}) = ((1 / 2) * e^{-1})
# 	x : 1 * (2 * e)^{-1}, y : 1 * ((1 / 2) * e^{-1}), z : (1 / 2) * e^{-1}
# 37	instantiation	551, 60	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 2) * (1 / e)) = ((1 / 2) * e^{-1})
# 	f(_a) : (1 / 2) * _a, x : 1 / e, y : e^{-1}
# 38	instantiation	602, 571, 61	{e in {1 .. 2^{t - 1} - 2}} |- (4 * e^{2}) in Complex
# 	A : Real, B : Complex, x : 4 * e^{2}
# 39	instantiation	62, 604, 63, 159, 64	{e in {1 .. 2^{t - 1} - 2}} |- (4 * e^{2}) != 0
# 	n : 2, a : (4, e^{2})
# 40	instantiation	531, 65, 66	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (4 * e^{2})^{-1}) = ((1 / 4) * e^{-2})
# 	x : 1 * (4 * e^{2})^{-1}, y : 1 * ((1 / 4) * e^{-2}), z : (1 / 4) * e^{-2}
# 41	instantiation	551, 67	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (1 / e^{2})) = ((1 / 4) * e^{-2})
# 	f(_a) : (1 / 4) * _a, x : 1 / e^{2}, y : e^{-2}
# 42	instantiation	285, 68, 69	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# 	P(_a) : ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * (_a + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2})))), x : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), y : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 43	instantiation	70, 585, 470, 117	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2})) = ((1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	f(l) : 1 / l^{2}, a : e, b : 2^{t - 1} - 1, x : l
# 44	instantiation	531, 71, 72	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + ((1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))) = ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2}))
# 	x : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + ((1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))), y : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), z : (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})
# 45	instantiation	537	|- |(2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), 1 / e^{2})| = |(1, ..., 2)|
# 	a : 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), b : 1 / e^{2}
# 46	instantiation	602, 571, 73	{e in {1 .. 2^{t - 1} - 2}} |- (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) in Complex
# 	A : Real, B : Complex, x : 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 47	instantiation	531, 74, 75	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))) = ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	x : (1 / 4) * (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))), y : (1 / 4) * 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), z : (1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 48	modus ponens	76, 77	{e in {1 .. 2^{t - 1} - 2}} |- (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl) in Real
# 49	instantiation	78, 79, 80, 579, 470, 81, 82, 135*	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) <= (Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl)
# 	S : RealPos, f(l) : 1 / l^{2}, a : e + 1, b : 2^{t - 1} - 1, x : l
# 50	instantiation	500, 83	|- 0 <= (1 / 2)
# 	x : 0, y : 1 / 2
# 51	conjecture		|- forall_{a, b in RealPos | a <= b} ((Integrate_{a}^{b} (1 / l^{2})\,dl) <= (1 / a))
# 	proveit.numbers.integration.boundedInvSqrdIntegral
# 52	instantiation	602, 363, 84	{e in {1 .. 2^{t - 1} - 2}} |- e in RealPos
# 	A : RationalPos, B : RealPos, x : e
# 53	instantiation	85, 336, 86	{e in {1 .. 2^{t - 1} - 2}} |- (2^{t - 1} - 1) in RealPos
# 	a : 2^{t - 1} - 1
# 54	instantiation	87, 547, 194, 583, 195, 88, 155*	{e in {1 .. 2^{t - 1} - 2}} |- e <= (2^{t - 1} - 1)
# 	a : e, b : 2^{t - 1} - 2, c : 1
# 55	instantiation	107, 577, 547	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e) in Real
# 	a : 2, b : e
# 56	instantiation	537	|- |(2, e)| = |(1, ..., 2)|
# 	a : 2, b : e
# 57	instantiation	602, 279, 89	{e in {1 .. 2^{t - 1} - 2}} |- e in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : e
# 58	instantiation	551, 90	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (2 * e)^{-1}) = (1 * ((1 / 2) * e^{-1}))
# 	f(_a) : 1 * _a, x : (2 * e)^{-1}, y : (1 / 2) * e^{-1}
# 59	instantiation	531, 91, 92	{e in {1 .. 2^{t - 1} - 2}} |- (1 * ((1 / 2) * e^{-1})) = ((1 / 2) * e^{-1})
# 	x : 1 * ((1 / 2) * e^{-1}), y : 1 * (1 / 2) * e^{-1}, z : (1 / 2) * e^{-1}
# 60	instantiation	98, 539, 213, 202, 93*	{e in {1 .. 2^{t - 1} - 2}} |- (1 / e) = e^{-1}
# 	x : 1, y : e
# 61	instantiation	107, 308, 224	{e in {1 .. 2^{t - 1} - 2}} |- (4 * e^{2}) in Real
# 	a : 4, b : e^{2}
# 62	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in ComplexNonZero} ((a_{1} *  a_{2} *  ... *  a_{n}) != 0)]
# 	proveit.numbers.multiplication.mult_not_eq_zero
# 63	instantiation	537	|- |(4, e^{2})| = |(1, ..., 2)|
# 	a : 4, b : e^{2}
# 64	instantiation	94, 125, 225	{e in {1 .. 2^{t - 1} - 2}} |- e^{2} in ComplexNonZero
# 	x : e^{2}
# 65	instantiation	551, 95	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (4 * e^{2})^{-1}) = (1 * ((1 / 4) * e^{-2}))
# 	f(_a) : 1 * _a, x : (4 * e^{2})^{-1}, y : (1 / 4) * e^{-2}
# 66	instantiation	531, 96, 97	{e in {1 .. 2^{t - 1} - 2}} |- (1 * ((1 / 4) * e^{-2})) = ((1 / 4) * e^{-2})
# 	x : 1 * ((1 / 4) * e^{-2}), y : 1 * (1 / 4) * e^{-2}, z : (1 / 4) * e^{-2}
# 67	instantiation	98, 539, 125, 225, 99*	{e in {1 .. 2^{t - 1} - 2}} |- (1 / e^{2}) = e^{-2}
# 	x : 1, y : e^{2}
# 68	instantiation	285, 100, 101	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))))
# 	P(_a) : ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + _a)), x : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}), y : Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2})
# 69	instantiation	137, 102, 103	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 	P : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}), Q : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 70	conjecture		|- forall_{f} [forall_{a, b in Integer | a < b} ((Sum_{x = a}^{b} f(x)) = (f(a) + (Sum_{x = a + 1}^{b} f(x))))]
# 	proveit.numbers.summation.sum_split_first
# 71	instantiation	511, 594, 604, 512, 104, 513, 276, 145	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + ((1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))) =  \\ ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	i : 1, j : 2, k : 0, a : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), b : (1 / e^{2}, Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), c : ()
# 72	instantiation	531, 105, 106	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) = ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2}))
# 	x : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), y : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}), z : (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2})
# 73	instantiation	107, 577, 307	{e in {1 .. 2^{t - 1} - 2}} |- (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) in Real
# 	a : 2, b : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 74	instantiation	442, 594, 604, 512, 108, 513, 129, 554, 276	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))) =  \\ ((1 / 4) * 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	i : 1, j : 2, k : 0, a : (1 / 4), b : (2, Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), c : ()
# 75	instantiation	109, 512, 604, 594, 513, 110, 129, 554, 276, 111*	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) =  \\ ((1 / 2) * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 4, 2), c : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 76	instantiation	112, 550	|- [forall_{l in [e,2^{t - 1} - 1]} ((1 / l^{2}) in Real)] => ((Integrate_{e}^{2^{t - 1} - 1} (1 / l^{2})\,dl) in Real)
# 	n : 1, f(l) : 1 / l^{2}, S : [e,2^{t - 1} - 1], x : (l)
# 77	generalization	113	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in [e,2^{t - 1} - 1]} ((1 / l^{2}) in Real)
# 78	conjecture		|- forall_{S} [forall_{f in MonDecFuncs(S) | S subset_eq Real} [forall_{a, b in Integer | a <= b, {a .. b} subset_eq S} ((Sum_{x = a}^{b} f(x)) <= (Integrate_{a - 1}^{b} f(x)\,dx))]]
# 	proveit.numbers.summation.sum_integrate_ineq_NC
# 79	conjecture		|- [x -> (1 / x^{2})] in MonDecFuncs(RealPos)
# 	proveit.numbers.functions.one_over_x_sqrd_in_mon_dec_fxns
# 80	instantiation	562, 114	|- RealPos subset_eq Real
# 	A : RealPos, B : Real
# 81	instantiation	546, 583, 547, 194, 195, 155*	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) <= (2^{t - 1} - 1)
# 	a : 1, x : e, y : 2^{t - 1} - 2
# 82	instantiation	115, 116	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1} - 1} subset_eq RealPos
# 	A : {e + 1 .. 2^{t - 1} - 1}, B : RealPos, x : _a
# 83	instantiation	261, 244	|- (1 / 2) > 0
# 	q : 1 / 2
# 84	instantiation	602, 380, 508	{e in {1 .. 2^{t - 1} - 2}} |- e in RationalPos
# 	A : NaturalPos, B : RationalPos, x : e
# 85	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 86	instantiation	438, 536, 117	{e in {1 .. 2^{t - 1} - 2}} |- 0 < (2^{t - 1} - 1)
# 	x : 0, y : e, z : 2^{t - 1} - 1
# 87	conjecture		|- forall_{a, b, c in Real | a <= b, 0 <= c} (a <= (b + c))
# 	proveit.numbers.ordering.less_eq_add_right
# 88	instantiation	118, 594	|- 1 >= 0
# 	n : 1
# 89	instantiation	602, 309, 275	{e in {1 .. 2^{t - 1} - 2}} |- e in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : e
# 90	instantiation	124, 554, 213, 475, 119, 202, 120*	{e in {1 .. 2^{t - 1} - 2}} |- (2 * e)^{-1} = ((1 / 2) * e^{-1})
# 	a : 2, b : e, c : -1
# 91	instantiation	442, 594, 604, 512, 121, 513, 539, 122, 123	{e in {1 .. 2^{t - 1} - 2}} |- (1 * ((1 / 2) * e^{-1})) =  \\ (1 * (1 / 2) * e^{-1})
# 	i : 1, j : 2, k : 0, a : (1), b : (1 / 2, e^{-1}), c : ()
# 92	instantiation	465, 512, 604, 513, 121, 122, 123	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (1 / 2) * e^{-1}) = ((1 / 2) * e^{-1})
# 	i : 0, j : 2, a : (), b : (1 / 2, e^{-1})
# 93	instantiation	565, 123	{e in {1 .. 2^{t - 1} - 2}} |- (1 * e^{-1}) = e^{-1}
# 	x : e^{-1}
# 94	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 	proveit.numbers.number_sets.complex_numbers.nonzero_complex_is_complex_nonzero
# 95	instantiation	124, 278, 125, 475, 126, 225, 127*, 161*	{e in {1 .. 2^{t - 1} - 2}} |- (4 * e^{2})^{-1} = ((1 / 4) * e^{-2})
# 	a : 4, b : e^{2}, c : -1
# 96	instantiation	442, 594, 604, 512, 128, 513, 539, 129, 162	{e in {1 .. 2^{t - 1} - 2}} |- (1 * ((1 / 4) * e^{-2})) =  \\ (1 * (1 / 4) * e^{-2})
# 	i : 1, j : 2, k : 0, a : (1), b : (1 / 4, e^{-2}), c : ()
# 97	instantiation	465, 512, 604, 513, 128, 129, 162	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (1 / 4) * e^{-2}) = ((1 / 4) * e^{-2})
# 	i : 0, j : 2, a : (), b : (1 / 4, e^{-2})
# 98	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 99	instantiation	531, 130, 131	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (e^{2})^{-1}) = e^{-2}
# 	x : 1 * (e^{2})^{-1}, y : 1 * e^{-2}, z : e^{-2}
# 100	instantiation	509, 132, 133	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# 	x : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), y : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))), z : (1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# 101	instantiation	134, 579, 596, 493, 135*, 136*	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) = (Sum_{l = e}^{2^{t - 1} - 1} (1 / l^{2}))
# 	f(l) : 1 / (l - 1)^{2}, a : e + 1, b : 2^{t - 1}, c : -1, x : l
# 102	instantiation	137, 138, 139	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# 	P : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}), Q : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# 103	instantiation	551, 140, 141*, 142*	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	f(_a) : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} _a(l)), x(l) : {(1 / l)^{2} if l in {e + 1 .. 2^{t - 1} - 1}., y(l) : {1 / l^{2} if l in {e + 1 .. 2^{t - 1} - 1}.
# 104	instantiation	537	|- |(1 / e^{2}, Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))| = |(1, ..., 2)|
# 	a : 1 / e^{2}, b : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 105	instantiation	143, 594, 512, 513, 276, 145	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) =  \\ ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2}))
# 	i : 1, j : 1, k : 0, a : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), b : (1 / e^{2}), c : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}), d : ()
# 106	instantiation	241, 512, 604, 594, 513, 144, 276, 145, 146*	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (1 / e^{2})) =  \\ ((2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) + (1 / e^{2}))
# 	i : 0, j : 2, k : 1, a : (), b : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), c : (1 / e^{2})
# 107	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 108	instantiation	537	|- |(2, Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))| = |(1, ..., 2)|
# 	a : 2, b : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 109	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 110	instantiation	537	|- |(1 / 4, 2)| = |(1, ..., 2)|
# 	a : 1 / 4, b : 2
# 111	instantiation	147, 539, 554, 159, 148, 149*, 150*	|- ((1 / 4) * 2) = (1 / 2)
# 	x : 1, y : 2, z : 4, w : 1
# 112	conjecture		|- forall_{n in NaturalPos} [forall_{f, S} ([forall_{x_{1}, x_{2}, ..., x_{n} in S} (f(x_{1}, x_{2}, ..., x_{n}) in Real)] => ([Integrate_{x_{1}, x_{2}, ..., x_{n} in S} f(x_{1}, x_{2}, ..., x_{n})] in Real))]
# 	proveit.numbers.integration.integration_real_closure
# 113	instantiation	369, 583, 151, 152	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- (1 / l^{2}) in Real
# 	a : 1, b : l^{2}
# 114	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 115	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 116	generalization	153	{e in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {e + 1 .. 2^{t - 1} - 1}} (_a in RealPos)
# 117	instantiation	285, 154, 155	{e in {1 .. 2^{t - 1} - 2}} |- e < (2^{t - 1} - 1)
# 	P(_a) : e < _a, x : (2^{t - 1} - 2) + 1, y : 2^{t - 1} - 1
# 118	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 119	instantiation	305, 450	|- 2 != 0
# 	n : 2
# 120	instantiation	158, 235, 550, 156*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 121	instantiation	537	|- |(1 / 2, e^{-1})| = |(1, ..., 2)|
# 	a : 1 / 2, b : e^{-1}
# 122	instantiation	602, 571, 157	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 123	instantiation	490, 213, 515	{e in {1 .. 2^{t - 1} - 2}} |- e^{-1} in Complex
# 	a : e, b : -1
# 124	conjecture		|- forall_{a in Complex, b in Complex, c in Real | a != 0, b != 0} ((a * b)^{c} = (a^{c} * b^{c}))
# 	proveit.numbers.exponentiation.real_power_of_product
# 125	instantiation	602, 571, 224	{e in {1 .. 2^{t - 1} - 2}} |- e^{2} in Complex
# 	A : Real, B : Complex, x : e^{2}
# 126	instantiation	305, 328	|- 4 != 0
# 	n : 4
# 127	instantiation	158, 159, 550, 160*	|- 4^{-1} = (1 / 4)
# 	a : 4, n : 1
# 128	instantiation	537	|- |(1 / 4, e^{-2})| = |(1, ..., 2)|
# 	a : 1 / 4, b : e^{-2}
# 129	instantiation	602, 571, 166	|- (1 / 4) in Complex
# 	A : Real, B : Complex, x : 1 / 4
# 130	instantiation	551, 161	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (e^{2})^{-1}) = (1 * e^{-2})
# 	f(_a) : 1 * _a, x : (e^{2})^{-1}, y : e^{-2}
# 131	instantiation	565, 162	{e in {1 .. 2^{t - 1} - 2}} |- (1 * e^{-2}) = e^{-2}
# 	x : e^{-2}
# 132	instantiation	165, 166, 163, 167, 164, 170	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))))
# 	a : 1 / 4, x : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), y : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))
# 133	instantiation	165, 166, 167, 168, 169, 170	{e in {1 .. 2^{t - 1} - 2}} |- ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))) <= ((1 / 4) * ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))))
# 	a : 1 / 4, x : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})), y : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# 134	conjecture		|- forall_{f} [forall_{a, b, c in Integer} ((Sum_{x = a}^{b} f(x)) = (Sum_{x = a + c}^{b + c} f(x - c)))]
# 	proveit.numbers.summation.index_shift
# 135	instantiation	531, 171, 172	{e in {1 .. 2^{t - 1} - 2}} |- ((e + 1) - 1) = e
# 	x : (e + 1) - 1, y : e + 1 - 1, z : e
# 136	instantiation	531, 173, 174	{e in {1 .. 2^{t - 1} - 2}, l in {e .. 2^{t - 1} - 1}} |- ((l - (-1)) - 1) = l
# 	x : (l - (-1)) - 1, y : (l + 1) - 1, z : l
# 137	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 138	instantiation	175, 567, 568, 176*, 177*	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})
# 	f(l) : 1 / l, a : -2^{t - 1} + 1, b : -(e + 1), x : l
# 139	instantiation	551, 178, 179*, 180*	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l)^{2}) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2})) = ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}))
# 	f(_a) : (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} _a(l)) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l)^{2}), x(l) : {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}., y(l) : {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.
# 140	modus ponens	181, 182	{e in {1 .. 2^{t - 1} - 2}} |- [l -> {(1 / l)^{2} if l in {e + 1 .. 2^{t - 1} - 1}.] =  \\ [l -> {1 / l^{2} if l in {e + 1 .. 2^{t - 1} - 1}.]
# 141	instantiation	222, 471	{l in {e + 1 .. 2^{t - 1} - 1}} |- {(1 / l)^{2} if l in {e + 1 .. 2^{t - 1} - 1}. = (1 / l)^{2}
# 	a : (1 / l)^{2}, Q : l in {e + 1 .. 2^{t - 1} - 1}
# 142	instantiation	222, 471	{l in {e + 1 .. 2^{t - 1} - 1}} |- {1 / l^{2} if l in {e + 1 .. 2^{t - 1} - 1}. = (1 / l^{2})
# 	a : 1 / l^{2}, Q : l in {e + 1 .. 2^{t - 1} - 1}
# 143	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j} + c+ d_{1} +  d_{2} +  ... +  d_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + c+ b_{1} +  b_{2} +  ... +  b_{j}+ d_{1} +  d_{2} +  ... +  d_{k}))]
# 	proveit.numbers.addition.leftward_commutation
# 144	instantiation	537	|- |(Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}), Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))| = |(1, ..., 2)|
# 	a : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}), b : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 145	instantiation	602, 571, 183	{e in {1 .. 2^{t - 1} - 2}} |- (1 / e^{2}) in Complex
# 	A : Real, B : Complex, x : 1 / e^{2}
# 146	instantiation	184, 185	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) = (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	x : 2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})), y : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 147	conjecture		|- forall_{x, y in Complex} [forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w)))]
# 	proveit.numbers.division.prod_of_fracs
# 148	instantiation	602, 279, 186	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 149	instantiation	187, 554	|- (2 / 1) = 2
# 	x : 2
# 150	instantiation	531, 188, 189	|- ((1 * 2) / (4 * 1)) = (1 / 2)
# 	x : (1 * 2) / (4 * 1), y : 2 / 4, z : 1 / 2
# 151	instantiation	384, 281, 604	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- l^{2} in Real
# 	a : l, b : 2
# 152	instantiation	190, 191, 554, 192	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- l^{2} != 0
# 	a : l, b : 2
# 153	instantiation	602, 363, 193	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1} - 1}} |- _a in RealPos
# 	A : RationalPos, B : RealPos, x : _a
# 154	instantiation	485, 547, 194, 583, 195, 559	{e in {1 .. 2^{t - 1} - 2}} |- e < ((2^{t - 1} - 2) + 1)
# 	a : e, b : 2^{t - 1} - 2, c : 1
# 155	instantiation	531, 196, 197	|- ((2^{t - 1} - 2) + 1) = (2^{t - 1} - 1)
# 	x : (2^{t - 1} - 2) + 1, y : 2^{t - 1} - 2 + 1, z : 2^{t - 1} - 1
# 156	instantiation	200, 554	|- 2^{1} = 2
# 	x : 2
# 157	instantiation	602, 586, 198	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 158	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 159	instantiation	602, 279, 199	|- 4 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 4
# 160	instantiation	200, 278	|- 4^{1} = 4
# 	x : 4
# 161	instantiation	201, 213, 577, 475, 202, 203*	{e in {1 .. 2^{t - 1} - 2}} |- (e^{2})^{-1} = e^{-2}
# 	a : e, b : 2, c : -1
# 162	instantiation	490, 213, 315	{e in {1 .. 2^{t - 1} - 2}} |- e^{-2} in Complex
# 	a : e, b : -2
# 163	instantiation	576, 204, 208	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) in Real
# 	a : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), b : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
# 164	instantiation	546, 208, 204, 207, 205	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) <= ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})))
# 	a : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), x : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), y : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})
# 165	conjecture		|- forall_{a, x, y in Real | x <= y, a >= 0} ((a * x) <= (a * y))
# 	proveit.numbers.multiplication.weak_bound_via_right_factor_bound
# 166	instantiation	602, 586, 206	|- (1 / 4) in Real
# 	A : Rational, B : Real, x : 1 / 4
# 167	instantiation	576, 207, 208	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) in Real
# 	a : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), b : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})
# 168	instantiation	576, 207, 209	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))) in Real
# 	a : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), b : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})
# 169	instantiation	497, 207, 208, 209, 210	{e in {1 .. 2^{t - 1} - 2}} |- ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}))) <= ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# 	a : Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}), x : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2}), y : Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})
# 170	instantiation	500, 211	|- 0 <= (1 / 4)
# 	x : 0, y : 1 / 4
# 171	instantiation	511, 512, 604, 594, 513, 212, 213, 539, 515	{e in {1 .. 2^{t - 1} - 2}} |- ((e + 1) - 1) =  \\ (e + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (e, 1), c : (-1)
# 172	instantiation	516, 539, 213, 518	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1 - 1) = e
# 	a : 1, b : 1, c : e
# 173	instantiation	551, 214	|- ((l - (-1)) - 1) = ((l + 1) - 1)
# 	f(_a) : [+]_a, x : (l - (-1), -1), y : (l + 1, -1)
# 174	instantiation	531, 215, 216	{e in {1 .. 2^{t - 1} - 2}, l in {e .. 2^{t - 1} - 1}} |- ((l + 1) - 1) = l
# 	x : (l + 1) - 1, y : l + 1 - 1, z : l
# 175	conjecture		|- forall_{f} [forall_{a, b in Integer} ((Sum_{x = a}^{b} f(x)^{2}) = (Sum_{x = -b}^{-a} f(x)^{2}))]
# 	proveit.numbers.summation.even_fxn_sum
# 176	instantiation	329, 217	{e in {1 .. 2^{t - 1} - 2}} |- (-(-(e + 1))) = (e + 1)
# 	x : e + 1
# 177	instantiation	553, 218, 539, 219*	|- (-(-2^{t - 1} + 1)) = (2^{t - 1} - 1)
# 	a : -2^{t - 1}, b : 1
# 178	modus ponens	220, 221	{e in {1 .. 2^{t - 1} - 2}} |- [l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.]
# 179	instantiation	222, 557	{l in {-2^{t - 1} + 1 .. -(e + 1)}} |- {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}. = (1 / l)^{2}
# 	a : (1 / l)^{2}, Q : l in {-2^{t - 1} + 1 .. -(e + 1)}
# 180	instantiation	222, 557	{l in {-2^{t - 1} + 1 .. -(e + 1)}} |- {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}. = (1 / l^{2})
# 	a : 1 / l^{2}, Q : l in {-2^{t - 1} + 1 .. -(e + 1)}
# 181	instantiation	271, 550	|- [forall_{l in {e + 1 .. 2^{t - 1} - 1}} ((1 / l)^{2} = (1 / l^{2}))] =>  \\ ([l -> {(1 / l)^{2} if l in {e + 1 .. 2^{t - 1} - 1}.] =  \\ [l -> {1 / l^{2} if l in {e + 1 .. 2^{t - 1} - 1}.])
# 	i : 1, f(l) : (1 / l)^{2}, g(l) : 1 / l^{2}, Q(l) : l in {e + 1 .. 2^{t - 1} - 1}, a : (l), b : (l), c : (l)
# 182	generalization	223	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {e + 1 .. 2^{t - 1} - 1}} ((1 / l)^{2} = (1 / l^{2}))
# 183	instantiation	369, 583, 224, 225	{e in {1 .. 2^{t - 1} - 2}} |- (1 / e^{2}) in Real
# 	a : 1, b : e^{2}
# 184	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 185	instantiation	226, 512, 604, 594, 513, 227, 539, 276, 548*, 228*	{e in {1 .. 2^{t - 1} - 2}} |- (2 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) =  \\ ((Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})) + (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})))
# 	i : 0, j : 2, k : 1, a : (), b : (1, 1), c : (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 186	instantiation	602, 309, 229	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 187	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 188	instantiation	230, 604, 231, 232, 504, 233	|- ((1 * 2) / (4 * 1)) =  \\ (2 / 4)
# 	n : 2, f(_a, _b) : _a / _b, x : (1 * 2, 4 * 1), y : (2, 4)
# 189	instantiation	234, 235, 539, 247*, 236*	|- (2 / 4) = (1 / 2)
# 	x : 2, z : 2, y : 1
# 190	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_not_eq_zero
# 191	instantiation	602, 571, 281	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- l in Complex
# 	A : Real, B : Complex, x : l
# 192	instantiation	394, 237	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- l != 0
# 	x : 0, y : l
# 193	instantiation	602, 380, 238	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1} - 1}} |- _a in RationalPos
# 	A : NaturalPos, B : RationalPos, x : _a
# 194	instantiation	602, 586, 239	|- (2^{t - 1} - 2) in Real
# 	A : Rational, B : Real, x : 2^{t - 1} - 2
# 195	instantiation	523, 592, 593, 589	{e in {1 .. 2^{t - 1} - 2}} |- e <= (2^{t - 1} - 2)
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 196	instantiation	511, 512, 604, 594, 513, 240, 270, 315, 539	|- ((2^{t - 1} - 2) + 1) =  \\ (2^{t - 1} - 2 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t - 1}, -2), c : (1)
# 197	instantiation	241, 594, 604, 512, 242, 513, 270, 315, 539, 243*	|- (2^{t - 1} - 2 + 1) =  \\ (2^{t - 1} - 1)
# 	i : 1, j : 2, k : 0, a : (2^{t - 1}), b : (-2, 1), c : ()
# 198	instantiation	602, 252, 244	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 199	instantiation	602, 309, 245	|- 4 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 4
# 200	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 201	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 202	instantiation	305, 508	{e in {1 .. 2^{t - 1} - 2}} |- e != 0
# 	n : e
# 203	instantiation	246, 554, 539, 247*	|- (2 * (-1)) = (-2)
# 	x : 2, y : 1
# 204	modus ponens	248, 249	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real
# 205	modus ponens	250, 251	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2}))
# 206	instantiation	602, 252, 262	|- (1 / 4) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 4
# 207	modus ponens	253, 254	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) in Real
# 208	modus ponens	255, 256	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real
# 209	modus ponens	257, 258	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) in Real
# 210	modus ponens	259, 260	{e in {1 .. 2^{t - 1} - 2}} |- (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2}))
# 211	instantiation	261, 262	|- (1 / 4) > 0
# 	q : 1 / 4
# 212	instantiation	537	|- |(e, 1)| = |(1, ..., 2)|
# 	a : e, b : 1
# 213	instantiation	602, 571, 547	{e in {1 .. 2^{t - 1} - 2}} |- e in Complex
# 	A : Real, B : Complex, x : e
# 214	instantiation	263, 450, 264, 265, 266, 267	|- (l - (-1), -1) = (l + 1, -1)
# 	i : 2, a : (l - (-1), -1), b : (l + 1, -1)
# 215	instantiation	511, 512, 604, 594, 513, 514, 268, 539, 515	{e in {1 .. 2^{t - 1} - 2}, l in {e .. 2^{t - 1} - 1}} |- ((l + 1) - 1) =  \\ (l + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (l, 1), c : (-1)
# 216	instantiation	516, 539, 268, 518	{e in {1 .. 2^{t - 1} - 2}, l in {e .. 2^{t - 1} - 1}} |- (l + 1 - 1) = l
# 	a : 1, b : 1, c : l
# 217	instantiation	602, 571, 525	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Complex
# 	A : Real, B : Complex, x : e + 1
# 218	instantiation	602, 571, 269	|- (-2^{t - 1}) in Complex
# 	A : Real, B : Complex, x : -2^{t - 1}
# 219	instantiation	329, 270	|- (-(-2^{t - 1})) = 2^{t - 1}
# 	x : 2^{t - 1}
# 220	instantiation	271, 550	|- [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l)^{2} = (1 / l^{2}))] =>  \\ ([l -> {(1 / l)^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.] =  \\ [l -> {1 / l^{2} if l in {-2^{t - 1} + 1 .. -(e + 1)}.])
# 	i : 1, f(l) : (1 / l)^{2}, g(l) : 1 / l^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(e + 1)}, a : (l), b : (l), c : (l)
# 221	generalization	272	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l)^{2} = (1 / l^{2}))
# 222	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 223	instantiation	303, 539, 273, 450, 274, 304*	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1} - 1}} |- (1 / l)^{2} = (1 / l^{2})
# 	a : 1, b : l, n : 2
# 224	instantiation	384, 547, 604	{e in {1 .. 2^{t - 1} - 2}} |- e^{2} in Real
# 	a : e, b : 2
# 225	instantiation	386, 275, 388	{e in {1 .. 2^{t - 1} - 2}} |- e^{2} != 0
# 	a : e, b : 2
# 226	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 227	instantiation	537	|- |(1, 1)| = |(1, ..., 2)|
# 	a : 1, b : 1
# 228	instantiation	565, 276	{e in {1 .. 2^{t - 1} - 2}} |- (1 * (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))) = (Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2}))
# 	x : Sum_{l = e + 1}^{2^{t - 1} - 1} (1 / l^{2})
# 229	instantiation	602, 400, 277	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 230	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 231	instantiation	537	|- |(1 * 2, 4 * 1)| = |(1, ..., 2)|
# 	a : 1 * 2, b : 4 * 1
# 232	instantiation	537	|- |(2, 4)| = |(1, ..., 2)|
# 	a : 2, b : 4
# 233	instantiation	441, 278	|- (4 * 1) = 4
# 	x : 4
# 234	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 235	instantiation	602, 279, 280	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 236	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 237	instantiation	408, 582, 281, 282	{e in {1 .. 2^{t - 1} - 2}, l in [e,2^{t - 1} - 1]} |- 0 != l
# 	a : 0, b : l
# 238	instantiation	535, 283, 284	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1} - 1}} |- _a in NaturalPos
# 	a : _a
# 239	instantiation	602, 590, 593	|- (2^{t - 1} - 2) in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1} - 2
# 240	instantiation	537	|- |(2^{t - 1}, -2)| = |(1, ..., 2)|
# 	a : 2^{t - 1}, b : -2
# 241	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 242	instantiation	537	|- |(-2, 1)| = |(1, ..., 2)|
# 	a : -2, b : 1
# 243	instantiation	285, 286, 287	|- (-2 + 1) = (-1)
# 	P(_a) : _a = (-1), x : 1 - 2, y : -2 + 1
# 244	instantiation	297, 364, 288	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 245	instantiation	602, 400, 289	|- 4 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 4
# 246	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 247	instantiation	441, 554	|- (2 * 1) = 2
# 	x : 2
# 248	instantiation	352	|- [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# 	f(l) : 1 / (l - (2^{t} * delta_{b_{f}}))^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(e + 1)}, x : l
# 249	generalization	290	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)
# 250	instantiation	295	|- [forall_{k in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / k^{2}))] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})))
# 	a(l) : 1 / (l - (2^{t} * delta_{b_{f}}))^{2}, b(l) : 1 / l^{2}, S : {-2^{t - 1} + 1 .. -(e + 1)}
# 251	generalization	291	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / l^{2}))
# 252	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 253	instantiation	352	|- [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l^{2}) in Real)] => ((Sum_{l = -2^{t - 1} + 1}^{-(e + 1)} (1 / l^{2})) in Real)
# 	f(l) : 1 / l^{2}, Q(l) : l in {-2^{t - 1} + 1 .. -(e + 1)}, x : l
# 254	generalization	292	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} ((1 / l^{2}) in Real)
# 255	instantiation	352	|- [forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) in Real)
# 	f(l) : 1 / (l - (2^{t} * delta_{b_{f}}))^{2}, Q(l) : l in {e + 1 .. 2^{t - 1}}, x : l
# 256	generalization	293	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) in Real)
# 257	instantiation	352	|- [forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - 1)^{2}) in Real)] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})) in Real)
# 	f(l) : 1 / (l - 1)^{2}, Q(l) : l in {e + 1 .. 2^{t - 1}}, x : l
# 258	generalization	294	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - 1)^{2}) in Real)
# 259	instantiation	295	|- [forall_{k in {e + 1 .. 2^{t - 1}}} ((1 / (k - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (k - 1)^{2}))] => ((Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - (2^{t} * delta_{b_{f}}))^{2})) <= (Sum_{l = e + 1}^{2^{t - 1}} (1 / (l - 1)^{2})))
# 	a(l) : 1 / (l - (2^{t} * delta_{b_{f}}))^{2}, b(l) : 1 / (l - 1)^{2}, S : {e + 1 .. 2^{t - 1}}
# 260	generalization	296	{e in {1 .. 2^{t - 1} - 2}} |- forall_{l in {e + 1 .. 2^{t - 1}}} ((1 / (l - (2^{t} * delta_{b_{f}}))^{2}) <= (1 / (l - 1)^{2}))
# 261	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 262	instantiation	297, 364, 298	|- (1 / 4) in RationalPos
# 	a : 1, b : 4
# ...
# 458	instantiation	549, 484	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in IntegerNeg
# 	a : e + 1
# 459	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 460	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 461	instantiation	576, 540, 583	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- (l + 1) in Real
# 	a : l, b : 1
# 462	instantiation	485, 577, 540, 583, 486, 559	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- 2 < (l + 1)
# 	a : 2, b : l, c : 1
# 463	instantiation	487, 539, 554, 548	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 464	instantiation	531, 488, 489	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- ((l + 1) - 1) = l
# 	x : (l + 1) - 1, y : l + 1 - 1, z : l
# 465	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 1* b_{1} *  b_{2} *  ... *  b_{j}) = (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}))]
# 	proveit.numbers.multiplication.elim_one_any
# 466	instantiation	537	|- |(2^{t}, delta_{b_{f}})| = |(1, ..., 2)|
# 	a : 2^{t}, b : delta_{b_{f}}
# 467	instantiation	490, 554, 491	|- 2^{t} in Complex
# 	a : 2, b : t
# 468	instantiation	602, 571, 492	|- delta_{b_{f}} in Complex
# 	A : Real, B : Complex, x : delta_{b_{f}}
# 469	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 470	instantiation	595, 596, 493	|- (2^{t - 1} - 1) in Integer
# 	a : 2^{t - 1}, b : -1
# 471	assumption		{l in {e + 1 .. 2^{t - 1} - 1}} |- l in {e + 1 .. 2^{t - 1} - 1}
# 472	instantiation	602, 586, 494	|- (-2) in Real
# 	A : Rational, B : Real, x : -2
# 473	instantiation	509, 495, 496	{e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l <= (-2)
# 	x : l, y : -(e + 1), z : -2
# 474	conjecture		|- forall_{a, x, y in Real | x <= y, a <= 0} ((a * x) >= (a * y))
# 	proveit.numbers.multiplication.reversed_weak_bound_via_right_factor_bound
# 475	instantiation	505, 583	|- (-1) in Real
# 	a : 1
# 476	instantiation	497, 577, 582, 578, 498, 499*	|- 2 <= (2 + (2^{t} * delta_{b_{f}}))
# 	a : 2, x : 0, y : 2^{t} * delta_{b_{f}}
# 477	instantiation	500, 501	|- (-1) <= 0
# 	x : -1, y : 0
# 478	instantiation	503, 539, 566, 502*	|- ((-1) * (2 + (2^{t} * delta_{b_{f}}))) = (-2 - (2^{t} * delta_{b_{f}}))
# 	x : 1, y : 2 + (2^{t} * delta_{b_{f}})
# 479	instantiation	503, 539, 554, 504*	|- ((-1) * 2) = (-2)
# 	x : 1, y : 2
# 480	instantiation	505, 578	|- (-(2^{t} * delta_{b_{f}})) in Real
# 	a : 2^{t} * delta_{b_{f}}
# 481	instantiation	602, 586, 506	{e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in Real
# 	A : Rational, B : Real, x : l
# 482	conjecture		|- forall_{a, b in Complex | a = b} ((-a + b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_reverse
# 483	instantiation	541	|- 2 = 2
# 	x : 2
# 484	instantiation	507, 508, 550	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 485	conjecture		|- forall_{a, b, c in Real | a <= b, 0 < c} (a < (b + c))
# 	proveit.numbers.ordering.less_eq_add_right_strong
# 486	instantiation	509, 526, 510	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- 2 <= l
# 	x : 2, y : e + 1, z : l
# 487	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 488	instantiation	511, 512, 604, 594, 513, 514, 517, 539, 515	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- ((l + 1) - 1) =  \\ (l + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (l, 1), c : (-1)
# 489	instantiation	516, 539, 517, 518	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- (l + 1 - 1) = l
# 	a : 1, b : 1, c : l
# 490	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 491	instantiation	602, 571, 519	|- t in Complex
# 	A : Real, B : Complex, x : t
# 492	instantiation	520, 521	|- delta_{b_{f}} in Real
# 	b : b_{f}
# 493	instantiation	602, 522, 530	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 494	instantiation	602, 590, 597	|- (-2) in Rational
# 	A : Integer, B : Rational, x : -2
# 495	instantiation	523, 567, 568, 557	{e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l <= (-(e + 1))
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : l
# 496	instantiation	524, 577, 525, 526	{e in {1 .. 2^{t - 1} - 2}} |- (-2) >= (-(e + 1))
# 	x : 2, y : e + 1
# 497	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 498	instantiation	527, 582, 583, 584	|- 0 <= (2^{t} * delta_{b_{f}})
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 499	instantiation	528, 554	|- (2 + 0) = 2
# 	a : 2
# 500	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 501	instantiation	529, 530	|- (-1) < 0
# 	a : -1
# 502	instantiation	531, 532, 533	|- (-(1 * (2 + (2^{t} * delta_{b_{f}})))) = (-2 - (2^{t} * delta_{b_{f}}))
# 	x : -(1 * (2 + (2^{t} * delta_{b_{f}}))), y : -(2 + (2^{t} * delta_{b_{f}})), z : -2 - (2^{t} * delta_{b_{f}})
# 503	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 504	instantiation	565, 554	|- (1 * 2) = 2
# 	x : 2
# 505	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 506	instantiation	602, 590, 534	{e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 507	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 508	instantiation	535, 585, 536	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 509	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 510	instantiation	569, 579, 596, 575	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- (e + 1) <= l
# 	a : e + 1, b : 2^{t - 1}, n : l
# 511	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 512	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 513	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 514	instantiation	537	|- |(l, 1)| = |(1, ..., 2)|
# 	a : l, b : 1
# 515	instantiation	538, 539	|- (-1) in Complex
# 	a : 1
# 516	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 517	instantiation	602, 571, 540	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- l in Complex
# 	A : Real, B : Complex, x : l
# 518	instantiation	541	|- 1 = 1
# 	x : 1
# 519	instantiation	542, 543, 544	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 520	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 521	conjecture		|- b_{f} in Integer
# 	proveit.physics.quantum.QPE._best_floor_is_int
# 522	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 523	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 524	conjecture		|- forall_{x, y in Real | x <= y} ((-x) >= (-y))
# 	proveit.numbers.negation.negated_weak_bound
# 525	instantiation	602, 586, 545	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Real
# 	A : Rational, B : Real, x : e + 1
# 526	instantiation	546, 583, 547, 560, 548*	{e in {1 .. 2^{t - 1} - 2}} |- 2 <= (e + 1)
# 	a : 1, x : 1, y : e
# 527	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 528	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 529	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 530	instantiation	549, 550	|- (-1) in IntegerNeg
# 	a : 1
# 531	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 532	instantiation	551, 552	|- (-(1 * (2 + (2^{t} * delta_{b_{f}})))) = (-(2 + (2^{t} * delta_{b_{f}})))
# 	f(_a) : -_a, x : 1 * (2 + (2^{t} * delta_{b_{f}})), y : 2 + (2^{t} * delta_{b_{f}})
# 533	instantiation	553, 554, 555	|- (-(2 + (2^{t} * delta_{b_{f}}))) = (-2 - (2^{t} * delta_{b_{f}}))
# 	a : 2, b : 2^{t} * delta_{b_{f}}
# 534	instantiation	602, 556, 557	{e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer, x : l
# 535	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 536	instantiation	558, 559, 560	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 537	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 538	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 539	instantiation	602, 571, 583	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 540	instantiation	602, 586, 561	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 541	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 542	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 543	instantiation	562, 563	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 544	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 545	instantiation	602, 590, 579	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Rational
# 	A : Integer, B : Rational, x : e + 1
# 546	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 547	instantiation	602, 586, 564	{e in {1 .. 2^{t - 1} - 2}} |- e in Real
# 	A : Rational, B : Real, x : e
# 548	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 549	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 550	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 551	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 552	instantiation	565, 566	|- (1 * (2 + (2^{t} * delta_{b_{f}}))) = (2 + (2^{t} * delta_{b_{f}}))
# 	x : 2 + (2^{t} * delta_{b_{f}})
# 553	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 554	instantiation	602, 571, 577	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 555	instantiation	602, 571, 578	|- (2^{t} * delta_{b_{f}}) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta_{b_{f}}
# 556	instantiation	591, 567, 568	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 557	assumption		{l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in {-2^{t - 1} + 1 .. -(e + 1)}
# 558	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 559	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 560	instantiation	569, 592, 593, 589	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 561	instantiation	602, 590, 570	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 562	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 563	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 564	instantiation	602, 590, 585	{e in {1 .. 2^{t - 1} - 2}} |- e in Rational
# 	A : Integer, B : Rational, x : e
# 565	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 566	instantiation	602, 571, 572	|- (2 + (2^{t} * delta_{b_{f}})) in Complex
# 	A : Real, B : Complex, x : 2 + (2^{t} * delta_{b_{f}})
# 567	instantiation	595, 573, 592	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 568	instantiation	600, 579	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	a : e + 1
# 569	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 570	instantiation	602, 574, 575	{e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {e + 1 .. 2^{t - 1}}, B : Integer, x : l
# 571	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 572	instantiation	576, 577, 578	|- (2 + (2^{t} * delta_{b_{f}})) in Real
# 	a : 2, b : 2^{t} * delta_{b_{f}}
# 573	instantiation	600, 596	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 574	instantiation	591, 579, 596	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : e + 1, b : 2^{t - 1}
# 575	assumption		{l in {e + 1 .. 2^{t - 1}}} |- l in {e + 1 .. 2^{t - 1}}
# 576	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 577	instantiation	602, 586, 580	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 578	instantiation	581, 582, 583, 584	|- (2^{t} * delta_{b_{f}}) in Real
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 579	instantiation	595, 585, 592	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 580	instantiation	602, 590, 601	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 581	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 582	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 583	instantiation	602, 586, 587	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 584	conjecture		|- (2^{t} * delta_{b_{f}}) in [0,1)
# 	proveit.physics.quantum.QPE._scaled_delta_b_floor_in_interval
# 585	instantiation	602, 588, 589	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 586	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 587	instantiation	602, 590, 592	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 588	instantiation	591, 592, 593	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 589	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 590	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 591	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 592	instantiation	602, 603, 594	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 593	instantiation	595, 596, 597	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 594	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 595	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 596	instantiation	602, 598, 599	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 597	instantiation	600, 601	|- (-2) in Integer
# 	a : 2
# 598	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 599	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 600	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 601	instantiation	602, 603, 604	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 602	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 603	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 604	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
