# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_best_guarantee_delta_nonzero">_best_guarantee_delta_nonzero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, m, theta, defaults
from proveit.logic import NotEquals, InSet
from proveit.numbers import (
        zero, one, two, pi, Abs, Add, Complex, frac, IntervalOC, Less, greater, Mult, Exp)
# QPE common exprs
from proveit.physics.quantum.QPE import _b_round, _delta_b_round, _t, _two_pow_t
 # QPE theorems
from proveit.physics.quantum.QPE import (
        _alpha_m_mod_as_geometric_sum, _alpha_are_complex, _best_round_is_int,
        _delta_b_is_real, _delta_b_is_zero_or_non_int,
        _phase_from_best_with_delta_b, _scaled_delta_b_round_in_interval,
        _t_in_natural_pos, _two_pow_t_is_nat_pos)
from proveit.trigonometry import Sin

# %%
# %proving _best_guarantee_delta_nonzero
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_best_guarantee_delta_nonzero">_best_guarantee_delta_nonzero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/71aa283d054a9028fe068383446a7aec129884730/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/7785f1810b740f72aebec97b7896dcb3efcf0e8a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = [_best_guarantee_delta_nonzero.antecedent]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/ecdd50710244b3da50fc52266bb53cd5a701a6980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Keep the factor of $2$ from combining with $2^t$ in the steps below:

# %%
Exp.change_simplification_directives(factor_numeric_rational=True)

# %%
alpha_index = _best_guarantee_delta_nonzero.consequent.lhs.base.operand.index
# Out:
# <strong id="alpha_index">alpha_index:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f48b8cb9e3740a250d050cd6d7873b4ef7c573490/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ## Start from $\alpha_{m~\textrm{mod}~2^t}$ expressed as a geometric sum, instantiated with $m:b_r$

# %%
_alpha_m_mod_as_geometric_sum
# Out:
# |- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))

# %%
_alpha_eq_01 = (
        _alpha_m_mod_as_geometric_sum.instantiate({m: _b_round}))
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{b_{r} mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k}))
# <strong id="_alpha_eq_01">_alpha_eq_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/1b7d5fa8440f54b7a3ef0a2409529489b92bfffd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/5afa169baa4e5a326d29b774308f379fa14335d90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Put this in terms of $\delta_{b_r}$

# %%
_phase_from_best_with_delta_b
# Out:
# |- forall_{b in Integer} (phase = ((b / 2^{t}) + delta_{b}))

# %%
_phase_from_best_with_delta_b_inst = (
        _phase_from_best_with_delta_b.instantiate({b: _b_round}))
# Out:
# <strong id="_phase_from_best_with_delta_b_inst">_phase_from_best_with_delta_b_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/8174ca033af9de4d3ad36d98e074ec714d119cba0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/4c3fd35d58c2f8d6125e31eea557e091b8a7ce160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# We want to know that _delta_b_round and 2^t are real so that
# auto-simplification will manifest in the substitute() step further below
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
_delta_b_is_real.instantiate({b: _b_round})
# Out:
# |- delta_{b_{r}} in Real

# %%
with Exp.temporary_simplification_directives() as tmp_directives:
    tmp_directives.reduce_double_exponent = False # don't simplify k double-exponent
    _alpha_eq_02 = (
        _alpha_eq_01.inner_expr().rhs.factors[1].summand.base.exponent.
        factors[3].operands[0].substitute(_phase_from_best_with_delta_b_inst.rhs))
# Out:
# Expression notebook is being updated for {(e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k})
# Expression notebook is being updated for (alpha_{b_{r} mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k}))
# Expression notebook is being updated for alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k}))
# Expression notebook is being updated for {(e^{2 * pi * i * delta_{b_{r}}})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{2 * pi * i * delta_{b_{r}}})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{2 * pi * i * delta_{b_{r}}})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k})
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k})
# Expression notebook is being updated for (alpha_{b_{r} mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}))
# Expression notebook is being updated for alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}))
# <strong id="_alpha_eq_02">_alpha_eq_02:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/49746fac464dc140a0b7ebf0130ed670fda792240/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/270208c3c8c95832241f86101bb53b06acc854130/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ## Evaluate the Finite Geometric Sum
#
# To evaluate the summation as a finite geometric sum, we need to establish that the constant ratio $e^{2\pi i \delta_{b_r}} \neq 1$ which is automatically proven given $\delta_{b_r} \notin \mathbb{Z}$.

# %%
_delta_b_is_zero_or_non_int
# Out:
# |- forall_{b in {b_{f}, b_{r}}} ((delta_{b} = 0) or (delta_{b} not-in Integer))

# %%
_delta_b_is_zero_or_non_int_inst = _delta_b_is_zero_or_non_int.instantiate({b: _b_round})
# Out:
# <strong id="_delta_b_is_zero_or_non_int_inst">_delta_b_is_zero_or_non_int_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/7cc0ddaa122ae04417fa37ed9b5e60a2a703a4fb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/a0028657ebf6ff6283e9432ece395d2cd3cb5fe20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_delta_b_round_non_int = _delta_b_is_zero_or_non_int_inst.derive_right_if_not_left()
# Out:
# <strong id="_delta_b_round_non_int">_delta_b_round_non_int:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/9f0d04a7d37d2f0efd706762751699efcf03f4810/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/593265c0dc0086a9b735dba69a5cf2a9259b82140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# We can then evaluate the sum using the standard formula for a finite geometric sum:

# %%
_alpha_eq_03 = _alpha_eq_02.inner_expr().rhs.factors[1].geom_sum_reduce()
# Out:
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}, (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))
# Expression notebook is being updated for (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}) = ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))
# <strong id="_alpha_eq_03">_alpha_eq_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/0f8dde9c26dd224626143f24d4d26f932925fa020/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/566c437afed2748d86e26e1455652bf5f5203fa50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ## Take the Magnitude (Abs) of Both Sides

# %% [markdown]
# ### Pre-requisites to allow auto-simplification to go through
#
# Establish that the $\alpha$ expression is in the Complex numbers.

# %%
_alpha_are_complex.instantiate({m:alpha_index})
# Out:
# Expression notebook is being updated for (b_{r} mod 2^{t}, {0 .. 2^{t} - 1})
# Expression notebook is being updated for (b_{r} mod 2^{t}) in {0 .. 2^{t} - 1}
# |- alpha_{b_{r} mod 2^{t}} in Complex

# %% [markdown]
# Prove that $\pi |\delta_{b_r}| \in \left(0, \frac{\pi}{2}\right)$ which is important to ensure the denominator is non-zero.  Along the way, we prove $2^t \pi |\delta_{b_r}| \leq \frac{\pi}{2}$ which will be useful for bounding the numerator.

# %%
angle = Mult(pi, Abs(_delta_b_round))
# Out:
# <strong id="angle">angle:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/c866f3cb7eed252f48431e7c0f2dc7629d38a5e50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
Less(zero, angle).prove()
# Out:
# {delta_{b_{r}} != 0} |- 0 < (pi * |delta_{b_{r}}|)

# %%
scaled_abs_bound = (Abs(_scaled_delta_b_round_in_interval.element).deduce_weak_upper_bound(frac(one, two))
         .inner_expr().lhs.simplify())
# Out:
# <strong id="scaled_abs_bound">scaled_abs_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/12de7a6448439c66cc30554aa6c5e660056c96a10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/e443c2ed837962a4bc357cb4c2cd7e1cb62a04860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Close enough to $2^t \pi |\delta_{b_r}| \leq \frac{\pi}{2}$ (the translation occurs automatically via canonical forms):

# %%
two_pow_t_times_angle__bound = scaled_abs_bound.left_mult_both_sides(pi)
# Out:
# <strong id="two_pow_t_times_angle__bound">two_pow_t_times_angle__bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/aaf974f5f11b8415b09a8fca4cbcdc015e6858d20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/6be77f7a589c310d97329c1ef60c581d55dd7a960/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_pow_t_bound = _two_pow_t.deduce_bound(_t_in_natural_pos.derive_element_lower_bound())
# Out:
# <strong id="two_pow_t_bound">two_pow_t_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/44cfc67bcc2c92ee1ae4b863e505ab7d055c9b490/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/56f63901cc70a6499a7f898886556ef05302a5900/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_pow_t_times_angle__bound.lhs.deduce_bound(greater(_two_pow_t, one))
# Out:
# {delta_{b_{r}} != 0} |- (pi * 2^{t} * |delta_{b_{r}}|) > (pi * |delta_{b_{r}}|)

# %%
Less(angle, frac(pi, two)).prove()
# Out:
# {delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) < (pi / 2)

# %% [markdown]
# ### Now take the absolute value on each side

# %%
with Mult.temporary_simplification_directives() as tmp_directives:
    # pull the 2^t to the front
    tmp_directives.order_key_fn = lambda factor : 0 if factor==_two_pow_t else 1
    _alpha_eq_04 = _alpha_eq_03.abs_both_sides()
# Out:
# <strong id="_alpha_eq_04">_alpha_eq_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/283ddacafd67b1621d89ce59c021b6497894ddc40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/a2fbd229598721bca872d923239d576f473888210/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ## Bound the numerator and the denominator

# %% [markdown]
# ### Bound the sin function in the _denominator_ utilizing $\sin{\theta} < \theta$ for $\theta > 0$

# %%
denominator_sin_bound = _alpha_eq_04.rhs.factors[1].denominator.deduce_linear_upper_bound()
# Out:
# <strong id="denominator_sin_bound">denominator_sin_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/7a1eb52749e685bb1ea5566383cc29950a52e6920/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/e1f660dca57a57165327b17ee045143ddfbb4f4a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Bound the sin function in the _numerator_ utilizing $\sin{\theta} \ge \frac{2}{\pi}(\theta)$ for $0 < \theta \le \frac{\pi}{2}$

# %%
numerator_sin_bound = _alpha_eq_04.rhs.factors[1].numerator.deduce_linear_lower_bound()
# Out:
# <strong id="numerator_sin_bound">numerator_sin_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/9ea024b075498aae212ec5ef0e88687df9a1dee40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/a5474068d31a83ffebdffbc0003377430d6a45ea0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Apply these numerator and denominator bounds

# %%
rhs_bound = _alpha_eq_04.rhs.deduce_bound([numerator_sin_bound, denominator_sin_bound])
# Out:
# <strong id="rhs_bound">rhs_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/ac1bd60cfa5d6cccae1bee5ea8d54c2c91e18bde0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/6113d08ddf9cf567991e36ed117746ed6bfed43e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_alpha_ineq = _alpha_eq_04.apply_transitivity(rhs_bound)
# Out:
# <strong id="_alpha_ineq">_alpha_ineq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/a3b9d54576d7ca75c1114e25790fdff284c4b7390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/1661539ca2577288e58d4a7da970be6726742b3c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__best_guarantee_delta_nonzero/3900b146a99d223d800c2ff6919c403eaf5bf3670/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ## Finally square both sides

# %%
_alpha_ineq.square_both_sides()
# Out:
# {delta_{b_{r}} != 0} |- |alpha_{b_{r} mod 2^{t}}|^{2} > (2 / pi)^{2}
# _best_guarantee_delta_nonzero may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._best_guarantee_delta_nonzero has been proven.
# 	step type	requirements	statement
# 0	deduction	1	|- (delta_{b_{r}} != 0) => (|alpha_{b_{r} mod 2^{t}}|^{2} > (4 / pi^{2}))
# 1	instantiation	426, 2, 3	{delta_{b_{r}} != 0} |- (4 / pi^{2}) < |alpha_{b_{r} mod 2^{t}}|^{2}
# 	P(_a) : _a < |alpha_{b_{r} mod 2^{t}}|^{2}, x : 4 / pi^{2}, y : (2 / pi)^{2}
# 2	instantiation	4, 603, 5, 6, 7, 8	{delta_{b_{r}} != 0} |- (2 / pi)^{2} < |alpha_{b_{r} mod 2^{t}}|^{2}
# 	a : 2, x : 2 / pi, y : |alpha_{b_{r} mod 2^{t}}|
# 3	instantiation	445, 9, 10, 11	|- (4 / pi^{2}) = (2 / pi)^{2}
# 	a : 4 / pi^{2}, b : 4 * pi^{-2}, c : 4 * pi^{-2}, d : (2 / pi)^{2}
# 4	conjecture		|- forall_{a, x, y in Real | 0 <= x < y, a > 0} (x^{a} < y^{a})
# 	proveit.numbers.exponentiation.exp_pos_less
# 5	instantiation	620, 542, 29	|- (2 / pi) in Real
# 	A : RealPos, B : Real, x : 2 / pi
# 6	instantiation	620, 334, 12	|- |alpha_{b_{r} mod 2^{t}}| in Real
# 	A : RealNonNeg, B : Real, x : |alpha_{b_{r} mod 2^{t}}|
# 7	instantiation	338, 13, 14	{delta_{b_{r}} != 0} |- (0 <= (2 / pi)) and ((2 / pi) < |alpha_{b_{r} mod 2^{t}}|)
# 	A : 0 <= (2 / pi), B : (2 / pi) < |alpha_{b_{r} mod 2^{t}}|
# 8	instantiation	574, 617	|- 2 > 0
# 	n : 2
# 9	instantiation	255, 521, 15, 16, 17*	|- (4 / pi^{2}) = (4 * pi^{-2})
# 	x : 4, y : pi^{2}
# 10	instantiation	568	|- (4 * pi^{-2}) = (4 * pi^{-2})
# 	x : 4 * pi^{-2}
# 11	instantiation	414, 18	|- (4 * pi^{-2}) = (2 / pi)^{2}
# 	x : (2 / pi)^{2}, y : 4 * pi^{-2}
# 12	instantiation	19, 35	|- |alpha_{b_{r} mod 2^{t}}| in RealNonNeg
# 	a : alpha_{b_{r} mod 2^{t}}
# 13	instantiation	20, 21	|- 0 <= (2 / pi)
# 	x : 2 / pi
# 14	instantiation	426, 22, 23	{delta_{b_{r}} != 0} |- |alpha_{b_{r} mod 2^{t}}| > (2 / pi)
# 	P(_a) : _a > (2 / pi), x : |alpha_{b_{r} mod 2^{t}}|, y : (1 / 2^{t}) * (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 15	instantiation	620, 602, 24	|- pi^{2} in Complex
# 	A : Real, B : Complex, x : pi^{2}
# 16	instantiation	25, 481, 594, 396	|- pi^{2} != 0
# 	a : pi, b : 2
# 17	instantiation	62, 481, 603, 566, 396, 26*	|- (pi^{2})^{-1} = pi^{-2}
# 	a : pi, b : 2, c : -1
# 18	instantiation	552, 27, 28	|- (2 / pi)^{2} = (4 * pi^{-2})
# 	x : (2 / pi)^{2}, y : (2 * pi^{-1})^{2}, z : 4 * pi^{-2}
# 19	conjecture		|- forall_{a in Complex} (|a| in RealNonNeg)
# 	proveit.numbers.absolute_value.abs_complex_closure
# 20	conjecture		|- forall_{x in RealNonNeg} (x >= 0)
# 	proveit.numbers.number_sets.real_numbers.nonneg_if_in_real_nonneg
# 21	instantiation	620, 380, 29	|- (2 / pi) in RealNonNeg
# 	A : RealPos, B : RealNonNeg, x : 2 / pi
# 22	instantiation	409, 84, 30, 31, 32, 117, 33*	{delta_{b_{r}} != 0} |- (2 / pi) < ((1 / 2^{t}) * (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)))
# 	a : 1 / 2^{t}, x : (2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|), y : sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)
# 23	instantiation	34, 35, 36, 37, 38*	{delta_{b_{r}} != 0} |- |alpha_{b_{r} mod 2^{t}}| = ((1 / 2^{t}) * (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)))
# 	x : alpha_{b_{r} mod 2^{t}}, y : (1 / 2^{t}) * ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))
# 24	instantiation	39, 508, 622	|- pi^{2} in Real
# 	a : pi, b : 2
# 25	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_not_eq_zero
# 26	instantiation	40, 594, 545, 579*	|- (2 * (-1)) = (-2)
# 	x : 2, y : 1
# 27	instantiation	561, 41	|- (2 / pi)^{2} = (2 * pi^{-1})^{2}
# 	f(_a) : _a^{2}, x : 2 / pi, y : 2 * pi^{-1}
# 28	instantiation	42, 594, 393, 617, 43*, 44*	|- (2 * pi^{-1})^{2} = (4 * pi^{-2})
# 	a : 2, b : pi^{-1}, n : 2
# 29	instantiation	45, 299, 541, 396	|- (2 / pi) in RealPos
# 	a : 2, b : pi
# 30	instantiation	46, 245, 317, 191	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)) in Real
# 	a : 2 * 2^{t} * |delta_{b_{r}}|, b : pi * |delta_{b_{r}}|
# 31	instantiation	46, 184, 241, 183	{delta_{b_{r}} != 0} |- (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)) in Real
# 	a : sin(2^{t} * pi * |delta_{b_{r}}|), b : sin(pi * |delta_{b_{r}}|)
# 32	instantiation	406, 47, 48	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)) < (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 	x : (2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|), y : (2 * 2^{t} * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|), z : sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)
# 33	instantiation	552, 49, 50	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = (2 / pi)
# 	x : (1 / 2^{t}) * ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), y : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|), z : 2 / pi
# 34	conjecture		|- forall_{x, y in Complex | x = y} (|x| = |y|)
# 	proveit.numbers.absolute_value.abs_eq
# 35	instantiation	51, 52	|- alpha_{b_{r} mod 2^{t}} in Complex
# 	m : b_{r} mod 2^{t}
# 36	instantiation	388, 56, 57	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))) in Complex
# 	a : 1 / 2^{t}, b : (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})
# 37	instantiation	456, 53, 54	{delta_{b_{r}} != 0} |- alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})))
# 	P(_a) : alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * _a), x : Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}, y : (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})
# 38	instantiation	488, 617, 55, 56, 57, 58*, 59*	{delta_{b_{r}} != 0} |- |(1 / 2^{t}) * ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))| = ((1 / 2^{t}) * (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)))
# 	n : 2, x : (1 / 2^{t}, (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))
# 39	conjecture		|- forall_{a in Real, b in Natural} (a^{b} in Real)
# 	proveit.numbers.exponentiation.exp_real_closure_nat_power
# 40	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 41	instantiation	255, 594, 481, 396	|- (2 / pi) = (2 * pi^{-1})
# 	x : 2, y : pi
# 42	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos} ((a * b)^{n} = (a^{n} * b^{n}))
# 	proveit.numbers.exponentiation.posnat_power_of_product
# 43	instantiation	445, 60, 61, 519	|- 2^{2} = 4
# 	a : 2^{2}, b : 2 *  ..0 ×.. *  2, c : 2 * 2, d : 4
# 44	instantiation	62, 481, 566, 603, 396, 63*	|- (pi^{-1})^{2} = pi^{-2}
# 	a : pi, b : -1, c : 2
# 45	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 46	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 47	instantiation	64, 275, 65, 362, 66	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)) > ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))
# 	a : 2 * 2^{t} * |delta_{b_{r}}|, x : sin(pi * |delta_{b_{r}}|), y : pi * |delta_{b_{r}}|
# 48	instantiation	67, 241, 245, 184, 68, 242	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)) <= (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 	a : sin(pi * |delta_{b_{r}}|), x : 2 * 2^{t} * |delta_{b_{r}}|, y : sin(2^{t} * pi * |delta_{b_{r}}|)
# 49	instantiation	552, 69, 70	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))
# 	x : (1 / 2^{t}) * ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), y : (1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|)), z : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)
# 50	instantiation	445, 71, 72, 73	{delta_{b_{r}} != 0} |- ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)) = (2 / pi)
# 	a : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|), b : (|delta_{b_{r}}| * 2) / (pi * |delta_{b_{r}}|), c : (|delta_{b_{r}}| * 2) / (|delta_{b_{r}}| * pi), d : 2 / pi
# 51	conjecture		|- forall_{m in {0 .. 2^{t} - 1}} (alpha_{m} in Complex)
# 	proveit.physics.quantum.QPE._alpha_are_complex
# 52	instantiation	74, 608, 585	|- (b_{r} mod 2^{t}) in {0 .. 2^{t} - 1}
# 	a : b_{r}, b : 2^{t}
# 53	instantiation	456, 75, 76, 77*	|- alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}))
# 	P(_a) : alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (_a - (b_{r} / 2^{t}))})^{k})), x : phase, y : (b_{r} / 2^{t}) + delta_{b_{r}}
# 54	instantiation	78, 148, 149, 79, 80, 81, 82*, 83*	{delta_{b_{r}} != 0} |- (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * delta_{b_{r}}})^{k}) = ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))
# 	x : e^{2 * pi * i * delta_{b_{r}}}, j : 0, k : 2^{t} - 1, i : k
# 55	instantiation	591	|- |(1 / 2^{t}, (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}}))| = |(1, ..., 2)|
# 	a : 1 / 2^{t}, b : (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})
# 56	instantiation	620, 602, 84	|- (1 / 2^{t}) in Complex
# 	A : Real, B : Complex, x : 1 / 2^{t}
# 57	instantiation	192, 87, 88, 89	{delta_{b_{r}} != 0} |- ((1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})) in Complex
# 	a : 1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}, b : 1 - e^{2 * pi * i * delta_{b_{r}}}
# 58	instantiation	514, 85	|- |1 / 2^{t}| = (1 / 2^{t})
# 	x : 1 / 2^{t}
# 59	instantiation	86, 87, 88, 89, 90*	{delta_{b_{r}} != 0} |- |(1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) / (1 - e^{2 * pi * i * delta_{b_{r}}})| = (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 	a : 1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}, b : 1 - e^{2 * pi * i * delta_{b_{r}}}
# 60	instantiation	91, 617, 594	|- 2^{2} = (2 *  ..0 ×.. *  2)
# 	n : 2, x : 2
# 61	instantiation	92, 622, 93, 577, 94	|- (2 *  ..0 ×.. *  2) =  \\ (2 * 2)
# 	n : 2, f(_b_{1}, ..., _b_{2}) : _b_{1} *  ... *  _b_{2}, x : (2, ..0 ×.., 2), y : (2, 2)
# 62	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 63	instantiation	544, 545, 594, 578*	|- ((-1) * 2) = (-2)
# 	x : 1, y : 2
# 64	conjecture		|- forall_{a, x, y in RealPos | x < y} ((a / x) > (a / y))
# 	proveit.numbers.division.strong_div_from_denom_bound__all_pos
# 65	instantiation	95, 241, 242	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) in RealPos
# 	a : sin(pi * |delta_{b_{r}}|)
# 66	instantiation	96, 362	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) < (pi * |delta_{b_{r}}|)
# 	theta : pi * |delta_{b_{r}}|
# 67	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 	proveit.numbers.division.weak_div_from_numer_bound__pos_denom
# 68	instantiation	97, 335, 98, 99*	{delta_{b_{r}} != 0} |- sin(2^{t} * pi * |delta_{b_{r}}|) >= (2 * 2^{t} * |delta_{b_{r}}|)
# 	theta : 2^{t} * pi * |delta_{b_{r}}|
# 69	instantiation	561, 100	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((2 * 2^{t} * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = ((1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|)))
# 	f(_a) : (1 / 2^{t}) * (_a / (pi * |delta_{b_{r}}|)), x : 2 * 2^{t} * |delta_{b_{r}}|, y : 2^{t} * (2 * |delta_{b_{r}}|)
# 70	instantiation	456, 101, 102	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))) = ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))
# 	P(_a) : ((1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))) = _a, x : (1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), y : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)
# 71	instantiation	561, 103	{delta_{b_{r}} != 0} |- ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)) = ((|delta_{b_{r}}| * 2) / (pi * |delta_{b_{r}}|))
# 	f(_a) : _a / (pi * |delta_{b_{r}}|), x : 2 * |delta_{b_{r}}|, y : |delta_{b_{r}}| * 2
# 72	instantiation	561, 104	{delta_{b_{r}} != 0} |- ((|delta_{b_{r}}| * 2) / (pi * |delta_{b_{r}}|)) = ((|delta_{b_{r}}| * 2) / (|delta_{b_{r}}| * pi))
# 	f(_a) : (|delta_{b_{r}}| * 2) / _a, x : pi * |delta_{b_{r}}|, y : |delta_{b_{r}}| * pi
# 73	instantiation	293, 105, 282, 594	{delta_{b_{r}} != 0} |- ((|delta_{b_{r}}| * 2) / (|delta_{b_{r}}| * pi)) = (2 / pi)
# 	x : |delta_{b_{r}}|, z : pi, y : 2
# 74	conjecture		|- forall_{a in Integer, b in NaturalPos} ((a mod b) in {0 .. b - 1})
# 	proveit.numbers.modular.mod_natpos_in_interval
# 75	instantiation	106, 608	|- alpha_{b_{r} mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (b_{r} / 2^{t}))})^{k}))
# 	m : b_{r}
# 76	instantiation	107, 608	|- phase = ((b_{r} / 2^{t}) + delta_{b_{r}})
# 	b : b_{r}
# 77	instantiation	552, 108, 109	|- (((b_{r} / 2^{t}) + delta_{b_{r}}) - (b_{r} / 2^{t})) = delta_{b_{r}}
# 	x : ((b_{r} / 2^{t}) + delta_{b_{r}}) - (b_{r} / 2^{t}), y : (b_{r} / 2^{t}) + delta_{b_{r}} - (b_{r} / 2^{t}), z : delta_{b_{r}}
# 78	conjecture		|- forall_{x in Complex | x != 1} [forall_{j, k in Integer | j <= k} ((Sum_{i = j}^{k} x^{i}) = ((x^{j} - x^{k + 1}) / (1 - x)))]
# 	proveit.numbers.summation.gen_finite_geom_sum
# 79	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 80	instantiation	110, 111, 596	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 81	instantiation	112, 113	|- 0 <= (2^{t} - 1)
# 	a : 2^{t}, b : 1
# 82	instantiation	451, 148	|- (e^{2 * pi * i * delta_{b_{r}}})^{0} = 1
# 	a : e^{2 * pi * i * delta_{b_{r}}}
# 83	instantiation	552, 114, 115	|- (e^{2 * pi * i * delta_{b_{r}}})^{(2^{t} - 1) + 1} = e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 	x : (e^{2 * pi * i * delta_{b_{r}}})^{(2^{t} - 1) + 1}, y : (e^{2 * pi * i * delta_{b_{r}}})^{2^{t}}, z : e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 84	instantiation	620, 612, 116	|- (1 / 2^{t}) in Real
# 	A : Rational, B : Real, x : 1 / 2^{t}
# 85	instantiation	550, 117	|- 0 <= (1 / 2^{t})
# 	x : 0, y : 1 / 2^{t}
# 86	conjecture		|- forall_{a, b in Complex | b != 0} (|a / b| = (|a| / |b|))
# 	proveit.numbers.absolute_value.abs_frac
# 87	instantiation	119, 545, 118	|- (1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) in Complex
# 	a : 1, b : -e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 88	instantiation	119, 545, 120	|- (1 - e^{2 * pi * i * delta_{b_{r}}}) in Complex
# 	a : 1, b : -e^{2 * pi * i * delta_{b_{r}}}
# 89	instantiation	121, 122	{delta_{b_{r}} != 0} |- (1 - e^{2 * pi * i * delta_{b_{r}}}) != 0
# 	a : 1, b : e^{2 * pi * i * delta_{b_{r}}}
# 90	instantiation	552, 123, 124	{delta_{b_{r}} != 0} |- (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|) = (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 	x : |1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|, y : (2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|)), z : sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|)
# 91	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} (x^{n} = (x *  x *  ..(n - 3) ×.. *  x))]
# 	proveit.numbers.exponentiation.exp_nat_pos_expansion
# 92	conjecture		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution_via_tuple
# 93	instantiation	125, 622	|- |(2, ..0 ×.., 2)| = |(1, ..., 2)|
# 	i : 2, f(_a) : 2
# 94	instantiation	126	|- (2, ..0 ×.., 2) = (2, 2)
# 	x : 2
# 95	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 96	conjecture		|- forall_{theta in RealPos} (sin(theta) < theta)
# 	proveit.trigonometry.sine_linear_bound_by_arg_pos
# 97	conjecture		|- forall_{theta in RealNonNeg | theta <= (pi / 2)} (sin(theta) >= ((2 * theta) / pi))
# 	proveit.trigonometry.sine_linear_bound_nonneg
# 98	instantiation	426, 127, 128	{delta_{b_{r}} != 0} |- (2^{t} * pi * |delta_{b_{r}}|) <= (pi / 2)
# 	P(_a) : (2^{t} * pi * |delta_{b_{r}}|) <= _a, x : pi / 2, y : (1 / 2) * pi
# 99	instantiation	552, 129, 130	{delta_{b_{r}} != 0} |- ((2 * (2^{t} * pi * |delta_{b_{r}}|)) / pi) = (2 * 2^{t} * |delta_{b_{r}}|)
# 	x : (2 * (2^{t} * pi * |delta_{b_{r}}|)) / pi, y : (2 * 2^{t} * pi * |delta_{b_{r}}|) / pi, z : 2 * 2^{t} * |delta_{b_{r}}|
# 100	instantiation	552, 131, 132	{delta_{b_{r}} != 0} |- (2 * 2^{t} * |delta_{b_{r}}|) = (2^{t} * (2 * |delta_{b_{r}}|))
# 	x : 2 * 2^{t} * |delta_{b_{r}}|, y : 2^{t} * 2 * |delta_{b_{r}}|, z : 2^{t} * (2 * |delta_{b_{r}}|)
# 101	instantiation	456, 133, 134	{delta_{b_{r}} != 0} |- ((1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))) = ((1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)))
# 	P(_a) : _a = ((1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))), x : (1 / (1 * 2^{t})) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|)), y : (1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))
# 102	instantiation	552, 135, 136	{delta_{b_{r}} != 0} |- ((1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))
# 	x : (1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), y : 1 * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), z : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)
# 103	instantiation	462, 594, 482	{delta_{b_{r}} != 0} |- (2 * |delta_{b_{r}}|) = (|delta_{b_{r}}| * 2)
# 	a : 2, b : |delta_{b_{r}}|
# 104	instantiation	462, 481, 482	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) = (|delta_{b_{r}}| * pi)
# 	a : pi, b : |delta_{b_{r}}|
# 105	instantiation	620, 496, 137	{delta_{b_{r}} != 0} |- |delta_{b_{r}}| in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : |delta_{b_{r}}|
# 106	conjecture		|- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# 	proveit.physics.quantum.QPE._alpha_m_mod_as_geometric_sum
# 107	conjecture		|- forall_{b in Integer} (phase = ((b / 2^{t}) + delta_{b}))
# 	proveit.physics.quantum.QPE._phase_from_best_with_delta_b
# 108	instantiation	533, 534, 622, 614, 535, 138, 166, 587, 139	|- (((b_{r} / 2^{t}) + delta_{b_{r}}) - (b_{r} / 2^{t})) =  \\ ((b_{r} / 2^{t}) + delta_{b_{r}} - (b_{r} / 2^{t}))
# 	i : 0, j : 2, k : 1, a : (), b : (b_{r} / 2^{t}, delta_{b_{r}}), c : (-(b_{r} / 2^{t}))
# 109	instantiation	140, 166, 587, 141	|- ((b_{r} / 2^{t}) + delta_{b_{r}} - (b_{r} / 2^{t})) = delta_{b_{r}}
# 	a : b_{r} / 2^{t}, b : b_{r} / 2^{t}, c : delta_{b_{r}}
# 110	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 111	instantiation	620, 142, 585	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 112	conjecture		|- forall_{a, b | a >= b} ((a - b) >= 0)
# 	proveit.numbers.addition.subtraction.nonneg_difference
# 113	instantiation	563, 585	|- 2^{t} >= 1
# 	n : 2^{t}
# 114	instantiation	561, 143	|- (e^{2 * pi * i * delta_{b_{r}}})^{(2^{t} - 1) + 1} = (e^{2 * pi * i * delta_{b_{r}}})^{2^{t}}
# 	f(_a) : (e^{2 * pi * i * delta_{b_{r}}})^{_a}, x : (2^{t} - 1) + 1, y : 2^{t}
# 115	instantiation	144, 289, 171, 539, 145*	|- (e^{2 * pi * i * delta_{b_{r}}})^{2^{t}} = e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 	a : e, b : 2 * pi * i * delta_{b_{r}}, c : 2^{t}
# 116	instantiation	620, 600, 146	|- (1 / 2^{t}) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2^{t}
# 117	instantiation	435, 146	|- (1 / 2^{t}) > 0
# 	q : 1 / 2^{t}
# 118	instantiation	336, 147	|- (-e^{2 * pi * i * delta_{b_{r}} * 2^{t}}) in Complex
# 	a : e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 119	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 120	instantiation	336, 148	|- (-e^{2 * pi * i * delta_{b_{r}}}) in Complex
# 	a : e^{2 * pi * i * delta_{b_{r}}}
# 121	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 122	instantiation	211, 149	{delta_{b_{r}} != 0} |- 1 != e^{2 * pi * i * delta_{b_{r}}}
# 	x : e^{2 * pi * i * delta_{b_{r}}}, y : 1
# 123	instantiation	575, 622, 150, 151, 152, 153	{delta_{b_{r}} != 0} |- (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| / |1 - e^{2 * pi * i * delta_{b_{r}}}|) =  \\ ((2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|)))
# 	n : 2, f(_a, _b) : _a / _b, x : (|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}|, |1 - e^{2 * pi * i * delta_{b_{r}}}|), y : (2 * sin(2^{t} * pi * |delta_{b_{r}}|), 2 * sin(pi * |delta_{b_{r}}|))
# 124	instantiation	293, 470, 154, 155	{delta_{b_{r}} != 0} |- ((2 * sin(2^{t} * pi * |delta_{b_{r}}|)) / (2 * sin(pi * |delta_{b_{r}}|))) = (sin(2^{t} * pi * |delta_{b_{r}}|) / sin(pi * |delta_{b_{r}}|))
# 	x : 2, z : sin(pi * |delta_{b_{r}}|), y : sin(2^{t} * pi * |delta_{b_{r}}|)
# 125	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 126	conjecture		|- forall_{x} ((x, ..0 ×.., x) = (x, x))
# 	proveit.numbers.numerals.decimals.reduce_2_repeats
# 127	instantiation	426, 408, 156	{delta_{b_{r}} != 0} |- (2^{t} * pi * |delta_{b_{r}}|) <= ((1 / 2) * pi)
# 	P(_a) : _a <= ((1 / 2) * pi), x : 2^{t} * pi * |delta_{b_{r}}|, y : pi * 2^{t} * |delta_{b_{r}}|
# 128	instantiation	255, 481, 594, 323, 157*	|- (pi / 2) = ((1 / 2) * pi)
# 	x : pi, y : 2
# 129	instantiation	561, 158	{delta_{b_{r}} != 0} |- ((2 * (2^{t} * pi * |delta_{b_{r}}|)) / pi) = ((2 * 2^{t} * pi * |delta_{b_{r}}|) / pi)
# 	f(_a) : _a / pi, x : 2 * (2^{t} * pi * |delta_{b_{r}}|), y : 2 * 2^{t} * pi * |delta_{b_{r}}|
# 130	instantiation	552, 159, 160	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * pi * |delta_{b_{r}}|) / pi) = (2 * 2^{t} * |delta_{b_{r}}|)
# 	x : (2 * 2^{t} * pi * |delta_{b_{r}}|) / pi, y : (2 * 2^{t} * |delta_{b_{r}}|) / 1, z : 2 * 2^{t} * |delta_{b_{r}}|
# 131	instantiation	371, 534, 614, 535, 594, 539, 482	{delta_{b_{r}} != 0} |- (2 * 2^{t} * |delta_{b_{r}}|) =  \\ (2^{t} * 2 * |delta_{b_{r}}|)
# 	i : 0, j : 1, k : 1, a : (), b : (2), c : 2^{t}, d : (|delta_{b_{r}}|)
# 132	instantiation	389, 614, 622, 534, 161, 535, 539, 594, 482	{delta_{b_{r}} != 0} |- (2^{t} * 2 * |delta_{b_{r}}|) =  \\ (2^{t} * (2 * |delta_{b_{r}}|))
# 	i : 1, j : 2, k : 0, a : (2^{t}), b : (2, |delta_{b_{r}}|), c : ()
# 133	instantiation	468, 545, 190, 469, 162, 163	{delta_{b_{r}} != 0} |- ((1 / (1 * 2^{t})) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))) = ((1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)))
# 	a : 1, d : 2 * |delta_{b_{r}}|, b : 1, c : 2^{t}, e : pi * |delta_{b_{r}}|
# 134	instantiation	561, 164	|- ((1 / (1 * 2^{t})) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|))) = ((1 / 2^{t}) * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|)))
# 	f(_a) : _a * ((2^{t} * (2 * |delta_{b_{r}}|)) / (pi * |delta_{b_{r}}|)), x : 1 / (1 * 2^{t}), y : 1 / 2^{t}
# 135	instantiation	561, 473	|- ((1 / 1) * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = (1 * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)))
# 	f(_a) : _a * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)), x : 1 / 1, y : 1
# 136	instantiation	592, 165	{delta_{b_{r}} != 0} |- (1 * ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))) = ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|))
# 	x : (2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)
# 137	instantiation	620, 449, 543	{delta_{b_{r}} != 0} |- |delta_{b_{r}}| in RealNonZero
# 	A : RealPos, B : RealNonZero, x : |delta_{b_{r}}|
# 138	instantiation	591	|- |(b_{r} / 2^{t}, delta_{b_{r}})| = |(1, ..., 2)|
# 	a : b_{r} / 2^{t}, b : delta_{b_{r}}
# 139	instantiation	336, 166	|- (-(b_{r} / 2^{t})) in Complex
# 	a : b_{r} / 2^{t}
# 140	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 141	instantiation	568	|- (b_{r} / 2^{t}) = (b_{r} / 2^{t})
# 	x : b_{r} / 2^{t}
# 142	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 143	instantiation	552, 167, 168	|- ((2^{t} - 1) + 1) = 2^{t}
# 	x : (2^{t} - 1) + 1, y : 2^{t} - 1 + 1, z : 2^{t}
# 144	conjecture		|- forall_{a in RealPos, b in Complex, c in Complex} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.complex_power_of_complex_power
# 145	instantiation	460, 534, 604, 614, 535, 169, 594, 481, 301, 587, 539	|- ((2 * pi * i * delta_{b_{r}}) * 2^{t}) =  \\ (2 * pi * i * delta_{b_{r}} * 2^{t})
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, delta_{b_{r}}), c : (2^{t})
# 146	instantiation	609, 610, 320	|- (1 / 2^{t}) in RationalPos
# 	a : 1, b : 2^{t}
# 147	instantiation	417, 235, 170	|- e^{2 * pi * i * delta_{b_{r}} * 2^{t}} in Complex
# 	a : e, b : 2 * pi * i * delta_{b_{r}} * 2^{t}
# 148	instantiation	417, 235, 171	|- e^{2 * pi * i * delta_{b_{r}}} in Complex
# 	a : e, b : 2 * pi * i * delta_{b_{r}}
# 149	instantiation	172, 178, 173, 180*	{delta_{b_{r}} != 0} |- e^{2 * pi * i * delta_{b_{r}}} != 1
# 	theta : 2 * pi * delta_{b_{r}}
# 150	instantiation	591	|- |(|1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}|, |1 - e^{2 * pi * i * delta_{b_{r}}}|)| = |(1, ..., 2)|
# 	a : |1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}|, b : |1 - e^{2 * pi * i * delta_{b_{r}}}|
# 151	instantiation	591	|- |(2 * sin(2^{t} * pi * |delta_{b_{r}}|), 2 * sin(pi * |delta_{b_{r}}|))| = |(1, ..., 2)|
# 	a : 2 * sin(2^{t} * pi * |delta_{b_{r}}|), b : 2 * sin(pi * |delta_{b_{r}}|)
# 152	instantiation	177, 410, 174, 179*, 175*, 176*	{delta_{b_{r}} != 0} |- |1 - e^{2 * pi * i * delta_{b_{r}} * 2^{t}}| = (2 * sin(2^{t} * pi * |delta_{b_{r}}|))
# 	a : 0, b : 2 * pi * delta_{b_{r}} * 2^{t}
# 153	instantiation	177, 410, 178, 179*, 180*, 181*	{delta_{b_{r}} != 0} |- |1 - e^{2 * pi * i * delta_{b_{r}}}| = (2 * sin(pi * |delta_{b_{r}}|))
# 	a : 0, b : 2 * pi * delta_{b_{r}}
# 154	instantiation	586, 182, 183	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) in ComplexNonZero
# 	x : sin(pi * |delta_{b_{r}}|)
# 155	instantiation	620, 602, 184	{delta_{b_{r}} != 0} |- sin(2^{t} * pi * |delta_{b_{r}}|) in Complex
# 	A : Real, B : Complex, x : sin(2^{t} * pi * |delta_{b_{r}}|)
# 156	instantiation	371, 534, 614, 535, 539, 481, 482	{delta_{b_{r}} != 0} |- (2^{t} * pi * |delta_{b_{r}}|) =  \\ (pi * 2^{t} * |delta_{b_{r}}|)
# 	i : 0, j : 1, k : 1, a : (), b : (2^{t}), c : pi, d : (|delta_{b_{r}}|)
# 157	instantiation	552, 185, 434	|- (pi * 2^{-1}) = ((1 / 2) * pi)
# 	x : pi * 2^{-1}, y : pi * (1 / 2), z : (1 / 2) * pi
# 158	instantiation	460, 614, 390, 534, 356, 535, 594, 539, 481, 482	{delta_{b_{r}} != 0} |- (2 * (2^{t} * pi * |delta_{b_{r}}|)) = (2 * 2^{t} * pi * |delta_{b_{r}}|)
# 	i : 1, j : 3, k : 0, a : (2), b : (2^{t}, pi, |delta_{b_{r}}|), c : ()
# 159	instantiation	552, 186, 187	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * pi * |delta_{b_{r}}|) / pi) = ((2 * 2^{t} * |delta_{b_{r}}|) / 1)
# 	x : (2 * 2^{t} * pi * |delta_{b_{r}}|) / pi, y : (pi * (2 * 2^{t} * |delta_{b_{r}}|)) / pi, z : (2 * 2^{t} * |delta_{b_{r}}|) / 1
# 160	instantiation	562, 215	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * |delta_{b_{r}}|) / 1) = (2 * 2^{t} * |delta_{b_{r}}|)
# 	x : 2 * 2^{t} * |delta_{b_{r}}|
# 161	instantiation	591	|- |(2, |delta_{b_{r}}|)| = |(1, ..., 2)|
# 	a : 2, b : |delta_{b_{r}}|
# 162	instantiation	620, 496, 188	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 163	instantiation	620, 496, 218	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : pi * |delta_{b_{r}}|
# 164	instantiation	561, 189	|- (1 / (1 * 2^{t})) = (1 / 2^{t})
# 	f(_a) : 1 / _a, x : 1 * 2^{t}, y : 2^{t}
# 165	instantiation	192, 190, 294, 191	{delta_{b_{r}} != 0} |- ((2 * |delta_{b_{r}}|) / (pi * |delta_{b_{r}}|)) in Complex
# 	a : 2 * |delta_{b_{r}}|, b : pi * |delta_{b_{r}}|
# 166	instantiation	192, 193, 539, 194	|- (b_{r} / 2^{t}) in Complex
# 	a : b_{r}, b : 2^{t}
# 167	instantiation	533, 534, 622, 614, 535, 195, 539, 537, 545	|- ((2^{t} - 1) + 1) =  \\ (2^{t} - 1 + 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t}, -1), c : (1)
# 168	instantiation	196, 545, 539, 540	|- (2^{t} - 1 + 1) = 2^{t}
# 	a : 1, b : 1, c : 2^{t}
# 169	instantiation	330	|- |(2, pi, i, delta_{b_{r}})| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : delta_{b_{r}}
# 170	instantiation	456, 197, 198	|- (2 * pi * i * delta_{b_{r}} * 2^{t}) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * delta_{b_{r}} * 2^{t}), y : 2 * pi * i * delta_{b_{r}} * 2^{t}
# 171	instantiation	456, 199, 200	|- (2 * pi * i * delta_{b_{r}}) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * delta_{b_{r}}), y : 2 * pi * i * delta_{b_{r}}
# 172	conjecture		|- forall_{theta in Real | (theta / (2 * pi)) not-in Integer} (e^{i * theta} != 1)
# 	proveit.numbers.exponentiation.unit_complex_polar_num_neq_one
# 173	instantiation	426, 201, 202	{delta_{b_{r}} != 0} |- ((2 * pi * delta_{b_{r}}) / (2 * pi)) not-in Integer
# 	P(_a) : _a not-in Integer, x : (2 * pi * delta_{b_{r}}) / (2 * pi), y : delta_{b_{r}}
# 174	instantiation	456, 374, 349	|- (2 * pi * delta_{b_{r}} * 2^{t}) in Real
# 	P(_a) : _a in Real, x : (2 * pi) * (delta_{b_{r}} * 2^{t}), y : 2 * pi * delta_{b_{r}} * 2^{t}
# 175	instantiation	414, 203	|- e^{i * (2 * pi * delta_{b_{r}} * 2^{t})} = e^{2 * pi * i * delta_{b_{r}} * 2^{t}}
# 	x : e^{2 * pi * i * delta_{b_{r}} * 2^{t}}, y : e^{i * (2 * pi * delta_{b_{r}} * 2^{t})}
# 176	instantiation	552, 204, 205	{delta_{b_{r}} != 0} |- (|0 - (2 * pi * delta_{b_{r}} * 2^{t})| / 2) = (2^{t} * pi * |delta_{b_{r}}|)
# 	x : |0 - (2 * pi * delta_{b_{r}} * 2^{t})| / 2, y : (2^{t} * 2 * pi * |delta_{b_{r}}|) / 2, z : 2^{t} * pi * |delta_{b_{r}}|
# 177	conjecture		|- forall_{a, b in Real} (|e^{i * a} - e^{i * b}| = (2 * sin(|a - b| / 2)))
# 	proveit.trigonometry.complex_unit_circle_chord_length
# 178	instantiation	456, 381, 361	|- (2 * pi * delta_{b_{r}}) in Real
# 	P(_a) : _a in Real, x : (2 * pi) * delta_{b_{r}}, y : 2 * pi * delta_{b_{r}}
# 179	instantiation	552, 206, 207	|- e^{i * 0} = 1
# 	x : e^{i * 0}, y : e^{0}, z : 1
# 180	instantiation	414, 208	|- e^{i * (2 * pi * delta_{b_{r}})} = e^{2 * pi * i * delta_{b_{r}}}
# 	x : e^{2 * pi * i * delta_{b_{r}}}, y : e^{i * (2 * pi * delta_{b_{r}})}
# 181	instantiation	552, 209, 210	{delta_{b_{r}} != 0} |- (|0 - (2 * pi * delta_{b_{r}})| / 2) = (pi * |delta_{b_{r}}|)
# 	x : |0 - (2 * pi * delta_{b_{r}})| / 2, y : (2 * pi * |delta_{b_{r}}|) / 2, z : pi * |delta_{b_{r}}|
# 182	instantiation	620, 602, 241	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) in Complex
# 	A : Real, B : Complex, x : sin(pi * |delta_{b_{r}}|)
# 183	instantiation	211, 212	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) != 0
# 	x : 0, y : sin(pi * |delta_{b_{r}}|)
# 184	instantiation	213, 313	{delta_{b_{r}} != 0} |- sin(2^{t} * pi * |delta_{b_{r}}|) in Real
# 	theta : 2^{t} * pi * |delta_{b_{r}}|
# 185	instantiation	561, 324	|- (pi * 2^{-1}) = (pi * (1 / 2))
# 	f(_a) : pi * _a, x : 2^{-1}, y : 1 / 2
# 186	instantiation	561, 214	{delta_{b_{r}} != 0} |- ((2 * 2^{t} * pi * |delta_{b_{r}}|) / pi) = ((pi * (2 * 2^{t} * |delta_{b_{r}}|)) / pi)
# 	f(_a) : _a / pi, x : 2 * 2^{t} * pi * |delta_{b_{r}}|, y : pi * (2 * 2^{t} * |delta_{b_{r}}|)
# 187	instantiation	293, 282, 469, 215, 216*	{delta_{b_{r}} != 0} |- ((pi * (2 * 2^{t} * |delta_{b_{r}}|)) / pi) = ((2 * 2^{t} * |delta_{b_{r}}|) / 1)
# 	x : pi, z : 1, y : 2 * 2^{t} * |delta_{b_{r}}|
# 188	instantiation	620, 524, 217	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 189	instantiation	592, 539	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 190	instantiation	388, 594, 482	{delta_{b_{r}} != 0} |- (2 * |delta_{b_{r}}|) in Complex
# 	a : 2, b : |delta_{b_{r}}|
# 191	instantiation	420, 218	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) != 0
# 	x : pi * |delta_{b_{r}}|
# 192	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 193	instantiation	620, 602, 219	|- b_{r} in Complex
# 	A : Real, B : Complex, x : b_{r}
# 194	instantiation	556, 585	|- 2^{t} != 0
# 	n : 2^{t}
# 195	instantiation	591	|- |(2^{t}, -1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : -1
# 196	conjecture		|- forall_{a, b, c in Complex | a = b} ((c - a + b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 197	instantiation	388, 400, 220	|- ((2 * pi) * (i * delta_{b_{r}} * 2^{t})) in Complex
# 	a : 2 * pi, b : i * delta_{b_{r}} * 2^{t}
# 198	instantiation	552, 221, 222	|- ((2 * pi) * (i * delta_{b_{r}} * 2^{t})) = (2 * pi * i * delta_{b_{r}} * 2^{t})
# 	x : (2 * pi) * (i * delta_{b_{r}} * 2^{t}), y : (2 * pi) * i * delta_{b_{r}} * 2^{t}, z : 2 * pi * i * delta_{b_{r}} * 2^{t}
# 199	instantiation	388, 400, 276	|- ((2 * pi) * (i * delta_{b_{r}})) in Complex
# 	a : 2 * pi, b : i * delta_{b_{r}}
# 200	instantiation	552, 223, 224	|- ((2 * pi) * (i * delta_{b_{r}})) = (2 * pi * i * delta_{b_{r}})
# 	x : (2 * pi) * (i * delta_{b_{r}}), y : (2 * pi) * i * delta_{b_{r}}, z : 2 * pi * i * delta_{b_{r}}
# 201	instantiation	225, 226, 227, 280, 278	{delta_{b_{r}} != 0} |- delta_{b_{r}} not-in Integer
# 	A : delta_{b_{r}} = 0, B : delta_{b_{r}} not-in Integer
# 202	instantiation	445, 228, 546, 229	|- ((2 * pi * delta_{b_{r}}) / (2 * pi)) = delta_{b_{r}}
# 	a : (2 * pi * delta_{b_{r}}) / (2 * pi), b : 1 * delta_{b_{r}}, c : delta_{b_{r}}, d : delta_{b_{r}}
# 203	instantiation	561, 230	|- e^{2 * pi * i * delta_{b_{r}} * 2^{t}} = e^{i * (2 * pi * delta_{b_{r}} * 2^{t})}
# 	f(_a) : e^{_a}, x : 2 * pi * i * delta_{b_{r}} * 2^{t}, y : i * (2 * pi * delta_{b_{r}} * 2^{t})
# 204	instantiation	561, 231	{delta_{b_{r}} != 0} |- (|0 - (2 * pi * delta_{b_{r}} * 2^{t})| / 2) = ((2^{t} * 2 * pi * |delta_{b_{r}}|) / 2)
# 	f(_a) : _a / 2, x : |0 - (2 * pi * delta_{b_{r}} * 2^{t})|, y : 2^{t} * 2 * pi * |delta_{b_{r}}|
# 205	instantiation	552, 232, 233	{delta_{b_{r}} != 0} |- ((2^{t} * 2 * pi * |delta_{b_{r}}|) / 2) = (2^{t} * pi * |delta_{b_{r}}|)
# 	x : (2^{t} * 2 * pi * |delta_{b_{r}}|) / 2, y : (2^{t} * pi * |delta_{b_{r}}|) / 1, z : 2^{t} * pi * |delta_{b_{r}}|
# 206	instantiation	561, 234	|- e^{i * 0} = e^{0}
# 	f(_a) : e^{_a}, x : i * 0, y : 0
# 207	instantiation	451, 235	|- e^{0} = 1
# 	a : e
# 208	instantiation	561, 236	|- e^{2 * pi * i * delta_{b_{r}}} = e^{i * (2 * pi * delta_{b_{r}})}
# 	f(_a) : e^{_a}, x : 2 * pi * i * delta_{b_{r}}, y : i * (2 * pi * delta_{b_{r}})
# 209	instantiation	561, 237	|- (|0 - (2 * pi * delta_{b_{r}})| / 2) = ((2 * pi * |delta_{b_{r}}|) / 2)
# 	f(_a) : _a / 2, x : |0 - (2 * pi * delta_{b_{r}})|, y : 2 * pi * |delta_{b_{r}}|
# 210	instantiation	552, 238, 239	{delta_{b_{r}} != 0} |- ((2 * pi * |delta_{b_{r}}|) / 2) = (pi * |delta_{b_{r}}|)
# 	x : (2 * pi * |delta_{b_{r}}|) / 2, y : (pi * |delta_{b_{r}}|) / 1, z : pi * |delta_{b_{r}}|
# 211	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 212	instantiation	240, 410, 241, 242	{delta_{b_{r}} != 0} |- 0 != sin(pi * |delta_{b_{r}}|)
# 	a : 0, b : sin(pi * |delta_{b_{r}}|)
# 213	conjecture		|- forall_{theta in Real} (sin(theta) in Real)
# 	proveit.trigonometry.real_closure
# 214	instantiation	552, 243, 244	{delta_{b_{r}} != 0} |- (2 * 2^{t} * pi * |delta_{b_{r}}|) = (pi * (2 * 2^{t} * |delta_{b_{r}}|))
# 	x : 2 * 2^{t} * pi * |delta_{b_{r}}|, y : pi * 2 * 2^{t} * |delta_{b_{r}}|, z : pi * (2 * 2^{t} * |delta_{b_{r}}|)
# 215	instantiation	620, 602, 245	{delta_{b_{r}} != 0} |- (2 * 2^{t} * |delta_{b_{r}}|) in Complex
# 	A : Real, B : Complex, x : 2 * 2^{t} * |delta_{b_{r}}|
# 216	instantiation	593, 481	|- (pi * 1) = pi
# 	x : pi
# 217	instantiation	620, 559, 246	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 218	instantiation	620, 449, 362	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : pi * |delta_{b_{r}}|
# 219	instantiation	620, 612, 247	|- b_{r} in Real
# 	A : Rational, B : Real, x : b_{r}
# 220	instantiation	456, 248, 249	|- (i * delta_{b_{r}} * 2^{t}) in Complex
# 	P(_a) : _a in Complex, x : (i * delta_{b_{r}}) * 2^{t}, y : i * delta_{b_{r}} * 2^{t}
# 221	instantiation	460, 614, 390, 534, 250, 535, 400, 301, 587, 539	|- ((2 * pi) * (i * delta_{b_{r}} * 2^{t})) =  \\ ((2 * pi) * i * delta_{b_{r}} * 2^{t})
# 	i : 1, j : 3, k : 0, a : (2 * pi), b : (i, delta_{b_{r}}, 2^{t}), c : ()
# 222	instantiation	460, 534, 622, 390, 535, 401, 250, 594, 481, 301, 587, 539	|- ((2 * pi) * i * delta_{b_{r}} * 2^{t}) =  \\ (2 * pi * i * delta_{b_{r}} * 2^{t})
# 	i : 0, j : 2, k : 3, a : (), b : (2, pi), c : (i, delta_{b_{r}}, 2^{t})
# 223	instantiation	460, 614, 622, 534, 277, 535, 400, 301, 587	|- ((2 * pi) * (i * delta_{b_{r}})) =  \\ ((2 * pi) * i * delta_{b_{r}})
# 	i : 1, j : 2, k : 0, a : (2 * pi), b : (i, delta_{b_{r}}), c : ()
# 224	instantiation	460, 534, 622, 535, 401, 277, 594, 481, 301, 587	|- ((2 * pi) * i * delta_{b_{r}}) =  \\ (2 * pi * i * delta_{b_{r}})
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : (i, delta_{b_{r}})
# 225	theorem		|- forall_{A, B in BOOLEAN | A or B, [not](A)} B
# 	proveit.logic.booleans.disjunction.right_if_not_left
# 226	instantiation	251, 252	{delta_{b_{r}} != 0} |- (delta_{b_{r}} = 0) in BOOLEAN
# 	A : delta_{b_{r}} = 0
# 227	instantiation	253, 254	|- (delta_{b_{r}} not-in Integer) in BOOLEAN
# 	A : delta_{b_{r}} = 0, B : delta_{b_{r}} not-in Integer
# 228	instantiation	255, 337, 400, 256, 257*	|- ((2 * pi * delta_{b_{r}}) / (2 * pi)) = (1 * delta_{b_{r}})
# 	x : 2 * pi * delta_{b_{r}}, y : 2 * pi
# 229	instantiation	568	|- delta_{b_{r}} = delta_{b_{r}}
# 	x : delta_{b_{r}}
# 230	instantiation	552, 258, 259	|- (2 * pi * i * delta_{b_{r}} * 2^{t}) = (i * (2 * pi * delta_{b_{r}} * 2^{t}))
# 	x : 2 * pi * i * delta_{b_{r}} * 2^{t}, y : i * 2 * pi * delta_{b_{r}} * 2^{t}, z : i * (2 * pi * delta_{b_{r}} * 2^{t})
# 231	instantiation	552, 260, 261	{delta_{b_{r}} != 0} |- |0 - (2 * pi * delta_{b_{r}} * 2^{t})| = (2^{t} * 2 * pi * |delta_{b_{r}}|)
# 	x : |0 - (2 * pi * delta_{b_{r}} * 2^{t})|, y : |-(2 * pi * delta_{b_{r}} * 2^{t})|, z : 2^{t} * 2 * pi * |delta_{b_{r}}|
# 232	instantiation	552, 262, 263	{delta_{b_{r}} != 0} |- ((2^{t} * 2 * pi * |delta_{b_{r}}|) / 2) = ((2^{t} * pi * |delta_{b_{r}}|) / 1)
# 	x : (2^{t} * 2 * pi * |delta_{b_{r}}|) / 2, y : (2 * (2^{t} * pi * |delta_{b_{r}}|)) / 2, z : (2^{t} * pi * |delta_{b_{r}}|) / 1
# 233	instantiation	562, 288	{delta_{b_{r}} != 0} |- ((2^{t} * pi * |delta_{b_{r}}|) / 1) = (2^{t} * pi * |delta_{b_{r}}|)
# 	x : 2^{t} * pi * |delta_{b_{r}}|
# 234	instantiation	463, 301	|- (i * 0) = 0
# 	x : i
# 235	instantiation	620, 602, 264	|- e in Complex
# 	A : Real, B : Complex, x : e
# 236	instantiation	552, 265, 266	|- (2 * pi * i * delta_{b_{r}}) = (i * (2 * pi * delta_{b_{r}}))
# 	x : 2 * pi * i * delta_{b_{r}}, y : i * 2 * pi * delta_{b_{r}}, z : i * (2 * pi * delta_{b_{r}})
# 237	instantiation	552, 267, 268	|- |0 - (2 * pi * delta_{b_{r}})| = (2 * pi * |delta_{b_{r}}|)
# 	x : |0 - (2 * pi * delta_{b_{r}})|, y : |-(2 * pi * delta_{b_{r}})|, z : 2 * pi * |delta_{b_{r}}|
# 238	instantiation	552, 269, 270	{delta_{b_{r}} != 0} |- ((2 * pi * |delta_{b_{r}}|) / 2) = ((pi * |delta_{b_{r}}|) / 1)
# 	x : (2 * pi * |delta_{b_{r}}|) / 2, y : (2 * (pi * |delta_{b_{r}}|)) / 2, z : (pi * |delta_{b_{r}}|) / 1
# 239	instantiation	562, 294	{delta_{b_{r}} != 0} |- ((pi * |delta_{b_{r}}|) / 1) = (pi * |delta_{b_{r}}|)
# 	x : pi * |delta_{b_{r}}|
# 240	conjecture		|- forall_{a, b in Real | a < b} (a != b)
# 	proveit.numbers.ordering.less_is_not_eq
# 241	instantiation	271, 410, 571, 273	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) in Real
# 	a : 0, b : 1, x : sin(pi * |delta_{b_{r}}|)
# 242	instantiation	272, 410, 571, 273	{delta_{b_{r}} != 0} |- 0 < sin(pi * |delta_{b_{r}}|)
# 	a : 0, b : 1, x : sin(pi * |delta_{b_{r}}|)
# 243	instantiation	371, 534, 622, 614, 535, 274, 594, 539, 481, 482	{delta_{b_{r}} != 0} |- (2 * 2^{t} * pi * |delta_{b_{r}}|) =  \\ (pi * 2 * 2^{t} * |delta_{b_{r}}|)
# 	i : 0, j : 2, k : 1, a : (), b : (2, 2^{t}), c : pi, d : (|delta_{b_{r}}|)
# 244	instantiation	389, 614, 390, 534, 298, 535, 481, 594, 539, 482	{delta_{b_{r}} != 0} |- (pi * 2 * 2^{t} * |delta_{b_{r}}|) =  \\ (pi * (2 * 2^{t} * |delta_{b_{r}}|))
# 	i : 1, j : 3, k : 0, a : (pi), b : (2, 2^{t}, |delta_{b_{r}}|), c : ()
# 245	instantiation	620, 542, 275	{delta_{b_{r}} != 0} |- (2 * 2^{t} * |delta_{b_{r}}|) in Real
# 	A : RealPos, B : Real, x : 2 * 2^{t} * |delta_{b_{r}}|
# 246	instantiation	620, 581, 585	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 247	instantiation	620, 618, 608	|- b_{r} in Rational
# 	A : Integer, B : Rational, x : b_{r}
# 248	instantiation	388, 276, 539	|- ((i * delta_{b_{r}}) * 2^{t}) in Complex
# 	a : i * delta_{b_{r}}, b : 2^{t}
# 249	instantiation	460, 534, 622, 614, 535, 277, 301, 587, 539	|- ((i * delta_{b_{r}}) * 2^{t}) =  \\ (i * delta_{b_{r}} * 2^{t})
# 	i : 0, j : 2, k : 1, a : (), b : (i, delta_{b_{r}}), c : (2^{t})
# 250	instantiation	416	|- |(i, delta_{b_{r}}, 2^{t})| = |(1, 2, ..., 3)|
# 	a : i, b : delta_{b_{r}}, c : 2^{t}
# 251	axiom		|- forall_{A | [not](A) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.negation.operand_is_bool
# 252	instantiation	279, 278	{delta_{b_{r}} != 0} |- [not](delta_{b_{r}} = 0) in BOOLEAN
# 	A : [not](delta_{b_{r}} = 0)
# 253	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 254	instantiation	279, 280	|- ((delta_{b_{r}} = 0) or (delta_{b_{r}} not-in Integer)) in BOOLEAN
# 	A : (delta_{b_{r}} = 0) or (delta_{b_{r}} not-in Integer)
# 255	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 256	instantiation	281, 622, 401, 470, 282	|- (2 * pi) != 0
# 	n : 2, a : (2, pi)
# 257	instantiation	552, 283, 284	|- ((2 * pi * delta_{b_{r}}) * (2 * pi)^{-1}) = (1 * delta_{b_{r}})
# 	x : (2 * pi * delta_{b_{r}}) * (2 * pi)^{-1}, y : (2 * pi * delta_{b_{r}}) * ((1 / 2) * pi^{-1}), z : 1 * delta_{b_{r}}
# 258	instantiation	371, 534, 622, 535, 401, 402, 594, 481, 301, 587, 539	|- (2 * pi * i * delta_{b_{r}} * 2^{t}) =  \\ (i * 2 * pi * delta_{b_{r}} * 2^{t})
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : i, d : (delta_{b_{r}}, 2^{t})
# 259	instantiation	389, 614, 604, 534, 309, 535, 301, 594, 481, 587, 539	|- (i * 2 * pi * delta_{b_{r}} * 2^{t}) =  \\ (i * (2 * pi * delta_{b_{r}} * 2^{t}))
# 	i : 1, j : 4, k : 0, a : (i), b : (2, pi, delta_{b_{r}}, 2^{t}), c : ()
# 260	instantiation	561, 285	|- |0 - (2 * pi * delta_{b_{r}} * 2^{t})| = |-(2 * pi * delta_{b_{r}} * 2^{t})|
# 	f(_a) : |_a|, x : 0 - (2 * pi * delta_{b_{r}} * 2^{t}), y : -(2 * pi * delta_{b_{r}} * 2^{t})
# 261	instantiation	511, 329, 286*	{delta_{b_{r}} != 0} |- |-(2 * pi * delta_{b_{r}} * 2^{t})| = (2^{t} * 2 * pi * |delta_{b_{r}}|)
# 	x : 2 * pi * delta_{b_{r}} * 2^{t}
# 262	instantiation	561, 287	{delta_{b_{r}} != 0} |- ((2^{t} * 2 * pi * |delta_{b_{r}}|) / 2) = ((2 * (2^{t} * pi * |delta_{b_{r}}|)) / 2)
# 	f(_a) : _a / 2, x : 2^{t} * 2 * pi * |delta_{b_{r}}|, y : 2 * (2^{t} * pi * |delta_{b_{r}}|)
# 263	instantiation	293, 470, 469, 288, 579*	{delta_{b_{r}} != 0} |- ((2 * (2^{t} * pi * |delta_{b_{r}}|)) / 2) = ((2^{t} * pi * |delta_{b_{r}}|) / 1)
# 	x : 2, z : 1, y : 2^{t} * pi * |delta_{b_{r}}|
# 264	instantiation	620, 542, 289	|- e in Real
# 	A : RealPos, B : Real, x : e
# 265	instantiation	371, 534, 622, 614, 535, 401, 594, 481, 301, 587	|- (2 * pi * i * delta_{b_{r}}) =  \\ (i * 2 * pi * delta_{b_{r}})
# 	i : 0, j : 2, k : 1, a : (), b : (2, pi), c : i, d : (delta_{b_{r}})
# 266	instantiation	389, 614, 390, 534, 368, 535, 301, 594, 481, 587	|- (i * 2 * pi * delta_{b_{r}}) =  \\ (i * (2 * pi * delta_{b_{r}}))
# 	i : 1, j : 3, k : 0, a : (i), b : (2, pi, delta_{b_{r}}), c : ()
# 267	instantiation	561, 290	|- |0 - (2 * pi * delta_{b_{r}})| = |-(2 * pi * delta_{b_{r}})|
# 	f(_a) : |_a|, x : 0 - (2 * pi * delta_{b_{r}}), y : -(2 * pi * delta_{b_{r}})
# 268	instantiation	511, 337, 291*	|- |-(2 * pi * delta_{b_{r}})| = (2 * pi * |delta_{b_{r}}|)
# 	x : 2 * pi * delta_{b_{r}}
# 269	instantiation	561, 292	{delta_{b_{r}} != 0} |- ((2 * pi * |delta_{b_{r}}|) / 2) = ((2 * (pi * |delta_{b_{r}}|)) / 2)
# 	f(_a) : _a / 2, x : 2 * pi * |delta_{b_{r}}|, y : 2 * (pi * |delta_{b_{r}}|)
# 270	instantiation	293, 470, 469, 294, 579*	{delta_{b_{r}} != 0} |- ((2 * (pi * |delta_{b_{r}}|)) / 2) = ((pi * |delta_{b_{r}}|) / 1)
# 	x : 2, z : 1, y : pi * |delta_{b_{r}}|
# 271	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 272	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 273	instantiation	295, 296	{delta_{b_{r}} != 0} |- sin(pi * |delta_{b_{r}}|) in (0,1]
# 	theta : pi * |delta_{b_{r}}|
# 274	instantiation	591	|- |(2, 2^{t})| = |(1, ..., 2)|
# 	a : 2, b : 2^{t}
# 275	instantiation	297, 390, 298, 299, 300, 543	{delta_{b_{r}} != 0} |- (2 * 2^{t} * |delta_{b_{r}}|) in RealPos
# 	n : 3, a : (2, 2^{t}, |delta_{b_{r}}|)
# 276	instantiation	388, 301, 587	|- (i * delta_{b_{r}}) in Complex
# 	a : i, b : delta_{b_{r}}
# 277	instantiation	591	|- |(i, delta_{b_{r}})| = |(1, ..., 2)|
# 	a : i, b : delta_{b_{r}}
# 278	instantiation	302, 588	{delta_{b_{r}} != 0} |- [not](delta_{b_{r}} = 0)
# 	x : delta_{b_{r}}, y : 0
# 279	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 280	instantiation	303, 304	|- (delta_{b_{r}} = 0) or (delta_{b_{r}} not-in Integer)
# 	b : b_{r}
# 281	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in ComplexNonZero} ((a_{1} *  a_{2} *  ... *  a_{n}) != 0)]
# 	proveit.numbers.multiplication.mult_not_eq_zero
# 282	instantiation	620, 496, 421	|- pi in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : pi
# 283	instantiation	561, 305	|- ((2 * pi * delta_{b_{r}}) * (2 * pi)^{-1}) = ((2 * pi * delta_{b_{r}}) * ((1 / 2) * pi^{-1}))
# 	f(_a) : (2 * pi * delta_{b_{r}}) * _a, x : (2 * pi)^{-1}, y : (1 / 2) * pi^{-1}
# 284	instantiation	552, 306, 307	|- ((2 * pi * delta_{b_{r}}) * ((1 / 2) * pi^{-1})) = (1 * delta_{b_{r}})
# 	x : (2 * pi * delta_{b_{r}}) * ((1 / 2) * pi^{-1}), y : 1 * pi * delta_{b_{r}} * pi^{-1}, z : 1 * delta_{b_{r}}
# 285	instantiation	437, 308	|- (0 - (2 * pi * delta_{b_{r}} * 2^{t})) = (-(2 * pi * delta_{b_{r}} * 2^{t}))
# 	a : -(2 * pi * delta_{b_{r}} * 2^{t})
# 286	instantiation	488, 557, 309, 594, 481, 587, 539, 310*	{delta_{b_{r}} != 0} |- |2 * pi * delta_{b_{r}} * 2^{t}| = (2^{t} * 2 * pi * |delta_{b_{r}}|)
# 	n : 4, x : (2, pi, delta_{b_{r}}, 2^{t})
# 287	instantiation	552, 311, 312	{delta_{b_{r}} != 0} |- (2^{t} * 2 * pi * |delta_{b_{r}}|) = (2 * (2^{t} * pi * |delta_{b_{r}}|))
# 	x : 2^{t} * 2 * pi * |delta_{b_{r}}|, y : 2 * 2^{t} * pi * |delta_{b_{r}}|, z : 2 * (2^{t} * pi * |delta_{b_{r}}|)
# 288	instantiation	620, 602, 313	{delta_{b_{r}} != 0} |- (2^{t} * pi * |delta_{b_{r}}|) in Complex
# 	A : Real, B : Complex, x : 2^{t} * pi * |delta_{b_{r}}|
# 289	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 290	instantiation	437, 314	|- (0 - (2 * pi * delta_{b_{r}})) = (-(2 * pi * delta_{b_{r}}))
# 	a : -(2 * pi * delta_{b_{r}})
# 291	instantiation	488, 315, 368, 594, 481, 587, 352*, 353*	|- |2 * pi * delta_{b_{r}}| = (2 * pi * |delta_{b_{r}}|)
# 	n : 3, x : (2, pi, delta_{b_{r}})
# 292	instantiation	389, 614, 622, 534, 333, 535, 594, 481, 482	{delta_{b_{r}} != 0} |- (2 * pi * |delta_{b_{r}}|) =  \\ (2 * (pi * |delta_{b_{r}}|))
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |delta_{b_{r}}|), c : ()
# 293	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 294	instantiation	620, 602, 317	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) in Complex
# 	A : Real, B : Complex, x : pi * |delta_{b_{r}}|
# 295	conjecture		|- forall_{theta in (0,pi)} (sin(theta) in (0,1])
# 	proveit.trigonometry.sine_pos_interval
# 296	instantiation	316, 410, 508, 317, 318	{delta_{b_{r}} != 0} |- (pi * |delta_{b_{r}}|) in (0,pi)
# 	a : 0, b : pi, x : pi * |delta_{b_{r}}|
# 297	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in RealPos} ((a_{1} *  a_{2} *  ... *  a_{n}) in RealPos)]
# 	proveit.numbers.multiplication.mult_real_pos_closure
# 298	instantiation	416	|- |(2, 2^{t}, |delta_{b_{r}}|)| = |(1, 2, ..., 3)|
# 	a : 2, b : 2^{t}, c : |delta_{b_{r}}|
# 299	instantiation	620, 319, 611	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 300	instantiation	620, 319, 320	|- 2^{t} in RealPos
# 	A : RationalPos, B : RealPos, x : 2^{t}
# 301	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 302	theorem		|- forall_{x, y | x != y} [not](x = y)
# ...
# 466	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 467	instantiation	552, 493, 494	|- (((1 * 2) + (2 * 1)) / (2 * 2)) = 1
# 	x : ((1 * 2) + (2 * 1)) / (2 * 2), y : 4 / 4, z : 1
# 468	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 469	instantiation	620, 496, 495	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 470	instantiation	620, 496, 497	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 471	instantiation	561, 498	|- ((1 / (1 * 2)) * ((2 * 1) / 1)) = ((1 / 2) * ((2 * 1) / 1))
# 	f(_a) : _a * ((2 * 1) / 1), x : 1 / (1 * 2), y : 1 / 2
# 472	instantiation	561, 499	|- ((1 / 2) * ((2 * 1) / 1)) = ((1 / 2) * 2)
# 	f(_a) : (1 / 2) * _a, x : (2 * 1) / 1, y : 2
# 473	instantiation	562, 545	|- (1 / 1) = 1
# 	x : 1
# 474	conjecture		|- forall_{a, b in Complex | a = b} ((a - b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_basic
# 475	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 476	instantiation	500, 567, 571	|- (2^{t} + 1) in Real
# 	a : 2^{t}, b : 1
# 477	instantiation	501, 603, 567, 571, 502, 503	|- 2 < (2^{t} + 1)
# 	a : 2, b : 2^{t}, c : 1
# 478	instantiation	504, 545, 594, 505	|- (2 - 1) = 1
# 	a : 1, b : 1, c : 2
# 479	instantiation	552, 506, 507	|- ((2^{t} + 1) - 1) = 2^{t}
# 	x : (2^{t} + 1) - 1, y : 2^{t} + 1 - 1, z : 2^{t}
# 480	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 1* b_{1} *  b_{2} *  ... *  b_{j}) = (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}))]
# 	proveit.numbers.multiplication.elim_one_any
# 481	instantiation	620, 602, 508	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 482	instantiation	620, 602, 509	{delta_{b_{r}} != 0} |- |delta_{b_{r}}| in Complex
# 	A : Real, B : Complex, x : |delta_{b_{r}}|
# 483	instantiation	561, 510	|- |(-1) * delta_{b_{r}}| = |-delta_{b_{r}}|
# 	f(_a) : |_a|, x : (-1) * delta_{b_{r}}, y : -delta_{b_{r}}
# 484	instantiation	511, 587	|- |-delta_{b_{r}}| = |delta_{b_{r}}|
# 	x : delta_{b_{r}}
# 485	conjecture		|- forall_{a, c | (-c) <= a, a <= c} (|a| <= c)
# 	proveit.numbers.absolute_value.weak_upper_bound
# 486	instantiation	512, 548, 573, 549	|- (-(1 / 2)) <= (2^{t} * delta_{b_{r}})
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 487	instantiation	550, 513	|- (2^{t} * delta_{b_{r}}) <= (1 / 2)
# 	x : 2^{t} * delta_{b_{r}}, y : 1 / 2
# 488	conjecture		|- forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in Complex} (|x_{1} *  x_{2} *  ... *  x_{n}| = (|x_{1}| *  |x_{2}| *  ... *  |x_{n}|))]
# 	proveit.numbers.absolute_value.abs_prod
# 489	instantiation	591	|- |(2^{t}, delta_{b_{r}})| = |(1, ..., 2)|
# 	a : 2^{t}, b : delta_{b_{r}}
# 490	instantiation	514, 515	|- |2^{t}| = 2^{t}
# 	x : 2^{t}
# 491	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 492	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 493	instantiation	575, 622, 516, 517, 518, 519	|- (((1 * 2) + (2 * 1)) / (2 * 2)) =  \\ (4 / 4)
# 	n : 2, f(_a, _b) : _a / _b, x : ((1 * 2) + (2 * 1), 2 * 2), y : (4, 4)
# 494	instantiation	520, 521, 522	|- (4 / 4) = 1
# 	x : 4
# 495	instantiation	620, 524, 523	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 496	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 497	instantiation	620, 524, 525	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 498	instantiation	561, 578	|- (1 / (1 * 2)) = (1 / 2)
# 	f(_a) : 1 / _a, x : 1 * 2, y : 2
# 499	instantiation	552, 526, 527	|- ((2 * 1) / 1) = 2
# 	x : (2 * 1) / 1, y : 2 / 1, z : 2
# 500	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 501	conjecture		|- forall_{a, b, c in Real | a <= b, 0 < c} (a < (b + c))
# 	proveit.numbers.ordering.less_eq_add_right_strong
# 502	instantiation	528, 603, 571, 529, 530, 531, 532*	|- 2 <= 2^{t}
# 	a : 2, x : 1, y : t
# 503	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 504	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((c - b) = a)
# 	proveit.numbers.addition.subtraction.subtract_from_add
# 505	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 506	instantiation	533, 534, 622, 614, 535, 536, 539, 545, 537	|- ((2^{t} + 1) - 1) =  \\ (2^{t} + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t}, 1), c : (-1)
# 507	instantiation	538, 545, 539, 540	|- (2^{t} + 1 - 1) = 2^{t}
# 	a : 1, b : 1, c : 2^{t}
# 508	instantiation	620, 542, 541	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 509	instantiation	620, 542, 543	{delta_{b_{r}} != 0} |- |delta_{b_{r}}| in Real
# 	A : RealPos, B : Real, x : |delta_{b_{r}}|
# 510	instantiation	544, 545, 587, 546*	|- ((-1) * delta_{b_{r}}) = (-delta_{b_{r}})
# 	x : 1, y : delta_{b_{r}}
# 511	conjecture		|- forall_{x in Complex} (|-x| = |x|)
# 	proveit.numbers.absolute_value.abs_even
# 512	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 513	instantiation	547, 548, 573, 549	|- (2^{t} * delta_{b_{r}}) < (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 514	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 515	instantiation	550, 551	|- 0 <= 2^{t}
# 	x : 0, y : 2^{t}
# 516	instantiation	591	|- |((1 * 2) + (2 * 1), 2 * 2)| = |(1, ..., 2)|
# 	a : (1 * 2) + (2 * 1), b : 2 * 2
# 517	instantiation	591	|- |(4, 4)| = |(1, ..., 2)|
# 	a : 4, b : 4
# 518	instantiation	552, 553, 554	|- ((1 * 2) + (2 * 1)) = 4
# 	x : (1 * 2) + (2 * 1), y : 2 + 2, z : 4
# 519	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 520	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 521	instantiation	620, 602, 555	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 522	instantiation	556, 557	|- 4 != 0
# 	n : 4
# 523	instantiation	620, 559, 558	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 524	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 525	instantiation	620, 559, 560	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 526	instantiation	561, 579	|- ((2 * 1) / 1) = (2 / 1)
# 	f(_a) : _a / 1, x : 2 * 1, y : 2
# 527	instantiation	562, 594	|- (2 / 1) = 2
# 	x : 2
# 528	conjecture		|- forall_{a, x, y in Real | a > 1, x <= y} (a^{x} <= a^{y})
# 	proveit.numbers.exponentiation.exp_monotonicity_large_base_less_eq
# 529	instantiation	583, 584, 564	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 530	conjecture		|- 1 < 2
# 	proveit.numbers.numerals.decimals.less_1_2
# 531	instantiation	563, 564	|- t >= 1
# 	n : t
# 532	instantiation	565, 594	|- 2^{1} = 2
# 	x : 2
# 533	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 534	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 535	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 536	instantiation	591	|- |(2^{t}, 1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : 1
# 537	instantiation	620, 602, 566	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 538	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 539	instantiation	620, 602, 567	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 540	instantiation	568	|- 1 = 1
# 	x : 1
# 541	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 542	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 543	instantiation	569, 570	{delta_{b_{r}} != 0} |- |delta_{b_{r}}| in RealPos
# 	a : delta_{b_{r}}
# 544	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 545	instantiation	620, 602, 571	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 546	instantiation	592, 587	|- (1 * delta_{b_{r}}) = delta_{b_{r}}
# 	x : delta_{b_{r}}
# 547	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 548	instantiation	572, 573	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 549	conjecture		|- (2^{t} * delta_{b_{r}}) in [-(1 / 2),1 / 2)
# 	proveit.physics.quantum.QPE._scaled_delta_b_round_in_interval
# 550	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 551	instantiation	574, 585	|- 2^{t} > 0
# 	n : 2^{t}
# 552	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 553	instantiation	575, 622, 576, 577, 578, 579	|- ((1 * 2) + (2 * 1)) =  \\ (2 + 2)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 2, 2 * 1), y : (2, 2)
# 554	conjecture		|- (2 + 2) = 4
# 	proveit.numbers.numerals.decimals.add_2_2
# 555	instantiation	620, 612, 580	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 556	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 557	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 558	instantiation	620, 581, 615	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 559	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 560	instantiation	620, 581, 617	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 561	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 562	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 563	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 564	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 565	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 566	instantiation	620, 612, 582	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 567	instantiation	583, 584, 585	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 568	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 569	conjecture		|- forall_{a in ComplexNonZero} (|a| in RealPos)
# 	proveit.numbers.absolute_value.abs_nonzero_closure
# 570	instantiation	586, 587, 588	{delta_{b_{r}} != 0} |- delta_{b_{r}} in ComplexNonZero
# 	x : delta_{b_{r}}
# 571	instantiation	620, 612, 589	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 572	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 573	instantiation	620, 612, 590	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 574	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 575	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 576	instantiation	591	|- |(1 * 2, 2 * 1)| = |(1, ..., 2)|
# 	a : 1 * 2, b : 2 * 1
# 577	instantiation	591	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 578	instantiation	592, 594	|- (1 * 2) = 2
# 	x : 2
# 579	instantiation	593, 594	|- (2 * 1) = 2
# 	x : 2
# 580	instantiation	620, 618, 595	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 581	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 582	instantiation	620, 618, 596	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 583	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 584	instantiation	597, 598	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 585	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 586	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 	proveit.numbers.number_sets.complex_numbers.nonzero_complex_is_complex_nonzero
# 587	instantiation	620, 602, 599	|- delta_{b_{r}} in Complex
# 	A : Real, B : Complex, x : delta_{b_{r}}
# 588	assumption		{delta_{b_{r}} != 0} |- delta_{b_{r}} != 0
# 589	instantiation	620, 618, 606	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 590	instantiation	620, 600, 601	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 591	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 592	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 593	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 594	instantiation	620, 602, 603	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 595	instantiation	620, 621, 604	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 596	instantiation	605, 606	|- (-1) in Integer
# 	a : 1
# 597	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 598	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 599	instantiation	607, 608	|- delta_{b_{r}} in Real
# 	b : b_{r}
# 600	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 601	instantiation	609, 610, 611	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 602	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 603	instantiation	620, 612, 613	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 604	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 605	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 606	instantiation	620, 621, 614	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 607	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 608	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
# 609	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 610	instantiation	620, 616, 615	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 611	instantiation	620, 616, 617	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 612	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 613	instantiation	620, 618, 619	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 614	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 615	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 616	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 617	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 618	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 619	instantiation	620, 621, 622	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 620	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 621	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 622	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
