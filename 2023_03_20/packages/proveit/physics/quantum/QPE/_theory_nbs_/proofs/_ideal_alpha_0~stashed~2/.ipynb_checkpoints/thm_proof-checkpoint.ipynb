# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_ideal_alpha_0">_ideal_alpha_0</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit import k, l, r, x
from proveit.numbers import zero, Mult
from proveit.numbers.number_sets.complex_numbers import exp_neg2pi_i_x
from proveit.physics.quantum.QPE import (
    _t_in_natural_pos, _two_pow_t, _ideal_phase_cond, _phase_is_real, _b, _alpha_l_eval, _best_def)

# %%
# %proving _ideal_alpha_0
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_ideal_alpha_0">_ideal_alpha_0:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/82e1ec23952984766e11891f1cef6c0fe459bcf90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/690aa89b04750f69b5ea1fb15fefa89a10b992ad0/dependencies.ipynb">dependencies</a>)<br>

# %%
_alpha_l_eval
# Out:
# |- forall_{l in Integer} (alpha_{l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (b MOD_ADD l)) / 2^{t})} * e^{2 * pi * i * phase * k}))))

# %%
_ideal_phase_cond.inner_expr().element.commute()
# Out:
# |- (2^{t} * phase) in {0 .. 2^{t} - 1}

# %%
_best_def
# Out:
# |- b = floor(phase * 2^{t})

# %%
b_eval = _best_def.inner_expr().rhs.simplify()
# Out:
# <strong id="b_eval">b_eval:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/c2e11f0115b482b75b2d7a7a31cd6896ea404ec00/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/1c332787f79e237f9706b36d922d2c64b250d2b80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Mult.change_simplification_directives(combine_exponents=False)

# %%
alpha0_1 = _alpha_l_eval.instantiate({l:zero}, replacements=[b_eval])
# Out:
# <strong id="alpha0_1">alpha0_1:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/a3f8488ec8e27872f076f46e2a3c0d3d56baa2be0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/3e633672e327a2046a97e8e2cab1b85dd9ef36e40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha0_2 = (alpha0_1.inner_expr().rhs.factors[1].summand
             .factors[0].exponent.operand.numerator.factors[-1].define())
# Out:
# <strong id="alpha0_2">alpha0_2:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/b92817db711230e6d39c999b7d07d0cb51e381050/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/905b6281456e6181815833c18fcee8a9a57286170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
exp_neg2pi_i_x
# Out:
# |- forall_{x, r in Real} (e^{(-(2 * pi * i * (x mod r))) / r} = e^{(-(2 * pi * i * x)) / r})

# %%
exp_neg2pi_i_x_inst = exp_neg2pi_i_x.instantiate({x:b_eval.rhs, r:_two_pow_t})
# Out:
# <strong id="exp_neg2pi_i_x_inst">exp_neg2pi_i_x_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/66f1de3faef96b9991e42ea1695fda0774287c680/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/5522034c547ddc78c8a6a6cb7d7a02ae237b624c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Mult.change_simplification_directives(combine_exponents=True)

# %%
# Why doesn't the replacement work here?
alpha0_3 = alpha0_2.inner_expr().rhs.factors[1].summand.common_power_extract(
    exp_factor=k, replacements=[exp_neg2pi_i_x_inst])
# Out:
# <strong id="alpha0_3">alpha0_3:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/b09f0c982081b74facb009bc16c4f17db83079d70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__ideal_alpha_0/9d7dce20bd515a1b915ba1659c765d25bd947ca90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
alpha0_3.inner_expr().rhs.factors[1].summand.base.operands[0].substitute(exp_neg2pi_i_x_inst)
# Out:
# |- alpha_{0} = 1
# _ideal_alpha_0 has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._ideal_alpha_0 has been proven.
# 	step type	requirements	statement
# 0	instantiation	32, 1, 2, 3*	|- alpha_{0} = 1
# 	P(_a) : alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (_a * e^{2 * pi * i * phase})^{k})), x : e^{-(2 * pi * i * phase)}, y : e^{-(2 * pi * i * phase)}
# 1	instantiation	4, 5, 6	|- alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}))
# 	P : alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}))), Q : alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}))
# 2	instantiation	190	|- e^{-(2 * pi * i * phase)} = e^{-(2 * pi * i * phase)}
# 	x : e^{-(2 * pi * i * phase)}
# 3	instantiation	159, 7, 8	|- ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k})) = 1
# 	x : (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}), y : (1 / 2^{t}) * 2^{t}, z : 1
# 4	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 5	instantiation	32, 9, 10, 11*	|- alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k})))
# 	P(_a) : alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * _a) / 2^{t})} * e^{2 * pi * i * phase * k}))), x : (2^{t} * phase) MOD_ADD 0, y : 2^{t} * phase
# 6	instantiation	185, 12, 13*, 42*	|- (alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k})))) = (alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k})))
# 	f(_a) : alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} _a(k))), x(k) : {e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., y(k) : {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}.
# 7	instantiation	185, 14	|- ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k})) = ((1 / 2^{t}) * 2^{t})
# 	f(_a) : (1 / 2^{t}) * _a, x : Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, y : 2^{t}
# 8	instantiation	32, 15, 16	|- ((1 / 2^{t}) * 2^{t}) = 1
# 	P(_a) : ((1 / 2^{t}) * 2^{t}) = _a, x : (1 / 1) * (1 / 1), y : 1
# 9	instantiation	17, 220, 18*	|- alpha_{0} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * ((2^{t} * phase) MOD_ADD 0)) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	l : 0
# 10	instantiation	19, 128, 220, 20*	|- ((2^{t} * phase) MOD_ADD 0) = (2^{t} * phase)
# 	a : 2^{t} * phase, b : 0
# 11	instantiation	159, 21, 22	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * (2^{t} * phase)) / 2^{t}) = (2 * pi * i * k * phase)
# 	x : (2 * pi * i * k * (2^{t} * phase)) / 2^{t}, y : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, z : 2 * pi * i * k * phase
# 12	modus ponens	23, 24	|- [k -> {e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}.]
# 13	instantiation	63, 213	{k in {0 .. 2^{t} - 1}} |- {e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. = (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k})
# 	a : e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}, Q : k in {0 .. 2^{t} - 1}
# 14	instantiation	159, 25, 26	|- (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}) = 2^{t}
# 	x : Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, y : Sum_{k = 0}^{2^{t} - 1} 1, z : 2^{t}
# 15	instantiation	32, 27, 28	|- ((1 / 2^{t}) * 2^{t}) = ((1 / 1) * (1 / 1))
# 	P(_a) : _a = ((1 / 1) * (1 / 1)), x : (1 / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (1 / 2^{t}) * 2^{t}
# 16	instantiation	142, 29, 30, 31	|- ((1 / 1) * (1 / 1)) = 1
# 	a : (1 / 1) * (1 / 1), b : 1 * (1 / 1), c : 1 * 1, d : 1
# 17	conjecture		|- forall_{l in Integer} (alpha_{l} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * (b MOD_ADD l)) / 2^{t})} * e^{2 * pi * i * phase * k}))))
# 	proveit.physics.quantum.QPE._alpha_l_eval
# 18	instantiation	32, 33, 34	|- b = (2^{t} * phase)
# 	P(_a) : b = _a, x : floor(phase * 2^{t}), y : 2^{t} * phase
# 19	axiom		|- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod 2^{t}))
# 	proveit.physics.quantum.QPE._mod_add_def
# 20	instantiation	159, 35, 36	|- (((2^{t} * phase) + 0) mod 2^{t}) = (2^{t} * phase)
# 	x : ((2^{t} * phase) + 0) mod 2^{t}, y : (2^{t} * phase) mod 2^{t}, z : 2^{t} * phase
# 21	instantiation	185, 37	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * (2^{t} * phase)) / 2^{t}) = ((2 * pi * i * k * 2^{t} * phase) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * k * (2^{t} * phase), y : 2 * pi * i * k * 2^{t} * phase
# 22	instantiation	159, 38, 39	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = (2 * pi * i * k * phase)
# 	x : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, y : (2 * pi * i * k * phase) / 1, z : 2 * pi * i * k * phase
# 23	instantiation	79, 241	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}) = (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k})] =>  \\ ([k -> {e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}, g(k) : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 24	generalization	40	|- forall_{k in {0 .. 2^{t} - 1}} ((e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}) = (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k})
# 25	instantiation	185, 41, 42*, 43*	|- (Sum_{k = 0}^{2^{t} - 1} (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}) = (Sum_{k = 0}^{2^{t} - 1} 1)
# 	f(_a) : Sum_{k = 0}^{2^{t} - 1} _a(k), x(k) : {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}., y(k) : {1 if k in {0 .. 2^{t} - 1}.
# 26	instantiation	44, 220, 221, 179, 45*	|- (Sum_{i = 0}^{2^{t} - 1} 1) = 2^{t}
# 	a : 0, b : 2^{t} - 1, x : 1
# 27	instantiation	46, 179, 74, 73	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 1) * (1 / 1))
# 	a : 1, d : 1, b : 1, c : 2^{t}, e : 1
# 28	instantiation	159, 47, 48	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * 2^{t})
# 	x : (1 / (1 * 2^{t})) * ((2^{t} * 1) / 1), y : (1 / 2^{t}) * ((2^{t} * 1) / 1), z : (1 / 2^{t}) * 2^{t}
# 29	instantiation	185, 49	|- ((1 / 1) * (1 / 1)) = (1 * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : 1 / 1, y : 1
# 30	instantiation	185, 49	|- (1 * (1 / 1)) = (1 * 1)
# 	f(_a) : 1 * _a, x : 1 / 1, y : 1
# 31	instantiation	127, 179	|- (1 * 1) = 1
# 	x : 1
# 32	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 33	axiom		|- b = floor(phase * 2^{t})
# 	proveit.physics.quantum.QPE._best_def
# 34	instantiation	159, 50, 51	|- floor(phase * 2^{t}) = (2^{t} * phase)
# 	x : floor(phase * 2^{t}), y : floor(2^{t} * phase), z : 2^{t} * phase
# 35	instantiation	185, 52	|- (((2^{t} * phase) + 0) mod 2^{t}) = ((2^{t} * phase) mod 2^{t})
# 	f(_a) : _a mod 2^{t}, x : (2^{t} * phase) + 0, y : 2^{t} * phase
# 36	instantiation	53, 147, 146	|- ((2^{t} * phase) mod 2^{t}) = (2^{t} * phase)
# 	L : 2^{t}, x : 2^{t} * phase
# 37	instantiation	54, 204, 182, 170, 111, 55, 171, 206, 207, 208, 153, 180, 209	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * (2^{t} * phase)) =  \\ (2 * pi * i * k * 2^{t} * phase)
# 	i : 4, j : 2, k : 0, a : (2, pi, i, k), b : (2^{t}, phase), c : ()
# 38	instantiation	159, 56, 57	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = ((2 * pi * i * k * phase) / 1)
# 	x : (2 * pi * i * k * 2^{t} * phase) / 2^{t}, y : (2^{t} * (2 * pi * i * k * phase)) / 2^{t}, z : (2 * pi * i * k * phase) / 1
# 39	instantiation	108, 75	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * phase) / 1) = (2 * pi * i * k * phase)
# 	x : 2 * pi * i * k * phase
# 40	instantiation	142, 58, 59, 60	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}) = (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}
# 	a : e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}, b : (e^{-(2 * pi * i * phase)})^{k} * e^{2 * pi * i * phase * k}, c : (e^{-(2 * pi * i * phase)})^{k} * (e^{2 * pi * i * phase})^{k}, d : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}
# 41	modus ponens	61, 62	|- [k -> {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {1 if k in {0 .. 2^{t} - 1}.]
# 42	instantiation	63, 213	{k in {0 .. 2^{t} - 1}} |- {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}. = (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}
# 	a : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, Q : k in {0 .. 2^{t} - 1}
# 43	instantiation	63, 213	{k in {0 .. 2^{t} - 1}} |- {1 if k in {0 .. 2^{t} - 1}. = 1
# 	a : 1, Q : k in {0 .. 2^{t} - 1}
# 44	conjecture		|- forall_{a, b in Integer} [forall_{x in Complex} ((Sum_{i = a}^{b} x) = ((b - a + 1) * x))]
# 	proveit.numbers.summation.trivial_sum
# 45	instantiation	159, 64, 107	|- (((2^{t} - 1) - 0 + 1) * 1) = 2^{t}
# 	x : ((2^{t} - 1) - 0 + 1) * 1, y : 2^{t} * 1, z : 2^{t}
# 46	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 47	instantiation	185, 65	|- ((1 / (1 * 2^{t})) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * ((2^{t} * 1) / 1))
# 	f(_a) : _a * ((2^{t} * 1) / 1), x : 1 / (1 * 2^{t}), y : 1 / 2^{t}
# 48	instantiation	185, 66	|- ((1 / 2^{t}) * ((2^{t} * 1) / 1)) = ((1 / 2^{t}) * 2^{t})
# 	f(_a) : (1 / 2^{t}) * _a, x : (2^{t} * 1) / 1, y : 2^{t}
# 49	instantiation	108, 179	|- (1 / 1) = 1
# 	x : 1
# 50	instantiation	185, 67	|- floor(phase * 2^{t}) = floor(2^{t} * phase)
# 	f(_a) : floor(_a), x : phase * 2^{t}, y : 2^{t} * phase
# 51	instantiation	68, 128	|- floor(2^{t} * phase) = (2^{t} * phase)
# 	x : 2^{t} * phase
# 52	instantiation	69, 70	|- ((2^{t} * phase) + 0) = (2^{t} * phase)
# 	a : 2^{t} * phase
# 53	conjecture		|- forall_{L in NaturalPos} [forall_{x in {0 .. L - 1}} ((x mod L) = x)]
# 	proveit.numbers.modular.int_mod_elimination
# 54	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 55	instantiation	191	|- |(2^{t}, phase)| = |(1, ..., 2)|
# 	a : 2^{t}, b : phase
# 56	instantiation	185, 71	{k in {0 .. 2^{t} - 1}} |- ((2 * pi * i * k * 2^{t} * phase) / 2^{t}) = ((2^{t} * (2 * pi * i * k * phase)) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * k * 2^{t} * phase, y : 2^{t} * (2 * pi * i * k * phase)
# 57	instantiation	72, 73, 74, 75, 107*	{k in {0 .. 2^{t} - 1}} |- ((2^{t} * (2 * pi * i * k * phase)) / 2^{t}) = ((2 * pi * i * k * phase) / 1)
# 	x : 2^{t}, z : 1, y : 2 * pi * i * k * phase
# 58	instantiation	185, 76	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * k * phase)} * e^{2 * pi * i * phase * k}) = ((e^{-(2 * pi * i * phase)})^{k} * e^{2 * pi * i * phase * k})
# 	f(_a) : _a * e^{2 * pi * i * phase * k}, x : e^{-(2 * pi * i * k * phase)}, y : (e^{-(2 * pi * i * phase)})^{k}
# 59	instantiation	185, 77	{k in {0 .. 2^{t} - 1}} |- ((e^{-(2 * pi * i * phase)})^{k} * e^{2 * pi * i * phase * k}) = ((e^{-(2 * pi * i * phase)})^{k} * (e^{2 * pi * i * phase})^{k})
# 	f(_a) : (e^{-(2 * pi * i * phase)})^{k} * _a, x : e^{2 * pi * i * phase * k}, y : (e^{2 * pi * i * phase})^{k}
# 60	instantiation	119, 78	{k in {0 .. 2^{t} - 1}} |- ((e^{-(2 * pi * i * phase)})^{k} * (e^{2 * pi * i * phase})^{k}) = (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}
# 	x : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, y : (e^{-(2 * pi * i * phase)})^{k} * (e^{2 * pi * i * phase})^{k}
# 61	instantiation	79, 241	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} = 1)] =>  \\ ([k -> {(e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {1 if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, g(k) : 1, Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 62	generalization	80	|- forall_{k in {0 .. 2^{t} - 1}} ((e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} = 1)
# 63	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 64	instantiation	185, 81	|- (((2^{t} - 1) - 0 + 1) * 1) = (2^{t} * 1)
# 	f(_a) : [*]_a, x : ((2^{t} - 1) - 0 + 1, 1), y : (2^{t}, 1)
# 65	instantiation	185, 82	|- (1 / (1 * 2^{t})) = (1 / 2^{t})
# 	f(_a) : 1 / _a, x : 1 * 2^{t}, y : 2^{t}
# 66	instantiation	159, 83, 84	|- ((2^{t} * 1) / 1) = 2^{t}
# 	x : (2^{t} * 1) / 1, y : 2^{t} / 1, z : 2^{t}
# 67	instantiation	85, 209, 180	|- (phase * 2^{t}) = (2^{t} * phase)
# 	a : phase, b : 2^{t}
# 68	conjecture		|- forall_{x in Integer} (floor(x) = x)
# 	proveit.numbers.rounding.floor_of_integer
# 69	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 70	instantiation	239, 217, 86	|- (2^{t} * phase) in Complex
# 	A : Real, B : Complex, x : 2^{t} * phase
# 71	instantiation	159, 87, 88	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * 2^{t} * phase) = (2^{t} * (2 * pi * i * k * phase))
# 	x : 2 * pi * i * k * 2^{t} * phase, y : 2^{t} * 2 * pi * i * k * phase, z : 2^{t} * (2 * pi * i * k * phase)
# 72	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 73	instantiation	239, 90, 89	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 74	instantiation	239, 90, 91	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 75	instantiation	203, 112, 113, 206, 207, 208, 153, 209	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * phase) in Complex
# 	n : 5, a : (2, pi, i, k, phase)
# 76	instantiation	159, 92, 93	{k in {0 .. 2^{t} - 1}} |- e^{-(2 * pi * i * k * phase)} = (e^{-(2 * pi * i * phase)})^{k}
# 	x : e^{-(2 * pi * i * k * phase)}, y : e^{-((2 * pi * i * phase) * k)}, z : (e^{-(2 * pi * i * phase)})^{k}
# 77	instantiation	159, 94, 95	{k in {0 .. 2^{t} - 1}} |- e^{2 * pi * i * phase * k} = (e^{2 * pi * i * phase})^{k}
# 	x : e^{2 * pi * i * phase * k}, y : e^{(2 * pi * i * phase) * k}, z : (e^{2 * pi * i * phase})^{k}
# 78	instantiation	96, 97, 98, 183, 99, 100	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} = ((e^{-(2 * pi * i * phase)})^{k} * (e^{2 * pi * i * phase})^{k})
# 	a : e^{-(2 * pi * i * phase)}, b : e^{2 * pi * i * phase}, c : k
# 79	conjecture		|- forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))]
# 	proveit.core_expr_types.lambda_maps.general_lambda_substitution
# 80	instantiation	159, 101, 102	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} = 1
# 	x : (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k}, y : 1^{k}, z : 1
# 81	instantiation	162, 236, 103, 104, 105, 168	|- ((2^{t} - 1) - 0 + 1, 1) = (2^{t}, 1)
# 	i : 2, a : ((2^{t} - 1) - 0 + 1, 1), b : (2^{t}, 1)
# 82	instantiation	106, 180	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 83	instantiation	185, 107	|- ((2^{t} * 1) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 2^{t} * 1, y : 2^{t}
# 84	instantiation	108, 180	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 85	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 86	instantiation	239, 200, 109	|- (2^{t} * phase) in Real
# 	A : Rational, B : Real, x : 2^{t} * phase
# 87	instantiation	110, 170, 204, 175, 171, 111, 206, 207, 208, 153, 180, 209	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * 2^{t} * phase) =  \\ (2^{t} * 2 * pi * i * k * phase)
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, k), c : 2^{t}, d : (phase)
# 88	instantiation	152, 175, 112, 170, 113, 171, 180, 206, 207, 208, 153, 209	{k in {0 .. 2^{t} - 1}} |- (2^{t} * 2 * pi * i * k * phase) =  \\ (2^{t} * (2 * pi * i * k * phase))
# 	i : 1, j : 5, k : 0, a : (2^{t}), b : (2, pi, i, k, phase), c : ()
# 89	instantiation	239, 115, 114	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 90	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 91	instantiation	239, 115, 116	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 92	instantiation	185, 117	{k in {0 .. 2^{t} - 1}} |- e^{-(2 * pi * i * k * phase)} = e^{-((2 * pi * i * phase) * k)}
# 	f(_a) : e^{-_a}, x : 2 * pi * i * k * phase, y : (2 * pi * i * phase) * k
# 93	instantiation	119, 118	{k in {0 .. 2^{t} - 1}} |- e^{-((2 * pi * i * phase) * k)} = (e^{-(2 * pi * i * phase)})^{k}
# 	x : (e^{-(2 * pi * i * phase)})^{k}, y : e^{-((2 * pi * i * phase) * k)}
# 94	instantiation	185, 134	{k in {0 .. 2^{t} - 1}} |- e^{2 * pi * i * phase * k} = e^{(2 * pi * i * phase) * k}
# 	f(_a) : e^{_a}, x : 2 * pi * i * phase * k, y : (2 * pi * i * phase) * k
# 95	instantiation	119, 120	{k in {0 .. 2^{t} - 1}} |- e^{(2 * pi * i * phase) * k} = (e^{2 * pi * i * phase})^{k}
# 	x : (e^{2 * pi * i * phase})^{k}, y : e^{(2 * pi * i * phase) * k}
# 96	conjecture		|- forall_{a in Complex, b in Complex, c in Real | a != 0, b != 0} ((a * b)^{c} = (a^{c} * b^{c}))
# 	proveit.numbers.exponentiation.real_power_of_product
# 97	instantiation	121, 188, 139	|- e^{-(2 * pi * i * phase)} in Complex
# 	a : e, b : -(2 * pi * i * phase)
# 98	instantiation	121, 188, 197	|- e^{2 * pi * i * phase} in Complex
# 	a : e, b : 2 * pi * i * phase
# 99	instantiation	122, 188, 139, 137	|- e^{-(2 * pi * i * phase)} != 0
# 	a : e, b : -(2 * pi * i * phase)
# 100	instantiation	122, 188, 197, 137	|- e^{2 * pi * i * phase} != 0
# 	a : e, b : 2 * pi * i * phase
# 101	instantiation	185, 123	|- (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase})^{k} = 1^{k}
# 	f(_a) : _a^{k}, x : e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase}, y : 1
# 102	instantiation	124, 153	{k in {0 .. 2^{t} - 1}} |- 1^{k} = 1
# 	x : k
# 103	instantiation	191	|- |((2^{t} - 1) - 0 + 1, 1)| = |(1, ..., 2)|
# 	a : (2^{t} - 1) - 0 + 1, b : 1
# 104	instantiation	191	|- |(2^{t}, 1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : 1
# 105	instantiation	159, 125, 126	|- ((2^{t} - 1) - 0 + 1) = 2^{t}
# 	x : (2^{t} - 1) - 0 + 1, y : (2^{t} - 1) + 0 + 1, z : 2^{t}
# 106	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 107	instantiation	127, 180	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 108	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 109	instantiation	239, 211, 128	|- (2^{t} * phase) in Rational
# 	A : Integer, B : Rational, x : 2^{t} * phase
# 110	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 111	instantiation	214	|- |(2, pi, i, k)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : k
# 112	conjecture		|- 5 in Natural
# 	proveit.numbers.numerals.decimals.nat5
# 113	instantiation	129	|- |(2, pi, i, k, phase)| = |(1, 2, ..., 5)|
# 	a : 2, b : pi, c : i, d : k, e : phase
# 114	instantiation	239, 131, 130	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 115	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 116	instantiation	239, 131, 132	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 117	instantiation	159, 133, 134	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * phase) = ((2 * pi * i * phase) * k)
# 	x : 2 * pi * i * k * phase, y : 2 * pi * i * phase * k, z : (2 * pi * i * phase) * k
# 118	instantiation	135, 188, 197, 137	{k in {0 .. 2^{t} - 1}} |- (e^{-(2 * pi * i * phase)})^{k} = e^{-((2 * pi * i * phase) * k)}
# 	a : e, b : 2 * pi * i * phase
# 119	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 120	instantiation	136, 188, 197, 137	{k in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase})^{k} = e^{(2 * pi * i * phase) * k}
# 	a : e, b : 2 * pi * i * phase
# 121	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 122	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_not_eq_zero
# 123	instantiation	138, 210, 139, 197, 140*	|- (e^{-(2 * pi * i * phase)} * e^{2 * pi * i * phase}) = 1
# 	a : e, b : -(2 * pi * i * phase), c : 2 * pi * i * phase
# 124	conjecture		|- forall_{x in Complex} (1^{x} = 1)
# 	proveit.numbers.exponentiation.exponentiated_one
# 125	instantiation	185, 141	|- ((2^{t} - 1) - 0 + 1) = ((2^{t} - 1) + 0 + 1)
# 	f(_a) : [+]_a, x : (2^{t} - 1, -0, 1), y : (2^{t} - 1, 0, 1)
# 126	instantiation	142, 143, 144, 145	|- ((2^{t} - 1) + 0 + 1) = 2^{t}
# 	a : (2^{t} - 1) + 0 + 1, b : 2^{t} - 1 + 0 + 1, c : 2^{t} - 1 + 1, d : 2^{t}
# 127	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 128	instantiation	239, 212, 146	|- (2^{t} * phase) in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : 2^{t} * phase
# 129	conjecture		|- forall_{a, b, c, d, e} (|(a, b, c, d, e)| = |(1, 2, ..., 5)|)
# 	proveit.numbers.numerals.decimals.tuple_len_5_typical_eq
# 130	instantiation	239, 148, 147	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 131	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 132	instantiation	239, 148, 241	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 133	instantiation	149, 150, 175, 170, 151, 171, 206, 207, 208, 153, 209	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * k * phase) =  \\ (2 * pi * i * phase * k)
# 	i : 3, j : 1, k : 0, a : (2, pi, i), b : k, c : (phase), d : ()
# 134	instantiation	152, 170, 204, 175, 171, 205, 206, 207, 208, 209, 153	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * phase * k) =  \\ ((2 * pi * i * phase) * k)
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, phase), c : (k)
# 135	instantiation	154, 202	{k in {0 .. 2^{t} - 1}} |- forall_{a, b in Complex | a != 0} ((a^{-b})^{k} = a^{-(b * k)})
# 	n : k
# 136	instantiation	155, 202	{k in {0 .. 2^{t} - 1}} |- forall_{a, b in Complex | a != 0} ((a^{b})^{k} = a^{b * k})
# 	n : k
# 137	instantiation	156, 157	|- e != 0
# 	x : e
# 138	conjecture		|- forall_{a in RealPos, b in Complex, c in Complex} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_complex_powers
# 139	instantiation	158, 197	|- (-(2 * pi * i * phase)) in Complex
# 	a : 2 * pi * i * phase
# 140	instantiation	159, 160, 161	|- e^{-(2 * pi * i * phase) + (2 * pi * i * phase)} = 1
# 	x : e^{-(2 * pi * i * phase) + (2 * pi * i * phase)}, y : e^{0}, z : 1
# 141	instantiation	162, 163, 164, 165, 166, 167, 168	|- (2^{t} - 1, -0, 1) = (2^{t} - 1, 0, 1)
# 	i : 3, a : (2^{t} - 1, -0, 1), b : (2^{t} - 1, 0, 1)
# 142	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 143	instantiation	169, 170, 182, 171, 176, 172, 180, 177, 173, 179	|- ((2^{t} - 1) + 0 + 1) =  \\ (2^{t} - 1 + 0 + 1)
# 	i : 0, j : 2, k : 2, a : (), b : (2^{t}, -1), c : (0, 1)
# 144	instantiation	174, 182, 175, 176, 180, 177, 179	|- (2^{t} - 1 + 0 + 1) = (2^{t} - 1 + 1)
# 	i : 2, j : 1, a : (2^{t}, -1), b : (1)
# 145	instantiation	178, 179, 180	|- (2^{t} - 1 + 1) = 2^{t}
# 	a : 1, b : 2^{t}
# 146	axiom		|- (2^{t} * phase) in {0 .. 2^{t} - 1}
# 	proveit.physics.quantum.QPE._ideal_phase_cond
# 147	instantiation	181, 182, 233	|- 2^{t} in NaturalPos
# 	a : 2, b : t
# 148	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 149	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* c_{1} *  c_{2} *  ... *  c_{j} * b* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.rightward_commutation
# 150	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 151	instantiation	189	|- |(2, pi, i)| = |(1, 2, ..., 3)|
# 	a : 2, b : pi, c : i
# 152	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 153	instantiation	239, 217, 183	{k in {0 .. 2^{t} - 1}} |- k in Complex
# 	A : Real, B : Complex, x : k
# 154	conjecture		|- forall_{n in Integer} [forall_{a, b in Complex | a != 0} ((a^{-b})^{n} = a^{-(b * n)})]
# 	proveit.numbers.exponentiation.int_exp_of_neg_exp
# 155	conjecture		|- forall_{n in Integer} [forall_{a, b in Complex | a != 0} ((a^{b})^{n} = a^{b * n})]
# 	proveit.numbers.exponentiation.int_exp_of_exp
# 156	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 157	instantiation	239, 184, 210	|- e in RealNonZero
# 	A : RealPos, B : RealNonZero, x : e
# 158	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 159	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 160	instantiation	185, 186	|- e^{-(2 * pi * i * phase) + (2 * pi * i * phase)} = e^{0}
# 	f(_a) : e^{_a}, x : -(2 * pi * i * phase) + (2 * pi * i * phase), y : 0
# 161	instantiation	187, 188	|- e^{0} = 1
# 	a : e
# 162	conjecture		|- forall_{i in NaturalPos} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{i} | (a_{1} = b_{1}), (a_{2} = b_{2}), ..., (a_{i} = b_{i})} ((a_{1}, a_{2}, ..., a_{i}) = (b_{1}, b_{2}, ..., b_{i}))]
# 	proveit.core_expr_types.tuples.tuple_eq_via_elem_eq
# 163	conjecture		|- 3 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat3
# 164	instantiation	189	|- |(2^{t} - 1, -0, 1)| = |(1, 2, ..., 3)|
# 	a : 2^{t} - 1, b : -0, c : 1
# 165	instantiation	189	|- |(2^{t} - 1, 0, 1)| = |(1, 2, ..., 3)|
# 	a : 2^{t} - 1, b : 0, c : 1
# 166	instantiation	190	|- (2^{t} - 1) = (2^{t} - 1)
# 	x : 2^{t} - 1
# 167	conjecture		|- (-0) = 0
# 	proveit.numbers.negation.negated_zero
# 168	instantiation	190	|- 1 = 1
# 	x : 1
# 169	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 170	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 171	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 172	instantiation	191	|- |(0, 1)| = |(1, ..., 2)|
# 	a : 0, b : 1
# 173	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 174	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
# 	proveit.numbers.addition.elim_zero_any
# 175	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 176	instantiation	191	|- |(2^{t}, -1)| = |(1, ..., 2)|
# 	a : 2^{t}, b : -1
# 177	instantiation	239, 217, 192	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 178	conjecture		|- forall_{a, b in Complex} ((b - a + a) = b)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_32
# 179	instantiation	239, 217, 193	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 180	instantiation	239, 217, 194	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 181	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 182	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 183	instantiation	239, 200, 195	{k in {0 .. 2^{t} - 1}} |- k in Real
# 	A : Rational, B : Real, x : k
# 184	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 185	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 186	instantiation	196, 197	|- (-(2 * pi * i * phase) + (2 * pi * i * phase)) = 0
# 	a : 2 * pi * i * phase
# 187	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 	proveit.numbers.exponentiation.exp_zero_eq_one
# 188	instantiation	239, 217, 198	|- e in Complex
# 	A : Real, B : Complex, x : e
# 189	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 190	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 191	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 192	instantiation	239, 200, 199	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 193	instantiation	222, 223, 241	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 194	instantiation	239, 200, 201	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 195	instantiation	239, 211, 202	{k in {0 .. 2^{t} - 1}} |- k in Rational
# 	A : Integer, B : Rational, x : k
# 196	conjecture		|- forall_{a in Complex} ((-a + a) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_reverse
# 197	instantiation	203, 204, 205, 206, 207, 208, 209	|- (2 * pi * i * phase) in Complex
# 	n : 4, a : (2, pi, i, phase)
# 198	instantiation	239, 224, 210	|- e in Real
# 	A : RealPos, B : Real, x : e
# 199	instantiation	239, 211, 228	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 200	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 201	instantiation	239, 211, 227	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 202	instantiation	239, 212, 213	{k in {0 .. 2^{t} - 1}} |- k in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : k
# 203	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} ((a_{1} *  a_{2} *  ... *  a_{n}) in Complex)]
# 	proveit.numbers.multiplication.mult_complex_closure
# 204	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 205	instantiation	214	|- |(2, pi, i, phase)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : phase
# 206	instantiation	239, 217, 215	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 207	instantiation	239, 217, 216	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 208	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 209	instantiation	239, 217, 218	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 210	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 211	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 212	instantiation	219, 220, 221	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 213	assumption		{k in {0 .. 2^{t} - 1}} |- k in {0 .. 2^{t} - 1}
# 214	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, 2, ..., 4)|)
# 	proveit.numbers.numerals.decimals.tuple_len_4_typical_eq
# 215	instantiation	222, 223, 236	|- 2 in Real
# 	A : NaturalPos, B : Real, x : 2
# 216	instantiation	239, 224, 225	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 217	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 218	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 219	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 220	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 221	instantiation	226, 227, 228	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 222	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 223	instantiation	229, 230	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 224	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 225	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 226	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 227	instantiation	231, 232, 233	|- 2^{t} in Integer
# 	a : 2, b : t
# 228	instantiation	234, 235	|- (-1) in Integer
# 	a : 1
# 229	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 230	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 231	conjecture		|- forall_{a in Integer, b in Natural} (a^{b} in Integer)
# 	proveit.numbers.exponentiation.exp_int_closure
# 232	instantiation	239, 240, 236	|- 2 in Integer
# 	A : NaturalPos, B : Integer, x : 2
# 233	instantiation	239, 237, 238	|- t in Natural
# 	A : NaturalPos, B : Natural, x : t
# 234	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 235	instantiation	239, 240, 241	|- 1 in Integer
# 	A : NaturalPos, B : Integer, x : 1
# 236	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 237	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 238	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 239	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 240	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 241	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
