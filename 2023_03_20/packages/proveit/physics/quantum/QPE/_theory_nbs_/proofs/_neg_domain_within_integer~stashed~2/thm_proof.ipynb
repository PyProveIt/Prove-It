# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_neg_domain_within_integer">_neg_domain_within_integer</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _neg_domain_within_integer
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_neg_domain_within_integer">_neg_domain_within_integer:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b79592523c6c10d6a321fa541c4f4b851c3d30ec0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/125a56a714255e905e5845f8d782d98bf989ac0f0/dependencies.ipynb">dependencies</a>)<br>
# _neg_domain_within_integer may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._neg_domain_within_integer has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(e + 1)} subset_eq Integer)
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} subset_eq Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer
# 2	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 3	instantiation	11, 4, 5	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 4	instantiation	15, 6, 12	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 5	instantiation	20, 7	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	a : e + 1
# 6	instantiation	20, 16	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 7	instantiation	15, 8, 12	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# ...
