# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_two_pow_t_less_one_is_nat_pos">_two_pow_t_less_one_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit import a, b
from proveit.numbers import two
from proveit.numbers.exponentiation import nat_pos_to_nat_pos_lower_bound
from proveit.physics.quantum.QPE import _t
from proveit.physics.quantum.QPE import _t_in_natural_pos
from proveit.physics.quantum.QPE import _two_pow_t_is_nat_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _two_pow_t_less_one_is_nat_pos
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_two_pow_t_less_one_is_nat_pos">_two_pow_t_less_one_is_nat_pos:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/86d1bd43208fa41fc0cf53968d1aef7ec605b52a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/db5f20947c9ca27d8f948800f48acf0b3b4aa4170/dependencies.ipynb">dependencies</a>)<br>

# %%
# Recall that t (represented by the Literal t_)
# denotes the number of Qbits in the input register.
# Considered an axiom that t is a positive natural number
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
# Have also already proven that 2^t is a positive nat
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
_two_pow_t_less_one = _two_pow_t_less_one_is_nat_pos.operands[0]
# Out:
# <strong id="_two_pow_t_less_one">_two_pow_t_less_one:</strong> <a class="ProveItLink" href="../../../__pv_it/common/f186bef3123c37aced8bb4cc37639e91545fb7610/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
nat_pos_to_nat_pos_lower_bound
# Out:
# |- forall_{a, b in NaturalPos} (a^{b} >= a)

# %%
_two_pow_t_ge_two = nat_pos_to_nat_pos_lower_bound.instantiate({a:two, b:_t})
# Out:
# <strong id="_two_pow_t_ge_two">_two_pow_t_ge_two:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__two_pow_t_less_one_is_nat_pos/fc11b19d6902bead9f5af303074cff7cc88475590/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__two_pow_t_less_one_is_nat_pos/56f63901cc70a6499a7f898886556ef05302a5900/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _two_pow_t_less_one_is_nat_pos may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._two_pow_t_less_one_is_nat_pos has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- (2^{t} - 1) in NaturalPos
# 	a : 2^{t} - 1
# 1	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 2	instantiation	4, 5, 52	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 3	instantiation	6, 7	|- (2^{t} - 1) > 0
# 	a : 2^{t}, b : 1
# 4	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 5	instantiation	59, 8, 50	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 6	conjecture		|- forall_{a, b | a > b} ((a - b) > 0)
# 	proveit.numbers.addition.subtraction.pos_difference
# 7	instantiation	9, 39, 27, 10, 11, 12*, 13*	|- 1 < 2^{t}
# 	a : -1, x : 2, y : 2^{t} + 1
# 8	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# ...
