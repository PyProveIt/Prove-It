# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_phase_from_best_with_delta_b">_phase_from_best_with_delta_b</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit.physics.quantum.QPE import _phase_is_real, _two_pow_t_is_nat_pos

# %%
# %proving _phase_from_best_with_delta_b
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_phase_from_best_with_delta_b">_phase_from_best_with_delta_b:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/fdd70e0d0a30751b7e0297e681ca12a6a2b3f8d30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/63cd2e9348e2b2664a0817e737c9c2dcee0a42810/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _phase_from_best_with_delta_b.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__phase_from_best_with_delta_b/573f4cd331da201f507b04e9d621277df04961e90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.physics.quantum.QPE import _delta_b_def
_delta_b_def
# Out:
# |- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))

# %%
_delta_b_def_inst = _delta_b_def.instantiate()
# Out:
# <strong id="_delta_b_def_inst">_delta_b_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/035e0ae7bd8c0fe127ee5d2062443d6c874adcdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__phase_from_best_with_delta_b/e2b26862c448bb8607fa8d2f63ca6991075a4d860/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/f36aeb0fcc4a09d334de072cccaf2d807548c1580/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_delta_b_def_inst.substitution(_phase_from_best_with_delta_b.instance_expr.rhs)
# Out:
# {b in Integer} |- ((b / 2^{t}) + delta_{b}) = phase
# _phase_from_best_with_delta_b may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._phase_from_best_with_delta_b has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in Integer} (phase = ((b / 2^{t}) + delta_{b}))
# 1	instantiation	2, 3	{b in Integer} |- phase = ((b / 2^{t}) + delta_{b})
# 	x : (b / 2^{t}) + delta_{b}, y : phase
# 2	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 3	instantiation	4, 5, 6*	{b in Integer} |- ((b / 2^{t}) + delta_{b}) = phase
# 	f(_a) : (b / 2^{t}) + _a, x : delta_{b}, y : phase - (b / 2^{t})
# 4	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 5	instantiation	7, 37	{b in Integer} |- delta_{b} = (phase - (b / 2^{t}))
# 	b : b
# 6	instantiation	8, 9, 10	{b in Integer} |- ((b / 2^{t}) + (phase - (b / 2^{t}))) = phase
# 	x : (b / 2^{t}) + (phase - (b / 2^{t})), y : (b / 2^{t}) + phase - (b / 2^{t}), z : phase
# 7	axiom		|- forall_{b in Integer} (delta_{b} = (phase - (b / 2^{t})))
# 	proveit.physics.quantum.QPE._delta_b_def
# 8	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 9	instantiation	11, 12, 13, 14, 15, 16, 23, 19, 17	{b in Integer} |- ((b / 2^{t}) + (phase - (b / 2^{t}))) =  \\ ((b / 2^{t}) + phase - (b / 2^{t}))
# 	i : 1, j : 2, k : 0, a : (b / 2^{t}), b : (phase, -(b / 2^{t})), c : ()
# 10	instantiation	18, 23, 19, 20	{b in Integer} |- ((b / 2^{t}) + phase - (b / 2^{t})) = phase
# 	a : b / 2^{t}, b : b / 2^{t}, c : phase
# 11	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 12	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 13	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 14	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 15	instantiation	21	|- |(phase, -(b / 2^{t}))| = |(1, ..., 2)|
# 	a : phase, b : -(b / 2^{t})
# 16	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 17	instantiation	22, 23	{b in Integer} |- (-(b / 2^{t})) in Complex
# 	a : b / 2^{t}
# 18	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 19	instantiation	40, 31, 24	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 20	instantiation	25	|- (b / 2^{t}) = (b / 2^{t})
# 	x : b / 2^{t}
# 21	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 22	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 23	instantiation	26, 27, 28, 29	{b in Integer} |- (b / 2^{t}) in Complex
# 	a : b, b : 2^{t}
# 24	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 25	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 26	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 27	instantiation	40, 31, 30	{b in Integer} |- b in Complex
# 	A : Real, B : Complex, x : b
# 28	instantiation	40, 31, 32	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 29	instantiation	33, 42	|- 2^{t} != 0
# 	n : 2^{t}
# 30	instantiation	40, 35, 34	{b in Integer} |- b in Real
# 	A : Rational, B : Real, x : b
# 31	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 32	instantiation	40, 35, 36	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 33	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 34	instantiation	40, 38, 37	{b in Integer} |- b in Rational
# 	A : Integer, B : Rational, x : b
# 35	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 36	instantiation	40, 38, 39	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 37	assumption		{b in Integer} |- b in Integer
# 38	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 39	instantiation	40, 41, 42	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 40	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 41	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 42	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
