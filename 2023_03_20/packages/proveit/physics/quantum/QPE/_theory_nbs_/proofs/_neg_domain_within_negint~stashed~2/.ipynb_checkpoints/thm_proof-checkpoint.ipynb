# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_neg_domain_within_negint">_neg_domain_within_negint</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import k, defaults
from proveit.logic import InSet
from proveit.numbers import one
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _neg_domain_within_negint
# Out:
# _neg_domain_within_negint: forall_{e in {2 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(e + 1)} subset_eq IntegerNeg)

# %%
defaults.assumptions = _neg_domain_within_negint.all_conditions()
# Out:
# defaults.assumptions: (e in {2 .. 2^{t - 1} - 2})

# %%
e_in_e_domain = defaults.assumptions[0]
# Out:
# e_in_e_domain: e in {2 .. 2^{t - 1} - 2}

# %%
# acknowledge previously proven fact
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
two_less_eq_eps = e_in_e_domain.derive_element_lower_bound()
# Out:
# two_less_eq_eps: {e in {2 .. 2^{t - 1} - 2}} |- 2 <= e

# %%
# for convenience name our subset
the_subset = _neg_domain_within_negint.instance_expr.lhs
# Out:
# the_subset: {-2^{t - 1} + 1 .. -(e + 1)}

# %%
two_less_eq_eps.derive_shifted(one).derive_negated()
# Out:
# {e in {2 .. 2^{t - 1} - 2}} |- (-(e + 1)) <= (-3)

# %%
InSet(k, the_subset).derive_element_in_integer_neg(assumptions=[InSet(k, the_subset), e_in_e_domain])
# Out:
# {e in {2 .. 2^{t - 1} - 2}, k in {-2^{t - 1} + 1 .. -(e + 1)}} |- k in IntegerNeg

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {2 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(e + 1)} subset_eq IntegerNeg)
# 1	instantiation	2, 3	{e in {2 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} subset_eq IntegerNeg
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : IntegerNeg, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalization	4	{e in {2 .. 2^{t - 1} - 2}} |- forall_{_a in {-2^{t - 1} + 1 .. -(e + 1)}} (_a in IntegerNeg)
# 4	instantiation	5, 6, 7	{e in {2 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in IntegerNeg
# 	a : _a
# 5	conjecture		|- forall_{a in Integer | a < 0} (a in IntegerNeg)
# 	proveit.numbers.number_sets.integers.neg_int_is_int_neg
# 6	instantiation	45, 8, 15	{e in {2 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer, x : _a
# 7	instantiation	9, 10, 11	{e in {2 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a < 0
# 	x : _a, y : -(e + 1), z : 0
# 8	instantiation	32, 13, 14	{e in {2 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 9	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_eq_less
# 10	instantiation	12, 13, 14, 15	{e in {2 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a <= (-(e + 1))
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : _a
# 11	instantiation	16, 19	{e in {2 .. 2^{t - 1} - 2}} |- (-(e + 1)) < 0
# 	a : -(e + 1)
# 12	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 13	instantiation	40, 17, 18	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 14	instantiation	45, 46, 19	{e in {2 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	A : IntegerNeg, B : Integer, x : -(e + 1)
# 15	assumption		{_a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in {-2^{t - 1} + 1 .. -(e + 1)}
# 16	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 17	instantiation	45, 46, 20	|- (-2^{t - 1}) in Integer
# 	A : IntegerNeg, B : Integer, x : -2^{t - 1}
# 18	instantiation	45, 43, 24	|- 1 in Integer
# 	A : NaturalPos, B : Integer, x : 1
# 19	instantiation	48, 21	{e in {2 .. 2^{t - 1} - 2}} |- (-(e + 1)) in IntegerNeg
# 	a : e + 1
# 20	instantiation	48, 44	|- (-2^{t - 1}) in IntegerNeg
# 	a : 2^{t - 1}
# 21	instantiation	22, 23, 24	{e in {2 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 22	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 23	instantiation	25, 26, 27	{e in {2 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 24	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 25	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 26	instantiation	45, 28, 38	{e in {2 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {2 .. 2^{t - 1} - 2}, B : Integer, x : e
# 27	instantiation	29, 30, 31	{e in {2 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 2, z : e
# 28	instantiation	32, 36, 37	|- {2 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 2, b : 2^{t - 1} - 2
# 29	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 30	instantiation	33, 34	|- 2 > 0
# 	q : 2
# 31	instantiation	35, 36, 37, 38	{e in {2 .. 2^{t - 1} - 2}} |- 2 <= e
# 	a : 2, b : 2^{t - 1} - 2, n : e
# 32	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 33	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 34	instantiation	45, 39, 49	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 35	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 36	instantiation	45, 43, 49	|- 2 in Integer
# 	A : NaturalPos, B : Integer, x : 2
# 37	instantiation	40, 41, 42	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 38	assumption		{e in {2 .. 2^{t - 1} - 2}} |- e in {2 .. 2^{t - 1} - 2}
# 39	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 40	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 41	instantiation	45, 43, 44	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 42	instantiation	45, 46, 47	|- (-2) in Integer
# 	A : IntegerNeg, B : Integer, x : -2
# 43	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 44	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 45	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 46	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 47	instantiation	48, 49	|- (-2) in IntegerNeg
# 	a : 2
# 48	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 49	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
