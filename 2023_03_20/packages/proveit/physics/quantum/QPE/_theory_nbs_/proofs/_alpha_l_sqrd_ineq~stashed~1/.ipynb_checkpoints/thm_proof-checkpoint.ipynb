# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_l_sqrd_ineq">_alpha_l_sqrd_ineq</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import l, defaults
from proveit.logic import InSet
from proveit.numbers import zero, greater, Integer
from proveit.physics.quantum.QPE import (
    _alpha_l_summed_abs, _delta_is_real, _two_pow_t_is_nat_pos, 
    _scaled_delta_minus_l__in__real, _scaled_abs_delta_diff_interval,
    _scaled_delta_not_eq_nonzeroInt,
    _delta_not_eq_scaledNonzeroInt, _delta_is_real,
    _l_non_zero, _all_abs_alpha_l_sqrd_are_real,
    _all_abs_alpha_l_are_nonneg, _full_domain)

# %%
# %proving _alpha_l_sqrd_ineq
# Out:
# _alpha_l_sqrd_ineq: forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))

# %%
defaults.assumptions = _alpha_l_sqrd_ineq.conditions
# Out:
# defaults.assumptions: (l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))

# %% [markdown]
# ## Instantiate some needed theorems of this package

# %%
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# to replace the l_non_zero.instantiate() approach
InSet(l, Integer).prove(assumptions=[InSet(l, _full_domain)])
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer

# %%
_scaled_delta_minus_l__in__real.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in Real

# %%
_scaled_abs_delta_diff_interval.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in (0,pi / 2]

# %%
_delta_not_eq_scaledNonzeroInt.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- delta != (l / 2^{t})

# %%
_scaled_delta_not_eq_nonzeroInt.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * delta) != l

# %%
_all_abs_alpha_l_are_nonneg.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in RealNonNeg

# %%
_all_abs_alpha_l_sqrd_are_real.instantiate()
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} in Real

# %%
_alpha_l_summed_abs_inst = _alpha_l_summed_abs.instantiate(auto_simplify=False)
# Out:
# _alpha_l_summed_abs_inst: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))

# %% [markdown]
# ## Bound the numerator and the denominator of the above right hand side

# %% [markdown]
# ### Use a triangle inequality for the numerator

# %%
numerator = _alpha_l_summed_abs_inst.rhs.numerator
# Out:
# numerator: |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|

# %%
numer_bound = numerator.deduce_triangle_bound()
# Out:
# numer_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= 2

# %% [markdown]
# ### Bound the sine in the denominator by a line

# %%
sin_factor = _alpha_l_summed_abs_inst.rhs.denominator.operands[2]
# Out:
# sin_factor: sin(pi * |delta - (l / 2^{t})|)

# %%
sin_factor_bound = sin_factor.deduce_linear_bound()
# Out:
# sin_factor_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) > (2 * |delta - (l / 2^{t})|)

# %%
bound_is_positive = sin_factor_bound.rhs.deduce_positive()
# Out:
# bound_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) > 0

# %%
sin_factor_is_positive = sin_factor_bound.apply_transitivity(bound_is_positive)
# Out:
# sin_factor_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) > 0

# %%
denominator = _alpha_l_summed_abs_inst.rhs.denominator
# Out:
# denominator: 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)

# %%
denom_bound = denominator.deduce_bound(sin_factor_bound)
# Out:
# denom_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) > (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)

# %%
# We should try to eliminate having to do this step manually.  It should be managable, sorting w.r.t. zero.
denom_is_positive = denominator.deduce_bound(sin_factor_is_positive)
# Out:
# denom_is_positive: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) > 0

# %% [markdown]
# ### Now we use the numerator and denominator bounds to bound $|\alpha_l|$

# %%
# recall from earlier:
_alpha_l_summed_abs_inst
# Out:
# {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))

# %%
rhs_bound = _alpha_l_summed_abs_inst.rhs.deduce_bound([numer_bound, denom_bound])
# Out:
# rhs_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))

# %%
alpha_l_bound = _alpha_l_summed_abs_inst.apply_transitivity(rhs_bound)
# Out:
# alpha_l_bound: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))

# %% [markdown]
# ## Simplify (rearrange) and square both sides

# %%
alpha_l_bound_v2 = alpha_l_bound.inner_expr().rhs.denominator.commute(0, 1)
# Out:
# alpha_l_bound_v2: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))

# %%
alpha_l_bound_v3 = alpha_l_bound_v2.inner_expr().rhs.denominator.associate(1, 2)
# Out:
# alpha_l_bound_v3: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * (2^{t} * |delta - (l / 2^{t})|)))

# %%
alpha_l_bound_v4 = alpha_l_bound_v3.inner_expr().rhs.denominator.operands[1].distribute(1)
# Out:
# alpha_l_bound_v4: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * |(2^{t} * delta) - l|))

# %%
alpha_l_bound_v5 = alpha_l_bound_v4.inner_expr().rhs.denominator.operands[1].reverse_difference()
# Out:
# alpha_l_bound_v5: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * |l - (2^{t} * delta)|))

# %%
# alpha_l_bound_v5.rhs.denominator.deduce_positive()

# %%
# from proveit.numbers import deduce_number_set, RealPos, greater, zero
# from proveit.logic import Equals
# from IPython.display import display

# %%
# for eq_expr in Equals.yield_known_equal_expressions(alpha_l_bound_v5.rhs.denominator.operands[1]):
#     display(eq_expr)
#     print(greater(eq_expr, zero).proven())

# %%
alpha_l_sqrd_bound_v1 = alpha_l_bound_v5.square_both_sides()
# Out:
# alpha_l_sqrd_bound_v1: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (2 * |l - (2^{t} * delta)|))^{2}

# %%
alpha_l_sqrd_bound_v2 = alpha_l_sqrd_bound_v1.inner_expr().rhs.distribute()
# Out:
# alpha_l_sqrd_bound_v2: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (2 * |l - (2^{t} * delta)|)^{2})

# %%
alpha_l_sqrd_bound_v3 = alpha_l_sqrd_bound_v2.inner_expr().rhs.denominator.distribute()
# Out:
# alpha_l_sqrd_bound_v3: {l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (4 * (l - (2^{t} * delta))^{2}))

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}} (|alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2})))
# 1	instantiation	2, 3	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} <= (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	x : |alpha_{l}|^{2}, y : 1 / (4 * (l - (2^{t} * delta))^{2})
# 2	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 3	instantiation	226, 4, 5	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (4 * (l - (2^{t} * delta))^{2}))
# 	P(_a) : |alpha_{l}|^{2} < (1 / _a), x : (2 * |l - (2^{t} * delta)|)^{2}, y : 4 * (l - (2^{t} * delta))^{2}
# 4	instantiation	226, 6, 7	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (2 * |l - (2^{t} * delta)|)^{2})
# 	P(_a) : |alpha_{l}|^{2} < _a, x : (1 / (2 * |l - (2^{t} * delta)|))^{2}, y : 1 / (2 * |l - (2^{t} * delta)|)^{2}
# 5	instantiation	8, 337, 9, 404, 10*, 11*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|)^{2} = (4 * (l - (2^{t} * delta))^{2})
# 	a : 2, b : |l - (2^{t} * delta)|, n : 2
# 6	instantiation	12, 375, 13, 14, 15, 16	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}|^{2} < (1 / (2 * |l - (2^{t} * delta)|))^{2}
# 	a : 2, x : |alpha_{l}|, y : 1 / (2 * |l - (2^{t} * delta)|)
# 7	instantiation	17, 300, 18, 404, 37, 19*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |l - (2^{t} * delta)|))^{2} = (1 / (2 * |l - (2^{t} * delta)|)^{2})
# 	a : 1, b : 2 * |l - (2^{t} * delta)|, n : 2
# 8	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos} ((a * b)^{n} = (a^{n} * b^{n}))
# 	proveit.numbers.exponentiation.posnat_power_of_product
# 9	instantiation	449, 379, 20	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in Complex
# 	A : Real, B : Complex, x : |l - (2^{t} * delta)|
# 10	instantiation	325, 21, 22	|- 2^{2} = 4
# 	x : 2^{2}, y : 2 *  ..0 ×.. *  2, z : 4
# 11	instantiation	23, 94	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)|^{2} = (l - (2^{t} * delta))^{2}
# 	a : l - (2^{t} * delta)
# 12	conjecture		|- forall_{a, x, y in Real | 0 <= x < y, a > 0} (x^{a} < y^{a})
# 	proveit.numbers.exponentiation.exp_pos_less
# 13	instantiation	449, 24, 39	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in Real
# 	A : RealNonNeg, B : Real, x : |alpha_{l}|
# 14	instantiation	449, 392, 25	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |l - (2^{t} * delta)|)) in Real
# 	A : RealPos, B : Real, x : 1 / (2 * |l - (2^{t} * delta)|)
# 15	instantiation	26, 27, 28	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (0 <= |alpha_{l}|) and (|alpha_{l}| < (1 / (2 * |l - (2^{t} * delta)|)))
# 	A : 0 <= |alpha_{l}|, B : |alpha_{l}| < (1 / (2 * |l - (2^{t} * delta)|))
# 16	instantiation	29, 386	|- 2 > 0
# 	q : 2
# 17	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos | b != 0} ((a / b)^{n} = (a^{n} / b^{n}))
# 	proveit.numbers.exponentiation.posnat_power_of_quotient
# 18	instantiation	449, 379, 30	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in Complex
# 	A : Real, B : Complex, x : 2 * |l - (2^{t} * delta)|
# 19	instantiation	31, 337	|- 1^{2} = 1
# 	x : 2
# 20	instantiation	449, 392, 61	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in Real
# 	A : RealPos, B : Real, x : |l - (2^{t} * delta)|
# 21	instantiation	32, 404, 337	|- 2^{2} = (2 *  ..0 ×.. *  2)
# 	n : 2, x : 2
# 22	instantiation	33, 365, 34, 209, 35, 238*	|- (2 *  ..0 ×.. *  2) =  \\ 4
# 	n : 2, f(_a_{1}, ..., _a_{2}) : _a_{1} *  ... *  _a_{2}, x : (2, ..0 ×.., 2), y : (2, 2)
# 23	conjecture		|- forall_{a in Real} (|a|^{2} = a^{2})
# 	proveit.numbers.exponentiation.square_abs_real_simp
# 24	conjecture		|- RealNonNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_nonneg_within_real
# 25	instantiation	255, 36, 52, 37	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * |l - (2^{t} * delta)|)) in RealPos
# 	a : 1, b : 2 * |l - (2^{t} * delta)|
# 26	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 27	instantiation	38, 39	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| >= 0
# 	x : |alpha_{l}|
# 28	instantiation	226, 40, 41	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * |l - (2^{t} * delta)|))
# 	P(_a) : |alpha_{l}| < (1 / (2 * _a)), x : |(2^{t} * delta) - l|, y : |l - (2^{t} * delta)|
# 29	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 30	instantiation	449, 392, 52	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in Real
# 	A : RealPos, B : Real, x : 2 * |l - (2^{t} * delta)|
# 31	conjecture		|- forall_{x in Complex} (1^{x} = 1)
# 	proveit.numbers.exponentiation.exponentiated_one
# 32	conjecture		|- forall_{n in NaturalPos} [forall_{x in Complex} (x^{n} = (x *  x *  ..(n - 3) ×.. *  x))]
# 	proveit.numbers.exponentiation.exp_nat_pos_expansion
# 33	conjecture		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1}, x_{2}, ..., x_{n}) = (y_{1}, y_{2}, ..., y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution_via_tuple
# 34	instantiation	42, 365	|- |(2, ..0 ×.., 2)| = |(1, ..., 2)|
# 	i : 2, f(k) : 2
# 35	instantiation	43	|- (2, ..0 ×.., 2) = (2, 2)
# 	x : 2
# 36	instantiation	449, 385, 44	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 37	instantiation	45, 46	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) != 0
# 	x : 2 * |l - (2^{t} * delta)|
# 38	conjecture		|- forall_{x in RealNonNeg} (x >= 0)
# 	proveit.numbers.number_sets.real_numbers.nonneg_if_in_real_nonneg
# 39	instantiation	47, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| in RealNonNeg
# 	l : l
# 40	instantiation	226, 48, 49	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * |(2^{t} * delta) - l|))
# 	P(_a) : |alpha_{l}| < (1 / (2 * _a)), x : 2^{t} * |delta - (l / 2^{t})|, y : |(2^{t} * delta) - l|
# 41	instantiation	50, 51, 162	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| = |l - (2^{t} * delta)|
# 	a : 2^{t} * delta, b : l
# 42	conjecture		|- forall_{i in Natural} [forall_{f} (|(f(1), f(2), ..., f(i))| = |(1, 2, ..., i)|)]
# 	proveit.core_expr_types.tuples.range_from1_len_typical_eq
# 43	conjecture		|- forall_{x} ((x, ..0 ×.., x) = (x, x))
# 	proveit.numbers.numerals.decimals.reduce_2_repeats
# 44	instantiation	449, 396, 451	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 45	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 46	instantiation	449, 339, 52	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2 * |l - (2^{t} * delta)|
# 47	conjecture		|- forall_{l in Integer} (|alpha_{l}| in RealNonNeg)
# 	proveit.physics.quantum.QPE._all_abs_alpha_l_are_nonneg
# 48	instantiation	226, 53, 54	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * (2^{t} * |delta - (l / 2^{t})|)))
# 	P(_a) : |alpha_{l}| < (1 / _a), x : 2 * 2^{t} * |delta - (l / 2^{t})|, y : 2 * (2^{t} * |delta - (l / 2^{t})|)
# 49	instantiation	55, 333, 365, 334, 336, 56, 57, 58, 59, 60*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * |delta - (l / 2^{t})|) =  \\ |(2^{t} * delta) - l|
# 	i : 1, j : 2, k : 0, a : (2^{t}), c : (), b : (delta, -(l / 2^{t}))
# 50	conjecture		|- forall_{a, b in Complex} (|a - b| = |b - a|)
# 	proveit.numbers.absolute_value.abs_diff_reversal
# 51	instantiation	449, 379, 135	|- (2^{t} * delta) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta
# 52	instantiation	368, 363, 61	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |l - (2^{t} * delta)|) in RealPos
# 	a : 2, b : |l - (2^{t} * delta)|
# 53	instantiation	236, 62, 63	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	P(_a) : _a < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|)), x : |alpha_{l}|, y : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 54	instantiation	332, 333, 365, 334, 184, 336, 337, 214, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * |delta - (l / 2^{t})|) =  \\ (2 * (2^{t} * |delta - (l / 2^{t})|))
# 	i : 1, j : 2, k : 0, a : (2), b : (2^{t}, |delta - (l / 2^{t})|), c : ()
# 55	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{k} in RealNonNeg} [forall_{b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * |b_{1} +  b_{2} +  ... +  b_{j}|* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ |(a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})|)]]
# 	proveit.numbers.multiplication.distribute_through_abs_sum
# 56	instantiation	449, 342, 64	|- 2^{t} in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 2^{t}
# 57	instantiation	361	|- |(delta, -(l / 2^{t}))| = |(1, ..., 2)|
# 	a : delta, b : -(l / 2^{t})
# 58	instantiation	449, 379, 411	|- delta in Complex
# 	A : Real, B : Complex, x : delta
# 59	instantiation	449, 379, 412	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in Complex
# 	A : Real, B : Complex, x : -(l / 2^{t})
# 60	instantiation	65, 214, 66, 67*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (-(l / 2^{t}))) = (-l)
# 	x : 2^{t}, y : l / 2^{t}
# 61	instantiation	394, 68	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |l - (2^{t} * delta)| in RealPos
# 	a : l - (2^{t} * delta)
# 62	instantiation	69, 70, 71	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) < (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), y : 2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)), z : 1 / (2 * 2^{t} * |delta - (l / 2^{t})|)
# 63	instantiation	72, 441	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
# 	l : l
# 64	instantiation	449, 364, 73	|- 2^{t} in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 2^{t}
# 65	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 66	instantiation	449, 379, 74	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in Complex
# 	A : Real, B : Complex, x : l / 2^{t}
# 67	instantiation	226, 75, 76	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (l / 2^{t})) = l
# 	P(_a) : (2^{t} * (l / 2^{t})) = _a, x : (1 / 1) * (l / 1), y : l
# 68	instantiation	449, 400, 77	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l - (2^{t} * delta)) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : l - (2^{t} * delta)
# 69	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_eq_less
# 70	instantiation	78, 79, 80, 375, 81, 82	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))) <= (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
# 	a : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|), x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : 2
# 71	instantiation	83, 363, 84, 85, 86, 87*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 / (2 * 2^{t} * |delta - (l / 2^{t})|)) > (2 / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)))
# 	a : 2, x : 2 * 2 * 2^{t} * |delta - (l / 2^{t})|, y : 2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)
# 72	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} (|alpha_{l}| = (|1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| / (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))))
# 	proveit.physics.quantum.QPE._alpha_l_summed_abs
# 73	instantiation	449, 88, 433	|- 2^{t} in Natural
# 	A : NaturalPos, B : Natural, x : 2^{t}
# 74	instantiation	449, 416, 89	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in Real
# 	A : Rational, B : Real, x : l / 2^{t}
# 75	instantiation	226, 90, 91	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (l / 2^{t})) = ((1 / 1) * (l / 1))
# 	P(_a) : _a = ((1 / 1) * (l / 1)), x : ((1 * 2^{t}) / 1) * (l / (2^{t} * 1)), y : 2^{t} * (l / 2^{t})
# 76	instantiation	325, 92, 93	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((1 / 1) * (l / 1)) = l
# 	x : (1 / 1) * (l / 1), y : 1 * l, z : l
# 77	instantiation	405, 94, 95	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l - (2^{t} * delta)) in RealNonZero
# 	a : l - (2^{t} * delta)
# 78	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 	proveit.numbers.division.weak_div_from_numer_bound__pos_denom
# 79	instantiation	372, 373, 102, 240, 375, 124	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) in Real
# 	n : 3, a : (2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))
# 80	instantiation	236, 96, 97	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| in Real
# 	P(_a) : _a in Real, x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : 2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2)
# 81	instantiation	98, 300, 168, 99*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| <= 2
# 	a : 1, b : -e^{2 * pi * i * ((2^{t} * delta) - l)}
# 82	instantiation	104, 365, 334, 155, 336, 213, 363, 125, 100*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	i : 2, j : 0, x : 0, y : sin(pi * |delta - (l / 2^{t})|), a : (2^{t}, 2), b : ()
# 83	conjecture		|- forall_{a, x, y in RealPos | x < y} ((a / x) > (a / y))
# 	proveit.numbers.division.strong_div_from_denom_bound__all_pos
# 84	instantiation	211, 272, 101, 363, 213, 384	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2 * 2^{t} * |delta - (l / 2^{t})|) in RealPos
# 	n : 4, a : (2, 2, 2^{t}, |delta - (l / 2^{t})|)
# 85	instantiation	211, 373, 102, 213, 363, 103	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|)) in RealPos
# 	n : 3, a : (2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))
# 86	instantiation	104, 365, 334, 155, 336, 213, 363, 154, 105*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2 * 2^{t} * |delta - (l / 2^{t})|) < (2^{t} * 2 * sin(pi * |delta - (l / 2^{t})|))
# 	i : 2, j : 0, x : 2 * |delta - (l / 2^{t})|, y : sin(pi * |delta - (l / 2^{t})|), a : (2^{t}, 2), b : ()
# 87	instantiation	325, 106, 107	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)) = (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	x : 2 / (2 * 2 * 2^{t} * |delta - (l / 2^{t})|), y : 2 / (2 * (2 * 2^{t} * |delta - (l / 2^{t})|)), z : 1 / (2 * 2^{t} * |delta - (l / 2^{t})|)
# 88	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 89	instantiation	449, 419, 422	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in Rational
# 	A : RationalNonZero, B : Rational, x : l / 2^{t}
# 90	instantiation	108, 300, 162, 109, 292	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = ((1 / 1) * (l / 1))
# 	a : 1, d : l, b : 2^{t}, c : 1, e : 1
# 91	instantiation	325, 110, 111	|- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = (2^{t} * (l / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (l / (2^{t} * 1)), y : 2^{t} * (l / (2^{t} * 1)), z : 2^{t} * (l / 2^{t})
# 92	instantiation	325, 112, 113	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((1 / 1) * (l / 1)) = (1 * l)
# 	x : (1 / 1) * (l / 1), y : 1 * (l / 1), z : 1 * l
# 93	instantiation	252, 162	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * l) = l
# 	x : l
# 94	instantiation	410, 187, 114	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l - (2^{t} * delta)) in Real
# 	a : l, b : -(2^{t} * delta)
# 95	instantiation	413, 115	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l - (2^{t} * delta)) != 0
# 	a : l, b : 2^{t} * delta
# 96	instantiation	236, 116, 117	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2)) in Real
# 	P(_a) : _a in Real, x : 2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2), y : 2 * sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2)
# 97	instantiation	325, 118, 119	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| = (2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2))
# 	x : |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1|, z : 2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2)
# 98	conjecture		|- forall_{a, b in Complex} (|a + b| <= (|a| + |b|))
# 	proveit.numbers.absolute_value.triangle_inequality
# 99	instantiation	325, 120, 121	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1| + |-e^{2 * pi * i * ((2^{t} * delta) - l)}|) = 2
# 	x : |1| + |-e^{2 * pi * i * ((2^{t} * delta) - l)}|, y : 1 + 1, z : 2
# 100	instantiation	122, 365, 334, 155, 336, 214, 337	|- (2^{t} * 2 * 0) = 0
# 	i : 2, j : 0, a : (2^{t}, 2), b : ()
# 101	instantiation	298	|- |(2, 2, 2^{t}, |delta - (l / 2^{t})|)| = |(1, 2, ..., 4)|
# 	a : 2, b : 2, c : 2^{t}, d : |delta - (l / 2^{t})|
# 102	instantiation	389	|- |(2^{t}, 2, sin(pi * |delta - (l / 2^{t})|))| = |(1, 2, ..., 3)|
# 	a : 2^{t}, b : 2, c : sin(pi * |delta - (l / 2^{t})|)
# 103	instantiation	123, 124, 125	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) in RealPos
# 	a : sin(pi * |delta - (l / 2^{t})|)
# 104	conjecture		|- forall_{i, j in Natural} [forall_{x, y} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in RealPos | x < y} ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) < (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j}))]]
# 	proveit.numbers.multiplication.strong_bound_via_factor_bound
# 105	instantiation	325, 126, 127	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) = (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)
# 	x : 2^{t} * 2 * (2 * |delta - (l / 2^{t})|), y : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|, z : 2 * 2 * 2^{t} * |delta - (l / 2^{t})|
# 106	instantiation	354, 128	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)) = (2 / (2 * (2 * 2^{t} * |delta - (l / 2^{t})|)))
# 	f(_a) : 2 / _a, x : 2 * 2 * 2^{t} * |delta - (l / 2^{t})|, y : 2 * (2 * 2^{t} * |delta - (l / 2^{t})|)
# 107	instantiation	290, 291, 129, 300, 294*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 / (2 * (2 * 2^{t} * |delta - (l / 2^{t})|))) = (1 / (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	x : 2, z : 2 * 2^{t} * |delta - (l / 2^{t})|, y : 1
# 108	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_numer_left
# 109	instantiation	449, 400, 130	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 110	instantiation	354, 131	|- (((1 * 2^{t}) / 1) * (l / (2^{t} * 1))) = (2^{t} * (l / (2^{t} * 1)))
# 	f(_a) : _a * (l / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 111	instantiation	354, 132	|- (2^{t} * (l / (2^{t} * 1))) = (2^{t} * (l / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : l / (2^{t} * 1), y : l / 2^{t}
# 112	instantiation	354, 133	|- ((1 / 1) * (l / 1)) = (1 * (l / 1))
# 	f(_a) : _a * (l / 1), x : 1 / 1, y : 1
# 113	instantiation	354, 134	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 * (l / 1)) = (1 * l)
# 	f(_a) : 1 * _a, x : l / 1, y : l
# 114	instantiation	216, 135	|- (-(2^{t} * delta)) in Real
# 	a : 2^{t} * delta
# 115	instantiation	136, 409	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l != (2^{t} * delta)
# 	x : 2^{t} * delta, y : l
# 116	instantiation	236, 137, 138	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2)) in Real
# 	P(_a) : _a in Real, x : 2 * sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2), y : 2 * sin(pi * |(2^{t} * delta) - l|)
# 117	instantiation	354, 139	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2)) = (2 * sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2))
# 	f(_a) : 2 * _a, x : sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2), y : sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2)
# 118	instantiation	354, 140	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |1 - e^{2 * pi * i * ((2^{t} * delta) - l)}| = |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1|
# 	f(_a) : |_a|, x : 1 - e^{2 * pi * i * ((2^{t} * delta) - l)}, y : -e^{2 * pi * i * ((2^{t} * delta) - l)} + 1
# 119	instantiation	141, 142, 143, 144*, 145*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1| = (2 * sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2))
# 	a : (2 * pi * ((2^{t} * delta) - l)) + pi, b : 0 + pi
# 120	instantiation	146, 365, 147, 148, 149, 150	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|1| + |-e^{2 * pi * i * ((2^{t} * delta) - l)}|) =  \\ (1 + 1)
# 	n : 2, f(_a, _b) : _a + _b, x : (|1|, |-e^{2 * pi * i * ((2^{t} * delta) - l)}|), y : (1, 1)
# 121	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 122	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * 0* b_{1} *  b_{2} *  ... *  b_{j}) = 0)]
# 	proveit.numbers.multiplication.mult_zero_any
# 123	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 124	instantiation	188, 189, 328, 151	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) in Real
# 	a : -1, b : 1, x : sin(pi * |delta - (l / 2^{t})|)
# 125	instantiation	152, 153, 154	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- 0 < sin(pi * |delta - (l / 2^{t})|)
# 	x : 0, y : 2 * |delta - (l / 2^{t})|, z : sin(pi * |delta - (l / 2^{t})|)
# 126	instantiation	257, 365, 334, 155, 335, 336, 214, 337, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * (2 * |delta - (l / 2^{t})|)) =  \\ (2^{t} * 2 * 2 * |delta - (l / 2^{t})|)
# 	i : 2, j : 2, k : 0, a : (2^{t}, 2), b : (2, |delta - (l / 2^{t})|), c : ()
# 127	instantiation	325, 156, 157	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) = (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)
# 	x : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|, y : (2 * 2) * 2^{t} * |delta - (l / 2^{t})|, z : 2 * 2 * 2^{t} * |delta - (l / 2^{t})|
# 128	instantiation	332, 333, 373, 334, 212, 336, 337, 214, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2 * 2^{t} * |delta - (l / 2^{t})|) =  \\ (2 * (2 * 2^{t} * |delta - (l / 2^{t})|))
# 	i : 1, j : 3, k : 0, a : (2), b : (2, 2^{t}, |delta - (l / 2^{t})|), c : ()
# 129	instantiation	449, 400, 158	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * |delta - (l / 2^{t})|) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2 * 2^{t} * |delta - (l / 2^{t})|
# 130	instantiation	449, 347, 425	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 131	instantiation	325, 159, 160	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 132	instantiation	354, 161	|- (l / (2^{t} * 1)) = (l / 2^{t})
# 	f(_a) : l / _a, x : 2^{t} * 1, y : 2^{t}
# 133	instantiation	267, 300	|- (1 / 1) = 1
# 	x : 1
# 134	instantiation	267, 162	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 1) = l
# 	x : l
# 135	instantiation	163, 240, 411	|- (2^{t} * delta) in Real
# 	a : 2^{t}, b : delta
# 136	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 137	instantiation	163, 375, 164	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin(pi * |(2^{t} * delta) - l|)) in Real
# 	a : 2, b : sin(pi * |(2^{t} * delta) - l|)
# 138	instantiation	354, 165	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2)) = (2 * sin(pi * |(2^{t} * delta) - l|))
# 	f(_a) : 2 * _a, x : sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2), y : sin(pi * |(2^{t} * delta) - l|)
# 139	instantiation	354, 166	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2) = sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2)
# 	f(_a) : sin(_a), x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2, y : (|2| * |pi| * |(2^{t} * delta) - l|) / 2
# 140	instantiation	167, 300, 168	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (1 - e^{2 * pi * i * ((2^{t} * delta) - l)}) = (-e^{2 * pi * i * ((2^{t} * delta) - l)} + 1)
# 	a : 1, b : -e^{2 * pi * i * ((2^{t} * delta) - l)}
# 141	conjecture		|- forall_{a, b in Real} (|e^{i * a} - e^{i * b}| = (2 * sin(|a - b| / 2)))
# 	proveit.trigonometry.complex_unit_circle_chord_length
# 142	instantiation	410, 353, 376	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * ((2^{t} * delta) - l)) + pi) in Real
# 	a : 2 * pi * ((2^{t} * delta) - l), b : pi
# 143	instantiation	449, 392, 169	|- (0 + pi) in Real
# 	A : RealPos, B : Real, x : 0 + pi
# 144	instantiation	170, 353, 202*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * ((2 * pi * ((2^{t} * delta) - l)) + pi)} = (-e^{2 * pi * i * ((2^{t} * delta) - l)})
# 	theta : 2 * pi * ((2^{t} * delta) - l)
# 145	instantiation	325, 171, 172	|- (-e^{i * (0 + pi)}) = 1
# 	x : -e^{i * (0 + pi)}, y : -(-1), z : 1
# 146	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 147	instantiation	361	|- |(|1|, |-e^{2 * pi * i * ((2^{t} * delta) - l)}|)| = |(1, ..., 2)|
# 	a : |1|, b : |-e^{2 * pi * i * ((2^{t} * delta) - l)}|
# 148	instantiation	361	|- |(1, 1)| = |(1, ..., 2)|
# 	a : 1, b : 1
# 149	instantiation	311, 173	|- |1| = 1
# 	x : 1
# 150	instantiation	174, 175, 176*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |-e^{2 * pi * i * ((2^{t} * delta) - l)}| = 1
# 	x : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 151	instantiation	217, 177	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) in [-1,1]
# 	theta : pi * |delta - (l / 2^{t})|
# 152	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 153	instantiation	225, 340	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) > 0
# 	x : 2 * |delta - (l / 2^{t})|
# 154	instantiation	178, 179, 180, 181*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |delta - (l / 2^{t})|) > (2 * |delta - (l / 2^{t})|)
# 	theta : pi * |delta - (l / 2^{t})|
# 155	instantiation	361	|- |(2^{t}, 2)| = |(1, ..., 2)|
# 	a : 2^{t}, b : 2
# 156	instantiation	325, 182, 183	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) = ((2 * 2) * 2^{t} * |delta - (l / 2^{t})|)
# 	x : 2^{t} * 2 * 2 * |delta - (l / 2^{t})|, y : 2^{t} * (2 * 2) * |delta - (l / 2^{t})|, z : (2 * 2) * 2^{t} * |delta - (l / 2^{t})|
# 157	instantiation	257, 334, 365, 336, 209, 184, 337, 214, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * 2) * 2^{t} * |delta - (l / 2^{t})|) =  \\ (2 * 2 * 2^{t} * |delta - (l / 2^{t})|)
# 	i : 0, j : 2, k : 2, a : (), b : (2, 2), c : (2^{t}, |delta - (l / 2^{t})|)
# 158	instantiation	449, 339, 185	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * |delta - (l / 2^{t})|) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2 * 2^{t} * |delta - (l / 2^{t})|
# 159	instantiation	354, 186	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 160	instantiation	267, 214	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 161	instantiation	318, 214	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 162	instantiation	449, 379, 187	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Complex
# 	A : Real, B : Complex, x : l
# 163	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 164	instantiation	188, 189, 328, 190	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |(2^{t} * delta) - l|) in Real
# 	a : -1, b : 1, x : sin(pi * |(2^{t} * delta) - l|)
# 165	instantiation	354, 191	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin((|2| * |pi| * |(2^{t} * delta) - l|) / 2) = sin(pi * |(2^{t} * delta) - l|)
# 	f(_a) : sin(_a), x : (|2| * |pi| * |(2^{t} * delta) - l|) / 2, y : pi * |(2^{t} * delta) - l|
# 166	instantiation	354, 192	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (|((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| / 2) = ((|2| * |pi| * |(2^{t} * delta) - l|) / 2)
# 	f(_a) : _a / 2, x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)|, y : |2| * |pi| * |(2^{t} * delta) - l|
# 167	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 168	instantiation	449, 200, 193	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-e^{2 * pi * i * ((2^{t} * delta) - l)}) in Complex
# 	A : ComplexNonZero, B : Complex, x : -e^{2 * pi * i * ((2^{t} * delta) - l)}
# 169	instantiation	194, 333, 334, 336, 195, 312, 196	|- (0 + pi) in RealPos
# 	i : 1, j : 0, a : (0), b : pi, c : ()
# 170	conjecture		|- forall_{theta in Real} (e^{i * (theta + pi)} = (-e^{i * theta}))
# 	proveit.numbers.number_sets.complex_numbers.unit_length_complex_polar_negation
# 171	instantiation	354, 197	|- (-e^{i * (0 + pi)}) = (-(-1))
# 	f(_a) : -_a, x : e^{i * (0 + pi)}, y : -1
# 172	instantiation	198, 300	|- (-(-1)) = 1
# 	x : 1
# 173	instantiation	449, 342, 199	|- 1 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 1
# 174	conjecture		|- forall_{x in Complex} (|-x| = |x|)
# 	proveit.numbers.absolute_value.abs_even
# 175	instantiation	449, 200, 223	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * ((2^{t} * delta) - l)} in Complex
# 	A : ComplexNonZero, B : Complex, x : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 176	instantiation	201, 353, 202*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |e^{2 * pi * i * ((2^{t} * delta) - l)}| = 1
# 	theta : 2 * pi * ((2^{t} * delta) - l)
# 177	instantiation	203, 360, 205, 206	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in Real
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 178	conjecture		|- forall_{theta in RealPos | theta <= (pi / 2)} (sin(theta) > ((2 * theta) / pi))
# 	proveit.trigonometry.sine_linear_bound_pos
# 179	instantiation	368, 391, 384	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in RealPos
# 	a : pi, b : |delta - (l / 2^{t})|
# 180	instantiation	204, 360, 205, 206	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) <= (pi / 2)
# 	a : 0, b : pi / 2, x : pi * |delta - (l / 2^{t})|
# 181	instantiation	325, 207, 208	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |delta - (l / 2^{t})|)) / pi) = (2 * |delta - (l / 2^{t})|)
# 	x : (2 * (pi * |delta - (l / 2^{t})|)) / pi, y : (2 * pi * |delta - (l / 2^{t})|) / pi, z : 2 * |delta - (l / 2^{t})|
# 182	instantiation	332, 333, 365, 209, 214, 337, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * 2 * 2 * |delta - (l / 2^{t})|) =  \\ (2^{t} * (2 * 2) * |delta - (l / 2^{t})|)
# 	i : 1, j : 2, k : 1, a : (2^{t}), b : (2, 2), c : (|delta - (l / 2^{t})|)
# 183	instantiation	331, 334, 333, 336, 214, 210, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * (2 * 2) * |delta - (l / 2^{t})|) =  \\ ((2 * 2) * 2^{t} * |delta - (l / 2^{t})|)
# 	i : 0, j : 1, k : 1, a : (), b : (2^{t}), c : 2 * 2, d : (|delta - (l / 2^{t})|)
# 184	instantiation	361	|- |(2^{t}, |delta - (l / 2^{t})|)| = |(1, ..., 2)|
# 	a : 2^{t}, b : |delta - (l / 2^{t})|
# 185	instantiation	211, 373, 212, 363, 213, 384	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * 2^{t} * |delta - (l / 2^{t})|) in RealPos
# 	n : 3, a : (2, 2^{t}, |delta - (l / 2^{t})|)
# 186	instantiation	252, 214	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 187	instantiation	449, 416, 215	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Real
# 	A : Rational, B : Real, x : l
# 188	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_cc__is__real
# 189	instantiation	216, 328	|- (-1) in Real
# 	a : 1
# 190	instantiation	217, 317	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- sin(pi * |(2^{t} * delta) - l|) in [-1,1]
# 	theta : pi * |(2^{t} * delta) - l|
# 191	instantiation	325, 218, 219	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((|2| * |pi| * |(2^{t} * delta) - l|) / 2) = (pi * |(2^{t} * delta) - l|)
# 	x : (|2| * |pi| * |(2^{t} * delta) - l|) / 2, y : (2 * pi * |(2^{t} * delta) - l|) / 2, z : pi * |(2^{t} * delta) - l|
# 192	instantiation	325, 220, 221	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| = (|2| * |pi| * |(2^{t} * delta) - l|)
# 	x : |((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)|, y : |2 * pi * ((2^{t} * delta) - l)|, z : |2| * |pi| * |(2^{t} * delta) - l|
# 193	instantiation	222, 223	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-e^{2 * pi * i * ((2^{t} * delta) - l)}) in ComplexNonZero
# 	a : e^{2 * pi * i * ((2^{t} * delta) - l)}
# 194	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in RealNonNeg | b > 0} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) in RealPos)]
# 	proveit.numbers.addition.add_real_pos_from_non_neg
# 195	instantiation	449, 342, 224	|- 0 in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 0
# 196	instantiation	225, 391	|- pi > 0
# 	x : pi
# 197	instantiation	226, 227, 228	|- e^{i * (0 + pi)} = (-1)
# 	P(_a) : _a = (-1), x : 1 * e^{i * (0 + pi)}, y : e^{i * (0 + pi)}
# 198	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 	proveit.numbers.negation.double_negation
# 199	instantiation	449, 364, 333	|- 1 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 1
# 200	conjecture		|- ComplexNonZero proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.complex_nonzero_within_complex
# 201	conjecture		|- forall_{theta in Real} (|e^{i * theta}| = 1)
# 	proveit.numbers.absolute_value.complex_unit_length
# 202	instantiation	229, 230	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{i * (2 * pi * ((2^{t} * delta) - l))} = e^{2 * pi * i * ((2^{t} * delta) - l)}
# 	x : e^{2 * pi * i * ((2^{t} * delta) - l)}, y : e^{i * (2 * pi * ((2^{t} * delta) - l))}
# 203	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 204	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_upper_bound
# 205	instantiation	449, 392, 231	|- (pi / 2) in Real
# 	A : RealPos, B : Real, x : pi / 2
# 206	instantiation	232, 435	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |delta - (l / 2^{t})|) in (0,pi / 2]
# 	l : l
# 207	instantiation	354, 233	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |delta - (l / 2^{t})|)) / pi) = ((2 * pi * |delta - (l / 2^{t})|) / pi)
# 	f(_a) : _a / pi, x : 2 * (pi * |delta - (l / 2^{t})|), y : 2 * pi * |delta - (l / 2^{t})|
# 208	instantiation	325, 234, 235	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / pi) = (2 * |delta - (l / 2^{t})|)
# 	x : (2 * pi * |delta - (l / 2^{t})|) / pi, y : (2 * |delta - (l / 2^{t})|) / 1, z : 2 * |delta - (l / 2^{t})|
# 209	instantiation	361	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 210	instantiation	236, 237, 238	|- (2 * 2) in Complex
# 	P(_a) : _a in Complex, x : 2 * 2, y : 4
# 211	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in RealPos} ((a_{1} *  a_{2} *  ... *  a_{n}) in RealPos)]
# 	proveit.numbers.multiplication.mult_real_pos_closure
# 212	instantiation	389	|- |(2, 2^{t}, |delta - (l / 2^{t})|)| = |(1, 2, ..., 3)|
# 	a : 2, b : 2^{t}, c : |delta - (l / 2^{t})|
# 213	instantiation	449, 385, 239	|- 2^{t} in RealPos
# 	A : RationalPos, B : RealPos, x : 2^{t}
# 214	instantiation	449, 379, 240	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 215	instantiation	449, 398, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 216	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 217	conjecture		|- forall_{theta in Real} (sin(theta) in [-1,1])
# 	proveit.trigonometry.sine_interval
# 218	instantiation	354, 241	|- ((|2| * |pi| * |(2^{t} * delta) - l|) / 2) = ((2 * pi * |(2^{t} * delta) - l|) / 2)
# 	f(_a) : _a / 2, x : |2| * |pi| * |(2^{t} * delta) - l|, y : 2 * pi * |(2^{t} * delta) - l|
# 219	instantiation	325, 242, 243	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |(2^{t} * delta) - l|) / 2) = (pi * |(2^{t} * delta) - l|)
# 	x : (2 * pi * |(2^{t} * delta) - l|) / 2, y : (pi * |(2^{t} * delta) - l|) / 1, z : pi * |(2^{t} * delta) - l|
# 220	instantiation	354, 244	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)| = |2 * pi * ((2^{t} * delta) - l)|
# 	f(_a) : |_a|, x : ((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi), y : 2 * pi * ((2^{t} * delta) - l)
# 221	instantiation	245, 246, 374, 337, 351, 304	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |2 * pi * ((2^{t} * delta) - l)| = (|2| * |pi| * |(2^{t} * delta) - l|)
# 	n : 3, x : (2, pi, (2^{t} * delta) - l)
# 222	conjecture		|- forall_{a in ComplexNonZero} ((-a) in ComplexNonZero)
# 	proveit.numbers.negation.complex_nonzero_closure
# 223	instantiation	247, 248, 249	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * ((2^{t} * delta) - l)} in ComplexNonZero
# 	a : e, b : 2 * pi * i * ((2^{t} * delta) - l)
# 224	instantiation	449, 364, 334	|- 0 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 0
# 225	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 226	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 227	instantiation	250, 328, 360, 251*	|- (1 * e^{i * (0 + pi)}) = (-1)
# 	r : 1, theta : 0
# 228	instantiation	252, 253	|- (1 * e^{i * (0 + pi)}) = e^{i * (0 + pi)}
# 	x : e^{i * (0 + pi)}
# 229	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 230	instantiation	354, 254	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- e^{2 * pi * i * ((2^{t} * delta) - l)} = e^{i * (2 * pi * ((2^{t} * delta) - l))}
# 	f(_a) : e^{_a}, x : 2 * pi * i * ((2^{t} * delta) - l), y : i * (2 * pi * ((2^{t} * delta) - l))
# 231	instantiation	255, 391, 363, 256	|- (pi / 2) in RealPos
# 	a : pi, b : 2
# 232	conjecture		|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} ((pi * |delta - (l / 2^{t})|) in (0,pi / 2])
# 	proveit.physics.quantum.QPE._scaled_abs_delta_diff_interval
# 233	instantiation	257, 333, 365, 334, 258, 336, 337, 351, 338	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * (pi * |delta - (l / 2^{t})|)) =  \\ (2 * pi * |delta - (l / 2^{t})|)
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |delta - (l / 2^{t})|), c : ()
# 234	instantiation	325, 259, 260	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / pi) = ((2 * |delta - (l / 2^{t})|) / 1)
# 	x : (2 * pi * |delta - (l / 2^{t})|) / pi, y : (pi * (2 * |delta - (l / 2^{t})|)) / pi, z : (2 * |delta - (l / 2^{t})|) / 1
# 235	instantiation	267, 283	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * |delta - (l / 2^{t})|) / 1) = (2 * |delta - (l / 2^{t})|)
# 	x : 2 * |delta - (l / 2^{t})|
# 236	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 237	instantiation	449, 379, 261	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 238	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 239	instantiation	449, 396, 433	|- 2^{t} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t}
# 240	instantiation	449, 416, 262	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 241	instantiation	325, 263, 264	|- (|2| * |pi| * |(2^{t} * delta) - l|) = (2 * pi * |(2^{t} * delta) - l|)
# 	x : |2| * |pi| * |(2^{t} * delta) - l|, y : 2 * |pi| * |(2^{t} * delta) - l|, z : 2 * pi * |(2^{t} * delta) - l|
# 242	instantiation	325, 265, 266	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |(2^{t} * delta) - l|) / 2) = ((pi * |(2^{t} * delta) - l|) / 1)
# 	x : (2 * pi * |(2^{t} * delta) - l|) / 2, y : (2 * (pi * |(2^{t} * delta) - l|)) / 2, z : (pi * |(2^{t} * delta) - l|) / 1
# 243	instantiation	267, 293	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((pi * |(2^{t} * delta) - l|) / 1) = (pi * |(2^{t} * delta) - l|)
# 	x : pi * |(2^{t} * delta) - l|
# 244	instantiation	325, 268, 269	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)) = (2 * pi * ((2^{t} * delta) - l))
# 	x : ((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi), y : ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi, z : 2 * pi * ((2^{t} * delta) - l)
# 245	conjecture		|- forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n} in Complex} (|x_{1} *  x_{2} *  ... *  x_{n}| = (|x_{1}| *  |x_{2}| *  ... *  |x_{n}|))]
# 	proveit.numbers.absolute_value.abs_prod
# 246	conjecture		|- 3 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat3
# 247	conjecture		|- forall_{a in ComplexNonZero, b in Complex} (a^{b} in ComplexNonZero)
# 	proveit.numbers.exponentiation.exp_complex_nonzero_closure
# 248	instantiation	449, 400, 270	|- e in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : e
# 249	instantiation	271, 272, 273, 337, 351, 378, 304	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) in Complex
# 	n : 4, a : (2, pi, i, (2^{t} * delta) - l)
# 250	conjecture		|- forall_{r, theta in Real} ((r * e^{i * (theta + pi)}) = (-(r * e^{i * theta})))
# 	proveit.numbers.number_sets.complex_numbers.complex_polar_negation
# 251	instantiation	325, 274, 275	|- (1 * e^{i * 0}) = 1
# 	x : 1 * e^{i * 0}, y : 1 * 1, z : 1
# 252	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 253	instantiation	276, 357, 277	|- e^{i * (0 + pi)} in Complex
# 	a : e, b : i * (0 + pi)
# 254	instantiation	325, 278, 279	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) = (i * (2 * pi * ((2^{t} * delta) - l)))
# 	x : 2 * pi * i * ((2^{t} * delta) - l), y : i * 2 * pi * ((2^{t} * delta) - l), z : i * (2 * pi * ((2^{t} * delta) - l))
# 255	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 256	instantiation	280, 404	|- 2 != 0
# 	n : 2
# 257	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 258	instantiation	361	|- |(pi, |delta - (l / 2^{t})|)| = |(1, ..., 2)|
# 	a : pi, b : |delta - (l / 2^{t})|
# 259	instantiation	354, 281	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |delta - (l / 2^{t})|) / pi) = ((pi * (2 * |delta - (l / 2^{t})|)) / pi)
# 	f(_a) : _a / pi, x : 2 * pi * |delta - (l / 2^{t})|, y : pi * (2 * |delta - (l / 2^{t})|)
# 260	instantiation	290, 282, 292, 283, 284*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((pi * (2 * |delta - (l / 2^{t})|)) / pi) = ((2 * |delta - (l / 2^{t})|) / 1)
# 	x : pi, z : 1, y : 2 * |delta - (l / 2^{t})|
# 261	instantiation	449, 416, 285	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 262	instantiation	449, 398, 286	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 263	instantiation	354, 287	|- (|2| * |pi| * |(2^{t} * delta) - l|) = (2 * |pi| * |(2^{t} * delta) - l|)
# 	f(_a) : _a * |pi| * |(2^{t} * delta) - l|, x : |2|, y : 2
# 264	instantiation	354, 288	|- (2 * |pi| * |(2^{t} * delta) - l|) = (2 * pi * |(2^{t} * delta) - l|)
# 	f(_a) : 2 * _a * |(2^{t} * delta) - l|, x : |pi|, y : pi
# 265	instantiation	354, 289	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * pi * |(2^{t} * delta) - l|) / 2) = ((2 * (pi * |(2^{t} * delta) - l|)) / 2)
# 	f(_a) : _a / 2, x : 2 * pi * |(2^{t} * delta) - l|, y : 2 * (pi * |(2^{t} * delta) - l|)
# 266	instantiation	290, 291, 292, 293, 294*	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2 * (pi * |(2^{t} * delta) - l|)) / 2) = ((pi * |(2^{t} * delta) - l|) / 1)
# 	x : 2, z : 1, y : pi * |(2^{t} * delta) - l|
# 267	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 268	instantiation	354, 295	|- (((2 * pi * ((2^{t} * delta) - l)) + pi) - (0 + pi)) = (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi)
# 	f(_a) : ((2 * pi * ((2^{t} * delta) - l)) + pi) + _a, x : -(0 + pi), y : -pi
# 269	instantiation	325, 296, 297	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (((2 * pi * ((2^{t} * delta) - l)) + pi) - pi) = (2 * pi * ((2^{t} * delta) - l))
# 	x : ((2 * pi * ((2^{t} * delta) - l)) + pi) - pi, y : (2 * pi * ((2^{t} * delta) - l)) + pi - pi, z : 2 * pi * ((2^{t} * delta) - l)
# 270	instantiation	449, 339, 393	|- e in RealNonZero
# 	A : RealPos, B : RealNonZero, x : e
# 271	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in Complex} ((a_{1} *  a_{2} *  ... *  a_{n}) in Complex)]
# 	proveit.numbers.multiplication.mult_complex_closure
# 272	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 273	instantiation	298	|- |(2, pi, i, (2^{t} * delta) - l)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : (2^{t} * delta) - l
# 274	instantiation	354, 299	|- (1 * e^{i * 0}) = (1 * 1)
# 	f(_a) : 1 * _a, x : e^{i * 0}, y : 1
# 275	instantiation	318, 300	|- (1 * 1) = 1
# 	x : 1
# 276	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 277	instantiation	301, 378, 302	|- (i * (0 + pi)) in Complex
# 	a : i, b : 0 + pi
# 278	instantiation	331, 334, 365, 333, 336, 303, 337, 351, 378, 304	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * i * ((2^{t} * delta) - l)) =  \\ (i * 2 * pi * ((2^{t} * delta) - l))
# 	i : 0, j : 2, k : 1, a : (), b : (2, pi), c : i, d : ((2^{t} * delta) - l)
# 279	instantiation	332, 333, 373, 334, 374, 336, 378, 337, 351, 304	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (i * 2 * pi * ((2^{t} * delta) - l)) =  \\ (i * (2 * pi * ((2^{t} * delta) - l)))
# 	i : 1, j : 3, k : 0, a : (i), b : (2, pi, (2^{t} * delta) - l), c : ()
# 280	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 281	instantiation	325, 305, 306	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |delta - (l / 2^{t})|) = (pi * (2 * |delta - (l / 2^{t})|))
# 	x : 2 * pi * |delta - (l / 2^{t})|, y : pi * 2 * |delta - (l / 2^{t})|, z : pi * (2 * |delta - (l / 2^{t})|)
# 282	instantiation	449, 400, 307	|- pi in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : pi
# 283	instantiation	449, 379, 308	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) in Complex
# 	A : Real, B : Complex, x : 2 * |delta - (l / 2^{t})|
# 284	instantiation	318, 351	|- (pi * 1) = pi
# 	x : pi
# 285	instantiation	449, 398, 309	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 286	instantiation	449, 450, 433	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 287	instantiation	311, 310	|- |2| = 2
# 	x : 2
# 288	instantiation	311, 312	|- |pi| = pi
# 	x : pi
# 289	instantiation	332, 333, 365, 334, 313, 336, 337, 351, 314	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * |(2^{t} * delta) - l|) =  \\ (2 * (pi * |(2^{t} * delta) - l|))
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, |(2^{t} * delta) - l|), c : ()
# 290	conjecture		|- forall_{x, z in ComplexNonZero} [forall_{y in Complex} (((x * y) / (x * z)) = (y / z))]
# 	proveit.numbers.division.frac_cancel_left
# 291	instantiation	449, 400, 315	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 292	instantiation	449, 400, 316	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 293	instantiation	449, 379, 317	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |(2^{t} * delta) - l|) in Complex
# 	A : Real, B : Complex, x : pi * |(2^{t} * delta) - l|
# 294	instantiation	318, 337	|- (2 * 1) = 2
# 	x : 2
# 295	instantiation	354, 319	|- (-(0 + pi)) = (-pi)
# ...
# 320	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 321	instantiation	361	|- |(2 * pi * ((2^{t} * delta) - l), pi)| = |(1, ..., 2)|
# 	a : 2 * pi * ((2^{t} * delta) - l), b : pi
# 322	instantiation	449, 379, 352	|- (-pi) in Complex
# 	A : Real, B : Complex, x : -pi
# 323	conjecture		|- forall_{a, b in Complex} ((b + a - a) = b)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 324	instantiation	449, 379, 353	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * ((2^{t} * delta) - l)) in Complex
# 	A : Real, B : Complex, x : 2 * pi * ((2^{t} * delta) - l)
# 325	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 326	instantiation	354, 355	|- e^{i * 0} = e^{0}
# 	f(_a) : e^{_a}, x : i * 0, y : 0
# 327	instantiation	356, 357	|- e^{0} = 1
# 	a : e
# 328	instantiation	358, 359, 451	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 329	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 330	instantiation	449, 379, 360	|- 0 in Complex
# 	A : Real, B : Complex, x : 0
# 331	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 332	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 333	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 334	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 335	instantiation	361	|- |(2, |delta - (l / 2^{t})|)| = |(1, ..., 2)|
# 	a : 2, b : |delta - (l / 2^{t})|
# 336	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 337	instantiation	449, 379, 375	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 338	instantiation	449, 379, 362	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in Complex
# 	A : Real, B : Complex, x : |delta - (l / 2^{t})|
# 339	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 340	instantiation	368, 363, 384	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * |delta - (l / 2^{t})|) in RealPos
# 	a : 2, b : |delta - (l / 2^{t})|
# 341	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 342	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.rational_nonneg_within_real_nonneg
# 343	instantiation	449, 364, 365	|- 2 in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 2
# 344	conjecture		|- RealPos proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonneg
# 345	instantiation	449, 392, 369	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| in Real
# 	A : RealPos, B : Real, x : |(2^{t} * delta) - l|
# 346	instantiation	449, 427, 366	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 347	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 348	instantiation	449, 427, 367	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 349	instantiation	368, 391, 369	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (pi * |(2^{t} * delta) - l|) in RealPos
# 	a : pi, b : |(2^{t} * delta) - l|
# 350	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 351	instantiation	449, 379, 376	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 352	instantiation	449, 370, 371	|- (-pi) in Real
# 	A : RealNeg, B : Real, x : -pi
# 353	instantiation	372, 373, 374, 375, 376, 402	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2 * pi * ((2^{t} * delta) - l)) in Real
# 	n : 3, a : (2, pi, (2^{t} * delta) - l)
# 354	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 355	instantiation	377, 378	|- (i * 0) = 0
# 	x : i
# 356	conjecture		|- forall_{a in Complex} (a^{0} = 1)
# 	proveit.numbers.exponentiation.exp_zero_eq_one
# 357	instantiation	449, 379, 380	|- e in Complex
# 	A : Real, B : Complex, x : e
# 358	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 359	instantiation	381, 382	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 360	instantiation	449, 416, 383	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 361	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 362	instantiation	449, 392, 384	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in Real
# 	A : RealPos, B : Real, x : |delta - (l / 2^{t})|
# 363	instantiation	449, 385, 386	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 364	conjecture		|- Natural proper_subset RationalNonNeg
# 	proveit.numbers.number_sets.rational_numbers.nat_within_rational_nonneg
# 365	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 366	instantiation	449, 432, 404	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 367	instantiation	449, 432, 451	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 368	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 	proveit.numbers.multiplication.mult_real_pos_closure_bin
# 369	instantiation	394, 387	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |(2^{t} * delta) - l| in RealPos
# 	a : (2^{t} * delta) - l
# 370	conjecture		|- RealNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_neg_within_real
# 371	instantiation	388, 391	|- (-pi) in RealNeg
# 	a : pi
# 372	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in Real} ((a_{1} *  a_{2} *  ... *  a_{n}) in Real)]
# 	proveit.numbers.multiplication.mult_real_closure
# 373	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 374	instantiation	389	|- |(2, pi, (2^{t} * delta) - l)| = |(1, 2, ..., 3)|
# 	a : 2, b : pi, c : (2^{t} * delta) - l
# 375	instantiation	449, 416, 390	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 376	instantiation	449, 392, 391	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 377	conjecture		|- forall_{x in Complex} ((x * 0) = 0)
# 	proveit.numbers.multiplication.mult_zero_right
# 378	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 379	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 380	instantiation	449, 392, 393	|- e in Real
# 	A : RealPos, B : Real, x : e
# 381	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 382	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 383	conjecture		|- 0 in Rational
# 	proveit.numbers.number_sets.rational_numbers.zero_is_rational
# 384	instantiation	394, 395	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- |delta - (l / 2^{t})| in RealPos
# 	a : delta - (l / 2^{t})
# 385	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 386	instantiation	449, 396, 404	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 387	instantiation	449, 400, 397	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : (2^{t} * delta) - l
# 388	conjecture		|- forall_{a in RealPos} ((-a) in RealNeg)
# 	proveit.numbers.negation.real_neg_closure
# 389	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 390	instantiation	449, 398, 399	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 391	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 392	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 393	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 394	conjecture		|- forall_{a in ComplexNonZero} (|a| in RealPos)
# 	proveit.numbers.absolute_value.abs_nonzero_closure
# 395	instantiation	449, 400, 401	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : delta - (l / 2^{t})
# 396	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 397	instantiation	405, 402, 403	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in RealNonZero
# 	a : (2^{t} * delta) - l
# 398	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 399	instantiation	449, 450, 404	|- 2 in Integer
# 	A : NaturalPos, B : Integer, x : 2
# 400	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 401	instantiation	405, 406, 407	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) in RealNonZero
# 	a : delta - (l / 2^{t})
# 402	instantiation	408, 430	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) in Real
# 	l : l
# 403	instantiation	413, 409	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- ((2^{t} * delta) - l) != 0
# 	a : 2^{t} * delta, b : l
# 404	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 405	conjecture		|- forall_{a in Real | a != 0} (a in RealNonZero)
# 	proveit.numbers.number_sets.real_numbers.nonzero_real_is_real_nonzero
# 406	instantiation	410, 411, 412	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) in Real
# 	a : delta, b : -(l / 2^{t})
# 407	instantiation	413, 414	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (delta - (l / 2^{t})) != 0
# 	a : delta, b : l / 2^{t}
# 408	conjecture		|- forall_{l in Integer} (((2^{t} * delta) - l) in Real)
# 	proveit.physics.quantum.QPE._scaled_delta_minus_l__in__real
# 409	instantiation	415, 430, 431	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (2^{t} * delta) != l
# 	l : l
# 410	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 411	conjecture		|- delta in Real
# 	proveit.physics.quantum.QPE._delta_is_real
# 412	instantiation	449, 416, 417	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in Real
# 	A : Rational, B : Real, x : -(l / 2^{t})
# 413	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 414	instantiation	418, 430, 431	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- delta != (l / 2^{t})
# 	l : l
# 415	conjecture		|- forall_{l in Integer | l != 0} ((2^{t} * delta) != l)
# 	proveit.physics.quantum.QPE._scaled_delta_not_eq_nonzeroInt
# 416	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 417	instantiation	449, 419, 420	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in Rational
# 	A : RationalNonZero, B : Rational, x : -(l / 2^{t})
# 418	conjecture		|- forall_{l in Integer | l != 0} (delta != (l / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_not_eq_scaledNonzeroInt
# 419	conjecture		|- RationalNonZero proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_nonzero_within_rational
# 420	instantiation	421, 422	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (-(l / 2^{t})) in RationalNonZero
# 	a : l / 2^{t}
# 421	conjecture		|- forall_{a in RationalNonZero} ((-a) in RationalNonZero)
# 	proveit.numbers.negation.rational_nonzero_closure
# 422	instantiation	423, 424, 425	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l / 2^{t}) in RationalNonZero
# 	a : l, b : 2^{t}
# 423	conjecture		|- forall_{a, b in RationalNonZero} ((a / b) in RationalNonZero)
# 	proveit.numbers.division.div_rational_nonzero_closure
# 424	instantiation	449, 427, 426	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : l
# 425	instantiation	449, 427, 428	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 426	instantiation	429, 430, 431	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in IntegerNonZero
# 	a : l
# 427	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 428	instantiation	449, 432, 433	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 429	conjecture		|- forall_{a in Integer | a != 0} (a in IntegerNonZero)
# 	proveit.numbers.number_sets.integers.nonzero_int_is_int_nonzero
# 430	instantiation	449, 434, 435	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 431	instantiation	436, 441	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l != 0
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : l != 0
# 432	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 433	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 434	instantiation	437, 438, 439	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 435	instantiation	440, 441	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	A : l in {-2^{t - 1} + 1 .. 2^{t - 1}}, B : l != 0
# 436	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 437	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 438	instantiation	442, 443, 444	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 439	instantiation	449, 450, 453	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 440	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 441	instantiation	445, 446	{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- (l in {-2^{t - 1} + 1 .. 2^{t - 1}}) and (l != 0)
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : l
# 442	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 443	instantiation	449, 447, 448	|- (-2^{t - 1}) in Integer
# 	A : IntegerNeg, B : Integer, x : -2^{t - 1}
# 444	instantiation	449, 450, 451	|- 1 in Integer
# 	A : NaturalPos, B : Integer, x : 1
# 445	conjecture		|- forall_{S, y} [forall_{x in S - {y}} ((x in S) and (x != y))]
# 	proveit.logic.sets.subtraction.all_but_one_membership_unfolding
# 446	assumption		{l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})} |- l in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 447	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 448	instantiation	452, 453	|- (-2^{t - 1}) in IntegerNeg
# 	a : 2^{t - 1}
# 449	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 450	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 451	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 452	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 453	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
