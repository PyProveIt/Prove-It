# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_alpha_m_mod_as_geometric_sum">_alpha_m_mod_as_geometric_sum</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults
from proveit.numbers import two, i, pi, Mult, Exp
from proveit.physics.quantum.QPE import (
        _alpha_m_mod_evaluation, _phase_is_real, _two_pow_t_is_nat_pos)

# %%
# %proving _alpha_m_mod_as_geometric_sum
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_alpha_m_mod_as_geometric_sum">_alpha_m_mod_as_geometric_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ee3913465388bb29e3fe9c45b2e7ac2532cc2d8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3414a4b887c7c46d9fae6c2a56c87a2250e9d5650/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _alpha_m_mod_as_geometric_sum.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/a5606ad52c8cc560a897c3d312496d21d1472fd30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_alpha_m_mod_evaluation
# Out:
# |- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))

# %%
# Don't combine exponents during auto-simplification for the following steps.
Mult.change_simplification_directives(combine_all_exponents = False)

# %%
_alpha_m_mod_evaluation_inst = _alpha_m_mod_evaluation.instantiate()
# Out:
# <strong id="_alpha_m_mod_evaluation_inst">_alpha_m_mod_evaluation_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/aaa3809025d2af8847f080d7648e594bed330fc70/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/19d0223fa9ad43ebec60ee0d548585ba950cc40b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
the_summation = _alpha_m_mod_evaluation_inst.rhs.factors[1]
# Out:
# <strong id="the_summation">the_summation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c74292116586b495a81d09ec003ad696664205980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
k_domain = the_summation.domain
# Out:
# <strong id="k_domain">k_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/common/0107914a254b4cba063b4849ea3d536e6979ec8c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit import k
from proveit.logic import InSet
k_in_k_domain = InSet(k, k_domain)
# Out:
# <strong id="k_in_k_domain">k_in_k_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = defaults.assumptions + (k_in_k_domain,)
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/7d069ac2729618c6150790535824daa85a69726d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# Rewriting the summand, step by step, to get
#
# $\exp{(-\frac{2 \pi i k \ell}{2^t})}\exp{(2\pi i \varphi k)} = (\exp{(-\frac{2 \pi i k \ell}{2^t})}\exp{(2\pi i \varphi k)})^k = (e^{2\pi i (\varphi - \frac{\ell}{2^t})})^k$
#
# (so we can eventually evaluate as a geometric sum under the right circumstances in further theorems).

# %%
the_summand_01 = the_summation.instance_expr
# Out:
# <strong id="the_summand_01">the_summand_01:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/bbc394d0a8e6a2e3d51e42556eea4f8d55fae2f90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# need these for the common_power_extraction() to work
display(_phase_is_real)
display(_two_pow_t_is_nat_pos)
# Out:
# |- phase in Real
# |- 2^{t} in NaturalPos

# %%
the_summand_02 = the_summand_01.inner_expr().common_power_extraction(exp_factor=k)
# Out:
# <strong id="the_summand_02">the_summand_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/91d9415a2948e62073d06cff2a0fe751198663580/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/f87ebfbaa7c41d8dfeb93adb7caa7e68c28b59330/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# # Now we can combine exponents, but let's preserve the left side as an exception.
Mult.change_simplification_directives(combine_all_exponents = True)
Exp.change_simplification_directives(reduce_double_exponent = False)
defaults.preserved_exprs = set([the_summand_02.lhs])
# Out:
# <strong id="defaults.preserved_exprs">defaults.preserved_exprs:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/5fa23a120d9a104232629efef3cd904c9fcbf5460/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
the_summand_03 = the_summand_02.inner_expr().rhs.base.simplify()
# Out:
# <strong id="the_summand_03">the_summand_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/512bb712f12b74b0e762d9673981752f7530a8880/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/44fc8386872cd0ba9547c378b5cb798345985c5b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
the_summand_04 = the_summand_03.inner_expr().rhs.base.exponent.commute()
# Out:
# <strong id="the_summand_04">the_summand_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/e9daf327b7c520ef5bfd4711a050dd456dd022d60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/c13d2a2f5d41eb4411bcc345b1d7c3e0a746944d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
the_summand_05 = (
        the_summand_04.inner_expr().rhs.base.exponent.factor(
                Mult(two, pi, i), auto_simplify=False))
# Out:
# <strong id="the_summand_05">the_summand_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/dc8967d774a1cf020bd84e7240025b026696734e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/727b4f207a1b5fa1c66c64df2f7281fa0fc313140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# And a quick tinkering with the grouping in the exponent:

# %%
the_summand_06 = the_summand_05.inner_expr().rhs.base.exponent.disassociate(0)
# Out:
# <strong id="the_summand_06">the_summand_06:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/df30aba3a535ce7eb8609d1347296ba1cd1680060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2f5faeeeee8eb4ecce80df00c7a8d0d93c0284040/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/17e75aede09fce6b36b089f2aa5193a0302d10850/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__alpha_m_mod_as_geometric_sum/dbd10a4f71960b512552bf8ce4644227cf0eb7360/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now we can substitute the modified summand expression back into the original summation:

# %%
(_alpha_m_mod_evaluation_inst.inner_expr().
        rhs.factors[1].summand.substitute(the_summand_06.rhs))
# Out:
# Expression notebook is being updated for {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {(e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
# Expression notebook is being updated for (k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.]
# Expression notebook is being updated for (forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}), [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for [forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})] =>  \\ ([k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
# Expression notebook is being updated for (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}, e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# Expression notebook is being updated for {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# Expression notebook is being updated for ((e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}, (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
# Expression notebook is being updated for {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}. = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
# Expression notebook is being updated for {_a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for k -> {_a(k) if k in {0 .. 2^{t} - 1}.
# Expression notebook is being updated for (k -> {_a(k) if k in {0 .. 2^{t} - 1}.)
# Expression notebook is being updated for Sum_{k = 0}^{2^{t} - 1} _a(k)
# Expression notebook is being updated for (1 / 2^{t}, Sum_{k = 0}^{2^{t} - 1} _a(k))
# Expression notebook is being updated for (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} _a(k))
# Expression notebook is being updated for (alpha_{m mod 2^{t}}, (1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} _a(k)))
# Expression notebook is being updated for alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} _a(k)))
# Expression notebook is being updated for (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))), alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# Expression notebook is being updated for (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))) = (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# {m in Integer} |- alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}))
# _alpha_m_mod_as_geometric_sum may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._alpha_m_mod_as_geometric_sum has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# 1	instantiation	2, 3, 4	{m in Integer} |- alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}))
# 	P : alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))), Q : alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}))
# 2	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 3	instantiation	5, 189	{m in Integer} |- alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))
# 	m : m
# 4	instantiation	85, 6, 7*, 8*	{m in Integer} |- (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})))) = (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})))
# 	f(_a) : alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} _a(k))), x(k) : {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}., y(k) : {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.
# 5	conjecture		|- forall_{m in Integer} (alpha_{m mod 2^{t}} = ((1 / 2^{t}) * (Sum_{k = 0}^{2^{t} - 1} (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}))))
# 	proveit.physics.quantum.QPE._alpha_m_mod_evaluation
# 6	modus ponens	9, 10	{m in Integer} |- [k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.]
# 7	instantiation	11, 184	{k in {0 .. 2^{t} - 1}} |- {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}. = (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k})
# 	a : e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, Q : k in {0 .. 2^{t} - 1}
# 8	instantiation	11, 184	{k in {0 .. 2^{t} - 1}} |- {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}. = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
# 	a : (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}, Q : k in {0 .. 2^{t} - 1}
# 9	instantiation	12, 177	|- [forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})] =>  \\ ([k -> {e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k} if k in {0 .. 2^{t} - 1}.] =  \\ [k -> {(e^{2 * pi * i * (phase - (m / 2^{t}))})^{k} if k in {0 .. 2^{t} - 1}.])
# 	i : 1, f(k) : e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, g(k) : (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}, Q(k) : k in {0 .. 2^{t} - 1}, a : (k), b : (k), c : (k)
# 10	generalization	13	{m in Integer} |- forall_{k in {0 .. 2^{t} - 1}} ((e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k})
# 11	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 12	conjecture		|- forall_{i in NaturalPos} [forall_{f, g, Q} ([forall_{a_{1}, a_{2}, ..., a_{i} | Q(a_{1}, a_{2}, ..., a_{i})} (f(a_{1}, a_{2}, ..., a_{i}) = g(a_{1}, a_{2}, ..., a_{i}))] =>  \\ ([(b_{1}, b_{2}, ..., b_{i}) -> {f(b_{1}, b_{2}, ..., b_{i}) if Q(b_{1}, b_{2}, ..., b_{i}).] =  \\ [(c_{1}, c_{2}, ..., c_{i}) -> {g(c_{1}, c_{2}, ..., c_{i}) if Q(c_{1}, c_{2}, ..., c_{i}).]))]
# 	proveit.core_expr_types.lambda_maps.general_lambda_substitution
# 13	instantiation	131, 14, 15	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{2 * pi * i * (phase - (m / 2^{t}))})^{k}
# 	P(_a) : (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{_a})^{k}, x : (2 * pi * i) * (phase - (m / 2^{t})), y : 2 * pi * i * (phase - (m / 2^{t}))
# 14	instantiation	131, 16, 17	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{(2 * pi * i) * (phase - (m / 2^{t}))})^{k}
# 	P(_a) : (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{_a})^{k}, x : (2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t}), y : (2 * pi * i) * (phase - (m / 2^{t}))
# 15	instantiation	158, 159, 126, 205, 160, 127, 172, 173, 163, 18	{m in Integer} |- ((2 * pi * i) * (phase - (m / 2^{t}))) =  \\ (2 * pi * i * (phase - (m / 2^{t})))
# 	i : 0, j : 3, k : 1, a : (), b : (2, pi, i), c : (phase - (m / 2^{t}))
# 16	instantiation	131, 19, 20	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{(2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t})})^{k}
# 	P(_a) : (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{_a})^{k}, x : -((2 * pi * i * m) / 2^{t}) + (2 * pi * i * phase), y : (2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t})
# 17	instantiation	31, 21, 22, 23	{m in Integer} |- ((2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t})) = ((2 * pi * i) * (phase - (m / 2^{t})))
# 	a : (2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t}), b : ((2 * pi * i) * phase) - ((2 * pi * i * m) / 2^{t}), c : ((2 * pi * i) * phase) + ((2 * pi * i) * (-(m / 2^{t}))), d : (2 * pi * i) * (phase - (m / 2^{t}))
# 18	instantiation	24, 156, 40	{m in Integer} |- (phase - (m / 2^{t})) in Complex
# 	a : phase, b : -(m / 2^{t})
# 19	instantiation	131, 25, 26	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{-((2 * pi * i * m) / 2^{t}) + (2 * pi * i * phase)})^{k}
# 	P(_a) : (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = _a^{k}, x : e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase}, y : e^{-((2 * pi * i * m) / 2^{t}) + (2 * pi * i * phase)}
# 20	instantiation	27, 64, 75	{m in Integer} |- (-((2 * pi * i * m) / 2^{t}) + (2 * pi * i * phase)) = ((2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t}))
# 	a : -((2 * pi * i * m) / 2^{t}), b : 2 * pi * i * phase
# 21	instantiation	85, 28	|- ((2 * pi * i * phase) - ((2 * pi * i * m) / 2^{t})) = (((2 * pi * i) * phase) - ((2 * pi * i * m) / 2^{t}))
# 	f(_a) : _a - ((2 * pi * i * m) / 2^{t}), x : 2 * pi * i * phase, y : (2 * pi * i) * phase
# 22	instantiation	85, 29	{m in Integer} |- (((2 * pi * i) * phase) - ((2 * pi * i * m) / 2^{t})) = (((2 * pi * i) * phase) + ((2 * pi * i) * (-(m / 2^{t}))))
# 	f(_a) : ((2 * pi * i) * phase) + _a, x : -((2 * pi * i * m) / 2^{t}), y : (2 * pi * i) * (-(m / 2^{t}))
# 23	instantiation	87, 30	{m in Integer} |- (((2 * pi * i) * phase) + ((2 * pi * i) * (-(m / 2^{t})))) = ((2 * pi * i) * (phase - (m / 2^{t})))
# 	x : (2 * pi * i) * (phase - (m / 2^{t})), y : ((2 * pi * i) * phase) + ((2 * pi * i) * (-(m / 2^{t})))
# 24	conjecture		|- forall_{a, b in Complex} ((a + b) in Complex)
# 	proveit.numbers.addition.add_complex_closure_bin
# 25	instantiation	31, 32, 33, 34	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase})^{k}
# 	a : e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}, b : (e^{-((2 * pi * i * m) / 2^{t})})^{k} * e^{2 * pi * i * phase * k}, c : (e^{-((2 * pi * i * m) / 2^{t})})^{k} * (e^{2 * pi * i * phase})^{k}, d : (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase})^{k}
# 26	instantiation	35, 120, 64, 75	{m in Integer} |- (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase}) = e^{-((2 * pi * i * m) / 2^{t}) + (2 * pi * i * phase)}
# 	a : e, b : -((2 * pi * i * m) / 2^{t}), c : 2 * pi * i * phase
# 27	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 28	instantiation	128, 159, 126, 205, 160, 127, 172, 173, 163, 156	|- (2 * pi * i * phase) =  \\ ((2 * pi * i) * phase)
# 	i : 0, j : 3, k : 1, a : (), b : (2, pi, i), c : (phase)
# 29	instantiation	148, 36, 37	{m in Integer} |- (-((2 * pi * i * m) / 2^{t})) = ((2 * pi * i) * (-(m / 2^{t})))
# 	x : -((2 * pi * i * m) / 2^{t}), y : -((2 * pi * i) * (m / 2^{t})), z : (2 * pi * i) * (-(m / 2^{t}))
# 30	instantiation	38, 205, 198, 159, 39, 160, 102, 156, 40	{m in Integer} |- ((2 * pi * i) * (phase - (m / 2^{t}))) =  \\ (((2 * pi * i) * phase) + ((2 * pi * i) * (-(m / 2^{t}))))
# 	i : 1, j : 2, k : 0, a : (2 * pi * i), b : (phase, -(m / 2^{t})), c : ()
# 31	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 32	instantiation	85, 41	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * k * m) / 2^{t})} * e^{2 * pi * i * phase * k}) = ((e^{-((2 * pi * i * m) / 2^{t})})^{k} * e^{2 * pi * i * phase * k})
# 	f(_a) : _a * e^{2 * pi * i * phase * k}, x : e^{-((2 * pi * i * k * m) / 2^{t})}, y : (e^{-((2 * pi * i * m) / 2^{t})})^{k}
# 33	instantiation	85, 42	{k in {0 .. 2^{t} - 1}} |- ((e^{-((2 * pi * i * m) / 2^{t})})^{k} * e^{2 * pi * i * phase * k}) = ((e^{-((2 * pi * i * m) / 2^{t})})^{k} * (e^{2 * pi * i * phase})^{k})
# 	f(_a) : (e^{-((2 * pi * i * m) / 2^{t})})^{k} * _a, x : e^{2 * pi * i * phase * k}, y : (e^{2 * pi * i * phase})^{k}
# 34	instantiation	87, 43	{m in Integer, k in {0 .. 2^{t} - 1}} |- ((e^{-((2 * pi * i * m) / 2^{t})})^{k} * (e^{2 * pi * i * phase})^{k}) = (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase})^{k}
# 	x : (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase})^{k}, y : (e^{-((2 * pi * i * m) / 2^{t})})^{k} * (e^{2 * pi * i * phase})^{k}
# 35	conjecture		|- forall_{a in RealPos, b in Complex, c in Complex} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_complex_powers
# 36	instantiation	85, 44	{m in Integer} |- (-((2 * pi * i * m) / 2^{t})) = (-((2 * pi * i) * (m / 2^{t})))
# 	f(_a) : -_a, x : (2 * pi * i * m) / 2^{t}, y : (2 * pi * i) * (m / 2^{t})
# 37	instantiation	87, 45	{m in Integer} |- (-((2 * pi * i) * (m / 2^{t}))) = ((2 * pi * i) * (-(m / 2^{t})))
# 	x : (2 * pi * i) * (-(m / 2^{t})), y : -((2 * pi * i) * (m / 2^{t}))
# 38	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} +  b_{2} +  ... +  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * b_{1}* c_{1} *  c_{2} *  ... *  c_{k}) +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{2}* c_{1} *  c_{2} *  ... *  c_{k}) +  ... +  (a_{1} *  a_{2} *  ... *  a_{i} * b_{j}* c_{1} *  c_{2} *  ... *  c_{k})))]
# 	proveit.numbers.multiplication.distribute_through_sum
# 39	instantiation	174	|- |(phase, -(m / 2^{t}))| = |(1, ..., 2)|
# 	a : phase, b : -(m / 2^{t})
# 40	instantiation	76, 58	{m in Integer} |- (-(m / 2^{t})) in Complex
# 	a : m / 2^{t}
# 41	instantiation	148, 46, 47	{k in {0 .. 2^{t} - 1}, m in Integer} |- e^{-((2 * pi * i * k * m) / 2^{t})} = (e^{-((2 * pi * i * m) / 2^{t})})^{k}
# 	x : e^{-((2 * pi * i * k * m) / 2^{t})}, y : e^{-(((2 * pi * i * m) / 2^{t}) * k)}, z : (e^{-((2 * pi * i * m) / 2^{t})})^{k}
# 42	instantiation	148, 48, 49	{k in {0 .. 2^{t} - 1}} |- e^{2 * pi * i * phase * k} = (e^{2 * pi * i * phase})^{k}
# 	x : e^{2 * pi * i * phase * k}, y : e^{(2 * pi * i * phase) * k}, z : (e^{2 * pi * i * phase})^{k}
# 43	instantiation	50, 51, 52, 154, 53, 54	{m in Integer, k in {0 .. 2^{t} - 1}} |- (e^{-((2 * pi * i * m) / 2^{t})} * e^{2 * pi * i * phase})^{k} = ((e^{-((2 * pi * i * m) / 2^{t})})^{k} * (e^{2 * pi * i * phase})^{k})
# 	a : e^{-((2 * pi * i * m) / 2^{t})}, b : e^{2 * pi * i * phase}, c : k
# 44	instantiation	148, 55, 56	{m in Integer} |- ((2 * pi * i * m) / 2^{t}) = ((2 * pi * i) * (m / 2^{t}))
# 	x : (2 * pi * i * m) / 2^{t}, y : ((2 * pi * i) * m) / 2^{t}, z : (2 * pi * i) * (m / 2^{t})
# 45	instantiation	57, 102, 58	{m in Integer} |- ((2 * pi * i) * (-(m / 2^{t}))) = (-((2 * pi * i) * (m / 2^{t})))
# 	x : 2 * pi * i, y : m / 2^{t}
# 46	instantiation	85, 59	{k in {0 .. 2^{t} - 1}, m in Integer} |- e^{-((2 * pi * i * k * m) / 2^{t})} = e^{-(((2 * pi * i * m) / 2^{t}) * k)}
# 	f(_a) : e^{-_a}, x : (2 * pi * i * k * m) / 2^{t}, y : ((2 * pi * i * m) / 2^{t}) * k
# 47	instantiation	87, 60	{k in {0 .. 2^{t} - 1}, m in Integer} |- e^{-(((2 * pi * i * m) / 2^{t}) * k)} = (e^{-((2 * pi * i * m) / 2^{t})})^{k}
# 	x : (e^{-((2 * pi * i * m) / 2^{t})})^{k}, y : e^{-(((2 * pi * i * m) / 2^{t}) * k)}
# 48	instantiation	85, 61	{k in {0 .. 2^{t} - 1}} |- e^{2 * pi * i * phase * k} = e^{(2 * pi * i * phase) * k}
# 	f(_a) : e^{_a}, x : 2 * pi * i * phase * k, y : (2 * pi * i * phase) * k
# 49	instantiation	87, 62	{k in {0 .. 2^{t} - 1}} |- e^{(2 * pi * i * phase) * k} = (e^{2 * pi * i * phase})^{k}
# 	x : (e^{2 * pi * i * phase})^{k}, y : e^{(2 * pi * i * phase) * k}
# 50	conjecture		|- forall_{a in Complex, b in Complex, c in Real | a != 0, b != 0} ((a * b)^{c} = (a^{c} * b^{c}))
# 	proveit.numbers.exponentiation.real_power_of_product
# 51	instantiation	63, 79, 64	{m in Integer} |- e^{-((2 * pi * i * m) / 2^{t})} in Complex
# 	a : e, b : -((2 * pi * i * m) / 2^{t})
# 52	instantiation	63, 79, 75	|- e^{2 * pi * i * phase} in Complex
# 	a : e, b : 2 * pi * i * phase
# 53	instantiation	78, 79, 64, 81	{m in Integer} |- e^{-((2 * pi * i * m) / 2^{t})} != 0
# 	a : e, b : -((2 * pi * i * m) / 2^{t})
# 54	instantiation	65, 66, 67	|- e^{2 * pi * i * phase} != 0
# 	P(_a) : _a != 0, x : e^{2 * pi * i * phase}, y : e^{2 * phase * i * pi}
# 55	instantiation	85, 68	{m in Integer} |- ((2 * pi * i * m) / 2^{t}) = (((2 * pi * i) * m) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * m, y : (2 * pi * i) * m
# 56	instantiation	87, 69	{m in Integer} |- (((2 * pi * i) * m) / 2^{t}) = ((2 * pi * i) * (m / 2^{t}))
# 	x : (2 * pi * i) * (m / 2^{t}), y : ((2 * pi * i) * m) / 2^{t}
# 57	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 58	instantiation	93, 164, 140, 94	{m in Integer} |- (m / 2^{t}) in Complex
# 	a : m, b : 2^{t}
# 59	instantiation	148, 70, 71	{k in {0 .. 2^{t} - 1}, m in Integer} |- ((2 * pi * i * k * m) / 2^{t}) = (((2 * pi * i * m) / 2^{t}) * k)
# 	x : (2 * pi * i * k * m) / 2^{t}, y : ((2 * pi * i * m) * k) / 2^{t}, z : ((2 * pi * i * m) / 2^{t}) * k
# 60	instantiation	72, 79, 77, 81	{k in {0 .. 2^{t} - 1}, m in Integer} |- (e^{-((2 * pi * i * m) / 2^{t})})^{k} = e^{-(((2 * pi * i * m) / 2^{t}) * k)}
# 	a : e, b : (2 * pi * i * m) / 2^{t}
# 61	instantiation	128, 159, 129, 205, 160, 73, 172, 173, 163, 156, 138	{k in {0 .. 2^{t} - 1}} |- (2 * pi * i * phase * k) =  \\ ((2 * pi * i * phase) * k)
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, phase), c : (k)
# 62	instantiation	74, 79, 75, 81	{k in {0 .. 2^{t} - 1}} |- (e^{2 * pi * i * phase})^{k} = e^{(2 * pi * i * phase) * k}
# 	a : e, b : 2 * pi * i * phase
# 63	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 64	instantiation	76, 77	{m in Integer} |- (-((2 * pi * i * m) / 2^{t})) in Complex
# 	a : (2 * pi * i * m) / 2^{t}
# 65	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 66	instantiation	78, 79, 80, 81	|- e^{2 * phase * i * pi} != 0
# 	a : e, b : 2 * phase * i * pi
# 67	instantiation	85, 82	|- e^{2 * pi * i * phase} = e^{2 * phase * i * pi}
# 	f(_a) : e^{_a}, x : 2 * pi * i * phase, y : 2 * phase * i * pi
# 68	instantiation	128, 159, 126, 205, 160, 127, 172, 173, 163, 164	{m in Integer} |- (2 * pi * i * m) =  \\ ((2 * pi * i) * m)
# 	i : 0, j : 3, k : 1, a : (), b : (2, pi, i), c : (m)
# 69	instantiation	106, 102, 164, 109, 108, 83*, 84*	{m in Integer} |- ((2 * pi * i) * (m / 2^{t})) = (((2 * pi * i) * m) / 2^{t})
# 	x : 2 * pi * i, y : m, z : 1, w : 2^{t}
# 70	instantiation	85, 86	{k in {0 .. 2^{t} - 1}, m in Integer} |- ((2 * pi * i * k * m) / 2^{t}) = (((2 * pi * i * m) * k) / 2^{t})
# 	f(_a) : _a / 2^{t}, x : 2 * pi * i * k * m, y : (2 * pi * i * m) * k
# 71	instantiation	87, 88	{m in Integer, k in {0 .. 2^{t} - 1}} |- (((2 * pi * i * m) * k) / 2^{t}) = (((2 * pi * i * m) / 2^{t}) * k)
# 	x : ((2 * pi * i * m) / 2^{t}) * k, y : ((2 * pi * i * m) * k) / 2^{t}
# 72	instantiation	89, 178	{k in {0 .. 2^{t} - 1}} |- forall_{a, b in Complex | a != 0} ((a^{-b})^{k} = a^{-(b * k)})
# 	n : k
# 73	instantiation	146	|- |(2, pi, i, phase)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : phase
# 74	instantiation	90, 178	{k in {0 .. 2^{t} - 1}} |- forall_{a, b in Complex | a != 0} ((a^{b})^{k} = a^{b * k})
# 	n : k
# 75	instantiation	131, 91, 92	|- (2 * pi * i * phase) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * phase), y : 2 * pi * i * phase
# 76	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 77	instantiation	93, 107, 140, 94	{m in Integer} |- ((2 * pi * i * m) / 2^{t}) in Complex
# 	a : 2 * pi * i * m, b : 2^{t}
# 78	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_not_eq_zero
# 79	instantiation	203, 180, 95	|- e in Complex
# 	A : Real, B : Complex, x : e
# 80	instantiation	131, 96, 97	|- (2 * phase * i * pi) in Complex
# 	P(_a) : _a in Complex, x : (2 * phase) * (i * pi), y : 2 * phase * i * pi
# 81	instantiation	98, 99	|- e != 0
# 	x : e
# 82	instantiation	148, 100, 101	|- (2 * pi * i * phase) = (2 * phase * i * pi)
# 	x : 2 * pi * i * phase, y : 2 * phase * pi * i, z : 2 * phase * i * pi
# 83	instantiation	137, 102	|- ((2 * pi * i) / 1) = (2 * pi * i)
# 	x : 2 * pi * i
# 84	instantiation	103, 140	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 85	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 86	instantiation	148, 104, 105	{k in {0 .. 2^{t} - 1}, m in Integer} |- (2 * pi * i * k * m) = ((2 * pi * i * m) * k)
# 	x : 2 * pi * i * k * m, y : 2 * pi * i * m * k, z : (2 * pi * i * m) * k
# 87	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 88	instantiation	106, 107, 138, 108, 109, 110*, 111*	{m in Integer, k in {0 .. 2^{t} - 1}} |- (((2 * pi * i * m) / 2^{t}) * k) = (((2 * pi * i * m) * k) / 2^{t})
# 	x : 2 * pi * i * m, y : k, z : 2^{t}, w : 1
# 89	conjecture		|- forall_{n in Integer} [forall_{a, b in Complex | a != 0} ((a^{-b})^{n} = a^{-(b * n)})]
# 	proveit.numbers.exponentiation.int_exp_of_neg_exp
# 90	conjecture		|- forall_{n in Integer} [forall_{a, b in Complex | a != 0} ((a^{b})^{n} = a^{b * n})]
# 	proveit.numbers.exponentiation.int_exp_of_exp
# 91	instantiation	171, 157, 112	|- ((2 * pi) * (i * phase)) in Complex
# 	a : 2 * pi, b : i * phase
# 92	instantiation	148, 113, 114	|- ((2 * pi) * (i * phase)) = (2 * pi * i * phase)
# 	x : (2 * pi) * (i * phase), y : (2 * pi) * i * phase, z : 2 * pi * i * phase
# 93	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 94	instantiation	115, 200	|- 2^{t} != 0
# 	n : 2^{t}
# 95	instantiation	203, 187, 120	|- e in Real
# 	A : RealPos, B : Real, x : e
# 96	instantiation	171, 142, 116	|- ((2 * phase) * (i * pi)) in Complex
# 	a : 2 * phase, b : i * pi
# 97	instantiation	148, 117, 118	|- ((2 * phase) * (i * pi)) = (2 * phase * i * pi)
# 	x : (2 * phase) * (i * pi), y : (2 * phase) * i * pi, z : 2 * phase * i * pi
# 98	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 99	instantiation	203, 119, 120	|- e in RealNonZero
# 	A : RealPos, B : RealNonZero, x : e
# 100	instantiation	122, 205, 198, 159, 121, 160, 172, 173, 163, 156	|- (2 * pi * i * phase) =  \\ (2 * phase * pi * i)
# 	i : 1, j : 2, k : 0, a : (2), b : (pi, i), c : phase, d : ()
# 101	instantiation	122, 198, 205, 159, 143, 160, 172, 156, 173, 163	|- (2 * phase * pi * i) =  \\ (2 * phase * i * pi)
# 	i : 2, j : 1, k : 0, a : (2, phase), b : (pi), c : i, d : ()
# 102	instantiation	131, 123, 124	|- (2 * pi * i) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * i, y : 2 * pi * i
# 103	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 104	instantiation	125, 126, 205, 159, 127, 160, 172, 173, 163, 138, 164	{k in {0 .. 2^{t} - 1}, m in Integer} |- (2 * pi * i * k * m) =  \\ (2 * pi * i * m * k)
# 	i : 3, j : 1, k : 0, a : (2, pi, i), b : k, c : (m), d : ()
# 105	instantiation	128, 159, 129, 205, 160, 130, 172, 173, 163, 164, 138	{m in Integer, k in {0 .. 2^{t} - 1}} |- (2 * pi * i * m * k) =  \\ ((2 * pi * i * m) * k)
# 	i : 0, j : 4, k : 1, a : (), b : (2, pi, i, m), c : (k)
# 106	conjecture		|- forall_{x, y in Complex} [forall_{z, w in ComplexNonZero} (((x / z) * (y / w)) = ((x * y) / (z * w)))]
# 	proveit.numbers.division.prod_of_fracs
# 107	instantiation	131, 132, 133	{m in Integer} |- (2 * pi * i * m) in Complex
# 	P(_a) : _a in Complex, x : (2 * pi) * (i * m), y : 2 * pi * i * m
# 108	instantiation	203, 135, 134	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 109	instantiation	203, 135, 136	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 110	instantiation	137, 138	{k in {0 .. 2^{t} - 1}} |- (k / 1) = k
# 	x : k
# 111	instantiation	139, 140	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 112	instantiation	171, 163, 156	|- (i * phase) in Complex
# 	a : i, b : phase
# 113	instantiation	158, 205, 198, 159, 141, 160, 157, 163, 156	|- ((2 * pi) * (i * phase)) =  \\ ((2 * pi) * i * phase)
# 	i : 1, j : 2, k : 0, a : (2 * pi), b : (i, phase), c : ()
# 114	instantiation	158, 159, 198, 160, 161, 141, 172, 173, 163, 156	|- ((2 * pi) * i * phase) =  \\ (2 * pi * i * phase)
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : (i, phase)
# 115	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 116	instantiation	171, 163, 173	|- (i * pi) in Complex
# 	a : i, b : pi
# 117	instantiation	158, 205, 198, 159, 144, 160, 142, 163, 173	|- ((2 * phase) * (i * pi)) =  \\ ((2 * phase) * i * pi)
# 	i : 1, j : 2, k : 0, a : (2 * phase), b : (i, pi), c : ()
# 118	instantiation	158, 159, 198, 160, 143, 144, 172, 156, 163, 173	|- ((2 * phase) * i * pi) =  \\ (2 * phase * i * pi)
# 	i : 0, j : 2, k : 2, a : (), b : (2, phase), c : (i, pi)
# 119	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 120	conjecture		|- e in RealPos
# 	proveit.numbers.number_sets.real_numbers.e_is_real_pos
# 121	instantiation	174	|- |(pi, i)| = |(1, ..., 2)|
# 	a : pi, b : i
# 122	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j} * c* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * c* b_{1} *  b_{2} *  ... *  b_{j}* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.leftward_commutation
# 123	instantiation	171, 157, 163	|- ((2 * pi) * i) in Complex
# 	a : 2 * pi, b : i
# 124	instantiation	158, 159, 198, 205, 160, 161, 172, 173, 163	|- ((2 * pi) * i) =  \\ (2 * pi * i)
# 	i : 0, j : 2, k : 1, a : (), b : (2, pi), c : (i)
# 125	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j}, d_{1}, d_{2}, ..., d_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * b* c_{1} *  c_{2} *  ... *  c_{j}* d_{1} *  d_{2} *  ... *  d_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* c_{1} *  c_{2} *  ... *  c_{j} * b* d_{1} *  d_{2} *  ... *  d_{k}))]
# 	proveit.numbers.multiplication.rightward_commutation
# 126	conjecture		|- 3 in Natural
# 	proveit.numbers.numerals.decimals.nat3
# 127	instantiation	145	|- |(2, pi, i)| = |(1, 2, ..., 3)|
# 	a : 2, b : pi, c : i
# 128	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.association
# 129	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 130	instantiation	146	|- |(2, pi, i, m)| = |(1, 2, ..., 4)|
# 	a : 2, b : pi, c : i, d : m
# 131	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 132	instantiation	171, 157, 147	{m in Integer} |- ((2 * pi) * (i * m)) in Complex
# 	a : 2 * pi, b : i * m
# 133	instantiation	148, 149, 150	{m in Integer} |- ((2 * pi) * (i * m)) = (2 * pi * i * m)
# 	x : (2 * pi) * (i * m), y : (2 * pi) * i * m, z : 2 * pi * i * m
# 134	instantiation	203, 152, 151	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 135	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 136	instantiation	203, 152, 153	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 137	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 138	instantiation	203, 180, 154	{k in {0 .. 2^{t} - 1}} |- k in Complex
# 	A : Real, B : Complex, x : k
# 139	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 140	instantiation	203, 180, 155	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 141	instantiation	174	|- |(i, phase)| = |(1, ..., 2)|
# 	a : i, b : phase
# 142	instantiation	171, 172, 156	|- (2 * phase) in Complex
# 	a : 2, b : phase
# 143	instantiation	174	|- |(2, phase)| = |(1, ..., 2)|
# 	a : 2, b : phase
# 144	instantiation	174	|- |(i, pi)| = |(1, ..., 2)|
# 	a : i, b : pi
# 145	conjecture		|- forall_{a, b, c} (|(a, b, c)| = |(1, 2, ..., 3)|)
# 	proveit.numbers.numerals.decimals.tuple_len_3_typical_eq
# 146	conjecture		|- forall_{a, b, c, d} (|(a, b, c, d)| = |(1, 2, ..., 4)|)
# 	proveit.numbers.numerals.decimals.tuple_len_4_typical_eq
# 147	instantiation	171, 163, 164	{m in Integer} |- (i * m) in Complex
# 	a : i, b : m
# 148	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 149	instantiation	158, 205, 198, 159, 162, 160, 157, 163, 164	{m in Integer} |- ((2 * pi) * (i * m)) =  \\ ((2 * pi) * i * m)
# 	i : 1, j : 2, k : 0, a : (2 * pi), b : (i, m), c : ()
# 150	instantiation	158, 159, 198, 160, 161, 162, 172, 173, 163, 164	{m in Integer} |- ((2 * pi) * i * m) =  \\ (2 * pi * i * m)
# 	i : 0, j : 2, k : 2, a : (), b : (2, pi), c : (i, m)
# 151	instantiation	203, 166, 165	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 152	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 153	instantiation	203, 166, 167	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 154	instantiation	203, 185, 168	{k in {0 .. 2^{t} - 1}} |- k in Real
# 	A : Rational, B : Real, x : k
# 155	instantiation	203, 185, 169	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 156	instantiation	203, 180, 170	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 157	instantiation	171, 172, 173	|- (2 * pi) in Complex
# 	a : 2, b : pi
# 158	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (b_{1} *  b_{2} *  ... *  b_{j})* c_{1} *  c_{2} *  ... *  c_{k}) =  \\ (a_{1} *  a_{2} *  ... *  a_{i}* b_{1} *  b_{2} *  ... *  b_{j}* c_{1} *  c_{2} *  ... *  c_{k}))]
# 	proveit.numbers.multiplication.disassociation
# 159	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 160	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 161	instantiation	174	|- |(2, pi)| = |(1, ..., 2)|
# 	a : 2, b : pi
# 162	instantiation	174	|- |(i, m)| = |(1, ..., 2)|
# 	a : i, b : m
# 163	conjecture		|- i in Complex
# 	proveit.numbers.number_sets.complex_numbers.i_is_complex
# 164	instantiation	203, 180, 175	{m in Integer} |- m in Complex
# 	A : Real, B : Complex, x : m
# 165	instantiation	203, 176, 200	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 166	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 167	instantiation	203, 176, 177	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 168	instantiation	203, 193, 178	{k in {0 .. 2^{t} - 1}} |- k in Rational
# 	A : Integer, B : Rational, x : k
# 169	instantiation	203, 193, 196	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 170	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 171	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 172	instantiation	203, 180, 179	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 173	instantiation	203, 180, 181	|- pi in Complex
# 	A : Real, B : Complex, x : pi
# 174	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 175	instantiation	203, 185, 182	{m in Integer} |- m in Real
# 	A : Rational, B : Real, x : m
# 176	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 177	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 178	instantiation	203, 183, 184	{k in {0 .. 2^{t} - 1}} |- k in Integer
# 	A : {0 .. 2^{t} - 1}, B : Integer, x : k
# 179	instantiation	203, 185, 186	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 180	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 181	instantiation	203, 187, 188	|- pi in Real
# 	A : RealPos, B : Real, x : pi
# 182	instantiation	203, 193, 189	{m in Integer} |- m in Rational
# 	A : Integer, B : Rational, x : m
# 183	instantiation	190, 191, 192	|- {0 .. 2^{t} - 1} proper_subset Integer
# 	a : 0, b : 2^{t} - 1
# 184	assumption		{k in {0 .. 2^{t} - 1}} |- k in {0 .. 2^{t} - 1}
# 185	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 186	instantiation	203, 193, 194	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 187	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 188	conjecture		|- pi in RealPos
# 	proveit.numbers.number_sets.real_numbers.pi_is_real_pos
# 189	assumption		{m in Integer} |- m in Integer
# 190	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 191	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 192	instantiation	195, 196, 197	|- (2^{t} - 1) in Integer
# 	a : 2^{t}, b : -1
# 193	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 194	instantiation	203, 204, 198	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 195	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 196	instantiation	203, 199, 200	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 197	instantiation	201, 202	|- (-1) in Integer
# 	a : 1
# 198	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 199	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 200	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 201	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 202	instantiation	203, 204, 205	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 203	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 204	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 205	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
