# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_b_is_zero_or_non_int">_scaled_delta_b_is_zero_or_non_int</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, n, x, A, defaults
from proveit.logic import Equals, Forall, Implies, InSet, Not, NotEquals, Or, Set
from proveit.numbers import (
        zero, one, two, Add, Exp, frac, IntervalOO, Less, LessEq, Mult, Neg, Real)
from proveit.numbers.number_sets.real_numbers import not_int_if_not_int_in_interval
from proveit.physics.quantum.QPE import (
        _b_floor, _b_round, _delta_b, _t,
        _scaled_delta_b_floor_in_interval, _scaled_delta_b_round_in_interval)

# %%
# %proving _scaled_delta_b_is_zero_or_non_int
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_delta_b_is_zero_or_non_int">_scaled_delta_b_is_zero_or_non_int:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b77d4fbf7a9efe9c1e09a239e7a87d056083f4ac0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/3875ffe0dba065cb8bfad9a7c3b5e9fc48c1a7f30/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _scaled_delta_b_is_zero_or_non_int.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/fc94743a44fa455c6682a16aed1c93018554f7bc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ### Deduce $2^t \delta_{b_f}$ in expanded interval $(-1, 1)$.

# %%
_scaled_delta_b_floor_in_interval
# Out:
# |- (2^{t} * delta_{b_{f}}) in [0,1)

# %% [markdown]
# Perhaps because of the integer bounds involved, Prove-It has no trouble expanding that interval to the desired open interval $(-1, 1)$:

# %%
InSet(_scaled_delta_b_floor_in_interval.element, IntervalOO(Neg(one), one)).prove()
# Out:
# |- (2^{t} * delta_{b_{f}}) in (-1,1)

# %% [markdown]
# ### Deduce $2^t \delta_{b_r}$ in expanded interval $(-1, 1)$.

# %% [markdown]
# The automation is insufficient when trying to do the analogous thing for $2^t \delta_{b_r}$, so we have to do a bit more work. We seem to need explicit derivations that $-1 < -\frac{1}{2}$ and $\frac{1}{2} < 1$ to allow the domain interval expansion.

# %%
_scaled_delta_b_round_in_interval
# Out:
# |- (2^{t} * delta_{b_{r}}) in [-(1 / 2),1 / 2)

# %%
# To avoid an error in the next cell (even after re-setting presumptions):
# ProofFailure: Unable to prove ((-1) / 1) = (-1) assuming {b in {b_{f}, b_{r}}}:
# Infinite 'conclude' recursion blocked.
frac(Neg(one), one).factorization(one).inner_expr().rhs.simplify()
# Out:
# |- ((-1) / 1) = (-1)

# %%
neg_one_less_neg_one_half = Less(Neg(one), Neg(frac(one, two))).prove()
# Out:
# <strong id="neg_one_less_neg_one_half">neg_one_less_neg_one_half:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/151d5d436a492d01ef06ef187b75634380bdd7380/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/904c6c7c1021449d6b8e2e94d945cf03ddabb6ff0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Less(frac(one, two), one).prove()
# Out:
# |- (1 / 2) < 1

# %% [markdown]
# Now Prove-It can derive the expanded interval membership for $2^t \delta_{b_r}$:

# %%
InSet(_scaled_delta_b_round_in_interval.element, IntervalOO(Neg(one), one)).prove()
# Out:
# |- (2^{t} * delta_{b_{r}}) in (-1,1)

# %% [markdown]
# ### Combine the results for both the $b_f$ and $b_r$ cases:

# %%
all_scaled_deltas_in_interval_neg_one_to_one = Forall(b,
       InSet(Mult(Exp(two, _t), _delta_b), IntervalOO(Neg(one), one)),
       domain=Set(_b_floor, _b_round)).prove()
# Out:
# <strong id="all_scaled_deltas_in_interval_neg_one_to_one">all_scaled_deltas_in_interval_neg_one_to_one:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/3d40ae9026b9f82f693b3bba32fdd561730c685b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/d8dde46306a418a5c4b837a074e18a085c0c09ee0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
all_scaled_deltas_in_interval_neg_one_to_one_inst = (
        all_scaled_deltas_in_interval_neg_one_to_one.instantiate())
# Out:
# <strong id="all_scaled_deltas_in_interval_neg_one_to_one_inst">all_scaled_deltas_in_interval_neg_one_to_one_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/4bc33837de8ae91d49d951ebb5083c0daa1a5d200/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/eae12c39bb34b4c01acc0d5e1679a6749d3bfcaa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Establish that $(2^t \delta = 0) \lor (\lnot[2^t \delta = 0])$ using a version of the Law of the Excluded Middle

# %%
# for convenience
_scaled_delta_b = all_scaled_deltas_in_interval_neg_one_to_one_inst.element
# Out:
# <strong id="_scaled_delta_b">_scaled_delta_b:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/70022aaf188bb04f6bba5ff51566ec6109260fab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.logic.booleans import unfold_is_bool
unfold_is_bool
# Out:
# |- forall_{A in BOOLEAN} (A or [not](A))

# %%
non_zero_assumption = NotEquals(_scaled_delta_b, zero)
# Out:
# <strong id="non_zero_assumption">non_zero_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/3b93f28d74381ecad7b87e59e4e03086860655510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
zero_assumption = Equals(_scaled_delta_b, zero)
# Out:
# <strong id="zero_assumption">zero_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ee70118f4670b6d90126711431d24532b4c278390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
scaled_delta_b_is_zero_or_not = unfold_is_bool.instantiate({A: zero_assumption})
# Out:
# <strong id="scaled_delta_b_is_zero_or_not">scaled_delta_b_is_zero_or_not:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/aba8098c4a0535c63e0baa17e5decf334c8793470/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/f9fa60afe2ba8dc3aa6682bb6774a9c525d6b2530/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Establish that the assumptions $(2^t \delta = 0)$ and $(\lnot[2^t \delta = 0])$ _each_ imply that $(2^t \delta = 0) \lor (2^t \delta_{b} \notin \mathbb{Z})$

# %% [markdown]
# #### First, assuming that $2^t \delta_b \ne 0$

# %%
not_int_if_not_int_in_interval
# Out:
# |- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]

# %%
not_zero_assumption_gives_not_int = not_int_if_not_int_in_interval.instantiate(
    {n: zero, x: _scaled_delta_b},
    assumptions=[*defaults.assumptions, non_zero_assumption])
# Out:
# <strong id="not_zero_assumption_gives_not_int">not_zero_assumption_gives_not_int:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/3b93f28d74381ecad7b87e59e4e03086860655510/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/147b91f88bac9fac62876047159b186154e842770/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/f9ef256228ee6fc6a33bb48a5c6af55190aea4b20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Or(zero_assumption, not_zero_assumption_gives_not_int.expr).prove(
        assumptions=[*defaults.assumptions, non_zero_assumption]).as_implication(hypothesis=non_zero_assumption)
# Out:
# {b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) != 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))

# %%
not_zero_implies_not_eq_zero = non_zero_assumption.conclude_as_folded(
        assumptions = [Not(zero_assumption)]).as_implication(hypothesis=Not(zero_assumption))
# Out:
# <strong id="not_zero_implies_not_eq_zero">not_zero_implies_not_eq_zero:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/551833158481580d643c11714ba32eac9707396b0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/bb08a1ad1adeb32a37856f98c56d8310f54c4a110/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Implies(Not(zero_assumption), Or(zero_assumption, not_zero_assumption_gives_not_int.expr)).prove()
# Out:
# {b in {b_{f}, b_{r}}} |- [not]((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))

# %% [markdown]
# #### Second, assuming that $2^t \delta_b = 0$

# %%
zero_assumption_gives_zero = zero_assumption.prove(assumptions=[*defaults.assumptions, zero_assumption])
# Out:
# <strong id="zero_assumption_gives_zero">zero_assumption_gives_zero:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/ee70118f4670b6d90126711431d24532b4c278390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_is_zero_or_non_int/834010178d7eef89e65687184fc8c6096b52cdab0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/ee70118f4670b6d90126711431d24532b4c278390/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Or(zero_assumption_gives_zero.expr, not_zero_assumption_gives_not_int.expr).prove(
        assumptions=[*defaults.assumptions, zero_assumption]).as_implication(hypothesis=zero_assumption)
# Out:
# |- ((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))

# %% [markdown]
# ### Thus in all cases we have the desired conclusion:

# %%
scaled_delta_b_is_zero_or_not.derive_via_singular_dilemma(_scaled_delta_b_is_zero_or_non_int.instance_expr)
# Out:
# {b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# _scaled_delta_b_is_zero_or_non_int may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_delta_b_is_zero_or_non_int has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}} (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 1	instantiation	2, 9, 3, 4, 5, 6	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 	A : (2^{t} * delta_{b}) = 0, B : [not]((2^{t} * delta_{b}) = 0), C : ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 2	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 3	instantiation	7, 9	|- [not]((2^{t} * delta_{b}) = 0) in BOOLEAN
# 	A : (2^{t} * delta_{b}) = 0
# 4	instantiation	8, 9	|- ((2^{t} * delta_{b}) = 0) or [not]((2^{t} * delta_{b}) = 0)
# 	A : (2^{t} * delta_{b}) = 0
# 5	deduction	10	|- ((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 6	instantiation	11, 12, 13	{b in {b_{f}, b_{r}}} |- [not]((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 	P : ((2^{t} * delta_{b}) != 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)), Q : [not]((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 7	conjecture		|- forall_{A in BOOLEAN} ([not](A) in BOOLEAN)
# 	proveit.logic.booleans.negation.closure
# 8	conjecture		|- forall_{A in BOOLEAN} (A or [not](A))
# 	proveit.logic.booleans.unfold_is_bool
# 9	instantiation	14	|- ((2^{t} * delta_{b}) = 0) in BOOLEAN
# 	x : 2^{t} * delta_{b}, y : 0
# 10	instantiation	15, 26, 16	{(2^{t} * delta_{b}) = 0} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 	A : (2^{t} * delta_{b}) = 0, B : (2^{t} * delta_{b}) not-in Integer
# 11	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 12	deduction	17	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) != 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 13	instantiation	18, 19	|- (((2^{t} * delta_{b}) != 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))) = ([not]((2^{t} * delta_{b}) = 0) => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)))
# 	f(_a) : _a => (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)), x : (2^{t} * delta_{b}) != 0, y : [not]((2^{t} * delta_{b}) = 0)
# 14	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 15	theorem		|- forall_{A, B | A, [not](B)} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_left
# 16	instantiation	20, 21	{(2^{t} * delta_{b}) = 0} |- [not]((2^{t} * delta_{b}) not-in Integer)
# 	x : 2^{t} * delta_{b}, S : Integer
# 17	instantiation	22, 23, 24	{(2^{t} * delta_{b}) != 0, b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 	A : (2^{t} * delta_{b}) = 0, B : (2^{t} * delta_{b}) not-in Integer
# 18	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 19	instantiation	25	|- ((2^{t} * delta_{b}) != 0) = [not]((2^{t} * delta_{b}) = 0)
# 	x : 2^{t} * delta_{b}, y : 0
# 20	conjecture		|- forall_{x, S | x in S} [not](x not-in S)
# 	proveit.logic.sets.membership.double_negated_membership
# 21	instantiation	40, 29, 26	{(2^{t} * delta_{b}) = 0} |- (2^{t} * delta_{b}) in Integer
# 	P(_a) : _a in Integer, x : 2^{t} * delta_{b}, y : 0
# 22	theorem		|- forall_{A, B | [not](A), B} (A or B)
# 	proveit.logic.booleans.disjunction.or_if_only_right
# 23	instantiation	27, 31	{(2^{t} * delta_{b}) != 0} |- [not]((2^{t} * delta_{b}) = 0)
# 	x : 2^{t} * delta_{b}, y : 0
# 24	instantiation	28, 29, 30, 31	{b in {b_{f}, b_{r}}, (2^{t} * delta_{b}) != 0} |- (2^{t} * delta_{b}) not-in Integer
# 	n : 0, x : 2^{t} * delta_{b}
# 25	axiom		|- forall_{x, y} ((x != y) = [not](x = y))
# 	proveit.logic.equality.not_equals_def
# 26	assumption		{(2^{t} * delta_{b}) = 0} |- (2^{t} * delta_{b}) = 0
# 27	theorem		|- forall_{x, y | x != y} [not](x = y)
# 	proveit.logic.equality.unfold_not_equals
# 28	conjecture		|- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]
# 	proveit.numbers.number_sets.real_numbers.not_int_if_not_int_in_interval
# 29	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 30	instantiation	53, 32, 33, 34, 35	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) in (0 - 1,0 + 1)
# 	a : 0 - 1, b : 0 + 1, x : 2^{t} * delta_{b}
# 31	assumption		{(2^{t} * delta_{b}) != 0} |- (2^{t} * delta_{b}) != 0
# 32	instantiation	76, 113, 106	|- (0 - 1) in Real
# 	a : 0, b : -1
# 33	instantiation	76, 113, 114	|- (0 + 1) in Real
# 	a : 0, b : 1
# 34	instantiation	36, 106, 114, 45	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) in Real
# 	a : -1, b : 1, x : 2^{t} * delta_{b}
# 35	instantiation	57, 37, 38	{b in {b_{f}, b_{r}}} |- ((0 - 1) < (2^{t} * delta_{b})) and ((2^{t} * delta_{b}) < (0 + 1))
# 	A : (0 - 1) < (2^{t} * delta_{b}), B : (2^{t} * delta_{b}) < (0 + 1)
# 36	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oo__is__real
# 37	instantiation	40, 39, 62	{b in {b_{f}, b_{r}}} |- (0 - 1) < (2^{t} * delta_{b})
# 	P(_a) : _a < (2^{t} * delta_{b}), x : 0 - 1, y : -1
# 38	instantiation	40, 41, 42	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) < (0 + 1)
# 	P(_a) : (2^{t} * delta_{b}) < _a, x : 0 + 1, y : 1
# 39	instantiation	43, 106, 114, 45	{b in {b_{f}, b_{r}}} |- (-1) < (2^{t} * delta_{b})
# 	a : -1, b : 1, x : 2^{t} * delta_{b}
# 40	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 41	instantiation	44, 106, 114, 45	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) < 1
# 	a : -1, b : 1, x : 2^{t} * delta_{b}
# 42	instantiation	73, 88	|- (0 + 1) = 1
# 	a : 1
# 43	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b)} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oo_lower_bound
# 44	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oo_upper_bound
# 45	instantiation	46, 47	{b in {b_{f}, b_{r}}} |- (2^{t} * delta_{b}) in (-1,1)
# 	b : b
# 46	instantiation	48, 166, 49, 50, 51	|- forall_{b in {b_{f}, b_{r}}} ((2^{t} * delta_{b}) in (-1,1))
# 	n : 2, (a_{1}, ..., a_{2}) : (b_{f}, b_{r}), P(b) : (2^{t} * delta_{b}) in (-1,1), x : b
# 47	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 48	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P | P(a_{1}), P(a_{2}), ..., P(a_{n})} [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]]]
# 	proveit.logic.sets.enumeration.true_for_each_then_true_for_all
# 49	instantiation	144	|- |(b_{f}, b_{r})| = |(1, ..., 2)|
# 	a : b_{f}, b : b_{r}
# 50	instantiation	53, 106, 114, 107, 52	|- (2^{t} * delta_{b_{f}}) in (-1,1)
# 	a : -1, b : 1, x : 2^{t} * delta_{b_{f}}
# 51	instantiation	53, 106, 114, 110, 54	|- (2^{t} * delta_{b_{r}}) in (-1,1)
# 	a : -1, b : 1, x : 2^{t} * delta_{b_{r}}
# 52	instantiation	57, 55, 56	|- ((-1) < (2^{t} * delta_{b_{f}})) and ((2^{t} * delta_{b_{f}}) < 1)
# 	A : (-1) < (2^{t} * delta_{b_{f}}), B : (2^{t} * delta_{b_{f}}) < 1
# 53	conjecture		|- forall_{a, b, x in Real | a < x < b} (x in (a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalOO
# 54	instantiation	57, 58, 59	|- ((-1) < (2^{t} * delta_{b_{r}})) and ((2^{t} * delta_{b_{r}}) < 1)
# 	A : (-1) < (2^{t} * delta_{b_{r}}), B : (2^{t} * delta_{b_{r}}) < 1
# 55	instantiation	64, 106, 113, 60, 61, 62*, 63*	|- (-1) < (2^{t} * delta_{b_{f}})
# 	a : -1, x : 0, y : (2^{t} * delta_{b_{f}}) + 1
# 56	instantiation	103, 113, 114, 115	|- (2^{t} * delta_{b_{f}}) < 1
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 57	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 58	instantiation	64, 124, 65, 66, 67*, 68*	|- (-1) < (2^{t} * delta_{b_{r}})
# 	a : -(1 / 2), x : -(1 / 2), y : (2^{t} * delta_{b_{r}}) + (1 / 2)
# 59	instantiation	69, 70, 80	|- (2^{t} * delta_{b_{r}}) < 1
# 	P(_a) : (2^{t} * delta_{b_{r}}) < _a, x : (1 / 2) + (1 / 2), y : 1
# 60	instantiation	76, 107, 114	|- ((2^{t} * delta_{b_{f}}) + 1) in Real
# 	a : 2^{t} * delta_{b_{f}}, b : 1
# 61	instantiation	77, 113, 107, 114, 71, 72	|- 0 < ((2^{t} * delta_{b_{f}}) + 1)
# 	a : 0, b : 2^{t} * delta_{b_{f}}, c : 1
# 62	instantiation	73, 87	|- (0 - 1) = (-1)
# 	a : -1
# 63	instantiation	127, 74, 75	|- (((2^{t} * delta_{b_{f}}) + 1) - 1) = (2^{t} * delta_{b_{f}})
# 	x : ((2^{t} * delta_{b_{f}}) + 1) - 1, y : (2^{t} * delta_{b_{f}}) + 1 - 1, z : 2^{t} * delta_{b_{f}}
# 64	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 65	instantiation	76, 110, 134	|- ((2^{t} * delta_{b_{r}}) + (1 / 2)) in Real
# 	a : 2^{t} * delta_{b_{r}}, b : 1 / 2
# 66	instantiation	77, 124, 110, 134, 78, 105	|- (-(1 / 2)) < ((2^{t} * delta_{b_{r}}) + (1 / 2))
# 	a : -(1 / 2), b : 2^{t} * delta_{b_{r}}, c : 1 / 2
# 67	instantiation	79, 100, 88, 80	|- (-(1 / 2) - (1 / 2)) = (-1)
# 	a : 1 / 2, b : 1 / 2, c : 1
# 68	instantiation	127, 81, 82	|- (((2^{t} * delta_{b_{r}}) + (1 / 2)) - (1 / 2)) = (2^{t} * delta_{b_{r}})
# 	x : ((2^{t} * delta_{b_{r}}) + (1 / 2)) - (1 / 2), y : (2^{t} * delta_{b_{r}}) + (1 / 2) - (1 / 2), z : 2^{t} * delta_{b_{r}}
# 69	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 70	instantiation	83, 110, 134, 84, 85	|- (2^{t} * delta_{b_{r}}) < ((1 / 2) + (1 / 2))
# 	a : 2^{t} * delta_{b_{r}}, b : 1 / 2, c : 1 / 2
# 71	instantiation	91, 113, 114, 115	|- 0 <= (2^{t} * delta_{b_{f}})
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 72	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 73	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 74	instantiation	94, 95, 166, 143, 96, 86, 89, 88, 87	|- (((2^{t} * delta_{b_{f}}) + 1) - 1) =  \\ ((2^{t} * delta_{b_{f}}) + 1 - 1)
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t} * delta_{b_{f}}, 1), c : (-1)
# 75	instantiation	99, 88, 89, 90	|- ((2^{t} * delta_{b_{f}}) + 1 - 1) = (2^{t} * delta_{b_{f}})
# 	a : 1, b : 1, c : 2^{t} * delta_{b_{f}}
# 76	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 77	conjecture		|- forall_{a, b, c in Real | a <= b, 0 < c} (a < (b + c))
# 	proveit.numbers.ordering.less_eq_add_right_strong
# 78	instantiation	91, 124, 134, 125	|- (-(1 / 2)) <= (2^{t} * delta_{b_{r}})
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 79	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((-a - b) = (-c))
# 	proveit.numbers.addition.subtraction.negated_add
# 80	instantiation	92, 135, 163, 93*	|- ((1 / 2) + (1 / 2)) = 1
# 	a : 1, b : 2, c : 1, d : 2
# 81	instantiation	94, 95, 166, 143, 96, 97, 101, 100, 98	|- (((2^{t} * delta_{b_{r}}) + (1 / 2)) - (1 / 2)) =  \\ ((2^{t} * delta_{b_{r}}) + (1 / 2) - (1 / 2))
# 	i : 0, j : 2, k : 1, a : (), b : (2^{t} * delta_{b_{r}}, 1 / 2), c : (-(1 / 2))
# 82	instantiation	99, 100, 101, 102	|- ((2^{t} * delta_{b_{r}}) + (1 / 2) - (1 / 2)) = (2^{t} * delta_{b_{r}})
# 	a : 1 / 2, b : 1 / 2, c : 2^{t} * delta_{b_{r}}
# 83	conjecture		|- forall_{a, b, c in Real | a < b, 0 <= c} (a < (b + c))
# 	proveit.numbers.ordering.less_add_right
# 84	instantiation	103, 124, 134, 125	|- (2^{t} * delta_{b_{r}}) < (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 85	instantiation	104, 105	|- 0 <= (1 / 2)
# 	x : 0, y : 1 / 2
# 86	instantiation	144	|- |(2^{t} * delta_{b_{f}}, 1)| = |(1, ..., 2)|
# 	a : 2^{t} * delta_{b_{f}}, b : 1
# 87	instantiation	164, 151, 106	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 88	instantiation	164, 151, 114	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 89	instantiation	164, 151, 107	|- (2^{t} * delta_{b_{f}}) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta_{b_{f}}
# 90	instantiation	111	|- 1 = 1
# 	x : 1
# 91	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 92	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 93	instantiation	127, 108, 109	|- (((1 * 2) + (2 * 1)) / (2 * 2)) = 1
# 	x : ((1 * 2) + (2 * 1)) / (2 * 2), y : 4 / 4, z : 1
# 94	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 95	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 96	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 97	instantiation	144	|- |(2^{t} * delta_{b_{r}}, 1 / 2)| = |(1, ..., 2)|
# 	a : 2^{t} * delta_{b_{r}}, b : 1 / 2
# 98	instantiation	164, 151, 124	|- (-(1 / 2)) in Complex
# 	A : Real, B : Complex, x : -(1 / 2)
# 99	conjecture		|- forall_{a, b, c in Complex | a = b} ((c + a - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_23
# 100	instantiation	164, 151, 134	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 101	instantiation	164, 151, 110	|- (2^{t} * delta_{b_{r}}) in Complex
# 	A : Real, B : Complex, x : 2^{t} * delta_{b_{r}}
# 102	instantiation	111	|- (1 / 2) = (1 / 2)
# 	x : 1 / 2
# 103	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x < b)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_upper_bound
# 104	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 105	instantiation	112, 150	|- (1 / 2) > 0
# 	q : 1 / 2
# 106	instantiation	133, 114	|- (-1) in Real
# 	a : 1
# 107	instantiation	123, 113, 114, 115	|- (2^{t} * delta_{b_{f}}) in Real
# 	a : 0, b : 1, x : 2^{t} * delta_{b_{f}}
# 108	instantiation	136, 166, 116, 117, 118, 119	|- (((1 * 2) + (2 * 1)) / (2 * 2)) =  \\ (4 / 4)
# 	n : 2, f(_a, _b) : _a / _b, x : ((1 * 2) + (2 * 1), 2 * 2), y : (4, 4)
# 109	instantiation	120, 121, 122	|- (4 / 4) = 1
# 	x : 4
# 110	instantiation	123, 124, 134, 125	|- (2^{t} * delta_{b_{r}}) in Real
# 	a : -(1 / 2), b : 1 / 2, x : 2^{t} * delta_{b_{r}}
# 111	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 112	conjecture		|- forall_{q in RationalPos} (q > 0)
# 	proveit.numbers.number_sets.rational_numbers.positive_if_in_rational_pos
# 113	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 114	instantiation	164, 157, 126	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 115	conjecture		|- (2^{t} * delta_{b_{f}}) in [0,1)
# 	proveit.physics.quantum.QPE._scaled_delta_b_floor_in_interval
# 116	instantiation	144	|- |((1 * 2) + (2 * 1), 2 * 2)| = |(1, ..., 2)|
# 	a : (1 * 2) + (2 * 1), b : 2 * 2
# 117	instantiation	144	|- |(4, 4)| = |(1, ..., 2)|
# 	a : 4, b : 4
# 118	instantiation	127, 128, 129	|- ((1 * 2) + (2 * 1)) = 4
# 	x : (1 * 2) + (2 * 1), y : 2 + 2, z : 4
# 119	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 120	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 121	instantiation	164, 151, 130	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 122	instantiation	131, 132	|- 4 != 0
# 	n : 4
# 123	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 124	instantiation	133, 134	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 125	conjecture		|- (2^{t} * delta_{b_{r}}) in [-(1 / 2),1 / 2)
# 	proveit.physics.quantum.QPE._scaled_delta_b_round_in_interval
# 126	instantiation	164, 162, 135	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 127	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 128	instantiation	136, 166, 137, 138, 139, 140	|- ((1 * 2) + (2 * 1)) =  \\ (2 + 2)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 2, 2 * 1), y : (2, 2)
# 129	conjecture		|- (2 + 2) = 4
# 	proveit.numbers.numerals.decimals.add_2_2
# 130	instantiation	164, 157, 141	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 131	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 132	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 133	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 134	instantiation	164, 157, 142	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 135	instantiation	164, 165, 143	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 136	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 137	instantiation	144	|- |(1 * 2, 2 * 1)| = |(1, ..., 2)|
# 	a : 1 * 2, b : 2 * 1
# 138	instantiation	144	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 139	instantiation	145, 147	|- (1 * 2) = 2
# 	x : 2
# 140	instantiation	146, 147	|- (2 * 1) = 2
# 	x : 2
# 141	instantiation	164, 162, 148	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 142	instantiation	164, 149, 150	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 143	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 144	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 145	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 146	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 147	instantiation	164, 151, 152	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 148	instantiation	164, 165, 153	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 149	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 150	instantiation	154, 155, 156	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 151	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 152	instantiation	164, 157, 158	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 153	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 154	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 155	instantiation	164, 160, 159	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 156	instantiation	164, 160, 161	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 157	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 158	instantiation	164, 162, 163	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 159	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 160	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 161	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 162	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 163	instantiation	164, 165, 166	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 164	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 165	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 166	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
