# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_pos_domain_in_full_domain_sans_zero">_pos_domain_in_full_domain_sans_zero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import defaults, a, e, l
from proveit.logic import InSet, NotEquals
from proveit.numbers import zero, one, two
from proveit.numbers import Add, greater, Integer, NaturalPos, Less, LessEq, Neg
from proveit.numbers.negation import negated_positive_is_negative
from proveit.physics.quantum.QPE import (_full_domain, _full_domain_sans_zero,
                                         _pos_domain, _two_pow__t_minus_one)
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _pos_domain_in_full_domain_sans_zero
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_pos_domain_in_full_domain_sans_zero">_pos_domain_in_full_domain_sans_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b12dbc5e87de85f489eecb3c46f2fa094099dc140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/07af28506586e02370cb0bc6f80997d7a6f4aeeb0/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# The basic approach is to show that<br>
# $\ell\in\{e+1\ldots 2^{t-1}\}$ means $\ell\in\{-2^{t-1}+1\ldots 2^{t-1}\}$ and $\ell\ne 0$<br>
# More specifically:<br>
# (1) $\ell\in\{e+1\ldots 2^{t-1}\}$ means $\ell \le 2^{t-1}$ (and $\ell\in\mathbb{Z}$) (both auto side-effect)<br>
# (2) $\ell\in\{e+1\ldots 2^{t-1}\}$ means $e+1 \le \ell$ (auto side-effect)<br>
# (3) $e\in\{1\ldots 2^{t-1}-2\}$ means $e + 1 > 0$<br>
# (4) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell>0$.<br/>
# (5) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell\ne 0$.<br/>
# (6) Thus $\ell\in\{-2^{t-1 + 1}\ldots 2^{t-1}\}-\{0\}$

# %%
defaults.assumptions = _pos_domain_in_full_domain_sans_zero.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/d6451ebca630c456e1c1f2777c5439c1c43bd4fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [*defaults.assumptions, InSet(l, _pos_domain)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/b25719babf3e418c08bc80ca27de511c71b34d0d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %% [markdown]
# Automation will actually take care of the following three cells, but it can be useful to see the steps:

# %%
# From the default assumptions, we know 1 <= e, and thus also 0 < e
ineq_01 = Less(zero, e).prove()
# Out:
# <strong id="ineq_01">ineq_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/61c5d9c05b540d230aad7039163e9581ee63a98d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/3e73446bb253ac38e99d42495913879d1f811f160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Less(e, Add(e, one)).prove()
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- e < (e + 1)

# %%
# From the default assumptions, prove 0 < ell. Also then gives us ell != 0
# The lower and upper bounds on ell are automatic side-effects
Less(zero, l).prove()
# Out:
# {e in {1 .. 2^{t - 1} - 2}, l in {e + 1 .. 2^{t - 1}}} |- 0 < l

# %% [markdown]
# The following 2-step process is still needed, but could be automated in the future (_i.e._, if we know $a \in \mathbb{N}^+$, then we should be able to more automatically derive that $-a < 0$).

# %%
negated_positive_is_negative
# Out:
# |- forall_{a in Real | a > 0} ((-a) < 0)

# %%
negated_positive_is_negative.instantiate({a:_two_pow__t_minus_one})
# Out:
# |- (-2^{t - 1}) < 0

# %%
ineq_03 = Less(Neg(_two_pow__t_minus_one), e).prove()
# Out:
# <strong id="ineq_03">ineq_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/d815531739f10129c5ccb1a46dc1f1273cb17d320/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__pos_domain_in_full_domain_sans_zero/dd203f25be03ad8376e815feca8c8407ba34c0230/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ineq_03.derive_shifted(one)
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) < (e + 1)

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._pos_domain_in_full_domain_sans_zero has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({e + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	A : {e + 1 .. 2^{t - 1}}, B : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalization	4	{e in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {e + 1 .. 2^{t - 1}}} (_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 4	instantiation	5, 6, 7	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : _a
# 5	conjecture		|- forall_{S, y} [forall_{x in S | x != y} (x in (S - {y}))]
# 	proveit.logic.sets.subtraction.all_but_one_membership_folding
# 6	instantiation	8, 9, 65, 17, 10	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : _a
# 7	instantiation	11, 12	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a != 0
# 	n : _a
# 8	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 9	instantiation	64, 13, 61	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 10	instantiation	14, 15, 16	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- ((-2^{t - 1} + 1) <= _a) and (_a <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= _a, B : _a <= 2^{t - 1}
# 11	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 12	instantiation	45, 17, 18	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in NaturalPos
# 	a : _a
# 13	instantiation	71, 19, 51	|- (-2^{t - 1}) in Integer
# 	A : IntegerNeg, B : Integer, x : -2^{t - 1}
# 14	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 15	instantiation	20, 21	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) <= _a
# 	x : -2^{t - 1} + 1, y : _a
# 16	instantiation	22, 34, 65, 35	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a <= 2^{t - 1}
# 	a : e + 1, b : 2^{t - 1}, n : _a
# 17	instantiation	71, 23, 35	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- _a in Integer
# 	A : {e + 1 .. 2^{t - 1}}, B : Integer, x : _a
# 18	instantiation	52, 24, 26	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- 0 < _a
# 	x : 0, y : e + 1, z : _a
# 19	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 20	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 21	instantiation	52, 25, 26	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) < _a
# 	x : -2^{t - 1} + 1, y : e + 1, z : _a
# 22	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 23	instantiation	60, 34, 65	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : e + 1, b : 2^{t - 1}
# 24	instantiation	27, 28	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) > 0
# 	n : e + 1
# 25	instantiation	29, 30, 31, 32, 33	{e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1} + 1) < (e + 1)
# 	a : -2^{t - 1}, b : e, c : 1
# 26	instantiation	58, 34, 65, 35	{e in {1 .. 2^{t - 1} - 2}, _a in {e + 1 .. 2^{t - 1}}} |- (e + 1) <= _a
# 	a : e + 1, b : 2^{t - 1}, n : _a
# 27	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 28	instantiation	36, 37, 38	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 29	conjecture		|- forall_{a, b, c in Real | a < b} ((a + c) < (b + c))
# 	proveit.numbers.ordering.less_shift_add_right
# 30	instantiation	39, 40	|- (-2^{t - 1}) in Real
# 	a : 2^{t - 1}
# 31	instantiation	71, 47, 41	{e in {1 .. 2^{t - 1} - 2}} |- e in Real
# 	A : Rational, B : Real, x : e
# 32	instantiation	71, 47, 42	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 33	instantiation	43, 44, 46	{e in {1 .. 2^{t - 1} - 2}} |- (-2^{t - 1}) < e
# 	x : -2^{t - 1}, y : 0, z : e
# 34	instantiation	64, 49, 61	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 35	assumption		{_a in {e + 1 .. 2^{t - 1}}} |- _a in {e + 1 .. 2^{t - 1}}
# 36	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 37	instantiation	45, 49, 46	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 38	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 39	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 40	instantiation	71, 47, 48	|- 2^{t - 1} in Real
# 	A : Rational, B : Real, x : 2^{t - 1}
# 41	instantiation	71, 55, 49	{e in {1 .. 2^{t - 1} - 2}} |- e in Rational
# 	A : Integer, B : Rational, x : e
# 42	instantiation	71, 55, 61	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 43	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 44	instantiation	50, 51	|- (-2^{t - 1}) < 0
# 	a : -2^{t - 1}
# 45	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 46	instantiation	52, 53, 54	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 47	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 48	instantiation	71, 55, 65	|- 2^{t - 1} in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1}
# 49	instantiation	71, 56, 59	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 50	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 51	instantiation	57, 68	|- (-2^{t - 1}) in IntegerNeg
# 	a : 2^{t - 1}
# 52	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 53	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 54	instantiation	58, 61, 62, 59	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 55	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 56	instantiation	60, 61, 62	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 57	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 58	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 59	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 60	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 61	instantiation	71, 72, 63	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 62	instantiation	64, 65, 66	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 63	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 64	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 65	instantiation	71, 67, 68	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 66	instantiation	69, 70	|- (-2) in Integer
# 	a : 2
# 67	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 68	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 69	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 70	instantiation	71, 72, 73	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 71	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 72	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 73	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
