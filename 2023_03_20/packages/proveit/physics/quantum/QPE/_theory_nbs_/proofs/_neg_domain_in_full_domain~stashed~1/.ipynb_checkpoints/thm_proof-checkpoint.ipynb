# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_neg_domain_in_full_domain">_neg_domain_in_full_domain</a> theorem
# ========

# %%
import proveit
from proveit import a, defaults, l
from proveit.logic import InSet
from proveit.numbers import Less, NaturalPos
from proveit.numbers.negation import negated_positive_is_negative
from proveit.physics.quantum.QPE import _full_domain, _neg_domain, _pos_domain
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _neg_domain_in_full_domain
# Out:
# _neg_domain_in_full_domain: forall_{e in NaturalPos} [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})]

# %% [markdown]
# The basic approach is to show<br>
# (1) $\ell\in\{2^{t-1}+1\ldots-(\epsilon+1)\}$ means $-2^{t-1}+1 \le \ell$ (and $\ell\in\mathbb{Z}$)<br>
# (2) $\ell\in\{2^{t-1}+1\ldots-(\epsilon+1)\}$ means $\ell \le -(\epsilon+1)$<br>
# (3) $\epsilon\in\mathbb{N}^{+}$ means $-(\epsilon+1) < 2^{t-1}$<br>
# (4) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell$ is an Integer.<br/>
# (5) Thus $\ell\in\{-2^{t-1 + 1}\ldots 2^{t-1}\}$

# %%
defaults.assumptions = _neg_domain_in_full_domain.all_conditions()
# Out:
# defaults.assumptions: (e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)})

# %%
ell_membership = _neg_domain_in_full_domain.all_conditions()[1]
# Out:
# ell_membership: l in {-2^{t - 1} + 1 .. -(e + 1)}

# %%
ell_membership.derive_element_in_integer()
# Out:
# {e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in Integer

# %%
ell_membership.derive_element_upper_bound()
# Out:
# {e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l <= (-(e + 1))

# %%
InSet(_pos_domain.lower_bound, NaturalPos).prove()
# Out:
# {e in NaturalPos} |- (e + 1) in NaturalPos

# %%
negated_positive_is_negative
# Out:
# |- forall_{a in Real | a > 0} ((-a) < 0)

# %%
negated_positive_is_negative.instantiate({a:_pos_domain.lower_bound})
# Out:
# {e in NaturalPos} |- (-(e + 1)) < 0

# %%
Less(_neg_domain.upper_bound, _full_domain.upper_bound).prove()
# Out:
# {e in NaturalPos} |- (-(e + 1)) < 2^{t - 1}

# %%
_full_domain.deduce_elem_in_set(l)
# Out:
# {e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in NaturalPos} [forall_{l in {-2^{t - 1} + 1 .. -(e + 1)}} (l in {-2^{t - 1} + 1 .. 2^{t - 1}})]
# 1	instantiation	2, 22, 33, 3, 4	{e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 2	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 3	instantiation	36, 5, 24	{e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer, x : l
# 4	instantiation	6, 7, 8	{e in NaturalPos, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- ((-2^{t - 1} + 1) <= l) and (l <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= l, B : l <= 2^{t - 1}
# 5	instantiation	9, 22, 23	{e in NaturalPos} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 6	theorem		|- forall_{A, B | A, B} (A and B)
# ...
