# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_e_domain_sorting">_e_domain_sorting</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit import defaults
from proveit.physics.quantum.QPE import _t_in_natural_pos, _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _e_domain_sorting
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_e_domain_sorting">_e_domain_sorting:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/484c6aa5b983f27273fc553f8b6365b259993dfe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/24ee229dd31041e24a745fd7aa42e904fbeed7f00/dependencies.ipynb">dependencies</a>)<br>

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._e_domain_sorting has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ((-2^{t - 1} + 1) <= (-(e + 1)) < 0 < (e + 1) < 2^{t - 1})
# 1	instantiation	2, 3, 4, 5, 6, 7, 8	{e in {1 .. 2^{t - 1} - 2}} |- ((-2^{t - 1} + 1) <= (-(e + 1))) and ((-(e + 1)) < 0) and (0 < (e + 1)) and ((e + 1) < 2^{t - 1})
# 	m : 4, A : ((-2^{t - 1} + 1) <= (-(e + 1)), (-(e + 1)) < 0, 0 < (e + 1), (e + 1) < 2^{t - 1})
# 2	conjecture		|- forall_{m in Natural} [forall_{A_{1}, A_{2}, ..., A_{m} | A_{1}, A_{2}, ..., A_{m}} (A_{1} and  A_{2} and  ... and  A_{m})]
# 	proveit.logic.booleans.conjunction.and_if_all
# 3	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 4	instantiation	9	|- |((-2^{t - 1} + 1) <= (-(e + 1)), (-(e + 1)) < 0, 0 < (e + 1), (e + 1) < 2^{t - 1})| = |(1, 2, ..., 4)|
# 	a : (-2^{t - 1} + 1) <= (-(e + 1)), b : (-(e + 1)) < 0, c : 0 < (e + 1), d : (e + 1) < 2^{t - 1}
# ...
