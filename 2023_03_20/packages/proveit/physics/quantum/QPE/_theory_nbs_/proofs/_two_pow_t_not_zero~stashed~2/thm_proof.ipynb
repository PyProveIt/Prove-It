# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_two_pow_t_not_zero">_two_pow_t_not_zero</a> theorem
# ========

# %%
import proveit
from proveit import a, b
from proveit.numbers import two
from proveit.numbers.exponentiation import exp_not_eq_zero
from proveit.physics.quantum.QPE import _t
from proveit.physics.quantum.QPE  import _t_in_natural_pos
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _two_pow_t_not_zero
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_two_pow_t_not_zero">_two_pow_t_not_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/ba027df915a8747b17b2f8c0c6b40c763e79974f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dc0d08e801f1a81403349878b3557fa1395cb4c80/dependencies.ipynb">dependencies</a>)<br>
# _two_pow_t_not_zero may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
exp_not_eq_zero
# Out:
# |- forall_{a, b in Complex | a != 0} (a^{b} != 0)

# %%
exp_not_eq_zero.instantiate({a:two, b:_t})
# Out:
# |- 2^{t} != 0

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._two_pow_t_not_zero has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3, 4	|- 2^{t} != 0
# 	a : 2, b : t
# 1	conjecture		|- forall_{a, b in Complex | a != 0} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_not_eq_zero
# 2	instantiation	19, 6, 5	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 3	instantiation	19, 6, 7	|- t in Complex
# 	A : Real, B : Complex, x : t
# 4	instantiation	8, 9	|- 2 != 0
# 	n : 2
# 5	instantiation	19, 10, 11	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 6	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 7	instantiation	12, 13, 14	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 8	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 9	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 10	conjecture		|- Rational proper_subset Real
# ...
