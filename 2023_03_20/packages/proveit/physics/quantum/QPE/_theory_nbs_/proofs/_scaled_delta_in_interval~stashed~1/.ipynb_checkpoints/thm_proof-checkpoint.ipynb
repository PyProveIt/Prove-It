# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_in_interval">_scaled_delta_in_interval</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, c, x, defaults, ExprTuple
from proveit.logic import Equals, InSet, NotEquals
from proveit.numbers import Add, frac, Mult, Neg
from proveit.numbers import zero, Complex, Real
from proveit.numbers.rounding import real_minus_floor_interval
from proveit.physics.quantum.QPE import _best_def, _b, _delta_def, _delta_is_real, _two_pow_t, _phase
from proveit.physics.quantum.QPE import _best_is_int, _phase_in_interval, _phase_is_real, _two_pow_t_is_nat_pos

# %%
# %proving _scaled_delta_in_interval
# Out:
# _scaled_delta_in_interval: (2^{t} * delta) in [0,1)

# %% [markdown]
# The proof utilizes the chain of equalities $2^t\cdot \delta = 2^t \left(\varphi - \frac{b}{2^t}\right) = 2^t \left(\varphi - \frac{\lfloor\varphi\cdot 2^t\rfloor}{2^t}\right) = \varphi \cdot 2^t - \lfloor\varphi\cdot 2^t\rfloor$, then calls upon a theorem for the value of an expression of the form $x - \lfloor x \rfloor$.

# %%
scaled_delta = _scaled_delta_in_interval.operands[0]
# Out:
# scaled_delta: 2^{t} * delta

# %%
_delta_def
# Out:
# |- delta = (phase - (b / 2^{t}))

# %%
eq_01 = _delta_def.substitution(scaled_delta)
# Out:
# eq_01: |- (2^{t} * delta) = (2^{t} * (phase - (b / 2^{t})))

# %%
eq_02 = eq_01.inner_expr().rhs.distribute(1)
# Out:
# eq_02: |- (2^{t} * delta) = ((2^{t} * phase) - b)

# %%
_best_def
# Out:
# |- b = floor(phase * 2^{t})

# %%
best_def_commuted = _best_def.inner_expr().rhs.operands[0].commute()
# Out:
# best_def_commuted: |- b = floor(2^{t} * phase)

# %%
eq_03 = eq_02.inner_expr().rhs.operands[1].operand.substitute(best_def_commuted.rhs)
# Out:
# eq_03: |- (2^{t} * delta) = ((2^{t} * phase) - floor(2^{t} * phase))

# %% [markdown]
# $(2^t\cdot\delta)$ has now been expressed in the form $x - \lfloor x \rfloor$, and we have a theorem for the value of such an expression:

# %%
real_minus_floor_interval
# Out:
# |- forall_{x in Real} ((x - floor(x)) in [0,1))

# %% [markdown]
# We need to show that our eventual argument $x = 2^t\cdot\delta$ is Real, then instantiate our theorem:

# %%
_phase_is_real
# Out:
# |- phase in Real

# %%
InSet(Mult(_two_pow_t, _phase), Real).prove()
# Out:
# |- (2^{t} * phase) in Real

# %%
interval_claim = real_minus_floor_interval.instantiate({x:Mult(_two_pow_t, _phase)})
# Out:
# interval_claim: |- ((2^{t} * phase) - floor(2^{t} * phase)) in [0,1)

# %%
# Prove-It doesn't need this explicit step, but it's nice to show it
eq_03.sub_left_side_into(interval_claim)
# Out:
# _scaled_delta_in_interval has been proven.  Now simply execute "%qed".
# |- (2^{t} * delta) in [0,1)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- (2^{t} * delta) in [0,1)
# 	P(_a) : _a in [0,1), x : 2^{t} * delta, y : (2^{t} * phase) - floor(2^{t} * phase)
# 1	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 2	instantiation	4, 5	|- ((2^{t} * phase) - floor(2^{t} * phase)) in [0,1)
# 	x : 2^{t} * phase
# 3	instantiation	39, 6, 7	|- (2^{t} * delta) = ((2^{t} * phase) - floor(2^{t} * phase))
# 	P(_a) : (2^{t} * delta) = ((2^{t} * phase) - _a), x : b, y : floor(2^{t} * phase)
# 4	conjecture		|- forall_{x in Real} ((x - floor(x)) in [0,1))
# 	proveit.numbers.rounding.real_minus_floor_interval
# 5	instantiation	97, 8, 9	|- (2^{t} * phase) in Real
# 	A : RealNonNeg, B : Real, x : 2^{t} * phase
# 6	instantiation	39, 10, 11	|- (2^{t} * delta) = ((2^{t} * phase) - b)
# 	P(_a) : (2^{t} * delta) = _a, x : 2^{t} * (phase - (b / 2^{t})), y : (2^{t} * phase) - b
# 7	instantiation	39, 12, 13	|- b = floor(2^{t} * phase)
# 	P(_a) : b = floor(_a), x : phase * 2^{t}, y : 2^{t} * phase
# 8	conjecture		|- RealNonNeg proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_nonneg_within_real
# 9	instantiation	14, 15, 16	|- (2^{t} * phase) in RealNonNeg
# 	a : 2^{t}, b : phase
# 10	instantiation	75, 17	|- (2^{t} * delta) = (2^{t} * (phase - (b / 2^{t})))
# 	f(_a) : 2^{t} * _a, x : delta, y : phase - (b / 2^{t})
# 11	instantiation	18, 19, 20, 21, 83, 25, 22, 23*	|- (2^{t} * (phase - (b / 2^{t}))) =  \\ ((2^{t} * phase) - b)
# 	i : 1, j : 0, a : (2^{t}), x : phase, y : b / 2^{t}, b : ()
# 12	axiom		|- b = floor(phase * 2^{t})
# 	proveit.physics.quantum.QPE._best_def
# 13	instantiation	24, 25, 83	|- (phase * 2^{t}) = (2^{t} * phase)
# 	a : phase, b : 2^{t}
# 14	conjecture		|- forall_{a, b in RealNonNeg} ((a * b) in RealNonNeg)
# 	proveit.numbers.multiplication.mult_real_nonneg_closure_bin
# 15	instantiation	97, 26, 27	|- 2^{t} in RealNonNeg
# 	A : RationalNonNeg, B : RealNonNeg, x : 2^{t}
# 16	instantiation	28, 34, 29	|- phase in RealNonNeg
# 	a : phase
# 17	axiom		|- delta = (phase - (b / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_def
# 18	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, x, y, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} *  a_{2} *  ... *  a_{i} * (x - y)* b_{1} *  b_{2} *  ... *  b_{j}) =  \\ ((a_{1} *  a_{2} *  ... *  a_{i} * x* b_{1} *  b_{2} *  ... *  b_{j}) - (a_{1} *  a_{2} *  ... *  a_{i} * y* b_{1} *  b_{2} *  ... *  b_{j})))]
# 	proveit.numbers.multiplication.distribute_through_subtract
# 19	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 20	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 21	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 22	instantiation	30, 71, 83, 31	|- (b / 2^{t}) in Complex
# 	a : b, b : 2^{t}
# 23	instantiation	39, 32, 33	|- (2^{t} * (b / 2^{t})) = b
# 	P(_a) : (2^{t} * (b / 2^{t})) = _a, x : (1 / 1) * (b / 1), y : b
# 24	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 25	instantiation	97, 88, 34	|- phase in Complex
# 	A : Real, B : Complex, x : phase
# 26	conjecture		|- RationalNonNeg proper_subset RealNonNeg
# 	proveit.numbers.number_sets.real_numbers.rational_nonneg_within_real_nonneg
# 27	instantiation	97, 35, 36	|- 2^{t} in RationalNonNeg
# 	A : Natural, B : RationalNonNeg, x : 2^{t}
# 28	conjecture		|- forall_{a in Real | a >= 0} (a in RealNonNeg)
# 	proveit.numbers.number_sets.real_numbers.nonneg_real_is_real_nonneg
# 29	instantiation	37, 45, 79, 46	|- 0 <= phase
# 	a : 0, b : 1, x : phase
# 30	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 31	instantiation	38, 99	|- 2^{t} != 0
# 	n : 2^{t}
# 32	instantiation	39, 40, 41	|- (2^{t} * (b / 2^{t})) = ((1 / 1) * (b / 1))
# 	P(_a) : _a = ((1 / 1) * (b / 1)), x : ((1 * 2^{t}) / 1) * (b / (2^{t} * 1)), y : 2^{t} * (b / 2^{t})
# 33	instantiation	66, 42, 43	|- ((1 / 1) * (b / 1)) = b
# 	x : (1 / 1) * (b / 1), y : 1 * b, z : b
# 34	instantiation	44, 45, 79, 46	|- phase in Real
# 	a : 0, b : 1, x : phase
# 35	conjecture		|- Natural proper_subset RationalNonNeg
# 	proveit.numbers.number_sets.rational_numbers.nat_within_rational_nonneg
# 36	instantiation	97, 47, 99	|- 2^{t} in Natural
# 	A : NaturalPos, B : Natural, x : 2^{t}
# 37	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (a <= x)]
# 	proveit.numbers.number_sets.real_numbers.interval_co_lower_bound
# 38	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 39	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 40	instantiation	48, 70, 71, 49, 50	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = ((1 / 1) * (b / 1))
# 	a : 1, d : b, b : 2^{t}, c : 1, e : 1
# 41	instantiation	66, 51, 52	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = (2^{t} * (b / 2^{t}))
# 	x : ((1 * 2^{t}) / 1) * (b / (2^{t} * 1)), y : 2^{t} * (b / (2^{t} * 1)), z : 2^{t} * (b / 2^{t})
# 42	instantiation	66, 53, 54	|- ((1 / 1) * (b / 1)) = (1 * b)
# 	x : (1 / 1) * (b / 1), y : 1 * (b / 1), z : 1 * b
# 43	instantiation	82, 71	|- (1 * b) = b
# 	x : b
# 44	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 45	instantiation	97, 93, 55	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 46	axiom		|- phase in [0,1)
# 	proveit.physics.quantum.QPE._phase_in_interval
# 47	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 48	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} ((((a * b) / c) * (d / (b * e))) = ((a / c) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_numer_left
# 49	instantiation	97, 57, 56	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 50	instantiation	97, 57, 58	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 51	instantiation	75, 59	|- (((1 * 2^{t}) / 1) * (b / (2^{t} * 1))) = (2^{t} * (b / (2^{t} * 1)))
# 	f(_a) : _a * (b / (2^{t} * 1)), x : (1 * 2^{t}) / 1, y : 2^{t}
# 52	instantiation	75, 60	|- (2^{t} * (b / (2^{t} * 1))) = (2^{t} * (b / 2^{t}))
# 	f(_a) : 2^{t} * _a, x : b / (2^{t} * 1), y : b / 2^{t}
# 53	instantiation	75, 61	|- ((1 / 1) * (b / 1)) = (1 * (b / 1))
# 	f(_a) : _a * (b / 1), x : 1 / 1, y : 1
# 54	instantiation	75, 62	|- (1 * (b / 1)) = (1 * b)
# 	f(_a) : 1 * _a, x : b / 1, y : b
# 55	conjecture		|- 0 in Rational
# 	proveit.numbers.number_sets.rational_numbers.zero_is_rational
# 56	instantiation	97, 64, 63	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 57	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 58	instantiation	97, 64, 65	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 59	instantiation	66, 67, 68	|- ((1 * 2^{t}) / 1) = 2^{t}
# 	x : (1 * 2^{t}) / 1, y : 2^{t} / 1, z : 2^{t}
# 60	instantiation	75, 69	|- (b / (2^{t} * 1)) = (b / 2^{t})
# 	f(_a) : b / _a, x : 2^{t} * 1, y : 2^{t}
# 61	instantiation	77, 70	|- (1 / 1) = 1
# 	x : 1
# 62	instantiation	77, 71	|- (b / 1) = b
# 	x : b
# 63	instantiation	97, 73, 72	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 64	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 65	instantiation	97, 73, 74	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 66	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 67	instantiation	75, 76	|- ((1 * 2^{t}) / 1) = (2^{t} / 1)
# 	f(_a) : _a / 1, x : 1 * 2^{t}, y : 2^{t}
# 68	instantiation	77, 83	|- (2^{t} / 1) = 2^{t}
# 	x : 2^{t}
# 69	instantiation	78, 83	|- (2^{t} * 1) = 2^{t}
# 	x : 2^{t}
# 70	instantiation	97, 88, 79	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 71	instantiation	97, 88, 80	|- b in Complex
# 	A : Real, B : Complex, x : b
# 72	instantiation	97, 81, 99	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 73	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 74	instantiation	97, 81, 86	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 75	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 76	instantiation	82, 83	|- (1 * 2^{t}) = 2^{t}
# 	x : 2^{t}
# 77	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 78	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 79	instantiation	84, 85, 86	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 80	instantiation	97, 93, 87	|- b in Real
# 	A : Rational, B : Real, x : b
# 81	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 82	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 83	instantiation	97, 88, 89	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 84	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 85	instantiation	90, 91	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 86	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 87	instantiation	97, 95, 92	|- b in Rational
# 	A : Integer, B : Rational, x : b
# 88	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 89	instantiation	97, 93, 94	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 90	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 91	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 92	conjecture		|- b in Integer
# 	proveit.physics.quantum.QPE._best_is_int
# 93	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 94	instantiation	97, 95, 96	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 95	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 96	instantiation	97, 98, 99	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 97	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 98	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 99	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
