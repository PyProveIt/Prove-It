# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_exp2pi_i_modadd">_exp2pi_i_modadd</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, r, x, defaults
from proveit.logic import InSet
from proveit.numbers import Add, Real
from proveit.numbers.number_sets.complex_numbers import exp_2pi_i_x
from proveit.physics.quantum.QPE import _mod_add_def, _two_pow_t, _two_pow_t_is_nat_pos

# %%
# %proving _exp2pi_i_modadd
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_exp2pi_i_modadd">_exp2pi_i_modadd:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b0f22ea234c9056400f5733a1a5cb1ac1edf2f5b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/dc45014d29c4b9f57fe99a6e5a969e27c76b098a0/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _exp2pi_i_modadd.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/085eda8e0e8299cb41f4e5affd07cf5fc4365d1e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# need this for the instantiation to work below
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
# from the numbers/number_sets/complex_numbers pkg:
exp_2pi_i_x
# Out:
# |- forall_{x, r in Real} (e^{(2 * pi * i * (x mod r)) / r} = e^{(2 * pi * i * x) / r})

# %%
exp_2pi_i_x_inst = exp_2pi_i_x.instantiate({x: Add(a, b), r: _two_pow_t})
# Out:
# <strong id="exp_2pi_i_x_inst">exp_2pi_i_x_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/d8d02d2a77383d238ed10b8fda7965dfafa87db90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/axioms/035e0ae7bd8c0fe127ee5d2062443d6c874adcdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__exp2pi_i_modadd/1a984a469f79aa69c88b36a8e269c416cb9778140/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__exp2pi_i_modadd/a80ff53267ef765fa150ac1332a39e188e9c62ad0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
_mod_add_def
# Out:
# |- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod 2^{t}))

# %%
mod_add_def_inst = _mod_add_def.instantiate()
# Out:
# <strong id="mod_add_def_inst">mod_add_def_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/d8d02d2a77383d238ed10b8fda7965dfafa87db90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/axioms/035e0ae7bd8c0fe127ee5d2062443d6c874adcdd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__exp2pi_i_modadd/5746d1c4f2bd005bbbe782653487eacd2407e28a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/298f656643be9bdc631616ae2fc8c878046de0840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
mod_add_def_inst.sub_left_side_into(exp_2pi_i_x_inst)
# Out:
# {a in Integer, b in Integer} |- e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}
# _exp2pi_i_modadd may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._exp2pi_i_modadd has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{a, b in Integer} (e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}})
# 1	instantiation	2, 3, 4	{a in Integer, b in Integer} |- e^{(2 * pi * i * (a MOD_ADD b)) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}
# 	P(_a) : e^{(2 * pi * i * _a) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}, x : a MOD_ADD b, y : (a + b) mod 2^{t}
# 2	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 3	instantiation	5, 6, 7	{a in Integer, b in Integer} |- e^{(2 * pi * i * ((a + b) mod 2^{t})) / 2^{t}} = e^{(2 * pi * i * (a + b)) / 2^{t}}
# 	x : a + b, r : 2^{t}
# 4	instantiation	8, 16, 17	{a in Integer, b in Integer} |- (a MOD_ADD b) = ((a + b) mod 2^{t})
# 	a : a, b : b
# 5	conjecture		|- forall_{x, r in Real} (e^{(2 * pi * i * (x mod r)) / r} = e^{(2 * pi * i * x) / r})
# 	proveit.numbers.number_sets.complex_numbers.exp_2pi_i_x
# 6	instantiation	18, 10, 9	{a in Integer, b in Integer} |- (a + b) in Real
# 	A : Rational, B : Real, x : a + b
# 7	instantiation	18, 10, 11	|- 2^{t} in Real
# 	A : Rational, B : Real, x : 2^{t}
# 8	axiom		|- forall_{a, b in Integer} ((a MOD_ADD b) = ((a + b) mod 2^{t}))
# 	proveit.physics.quantum.QPE._mod_add_def
# 9	instantiation	18, 13, 12	{a in Integer, b in Integer} |- (a + b) in Rational
# 	A : Integer, B : Rational, x : a + b
# 10	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 11	instantiation	18, 13, 14	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 12	instantiation	15, 16, 17	{a in Integer, b in Integer} |- (a + b) in Integer
# 	a : a, b : b
# 13	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 14	instantiation	18, 19, 20	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 15	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 16	assumption		{a in Integer} |- a in Integer
# 17	assumption		{b in Integer} |- b in Integer
# 18	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 19	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 20	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
