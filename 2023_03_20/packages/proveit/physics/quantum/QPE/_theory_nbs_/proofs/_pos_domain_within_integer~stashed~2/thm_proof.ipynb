# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_pos_domain_within_integer">_pos_domain_within_integer</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _pos_domain_within_integer
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_pos_domain_within_integer">_pos_domain_within_integer:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d9e1000e5d12e5d5796be584a91b3ac7b4ffaddc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/22e084d177cbef5bb5151fc80debac93ef164b430/dependencies.ipynb">dependencies</a>)<br>
# _pos_domain_within_integer may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._pos_domain_within_integer has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({e + 1 .. 2^{t - 1}} subset_eq Integer)
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} subset_eq Integer
# 	A : {e + 1 .. 2^{t - 1}}, B : Integer
# 2	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 3	instantiation	8, 4, 13	{e in {1 .. 2^{t - 1} - 2}} |- {e + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : e + 1, b : 2^{t - 1}
# 4	instantiation	12, 5, 9	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 5	instantiation	19, 6, 7	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 6	instantiation	8, 9, 10	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 7	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 8	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 9	instantiation	19, 20, 11	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 10	instantiation	12, 13, 14	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 11	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 12	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 13	instantiation	19, 15, 16	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 14	instantiation	17, 18	|- (-2) in Integer
# 	a : 2
# 15	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 16	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 17	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 18	instantiation	19, 20, 21	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 19	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 20	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 21	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
