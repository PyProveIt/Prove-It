# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_n_less_eq_t">_n_less_eq_t</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit.numbers import deduce_number_set
from proveit.physics.quantum.QPE import _n, _t_req, _eps_in_interval, _n_in_natural_pos

# %%
# %proving _n_less_eq_t
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_n_less_eq_t">_n_less_eq_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/63769816028ec6d64131a886e2edcae96a2e7aa40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/f49e42ca28bd6e760f2870b130488e3643d1e54f0/dependencies.ipynb">dependencies</a>)<br>

# %%
_t_req
# Out:
# |- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))

# %%
_eps_in_interval
# Out:
# |- eps in (0,1]

# %%
eps_lower_bound = _eps_in_interval.derive_element_lower_bound().reversed()
# Out:
# <strong id="eps_lower_bound">eps_lower_bound:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/c37d1361c385de9993eaba9e477981bfd9833af30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
one_over_2eps = _t_req.rhs.operands[1].operand.antilog.operands[1]
# Out:
# <strong id="one_over_2eps">one_over_2eps:</strong> <a class="ProveItLink" href="../../../__pv_it/axioms/8b0bc984e0f8356329aed2160b2a4506e33005170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
one_over_2eps__membership = deduce_number_set(one_over_2eps)
# Out:
# <strong id="one_over_2eps__membership">one_over_2eps__membership:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/7c2cc5412571f1d174bf0ff210f371f8b5ed72100/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/1ff3e6ea986cf2756a1a9c1cb2d81a8eb52a32ea0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
one_over_2eps__lb = one_over_2eps__membership.derive_element_lower_bound()
# Out:
# <strong id="one_over_2eps__lb">one_over_2eps__lb:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/23a4c7a7427647500db7cfd2458b9cd5d0d874450/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/1de3f274d3f8d50abfcc5ab923b59e9608eb72de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
rhs_bound = _t_req.rhs.deduce_bound(one_over_2eps__lb)
# Out:
# <strong id="rhs_bound">rhs_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/cfabfde921f6eafc2bd8162e2613ca3ccb934b130/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/eeecbcbbafbe2b05cec31deabca4bac70fa89ef30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _n_less_eq_t may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
t_bound =_t_req.apply_transitivity(rhs_bound)
# Out:
# <strong id="t_bound">t_bound:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/d9dd3c461615efc5c0033eea24607250aee8c62c0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/d32d90dab97af818889c40d0deb27b49abbc4f170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.numbers import greater, zero, two
np2_gt_n = greater(two, zero).left_add_both_sides(_n)
# Out:
# <strong id="np2_gt_n">np2_gt_n:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/1915a01086756a0ff2308bbd821e5f016f1bf8d80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__n_less_eq_t/424724668aa7bc00de6c051bb77492cae84480f40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
t_bound.apply_transitivity(np2_gt_n)
# Out:
# |- t > n

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._n_less_eq_t has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- n <= t
# 	x : n, y : t
# 1	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 2	instantiation	3, 4, 5	|- n < t
# 	x : n, y : n + 2, z : t
# 3	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 4	instantiation	32, 16, 76, 53, 6, 7*	|- n < (n + 2)
# 	a : n, x : 0, y : 2
# 5	instantiation	8, 9, 10	|- (n + 2) <= t
# 	x : n + 2, y : n + ceil(log_2(2 + (1 / (2 * eps)))), z : t
# 6	instantiation	11, 73	|- 2 > 0
# 	n : 2
# 7	instantiation	42, 12	|- (n + 0) = n
# 	a : n
# 8	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 9	instantiation	13, 16, 53, 14, 15	|- (n + 2) <= (n + ceil(log_2(2 + (1 / (2 * eps)))))
# 	a : n, x : 2, y : ceil(log_2(2 + (1 / (2 * eps))))
# 10	axiom		|- t >= (n + ceil(log_2(2 + (1 / (2 * eps)))))
# 	proveit.physics.quantum.QPE._t_req
# 11	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 12	instantiation	83, 48, 16	|- n in Complex
# 	A : Real, B : Complex, x : n
# 13	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 14	instantiation	83, 79, 17	|- ceil(log_2(2 + (1 / (2 * eps)))) in Real
# 	A : Rational, B : Real, x : ceil(log_2(2 + (1 / (2 * eps))))
# 15	instantiation	18, 82, 31, 19, 20*	|- 2 <= ceil(log_2(2 + (1 / (2 * eps))))
# 	x : 1, y : log_2(2 + (1 / (2 * eps)))
# 16	instantiation	21, 22, 23	|- n in Real
# 	A : NaturalPos, B : Real, x : n
# 17	instantiation	83, 81, 24	|- ceil(log_2(2 + (1 / (2 * eps)))) in Rational
# 	A : Integer, B : Rational, x : ceil(log_2(2 + (1 / (2 * eps))))
# 18	conjecture		|- forall_{x in Integer, y in Real | x < y} ((x + 1) <= ceil(y))
# 	proveit.numbers.rounding.ceil_of_real_above_int
# 19	instantiation	25, 64, 38, 26, 54, 27*	|- 1 < log_2(2 + (1 / (2 * eps)))
# 	a : 2, x : 2, y : 2 + (1 / (2 * eps))
# 20	conjecture		|- (1 + 1) = 2
# 	proveit.numbers.numerals.decimals.add_1_1
# 21	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 22	instantiation	28, 29	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 23	axiom		|- n in NaturalPos
# 	proveit.physics.quantum.QPE._n_in_natural_pos
# 24	instantiation	30, 31	|- ceil(log_2(2 + (1 / (2 * eps)))) in Integer
# 	x : log_2(2 + (1 / (2 * eps)))
# 25	conjecture		|- forall_{a, x, y in RealPos | x < y, a > 1} (log_a(x) < log_a(y))
# 	proveit.numbers.logarithms.log_increasing_less
# 26	instantiation	32, 53, 76, 33, 34, 35*	|- 2 < (2 + (1 / (2 * eps)))
# 	a : 2, x : 0, y : 1 / (2 * eps)
# 27	instantiation	36, 64	|- log_2(2) = 1
# 	a : 2
# 28	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 29	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 30	axiom		|- forall_{x in Real} (ceil(x) in Integer)
# 	proveit.numbers.rounding.ceil_is_an_int
# 31	instantiation	37, 64, 38, 39	|- log_2(2 + (1 / (2 * eps))) in Real
# 	a : 2, b : 2 + (1 / (2 * eps))
# 32	conjecture		|- forall_{a, x, y in Real | x < y} ((a + x) < (a + y))
# 	proveit.numbers.addition.strong_bound_via_right_term_bound
# 33	instantiation	83, 40, 45	|- (1 / (2 * eps)) in Real
# 	A : RealPos, B : Real, x : 1 / (2 * eps)
# 34	instantiation	41, 45	|- (1 / (2 * eps)) > 0
# 	x : 1 / (2 * eps)
# 35	instantiation	42, 43	|- (2 + 0) = 2
# 	a : 2
# 36	conjecture		|- forall_{a in RealPos} (log_a(a) = 1)
# 	proveit.numbers.logarithms.log_eq_1
# 37	conjecture		|- forall_{a, b in RealPos | a != 1} (log_a(b) in Real)
# 	proveit.numbers.logarithms.log_real_pos_real_closure
# 38	instantiation	44, 64, 45	|- (2 + (1 / (2 * eps))) in RealPos
# 	a : 2, b : 1 / (2 * eps)
# 39	instantiation	46, 47	|- 2 != 1
# 	x : 1, y : 2
# 40	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 41	conjecture		|- forall_{x in RealPos} (x > 0)
# 	proveit.numbers.number_sets.real_numbers.positive_if_in_real_pos
# 42	conjecture		|- forall_{a in Complex} ((a + 0) = a)
# 	proveit.numbers.addition.elim_zero_right
# 43	instantiation	83, 48, 53	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 44	conjecture		|- forall_{a, b in RealPos} ((a + b) in RealPos)
# 	proveit.numbers.addition.add_real_pos_closure_bin
# 45	instantiation	49, 50, 61, 51	|- (1 / (2 * eps)) in RealPos
# 	a : 1, b : 2 * eps
# 46	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 47	instantiation	52, 77, 53, 54	|- 1 != 2
# 	a : 1, b : 2
# 48	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 49	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 50	instantiation	83, 67, 55	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 51	instantiation	56, 57	|- (2 * eps) != 0
# 	x : 2 * eps
# 52	conjecture		|- forall_{a, b in Real | a < b} (a != b)
# 	proveit.numbers.ordering.less_is_not_eq
# 53	instantiation	83, 79, 58	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 54	conjecture		|- 1 < 2
# 	proveit.numbers.numerals.decimals.less_1_2
# 55	instantiation	83, 72, 59	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 56	conjecture		|- forall_{x in RealNonZero} (x != 0)
# 	proveit.numbers.number_sets.real_numbers.nonzero_if_in_real_nonzero
# 57	instantiation	83, 60, 61	|- (2 * eps) in RealNonZero
# 	A : RealPos, B : RealNonZero, x : 2 * eps
# 58	instantiation	83, 81, 62	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 59	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 60	conjecture		|- RealPos proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real_nonzero
# 61	instantiation	63, 64, 65	|- (2 * eps) in RealPos
# 	a : 2, b : eps
# 62	instantiation	83, 84, 66	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 63	conjecture		|- forall_{a, b in RealPos} ((a * b) in RealPos)
# 	proveit.numbers.multiplication.mult_real_pos_closure_bin
# 64	instantiation	83, 67, 68	|- 2 in RealPos
# 	A : RationalPos, B : RealPos, x : 2
# 65	instantiation	69, 70, 71	|- eps in RealPos
# 	a : eps
# 66	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 67	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 68	instantiation	83, 72, 73	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 69	conjecture		|- forall_{a in Real | a > 0} (a in RealPos)
# 	proveit.numbers.number_sets.real_numbers.pos_real_is_real_pos
# 70	instantiation	74, 76, 77, 78	|- eps in Real
# 	a : 0, b : 1, x : eps
# 71	instantiation	75, 76, 77, 78	|- 0 < eps
# 	a : 0, b : 1, x : eps
# 72	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 73	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 74	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 75	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 76	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 77	instantiation	83, 79, 80	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 78	axiom		|- eps in (0,1]
# 	proveit.physics.quantum.QPE._eps_in_interval
# 79	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 80	instantiation	83, 81, 82	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 81	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 82	instantiation	83, 84, 85	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 83	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 84	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 85	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
