# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_psi_t_formula">_psi_t_formula</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, b, c, k, m, n, t, P, defaults, Function
from proveit.linear_algebra import ScalarMult, TensorProd, VecSpaces
from proveit.logic import Equals, InSet
from proveit.numbers import (
        zero, one, two, i, e, pi, Add, Sum, Exp, Less, LessEq, Mult, frac, Neg, subtract)
from proveit.numbers import Complex, Interval, Natural
from proveit.numbers.number_sets.natural_numbers import fold_forall_natural_pos
from proveit.physics.quantum import Ket, NumKet
from proveit.physics.quantum.QPE import _phase, _phase_is_real, _psi_t_def

# %%
# %proving _psi_t_formula
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_psi_t_formula">_psi_t_formula:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/a88ec0c8744e13505b853b6e58491d95dad52e200/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/20171921f3332d2b2005abf236e939e383cee3be0/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# Keep the $2$ in $2 \pi i$ from combining with powers of $2$:

# %%
Exp.change_simplification_directives(factor_numeric_rational=True)

# %%
# the induction theorem for positive naturals
fold_forall_natural_pos
# Out:
# |- forall_{P} ((P(1) and [forall_{m in NaturalPos | P(m)} P(m + 1)]) => [forall_{n in NaturalPos} P(n)])

# %%
# instantiate the induction theorem
induction_inst = fold_forall_natural_pos.instantiate(
    {Function(P,t):_psi_t_formula.instance_expr, m:t, n:t})
# Out:
# <strong id="induction_inst">induction_inst:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/236b07a97e7a52029a7c0b70520bdcb13e8adc550/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/69919c5c651e83e6f11dc8147dea27ee8da200f80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Base Case

# %%
VecSpaces.default_field=Complex
defaults.assumptions = _psi_t_formula.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/b224c91479a3b890185904715420afd2361984620/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
base_case = induction_inst.antecedent.operands[0]
# Out:
# <strong id="base_case">base_case:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/51eb2cc41a2bdc949874f3a39ef659c35d8df6a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# We have $|\psi_{t}\rangle$ defined as a tensor product (the result of the first phase of the quantum circuit, and the LHS of Nielsen & Chuang's identity 5.20 on pg 222):

# %%
_psi_t_def
# Out:
# |- forall_{t in NaturalPos} (|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))

# %%
_psi_t_as_tensor_prod = _psi_t_def.instantiate()
# Out:
# <strong id="_psi_t_as_tensor_prod">_psi_t_as_tensor_prod:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/3b2b244a456255e6f1b54fc7e6aa4dbb54eb3d3f0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/563650e734cfbeae20efdbfe15f272f48df74d250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# For $\psi'_{1}$, we prove a useful equality then instantiate the `psi_t_def` with $t=1$:

# %%
psi_1_def = _psi_t_def.instantiate({t:one})
# Out:
# <strong id="psi_1_def">psi_1_def:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/5349e41bb9a243ec3d5f5a48a729d0ec13ed168a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/d82b0722718f2bc566bfc59a130a4d12eff7eb140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Then show that the summation formula also gives the same qbit result

# %%
sum_0_to_1 = base_case.rhs
# Out:
# <strong id="sum_0_to_1">sum_0_to_1:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/f1c47a2b0b28eb9fdefd782dc251fc52143be4280/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
sum_0_to_1_processed_01 = sum_0_to_1.inner_expr().operands[1].partitioning_first()
# Out:
# <strong id="sum_0_to_1_processed_01">sum_0_to_1_processed_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/c650eccb93d1561fa32719870789e80fdbbba9310/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/c513b3a0870f23e09a62ef0038e1d5bbeade72840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# finish off the Base Case
base_case_jdgmt = sum_0_to_1_processed_01.sub_left_side_into(psi_1_def)
# Out:
# <strong id="base_case_jdgmt">base_case_jdgmt:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/d0e2ff9c83144ce17d575d793b9e829c68d4f5c40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/51eb2cc41a2bdc949874f3a39ef659c35d8df6a70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Inductive Step

# %%
inductive_step = induction_inst.antecedent.operands[1]
# Out:
# <strong id="inductive_step">inductive_step:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/4c67646e9e6912d7fb24ed78d7120288232873840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = defaults.assumptions + inductive_step.conditions.entries
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/660546566063b9ebb729cb261815b744823dfc920/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# First, partition the summation:
# $\sum_{k=0}^{2^{t+1}-1} e^{2\pi i \varphi k} |k\rangle_{t+1} = \sum_{k=0}^{2^{t}-1} e^{2\pi i \varphi k} |k\rangle_{t+1} + \sum_{k=2^{t}}^{2^{t+1}-1} e^{2\pi i \varphi k} |k\rangle_{t+1}$

# %%
desired_domain = _psi_t_formula.instance_expr.rhs.scaled.domain
# Out:
# <strong id="desired_domain">desired_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/904fdaffb14babe7fdc4a3341d9bcad2602f0cbd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
summation_partition_01 = (
    inductive_step.instance_expr.rhs.operands[1]
    .partitioning(desired_domain.upper_bound))
# Out:
# <strong id="summation_partition_01">summation_partition_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/a559d62e743b01c5a01181aa98b76aa33061d8720/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/f24112b8020bb002823ed8d7ab2aad134156a8e50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Then shift the second summation of that partition, so that the two summations then have the same index domain:

# %%
summation_partition_02 = (summation_partition_01.inner_expr().rhs.
                          operands[1].shift(Neg(Exp(two, t))))
# Out:
# <strong id="summation_partition_02">summation_partition_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/7ccb1232456d3f318a734a22990287f52b36eaf40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/5815e7ddd6d8de56c8f5d4f4bcef4e60d0d7a5cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# We want to rewrite the summand of that 2nd summation on the rhs now by (1) expanding the exponential term and (2) rewriting the $|k+2^t{\rangle}_{t+1}$ ket as $|1\rangle \otimes |k{\rangle}_t$. This takes a little work.

# %%
rhs_2nd_sum = summation_partition_02.rhs.operands[1]
# Out:
# <strong id="rhs_2nd_sum">rhs_2nd_sum:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/7e6e165ad69f49df1ecd1a46a2e7e233d5e4949a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
summand_processed_01 = rhs_2nd_sum.summand.inner_expr().operands[0].exponent.distribution(
    4, assumptions=[*defaults.assumptions,
                    rhs_2nd_sum.condition])
# Out:
# <strong id="summand_processed_01">summand_processed_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f96b113649920e91f2100c5281286cc556b8f3f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/e0da590819cb15a10ef5249d32fe2e32065a967e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/3b9e7a15f0d710b73eedafb5d5cee0bb55b606990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
summand_processed_02 = (
    summand_processed_01.inner_expr().rhs.operands[0]
    .exponent_separate(
        assumptions=[*defaults.assumptions,
                     InSet(k, Interval(zero, subtract(Exp(two, t), one)))]))
# Out:
# <strong id="summand_processed_02">summand_processed_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f96b113649920e91f2100c5281286cc556b8f3f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/005a56ca4d7362725a97e652c6f8841976e092ca0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/4318675edd1b266ae4aa8afcdad430d74cbc77870/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Avoid recombining these via auto-simplification
defaults.preserved_exprs = set([summand_processed_02.rhs.scalar])
# Out:
# <strong id="defaults.preserved_exprs">defaults.preserved_exprs:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/b7ad566314238e4699841046f976661cab36153d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.physics.quantum.algebra import prepend_num_ket_with_one_ket
prepend_num_ket_with_one_ket
# Out:
# |- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} (|2^{n} + k〉_{n + 1} = (|1〉 otimes |k〉_{n}))]

# %%
prepend_num_ket_with_one_ket_inst = prepend_num_ket_with_one_ket.instantiate(
        {n: t, k: k},
        assumptions=[*defaults.assumptions, InSet(k, Interval(zero, subtract(Exp(two, t), one)))])
# Out:
# <strong id="prepend_num_ket_with_one_ket_inst">prepend_num_ket_with_one_ket_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f96b113649920e91f2100c5281286cc556b8f3f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/9fa096739d65c4f6b67a47515130e4eb02a249bf0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/5dc692f02c7f60e04d6bb708517ab38d6004bec70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
summand_processed_03 = (
    summand_processed_02.inner_expr().rhs.operands[1]
    .substitute(prepend_num_ket_with_one_ket_inst))
# Out:
# <strong id="summand_processed_03">summand_processed_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f96b113649920e91f2100c5281286cc556b8f3f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/46b21aab003e1e881f192fb5f80550752718d5b50/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/406ba9c1055a182d6efbe8bc509297cbf4d4230b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# reminder of summation_partition_03
summation_partition_02
# Out:
# {t in NaturalPos} |- (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) = ((Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1})) + (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * (k + 2^{t})} * |k + 2^{t}〉_{t + 1})))

# %%
summation_partition_04 = (
    summation_partition_02.inner_expr().rhs.operands[1].summand.substitute(
        summand_processed_03))
# Out:
# <strong id="summation_partition_04">summation_partition_04:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/41eea3156f7695e187e1881eaf9cbdefdf7ba8dd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/174f7ed588507af0a71181baa9bcbce578a1edc70/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Also process the summand in the 1st sum on the rhs, converting the ket $|k\rangle_{t+1}$ to the tensor product $|0\rangle \otimes |k\rangle_{t}$:

# %%
# pull up the relevant NumKet theorem
from proveit.physics.quantum.algebra import prepend_num_ket_with_zero_ket
prepend_num_ket_with_zero_ket
# Out:
# |- forall_{n in NaturalPos} [forall_{k in {0 .. 2^{n} - 1}} (|k〉_{n + 1} = (|0〉 otimes |k〉_{n}))]

# %%
# instantiate the theorem for our specific case
prepend_num_ket_with_zero_ket_inst = prepend_num_ket_with_zero_ket.instantiate(
        {n: t, k: k},
        assumptions=[*defaults.assumptions, InSet(k, Interval(zero, subtract(Exp(two, t), one)))])
# Out:
# <strong id="prepend_num_ket_with_zero_ket_inst">prepend_num_ket_with_zero_ket_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/f96b113649920e91f2100c5281286cc556b8f3f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/624ddc0c1ed5e8d9f3a41a7fb5c7d850fcdbd6020/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/38c650b62ca0a8cc080d096df6f56cf61c887a1f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# use our instantiation to substitute
summation_partition_05 = (
    summation_partition_04.inner_expr().rhs.operands[0].summand.scaled.substitute(
    prepend_num_ket_with_zero_ket_inst))
# Out:
# <strong id="summation_partition_05">summation_partition_05:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/65bb1a3fa1bf2c50f53bcce96fd04d7b781555b30/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/b75107ec32a99f156382cf4514d5bacc3e5d4e270/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
coef = inductive_step.instance_expr.rhs.scalar
summation_partition_06 = summation_partition_05.scalar_mult_both_sides(coef)
# Out:
# <strong id="summation_partition_06">summation_partition_06:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/97fb0b561d89be74b3fad0ac0fdfb971aefc25220/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/31d1a14aebe4ce9cd4f4018f6250e7ab0295afc90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Recall our inductive hypothesis:
inductive_hypothesis = defaults.assumptions[-1]
# Out:
# <strong id="inductive_hypothesis">inductive_hypothesis:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/9ce84ed3601547c8443631ee6cb273a26ca9fee40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
conclusion_01 = summation_partition_06.inner_expr().rhs.factor(
        inductive_hypothesis.rhs, pull='right', field=Complex)
# Out:
# <strong id="conclusion_01">conclusion_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/e17e59f444028249663b18d382eaa645312b7f920/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/f562af21549719a35c6abcbe54721e98c25c176f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# use the inductive hypothesis:
conclusion_02 = inductive_hypothesis.sub_left_side_into(conclusion_01)
# Out:
# <strong id="conclusion_02">conclusion_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/9ce84ed3601547c8443631ee6cb273a26ca9fee40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/c7cd73800f04511d58fad38594d6a5b48ce6bf520/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/c1a9b6f50c37cfc2d0491fa049f07282449d37060/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# The RHS of conclusion_02 above should be equal to $|\psi_{t+1}\rangle$. Let's see how to get there. Ideally we could use the next three cells to show the rhs of the equality in `conclusion_02` is equal to $|\psi_{t+1}\rangle$

# %%
# reminder
_psi_t_def
# Out:
# |- forall_{t in NaturalPos} (|psi_{t}> = (((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 2} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))))

# %%
psi_t_plus_one_as_tensor_prod = _psi_t_def.instantiate({t:Add(t, one)})
# Out:
# <strong id="psi_t_plus_one_as_tensor_prod">psi_t_plus_one_as_tensor_prod:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/ff077a2f20be7e8b9f71c8bb1bb29507f7beaa110/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/cc6fe3591425ee4a5c25ab3b70c6b1678c2a24150/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now this `substitute()` step will also manage to pull the scalar coefficients out to the front in the process:

# %%
conclusion_03 = conclusion_02.inner_expr().rhs.operands[1].substitute(
        _psi_t_as_tensor_prod)
# Out:
# <strong id="conclusion_03">conclusion_03:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/9ce84ed3601547c8443631ee6cb273a26ca9fee40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/8c56609e38eb046b229b4f0493375948c4589dfd0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/1537e8a8b250ed02b911ebea160771c55dcb230a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now we partition the tensor product expression of $\psi_{t+1}$, so we can eventually show that it is equal to the rhs of conclusion_03.

# %%
psi_t_plus_one_as_tensor_prod.rhs
# Out:
# ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t} * phase} * |1〉))) otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{t - 1} * phase} * |1〉))) otimes  ... otimes  ((1 / sqrt(2)) * (|0〉 + (e^{2 * pi * i * 2^{0} * phase} * |1〉)))

# %%
# # we can partition the operands in the psi_{t+1} tensor prod expression
psi_t_plus_one_as_tensor_prod_02 = (
    psi_t_plus_one_as_tensor_prod.inner_expr().rhs.operands[0].split(t))
# Out:
# <strong id="psi_t_plus_one_as_tensor_prod_02">psi_t_plus_one_as_tensor_prod_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/axioms/71c1fc00120f763c694cd99d32f7a5e7315b9ca50/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/c31d57b355b4d104748bb325324a1b23d4948ca10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__psi_t_formula/413197fa684c6a545f3317027c53f7b0e7bcb1a00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
conclusion_03.inner_expr().rhs.substitute(psi_t_plus_one_as_tensor_prod_02.derive_reversed())
# Out:
# {t in NaturalPos, |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} |- ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))) = |psi_{t + 1}>

# %%
# # recall our earlier instantiation of the induction theorem:
induction_inst
# Out:
# |- ((|psi_{1}> = ((1 / sqrt(2)) * (Sum_{k=0}^{1} (e^{2 * pi * i * phase * k} * |k〉)))) and [forall_{t in NaturalPos | |psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t})))} (|psi_{t + 1}> = ((1 / 2^{(t + 1) / 2}) * (Sum_{k=0}^{(2 * 2^{t}) - 1} (e^{2 * pi * i * phase * k} * |k〉_{t + 1}))))]) => [forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))]

# %% [markdown]
# We have proven both pieces of the antecedent (_i.e._, the base case and inductive case) of the instantiated induction theorem `induction_inst`, so we can now derive the consequent:

# %%
induction_inst.derive_consequent()
# Out:
# |- forall_{t in NaturalPos} (|psi_{t}> = ((1 / 2^{t / 2}) * (Sum_{k=0}^{2^{t} - 1} (e^{2 * pi * i * phase * k} * |k〉_{t}))))
# _psi_t_formula has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._psi_t_formula has been proven.
