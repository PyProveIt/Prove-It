# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_minus_l__in__real">_scaled_delta_minus_l__in__real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.physics.quantum.QPE import _scaled_delta_in_interval

# %%
# %proving _scaled_delta_minus_l__in__real
# Out:
# _scaled_delta_minus_l__in__real: forall_{l in Integer} (((2^{t} * delta) - l) in Real)

# %%
# As long as we know the real interval for the scaled delta,
# Prove-It can do the rest automatically
_scaled_delta_in_interval
# Out:
# |- (2^{t} * delta) in [0,1)

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in Integer} (((2^{t} * delta) - l) in Real)
# 1	instantiation	2, 3, 4	{l in Integer} |- ((2^{t} * delta) - l) in Real
# 	a : 2^{t} * delta, b : -l
# 2	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 3	instantiation	5, 6, 7, 8	|- (2^{t} * delta) in Real
# 	a : 0, b : 1, x : 2^{t} * delta
# 4	instantiation	15, 10, 9	{l in Integer} |- (-l) in Real
# 	A : Rational, B : Real, x : -l
# 5	conjecture		|- forall_{a, b in Real} [forall_{x in [a,b)} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_co__is__real
# 6	instantiation	15, 10, 11	|- 0 in Real
# 	A : Rational, B : Real, x : 0
# 7	instantiation	12, 13, 14	|- 1 in Real
# 	A : NaturalPos, B : Real, x : 1
# 8	conjecture		|- (2^{t} * delta) in [0,1)
# 	proveit.physics.quantum.QPE._scaled_delta_in_interval
# 9	instantiation	15, 16, 17	{l in Integer} |- (-l) in Rational
# ...
