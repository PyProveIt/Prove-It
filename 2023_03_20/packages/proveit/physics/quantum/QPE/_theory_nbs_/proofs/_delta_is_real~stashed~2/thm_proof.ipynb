# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_delta_is_real">_delta_is_real</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit.logic import InSet
from proveit.numbers import Real
from proveit.physics.quantum.QPE import _delta_def
from proveit.physics.quantum.QPE import _best_is_int, _phase_is_real, _two_pow_t_is_nat_pos

# %%
# %proving _delta_is_real
# Out:
# _delta_is_real: delta in Real

# %%
_delta_def
# Out:
# |- delta = (phase - (b / 2^{t}))

# %%
InSet(_delta_def.rhs, Real).prove()
# Out:
# |- (phase - (b / 2^{t})) in Real

# %%
# %qed
# Out:
# 	step type	requirements	statement
# 0	instantiation	1, 2, 3	|- delta in Real
# 	P(_a) : _a in Real, x : delta, y : phase - (b / 2^{t})
# 1	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 2	instantiation	4, 5, 6	|- (phase - (b / 2^{t})) in Real
# 	a : phase, b : -(b / 2^{t})
# 3	axiom		|- delta = (phase - (b / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_def
# 4	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 5	conjecture		|- phase in Real
# 	proveit.physics.quantum.QPE._phase_is_real
# 6	instantiation	19, 7, 8	|- (-(b / 2^{t})) in Real
# 	A : Rational, B : Real, x : -(b / 2^{t})
# 7	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 8	instantiation	9, 10	|- (-(b / 2^{t})) in Rational
# 	a : b / 2^{t}
# 9	conjecture		|- forall_{a in Rational} ((-a) in Rational)
# 	proveit.numbers.negation.rational_closure
# 10	instantiation	11, 12, 13, 14	|- (b / 2^{t}) in Rational
# 	a : b, b : 2^{t}
# 11	conjecture		|- forall_{a, b in Rational | b != 0} ((a / b) in Rational)
# 	proveit.numbers.division.div_rational_closure
# 12	instantiation	19, 16, 15	|- b in Rational
# 	A : Integer, B : Rational, x : b
# 13	instantiation	19, 16, 17	|- 2^{t} in Rational
# 	A : Integer, B : Rational, x : 2^{t}
# 14	instantiation	18, 21	|- 2^{t} != 0
# 	n : 2^{t}
# 15	conjecture		|- b in Integer
# 	proveit.physics.quantum.QPE._best_is_int
# 16	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 17	instantiation	19, 20, 21	|- 2^{t} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t}
# 18	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 19	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 20	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 21	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
