# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_non_int_delta_b_diff">_non_int_delta_b_diff</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import b, n, x, defaults
from proveit.logic import Forall, InSet, NotEquals, Set
from proveit.numbers import (
        zero, one, two, Add, IntervalOO, Less, Neg, Real)
from proveit.numbers.number_sets.real_numbers import (
        not_int_if_not_int_in_interval)
from proveit.physics.quantum.QPE import (
        _b_floor, _b_round, _best_round_is_int, _delta_b,
        _delta_b_in_interval, _delta_b_is_real,
        _delta_b_not_eq_scaledNonzeroInt, _t, _t_in_natural_pos,
       _two_pow_t, _two_pow_t_is_nat_pos)

# %%
# %proving _non_int_delta_b_diff
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_non_int_delta_b_diff">_non_int_delta_b_diff:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/e071bc293a5f27954f9d2713c99a47a7e73843a90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/2728c0b5175ee019897a735be401add4189d4a000/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _non_int_delta_b_diff.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c4ce15397e5d747ea86f6d6143ae86209e6857980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_delta_b_in_interval
# Out:
# |- forall_{b in {b_{f}, b_{r}}} (delta_{b} in (-(1 / 2),1 / 2])

# %%
_delta_b_in_interval_inst = _delta_b_in_interval.instantiate()
# Out:
# <strong id="_delta_b_in_interval_inst">_delta_b_in_interval_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/891d554379ae8acea5dc5bfc295f64ba6a26988d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/0b9e90686cc9b38cd6279d1c28569daacc8ff4b60/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Some convenient, short-cut labelings:

# %%
delta_diff = _non_int_delta_b_diff.instance_expr.element
# Out:
# <strong id="delta_diff">delta_diff:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0b65bb55bcfa6a21cf4effa238e6371cac54b72d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
neg_ell_over_two_pow_t = delta_diff.operands[1]
# Out:
# <strong id="neg_ell_over_two_pow_t">neg_ell_over_two_pow_t:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/400ae4473727f2fbe37a6d049af6de0ef76f59f20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
ell_in_full_domain = defaults.assumptions[1]
# Out:
# <strong id="ell_in_full_domain">ell_in_full_domain:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# #### Some Domain Facts

# %%
_t_in_natural_pos
# Out:
# |- t in NaturalPos

# %%
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
# needed for establishing that the
# assumed ell domain consists of integers
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
from proveit.physics.quantum.QPE import _best_floor_is_int
_best_floor_is_int
# Out:
# |- b_{f} in Integer

# %%
_best_round_is_int
# Out:
# |- b_{r} in Integer

# %%
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
_delta_b_is_real.instantiate({b: _b_floor})
# Out:
# |- delta_{b_{f}} in Real

# %%
_delta_b_is_real.instantiate({b: _b_round})
# Out:
# |- delta_{b_{r}} in Real

# %%
all_delta_b_are_real = Forall(b,
       InSet(_delta_b, Real),
       domain=Set(_b_floor, _b_round)).prove()
# Out:
# <strong id="all_delta_b_are_real">all_delta_b_are_real:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/e4c74877f3cacc8b38a38b35a8b7cbb791c4c7f90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/e5033f26cf4327e66b2618f27bcc5d0180bdcedf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
all_delta_b_are_real.instantiate()
# Out:
# {b in {b_{f}, b_{r}}} |- delta_{b} in Real

# %% [markdown]
# #### Upper & Lower Bounds on $\ell$

# %%
ell_upper_bound = ell_in_full_domain.derive_element_upper_bound()
# Out:
# <strong id="ell_upper_bound">ell_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/137c2805f54bd37dbcf2ebc503f8ec8d9369f3b10/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/d959c94c6b67001a2d9a6245fbea5be37f398c430/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ell_lower_bound = ell_in_full_domain.derive_element_lower_bound()
# Out:
# <strong id="ell_lower_bound">ell_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/23c22fe1298bc06b01c6ef3d3b8c79f884e1d8620/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/df26de15e6281c28c9df783cf413d8b0c3c4c5990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Upper & Lower Bounds on $\delta_{b}$

# %%
delta_b_upper_bound = _delta_b_in_interval_inst.derive_element_upper_bound()
# Out:
# <strong id="delta_b_upper_bound">delta_b_upper_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/5c64a3dc920eaac9599d41ddbcc53a4da9cedd780/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/421935471872c5b236811b6a090f1f5d7b08472a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
delta_b_lower_bound = _delta_b_in_interval_inst.derive_element_lower_bound()
# Out:
# <strong id="delta_b_lower_bound">delta_b_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/ab22e56afd31d125122ba6bd6c36f1a0e742fb950/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/362db4d0b9e614b84ee6b5b63b7f9f1d6fada7770/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Deducing Bounds on $\delta_{b} - \frac{\ell}{2^t}$

# %%
delta_diff_lower_bound = (
        delta_diff.deduce_bound(
        [ell_upper_bound, delta_b_lower_bound.reversed()]))
# Out:
# <strong id="delta_diff_lower_bound">delta_diff_lower_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/3ed5c4de773482b4e28aa393bf9d2fae830999950/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/872715fb44ed53fd2fb504d29eecc6ff2d91c3990/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
delta_diff_upper_bound_01 = (
        delta_diff.deduce_bound(
        [ell_lower_bound.reversed(), delta_b_upper_bound]))
# Out:
# <strong id="delta_diff_upper_bound_01">delta_diff_upper_bound_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/3d3a14391ddcd95059bbd242833c996fb73d114e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/590532bfd354a836697eb6bd84f84ba567e810fe0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
delta_diff_upper_bound_02 = (
        delta_diff_upper_bound_01.inner_expr().rhs.operands[1].
        operand.distribute())
# Out:
# <strong id="delta_diff_upper_bound_02">delta_diff_upper_bound_02:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/4a377ad41c9ff27d49e7ef8cba941c1a3f0463a20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/491c3be245e654887679869a4b8ea1a026afc17b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
Less(delta_diff_upper_bound_02.rhs, one).prove()
# Out:
# |- (1 - (1 / 2^{t})) < 1

# %%
InSet(delta_diff, IntervalOO(Neg(one), one)).prove()
# Out:
# {b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l / 2^{t})) in (-1,1)

# %% [markdown]
# #### Now use the QPE theorem `_delta_b_not_eq_scaledNonzeroInt` to deduce that $\delta_{b}-\frac{\ell}{2^t} \ne 0$:

# %%
_delta_b_not_eq_scaledNonzeroInt
# Out:
# |- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} (delta_{b} != (l / 2^{t}))

# %%
_delta_b_not_eq_scaledNonzeroInt_inst = _delta_b_not_eq_scaledNonzeroInt.instantiate()
# Out:
# <strong id="_delta_b_not_eq_scaledNonzeroInt_inst">_delta_b_not_eq_scaledNonzeroInt_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/aac49a0da739e2f881363626cadba42bc6cac6890/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/ffe68e9d551b311b9c7e41ea63890c69a6ae8b5e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
NotEquals(Add(_delta_b, neg_ell_over_two_pow_t), zero).prove()
# Out:
# {b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b} - (l / 2^{t})) != 0

# %% [markdown]
# #### Instantiate one last useful theorem: $\delta_{b}-\frac{\ell}{2^t}\in(-1, 1)$ cannot be an integer if $\delta_{b}-\frac{\ell}{2^t}\ne 0$:

# %%
not_int_if_not_int_in_interval
# Out:
# |- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]

# %%
not_int_if_not_int_in_interval_inst = (
        not_int_if_not_int_in_interval.instantiate(
                {n: zero, x: delta_diff}))
# Out:
# <strong id="not_int_if_not_int_in_interval_inst">not_int_if_not_int_in_interval_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/b38b045a9246dd5ac239f68f921874310f53aad00/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__non_int_delta_b_diff/7e1206dd41801936356e64be55b2aefd4d1f04610/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/4710760a20af583e0a62657d5371a4fb2cd9c06d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>
# _non_int_delta_b_diff may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._non_int_delta_b_diff has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}} | l != 0} ((delta_{b} - (l / 2^{t})) not-in Integer)
# 1	instantiation	2, 3, 4, 5	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b} - (l / 2^{t})) not-in Integer
# 	n : 0, x : delta_{b} - (l / 2^{t})
# 2	conjecture		|- forall_{n in Integer} [forall_{x in (n - 1,n + 1) | x != n} (x not-in Integer)]
# 	proveit.numbers.number_sets.real_numbers.not_int_if_not_int_in_interval
# 3	conjecture		|- 0 in Integer
# 	proveit.numbers.number_sets.integers.zero_is_int
# 4	instantiation	6, 7, 8, 9, 10	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l / 2^{t})) in (0 - 1,0 + 1)
# 	a : 0 - 1, b : 0 + 1, x : delta_{b} - (l / 2^{t})
# 5	instantiation	11, 12	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- (delta_{b} - (l / 2^{t})) != 0
# 	a : delta_{b}, b : l / 2^{t}
# 6	conjecture		|- forall_{a, b, x in Real | a < x < b} (x in (a,b))
# 	proveit.numbers.number_sets.real_numbers.in_IntervalOO
# 7	instantiation	14, 13, 213	|- (0 - 1) in Real
# 	a : 0, b : -1
# 8	instantiation	228, 229, 57	|- (0 + 1) in Real
# 	A : NaturalPos, B : Real, x : 0 + 1
# 9	instantiation	14, 63, 66	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (delta_{b} - (l / 2^{t})) in Real
# 	a : delta_{b}, b : -(l / 2^{t})
# 10	instantiation	15, 16, 17	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- ((0 - 1) < (delta_{b} - (l / 2^{t}))) and ((delta_{b} - (l / 2^{t})) < (0 + 1))
# 	A : (0 - 1) < (delta_{b} - (l / 2^{t})), B : (delta_{b} - (l / 2^{t})) < (0 + 1)
# 11	conjecture		|- forall_{a, b | a != b} ((a - b) != 0)
# 	proveit.numbers.addition.subtraction.nonzero_difference_if_different
# 12	instantiation	18, 99, 129, 19	{b in {b_{f}, b_{r}}, l in {-2^{t - 1} + 1 .. 2^{t - 1}}, l != 0} |- delta_{b} != (l / 2^{t})
# 	b : b, l : l
# 13	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 14	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 15	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 16	instantiation	22, 20, 21	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (0 - 1) < (delta_{b} - (l / 2^{t}))
# 	P(_a) : _a < (delta_{b} - (l / 2^{t})), x : 0 - 1, y : -1
# 17	instantiation	22, 23, 24	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) < (0 + 1)
# 	P(_a) : (delta_{b} - (l / 2^{t})) < _a, x : 0 + 1, y : 1
# 18	conjecture		|- forall_{b in {b_{f}, b_{r}}, l in Integer | l != 0} (delta_{b} != (l / 2^{t}))
# 	proveit.physics.quantum.QPE._delta_b_not_eq_scaledNonzeroInt
# 19	assumption		{l != 0} |- l != 0
# 20	instantiation	27, 25, 26	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-1) < (delta_{b} - (l / 2^{t}))
# 	x : -1, y : -(1 / 2) - (l / 2^{t}), z : delta_{b} - (l / 2^{t})
# 21	instantiation	30, 201	|- (0 - 1) = (-1)
# 	a : -1
# 22	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 23	instantiation	27, 28, 29	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) < 1
# 	x : delta_{b} - (l / 2^{t}), y : 1 - (1 / 2^{t}), z : 1
# 24	instantiation	30, 157	|- (0 + 1) = 1
# 	a : 1
# 25	instantiation	65, 105, 31, 66, 32, 33*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-1) <= (-(1 / 2) - (l / 2^{t}))
# 	a : -(1 / 2), x : -(2^{t - 1} / 2^{t}), y : -(l / 2^{t})
# 26	instantiation	34, 66, 105, 63, 35	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (-(1 / 2) - (l / 2^{t})) < (delta_{b} - (l / 2^{t}))
# 	a : -(l / 2^{t}), x : -(1 / 2), y : delta_{b}
# 27	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_eq_less
# 28	instantiation	36, 37, 38, 39*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) <= (1 - (1 / 2^{t}))
# 	P(_a) : (delta_{b} - (l / 2^{t})) <= ((1 / 2) - _a), x : (-2^{t - 1} + 1) / 2^{t}, y : -(1 / 2) + (1 / 2^{t})
# 29	instantiation	40, 195, 220, 41, 196, 42, 177	|- (1 - (1 / 2^{t})) < 1
# 	i : 0, j : 1, a : (), c : (-(1 / 2^{t})), b : 1
# 30	conjecture		|- forall_{a in Complex} ((0 + a) = a)
# 	proveit.numbers.addition.elim_zero_left
# 31	instantiation	221, 60	|- (-(2^{t - 1} / 2^{t})) in Real
# 	a : 2^{t - 1} / 2^{t}
# 32	instantiation	81, 83, 60, 43	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(l / 2^{t})) >= (-(2^{t - 1} / 2^{t}))
# 	x : l / 2^{t}, y : 2^{t - 1} / 2^{t}
# 33	instantiation	44, 107, 45, 157, 46	|- (-(1 / 2) - (2^{t - 1} / 2^{t})) = (-1)
# 	a : 1 / 2, b : 2^{t - 1} / 2^{t}, c : 1
# 34	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 35	instantiation	47, 105, 120, 80	{b in {b_{f}, b_{r}}} |- (-(1 / 2)) < delta_{b}
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 36	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 37	instantiation	48, 49, 50	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) <= ((1 / 2) - ((-2^{t - 1} + 1) / 2^{t}))
# 	x : delta_{b} - (l / 2^{t}), y : (1 / 2) - (l / 2^{t}), z : (1 / 2) - ((-2^{t - 1} + 1) / 2^{t})
# 38	instantiation	51, 226, 52, 53, 157, 96, 151, 54*	|- ((-2^{t - 1} + 1) / 2^{t}) = (-(1 / 2) + (1 / 2^{t}))
# 	n : 2, x : (-2^{t - 1}, 1), y : 2^{t}
# 39	instantiation	179, 55, 56	|- ((1 / 2) - (-(1 / 2) + (1 / 2^{t}))) = (1 - (1 / 2^{t}))
# 	x : (1 / 2) - (-(1 / 2) + (1 / 2^{t})), y : (1 / 2) + ((1 / 2) - (1 / 2^{t})), z : 1 - (1 / 2^{t})
# 40	conjecture		|- forall_{i, j in Natural | (i + j) > 0} [forall_{a_{1}, a_{2}, ..., a_{i}, c_{1}, c_{2}, ..., c_{j} in RealNeg} [forall_{b in Real} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) < b)]]
# 	proveit.numbers.addition.term_as_strong_upper_bound
# 41	instantiation	119, 57	|- (0 + 1) > 0
# 	n : 0 + 1
# 42	instantiation	58, 132	|- (-(1 / 2^{t})) in RealNeg
# 	a : 1 / 2^{t}
# 43	instantiation	100, 113, 102, 112, 59, 104	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 2^{t}) <= (2^{t - 1} / 2^{t})
# 	a : 2^{t}, x : l, y : 2^{t - 1}
# 44	conjecture		|- forall_{a, b, c in Complex | (a + b) = c} ((-a - b) = (-c))
# 	proveit.numbers.addition.subtraction.negated_add
# 45	instantiation	237, 212, 60	|- (2^{t - 1} / 2^{t}) in Complex
# 	A : Real, B : Complex, x : 2^{t - 1} / 2^{t}
# 46	instantiation	179, 61, 93	|- ((1 / 2) + (2^{t - 1} / 2^{t})) = 1
# 	x : (1 / 2) + (2^{t - 1} / 2^{t}), y : (1 / 2) + (1 / 2), z : 1
# 47	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (a < x)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_lower_bound
# 48	conjecture		|- forall_{x, y, z | x <= y, y <= z} (x <= z)
# 	proveit.numbers.ordering.transitivity_less_eq_less_eq
# 49	instantiation	62, 66, 63, 120, 64	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}, b in {b_{f}, b_{r}}} |- (delta_{b} - (l / 2^{t})) <= ((1 / 2) - (l / 2^{t}))
# 	a : -(l / 2^{t}), x : delta_{b}, y : 1 / 2
# 50	instantiation	65, 120, 66, 67, 68	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((1 / 2) - (l / 2^{t})) <= ((1 / 2) - ((-2^{t - 1} + 1) / 2^{t}))
# 	a : 1 / 2, x : -(l / 2^{t}), y : -((-2^{t - 1} + 1) / 2^{t})
# 51	conjecture		|- forall_{n in NaturalPos} [forall_{x_{1}, x_{2}, ..., x_{n}, y in Complex | y != 0} (((x_{1} +  x_{2} +  ... +  x_{n}) / y) = ((x_{1} / y) +  (x_{2} / y) +  ... +  (x_{n} / y)))]
# 	proveit.numbers.division.distribute_frac_through_sum
# 52	instantiation	210	|- |(-2^{t - 1}, 1)| = |(1, ..., 2)|
# 	a : -2^{t - 1}, b : 1
# 53	instantiation	237, 212, 69	|- (-2^{t - 1}) in Complex
# 	A : Real, B : Complex, x : -2^{t - 1}
# 54	instantiation	70, 95, 96, 151, 77*	|- ((-2^{t - 1}) / 2^{t}) = (-(1 / 2))
# 	x : 2^{t - 1}, y : 2^{t}
# 55	instantiation	160, 71	|- ((1 / 2) - (-(1 / 2) + (1 / 2^{t}))) = ((1 / 2) + ((1 / 2) - (1 / 2^{t})))
# 	f(_a) : (1 / 2) + _a, x : -(-(1 / 2) + (1 / 2^{t})), y : (1 / 2) - (1 / 2^{t})
# 56	instantiation	179, 72, 73	|- ((1 / 2) + ((1 / 2) - (1 / 2^{t}))) = (1 - (1 / 2^{t}))
# 	x : (1 / 2) + ((1 / 2) - (1 / 2^{t})), y : (1 / 2) + (1 / 2) - (1 / 2^{t}), z : 1 - (1 / 2^{t})
# 57	instantiation	74, 220, 195, 196, 75	|- (0 + 1) in NaturalPos
# 	i : 1, j : 0, a : (0), b : 1, c : ()
# 58	conjecture		|- forall_{a in RealPos} ((-a) in RealNeg)
# 	proveit.numbers.negation.real_neg_closure
# 59	instantiation	76, 166, 206, 147	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l <= 2^{t - 1}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 60	instantiation	130, 112, 113, 151	|- (2^{t - 1} / 2^{t}) in Real
# 	a : 2^{t - 1}, b : 2^{t}
# 61	instantiation	160, 77	|- ((1 / 2) + (2^{t - 1} / 2^{t})) = ((1 / 2) + (1 / 2))
# 	f(_a) : (1 / 2) + _a, x : 2^{t - 1} / 2^{t}, y : 1 / 2
# 62	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 63	instantiation	78, 105, 120, 80	{b in {b_{f}, b_{r}}} |- delta_{b} in Real
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 64	instantiation	79, 105, 120, 80	{b in {b_{f}, b_{r}}} |- delta_{b} <= (1 / 2)
# 	a : -(1 / 2), b : 1 / 2, x : delta_{b}
# 65	conjecture		|- forall_{a, x, y in Real | x <= y} ((a + x) <= (a + y))
# 	proveit.numbers.addition.weak_bound_via_right_term_bound
# 66	instantiation	221, 83	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-(l / 2^{t})) in Real
# 	a : l / 2^{t}
# 67	instantiation	221, 82	|- (-((-2^{t - 1} + 1) / 2^{t})) in Real
# 	a : (-2^{t - 1} + 1) / 2^{t}
# 68	instantiation	81, 82, 83, 84	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-((-2^{t - 1} + 1) / 2^{t})) >= (-(l / 2^{t}))
# 	x : (-2^{t - 1} + 1) / 2^{t}, y : l / 2^{t}
# 69	instantiation	237, 223, 85	|- (-2^{t - 1}) in Real
# 	A : Rational, B : Real, x : -2^{t - 1}
# 70	conjecture		|- forall_{x, y in Complex | y != 0} (((-x) / y) = (-(x / y)))
# 	proveit.numbers.division.neg_frac_neg_numerator
# 71	instantiation	86, 87, 109, 88*	|- (-(-(1 / 2) + (1 / 2^{t}))) = ((1 / 2) - (1 / 2^{t}))
# 	a : -(1 / 2), b : 1 / 2^{t}
# 72	instantiation	194, 220, 234, 195, 89, 196, 107, 92	|- ((1 / 2) + ((1 / 2) - (1 / 2^{t}))) =  \\ ((1 / 2) + (1 / 2) - (1 / 2^{t}))
# 	i : 1, j : 2, k : 0, a : (1 / 2), b : (1 / 2, -(1 / 2^{t})), c : ()
# 73	instantiation	90, 195, 234, 220, 196, 91, 107, 92, 93*	|- ((1 / 2) + (1 / 2) - (1 / 2^{t})) =  \\ (1 - (1 / 2^{t}))
# 	i : 0, j : 2, k : 1, a : (), b : (1 / 2, 1 / 2), c : (-(1 / 2^{t}))
# 74	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b, c_{1}, c_{2}, ..., c_{j} in Natural | b > 0} ((a_{1} +  a_{2} +  ... +  a_{i} + b+ c_{1} +  c_{2} +  ... +  c_{j}) in NaturalPos)]
# 	proveit.numbers.addition.add_nat_pos_from_nonneg
# 75	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 76	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 77	instantiation	94, 95, 96, 151, 97*	|- (2^{t - 1} / 2^{t}) = (1 / 2)
# 	x : 2^{t - 1}, y : 2^{t}
# 78	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x in Real)]
# 	proveit.numbers.number_sets.real_numbers.all_in_interval_oc__is__real
# 79	conjecture		|- forall_{a, b in Real} [forall_{x in (a,b]} (x <= b)]
# 	proveit.numbers.number_sets.real_numbers.interval_oc_upper_bound
# 80	instantiation	98, 99	{b in {b_{f}, b_{r}}} |- delta_{b} in (-(1 / 2),1 / 2]
# 	b : b
# 81	conjecture		|- forall_{x, y in Real | x <= y} ((-x) >= (-y))
# 	proveit.numbers.negation.negated_weak_bound
# 82	instantiation	130, 101, 113, 151	|- ((-2^{t - 1} + 1) / 2^{t}) in Real
# 	a : -2^{t - 1} + 1, b : 2^{t}
# 83	instantiation	130, 102, 113, 151	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (l / 2^{t}) in Real
# 	a : l, b : 2^{t}
# 84	instantiation	100, 113, 101, 102, 103, 104	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-2^{t - 1} + 1) / 2^{t}) <= (l / 2^{t})
# 	a : 2^{t}, x : -2^{t - 1} + 1, y : l
# 85	instantiation	237, 231, 186	|- (-2^{t - 1}) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1}
# 86	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 87	instantiation	237, 212, 105	|- (-(1 / 2)) in Complex
# 	A : Real, B : Complex, x : -(1 / 2)
# 88	instantiation	106, 107	|- (-(-(1 / 2))) = (1 / 2)
# 	x : 1 / 2
# 89	instantiation	210	|- |(1 / 2, -(1 / 2^{t}))| = |(1, ..., 2)|
# 	a : 1 / 2, b : -(1 / 2^{t})
# 90	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.association
# 91	instantiation	210	|- |(1 / 2, 1 / 2)| = |(1, ..., 2)|
# 	a : 1 / 2, b : 1 / 2
# 92	instantiation	108, 109	|- (-(1 / 2^{t})) in Complex
# 	a : 1 / 2^{t}
# 93	instantiation	110, 209, 227, 111*	|- ((1 / 2) + (1 / 2)) = 1
# 	a : 1, b : 2, c : 1, d : 2
# 94	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 95	instantiation	237, 212, 112	|- 2^{t - 1} in Complex
# 	A : Real, B : Complex, x : 2^{t - 1}
# 96	instantiation	237, 212, 113	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 97	instantiation	179, 114, 115	|- (2^{t - 1} * (2^{t})^{-1}) = (1 / 2)
# 	x : 2^{t - 1} * (2^{t})^{-1}, y : 2^{t - 1} * 2^{-t}, z : 1 / 2
# 98	conjecture		|- forall_{b in {b_{f}, b_{r}}} (delta_{b} in (-(1 / 2),1 / 2])
# 	proveit.physics.quantum.QPE._delta_b_in_interval
# 99	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 100	conjecture		|- forall_{a, x, y in Real | x <= y, a > 0} ((x / a) <= (y / a))
# 	proveit.numbers.division.weak_div_from_numer_bound__pos_denom
# 101	instantiation	237, 223, 116	|- (-2^{t - 1} + 1) in Real
# 	A : Rational, B : Real, x : -2^{t - 1} + 1
# 102	instantiation	237, 223, 117	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 103	instantiation	118, 166, 206, 147	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) <= l
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 104	instantiation	119, 188	|- 2^{t} > 0
# 	n : 2^{t}
# 105	instantiation	221, 120	|- (-(1 / 2)) in Real
# 	a : 1 / 2
# 106	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 	proveit.numbers.negation.double_negation
# 107	instantiation	237, 212, 120	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 108	conjecture		|- forall_{a in Complex} ((-a) in Complex)
# 	proveit.numbers.negation.complex_closure
# 109	instantiation	237, 212, 121	|- (1 / 2^{t}) in Complex
# 	A : Real, B : Complex, x : 1 / 2^{t}
# 110	conjecture		|- forall_{a, b, c, d in Integer} (((a / b) + (c / d)) = (((a * d) + (b * c)) / (b * d)))
# 	proveit.numbers.addition.rational_pair_addition
# 111	instantiation	179, 122, 123	|- (((1 * 2) + (2 * 1)) / (2 * 2)) = 1
# 	x : ((1 * 2) + (2 * 1)) / (2 * 2), y : 4 / 4, z : 1
# 112	instantiation	237, 223, 124	|- 2^{t - 1} in Real
# 	A : Rational, B : Real, x : 2^{t - 1}
# 113	instantiation	228, 229, 188	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 114	instantiation	160, 125	|- (2^{t - 1} * (2^{t})^{-1}) = (2^{t - 1} * 2^{-t})
# 	f(_a) : 2^{t - 1} * _a, x : (2^{t})^{-1}, y : 2^{-t}
# 115	instantiation	126, 191, 127, 211, 141, 128*	|- (2^{t - 1} * 2^{-t}) = (1 / 2)
# 	a : 2, b : t - 1, c : -t
# 116	instantiation	237, 231, 166	|- (-2^{t - 1} + 1) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1} + 1
# 117	instantiation	237, 231, 129	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 118	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 119	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 120	instantiation	130, 177, 207, 141	|- (1 / 2) in Real
# 	a : 1, b : 2
# 121	instantiation	237, 131, 132	|- (1 / 2^{t}) in Real
# 	A : RealPos, B : Real, x : 1 / 2^{t}
# 122	instantiation	171, 234, 133, 134, 135, 136	|- (((1 * 2) + (2 * 1)) / (2 * 2)) =  \\ (4 / 4)
# 	n : 2, f(_a, _b) : _a / _b, x : ((1 * 2) + (2 * 1), 2 * 2), y : (4, 4)
# 123	instantiation	137, 138, 139	|- (4 / 4) = 1
# 	x : 4
# 124	instantiation	237, 231, 206	|- 2^{t - 1} in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1}
# 125	instantiation	140, 191, 222, 213, 141, 142*	|- (2^{t})^{-1} = 2^{-t}
# 	a : 2, b : t, c : -1
# 126	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 127	instantiation	237, 223, 143	|- (t - 1) in Real
# 	A : Rational, B : Real, x : t - 1
# 128	instantiation	179, 144, 145	|- 2^{(t - 1) - t} = (1 / 2)
# 	x : 2^{(t - 1) - t}, y : 2^{-1}, z : 1 / 2
# 129	instantiation	237, 146, 147	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 130	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 131	conjecture		|- RealPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.real_pos_within_real
# 132	instantiation	148, 149, 150, 151	|- (1 / 2^{t}) in RealPos
# 	a : 1, b : 2^{t}
# 133	instantiation	210	|- |((1 * 2) + (2 * 1), 2 * 2)| = |(1, ..., 2)|
# 	a : (1 * 2) + (2 * 1), b : 2 * 2
# 134	instantiation	210	|- |(4, 4)| = |(1, ..., 2)|
# 	a : 4, b : 4
# 135	instantiation	179, 152, 153	|- ((1 * 2) + (2 * 1)) = 4
# 	x : (1 * 2) + (2 * 1), y : 2 + 2, z : 4
# 136	conjecture		|- (2 * 2) = 4
# 	proveit.numbers.numerals.decimals.mult_2_2
# 137	conjecture		|- forall_{x in Complex | x != 0} ((x / x) = 1)
# 	proveit.numbers.division.frac_cancel_complete
# 138	instantiation	237, 212, 154	|- 4 in Complex
# 	A : Real, B : Complex, x : 4
# 139	instantiation	170, 155	|- 4 != 0
# 	n : 4
# 140	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b})^{c} = a^{b * c})
# 	proveit.numbers.exponentiation.real_power_of_real_power
# 141	instantiation	170, 226	|- 2 != 0
# 	n : 2
# 142	instantiation	156, 200, 157, 158*	|- (t * (-1)) = (-t)
# 	x : t, y : 1
# 143	instantiation	237, 231, 159	|- (t - 1) in Rational
# 	A : Integer, B : Rational, x : t - 1
# 144	instantiation	160, 161	|- 2^{(t - 1) - t} = 2^{-1}
# 	f(_a) : 2^{_a}, x : (t - 1) - t, y : -1
# 145	instantiation	162, 163, 241, 164*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 146	instantiation	165, 166, 206	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 147	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 148	conjecture		|- forall_{a, b in RealPos | b != 0} ((a / b) in RealPos)
# 	proveit.numbers.division.div_real_pos_closure
# 149	instantiation	237, 168, 167	|- 1 in RealPos
# 	A : RationalPos, B : RealPos, x : 1
# 150	instantiation	237, 168, 169	|- 2^{t} in RealPos
# 	A : RationalPos, B : RealPos, x : 2^{t}
# 151	instantiation	170, 188	|- 2^{t} != 0
# 	n : 2^{t}
# 152	instantiation	171, 234, 172, 173, 174, 175	|- ((1 * 2) + (2 * 1)) =  \\ (2 + 2)
# 	n : 2, f(_a, _b) : _a + _b, x : (1 * 2, 2 * 1), y : (2, 2)
# 153	conjecture		|- (2 + 2) = 4
# 	proveit.numbers.numerals.decimals.add_2_2
# 154	instantiation	237, 223, 176	|- 4 in Real
# 	A : Rational, B : Real, x : 4
# 155	conjecture		|- 4 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat4
# 156	conjecture		|- forall_{x, y in Complex} ((x * (-y)) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_right
# 157	instantiation	237, 212, 177	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 158	instantiation	190, 200	|- (t * 1) = t
# 	x : t
# 159	instantiation	185, 178, 232	|- (t - 1) in Integer
# 	a : t, b : -1
# 160	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 161	instantiation	179, 180, 181	|- ((t - 1) - t) = (-1)
# 	x : (t - 1) - t, y : t - 1 - t, z : -1
# 162	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 163	instantiation	237, 182, 183	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 164	instantiation	184, 191	|- 2^{1} = 2
# 	x : 2
# 165	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 166	instantiation	185, 186, 209	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 167	instantiation	237, 187, 241	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 168	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 169	instantiation	237, 187, 188	|- 2^{t} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t}
# 170	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 171	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 172	instantiation	210	|- |(1 * 2, 2 * 1)| = |(1, ..., 2)|
# 	a : 1 * 2, b : 2 * 1
# 173	instantiation	210	|- |(2, 2)| = |(1, ..., 2)|
# 	a : 2, b : 2
# 174	instantiation	189, 191	|- (1 * 2) = 2
# 	x : 2
# 175	instantiation	190, 191	|- (2 * 1) = 2
# 	x : 2
# 176	instantiation	237, 231, 192	|- 4 in Rational
# 	A : Integer, B : Rational, x : 4
# 177	instantiation	237, 223, 193	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 178	instantiation	237, 217, 230	|- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 179	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 180	instantiation	194, 195, 234, 220, 196, 197, 200, 201, 198	|- ((t - 1) - t) =  \\ (t - 1 - t)
# 	i : 0, j : 2, k : 1, a : (), b : (t, -1), c : (-t)
# 181	instantiation	199, 200, 201, 202	|- (t - 1 - t) = (-1)
# 	a : t, b : t, c : -1
# 182	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 183	instantiation	237, 203, 204	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 184	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 185	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 186	instantiation	205, 206	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 187	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 188	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 189	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 190	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 191	instantiation	237, 212, 207	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 192	instantiation	237, 233, 208	|- 4 in Integer
# 	A : Natural, B : Integer, x : 4
# 193	instantiation	237, 231, 209	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 194	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 195	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 196	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 197	instantiation	210	|- |(t, -1)| = |(1, ..., 2)|
# 	a : t, b : -1
# 198	instantiation	237, 212, 211	|- (-t) in Complex
# 	A : Real, B : Complex, x : -t
# 199	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 200	instantiation	237, 212, 222	|- t in Complex
# 	A : Real, B : Complex, x : t
# 201	instantiation	237, 212, 213	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 202	instantiation	214	|- t = t
# 	x : t
# 203	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 204	instantiation	237, 215, 216	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 205	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 206	instantiation	237, 217, 218	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 207	instantiation	237, 223, 219	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 208	conjecture		|- 4 in Natural
# 	proveit.numbers.numerals.decimals.nat4
# 209	instantiation	237, 233, 220	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 210	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 211	instantiation	221, 222	|- (-t) in Real
# 	a : t
# 212	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 213	instantiation	237, 223, 224	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 214	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 215	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 216	instantiation	237, 225, 226	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 217	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 218	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 219	instantiation	237, 231, 227	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 220	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 221	conjecture		|- forall_{a in Real} ((-a) in Real)
# 	proveit.numbers.negation.real_closure
# 222	instantiation	228, 229, 230	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 223	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 224	instantiation	237, 231, 232	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 225	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 226	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 227	instantiation	237, 233, 234	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 228	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 229	instantiation	235, 236	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 230	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 231	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 232	instantiation	237, 238, 239	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 233	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 234	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 235	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 236	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 237	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 238	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 239	instantiation	240, 241	|- (-1) in IntegerNeg
# 	a : 1
# 240	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 241	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
