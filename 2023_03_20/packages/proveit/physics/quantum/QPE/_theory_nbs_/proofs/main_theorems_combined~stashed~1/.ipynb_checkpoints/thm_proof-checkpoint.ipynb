# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#main_theorems_combined">main_theorems_combined</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

from proveit.physics.quantum.QPE import qpe_exact, qpe_best_guarantee, qpe_precision_guarantee

# %%
# %proving main_theorems_combined
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="main_theorems_combined">main_theorems_combined:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f1f012f18787e335a59c2e9be6c08a09c9b460910/expr.ipynb"><img src="...
# main_theorems_combined may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE.main_theorems_combined has been proven.
# 	step type	requirements	statement
# ...
