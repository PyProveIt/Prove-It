# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_modabs_in_full_domain_simp">_modabs_in_full_domain_simp</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import l, x, N, defaults
from proveit.numbers import (
        zero, one, two, Div, greater_eq, Less, Mult, Neg, subtract)
from proveit.numbers.modular import mod_abs_x_reduce_to_abs_x
from proveit.physics.quantum.QPE import (
        _t_in_natural_pos, _two_pow_t, _two_pow__t_minus_one,
        _two_pow_t_is_nat_pos)

# %%
# %proving _modabs_in_full_domain_simp
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_modabs_in_full_domain_simp">_modabs_in_full_domain_simp:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0fb99394f15210ee297c213071cd6210cf67fb1a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/4e60ddab0f5da45bc9c316d8a0584d5c28887fa00/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = _modabs_in_full_domain_simp.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/9d44703202c90bf74d9fdb2fd6b052ac5a74ac8b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience
l_membership = _modabs_in_full_domain_simp.condition
# Out:
# <strong id="l_membership">l_membership:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# We plan to instantiate the following `mod_abs_x_reduce_to_abs_x` theorem with $x: \ell$ and $N = 2^t$, the challenging piece of which is to establish that $|\ell|\le\frac{2^t}{2}=2^{t-1}$:

# %%
mod_abs_x_reduce_to_abs_x
# Out:
# |- forall_{x in Real, N in RealPos | |x| <= (N / 2)} (|x|_{mod N} = |x|)

# %% [markdown]
# Establish an upper bound on $|\ell|$, and along the way establish some properties of the $\ell$ bounds $2^{t-1}$ and $-2^{t-1}+1$ so their absolute values will eventually be (automatically) simplified and so we can also evaluate a Max() on the values.

# %%
from proveit.numbers.absolute_value import weak_upper_bound_asym_interval
weak_upper_bound_asym_interval
# Out:
# |- forall_{a, b, c in Real | b <= a <= c} (|a| <= Max(|b|, |c|))

# %%
temp_bound_01 = _two_pow__t_minus_one.deduce_bound(_t_in_natural_pos.derive_element_lower_bound())
# Out:
# <strong id="temp_bound_01">temp_bound_01:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/bbe5d8957fd6ab88edea41e222208158b321369a0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/1d407b6d4c9b606e0513b5a9b2bc6a67e023e89d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
temp_bound_02 = temp_bound_01.left_mult_both_sides(Neg(one))
# Out:
# <strong id="temp_bound_02">temp_bound_02:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/261c167eb4ee7d829cdcfe0f0810668baab016ce0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/e1f88d7d68d4619917a64a42a73b4888c8a208950/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
temp_bound_03 = temp_bound_02.right_add_both_sides(one)
# Out:
# <strong id="temp_bound_03">temp_bound_03:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/400a69e9beea08603bb4b01318d3d66447214ecb0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/4dd4e1fec9619c4b15e25eb52b5f102bd3c931b40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Want to explicitly establish this, so the eventual Max() evaluation
# will go through in the instantiation of abs_l_max_bound further below
Less(subtract(temp_bound_01.lhs, one), temp_bound_01.lhs).prove()
# Out:
# |- (2^{t - 1} - 1) < 2^{t - 1}

# %% [markdown]
# Since we know $-2^{t-1}+1 \le 0$ and $2^{t-1} > 0$, when we instantiate the `weak_upper_bound_asym_interval` theorem, the absolute values are simplified, and since we have pre-established the relative size of $2^{t-1}-1$ and $2^{t-1}$, the Max() operation can be simplified:

# %%
from proveit import a, b, c
_a_sub, _b_sub, _c_sub = (
    l,
    l_membership.domain.lower_bound,
    l_membership.domain.upper_bound)
abs_l_max_bound = weak_upper_bound_asym_interval.instantiate({a: _a_sub, b: _b_sub, c: _c_sub})
# Out:
# <strong id="abs_l_max_bound">abs_l_max_bound:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/8bc9b38cf75c7371ab646fd064ad09fc02345f250/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/9729b36e815ddbc23d41e6e07dead766f2ce4d590/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__modabs_in_full_domain_simp/84c6a6d26fcc7528f427aa85a1baa16b109dabdb0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Now we're ready to instantiate the mod_abs_x_reduce_to_abs_x theorem

# %%
mod_abs_x_reduce_to_abs_x.instantiate({x: l, N: _two_pow_t})
# Out:
# {l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |l| = |l|
# _modabs_in_full_domain_simp may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._modabs_in_full_domain_simp has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} (|l|_{mod 2^{t}} = |l|)
# 1	instantiation	2, 11, 3, 4	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |l|_{mod 2^{t}} = |l|
# 	x : l, N : 2^{t}
# 2	conjecture		|- forall_{x in Real, N in RealPos | |x| <= (N / 2)} (|x|_{mod N} = |x|)
# 	proveit.numbers.modular.mod_abs_x_reduce_to_abs_x
# 3	instantiation	216, 5, 6	|- 2^{t} in RealPos
# 	A : RationalPos, B : RealPos, x : 2^{t}
# 4	instantiation	7, 8, 9	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |l| <= (2^{t} / 2)
# 	P(_a) : |l| <= _a, x : 2^{t - 1}, y : 2^{t} / 2
# 5	conjecture		|- RationalPos proper_subset RealPos
# 	proveit.numbers.number_sets.real_numbers.rational_pos_within_real_pos
# 6	instantiation	216, 109, 179	|- 2^{t} in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2^{t}
# 7	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 8	instantiation	10, 11, 12, 111, 13, 14*	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- |l| <= 2^{t - 1}
# 	a : l, b : -2^{t - 1} + 1, c : 2^{t - 1}
# 9	instantiation	143, 133, 15, 16	|- 2^{t - 1} = (2^{t} / 2)
# 	a : 2^{t - 1}, b : (1 / 2^{1}) * 2^{t}, c : (1 / 2) * 2^{t}, d : 2^{t} / 2
# 10	conjecture		|- forall_{a, b, c in Real | b <= a <= c} (|a| <= Max(|b|, |c|))
# 	proveit.numbers.absolute_value.weak_upper_bound_asym_interval
# 11	instantiation	216, 205, 17	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Real
# 	A : Rational, B : Real, x : l
# 12	instantiation	216, 205, 18	|- (-2^{t - 1} + 1) in Real
# 	A : Rational, B : Real, x : -2^{t - 1} + 1
# 13	instantiation	19, 20, 21	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- ((-2^{t - 1} + 1) <= l) and (l <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= l, B : l <= 2^{t - 1}
# 14	instantiation	127, 22, 23	|- Max(|-2^{t - 1} + 1|, |2^{t - 1}|) = 2^{t - 1}
# 	x : Max(|-2^{t - 1} + 1|, |2^{t - 1}|), y : Max(2^{t - 1} - 1, 2^{t - 1}), z : 2^{t - 1}
# 15	instantiation	158, 24	|- ((1 / 2^{1}) * 2^{t}) = ((1 / 2) * 2^{t})
# 	f(_a) : _a * 2^{t}, x : 1 / 2^{1}, y : 1 / 2
# 16	instantiation	156, 25	|- ((1 / 2) * 2^{t}) = (2^{t} / 2)
# 	x : 2^{t} / 2, y : (1 / 2) * 2^{t}
# 17	instantiation	216, 212, 26	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Rational
# 	A : Integer, B : Rational, x : l
# 18	instantiation	216, 212, 50	|- (-2^{t - 1} + 1) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1} + 1
# 19	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 20	instantiation	27, 50, 123, 38	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- (-2^{t - 1} + 1) <= l
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 21	instantiation	28, 50, 123, 38	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l <= 2^{t - 1}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : l
# 22	instantiation	72, 218, 29, 30, 31, 32	|- Max(|-2^{t - 1} + 1|, |2^{t - 1}|) =  \\ Max(2^{t - 1} - 1, 2^{t - 1})
# 	n : 2, f(_a, _b) : Max(_a, _b), x : (|-2^{t - 1} + 1|, |2^{t - 1}|), y : (2^{t - 1} - 1, 2^{t - 1})
# 23	instantiation	127, 33, 34	|- Max(2^{t - 1} - 1, 2^{t - 1}) = 2^{t - 1}
# 	x : Max(2^{t - 1} - 1, 2^{t - 1}), y : Max(2^{t - 1}, 2^{t - 1} - 1), z : 2^{t - 1}
# 24	instantiation	158, 178	|- (1 / 2^{1}) = (1 / 2)
# 	f(_a) : 1 / _a, x : 2^{1}, y : 2
# 25	instantiation	35, 150, 189, 177, 36*	|- (2^{t} / 2) = ((1 / 2) * 2^{t})
# 	x : 2^{t}, y : 2
# 26	instantiation	216, 37, 38	{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in Integer
# 	A : {-2^{t - 1} + 1 .. 2^{t - 1}}, B : Integer, x : l
# 27	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 28	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 29	instantiation	147	|- |(|-2^{t - 1} + 1|, |2^{t - 1}|)| = |(1, ..., 2)|
# 	a : |-2^{t - 1} + 1|, b : |2^{t - 1}|
# 30	instantiation	147	|- |(2^{t - 1} - 1, 2^{t - 1})| = |(1, ..., 2)|
# 	a : 2^{t - 1} - 1, b : 2^{t - 1}
# 31	instantiation	39, 40, 41*	|- |-2^{t - 1} + 1| = (2^{t - 1} - 1)
# 	x : -2^{t - 1} + 1
# 32	instantiation	42, 43	|- |2^{t - 1}| = 2^{t - 1}
# 	x : 2^{t - 1}
# 33	instantiation	44, 104, 111	|- Max(2^{t - 1} - 1, 2^{t - 1}) = Max(2^{t - 1}, 2^{t - 1} - 1)
# 	x : 2^{t - 1} - 1, y : 2^{t - 1}
# 34	instantiation	45, 111, 104, 46*	|- Max(2^{t - 1}, 2^{t - 1} - 1) = 2^{t - 1}
# 	x : 2^{t - 1}, y : 2^{t - 1} - 1
# 35	conjecture		|- forall_{x, y in Complex | y != 0} ((x / y) = (x * y^{-1}))
# 	proveit.numbers.division.div_as_mult
# 36	instantiation	127, 47, 48	|- (2^{t} * 2^{-1}) = ((1 / 2) * 2^{t})
# 	x : 2^{t} * 2^{-1}, y : 2^{t} * (1 / 2), z : (1 / 2) * 2^{t}
# 37	instantiation	49, 50, 123	|- {-2^{t - 1} + 1 .. 2^{t - 1}} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}
# 38	assumption		{l in {-2^{t - 1} + 1 .. 2^{t - 1}}} |- l in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 39	conjecture		|- forall_{x | x <= 0} (|x| = (-x))
# 	proveit.numbers.absolute_value.abs_neg_elim
# 40	instantiation	51, 186, 69, 183, 52, 53*	|- (-2^{t - 1} + 1) <= 0
# 	a : 1, x : -2^{t - 1}, y : -1
# 41	instantiation	54, 55, 175, 56*	|- (-(-2^{t - 1} + 1)) = (2^{t - 1} - 1)
# 	a : -2^{t - 1}, b : 1
# 42	conjecture		|- forall_{x | x >= 0} (|x| = x)
# 	proveit.numbers.absolute_value.abs_non_neg_elim
# 43	instantiation	98, 57	|- 0 <= 2^{t - 1}
# 	x : 0, y : 2^{t - 1}
# 44	conjecture		|- forall_{x, y in Real} (Max(x, y) = Max(y, x))
# 	proveit.numbers.ordering.max_bin_args_commute
# 45	axiom		|- forall_{x, y in Real} (Max(x, y) = {x if x >= y; y if y > x.)
# 	proveit.numbers.ordering.max_def_bin
# 46	instantiation	127, 58, 59	|- {2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1); 2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}. = 2^{t - 1}
# 	x : {2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1); 2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}., y : {2^{t - 1}; 2^{t - 1} - 1 if FALSE., z : 2^{t - 1}
# 47	instantiation	158, 60	|- (2^{t} * 2^{-1}) = (2^{t} * (1 / 2))
# 	f(_a) : 2^{t} * _a, x : 2^{-1}, y : 1 / 2
# 48	instantiation	61, 150, 62	|- (2^{t} * (1 / 2)) = ((1 / 2) * 2^{t})
# 	a : 2^{t}, b : 1 / 2
# 49	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 50	instantiation	164, 92, 204	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 51	conjecture		|- forall_{a, x, y in Real | x <= y} ((x + a) <= (y + a))
# 	proveit.numbers.addition.weak_bound_via_left_term_bound
# 52	instantiation	63, 183, 186, 111, 64, 65, 66*, 67*	|- (-1) >= (-2^{t - 1})
# 	a : -1, x : 1, y : 2^{t - 1}
# 53	instantiation	68, 175, 140	|- (-1 + 1) = 0
# 	a : 1, b : 1
# 54	conjecture		|- forall_{a, b in Complex} ((-(a + b)) = (-a - b))
# 	proveit.numbers.negation.distribute_neg_through_binary_sum
# 55	instantiation	216, 197, 69	|- (-2^{t - 1}) in Complex
# 	A : Real, B : Complex, x : -2^{t - 1}
# 56	instantiation	70, 90	|- (-(-2^{t - 1})) = 2^{t - 1}
# 	x : 2^{t - 1}
# 57	instantiation	71, 130	|- 2^{t - 1} > 0
# 	n : 2^{t - 1}
# 58	instantiation	72, 218, 73, 74, 75, 76	|- {2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1); 2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}. =  \\ {2^{t - 1}; 2^{t - 1} - 1 if FALSE.
# 	n : 2, f(_a, _b) : {_a; _b., x : (2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1), 2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}), y : (2^{t - 1}, 2^{t - 1} - 1 if FALSE)
# 59	instantiation	77, 135, 211, 137	|- {2^{t - 1}; 2^{t - 1} - 1 if FALSE. = 2^{t - 1}
# 	m : 0, n : 1, a : (), b : 2^{t - 1}, c : (2^{t - 1} - 1)
# 60	instantiation	172, 173, 215, 178*	|- 2^{-1} = (1 / 2)
# 	a : 2, n : 1
# 61	conjecture		|- forall_{a, b in Complex} ((a * b) = (b * a))
# 	proveit.numbers.multiplication.commutation
# 62	instantiation	216, 197, 78	|- (1 / 2) in Complex
# 	A : Real, B : Complex, x : 1 / 2
# 63	conjecture		|- forall_{a, x, y in Real | x <= y, a <= 0} ((a * x) >= (a * y))
# 	proveit.numbers.multiplication.reversed_weak_bound_via_right_factor_bound
# 64	instantiation	181, 130	|- 2^{t - 1} >= 1
# 	n : 2^{t - 1}
# 65	instantiation	98, 79	|- (-1) <= 0
# 	x : -1, y : 0
# 66	instantiation	81, 175, 90, 80*	|- ((-1) * 2^{t - 1}) = (-2^{t - 1})
# 	x : 1, y : 2^{t - 1}
# 67	instantiation	81, 175, 82*	|- ((-1) * 1) = (-1)
# 	x : 1, y : 1
# 68	conjecture		|- forall_{a, b in Complex | a = b} ((-a + b) = 0)
# 	proveit.numbers.addition.subtraction.add_cancel_reverse
# 69	instantiation	216, 205, 83	|- (-2^{t - 1}) in Real
# 	A : Rational, B : Real, x : -2^{t - 1}
# 70	conjecture		|- forall_{x in Complex} ((-(-x)) = x)
# 	proveit.numbers.negation.double_negation
# 71	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 72	axiom		|- forall_{n in Natural} [forall_{f, x_{1}, x_{2}, ..., x_{n}, y_{1}, y_{2}, ..., y_{n} | (x_{1} = y_{1}), (x_{2} = y_{2}), ..., (x_{n} = y_{n})} (f(x_{1}, x_{2}, ..., x_{n}) =  \\ f(y_{1}, y_{2}, ..., y_{n}))]
# 	proveit.core_expr_types.operations.operands_substitution
# 73	instantiation	147	|- |(2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1), 2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1})| = |(1, ..., 2)|
# 	a : {2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1)., b : {2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}.
# 74	instantiation	147	|- |(2^{t - 1}, 2^{t - 1} - 1 if FALSE)| = |(1, ..., 2)|
# 	a : 2^{t - 1}, b : {2^{t - 1} - 1 if FALSE.
# 75	instantiation	84, 94	|- {2^{t - 1} if 2^{t - 1} >= (2^{t - 1} - 1). = 2^{t - 1}
# 	a : 2^{t - 1}, Q : 2^{t - 1} >= (2^{t - 1} - 1)
# 76	instantiation	85, 86	|- {2^{t - 1} - 1 if (2^{t - 1} - 1) > 2^{t - 1}. = {2^{t - 1} - 1 if FALSE.
# 	a : 2^{t - 1} - 1, Q : (2^{t - 1} - 1) > 2^{t - 1}
# 77	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 78	instantiation	216, 205, 87	|- (1 / 2) in Real
# 	A : Rational, B : Real, x : 1 / 2
# 79	instantiation	88, 208	|- (-1) < 0
# 	a : -1
# 80	instantiation	89, 90	|- (1 * 2^{t - 1}) = 2^{t - 1}
# 	x : 2^{t - 1}
# 81	conjecture		|- forall_{x, y in Complex} (((-x) * y) = (-(x * y)))
# 	proveit.numbers.multiplication.mult_neg_left
# 82	instantiation	91, 175	|- (1 * 1) = 1
# 	x : 1
# 83	instantiation	216, 212, 92	|- (-2^{t - 1}) in Rational
# 	A : Integer, B : Rational, x : -2^{t - 1}
# 84	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 85	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 86	instantiation	93, 104, 111, 94	|- [not](2^{t - 1} < (2^{t - 1} - 1))
# 	x : 2^{t - 1} - 1, y : 2^{t - 1}
# 87	instantiation	216, 95, 96	|- (1 / 2) in Rational
# 	A : RationalPos, B : Rational, x : 1 / 2
# 88	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 89	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 90	instantiation	216, 197, 111	|- 2^{t - 1} in Complex
# 	A : Real, B : Complex, x : 2^{t - 1}
# 91	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 92	instantiation	97, 123	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 93	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 94	instantiation	98, 99	|- (2^{t - 1} - 1) <= 2^{t - 1}
# 	x : 2^{t - 1} - 1, y : 2^{t - 1}
# 95	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 96	instantiation	100, 101, 102	|- (1 / 2) in RationalPos
# 	a : 1, b : 2
# 97	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 98	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 99	instantiation	103, 104, 105, 186, 106, 107*, 108*	|- (2^{t - 1} - 1) < 2^{t - 1}
# 	a : 2^{t - 1} - 1, x : 0, y : 1
# 100	conjecture		|- forall_{a, b in RationalPos} ((a / b) in RationalPos)
# 	proveit.numbers.division.div_rational_pos_closure
# 101	instantiation	216, 109, 215	|- 1 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 1
# 102	instantiation	216, 109, 210	|- 2 in RationalPos
# 	A : NaturalPos, B : RationalPos, x : 2
# 103	conjecture		|- forall_{a, x, y in Real | x < y} ((x + a) < (y + a))
# 	proveit.numbers.addition.strong_bound_via_left_term_bound
# 104	instantiation	110, 111, 183	|- (2^{t - 1} - 1) in Real
# 	a : 2^{t - 1}, b : -1
# 105	conjecture		|- 0 in Real
# 	proveit.numbers.number_sets.real_numbers.zero_is_real
# 106	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 107	instantiation	143, 112, 113, 114	|- (0 + (2^{t - 1} - 1)) = (2^{t - 1} - 1)
# 	a : 0 + (2^{t - 1} - 1), b : ((1 / 2^{1}) * 2^{t}) - 1, c : ((1 / 2^{1}) * 2^{t}) - 1, d : 2^{t - 1} - 1
# 108	instantiation	143, 115, 116, 117	|- (1 + (2^{t - 1} - 1)) = 2^{t - 1}
# 	a : 1 + (2^{t - 1} - 1), b : (1 / 2^{1}) * 2^{t}, c : (1 / 2^{1}) * 2^{t}, d : 2^{t - 1}
# 109	conjecture		|- NaturalPos proper_subset RationalPos
# 	proveit.numbers.number_sets.rational_numbers.nat_pos_within_rational_pos
# 110	conjecture		|- forall_{a, b in Real} ((a + b) in Real)
# 	proveit.numbers.addition.add_real_closure_bin
# 111	instantiation	216, 205, 118	|- 2^{t - 1} in Real
# 	A : Rational, B : Real, x : 2^{t - 1}
# 112	instantiation	127, 119, 120	|- (0 + (2^{t - 1} - 1)) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	x : 0 + (2^{t - 1} - 1), y : 0 + (((1 / 2^{1}) * 2^{t}) - 1), z : ((1 / 2^{1}) * 2^{t}) - 1
# 113	instantiation	151	|- (((1 / 2^{1}) * 2^{t}) - 1) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	x : ((1 / 2^{1}) * 2^{t}) - 1
# 114	instantiation	156, 126	|- (((1 / 2^{1}) * 2^{t}) - 1) = (2^{t - 1} - 1)
# 	x : 2^{t - 1} - 1, y : ((1 / 2^{1}) * 2^{t}) - 1
# 115	instantiation	127, 121, 122	|- (1 + (2^{t - 1} - 1)) = ((1 / 2^{1}) * 2^{t})
# 	x : 1 + (2^{t - 1} - 1), y : 1 + (((1 / 2^{1}) * 2^{t}) - 1), z : (1 / 2^{1}) * 2^{t}
# 116	instantiation	151	|- ((1 / 2^{1}) * 2^{t}) = ((1 / 2^{1}) * 2^{t})
# 	x : (1 / 2^{1}) * 2^{t}
# 117	instantiation	156, 133	|- ((1 / 2^{1}) * 2^{t}) = 2^{t - 1}
# 	x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 118	instantiation	216, 212, 123	|- 2^{t - 1} in Rational
# 	A : Integer, B : Rational, x : 2^{t - 1}
# 119	instantiation	158, 126	|- (0 + (2^{t - 1} - 1)) = (0 + (((1 / 2^{1}) * 2^{t}) - 1))
# 	f(_a) : 0 + _a, x : 2^{t - 1} - 1, y : ((1 / 2^{1}) * 2^{t}) - 1
# 120	instantiation	127, 124, 125	|- (0 + (((1 / 2^{1}) * 2^{t}) - 1)) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	x : 0 + (((1 / 2^{1}) * 2^{t}) - 1), y : 0 + ((1 / 2^{1}) * 2^{t}) - 1, z : ((1 / 2^{1}) * 2^{t}) - 1
# 121	instantiation	158, 126	|- (1 + (2^{t - 1} - 1)) = (1 + (((1 / 2^{1}) * 2^{t}) - 1))
# 	f(_a) : 1 + _a, x : 2^{t - 1} - 1, y : ((1 / 2^{1}) * 2^{t}) - 1
# 122	instantiation	127, 128, 129	|- (1 + (((1 / 2^{1}) * 2^{t}) - 1)) = ((1 / 2^{1}) * 2^{t})
# 	x : 1 + (((1 / 2^{1}) * 2^{t}) - 1), y : 1 + ((1 / 2^{1}) * 2^{t}) - 1, z : (1 / 2^{1}) * 2^{t}
# 123	instantiation	216, 180, 130	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 124	instantiation	134, 211, 218, 135, 136, 137, 131, 139, 170	|- (0 + (((1 / 2^{1}) * 2^{t}) - 1)) =  \\ (0 + ((1 / 2^{1}) * 2^{t}) - 1)
# 	i : 1, j : 2, k : 0, a : (0), b : ((1 / 2^{1}) * 2^{t}, -1), c : ()
# 125	instantiation	132, 135, 218, 137, 136, 139, 170	|- (0 + ((1 / 2^{1}) * 2^{t}) - 1) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	i : 0, j : 2, a : (), b : ((1 / 2^{1}) * 2^{t}, -1)
# 126	instantiation	158, 133	|- (2^{t - 1} - 1) = (((1 / 2^{1}) * 2^{t}) - 1)
# 	f(_a) : _a - 1, x : 2^{t - 1}, y : (1 / 2^{1}) * 2^{t}
# 127	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 128	instantiation	134, 211, 218, 135, 136, 137, 175, 139, 170	|- (1 + (((1 / 2^{1}) * 2^{t}) - 1)) =  \\ (1 + ((1 / 2^{1}) * 2^{t}) - 1)
# 	i : 1, j : 2, k : 0, a : (1), b : ((1 / 2^{1}) * 2^{t}, -1), c : ()
# 129	instantiation	138, 175, 139, 140	|- (1 + ((1 / 2^{1}) * 2^{t}) - 1) = ((1 / 2^{1}) * 2^{t})
# 	a : 1, b : 1, c : (1 / 2^{1}) * 2^{t}
# 130	instantiation	141, 218, 142	|- 2^{t - 1} in NaturalPos
# 	a : 2, b : t - 1
# 131	conjecture		|- 0 in Complex
# 	proveit.numbers.number_sets.complex_numbers.zero_is_complex
# 132	conjecture		|- forall_{i, j in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + 0+ b_{1} +  b_{2} +  ... +  b_{j}) = (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}))]
# 	proveit.numbers.addition.elim_zero_any
# 133	instantiation	143, 144, 145, 146	|- 2^{t - 1} = ((1 / 2^{1}) * 2^{t})
# 	a : 2^{t - 1}, b : 2^{-1 + t}, c : 2^{-1} * 2^{t}, d : (1 / 2^{1}) * 2^{t}
# 134	conjecture		|- forall_{i, j, k in Natural} [forall_{a_{1}, a_{2}, ..., a_{i}, b_{1}, b_{2}, ..., b_{j}, c_{1}, c_{2}, ..., c_{k} in Complex} ((a_{1} +  a_{2} +  ... +  a_{i} + (b_{1} +  b_{2} +  ... +  b_{j})+ c_{1} +  c_{2} +  ... +  c_{k}) =  \\ (a_{1} +  a_{2} +  ... +  a_{i}+ b_{1} +  b_{2} +  ... +  b_{j}+ c_{1} +  c_{2} +  ... +  c_{k}))]
# 	proveit.numbers.addition.disassociation
# 135	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 136	instantiation	147	|- |((1 / 2^{1}) * 2^{t}, -1)| = |(1, ..., 2)|
# 	a : (1 / 2^{1}) * 2^{t}, b : -1
# 137	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 138	conjecture		|- forall_{a, b, c in Complex | a = b} ((a + c - b) = c)
# 	proveit.numbers.addition.subtraction.add_cancel_triple_13
# 139	instantiation	148, 149, 150	|- ((1 / 2^{1}) * 2^{t}) in Complex
# 	a : 1 / 2^{1}, b : 2^{t}
# 140	instantiation	151	|- 1 = 1
# 	x : 1
# 141	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 142	instantiation	152, 153, 154	|- (t - 1) in Natural
# 	a : t - 1
# 143	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 144	instantiation	158, 155	|- 2^{t - 1} = 2^{-1 + t}
# 	f(_a) : 2^{_a}, x : t - 1, y : -1 + t
# 145	instantiation	156, 157	|- 2^{-1 + t} = (2^{-1} * 2^{t})
# 	x : 2^{-1} * 2^{t}, y : 2^{-1 + t}
# 146	instantiation	158, 159	|- (2^{-1} * 2^{t}) = ((1 / 2^{1}) * 2^{t})
# 	f(_a) : _a * 2^{t}, x : 2^{-1}, y : 1 / 2^{1}
# 147	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 148	conjecture		|- forall_{a, b in Complex} ((a * b) in Complex)
# 	proveit.numbers.multiplication.mult_complex_closure_bin
# 149	instantiation	160, 175, 161, 162	|- (1 / 2^{1}) in Complex
# 	a : 1, b : 2^{1}
# 150	instantiation	216, 197, 163	|- 2^{t} in Complex
# 	A : Real, B : Complex, x : 2^{t}
# 151	axiom		|- forall_{x} (x = x)
# 	proveit.logic.equality.equals_reflexivity
# 152	conjecture		|- forall_{a in Integer | a >= 0} (a in Natural)
# 	proveit.numbers.number_sets.integers.nonneg_int_is_natural
# 153	instantiation	164, 165, 201	|- (t - 1) in Integer
# 	a : t, b : -1
# 154	instantiation	166, 167	|- (t - 1) >= 0
# 	a : t, b : 1
# 155	instantiation	168, 169, 170	|- (t - 1) = (-1 + t)
# 	a : t, b : -1
# 156	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 157	instantiation	171, 189, 183, 182, 177	|- (2^{-1} * 2^{t}) = 2^{-1 + t}
# 	a : 2, b : -1, c : t
# 158	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 159	instantiation	172, 173, 215	|- 2^{-1} = (1 / 2^{1})
# 	a : 2, n : 1
# 160	conjecture		|- forall_{a, b in Complex | b != 0} ((a / b) in Complex)
# 	proveit.numbers.division.div_complex_closure
# 161	instantiation	174, 189, 175	|- 2^{1} in Complex
# 	a : 2, b : 1
# 162	instantiation	176, 177, 178	|- 2^{1} != 0
# 	P(_a) : _a != 0, x : 2^{1}, y : 2
# 163	instantiation	190, 191, 179	|- 2^{t} in Real
# 	A : NaturalPos, B : Real, x : 2^{t}
# 164	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 165	instantiation	216, 180, 192	|- t in Integer
# 	A : NaturalPos, B : Integer, x : t
# 166	conjecture		|- forall_{a, b | a >= b} ((a - b) >= 0)
# 	proveit.numbers.addition.subtraction.nonneg_difference
# 167	instantiation	181, 192	|- t >= 1
# 	n : t
# 168	conjecture		|- forall_{a, b in Complex} ((a + b) = (b + a))
# 	proveit.numbers.addition.commutation
# 169	instantiation	216, 197, 182	|- t in Complex
# 	A : Real, B : Complex, x : t
# 170	instantiation	216, 197, 183	|- (-1) in Complex
# 	A : Real, B : Complex, x : -1
# 171	conjecture		|- forall_{a in Complex, b in Real, c in Real | a != 0} ((a^{b} * a^{c}) = a^{b + c})
# 	proveit.numbers.exponentiation.product_of_real_powers
# 172	conjecture		|- forall_{a in ComplexNonZero, n in NaturalPos} (a^{-n} = (1 / a^{n}))
# 	proveit.numbers.exponentiation.neg_power_as_div
# 173	instantiation	216, 184, 185	|- 2 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2
# 174	conjecture		|- forall_{a, b in Complex} (a^{b} in Complex)
# 	proveit.numbers.exponentiation.exp_complex_closure
# 175	instantiation	216, 197, 186	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 176	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 177	instantiation	187, 210	|- 2 != 0
# 	n : 2
# 178	instantiation	188, 189	|- 2^{1} = 2
# 	x : 2
# 179	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 180	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 181	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 182	instantiation	190, 191, 192	|- t in Real
# 	A : NaturalPos, B : Real, x : t
# 183	instantiation	216, 205, 193	|- (-1) in Real
# 	A : Rational, B : Real, x : -1
# 184	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 185	instantiation	216, 194, 195	|- 2 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2
# 186	instantiation	216, 205, 196	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 187	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 188	conjecture		|- forall_{x in Complex} (x^{1} = x)
# 	proveit.numbers.exponentiation.complex_x_to_first_power_is_x
# 189	instantiation	216, 197, 198	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 190	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 191	instantiation	199, 200	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 192	axiom		|- t in NaturalPos
# 	proveit.physics.quantum.QPE._t_in_natural_pos
# 193	instantiation	216, 212, 201	|- (-1) in Rational
# 	A : Integer, B : Rational, x : -1
# 194	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 195	instantiation	216, 202, 203	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 196	instantiation	216, 212, 204	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 197	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 198	instantiation	216, 205, 206	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 199	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 200	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 201	instantiation	216, 207, 208	|- (-1) in Integer
# 	A : IntegerNeg, B : Integer, x : -1
# 202	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 203	instantiation	216, 209, 210	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 204	instantiation	216, 217, 211	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 205	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 206	instantiation	216, 212, 213	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 207	conjecture		|- IntegerNeg proper_subset Integer
# 	proveit.numbers.number_sets.integers.neg_int_within_int
# 208	instantiation	214, 215	|- (-1) in IntegerNeg
# 	a : 1
# 209	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 210	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 211	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 212	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 213	instantiation	216, 217, 218	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 214	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 215	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 216	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 217	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 218	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
