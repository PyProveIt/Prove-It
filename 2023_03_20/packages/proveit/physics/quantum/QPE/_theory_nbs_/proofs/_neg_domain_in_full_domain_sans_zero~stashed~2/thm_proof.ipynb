# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_neg_domain_in_full_domain_sans_zero">_neg_domain_in_full_domain_sans_zero</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import a, defaults, e, l
from proveit.logic import InSet, NotEquals
from proveit.numbers import zero, one, Add, Less, Neg
from proveit.numbers import RealNeg
from proveit.numbers.negation import negated_positive_is_negative
from proveit.physics.quantum.QPE import (_full_domain, _full_domain_sans_zero,
                                         _neg_domain)
from proveit.physics.quantum.QPE import _two_pow_t_minus_one_is_nat_pos

# %%
# %proving _neg_domain_in_full_domain_sans_zero
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_neg_domain_in_full_domain_sans_zero">_neg_domain_in_full_domain_sans_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/03e33d4f0492578d2a8586e15f5f006508b1ed860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e7e32ef72661604a80f81b03af7bccfc3f8cd43c0/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# This theorem is very similar to its companion theorem `pos_domain_in_full_domain_sans_zero` and the approach is essentially the same.<br>
# The basic approach is to show that<br>
# $\ell\in\{-2^{t-1}+1 \ldots -(e+1)\}$ means $\ell\in\{-2^{t-1}+1\ldots 2^{t-1}\}$ and $\ell\ne 0$<br>
# More specifically:<br>
# (1) $\ell\in\{-2^{t-1}+1 \ldots -(e+1)\}$ means $\ell \ge -2^{t-1}+1$ (and $\ell\in\mathbb{Z}$)<br>
# (2) $\ell\in\{-2^{t-1}+1 \ldots -(e+1)\}$ means $\ell \le -(e+1)$<br>
# (3) $e\in\{1\ldots 2^{t-1}-2\}$ means $-(e + 1) < 0$<br>
# (4) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell<0$.<br/>
# (5) Thus $-2^{t-1 + 1} \le \ell \le 2^{t-1}$ and $\ell\ne 0$.<br/>
# (6) Thus $\ell\in\{-2^{t-1 + 1}\ldots 2^{t-1}\}-\{0\}$

# %%
defaults.assumptions = _neg_domain_in_full_domain_sans_zero.all_conditions()
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/d6451ebca630c456e1c1f2777c5439c1c43bd4fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [*defaults.assumptions, InSet(l, _neg_domain)]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/4ce27e8eebdd9b176221f90a28c6a7b3c38cf4170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
_two_pow_t_minus_one_is_nat_pos
# Out:
# |- 2^{t - 1} in NaturalPos

# %%
ineq_01 = Less(zero, e).prove()
# Out:
# <strong id="ineq_01">ineq_01:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/61c5d9c05b540d230aad7039163e9581ee63a98d0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/3e73446bb253ac38e99d42495913879d1f811f160/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
ineq_01.derive_shifted(one)
# Out:
# {e in {1 .. 2^{t - 1} - 2}} |- 1 < (e + 1)

# %%
# Some way to automate related info? 
negated_positive_is_negative
# Out:
# |- forall_{a in Real | a > 0} ((-a) < 0)

# %%
neg_domain_upper_bound_ineq = negated_positive_is_negative.instantiate({a: Add(e, one)})
# Out:
# <strong id="neg_domain_upper_bound_ineq">neg_domain_upper_bound_ineq:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e5f8fae80d0c15a1e3af708f726b9705a021c1de0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/9ad86cc33fff57a6a0b7384262b2268fdb1881d40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__neg_domain_in_full_domain_sans_zero/9b2823e7ad3fa724bbc053641a81f0371a94276b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# not currently the default … consider?
Less(l, zero).conclude_via_transitivity()
# Out:
# {e in {1 .. 2^{t - 1} - 2}, l in {-2^{t - 1} + 1 .. -(e + 1)}} |- l < 0

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._neg_domain_in_full_domain_sans_zero has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{e in {1 .. 2^{t - 1} - 2}} ({-2^{t - 1} + 1 .. -(e + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 1	instantiation	2, 3	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} subset_eq ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : {-2^{t - 1} + 1 .. 2^{t - 1}} - {0}, x : _a
# 2	theorem		|- forall_{A, B | forall_{x in A} (x in B)} (A subset_eq B)
# 	proveit.logic.sets.inclusion.fold_subset_eq
# 3	generalization	4	{e in {1 .. 2^{t - 1} - 2}} |- forall_{_a in {-2^{t - 1} + 1 .. -(e + 1)}} (_a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0}))
# 4	instantiation	5, 6, 7	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in ({-2^{t - 1} + 1 .. 2^{t - 1}} - {0})
# 	S : {-2^{t - 1} + 1 .. 2^{t - 1}}, y : 0, x : _a
# 5	conjecture		|- forall_{S, y} [forall_{x in S | x != y} (x in (S - {y}))]
# 	proveit.logic.sets.subtraction.all_but_one_membership_folding
# 6	instantiation	8, 30, 56, 20, 9	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in {-2^{t - 1} + 1 .. 2^{t - 1}}
# 	a : -2^{t - 1} + 1, b : 2^{t - 1}, n : _a
# 7	instantiation	10, 11	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a != 0
# 	a : _a
# 8	conjecture		|- forall_{a, b, n in Integer | a <= n <= b} (n in {a .. b})
# 	proveit.numbers.number_sets.integers.in_interval
# 9	instantiation	12, 13, 14	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- ((-2^{t - 1} + 1) <= _a) and (_a <= 2^{t - 1})
# 	A : (-2^{t - 1} + 1) <= _a, B : _a <= 2^{t - 1}
# 10	conjecture		|- forall_{a in IntegerNonZero} (a != 0)
# 	proveit.numbers.number_sets.integers.nonzero_if_in_nonzero_int
# 11	instantiation	62, 15, 16	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in IntegerNonZero
# 	A : IntegerNeg, B : IntegerNonZero, x : _a
# 12	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 13	instantiation	50, 30, 31, 32	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- (-2^{t - 1} + 1) <= _a
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : _a
# 14	instantiation	17, 18	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a <= 2^{t - 1}
# 	x : _a, y : 2^{t - 1}
# 15	conjecture		|- IntegerNeg proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.neg_int_within_nonzero_int
# 16	instantiation	19, 20, 22	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in IntegerNeg
# 	a : _a
# 17	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 18	instantiation	21, 22, 23	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a < 2^{t - 1}
# 	x : _a, y : 0, z : 2^{t - 1}
# 19	conjecture		|- forall_{a in Integer | a < 0} (a in IntegerNeg)
# 	proveit.numbers.number_sets.integers.neg_int_is_int_neg
# 20	instantiation	62, 24, 32	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in Integer
# 	A : {-2^{t - 1} + 1 .. -(e + 1)}, B : Integer, x : _a
# 21	axiom		|- forall_{x, y, z | x < y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less
# 22	instantiation	25, 26, 27	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a < 0
# 	x : _a, y : -(e + 1), z : 0
# 23	instantiation	28, 59	|- 2^{t - 1} > 0
# 	n : 2^{t - 1}
# 24	instantiation	49, 30, 31	{e in {1 .. 2^{t - 1} - 2}} |- {-2^{t - 1} + 1 .. -(e + 1)} proper_subset Integer
# 	a : -2^{t - 1} + 1, b : -(e + 1)
# 25	conjecture		|- forall_{x, y, z | x <= y, y < z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_eq_less
# 26	instantiation	29, 30, 31, 32	{e in {1 .. 2^{t - 1} - 2}, _a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a <= (-(e + 1))
# 	a : -2^{t - 1} + 1, b : -(e + 1), n : _a
# 27	instantiation	33, 34	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) < 0
# 	a : -(e + 1)
# 28	conjecture		|- forall_{n in NaturalPos} (n > 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_is_pos
# 29	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (n <= b)]
# 	proveit.numbers.number_sets.integers.interval_upper_bound
# 30	instantiation	55, 35, 51	|- (-2^{t - 1} + 1) in Integer
# 	a : -2^{t - 1}, b : 1
# 31	instantiation	60, 36	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in Integer
# 	a : e + 1
# 32	assumption		{_a in {-2^{t - 1} + 1 .. -(e + 1)}} |- _a in {-2^{t - 1} + 1 .. -(e + 1)}
# 33	conjecture		|- forall_{a in IntegerNeg} (a < 0)
# 	proveit.numbers.number_sets.integers.negative_if_in_neg_int
# 34	instantiation	37, 38	{e in {1 .. 2^{t - 1} - 2}} |- (-(e + 1)) in IntegerNeg
# 	a : e + 1
# 35	instantiation	60, 56	|- (-2^{t - 1}) in Integer
# 	a : 2^{t - 1}
# 36	instantiation	55, 43, 51	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in Integer
# 	a : e, b : 1
# 37	conjecture		|- forall_{a in NaturalPos} ((-a) in IntegerNeg)
# 	proveit.numbers.negation.int_neg_closure
# 38	instantiation	39, 40, 41	{e in {1 .. 2^{t - 1} - 2}} |- (e + 1) in NaturalPos
# 	a : e, b : 1
# 39	conjecture		|- forall_{a, b in NaturalPos} ((a + b) in NaturalPos)
# 	proveit.numbers.addition.add_nat_pos_closure_bin
# 40	instantiation	42, 43, 44	{e in {1 .. 2^{t - 1} - 2}} |- e in NaturalPos
# 	a : e
# 41	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 42	conjecture		|- forall_{a in Integer | a > 0} (a in NaturalPos)
# 	proveit.numbers.number_sets.integers.pos_int_is_natural_pos
# 43	instantiation	62, 45, 53	{e in {1 .. 2^{t - 1} - 2}} |- e in Integer
# 	A : {1 .. 2^{t - 1} - 2}, B : Integer, x : e
# 44	instantiation	46, 47, 48	{e in {1 .. 2^{t - 1} - 2}} |- 0 < e
# 	x : 0, y : 1, z : e
# 45	instantiation	49, 51, 52	|- {1 .. 2^{t - 1} - 2} proper_subset Integer
# 	a : 1, b : 2^{t - 1} - 2
# 46	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 47	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 48	instantiation	50, 51, 52, 53	{e in {1 .. 2^{t - 1} - 2}} |- 1 <= e
# 	a : 1, b : 2^{t - 1} - 2, n : e
# 49	conjecture		|- forall_{a, b in Integer} ({a .. b} proper_subset Integer)
# 	proveit.numbers.number_sets.integers.int_interval_within_int
# 50	conjecture		|- forall_{a, b in Integer} [forall_{n in {a .. b}} (a <= n)]
# 	proveit.numbers.number_sets.integers.interval_lower_bound
# 51	instantiation	62, 63, 54	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 52	instantiation	55, 56, 57	|- (2^{t - 1} - 2) in Integer
# 	a : 2^{t - 1}, b : -2
# 53	assumption		{e in {1 .. 2^{t - 1} - 2}} |- e in {1 .. 2^{t - 1} - 2}
# 54	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 55	conjecture		|- forall_{a, b in Integer} ((a + b) in Integer)
# 	proveit.numbers.addition.add_int_closure_bin
# 56	instantiation	62, 58, 59	|- 2^{t - 1} in Integer
# 	A : NaturalPos, B : Integer, x : 2^{t - 1}
# 57	instantiation	60, 61	|- (-2) in Integer
# 	a : 2
# 58	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 59	conjecture		|- 2^{t - 1} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_minus_one_is_nat_pos
# 60	conjecture		|- forall_{a in Integer} ((-a) in Integer)
# 	proveit.numbers.negation.int_closure
# 61	instantiation	62, 63, 64	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 62	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 63	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 64	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
