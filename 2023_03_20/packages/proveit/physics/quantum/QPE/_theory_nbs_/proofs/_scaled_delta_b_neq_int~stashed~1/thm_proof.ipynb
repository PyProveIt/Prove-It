# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">QPE</a>.<a class="ProveItLink" href="../../theorems.ipynb#_scaled_delta_b_neq_int">_scaled_delta_b_neq_int</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving _scaled_delta_b_neq_int
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="_scaled_delta_b_neq_int">_scaled_delta_b_neq_int:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d76f0a9cdb4230c71315163bd0847733b543be6b0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/fb64d6e2e1a3b08a58ea124025e2c7619716511f0/dependencies.ipynb">dependencies</a>)<br>

# %%
from proveit import defaults
defaults.assumptions = _scaled_delta_b_neq_int.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2d56bb4a5b2ccff919b46a0ece007ee2a70468330/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the individual assumptions
ell_in_integers = defaults.assumptions[1]
# Out:
# <strong id="ell_in_integers">ell_in_integers:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the individual assumptions
delta_b_not_zero = defaults.assumptions[2]
# Out:
# <strong id="delta_b_not_zero">delta_b_not_zero:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/81a29f792df44424868eba54f0f5a42007089ab90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# for convenience, name the scaled delta expression
_scaled_delta = _scaled_delta_b_neq_int.instance_expr.lhs
# Out:
# <strong id="_scaled_delta">_scaled_delta:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/70022aaf188bb04f6bba5ff51566ec6109260fab0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
from proveit.physics.quantum.QPE import _scaled_delta_b_is_zero_or_non_int
_scaled_delta_b_is_zero_or_non_int
# Out:
# |- forall_{b in {b_{f}, b_{r}}} (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))

# %%
_scaled_delta_b_is_zero_or_non_int_inst = (
        _scaled_delta_b_is_zero_or_non_int.instantiate())
# Out:
# <strong id="_scaled_delta_b_is_zero_or_non_int_inst">_scaled_delta_b_is_zero_or_non_int_inst:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/08ffaf7139b40197219d0d57a58c1216a59566150/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/a24f8a7da68096e7531ccb0c281edeeafa16da490/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.physics.quantum.QPE import _two_pow_t_is_nat_pos
_two_pow_t_is_nat_pos
# Out:
# |- 2^{t} in NaturalPos

# %%
from proveit.physics.quantum.QPE import _best_floor_is_int
_best_floor_is_int
# Out:
# |- b_{f} in Integer

# %%
from proveit.physics.quantum.QPE import _best_round_is_int
_best_round_is_int
# Out:
# |- b_{r} in Integer

# %%
from proveit.physics.quantum.QPE import _delta_b_is_real
_delta_b_is_real
# Out:
# |- forall_{b in Integer} (delta_{b} in Real)

# %%
from proveit import b
from proveit.physics.quantum.QPE import _b_floor
_delta_b_is_real.instantiate({b: _b_floor})
# Out:
# |- delta_{b_{f}} in Real

# %%
from proveit.physics.quantum.QPE import _b_round
_delta_b_is_real.instantiate({b: _b_round})
# Out:
# |- delta_{b_{r}} in Real

# %%
from proveit.logic import Forall, InSet, Set
from proveit.numbers import Real
from proveit.physics.quantum.QPE import _delta_b
all_delta_b_are_real = Forall(b,
       InSet(_delta_b, Real),
       domain=Set(_b_floor, _b_round)).prove()
# Out:
# <strong id="all_delta_b_are_real">all_delta_b_are_real:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/6b69ced4787b7b6fa3a8affb7933c940c9e528140/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/e5033f26cf4327e66b2618f27bcc5d0180bdcedf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.logic import NotEquals
from proveit.numbers import zero
NotEquals(_scaled_delta, zero).prove()
# Out:
# {b in {b_{f}, b_{r}}, delta_{b} != 0} |- (2^{t} * delta_{b}) != 0

# %%
scaled_delta_not_in_integers = (
    _scaled_delta_b_is_zero_or_non_int_inst.derive_right_if_not_left())
# Out:
# <strong id="scaled_delta_not_in_integers">scaled_delta_not_in_integers:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/81a29f792df44424868eba54f0f5a42007089ab90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/df26ede8d28da88f3e127f46e6ccdd4a651fa5780/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/f9ef256228ee6fc6a33bb48a5c6af55190aea4b20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
# Assume to the contrary that _scaled_delta_b = ell
from proveit import l
from proveit.logic import Equals
contradictory_assumption = Equals(_scaled_delta, l)
# Out:
# <strong id="contradictory_assumption">contradictory_assumption:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
contradictory_conclusion = (
    scaled_delta_not_in_integers.inner_expr().element.
    substitute(contradictory_assumption.rhs,
    assumptions=[*defaults.assumptions, contradictory_assumption]).unfold())
# Out:
# <strong id="contradictory_conclusion">contradictory_conclusion:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/81a29f792df44424868eba54f0f5a42007089ab90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/5ee6827aa050ab0a2912cb59c02819e512ee27720/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/1ed7128b5b1c3d21b54d51cbb6eaa9b444e359cc0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
from proveit.logic import And
contradictory_and = And(contradictory_conclusion, ell_in_integers).prove(
assumptions=[*defaults.assumptions, contradictory_assumption])
# Out:
# <strong id="contradictory_and">contradictory_and:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/81a29f792df44424868eba54f0f5a42007089ab90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/ffcb6be873ed20d388ab2628b7fc9b38aef074690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/e407f12f40a10f61204aaabf5884d7b1322066d80/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/09df9edcfbf0bb55500c5e7032cd5c8332a0824c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradictory_and_as_imp = contradictory_and.as_implication(contradictory_assumption)
# Out:
# <strong id="contradictory_and_as_imp">contradictory_and_as_imp:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/e81ca03d6396cbbd2846fe29fcb4dc2b9ebeaf2e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/81a29f792df44424868eba54f0f5a42007089ab90/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/7b8e14bfeec30fa2c83deb2740813fd8ea169a4c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/e53eb36afa97f93ce4513db5780db8d889fb805e0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof__scaled_delta_b_neq_int/e4ca5a55d5975434e474ef25b6fc742fbfd156500/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradictory_and_as_imp.deny_antecedent()
# Out:
# {b in {b_{f}, b_{r}}, delta_{b} != 0, l in Integer} |- [not]((2^{t} * delta_{b}) = l)
# _scaled_delta_b_neq_int may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.physics.quantum.QPE._scaled_delta_b_neq_int has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{b in {b_{f}, b_{r}}, l in Integer | delta_{b} != 0} ((2^{t} * delta_{b}) != l)
# 1	instantiation	2, 3	{b in {b_{f}, b_{r}}, delta_{b} != 0, l in Integer} |- (2^{t} * delta_{b}) != l
# 	x : 2^{t} * delta_{b}, y : l
# 2	theorem		|- forall_{x, y | [not](x = y)} (x != y)
# 	proveit.logic.equality.fold_not_equals
# 3	instantiation	4, 5, 6, 7	{b in {b_{f}, b_{r}}, delta_{b} != 0, l in Integer} |- [not]((2^{t} * delta_{b}) = l)
# 	A : (2^{t} * delta_{b}) = l, B : [not](l in Integer) and (l in Integer)
# 4	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 5	instantiation	8	|- ((2^{t} * delta_{b}) = l) in BOOLEAN
# 	x : 2^{t} * delta_{b}, y : l
# 6	deduction	9	{b in {b_{f}, b_{r}}, delta_{b} != 0, l in Integer} |- ((2^{t} * delta_{b}) = l) => ([not](l in Integer) and (l in Integer))
# 7	instantiation	10, 11, 15	{l in Integer} |- [not]([not](l in Integer) and (l in Integer))
# 	A : [not](l in Integer), B : l in Integer
# 8	axiom		|- forall_{x, y} ((x = y) in BOOLEAN)
# 	proveit.logic.equality.equality_in_bool
# 9	instantiation	12, 13, 15	{b in {b_{f}, b_{r}}, delta_{b} != 0, (2^{t} * delta_{b}) = l, l in Integer} |- [not](l in Integer) and (l in Integer)
# 	A : [not](l in Integer), B : l in Integer
# 10	theorem		|- forall_{A, B | [not](A), B} [not](A and B)
# 	proveit.logic.booleans.conjunction.nand_if_right_but_not_left
# 11	instantiation	14, 15	{l in Integer} |- [not]([not](l in Integer))
# 	A : l in Integer
# 12	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 13	instantiation	16, 17	{b in {b_{f}, b_{r}}, delta_{b} != 0, (2^{t} * delta_{b}) = l} |- [not](l in Integer)
# 	x : l, S : Integer
# 14	theorem		|- forall_{A | A} [not]([not](A))
# 	proveit.logic.booleans.negation.double_negation_intro
# 15	assumption		{l in Integer} |- l in Integer
# 16	theorem		|- forall_{x, S | x not-in S} [not](x in S)
# 	proveit.logic.sets.membership.unfold_not_in_set
# 17	instantiation	18, 19, 20	{b in {b_{f}, b_{r}}, delta_{b} != 0, (2^{t} * delta_{b}) = l} |- l not-in Integer
# 	P(_a) : _a not-in Integer, x : 2^{t} * delta_{b}, y : l
# 18	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 19	instantiation	21, 22, 23, 31, 24	{b in {b_{f}, b_{r}}, delta_{b} != 0} |- (2^{t} * delta_{b}) not-in Integer
# 	A : (2^{t} * delta_{b}) = 0, B : (2^{t} * delta_{b}) not-in Integer
# 20	assumption		{(2^{t} * delta_{b}) = l} |- (2^{t} * delta_{b}) = l
# 21	theorem		|- forall_{A, B in BOOLEAN | A or B, [not](A)} B
# 	proveit.logic.booleans.disjunction.right_if_not_left
# 22	instantiation	25, 27	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) in BOOLEAN
# 	A : (2^{t} * delta_{b}) = 0, B : (2^{t} * delta_{b}) not-in Integer
# 23	instantiation	26, 27	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) not-in Integer) in BOOLEAN
# 	A : (2^{t} * delta_{b}) = 0, B : (2^{t} * delta_{b}) not-in Integer
# 24	instantiation	28, 29	{b in {b_{f}, b_{r}}, delta_{b} != 0} |- [not]((2^{t} * delta_{b}) = 0)
# 	x : 2^{t} * delta_{b}, y : 0
# 25	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 26	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 27	instantiation	30, 31	{b in {b_{f}, b_{r}}} |- (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)) in BOOLEAN
# 	A : ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 28	theorem		|- forall_{x, y | x != y} [not](x = y)
# 	proveit.logic.equality.unfold_not_equals
# 29	instantiation	32, 54, 33, 34, 35	{b in {b_{f}, b_{r}}, delta_{b} != 0} |- (2^{t} * delta_{b}) != 0
# 	n : 2, a : (2^{t}, delta_{b})
# 30	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 31	instantiation	36, 49	{b in {b_{f}, b_{r}}} |- ((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer)
# 	b : b
# 32	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n} in ComplexNonZero} ((a_{1} *  a_{2} *  ... *  a_{n}) != 0)]
# 	proveit.numbers.multiplication.mult_not_eq_zero
# 33	instantiation	58	|- |(2^{t}, delta_{b})| = |(1, ..., 2)|
# 	a : 2^{t}, b : delta_{b}
# 34	instantiation	50, 37, 38	|- 2^{t} in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 2^{t}
# 35	instantiation	39, 40, 41	{b in {b_{f}, b_{r}}, delta_{b} != 0} |- delta_{b} in ComplexNonZero
# 	x : delta_{b}
# 36	conjecture		|- forall_{b in {b_{f}, b_{r}}} (((2^{t} * delta_{b}) = 0) or ((2^{t} * delta_{b}) not-in Integer))
# 	proveit.physics.quantum.QPE._scaled_delta_b_is_zero_or_non_int
# 37	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 38	instantiation	50, 42, 43	|- 2^{t} in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 2^{t}
# 39	conjecture		|- forall_{x in Complex | x != 0} (x in ComplexNonZero)
# 	proveit.numbers.number_sets.complex_numbers.nonzero_complex_is_complex_nonzero
# 40	instantiation	50, 44, 45	{b in {b_{f}, b_{r}}} |- delta_{b} in Complex
# 	A : Real, B : Complex, x : delta_{b}
# 41	assumption		{delta_{b} != 0} |- delta_{b} != 0
# 42	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 43	instantiation	50, 46, 47	|- 2^{t} in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2^{t}
# 44	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 45	instantiation	48, 49	{b in {b_{f}, b_{r}}} |- delta_{b} in Real
# 	b : b
# 46	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 47	instantiation	50, 51, 52	|- 2^{t} in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2^{t}
# 48	instantiation	53, 54, 55, 56, 57	|- forall_{b in {b_{f}, b_{r}}} (delta_{b} in Real)
# 	n : 2, (a_{1}, ..., a_{2}) : (b_{f}, b_{r}), P(b) : delta_{b} in Real, x : b
# 49	assumption		{b in {b_{f}, b_{r}}} |- b in {b_{f}, b_{r}}
# 50	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 51	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 52	conjecture		|- 2^{t} in NaturalPos
# 	proveit.physics.quantum.QPE._two_pow_t_is_nat_pos
# 53	conjecture		|- forall_{n in Natural} [forall_{a_{1}, a_{2}, ..., a_{n}} [forall_{P | P(a_{1}), P(a_{2}), ..., P(a_{n})} [forall_{x in {a_{1}, a_{2}, ..., a_{n}}} P(x)]]]
# 	proveit.logic.sets.enumeration.true_for_each_then_true_for_all
# 54	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 55	instantiation	58	|- |(b_{f}, b_{r})| = |(1, ..., 2)|
# 	a : b_{f}, b : b_{r}
# 56	instantiation	60, 59	|- delta_{b_{f}} in Real
# 	b : b_{f}
# 57	instantiation	60, 61	|- delta_{b_{r}} in Real
# 	b : b_{r}
# 58	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 59	conjecture		|- b_{f} in Integer
# 	proveit.physics.quantum.QPE._best_floor_is_int
# 60	conjecture		|- forall_{b in Integer} (delta_{b} in Real)
# 	proveit.physics.quantum.QPE._delta_b_is_real
# 61	conjecture		|- b_{r} in Integer
# 	proveit.physics.quantum.QPE._best_round_is_int
