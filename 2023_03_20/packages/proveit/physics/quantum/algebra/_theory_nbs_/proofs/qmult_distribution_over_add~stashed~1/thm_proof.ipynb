# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#qmult_distribution_over_add">qmult_distribution_over_add</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving qmult_distribution_over_add
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="qmult_distribution_over_add">qmult_distribution_over_add:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/f354949265c084322e3436773224f718c4e7f08e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/8cc4a4ce4a8cfa51ad415c63a07037ff08a9e5020/dependencies.ipynb">dependencies</a>)<br>
