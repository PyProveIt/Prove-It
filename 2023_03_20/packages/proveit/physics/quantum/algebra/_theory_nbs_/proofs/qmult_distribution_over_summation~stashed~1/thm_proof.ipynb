# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">physics</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">quantum</a>.<a class="ProveItLink" href="../../theory.ipynb">algebra</a>.<a class="ProveItLink" href="../../theorems.ipynb#qmult_distribution_over_summation">qmult_distribution_over_summation</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving qmult_distribution_over_summation
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="qmult_distribution_over_summation">qmult_distribution_over_summation:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/b2aa2a5b66568d0d0ecbb82d908c2189ab36804a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/1c28998c6ec1c071458a4324be9c91d43601790e0/dependencies.ipynb">dependencies</a>)<br>
