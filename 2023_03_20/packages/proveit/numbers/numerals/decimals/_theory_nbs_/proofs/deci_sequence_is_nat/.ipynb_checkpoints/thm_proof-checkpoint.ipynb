# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numerals</a>.<a class="ProveItLink" href="../../theory.ipynb">decimals</a>.<a class="ProveItLink" href="../../theorems.ipynb#deci_sequence_is_nat">deci_sequence_is_nat</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory

# %%
# %proving deci_sequence_is_nat
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="deci_sequence_is_nat">deci_sequence_is_nat:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/c250efbba5167ebc263c9c6b19d12d998b380a950/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/5aa06da46723f581c683555c49d0c780940928170/dependencies.ipynb">dependencies</a>)<br>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-530fb2ddf5b6> in <module>
# ----> 1 get_ipython().run_line_magic('proving', 'deci_sequence_is_nat')
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2415                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416             with self.builtin_trap:
# -> 2417                 result = fn(*args, **kwargs)
#    2418             return result
#    2419
#
# <decorator-gen-179> in proving(self, line)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in proving(self, line)
#    1012         self.shell.user_ns[theorem_name] = begin_proof_result
#    1013         display_assignments([theorem_name], [begin_proof_result],
# -> 1014                             beginning_proof=True)
#    1015
#    1016     @line_magic
#
# /home/wwitzel/Prove-It/packages/proveit/magics.py in display_assignments(names, right_sides, beginning_proof)
#    1111     # is being proven is readily provable; if so, indicate that
#    1112     # '%qed' is all that is needed.
# -> 1113     Judgment._check_if_ready_for_qed()
#    1114
#    1115
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/judgment.py in _check_if_ready_for_qed()
#     641         theorem_being_proven = Judgment.theorem_being_proven
#     642         theorem_expr = Judgment.theorem_being_proven.proven_truth.expr
# --> 643         if theorem_expr.readily_provable():
#     644             if not Judgment.theorem_readily_provable:
#     645                 Judgment.theorem_readily_provable = True
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1044                 Expression.in_progress_to_check_provability.add(
#    1045                         in_progress_key)
# -> 1046                 return self._readily_provable()
#    1047             finally:
#    1048                 Expression.in_progress_to_check_provability.remove(
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable(self)
#      67         been proven with a more inclusive domain.
#      68         '''
# ---> 69         if self._readily_provable_via_generalization():
#      70             return True
#      71         return False
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable_via_generalization(self)
#      87         # Add the conditions as assumptions.
#      88         inner_assumptions += list(conditions.entries)
# ---> 89         return expr.readily_provable(assumptions=inner_assumptions)
#      90
#      91     @prover
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1044                 Expression.in_progress_to_check_provability.add(
#    1045                         in_progress_key)
# -> 1046                 return self._readily_provable()
#    1047             finally:
#    1048                 Expression.in_progress_to_check_provability.remove(
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable(self)
#      67         been proven with a more inclusive domain.
#      68         '''
# ---> 69         if self._readily_provable_via_generalization():
#      70             return True
#      71         return False
#
# /home/wwitzel/Prove-It/packages/proveit/logic/booleans/quantification/universality/forall.py in _readily_provable_via_generalization(self)
#      87         # Add the conditions as assumptions.
#      88         inner_assumptions += list(conditions.entries)
# ---> 89         return expr.readily_provable(assumptions=inner_assumptions)
#      90
#      91     @prover
#
# /home/wwitzel/Prove-It/packages/proveit/_core_/expression/expr.py in readily_provable(self, assumptions)
#    1044                 Expression.in_progress_to_check_provability.add(
#    1045                         in_progress_key)
# -> 1046                 return self._readily_provable()
#    1047             finally:
#    1048                 Expression.in_progress_to_check_provability.remove(
#
# /home/wwitzel/Prove-It/packages/proveit/logic/sets/membership/in_set.py in _readily_provable(self)
#      40         domain a subset of the desired domain).
#      41         '''
# ---> 42         if InClass._readily_provable(self):
#      43             return True
#      44         if self.stronger_known_membership() is not None:
#
# /home/wwitzel/Prove-It/packages/proveit/logic/classes/membership/in_class.py in _readily_provable(self)
#     148         '''
#     149         if hasattr(self, 'membership_object'):
# --> 150             if self.membership_object._readily_provable():
#     151                 return True
#     152         return False
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/natural_numbers/natural_membership.py in _readily_provable(self)
#      20             nonneg_int_is_natural)
#      21         if not nonneg_int_is_natural.is_usable(): return False
# ---> 22         return NumberMembership._readily_provable(self)
#      23
#      24     @prover
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_sets/number_set.py in _readily_provable(self)
#     172         from proveit.numbers import readily_provable_number_set
#     173         provable_number_set = readily_provable_number_set(
# --> 174                 self.element, must_be_direct=True)
#     175         if provable_number_set is None: return False
#     176         return self.number_set.includes(provable_number_set)
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/number_operation.py in readily_provable_number_set(expr, automation, assumptions, must_be_direct, default, _compare_to_zero)
#     415             # Use 'readily_provable_number_set' method.
#     416             try:
# --> 417                 number_set = expr.readily_provable_number_set()
#     418             except (UnsatisfiedPrerequisites, ProofFailure):
#     419                 number_set = None
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/numerals/decimals/deci.py in readily_provable_number_set(self)
#     113         from proveit.numbers import Natural, NaturalPos, greater
#     114         _a = self.digits[0]
# --> 115         if greater(_a, zero).readily_provable():
#     116             return NaturalPos
#     117         else:
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/less.py in greater(a, b)
#     546     as b < a but with a style that reverses the direction.
#     547     '''
# --> 548     return Less(b, a).with_styles(direction='reversed')
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/less.py in __init__(self, lhs, rhs, styles)
#      27         '''
#      28         NumberOrderingRelation.__init__(self, Less._operator_, lhs, rhs,
# ---> 29                                         styles=styles)
#      30
#      31     def _record_as_proven(self, judgment):
#
# /home/wwitzel/Prove-It/packages/proveit/numbers/ordering/number_ordering_relation.py in __init__(self, operator, lhs, rhs, styles)
#       7     def __init__(self, operator, lhs, rhs, *, styles):
#       8         TransitiveRelation.__init__(self, operator, lhs, rhs,
# ----> 9                                     styles=styles)
#      10         # The lower bound side of this inequality.
#      11         # (regardless of the 'direction' style).
#
# /home/wwitzel/Prove-It/packages/proveit/relation/transitivity.py in __init__(self, operator, normal_lhs, normal_rhs, styles)
#      36
#      37     def __init__(self, operator, normal_lhs, normal_rhs, *, styles):
# ---> 38         Relation.__init__(self,operator, normal_lhs, normal_rhs, styles=styles)
#      39
#      40     def _record_as_proven(self, judgment):
#
# /home/wwitzel/Prove-It/packages/proveit/relation/relation.py in __init__(self, operator, normal_lhs, normal_rhs, styles)
#      20         Operation.__init__(self, operator, (normal_lhs, normal_rhs),
#      21                            styles=styles)
# ---> 22         assert self.operands.is_double(), "%s is not double"%self.operands
#      23         # lhs and rhs with the "direction" style of "normal"
#      24         # (not subject to reversal)
#
# AssertionError: (0,a_{1}, a_{2}, ..., a_{n}) is not double
