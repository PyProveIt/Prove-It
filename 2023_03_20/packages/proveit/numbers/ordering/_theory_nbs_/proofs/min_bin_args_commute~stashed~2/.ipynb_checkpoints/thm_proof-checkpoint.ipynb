# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">ordering</a>.<a class="ProveItLink" href="../../theorems.ipynb#min_bin_args_commute">min_bin_args_commute</a> theorem
# ========

# %%
import proveit
theory = proveit.Theory() # the theorem's theory
from proveit import x, y, defaults
from proveit.logic import Not
from proveit.numbers import greater_eq
from proveit.numbers.ordering import (
        less_eq_def, less_or_greater_eq, min_def_bin)

# %%
# %proving min_bin_args_commute
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="min_bin_args_commute">min_bin_args_commute:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/0e065a433b4f3aeea2ac6362a49e7e9bee60244f0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/d33ba64ef4195c3713fe4fe965786f0d7b7cb9b70/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = min_bin_args_commute.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/d1ad07990e7eda932aeddb9254501f6273d630bd0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
min_def_bin
# Out:
# |- forall_{x, y in Real} (Min(x, y) = {x if x <= y; y if y < x.)

# %%
min_x_y_def = min_def_bin.instantiate({x: x, y: y})
# Out:
# <strong id="min_x_y_def">min_x_y_def:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/7eb46ba8a830a000078a95a55ac0adc59b7d32340/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/axioms/36daeecaccc8dacd65d11677a01e22287379ff910/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
min_y_x_def = min_def_bin.instantiate({x: y, y: x})
# Out:
# <strong id="min_y_x_def">min_y_x_def:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/16a4e75bb6e1c85507aad4c9b2137944794e4e820/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/7e122bf7da4aeb697fe820d8bc3616c5bca420430/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
less_or_greater_eq
# Out:
# |- forall_{x, y in Real} ((x < y) or (x >= y))

# %%
relation_choices = less_or_greater_eq.instantiate({x: x, y: y})
# Out:
# <strong id="relation_choices">relation_choices:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/552bdcd56f22af3ebd0a2ec721a4ad24070a5fb00/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/theorems/54335d8dfd35039941eb12e174e0565e436e21170/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Case 1: $x < y$

# %%
case_1_assumptions = defaults.assumptions+(relation_choices.operands[0],)
# Out:
# <strong id="case_1_assumptions">case_1_assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/546f83cd7886df4e948ff2fd260fe32f4cc158620/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
min_x_y_def.inner_expr().rhs.simplify(assumptions=case_1_assumptions)
# Out:
# {x in Real, y in Real, x < y} |- Min(x, y) = x

# %%
min_y_x_def.inner_expr().rhs.simplify(assumptions=case_1_assumptions)
# Out:
# {y in Real, x in Real, x < y} |- Min(y, x) = x

# %% [markdown]
# #### Case 2: $x \ge y$

# %%
case_2_assumptions = defaults.assumptions+(relation_choices.operands[1],)
# Out:
# <strong id="case_2_assumptions">case_2_assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/d4c4f8c0017f831760eb7cb099b2bf1f7dca49b20/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# For Case 2, we can quickly get the desired output for Min(y, x):

# %%
case_2_non_implication = min_y_x_def.inner_expr().rhs.simplify(assumptions=case_2_assumptions)
# Out:
# <strong id="case_2_non_implication">case_2_non_implication:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/2a516f0944259c69b1ee6ea6089cf0e6c33d73950/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/9e3a5322f091228fc3af0f19678447ed8d0ab9810/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/80d928ce1456c5e4d863c99316c65c051ec93b420/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Then for later we seem to need this in implication form:

# %%
from proveit.logic import Implies
Implies(greater_eq(x, y), case_2_non_implication).prove()
# Out:
# {y in Real, x in Real} |- (x >= y) => (Min(y, x) = y)

# %% [markdown]
# For Min(x, y), Case 2 needs to be broken up into two pieces.

# %%
less_eq_def
# Out:
# |- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))

# %%
y_le_x_as_disjunction = less_eq_def.instantiate({x: y, y: x})
# Out:
# <strong id="y_le_x_as_disjunction">y_le_x_as_disjunction:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/00d99ac7def6a7f7e7bcfc37f08eac73991c04240/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/404584cb1889bf6903a64a892e8b517a77046e5d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
y_le_x_as_disjunction.derive_right_via_equality(assumptions=case_2_assumptions)
# Out:
# {x >= y} |- (y < x) or (y = x)

# %%
case_2_a_assumptions = defaults.assumptions + (y_le_x_as_disjunction.rhs.operands[0],)
# Out:
# <strong id="case_2_a_assumptions">case_2_a_assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/0225ba9517f2c7e56653ccd19e58082141c80d630/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
min_x_y_def.inner_expr().rhs.simplify(assumptions=case_2_a_assumptions)
# Out:
# {x in Real, y in Real, y < x} |- Min(x, y) = y

# %%
case_2_b_assumptions = defaults.assumptions + (y_le_x_as_disjunction.rhs.operands[1],)
# Out:
# <strong id="case_2_b_assumptions">case_2_b_assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/72e1eb29bc84e2b8a99703e4c72a7c860032575a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
# Need this piece explicitly ---
# y >= x is not derived as an automatic side-effect from y = x
greater_eq(y, x).prove(assumptions=case_2_b_assumptions)
# Out:
# {x in Real, y in Real, y = x} |- y >= x

# %%
min_x_y_when_y_eq_x = min_x_y_def.inner_expr().rhs.simplify(assumptions=case_2_b_assumptions)
# Out:
# <strong id="min_x_y_when_y_eq_x">min_x_y_when_y_eq_x:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../logic/equality/__pv_it/theorems/acfe5674bf1a89e3505c0b734f02fc003ed025860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/4c451b685c5fcaa0f2a8c1ea5f3a4569b9ea05d40/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/e4cd168f1315c22791d06761f7bbf7f819e63e750/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
case_2_b_non_implication = min_x_y_when_y_eq_x.inner_expr().rhs.substitute(y,
        assumptions=case_2_b_assumptions, auto_simplify=False)
# Out:
# <strong id="case_2_b_non_implication">case_2_b_non_implication:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/theorems/d1323f34847310a404e8089c2c268d3c2eb89dbf0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/theorems/5d76fdd975252a644e3e1cb067a357f9a9c8486a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../../../logic/equality/__pv_it/theorems/acfe5674bf1a89e3505c0b734f02fc003ed025860/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/485318822128b9f6a61d8bbbd92dddc5a16fe8d00/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_min_bin_args_commute/0e74b0338e000c3ba668fc066e71d969644af3c80/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# Recall the full Case (2) conditions, and combine the two sub-cases of Case (2) into a single conclusion:

# %%
y_le_x_as_disjunction
# Out:
# |- (y <= x) = ((y < x) or (y = x))

# %%
y_le_x_as_disjunction.rhs.derive_via_singular_dilemma(
        min_bin_args_commute.instance_expr,
        assumptions=defaults.assumptions+(y_le_x_as_disjunction.lhs,))
# Out:
# {y <= x, x in Real, y in Real} |- Min(x, y) = Min(y, x)

# %% [markdown]
# Now we're ready for combining Cases (1) and (2) using derive_via_singular_dilemma() and the default assumptions:

# %%
relation_choices.expr.derive_via_singular_dilemma(
    min_bin_args_commute.instance_expr)
# Out:
# {x in Real, y in Real} |- Min(x, y) = Min(y, x)
# min_bin_args_commute may now be readily provable (assuming required theorems are usable).  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.ordering.min_bin_args_commute has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{x, y in Real} (Min(x, y) = Min(y, x))
# 1	instantiation	11, 2, 3, 9, 4, 5	{x in Real, y in Real} |- Min(x, y) = Min(y, x)
# 	A : x < y, B : x >= y, C : Min(x, y) = Min(y, x)
# 2	instantiation	19, 6	{x in Real, y in Real} |- (x < y) in BOOLEAN
# 	A : x < y, B : x >= y
# 3	instantiation	20, 6	{x in Real, y in Real} |- (x >= y) in BOOLEAN
# 	A : x < y, B : x >= y
# 4	deduction	7	{y in Real, x in Real} |- (x < y) => (Min(x, y) = Min(y, x))
# 5	deduction	8	{x in Real, y in Real} |- (x >= y) => (Min(x, y) = Min(y, x))
# 6	instantiation	26, 9	{x in Real, y in Real} |- ((x < y) or (x >= y)) in BOOLEAN
# 	A : (x < y) or (x >= y)
# 7	instantiation	54, 10, 44	{y in Real, x in Real, x < y} |- Min(x, y) = Min(y, x)
# 	P(_a) : _a = Min(y, x), x : Min(x, y), y : {x if x <= y; y if y < x.
# 8	instantiation	11, 12, 13, 27, 14, 15	{y <= x, x in Real, y in Real} |- Min(x, y) = Min(y, x)
# 	A : y < x, B : y = x, C : Min(x, y) = Min(y, x)
# 9	instantiation	16, 95, 96	{x in Real, y in Real} |- (x < y) or (x >= y)
# 	x : x, y : y
# 10	instantiation	54, 17, 18	{y in Real, x in Real, x < y} |- {x if x <= y; y if y < x. = Min(y, x)
# 	P(_a) : _a = Min(y, x), x : {x if x <= y; y if y < x., y : x
# 11	theorem		|- forall_{A, B in BOOLEAN | A or B} [forall_{C | A => C, B => C} C]
# 	proveit.logic.booleans.disjunction.singular_constructive_dilemma
# 12	instantiation	19, 21	{x >= y} |- (y < x) in BOOLEAN
# 	A : y < x, B : y = x
# 13	instantiation	20, 21	{x >= y} |- (y = x) in BOOLEAN
# 	A : y < x, B : y = x
# 14	deduction	22	{x in Real, y in Real, y <= x} |- (y < x) => (Min(x, y) = Min(y, x))
# 15	deduction	23	{x in Real, y in Real, y <= x} |- (y = x) => (Min(x, y) = Min(y, x))
# 16	conjecture		|- forall_{x, y in Real} ((x < y) or (x >= y))
# 	proveit.numbers.ordering.less_or_greater_eq
# 17	instantiation	98, 24	{y in Real, x in Real, x < y} |- x = Min(y, x)
# 	x : Min(y, x), y : x
# 18	instantiation	71, 25, 64	{x < y, x in Real, y in Real} |- {x if x <= y; y if y < x. = x
# 	x : {x if x <= y; y if y < x., y : {x; y if FALSE., z : x
# 19	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (A in BOOLEAN)
# 	proveit.logic.booleans.disjunction.left_in_bool
# 20	axiom		|- forall_{A, B | (A or B) in BOOLEAN} (B in BOOLEAN)
# 	proveit.logic.booleans.disjunction.right_in_bool
# 21	instantiation	26, 27	{x >= y} |- ((y < x) or (y = x)) in BOOLEAN
# 	A : (y < x) or (y = x)
# 22	instantiation	54, 28, 30	{x in Real, y in Real, y < x, y <= x} |- Min(x, y) = Min(y, x)
# 	P(_a) : Min(x, y) = _a, x : Min(y, x), y : {y if y <= x; x if x < y.
# 23	instantiation	54, 29, 30	{y = x, x in Real, y in Real, y <= x} |- Min(x, y) = Min(y, x)
# 	P(_a) : Min(x, y) = _a, x : Min(y, x), y : {y if y <= x; x if x < y.
# 24	instantiation	43, 30, 31	{y in Real, x in Real, x < y} |- Min(y, x) = x
# 	P(_a) : Min(y, x) = _a, x : {y if y <= x; x if x < y., y : x
# 25	instantiation	71, 32, 33	{x < y, x in Real, y in Real} |- {x if x <= y; y if y < x. = {x; y if FALSE.
# 	x : {x if x <= y; y if y < x., y : {x; y if y < x., z : {x; y if FALSE.
# 26	conjecture		|- forall_{A | A} (A in BOOLEAN)
# 	proveit.logic.booleans.in_bool_if_true
# 27	instantiation	34, 91, 35	{x >= y} |- (y < x) or (y = x)
# 	P : y <= x, Q : (y < x) or (y = x)
# 28	instantiation	54, 36, 47	{x in Real, y in Real, y < x, y <= x} |- Min(x, y) = {y if y <= x; x if x < y.
# 	P(_a) : Min(x, y) = _a, x : {y if y <= x; x if x < y., y : y
# 29	instantiation	54, 37, 44	{y = x, x in Real, y in Real, y <= x} |- Min(x, y) = {y if y <= x; x if x < y.
# 	P(_a) : _a = {y if y <= x; x if x < y., x : Min(x, y), y : {x if x <= y; y if y < x.
# 30	instantiation	51, 96, 95	{y in Real, x in Real} |- Min(y, x) = {y if y <= x; x if x < y.
# 	x : y, y : x
# 31	instantiation	71, 38, 39	{x in Real, y in Real, x < y} |- {y if y <= x; x if x < y. = x
# 	x : {y if y <= x; x if x < y., y : {y if FALSE; x., z : x
# 32	instantiation	83, 40	{x < y} |- {x if x <= y; y if y < x. = {x; y if y < x.
# 	f(_a) : {_a; y if y < x., x : {x if x <= y., y : x
# 33	instantiation	83, 41	{x in Real, y in Real, x < y} |- {x; y if y < x. = {x; y if FALSE.
# 	f(_a) : {x; _a., x : {y if y < x., y : {y if FALSE.
# 34	theorem		|- forall_{P, Q | P, P = Q} Q
# 	proveit.logic.equality.rhs_via_equality
# 35	instantiation	42	|- (y <= x) = ((y < x) or (y = x))
# 	x : y, y : x
# 36	instantiation	43, 44, 45	{x in Real, y in Real, y < x} |- Min(x, y) = y
# 	P(_a) : Min(x, y) = _a, x : {x if x <= y; y if y < x., y : y
# 37	instantiation	54, 46, 47	{y = x, x in Real, y in Real, y <= x} |- {x if x <= y; y if y < x. = {y if y <= x; x if x < y.
# 	P(_a) : {x if x <= y; y if y < x. = _a, x : {y if y <= x; x if x < y., y : y
# 38	instantiation	71, 48, 49	{x in Real, y in Real, x < y} |- {y if y <= x; x if x < y. = {y if FALSE; x.
# 	x : {y if y <= x; x if x < y., y : {y if FALSE; x if x < y., z : {y if FALSE; x.
# 39	instantiation	74, 76, 75, 77	|- {y if FALSE; x. = x
# 	m : 1, n : 0, a : (y), b : x, c : ()
# 40	instantiation	88, 60	{x < y} |- {x if x <= y. = x
# 	a : x, Q : x <= y
# 41	instantiation	89, 50	{x in Real, y in Real, x < y} |- {y if y < x. = {y if FALSE.
# 	a : y, Q : y < x
# 42	axiom		|- forall_{x, y} ((x <= y) = ((x < y) or (x = y)))
# 	proveit.numbers.ordering.less_eq_def
# 43	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 44	instantiation	51, 95, 96	{x in Real, y in Real} |- Min(x, y) = {x if x <= y; y if y < x.
# 	x : x, y : y
# 45	instantiation	71, 52, 53	{y in Real, x in Real, y < x} |- {x if x <= y; y if y < x. = y
# 	x : {x if x <= y; y if y < x., y : {x if FALSE; y., z : y
# 46	instantiation	54, 97, 55	{y = x, x in Real, y in Real} |- {x if x <= y; y if y < x. = y
# 	P(_a) : _a = y, x : {x if x <= y; y if y < x., y : x
# 47	instantiation	71, 56, 57	{x >= y, y in Real, x in Real} |- {y if y <= x; x if x < y. = y
# 	x : {y if y <= x; x if x < y., y : {y; x if FALSE., z : y
# 48	instantiation	83, 58	{x in Real, y in Real, x < y} |- {y if y <= x; x if x < y. = {y if FALSE; x if x < y.
# 	f(_a) : {_a; x if x < y., x : {y if y <= x., y : {y if FALSE.
# 49	instantiation	83, 59	{x < y} |- {y if FALSE; x if x < y. = {y if FALSE; x.
# 	f(_a) : {y if FALSE; _a., x : {x if x < y., y : x
# 50	instantiation	92, 95, 96, 60	{x in Real, y in Real, x < y} |- [not](y < x)
# 	x : x, y : y
# 51	axiom		|- forall_{x, y in Real} (Min(x, y) = {x if x <= y; y if y < x.)
# 	proveit.numbers.ordering.min_def_bin
# 52	instantiation	71, 61, 62	{y in Real, x in Real, y < x} |- {x if x <= y; y if y < x. = {x if FALSE; y.
# 	x : {x if x <= y; y if y < x., y : {x if FALSE; y if y < x., z : {x if FALSE; y.
# 53	instantiation	74, 76, 75, 77	|- {x if FALSE; y. = y
# 	m : 1, n : 0, a : (x), b : y, c : ()
# 54	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 55	instantiation	71, 63, 64	{x in Real, y in Real, y = x} |- {x if x <= y; y if y < x. = x
# 	x : {x if x <= y; y if y < x., y : {x; y if FALSE., z : x
# 56	instantiation	71, 65, 66	{x >= y, y in Real, x in Real} |- {y if y <= x; x if x < y. = {y; x if FALSE.
# 	x : {y if y <= x; x if x < y., y : {y; x if x < y., z : {y; x if FALSE.
# 57	instantiation	74, 75, 76, 77	|- {y; x if FALSE. = y
# 	m : 0, n : 1, a : (), b : y, c : (x)
# 58	instantiation	89, 67	{x in Real, y in Real, x < y} |- {y if y <= x. = {y if FALSE.
# 	a : y, Q : y <= x
# 59	instantiation	88, 80	{x < y} |- {x if x < y. = x
# 	a : x, Q : x < y
# 60	instantiation	68, 80	{x < y} |- x <= y
# 	x : x, y : y
# 61	instantiation	83, 69	{y in Real, x in Real, y < x} |- {x if x <= y; y if y < x. = {x if FALSE; y if y < x.
# 	f(_a) : {_a; y if y < x., x : {x if x <= y., y : {x if FALSE.
# 62	instantiation	83, 70	{y < x} |- {x if FALSE; y if y < x. = {x if FALSE; y.
# 	f(_a) : {x if FALSE; _a., x : {y if y < x., y : y
# 63	instantiation	71, 72, 73	{x in Real, y in Real, y = x} |- {x if x <= y; y if y < x. = {x; y if FALSE.
# 	x : {x if x <= y; y if y < x., y : {x; y if y < x., z : {x; y if FALSE.
# 64	instantiation	74, 75, 76, 77	|- {x; y if FALSE. = x
# 	m : 0, n : 1, a : (), b : x, c : (y)
# 65	instantiation	83, 78	{x >= y} |- {y if y <= x; x if x < y. = {y; x if x < y.
# 	f(_a) : {_a; x if x < y., x : {y if y <= x., y : y
# 66	instantiation	83, 79	{y in Real, x in Real, x >= y} |- {y; x if x < y. = {y; x if FALSE.
# 	f(_a) : {y; _a., x : {x if x < y., y : {x if FALSE.
# 67	instantiation	86, 95, 96, 80	{x in Real, y in Real, x < y} |- [not](y <= x)
# 	x : x, y : y
# 68	conjecture		|- forall_{x, y | x < y} (x <= y)
# 	proveit.numbers.ordering.relax_less
# 69	instantiation	89, 81	{y in Real, x in Real, y < x} |- {x if x <= y. = {x if FALSE.
# 	a : x, Q : x <= y
# 70	instantiation	88, 87	{y < x} |- {y if y < x. = y
# 	a : y, Q : y < x
# 71	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 72	instantiation	83, 82	{x in Real, y in Real, y = x} |- {x if x <= y; y if y < x. = {x; y if y < x.
# 	f(_a) : {_a; y if y < x., x : {x if x <= y., y : x
# 73	instantiation	83, 84	{x in Real, y in Real, y = x} |- {x; y if y < x. = {x; y if FALSE.
# 	f(_a) : {x; _a., x : {y if y < x., y : {y if FALSE.
# 74	axiom		|- forall_{m, n in Natural} [forall_{a_{1}, a_{2}, ..., a_{m}, b, c_{1}, c_{2}, ..., c_{n}} ({{a_{1} if FALSE. ; {a_{2} if FALSE. ; ... ; {a_{m} if FALSE.; b;{c_{1} if FALSE. ; {c_{2} if FALSE. ; ... ; {c_{n} if FALSE.. = b)]
# 	proveit.core_expr_types.conditionals.true_case_reduction
# 75	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 76	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 77	conjecture		|- |()| = |(1, 2, ..., 0)|
# 	proveit.core_expr_types.tuples.tuple_len_0_typical_eq
# 78	instantiation	88, 91	{x >= y} |- {y if y <= x. = y
# 	a : y, Q : y <= x
# 79	instantiation	89, 85	{y in Real, x in Real, x >= y} |- {x if x < y. = {x if FALSE.
# 	a : x, Q : x < y
# 80	assumption		{x < y} |- x < y
# 81	instantiation	86, 96, 95, 87	{y in Real, x in Real, y < x} |- [not](x <= y)
# 	x : y, y : x
# 82	instantiation	88, 93	{x in Real, y in Real, y = x} |- {x if x <= y. = x
# 	a : x, Q : x <= y
# 83	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 84	instantiation	89, 90	{x in Real, y in Real, y = x} |- {y if y < x. = {y if FALSE.
# 	a : y, Q : y < x
# 85	instantiation	92, 96, 95, 91	{y in Real, x in Real, y <= x} |- [not](x < y)
# 	x : y, y : x
# 86	conjecture		|- forall_{x, y in Real | x < y} [not](y <= x)
# 	proveit.numbers.ordering.not_less_eq_from_less
# 87	assumption		{y < x} |- y < x
# 88	conjecture		|- forall_{a, Q | Q} ({a if Q. = a)
# 	proveit.core_expr_types.conditionals.satisfied_condition_reduction
# 89	conjecture		|- forall_{a, Q | [not](Q)} ({a if Q. = {a if FALSE.)
# 	proveit.core_expr_types.conditionals.dissatisfied_condition_reduction
# 90	instantiation	92, 95, 96, 93	{x in Real, y in Real, y = x} |- [not](y < x)
# 	x : x, y : y
# 91	assumption		{y <= x} |- y <= x
# 92	conjecture		|- forall_{x, y in Real | x <= y} [not](y < x)
# 	proveit.numbers.ordering.not_less_from_less_eq
# 93	instantiation	94, 95, 96, 97	{x in Real, y in Real, y = x} |- x <= y
# 	x : x, y : y
# 94	conjecture		|- forall_{x, y in Real | x = y} (x <= y)
# 	proveit.numbers.ordering.relax_equal_to_less_eq
# 95	assumption		{x in Real} |- x in Real
# 96	assumption		{y in Real} |- y in Real
# 97	instantiation	98, 99	{y = x} |- x = y
# 	x : y, y : x
# 98	theorem		|- forall_{x, y | x = y} (y = x)
# 	proveit.logic.equality.equals_reversal
# 99	assumption		{y = x} |- y = x
