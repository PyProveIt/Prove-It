# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../theory.ipynb">exponentiation</a>.<a class="ProveItLink" href="../../theorems.ipynb#sqrt2_is_not_rational">sqrt2_is_not_rational</a> theorem
# ========

# %%
import proveit
from proveit import defaults, Variable
from proveit import p, a_star, b_star
from proveit.logic import InSet, Equals
from proveit.numbers import (zero, two, NaturalPos, 
                             Rational, RationalNonZero, RationalPos, 
                             Abs, greater, Mult, frac, Divides, GCD, Exp, sqrt)

# %%
# %proving sqrt2_is_not_rational
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="sqrt2_is_not_rational">sqrt2_is_not_rational:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/1906439152290d28564920e9493e1c539bac4ba40/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/e94751def7d13f9efa254c4f90001431f82253b00/dependencies.ipynb">dependencies</a>)<br>

# %% [markdown]
# ### Setting up a contradiction proof by first assuming $\sqrt{2} \in \mathbb{Q}$

# %%
sqrt_2_is_rational = InSet(sqrt(two), Rational)
# Out:
# <strong id="sqrt_2_is_rational">sqrt_2_is_rational:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
defaults.assumptions = [sqrt_2_is_rational]
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/52e0313d771ce8e579ed8baa3c900855ebe4dd140/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %% [markdown]
# ### If $\sqrt{2}$ is in $\mathbb{Q}$, then $\left|\sqrt{2}\right|$ is in $\mathbb{Q^+}$
# ***($\sqrt{2} \in \mathbb{Q^+}$ as well by convention, but this proof is really about showing that no squared rational number is equal to $2$.)***

# %% [markdown]
# #### We know that a non-zero rational raised to a rational power is non-zero.

# %%
sqrt(two).deduce_not_zero()
# Out:
# |- sqrt(2) != 0

# %% [markdown]
# #### The absolute value of a non-zero rational is a positive rational.

# %%
abs_sqrt_2_is_rational_pos = InSet(Abs(sqrt(two)), RationalPos).prove()
# Out:
# <strong id="abs_sqrt_2_is_rational_pos">abs_sqrt_2_is_rational_pos:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4d9db93b8ddc8c704dec5cd1d164675fe749c8d20/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/640109496aa750cc5c215ecf432bd781fd5a5fb30/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Choose relatively prime $a^*$ and $b^*$ such $\left| \sqrt{2} \right| = a^* / b^*$ assuming $\sqrt{2} \in \mathbb{Q}$
# #### (Relatively prime means there are no nontrivial common divisors; that is, $gcd(a^*, b^*) = 1$ where $gcd$ is the "greatest common divisor")

# %%
abs_sqrt_2_is_rational_pos.choose_reduced_rational_fraction(a_star, b_star)
# Out:
# Creating Skolem 'constant(s)': (a_star, b_star).
# Call the Judgment.eliminate(a_star, b_star) to complete the Skolemization
# (when the 'constant(s)' are no longer needed).
# Adding to defaults.assumptions:
# (a_star in NaturalPos, b_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1))

# %% [markdown]
# ### From $\sqrt{2} = a^* / b^*$, derive $2 \cdot (b^*)^2 = (a^*)^2$

# %%
sqrt_2_equation = Equals(Abs(sqrt(two)), frac(a_star, b_star)).prove()
# Out:
# <strong id="sqrt_2_equation">sqrt_2_equation:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/ec68afdda9efa1af3792b4825ef19e954132b3170/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/2d5758ce0d8e8d47a526223df85e3e905d556ef10/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sqrt_2_equation = sqrt_2_equation.right_mult_both_sides(b_star)
# Out:
# <strong id="sqrt_2_equation">sqrt_2_equation:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/9d64314629d39fc0a2bae3aface91f722f9612fa0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/79a0e5f61af59ab50ee76ce983474a855a1fa1640/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sqrt_2_equation = sqrt_2_equation.square_both_sides()
# Out:
# <strong id="sqrt_2_equation">sqrt_2_equation:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/44a75a7f2438e05d8bafbea6f1646daa64069b570/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/09b267e9bd6429fa51675bb11c5bd52ac7e8656c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_bStar_sqrd__eq__a_star_sqrd = sqrt_2_equation.inner_expr().lhs.distribute()
# Out:
# <strong id="two_bStar_sqrd__eq__a_star_sqrd">two_bStar_sqrd__eq__a_star_sqrd:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/2b282df58e891233505c22d1a23dc384569891490/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/3bfd5233f3cd8f54a33c8dcdfaede4ef5f98836e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Now prove that $2~|~a^*$ via $2 \cdot (b^*)^2 = (a^*)^2$

# %%
InSet(Exp(b_star, two), NaturalPos).prove()
# Out:
# {b_star in NaturalPos} |- (b_star)^{2} in NaturalPos

# %% [markdown]
# #### Proving $2~|~(2 \cdot (b^*)^2)$ is trivial knowing $(b^*)^2 \in \mathbb{N^+}$

# %%
two_divides_two_bStar_sqrd = Divides(two, Mult(two, Exp(b_star, two))).prove()
# Out:
# <strong id="two_divides_two_bStar_sqrd">two_divides_two_bStar_sqrd:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/efafeee919d330921164db71ccac0cfe3be941000/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/34ab4dba5cb279aaa2f640fb6a9370ce90a4520d0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_bStar_sqrd__eq__a_star_sqrd.sub_right_side_into(two_divides_two_bStar_sqrd)
# Out:
# {b_star in NaturalPos, sqrt(2) in Rational, a_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | (a_star)^{2}

# %% [markdown]
# #### $2~|~(a^*)$ was proven as a side-effect of  $2~|~(a^*)^2$ since any integer is even if its square is even

# %%
two_divides_a_star = Divides(two, a_star).prove()
# Out:
# <strong id="two_divides_a_star">two_divides_a_star:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/20f08657d2164ab645f24a2c4fa4803326d446d90/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/e11da69c054bdd7cadfadd11ad933ae08bba69690/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Next derive $2~|~b^*$ from $2 \cdot (b^*)^2 = (a^*)^2$ and $2~|~(a^*)$ in a few steps
# #### Derive $2^{2}~|~(a^{*})^{2}$ from $2~|~(a^{*})$

# %%
two_sqrd__divides__a_star_sqrd = \
    two_divides_a_star.introduce_common_exponent(two, auto_simplify=False)
# Out:
# <strong id="two_sqrd__divides__a_star_sqrd">two_sqrd__divides__a_star_sqrd:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/143c6dadb4caf4ff149a97686b073a45b79742fe0/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/0763d4122b1f8edad03c2c034389b32fdaecf2430/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Derive $2^{2}~|~2 \cdot (b^{*})^2$ from $2^{2}~|~(a^{*})^2$

# %%
two_sqrd__divides__two_bStar_sqrd = \
    two_bStar_sqrd__eq__a_star_sqrd.sub_left_side_into(
        two_sqrd__divides__a_star_sqrd)
# Out:
# <strong id="two_sqrd__divides__two_bStar_sqrd">two_sqrd__divides__two_bStar_sqrd:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/bc2b04a7c040665fa01ac8e7cb08f572026fa7970/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/182d8a6436dd268687e622443e244ac0cfbdcd3e0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# #### Derive $2~|~(b^*)^2$ from $2^{2}~|~2 \cdot (b^{*})^2$

# %%
two_sqrd__eq__two_times_two = Exp(two, two).expansion(auto_simplify=False)
# Out:
# <strong id="two_sqrd__eq__two_times_two">two_sqrd__eq__two_times_two:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/dd64fb939b1c94137aec3b76f0130aa89f4de4b60/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/fccbca61d3d16bc586192ba061603c6b2b48d7810/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_sqrd__eq__two_times_two.sub_right_side_into(
    two_sqrd__divides__two_bStar_sqrd)
# Out:
# {a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (2 * 2) | (2 * (b_star)^{2})

# %%
Divides(two, Exp(b_star, two)).prove()
# Out:
# {b_star in NaturalPos, a_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | (b_star)^{2}

# %% [markdown]
# #### Finally, derive $2~|~(b^*)$ from $2~|~(b^*)^2$

# %%
two_divides_bStar = Divides(two, b_star).prove()
# Out:
# <strong id="two_divides_bStar">two_divides_bStar:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/1616ce6f85b7f46399473f64ae2b66d60cc102760/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/cea89397de65c4953175db631ca97a98e0fb3a260/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Prove a contradiction given that $2~|~(a^*)$, $2~|~(b^*)$, and $a^*$ and $b^*$ were chosen to be relatively prime

# %%
a_star_bStar_relatively_prime = GCD(a_star, b_star).deduce_relatively_prime()
# Out:
# <strong id="a_star_bStar_relatively_prime">a_star_bStar_relatively_prime:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/b94060e5504e57c9eed1f3b64aa03601fd8537580/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/ce2d34a32185ec958e86aa90383e21025c38d3840/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
two_does_not_divide_both = a_star_bStar_relatively_prime.instantiate({p:two})
# Out:
# <strong id="two_does_not_divide_both">two_does_not_divide_both:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/0085ee3d089f77b402756b2f954f0d1a45b172060/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/42d538df167b73c29abb63c658b64ecd29cdcb440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
contradiction_with_choices = two_does_not_divide_both.derive_contradiction()
# Out:
# <strong id="contradiction_with_choices">contradiction_with_choices:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/69b479719ac63f54970c58265178e6cdca99a9ce0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/440287a858afc266c62f886d5a15a7476af8640a0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a>, <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4071a8894b1d6bb90c0496c7d4ef7c27f4e761980/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/4e2b1f6c67a8b996809c48612122727bff895f460/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../logic/booleans/__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Use the existence of $a^*$ and $b^*$, assuming $\sqrt{2} \in \mathbb{Q}$, to eliminate extra assumptions (effective Skolemization)

# %%
contradiction = contradiction_with_choices.eliminate(a_star, b_star)
# Out:
# <strong id="contradiction">contradiction:</strong> <span style="font-size:20px;"><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/62b6503c8b6feb454a4c351de76f67644ce041fa0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/263509cb9345b2b3b439e302211872a48ddb8e570/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../../../logic/booleans/__pv_it/common/e0f123f2e4f322e1eba7f861749cda9fd9d99a120/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %% [markdown]
# ### Prove $\sqrt{2} \notin \mathbb{Q}$ via contradiction

# %%
sqrt2_impl_F = contradiction.as_implication(hypothesis=sqrt_2_is_rational)
# Out:
# <strong id="sqrt2_impl_F">sqrt2_impl_F:</strong> <span style="font-size:20px;"> <a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/ba05c9f3742d114938e6f231fe1a25bdcd043c310/proof.ipynb" style="text-decoration: none">&nbsp;&#x22A2;&nbsp;&nbsp;</a><a class="ProveItLink" href="../../../__pv_it/_proof_sqrt2_is_not_rational/9d054eb3d95f6b1cb601d02021d1e0f2bc28e21c0/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a></span><br>

# %%
sqrt2_impl_F.deny_antecedent(assumptions=[])
# Out:
# |- [not](sqrt(2) in Rational)
# sqrt2_is_not_rational has been proven.  Now simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.exponentiation.sqrt2_is_not_rational has been proven.
# 	step type	requirements	statement
# 0	instantiation	1, 2	|- sqrt(2) not-in Rational
# 	x : sqrt(2), S : Rational
# 1	theorem		|- forall_{x, S | [not](x in S)} (x not-in S)
# 	proveit.logic.sets.membership.fold_not_in_set
# 2	instantiation	3, 4, 5, 6	|- [not](sqrt(2) in Rational)
# 	A : sqrt(2) in Rational, B : FALSE
# 3	theorem		|- forall_{A in BOOLEAN} [forall_{B | A => B, [not](B)} [not](A)]
# 	proveit.logic.booleans.implication.modus_tollens_denial
# 4	instantiation	7	|- (sqrt(2) in Rational) in BOOLEAN
# 	x : sqrt(2)
# 5	deduction	8	|- (sqrt(2) in Rational) => FALSE
# 6	theorem		|- [not](FALSE)
# 	proveit.logic.booleans.negation.not_false
# 7	conjecture		|- forall_{x} ((x in Rational) in BOOLEAN)
# 	proveit.numbers.number_sets.rational_numbers.rational_membership_is_bool
# 8	modus ponens	9, 10	{sqrt(2) in Rational} |- FALSE
# 9	instantiation	11, 12, 13, 151	|- ([exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)]) => FALSE
# 	n : 2, P(a, b) : (|sqrt(2)| = (a / b)) and (gcd(a, b) = 1), Q(a, b) : (a in NaturalPos) and (b in NaturalPos), alpha : FALSE, (y_{1}, ..., y_{2}) : (a, b), (x_{1}, ..., x_{2}) : (a_star, b_star)
# 10	instantiation	23, 14, 15	{sqrt(2) in Rational} |- [exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))] and [forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)]
# 	A : exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1)), B : forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)
# 11	theorem		|- forall_{n in NaturalPos} [forall_{P, Q, alpha} (([exists_{y_{1}, y_{2}, ..., y_{n} | Q(y_{1}, y_{2}, ..., y_{n})} P(y_{1}, y_{2}, ..., y_{n})] and [forall_{x_{1}, x_{2}, ..., x_{n} | Q(x_{1}, x_{2}, ..., x_{n})} (P(x_{1}, x_{2}, ..., x_{n}) => alpha)]) => alpha)]
# 	proveit.logic.booleans.quantification.existence.skolem_elim
# 12	instantiation	16	|- |(a_star, b_star)| = |(1, ..., 2)|
# 	a : a_star, b : b_star
# 13	instantiation	16	|- |(a, b)| = |(1, ..., 2)|
# 	a : a, b : b
# 14	instantiation	17, 94	{sqrt(2) in Rational} |- exists_{a, b in NaturalPos} ((|sqrt(2)| = (a / b)) and (gcd(a, b) = 1))
# 	q : |sqrt(2)|
# 15	generalization	18	{sqrt(2) in Rational} |- forall_{a_star, b_star in NaturalPos} (((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE)
# 16	conjecture		|- forall_{a, b} (|(a, b)| = |(1, ..., 2)|)
# 	proveit.numbers.numerals.decimals.tuple_len_2_typical_eq
# 17	conjecture		|- forall_{q in RationalPos} [exists_{a, b in NaturalPos} ((q = (a / b)) and (gcd(a, b) = 1))]
# 	proveit.numbers.number_sets.rational_numbers.reduced_nat_pos_ratio
# 18	deduction	19	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational} |- ((|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)) => FALSE
# 19	instantiation	20, 21, 22	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- FALSE
# 	A : (2 | a_star) and (2 | b_star)
# 20	theorem		|- forall_{A | A, [not](A)} FALSE
# 	proveit.logic.booleans.negation.negation_contradiction
# 21	instantiation	23, 42, 24	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (2 | a_star) and (2 | b_star)
# 	A : 2 | a_star, B : 2 | b_star
# 22	instantiation	25, 151, 26	{a_star in NaturalPos, b_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- [not]((2 | a_star) and (2 | b_star))
# 	p : 2
# 23	theorem		|- forall_{A, B | A, B} (A and B)
# 	proveit.logic.booleans.conjunction.and_if_both
# 24	instantiation	43, 27, 75, 28	{b_star in NaturalPos, a_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | b_star
# 	a : b_star, n : 2
# 25	instantiation	29, 131, 154, 30	{a_star in NaturalPos, b_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- forall_{p in NaturalPos | p > 1} [not]((p | a_star) and (p | b_star))
# 	a : a_star, b : b_star
# 26	conjecture		|- 1 < 2
# 	proveit.numbers.numerals.decimals.less_1_2
# 27	instantiation	149, 54, 154	{b_star in NaturalPos} |- b_star in Integer
# 	A : NaturalPos, B : Integer, x : b_star
# 28	instantiation	31, 49, 32, 33, 51	{b_star in NaturalPos, a_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | (b_star)^{2}
# 	a : 2, b : (b_star)^{2}, k : 2
# 29	conjecture		|- forall_{a, b in NaturalPos | gcd(a, b) = 1} [forall_{p in NaturalPos | p > 1} [not]((p | a) and (p | b))]
# 	proveit.numbers.divisibility.GCD_one_def
# 30	instantiation	34, 79	{(|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- gcd(a_star, b_star) = 1
# 	A : |sqrt(2)| = (a_star / b_star), B : gcd(a_star, b_star) = 1
# 31	conjecture		|- forall_{a, b, k in Complex | (k * a) | (k * b), k != 0} (a | b)
# 	proveit.numbers.divisibility.common_factor_elimination
# 32	instantiation	149, 144, 35	{b_star in NaturalPos} |- (b_star)^{2} in Complex
# 	A : Real, B : Complex, x : (b_star)^{2}
# 33	instantiation	86, 36, 37	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (2 * 2) | (2 * (b_star)^{2})
# 	P(_a) : _a | (2 * (b_star)^{2}), x : 2^{2}, y : 2 * 2
# 34	theorem		|- forall_{A, B | A, B} B
# 	proveit.logic.booleans.conjunction.right_from_and
# 35	instantiation	152, 153, 55	{b_star in NaturalPos} |- (b_star)^{2} in Real
# 	A : NaturalPos, B : Real, x : (b_star)^{2}
# 36	instantiation	38, 39, 47	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2^{2} | (2 * (b_star)^{2})
# 	P(_a) : 2^{2} | _a, x : 2 * (b_star)^{2}, y : (a_star)^{2}
# 37	instantiation	40, 49	|- 2^{2} = (2 * 2)
# 	x : 2
# 38	theorem		|- forall_{P, x, y | P(y), x = y} P(x)
# 	proveit.logic.equality.sub_left_side_into
# 39	instantiation	41, 75, 44, 151, 42	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2^{2} | (a_star)^{2}
# 	k : 2, a : a_star, n : 2
# 40	conjecture		|- forall_{x in Complex} (x^{2} = (x * x))
# 	proveit.numbers.exponentiation.square_expansion
# 41	conjecture		|- forall_{k in Integer, a in Integer, n in NaturalPos | k | a} (k^{n} | a^{n})
# 	proveit.numbers.divisibility.common_exponent_introduction
# 42	instantiation	43, 44, 75, 45	{a_star in NaturalPos, b_star in NaturalPos, sqrt(2) in Rational, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | a_star
# 	a : a_star, n : 2
# 43	conjecture		|- forall_{a, n in Integer | 2 | a^{n}} (2 | a)
# 	proveit.numbers.divisibility.even__if__power_is_even
# 44	instantiation	149, 54, 131	{a_star in NaturalPos} |- a_star in Integer
# 	A : NaturalPos, B : Integer, x : a_star
# 45	instantiation	86, 46, 47	{b_star in NaturalPos, sqrt(2) in Rational, a_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- 2 | (a_star)^{2}
# 	P(_a) : 2 | _a, x : 2 * (b_star)^{2}, y : (a_star)^{2}
# 46	instantiation	48, 49, 50, 51	{b_star in NaturalPos} |- 2 | (2 * (b_star)^{2})
# 	x : 2, y : (b_star)^{2}
# 47	instantiation	86, 52, 53	{sqrt(2) in Rational, b_star in NaturalPos, a_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (2 * (b_star)^{2}) = (a_star)^{2}
# 	P(_a) : _a = (a_star)^{2}, x : (|sqrt(2)| * b_star)^{2}, y : 2 * (b_star)^{2}
# 48	conjecture		|- forall_{x in Complex, y in Integer | x != 0} (x | (x * y))
# 	proveit.numbers.divisibility.left_factor_divisibility
# 49	instantiation	149, 144, 57	|- 2 in Complex
# 	A : Real, B : Complex, x : 2
# 50	instantiation	149, 54, 55	{b_star in NaturalPos} |- (b_star)^{2} in Integer
# 	A : NaturalPos, B : Integer, x : (b_star)^{2}
# 51	instantiation	85, 151	|- 2 != 0
# 	n : 2
# 52	instantiation	56, 57, 58, 122, 59	{sqrt(2) in Rational, b_star in NaturalPos, a_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (|sqrt(2)| * b_star)^{2} = (a_star)^{2}
# 	a : 2, x : |sqrt(2)| * b_star, y : a_star
# 53	instantiation	60, 61, 138, 151, 62*	{sqrt(2) in Rational, b_star in NaturalPos} |- (|sqrt(2)| * b_star)^{2} = (2 * (b_star)^{2})
# 	a : |sqrt(2)|, b : b_star, n : 2
# 54	conjecture		|- NaturalPos proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_pos_within_int
# 55	instantiation	63, 64, 96	{b_star in NaturalPos} |- (b_star)^{2} in NaturalPos
# 	a : b_star, b : 2
# 56	conjecture		|- forall_{a, x, y in Real | x = y} (x^{a} = y^{a})
# 	proveit.numbers.exponentiation.exp_eq_real
# 57	instantiation	149, 132, 65	|- 2 in Real
# 	A : Rational, B : Real, x : 2
# 58	instantiation	66, 71, 145	{sqrt(2) in Rational, b_star in NaturalPos} |- (|sqrt(2)| * b_star) in Real
# 	a : |sqrt(2)|, b : b_star
# 59	instantiation	67, 145, 71, 68, 69, 70*	{b_star in NaturalPos, sqrt(2) in Rational, a_star in NaturalPos, (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (|sqrt(2)| * b_star) = a_star
# 	a : b_star, x : |sqrt(2)|, y : a_star / b_star
# 60	conjecture		|- forall_{a in Complex, b in Complex, n in NaturalPos} ((a * b)^{n} = (a^{n} * b^{n}))
# 	proveit.numbers.exponentiation.posnat_power_of_product
# 61	instantiation	149, 144, 71	{sqrt(2) in Rational} |- |sqrt(2)| in Complex
# 	A : Real, B : Complex, x : |sqrt(2)|
# 62	instantiation	72, 114, 73*	{sqrt(2) in Rational} |- |sqrt(2)|^{2} = 2
# 	a : sqrt(2)
# 63	conjecture		|- forall_{a, b in Natural} (a^{b} in NaturalPos)
# 	proveit.numbers.exponentiation.exp_natpos_closure
# 64	instantiation	149, 74, 154	{b_star in NaturalPos} |- b_star in Natural
# 	A : NaturalPos, B : Natural, x : b_star
# 65	instantiation	149, 139, 75	|- 2 in Rational
# 	A : Integer, B : Rational, x : 2
# 66	conjecture		|- forall_{a, b in Real} ((a * b) in Real)
# 	proveit.numbers.multiplication.mult_real_closure_bin
# 67	conjecture		|- forall_{a, x, y in Real | x = y} ((x * a) = (y * a))
# 	proveit.numbers.multiplication.right_mult_eq_real
# 68	instantiation	76, 122, 145, 77	{a_star in NaturalPos, b_star in NaturalPos} |- (a_star / b_star) in Real
# 	a : a_star, b : b_star
# 69	instantiation	78, 79	{(|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- |sqrt(2)| = (a_star / b_star)
# 	A : |sqrt(2)| = (a_star / b_star), B : gcd(a_star, b_star) = 1
# 70	instantiation	86, 80, 81	{a_star in NaturalPos, b_star in NaturalPos} |- ((a_star / b_star) * b_star) = a_star
# 	P(_a) : ((a_star / b_star) * b_star) = _a, x : (a_star / 1) * (1 / 1), y : a_star
# 71	instantiation	149, 132, 82	{sqrt(2) in Rational} |- |sqrt(2)| in Real
# 	A : Rational, B : Real, x : |sqrt(2)|
# 72	conjecture		|- forall_{a in Rational} (|a|^{2} = a^{2})
# 	proveit.numbers.exponentiation.square_abs_rational_simp
# 73	instantiation	83, 151, 84	|- (sqrt(2))^{2} = 2
# 	n : 2, x : 2
# 74	conjecture		|- NaturalPos proper_subset Natural
# 	proveit.numbers.number_sets.natural_numbers.nat_pos_within_nat
# 75	instantiation	149, 146, 96	|- 2 in Integer
# 	A : Natural, B : Integer, x : 2
# 76	conjecture		|- forall_{a, b in Real | b != 0} ((a / b) in Real)
# 	proveit.numbers.division.div_real_closure
# 77	instantiation	85, 154	{b_star in NaturalPos} |- b_star != 0
# 	n : b_star
# 78	theorem		|- forall_{A, B | A, B} A
# 	proveit.logic.booleans.conjunction.left_from_and
# 79	assumption		{(|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)} |- (|sqrt(2)| = (a_star / b_star)) and (gcd(a_star, b_star) = 1)
# 80	instantiation	86, 87, 88	{a_star in NaturalPos, b_star in NaturalPos} |- ((a_star / b_star) * b_star) = ((a_star / 1) * (1 / 1))
# 	P(_a) : _a = ((a_star / 1) * (1 / 1)), x : (a_star / (1 * b_star)) * ((b_star * 1) / 1), y : (a_star / b_star) * b_star
# 81	instantiation	89, 90, 91, 92	{a_star in NaturalPos} |- ((a_star / 1) * (1 / 1)) = a_star
# 	a : (a_star / 1) * (1 / 1), b : a_star * (1 / 1), c : a_star * 1, d : a_star
# 82	instantiation	149, 93, 94	{sqrt(2) in Rational} |- |sqrt(2)| in Rational
# 	A : RationalPos, B : Rational, x : |sqrt(2)|
# 83	conjecture		|- forall_{n in NaturalPos} [forall_{x | x >= 0} ((n radical(x))^{n} = x)]
# 	proveit.numbers.exponentiation.nth_power_of_nth_root
# 84	instantiation	95, 96	|- 0 <= 2
# 	n : 2
# 85	conjecture		|- forall_{n in NaturalPos} (n != 0)
# 	proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos
# 86	theorem		|- forall_{P, x, y | P(x), x = y} P(y)
# 	proveit.logic.equality.sub_right_side_into
# 87	instantiation	97, 111, 112, 98, 99	{a_star in NaturalPos, b_star in NaturalPos} |- ((a_star / (1 * b_star)) * ((b_star * 1) / 1)) = ((a_star / 1) * (1 / 1))
# 	a : a_star, d : 1, b : 1, c : b_star, e : 1
# 88	instantiation	119, 100, 101	{b_star in NaturalPos} |- ((a_star / (1 * b_star)) * ((b_star * 1) / 1)) = ((a_star / b_star) * b_star)
# 	x : (a_star / (1 * b_star)) * ((b_star * 1) / 1), y : (a_star / b_star) * ((b_star * 1) / 1), z : (a_star / b_star) * b_star
# 89	conjecture		|- forall_{a, b, c, d | a = b, b = c, c = d} (a = d)
# 	proveit.logic.equality.four_chain_transitivity
# 90	instantiation	128, 102	{a_star in NaturalPos} |- ((a_star / 1) * (1 / 1)) = (a_star * (1 / 1))
# 	f(_a) : _a * (1 / 1), x : a_star / 1, y : a_star
# 91	instantiation	128, 103	|- (a_star * (1 / 1)) = (a_star * 1)
# 	f(_a) : a_star * _a, x : 1 / 1, y : 1
# 92	instantiation	137, 111	{a_star in NaturalPos} |- (a_star * 1) = a_star
# 	x : a_star
# 93	conjecture		|- RationalPos proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.rational_pos_within_rational
# 94	instantiation	104, 105	{sqrt(2) in Rational} |- |sqrt(2)| in RationalPos
# 	a : sqrt(2)
# 95	conjecture		|- forall_{n in Natural} (n >= 0)
# 	proveit.numbers.number_sets.natural_numbers.natural_lower_bound
# 96	theorem		|- 2 in Natural
# 	proveit.numbers.numerals.decimals.nat2
# 97	conjecture		|- forall_{a, d in Complex} [forall_{b, c, e in ComplexNonZero} (((a / (b * c)) * ((c * d) / e)) = ((a / b) * (d / e)))]
# 	proveit.numbers.division.mult_frac_cancel_denom_left
# 98	instantiation	149, 107, 106	|- 1 in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : 1
# 99	instantiation	149, 107, 108	{b_star in NaturalPos} |- b_star in ComplexNonZero
# 	A : RealNonZero, B : ComplexNonZero, x : b_star
# 100	instantiation	128, 109	{b_star in NaturalPos} |- ((a_star / (1 * b_star)) * ((b_star * 1) / 1)) = ((a_star / b_star) * ((b_star * 1) / 1))
# 	f(_a) : _a * ((b_star * 1) / 1), x : a_star / (1 * b_star), y : a_star / b_star
# 101	instantiation	128, 110	{b_star in NaturalPos} |- ((a_star / b_star) * ((b_star * 1) / 1)) = ((a_star / b_star) * b_star)
# 	f(_a) : (a_star / b_star) * _a, x : (b_star * 1) / 1, y : b_star
# 102	instantiation	130, 111	{a_star in NaturalPos} |- (a_star / 1) = a_star
# 	x : a_star
# 103	instantiation	130, 112	|- (1 / 1) = 1
# 	x : 1
# 104	conjecture		|- forall_{a in RationalNonZero} (|a| in RationalPos)
# 	proveit.numbers.absolute_value.abs_rational_nonzero_closure
# 105	instantiation	113, 114, 115	{sqrt(2) in Rational} |- sqrt(2) in RationalNonZero
# 	q : sqrt(2)
# 106	instantiation	149, 116, 135	|- 1 in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : 1
# 107	conjecture		|- RealNonZero proper_subset ComplexNonZero
# 	proveit.numbers.number_sets.complex_numbers.real_nonzero_within_complex_nonzero
# 108	instantiation	149, 116, 117	{b_star in NaturalPos} |- b_star in RealNonZero
# 	A : RationalNonZero, B : RealNonZero, x : b_star
# 109	instantiation	128, 118	{b_star in NaturalPos} |- (a_star / (1 * b_star)) = (a_star / b_star)
# 	f(_a) : a_star / _a, x : 1 * b_star, y : b_star
# 110	instantiation	119, 120, 121	{b_star in NaturalPos} |- ((b_star * 1) / 1) = b_star
# 	x : (b_star * 1) / 1, y : b_star / 1, z : b_star
# 111	instantiation	149, 144, 122	{a_star in NaturalPos} |- a_star in Complex
# 	A : Real, B : Complex, x : a_star
# 112	instantiation	149, 144, 123	|- 1 in Complex
# 	A : Real, B : Complex, x : 1
# 113	conjecture		|- forall_{q in Rational | q != 0} (q in RationalNonZero)
# 	proveit.numbers.number_sets.rational_numbers.nonzero_rational_is_rational_nonzero
# 114	assumption		{sqrt(2) in Rational} |- sqrt(2) in Rational
# 115	instantiation	124, 136, 125	|- sqrt(2) != 0
# 	a : 2, b : 1 / 2
# 116	conjecture		|- RationalNonZero proper_subset RealNonZero
# 	proveit.numbers.number_sets.real_numbers.rational_nonzero_within_real_nonzero
# 117	instantiation	149, 142, 126	{b_star in NaturalPos} |- b_star in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : b_star
# 118	instantiation	127, 138	{b_star in NaturalPos} |- (1 * b_star) = b_star
# 	x : b_star
# 119	axiom		|- forall_{x, y, z | x = y, y = z} (x = z)
# 	proveit.logic.equality.equals_transitivity
# 120	instantiation	128, 129	{b_star in NaturalPos} |- ((b_star * 1) / 1) = (b_star / 1)
# 	f(_a) : _a / 1, x : b_star * 1, y : b_star
# 121	instantiation	130, 138	{b_star in NaturalPos} |- (b_star / 1) = b_star
# 	x : b_star
# 122	instantiation	152, 153, 131	{a_star in NaturalPos} |- a_star in Real
# 	A : NaturalPos, B : Real, x : a_star
# 123	instantiation	149, 132, 133	|- 1 in Real
# 	A : Rational, B : Real, x : 1
# 124	conjecture		|- forall_{a, b in RationalNonZero} (a^{b} != 0)
# 	proveit.numbers.exponentiation.exp_rational_non_zero__not_zero
# 125	instantiation	134, 135, 136	|- (1 / 2) in RationalNonZero
# 	a : 1, b : 2
# 126	instantiation	149, 150, 154	{b_star in NaturalPos} |- b_star in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : b_star
# 127	conjecture		|- forall_{x in Complex} ((1 * x) = x)
# 	proveit.numbers.multiplication.elim_one_left
# 128	axiom		|- forall_{f, x, y | x = y} (f(x) = f(y))
# 	proveit.logic.equality.substitution
# 129	instantiation	137, 138	{b_star in NaturalPos} |- (b_star * 1) = b_star
# 	x : b_star
# 130	conjecture		|- forall_{x in Complex} ((x / 1) = x)
# 	proveit.numbers.division.frac_one_denom
# 131	assumption		{a_star in NaturalPos} |- a_star in NaturalPos
# 132	conjecture		|- Rational proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.rational_within_real
# 133	instantiation	149, 139, 140	|- 1 in Rational
# 	A : Integer, B : Rational, x : 1
# 134	conjecture		|- forall_{a, b in RationalNonZero} ((a / b) in RationalNonZero)
# 	proveit.numbers.division.div_rational_nonzero_closure
# 135	instantiation	149, 142, 141	|- 1 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 1
# 136	instantiation	149, 142, 143	|- 2 in RationalNonZero
# 	A : IntegerNonZero, B : RationalNonZero, x : 2
# 137	conjecture		|- forall_{x in Complex} ((x * 1) = x)
# 	proveit.numbers.multiplication.elim_one_right
# 138	instantiation	149, 144, 145	{b_star in NaturalPos} |- b_star in Complex
# 	A : Real, B : Complex, x : b_star
# 139	conjecture		|- Integer proper_subset Rational
# 	proveit.numbers.number_sets.rational_numbers.int_within_rational
# 140	instantiation	149, 146, 147	|- 1 in Integer
# 	A : Natural, B : Integer, x : 1
# 141	instantiation	149, 150, 148	|- 1 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 1
# 142	conjecture		|- IntegerNonZero proper_subset RationalNonZero
# 	proveit.numbers.number_sets.rational_numbers.nonzero_int_within_rational_nonzero
# 143	instantiation	149, 150, 151	|- 2 in IntegerNonZero
# 	A : NaturalPos, B : IntegerNonZero, x : 2
# 144	conjecture		|- Real proper_subset Complex
# 	proveit.numbers.number_sets.complex_numbers.real_within_complex
# 145	instantiation	152, 153, 154	{b_star in NaturalPos} |- b_star in Real
# 	A : NaturalPos, B : Real, x : b_star
# 146	conjecture		|- Natural proper_subset Integer
# 	proveit.numbers.number_sets.integers.nat_within_int
# 147	theorem		|- 1 in Natural
# 	proveit.numbers.numerals.decimals.nat1
# 148	conjecture		|- 1 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat1
# 149	theorem		|- forall_{A, B | A proper_subset B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.superset_membership_from_proper_subset
# 150	conjecture		|- NaturalPos proper_subset IntegerNonZero
# 	proveit.numbers.number_sets.integers.nat_pos_within_nonzero_int
# 151	conjecture		|- 2 in NaturalPos
# 	proveit.numbers.numerals.decimals.posnat2
# 152	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 153	instantiation	155, 156	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 154	assumption		{b_star in NaturalPos} |- b_star in NaturalPos
# 155	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 156	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
