# %% [markdown]
# Proof of <a class="ProveItLink" href="../../../../../../_theory_nbs_/theory.ipynb">proveit</a>.<a class="ProveItLink" href="../../../../../_theory_nbs_/theory.ipynb">numbers</a>.<a class="ProveItLink" href="../../../../_theory_nbs_/theory.ipynb">number_sets</a>.<a class="ProveItLink" href="../../theory.ipynb">natural_numbers</a>.<a class="ProveItLink" href="../../theorems.ipynb#nonzero_if_is_nat_pos">nonzero_if_is_nat_pos</a> theorem
# ========

# %%
import proveit
from proveit import defaults
from proveit import a, b, n
from proveit.numbers import zero, one, greater, greater_eq
theory = proveit.Theory() # the theorem's theory

# %%
# %proving nonzero_if_is_nat_pos
# Out:
# Under these <a href="presumptions.txt">presumptions</a>, we begin our proof of<br><strong id="nonzero_if_is_nat_pos">nonzero_if_is_nat_pos:</strong> <a class="ProveItLink" href="../../../__pv_it/theorems/2da89c571229ffc57db13a7e9b9b2d58a4b513440/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>(see <a class="ProveItLink" href="../../../__pv_it/theorems/6b94bcd1d8eb42e3c3cdc7e765fb8dda184545770/dependencies.ipynb">dependencies</a>)<br>

# %%
defaults.assumptions = nonzero_if_is_nat_pos.conditions
# Out:
# <strong id="defaults.assumptions">defaults.assumptions:</strong> <a class="ProveItLink" href="../../../__pv_it/_proof_nonzero_if_is_nat_pos/15978e039a9ffdbed4cfcaf3be88bb0eab6dd0970/expr.ipynb"><img src="..." style="display:inline;vertical-align:middle;" /></a><br>

# %%
greater(n, zero).conclude_via_transitivity()
# Out:
# {n in NaturalPos} |- n > 0
# nonzero_if_is_nat_pos is now readily provable.  Simply execute "%qed".

# %%
# %qed
# Out:
# proveit.numbers.number_sets.natural_numbers.nonzero_if_is_nat_pos has been proven.
# 	step type	requirements	statement
# 0	generalization	1	|- forall_{n in NaturalPos} (n != 0)
# 1	instantiation	2, 3	{n in NaturalPos} |- n != 0
# 	x : 0, y : n
# 2	theorem		|- forall_{x, y | x != y} (y != x)
# 	proveit.logic.equality.not_equals_symmetry
# 3	instantiation	4, 5, 6, 7	{n in NaturalPos} |- 0 != n
# 	a : 0, b : n
# 4	conjecture		|- forall_{a, b in Real | a < b} (a != b)
# 	proveit.numbers.ordering.less_is_not_eq
# 5	instantiation	10, 8, 9	|- 0 in Real
# 	A : Natural, B : Real, x : 0
# 6	instantiation	10, 11, 19	{n in NaturalPos} |- n in Real
# 	A : NaturalPos, B : Real, x : n
# 7	instantiation	12, 13, 14	{n in NaturalPos} |- n > 0
# 	x : 0, y : 1, z : n
# 8	instantiation	16, 15	|- Natural subset_eq Real
# 	A : Natural, B : Real
# 9	axiom		|- 0 in Natural
# 	proveit.numbers.number_sets.natural_numbers.zero_in_nats
# 10	theorem		|- forall_{A, B | A subset_eq B} [forall_{x in A} (x in B)]
# 	proveit.logic.sets.inclusion.unfold_subset_eq
# 11	instantiation	16, 17	|- NaturalPos subset_eq Real
# 	A : NaturalPos, B : Real
# 12	conjecture		|- forall_{x, y, z | x < y, y <= z} (x < z)
# 	proveit.numbers.ordering.transitivity_less_less_eq
# 13	conjecture		|- 0 < 1
# 	proveit.numbers.numerals.decimals.less_0_1
# 14	instantiation	18, 19	{n in NaturalPos} |- n >= 1
# 	n : n
# 15	conjecture		|- Natural proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_within_real
# 16	theorem		|- forall_{A, B | A proper_subset B} (A subset_eq B)
# 	proveit.logic.sets.inclusion.relax_proper_subset
# 17	conjecture		|- NaturalPos proper_subset Real
# 	proveit.numbers.number_sets.real_numbers.nat_pos_within_real
# 18	conjecture		|- forall_{n in NaturalPos} (n >= 1)
# 	proveit.numbers.number_sets.natural_numbers.natural_pos_lower_bound
# 19	assumption		{n in NaturalPos} |- n in NaturalPos
